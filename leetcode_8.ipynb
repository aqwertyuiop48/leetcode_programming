# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME')
    user_cookie = userdata.get('LEETCODE_TOKEN')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME'] = user_name
    os.environ['LEETCODE_TOKEN'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME" "$LEETCODE_TOKEN" | leetcode user -c

# %%
# %%bash
#
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v kotlin_solutions/*.kt | sed -n '701,$p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 7
# done
# Out:
# Submitting: kotlin_solutions/899.orderly-queue.kt
# - Downloading problems
# - Downloading orderly-queue
#   ✔ Accepted
#   ✔ 112/112 cases passed (30 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (47.2 MB)
# Submitting: kotlin_solutions/900.rle-iterator.kt
# - Downloading rle-iterator
#   ✔ Accepted
#   ✔ 11/11 cases passed (28 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
#   ✔ Your memory usage beats 20 % of kotlin submissions (46.6 MB)
# Submitting: kotlin_solutions/902.numbers-at-most-n-given-digit-set.kt
# - Downloading numbers-at-most-n-given-digit-set
#   ✔ Accepted
#   ✔ 84/84 cases passed (11 ms)
#   ✔ Your runtime beats 28.57 % of kotlin submissions
#   ✔ Your memory usage beats 57.14 % of kotlin submissions (42.5 MB)
# Submitting: kotlin_solutions/903.valid-permutations-for-di-sequence.kt
# - Downloading valid-permutations-for-di-sequence
#   ✔ Accepted
#   ✔ 83/83 cases passed (41 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/1389.create-target-array-in-the-given-order.kt
# - Downloading create-target-array-in-the-given-order
#   ✔ Accepted
#   ✔ 45/45 cases passed (20 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/1991.find-the-middle-index-in-array.kt
# - Downloading find-the-middle-index-in-array
#   ✔ Accepted
#   ✔ 294/294 cases passed (23 ms)
#   ✔ Your runtime beats 8.33 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (46.5 MB)
# Submitting: kotlin_solutions/2303.calculate-amount-paid-in-taxes.kt
# - Downloading calculate-amount-paid-in-taxes
#   ✔ Accepted
#   ✔ 227/227 cases passed (2 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/2437.number-of-valid-clock-times.kt
# - Downloading number-of-valid-clock-times
#   ✔ Accepted
#   ✔ 55/55 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (40.4 MB)
# Submitting: kotlin_solutions/2441.largest-positive-integer-that-exists-with-its-negative.kt
# - Downloading largest-positive-integer-that-exists-with-its-negative
#   ✔ Accepted
#   ✔ 339/339 cases passed (22 ms)
#   ✔ Your runtime beats 7.14 % of kotlin submissions
#   ✔ Your memory usage beats 7.14 % of kotlin submissions (50.3 MB)
# Submitting: kotlin_solutions/2446.determine-if-two-events-have-conflict.kt
# - Downloading determine-if-two-events-have-conflict
#   ✔ Accepted
#   ✔ 129/129 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 90 % of kotlin submissions (40.4 MB)
# Submitting: kotlin_solutions/2451.odd-string-difference.kt
# - Downloading odd-string-difference
#   ✔ Accepted
#   ✔ 40/40 cases passed (21 ms)
#   ✔ Your runtime beats 42.86 % of kotlin submissions
#   ✔ Your memory usage beats 42.86 % of kotlin submissions (46.1 MB)
# Submitting: kotlin_solutions/2455.average-value-of-even-numbers-that-are-divisible-by-three.kt
# - Downloading average-value-of-even-numbers-that-are-divisible-by-three
#   ✔ Accepted
#   ✔ 181/181 cases passed (22 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/2460.apply-operations-to-an-array.kt
# - Downloading apply-operations-to-an-array
#   ✔ Accepted
#   ✔ 36/36 cases passed (22 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 9.09 % of kotlin submissions (46.8 MB)
# Submitting: kotlin_solutions/2465.number-of-distinct-averages.kt
# - Downloading number-of-distinct-averages
#   ✔ Accepted
#   ✔ 36/36 cases passed (23 ms)
#   ✔ Your runtime beats 14.29 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (45.4 MB)
# Submitting: kotlin_solutions/2469.convert-the-temperature.kt
# - Downloading convert-the-temperature
#   ✔ Accepted
#   ✔ 74/74 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 11.76 % of kotlin submissions (41.6 MB)
# Submitting: kotlin_solutions/2475.number-of-unequal-triplets-in-array.kt
# - Downloading number-of-unequal-triplets-in-array
#   ✔ Accepted
#   ✔ 104/104 cases passed (40 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (47.1 MB)
# Submitting: kotlin_solutions/2481.minimum-cuts-to-divide-a-circle.kt
# - Downloading minimum-cuts-to-divide-a-circle
#   ✔ Accepted
#   ✔ 100/100 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions/2490.circular-sentence.kt
# - Downloading circular-sentence
#   ✔ Accepted
#   ✔ 266/266 cases passed (15 ms)
#   ✔ Your runtime beats 10 % of kotlin submissions
#   ✔ Your memory usage beats 20 % of kotlin submissions (44.3 MB)
# Submitting: kotlin_solutions/2496.maximum-value-of-a-string-in-an-array.kt
# - Downloading maximum-value-of-a-string-in-an-array
#   ✔ Accepted
#   ✔ 64/64 cases passed (18 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/2500.delete-greatest-value-in-each-row.kt
# - Downloading delete-greatest-value-in-each-row
#   ✔ Accepted
#   ✔ 55/55 cases passed (22 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (52.4 MB)
# Submitting: kotlin_solutions/2506.count-pairs-of-similar-strings.kt
# - Downloading count-pairs-of-similar-strings
#   ✔ Accepted
#   ✔ 225/225 cases passed (59 ms)
#   ✔ Your runtime beats 23.08 % of kotlin submissions
#   ✔ Your memory usage beats 7.69 % of kotlin submissions (50.7 MB)
# Submitting: kotlin_solutions/2513.minimize-the-maximum-of-two-arrays.kt
# - Downloading minimize-the-maximum-of-two-arrays
#   ✔ Accepted
#   ✔ 63/63 cases passed (113 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/2520.count-the-digits-that-divide-a-number.kt
# - Downloading count-the-digits-that-divide-a-number
#   ✔ Accepted
#   ✔ 56/56 cases passed (1 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/2521.distinct-prime-factors-of-product-of-array.kt
# - Downloading distinct-prime-factors-of-product-of-array
#   ✔ Accepted
#   ✔ 81/81 cases passed (227 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/2525.categorize-box-according-to-criteria.kt
# - Downloading categorize-box-according-to-criteria
#   ✔ Accepted
#   ✔ 50/50 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (40.4 MB)
# Submitting: kotlin_solutions/2527.find-xor-beauty-of-array.kt
# - Downloading find-xor-beauty-of-array
#   ✔ Accepted
#   ✔ 32/32 cases passed (12 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/2529.maximum-count-of-positive-integer-and-negative-integer.kt
# - Downloading maximum-count-of-positive-integer-and-negative-integer
#   ✔ Accepted
#   ✔ 169/169 cases passed (12 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 30 % of kotlin submissions (48.9 MB)
# Submitting: kotlin_solutions/2535.difference-between-element-sum-and-digit-sum-of-an-array.kt
# - Downloading difference-between-element-sum-and-digit-sum-of-an-array
#   ✔ Accepted
#   ✔ 142/142 cases passed (8 ms)
#   ✔ Your runtime beats 21.43 % of kotlin submissions
#   ✔ Your memory usage beats 35.71 % of kotlin submissions (48.6 MB)
# Submitting: kotlin_solutions/2536.increment-submatrices-by-one.kt
# - Downloading increment-submatrices-by-one
#   ✘ Time Limit Exceeded
#   ✘ 31/32 cases passed (N/A)
#   ✘ Testcase: 500
# ' +
#   '[[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,499,499],[0,0,4 ...
#   ✘ Answer:
#   ✘ Expected Answer: [[10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000],[10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,100 ...
#   ✘ Stdout:
# Submitting: kotlin_solutions/2540.minimum-common-value.kt
# - Downloading minimum-common-value
#   ✔ Accepted
#   ✔ 41/41 cases passed (76 ms)
#   ✔ Your runtime beats 5.45 % of kotlin submissions
#   ✔ Your memory usage beats 5.45 % of kotlin submissions (91.1 MB)
# Submitting: kotlin_solutions/2544.alternating-digit-sum.kt
# - Downloading alternating-digit-sum
#   ✔ Accepted
#   ✔ 118/118 cases passed (7 ms)
#   ✔ Your runtime beats 13.04 % of kotlin submissions
#   ✔ Your memory usage beats 13.04 % of kotlin submissions (40.9 MB)
# Submitting: kotlin_solutions/2545.sort-the-students-by-their-kth-score.kt
# - Downloading sort-the-students-by-their-kth-score
#   ✔ Accepted
#   ✔ 33/33 cases passed (16 ms)
#   ✔ Your runtime beats 21.43 % of kotlin submissions
#   ✔ Your memory usage beats 7.14 % of kotlin submissions (70.1 MB)
# Submitting: kotlin_solutions/2553.separate-the-digits-in-an-array.kt
# - Downloading separate-the-digits-in-an-array
#   ✔ Accepted
#   ✔ 52/52 cases passed (19 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions/2559.count-vowel-strings-in-ranges.kt
# - Downloading count-vowel-strings-in-ranges
#   ✔ Accepted
#   ✔ 94/94 cases passed (54 ms)
#   ✔ Your runtime beats 18.75 % of kotlin submissions
#   ✔ Your memory usage beats 18.75 % of kotlin submissions (116.6 MB)
# Submitting: kotlin_solutions/2562.find-the-array-concatenation-value.kt
# - Downloading find-the-array-concatenation-value
#   ✔ Accepted
#   ✔ 53/53 cases passed (13 ms)
#   ✔ Your runtime beats 36.36 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (46.3 MB)
# Submitting: kotlin_solutions/2563.count-the-number-of-fair-pairs.kt
# - Downloading count-the-number-of-fair-pairs
#   ✔ Accepted
#   ✔ 55/55 cases passed (299 ms)
#   ✔ Your runtime beats 12.5 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (84.6 MB)
# Submitting: kotlin_solutions/2566.maximum-difference-by-remapping-a-digit.kt
# - Downloading maximum-difference-by-remapping-a-digit
#   ✔ Accepted
#   ✔ 214/214 cases passed (12 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/2570.merge-two-2-d-arrays-by-summing-values.kt
# - Downloading merge-two-2d-arrays-by-summing-values
#   ✔ Accepted
#   ✔ 39/39 cases passed (17 ms)
#   ✔ Your runtime beats 14.29 % of kotlin submissions
#   ✔ Your memory usage beats 7.14 % of kotlin submissions (54.1 MB)
# Submitting: kotlin_solutions/2574.left-and-right-sum-differences.kt
# - Downloading left-and-right-sum-differences
#   ✔ Accepted
#   ✔ 53/53 cases passed (100 ms)
#   ✔ Your runtime beats 5.56 % of kotlin submissions
#   ✔ Your memory usage beats 11.11 % of kotlin submissions (50.4 MB)
# Submitting: kotlin_solutions/2575.find-the-divisibility-array-of-a-string.kt
# - Downloading find-the-divisibility-array-of-a-string
#   ✔ Accepted
#   ✔ 51/51 cases passed (56 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/2578.split-with-minimum-sum.kt
# - Downloading split-with-minimum-sum
#   ✔ Accepted
#   ✔ 140/140 cases passed (22 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/2582.pass-the-pillow.kt
# - Downloading pass-the-pillow
#   ✔ Accepted
#   ✔ 68/68 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 80 % of kotlin submissions (40.1 MB)
# Submitting: kotlin_solutions/2583.kth-largest-sum-in-a-binary-tree.kt
# - Downloading kth-largest-sum-in-a-binary-tree
#   ✔ Accepted
#   ✔ 51/51 cases passed (179 ms)
#   ✔ Your runtime beats 14.29 % of kotlin submissions
#   ✔ Your memory usage beats 28.57 % of kotlin submissions (92.6 MB)
# Submitting: kotlin_solutions/2586.count-the-number-of-vowel-strings-in-range.kt
# - Downloading count-the-number-of-vowel-strings-in-range
#   ✔ Accepted
#   ✔ 1053/1053 cases passed (24 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (47.4 MB)
# Submitting: kotlin_solutions/2587.rearrange-array-to-maximize-prefix-score.kt
# - Downloading rearrange-array-to-maximize-prefix-score
#   ✔ Accepted
#   ✔ 1071/1071 cases passed (91 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/2595.number-of-even-and-odd-bits.kt
# - Downloading number-of-even-and-odd-bits
#   ✔ Accepted
#   ✔ 1003/1003 cases passed (1 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (42.4 MB)
# Submitting: kotlin_solutions/2600.k-items-with-the-maximum-sum.kt
# - Downloading k-items-with-the-maximum-sum
#   ✔ Accepted
#   ✔ 1310/1310 cases passed (1 ms)
#   ✔ Your runtime beats 80 % of kotlin submissions
#   ✔ Your memory usage beats 60 % of kotlin submissions (41.4 MB)
# Submitting: kotlin_solutions/2605.form-smallest-number-from-two-digit-arrays.kt
# - Downloading form-smallest-number-from-two-digit-arrays
#   ✔ Accepted
#   ✔ 388/388 cases passed (24 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/2609.find-the-longest-balanced-substring-of-a-binary-string.kt
# - Downloading find-the-longest-balanced-substring-of-a-binary-string
#   ✔ Accepted
#   ✔ 1848/1848 cases passed (49 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/2615.sum-of-distances.kt
# - Downloading sum-of-distances
#   ✔ Accepted
#   ✔ 1068/1068 cases passed (115 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/2640.find-the-score-of-all-prefixes-of-an-array.kt
# - Downloading find-the-score-of-all-prefixes-of-an-array
#   ✔ Accepted
#   ✔ 43/43 cases passed (41 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/2643.row-with-maximum-ones.kt
# - Downloading row-with-maximum-ones
# [ERROR] session expired, please login again [code=-1]
# Submitting: kotlin_solutions/2644.find-the-maximum-divisibility-score.kt
# - Downloading find-the-maximum-divisibility-score
#   ✔ Accepted
#   ✔ 160/160 cases passed (282 ms)
#   ✔ Your runtime beats 7.69 % of kotlin submissions
#   ✔ Your memory usage beats 84.62 % of kotlin submissions (51.5 MB)
# Submitting: kotlin_solutions/2651.calculate-delayed-arrival-time.kt
# - Downloading calculate-delayed-arrival-time
#   ✔ Accepted
#   ✔ 556/556 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (40.6 MB)
# Submitting: kotlin_solutions/2652.sum-multiples.kt
# - Downloading sum-multiples
#   ✔ Accepted
#   ✔ 1000/1000 cases passed (24 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 22.22 % of kotlin submissions (47 MB)
# Submitting: kotlin_solutions/2656.maximum-sum-with-exactly-k-elements.kt
# - Downloading maximum-sum-with-exactly-k-elements
#   ✔ Accepted
#   ✔ 3004/3004 cases passed (12 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
#   ✔ Your memory usage beats 40 % of kotlin submissions (49.9 MB)
# Submitting: kotlin_solutions/2657.find-the-prefix-common-array-of-two-arrays.kt
# - Downloading find-the-prefix-common-array-of-two-arrays
#   ✔ Accepted
#   ✔ 1773/1773 cases passed (100 ms)
#   ✔ Your runtime beats 9.09 % of kotlin submissions
#   ✔ Your memory usage beats 54.55 % of kotlin submissions (53.9 MB)
# Submitting: kotlin_solutions/3000.maximum-area-of-longest-diagonal-rectangle.kt
# - Downloading maximum-area-of-longest-diagonal-rectangle
#   ✔ Accepted
#   ✔ 817/817 cases passed (6 ms)
#   ✔ Your runtime beats 14.29 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (49.9 MB)
# Submitting: kotlin_solutions/3005.count-elements-with-maximum-frequency.kt
# - Downloading count-elements-with-maximum-frequency
#   ✔ Accepted
#   ✔ 623/623 cases passed (21 ms)
#   ✔ Your runtime beats 17.07 % of kotlin submissions
#   ✔ Your memory usage beats 14.63 % of kotlin submissions (46.6 MB)
# Submitting: kotlin_solutions/3006.find-beautiful-indices-in-the-given-array-i.kt
# - Downloading find-beautiful-indices-in-the-given-array-i
#   ✔ Accepted
#   ✔ 535/535 cases passed (217 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/3019.number-of-changing-keys.kt
# - Downloading number-of-changing-keys
#   ✔ Accepted
#   ✔ 802/802 cases passed (15 ms)
#   ✔ Your runtime beats 5.56 % of kotlin submissions
#   ✔ Your memory usage beats 5.56 % of kotlin submissions (45.9 MB)
# Submitting: kotlin_solutions/3024.type-of-triangle.kt
# - Downloading type-of-triangle
#   ✔ Accepted
#   ✔ 705/705 cases passed (17 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/3033.modify-the-matrix.kt
# - Downloading modify-the-matrix
#   ✔ Accepted
#   ✔ 514/514 cases passed (18 ms)
#   ✔ Your runtime beats 9.09 % of kotlin submissions
#   ✔ Your memory usage beats 9.09 % of kotlin submissions (55.4 MB)
# Submitting: kotlin_solutions/3563.lexicographically-smallest-string-after-adjacent-removals.kt
# - Downloading lexicographically-smallest-string-after-adjacent-removals
#   ✔ Accepted
#   ✔ 930/930 cases passed (330 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (59.6 MB)
# Submitting: kotlin_solutions/3721.longest-balanced-subarray-ii.kt
# - Downloading longest-balanced-subarray-ii
#   ✔ Accepted
#   ✔ 999/999 cases passed (263 ms)
#   ✔ Your runtime beats 27.89 % of kotlin submissions
#   ✔ Your memory usage beats 38.78 % of kotlin submissions (84.4 MB)

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-02-15 11:50:55
