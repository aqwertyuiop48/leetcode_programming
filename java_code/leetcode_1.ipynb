# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME')
    user_cookie = userdata.get('LEETCODE_TOKEN')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME'] = user_name
    os.environ['LEETCODE_TOKEN'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME" "$LEETCODE_TOKEN" | leetcode user -c

# %%
# %%bash
#
#
# # top 100 answers
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v java_solutions/*.java | head -n 100); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 7
# done
# Out:
# Submitting: java_solutions/1.two-sum.java
#   ✔ Accepted
#   ✔ 63/63 cases passed (2784 ms)
#   ✔ Your runtime beats 6.3 % of java submissions
#   ✔ Your memory usage beats 5.52 % of java submissions (48.2 MB)
# Submitting: java_solutions/2.add-two-numbers.java
# - Downloading add-two-numbers
#   ✔ Accepted
#   ✔ 1569/1569 cases passed (39 ms)
#   ✔ Your runtime beats 2.35 % of java submissions
#   ✔ Your memory usage beats 10.35 % of java submissions (47.8 MB)
# Submitting: java_solutions/3.longest-substring-without-repeating-characters.java
# - Downloading longest-substring-without-repeating-characters
#   ✔ Accepted
#   ✔ 988/988 cases passed (15 ms)
#   ✔ Your runtime beats 10.22 % of java submissions
#   ✔ Your memory usage beats 5.72 % of java submissions (47.4 MB)
# Submitting: java_solutions/4.median-of-two-sorted-arrays.java
# - Downloading median-of-two-sorted-arrays
#   ✔ Accepted
#   ✔ 2098/2098 cases passed (3 ms)
#   ✔ Your runtime beats 26.85 % of java submissions
#   ✔ Your memory usage beats 76.5 % of java submissions (48.7 MB)
# Submitting: java_solutions/5.longest-palindromic-substring.java
# - Downloading longest-palindromic-substring
#   ✔ Accepted
#   ✔ 143/143 cases passed (86 ms)
#   ✔ Your runtime beats 28.87 % of java submissions
#   ✔ Your memory usage beats 15.64 % of java submissions (47.2 MB)
# Submitting: java_solutions/6.zigzag-conversion.java
# - Downloading zigzag-conversion
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 4: error: missing return statement
#   ✘ Error: Line 4: error: missing return statement
#     }
#     ^
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: java_solutions/7.reverse-integer.java
# - Downloading reverse-integer
#   ✔ Accepted
#   ✔ 1045/1045 cases passed (7 ms)
#   ✔ Your runtime beats 2.38 % of java submissions
#   ✔ Your memory usage beats 6.63 % of java submissions (43.1 MB)
# Submitting: java_solutions/8.string-to-integer-atoi.java
# - Downloading string-to-integer-atoi
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 4: error: missing return statement
#   ✘ Error: Line 4: error: missing return statement
#     }
#     ^
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: java_solutions/9.palindrome-number.java
# - Downloading palindrome-number
#   ✔ Accepted
#   ✔ 11511/11511 cases passed (22 ms)
#   ✔ Your runtime beats 5.56 % of java submissions
#   ✔ Your memory usage beats 10 % of java submissions (46.8 MB)
# Submitting: java_solutions/10.regular-expression-matching.java
# - Downloading regular-expression-matching
#   ✔ Accepted
#   ✔ 354/354 cases passed (496 ms)
#   ✔ Your runtime beats 7.1 % of java submissions
#   ✔ Your memory usage beats 15.73 % of java submissions (43.9 MB)
# Submitting: java_solutions/11.container-with-most-water.java
# - Downloading container-with-most-water
#   ✔ Accepted
#   ✔ 65/65 cases passed (16 ms)
#   ✔ Your runtime beats 5.35 % of java submissions
#   ✔ Your memory usage beats 99.69 % of java submissions (74.2 MB)
# Submitting: java_solutions/12.integer-to-roman.java
# - Downloading integer-to-roman
#   ✔ Accepted
#   ✔ 3999/3999 cases passed (34 ms)
#   ✔ Your runtime beats 6.38 % of java submissions
#   ✔ Your memory usage beats 5.47 % of java submissions (48.1 MB)
# Submitting: java_solutions/13.roman-to-integer.java
# - Downloading roman-to-integer
#   ✔ Accepted
#   ✔ 3999/3999 cases passed (17 ms)
#   ✔ Your runtime beats 5.01 % of java submissions
#   ✔ Your memory usage beats 7.66 % of java submissions (47.3 MB)
# Submitting: java_solutions/14.longest-common-prefix.java
# - Downloading longest-common-prefix
#   ✔ Accepted
#   ✔ 126/126 cases passed (15 ms)
#   ✔ Your runtime beats 5.46 % of java submissions
#   ✔ Your memory usage beats 6.08 % of java submissions (46.8 MB)
# Submitting: java_solutions/15.3-sum.java
# - Downloading 3sum
#   ✔ Accepted
#   ✔ 316/316 cases passed (183 ms)
#   ✔ Your runtime beats 15.39 % of java submissions
#   ✔ Your memory usage beats 14.2 % of java submissions (60.2 MB)
# Submitting: java_solutions/16.3-sum-closest.java
# - Downloading 3sum-closest
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 4: error: missing return statement
#   ✘ Error: Line 4: error: missing return statement
#     }
#     ^
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: java_solutions/17.letter-combinations-of-a-phone-number.java
# - Downloading letter-combinations-of-a-phone-number
#   ✔ Accepted
#   ✔ 24/24 cases passed (9 ms)
#   ✔ Your runtime beats 1.69 % of java submissions
#   ✔ Your memory usage beats 5.94 % of java submissions (49.7 MB)
# Submitting: java_solutions/18.4-sum.java
# - Downloading 4sum
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 4: error: missing return statement
#   ✘ Error: Line 4: error: missing return statement
#     }
#     ^
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: java_solutions/19.remove-nth-node-from-end-of-list.java
# - Downloading remove-nth-node-from-end-of-list
#   ✔ Accepted
#   ✔ 208/208 cases passed (22 ms)
#   ✔ Your runtime beats 0.65 % of java submissions
#   ✔ Your memory usage beats 10.24 % of java submissions (52.3 MB)
# Submitting: java_solutions/20.valid-parentheses.java
# - Downloading valid-parentheses
#   ✔ Accepted
#   ✔ 102/102 cases passed (31 ms)
#   ✔ Your runtime beats 5.92 % of java submissions
#   ✔ Your memory usage beats 5.12 % of java submissions (53.1 MB)
# Submitting: java_solutions/21.merge-two-sorted-lists.java
# - Downloading merge-two-sorted-lists
#   ✔ Accepted
#   ✔ 208/208 cases passed (17 ms)
#   ✔ Your runtime beats 0.59 % of java submissions
#   ✔ Your memory usage beats 10.89 % of java submissions (46.8 MB)
# Submitting: java_solutions/22.generate-parentheses.java
# - Downloading generate-parentheses
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 4: error: missing return statement
#   ✘ Error: Line 4: error: missing return statement
#     }
#     ^
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: java_solutions/23.merge-k-sorted-lists.java
# - Downloading merge-k-sorted-lists
#   ✔ Accepted
#   ✔ 134/134 cases passed (5 ms)
#   ✔ Your runtime beats 41.18 % of java submissions
#   ✔ Your memory usage beats 81.32 % of java submissions (46.6 MB)
# Submitting: java_solutions/24.swap-nodes-in-pairs.java
# - Downloading swap-nodes-in-pairs
#   ✔ Accepted
#   ✔ 55/55 cases passed (13 ms)
#   ✔ Your runtime beats 0.4 % of java submissions
#   ✔ Your memory usage beats 17.23 % of java submissions (45.2 MB)
# Submitting: java_solutions/25.reverse-nodes-in-k-group.java
# - Downloading reverse-nodes-in-k-group
#   ✔ Accepted
#   ✔ 62/62 cases passed (6 ms)
#   ✔ Your runtime beats 1.1 % of java submissions
#   ✔ Your memory usage beats 62.27 % of java submissions (46.4 MB)
# Submitting: java_solutions/26.remove-duplicates-from-sorted-array.java
# - Downloading remove-duplicates-from-sorted-array
#   ✔ Accepted
#   ✔ 362/362 cases passed (9 ms)
#   ✔ Your runtime beats 3.94 % of java submissions
#   ✔ Your memory usage beats 13.53 % of java submissions (47.1 MB)
# Submitting: java_solutions/27.remove-element.java
# - Downloading remove-element
#   ✔ Accepted
#   ✔ 116/116 cases passed (8 ms)
#   ✔ Your runtime beats 0.8 % of java submissions
#   ✔ Your memory usage beats 13 % of java submissions (49.8 MB)
# Submitting: java_solutions/28.find-the-index-of-the-first-occurrence-in-a-string.java
# - Downloading find-the-index-of-the-first-occurrence-in-a-string
#   ✔ Accepted
#   ✔ 85/85 cases passed (3 ms)
#   ✔ Your runtime beats 9.38 % of java submissions
#   ✔ Your memory usage beats 24.48 % of java submissions (43.3 MB)
# Submitting: java_solutions/29.divide-two-integers.java
# - Downloading divide-two-integers
#   ✔ Accepted
#   ✔ 994/994 cases passed (1 ms)
#   ✔ Your runtime beats 92.85 % of java submissions
#   ✔ Your memory usage beats 93.64 % of java submissions (42.3 MB)
# Submitting: java_solutions/30.substring-with-concatenation-of-all-words.java
# - Downloading substring-with-concatenation-of-all-words
#   ✔ Accepted
#   ✔ 182/182 cases passed (15 ms)
#   ✔ Your runtime beats 12.5 % of java submissions
#   ✔ Your memory usage beats 12.81 % of java submissions (47.6 MB)
# Submitting: java_solutions/31.next-permutation.java
# - Downloading next-permutation
#   ✔ Accepted
#   ✔ 266/266 cases passed (27 ms)
#   ✔ Your runtime beats 1.61 % of java submissions
#   ✔ Your memory usage beats 7.76 % of java submissions (52.9 MB)
# Submitting: java_solutions/32.longest-valid-parentheses.java
# - Downloading longest-valid-parentheses
#   ✔ Accepted
#   ✔ 235/235 cases passed (4 ms)
#   ✔ Your runtime beats 83.95 % of java submissions
#   ✔ Your memory usage beats 90.14 % of java submissions (44.7 MB)
# Submitting: java_solutions/33.search-in-rotated-sorted-array.java
# - Downloading search-in-rotated-sorted-array
#   ✔ Accepted
#   ✔ 196/196 cases passed (5 ms)
#   ✔ Your runtime beats 1.41 % of java submissions
#   ✔ Your memory usage beats 15.68 % of java submissions (44.4 MB)
# Submitting: java_solutions/34.find-first-and-last-position-of-element-in-sorted-array.java
# - Downloading find-first-and-last-position-of-element-in-sorted-array
#   ✔ Accepted
#   ✔ 88/88 cases passed (7 ms)
#   ✔ Your runtime beats 0.75 % of java submissions
#   ✔ Your memory usage beats 37.49 % of java submissions (48.3 MB)
# Submitting: java_solutions/35.search-insert-position.java
# - Downloading search-insert-position
#   ✔ Accepted
#   ✔ 66/66 cases passed (7 ms)
#   ✔ Your runtime beats 0.5 % of java submissions
#   ✔ Your memory usage beats 5.45 % of java submissions (45.6 MB)
# Submitting: java_solutions/36.valid-sudoku.java
# - Downloading valid-sudoku
#   ✔ Accepted
#   ✔ 507/507 cases passed (29 ms)
#   ✔ Your runtime beats 7.88 % of java submissions
#   ✔ Your memory usage beats 7.38 % of java submissions (53.2 MB)
# Submitting: java_solutions/37.sudoku-solver.java
# - Downloading sudoku-solver
#   ✔ Accepted
#   ✔ 8/8 cases passed (956 ms)
#   ✔ Your runtime beats 5.22 % of java submissions
#   ✔ Your memory usage beats 10.3 % of java submissions (46.7 MB)
# Submitting: java_solutions/38.count-and-say.java
# - Downloading count-and-say
#   ✔ Accepted
#   ✔ 30/30 cases passed (30 ms)
#   ✔ Your runtime beats 5.36 % of java submissions
#   ✔ Your memory usage beats 6.35 % of java submissions (48.2 MB)
# Submitting: java_solutions/41.first-missing-positive.java
# - Downloading first-missing-positive
#   ✔ Accepted
#   ✔ 179/179 cases passed (2 ms)
#   ✔ Your runtime beats 37.92 % of java submissions
#   ✔ Your memory usage beats 77.21 % of java submissions (71.2 MB)
# Submitting: java_solutions/42.trapping-rain-water.java
# - Downloading trapping-rain-water
#   ✔ Accepted
#   ✔ 324/324 cases passed (1 ms)
#   ✔ Your runtime beats 58.75 % of java submissions
#   ✔ Your memory usage beats 73.57 % of java submissions (47.7 MB)
# Submitting: java_solutions/43.multiply-strings.java
# - Downloading multiply-strings
#   ✔ Accepted
#   ✔ 311/311 cases passed (13 ms)
#   ✔ Your runtime beats 5.76 % of java submissions
#   ✔ Your memory usage beats 18.14 % of java submissions (44.5 MB)
# Submitting: java_solutions/44.wildcard-matching.java
# - Downloading wildcard-matching
#   ✔ Accepted
#   ✔ 1812/1812 cases passed (65 ms)
#   ✔ Your runtime beats 10.57 % of java submissions
#   ✔ Your memory usage beats 47.27 % of java submissions (47.5 MB)
# Submitting: java_solutions/45.jump-game-ii.java
# - Downloading jump-game-ii
#   ✔ Accepted
#   ✔ 110/110 cases passed (3 ms)
#   ✔ Your runtime beats 17.49 % of java submissions
#   ✔ Your memory usage beats 25.51 % of java submissions (47.5 MB)
# Submitting: java_solutions/46.permutations.java
# - Downloading permutations
#   ✔ Accepted
#   ✔ 26/26 cases passed (35 ms)
#   ✔ Your runtime beats 2.5 % of java submissions
#   ✔ Your memory usage beats 5.16 % of java submissions (53.2 MB)
# Submitting: java_solutions/48.rotate-image.java
# - Downloading rotate-image
#   ✔ Accepted
#   ✔ 21/21 cases passed (14 ms)
#   ✔ Your runtime beats 1.5 % of java submissions
#   ✔ Your memory usage beats 7.7 % of java submissions (50.6 MB)
# Submitting: java_solutions/49.group-anagrams.java
# - Downloading group-anagrams
#   ✔ Accepted
#   ✔ 128/128 cases passed (59 ms)
#   ✔ Your runtime beats 5.04 % of java submissions
#   ✔ Your memory usage beats 5.09 % of java submissions (56.4 MB)
# Submitting: java_solutions/50.pow-x-n.java
# - Downloading powx-n
#   ✔ Accepted
#   ✔ 307/307 cases passed (12 ms)
#   ✔ Your runtime beats 1.33 % of java submissions
#   ✔ Your memory usage beats 94.15 % of java submissions (47.3 MB)
# Submitting: java_solutions/51.n-queens.java
# - Downloading n-queens
#   ✔ Accepted
#   ✔ 9/9 cases passed (11 ms)
#   ✔ Your runtime beats 5.66 % of java submissions
#   ✔ Your memory usage beats 50.82 % of java submissions (46.7 MB)
# Submitting: java_solutions/52.n-queens-ii.java
# - Downloading n-queens-ii
#   ✔ Accepted
#   ✔ 9/9 cases passed (9 ms)
#   ✔ Your runtime beats 5.99 % of java submissions
#   ✔ Your memory usage beats 33.39 % of java submissions (42.2 MB)
# Submitting: java_solutions/53.maximum-subarray.java
# - Downloading maximum-subarray
#   ✔ Accepted
#   ✔ 210/210 cases passed (2 ms)
#   ✔ Your runtime beats 4.5 % of java submissions
#   ✔ Your memory usage beats 54.54 % of java submissions (77.2 MB)
# Submitting: java_solutions/56.merge-intervals.java
# - Downloading merge-intervals
#   ✔ Accepted
#   ✔ 172/172 cases passed (27 ms)
#   ✔ Your runtime beats 5.06 % of java submissions
#   ✔ Your memory usage beats 7.64 % of java submissions (56 MB)
# Submitting: java_solutions/58.length-of-last-word.java
# - Downloading length-of-last-word
#   ✔ Accepted
#   ✔ 60/60 cases passed (6 ms)
#   ✔ Your runtime beats 0.7 % of java submissions
#   ✔ Your memory usage beats 56.93 % of java submissions (43.1 MB)
# Submitting: java_solutions/60.permutation-sequence.java
# - Downloading permutation-sequence
#   ✔ Accepted
#   ✔ 200/200 cases passed (5 ms)
#   ✔ Your runtime beats 13.46 % of java submissions
#   ✔ Your memory usage beats 9.8 % of java submissions (43.2 MB)
# Submitting: java_solutions/61.rotate-list.java
# - Downloading rotate-list
#   ✔ Accepted
#   ✔ 232/232 cases passed (20 ms)
#   ✔ Your runtime beats 1.54 % of java submissions
#   ✔ Your memory usage beats 14.47 % of java submissions (46.6 MB)
# Submitting: java_solutions/65.valid-number.java
# - Downloading valid-number
#   ✔ Accepted
#   ✔ 1499/1499 cases passed (13 ms)
#   ✔ Your runtime beats 6.72 % of java submissions
#   ✔ Your memory usage beats 6.17 % of java submissions (47.8 MB)
# Submitting: java_solutions/66.plus-one.java
# - Downloading plus-one
#   ✔ Accepted
#   ✔ 114/114 cases passed (13 ms)
#   ✔ Your runtime beats 0.76 % of java submissions
#   ✔ Your memory usage beats 13.2 % of java submissions (44.6 MB)
# Submitting: java_solutions/67.add-binary.java
# - Downloading add-binary
#   ✔ Accepted
#   ✔ 296/296 cases passed (10 ms)
#   ✔ Your runtime beats 9.03 % of java submissions
#   ✔ Your memory usage beats 18.77 % of java submissions (44 MB)
# Submitting: java_solutions/68.text-justification.java
# - Downloading text-justification
#   ✔ Accepted
#   ✔ 29/29 cases passed (1 ms)
#   ✔ Your runtime beats 39.86 % of java submissions
#   ✔ Your memory usage beats 32.81 % of java submissions (43.4 MB)
# Submitting: java_solutions/69.sqrtx.java
# - Downloading sqrtx
#   ✔ Accepted
#   ✔ 1019/1019 cases passed (331 ms)
#   ✔ Your runtime beats 5.3 % of java submissions
#   ✔ Your memory usage beats 13.21 % of java submissions (43.2 MB)
# Submitting: java_solutions/70.climbing-stairs.java
# - Downloading climbing-stairs
#   ✔ Accepted
#   ✔ 45/45 cases passed (9 ms)
#   ✔ Your runtime beats 0.28 % of java submissions
#   ✔ Your memory usage beats 7.9 % of java submissions (42.8 MB)
# Submitting: java_solutions/73.set-matrix-zeroes.java
# - Downloading set-matrix-zeroes
#   ✔ Accepted
#   ✔ 203/203 cases passed (28 ms)
#   ✔ Your runtime beats 5.55 % of java submissions
#   ✔ Your memory usage beats 8.17 % of java submissions (53.6 MB)
# Submitting: java_solutions/74.search-a-2d-matrix.java
# - Downloading search-a-2d-matrix
#   ✔ Accepted
#   ✔ 133/133 cases passed (6 ms)
#   ✔ Your runtime beats 1.17 % of java submissions
#   ✔ Your memory usage beats 13.25 % of java submissions (44.7 MB)
# Submitting: java_solutions/75.sort-colors.java
# - Downloading sort-colors
#   ✔ Accepted
#   ✔ 89/89 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 81.59 % of java submissions (43.4 MB)
# Submitting: java_solutions/76.minimum-window-substring.java
# - Downloading minimum-window-substring
#   ✔ Accepted
#   ✔ 268/268 cases passed (3 ms)
#   ✔ Your runtime beats 76.69 % of java submissions
#   ✔ Your memory usage beats 86.64 % of java submissions (45.4 MB)
# Submitting: java_solutions/80.remove-duplicates-from-sorted-array-ii.java
# - Downloading remove-duplicates-from-sorted-array-ii
#   ✔ Accepted
#   ✔ 170/170 cases passed (31 ms)
#   ✔ Your runtime beats 4.44 % of java submissions
#   ✔ Your memory usage beats 6.77 % of java submissions (55.6 MB)
# Submitting: java_solutions/81.search-in-rotated-sorted-array-ii.java
# - Downloading search-in-rotated-sorted-array-ii
#   ✔ Accepted
#   ✔ 283/283 cases passed (5 ms)
#   ✔ Your runtime beats 3.01 % of java submissions
#   ✔ Your memory usage beats 6.43 % of java submissions (45.4 MB)
# Submitting: java_solutions/82.remove-duplicates-from-sorted-list-ii.java
# - Downloading remove-duplicates-from-sorted-list-ii
#   ✔ Accepted
#   ✔ 166/166 cases passed (17 ms)
#   ✔ Your runtime beats 2.07 % of java submissions
#   ✔ Your memory usage beats 5.48 % of java submissions (52.2 MB)
# Submitting: java_solutions/83.remove-duplicates-from-sorted-list.java
# - Downloading remove-duplicates-from-sorted-list
#   ✔ Accepted
#   ✔ 168/168 cases passed (12 ms)
#   ✔ Your runtime beats 0.6 % of java submissions
#   ✔ Your memory usage beats 8.93 % of java submissions (46.5 MB)
# Submitting: java_solutions/84.largest-rectangle-in-histogram.java
# - Downloading largest-rectangle-in-histogram
#   ✔ Accepted
#   ✔ 99/99 cases passed (12 ms)
#   ✔ Your runtime beats 97.33 % of java submissions
#   ✔ Your memory usage beats 99.08 % of java submissions (73.7 MB)
# Submitting: java_solutions/85.maximal-rectangle.java
# - Downloading maximal-rectangle
#   ✔ Accepted
#   ✔ 76/76 cases passed (10 ms)
#   ✔ Your runtime beats 87.42 % of java submissions
#   ✔ Your memory usage beats 19.4 % of java submissions (51.7 MB)
# Submitting: java_solutions/87.scramble-string.java
# - Downloading scramble-string
#   ✔ Accepted
#   ✔ 290/290 cases passed (9 ms)
#   ✔ Your runtime beats 31.24 % of java submissions
#   ✔ Your memory usage beats 89.84 % of java submissions (45.2 MB)
# Submitting: java_solutions/88.merge-sorted-array.java
# - Downloading merge-sorted-array
#   ✔ Accepted
#   ✔ 59/59 cases passed (6 ms)
#   ✔ Your runtime beats 3.81 % of java submissions
#   ✔ Your memory usage beats 5.09 % of java submissions (47.7 MB)
# Submitting: java_solutions/89.gray-code.java
# - Downloading gray-code
#   ✔ Accepted
#   ✔ 16/16 cases passed (7 ms)
#   ✔ Your runtime beats 20.31 % of java submissions
#   ✔ Your memory usage beats 99.69 % of java submissions (49.9 MB)
# Submitting: java_solutions/92.reverse-linked-list-ii.java
# - Downloading reverse-linked-list-ii
#   ✔ Accepted
#   ✔ 44/44 cases passed (7 ms)
#   ✔ Your runtime beats 0.45 % of java submissions
#   ✔ Your memory usage beats 16.76 % of java submissions (43.8 MB)
# Submitting: java_solutions/94.binary-tree-inorder-traversal.java
# - Downloading binary-tree-inorder-traversal
#   ✔ Accepted
#   ✔ 71/71 cases passed (6 ms)
#   ✔ Your runtime beats 0.14 % of java submissions
#   ✔ Your memory usage beats 6.39 % of java submissions (44 MB)
# Submitting: java_solutions/100.same-tree.java
# - Downloading same-tree
#   ✔ Accepted
#   ✔ 67/67 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 94.3 % of java submissions (42.6 MB)
# Submitting: java_solutions/101.symmetric-tree.java
# - Downloading symmetric-tree
#   ✔ Accepted
#   ✔ 200/200 cases passed (15 ms)
#   ✔ Your runtime beats 0.46 % of java submissions
#   ✔ Your memory usage beats 8.12 % of java submissions (44.9 MB)
# Submitting: java_solutions/104.maximum-depth-of-binary-tree.java
# - Downloading maximum-depth-of-binary-tree
#   ✔ Accepted
#   ✔ 39/39 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 17.58 % of java submissions (44.6 MB)
# Submitting: java_solutions/110.balanced-binary-tree.java
# - Downloading balanced-binary-tree
#   ✔ Accepted
#   ✔ 228/228 cases passed (12 ms)
#   ✔ Your runtime beats 2.33 % of java submissions
#   ✔ Your memory usage beats 6.59 % of java submissions (46.8 MB)
# Submitting: java_solutions/111.minimum-depth-of-binary-tree.java
# - Downloading minimum-depth-of-binary-tree
#   ✔ Accepted
#   ✔ 53/53 cases passed (124 ms)
#   ✔ Your runtime beats 6.59 % of java submissions
#   ✔ Your memory usage beats 5.85 % of java submissions (98.5 MB)
# Submitting: java_solutions/112.path-sum.java
# - Downloading path-sum
#   ✔ Accepted
#   ✔ 118/118 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 54.63 % of java submissions (45 MB)
# Submitting: java_solutions/114.flatten-binary-tree-to-linked-list.java
# - Downloading flatten-binary-tree-to-linked-list
#   ✔ Accepted
#   ✔ 225/225 cases passed (20 ms)
#   ✔ Your runtime beats 0.54 % of java submissions
#   ✔ Your memory usage beats 7.68 % of java submissions (46.8 MB)
# Submitting: java_solutions/115.distinct-subsequences.java
# - Downloading distinct-subsequences
#   ✔ Accepted
#   ✔ 66/66 cases passed (17 ms)
#   ✔ Your runtime beats 81.72 % of java submissions
#   ✔ Your memory usage beats 99.94 % of java submissions (42 MB)
# Submitting: java_solutions/118.pascals-triangle.java
# - Downloading pascals-triangle
#   ✔ Accepted
#   ✔ 30/30 cases passed (6 ms)
#   ✔ Your runtime beats 0.89 % of java submissions
#   ✔ Your memory usage beats 8.12 % of java submissions (44.2 MB)
# Submitting: java_solutions/119.pascals-triangle-ii.java
# - Downloading pascals-triangle-ii
#   ✔ Accepted
#   ✔ 34/34 cases passed (7 ms)
#   ✔ Your runtime beats 1.08 % of java submissions
#   ✔ Your memory usage beats 22.7 % of java submissions (42.8 MB)
# Submitting: java_solutions/120.triangle.java
# - Downloading triangle
#   ✔ Accepted
#   ✔ 46/46 cases passed (8 ms)
#   ✔ Your runtime beats 20.21 % of java submissions
#   ✔ Your memory usage beats 5.98 % of java submissions (46.8 MB)
# Submitting: java_solutions/121.best-time-to-buy-and-sell-stock.java
# - Downloading best-time-to-buy-and-sell-stock
#   ✔ Accepted
#   ✔ 212/212 cases passed (20 ms)
#   ✔ Your runtime beats 1.47 % of java submissions
#   ✔ Your memory usage beats 7.05 % of java submissions (100 MB)
# Submitting: java_solutions/123.best-time-to-buy-and-sell-stock-iii.java
# - Downloading best-time-to-buy-and-sell-stock-iii
#   ✔ Accepted
#   ✔ 214/214 cases passed (4 ms)
#   ✔ Your runtime beats 51.67 % of java submissions
#   ✔ Your memory usage beats 90.2 % of java submissions (75.6 MB)
# Submitting: java_solutions/124.binary-tree-maximum-path-sum.java
# - Downloading binary-tree-maximum-path-sum
#   ✔ Accepted
#   ✔ 96/96 cases passed (31 ms)
#   ✔ Your runtime beats 2.23 % of java submissions
#   ✔ Your memory usage beats 10.66 % of java submissions (49.5 MB)
# Submitting: java_solutions/125.valid-palindrome.java
# - Downloading valid-palindrome
#   ✔ Accepted
#   ✔ 488/488 cases passed (15 ms)
#   ✔ Your runtime beats 19.66 % of java submissions
#   ✔ Your memory usage beats 12.83 % of java submissions (47.4 MB)
# Submitting: java_solutions/126.word-ladder-ii.java
# - Downloading word-ladder-ii
#   ✔ Accepted
#   ✔ 38/38 cases passed (31 ms)
#   ✔ Your runtime beats 5.27 % of java submissions
#   ✔ Your memory usage beats 5.14 % of java submissions (48.7 MB)
# Submitting: java_solutions/127.word-ladder.java
# - Downloading word-ladder
#   ✔ Accepted
#   ✔ 52/52 cases passed (105 ms)
#   ✔ Your runtime beats 25.11 % of java submissions
#   ✔ Your memory usage beats 15.37 % of java submissions (50.1 MB)
# Submitting: java_solutions/128.longest-consecutive-sequence.java
# - Downloading longest-consecutive-sequence
#   ✔ Accepted
#   ✔ 85/85 cases passed (103 ms)
#   ✔ Your runtime beats 5.06 % of java submissions
#   ✔ Your memory usage beats 69.09 % of java submissions (94.6 MB)
# Submitting: java_solutions/132.palindrome-partitioning-ii.java
# - Downloading palindrome-partitioning-ii
#   ✔ Accepted
#   ✔ 37/37 cases passed (34 ms)
#   ✔ Your runtime beats 56.27 % of java submissions
#   ✔ Your memory usage beats 26.58 % of java submissions (47.7 MB)
# Submitting: java_solutions/135.candy.java
# - Downloading candy
#   ✔ Accepted
#   ✔ 50/50 cases passed (5 ms)
#   ✔ Your runtime beats 9.58 % of java submissions
#   ✔ Your memory usage beats 38.3 % of java submissions (47.8 MB)
# Submitting: java_solutions/136.single-number.java
# - Downloading single-number
#   ✔ Accepted
#   ✔ 61/61 cases passed (27 ms)
#   ✔ Your runtime beats 8.64 % of java submissions
#   ✔ Your memory usage beats 5.87 % of java submissions (53 MB)
# Submitting: java_solutions/137.single-number-ii.java
# - Downloading single-number-ii
#   ✔ Accepted
#   ✔ 15/15 cases passed (15 ms)
#   ✔ Your runtime beats 6.06 % of java submissions
#   ✔ Your memory usage beats 6.54 % of java submissions (53.4 MB)
# Submitting: java_solutions/140.word-break-ii.java
# - Downloading word-break-ii
#   ✔ Accepted
#   ✔ 29/29 cases passed (3 ms)
#   ✔ Your runtime beats 53.88 % of java submissions
#   ✔ Your memory usage beats 33.71 % of java submissions (48.7 MB)
# Submitting: java_solutions/143.reorder-list.java
# - Downloading reorder-list
#   ✔ Accepted
#   ✔ 12/12 cases passed (15 ms)
#   ✔ Your runtime beats 5.36 % of java submissions
#   ✔ Your memory usage beats 99.83 % of java submissions (48.4 MB)
# Submitting: java_solutions/144.binary-tree-preorder-traversal.java
# - Downloading binary-tree-preorder-traversal
#   ✔ Accepted
#   ✔ 71/71 cases passed (4 ms)
#   ✔ Your runtime beats 0.16 % of java submissions
#   ✔ Your memory usage beats 6.39 % of java submissions (43.7 MB)

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-04-13 22:31:03
