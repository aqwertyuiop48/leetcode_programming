# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME_2')
    user_cookie = userdata.get('LEETCODE_TOKEN_2')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME_2'] = user_name
    os.environ['LEETCODE_TOKEN_2'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME_2" "$LEETCODE_TOKEN_2" | leetcode user -c

# %%
# %%bash
#
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v kotlin_solutions_1/*.kt | sed -n '101,200p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 7
# done
# Out:
# Submitting: kotlin_solutions_1/1089.duplicate-zeros.kt
# - Downloading duplicate-zeros
#   ✔ Accepted
#   ✔ 33/33 cases passed (21 ms)
#   ✔ Your runtime beats 6.06 % of kotlin submissions
#   ✔ Your memory usage beats 9.09 % of kotlin submissions (50.1 MB)
# Submitting: kotlin_solutions_1/1090.largest-values-from-labels.kt
# - Downloading largest-values-from-labels
#   ✔ Accepted
#   ✔ 81/81 cases passed (61 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1091.shortest-path-in-binary-matrix.kt
# - Downloading shortest-path-in-binary-matrix
#   ✔ Accepted
#   ✔ 90/90 cases passed (120 ms)
#   ✔ Your runtime beats 13.51 % of kotlin submissions
#   ✔ Your memory usage beats 39.19 % of kotlin submissions (63.2 MB)
# Submitting: kotlin_solutions_1/1092.shortest-common-supersequence.kt
# - Downloading shortest-common-supersequence
#   ✔ Accepted
#   ✔ 50/50 cases passed (72 ms)
#   ✔ Your runtime beats 12.5 % of kotlin submissions
#   ✔ Your memory usage beats 37.5 % of kotlin submissions (55 MB)
# Submitting: kotlin_solutions_1/1093.statistics-from-a-large-sample.kt
# - Downloading statistics-from-a-large-sample
#   ✔ Accepted
#   ✔ 52/52 cases passed (15 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1094.car-pooling.kt
# - Downloading car-pooling
#   ✔ Accepted
#   ✔ 59/59 cases passed (12 ms)
#   ✔ Your runtime beats 34.78 % of kotlin submissions
#   ✔ Your memory usage beats 15.22 % of kotlin submissions (49.9 MB)
# Submitting: kotlin_solutions_1/1095.find-in-mountain-array.kt
# - Downloading find-in-mountain-array
#   ✔ Accepted
#   ✔ 80/80 cases passed (130 ms)
#   ✔ Your runtime beats 90.48 % of kotlin submissions
#   ✔ Your memory usage beats 61.9 % of kotlin submissions (44.5 MB)
# Submitting: kotlin_solutions_1/1096.brace-expansion-ii.kt
# - Downloading brace-expansion-ii
#   ✔ Accepted
#   ✔ 115/115 cases passed (77 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1103.distribute-candies-to-people.kt
# - Downloading distribute-candies-to-people
#   ✔ Accepted
#   ✔ 27/27 cases passed (6 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1104.path-in-zigzag-labelled-binary-tree.kt
# - Downloading path-in-zigzag-labelled-binary-tree
#   ✔ Accepted
#   ✔ 44/44 cases passed (12 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (42.5 MB)
# Submitting: kotlin_solutions_1/1105.filling-bookcase-shelves.kt
# - Downloading filling-bookcase-shelves
#   ✔ Accepted
#   ✔ 20/20 cases passed (52 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1106.parsing-a-boolean-expression.kt
# - Downloading parsing-a-boolean-expression
#   ✔ Accepted
#   ✔ 78/78 cases passed (58 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1108.defanging-an-ip-address.kt
# - Downloading defanging-an-ip-address
#   ✔ Accepted
#   ✔ 62/62 cases passed (97 ms)
#   ✔ Your runtime beats 9.09 % of kotlin submissions
#   ✔ Your memory usage beats 9.09 % of kotlin submissions (41.7 MB)
# Submitting: kotlin_solutions_1/1109.corporate-flight-bookings.kt
# - Downloading corporate-flight-bookings
#   ✔ Accepted
#   ✔ 63/63 cases passed (10 ms)
#   ✔ Your runtime beats 45.45 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (68.2 MB)
# Submitting: kotlin_solutions_1/1110.delete-nodes-and-return-forest.kt
# - Downloading delete-nodes-and-return-forest
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 7: Char 152: WARNING: Parameter 'delSet: Set<Int>' is never used, could be renamed to '_'.
#   ✘ Error: Line 7: Char 152: WARNING: Parameter 'delSet: Set<Int>' is never used, could be renamed to '_'.
# Line 7: Char 261: ERROR: The expression cannot be a selector (cannot occur after a dot).
# Line 7: Char 265: ERROR: Syntax error: Expecting property name or receiver type.
# Line 7: Char 268: ERROR: Unresolved reference 'delSet'.
# Line 7: Char 274: ERROR: Syntax error: Expecting an element.
# Line 7: Char 276: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 7: Char 276: ERROR: Not enough information to infer type argument for 'R'.
# Line 7: Char 282: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 7: Char 308: ERROR: Unresolved reference 'not' for operator '!'.
# Line 7: Char 345: WARNING: Parameter 'it: Boolean' is never used, could be renamed to '_'.
# Line 7: Char 395: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 7: Char 447: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1111.maximum-nesting-depth-of-two-valid-parentheses-strings.kt
# - Downloading maximum-nesting-depth-of-two-valid-parentheses-strings
#   ✔ Accepted
#   ✔ 31/31 cases passed (11 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1114.print-in-order.kt
# - Downloading print-in-order
#   ✘ Internal Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1115.print-foobar-alternately.kt
# - Downloading print-foobar-alternately
#   ✘ Internal Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1116.print-zero-even-odd.kt
# - Downloading print-zero-even-odd
#   ✘ Internal Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1122.relative-sort-array.kt
# - Downloading relative-sort-array
#   ✔ Accepted
#   ✔ 17/17 cases passed (32 ms)
#   ✔ Your runtime beats 7.69 % of kotlin submissions
#   ✔ Your memory usage beats 7.69 % of kotlin submissions (46.5 MB)
# Submitting: kotlin_solutions_1/1123.lowest-common-ancestor-of-deepest-leaves.kt
# - Downloading lowest-common-ancestor-of-deepest-leaves
#   ✔ Accepted
#   ✔ 81/81 cases passed (20 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1124.longest-well-performing-interval.kt
# - Downloading longest-well-performing-interval
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 7: Char 128: WARNING: Variable is unused.
#   ✘ Error: Line 7: Char 128: WARNING: Variable is unused.
# Line 7: Char 211: ERROR: Unresolved reference 'Triple'.
# Line 7: Char 220: ERROR: Syntax error: Expecting ')'.
# Line 7: Char 220: ERROR: Syntax error: Unexpected tokens (use ';' to separate expressions on the same line).
# Line 7: Char 274: ERROR: Argument type mismatch: actual type is 'kotlin.Int#2', but 'kotlin.Triple<kotlin.Int#1, kotlin.Int#1, kotlin.collections.MutableMap<kotlin.Int#1, kotlin.Int#1>>' was expected.
# Line 7: Char 280: ERROR: Unresolved reference 'it'.
# Line 7: Char 289: ERROR: Syntax error: Unexpected tokens (use ';' to separate expressions on the same line).
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1125.smallest-sufficient-team.kt
# - Downloading smallest-sufficient-team
#   ✔ Accepted
#   ✔ 38/38 cases passed (58 ms)
#   ✔ Your runtime beats 42.86 % of kotlin submissions
#   ✔ Your memory usage beats 28.57 % of kotlin submissions (57.5 MB)
# Submitting: kotlin_solutions_1/1128.number-of-equivalent-domino-pairs.kt
# - Downloading number-of-equivalent-domino-pairs
#   ✔ Accepted
#   ✔ 19/19 cases passed (20 ms)
#   ✔ Your runtime beats 44.44 % of kotlin submissions
#   ✔ Your memory usage beats 77.78 % of kotlin submissions (62.5 MB)
# Submitting: kotlin_solutions_1/1129.shortest-path-with-alternating-colors.kt
# - Downloading shortest-path-with-alternating-colors
#   ✔ Accepted
#   ✔ 91/91 cases passed (5 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (46.8 MB)
# Submitting: kotlin_solutions_1/1130.minimum-cost-tree-from-leaf-values.kt
# - Downloading minimum-cost-tree-from-leaf-values
#   ✔ Accepted
#   ✔ 103/103 cases passed (2 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/1131.maximum-of-absolute-value-expression.kt
# - Downloading maximum-of-absolute-value-expression
#   ✔ Accepted
#   ✔ 21/21 cases passed (48 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (58.2 MB)
# Submitting: kotlin_solutions_1/1137.n-th-tribonacci-number.kt
# - Downloading n-th-tribonacci-number
#   ✔ Accepted
#   ✔ 38/38 cases passed (7 ms)
#   ✔ Your runtime beats 6.67 % of kotlin submissions
#   ✔ Your memory usage beats 13.33 % of kotlin submissions (40.5 MB)
# Submitting: kotlin_solutions_1/1138.alphabet-board-path.kt
# - Downloading alphabet-board-path
#   ✔ Accepted
#   ✔ 61/61 cases passed (91 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (42.5 MB)
# Submitting: kotlin_solutions_1/1139.largest-1-bordered-square.kt
# - Downloading largest-1-bordered-square
#   ✔ Accepted
#   ✔ 84/84 cases passed (220 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1140.stone-game-ii.kt
# - Downloading stone-game-ii
#   ✔ Accepted
#   ✔ 92/92 cases passed (32 ms)
#   ✔ Your runtime beats 19.17 % of kotlin submissions
#   ✔ Your memory usage beats 15.03 % of kotlin submissions (46.9 MB)
# Submitting: kotlin_solutions_1/1143.longest-common-subsequence.kt
# - Downloading longest-common-subsequence
#   ✔ Accepted
#   ✔ 47/47 cases passed (34 ms)
#   ✔ Your runtime beats 21.28 % of kotlin submissions
#   ✔ Your memory usage beats 28.37 % of kotlin submissions (52.5 MB)
# Submitting: kotlin_solutions_1/1144.decrease-elements-to-make-array-zigzag.kt
# - Downloading decrease-elements-to-make-array-zigzag
#   ✔ Accepted
#   ✔ 37/37 cases passed (4 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1145.binary-tree-coloring-game.kt
# - Downloading binary-tree-coloring-game
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 7: Char 265: ERROR: Unresolved reference 'val'.
#   ✘ Error: Line 7: Char 265: ERROR: Unresolved reference 'val'.
# Line 7: Char 336: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1146.snapshot-array.kt
# - Downloading snapshot-array
#   ✔ Accepted
#   ✔ 78/78 cases passed (129 ms)
#   ✔ Your runtime beats 10 % of kotlin submissions
#   ✔ Your memory usage beats 55 % of kotlin submissions (106 MB)
# Submitting: kotlin_solutions_1/1147.longest-chunked-palindrome-decomposition.kt
# - Downloading longest-chunked-palindrome-decomposition
#   ✔ Accepted
#   ✔ 84/84 cases passed (22 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1154.day-of-the-year.kt
# - Downloading day-of-the-year
#   ✔ Accepted
#   ✔ 10958/10958 cases passed (44 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 16.67 % of kotlin submissions (51.4 MB)
# Submitting: kotlin_solutions_1/1155.number-of-dice-rolls-with-target-sum.kt
# - Downloading number-of-dice-rolls-with-target-sum
#   ✔ Accepted
#   ✔ 65/65 cases passed (24 ms)
#   ✔ Your runtime beats 60 % of kotlin submissions
#   ✔ Your memory usage beats 60 % of kotlin submissions (44.8 MB)
# Submitting: kotlin_solutions_1/1156.swap-for-longest-repeated-character-substring.kt
# - Downloading swap-for-longest-repeated-character-substring
#   ✔ Accepted
#   ✔ 44/44 cases passed (58 ms)
#   ✔ Your runtime beats 66.67 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (47 MB)
# Submitting: kotlin_solutions_1/1157.online-majority-element-in-subarray.kt
# - Downloading online-majority-element-in-subarray
#   ✔ Accepted
#   ✔ 37/37 cases passed (286 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (82.9 MB)
# Submitting: kotlin_solutions_1/1160.find-words-that-can-be-formed-by-characters.kt
# - Downloading find-words-that-can-be-formed-by-characters
#   ✔ Accepted
#   ✔ 36/36 cases passed (95 ms)
#   ✔ Your runtime beats 9.09 % of kotlin submissions
#   ✔ Your memory usage beats 9.09 % of kotlin submissions (49.3 MB)
# Submitting: kotlin_solutions_1/1161.maximum-level-sum-of-a-binary-tree.kt
# - Downloading maximum-level-sum-of-a-binary-tree
#   ✔ Accepted
#   ✔ 41/41 cases passed (56 ms)
#   ✔ Your runtime beats 8.82 % of kotlin submissions
#   ✔ Your memory usage beats 5.88 % of kotlin submissions (54.3 MB)
# Submitting: kotlin_solutions_1/1162.as-far-from-land-as-possible.kt
# - Downloading as-far-from-land-as-possible
#   ✔ Accepted
#   ✔ 38/38 cases passed (127 ms)
#   ✔ Your runtime beats 28.57 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (68.2 MB)
# Submitting: kotlin_solutions_1/1163.last-substring-in-lexicographical-order.kt
# - Downloading last-substring-in-lexicographical-order
#   ✔ Accepted
#   ✔ 36/36 cases passed (38 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1169.invalid-transactions.kt
# - Downloading invalid-transactions
#   ✔ Accepted
#   ✔ 38/38 cases passed (53 ms)
#   ✔ Your runtime beats 30.77 % of kotlin submissions
#   ✔ Your memory usage beats 7.69 % of kotlin submissions (50.7 MB)
# Submitting: kotlin_solutions_1/1170.compare-strings-by-frequency-of-the-smallest-character.kt
# - Downloading compare-strings-by-frequency-of-the-smallest-character
#   ✔ Accepted
#   ✔ 37/37 cases passed (91 ms)
#   ✔ Your runtime beats 7.69 % of kotlin submissions
#   ✔ Your memory usage beats 23.08 % of kotlin submissions (48.7 MB)
# Submitting: kotlin_solutions_1/1171.remove-zero-sum-consecutive-nodes-from-linked-list.kt
# - Downloading remove-zero-sum-consecutive-nodes-from-linked-list
#   ✔ Accepted
#   ✔ 105/105 cases passed (12 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (46.6 MB)
# Submitting: kotlin_solutions_1/1172.dinner-plate-stacks.kt
# - Downloading dinner-plate-stacks
#   ✔ Accepted
#   ✔ 20/20 cases passed (291 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 75 % of kotlin submissions (179.7 MB)
# Submitting: kotlin_solutions_1/1175.prime-arrangements.kt
# - Downloading prime-arrangements
#   ✔ Accepted
#   ✔ 100/100 cases passed (8 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1177.can-make-palindrome-from-substring.kt
# - Downloading can-make-palindrome-from-substring
#   ✔ Accepted
#   ✔ 31/31 cases passed (20 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1178.number-of-valid-words-for-each-puzzle.kt
# - Downloading number-of-valid-words-for-each-puzzle
#   ✘ Wrong Answer
#   ✘ 1/11 cases passed (N/A)
#   ✘ Testcase: ["aaaa","asas","able","ability","actt","actor","access"]
# ' +
#   '["aboveyz","abrodyz","abslute","absoryz","actresz","gaswxyz"]
#   ✘ Answer: [2,2,6,4,8,0]
#   ✘ Expected Answer: [1,1,3,2,4,0]
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1184.distance-between-bus-stops.kt
# - Downloading distance-between-bus-stops
#   ✔ Accepted
#   ✔ 37/37 cases passed (134 ms)
#   ✔ Your runtime beats 6.25 % of kotlin submissions
#   ✔ Your memory usage beats 18.75 % of kotlin submissions (45.1 MB)
# Submitting: kotlin_solutions_1/1185.day-of-the-week.kt
# - Downloading day-of-the-week
#   ✔ Accepted
#   ✔ 44/44 cases passed (1 ms)
#   ✔ Your runtime beats 66.67 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (40.6 MB)
# Submitting: kotlin_solutions_1/1186.maximum-subarray-sum-with-one-deletion.kt
# - Downloading maximum-subarray-sum-with-one-deletion
#   ✔ Accepted
#   ✔ 38/38 cases passed (38 ms)
#   ✔ Your runtime beats 7.69 % of kotlin submissions
#   ✔ Your memory usage beats 7.69 % of kotlin submissions (62.4 MB)
# Submitting: kotlin_solutions_1/1187.make-array-strictly-increasing.kt
# - Downloading make-array-strictly-increasing
#   ✔ Accepted
#   ✔ 22/22 cases passed (150 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (51.5 MB)
# Submitting: kotlin_solutions_1/1189.maximum-number-of-balloons.kt
# - Downloading maximum-number-of-balloons
#   ✔ Accepted
#   ✔ 29/29 cases passed (22 ms)
#   ✔ Your runtime beats 8.87 % of kotlin submissions
#   ✔ Your memory usage beats 20.38 % of kotlin submissions (43.9 MB)
# Submitting: kotlin_solutions_1/1190.reverse-substrings-between-each-pair-of-parentheses.kt
# - Downloading reverse-substrings-between-each-pair-of-parentheses
#   ✔ Accepted
#   ✔ 40/40 cases passed (9 ms)
#   ✔ Your runtime beats 70 % of kotlin submissions
#   ✔ Your memory usage beats 70 % of kotlin submissions (42.2 MB)
# Submitting: kotlin_solutions_1/1191.k-concatenation-maximum-sum.kt
# - Downloading k-concatenation-maximum-sum
#   ✔ Accepted
#   ✔ 44/44 cases passed (24 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (65.6 MB)
# Submitting: kotlin_solutions_1/1192.critical-connections-in-a-network.kt
# - Downloading critical-connections-in-a-network
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 7: Char 108: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 7: Char 108: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 7: Char 289: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 7: Char 465: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 7: Char 578: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 7: Char 618: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 43: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1200.minimum-absolute-difference.kt
# - Downloading minimum-absolute-difference
#   ✔ Accepted
#   ✔ 39/39 cases passed (145 ms)
#   ✔ Your runtime beats 6.56 % of kotlin submissions
#   ✔ Your memory usage beats 9.84 % of kotlin submissions (64.3 MB)
# Submitting: kotlin_solutions_1/1201.ugly-number-iii.kt
# - Downloading ugly-number-iii
#   ✔ Accepted
#   ✔ 53/53 cases passed (14 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1202.smallest-string-with-swaps.kt
# - Downloading smallest-string-with-swaps
#   ✔ Accepted
#   ✔ 36/36 cases passed (140 ms)
#   ✔ Your runtime beats 14.29 % of kotlin submissions
#   ✔ Your memory usage beats 28.57 % of kotlin submissions (113.7 MB)
# Submitting: kotlin_solutions_1/1203.sort-items-by-groups-respecting-dependencies.kt
# - Downloading sort-items-by-groups-respecting-dependencies
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 7: Char 236: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 7: Char 236: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 7: Char 286: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 7: Char 476: WARNING: Parameter 'it: Boolean' is never used, could be renamed to '_'.
# Line 7: Char 495: WARNING: Parameter 'it: Boolean' is never used, could be renamed to '_'.
# Line 7: Char 551: WARNING: Parameter 'it: Boolean' is never used, could be renamed to '_'.
# Line 7: Char 580: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 7: Char 805: WARNING: Parameter 'it: Boolean' is never used, could be renamed to '_'.
# Line 14: Char 1: ERROR: Argument type mismatch: actual type is 'kotlin.Unit', but 'kotlin.IntArray' was expected.
# Line 47: Char 2: ERROR: Syntax error: Expecting '}'.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1206.design-skiplist.kt
# - Downloading design-skiplist
#   ✔ Accepted
#   ✔ 21/21 cases passed (30 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (64.4 MB)
# Submitting: kotlin_solutions_1/1207.unique-number-of-occurrences.kt
# - Downloading unique-number-of-occurrences
#   ✔ Accepted
#   ✔ 73/73 cases passed (28 ms)
#   ✔ Your runtime beats 5.66 % of kotlin submissions
#   ✔ Your memory usage beats 7.55 % of kotlin submissions (46.8 MB)
# Submitting: kotlin_solutions_1/1208.get-equal-substrings-within-budget.kt
# - Downloading get-equal-substrings-within-budget
#   ✔ Accepted
#   ✔ 38/38 cases passed (33 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 11.11 % of kotlin submissions (48.3 MB)
# Submitting: kotlin_solutions_1/1209.remove-all-adjacent-duplicates-in-string-ii.kt
# - Downloading remove-all-adjacent-duplicates-in-string-ii
#   ✔ Accepted
#   ✔ 22/22 cases passed (56 ms)
#   ✔ Your runtime beats 24.24 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (48.9 MB)
# Submitting: kotlin_solutions_1/1210.minimum-moves-to-reach-target-with-rotations.kt
# - Downloading minimum-moves-to-reach-target-with-rotations
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 8: Char 987: ERROR: Only expressions are allowed in this context.
#   ✘ Error: Line 8: Char 987: ERROR: Only expressions are allowed in this context.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1217.minimum-cost-to-move-chips-to-the-same-position.kt
# - Downloading minimum-cost-to-move-chips-to-the-same-position
#   ✔ Accepted
#   ✔ 51/51 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 62.5 % of kotlin submissions (40.9 MB)
# Submitting: kotlin_solutions_1/1218.longest-arithmetic-subsequence-of-given-difference.kt
# - Downloading longest-arithmetic-subsequence-of-given-difference
#   ✔ Accepted
#   ✔ 41/41 cases passed (62 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 58.33 % of kotlin submissions (62.2 MB)
# Submitting: kotlin_solutions_1/1219.path-with-maximum-gold.kt
# - Downloading path-with-maximum-gold
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 8: Char 207: ERROR: Only expressions are allowed in this context.
#   ✘ Error: Line 8: Char 207: ERROR: Only expressions are allowed in this context.
# Line 8: Char 354: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1220.count-vowels-permutation.kt
# - Downloading count-vowels-permutation
#   ✔ Accepted
#   ✔ 64/64 cases passed (30 ms)
#   ✔ Your runtime beats 30.77 % of kotlin submissions
#   ✔ Your memory usage beats 53.85 % of kotlin submissions (45.5 MB)
# Submitting: kotlin_solutions_1/1221.split-a-string-in-balanced-strings.kt
# - Downloading split-a-string-in-balanced-strings
#   ✔ Accepted
#   ✔ 40/40 cases passed (3 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (40.8 MB)
# Submitting: kotlin_solutions_1/1222.queens-that-can-attack-the-king.kt
# - Downloading queens-that-can-attack-the-king
#   ✔ Accepted
#   ✔ 100/100 cases passed (35 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1223.dice-roll-simulation.kt
# - Downloading dice-roll-simulation
#   ✔ Accepted
#   ✔ 32/32 cases passed (54 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1224.maximum-equal-frequency.kt
# - Downloading maximum-equal-frequency
#   ✔ Accepted
#   ✔ 46/46 cases passed (44 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (62.6 MB)
# Submitting: kotlin_solutions_1/1226.the-dining-philosophers.kt
# - Downloading the-dining-philosophers
#   ✘ Internal Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1227.airplane-seat-assignment-probability.kt
# - Downloading airplane-seat-assignment-probability
#   ✔ Accepted
#   ✔ 100/100 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (40.5 MB)
# Submitting: kotlin_solutions_1/1232.check-if-it-is-a-straight-line.kt
# - Downloading check-if-it-is-a-straight-line
#   ✔ Accepted
#   ✔ 83/83 cases passed (3 ms)
#   ✔ Your runtime beats 28.57 % of kotlin submissions
#   ✔ Your memory usage beats 35.71 % of kotlin submissions (46.9 MB)
# Submitting: kotlin_solutions_1/1233.remove-sub-folders-from-the-filesystem.kt
# - Downloading remove-sub-folders-from-the-filesystem
#   ✔ Accepted
#   ✔ 35/35 cases passed (91 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (62.9 MB)
# Submitting: kotlin_solutions_1/1234.replace-the-substring-for-balanced-string.kt
# - Downloading replace-the-substring-for-balanced-string
#   ✔ Accepted
#   ✔ 40/40 cases passed (24 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (45.5 MB)
# Submitting: kotlin_solutions_1/1235.maximum-profit-in-job-scheduling.kt
# - Downloading maximum-profit-in-job-scheduling
#   ✔ Accepted
#   ✔ 35/35 cases passed (96 ms)
#   ✔ Your runtime beats 30.3 % of kotlin submissions
#   ✔ Your memory usage beats 78.79 % of kotlin submissions (62 MB)
# Submitting: kotlin_solutions_1/1237.find-positive-integer-solution-for-a-given-equation.kt
# - Downloading find-positive-integer-solution-for-a-given-equation
#   ✔ Accepted
#   ✔ 45/45 cases passed (635 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1238.circular-permutation-in-binary-representation.kt
# - Downloading circular-permutation-in-binary-representation
#   ✔ Accepted
#   ✔ 47/47 cases passed (277 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1239.maximum-length-of-a-concatenated-string-with-unique-characters.kt
# - Downloading maximum-length-of-a-concatenated-string-with-unique-characters
#   ✔ Accepted
#   ✔ 89/89 cases passed (20 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (47.2 MB)
# Submitting: kotlin_solutions_1/1240.tiling-a-rectangle-with-the-fewest-squares.kt
# - Downloading tiling-a-rectangle-with-the-fewest-squares
#   ✔ Accepted
#   ✔ 38/38 cases passed (1236 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (220.9 MB)
# Submitting: kotlin_solutions_1/1247.minimum-swaps-to-make-strings-equal.kt
# - Downloading minimum-swaps-to-make-strings-equal
#   ✔ Accepted
#   ✔ 70/70 cases passed (12 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1248.count-number-of-nice-subarrays.kt
# - Downloading count-number-of-nice-subarrays
#   ✔ Accepted
#   ✔ 38/38 cases passed (28 ms)
#   ✔ Your runtime beats 50.91 % of kotlin submissions
#   ✔ Your memory usage beats 76.36 % of kotlin submissions (59.2 MB)
# Submitting: kotlin_solutions_1/1249.minimum-remove-to-make-valid-parentheses.kt
# - Downloading minimum-remove-to-make-valid-parentheses
#   ✔ Accepted
#   ✔ 62/62 cases passed (32 ms)
#   ✔ Your runtime beats 72 % of kotlin submissions
#   ✔ Your memory usage beats 88 % of kotlin submissions (47.3 MB)
# Submitting: kotlin_solutions_1/1250.check-if-it-is-a-good-array.kt
# - Downloading check-if-it-is-a-good-array
#   ✔ Accepted
#   ✔ 48/48 cases passed (51 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1252.cells-with-odd-values-in-a-matrix.kt
# - Downloading cells-with-odd-values-in-a-matrix
#   ✔ Accepted
#   ✔ 45/45 cases passed (7 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1253.reconstruct-a-2-row-binary-matrix.kt
# - Downloading reconstruct-a-2-row-binary-matrix
#   ✔ Accepted
#   ✔ 69/69 cases passed (56 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1254.number-of-closed-islands.kt
# - Downloading number-of-closed-islands
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 7: Char 188: ERROR: Only expressions are allowed in this context.
#   ✘ Error: Line 7: Char 188: ERROR: Only expressions are allowed in this context.
# Line 7: Char 244: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 7: Char 279: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 7: Char 314: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 7: Char 509: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1255.maximum-score-words-formed-by-letters.kt
# - Downloading maximum-score-words-formed-by-letters
#   ✔ Accepted
#   ✔ 53/53 cases passed (65 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
#   ✔ Your memory usage beats 20 % of kotlin submissions (49.4 MB)
# Submitting: kotlin_solutions_1/1260.shift-2d-grid.kt
# - Downloading shift-2d-grid
#   ✔ Accepted
#   ✔ 107/107 cases passed (30 ms)
#   ✔ Your runtime beats 11.5 % of kotlin submissions
#   ✔ Your memory usage beats 62.94 % of kotlin submissions (51.3 MB)
# Submitting: kotlin_solutions_1/1261.find-elements-in-a-contaminated-binary-tree.kt
# - Downloading find-elements-in-a-contaminated-binary-tree
#   ✔ Accepted
#   ✔ 34/34 cases passed (65 ms)
#   ✔ Your runtime beats 60 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (54.8 MB)
# Submitting: kotlin_solutions_1/1262.greatest-sum-divisible-by-three.kt
# - Downloading greatest-sum-divisible-by-three
#   ✔ Accepted
#   ✔ 48/48 cases passed (17 ms)
#   ✔ Your runtime beats 85.71 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (49.1 MB)
# Submitting: kotlin_solutions_1/1263.minimum-moves-to-move-a-box-to-their-target-location.kt
# - Downloading minimum-moves-to-move-a-box-to-their-target-location
#   ✔ Accepted
#   ✔ 30/30 cases passed (234 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1266.minimum-time-visiting-all-points.kt
# - Downloading minimum-time-visiting-all-points
#   ✔ Accepted
#   ✔ 123/123 cases passed (6 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
#   ✔ Your memory usage beats 40 % of kotlin submissions (47.8 MB)
# Submitting: kotlin_solutions_1/1267.count-servers-that-communicate.kt
# - Downloading count-servers-that-communicate
#   ✔ Accepted
#   ✔ 55/55 cases passed (25 ms)
# [WARN] Failed to get runtime percentile.

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-08-17 17:25:44
