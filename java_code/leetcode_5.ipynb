# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME')
    user_cookie = userdata.get('LEETCODE_TOKEN')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME'] = user_name
    os.environ['LEETCODE_TOKEN'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME" "$LEETCODE_TOKEN" | leetcode user -c

# %%
# %%bash
#
#
# # top 100 answers
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v java_solutions/*.java | sed -n '601,750p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 8
# done
# Out:
# Submitting: java_solutions/1131.maximum-of-absolute-value-expression.java
# - Downloading problems
# - Downloading maximum-of-absolute-value-expression
#   ✔ Accepted
#   ✔ 21/21 cases passed (7 ms)
#   ✔ Your runtime beats 80.79 % of java submissions
#   ✔ Your memory usage beats 70.2 % of java submissions (53.2 MB)
# Submitting: java_solutions/1137.n-th-tribonacci-number.java
# - Downloading n-th-tribonacci-number
#   ✔ Accepted
#   ✔ 38/38 cases passed (2 ms)
#   ✔ Your runtime beats 0.68 % of java submissions
#   ✔ Your memory usage beats 85.04 % of java submissions (41.9 MB)
# Submitting: java_solutions/1138.alphabet-board-path.java
# - Downloading alphabet-board-path
#   ✔ Accepted
#   ✔ 61/61 cases passed (1 ms)
#   ✔ Your runtime beats 45.71 % of java submissions
#   ✔ Your memory usage beats 21.43 % of java submissions (43.1 MB)
# Submitting: java_solutions/1139.largest-1-bordered-square.java
# - Downloading largest-1-bordered-square
#   ✔ Accepted
#   ✔ 84/84 cases passed (9 ms)
#   ✔ Your runtime beats 37.09 % of java submissions
#   ✔ Your memory usage beats 42.38 % of java submissions (47 MB)
# Submitting: java_solutions/1140.stone-game-ii.java
# - Downloading stone-game-ii
#   ✔ Accepted
#   ✔ 92/92 cases passed (16 ms)
#   ✔ Your runtime beats 24.32 % of java submissions
#   ✔ Your memory usage beats 35.63 % of java submissions (45 MB)
# Submitting: java_solutions/1143.longest-common-subsequence.java
# - Downloading longest-common-subsequence
#   ✔ Accepted
#   ✔ 47/47 cases passed (28 ms)
#   ✔ Your runtime beats 19.01 % of java submissions
#   ✔ Your memory usage beats 35.28 % of java submissions (54 MB)
# Submitting: java_solutions/1144.decrease-elements-to-make-array-zigzag.java
# - Downloading decrease-elements-to-make-array-zigzag
#   ✔ Accepted
#   ✔ 37/37 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 65.44 % of java submissions (42.7 MB)
# Submitting: java_solutions/1145.binary-tree-coloring-game.java
# - Downloading binary-tree-coloring-game
#   ✔ Accepted
#   ✔ 64/64 cases passed (3 ms)
#   ✔ Your runtime beats 7.46 % of java submissions
#   ✔ Your memory usage beats 30.35 % of java submissions (43.3 MB)
# Submitting: java_solutions/1146.snapshot-array.java
# - Downloading snapshot-array
#   ✔ Accepted
#   ✔ 76/76 cases passed (69 ms)
#   ✔ Your runtime beats 32.92 % of java submissions
#   ✔ Your memory usage beats 19.46 % of java submissions (133.9 MB)
# Submitting: java_solutions/1147.longest-chunked-palindrome-decomposition.java
# - Downloading longest-chunked-palindrome-decomposition
#   ✔ Accepted
#   ✔ 84/84 cases passed (3 ms)
#   ✔ Your runtime beats 48.43 % of java submissions
#   ✔ Your memory usage beats 74.84 % of java submissions (44.6 MB)
# Submitting: java_solutions/1154.day-of-the-year.java
# - Downloading day-of-the-year
#   ✔ Accepted
#   ✔ 10958/10958 cases passed (28 ms)
#   ✔ Your runtime beats 7.58 % of java submissions
#   ✔ Your memory usage beats 5.76 % of java submissions (49 MB)
# Submitting: java_solutions/1155.number-of-dice-rolls-with-target-sum.java
# - Downloading number-of-dice-rolls-with-target-sum
#   ✔ Accepted
#   ✔ 65/65 cases passed (31 ms)
#   ✔ Your runtime beats 6.38 % of java submissions
#   ✔ Your memory usage beats 84.18 % of java submissions (43.5 MB)
# Submitting: java_solutions/1156.swap-for-longest-repeated-character-substring.java
# - Downloading swap-for-longest-repeated-character-substring
#   ✔ Accepted
#   ✔ 61/61 cases passed (10 ms)
#   ✔ Your runtime beats 51.75 % of java submissions
#   ✔ Your memory usage beats 38.25 % of java submissions (44 MB)
# Submitting: java_solutions/1157.online-majority-element-in-subarray.java
# - Downloading online-majority-element-in-subarray
#   ✔ Accepted
#   ✔ 37/37 cases passed (98 ms)
#   ✔ Your runtime beats 56.1 % of java submissions
#   ✔ Your memory usage beats 5.69 % of java submissions (119 MB)
# Submitting: java_solutions/1160.find-words-that-can-be-formed-by-characters.java
# - Downloading find-words-that-can-be-formed-by-characters
#   ✔ Accepted
#   ✔ 36/36 cases passed (96 ms)
#   ✔ Your runtime beats 5.2 % of java submissions
#   ✔ Your memory usage beats 5.04 % of java submissions (53 MB)
# Submitting: java_solutions/1161.maximum-level-sum-of-a-binary-tree.java
# - Downloading maximum-level-sum-of-a-binary-tree
#   ✔ Accepted
#   ✔ 41/41 cases passed (16 ms)
#   ✔ Your runtime beats 5.63 % of java submissions
#   ✔ Your memory usage beats 9.18 % of java submissions (49.5 MB)
# Submitting: java_solutions/1162.as-far-from-land-as-possible.java
# - Downloading as-far-from-land-as-possible
#   ✔ Accepted
#   ✔ 38/38 cases passed (16 ms)
#   ✔ Your runtime beats 34.96 % of java submissions
#   ✔ Your memory usage beats 73.65 % of java submissions (47.4 MB)
# Submitting: java_solutions/1163.last-substring-in-lexicographical-order.java
# - Downloading last-substring-in-lexicographical-order
#   ✔ Accepted
#   ✔ 36/36 cases passed (21 ms)
#   ✔ Your runtime beats 15.19 % of java submissions
#   ✔ Your memory usage beats 67.09 % of java submissions (49.3 MB)
# Submitting: java_solutions/1169.invalid-transactions.java
# - Downloading invalid-transactions
#   ✔ Accepted
#   ✔ 38/38 cases passed (62 ms)
#   ✔ Your runtime beats 19.43 % of java submissions
#   ✔ Your memory usage beats 31.22 % of java submissions (47.5 MB)
# Submitting: java_solutions/1170.compare-strings-by-frequency-of-the-smallest-character.java
# - Downloading compare-strings-by-frequency-of-the-smallest-character
#   ✔ Accepted
#   ✔ 37/37 cases passed (138 ms)
#   ✔ Your runtime beats 18.51 % of java submissions
#   ✔ Your memory usage beats 6.05 % of java submissions (53.7 MB)
# Submitting: java_solutions/1171.remove-zero-sum-consecutive-nodes-from-linked-list.java
# - Downloading remove-zero-sum-consecutive-nodes-from-linked-list
#   ✔ Accepted
#   ✔ 105/105 cases passed (4 ms)
#   ✔ Your runtime beats 23.3 % of java submissions
#   ✔ Your memory usage beats 33.39 % of java submissions (46.1 MB)
# Submitting: java_solutions/1172.dinner-plate-stacks.java
# - Downloading dinner-plate-stacks
#   ✔ Accepted
#   ✔ 19/19 cases passed (110 ms)
#   ✔ Your runtime beats 15.41 % of java submissions
#   ✔ Your memory usage beats 65.27 % of java submissions (170.7 MB)
# Submitting: java_solutions/1175.prime-arrangements.java
# - Downloading prime-arrangements
#   ✔ Accepted
#   ✔ 100/100 cases passed (11 ms)
#   ✔ Your runtime beats 1.81 % of java submissions
#   ✔ Your memory usage beats 13.73 % of java submissions (43.9 MB)
# Submitting: java_solutions/1177.can-make-palindrome-from-substring.java
# - Downloading can-make-palindrome-from-substring
#   ✔ Accepted
#   ✔ 31/31 cases passed (10 ms)
#   ✔ Your runtime beats 60.4 % of java submissions
#   ✔ Your memory usage beats 54.36 % of java submissions (124.6 MB)
# Submitting: java_solutions/1178.number-of-valid-words-for-each-puzzle.java
# - Downloading number-of-valid-words-for-each-puzzle
#   ✔ Accepted
#   ✔ 11/11 cases passed (81 ms)
#   ✔ Your runtime beats 27.62 % of java submissions
#   ✔ Your memory usage beats 52.38 % of java submissions (79.7 MB)
# Submitting: java_solutions/1184.distance-between-bus-stops.java
# - Downloading distance-between-bus-stops
#   ✔ Accepted
#   ✔ 37/37 cases passed (2 ms)
#   ✔ Your runtime beats 4.35 % of java submissions
#   ✔ Your memory usage beats 56.52 % of java submissions (44.1 MB)
# Submitting: java_solutions/1185.day-of-the-week.java
# - Downloading day-of-the-week
#   ✔ Accepted
#   ✔ 44/44 cases passed (6 ms)
#   ✔ Your runtime beats 8.66 % of java submissions
#   ✔ Your memory usage beats 5.82 % of java submissions (43.1 MB)
# Submitting: java_solutions/1186.maximum-subarray-sum-with-one-deletion.java
# - Downloading maximum-subarray-sum-with-one-deletion
#   ✔ Accepted
#   ✔ 38/38 cases passed (14 ms)
#   ✔ Your runtime beats 5.11 % of java submissions
#   ✔ Your memory usage beats 6.49 % of java submissions (56.3 MB)
# Submitting: java_solutions/1187.make-array-strictly-increasing.java
# - Downloading make-array-strictly-increasing
#   ✔ Accepted
#   ✔ 22/22 cases passed (42 ms)
#   ✔ Your runtime beats 86.83 % of java submissions
#   ✔ Your memory usage beats 45.37 % of java submissions (64.6 MB)
# Submitting: java_solutions/1189.maximum-number-of-balloons.java
# - Downloading maximum-number-of-balloons
#   ✔ Accepted
#   ✔ 28/28 cases passed (8 ms)
#   ✔ Your runtime beats 48.2 % of java submissions
#   ✔ Your memory usage beats 53.04 % of java submissions (43.6 MB)
# Submitting: java_solutions/1190.reverse-substrings-between-each-pair-of-parentheses.java
# - Downloading reverse-substrings-between-each-pair-of-parentheses
#   ✔ Accepted
#   ✔ 40/40 cases passed (2 ms)
#   ✔ Your runtime beats 88.64 % of java submissions
#   ✔ Your memory usage beats 85.37 % of java submissions (43 MB)
# Submitting: java_solutions/1191.k-concatenation-maximum-sum.java
# - Downloading k-concatenation-maximum-sum
#   ✔ Accepted
#   ✔ 44/44 cases passed (11 ms)
#   ✔ Your runtime beats 7.93 % of java submissions
#   ✔ Your memory usage beats 46.9 % of java submissions (64.3 MB)
# Submitting: java_solutions/1192.critical-connections-in-a-network.java
# - Downloading critical-connections-in-a-network
#   ✔ Accepted
#   ✔ 18/18 cases passed (94 ms)
#   ✔ Your runtime beats 48.85 % of java submissions
#   ✔ Your memory usage beats 75.44 % of java submissions (206.7 MB)
# Submitting: java_solutions/1200.minimum-absolute-difference.java
# - Downloading minimum-absolute-difference
#   ✔ Accepted
#   ✔ 39/39 cases passed (58 ms)
#   ✔ Your runtime beats 5.27 % of java submissions
#   ✔ Your memory usage beats 5.01 % of java submissions (74 MB)
# Submitting: java_solutions/1201.ugly-number-iii.java
# - Downloading ugly-number-iii
#   ✔ Accepted
#   ✔ 53/53 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 87.73 % of java submissions (41.9 MB)
# Submitting: java_solutions/1202.smallest-string-with-swaps.java
# - Downloading smallest-string-with-swaps
#   ✔ Accepted
#   ✔ 36/36 cases passed (1233 ms)
#   ✔ Your runtime beats 5.17 % of java submissions
#   ✔ Your memory usage beats 61.26 % of java submissions (87.1 MB)
# Submitting: java_solutions/1203.sort-items-by-groups-respecting-dependencies.java
# - Downloading sort-items-by-groups-respecting-dependencies
#   ✔ Accepted
#   ✔ 18/18 cases passed (37 ms)
#   ✔ Your runtime beats 67.42 % of java submissions
#   ✔ Your memory usage beats 43.34 % of java submissions (75.1 MB)
# Submitting: java_solutions/1206.design-skiplist.java
# - Downloading design-skiplist
#   ✔ Accepted
#   ✔ 21/21 cases passed (13 ms)
#   ✔ Your runtime beats 98.38 % of java submissions
#   ✔ Your memory usage beats 68.46 % of java submissions (65 MB)
# Submitting: java_solutions/1207.unique-number-of-occurrences.java
# - Downloading unique-number-of-occurrences
#   ✔ Accepted
#   ✔ 72/72 cases passed (15 ms)
#   ✔ Your runtime beats 5.28 % of java submissions
#   ✔ Your memory usage beats 8.37 % of java submissions (50.1 MB)
# Submitting: java_solutions/1208.get-equal-substrings-within-budget.java
# - Downloading get-equal-substrings-within-budget
#   ✔ Accepted
#   ✔ 38/38 cases passed (10 ms)
#   ✔ Your runtime beats 12.13 % of java submissions
#   ✔ Your memory usage beats 94.11 % of java submissions (44.2 MB)
# Submitting: java_solutions/1209.remove-all-adjacent-duplicates-in-string-ii.java
# - Downloading remove-all-adjacent-duplicates-in-string-ii
#   ✔ Accepted
#   ✔ 22/22 cases passed (10 ms)
#   ✔ Your runtime beats 94.57 % of java submissions
#   ✔ Your memory usage beats 87.28 % of java submissions (46.7 MB)
# Submitting: java_solutions/1210.minimum-moves-to-reach-target-with-rotations.java
# - Downloading minimum-moves-to-reach-target-with-rotations
#   ✔ Accepted
#   ✔ 42/42 cases passed (34 ms)
#   ✔ Your runtime beats 33.33 % of java submissions
#   ✔ Your memory usage beats 24.24 % of java submissions (52.7 MB)
# Submitting: java_solutions/1217.minimum-cost-to-move-chips-to-the-same-position.java
# - Downloading minimum-cost-to-move-chips-to-the-same-position
#   ✔ Accepted
#   ✔ 51/51 cases passed (3 ms)
#   ✔ Your runtime beats 1.72 % of java submissions
#   ✔ Your memory usage beats 54.01 % of java submissions (42.9 MB)
# Submitting: java_solutions/1218.longest-arithmetic-subsequence-of-given-difference.java
# - Downloading longest-arithmetic-subsequence-of-given-difference
#   ✔ Accepted
#   ✔ 41/41 cases passed (59 ms)
#   ✔ Your runtime beats 5.54 % of java submissions
#   ✔ Your memory usage beats 68.01 % of java submissions (78.6 MB)
# Submitting: java_solutions/1219.path-with-maximum-gold.java
# - Downloading path-with-maximum-gold
#   ✔ Accepted
#   ✔ 55/55 cases passed (270 ms)
#   ✔ Your runtime beats 5.12 % of java submissions
#   ✔ Your memory usage beats 6 % of java submissions (47.2 MB)
# Submitting: java_solutions/1220.count-vowels-permutation.java
# - Downloading count-vowels-permutation
#   ✔ Accepted
#   ✔ 64/64 cases passed (20 ms)
#   ✔ Your runtime beats 36.82 % of java submissions
#   ✔ Your memory usage beats 89.15 % of java submissions (42 MB)
# Submitting: java_solutions/1221.split-a-string-in-balanced-strings.java
# - Downloading split-a-string-in-balanced-strings
#   ✔ Accepted
#   ✔ 40/40 cases passed (4 ms)
#   ✔ Your runtime beats 1.62 % of java submissions
#   ✔ Your memory usage beats 9.72 % of java submissions (43 MB)
# Submitting: java_solutions/1222.queens-that-can-attack-the-king.java
# - Downloading queens-that-can-attack-the-king
#   ✔ Accepted
#   ✔ 100/100 cases passed (1 ms)
#   ✔ Your runtime beats 88.94 % of java submissions
#   ✔ Your memory usage beats 59.73 % of java submissions (44.3 MB)
# Submitting: java_solutions/1223.dice-roll-simulation.java
# - Downloading dice-roll-simulation
#   ✔ Accepted
#   ✔ 32/32 cases passed (49 ms)
#   ✔ Your runtime beats 22.05 % of java submissions
#   ✔ Your memory usage beats 31.5 % of java submissions (51.4 MB)
# Submitting: java_solutions/1224.maximum-equal-frequency.java
# - Downloading maximum-equal-frequency
#   ✔ Accepted
#   ✔ 46/46 cases passed (23 ms)
#   ✔ Your runtime beats 76 % of java submissions
#   ✔ Your memory usage beats 100 % of java submissions (61.4 MB)
# Submitting: java_solutions/1226.the-dining-philosophers.java
# - Downloading the-dining-philosophers
#   ✔ Accepted
#   ✔ 24/24 cases passed (11 ms)
#   ✔ Your runtime beats 63.21 % of java submissions
#   ✔ Your memory usage beats 24.47 % of java submissions (53.4 MB)
# Submitting: java_solutions/1227.airplane-seat-assignment-probability.java
# - Downloading airplane-seat-assignment-probability
#   ✔ Accepted
#   ✔ 100/100 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 74.08 % of java submissions (44.8 MB)
# Submitting: java_solutions/1232.check-if-it-is-a-straight-line.java
# - Downloading check-if-it-is-a-straight-line
#   ✔ Accepted
#   ✔ 82/82 cases passed (3 ms)
#   ✔ Your runtime beats 2.43 % of java submissions
#   ✔ Your memory usage beats 63.94 % of java submissions (45.1 MB)
# Submitting: java_solutions/1233.remove-sub-folders-from-the-filesystem.java
# - Downloading remove-sub-folders-from-the-filesystem
#   ✔ Accepted
#   ✔ 35/35 cases passed (66 ms)
#   ✔ Your runtime beats 35 % of java submissions
#   ✔ Your memory usage beats 49.41 % of java submissions (57.4 MB)
# Submitting: java_solutions/1234.replace-the-substring-for-balanced-string.java
# - Downloading replace-the-substring-for-balanced-string
#   ✔ Accepted
#   ✔ 40/40 cases passed (14 ms)
#   ✔ Your runtime beats 31.56 % of java submissions
#   ✔ Your memory usage beats 76.7 % of java submissions (44.8 MB)
# Submitting: java_solutions/1235.maximum-profit-in-job-scheduling.java
# - Downloading maximum-profit-in-job-scheduling
#   ✔ Accepted
#   ✔ 35/35 cases passed (52 ms)
#   ✔ Your runtime beats 27.13 % of java submissions
#   ✔ Your memory usage beats 60.66 % of java submissions (69 MB)
# Submitting: java_solutions/1237.find-positive-integer-solution-for-a-given-equation.java
# - Downloading find-positive-integer-solution-for-a-given-equation
#   ✔ Accepted
#   ✔ 45/45 cases passed (439 ms)
#   ✔ Your runtime beats 5.67 % of java submissions
#   ✔ Your memory usage beats 12.06 % of java submissions (52.8 MB)
# Submitting: java_solutions/1238.circular-permutation-in-binary-representation.java
# - Downloading circular-permutation-in-binary-representation
#   ✔ Accepted
#   ✔ 47/47 cases passed (8 ms)
#   ✔ Your runtime beats 32.47 % of java submissions
#   ✔ Your memory usage beats 81.17 % of java submissions (54.6 MB)
# Submitting: java_solutions/1239.maximum-length-of-a-concatenated-string-with-unique-characters.java
# - Downloading maximum-length-of-a-concatenated-string-with-unique-characters
#   ✔ Accepted
#   ✔ 89/89 cases passed (27 ms)
#   ✔ Your runtime beats 18.08 % of java submissions
#   ✔ Your memory usage beats 5.25 % of java submissions (52.4 MB)
# Submitting: java_solutions/1240.tiling-a-rectangle-with-the-fewest-squares.java
# - Downloading tiling-a-rectangle-with-the-fewest-squares
#   ✔ Accepted
#   ✔ 38/38 cases passed (18 ms)
#   ✔ Your runtime beats 5.68 % of java submissions
#   ✔ Your memory usage beats 10.23 % of java submissions (43.3 MB)
# Submitting: java_solutions/1247.minimum-swaps-to-make-strings-equal.java
# - Downloading minimum-swaps-to-make-strings-equal
#   ✔ Accepted
#   ✔ 70/70 cases passed (3 ms)
#   ✔ Your runtime beats 1.76 % of java submissions
#   ✔ Your memory usage beats 10.59 % of java submissions (43.2 MB)
# Submitting: java_solutions/1248.count-number-of-nice-subarrays.java
# - Downloading count-number-of-nice-subarrays
#   ✔ Accepted
#   ✔ 38/38 cases passed (17 ms)
#   ✔ Your runtime beats 27.96 % of java submissions
#   ✔ Your memory usage beats 72.18 % of java submissions (58.2 MB)
# Submitting: java_solutions/1249.minimum-remove-to-make-valid-parentheses.java
# - Downloading minimum-remove-to-make-valid-parentheses
#   ✔ Accepted
#   ✔ 62/62 cases passed (44 ms)
#   ✔ Your runtime beats 7.42 % of java submissions
#   ✔ Your memory usage beats 49.68 % of java submissions (47.4 MB)
# Submitting: java_solutions/1250.check-if-it-is-a-good-array.java
# - Downloading check-if-it-is-a-good-array
#   ✔ Accepted
#   ✔ 48/48 cases passed (10 ms)
#   ✔ Your runtime beats 0.46 % of java submissions
#   ✔ Your memory usage beats 73.01 % of java submissions (61.8 MB)
# Submitting: java_solutions/1252.cells-with-odd-values-in-a-matrix.java
# - Downloading cells-with-odd-values-in-a-matrix
#   ✔ Accepted
#   ✔ 45/45 cases passed (1124 ms)
#   ✔ Your runtime beats 2.78 % of java submissions
#   ✔ Your memory usage beats 5.75 % of java submissions (53.3 MB)
# Submitting: java_solutions/1253.reconstruct-a-2-row-binary-matrix.java
# - Downloading reconstruct-a-2-row-binary-matrix
#   ✔ Accepted
#   ✔ 69/69 cases passed (19 ms)
#   ✔ Your runtime beats 11.45 % of java submissions
#   ✔ Your memory usage beats 5.42 % of java submissions (100.6 MB)
# Submitting: java_solutions/1254.number-of-closed-islands.java
# - Downloading number-of-closed-islands
#   ✔ Accepted
#   ✔ 47/47 cases passed (11 ms)
#   ✔ Your runtime beats 6.61 % of java submissions
#   ✔ Your memory usage beats 77.02 % of java submissions (46.3 MB)
# Submitting: java_solutions/1255.maximum-score-words-formed-by-letters.java
# - Downloading maximum-score-words-formed-by-letters
#   ✔ Accepted
#   ✔ 53/53 cases passed (35 ms)
#   ✔ Your runtime beats 5.73 % of java submissions
#   ✔ Your memory usage beats 78.92 % of java submissions (43.3 MB)
# Submitting: java_solutions/1260.shift-2d-grid.java
# - Downloading shift-2d-grid
#   ✔ Accepted
#   ✔ 107/107 cases passed (12 ms)
#   ✔ Your runtime beats 6.06 % of java submissions
#   ✔ Your memory usage beats 14.22 % of java submissions (53.5 MB)
# Submitting: java_solutions/1261.find-elements-in-a-contaminated-binary-tree.java
# - Downloading find-elements-in-a-contaminated-binary-tree
#   ✔ Accepted
#   ✔ 34/34 cases passed (25 ms)
#   ✔ Your runtime beats 29.79 % of java submissions
#   ✔ Your memory usage beats 8.24 % of java submissions (49.8 MB)
# Submitting: java_solutions/1262.greatest-sum-divisible-by-three.java
# - Downloading greatest-sum-divisible-by-three
#   ✔ Accepted
#   ✔ 48/48 cases passed (50 ms)
#   ✔ Your runtime beats 5.94 % of java submissions
#   ✔ Your memory usage beats 28.85 % of java submissions (51 MB)
# Submitting: java_solutions/1263.minimum-moves-to-move-a-box-to-their-target-location.java
# - Downloading minimum-moves-to-move-a-box-to-their-target-location
#   ✔ Accepted
#   ✔ 30/30 cases passed (98 ms)
#   ✔ Your runtime beats 7.45 % of java submissions
#   ✔ Your memory usage beats 5.32 % of java submissions (59.7 MB)
# Submitting: java_solutions/1266.minimum-time-visiting-all-points.java
# - Downloading minimum-time-visiting-all-points
#   ✔ Accepted
#   ✔ 123/123 cases passed (2 ms)
#   ✔ Your runtime beats 4.34 % of java submissions
#   ✔ Your memory usage beats 13.03 % of java submissions (45.2 MB)
# Submitting: java_solutions/1267.count-servers-that-communicate.java
# - Downloading count-servers-that-communicate
#   ✔ Accepted
#   ✔ 55/55 cases passed (6 ms)
#   ✔ Your runtime beats 24.94 % of java submissions
#   ✔ Your memory usage beats 76.53 % of java submissions (54.9 MB)
# Submitting: java_solutions/1268.search-suggestions-system.java
# - Downloading search-suggestions-system
#   ✔ Accepted
#   ✔ 43/43 cases passed (35 ms)
#   ✔ Your runtime beats 32.35 % of java submissions
#   ✔ Your memory usage beats 10.56 % of java submissions (55.9 MB)
# Submitting: java_solutions/1269.number-of-ways-to-stay-in-the-same-place-after-some-steps.java
# - Downloading number-of-ways-to-stay-in-the-same-place-after-some-steps
#   ✔ Accepted
#   ✔ 33/33 cases passed (10 ms)
#   ✔ Your runtime beats 59.82 % of java submissions
#   ✔ Your memory usage beats 88.22 % of java submissions (42.5 MB)
# Submitting: java_solutions/1275.find-winner-on-a-tic-tac-toe-game.java
# - Downloading find-winner-on-a-tic-tac-toe-game
#   ✔ Accepted
#   ✔ 101/101 cases passed (6 ms)
#   ✔ Your runtime beats 1.92 % of java submissions
#   ✔ Your memory usage beats 11.63 % of java submissions (43.4 MB)
# Submitting: java_solutions/1276.number-of-burgers-with-no-waste-of-ingredients.java
# - Downloading number-of-burgers-with-no-waste-of-ingredients
#   ✔ Accepted
#   ✔ 1008/1008 cases passed (2 ms)
#   ✔ Your runtime beats 42.14 % of java submissions
#   ✔ Your memory usage beats 51.57 % of java submissions (43.9 MB)
# Submitting: java_solutions/1277.count-square-submatrices-with-all-ones.java
# - Downloading count-square-submatrices-with-all-ones
#   ✔ Accepted
#   ✔ 32/32 cases passed (19 ms)
#   ✔ Your runtime beats 5 % of java submissions
#   ✔ Your memory usage beats 98.43 % of java submissions (60.5 MB)
# Submitting: java_solutions/1278.palindrome-partitioning-iii.java
# - Downloading palindrome-partitioning-iii
#   ✔ Accepted
#   ✔ 33/33 cases passed (13 ms)
#   ✔ Your runtime beats 28.08 % of java submissions
#   ✔ Your memory usage beats 13.46 % of java submissions (43.6 MB)
# Submitting: java_solutions/1281.subtract-the-product-and-sum-of-digits-of-an-integer.java
# - Downloading subtract-the-product-and-sum-of-digits-of-an-integer
#   ✔ Accepted
#   ✔ 123/123 cases passed (5 ms)
#   ✔ Your runtime beats 0.39 % of java submissions
#   ✔ Your memory usage beats 10.32 % of java submissions (42.4 MB)
# Submitting: java_solutions/1282.group-the-people-given-the-group-size-they-belong-to.java
# - Downloading group-the-people-given-the-group-size-they-belong-to
#   ✔ Accepted
#   ✔ 103/103 cases passed (9 ms)
#   ✔ Your runtime beats 36.47 % of java submissions
#   ✔ Your memory usage beats 59.75 % of java submissions (47.1 MB)
# Submitting: java_solutions/1283.find-the-smallest-divisor-given-a-threshold.java
# - Downloading find-the-smallest-divisor-given-a-threshold
#   ✔ Accepted
#   ✔ 71/71 cases passed (9 ms)
#   ✔ Your runtime beats 58.96 % of java submissions
#   ✔ Your memory usage beats 54.11 % of java submissions (51 MB)
# Submitting: java_solutions/1284.minimum-number-of-flips-to-convert-binary-matrix-to-zero-matrix.java
# - Downloading minimum-number-of-flips-to-convert-binary-matrix-to-zero-matrix
#   ✔ Accepted
#   ✔ 26/26 cases passed (7 ms)
#   ✔ Your runtime beats 31.3 % of java submissions
#   ✔ Your memory usage beats 83.97 % of java submissions (42.8 MB)
# Submitting: java_solutions/1286.iterator-for-combination.java
# - Downloading iterator-for-combination
#   ✔ Accepted
#   ✔ 18/18 cases passed (41 ms)
#   ✔ Your runtime beats 5.52 % of java submissions
#   ✔ Your memory usage beats 6.63 % of java submissions (56.1 MB)
# Submitting: java_solutions/1287.element-appearing-more-than-25-in-sorted-array.java
# - Downloading element-appearing-more-than-25-in-sorted-array
#   ✔ Accepted
#   ✔ 29/29 cases passed (4 ms)
#   ✔ Your runtime beats 30.35 % of java submissions
#   ✔ Your memory usage beats 24.26 % of java submissions (46.8 MB)
# Submitting: java_solutions/1288.remove-covered-intervals.java
# - Downloading remove-covered-intervals
#   ✔ Accepted
#   ✔ 34/34 cases passed (11 ms)
#   ✔ Your runtime beats 6 % of java submissions
#   ✔ Your memory usage beats 44.87 % of java submissions (46.6 MB)
# Submitting: java_solutions/1289.minimum-falling-path-sum-ii.java
# - Downloading minimum-falling-path-sum-ii
#   ✔ Accepted
#   ✔ 19/19 cases passed (136 ms)
#   ✔ Your runtime beats 36.36 % of java submissions
#   ✔ Your memory usage beats 42.11 % of java submissions (54.5 MB)
# Submitting: java_solutions/1290.convert-binary-number-in-a-linked-list-to-integer.java
# - Downloading convert-binary-number-in-a-linked-list-to-integer
#   ✔ Accepted
#   ✔ 102/102 cases passed (4 ms)
#   ✔ Your runtime beats 5.85 % of java submissions
#   ✔ Your memory usage beats 52.57 % of java submissions (42.9 MB)
# Submitting: java_solutions/1291.sequential-digits.java
# - Downloading sequential-digits
#   ✔ Accepted
#   ✔ 24/24 cases passed (12 ms)
#   ✔ Your runtime beats 1.09 % of java submissions
#   ✔ Your memory usage beats 5.99 % of java submissions (48.3 MB)
# Submitting: java_solutions/1292.maximum-side-length-of-a-square-with-sum-less-than-or-equal-to-threshold.java
# - Downloading maximum-side-length-of-a-square-with-sum-less-than-or-equal-to-threshold
#   ✔ Accepted
#   ✔ 53/53 cases passed (18 ms)
#   ✔ Your runtime beats 28.98 % of java submissions
#   ✔ Your memory usage beats 9.66 % of java submissions (63.8 MB)
# Submitting: java_solutions/1293.shortest-path-in-a-grid-with-obstacles-elimination.java
# - Downloading shortest-path-in-a-grid-with-obstacles-elimination
#   ✔ Accepted
#   ✔ 55/55 cases passed (124 ms)
#   ✔ Your runtime beats 9.14 % of java submissions
#   ✔ Your memory usage beats 5.04 % of java submissions (276.1 MB)
# Submitting: java_solutions/1295.find-numbers-with-even-number-of-digits.java
# - Downloading find-numbers-with-even-number-of-digits
#   ✔ Accepted
#   ✔ 105/105 cases passed (4 ms)
#   ✔ Your runtime beats 1.24 % of java submissions
#   ✔ Your memory usage beats 19.65 % of java submissions (45.3 MB)
# Submitting: java_solutions/1296.divide-array-in-sets-of-k-consecutive-numbers.java
# - Downloading divide-array-in-sets-of-k-consecutive-numbers
#   ✔ Accepted
#   ✔ 63/63 cases passed (250 ms)
#   ✔ Your runtime beats 13.69 % of java submissions
#   ✔ Your memory usage beats 69.13 % of java submissions (79 MB)
# Submitting: java_solutions/1297.maximum-number-of-occurrences-of-a-substring.java
# - Downloading maximum-number-of-occurrences-of-a-substring
#   ✔ Accepted
#   ✔ 40/40 cases passed (132 ms)
#   ✔ Your runtime beats 12.87 % of java submissions
#   ✔ Your memory usage beats 13.43 % of java submissions (49.6 MB)
# Submitting: java_solutions/1298.maximum-candies-you-can-get-from-boxes.java
# - Downloading maximum-candies-you-can-get-from-boxes
#   ✔ Accepted
#   ✔ 44/44 cases passed (17 ms)
#   ✔ Your runtime beats 23.98 % of java submissions
#   ✔ Your memory usage beats 24.69 % of java submissions (66 MB)
# Submitting: java_solutions/1299.replace-elements-with-greatest-element-on-right-side.java
# - Downloading replace-elements-with-greatest-element-on-right-side
#   ✔ Accepted
#   ✔ 90/90 cases passed (16 ms)
#   ✔ Your runtime beats 27.57 % of java submissions
#   ✔ Your memory usage beats 12.44 % of java submissions (49.6 MB)
# Submitting: java_solutions/1300.sum-of-mutated-array-closest-to-target.java
# - Downloading sum-of-mutated-array-closest-to-target
#   ✔ Accepted
#   ✔ 22/22 cases passed (25 ms)
#   ✔ Your runtime beats 6.61 % of java submissions
#   ✔ Your memory usage beats 8.81 % of java submissions (53 MB)
# Submitting: java_solutions/1301.number-of-paths-with-max-score.java
# - Downloading number-of-paths-with-max-score
#   ✔ Accepted
#   ✔ 25/25 cases passed (38 ms)
#   ✔ Your runtime beats 23.68 % of java submissions
#   ✔ Your memory usage beats 51.97 % of java submissions (45.3 MB)
# Submitting: java_solutions/1302.deepest-leaves-sum.java
# - Downloading deepest-leaves-sum
#   ✔ Accepted
#   ✔ 39/39 cases passed (14 ms)
#   ✔ Your runtime beats 6.74 % of java submissions
#   ✔ Your memory usage beats 8.95 % of java submissions (49.2 MB)
# Submitting: java_solutions/1304.find-n-unique-integers-sum-up-to-zero.java
# - Downloading find-n-unique-integers-sum-up-to-zero
#   ✔ Accepted
#   ✔ 43/43 cases passed (3 ms)
#   ✔ Your runtime beats 2.27 % of java submissions
#   ✔ Your memory usage beats 98.13 % of java submissions (42.6 MB)
# Submitting: java_solutions/1305.all-elements-in-two-binary-search-trees.java
# - Downloading all-elements-in-two-binary-search-trees
#   ✔ Accepted
#   ✔ 48/48 cases passed (21 ms)
#   ✔ Your runtime beats 18.12 % of java submissions
#   ✔ Your memory usage beats 36.15 % of java submissions (49.1 MB)
# Submitting: java_solutions/1306.jump-game-iii.java
# - Downloading jump-game-iii
#   ✔ Accepted
#   ✔ 56/56 cases passed (10 ms)
#   ✔ Your runtime beats 23.72 % of java submissions
#   ✔ Your memory usage beats 18.94 % of java submissions (56.2 MB)
# Submitting: java_solutions/1307.verbal-arithmetic-puzzle.java
# - Downloading verbal-arithmetic-puzzle
#   ✔ Accepted
#   ✔ 34/34 cases passed (18 ms)
#   ✔ Your runtime beats 77 % of java submissions
#   ✔ Your memory usage beats 61 % of java submissions (44.2 MB)
# Submitting: java_solutions/1309.decrypt-string-from-alphabet-to-integer-mapping.java
# - Downloading decrypt-string-from-alphabet-to-integer-mapping
#   ✔ Accepted
#   ✔ 41/41 cases passed (11 ms)
#   ✔ Your runtime beats 5.5 % of java submissions
#   ✔ Your memory usage beats 5.65 % of java submissions (44.1 MB)
# Submitting: java_solutions/1310.xor-queries-of-a-subarray.java
# - Downloading xor-queries-of-a-subarray
#   ✔ Accepted
#   ✔ 46/46 cases passed (5 ms)
#   ✔ Your runtime beats 19.21 % of java submissions
#   ✔ Your memory usage beats 28.45 % of java submissions (94.2 MB)
# Submitting: java_solutions/1311.get-watched-videos-by-your-friends.java
# - Downloading get-watched-videos-by-your-friends
#   ✔ Accepted
#   ✔ 52/52 cases passed (51 ms)
#   ✔ Your runtime beats 6.51 % of java submissions
#   ✔ Your memory usage beats 5.28 % of java submissions (53.2 MB)
# Submitting: java_solutions/1312.minimum-insertion-steps-to-make-a-string-palindrome.java
# - Downloading minimum-insertion-steps-to-make-a-string-palindrome
#   ✔ Accepted
#   ✔ 58/58 cases passed (41 ms)
#   ✔ Your runtime beats 9.75 % of java submissions
#   ✔ Your memory usage beats 20.99 % of java submissions (47.8 MB)
# Submitting: java_solutions/1313.decompress-run-length-encoded-list.java
# - Downloading decompress-run-length-encoded-list
#   ✔ Accepted
#   ✔ 53/53 cases passed (9 ms)
#   ✔ Your runtime beats 6.66 % of java submissions
#   ✔ Your memory usage beats 36.21 % of java submissions (46.7 MB)
# Submitting: java_solutions/1314.matrix-block-sum.java
# - Downloading matrix-block-sum
#   ✔ Accepted
#   ✔ 12/12 cases passed (12 ms)
#   ✔ Your runtime beats 31.36 % of java submissions
#   ✔ Your memory usage beats 9.5 % of java submissions (46.9 MB)
# Submitting: java_solutions/1315.sum-of-nodes-with-even-valued-grandparent.java
# - Downloading sum-of-nodes-with-even-valued-grandparent
#   ✔ Accepted
#   ✔ 76/76 cases passed (19 ms)
#   ✔ Your runtime beats 5.81 % of java submissions
#   ✔ Your memory usage beats 13.79 % of java submissions (48 MB)
# Submitting: java_solutions/1316.distinct-echo-substrings.java
# - Downloading distinct-echo-substrings
#   ✔ Accepted
#   ✔ 40/40 cases passed (1389 ms)
#   ✔ Your runtime beats 45.19 % of java submissions
#   ✔ Your memory usage beats 52.3 % of java submissions (48.9 MB)
# Submitting: java_solutions/1317.convert-integer-to-the-sum-of-two-no-zero-integers.java
# - Downloading convert-integer-to-the-sum-of-two-no-zero-integers
#   ✔ Accepted
#   ✔ 210/210 cases passed (6 ms)
#   ✔ Your runtime beats 6.13 % of java submissions
#   ✔ Your memory usage beats 9.49 % of java submissions (43.3 MB)
# Submitting: java_solutions/1318.minimum-flips-to-make-a-or-b-equal-to-c.java
# - Downloading minimum-flips-to-make-a-or-b-equal-to-c
#   ✔ Accepted
#   ✔ 64/64 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 60 % of java submissions (42.1 MB)
# Submitting: java_solutions/1319.number-of-operations-to-make-network-connected.java
# - Downloading number-of-operations-to-make-network-connected
#   ✔ Accepted
#   ✔ 36/36 cases passed (31 ms)
#   ✔ Your runtime beats 5.31 % of java submissions
#   ✔ Your memory usage beats 92.09 % of java submissions (65.2 MB)
# Submitting: java_solutions/1320.minimum-distance-to-type-a-word-using-two-fingers.java
# - Downloading minimum-distance-to-type-a-word-using-two-fingers
#   ✔ Accepted
#   ✔ 55/55 cases passed (85 ms)
#   ✔ Your runtime beats 6.24 % of java submissions
#   ✔ Your memory usage beats 32.92 % of java submissions (47.4 MB)
# Submitting: java_solutions/1323.maximum-69-number.java
# - Downloading maximum-69-number
#   ✔ Accepted
#   ✔ 153/153 cases passed (3 ms)
#   ✔ Your runtime beats 12.92 % of java submissions
#   ✔ Your memory usage beats 28.26 % of java submissions (42.4 MB)
# Submitting: java_solutions/1324.print-words-vertically.java
# - Downloading print-words-vertically
#   ✔ Accepted
#   ✔ 32/32 cases passed (1 ms)
#   ✔ Your runtime beats 85.81 % of java submissions
#   ✔ Your memory usage beats 98.71 % of java submissions (42.7 MB)
# Submitting: java_solutions/1325.delete-leaves-with-a-given-value.java
# - Downloading delete-leaves-with-a-given-value
#   ✔ Accepted
#   ✔ 51/51 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 48.39 % of java submissions (46.4 MB)
# Submitting: java_solutions/1326.minimum-number-of-taps-to-open-to-water-a-garden.java
# - Downloading minimum-number-of-taps-to-open-to-water-a-garden
#   ✔ Accepted
#   ✔ 42/42 cases passed (8 ms)
#   ✔ Your runtime beats 29.25 % of java submissions
#   ✔ Your memory usage beats 85.67 % of java submissions (46.5 MB)
# Submitting: java_solutions/1328.break-a-palindrome.java
# - Downloading break-a-palindrome
#   ✔ Accepted
#   ✔ 33/33 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 19.95 % of java submissions (43 MB)
# Submitting: java_solutions/1329.sort-the-matrix-diagonally.java
# - Downloading sort-the-matrix-diagonally
#   ✔ Accepted
#   ✔ 15/15 cases passed (438 ms)
#   ✔ Your runtime beats 7.03 % of java submissions
#   ✔ Your memory usage beats 100 % of java submissions (45.9 MB)
# Submitting: java_solutions/1330.reverse-subarray-to-maximize-array-value.java
# - Downloading reverse-subarray-to-maximize-array-value
#   ✔ Accepted
#   ✔ 28/28 cases passed (27 ms)
#   ✔ Your runtime beats 5.68 % of java submissions
#   ✔ Your memory usage beats 50 % of java submissions (51 MB)
# Submitting: java_solutions/1331.rank-transform-of-an-array.java
# - Downloading rank-transform-of-an-array
#   ✔ Accepted
#   ✔ 43/43 cases passed (54 ms)
#   ✔ Your runtime beats 12.82 % of java submissions
#   ✔ Your memory usage beats 5.06 % of java submissions (88.2 MB)
# Submitting: java_solutions/1332.remove-palindromic-subsequences.java
# - Downloading remove-palindromic-subsequences
#   ✔ Accepted
#   ✔ 48/48 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 66.67 % of java submissions (42.6 MB)
# Submitting: java_solutions/1333.filter-restaurants-by-vegan-friendly-price-and-distance.java
# - Downloading filter-restaurants-by-vegan-friendly-price-and-distance
#   ✔ Accepted
#   ✔ 53/53 cases passed (12 ms)
#   ✔ Your runtime beats 16.46 % of java submissions
#   ✔ Your memory usage beats 5.7 % of java submissions (61.3 MB)
# Submitting: java_solutions/1334.find-the-city-with-the-smallest-number-of-neighbors-at-a-threshold-distance.java
# - Downloading find-the-city-with-the-smallest-number-of-neighbors-at-a-threshold-distance
#   ✔ Accepted
#   ✔ 54/54 cases passed (68 ms)
#   ✔ Your runtime beats 6.87 % of java submissions
#   ✔ Your memory usage beats 5.4 % of java submissions (53.3 MB)
# Submitting: java_solutions/1335.minimum-difficulty-of-a-job-schedule.java
# - Downloading minimum-difficulty-of-a-job-schedule
#   ✔ Accepted
#   ✔ 34/34 cases passed (22 ms)
#   ✔ Your runtime beats 37.28 % of java submissions
#   ✔ Your memory usage beats 48.66 % of java submissions (43.3 MB)
# Submitting: java_solutions/1337.the-k-weakest-rows-in-a-matrix.java
# - Downloading the-k-weakest-rows-in-a-matrix
#   ✔ Accepted
#   ✔ 52/52 cases passed (13 ms)
#   ✔ Your runtime beats 5.63 % of java submissions
#   ✔ Your memory usage beats 12.13 % of java submissions (53.3 MB)
# Submitting: java_solutions/1338.reduce-array-size-to-the-half.java
# - Downloading reduce-array-size-to-the-half
#   ✔ Accepted
#   ✔ 33/33 cases passed (72 ms)
#   ✔ Your runtime beats 5.11 % of java submissions
#   ✔ Your memory usage beats 8.2 % of java submissions (95.7 MB)
# Submitting: java_solutions/1339.maximum-product-of-splitted-binary-tree.java
# - Downloading maximum-product-of-splitted-binary-tree
#   ✔ Accepted
#   ✔ 56/56 cases passed (84 ms)
#   ✔ Your runtime beats 5.11 % of java submissions
#   ✔ Your memory usage beats 8.85 % of java submissions (68 MB)
# Submitting: java_solutions/1340.jump-game-v.java
# - Downloading jump-game-v
#   ✔ Accepted
#   ✔ 127/127 cases passed (38 ms)
#   ✔ Your runtime beats 9.03 % of java submissions
#   ✔ Your memory usage beats 5.9 % of java submissions (47.4 MB)
# Submitting: java_solutions/1342.number-of-steps-to-reduce-a-number-to-zero.java
# - Downloading number-of-steps-to-reduce-a-number-to-zero
#   ✔ Accepted
#   ✔ 204/204 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 54.75 % of java submissions (42.1 MB)
# Submitting: java_solutions/1343.number-of-sub-arrays-of-size-k-and-average-greater-than-or-equal-to-threshold.java
# - Downloading number-of-sub-arrays-of-size-k-and-average-greater-than-or-equal-to-threshold
#   ✔ Accepted
#   ✔ 69/69 cases passed (7 ms)
#   ✔ Your runtime beats 5.92 % of java submissions
#   ✔ Your memory usage beats 61.69 % of java submissions (71.7 MB)
# Submitting: java_solutions/1344.angle-between-hands-of-a-clock.java
# - Downloading angle-between-hands-of-a-clock
#   ✔ Accepted
#   ✔ 105/105 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 87.38 % of java submissions (44.7 MB)
# Submitting: java_solutions/1345.jump-game-iv.java
# - Downloading jump-game-iv
#   ✔ Accepted
#   ✔ 33/33 cases passed (81 ms)
#   ✔ Your runtime beats 12.96 % of java submissions
#   ✔ Your memory usage beats 99.8 % of java submissions (65.6 MB)
# Submitting: java_solutions/1346.check-if-n-and-its-double-exist.java
# - Downloading check-if-n-and-its-double-exist
#   ✔ Accepted
#   ✔ 113/113 cases passed (11 ms)
#   ✔ Your runtime beats 6.71 % of java submissions
#   ✔ Your memory usage beats 6.04 % of java submissions (45.6 MB)
# Submitting: java_solutions/1347.minimum-number-of-steps-to-make-two-strings-anagram.java
# - Downloading minimum-number-of-steps-to-make-two-strings-anagram
#   ✔ Accepted
#   ✔ 63/63 cases passed (13 ms)
#   ✔ Your runtime beats 25.13 % of java submissions
#   ✔ Your memory usage beats 24.61 % of java submissions (47.8 MB)
# Submitting: java_solutions/1348.tweet-counts-per-frequency.java
# - Downloading tweet-counts-per-frequency
#   ✔ Accepted
#   ✔ 22/22 cases passed (158 ms)
#   ✔ Your runtime beats 12.56 % of java submissions
#   ✔ Your memory usage beats 5.38 % of java submissions (62.4 MB)
# Submitting: java_solutions/1349.maximum-students-taking-exam.java
# - Downloading maximum-students-taking-exam
#   ✔ Accepted
#   ✔ 57/57 cases passed (8 ms)
#   ✔ Your runtime beats 29.94 % of java submissions
#   ✔ Your memory usage beats 44.07 % of java submissions (43.2 MB)
# Submitting: java_solutions/1351.count-negative-numbers-in-a-sorted-matrix.java
# - Downloading count-negative-numbers-in-a-sorted-matrix
#   ✔ Accepted
#   ✔ 44/44 cases passed (4 ms)
#   ✔ Your runtime beats 1.1 % of java submissions
#   ✔ Your memory usage beats 24.66 % of java submissions (47.1 MB)
# Submitting: java_solutions/1352.product-of-the-last-k-numbers.java
# - Downloading product-of-the-last-k-numbers
#   ✔ Accepted
#   ✔ 35/35 cases passed (28 ms)
#   ✔ Your runtime beats 17.54 % of java submissions
#   ✔ Your memory usage beats 5.38 % of java submissions (87.4 MB)
# Submitting: java_solutions/1353.maximum-number-of-events-that-can-be-attended.java
# - Downloading maximum-number-of-events-that-can-be-attended
#   ✔ Accepted
#   ✔ 45/45 cases passed (84 ms)
#   ✔ Your runtime beats 5.06 % of java submissions
#   ✔ Your memory usage beats 5.06 % of java submissions (103.7 MB)
# Submitting: java_solutions/1354.construct-target-array-with-multiple-sums.java
# - Downloading construct-target-array-with-multiple-sums
# [ERROR] http error [code=429]
# Submitting: java_solutions/1356.sort-integers-by-the-number-of-1-bits.java
# - Downloading sort-integers-by-the-number-of-1-bits
# [ERROR] http error [code=429]
# Submitting: java_solutions/1357.apply-discount-every-n-orders.java
# - Downloading apply-discount-every-n-orders
# [ERROR] http error [code=429]
# Submitting: java_solutions/1358.number-of-substrings-containing-all-three-characters.java
# - Downloading number-of-substrings-containing-all-three-characters
# [ERROR] http error [code=429]
# Submitting: java_solutions/1359.count-all-valid-pickup-and-delivery-options.java
# - Downloading count-all-valid-pickup-and-delivery-options
# [ERROR] http error [code=429]
# Submitting: java_solutions/1360.number-of-days-between-two-dates.java
# - Downloading number-of-days-between-two-dates
# [ERROR] http error [code=429]
# Submitting: java_solutions/1361.validate-binary-tree-nodes.java
# - Downloading validate-binary-tree-nodes
# [ERROR] http error [code=429]

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-05-04 22:55:09
