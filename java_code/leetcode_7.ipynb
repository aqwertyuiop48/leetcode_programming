# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME_3')
    user_cookie = userdata.get('LEETCODE_TOKEN_3')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME_3'] = user_name
    os.environ['LEETCODE_TOKEN_3'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME_3" "$LEETCODE_TOKEN_3" | leetcode user -c

# %%
# %%bash
#
#
# # top 100 answers
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v java_solutions/*.java | sed -n '901,1050p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 8
# done
# Out:
# Submitting: java_solutions/1556.thousand-separator.java
# - Downloading problems
# - Downloading thousand-separator
#   ✔ Accepted
#   ✔ 69/69 cases passed (10 ms)
#   ✔ Your runtime beats 4.67 % of java submissions
#   ✔ Your memory usage beats 8.18 % of java submissions (43.5 MB)
# Submitting: java_solutions/1557.minimum-number-of-vertices-to-reach-all-nodes.java
# - Downloading minimum-number-of-vertices-to-reach-all-nodes
#   ✔ Accepted
#   ✔ 66/66 cases passed (11 ms)
#   ✔ Your runtime beats 29.88 % of java submissions
#   ✔ Your memory usage beats 20.51 % of java submissions (105.1 MB)
# Submitting: java_solutions/1558.minimum-numbers-of-function-calls-to-make-target-array.java
# - Downloading minimum-numbers-of-function-calls-to-make-target-array
#   ✔ Accepted
#   ✔ 58/58 cases passed (8 ms)
#   ✔ Your runtime beats 83.33 % of java submissions
#   ✔ Your memory usage beats 52.38 % of java submissions (55 MB)
# Submitting: java_solutions/1559.detect-cycles-in-2d-grid.java
# - Downloading detect-cycles-in-2d-grid
#   ✔ Accepted
#   ✔ 77/77 cases passed (32 ms)
#   ✔ Your runtime beats 5.59 % of java submissions
#   ✔ Your memory usage beats 82.86 % of java submissions (123.9 MB)
# Submitting: java_solutions/1560.most-visited-sector-in-a-circular-track.java
# - Downloading most-visited-sector-in-a-circular-track
#   ✔ Accepted
#   ✔ 204/204 cases passed (6 ms)
#   ✔ Your runtime beats 6.33 % of java submissions
#   ✔ Your memory usage beats 10.76 % of java submissions (44.8 MB)
# Submitting: java_solutions/1561.maximum-number-of-coins-you-can-get.java
# - Downloading maximum-number-of-coins-you-can-get
#   ✔ Accepted
#   ✔ 116/116 cases passed (40 ms)
#   ✔ Your runtime beats 7.12 % of java submissions
#   ✔ Your memory usage beats 93.22 % of java submissions (68.8 MB)
# Submitting: java_solutions/1562.find-latest-group-of-size-m.java
# - Downloading find-latest-group-of-size-m
#   ✔ Accepted
#   ✔ 114/114 cases passed (9 ms)
#   ✔ Your runtime beats 34.94 % of java submissions
#   ✔ Your memory usage beats 39.76 % of java submissions (89.3 MB)
# Submitting: java_solutions/1563.stone-game-v.java
# - Downloading stone-game-v
#   ✔ Accepted
#   ✔ 132/132 cases passed (1213 ms)
#   ✔ Your runtime beats 5.71 % of java submissions
#   ✔ Your memory usage beats 52.14 % of java submissions (47.7 MB)
# Submitting: java_solutions/1566.detect-pattern-of-length-m-repeated-k-or-more-times.java
# - Downloading detect-pattern-of-length-m-repeated-k-or-more-times
#   ✔ Accepted
#   ✔ 94/94 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 89.77 % of java submissions (42.8 MB)
# Submitting: java_solutions/1567.maximum-length-of-subarray-with-positive-product.java
# - Downloading maximum-length-of-subarray-with-positive-product
#   ✔ Accepted
#   ✔ 112/112 cases passed (4 ms)
#   ✔ Your runtime beats 17.01 % of java submissions
#   ✔ Your memory usage beats 66.39 % of java submissions (76.8 MB)
# Submitting: java_solutions/1568.minimum-number-of-days-to-disconnect-island.java
# - Downloading minimum-number-of-days-to-disconnect-island
#   ✔ Accepted
#   ✔ 104/104 cases passed (54 ms)
#   ✔ Your runtime beats 5.3 % of java submissions
#   ✔ Your memory usage beats 7.2 % of java submissions (47.4 MB)
# Submitting: java_solutions/1569.number-of-ways-to-reorder-array-to-get-same-bst.java
# - Downloading number-of-ways-to-reorder-array-to-get-same-bst
#   ✔ Accepted
#   ✔ 161/161 cases passed (91 ms)
#   ✔ Your runtime beats 30.1 % of java submissions
#   ✔ Your memory usage beats 54.59 % of java submissions (169.1 MB)
# Submitting: java_solutions/1572.matrix-diagonal-sum.java
# - Downloading matrix-diagonal-sum
#   ✔ Accepted
#   ✔ 114/114 cases passed (8 ms)
#   ✔ Your runtime beats 0.66 % of java submissions
#   ✔ Your memory usage beats 31.45 % of java submissions (46.5 MB)
# Submitting: java_solutions/1573.number-of-ways-to-split-a-string.java
# - Downloading number-of-ways-to-split-a-string
#   ✔ Accepted
#   ✔ 164/164 cases passed (15 ms)
#   ✔ Your runtime beats 5.08 % of java submissions
#   ✔ Your memory usage beats 9.32 % of java submissions (48.1 MB)
# Submitting: java_solutions/1574.shortest-subarray-to-be-removed-to-make-array-sorted.java
# - Downloading shortest-subarray-to-be-removed-to-make-array-sorted
#   ✔ Accepted
#   ✔ 119/119 cases passed (3 ms)
#   ✔ Your runtime beats 23.52 % of java submissions
#   ✔ Your memory usage beats 58.43 % of java submissions (85.4 MB)
# Submitting: java_solutions/1575.count-all-possible-routes.java
# - Downloading count-all-possible-routes
#   ✔ Accepted
#   ✔ 109/109 cases passed (139 ms)
#   ✔ Your runtime beats 5.91 % of java submissions
#   ✔ Your memory usage beats 46.8 % of java submissions (46.3 MB)
# Submitting: java_solutions/1576.replace-all-s-to-avoid-consecutive-repeating-characters.java
# - Downloading replace-all-s-to-avoid-consecutive-repeating-characters
#   ✔ Accepted
#   ✔ 776/776 cases passed (1 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 92.59 % of java submissions (43.6 MB)
# Submitting: java_solutions/1577.number-of-ways-where-square-of-number-is-equal-to-product-of-two-numbers.java
# - Downloading number-of-ways-where-square-of-number-is-equal-to-product-of-two-numbers
#   ✔ Accepted
#   ✔ 93/93 cases passed (51 ms)
#   ✔ Your runtime beats 56.34 % of java submissions
#   ✔ Your memory usage beats 26.06 % of java submissions (53.5 MB)
# Submitting: java_solutions/1578.minimum-time-to-make-rope-colorful.java
# - Downloading minimum-time-to-make-rope-colorful
#   ✔ Accepted
#   ✔ 114/114 cases passed (12 ms)
#   ✔ Your runtime beats 14.08 % of java submissions
#   ✔ Your memory usage beats 30.31 % of java submissions (92.8 MB)
# Submitting: java_solutions/1579.remove-max-number-of-edges-to-keep-graph-fully-traversable.java
# - Downloading remove-max-number-of-edges-to-keep-graph-fully-traversable
#   ✔ Accepted
#   ✔ 86/86 cases passed (21 ms)
#   ✔ Your runtime beats 40.08 % of java submissions
#   ✔ Your memory usage beats 96.41 % of java submissions (135.2 MB)
# Submitting: java_solutions/1582.special-positions-in-a-binary-matrix.java
# - Downloading special-positions-in-a-binary-matrix
#   ✔ Accepted
#   ✔ 95/95 cases passed (5 ms)
#   ✔ Your runtime beats 5.41 % of java submissions
#   ✔ Your memory usage beats 10.02 % of java submissions (47.3 MB)
# Submitting: java_solutions/1583.count-unhappy-friends.java
# - Downloading count-unhappy-friends
#   ✔ Accepted
#   ✔ 99/99 cases passed (15 ms)
#   ✔ Your runtime beats 34.36 % of java submissions
#   ✔ Your memory usage beats 74.23 % of java submissions (65.6 MB)
# Submitting: java_solutions/1584.min-cost-to-connect-all-points.java
# - Downloading min-cost-to-connect-all-points
#   ✔ Accepted
#   ✔ 72/72 cases passed (25 ms)
#   ✔ Your runtime beats 80.07 % of java submissions
#   ✔ Your memory usage beats 87.35 % of java submissions (45 MB)
# Submitting: java_solutions/1585.check-if-string-is-transformable-with-substring-sort-operations.java
# - Downloading check-if-string-is-transformable-with-substring-sort-operations
#   ✔ Accepted
#   ✔ 138/138 cases passed (25 ms)
#   ✔ Your runtime beats 55.71 % of java submissions
#   ✔ Your memory usage beats 47.14 % of java submissions (51.5 MB)
# Submitting: java_solutions/1588.sum-of-all-odd-length-subarrays.java
# - Downloading sum-of-all-odd-length-subarrays
#   ✔ Accepted
#   ✔ 96/96 cases passed (1 ms)
#   ✔ Your runtime beats 59.58 % of java submissions
#   ✔ Your memory usage beats 9.64 % of java submissions (43.3 MB)
# Submitting: java_solutions/1589.maximum-sum-obtained-of-any-permutation.java
# - Downloading maximum-sum-obtained-of-any-permutation
#   ✔ Accepted
#   ✔ 84/84 cases passed (49 ms)
#   ✔ Your runtime beats 10.66 % of java submissions
#   ✔ Your memory usage beats 15.74 % of java submissions (114.8 MB)
# Submitting: java_solutions/1590.make-sum-divisible-by-p.java
# - Downloading make-sum-divisible-by-p
#   ✔ Accepted
#   ✔ 145/145 cases passed (39 ms)
#   ✔ Your runtime beats 5.64 % of java submissions
#   ✔ Your memory usage beats 5.04 % of java submissions (101.4 MB)
# Submitting: java_solutions/1591.strange-printer-ii.java
# - Downloading strange-printer-ii
#   ✔ Accepted
#   ✔ 153/153 cases passed (20 ms)
#   ✔ Your runtime beats 71.43 % of java submissions
#   ✔ Your memory usage beats 78.15 % of java submissions (47.1 MB)
# Submitting: java_solutions/1592.rearrange-spaces-between-words.java
# - Downloading rearrange-spaces-between-words
#   ✔ Accepted
#   ✔ 90/90 cases passed (6 ms)
#   ✔ Your runtime beats 6.94 % of java submissions
#   ✔ Your memory usage beats 5.2 % of java submissions (44 MB)
# Submitting: java_solutions/1593.split-a-string-into-the-max-number-of-unique-substrings.java
# - Downloading split-a-string-into-the-max-number-of-unique-substrings
#   ✔ Accepted
#   ✔ 96/96 cases passed (129 ms)
#   ✔ Your runtime beats 5.13 % of java submissions
#   ✔ Your memory usage beats 57.7 % of java submissions (46.7 MB)
# Submitting: java_solutions/1594.maximum-non-negative-product-in-a-matrix.java
# - Downloading maximum-non-negative-product-in-a-matrix
#   ✔ Accepted
#   ✔ 159/159 cases passed (2 ms)
#   ✔ Your runtime beats 39.73 % of java submissions
#   ✔ Your memory usage beats 70.57 % of java submissions (43.9 MB)
# Submitting: java_solutions/1595.minimum-cost-to-connect-two-groups-of-points.java
# - Downloading minimum-cost-to-connect-two-groups-of-points
#   ✔ Accepted
#   ✔ 84/84 cases passed (81 ms)
#   ✔ Your runtime beats 28.8 % of java submissions
#   ✔ Your memory usage beats 99.2 % of java submissions (43.5 MB)
# Submitting: java_solutions/1598.crawler-log-folder.java
# - Downloading crawler-log-folder
#   ✔ Accepted
#   ✔ 99/99 cases passed (2 ms)
#   ✔ Your runtime beats 42.73 % of java submissions
#   ✔ Your memory usage beats 40.5 % of java submissions (44 MB)
# Submitting: java_solutions/1599.maximum-profit-of-operating-a-centennial-wheel.java
# - Downloading maximum-profit-of-operating-a-centennial-wheel
#   ✔ Accepted
#   ✔ 145/145 cases passed (30 ms)
#   ✔ Your runtime beats 8.33 % of java submissions
#   ✔ Your memory usage beats 29.17 % of java submissions (63.2 MB)
# Submitting: java_solutions/1600.throne-inheritance.java
# - Downloading throne-inheritance
#   ✔ Accepted
#   ✔ 49/49 cases passed (273 ms)
#   ✔ Your runtime beats 12.18 % of java submissions
#   ✔ Your memory usage beats 53.24 % of java submissions (119 MB)
# Submitting: java_solutions/1601.maximum-number-of-achievable-transfer-requests.java
# - Downloading maximum-number-of-achievable-transfer-requests
#   ✔ Accepted
#   ✔ 117/117 cases passed (222 ms)
#   ✔ Your runtime beats 5.59 % of java submissions
#   ✔ Your memory usage beats 36.65 % of java submissions (43.3 MB)
# Submitting: java_solutions/1603.design-parking-system.java
# - Downloading design-parking-system
#   ✔ Accepted
#   ✔ 102/102 cases passed (8 ms)
#   ✔ Your runtime beats 68.61 % of java submissions
#   ✔ Your memory usage beats 82.37 % of java submissions (46.8 MB)
# Submitting: java_solutions/1604.alert-using-same-key-card-three-or-more-times-in-a-one-hour-period.java
# - Downloading alert-using-same-key-card-three-or-more-times-in-a-one-hour-period
#   ✔ Accepted
#   ✔ 78/78 cases passed (83 ms)
#   ✔ Your runtime beats 42.86 % of java submissions
#   ✔ Your memory usage beats 34.04 % of java submissions (80.4 MB)
# Submitting: java_solutions/1605.find-valid-matrix-given-row-and-column-sums.java
# - Downloading find-valid-matrix-given-row-and-column-sums
#   ✔ Accepted
#   ✔ 85/85 cases passed (25 ms)
#   ✔ Your runtime beats 7.11 % of java submissions
#   ✔ Your memory usage beats 9.01 % of java submissions (61 MB)
# Submitting: java_solutions/1606.find-servers-that-handled-most-number-of-requests.java
# - Downloading find-servers-that-handled-most-number-of-requests
#   ✔ Accepted
#   ✔ 108/108 cases passed (159 ms)
#   ✔ Your runtime beats 16.27 % of java submissions
#   ✔ Your memory usage beats 6.63 % of java submissions (109.8 MB)
# Submitting: java_solutions/1608.special-array-with-x-elements-greater-than-or-equal-x.java
# - Downloading special-array-with-x-elements-greater-than-or-equal-x
#   ✔ Accepted
#   ✔ 98/98 cases passed (13 ms)
#   ✔ Your runtime beats 6.87 % of java submissions
#   ✔ Your memory usage beats 10.21 % of java submissions (44.5 MB)
# Submitting: java_solutions/1609.even-odd-tree.java
# - Downloading even-odd-tree
#   ✔ Accepted
#   ✔ 107/107 cases passed (19 ms)
#   ✔ Your runtime beats 14.34 % of java submissions
#   ✔ Your memory usage beats 5.08 % of java submissions (103.8 MB)
# Submitting: java_solutions/1610.maximum-number-of-visible-points.java
# - Downloading maximum-number-of-visible-points
#   ✔ Accepted
#   ✔ 119/119 cases passed (125 ms)
#   ✔ Your runtime beats 90.55 % of java submissions
#   ✔ Your memory usage beats 85.04 % of java submissions (159.1 MB)
# Submitting: java_solutions/1611.minimum-one-bit-operations-to-make-integers-zero.java
# - Downloading minimum-one-bit-operations-to-make-integers-zero
#   ✔ Accepted
#   ✔ 308/308 cases passed (5 ms)
#   ✔ Your runtime beats 1.29 % of java submissions
#   ✔ Your memory usage beats 6.96 % of java submissions (42.9 MB)
# Submitting: java_solutions/1614.maximum-nesting-depth-of-the-parentheses.java
# - Downloading maximum-nesting-depth-of-the-parentheses
#   ✔ Accepted
#   ✔ 168/168 cases passed (5 ms)
#   ✔ Your runtime beats 0.25 % of java submissions
#   ✔ Your memory usage beats 14.89 % of java submissions (47.1 MB)
# Submitting: java_solutions/1615.maximal-network-rank.java
# - Downloading maximal-network-rank
#   ✔ Accepted
#   ✔ 83/83 cases passed (18 ms)
#   ✔ Your runtime beats 46.55 % of java submissions
#   ✔ Your memory usage beats 6.7 % of java submissions (52.9 MB)
# Submitting: java_solutions/1616.split-two-strings-to-make-palindrome.java
# - Downloading split-two-strings-to-make-palindrome
#   ✔ Accepted
#   ✔ 112/112 cases passed (20 ms)
#   ✔ Your runtime beats 6.28 % of java submissions
#   ✔ Your memory usage beats 25.6 % of java submissions (47.8 MB)
# Submitting: java_solutions/1617.count-subtrees-with-max-distance-between-cities.java
# - Downloading count-subtrees-with-max-distance-between-cities
#   ✔ Accepted
#   ✔ 31/31 cases passed (37 ms)
#   ✔ Your runtime beats 69.23 % of java submissions
#   ✔ Your memory usage beats 72.31 % of java submissions (43.6 MB)
# Submitting: java_solutions/1619.mean-of-array-after-removing-some-elements.java
# - Downloading mean-of-array-after-removing-some-elements
#   ✔ Accepted
#   ✔ 50/50 cases passed (4 ms)
#   ✔ Your runtime beats 99.07 % of java submissions
#   ✔ Your memory usage beats 5.94 % of java submissions (47.8 MB)
# Submitting: java_solutions/1620.coordinate-with-maximum-network-quality.java
# - Downloading coordinate-with-maximum-network-quality
#   ✔ Accepted
#   ✔ 101/101 cases passed (36 ms)
#   ✔ Your runtime beats 26.41 % of java submissions
#   ✔ Your memory usage beats 52.83 % of java submissions (43.9 MB)
# Submitting: java_solutions/1621.number-of-sets-of-k-non-overlapping-line-segments.java
# - Downloading number-of-sets-of-k-non-overlapping-line-segments
#   ✔ Accepted
#   ✔ 68/68 cases passed (20 ms)
#   ✔ Your runtime beats 69.7 % of java submissions
#   ✔ Your memory usage beats 83.33 % of java submissions (46.2 MB)
# Submitting: java_solutions/1622.fancy-sequence.java
# - Downloading fancy-sequence
#   ✔ Accepted
#   ✔ 107/107 cases passed (66 ms)
#   ✔ Your runtime beats 9.79 % of java submissions
#   ✔ Your memory usage beats 5.57 % of java submissions (128.8 MB)
# Submitting: java_solutions/1624.largest-substring-between-two-equal-characters.java
# - Downloading largest-substring-between-two-equal-characters
#   ✔ Accepted
#   ✔ 59/59 cases passed (3 ms)
#   ✔ Your runtime beats 37.33 % of java submissions
#   ✔ Your memory usage beats 5.61 % of java submissions (43.3 MB)
# Submitting: java_solutions/1625.lexicographically-smallest-string-after-applying-operations.java
# - Downloading lexicographically-smallest-string-after-applying-operations
#   ✔ Accepted
#   ✔ 80/80 cases passed (366 ms)
#   ✔ Your runtime beats 5.31 % of java submissions
#   ✔ Your memory usage beats 5.31 % of java submissions (69 MB)
# Submitting: java_solutions/1626.best-team-with-no-conflicts.java
# - Downloading best-team-with-no-conflicts
#   ✔ Accepted
#   ✔ 150/150 cases passed (188 ms)
#   ✔ Your runtime beats 11.18 % of java submissions
#   ✔ Your memory usage beats 28.7 % of java submissions (47.4 MB)
# Submitting: java_solutions/1627.graph-connectivity-with-threshold.java
# - Downloading graph-connectivity-with-threshold
#   ✔ Accepted
#   ✔ 67/67 cases passed (16 ms)
#   ✔ Your runtime beats 31.58 % of java submissions
#   ✔ Your memory usage beats 15.79 % of java submissions (82.9 MB)
# Submitting: java_solutions/1629.slowest-key.java
# - Downloading slowest-key
#   ✔ Accepted
#   ✔ 109/109 cases passed (4 ms)
#   ✔ Your runtime beats 8.65 % of java submissions
#   ✔ Your memory usage beats 5.91 % of java submissions (52.8 MB)
# Submitting: java_solutions/1630.arithmetic-subarrays.java
# - Downloading arithmetic-subarrays
#   ✔ Accepted
#   ✔ 104/104 cases passed (61 ms)
#   ✔ Your runtime beats 5.39 % of java submissions
#   ✔ Your memory usage beats 21.02 % of java submissions (53.3 MB)
# Submitting: java_solutions/1632.rank-transform-of-a-matrix.java
# - Downloading rank-transform-of-a-matrix
#   ✔ Accepted
#   ✔ 41/41 cases passed (113 ms)
#   ✔ Your runtime beats 44.16 % of java submissions
#   ✔ Your memory usage beats 61.04 % of java submissions (111.3 MB)
# Submitting: java_solutions/1636.sort-array-by-increasing-frequency.java
# - Downloading sort-array-by-increasing-frequency
#   ✔ Accepted
#   ✔ 180/180 cases passed (25 ms)
#   ✔ Your runtime beats 5.08 % of java submissions
#   ✔ Your memory usage beats 5.13 % of java submissions (52.7 MB)
# Submitting: java_solutions/1637.widest-vertical-area-between-two-points-containing-no-points.java
# - Downloading widest-vertical-area-between-two-points-containing-no-points
#   ✔ Accepted
#   ✔ 56/56 cases passed (30 ms)
#   ✔ Your runtime beats 44.59 % of java submissions
#   ✔ Your memory usage beats 87.45 % of java submissions (89.1 MB)
# Submitting: java_solutions/1638.count-substrings-that-differ-by-one-character.java
# - Downloading count-substrings-that-differ-by-one-character
#   ✔ Accepted
#   ✔ 63/63 cases passed (45 ms)
#   ✔ Your runtime beats 10.43 % of java submissions
#   ✔ Your memory usage beats 5.22 % of java submissions (52.8 MB)
# Submitting: java_solutions/1639.number-of-ways-to-form-a-target-string-given-a-dictionary.java
# - Downloading number-of-ways-to-form-a-target-string-given-a-dictionary
#   ✔ Accepted
#   ✔ 90/90 cases passed (67 ms)
#   ✔ Your runtime beats 26.04 % of java submissions
#   ✔ Your memory usage beats 89.58 % of java submissions (50.9 MB)
# Submitting: java_solutions/1640.check-array-formation-through-concatenation.java
# - Downloading check-array-formation-through-concatenation
#   ✔ Accepted
#   ✔ 85/85 cases passed (12 ms)
#   ✔ Your runtime beats 5.14 % of java submissions
#   ✔ Your memory usage beats 6.54 % of java submissions (44.6 MB)
# Submitting: java_solutions/1641.count-sorted-vowel-strings.java
# - Downloading count-sorted-vowel-strings
#   ✔ Accepted
#   ✔ 41/41 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 44.56 % of java submissions (42.1 MB)
# Submitting: java_solutions/1642.furthest-building-you-can-reach.java
# - Downloading furthest-building-you-can-reach
#   ✔ Accepted
#   ✔ 80/80 cases passed (29 ms)
#   ✔ Your runtime beats 6.42 % of java submissions
#   ✔ Your memory usage beats 8.94 % of java submissions (74.1 MB)
# Submitting: java_solutions/1643.kth-smallest-instructions.java
# - Downloading kth-smallest-instructions
#   ✔ Accepted
#   ✔ 462/462 cases passed (8 ms)
#   ✔ Your runtime beats 3.85 % of java submissions
#   ✔ Your memory usage beats 5.77 % of java submissions (46.2 MB)
# Submitting: java_solutions/1646.get-maximum-in-generated-array.java
# - Downloading get-maximum-in-generated-array
#   ✔ Accepted
#   ✔ 101/101 cases passed (6 ms)
#   ✔ Your runtime beats 4.13 % of java submissions
#   ✔ Your memory usage beats 5.28 % of java submissions (42.8 MB)
# Submitting: java_solutions/1647.minimum-deletions-to-make-character-frequencies-unique.java
# - Downloading minimum-deletions-to-make-character-frequencies-unique
#   ✔ Accepted
#   ✔ 103/103 cases passed (172 ms)
#   ✔ Your runtime beats 5.25 % of java submissions
#   ✔ Your memory usage beats 7.81 % of java submissions (53.4 MB)
# Submitting: java_solutions/1648.sell-diminishing-valued-colored-balls.java
# - Downloading sell-diminishing-valued-colored-balls
#   ✔ Accepted
#   ✔ 95/95 cases passed (165 ms)
#   ✔ Your runtime beats 5.12 % of java submissions
#   ✔ Your memory usage beats 11.26 % of java submissions (67.7 MB)
# Submitting: java_solutions/1649.create-sorted-array-through-instructions.java
# - Downloading create-sorted-array-through-instructions
#   ✔ Accepted
#   ✔ 65/65 cases passed (56 ms)
#   ✔ Your runtime beats 41.67 % of java submissions
#   ✔ Your memory usage beats 91.67 % of java submissions (98.7 MB)
# Submitting: java_solutions/1652.defuse-the-bomb.java
# - Downloading defuse-the-bomb
#   ✔ Accepted
#   ✔ 74/74 cases passed (17 ms)
#   ✔ Your runtime beats 2.23 % of java submissions
#   ✔ Your memory usage beats 13.38 % of java submissions (51.5 MB)
# Submitting: java_solutions/1653.minimum-deletions-to-make-string-balanced.java
# - Downloading minimum-deletions-to-make-string-balanced
#   ✔ Accepted
#   ✔ 158/158 cases passed (39 ms)
#   ✔ Your runtime beats 40.95 % of java submissions
#   ✔ Your memory usage beats 66.34 % of java submissions (47.7 MB)
# Submitting: java_solutions/1655.distribute-repeating-integers.java
# - Downloading distribute-repeating-integers
#   ✔ Accepted
#   ✔ 109/109 cases passed (79 ms)
#   ✔ Your runtime beats 55.74 % of java submissions
#   ✔ Your memory usage beats 5.74 % of java submissions (275.2 MB)
# Submitting: java_solutions/1656.design-an-ordered-stream.java
# - Downloading design-an-ordered-stream
#   ✔ Accepted
#   ✔ 101/101 cases passed (100 ms)
#   ✔ Your runtime beats 5.21 % of java submissions
#   ✔ Your memory usage beats 5.92 % of java submissions (55.7 MB)
# Submitting: java_solutions/1657.determine-if-two-strings-are-close.java
# - Downloading determine-if-two-strings-are-close
#   ✔ Accepted
#   ✔ 169/169 cases passed (227 ms)
#   ✔ Your runtime beats 5.01 % of java submissions
#   ✔ Your memory usage beats 6.42 % of java submissions (53.5 MB)
# Submitting: java_solutions/1658.minimum-operations-to-reduce-x-to-zero.java
# - Downloading minimum-operations-to-reduce-x-to-zero
#   ✔ Accepted
#   ✔ 97/97 cases passed (63 ms)
#   ✔ Your runtime beats 11.63 % of java submissions
#   ✔ Your memory usage beats 12.4 % of java submissions (150.7 MB)
# Submitting: java_solutions/1659.maximize-grid-happiness.java
# - Downloading maximize-grid-happiness
#   ✔ Accepted
#   ✔ 67/67 cases passed (73 ms)
#   ✔ Your runtime beats 62.96 % of java submissions
#   ✔ Your memory usage beats 51.85 % of java submissions (50.9 MB)
# Submitting: java_solutions/1662.check-if-two-string-arrays-are-equivalent.java
# - Downloading check-if-two-string-arrays-are-equivalent
#   ✔ Accepted
#   ✔ 113/113 cases passed (3 ms)
#   ✔ Your runtime beats 9.27 % of java submissions
#   ✔ Your memory usage beats 39.23 % of java submissions (43.4 MB)
# Submitting: java_solutions/1663.smallest-string-with-a-given-numeric-value.java
# - Downloading smallest-string-with-a-given-numeric-value
#   ✔ Accepted
#   ✔ 94/94 cases passed (20 ms)
#   ✔ Your runtime beats 37.21 % of java submissions
#   ✔ Your memory usage beats 98.26 % of java submissions (46.4 MB)
# Submitting: java_solutions/1664.ways-to-make-a-fair-array.java
# - Downloading ways-to-make-a-fair-array
#   ✔ Accepted
#   ✔ 105/105 cases passed (24 ms)
#   ✔ Your runtime beats 5.19 % of java submissions
#   ✔ Your memory usage beats 97.41 % of java submissions (70.7 MB)
# Submitting: java_solutions/1665.minimum-initial-energy-to-finish-tasks.java
# - Downloading minimum-initial-energy-to-finish-tasks
#   ✔ Accepted
#   ✔ 42/42 cases passed (39 ms)
#   ✔ Your runtime beats 11.01 % of java submissions
#   ✔ Your memory usage beats 99.08 % of java submissions (111.4 MB)
# Submitting: java_solutions/1668.maximum-repeating-substring.java
# - Downloading maximum-repeating-substring
#   ✔ Accepted
#   ✔ 212/212 cases passed (4 ms)
#   ✔ Your runtime beats 1.36 % of java submissions
#   ✔ Your memory usage beats 7.64 % of java submissions (43.4 MB)
# Submitting: java_solutions/1669.merge-in-between-linked-lists.java
# - Downloading merge-in-between-linked-lists
#   ✔ Accepted
#   ✔ 61/61 cases passed (7 ms)
#   ✔ Your runtime beats 3.99 % of java submissions
#   ✔ Your memory usage beats 7.44 % of java submissions (55.1 MB)
# Submitting: java_solutions/1670.design-front-middle-back-queue.java
# - Downloading design-front-middle-back-queue
#   ✔ Accepted
#   ✔ 95/95 cases passed (51 ms)
#   ✔ Your runtime beats 5.24 % of java submissions
#   ✔ Your memory usage beats 5.85 % of java submissions (47.5 MB)
# Submitting: java_solutions/1671.minimum-number-of-removals-to-make-mountain-array.java
# - Downloading minimum-number-of-removals-to-make-mountain-array
#   ✔ Accepted
#   ✔ 91/91 cases passed (64 ms)
#   ✔ Your runtime beats 5.24 % of java submissions
#   ✔ Your memory usage beats 25 % of java submissions (46.5 MB)
# Submitting: java_solutions/1672.richest-customer-wealth.java
# - Downloading richest-customer-wealth
#   ✔ Accepted
#   ✔ 34/34 cases passed (4 ms)
#   ✔ Your runtime beats 0.89 % of java submissions
#   ✔ Your memory usage beats 6.41 % of java submissions (45.2 MB)
# Submitting: java_solutions/1673.find-the-most-competitive-subsequence.java
# - Downloading find-the-most-competitive-subsequence
#   ✔ Accepted
#   ✔ 88/88 cases passed (11 ms)
#   ✔ Your runtime beats 79.87 % of java submissions
#   ✔ Your memory usage beats 6.92 % of java submissions (123.6 MB)
# Submitting: java_solutions/1674.minimum-moves-to-make-array-complementary.java
# - Downloading minimum-moves-to-make-array-complementary
#   ✔ Accepted
#   ✔ 113/113 cases passed (30 ms)
#   ✔ Your runtime beats 5.17 % of java submissions
#   ✔ Your memory usage beats 13.79 % of java submissions (77.4 MB)
# Submitting: java_solutions/1675.minimize-deviation-in-array.java
# - Downloading minimize-deviation-in-array
#   ✔ Accepted
#   ✔ 76/76 cases passed (416 ms)
#   ✔ Your runtime beats 64.23 % of java submissions
#   ✔ Your memory usage beats 21.17 % of java submissions (66.6 MB)
# Submitting: java_solutions/1678.goal-parser-interpretation.java
# - Downloading goal-parser-interpretation
#   ✔ Accepted
#   ✔ 105/105 cases passed (5 ms)
#   ✔ Your runtime beats 1.67 % of java submissions
#   ✔ Your memory usage beats 5.4 % of java submissions (44 MB)
# Submitting: java_solutions/1679.max-number-of-k-sum-pairs.java
# - Downloading max-number-of-k-sum-pairs
#   ✔ Accepted
#   ✔ 51/51 cases passed (37 ms)
#   ✔ Your runtime beats 30.22 % of java submissions
#   ✔ Your memory usage beats 99.83 % of java submissions (66.2 MB)
# Submitting: java_solutions/1680.concatenation-of-consecutive-binary-numbers.java
# - Downloading concatenation-of-consecutive-binary-numbers
#   ✔ Accepted
#   ✔ 403/403 cases passed (180 ms)
#   ✔ Your runtime beats 20.49 % of java submissions
#   ✔ Your memory usage beats 9.15 % of java submissions (46.7 MB)
# Submitting: java_solutions/1681.minimum-incompatibility.java
# - Downloading minimum-incompatibility
#   ✔ Accepted
#   ✔ 59/59 cases passed (53 ms)
#   ✔ Your runtime beats 88.14 % of java submissions
#   ✔ Your memory usage beats 71.19 % of java submissions (47.1 MB)
# Submitting: java_solutions/1684.count-the-number-of-consistent-strings.java
# - Downloading count-the-number-of-consistent-strings
#   ✔ Accepted
#   ✔ 74/74 cases passed (11 ms)
#   ✔ Your runtime beats 70.44 % of java submissions
#   ✔ Your memory usage beats 69.1 % of java submissions (47.5 MB)
# Submitting: java_solutions/1685.sum-of-absolute-differences-in-a-sorted-array.java
# - Downloading sum-of-absolute-differences-in-a-sorted-array
#   ✔ Accepted
#   ✔ 59/59 cases passed (8 ms)
#   ✔ Your runtime beats 3.89 % of java submissions
#   ✔ Your memory usage beats 67.41 % of java submissions (85.4 MB)
# Submitting: java_solutions/1686.stone-game-vi.java
# - Downloading stone-game-vi
#   ✔ Accepted
#   ✔ 95/95 cases passed (93 ms)
#   ✔ Your runtime beats 16.1 % of java submissions
#   ✔ Your memory usage beats 66.1 % of java submissions (91.7 MB)
# Submitting: java_solutions/1687.delivering-boxes-from-storage-to-ports.java
# - Downloading delivering-boxes-from-storage-to-ports
#   ✔ Accepted
#   ✔ 39/39 cases passed (23 ms)
#   ✔ Your runtime beats 64.86 % of java submissions
#   ✔ Your memory usage beats 31.08 % of java submissions (150.9 MB)
# Submitting: java_solutions/1688.count-of-matches-in-tournament.java
# - Downloading count-of-matches-in-tournament
#   ✔ Accepted
#   ✔ 200/200 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 94.04 % of java submissions (41.9 MB)
# Submitting: java_solutions/1689.partitioning-into-minimum-number-of-deci-binary-numbers.java
# - Downloading partitioning-into-minimum-number-of-deci-binary-numbers
#   ✔ Accepted
#   ✔ 97/97 cases passed (8 ms)
#   ✔ Your runtime beats 12.22 % of java submissions
#   ✔ Your memory usage beats 86.13 % of java submissions (47.4 MB)
# Submitting: java_solutions/1690.stone-game-vii.java
# - Downloading stone-game-vii
#   ✔ Accepted
#   ✔ 68/68 cases passed (45 ms)
#   ✔ Your runtime beats 44.6 % of java submissions
#   ✔ Your memory usage beats 76.98 % of java submissions (62 MB)
# Submitting: java_solutions/1691.maximum-height-by-stacking-cuboids.java
# - Downloading maximum-height-by-stacking-cuboids
#   ✔ Accepted
#   ✔ 83/83 cases passed (26 ms)
#   ✔ Your runtime beats 5.15 % of java submissions
#   ✔ Your memory usage beats 5.15 % of java submissions (46.2 MB)
# Submitting: java_solutions/1694.reformat-phone-number.java
# - Downloading reformat-phone-number
#   ✔ Accepted
#   ✔ 108/108 cases passed (10 ms)
#   ✔ Your runtime beats 7.14 % of java submissions
#   ✔ Your memory usage beats 14.29 % of java submissions (44.3 MB)
# Submitting: java_solutions/1695.maximum-erasure-value.java
# - Downloading maximum-erasure-value
#   ✔ Accepted
#   ✔ 62/62 cases passed (13 ms)
#   ✔ Your runtime beats 91.37 % of java submissions
#   ✔ Your memory usage beats 91.07 % of java submissions (88.6 MB)
# Submitting: java_solutions/1696.jump-game-vi.java
# - Downloading jump-game-vi
#   ✔ Accepted
#   ✔ 73/73 cases passed (13 ms)
#   ✔ Your runtime beats 99.08 % of java submissions
#   ✔ Your memory usage beats 98.17 % of java submissions (80.4 MB)
# Submitting: java_solutions/1697.checking-existence-of-edge-length-limited-paths.java
# - Downloading checking-existence-of-edge-length-limited-paths
#   ✔ Accepted
#   ✔ 24/24 cases passed (90 ms)
#   ✔ Your runtime beats 11.18 % of java submissions
#   ✔ Your memory usage beats 28.54 % of java submissions (131 MB)
# Submitting: java_solutions/1700.number-of-students-unable-to-eat-lunch.java
# - Downloading number-of-students-unable-to-eat-lunch
#   ✔ Accepted
#   ✔ 55/55 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 38.62 % of java submissions (43.4 MB)
# Submitting: java_solutions/1701.average-waiting-time.java
# - Downloading average-waiting-time
#   ✔ Accepted
#   ✔ 38/38 cases passed (8 ms)
#   ✔ Your runtime beats 6.09 % of java submissions
#   ✔ Your memory usage beats 30.25 % of java submissions (95.2 MB)
# Submitting: java_solutions/1702.maximum-binary-string-after-change.java
# - Downloading maximum-binary-string-after-change
#   ✔ Accepted
#   ✔ 76/76 cases passed (59 ms)
#   ✔ Your runtime beats 6.36 % of java submissions
#   ✔ Your memory usage beats 63.64 % of java submissions (47.9 MB)
# Submitting: java_solutions/1703.minimum-adjacent-swaps-for-k-consecutive-ones.java
# - Downloading minimum-adjacent-swaps-for-k-consecutive-ones
#   ✔ Accepted
#   ✔ 117/117 cases passed (17 ms)
#   ✔ Your runtime beats 19.74 % of java submissions
#   ✔ Your memory usage beats 56.58 % of java submissions (104.5 MB)
# Submitting: java_solutions/1704.determine-if-string-halves-are-alike.java
# - Downloading determine-if-string-halves-are-alike
#   ✔ Accepted
#   ✔ 113/113 cases passed (5 ms)
#   ✔ Your runtime beats 44.46 % of java submissions
#   ✔ Your memory usage beats 82.59 % of java submissions (43 MB)
# Submitting: java_solutions/1705.maximum-number-of-eaten-apples.java
# - Downloading maximum-number-of-eaten-apples
#   ✔ Accepted
#   ✔ 73/73 cases passed (101 ms)
#   ✔ Your runtime beats 7.17 % of java submissions
#   ✔ Your memory usage beats 15.96 % of java submissions (49.3 MB)
# Submitting: java_solutions/1706.where-will-the-ball-fall.java
# - Downloading where-will-the-ball-fall
#   ✔ Accepted
#   ✔ 64/64 cases passed (7 ms)
#   ✔ Your runtime beats 8.62 % of java submissions
#   ✔ Your memory usage beats 67.24 % of java submissions (47.2 MB)
# Submitting: java_solutions/1707.maximum-xor-with-an-element-from-array.java
# - Downloading maximum-xor-with-an-element-from-array
#   ✔ Accepted
#   ✔ 67/67 cases passed (291 ms)
#   ✔ Your runtime beats 5.12 % of java submissions
#   ✔ Your memory usage beats 5.12 % of java submissions (268.1 MB)
# Submitting: java_solutions/1710.maximum-units-on-a-truck.java
# - Downloading maximum-units-on-a-truck
#   ✔ Accepted
#   ✔ 77/77 cases passed (13 ms)
#   ✔ Your runtime beats 12.02 % of java submissions
#   ✔ Your memory usage beats 12.07 % of java submissions (47.2 MB)
# Submitting: java_solutions/1711.count-good-meals.java
# - Downloading count-good-meals
#   ✔ Accepted
#   ✔ 72/72 cases passed (194 ms)
#   ✔ Your runtime beats 18.08 % of java submissions
#   ✔ Your memory usage beats 50.77 % of java submissions (79.9 MB)
# Submitting: java_solutions/1712.ways-to-split-array-into-three-subarrays.java
# - Downloading ways-to-split-array-into-three-subarrays
#   ✔ Accepted
#   ✔ 89/89 cases passed (55 ms)
#   ✔ Your runtime beats 49.63 % of java submissions
#   ✔ Your memory usage beats 65.93 % of java submissions (82.4 MB)
# Submitting: java_solutions/1713.minimum-operations-to-make-a-subsequence.java
# - Downloading minimum-operations-to-make-a-subsequence
#   ✔ Accepted
#   ✔ 82/82 cases passed (71 ms)
#   ✔ Your runtime beats 65.83 % of java submissions
#   ✔ Your memory usage beats 5 % of java submissions (136.9 MB)
# Submitting: java_solutions/1716.calculate-money-in-leetcode-bank.java
# - Downloading calculate-money-in-leetcode-bank
#   ✔ Accepted
#   ✔ 106/106 cases passed (5 ms)
#   ✔ Your runtime beats 1.94 % of java submissions
#   ✔ Your memory usage beats 62.93 % of java submissions (42.1 MB)
# Submitting: java_solutions/1717.maximum-score-from-removing-substrings.java
# - Downloading maximum-score-from-removing-substrings
#   ✔ Accepted
#   ✔ 77/77 cases passed (44 ms)
#   ✔ Your runtime beats 83.7 % of java submissions
#   ✔ Your memory usage beats 98.89 % of java submissions (47.3 MB)
# Submitting: java_solutions/1718.construct-the-lexicographically-largest-valid-sequence.java
# - Downloading construct-the-lexicographically-largest-valid-sequence
#   ✔ Accepted
#   ✔ 20/20 cases passed (12 ms)
#   ✔ Your runtime beats 2.38 % of java submissions
#   ✔ Your memory usage beats 14.29 % of java submissions (44.8 MB)
# Submitting: java_solutions/1719.number-of-ways-to-reconstruct-a-tree.java
# - Downloading number-of-ways-to-reconstruct-a-tree
#   ✔ Accepted
#   ✔ 81/81 cases passed (23 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 96.49 % of java submissions (113.7 MB)
# Submitting: java_solutions/1720.decode-xored-array.java
# - Downloading decode-xored-array
#   ✔ Accepted
#   ✔ 76/76 cases passed (10 ms)
#   ✔ Your runtime beats 1.55 % of java submissions
#   ✔ Your memory usage beats 25.19 % of java submissions (48 MB)
# Submitting: java_solutions/1721.swapping-nodes-in-a-linked-list.java
# - Downloading swapping-nodes-in-a-linked-list
#   ✔ Accepted
#   ✔ 132/132 cases passed (19 ms)
#   ✔ Your runtime beats 4.05 % of java submissions
#   ✔ Your memory usage beats 10.62 % of java submissions (119.9 MB)
# Submitting: java_solutions/1722.minimize-hamming-distance-after-swap-operations.java
# - Downloading minimize-hamming-distance-after-swap-operations
#   ✔ Accepted
#   ✔ 71/71 cases passed (197 ms)
#   ✔ Your runtime beats 5.11 % of java submissions
#   ✔ Your memory usage beats 5.51 % of java submissions (126.1 MB)
# Submitting: java_solutions/1723.find-minimum-time-to-finish-all-jobs.java
# - Downloading find-minimum-time-to-finish-all-jobs
#   ✔ Accepted
#   ✔ 65/65 cases passed (180 ms)
#   ✔ Your runtime beats 21.51 % of java submissions
#   ✔ Your memory usage beats 25.29 % of java submissions (43.7 MB)
# Submitting: java_solutions/1725.number-of-rectangles-that-can-form-the-largest-square.java
# - Downloading number-of-rectangles-that-can-form-the-largest-square
#   ✔ Accepted
#   ✔ 68/68 cases passed (15 ms)
#   ✔ Your runtime beats 8.73 % of java submissions
#   ✔ Your memory usage beats 9.13 % of java submissions (53 MB)
# Submitting: java_solutions/1726.tuple-with-same-product.java
# - Downloading tuple-with-same-product
#   ✔ Accepted
#   ✔ 37/37 cases passed (234 ms)
#   ✔ Your runtime beats 28.25 % of java submissions
#   ✔ Your memory usage beats 9.04 % of java submissions (109.2 MB)
# Submitting: java_solutions/1727.largest-submatrix-with-rearrangements.java
# - Downloading largest-submatrix-with-rearrangements
#   ✔ Accepted
#   ✔ 59/59 cases passed (117 ms)
#   ✔ Your runtime beats 5.91 % of java submissions
#   ✔ Your memory usage beats 5.04 % of java submissions (126.1 MB)
# Submitting: java_solutions/1728.cat-and-mouse-ii.java
# - Downloading cat-and-mouse-ii
#   ✔ Accepted
#   ✔ 180/180 cases passed (19 ms)
#   ✔ Your runtime beats 75.27 % of java submissions
#   ✔ Your memory usage beats 61.29 % of java submissions (47.8 MB)
# Submitting: java_solutions/1732.find-the-highest-altitude.java
# - Downloading find-the-highest-altitude
#   ✔ Accepted
#   ✔ 80/80 cases passed (12 ms)
#   ✔ Your runtime beats 1.41 % of java submissions
#   ✔ Your memory usage beats 6.84 % of java submissions (44.6 MB)
# Submitting: java_solutions/1733.minimum-number-of-people-to-teach.java
# - Downloading minimum-number-of-people-to-teach
#   ✔ Accepted
#   ✔ 100/100 cases passed (361 ms)
#   ✔ Your runtime beats 5.19 % of java submissions
#   ✔ Your memory usage beats 31.85 % of java submissions (99.1 MB)
# Submitting: java_solutions/1734.decode-xored-permutation.java
# - Downloading decode-xored-permutation
#   ✔ Accepted
#   ✔ 63/63 cases passed (32 ms)
#   ✔ Your runtime beats 1.03 % of java submissions
#   ✔ Your memory usage beats 96.91 % of java submissions (137.2 MB)
# Submitting: java_solutions/1735.count-ways-to-make-array-with-product.java
# - Downloading count-ways-to-make-array-with-product
#   ✔ Accepted
#   ✔ 67/67 cases passed (27 ms)
#   ✔ Your runtime beats 59.26 % of java submissions
#   ✔ Your memory usage beats 88.89 % of java submissions (48.2 MB)
# Submitting: java_solutions/1736.latest-time-by-replacing-hidden-digits.java
# - Downloading latest-time-by-replacing-hidden-digits
#   ✔ Accepted
#   ✔ 159/159 cases passed (3 ms)
#   ✔ Your runtime beats 11.11 % of java submissions
#   ✔ Your memory usage beats 94.65 % of java submissions (42.6 MB)
# Submitting: java_solutions/1737.change-minimum-characters-to-satisfy-one-of-three-conditions.java
# - Downloading change-minimum-characters-to-satisfy-one-of-three-conditions
#   ✔ Accepted
#   ✔ 72/72 cases passed (44 ms)
#   ✔ Your runtime beats 12.16 % of java submissions
#   ✔ Your memory usage beats 8.11 % of java submissions (53.2 MB)
# Submitting: java_solutions/1738.find-kth-largest-xor-coordinate-value.java
# - Downloading find-kth-largest-xor-coordinate-value
#   ✔ Accepted
#   ✔ 49/49 cases passed (491 ms)
#   ✔ Your runtime beats 7.94 % of java submissions
#   ✔ Your memory usage beats 35.1 % of java submissions (243.2 MB)
# Submitting: java_solutions/1739.building-boxes.java
# - Downloading building-boxes
#   ✔ Accepted
#   ✔ 86/86 cases passed (91 ms)
#   ✔ Your runtime beats 5.26 % of java submissions
#   ✔ Your memory usage beats 50 % of java submissions (42.1 MB)
# Submitting: java_solutions/1742.maximum-number-of-balls-in-a-box.java
# - Downloading maximum-number-of-balls-in-a-box
#   ✔ Accepted
#   ✔ 97/97 cases passed (210 ms)
#   ✔ Your runtime beats 5.28 % of java submissions
#   ✔ Your memory usage beats 6.65 % of java submissions (52.9 MB)
# Submitting: java_solutions/1743.restore-the-array-from-adjacent-pairs.java
# - Downloading restore-the-array-from-adjacent-pairs
#   ✔ Accepted
#   ✔ 46/46 cases passed (150 ms)
#   ✔ Your runtime beats 26.48 % of java submissions
#   ✔ Your memory usage beats 91.29 % of java submissions (132.7 MB)
# Submitting: java_solutions/1744.can-you-eat-your-favorite-candy-on-your-favorite-day.java
# - Downloading can-you-eat-your-favorite-candy-on-your-favorite-day
#   ✔ Accepted
#   ✔ 64/64 cases passed (15 ms)
#   ✔ Your runtime beats 2.6 % of java submissions
#   ✔ Your memory usage beats 12.99 % of java submissions (148.2 MB)
# Submitting: java_solutions/1745.palindrome-partitioning-iv.java
# - Downloading palindrome-partitioning-iv
#   ✔ Accepted
#   ✔ 92/92 cases passed (140 ms)
#   ✔ Your runtime beats 6.04 % of java submissions
#   ✔ Your memory usage beats 16.23 % of java submissions (48.4 MB)
# Submitting: java_solutions/1748.sum-of-unique-elements.java
# - Downloading sum-of-unique-elements
#   ✔ Accepted
#   ✔ 73/73 cases passed (14 ms)
#   ✔ Your runtime beats 2.51 % of java submissions
#   ✔ Your memory usage beats 8.37 % of java submissions (50.1 MB)
# Submitting: java_solutions/1749.maximum-absolute-sum-of-any-subarray.java
# - Downloading maximum-absolute-sum-of-any-subarray
#   ✔ Accepted
#   ✔ 67/67 cases passed (19 ms)
#   ✔ Your runtime beats 7.44 % of java submissions
#   ✔ Your memory usage beats 13.27 % of java submissions (67.7 MB)
# Submitting: java_solutions/1750.minimum-length-of-string-after-deleting-similar-ends.java
# - Downloading minimum-length-of-string-after-deleting-similar-ends
#   ✔ Accepted
#   ✔ 103/103 cases passed (54 ms)
#   ✔ Your runtime beats 5.01 % of java submissions
#   ✔ Your memory usage beats 7.82 % of java submissions (48 MB)
# Submitting: java_solutions/1751.maximum-number-of-events-that-can-be-attended-ii.java
# - Downloading maximum-number-of-events-that-can-be-attended-ii
#   ✔ Accepted
#   ✔ 70/70 cases passed (92 ms)
#   ✔ Your runtime beats 70.68 % of java submissions
#   ✔ Your memory usage beats 70.94 % of java submissions (181 MB)
# Submitting: java_solutions/1752.check-if-array-is-sorted-and-rotated.java
# - Downloading check-if-array-is-sorted-and-rotated
#   ✔ Accepted
#   ✔ 113/113 cases passed (3 ms)
#   ✔ Your runtime beats 3.47 % of java submissions
#   ✔ Your memory usage beats 46.09 % of java submissions (43 MB)
# Submitting: java_solutions/1753.maximum-score-from-removing-stones.java
# - Downloading maximum-score-from-removing-stones
#   ✔ Accepted
#   ✔ 96/96 cases passed (5 ms)
#   ✔ Your runtime beats 54.47 % of java submissions
#   ✔ Your memory usage beats 56.91 % of java submissions (42.3 MB)
# Submitting: java_solutions/1754.largest-merge-of-two-strings.java
# - Downloading largest-merge-of-two-strings
#   ✔ Accepted
#   ✔ 102/102 cases passed (46 ms)
#   ✔ Your runtime beats 31.27 % of java submissions
#   ✔ Your memory usage beats 23.71 % of java submissions (47.1 MB)
# Submitting: java_solutions/1755.closest-subsequence-sum.java
# - Downloading closest-subsequence-sum
#   ✔ Accepted
#   ✔ 74/74 cases passed (211 ms)
#   ✔ Your runtime beats 86.96 % of java submissions
#   ✔ Your memory usage beats 81.64 % of java submissions (86.6 MB)

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-05-04 22:59:42
