# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME')
    user_cookie = userdata.get('LEETCODE_TOKEN')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME'] = user_name
    os.environ['LEETCODE_TOKEN'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME" "$LEETCODE_TOKEN" | leetcode user -c

# %%
# %%bash
#
#
# # top 100 answers
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v java_solutions/*.java | sed -n '301,400p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 7
# done
# Out:
# Submitting: java_solutions/710.random-pick-with-blacklist.java
# - Downloading random-pick-with-blacklist
#   ✔ Accepted
#   ✔ 68/68 cases passed (50 ms)
#   ✔ Your runtime beats 31.08 % of java submissions
#   ✔ Your memory usage beats 83.87 % of java submissions (66.7 MB)
# Submitting: java_solutions/715.range-module.java
# - Downloading range-module
#   ✔ Accepted
#   ✔ 56/56 cases passed (61 ms)
#   ✔ Your runtime beats 19.53 % of java submissions
#   ✔ Your memory usage beats 63.28 % of java submissions (57.3 MB)
# Submitting: java_solutions/717.1-bit-and-2-bit-characters.java
# - Downloading 1-bit-and-2-bit-characters
#   ✔ Accepted
#   ✔ 95/95 cases passed (4 ms)
#   ✔ Your runtime beats 1.26 % of java submissions
#   ✔ Your memory usage beats 5.18 % of java submissions (44.8 MB)
# Submitting: java_solutions/719.find-k-th-smallest-pair-distance.java
# - Downloading find-k-th-smallest-pair-distance
#   ✔ Accepted
#   ✔ 21/21 cases passed (21 ms)
#   ✔ Your runtime beats 8.56 % of java submissions
#   ✔ Your memory usage beats 64.43 % of java submissions (47 MB)
# Submitting: java_solutions/724.find-pivot-index.java
# - Downloading find-pivot-index
#   ✔ Accepted
#   ✔ 747/747 cases passed (12 ms)
#   ✔ Your runtime beats 8.88 % of java submissions
#   ✔ Your memory usage beats 46.38 % of java submissions (47.4 MB)
# Submitting: java_solutions/726.number-of-atoms.java
# - Downloading number-of-atoms
#   ✔ Accepted
#   ✔ 39/39 cases passed (11 ms)
#   ✔ Your runtime beats 5.52 % of java submissions
#   ✔ Your memory usage beats 6.37 % of java submissions (44 MB)
# Submitting: java_solutions/728.self-dividing-numbers.java
# - Downloading self-dividing-numbers
#   ✔ Accepted
#   ✔ 31/31 cases passed (18 ms)
#   ✔ Your runtime beats 5.41 % of java submissions
#   ✔ Your memory usage beats 5.2 % of java submissions (46.8 MB)
# Submitting: java_solutions/730.count-different-palindromic-subsequences.java
# - Downloading count-different-palindromic-subsequences
#   ✔ Accepted
#   ✔ 367/367 cases passed (106 ms)
#   ✔ Your runtime beats 14.8 % of java submissions
#   ✔ Your memory usage beats 48.98 % of java submissions (57.1 MB)
# Submitting: java_solutions/732.my-calendar-iii.java
# - Downloading my-calendar-iii
#   ✔ Accepted
#   ✔ 98/98 cases passed (2054 ms)
#   ✔ Your runtime beats 5.09 % of java submissions
#   ✔ Your memory usage beats 6.37 % of java submissions (48.1 MB)
# Submitting: java_solutions/736.parse-lisp-expression.java
# - Downloading parse-lisp-expression
#   ✔ Accepted
#   ✔ 66/66 cases passed (10 ms)
#   ✔ Your runtime beats 6.67 % of java submissions
#   ✔ Your memory usage beats 9.09 % of java submissions (46.3 MB)
# Submitting: java_solutions/741.cherry-pickup.java
# - Downloading cherry-pickup
#   ✔ Accepted
#   ✔ 60/60 cases passed (110 ms)
#   ✔ Your runtime beats 15.16 % of java submissions
#   ✔ Your memory usage beats 69.69 % of java submissions (47.1 MB)
# Submitting: java_solutions/744.find-smallest-letter-greater-than-target.java
# - Downloading find-smallest-letter-greater-than-target
#   ✔ Accepted
#   ✔ 167/167 cases passed (6 ms)
#   ✔ Your runtime beats 0.58 % of java submissions
#   ✔ Your memory usage beats 7.07 % of java submissions (46.6 MB)
# Submitting: java_solutions/745.prefix-and-suffix-search.java
# - Downloading prefix-and-suffix-search
#   ✔ Accepted
#   ✔ 17/17 cases passed (479 ms)
#   ✔ Your runtime beats 47.95 % of java submissions
#   ✔ Your memory usage beats 64.86 % of java submissions (169.7 MB)
# Submitting: java_solutions/747.largest-number-at-least-twice-of-others.java
# - Downloading largest-number-at-least-twice-of-others
#   ✔ Accepted
#   ✔ 231/231 cases passed (8 ms)
#   ✔ Your runtime beats 4.87 % of java submissions
#   ✔ Your memory usage beats 13.16 % of java submissions (43.5 MB)
# Submitting: java_solutions/749.contain-virus.java
# - Downloading contain-virus
#   ✔ Accepted
#   ✔ 32/32 cases passed (36 ms)
#   ✔ Your runtime beats 7.66 % of java submissions
#   ✔ Your memory usage beats 5.26 % of java submissions (49.9 MB)
# Submitting: java_solutions/753.cracking-the-safe.java
# - Downloading cracking-the-safe
#   ✔ Accepted
#   ✔ 38/38 cases passed (8 ms)
#   ✔ Your runtime beats 77.88 % of java submissions
#   ✔ Your memory usage beats 5.77 % of java submissions (48.2 MB)
# Submitting: java_solutions/757.set-intersection-size-at-least-two.java
# - Downloading set-intersection-size-at-least-two
#   ✔ Accepted
#   ✔ 118/118 cases passed (362 ms)
#   ✔ Your runtime beats 8.11 % of java submissions
#   ✔ Your memory usage beats 31.94 % of java submissions (47.6 MB)
# Submitting: java_solutions/761.special-binary-string.java
# - Downloading special-binary-string
#   ✔ Accepted
#   ✔ 87/87 cases passed (3 ms)
#   ✔ Your runtime beats 68.5 % of java submissions
#   ✔ Your memory usage beats 30.53 % of java submissions (43.4 MB)
# Submitting: java_solutions/765.couples-holding-hands.java
# - Downloading couples-holding-hands
#   ✔ Accepted
#   ✔ 56/56 cases passed (1 ms)
#   ✔ Your runtime beats 35.05 % of java submissions
#   ✔ Your memory usage beats 68.66 % of java submissions (42.9 MB)
# Submitting: java_solutions/766.toeplitz-matrix.java
# - Downloading toeplitz-matrix
#   ✔ Accepted
#   ✔ 483/483 cases passed (9 ms)
#   ✔ Your runtime beats 0.56 % of java submissions
#   ✔ Your memory usage beats 33.85 % of java submissions (46.5 MB)
# Submitting: java_solutions/768.max-chunks-to-make-sorted-ii.java
# - Downloading max-chunks-to-make-sorted-ii
#   ✔ Accepted
#   ✔ 139/139 cases passed (1 ms)
#   ✔ Your runtime beats 48.04 % of java submissions
#   ✔ Your memory usage beats 23.09 % of java submissions (46.6 MB)
# Submitting: java_solutions/770.basic-calculator-iv.java
# - Downloading basic-calculator-iv
#   ✔ Accepted
#   ✔ 158/158 cases passed (10 ms)
#   ✔ Your runtime beats 86.29 % of java submissions
#   ✔ Your memory usage beats 16.93 % of java submissions (50.1 MB)
# Submitting: java_solutions/771.jewels-and-stones.java
# - Downloading jewels-and-stones
#   ✔ Accepted
#   ✔ 255/255 cases passed (4 ms)
#   ✔ Your runtime beats 2.12 % of java submissions
#   ✔ Your memory usage beats 75.26 % of java submissions (43.1 MB)
# Submitting: java_solutions/773.sliding-puzzle.java
# - Downloading sliding-puzzle
#   ✔ Accepted
#   ✔ 32/32 cases passed (18 ms)
#   ✔ Your runtime beats 17.3 % of java submissions
#   ✔ Your memory usage beats 41.31 % of java submissions (45.5 MB)
# Submitting: java_solutions/778.swim-in-rising-water.java
# - Downloading swim-in-rising-water
#   ✔ Accepted
#   ✔ 43/43 cases passed (19 ms)
#   ✔ Your runtime beats 13.7 % of java submissions
#   ✔ Your memory usage beats 19.74 % of java submissions (46.6 MB)
# Submitting: java_solutions/780.reaching-points.java
# - Downloading reaching-points
#   ✔ Accepted
#   ✔ 197/197 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 93.48 % of java submissions (42 MB)
# Submitting: java_solutions/782.transform-to-chessboard.java
# - Downloading transform-to-chessboard
#   ✔ Accepted
#   ✔ 127/127 cases passed (2 ms)
#   ✔ Your runtime beats 24.62 % of java submissions
#   ✔ Your memory usage beats 83.08 % of java submissions (46.2 MB)
# Submitting: java_solutions/783.minimum-distance-between-bst-nodes.java
# - Downloading minimum-distance-between-bst-nodes
#   ✔ Accepted
#   ✔ 49/49 cases passed (16 ms)
#   ✔ Your runtime beats 2.03 % of java submissions
#   ✔ Your memory usage beats 5.71 % of java submissions (44.1 MB)
# Submitting: java_solutions/793.preimage-size-of-factorial-zeroes-function.java
# - Downloading preimage-size-of-factorial-zeroes-function
#   ✔ Accepted
#   ✔ 44/44 cases passed (1 ms)
#   ✔ Your runtime beats 5.91 % of java submissions
#   ✔ Your memory usage beats 74.19 % of java submissions (41.9 MB)
# Submitting: java_solutions/796.rotate-string.java
# - Downloading rotate-string
#   ✔ Accepted
#   ✔ 62/62 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 47.72 % of java submissions (42.9 MB)
# Submitting: java_solutions/798.smallest-rotation-with-highest-score.java
# - Downloading smallest-rotation-with-highest-score
#   ✔ Accepted
#   ✔ 44/44 cases passed (7 ms)
#   ✔ Your runtime beats 58.06 % of java submissions
#   ✔ Your memory usage beats 83.87 % of java submissions (77 MB)
# Submitting: java_solutions/801.minimum-swaps-to-make-sequences-increasing.java
# - Downloading minimum-swaps-to-make-sequences-increasing
#   ✔ Accepted
#   ✔ 117/117 cases passed (10 ms)
#   ✔ Your runtime beats 36.45 % of java submissions
#   ✔ Your memory usage beats 78.93 % of java submissions (93.5 MB)
# Submitting: java_solutions/803.bricks-falling-when-hit.java
# - Downloading bricks-falling-when-hit
#   ✔ Accepted
#   ✔ 40/40 cases passed (29 ms)
#   ✔ Your runtime beats 6.59 % of java submissions
#   ✔ Your memory usage beats 5.49 % of java submissions (91.6 MB)
# Submitting: java_solutions/804.unique-morse-code-words.java
# - Downloading unique-morse-code-words
#   ✔ Accepted
#   ✔ 82/82 cases passed (10 ms)
#   ✔ Your runtime beats 1.91 % of java submissions
#   ✔ Your memory usage beats 8.28 % of java submissions (45.5 MB)
# Submitting: java_solutions/805.split-array-with-same-average.java
# - Downloading split-array-with-same-average
#   ✔ Accepted
#   ✔ 111/111 cases passed (914 ms)
#   ✔ Your runtime beats 25.57 % of java submissions
#   ✔ Your memory usage beats 31.68 % of java submissions (273.3 MB)
# Submitting: java_solutions/806.number-of-lines-to-write-string.java
# - Downloading number-of-lines-to-write-string
#   ✔ Accepted
#   ✔ 27/27 cases passed (3 ms)
#   ✔ Your runtime beats 2.21 % of java submissions
#   ✔ Your memory usage beats 12.5 % of java submissions (43.4 MB)
# Submitting: java_solutions/810.chalkboard-xor-game.java
# - Downloading chalkboard-xor-game
#   ✔ Accepted
#   ✔ 168/168 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 72.92 % of java submissions (46.3 MB)
# Submitting: java_solutions/812.largest-triangle-area.java
# - Downloading largest-triangle-area
#   ✔ Accepted
#   ✔ 57/57 cases passed (19 ms)
#   ✔ Your runtime beats 6.14 % of java submissions
#   ✔ Your memory usage beats 15.87 % of java submissions (47.9 MB)
# Submitting: java_solutions/815.bus-routes.java
# - Downloading bus-routes
#   ✔ Accepted
#   ✔ 54/54 cases passed (327 ms)
#   ✔ Your runtime beats 38.25 % of java submissions
#   ✔ Your memory usage beats 5.01 % of java submissions (270.8 MB)
# Submitting: java_solutions/818.race-car.java
# - Downloading race-car
#   ✔ Accepted
#   ✔ 55/55 cases passed (9 ms)
#   ✔ Your runtime beats 68.46 % of java submissions
#   ✔ Your memory usage beats 75.63 % of java submissions (42.5 MB)
# Submitting: java_solutions/819.most-common-word.java
# - Downloading most-common-word
#   ✔ Accepted
#   ✔ 50/50 cases passed (26 ms)
#   ✔ Your runtime beats 5.61 % of java submissions
#   ✔ Your memory usage beats 5.02 % of java submissions (52.6 MB)
# Submitting: java_solutions/821.shortest-distance-to-a-character.java
# - Downloading shortest-distance-to-a-character
#   ✔ Accepted
#   ✔ 76/76 cases passed (177 ms)
#   ✔ Your runtime beats 7.83 % of java submissions
#   ✔ Your memory usage beats 5.13 % of java submissions (47.2 MB)
# Submitting: java_solutions/824.goat-latin.java
# - Downloading goat-latin
#   ✔ Accepted
#   ✔ 99/99 cases passed (21 ms)
#   ✔ Your runtime beats 7.91 % of java submissions
#   ✔ Your memory usage beats 5.27 % of java submissions (50.7 MB)
# Submitting: java_solutions/827.making-a-large-island.java
# - Downloading making-a-large-island
#   ✔ Accepted
#   ✔ 75/75 cases passed (87 ms)
#   ✔ Your runtime beats 66.83 % of java submissions
#   ✔ Your memory usage beats 13.66 % of java submissions (169.1 MB)
# Submitting: java_solutions/828.count-unique-characters-of-all-substrings-of-a-given-string.java
# - Downloading count-unique-characters-of-all-substrings-of-a-given-string
#   ✔ Accepted
#   ✔ 76/76 cases passed (19 ms)
#   ✔ Your runtime beats 39.57 % of java submissions
#   ✔ Your memory usage beats 55.04 % of java submissions (47.2 MB)
# Submitting: java_solutions/829.consecutive-numbers-sum.java
# - Downloading consecutive-numbers-sum
#   ✔ Accepted
#   ✔ 170/170 cases passed (5 ms)
#   ✔ Your runtime beats 19.74 % of java submissions
#   ✔ Your memory usage beats 11.33 % of java submissions (42.4 MB)
# Submitting: java_solutions/830.positions-of-large-groups.java
# - Downloading positions-of-large-groups
#   ✔ Accepted
#   ✔ 202/202 cases passed (12 ms)
#   ✔ Your runtime beats 2.55 % of java submissions
#   ✔ Your memory usage beats 5.27 % of java submissions (47.2 MB)
# Submitting: java_solutions/832.flipping-an-image.java
# - Downloading flipping-an-image
#   ✔ Accepted
#   ✔ 82/82 cases passed (6 ms)
#   ✔ Your runtime beats 0.42 % of java submissions
#   ✔ Your memory usage beats 8.33 % of java submissions (46.8 MB)
# Submitting: java_solutions/834.sum-of-distances-in-tree.java
# - Downloading sum-of-distances-in-tree
#   ✔ Accepted
#   ✔ 74/74 cases passed (22 ms)
#   ✔ Your runtime beats 97.94 % of java submissions
#   ✔ Your memory usage beats 98.22 % of java submissions (88.3 MB)
# Submitting: java_solutions/836.rectangle-overlap.java
# - Downloading rectangle-overlap
#   ✔ Accepted
#   ✔ 41/41 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 56.56 % of java submissions (42.7 MB)
# Submitting: java_solutions/839.similar-string-groups.java
# - Downloading similar-string-groups
#   ✔ Accepted
#   ✔ 77/77 cases passed (20 ms)
#   ✔ Your runtime beats 44.4 % of java submissions
#   ✔ Your memory usage beats 41.92 % of java submissions (45 MB)
# Submitting: java_solutions/843.guess-the-word.java
# - Downloading guess-the-word
#   ✔ Accepted
#   ✔ 13/13 cases passed (13 ms)
#   ✔ Your runtime beats 20.09 % of java submissions
#   ✔ Your memory usage beats 9.27 % of java submissions (43.7 MB)
# Submitting: java_solutions/844.backspace-string-compare.java
# - Downloading backspace-string-compare
#   ✔ Accepted
#   ✔ 115/115 cases passed (9 ms)
#   ✔ Your runtime beats 4.1 % of java submissions
#   ✔ Your memory usage beats 21.37 % of java submissions (43.4 MB)
# Submitting: java_solutions/847.shortest-path-visiting-all-nodes.java
# - Downloading shortest-path-visiting-all-nodes
#   ✔ Accepted
#   ✔ 55/55 cases passed (84 ms)
#   ✔ Your runtime beats 7.41 % of java submissions
#   ✔ Your memory usage beats 7.69 % of java submissions (53.7 MB)
# Submitting: java_solutions/850.rectangle-area-ii.java
# - Downloading rectangle-area-ii
#   ✔ Accepted
#   ✔ 78/78 cases passed (47 ms)
#   ✔ Your runtime beats 11.96 % of java submissions
#   ✔ Your memory usage beats 38.59 % of java submissions (45.4 MB)
# Submitting: java_solutions/854.k-similar-strings.java
# - Downloading k-similar-strings
#   ✔ Accepted
#   ✔ 66/66 cases passed (60 ms)
#   ✔ Your runtime beats 38.35 % of java submissions
#   ✔ Your memory usage beats 29.9 % of java submissions (51.4 MB)
# Submitting: java_solutions/857.minimum-cost-to-hire-k-workers.java
# - Downloading minimum-cost-to-hire-k-workers
#   ✔ Accepted
#   ✔ 49/49 cases passed (51 ms)
#   ✔ Your runtime beats 6.84 % of java submissions
#   ✔ Your memory usage beats 32.42 % of java submissions (48.4 MB)
# Submitting: java_solutions/862.shortest-subarray-with-sum-at-least-k.java
# - Downloading shortest-subarray-with-sum-at-least-k
#   ✔ Accepted
#   ✔ 99/99 cases passed (41 ms)
#   ✔ Your runtime beats 14.17 % of java submissions
#   ✔ Your memory usage beats 87.87 % of java submissions (90.3 MB)
# Submitting: java_solutions/864.shortest-path-to-get-all-keys.java
# - Downloading shortest-path-to-get-all-keys
#   ✔ Accepted
#   ✔ 36/36 cases passed (42 ms)
#   ✔ Your runtime beats 34.5 % of java submissions
#   ✔ Your memory usage beats 34.36 % of java submissions (48.2 MB)
# Submitting: java_solutions/867.transpose-matrix.java
# - Downloading transpose-matrix
#   ✔ Accepted
#   ✔ 36/36 cases passed (6 ms)
#   ✔ Your runtime beats 0.55 % of java submissions
#   ✔ Your memory usage beats 74.75 % of java submissions (46.6 MB)
# Submitting: java_solutions/868.binary-gap.java
# - Downloading binary-gap
#   ✔ Accepted
#   ✔ 261/261 cases passed (10 ms)
#   ✔ Your runtime beats 1.62 % of java submissions
#   ✔ Your memory usage beats 13.1 % of java submissions (43 MB)
# Submitting: java_solutions/871.minimum-number-of-refueling-stops.java
# - Downloading minimum-number-of-refueling-stops
#   ✔ Accepted
#   ✔ 198/198 cases passed (46 ms)
#   ✔ Your runtime beats 9.33 % of java submissions
#   ✔ Your memory usage beats 98.44 % of java submissions (46.2 MB)
# Submitting: java_solutions/876.middle-of-the-linked-list.java
# - Downloading middle-of-the-linked-list
#   ✔ Accepted
#   ✔ 36/36 cases passed (2 ms)
#   ✔ Your runtime beats 0.25 % of java submissions
#   ✔ Your memory usage beats 7.26 % of java submissions (43.1 MB)
# Submitting: java_solutions/878.nth-magical-number.java
# - Downloading nth-magical-number
#   ✔ Accepted
#   ✔ 70/70 cases passed (1 ms)
#   ✔ Your runtime beats 4.87 % of java submissions
#   ✔ Your memory usage beats 84.74 % of java submissions (42 MB)
# Submitting: java_solutions/879.profitable-schemes.java
# - Downloading profitable-schemes
#   ✔ Accepted
#   ✔ 45/45 cases passed (93 ms)
#   ✔ Your runtime beats 39.58 % of java submissions
#   ✔ Your memory usage beats 90.91 % of java submissions (43.4 MB)
# Submitting: java_solutions/882.reachable-nodes-in-subdivided-graph.java
# - Downloading reachable-nodes-in-subdivided-graph
#   ✔ Accepted
#   ✔ 50/50 cases passed (849 ms)
#   ✔ Your runtime beats 5.21 % of java submissions
#   ✔ Your memory usage beats 5.21 % of java submissions (276.2 MB)
# Submitting: java_solutions/884.uncommon-words-from-two-sentences.java
# - Downloading uncommon-words-from-two-sentences
#   ✔ Accepted
#   ✔ 55/55 cases passed (14 ms)
#   ✔ Your runtime beats 6.94 % of java submissions
#   ✔ Your memory usage beats 8.09 % of java submissions (50 MB)
# Submitting: java_solutions/887.super-egg-drop.java
# - Downloading super-egg-drop
#   ✔ Accepted
#   ✔ 121/121 cases passed (2 ms)
#   ✔ Your runtime beats 58.97 % of java submissions
#   ✔ Your memory usage beats 71.5 % of java submissions (42.2 MB)
# Submitting: java_solutions/891.sum-of-subsequence-widths.java
# - Downloading sum-of-subsequence-widths
#   ✔ Accepted
#   ✔ 68/68 cases passed (49 ms)
#   ✔ Your runtime beats 5.19 % of java submissions
#   ✔ Your memory usage beats 67.41 % of java submissions (64.3 MB)
# Submitting: java_solutions/895.maximum-frequency-stack.java
# - Downloading maximum-frequency-stack
#   ✔ Accepted
#   ✔ 38/38 cases passed (48 ms)
#   ✔ Your runtime beats 5.55 % of java submissions
#   ✔ Your memory usage beats 6.09 % of java submissions (81.9 MB)
# Submitting: java_solutions/896.monotonic-array.java
# - Downloading monotonic-array
#   ✔ Accepted
#   ✔ 371/371 cases passed (260 ms)
#   ✔ Your runtime beats 1.97 % of java submissions
#   ✔ Your memory usage beats 10.81 % of java submissions (97 MB)
# Submitting: java_solutions/899.orderly-queue.java
# - Downloading orderly-queue
#   ✔ Accepted
#   ✔ 112/112 cases passed (10 ms)
#   ✔ Your runtime beats 5.8 % of java submissions
#   ✔ Your memory usage beats 11.95 % of java submissions (47.7 MB)
# Submitting: java_solutions/902.numbers-at-most-n-given-digit-set.java
# - Downloading numbers-at-most-n-given-digit-set
#   ✔ Accepted
#   ✔ 84/84 cases passed (1 ms)
#   ✔ Your runtime beats 45.88 % of java submissions
#   ✔ Your memory usage beats 29.39 % of java submissions (42.8 MB)
# Submitting: java_solutions/903.valid-permutations-for-di-sequence.java
# - Downloading valid-permutations-for-di-sequence
#   ✔ Accepted
#   ✔ 83/83 cases passed (12 ms)
#   ✔ Your runtime beats 40.59 % of java submissions
#   ✔ Your memory usage beats 92.08 % of java submissions (43.3 MB)
# Submitting: java_solutions/905.sort-array-by-parity.java
# - Downloading sort-array-by-parity
#   ✔ Accepted
#   ✔ 286/286 cases passed (15 ms)
#   ✔ Your runtime beats 5.26 % of java submissions
#   ✔ Your memory usage beats 7.97 % of java submissions (47.3 MB)
# Submitting: java_solutions/906.super-palindromes.java
# - Downloading super-palindromes
#   ✔ Accepted
#   ✔ 49/49 cases passed (559 ms)
#   ✔ Your runtime beats 10.29 % of java submissions
#   ✔ Your memory usage beats 83.09 % of java submissions (43 MB)
# Submitting: java_solutions/912.sort-an-array.java
# - Downloading sort-an-array
#   ✔ Accepted
#   ✔ 21/21 cases passed (30 ms)
#   ✔ Your runtime beats 31.49 % of java submissions
#   ✔ Your memory usage beats 82.13 % of java submissions (81.9 MB)
# Submitting: java_solutions/913.cat-and-mouse.java
# - Downloading cat-and-mouse
#   ✔ Accepted
#   ✔ 92/92 cases passed (50 ms)
#   ✔ Your runtime beats 22.68 % of java submissions
#   ✔ Your memory usage beats 18.21 % of java submissions (48.1 MB)
# Submitting: java_solutions/917.reverse-only-letters.java
# - Downloading reverse-only-letters
#   ✔ Accepted
#   ✔ 115/115 cases passed (13 ms)
#   ✔ Your runtime beats 1.64 % of java submissions
#   ✔ Your memory usage beats 8.44 % of java submissions (44.7 MB)
# Submitting: java_solutions/920.number-of-music-playlists.java
# - Downloading number-of-music-playlists
#   ✔ Accepted
#   ✔ 83/83 cases passed (15 ms)
#   ✔ Your runtime beats 8.64 % of java submissions
#   ✔ Your memory usage beats 14.55 % of java submissions (44.3 MB)
# Submitting: java_solutions/924.minimize-malware-spread.java
# - Downloading minimize-malware-spread
#   ✔ Accepted
#   ✔ 70/70 cases passed (11 ms)
#   ✔ Your runtime beats 33.24 % of java submissions
#   ✔ Your memory usage beats 57.71 % of java submissions (121.4 MB)
# Submitting: java_solutions/927.three-equal-parts.java
# - Downloading three-equal-parts
#   ✔ Accepted
#   ✔ 121/121 cases passed (4 ms)
#   ✔ Your runtime beats 7.94 % of java submissions
#   ✔ Your memory usage beats 99.21 % of java submissions (49.9 MB)
# Submitting: java_solutions/928.minimize-malware-spread-ii.java
# - Downloading minimize-malware-spread-ii
#   ✔ Accepted
#   ✔ 48/48 cases passed (56 ms)
#   ✔ Your runtime beats 9.37 % of java submissions
#   ✔ Your memory usage beats 72.92 % of java submissions (93.5 MB)
# Submitting: java_solutions/936.stamping-the-sequence.java
# - Downloading stamping-the-sequence
#   ✔ Accepted
#   ✔ 262/262 cases passed (9 ms)
#   ✔ Your runtime beats 18.04 % of java submissions
#   ✔ Your memory usage beats 12.23 % of java submissions (47.3 MB)
# Submitting: java_solutions/938.range-sum-of-bst.java
# - Downloading range-sum-of-bst
#   ✔ Accepted
#   ✔ 41/41 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 84.38 % of java submissions (53.8 MB)
# Submitting: java_solutions/940.distinct-subsequences-ii.java
# - Downloading distinct-subsequences-ii
#   ✔ Accepted
#   ✔ 110/110 cases passed (13 ms)
#   ✔ Your runtime beats 13.48 % of java submissions
#   ✔ Your memory usage beats 26.24 % of java submissions (43.7 MB)
# Submitting: java_solutions/941.valid-mountain-array.java
# - Downloading valid-mountain-array
#   ✔ Accepted
#   ✔ 53/53 cases passed (7 ms)
#   ✔ Your runtime beats 1.79 % of java submissions
#   ✔ Your memory usage beats 40.94 % of java submissions (47.5 MB)
# Submitting: java_solutions/943.find-the-shortest-superstring.java
# - Downloading find-the-shortest-superstring
#   ✔ Accepted
#   ✔ 85/85 cases passed (91 ms)
#   ✔ Your runtime beats 29.49 % of java submissions
#   ✔ Your memory usage beats 30.13 % of java submissions (48.7 MB)
# Submitting: java_solutions/944.delete-columns-to-make-sorted.java
# - Downloading delete-columns-to-make-sorted
#   ✔ Accepted
#   ✔ 86/86 cases passed (24 ms)
#   ✔ Your runtime beats 5.68 % of java submissions
#   ✔ Your memory usage beats 10.18 % of java submissions (47.4 MB)
# Submitting: java_solutions/952.largest-component-size-by-common-factor.java
# - Downloading largest-component-size-by-common-factor
#   ✔ Accepted
#   ✔ 108/108 cases passed (374 ms)
#   ✔ Your runtime beats 6.05 % of java submissions
#   ✔ Your memory usage beats 42.88 % of java submissions (51.3 MB)
# Submitting: java_solutions/956.tallest-billboard.java
# - Downloading tallest-billboard
#   ✔ Accepted
#   ✔ 80/80 cases passed (53 ms)
#   ✔ Your runtime beats 39.65 % of java submissions
#   ✔ Your memory usage beats 98.6 % of java submissions (46.2 MB)
# Submitting: java_solutions/960.delete-columns-to-make-sorted-iii.java
# - Downloading delete-columns-to-make-sorted-iii
#   ✔ Accepted
#   ✔ 131/131 cases passed (102 ms)
#   ✔ Your runtime beats 6.93 % of java submissions
#   ✔ Your memory usage beats 44.16 % of java submissions (44.4 MB)
# Submitting: java_solutions/961.n-repeated-element-in-size-2n-array.java
# - Downloading n-repeated-element-in-size-2n-array
#   ✔ Accepted
#   ✔ 106/106 cases passed (4 ms)
#   ✔ Your runtime beats 36.02 % of java submissions
#   ✔ Your memory usage beats 46.06 % of java submissions (47.6 MB)
# Submitting: java_solutions/964.least-operators-to-express-number.java
# - Downloading least-operators-to-express-number
#   ✔ Accepted
#   ✔ 162/162 cases passed (1 ms)
#   ✔ Your runtime beats 68.75 % of java submissions
#   ✔ Your memory usage beats 75 % of java submissions (42.4 MB)
# Submitting: java_solutions/965.univalued-binary-tree.java
# - Downloading univalued-binary-tree
#   ✔ Accepted
#   ✔ 72/72 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 62.1 % of java submissions (42.9 MB)
# Submitting: java_solutions/968.binary-tree-cameras.java
# - Downloading binary-tree-cameras
#   ✔ Accepted
#   ✔ 171/171 cases passed (1 ms)
#   ✔ Your runtime beats 12.55 % of java submissions
#   ✔ Your memory usage beats 11.77 % of java submissions (45.2 MB)
# Submitting: java_solutions/972.equal-rational-numbers.java
# - Downloading equal-rational-numbers
#   ✔ Accepted
#   ✔ 74/74 cases passed (2 ms)
#   ✔ Your runtime beats 69.23 % of java submissions
#   ✔ Your memory usage beats 24.36 % of java submissions (43.3 MB)
# Submitting: java_solutions/975.odd-even-jump.java
# - Downloading odd-even-jump
#   ✔ Accepted
#   ✔ 65/65 cases passed (101 ms)
#   ✔ Your runtime beats 9.19 % of java submissions
#   ✔ Your memory usage beats 74.56 % of java submissions (49.6 MB)
# Submitting: java_solutions/976.largest-perimeter-triangle.java
# - Downloading largest-perimeter-triangle
#   ✔ Accepted
#   ✔ 84/84 cases passed (53 ms)
#   ✔ Your runtime beats 5.16 % of java submissions
#   ✔ Your memory usage beats 48.08 % of java submissions (47.7 MB)
# Submitting: java_solutions/977.squares-of-a-sorted-array.java
# - Downloading squares-of-a-sorted-array
#   ✔ Accepted
#   ✔ 137/137 cases passed (22 ms)
#   ✔ Your runtime beats 5.29 % of java submissions
#   ✔ Your memory usage beats 32.56 % of java submissions (47.7 MB)

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-04-14 10:20:37
