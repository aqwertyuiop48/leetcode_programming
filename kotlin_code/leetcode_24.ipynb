# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME_2')
    user_cookie = userdata.get('LEETCODE_TOKEN_2')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME_2'] = user_name
    os.environ['LEETCODE_TOKEN_2'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME_2" "$LEETCODE_TOKEN_2" | leetcode user -c

# %%
# %%bash
#
# # top 300-400 answers (next batch)
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v kotlin_solutions_1/*.kt | sed -n '1501,1600p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 7
# done
# Out:
# Submitting: kotlin_solutions_1/3120.count-the-number-of-special-characters-i.kt
# - Downloading count-the-number-of-special-characters-i
#   ✔ Accepted
#   ✔ 866/866 cases passed (19 ms)
#   ✔ Your runtime beats 30 % of kotlin submissions
#   ✔ Your memory usage beats 10 % of kotlin submissions (46 MB)
# Submitting: kotlin_solutions_1/3121.count-the-number-of-special-characters-ii.kt
# - Downloading count-the-number-of-special-characters-ii
#   ✔ Accepted
#   ✔ 896/896 cases passed (230 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (49.6 MB)
# Submitting: kotlin_solutions_1/3122.minimum-number-of-operations-to-satisfy-conditions.kt
# - Downloading minimum-number-of-operations-to-satisfy-conditions
#   ✔ Accepted
#   ✔ 658/658 cases passed (112 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (176.8 MB)
# Submitting: kotlin_solutions_1/3123.find-edges-in-shortest-paths.kt
# - Downloading find-edges-in-shortest-paths
#   ✔ Accepted
#   ✔ 536/536 cases passed (176 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (109.2 MB)
# Submitting: kotlin_solutions_1/3127.make-a-square-with-the-same-color.kt
# - Downloading make-a-square-with-the-same-color
#   ✔ Accepted
#   ✔ 515/515 cases passed (19 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3128.right-triangles.kt
# - Downloading right-triangles
#   ✔ Accepted
#   ✔ 637/637 cases passed (75 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3129.find-all-possible-stable-binary-arrays-i.kt
# - Downloading find-all-possible-stable-binary-arrays-i
#   ✔ Accepted
#   ✔ 670/670 cases passed (20 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 11.11 % of kotlin submissions (50.4 MB)
# Submitting: kotlin_solutions_1/3130.find-all-possible-stable-binary-arrays-ii.kt
# - Downloading find-all-possible-stable-binary-arrays-ii
#   ✔ Accepted
#   ✔ 596/596 cases passed (112 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (114.7 MB)
# Submitting: kotlin_solutions_1/3131.find-the-integer-added-to-array-i.kt
# - Downloading find-the-integer-added-to-array-i
#   ✔ Accepted
#   ✔ 605/605 cases passed (12 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3132.find-the-integer-added-to-array-ii.kt
# - Downloading find-the-integer-added-to-array-ii
#   ✔ Accepted
#   ✔ 560/560 cases passed (174 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3133.minimum-array-end.kt
# - Downloading minimum-array-end
#   ✔ Accepted
#   ✔ 765/765 cases passed (9 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/3134.find-the-median-of-the-uniqueness-array.kt
# - Downloading find-the-median-of-the-uniqueness-array
#   ✔ Accepted
#   ✔ 792/792 cases passed (505 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (77.3 MB)
# Submitting: kotlin_solutions_1/3136.valid-word.kt
# - Downloading valid-word
#   ✔ Accepted
#   ✔ 678/678 cases passed (8 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (42.9 MB)
# Submitting: kotlin_solutions_1/3137.minimum-number-of-operations-to-make-word-k-periodic.kt
# - Downloading minimum-number-of-operations-to-make-word-k-periodic
#   ✔ Accepted
#   ✔ 820/820 cases passed (87 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (62.6 MB)
# Submitting: kotlin_solutions_1/3138.minimum-length-of-anagram-concatenation.kt
# - Downloading minimum-length-of-anagram-concatenation
#   ✔ Accepted
#   ✔ 560/560 cases passed (375 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/3139.minimum-cost-to-equalize-array.kt
# - Downloading minimum-cost-to-equalize-array
#   ✘ Wrong Answer
#   ✘ 624/636 cases passed (N/A)
#   ✘ Testcase: [55,52,29,11]
# 18
# 2
#   ✘ Answer: 122
#   ✘ Expected Answer: 118
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/3142.check-if-grid-satisfies-conditions.kt
# - Downloading check-if-grid-satisfies-conditions
#   ✔ Accepted
#   ✔ 882/882 cases passed (16 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3143.maximum-points-inside-the-square.kt
# - Downloading maximum-points-inside-the-square
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 7: Char 340: ERROR: Argument type mismatch: actual type is 'kotlin.IntArray', but 'kotlin.Int' was expected.
#   ✘ Error: Line 7: Char 340: ERROR: Argument type mismatch: actual type is 'kotlin.IntArray', but 'kotlin.Int' was expected.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/3144.minimum-substring-partition-of-equal-character-frequency.kt
# - Downloading minimum-substring-partition-of-equal-character-frequency
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 69: ERROR: Return type mismatch: expected 'kotlin.Int', actual 'kotlin.IntArray'.
#   ✘ Error: Line 2: Char 69: ERROR: Return type mismatch: expected 'kotlin.Int', actual 'kotlin.IntArray'.
# Line 2: Char 92: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 111: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun MatchGroupCollection.get(name: String): MatchGroup?
# Line 2: Char 240: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 36: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/3145.find-products-of-elements-of-big-array.kt
# - Downloading find-products-of-elements-of-big-array
#   ✔ Accepted
#   ✔ 758/758 cases passed (303 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (68.8 MB)
# Submitting: kotlin_solutions_1/3146.permutation-difference-between-two-strings.kt
# - Downloading permutation-difference-between-two-strings
#   ✔ Accepted
#   ✔ 823/823 cases passed (11 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 16.67 % of kotlin submissions (44 MB)
# Submitting: kotlin_solutions_1/3147.taking-maximum-energy-from-the-mystic-dungeon.kt
# - Downloading taking-maximum-energy-from-the-mystic-dungeon
#   ✔ Accepted
#   ✔ 534/534 cases passed (595 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (75.9 MB)
# Submitting: kotlin_solutions_1/3148.maximum-difference-score-in-a-grid.kt
# - Downloading maximum-difference-score-in-a-grid
#   ✔ Accepted
#   ✔ 564/564 cases passed (63 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3149.find-the-minimum-cost-array-permutation.kt
# - Downloading find-the-minimum-cost-array-permutation
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 7: Char 152: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 7: Char 152: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 7: Char 693: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 7: Char 754: WARNING: Parameter '<unused var>: Int' is never used, could be renamed to '_'.
# Line 7: Char 817: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 41: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/3151.special-array-i.kt
# - Downloading special-array-i
#   ✔ Accepted
#   ✔ 852/852 cases passed (5 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (48 MB)
# Submitting: kotlin_solutions_1/3152.special-array-ii.kt
# - Downloading special-array-ii
#   ✔ Accepted
#   ✔ 536/536 cases passed (9 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/3153.sum-of-digit-differences-of-all-pairs.kt
# - Downloading sum-of-digit-differences-of-all-pairs
#   ✔ Accepted
#   ✔ 643/643 cases passed (56 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3154.find-number-of-ways-to-reach-the-k-th-stair.kt
# - Downloading find-number-of-ways-to-reach-the-k-th-stair
#   ✔ Accepted
#   ✔ 600/600 cases passed (6 ms)
#   ✔ Your runtime beats 66.67 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (41.3 MB)
# Submitting: kotlin_solutions_1/3158.find-the-xor-of-numbers-which-appear-twice.kt
# - Downloading find-the-xor-of-numbers-which-appear-twice
#   ✔ Accepted
#   ✔ 833/833 cases passed (6 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3159.find-occurrences-of-an-element-in-an-array.kt
# - Downloading find-occurrences-of-an-element-in-an-array
#   ✔ Accepted
#   ✔ 527/527 cases passed (31 ms)
#   ✔ Your runtime beats 66.67 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (93.1 MB)
# Submitting: kotlin_solutions_1/3160.find-the-number-of-distinct-colors-among-the-balls.kt
# - Downloading find-the-number-of-distinct-colors-among-the-balls
#   ✔ Accepted
#   ✔ 551/551 cases passed (68 ms)
#   ✔ Your runtime beats 80 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/3161.block-placement-queries.kt
# - Downloading block-placement-queries
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 1122: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
#   ✘ Error: Line 2: Char 1122: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 1143: ERROR: Unresolved reference 'callRecursive'.
# Line 2: Char 1196: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 1196: ERROR: Not enough information to infer type argument for 'T'.
# Line 2: Char 1196: ERROR: Not enough information to infer type argument for 'R'.
# Line 2: Char 1200: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 1209: ERROR: Unresolved reference 'callRecursive'.
# Line 2: Char 1259: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 1259: ERROR: Not enough information to infer type argument for 'T'.
# Line 2: Char 1259: ERROR: Not enough information to infer type argument for 'R'.
# Line 2: Char 1263: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 1278: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 1278: ERROR: Not enough information to infer type argument for 'T'.
# Line 2: Char 1282: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 1371: ERROR: Unresolved reference 'callRecursive'.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/3162.find-the-number-of-good-pairs-i.kt
# - Downloading find-the-number-of-good-pairs-i
#   ✔ Accepted
#   ✔ 783/783 cases passed (2 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3163.string-compression-iii.kt
# - Downloading string-compression-iii
#   ✔ Accepted
#   ✔ 744/744 cases passed (208 ms)
#   ✔ Your runtime beats 12.5 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (55.5 MB)
# Submitting: kotlin_solutions_1/3164.find-the-number-of-good-pairs-ii.kt
# - Downloading find-the-number-of-good-pairs-ii
#   ✔ Accepted
#   ✔ 687/687 cases passed (244 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (81.9 MB)
# Submitting: kotlin_solutions_1/3165.maximum-sum-of-subsequence-with-non-adjacent-elements.kt
# - Downloading maximum-sum-of-subsequence-with-non-adjacent-elements
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 968: ERROR: Unresolved reference 'callRecursive'.
#   ✘ Error: Line 2: Char 968: ERROR: Unresolved reference 'callRecursive'.
# Line 2: Char 1063: ERROR: Unresolved reference 'callRecursive'.
# Line 2: Char 1114: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 1118: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/3168.minimum-number-of-chairs-in-a-waiting-room.kt
# - Downloading minimum-number-of-chairs-in-a-waiting-room
#   ✔ Accepted
#   ✔ 852/852 cases passed (4 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3169.count-days-without-meetings.kt
# - Downloading count-days-without-meetings
#   ✔ Accepted
#   ✔ 578/578 cases passed (125 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (118 MB)
# Submitting: kotlin_solutions_1/3170.lexicographically-minimum-string-after-removing-stars.kt
# - Downloading lexicographically-minimum-string-after-removing-stars
#   ✔ Accepted
#   ✔ 602/602 cases passed (169 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (56.6 MB)
# Submitting: kotlin_solutions_1/3171.find-subarray-with-bitwise-or-closest-to-k.kt
# - Downloading find-subarray-with-bitwise-or-closest-to-k
#   ✔ Accepted
#   ✔ 814/814 cases passed (311 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (82.9 MB)
# Submitting: kotlin_solutions_1/3174.clear-digits.kt
# - Downloading clear-digits
#   ✔ Accepted
#   ✔ 688/688 cases passed (3 ms)
#   ✔ Your runtime beats 92.31 % of kotlin submissions
#   ✔ Your memory usage beats 92.31 % of kotlin submissions (42.2 MB)
# Submitting: kotlin_solutions_1/3175.find-the-first-player-to-win-k-games-in-a-row.kt
# - Downloading find-the-first-player-to-win-k-games-in-a-row
#   ✔ Accepted
#   ✔ 684/684 cases passed (28 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3176.find-the-maximum-length-of-a-good-subsequence-i.kt
# - Downloading find-the-maximum-length-of-a-good-subsequence-i
#   ✔ Accepted
#   ✔ 543/543 cases passed (126 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (51.3 MB)
# Submitting: kotlin_solutions_1/3177.find-the-maximum-length-of-a-good-subsequence-ii.kt
# - Downloading find-the-maximum-length-of-a-good-subsequence-ii
#   ✔ Accepted
#   ✔ 551/551 cases passed (116 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (82.5 MB)
# Submitting: kotlin_solutions_1/3178.find-the-child-who-has-the-ball-after-k-seconds.kt
# - Downloading find-the-child-who-has-the-ball-after-k-seconds
#   ✔ Accepted
#   ✔ 803/803 cases passed (1 ms)
#   ✔ Your runtime beats 85.71 % of kotlin submissions
#   ✔ Your memory usage beats 7.14 % of kotlin submissions (41.5 MB)
# Submitting: kotlin_solutions_1/3179.find-the-n-th-value-after-k-seconds.kt
# - Downloading find-the-n-th-value-after-k-seconds
#   ✔ Accepted
#   ✔ 708/708 cases passed (219 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (42.8 MB)
# Submitting: kotlin_solutions_1/3180.maximum-total-reward-using-operations-i.kt
# - Downloading maximum-total-reward-using-operations-i
#   ✔ Accepted
#   ✔ 586/586 cases passed (252 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (49.7 MB)
# Submitting: kotlin_solutions_1/3181.maximum-total-reward-using-operations-ii.kt
# - Downloading maximum-total-reward-using-operations-ii
#   ✔ Accepted
#   ✔ 583/583 cases passed (1323 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (81.7 MB)
# Submitting: kotlin_solutions_1/3184.count-pairs-that-form-a-complete-day-i.kt
# - Downloading count-pairs-that-form-a-complete-day-i
#   ✔ Accepted
#   ✔ 667/667 cases passed (1 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 16.67 % of kotlin submissions (43.2 MB)
# Submitting: kotlin_solutions_1/3185.count-pairs-that-form-a-complete-day-ii.kt
# - Downloading count-pairs-that-form-a-complete-day-ii
#   ✔ Accepted
#   ✔ 714/714 cases passed (623 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/3186.maximum-total-damage-with-spell-casting.kt
# - Downloading maximum-total-damage-with-spell-casting
#   ✔ Accepted
#   ✔ 555/555 cases passed (659 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (110.8 MB)
# Submitting: kotlin_solutions_1/3187.peaks-in-array.kt
# - Downloading peaks-in-array
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 6: Char 513: WARNING: Parameter 'it: Boolean' is never used, could be renamed to '_'.
#   ✘ Error: Line 6: Char 513: WARNING: Parameter 'it: Boolean' is never used, could be renamed to '_'.
# Line 6: Char 773: WARNING: Parameter 'it: Nothing?' is never used, could be renamed to '_'.
# Line 6: Char 800: WARNING: Parameter 'it: Int?' is never used, could be renamed to '_'.
# Line 6: Char 955: WARNING: Parameter 'it: Boolean' is never used, could be renamed to '_'.
# Line 42: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/3190.find-minimum-operations-to-make-all-elements-divisible-by-three.kt
# - Downloading find-minimum-operations-to-make-all-elements-divisible-by-three
#   ✔ Accepted
#   ✔ 660/660 cases passed (1 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 87.5 % of kotlin submissions (42 MB)
# Submitting: kotlin_solutions_1/3191.minimum-operations-to-make-binary-array-elements-equal-to-one-i.kt
# - Downloading minimum-operations-to-make-binary-array-elements-equal-to-one-i
#   ✔ Accepted
#   ✔ 689/689 cases passed (18 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (78.6 MB)
# Submitting: kotlin_solutions_1/3192.minimum-operations-to-make-binary-array-elements-equal-to-one-ii.kt
# - Downloading minimum-operations-to-make-binary-array-elements-equal-to-one-ii
#   ✔ Accepted
#   ✔ 691/691 cases passed (11 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3193.count-the-number-of-inversions.kt
# - Downloading count-the-number-of-inversions
#   ✔ Accepted
#   ✔ 719/719 cases passed (543 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (66.3 MB)
# Submitting: kotlin_solutions_1/3194.minimum-average-of-smallest-and-largest-elements.kt
# - Downloading minimum-average-of-smallest-and-largest-elements
#   ✔ Accepted
#   ✔ 720/720 cases passed (21 ms)
#   ✔ Your runtime beats 12.5 % of kotlin submissions
#   ✔ Your memory usage beats 37.5 % of kotlin submissions (49.1 MB)
# Submitting: kotlin_solutions_1/3195.find-the-minimum-area-to-cover-all-ones-i.kt
# - Downloading find-the-minimum-area-to-cover-all-ones-i
#   ✔ Accepted
#   ✔ 713/713 cases passed (1580 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3196.maximize-total-cost-of-alternating-subarrays.kt
# - Downloading maximize-total-cost-of-alternating-subarrays
#   ✔ Accepted
#   ✔ 692/692 cases passed (43 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (75.7 MB)
# Submitting: kotlin_solutions_1/3197.find-the-minimum-area-to-cover-all-ones-ii.kt
# - Downloading find-the-minimum-area-to-cover-all-ones-ii
#   ✘ Runtime Error
#   ✘ 0/663 cases passed (N/A)
#   ✘ Error: Line 6: Exception in thread "main" java.util.NoSuchElementException
#   ✘ Error: Line 6: Exception in thread "main" java.util.NoSuchElementException
#   ✘ Testcase: [[1,0,1],[1,1,1]]
#   ✘ Answer:
#   ✘ Expected Answer: 5
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/3200.maximum-height-of-a-triangle.kt
# - Downloading maximum-height-of-a-triangle
#   ✔ Accepted
#   ✔ 857/857 cases passed (154 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3201.find-the-maximum-length-of-valid-subsequence-i.kt
# - Downloading find-the-maximum-length-of-valid-subsequence-i
#   ✔ Accepted
#   ✔ 951/951 cases passed (20 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (71.8 MB)
# Submitting: kotlin_solutions_1/3202.find-the-maximum-length-of-valid-subsequence-ii.kt
# - Downloading find-the-maximum-length-of-valid-subsequence-ii
#   ✔ Accepted
#   ✔ 734/734 cases passed (62 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3203.find-minimum-diameter-after-merging-two-trees.kt
# - Downloading find-minimum-diameter-after-merging-two-trees
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 106: ERROR: Return type mismatch: expected 'kotlin.Int', actual 'kotlin.Function1<kotlin.Array<kotlin.IntArray>, kotlin.Function1<ERROR CLASS: No type for parameter, ERROR CLASS: Cannot infer argument for type parameter R>>'.
#   ✘ Error: Line 2: Char 106: ERROR: Return type mismatch: expected 'kotlin.Int', actual 'kotlin.Function1<kotlin.Array<kotlin.IntArray>, kotlin.Function1<ERROR CLASS: No type for parameter, ERROR CLASS: Cannot infer argument for type parameter R>>'.
# Line 2: Char 259: ERROR: Argument type mismatch: actual type is 'kotlin.text.MatchGroup?', but 'kotlin.Int' was expected.
# Line 2: Char 259: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun MatchGroupCollection.get(name: String): MatchGroup?
# Line 2: Char 270: ERROR: Argument type mismatch: actual type is 'kotlin.text.MatchGroup?', but 'kotlin.Int' was expected.
# Line 2: Char 270: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun MatchGroupCollection.get(name: String): MatchGroup?
# Line 2: Char 358: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 794: ERROR: Syntax error: Unexpected tokens (use ';' to separate expressions on the same line).
# Line 2: Char 800: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 802: WARNING: Parameter 'getDia: <ERROR TYPE REF: No type for parameter>' is never used, could be renamed to '_'.
# Line 2: Char 802: ERROR: An explicit type is required on a value parameter.
# Line 2: Char 812: ERROR: Unresolved reference 'getDia'.
# Line 2: Char 827: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 833: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 839: ERROR: Unresolved reference 'getDia'.
# Line 2: Char 854: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 860: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 920: ERROR: Syntax error: Expecting ')'.
# Line 38: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/3206.alternating-groups-i.kt
# - Downloading alternating-groups-i
#   ✔ Accepted
#   ✔ 795/795 cases passed (151 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 16.67 % of kotlin submissions (45.6 MB)
# Submitting: kotlin_solutions_1/3207.maximum-points-after-enemy-battles.kt
# - Downloading maximum-points-after-enemy-battles
#   ✔ Accepted
#   ✔ 579/579 cases passed (67 ms)
#   ✔ Your runtime beats 66.67 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (67.8 MB)
# Submitting: kotlin_solutions_1/3208.alternating-groups-ii.kt
# - Downloading alternating-groups-ii
#   ✔ Accepted
#   ✔ 625/625 cases passed (449 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 60 % of kotlin submissions (81.1 MB)
# Submitting: kotlin_solutions_1/3209.number-of-subarrays-with-and-value-of-k.kt
# - Downloading number-of-subarrays-with-and-value-of-k
#   ✔ Accepted
#   ✔ 902/902 cases passed (790 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (65 MB)
# Submitting: kotlin_solutions_1/3210.find-the-encrypted-string.kt
# - Downloading find-the-encrypted-string
#   ✔ Accepted
#   ✔ 704/704 cases passed (7 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3211.generate-binary-strings-without-adjacent-zeros.kt
# - Downloading generate-binary-strings-without-adjacent-zeros
#   ✔ Accepted
#   ✔ 20/20 cases passed (225 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (48.1 MB)
# Submitting: kotlin_solutions_1/3212.count-submatrices-with-equal-frequency-of-x-and-y.kt
# - Downloading count-submatrices-with-equal-frequency-of-x-and-y
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 344: ERROR: Only expressions are allowed in this context.
#   ✘ Error: Line 2: Char 344: ERROR: Only expressions are allowed in this context.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/3213.construct-string-with-minimum-cost.kt
# - Downloading construct-string-with-minimum-cost
#   ✘ Time Limit Exceeded
#   ✘ 750/808 cases passed (N/A)
#   ✘ Testcase: "...'... 92263 more character
#   ✘ Answer:
#   ✘ Expected Answer: 4614
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/3216.lexicographically-smallest-string-after-a-swap.kt
# - Downloading lexicographically-smallest-string-after-a-swap
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 131: ERROR: Unresolved reference 'rem' for operator '%'.
#   ✘ Error: Line 2: Char 131: ERROR: Unresolved reference 'rem' for operator '%'.
# Line 2: Char 150: ERROR: Unresolved reference 'rem' for operator '%'.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/3217.delete-nodes-from-linked-list-present-in-array.kt
# - Downloading delete-nodes-from-linked-list-present-in-array
#   ✔ Accepted
#   ✔ 582/582 cases passed (79 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (92.5 MB)
# Submitting: kotlin_solutions_1/3218.minimum-cost-for-cutting-cake-i.kt
# - Downloading minimum-cost-for-cutting-cake-i
#   ✔ Accepted
#   ✔ 533/533 cases passed (26 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (47.4 MB)
# Submitting: kotlin_solutions_1/3219.minimum-cost-for-cutting-cake-ii.kt
# - Downloading minimum-cost-for-cutting-cake-ii
#   ✔ Accepted
#   ✔ 566/566 cases passed (410 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (96.6 MB)
# Submitting: kotlin_solutions_1/3222.find-the-winning-player-in-coin-game.kt
# - Downloading find-the-winning-player-in-coin-game
#   ✔ Accepted
#   ✔ 852/852 cases passed (1 ms)
#   ✔ Your runtime beats 60 % of kotlin submissions
#   ✔ Your memory usage beats 20 % of kotlin submissions (41.9 MB)
# Submitting: kotlin_solutions_1/3223.minimum-length-of-string-after-operations.kt
# - Downloading minimum-length-of-string-after-operations
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 93: ERROR: Overload resolution ambiguity between candidates:
#   ✘ Error: Line 2: Char 93: ERROR: Overload resolution ambiguity between candidates:
# fun <T> Iterable<T>.sumOf(selector: (T) -> Int): Int
# fun <T> Iterable<T>.sumOf(selector: (T) -> Long): Long
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/3224.minimum-array-changes-to-make-differences-equal.kt
# - Downloading minimum-array-changes-to-make-differences-equal
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 246: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 2: Char 246: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 38: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/3225.maximum-score-from-grid-operations.kt
# - Downloading maximum-score-from-grid-operations
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 201: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 2: Char 201: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 216: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 235: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 36: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/3226.number-of-bit-changes-to-make-two-integers-equal.kt
# - Downloading number-of-bit-changes-to-make-two-integers-equal
#   ✔ Accepted
#   ✔ 682/682 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (40.8 MB)
# Submitting: kotlin_solutions_1/3227.vowels-game-in-a-string.kt
# - Downloading vowels-game-in-a-string
#   ✔ Accepted
#   ✔ 697/697 cases passed (23 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (48.7 MB)
# Submitting: kotlin_solutions_1/3228.maximum-number-of-operations-to-move-ones-to-the-end.kt
# - Downloading maximum-number-of-operations-to-move-ones-to-the-end
#   ✔ Accepted
#   ✔ 694/694 cases passed (29 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3229.minimum-operations-to-make-array-equal-to-target.kt
# - Downloading minimum-operations-to-make-array-equal-to-target
#   ✔ Accepted
#   ✔ 554/554 cases passed (44 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (86.6 MB)
# Submitting: kotlin_solutions_1/3232.find-if-digit-game-can-be-won.kt
# - Downloading find-if-digit-game-can-be-won
#   ✔ Accepted
#   ✔ 897/897 cases passed (9 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3233.find-the-count-of-numbers-which-are-not-special.kt
# - Downloading find-the-count-of-numbers-which-are-not-special
#   ✔ Accepted
#   ✔ 855/855 cases passed (64 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (45.4 MB)
# Submitting: kotlin_solutions_1/3234.count-the-number-of-substrings-with-dominant-ones.kt
# - Downloading count-the-number-of-substrings-with-dominant-ones
#   ✔ Accepted
#   ✔ 882/882 cases passed (274 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/3235.check-if-the-rectangle-corner-is-reachable.kt
# - Downloading check-if-the-rectangle-corner-is-reachable
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 102: ERROR: Argument type mismatch: actual type is 'it(R & Any & R & Any & kotlin.Unit)', but 'kotlin.Boolean' was expected.
#   ✘ Error: Line 2: Char 102: ERROR: Argument type mismatch: actual type is 'it(R & Any & R & Any & kotlin.Unit)', but 'kotlin.Boolean' was expected.
# Line 2: Char 159: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 161: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 40: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/3238.find-the-number-of-winning-players.kt
# - Downloading find-the-number-of-winning-players
#   ✔ Accepted
#   ✔ 839/839 cases passed (16 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3239.minimum-number-of-flips-to-make-binary-grid-palindromic-i.kt
# - Downloading minimum-number-of-flips-to-make-binary-grid-palindromic-i
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 6: error: <identifier> expected
#   ✘ Error: Line 6: error: <identifier> expected
# class Solution { fun minFlips(grid: Array<IntArray>): Int = minOf(grid.sumOf { r -> (0 until r.size / 2).count { c -> r[c] != r[r.size - 1 - c] } }, (0 until grid[0].size).sumOf { c -> (0 until grid.size / 2).count { r -> grid[r][c] != grid[grid.size - 1 - r][c] } }) }
#                                   ^
# Line 6: error: illegal start of type
# class Solution { fun minFlips(grid: Array<IntArray>): Int = minOf(grid.sumOf { r -> (0 until r.size / 2).count { c -> r[c] != r[r.size - 1 - c] } }, (0 until grid[0].size).sumOf { c -> (0 until grid.size / 2).count { r -> grid[r][c] != grid[grid.size - 1 - r][c] } }) }
#                                                    ^
# Line 6: error: <identifier> expected
# class Solution { fun minFlips(grid: Array<IntArray>): Int = minOf(grid.sumOf { r -> (0 until r.size / 2).count { c -> r[c] != r[r.size - 1 - c] } }, (0 until grid[0].size).sumOf { c -> (0 until grid.size / 2).count { r -> grid[r][c] != grid[grid.size - 1 - r][c] } }) }
#                                                          ^
# Line 6: error: ')' or ',' expected
# class Solution { fun minFlips(grid: Array<IntArray>): Int = minOf(grid.sumOf { r -> (0 until r.size / 2).count { c -> r[c] != r[r.size - 1 - c] } }, (0 until grid[0].size).sumOf { c -> (0 until grid.size / 2).count { r -> grid[r][c] != grid[grid.size - 1 - r][c] } }) }
#                                                                             ^
# Line 6: error: ')' expected
# class Solution { fun minFlips(grid: Array<IntArray>): Int = minOf(grid.sumOf { r -> (0 until r.size / 2).count { c -> r[c] != r[r.size - 1 - c] } }, (0 until grid[0].size).sumOf { c -> (0 until grid.size / 2).count { r -> grid[r][c] != grid[grid.size - 1 - r][c] } }) }
#                                                                                       ^
# Line 6: error: ';' expected
# class Solution { fun minFlips(grid: Array<IntArray>): Int = minOf(grid.sumOf { r -> (0 until r.size / 2).count { c -> r[c] != r[r.size - 1 - c] } }, (0 until grid[0].size).sumOf { c -> (0 until grid.size / 2).count { r -> grid[r][c] != grid[grid.size - 1 - r][c] } }) }
#                                                                                             ^
# Line 6: error: not a statement
# class Solution { fun minFlips(grid: Array<IntArray>): Int = minOf(grid.sumOf { r -> (0 until r.size / 2).count { c -> r[c] != r[r.size - 1 - c] } }, (0 until grid[0].size).sumOf { c -> (0 until grid.size / 2).count { r -> grid[r][c] != grid[grid.size - 1 - r][c] } }) }
#                                                                                                     ^
# Line 6: error: ';' expected
# class Solution { fun minFlips(grid: Array<IntArray>): Int = minOf(grid.sumOf { r -> (0 until r.size / 2).count { c -> r[c] != r[r.size - 1 - c] } }, (0 until grid[0].size).sumOf { c -> (0 until grid.size / 2).count { r -> grid[r][c] != grid[grid.size - 1 - r][c] } }) }
#                                                                                                        ^
# Line 6: error: not a statement
# class Solution { fun minFlips(grid: Array<IntArray>): Int = minOf(grid.sumOf { r -> (0 until r.size / 2).count { c -> r[c] != r[r.size - 1 - c] } }, (0 until grid[0].size).sumOf { c -> (0 until grid.size / 2).count { r -> grid[r][c] != grid[grid.size - 1 - r][c] } }) }
#                                                                                                          ^
# Line 6: error: ';' expected
# class Solution { fun minFlips(grid: Array<IntArray>): Int = minOf(grid.sumOf { r -> (0 until r.size / 2).count { c -> r[c] != r[r.size - 1 - c] } }, (0 until grid[0].size).sumOf { c -> (0 until grid.size / 2).count { r -> grid[r][c] != grid[grid.size - 1 - r][c] } }) }
#                                                                                                               ^
# Line 6: error: not a statement
# class Solution { fun minFlips(grid: Array<IntArray>): Int = minOf(grid.sumOf { r -> (0 until r.size / 2).count { c -> r[c] != r[r.size - 1 - c] } }, (0 until grid[0].size).sumOf { c -> (0 until grid.size / 2).count { r -> grid[r][c] != grid[grid.size - 1 - r][c] } }) }
#                                                                                                                  ^
# Line 6: error: ';' expected
# class Solution { fun minFlips(grid: Array<IntArray>): Int = minOf(grid.sumOf { r -> (0 until r.size / 2).count { c -> r[c] != r[r.size - 1 - c] } }, (0 until grid[0].size).sumOf { c -> (0 until grid.size / 2).count { r -> grid[r][c] != grid[grid.size - 1 - r][c] } }) }
#                                                                                                                                                ^
# Line 6: error: illegal start of type
# class Solution { fun minFlips(grid: Array<IntArray>): Int = minOf(grid.sumOf { r -> (0 until r.size / 2).count { c -> r[c] != r[r.size - 1 - c] } }, (0 until grid[0].size).sumOf { c -> (0 until grid.size / 2).count { r -> grid[r][c] != grid[grid.size - 1 - r][c] } }) }
#                                                                                                                                                    ^
# Line 6: error: <identifier> expected
# class Solution { fun minFlips(grid: Array<IntArray>): Int = minOf(grid.sumOf { r -> (0 until r.size / 2).count { c -> r[c] != r[r.size - 1 - c] } }, (0 until grid[0].size).sumOf { c -> (0 until grid.size / 2).count { r -> grid[r][c] != grid[grid.size - 1 - r][c] } }) }
#                                                                                                                                                     ^
# Line 6: error: ']' expected
# class Solution { fun minFlips(grid: Array<IntArray>): Int = minOf(grid.sumOf { r -> (0 until r.size / 2).count { c -> r[c] != r[r.size - 1 - c] } }, (0 until grid[0].size).sumOf { c -> (0 until grid.size / 2).count { r -> grid[r][c] != grid[grid.size - 1 - r][c] } }) }
#                                                                                                                                                                    ^
# Line 6: error: <identifier> expected
# class Solution { fun minFlips(grid: Array<IntArray>): Int = minOf(grid.sumOf { r -> (0 until r.size / 2).count { c -> r[c] != r[r.size - 1 - c] } }, (0 until grid[0].size).sumOf { c -> (0 until grid.size / 2).count { r -> grid[r][c] != grid[grid.size - 1 - r][c] } }) }
#                                                                                                                                                                           ^
# Line 6: error: <identifier> expected
# class Solution { fun minFlips(grid: Array<IntArray>): Int = minOf(grid.sumOf { r -> (0 until r.size / 2).count { c -> r[c] != r[r.size - 1 - c] } }, (0 until grid[0].size).sumOf { c -> (0 until grid.size / 2).count { r -> grid[r][c] != grid[grid.size - 1 - r][c] } }) }
#                                                                                                                                                                                  ^
# Line 6: error: ')' expected
# class Solution { fun minFlips(grid: Array<IntArray>): Int = minOf(grid.sumOf { r -> (0 until r.size / 2).count { c -> r[c] != r[r.size - 1 - c] } }, (0 until grid[0].size).sumOf { c -> (0 until grid.size / 2).count { r -> grid[r][c] != grid[grid.size - 1 - r][c] } }) }
#                                                                                                                                                                                            ^
# Line 6: error: ';' expected
# class Solution { fun minFlips(grid: Array<IntArray>): Int = minOf(grid.sumOf { r -> (0 until r.size / 2).count { c -> r[c] != r[r.size - 1 - c] } }, (0 until grid[0].size).sumOf { c -> (0 until grid.size / 2).count { r -> grid[r][c] != grid[grid.size - 1 - r][c] } }) }
#                                                                                                                                                                                                  ^
# Line 6: error: not a statement
# class Solution { fun minFlips(grid: Array<IntArray>): Int = minOf(grid.sumOf { r -> (0 until r.size / 2).count { c -> r[c] != r[r.size - 1 - c] } }, (0 until grid[0].size).sumOf { c -> (0 until grid.size / 2).count { r -> grid[r][c] != grid[grid.size - 1 - r][c] } }) }
#                                                                                                                                                                                                             ^
# Line 6: error: ';' expected
# class Solution { fun minFlips(grid: Array<IntArray>): Int = minOf(grid.sumOf { r -> (0 until r.size / 2).count { c -> r[c] != r[r.size - 1 - c] } }, (0 until grid[0].size).sumOf { c -> (0 until grid.size / 2).count { r -> grid[r][c] != grid[grid.size - 1 - r][c] } }) }
#                                                                                                                                                                                                                ^
# Line 6: error: not a statement
# class Solution { fun minFlips(grid: Array<IntArray>): Int = minOf(grid.sumOf { r -> (0 until r.size / 2).count { c -> r[c] != r[r.size - 1 - c] } }, (0 until grid[0].size).sumOf { c -> (0 until grid.size / 2).count { r -> grid[r][c] != grid[grid.size - 1 - r][c] } }) }
#                                                                                                                                                                                                                  ^
# Line 6: error: ';' expected
# class Solution { fun minFlips(grid: Array<IntArray>): Int = minOf(grid.sumOf { r -> (0 until r.size / 2).count { c -> r[c] != r[r.size - 1 - c] } }, (0 until grid[0].size).sumOf { c -> (0 until grid.size / 2).count { r -> grid[r][c] != grid[grid.size - 1 - r][c] } }) }
#                                                                                                                                                                                                                       ^
# Line 6: error: not a statement
# class Solution { fun minFlips(grid: Array<IntArray>): Int = minOf(grid.sumOf { r -> (0 until r.size / 2).count { c -> r[c] != r[r.size - 1 - c] } }, (0 until grid[0].size).sumOf { c -> (0 until grid.size / 2).count { r -> grid[r][c] != grid[grid.size - 1 - r][c] } }) }
#                                                                                                                                                                                                                          ^
# Line 6: error: ';' expected
# class Solution { fun minFlips(grid: Array<IntArray>): Int = minOf(grid.sumOf { r -> (0 until r.size / 2).count { c -> r[c] != r[r.size - 1 - c] } }, (0 until grid[0].size).sumOf { c -> (0 until grid.size / 2).count { r -> grid[r][c] != grid[grid.size - 1 - r][c] } }) }
#                                                                                                                                                                                                                                                                       ^
# Line 6: error: illegal start of type
# class Solution { fun minFlips(grid: Array<IntArray>): Int = minOf(grid.sumOf { r -> (0 until r.size / 2).count { c -> r[c] != r[r.size - 1 - c] } }, (0 until grid[0].size).sumOf { c -> (0 until grid.size / 2).count { r -> grid[r][c] != grid[grid.size - 1 - r][c] } }) }
#                                                                                                                                                                                                                                                                           ^
# 26 errors
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/3240.minimum-number-of-flips-to-make-binary-grid-palindromic-ii.kt
# - Downloading minimum-number-of-flips-to-make-binary-grid-palindromic-ii
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 6: error: <identifier> expected
#   ✘ Error: Line 6: error: <identifier> expected
# class Solution { fun minFlips(grid: Array<IntArray>): Int = grid.size.let { n -> grid[0].size.let { m -> (0 until n / 2).sumOf { i -> (0 until m / 2).sumOf { j -> (grid[i][j] + grid[n - 1 - i][j] + grid[i][m - 1 - j] + grid[n - 1 - i][m - 1 - j]).let { s -> minOf(s, 4 - s) } } }.let { base -> (if (n % 2 == 1) (0 until m / 2).count { j -> grid[n / 2][j] != grid[n / 2][m - 1 - j] } else 0).let { rd -> (if (m % 2 == 1) (0 until n / 2).count { i -> grid[i][m / 2] != grid[n - 1 - i][m / 2] } else 0).let { cd -> (rd + cd).let { diffs -> (if (n % 2 == 1) (0 until m / 2).count { j -> grid[n / 2][j] == 1 && grid[n / 2][m - 1 - j] == 1 } else 0).let { ro -> (if (m % 2 == 1) (0 until n / 2).count { i -> grid[i][m / 2] == 1 && grid[n - 1 - i][m / 2] == 1 } else 0).let { co -> base + diffs + (if (diffs == 0 && (ro + co) % 2 == 1) 2 else 0) + (if (n % 2 == 1 && m % 2 == 1) grid[n / 2][m / 2] else 0) } } } } } } } } }
#                                   ^
# Line 6: error: illegal start of type
# class Solution { fun minFlips(grid: Array<IntArray>): Int = grid.size.let { n -> grid[0].size.let { m -> (0 until n / 2).sumOf { i -> (0 until m / 2).sumOf { j -> (grid[i][j] + grid[n - 1 - i][j] + grid[i][m - 1 - j] + grid[n - 1 - i][m - 1 - j]).let { s -> minOf(s, 4 - s) } } }.let { base -> (if (n % 2 == 1) (0 until m / 2).count { j -> grid[n / 2][j] != grid[n / 2][m - 1 - j] } else 0).let { rd -> (if (m % 2 == 1) (0 until n / 2).count { i -> grid[i][m / 2] != grid[n - 1 - i][m / 2] } else 0).let { cd -> (rd + cd).let { diffs -> (if (n % 2 == 1) (0 until m / 2).count { j -> grid[n / 2][j] == 1 && grid[n / 2][m - 1 - j] == 1 } else 0).let { ro -> (if (m % 2 == 1) (0 until n / 2).count { i -> grid[i][m / 2] == 1 && grid[n - 1 - i][m / 2] == 1 } else 0).let { co -> base + diffs + (if (diffs == 0 && (ro + co) % 2 == 1) 2 else 0) + (if (n % 2 == 1 && m % 2 == 1) grid[n / 2][m / 2] else 0) } } } } } } } } }
#                                                    ^
# Line 6: error: <identifier> expected
# class Solution { fun minFlips(grid: Array<IntArray>): Int = grid.size.let { n -> grid[0].size.let { m -> (0 until n / 2).sumOf { i -> (0 until m / 2).sumOf { j -> (grid[i][j] + grid[n - 1 - i][j] + grid[i][m - 1 - j] + grid[n - 1 - i][m - 1 - j]).let { s -> minOf(s, 4 - s) } } }.let { base -> (if (n % 2 == 1) (0 until m / 2).count { j -> grid[n / 2][j] != grid[n / 2][m - 1 - j] } else 0).let { rd -> (if (m % 2 == 1) (0 until n / 2).count { i -> grid[i][m / 2] != grid[n - 1 - i][m / 2] } else 0).let { cd -> (rd + cd).let { diffs -> (if (n % 2 == 1) (0 until m / 2).count { j -> grid[n / 2][j] == 1 && grid[n / 2][m - 1 - j] == 1 } else 0).let { ro -> (if (m % 2 == 1) (0 until n / 2).count { i -> grid[i][m / 2] == 1 && grid[n - 1 - i][m / 2] == 1 } else 0).let { co -> base + diffs + (if (diffs == 0 && (ro + co) % 2 == 1) 2 else 0) + (if (n % 2 == 1 && m % 2 == 1) grid[n / 2][m / 2] else 0) } } } } } } } } }
#                                                          ^
# Line 6: error: ';' expected
# ...
#                                                                                                                                                                                                                                                                                                                                       ^
# Line 6: error: ';' expected
# class Solution { fun maximumValueSum(board: Array<IntArray>): Long = board.flatMapIndexed { r, row -> row.mapIndexed { c, v -> longArrayOf(v.toLong(), r.toLong(), c.toLong()) }.sortedByDescending { it[0] }.take(3) }.sortedByDescending { it[0] }.take(200).let { c -> c.indices.fold(Long.MIN_VALUE) { m, i -> (i + 1 until c.size).fold(m) { m2, j -> (j + 1 until c.size).fold(m2) { m3, k -> if (c[i][1] != c[j][1] && c[i][1] != c[k][1] && c[j][1] != c[k][1] && c[i][2] != c[j][2] && c[i][2] != c[k][2] && c[j][2] != c[k][2]) maxOf(m3, c[i][0] + c[j][0] + c[k][0]) else m3 } } } } }
#                                                                                                                                                                                                                                                                                                                                                ^
# Line 6: error: not a statement
# class Solution { fun maximumValueSum(board: Array<IntArray>): Long = board.flatMapIndexed { r, row -> row.mapIndexed { c, v -> longArrayOf(v.toLong(), r.toLong(), c.toLong()) }.sortedByDescending { it[0] }.take(3) }.sortedByDescending { it[0] }.take(200).let { c -> c.indices.fold(Long.MIN_VALUE) { m, i -> (i + 1 until c.size).fold(m) { m2, j -> (j + 1 until c.size).fold(m2) { m3, k -> if (c[i][1] != c[j][1] && c[i][1] != c[k][1] && c[j][1] != c[k][1] && c[i][2] != c[j][2] && c[i][2] != c[k][2] && c[j][2] != c[k][2]) maxOf(m3, c[i][0] + c[j][0] + c[k][0]) else m3 } } } } }
#                                                                                                                                                                                                                                                                                                                                                   ^
# Line 6: error: ';' expected
# class Solution { fun maximumValueSum(board: Array<IntArray>): Long = board.flatMapIndexed { r, row -> row.mapIndexed { c, v -> longArrayOf(v.toLong(), r.toLong(), c.toLong()) }.sortedByDescending { it[0] }.take(3) }.sortedByDescending { it[0] }.take(200).let { c -> c.indices.fold(Long.MIN_VALUE) { m, i -> (i + 1 until c.size).fold(m) { m2, j -> (j + 1 until c.size).fold(m2) { m3, k -> if (c[i][1] != c[j][1] && c[i][1] != c[k][1] && c[j][1] != c[k][1] && c[i][2] != c[j][2] && c[i][2] != c[k][2] && c[j][2] != c[k][2]) maxOf(m3, c[i][0] + c[j][0] + c[k][0]) else m3 } } } } }
#                                                                                                                                                                                                                                                                                                                                                     ^
# Line 6: error: ')' expected
# class Solution { fun maximumValueSum(board: Array<IntArray>): Long = board.flatMapIndexed { r, row -> row.mapIndexed { c, v -> longArrayOf(v.toLong(), r.toLong(), c.toLong()) }.sortedByDescending { it[0] }.take(3) }.sortedByDescending { it[0] }.take(200).let { c -> c.indices.fold(Long.MIN_VALUE) { m, i -> (i + 1 until c.size).fold(m) { m2, j -> (j + 1 until c.size).fold(m2) { m3, k -> if (c[i][1] != c[j][1] && c[i][1] != c[k][1] && c[j][1] != c[k][1] && c[i][2] != c[j][2] && c[i][2] != c[k][2] && c[j][2] != c[k][2]) maxOf(m3, c[i][0] + c[j][0] + c[k][0]) else m3 } } } } }
#                                                                                                                                                                                                                                                                                                                                                                  ^
# Line 6: error: ';' expected
# class Solution { fun maximumValueSum(board: Array<IntArray>): Long = board.flatMapIndexed { r, row -> row.mapIndexed { c, v -> longArrayOf(v.toLong(), r.toLong(), c.toLong()) }.sortedByDescending { it[0] }.take(3) }.sortedByDescending { it[0] }.take(200).let { c -> c.indices.fold(Long.MIN_VALUE) { m, i -> (i + 1 until c.size).fold(m) { m2, j -> (j + 1 until c.size).fold(m2) { m3, k -> if (c[i][1] != c[j][1] && c[i][1] != c[k][1] && c[j][1] != c[k][1] && c[i][2] != c[j][2] && c[i][2] != c[k][2] && c[j][2] != c[k][2]) maxOf(m3, c[i][0] + c[j][0] + c[k][0]) else m3 } } } } }
#                                                                                                                                                                                                                                                                                                                                                                        ^
# Line 6: error: not a statement
# class Solution { fun maximumValueSum(board: Array<IntArray>): Long = board.flatMapIndexed { r, row -> row.mapIndexed { c, v -> longArrayOf(v.toLong(), r.toLong(), c.toLong()) }.sortedByDescending { it[0] }.take(3) }.sortedByDescending { it[0] }.take(200).let { c -> c.indices.fold(Long.MIN_VALUE) { m, i -> (i + 1 until c.size).fold(m) { m2, j -> (j + 1 until c.size).fold(m2) { m3, k -> if (c[i][1] != c[j][1] && c[i][1] != c[k][1] && c[j][1] != c[k][1] && c[i][2] != c[j][2] && c[i][2] != c[k][2] && c[j][2] != c[k][2]) maxOf(m3, c[i][0] + c[j][0] + c[k][0]) else m3 } } } } }
#                                                                                                                                                                                                                                                                                                                                                                          ^
# Line 6: error: ';' expected
# class Solution { fun maximumValueSum(board: Array<IntArray>): Long = board.flatMapIndexed { r, row -> row.mapIndexed { c, v -> longArrayOf(v.toLong(), r.toLong(), c.toLong()) }.sortedByDescending { it[0] }.take(3) }.sortedByDescending { it[0] }.take(200).let { c -> c.indices.fold(Long.MIN_VALUE) { m, i -> (i + 1 until c.size).fold(m) { m2, j -> (j + 1 until c.size).fold(m2) { m3, k -> if (c[i][1] != c[j][1] && c[i][1] != c[k][1] && c[j][1] != c[k][1] && c[i][2] != c[j][2] && c[i][2] != c[k][2] && c[j][2] != c[k][2]) maxOf(m3, c[i][0] + c[j][0] + c[k][0]) else m3 } } } } }
#                                                                                                                                                                                                                                                                                                                                                                               ^
# Line 6: error: ';' expected
# class Solution { fun maximumValueSum(board: Array<IntArray>): Long = board.flatMapIndexed { r, row -> row.mapIndexed { c, v -> longArrayOf(v.toLong(), r.toLong(), c.toLong()) }.sortedByDescending { it[0] }.take(3) }.sortedByDescending { it[0] }.take(200).let { c -> c.indices.fold(Long.MIN_VALUE) { m, i -> (i + 1 until c.size).fold(m) { m2, j -> (j + 1 until c.size).fold(m2) { m3, k -> if (c[i][1] != c[j][1] && c[i][1] != c[k][1] && c[j][1] != c[k][1] && c[i][2] != c[j][2] && c[i][2] != c[k][2] && c[j][2] != c[k][2]) maxOf(m3, c[i][0] + c[j][0] + c[k][0]) else m3 } } } } }
#                                                                                                                                                                                                                                                                                                                                                                                         ^
# Line 6: error: not a statement
# class Solution { fun maximumValueSum(board: Array<IntArray>): Long = board.flatMapIndexed { r, row -> row.mapIndexed { c, v -> longArrayOf(v.toLong(), r.toLong(), c.toLong()) }.sortedByDescending { it[0] }.take(3) }.sortedByDescending { it[0] }.take(200).let { c -> c.indices.fold(Long.MIN_VALUE) { m, i -> (i + 1 until c.size).fold(m) { m2, j -> (j + 1 until c.size).fold(m2) { m3, k -> if (c[i][1] != c[j][1] && c[i][1] != c[k][1] && c[j][1] != c[k][1] && c[i][2] != c[j][2] && c[i][2] != c[k][2] && c[j][2] != c[k][2]) maxOf(m3, c[i][0] + c[j][0] + c[k][0]) else m3 } } } } }
#                                                                                                                                                                                                                                                                                                                                                                                            ^
# Line 6: error: ';' expected
# class Solution { fun maximumValueSum(board: Array<IntArray>): Long = board.flatMapIndexed { r, row -> row.mapIndexed { c, v -> longArrayOf(v.toLong(), r.toLong(), c.toLong()) }.sortedByDescending { it[0] }.take(3) }.sortedByDescending { it[0] }.take(200).let { c -> c.indices.fold(Long.MIN_VALUE) { m, i -> (i + 1 until c.size).fold(m) { m2, j -> (j + 1 until c.size).fold(m2) { m3, k -> if (c[i][1] != c[j][1] && c[i][1] != c[k][1] && c[j][1] != c[k][1] && c[i][2] != c[j][2] && c[i][2] != c[k][2] && c[j][2] != c[k][2]) maxOf(m3, c[i][0] + c[j][0] + c[k][0]) else m3 } } } } }
#                                                                                                                                                                                                                                                                                                                                                                                              ^
# Line 6: error: illegal start of expression
# class Solution { fun maximumValueSum(board: Array<IntArray>): Long = board.flatMapIndexed { r, row -> row.mapIndexed { c, v -> longArrayOf(v.toLong(), r.toLong(), c.toLong()) }.sortedByDescending { it[0] }.take(3) }.sortedByDescending { it[0] }.take(200).let { c -> c.indices.fold(Long.MIN_VALUE) { m, i -> (i + 1 until c.size).fold(m) { m2, j -> (j + 1 until c.size).fold(m2) { m3, k -> if (c[i][1] != c[j][1] && c[i][1] != c[k][1] && c[j][1] != c[k][1] && c[i][2] != c[j][2] && c[i][2] != c[k][2] && c[j][2] != c[k][2]) maxOf(m3, c[i][0] + c[j][0] + c[k][0]) else m3 } } } } }
#                                                                                                                                                                                                                                                                                                                                                                                                     ^
# Line 6: error: not a statement
# class Solution { fun maximumValueSum(board: Array<IntArray>): Long = board.flatMapIndexed { r, row -> row.mapIndexed { c, v -> longArrayOf(v.toLong(), r.toLong(), c.toLong()) }.sortedByDescending { it[0] }.take(3) }.sortedByDescending { it[0] }.take(200).let { c -> c.indices.fold(Long.MIN_VALUE) { m, i -> (i + 1 until c.size).fold(m) { m2, j -> (j + 1 until c.size).fold(m2) { m3, k -> if (c[i][1] != c[j][1] && c[i][1] != c[k][1] && c[j][1] != c[k][1] && c[i][2] != c[j][2] && c[i][2] != c[k][2] && c[j][2] != c[k][2]) maxOf(m3, c[i][0] + c[j][0] + c[k][0]) else m3 } } } } }
#                                                                                                                                                                                                                                                                                                                                                                                                ^
# Line 6: error: ';' expected
# class Solution { fun maximumValueSum(board: Array<IntArray>): Long = board.flatMapIndexed { r, row -> row.mapIndexed { c, v -> longArrayOf(v.toLong(), r.toLong(), c.toLong()) }.sortedByDescending { it[0] }.take(3) }.sortedByDescending { it[0] }.take(200).let { c -> c.indices.fold(Long.MIN_VALUE) { m, i -> (i + 1 until c.size).fold(m) { m2, j -> (j + 1 until c.size).fold(m2) { m3, k -> if (c[i][1] != c[j][1] && c[i][1] != c[k][1] && c[j][1] != c[k][1] && c[i][2] != c[j][2] && c[i][2] != c[k][2] && c[j][2] != c[k][2]) maxOf(m3, c[i][0] + c[j][0] + c[k][0]) else m3 } } } } }
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ^
# Line 6: error: not a statement
# class Solution { fun maximumValueSum(board: Array<IntArray>): Long = board.flatMapIndexed { r, row -> row.mapIndexed { c, v -> longArrayOf(v.toLong(), r.toLong(), c.toLong()) }.sortedByDescending { it[0] }.take(3) }.sortedByDescending { it[0] }.take(200).let { c -> c.indices.fold(Long.MIN_VALUE) { m, i -> (i + 1 until c.size).fold(m) { m2, j -> (j + 1 until c.size).fold(m2) { m3, k -> if (c[i][1] != c[j][1] && c[i][1] != c[k][1] && c[j][1] != c[k][1] && c[i][2] != c[j][2] && c[i][2] != c[k][2] && c[j][2] != c[k][2]) maxOf(m3, c[i][0] + c[j][0] + c[k][0]) else m3 } } } } }
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ^
# Line 6: error: ';' expected
# class Solution { fun maximumValueSum(board: Array<IntArray>): Long = board.flatMapIndexed { r, row -> row.mapIndexed { c, v -> longArrayOf(v.toLong(), r.toLong(), c.toLong()) }.sortedByDescending { it[0] }.take(3) }.sortedByDescending { it[0] }.take(200).let { c -> c.indices.fold(Long.MIN_VALUE) { m, i -> (i + 1 until c.size).fold(m) { m2, j -> (j + 1 until c.size).fold(m2) { m3, k -> if (c[i][1] != c[j][1] && c[i][1] != c[k][1] && c[j][1] != c[k][1] && c[i][2] != c[j][2] && c[i][2] != c[k][2] && c[j][2] != c[k][2]) maxOf(m3, c[i][0] + c[j][0] + c[k][0]) else m3 } } } } }
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ^
# 49 errors
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-08-17 19:30:46
