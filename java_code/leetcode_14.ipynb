# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME_2')
    user_cookie = userdata.get('LEETCODE_TOKEN_2')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME_2'] = user_name
    os.environ['LEETCODE_TOKEN_2'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME_2" "$LEETCODE_TOKEN_2" | leetcode user -c

# %%
# %%bash
#
#
# # top 100 answers
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v java_solutions/*.java | sed -n '1951,2050p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 8
# done
# Out:
# Submitting: java_solutions/2996.smallest-missing-integer-greater-than-sequential-prefix-sum.java
# - Downloading problems
# - Downloading smallest-missing-integer-greater-than-sequential-prefix-sum
#   ✔ Accepted
#   ✔ 616/616 cases passed (2 ms)
#   ✔ Your runtime beats 54.55 % of java submissions
#   ✔ Your memory usage beats 44.55 % of java submissions (44.2 MB)
# Submitting: java_solutions/2997.minimum-number-of-operations-to-make-array-xor-equal-to-k.java
# - Downloading minimum-number-of-operations-to-make-array-xor-equal-to-k
#   ✔ Accepted
#   ✔ 684/684 cases passed (5 ms)
#   ✔ Your runtime beats 6.38 % of java submissions
#   ✔ Your memory usage beats 98.94 % of java submissions (78.9 MB)
# Submitting: java_solutions/2998.minimum-number-of-operations-to-make-x-and-y-equal.java
# - Downloading minimum-number-of-operations-to-make-x-and-y-equal
#   ✔ Accepted
#   ✔ 949/949 cases passed (21 ms)
#   ✔ Your runtime beats 9.79 % of java submissions
#   ✔ Your memory usage beats 67.83 % of java submissions (46.3 MB)
# Submitting: java_solutions/2999.count-the-number-of-powerful-integers.java
# - Downloading count-the-number-of-powerful-integers
#   ✔ Accepted
#   ✔ 933/933 cases passed (17 ms)
#   ✔ Your runtime beats 15.05 % of java submissions
#   ✔ Your memory usage beats 5.38 % of java submissions (51.1 MB)
# Submitting: java_solutions/3000.maximum-area-of-longest-diagonal-rectangle.java
# - Downloading maximum-area-of-longest-diagonal-rectangle
#   ✔ Accepted
#   ✔ 817/817 cases passed (11 ms)
#   ✔ Your runtime beats 6.04 % of java submissions
#   ✔ Your memory usage beats 14.2 % of java submissions (46.7 MB)
# Submitting: java_solutions/3001.minimum-moves-to-capture-the-queen.java
# - Downloading minimum-moves-to-capture-the-queen
#   ✔ Accepted
#   ✔ 744/744 cases passed (5 ms)
#   ✔ Your runtime beats 3.26 % of java submissions
#   ✔ Your memory usage beats 30.43 % of java submissions (42.8 MB)
# Submitting: java_solutions/3002.maximum-size-of-a-set-after-removals.java
# - Downloading maximum-size-of-a-set-after-removals
#   ✔ Accepted
#   ✔ 970/970 cases passed (40 ms)
#   ✔ Your runtime beats 37.36 % of java submissions
#   ✔ Your memory usage beats 36.26 % of java submissions (61.7 MB)
# Submitting: java_solutions/3003.maximize-the-number-of-partitions-after-operations.java
# - Downloading maximize-the-number-of-partitions-after-operations
#   ✔ Accepted
#   ✔ 278/278 cases passed (1218 ms)
#   ✔ Your runtime beats 5.36 % of java submissions
#   ✔ Your memory usage beats 5.36 % of java submissions (196.1 MB)
# Submitting: java_solutions/3005.count-elements-with-maximum-frequency.java
# - Downloading count-elements-with-maximum-frequency
#   ✔ Accepted
#   ✔ 623/623 cases passed (32 ms)
#   ✔ Your runtime beats 4.68 % of java submissions
#   ✔ Your memory usage beats 7.66 % of java submissions (52.2 MB)
# Submitting: java_solutions/3006.find-beautiful-indices-in-the-given-array-i.java
# - Downloading find-beautiful-indices-in-the-given-array-i
#   ✔ Accepted
#   ✔ 535/535 cases passed (57 ms)
#   ✔ Your runtime beats 36.32 % of java submissions
#   ✔ Your memory usage beats 5.19 % of java submissions (57 MB)
# Submitting: java_solutions/3007.maximum-number-that-sum-of-the-prices-is-less-than-or-equal-to-k.java
# - Downloading maximum-number-that-sum-of-the-prices-is-less-than-or-equal-to-k
#   ✔ Accepted
#   ✔ 932/932 cases passed (22 ms)
#   ✔ Your runtime beats 38.36 % of java submissions
#   ✔ Your memory usage beats 34.25 % of java submissions (43.4 MB)
# Submitting: java_solutions/3008.find-beautiful-indices-in-the-given-array-ii.java
# - Downloading find-beautiful-indices-in-the-given-array-ii
#   ✔ Accepted
#   ✔ 238/238 cases passed (1364 ms)
#   ✔ Your runtime beats 5.88 % of java submissions
#   ✔ Your memory usage beats 15.29 % of java submissions (155.6 MB)
# Submitting: java_solutions/3010.divide-an-array-into-subarrays-with-minimum-cost-i.java
# - Downloading divide-an-array-into-subarrays-with-minimum-cost-i
#   ✔ Accepted
#   ✔ 988/988 cases passed (4 ms)
#   ✔ Your runtime beats 25.3 % of java submissions
#   ✔ Your memory usage beats 25.08 % of java submissions (45.6 MB)
# Submitting: java_solutions/3011.find-if-array-can-be-sorted.java
# - Downloading find-if-array-can-be-sorted
#   ✔ Accepted
#   ✔ 999/999 cases passed (5 ms)
#   ✔ Your runtime beats 52.41 % of java submissions
#   ✔ Your memory usage beats 93.1 % of java submissions (46.1 MB)
# Submitting: java_solutions/3012.minimize-length-of-array-using-operations.java
# - Downloading minimize-length-of-array-using-operations
#   ✔ Accepted
#   ✔ 523/523 cases passed (7 ms)
#   ✔ Your runtime beats 28.57 % of java submissions
#   ✔ Your memory usage beats 61.9 % of java submissions (103.3 MB)
# Submitting: java_solutions/3013.divide-an-array-into-subarrays-with-minimum-cost-ii.java
# - Downloading divide-an-array-into-subarrays-with-minimum-cost-ii
#   ✔ Accepted
#   ✔ 691/691 cases passed (559 ms)
#   ✔ Your runtime beats 6.11 % of java submissions
#   ✔ Your memory usage beats 27.22 % of java submissions (99.5 MB)
# Submitting: java_solutions/3014.minimum-number-of-pushes-to-type-word-i.java
# - Downloading minimum-number-of-pushes-to-type-word-i
#   ✔ Accepted
#   ✔ 500/500 cases passed (3 ms)
#   ✔ Your runtime beats 15.15 % of java submissions
#   ✔ Your memory usage beats 5.05 % of java submissions (43.7 MB)
# Submitting: java_solutions/3015.count-the-number-of-houses-at-a-certain-distance-i.java
# - Downloading count-the-number-of-houses-at-a-certain-distance-i
#   ✔ Accepted
#   ✔ 880/880 cases passed (11 ms)
#   ✔ Your runtime beats 63.92 % of java submissions
#   ✔ Your memory usage beats 68.35 % of java submissions (45.7 MB)
# Submitting: java_solutions/3016.minimum-number-of-pushes-to-type-word-ii.java
# - Downloading minimum-number-of-pushes-to-type-word-ii
#   ✔ Accepted
#   ✔ 877/877 cases passed (16 ms)
#   ✔ Your runtime beats 37.8 % of java submissions
#   ✔ Your memory usage beats 93.3 % of java submissions (47.8 MB)
# Submitting: java_solutions/3017.count-the-number-of-houses-at-a-certain-distance-ii.java
# - Downloading count-the-number-of-houses-at-a-certain-distance-ii
#   ✔ Accepted
#   ✔ 549/549 cases passed (41 ms)
#   ✔ Your runtime beats 6.25 % of java submissions
#   ✔ Your memory usage beats 6.25 % of java submissions (114.2 MB)
# Submitting: java_solutions/3019.number-of-changing-keys.java
# - Downloading number-of-changing-keys
#   ✔ Accepted
#   ✔ 802/802 cases passed (7 ms)
#   ✔ Your runtime beats 1.83 % of java submissions
#   ✔ Your memory usage beats 13.12 % of java submissions (44.1 MB)
# Submitting: java_solutions/3020.find-the-maximum-number-of-elements-in-subset.java
# - Downloading find-the-maximum-number-of-elements-in-subset
#   ✔ Accepted
#   ✔ 731/731 cases passed (160 ms)
#   ✔ Your runtime beats 15.26 % of java submissions
#   ✔ Your memory usage beats 28.81 % of java submissions (68.2 MB)
# Submitting: java_solutions/3021.alice-and-bob-playing-flower-game.java
# - Downloading alice-and-bob-playing-flower-game
#   ✔ Accepted
#   ✔ 537/537 cases passed (4 ms)
#   ✔ Your runtime beats 0.57 % of java submissions
#   ✔ Your memory usage beats 97.71 % of java submissions (41.9 MB)
# Submitting: java_solutions/3022.minimize-or-of-remaining-elements-using-operations.java
# - Downloading minimize-or-of-remaining-elements-using-operations
#   ✔ Accepted
#   ✔ 822/822 cases passed (172 ms)
#   ✔ Your runtime beats 8.7 % of java submissions
#   ✔ Your memory usage beats 21.74 % of java submissions (76.4 MB)
# Submitting: java_solutions/3024.type-of-triangle.java
# - Downloading type-of-triangle
#   ✔ Accepted
#   ✔ 705/705 cases passed (13 ms)
#   ✔ Your runtime beats 0.62 % of java submissions
#   ✔ Your memory usage beats 9.17 % of java submissions (44.1 MB)
# Submitting: java_solutions/3025.find-the-number-of-ways-to-place-people-i.java
# - Downloading find-the-number-of-ways-to-place-people-i
#   ✔ Accepted
#   ✔ 955/955 cases passed (8 ms)
#   ✔ Your runtime beats 59.22 % of java submissions
#   ✔ Your memory usage beats 31.07 % of java submissions (46.7 MB)
# Submitting: java_solutions/3026.maximum-good-subarray-sum.java
# - Downloading maximum-good-subarray-sum
#   ✔ Accepted
#   ✔ 783/783 cases passed (192 ms)
#   ✔ Your runtime beats 5.35 % of java submissions
#   ✔ Your memory usage beats 5.03 % of java submissions (277.2 MB)
# Submitting: java_solutions/3027.find-the-number-of-ways-to-place-people-ii.java
# - Downloading find-the-number-of-ways-to-place-people-ii
#   ✔ Accepted
#   ✔ 551/551 cases passed (1323 ms)
#   ✔ Your runtime beats 6.38 % of java submissions
#   ✔ Your memory usage beats 6.38 % of java submissions (53.7 MB)
# Submitting: java_solutions/3028.ant-on-the-boundary.java
# - Downloading ant-on-the-boundary
#   ✔ Accepted
#   ✔ 641/641 cases passed (4 ms)
#   ✔ Your runtime beats 0.68 % of java submissions
#   ✔ Your memory usage beats 96.75 % of java submissions (43.5 MB)
# Submitting: java_solutions/3029.minimum-time-to-revert-word-to-initial-state-i.java
# - Downloading minimum-time-to-revert-word-to-initial-state-i
#   ✔ Accepted
#   ✔ 769/769 cases passed (4 ms)
#   ✔ Your runtime beats 4.35 % of java submissions
#   ✔ Your memory usage beats 11.59 % of java submissions (45.1 MB)
# Submitting: java_solutions/3030.find-the-grid-of-region-average.java
# - Downloading find-the-grid-of-region-average
#   ✔ Accepted
#   ✔ 810/810 cases passed (175 ms)
#   ✔ Your runtime beats 20 % of java submissions
#   ✔ Your memory usage beats 22.22 % of java submissions (135.2 MB)
# Submitting: java_solutions/3031.minimum-time-to-revert-word-to-initial-state-ii.java
# - Downloading minimum-time-to-revert-word-to-initial-state-ii
#   ✔ Accepted
#   ✔ 911/911 cases passed (1223 ms)
#   ✔ Your runtime beats 7.32 % of java submissions
#   ✔ Your memory usage beats 24.39 % of java submissions (84.9 MB)
# Submitting: java_solutions/3033.modify-the-matrix.java
# - Downloading modify-the-matrix
#   ✔ Accepted
#   ✔ 514/514 cases passed (13 ms)
#   ✔ Your runtime beats 0.62 % of java submissions
#   ✔ Your memory usage beats 13.26 % of java submissions (47.6 MB)
# Submitting: java_solutions/3034.number-of-subarrays-that-match-a-pattern-i.java
# - Downloading number-of-subarrays-that-match-a-pattern-i
#   ✔ Accepted
#   ✔ 792/792 cases passed (6 ms)
#   ✔ Your runtime beats 2.64 % of java submissions
#   ✔ Your memory usage beats 83.7 % of java submissions (46.2 MB)
# Submitting: java_solutions/3035.maximum-palindromes-after-operations.java
# - Downloading maximum-palindromes-after-operations
#   ✔ Accepted
#   ✔ 507/507 cases passed (21 ms)
#   ✔ Your runtime beats 33.74 % of java submissions
#   ✔ Your memory usage beats 100 % of java submissions (45.4 MB)
# Submitting: java_solutions/3036.number-of-subarrays-that-match-a-pattern-ii.java
# - Downloading number-of-subarrays-that-match-a-pattern-ii
#   ✔ Accepted
#   ✔ 792/792 cases passed (430 ms)
#   ✔ Your runtime beats 6.76 % of java submissions
#   ✔ Your memory usage beats 5.4 % of java submissions (255.2 MB)
# Submitting: java_solutions/3038.maximum-number-of-operations-with-the-same-score-i.java
# - Downloading maximum-number-of-operations-with-the-same-score-i
#   ✔ Accepted
#   ✔ 559/559 cases passed (4 ms)
#   ✔ Your runtime beats 2.62 % of java submissions
#   ✔ Your memory usage beats 78.01 % of java submissions (43.5 MB)
# Submitting: java_solutions/3039.apply-operations-to-make-string-empty.java
# - Downloading apply-operations-to-make-string-empty
#   ✔ Accepted
#   ✔ 697/697 cases passed (188 ms)
#   ✔ Your runtime beats 8.65 % of java submissions
#   ✔ Your memory usage beats 75 % of java submissions (51 MB)
# Submitting: java_solutions/3040.maximum-number-of-operations-with-the-same-score-ii.java
# - Downloading maximum-number-of-operations-with-the-same-score-ii
#   ✔ Accepted
#   ✔ 549/549 cases passed (295 ms)
#   ✔ Your runtime beats 17.86 % of java submissions
#   ✔ Your memory usage beats 46.43 % of java submissions (275.1 MB)
# Submitting: java_solutions/3041.maximize-consecutive-elements-in-an-array-after-modification.java
# - Downloading maximize-consecutive-elements-in-an-array-after-modification
#   ✔ Accepted
#   ✔ 668/668 cases passed (161 ms)
#   ✔ Your runtime beats 11.27 % of java submissions
#   ✔ Your memory usage beats 15.49 % of java submissions (123.9 MB)
# Submitting: java_solutions/3042.count-prefix-and-suffix-pairs-i.java
# - Downloading count-prefix-and-suffix-pairs-i
#   ✔ Accepted
#   ✔ 594/594 cases passed (5 ms)
#   ✔ Your runtime beats 6.14 % of java submissions
#   ✔ Your memory usage beats 26.47 % of java submissions (44.2 MB)
# Submitting: java_solutions/3043.find-the-length-of-the-longest-common-prefix.java
# - Downloading find-the-length-of-the-longest-common-prefix
#   ✔ Accepted
#   ✔ 718/718 cases passed (852 ms)
#   ✔ Your runtime beats 5.12 % of java submissions
#   ✔ Your memory usage beats 5.26 % of java submissions (270 MB)
# Submitting: java_solutions/3044.most-frequent-prime.java
# - Downloading most-frequent-prime
#   ✔ Accepted
#   ✔ 974/974 cases passed (50 ms)
#   ✔ Your runtime beats 38.46 % of java submissions
#   ✔ Your memory usage beats 48.08 % of java submissions (46.8 MB)
# Submitting: java_solutions/3045.count-prefix-and-suffix-pairs-ii.java
# - Downloading count-prefix-and-suffix-pairs-ii
#   ✔ Accepted
#   ✔ 598/598 cases passed (327 ms)
#   ✔ Your runtime beats 8.13 % of java submissions
#   ✔ Your memory usage beats 5 % of java submissions (288.3 MB)
# Submitting: java_solutions/3046.split-the-array.java
# - Downloading split-the-array
#   ✔ Accepted
#   ✔ 715/715 cases passed (5 ms)
#   ✔ Your runtime beats 11.37 % of java submissions
#   ✔ Your memory usage beats 10.1 % of java submissions (45 MB)
# Submitting: java_solutions/3047.find-the-largest-area-of-square-inside-two-rectangles.java
# - Downloading find-the-largest-area-of-square-inside-two-rectangles
#   ✔ Accepted
#   ✔ 661/661 cases passed (124 ms)
#   ✔ Your runtime beats 6.45 % of java submissions
#   ✔ Your memory usage beats 99.6 % of java submissions (46.9 MB)
# Submitting: java_solutions/3048.earliest-second-to-mark-indices-i.java
# - Downloading earliest-second-to-mark-indices-i
#   ✔ Accepted
#   ✔ 570/570 cases passed (8 ms)
#   ✔ Your runtime beats 41.51 % of java submissions
#   ✔ Your memory usage beats 15.09 % of java submissions (47.4 MB)
# Submitting: java_solutions/3049.earliest-second-to-mark-indices-ii.java
# - Downloading earliest-second-to-mark-indices-ii
#   ✔ Accepted
#   ✔ 510/510 cases passed (67 ms)
#   ✔ Your runtime beats 8.33 % of java submissions
#   ✔ Your memory usage beats 6.67 % of java submissions (53.7 MB)
# Submitting: java_solutions/3065.minimum-operations-to-exceed-threshold-value-i.java
# - Downloading minimum-operations-to-exceed-threshold-value-i
#   ✔ Accepted
#   ✔ 724/724 cases passed (4 ms)
#   ✔ Your runtime beats 13.3 % of java submissions
#   ✔ Your memory usage beats 11.65 % of java submissions (45.1 MB)
# Submitting: java_solutions/3066.minimum-operations-to-exceed-threshold-value-ii.java
# - Downloading minimum-operations-to-exceed-threshold-value-ii
#   ✔ Accepted
#   ✔ 677/677 cases passed (167 ms)
#   ✔ Your runtime beats 51.53 % of java submissions
#   ✔ Your memory usage beats 20.09 % of java submissions (93.4 MB)
# Submitting: java_solutions/3067.count-pairs-of-connectable-servers-in-a-weighted-tree-network.java
# - Downloading count-pairs-of-connectable-servers-in-a-weighted-tree-network
#   ✔ Accepted
#   ✔ 716/716 cases passed (123 ms)
#   ✔ Your runtime beats 90.32 % of java submissions
#   ✔ Your memory usage beats 11.29 % of java submissions (48.2 MB)
# Submitting: java_solutions/3068.find-the-maximum-sum-of-node-values.java
# - Downloading find-the-maximum-sum-of-node-values
#   ✔ Accepted
#   ✔ 718/718 cases passed (8 ms)
#   ✔ Your runtime beats 46.99 % of java submissions
#   ✔ Your memory usage beats 30.12 % of java submissions (57.7 MB)
# Submitting: java_solutions/3069.distribute-elements-into-two-arrays-i.java
# - Downloading distribute-elements-into-two-arrays-i
#   ✔ Accepted
#   ✔ 622/622 cases passed (5 ms)
#   ✔ Your runtime beats 6.85 % of java submissions
#   ✔ Your memory usage beats 9.52 % of java submissions (47.1 MB)
# Submitting: java_solutions/3070.count-submatrices-with-top-left-element-and-sum-less-than-k.java
# - Downloading count-submatrices-with-top-left-element-and-sum-less-than-k
#   ✔ Accepted
#   ✔ 859/859 cases passed (16 ms)
#   ✔ Your runtime beats 9.16 % of java submissions
#   ✔ Your memory usage beats 99.74 % of java submissions (158.1 MB)
# Submitting: java_solutions/3071.minimum-operations-to-write-the-letter-y-on-a-grid.java
# - Downloading minimum-operations-to-write-the-letter-y-on-a-grid
#   ✔ Accepted
#   ✔ 909/909 cases passed (8 ms)
#   ✔ Your runtime beats 30.96 % of java submissions
#   ✔ Your memory usage beats 8.79 % of java submissions (47.4 MB)
# Submitting: java_solutions/3072.distribute-elements-into-two-arrays-ii.java
# - Downloading distribute-elements-into-two-arrays-ii
#   ✔ Accepted
#   ✔ 785/785 cases passed (1556 ms)
#   ✔ Your runtime beats 5.4 % of java submissions
#   ✔ Your memory usage beats 52.7 % of java submissions (139 MB)
# Submitting: java_solutions/3074.apple-redistribution-into-boxes.java
# - Downloading apple-redistribution-into-boxes
#   ✔ Accepted
#   ✔ 565/565 cases passed (4 ms)
#   ✔ Your runtime beats 84.24 % of java submissions
#   ✔ Your memory usage beats 51.48 % of java submissions (44.5 MB)
# Submitting: java_solutions/3075.maximize-happiness-of-selected-children.java
# - Downloading maximize-happiness-of-selected-children
#   ✔ Accepted
#   ✔ 674/674 cases passed (33 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 99.74 % of java submissions (106.7 MB)
# Submitting: java_solutions/3076.shortest-uncommon-substring-in-an-array.java
# - Downloading shortest-uncommon-substring-in-an-array
#   ✔ Accepted
#   ✔ 631/631 cases passed (69 ms)
#   ✔ Your runtime beats 71.32 % of java submissions
#   ✔ Your memory usage beats 70.03 % of java submissions (47.7 MB)
# Submitting: java_solutions/3077.maximum-strength-of-k-disjoint-subarrays.java
# - Downloading maximum-strength-of-k-disjoint-subarrays
#   ✔ Accepted
#   ✔ 802/802 cases passed (105 ms)
#   ✔ Your runtime beats 34.78 % of java submissions
#   ✔ Your memory usage beats 41.3 % of java submissions (105.8 MB)
# Submitting: java_solutions/3079.find-the-sum-of-encrypted-integers.java
# - Downloading find-the-sum-of-encrypted-integers
#   ✔ Accepted
#   ✔ 865/865 cases passed (4 ms)
#   ✔ Your runtime beats 12.43 % of java submissions
#   ✔ Your memory usage beats 22.16 % of java submissions (45 MB)
# Submitting: java_solutions/3080.mark-elements-on-array-by-performing-queries.java
# - Downloading mark-elements-on-array-by-performing-queries
#   ✔ Accepted
#   ✔ 661/661 cases passed (123 ms)
#   ✔ Your runtime beats 87.65 % of java submissions
#   ✔ Your memory usage beats 92.59 % of java submissions (153 MB)
# Submitting: java_solutions/3081.replace-question-marks-in-string-to-minimize-its-value.java
# - Downloading replace-question-marks-in-string-to-minimize-its-value
#   ✔ Accepted
#   ✔ 548/548 cases passed (40 ms)
#   ✔ Your runtime beats 87.72 % of java submissions
#   ✔ Your memory usage beats 84.21 % of java submissions (48.1 MB)
# Submitting: java_solutions/3082.find-the-sum-of-the-power-of-all-subsequences.java
# - Downloading find-the-sum-of-the-power-of-all-subsequences
#   ✔ Accepted
#   ✔ 577/577 cases passed (152 ms)
#   ✔ Your runtime beats 11.9 % of java submissions
#   ✔ Your memory usage beats 35.71 % of java submissions (53.1 MB)
# Submitting: java_solutions/3083.existence-of-a-substring-in-a-string-and-its-reverse.java
# - Downloading existence-of-a-substring-in-a-string-and-its-reverse
#   ✔ Accepted
#   ✔ 719/719 cases passed (7 ms)
#   ✔ Your runtime beats 7.81 % of java submissions
#   ✔ Your memory usage beats 28.62 % of java submissions (44.5 MB)
# Submitting: java_solutions/3084.count-substrings-starting-and-ending-with-given-character.java
# - Downloading count-substrings-starting-and-ending-with-given-character
#   ✔ Accepted
#   ✔ 669/669 cases passed (5 ms)
#   ✔ Your runtime beats 6.31 % of java submissions
#   ✔ Your memory usage beats 5.83 % of java submissions (47.1 MB)
# Submitting: java_solutions/3085.minimum-deletions-to-make-string-k-special.java
# - Downloading minimum-deletions-to-make-string-k-special
#   ✔ Accepted
#   ✔ 732/732 cases passed (10 ms)
#   ✔ Your runtime beats 42.34 % of java submissions
#   ✔ Your memory usage beats 95.5 % of java submissions (47.5 MB)
# Submitting: java_solutions/3086.minimum-moves-to-pick-k-ones.java
# - Downloading minimum-moves-to-pick-k-ones
#   ✔ Accepted
#   ✔ 825/825 cases passed (31 ms)
#   ✔ Your runtime beats 26.09 % of java submissions
#   ✔ Your memory usage beats 34.78 % of java submissions (83.6 MB)
# Submitting: java_solutions/3090.maximum-length-substring-with-two-occurrences.java
# - Downloading maximum-length-substring-with-two-occurrences
#   ✔ Accepted
#   ✔ 709/709 cases passed (3 ms)
#   ✔ Your runtime beats 42.64 % of java submissions
#   ✔ Your memory usage beats 39.59 % of java submissions (43.9 MB)
# Submitting: java_solutions/3091.apply-operations-to-make-sum-of-array-greater-than-or-equal-to-k.java
# - Downloading apply-operations-to-make-sum-of-array-greater-than-or-equal-to-k
#   ✔ Accepted
#   ✔ 658/658 cases passed (6 ms)
#   ✔ Your runtime beats 20.21 % of java submissions
#   ✔ Your memory usage beats 87.23 % of java submissions (42.3 MB)
# Submitting: java_solutions/3092.most-frequent-ids.java
# - Downloading most-frequent-ids
#   ✔ Accepted
#   ✔ 623/623 cases passed (155 ms)
#   ✔ Your runtime beats 30.25 % of java submissions
#   ✔ Your memory usage beats 100 % of java submissions (146.6 MB)
# Submitting: java_solutions/3093.longest-common-suffix-queries.java
# - Downloading longest-common-suffix-queries
#   ✔ Accepted
#   ✔ 817/817 cases passed (519 ms)
#   ✔ Your runtime beats 5.13 % of java submissions
#   ✔ Your memory usage beats 5.13 % of java submissions (289.1 MB)
# Submitting: java_solutions/3095.shortest-subarray-with-or-at-least-k-i.java
# - Downloading shortest-subarray-with-or-at-least-k-i
#   ✔ Accepted
#   ✔ 834/834 cases passed (4 ms)
#   ✔ Your runtime beats 2.87 % of java submissions
#   ✔ Your memory usage beats 7.79 % of java submissions (44.4 MB)
# Submitting: java_solutions/3096.minimum-levels-to-gain-more-points.java
# - Downloading minimum-levels-to-gain-more-points
#   ✔ Accepted
#   ✔ 855/855 cases passed (54 ms)
#   ✔ Your runtime beats 5.07 % of java submissions
#   ✔ Your memory usage beats 7.25 % of java submissions (169.9 MB)
# Submitting: java_solutions/3097.shortest-subarray-with-or-at-least-k-ii.java
# - Downloading shortest-subarray-with-or-at-least-k-ii
#   ✔ Accepted
#   ✔ 718/718 cases passed (113 ms)
#   ✔ Your runtime beats 14.03 % of java submissions
#   ✔ Your memory usage beats 100 % of java submissions (84.4 MB)
# Submitting: java_solutions/3098.find-the-sum-of-subsequence-powers.java
# - Downloading find-the-sum-of-subsequence-powers
#   ✔ Accepted
#   ✔ 549/549 cases passed (902 ms)
#   ✔ Your runtime beats 44.83 % of java submissions
#   ✔ Your memory usage beats 62.07 % of java submissions (53.9 MB)
# Submitting: java_solutions/3099.harshad-number.java
# - Downloading harshad-number
#   ✔ Accepted
#   ✔ 100/100 cases passed (2 ms)
#   ✔ Your runtime beats 0.9 % of java submissions
#   ✔ Your memory usage beats 8.26 % of java submissions (42.4 MB)
# Submitting: java_solutions/3100.water-bottles-ii.java
# - Downloading water-bottles-ii
#   ✔ Accepted
#   ✔ 958/958 cases passed (4 ms)
#   ✔ Your runtime beats 2.87 % of java submissions
#   ✔ Your memory usage beats 9.43 % of java submissions (43.1 MB)
# Submitting: java_solutions/3101.count-alternating-subarrays.java
# - Downloading count-alternating-subarrays
#   ✔ Accepted
#   ✔ 789/789 cases passed (9 ms)
#   ✔ Your runtime beats 6.06 % of java submissions
#   ✔ Your memory usage beats 60.1 % of java submissions (90.1 MB)
# Submitting: java_solutions/3102.minimize-manhattan-distances.java
# - Downloading minimize-manhattan-distances
#   ✔ Accepted
#   ✔ 537/537 cases passed (119 ms)
#   ✔ Your runtime beats 24.39 % of java submissions
#   ✔ Your memory usage beats 48.78 % of java submissions (134.7 MB)
# Submitting: java_solutions/3105.longest-strictly-increasing-or-strictly-decreasing-subarray.java
# - Downloading longest-strictly-increasing-or-strictly-decreasing-subarray
#   ✔ Accepted
#   ✔ 868/868 cases passed (5 ms)
#   ✔ Your runtime beats 4.48 % of java submissions
#   ✔ Your memory usage beats 17.37 % of java submissions (44.7 MB)
# Submitting: java_solutions/3106.lexicographically-smallest-string-after-operations-with-constraint.java
# - Downloading lexicographically-smallest-string-after-operations-with-constraint
#   ✔ Accepted
#   ✔ 600/600 cases passed (4 ms)
#   ✔ Your runtime beats 3.64 % of java submissions
#   ✔ Your memory usage beats 18.18 % of java submissions (44.3 MB)
# Submitting: java_solutions/3107.minimum-operations-to-make-median-of-array-equal-to-k.java
# - Downloading minimum-operations-to-make-median-of-array-equal-to-k
#   ✔ Accepted
#   ✔ 723/723 cases passed (29 ms)
#   ✔ Your runtime beats 99.22 % of java submissions
#   ✔ Your memory usage beats 99.22 % of java submissions (93.1 MB)
# Submitting: java_solutions/3108.minimum-cost-walk-in-weighted-graph.java
# - Downloading minimum-cost-walk-in-weighted-graph
#   ✔ Accepted
#   ✔ 549/549 cases passed (79 ms)
#   ✔ Your runtime beats 5.05 % of java submissions
#   ✔ Your memory usage beats 97.47 % of java submissions (208.2 MB)
# Submitting: java_solutions/3110.score-of-a-string.java
# - Downloading score-of-a-string
#   ✔ Accepted
#   ✔ 705/705 cases passed (7 ms)
#   ✔ Your runtime beats 1.2 % of java submissions
#   ✔ Your memory usage beats 5.71 % of java submissions (43.8 MB)
# Submitting: java_solutions/3111.minimum-rectangles-to-cover-points.java
# - Downloading minimum-rectangles-to-cover-points
#   ✔ Accepted
#   ✔ 966/966 cases passed (31 ms)
#   ✔ Your runtime beats 5.97 % of java submissions
#   ✔ Your memory usage beats 14.18 % of java submissions (124.7 MB)
# Submitting: java_solutions/3112.minimum-time-to-visit-disappearing-nodes.java
# - Downloading minimum-time-to-visit-disappearing-nodes
#   ✔ Accepted
#   ✔ 534/534 cases passed (80 ms)
#   ✔ Your runtime beats 42.35 % of java submissions
#   ✔ Your memory usage beats 49.41 % of java submissions (203.1 MB)
# Submitting: java_solutions/3113.find-the-number-of-subarrays-where-boundary-elements-are-maximum.java
# - Downloading find-the-number-of-subarrays-where-boundary-elements-are-maximum
#   ✔ Accepted
#   ✔ 890/890 cases passed (146 ms)
#   ✔ Your runtime beats 12.66 % of java submissions
#   ✔ Your memory usage beats 50.63 % of java submissions (104.1 MB)
# Submitting: java_solutions/3114.latest-time-you-can-obtain-after-replacing-characters.java
# - Downloading latest-time-you-can-obtain-after-replacing-characters
#   ✔ Accepted
#   ✔ 908/908 cases passed (4 ms)
#   ✔ Your runtime beats 13.33 % of java submissions
#   ✔ Your memory usage beats 15 % of java submissions (44.7 MB)
# Submitting: java_solutions/3115.maximum-prime-difference.java
# - Downloading maximum-prime-difference
#   ✔ Accepted
#   ✔ 904/904 cases passed (9 ms)
#   ✔ Your runtime beats 52.82 % of java submissions
#   ✔ Your memory usage beats 22.31 % of java submissions (117.3 MB)
# Submitting: java_solutions/3116.kth-smallest-amount-with-single-denomination-combination.java
# - Downloading kth-smallest-amount-with-single-denomination-combination
#   ✔ Accepted
#   ✔ 561/561 cases passed (107 ms)
#   ✔ Your runtime beats 41.82 % of java submissions
#   ✔ Your memory usage beats 5.45 % of java submissions (53.5 MB)
# Submitting: java_solutions/3117.minimum-sum-of-values-by-dividing-array.java
# - Downloading minimum-sum-of-values-by-dividing-array
#   ✔ Accepted
#   ✔ 512/512 cases passed (765 ms)
#   ✔ Your runtime beats 23.68 % of java submissions
#   ✔ Your memory usage beats 94.74 % of java submissions (54.3 MB)
# Submitting: java_solutions/3120.count-the-number-of-special-characters-i.java
# - Downloading count-the-number-of-special-characters-i
#   ✔ Accepted
#   ✔ 866/866 cases passed (3 ms)
#   ✔ Your runtime beats 34.3 % of java submissions
#   ✔ Your memory usage beats 6.35 % of java submissions (44.5 MB)
# Submitting: java_solutions/3121.count-the-number-of-special-characters-ii.java
# - Downloading count-the-number-of-special-characters-ii
#   ✔ Accepted
#   ✔ 896/896 cases passed (13 ms)
#   ✔ Your runtime beats 74.69 % of java submissions
#   ✔ Your memory usage beats 53.06 % of java submissions (48.1 MB)
# Submitting: java_solutions/3122.minimum-number-of-operations-to-satisfy-conditions.java
# - Downloading minimum-number-of-operations-to-satisfy-conditions
#   ✔ Accepted
#   ✔ 658/658 cases passed (30 ms)
#   ✔ Your runtime beats 41.46 % of java submissions
#   ✔ Your memory usage beats 68.29 % of java submissions (207.3 MB)
# Submitting: java_solutions/3123.find-edges-in-shortest-paths.java
# - Downloading find-edges-in-shortest-paths
#   ✔ Accepted
#   ✔ 536/536 cases passed (709 ms)
#   ✔ Your runtime beats 8.03 % of java submissions
#   ✔ Your memory usage beats 16.96 % of java submissions (201.7 MB)
# Submitting: java_solutions/3127.make-a-square-with-the-same-color.java
# - Downloading make-a-square-with-the-same-color
#   ✔ Accepted
#   ✔ 515/515 cases passed (4 ms)
#   ✔ Your runtime beats 0.72 % of java submissions
#   ✔ Your memory usage beats 17.39 % of java submissions (44.3 MB)
# Submitting: java_solutions/3128.right-triangles.java
# - Downloading right-triangles
#   ✔ Accepted
#   ✔ 637/637 cases passed (29 ms)
#   ✔ Your runtime beats 14.58 % of java submissions
#   ✔ Your memory usage beats 93.75 % of java submissions (200 MB)
# Submitting: java_solutions/3129.find-all-possible-stable-binary-arrays-i.java
# - Downloading find-all-possible-stable-binary-arrays-i
#   ✔ Accepted
#   ✔ 670/670 cases passed (25 ms)
#   ✔ Your runtime beats 41.85 % of java submissions
#   ✔ Your memory usage beats 80.57 % of java submissions (47 MB)
# Submitting: java_solutions/3130.find-all-possible-stable-binary-arrays-ii.java
# - Downloading find-all-possible-stable-binary-arrays-ii
#   ✔ Accepted
#   ✔ 582/582 cases passed (402 ms)
#   ✔ Your runtime beats 15.09 % of java submissions
#   ✔ Your memory usage beats 5.46 % of java submissions (280.7 MB)

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-05-05 14:51:06
