# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME_2')
    user_cookie = userdata.get('LEETCODE_TOKEN_2')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME_2'] = user_name
    os.environ['LEETCODE_TOKEN_2'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME_2" "$LEETCODE_TOKEN_2" | leetcode user -c

# %%
# %%bash
#
#
# # top 100 answers
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v java_solutions/*.java | sed -n '1351,1500p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 8
# done
# Out:
# Submitting: java_solutions/2162.minimum-cost-to-set-cooking-time.java
# - Downloading problems
# - Downloading minimum-cost-to-set-cooking-time
#   ✔ Accepted
#   ✔ 239/239 cases passed (1 ms)
#   ✔ Your runtime beats 80.82 % of java submissions
#   ✔ Your memory usage beats 56.16 % of java submissions (42.3 MB)
# Submitting: java_solutions/2163.minimum-difference-in-sums-after-removal-of-elements.java
# - Downloading minimum-difference-in-sums-after-removal-of-elements
#   ✔ Accepted
#   ✔ 110/110 cases passed (553 ms)
#   ✔ Your runtime beats 5.74 % of java submissions
#   ✔ Your memory usage beats 57.42 % of java submissions (165.5 MB)
# Submitting: java_solutions/2164.sort-even-and-odd-indices-independently.java
# - Downloading sort-even-and-odd-indices-independently
#   ✔ Accepted
#   ✔ 218/218 cases passed (23 ms)
#   ✔ Your runtime beats 17.23 % of java submissions
#   ✔ Your memory usage beats 6.37 % of java submissions (53 MB)
# Submitting: java_solutions/2165.smallest-value-of-the-rearranged-number.java
# - Downloading smallest-value-of-the-rearranged-number
#   ✔ Accepted
#   ✔ 413/413 cases passed (9 ms)
#   ✔ Your runtime beats 7.39 % of java submissions
#   ✔ Your memory usage beats 6.96 % of java submissions (43.3 MB)
# Submitting: java_solutions/2166.design-bitset.java
# - Downloading design-bitset
#   ✔ Accepted
#   ✔ 48/48 cases passed (107 ms)
#   ✔ Your runtime beats 7.29 % of java submissions
#   ✔ Your memory usage beats 16.67 % of java submissions (122 MB)
# Submitting: java_solutions/2167.minimum-time-to-remove-all-cars-containing-illegal-goods.java
# - Downloading minimum-time-to-remove-all-cars-containing-illegal-goods
#   ✔ Accepted
#   ✔ 89/89 cases passed (34 ms)
#   ✔ Your runtime beats 69.64 % of java submissions
#   ✔ Your memory usage beats 83.93 % of java submissions (48.3 MB)
# Submitting: java_solutions/2169.count-operations-to-obtain-zero.java
# - Downloading count-operations-to-obtain-zero
#   ✔ Accepted
#   ✔ 161/161 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 28.48 % of java submissions (42.4 MB)
# Submitting: java_solutions/2170.minimum-operations-to-make-the-array-alternating.java
# - Downloading minimum-operations-to-make-the-array-alternating
#   ✔ Accepted
#   ✔ 153/153 cases passed (55 ms)
#   ✔ Your runtime beats 83.69 % of java submissions
#   ✔ Your memory usage beats 92.27 % of java submissions (97.4 MB)
# Submitting: java_solutions/2171.removing-minimum-number-of-magic-beans.java
# - Downloading removing-minimum-number-of-magic-beans
#   ✔ Accepted
#   ✔ 64/64 cases passed (64 ms)
#   ✔ Your runtime beats 5.17 % of java submissions
#   ✔ Your memory usage beats 98.71 % of java submissions (105.5 MB)
# Submitting: java_solutions/2172.maximum-and-sum-of-array.java
# - Downloading maximum-and-sum-of-array
#   ✔ Accepted
#   ✔ 84/84 cases passed (175 ms)
#   ✔ Your runtime beats 39.8 % of java submissions
#   ✔ Your memory usage beats 39.8 % of java submissions (53.2 MB)
# Submitting: java_solutions/2176.count-equal-and-divisible-pairs-in-an-array.java
# - Downloading count-equal-and-divisible-pairs-in-an-array
#   ✔ Accepted
#   ✔ 238/238 cases passed (25 ms)
#   ✔ Your runtime beats 2.51 % of java submissions
#   ✔ Your memory usage beats 5.4 % of java submissions (46.8 MB)
# Submitting: java_solutions/2177.find-three-consecutive-integers-that-sum-to-a-given-number.java
# - Downloading find-three-consecutive-integers-that-sum-to-a-given-number
#   ✔ Accepted
#   ✔ 379/379 cases passed (3 ms)
#   ✔ Your runtime beats 0.57 % of java submissions
#   ✔ Your memory usage beats 65.46 % of java submissions (43 MB)
# Submitting: java_solutions/2178.maximum-split-of-positive-even-integers.java
# - Downloading maximum-split-of-positive-even-integers
#   ✔ Accepted
#   ✔ 56/56 cases passed (15 ms)
#   ✔ Your runtime beats 12.94 % of java submissions
#   ✔ Your memory usage beats 99.41 % of java submissions (110.5 MB)
# Submitting: java_solutions/2179.count-good-triplets-in-an-array.java
# - Downloading count-good-triplets-in-an-array
#   ✔ Accepted
#   ✔ 148/148 cases passed (236 ms)
#   ✔ Your runtime beats 5.32 % of java submissions
#   ✔ Your memory usage beats 80.99 % of java submissions (87.4 MB)
# Submitting: java_solutions/2180.count-integers-with-even-digit-sum.java
# - Downloading count-integers-with-even-digit-sum
#   ✔ Accepted
#   ✔ 71/71 cases passed (13 ms)
#   ✔ Your runtime beats 2.35 % of java submissions
#   ✔ Your memory usage beats 7.49 % of java submissions (46.4 MB)
# Submitting: java_solutions/2181.merge-nodes-in-between-zeros.java
# - Downloading merge-nodes-in-between-zeros
#   ✔ Accepted
#   ✔ 39/39 cases passed (16 ms)
#   ✔ Your runtime beats 5.65 % of java submissions
#   ✔ Your memory usage beats 7.42 % of java submissions (262.6 MB)
# Submitting: java_solutions/2182.construct-string-with-repeat-limit.java
# - Downloading construct-string-with-repeat-limit
#   ✔ Accepted
#   ✔ 150/150 cases passed (25 ms)
#   ✔ Your runtime beats 60.8 % of java submissions
#   ✔ Your memory usage beats 63.52 % of java submissions (47.9 MB)
# Submitting: java_solutions/2183.count-array-pairs-divisible-by-k.java
# - Downloading count-array-pairs-divisible-by-k
#   ✔ Accepted
#   ✔ 115/115 cases passed (50 ms)
#   ✔ Your runtime beats 92.28 % of java submissions
#   ✔ Your memory usage beats 89.58 % of java submissions (76.9 MB)
# Submitting: java_solutions/2185.counting-words-with-a-given-prefix.java
# - Downloading counting-words-with-a-given-prefix
#   ✔ Accepted
#   ✔ 95/95 cases passed (2 ms)
#   ✔ Your runtime beats 20.85 % of java submissions
#   ✔ Your memory usage beats 30.37 % of java submissions (44.4 MB)
# Submitting: java_solutions/2186.minimum-number-of-steps-to-make-two-strings-anagram-ii.java
# - Downloading minimum-number-of-steps-to-make-two-strings-anagram-ii
#   ✔ Accepted
#   ✔ 70/70 cases passed (23 ms)
#   ✔ Your runtime beats 21.72 % of java submissions
#   ✔ Your memory usage beats 33.61 % of java submissions (49.3 MB)
# Submitting: java_solutions/2187.minimum-time-to-complete-trips.java
# - Downloading minimum-time-to-complete-trips
#   ✔ Accepted
#   ✔ 124/124 cases passed (135 ms)
#   ✔ Your runtime beats 5 % of java submissions
#   ✔ Your memory usage beats 90.95 % of java submissions (90.9 MB)
# Submitting: java_solutions/2188.minimum-time-to-finish-the-race.java
# - Downloading minimum-time-to-finish-the-race
#   ✔ Accepted
#   ✔ 58/58 cases passed (183 ms)
#   ✔ Your runtime beats 7.79 % of java submissions
#   ✔ Your memory usage beats 92.21 % of java submissions (172.8 MB)
# Submitting: java_solutions/2190.most-frequent-number-following-key-in-an-array.java
# - Downloading most-frequent-number-following-key-in-an-array
#   ✔ Accepted
#   ✔ 101/101 cases passed (6 ms)
#   ✔ Your runtime beats 6.96 % of java submissions
#   ✔ Your memory usage beats 20.43 % of java submissions (46.5 MB)
# Submitting: java_solutions/2191.sort-the-jumbled-numbers.java
# - Downloading sort-the-jumbled-numbers
#   ✔ Accepted
#   ✔ 68/68 cases passed (112 ms)
#   ✔ Your runtime beats 55.26 % of java submissions
#   ✔ Your memory usage beats 89.47 % of java submissions (62.1 MB)
# Submitting: java_solutions/2192.all-ancestors-of-a-node-in-a-directed-acyclic-graph.java
# - Downloading all-ancestors-of-a-node-in-a-directed-acyclic-graph
#   ✔ Accepted
#   ✔ 80/80 cases passed (40 ms)
#   ✔ Your runtime beats 97.39 % of java submissions
#   ✔ Your memory usage beats 67.93 % of java submissions (80.3 MB)
# Submitting: java_solutions/2193.minimum-number-of-moves-to-make-palindrome.java
# - Downloading minimum-number-of-moves-to-make-palindrome
#   ✔ Accepted
#   ✔ 129/129 cases passed (241 ms)
#   ✔ Your runtime beats 5.45 % of java submissions
#   ✔ Your memory usage beats 5.06 % of java submissions (53.3 MB)
# Submitting: java_solutions/2194.cells-in-a-range-on-an-excel-sheet.java
# - Downloading cells-in-a-range-on-an-excel-sheet
#   ✔ Accepted
#   ✔ 251/251 cases passed (13 ms)
#   ✔ Your runtime beats 5.66 % of java submissions
#   ✔ Your memory usage beats 12.83 % of java submissions (52.7 MB)
# Submitting: java_solutions/2195.append-k-integers-with-minimal-sum.java
# - Downloading append-k-integers-with-minimal-sum
#   ✔ Accepted
#   ✔ 108/108 cases passed (41 ms)
#   ✔ Your runtime beats 38.69 % of java submissions
#   ✔ Your memory usage beats 25 % of java submissions (76.6 MB)
# Submitting: java_solutions/2196.create-binary-tree-from-descriptions.java
# - Downloading create-binary-tree-from-descriptions
#   ✔ Accepted
#   ✔ 85/85 cases passed (77 ms)
#   ✔ Your runtime beats 19.12 % of java submissions
#   ✔ Your memory usage beats 5.16 % of java submissions (107.9 MB)
# Submitting: java_solutions/2197.replace-non-coprime-numbers-in-array.java
# - Downloading replace-non-coprime-numbers-in-array
#   ✔ Accepted
#   ✔ 73/73 cases passed (249 ms)
#   ✔ Your runtime beats 5.26 % of java submissions
#   ✔ Your memory usage beats 98.5 % of java submissions (115.3 MB)
# Submitting: java_solutions/2200.find-all-k-distant-indices-in-an-array.java
# - Downloading find-all-k-distant-indices-in-an-array
#   ✔ Accepted
#   ✔ 87/87 cases passed (3 ms)
#   ✔ Your runtime beats 74.6 % of java submissions
#   ✔ Your memory usage beats 83.48 % of java submissions (46.4 MB)
# Submitting: java_solutions/2201.count-artifacts-that-can-be-extracted.java
# - Downloading count-artifacts-that-can-be-extracted
#   ✔ Accepted
#   ✔ 97/97 cases passed (10 ms)
#   ✔ Your runtime beats 41.18 % of java submissions
#   ✔ Your memory usage beats 43.14 % of java submissions (165.5 MB)
# Submitting: java_solutions/2202.maximize-the-topmost-element-after-k-moves.java
# - Downloading maximize-the-topmost-element-after-k-moves
#   ✔ Accepted
#   ✔ 197/197 cases passed (1 ms)
#   ✔ Your runtime beats 96.2 % of java submissions
#   ✔ Your memory usage beats 64.98 % of java submissions (78.5 MB)
# Submitting: java_solutions/2203.minimum-weighted-subgraph-with-the-required-paths.java
# - Downloading minimum-weighted-subgraph-with-the-required-paths
#   ✔ Accepted
#   ✔ 88/88 cases passed (446 ms)
#   ✔ Your runtime beats 5.43 % of java submissions
#   ✔ Your memory usage beats 82.11 % of java submissions (208.8 MB)
# Submitting: java_solutions/2206.divide-array-into-equal-pairs.java
# - Downloading divide-array-into-equal-pairs
#   ✔ Accepted
#   ✔ 137/137 cases passed (22 ms)
#   ✔ Your runtime beats 6.42 % of java submissions
#   ✔ Your memory usage beats 5.43 % of java submissions (53 MB)
# Submitting: java_solutions/2207.maximize-number-of-subsequences-in-a-string.java
# - Downloading maximize-number-of-subsequences-in-a-string
#   ✔ Accepted
#   ✔ 172/172 cases passed (21 ms)
#   ✔ Your runtime beats 17.98 % of java submissions
#   ✔ Your memory usage beats 28.09 % of java submissions (47.9 MB)
# Submitting: java_solutions/2208.minimum-operations-to-halve-array-sum.java
# - Downloading minimum-operations-to-halve-array-sum
#   ✔ Accepted
#   ✔ 62/62 cases passed (294 ms)
#   ✔ Your runtime beats 30.65 % of java submissions
#   ✔ Your memory usage beats 37.44 % of java submissions (103.8 MB)
# Submitting: java_solutions/2209.minimum-white-tiles-after-covering-with-carpets.java
# - Downloading minimum-white-tiles-after-covering-with-carpets
#   ✔ Accepted
#   ✔ 2706/2706 cases passed (464 ms)
#   ✔ Your runtime beats 5.55 % of java submissions
#   ✔ Your memory usage beats 16.67 % of java submissions (58.1 MB)
# Submitting: java_solutions/2210.count-hills-and-valleys-in-an-array.java
# - Downloading count-hills-and-valleys-in-an-array
#   ✔ Accepted
#   ✔ 121/121 cases passed (7 ms)
#   ✔ Your runtime beats 2.63 % of java submissions
#   ✔ Your memory usage beats 5.02 % of java submissions (44 MB)
# Submitting: java_solutions/2211.count-collisions-on-a-road.java
# - Downloading count-collisions-on-a-road
#   ✔ Accepted
#   ✔ 120/120 cases passed (14 ms)
#   ✔ Your runtime beats 40.76 % of java submissions
#   ✔ Your memory usage beats 44.39 % of java submissions (47.8 MB)
# Submitting: java_solutions/2212.maximum-points-in-an-archery-competition.java
# - Downloading maximum-points-in-an-archery-competition
#   ✔ Accepted
#   ✔ 177/177 cases passed (49 ms)
#   ✔ Your runtime beats 8.33 % of java submissions
#   ✔ Your memory usage beats 63.33 % of java submissions (43.8 MB)
# Submitting: java_solutions/2213.longest-substring-of-one-repeating-character.java
# - Downloading longest-substring-of-one-repeating-character
#   ✔ Accepted
#   ✔ 57/57 cases passed (1027 ms)
#   ✔ Your runtime beats 5.66 % of java submissions
#   ✔ Your memory usage beats 83.02 % of java submissions (133.4 MB)
# Submitting: java_solutions/2215.find-the-difference-of-two-arrays.java
# - Downloading find-the-difference-of-two-arrays
#   ✔ Accepted
#   ✔ 202/202 cases passed (19 ms)
#   ✔ Your runtime beats 12.51 % of java submissions
#   ✔ Your memory usage beats 56.14 % of java submissions (47.5 MB)
# Submitting: java_solutions/2216.minimum-deletions-to-make-array-beautiful.java
# - Downloading minimum-deletions-to-make-array-beautiful
#   ✔ Accepted
#   ✔ 114/114 cases passed (6 ms)
#   ✔ Your runtime beats 24.32 % of java submissions
#   ✔ Your memory usage beats 54.6 % of java submissions (113.3 MB)
# Submitting: java_solutions/2217.find-palindrome-with-fixed-length.java
# - Downloading find-palindrome-with-fixed-length
#   ✔ Accepted
#   ✔ 162/162 cases passed (65 ms)
#   ✔ Your runtime beats 18.45 % of java submissions
#   ✔ Your memory usage beats 5.83 % of java submissions (75.6 MB)
# Submitting: java_solutions/2218.maximum-value-of-k-coins-from-piles.java
# - Downloading maximum-value-of-k-coins-from-piles
#   ✔ Accepted
#   ✔ 123/123 cases passed (992 ms)
#   ✔ Your runtime beats 5.26 % of java submissions
#   ✔ Your memory usage beats 79.65 % of java submissions (53.1 MB)
# Submitting: java_solutions/2220.minimum-bit-flips-to-convert-number.java
# - Downloading minimum-bit-flips-to-convert-number
#   ✔ Accepted
#   ✔ 250/250 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 5.81 % of java submissions (42.5 MB)
# Submitting: java_solutions/2221.find-triangular-sum-of-an-array.java
# - Downloading find-triangular-sum-of-an-array
#   ✔ Accepted
#   ✔ 300/300 cases passed (53 ms)
#   ✔ Your runtime beats 24.97 % of java submissions
#   ✔ Your memory usage beats 97.54 % of java submissions (46.1 MB)
# Submitting: java_solutions/2222.number-of-ways-to-select-buildings.java
# - Downloading number-of-ways-to-select-buildings
#   ✔ Accepted
#   ✔ 108/108 cases passed (31 ms)
#   ✔ Your runtime beats 57.02 % of java submissions
#   ✔ Your memory usage beats 80.7 % of java submissions (47.7 MB)
# Submitting: java_solutions/2223.sum-of-scores-of-built-strings.java
# - Downloading sum-of-scores-of-built-strings
#   ✔ Accepted
#   ✔ 150/150 cases passed (262 ms)
#   ✔ Your runtime beats 5.06 % of java submissions
#   ✔ Your memory usage beats 5.06 % of java submissions (60.9 MB)
# Submitting: java_solutions/2224.minimum-number-of-operations-to-convert-time.java
# - Downloading minimum-number-of-operations-to-convert-time
#   ✔ Accepted
#   ✔ 256/256 cases passed (1 ms)
#   ✔ Your runtime beats 81.22 % of java submissions
#   ✔ Your memory usage beats 13.06 % of java submissions (43.5 MB)
# Submitting: java_solutions/2225.find-players-with-zero-or-one-losses.java
# - Downloading find-players-with-zero-or-one-losses
#   ✔ Accepted
#   ✔ 127/127 cases passed (47 ms)
#   ✔ Your runtime beats 89.79 % of java submissions
#   ✔ Your memory usage beats 91.34 % of java submissions (148.5 MB)
# Submitting: java_solutions/2226.maximum-candies-allocated-to-k-children.java
# - Downloading maximum-candies-allocated-to-k-children
#   ✔ Accepted
#   ✔ 101/101 cases passed (95 ms)
#   ✔ Your runtime beats 5.51 % of java submissions
#   ✔ Your memory usage beats 28.56 % of java submissions (92.2 MB)
# Submitting: java_solutions/2227.encrypt-and-decrypt-strings.java
# - Downloading encrypt-and-decrypt-strings
#   ✔ Accepted
#   ✔ 211/211 cases passed (295 ms)
#   ✔ Your runtime beats 16.55 % of java submissions
#   ✔ Your memory usage beats 15.11 % of java submissions (55.9 MB)
# Submitting: java_solutions/2231.largest-number-after-digit-swaps-by-parity.java
# - Downloading largest-number-after-digit-swaps-by-parity
#   ✔ Accepted
#   ✔ 238/238 cases passed (17 ms)
#   ✔ Your runtime beats 6.64 % of java submissions
#   ✔ Your memory usage beats 8.73 % of java submissions (43.9 MB)
# Submitting: java_solutions/2232.minimize-result-by-adding-parentheses-to-expression.java
# - Downloading minimize-result-by-adding-parentheses-to-expression
#   ✔ Accepted
#   ✔ 124/124 cases passed (7 ms)
#   ✔ Your runtime beats 11.54 % of java submissions
#   ✔ Your memory usage beats 5.77 % of java submissions (49.3 MB)
# Submitting: java_solutions/2233.maximum-product-after-k-increments.java
# - Downloading maximum-product-after-k-increments
#   ✔ Accepted
#   ✔ 73/73 cases passed (341 ms)
#   ✔ Your runtime beats 15.64 % of java submissions
#   ✔ Your memory usage beats 11.23 % of java submissions (91.8 MB)
# Submitting: java_solutions/2234.maximum-total-beauty-of-the-gardens.java
# - Downloading maximum-total-beauty-of-the-gardens
#   ✔ Accepted
#   ✔ 77/77 cases passed (221 ms)
#   ✔ Your runtime beats 42 % of java submissions
#   ✔ Your memory usage beats 6 % of java submissions (106 MB)
# Submitting: java_solutions/2235.add-two-integers.java
# - Downloading add-two-integers
#   ✔ Accepted
#   ✔ 262/262 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 98.25 % of java submissions (41.8 MB)
# Submitting: java_solutions/2236.root-equals-sum-of-children.java
# - Downloading root-equals-sum-of-children
#   ✔ Accepted
#   ✔ 309/309 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 46.27 % of java submissions (43.1 MB)
# Submitting: java_solutions/2239.find-closest-number-to-zero.java
# - Downloading find-closest-number-to-zero
#   ✔ Accepted
#   ✔ 227/227 cases passed (4 ms)
#   ✔ Your runtime beats 8.18 % of java submissions
#   ✔ Your memory usage beats 40.65 % of java submissions (46.9 MB)
# Submitting: java_solutions/2240.number-of-ways-to-buy-pens-and-pencils.java
# - Downloading number-of-ways-to-buy-pens-and-pencils
#   ✔ Accepted
#   ✔ 145/145 cases passed (29 ms)
#   ✔ Your runtime beats 6.19 % of java submissions
#   ✔ Your memory usage beats 7.96 % of java submissions (42.6 MB)
# Submitting: java_solutions/2241.design-an-atm-machine.java
# - Downloading design-an-atm-machine
#   ✔ Accepted
#   ✔ 111/111 cases passed (65 ms)
#   ✔ Your runtime beats 7 % of java submissions
#   ✔ Your memory usage beats 43 % of java submissions (51 MB)
# Submitting: java_solutions/2242.maximum-score-of-a-node-sequence.java
# - Downloading maximum-score-of-a-node-sequence
#   ✔ Accepted
#   ✔ 75/75 cases passed (232 ms)
#   ✔ Your runtime beats 5.1 % of java submissions
#   ✔ Your memory usage beats 85.71 % of java submissions (127.7 MB)
# Submitting: java_solutions/2243.calculate-digit-sum-of-a-string.java
# - Downloading calculate-digit-sum-of-a-string
#   ✔ Accepted
#   ✔ 121/121 cases passed (15 ms)
#   ✔ Your runtime beats 5.92 % of java submissions
#   ✔ Your memory usage beats 5.03 % of java submissions (44.1 MB)
# Submitting: java_solutions/2244.minimum-rounds-to-complete-all-tasks.java
# - Downloading minimum-rounds-to-complete-all-tasks
#   ✔ Accepted
#   ✔ 79/79 cases passed (29 ms)
#   ✔ Your runtime beats 91.3 % of java submissions
#   ✔ Your memory usage beats 91.88 % of java submissions (106.8 MB)
# Submitting: java_solutions/2245.maximum-trailing-zeros-in-a-cornered-path.java
# - Downloading maximum-trailing-zeros-in-a-cornered-path
#   ✔ Accepted
#   ✔ 55/55 cases passed (147 ms)
#   ✔ Your runtime beats 11.76 % of java submissions
#   ✔ Your memory usage beats 47.06 % of java submissions (145.8 MB)
# Submitting: java_solutions/2246.longest-path-with-different-adjacent-characters.java
# - Downloading longest-path-with-different-adjacent-characters
#   ✔ Accepted
#   ✔ 142/142 cases passed (80 ms)
#   ✔ Your runtime beats 80.73 % of java submissions
#   ✔ Your memory usage beats 99.27 % of java submissions (103.2 MB)
# Submitting: java_solutions/2248.intersection-of-multiple-arrays.java
# - Downloading intersection-of-multiple-arrays
#   ✔ Accepted
#   ✔ 151/151 cases passed (25 ms)
#   ✔ Your runtime beats 5.33 % of java submissions
#   ✔ Your memory usage beats 6.78 % of java submissions (53.4 MB)
# Submitting: java_solutions/2249.count-lattice-points-inside-a-circle.java
# - Downloading count-lattice-points-inside-a-circle
#   ✔ Accepted
#   ✔ 60/60 cases passed (43 ms)
#   ✔ Your runtime beats 93.97 % of java submissions
#   ✔ Your memory usage beats 76.72 % of java submissions (46.9 MB)
# Submitting: java_solutions/2250.count-number-of-rectangles-containing-each-point.java
# - Downloading count-number-of-rectangles-containing-each-point
#   ✔ Accepted
#   ✔ 47/47 cases passed (361 ms)
#   ✔ Your runtime beats 26.25 % of java submissions
#   ✔ Your memory usage beats 31.25 % of java submissions (95.2 MB)
# Submitting: java_solutions/2251.number-of-flowers-in-full-bloom.java
# - Downloading number-of-flowers-in-full-bloom
#   ✔ Accepted
#   ✔ 53/53 cases passed (453 ms)
#   ✔ Your runtime beats 5.17 % of java submissions
#   ✔ Your memory usage beats 81.53 % of java submissions (108.2 MB)
# Submitting: java_solutions/2255.count-prefixes-of-a-given-string.java
# - Downloading count-prefixes-of-a-given-string
#   ✔ Accepted
#   ✔ 123/123 cases passed (2 ms)
#   ✔ Your runtime beats 14.83 % of java submissions
#   ✔ Your memory usage beats 42.58 % of java submissions (44.9 MB)
# Submitting: java_solutions/2256.minimum-average-difference.java
# - Downloading minimum-average-difference
#   ✔ Accepted
#   ✔ 78/78 cases passed (9 ms)
#   ✔ Your runtime beats 6.11 % of java submissions
#   ✔ Your memory usage beats 61.45 % of java submissions (92.7 MB)
# Submitting: java_solutions/2257.count-unguarded-cells-in-the-grid.java
# - Downloading count-unguarded-cells-in-the-grid
#   ✔ Accepted
#   ✔ 49/49 cases passed (33 ms)
#   ✔ Your runtime beats 14.39 % of java submissions
#   ✔ Your memory usage beats 31.84 % of java submissions (147.4 MB)
# Submitting: java_solutions/2258.escape-the-spreading-fire.java
# - Downloading escape-the-spreading-fire
#   ✔ Accepted
#   ✔ 57/57 cases passed (241 ms)
#   ✔ Your runtime beats 5.02 % of java submissions
#   ✔ Your memory usage beats 5.02 % of java submissions (57.1 MB)
# Submitting: java_solutions/2259.remove-digit-from-number-to-maximize-result.java
# - Downloading remove-digit-from-number-to-maximize-result
#   ✔ Accepted
#   ✔ 112/112 cases passed (10 ms)
#   ✔ Your runtime beats 5.03 % of java submissions
#   ✔ Your memory usage beats 8.96 % of java submissions (43.9 MB)
# Submitting: java_solutions/2260.minimum-consecutive-cards-to-pick-up.java
# - Downloading minimum-consecutive-cards-to-pick-up
#   ✔ Accepted
#   ✔ 80/80 cases passed (62 ms)
#   ✔ Your runtime beats 12.42 % of java submissions
#   ✔ Your memory usage beats 97.26 % of java submissions (75.8 MB)
# Submitting: java_solutions/2261.k-divisible-elements-subarrays.java
# - Downloading k-divisible-elements-subarrays
#   ✔ Accepted
#   ✔ 152/152 cases passed (209 ms)
#   ✔ Your runtime beats 24.55 % of java submissions
#   ✔ Your memory usage beats 70.91 % of java submissions (97.6 MB)
# Submitting: java_solutions/2262.total-appeal-of-a-string.java
# - Downloading total-appeal-of-a-string
#   ✔ Accepted
#   ✔ 77/77 cases passed (13 ms)
#   ✔ Your runtime beats 25.35 % of java submissions
#   ✔ Your memory usage beats 16.2 % of java submissions (47.1 MB)
# Submitting: java_solutions/2264.largest-3-same-digit-number-in-string.java
# - Downloading largest-3-same-digit-number-in-string
#   ✔ Accepted
#   ✔ 141/141 cases passed (9 ms)
#   ✔ Your runtime beats 8.66 % of java submissions
#   ✔ Your memory usage beats 40.97 % of java submissions (44.3 MB)
# Submitting: java_solutions/2265.count-nodes-equal-to-average-of-subtree.java
# - Downloading count-nodes-equal-to-average-of-subtree
#   ✔ Accepted
#   ✔ 139/139 cases passed (2 ms)
#   ✔ Your runtime beats 16.38 % of java submissions
#   ✔ Your memory usage beats 9.74 % of java submissions (46.3 MB)
# Submitting: java_solutions/2266.count-number-of-texts.java
# - Downloading count-number-of-texts
#   ✔ Accepted
#   ✔ 107/107 cases passed (37 ms)
#   ✔ Your runtime beats 41.46 % of java submissions
#   ✔ Your memory usage beats 46.34 % of java submissions (48 MB)
# Submitting: java_solutions/2267.check-if-there-is-a-valid-parentheses-string-path.java
# - Downloading check-if-there-is-a-valid-parentheses-string-path
#   ✔ Accepted
#   ✔ 81/81 cases passed (254 ms)
#   ✔ Your runtime beats 5.4 % of java submissions
#   ✔ Your memory usage beats 81.08 % of java submissions (59.5 MB)
# Submitting: java_solutions/2269.find-the-k-beauty-of-a-number.java
# - Downloading find-the-k-beauty-of-a-number
#   ✔ Accepted
#   ✔ 183/183 cases passed (7 ms)
#   ✔ Your runtime beats 4.62 % of java submissions
#   ✔ Your memory usage beats 6.97 % of java submissions (42.8 MB)
# Submitting: java_solutions/2270.number-of-ways-to-split-array.java
# - Downloading number-of-ways-to-split-array
#   ✔ Accepted
#   ✔ 104/104 cases passed (13 ms)
#   ✔ Your runtime beats 3.43 % of java submissions
#   ✔ Your memory usage beats 6.64 % of java submissions (102.4 MB)
# Submitting: java_solutions/2271.maximum-white-tiles-covered-by-a-carpet.java
# - Downloading maximum-white-tiles-covered-by-a-carpet
#   ✔ Accepted
#   ✔ 51/51 cases passed (59 ms)
#   ✔ Your runtime beats 7.79 % of java submissions
#   ✔ Your memory usage beats 94.81 % of java submissions (93.7 MB)
# Submitting: java_solutions/2272.substring-with-largest-variance.java
# - Downloading substring-with-largest-variance
#   ✔ Accepted
#   ✔ 139/139 cases passed (677 ms)
#   ✔ Your runtime beats 5.38 % of java submissions
#   ✔ Your memory usage beats 6.45 % of java submissions (53.1 MB)
# Submitting: java_solutions/2273.find-resultant-array-after-removing-anagrams.java
# - Downloading find-resultant-array-after-removing-anagrams
#   ✔ Accepted
#   ✔ 202/202 cases passed (42 ms)
#   ✔ Your runtime beats 6.65 % of java submissions
#   ✔ Your memory usage beats 7.64 % of java submissions (53.1 MB)
# Submitting: java_solutions/2274.maximum-consecutive-floors-without-special-floors.java
# - Downloading maximum-consecutive-floors-without-special-floors
#   ✔ Accepted
#   ✔ 80/80 cases passed (51 ms)
#   ✔ Your runtime beats 6.56 % of java submissions
#   ✔ Your memory usage beats 5.33 % of java submissions (84.4 MB)
# Submitting: java_solutions/2275.largest-combination-with-bitwise-and-greater-than-zero.java
# - Downloading largest-combination-with-bitwise-and-greater-than-zero
#   ✔ Accepted
#   ✔ 80/80 cases passed (49 ms)
#   ✔ Your runtime beats 8.95 % of java submissions
#   ✔ Your memory usage beats 98.95 % of java submissions (69.7 MB)
# Submitting: java_solutions/2276.count-integers-in-intervals.java
# - Downloading count-integers-in-intervals
#   ✔ Accepted
#   ✔ 73/73 cases passed (146 ms)
#   ✔ Your runtime beats 5.98 % of java submissions
#   ✔ Your memory usage beats 50.43 % of java submissions (127 MB)
# Submitting: java_solutions/2278.percentage-of-letter-in-string.java
# - Downloading percentage-of-letter-in-string
#   ✔ Accepted
#   ✔ 86/86 cases passed (3 ms)
#   ✔ Your runtime beats 2.45 % of java submissions
#   ✔ Your memory usage beats 19.3 % of java submissions (43 MB)
# Submitting: java_solutions/2279.maximum-bags-with-full-capacity-of-rocks.java
# - Downloading maximum-bags-with-full-capacity-of-rocks
#   ✔ Accepted
#   ✔ 79/79 cases passed (32 ms)
#   ✔ Your runtime beats 21.96 % of java submissions
#   ✔ Your memory usage beats 16.47 % of java submissions (68.3 MB)
# Submitting: java_solutions/2280.minimum-lines-to-represent-a-line-chart.java
# - Downloading minimum-lines-to-represent-a-line-chart
#   ✔ Accepted
#   ✔ 82/82 cases passed (53 ms)
#   ✔ Your runtime beats 6.52 % of java submissions
#   ✔ Your memory usage beats 33.7 % of java submissions (125.7 MB)
# Submitting: java_solutions/2281.sum-of-total-strength-of-wizards.java
# - Downloading sum-of-total-strength-of-wizards
#   ✔ Accepted
#   ✔ 82/82 cases passed (340 ms)
#   ✔ Your runtime beats 5.55 % of java submissions
#   ✔ Your memory usage beats 31.94 % of java submissions (108.7 MB)
# Submitting: java_solutions/2283.check-if-number-has-equal-digit-count-and-digit-value.java
# - Downloading check-if-number-has-equal-digit-count-and-digit-value
#   ✔ Accepted
#   ✔ 433/433 cases passed (9 ms)
#   ✔ Your runtime beats 4.02 % of java submissions
#   ✔ Your memory usage beats 9.14 % of java submissions (43.5 MB)
# Submitting: java_solutions/2284.sender-with-largest-word-count.java
# - Downloading sender-with-largest-word-count
#   ✔ Accepted
#   ✔ 70/70 cases passed (55 ms)
#   ✔ Your runtime beats 47.12 % of java submissions
#   ✔ Your memory usage beats 27.88 % of java submissions (58.1 MB)
# Submitting: java_solutions/2285.maximum-total-importance-of-roads.java
# - Downloading maximum-total-importance-of-roads
#   ✔ Accepted
#   ✔ 58/58 cases passed (28 ms)
#   ✔ Your runtime beats 26.05 % of java submissions
#   ✔ Your memory usage beats 24.42 % of java submissions (118.3 MB)
# Submitting: java_solutions/2286.booking-concert-tickets-in-groups.java
# - Downloading booking-concert-tickets-in-groups
#   ✔ Accepted
#   ✔ 97/97 cases passed (411 ms)
#   ✔ Your runtime beats 24 % of java submissions
#   ✔ Your memory usage beats 10 % of java submissions (137 MB)
# Submitting: java_solutions/2287.rearrange-characters-to-make-target-string.java
# - Downloading rearrange-characters-to-make-target-string
#   ✔ Accepted
#   ✔ 116/116 cases passed (9 ms)
#   ✔ Your runtime beats 2.76 % of java submissions
#   ✔ Your memory usage beats 5.25 % of java submissions (43.7 MB)
# Submitting: java_solutions/2288.apply-discount-to-prices.java
# - Downloading apply-discount-to-prices
#   ✔ Accepted
#   ✔ 151/151 cases passed (104 ms)
#   ✔ Your runtime beats 64.32 % of java submissions
#   ✔ Your memory usage beats 67.84 % of java submissions (52.6 MB)
# Submitting: java_solutions/2289.steps-to-make-array-non-decreasing.java
# - Downloading steps-to-make-array-non-decreasing
#   ✔ Accepted
#   ✔ 87/87 cases passed (16 ms)
#   ✔ Your runtime beats 89.04 % of java submissions
#   ✔ Your memory usage beats 78.54 % of java submissions (96.5 MB)
# Submitting: java_solutions/2290.minimum-obstacle-removal-to-reach-corner.java
# - Downloading minimum-obstacle-removal-to-reach-corner
#   ✔ Accepted
#   ✔ 54/54 cases passed (751 ms)
#   ✔ Your runtime beats 5.16 % of java submissions
#   ✔ Your memory usage beats 5.16 % of java submissions (147.6 MB)
# Submitting: java_solutions/2293.min-max-game.java
# - Downloading min-max-game
#   ✔ Accepted
#   ✔ 96/96 cases passed (5 ms)
#   ✔ Your runtime beats 2.85 % of java submissions
#   ✔ Your memory usage beats 15.65 % of java submissions (45.3 MB)
# Submitting: java_solutions/2294.partition-array-such-that-maximum-difference-is-k.java
# - Downloading partition-array-such-that-maximum-difference-is-k
#   ✔ Accepted
#   ✔ 93/93 cases passed (56 ms)
#   ✔ Your runtime beats 5.95 % of java submissions
#   ✔ Your memory usage beats 99.7 % of java submissions (95.2 MB)
# Submitting: java_solutions/2295.replace-elements-in-an-array.java
# - Downloading replace-elements-in-an-array
#   ✔ Accepted
#   ✔ 80/80 cases passed (63 ms)
#   ✔ Your runtime beats 5.49 % of java submissions
#   ✔ Your memory usage beats 73.47 % of java submissions (142.9 MB)
# Submitting: java_solutions/2296.design-a-text-editor.java
# - Downloading design-a-text-editor
#   ✔ Accepted
#   ✔ 45/45 cases passed (224 ms)
#   ✔ Your runtime beats 5.41 % of java submissions
#   ✔ Your memory usage beats 88.47 % of java submissions (92.1 MB)
# Submitting: java_solutions/2299.strong-password-checker-ii.java
# - Downloading strong-password-checker-ii
#   ✔ Accepted
#   ✔ 148/148 cases passed (3 ms)
#   ✔ Your runtime beats 8.82 % of java submissions
#   ✔ Your memory usage beats 5.08 % of java submissions (43.9 MB)
# Submitting: java_solutions/2300.successful-pairs-of-spells-and-potions.java
# - Downloading successful-pairs-of-spells-and-potions
#   ✔ Accepted
#   ✔ 57/57 cases passed (73 ms)
#   ✔ Your runtime beats 5.26 % of java submissions
#   ✔ Your memory usage beats 95.53 % of java submissions (142.4 MB)
# Submitting: java_solutions/2301.match-substring-after-replacement.java
# - Downloading match-substring-after-replacement
#   ✔ Accepted
#   ✔ 117/117 cases passed (684 ms)
#   ✔ Your runtime beats 9.84 % of java submissions
#   ✔ Your memory usage beats 9.84 % of java submissions (53 MB)
# Submitting: java_solutions/2302.count-subarrays-with-score-less-than-k.java
# - Downloading count-subarrays-with-score-less-than-k
#   ✔ Accepted
#   ✔ 167/167 cases passed (185 ms)
#   ✔ Your runtime beats 2.58 % of java submissions
#   ✔ Your memory usage beats 6.72 % of java submissions (90.8 MB)
# Submitting: java_solutions/2303.calculate-amount-paid-in-taxes.java
# - Downloading calculate-amount-paid-in-taxes
#   ✔ Accepted
#   ✔ 227/227 cases passed (8 ms)
#   ✔ Your runtime beats 3.83 % of java submissions
#   ✔ Your memory usage beats 8.55 % of java submissions (47.6 MB)
# Submitting: java_solutions/2304.minimum-path-cost-in-a-grid.java
# - Downloading minimum-path-cost-in-a-grid
#   ✔ Accepted
#   ✔ 34/34 cases passed (15 ms)
#   ✔ Your runtime beats 6.28 % of java submissions
#   ✔ Your memory usage beats 41.06 % of java submissions (162 MB)
# Submitting: java_solutions/2305.fair-distribution-of-cookies.java
# - Downloading fair-distribution-of-cookies
#   ✔ Accepted
#   ✔ 38/38 cases passed (2185 ms)
#   ✔ Your runtime beats 5.04 % of java submissions
#   ✔ Your memory usage beats 67.54 % of java submissions (42.6 MB)
# Submitting: java_solutions/2306.naming-a-company.java
# - Downloading naming-a-company
#   ✔ Accepted
#   ✔ 89/89 cases passed (173 ms)
#   ✔ Your runtime beats 46.57 % of java submissions
#   ✔ Your memory usage beats 36.99 % of java submissions (79.2 MB)
# Submitting: java_solutions/2309.greatest-english-letter-in-upper-and-lower-case.java
# - Downloading greatest-english-letter-in-upper-and-lower-case
#   ✔ Accepted
#   ✔ 113/113 cases passed (14 ms)
#   ✔ Your runtime beats 11.04 % of java submissions
#   ✔ Your memory usage beats 8.19 % of java submissions (43.9 MB)
# Submitting: java_solutions/2310.sum-of-numbers-with-units-digit-k.java
# - Downloading sum-of-numbers-with-units-digit-k
#   ✔ Accepted
#   ✔ 298/298 cases passed (1 ms)
#   ✔ Your runtime beats 22.73 % of java submissions
#   ✔ Your memory usage beats 66.36 % of java submissions (42.2 MB)
# Submitting: java_solutions/2311.longest-binary-subsequence-less-than-or-equal-to-k.java
# - Downloading longest-binary-subsequence-less-than-or-equal-to-k
#   ✔ Accepted
#   ✔ 155/155 cases passed (2 ms)
#   ✔ Your runtime beats 21.55 % of java submissions
#   ✔ Your memory usage beats 36.21 % of java submissions (43.2 MB)
# Submitting: java_solutions/2312.selling-pieces-of-wood.java
# - Downloading selling-pieces-of-wood
#   ✔ Accepted
#   ✔ 60/60 cases passed (193 ms)
#   ✔ Your runtime beats 11.48 % of java submissions
#   ✔ Your memory usage beats 6.56 % of java submissions (64.7 MB)
# Submitting: java_solutions/2315.count-asterisks.java
# - Downloading count-asterisks
#   ✔ Accepted
#   ✔ 69/69 cases passed (21 ms)
#   ✔ Your runtime beats 2.35 % of java submissions
#   ✔ Your memory usage beats 6.3 % of java submissions (47 MB)
# Submitting: java_solutions/2316.count-unreachable-pairs-of-nodes-in-an-undirected-graph.java
# - Downloading count-unreachable-pairs-of-nodes-in-an-undirected-graph
#   ✔ Accepted
#   ✔ 66/66 cases passed (23 ms)
#   ✔ Your runtime beats 78.16 % of java submissions
#   ✔ Your memory usage beats 74.7 % of java submissions (167.5 MB)
# Submitting: java_solutions/2317.maximum-xor-after-operations.java
# - Downloading maximum-xor-after-operations
#   ✔ Accepted
#   ✔ 73/73 cases passed (19 ms)
#   ✔ Your runtime beats 7.55 % of java submissions
#   ✔ Your memory usage beats 5.66 % of java submissions (64.5 MB)
# Submitting: java_solutions/2318.number-of-distinct-roll-sequences.java
# - Downloading number-of-distinct-roll-sequences
#   ✔ Accepted
#   ✔ 64/64 cases passed (1401 ms)
#   ✔ Your runtime beats 5 % of java submissions
#   ✔ Your memory usage beats 67.5 % of java submissions (53.1 MB)
# Submitting: java_solutions/2319.check-if-matrix-is-x-matrix.java
# - Downloading check-if-matrix-is-x-matrix
#   ✔ Accepted
#   ✔ 84/84 cases passed (6 ms)
#   ✔ Your runtime beats 1.46 % of java submissions
#   ✔ Your memory usage beats 18.04 % of java submissions (48 MB)
# Submitting: java_solutions/2320.count-number-of-ways-to-place-houses.java
# - Downloading count-number-of-ways-to-place-houses
#   ✔ Accepted
#   ✔ 150/150 cases passed (8 ms)
#   ✔ Your runtime beats 40.52 % of java submissions
#   ✔ Your memory usage beats 82.35 % of java submissions (42.1 MB)
# Submitting: java_solutions/2321.maximum-score-of-spliced-array.java
# - Downloading maximum-score-of-spliced-array
#   ✔ Accepted
#   ✔ 34/34 cases passed (10 ms)
#   ✔ Your runtime beats 11.61 % of java submissions
#   ✔ Your memory usage beats 7.14 % of java submissions (94.1 MB)
# Submitting: java_solutions/2322.minimum-score-after-removals-on-a-tree.java
# - Downloading minimum-score-after-removals-on-a-tree
#   ✔ Accepted
#   ✔ 65/65 cases passed (743 ms)
#   ✔ Your runtime beats 9.09 % of java submissions
#   ✔ Your memory usage beats 18.18 % of java submissions (54.5 MB)
# Submitting: java_solutions/2325.decode-the-message.java
# - Downloading decode-the-message
#   ✔ Accepted
#   ✔ 69/69 cases passed (14 ms)
#   ✔ Your runtime beats 21.7 % of java submissions
#   ✔ Your memory usage beats 8.63 % of java submissions (51.3 MB)
# Submitting: java_solutions/2326.spiral-matrix-iv.java
# - Downloading spiral-matrix-iv
#   ✔ Accepted
#   ✔ 50/50 cases passed (10 ms)
#   ✔ Your runtime beats 9.19 % of java submissions
#   ✔ Your memory usage beats 88.71 % of java submissions (133.8 MB)
# Submitting: java_solutions/2327.number-of-people-aware-of-a-secret.java
# - Downloading number-of-people-aware-of-a-secret
#   ✔ Accepted
#   ✔ 82/82 cases passed (7 ms)
#   ✔ Your runtime beats 54.81 % of java submissions
#   ✔ Your memory usage beats 48.08 % of java submissions (42.5 MB)
# Submitting: java_solutions/2328.number-of-increasing-paths-in-a-grid.java
# - Downloading number-of-increasing-paths-in-a-grid
#   ✔ Accepted
#   ✔ 36/36 cases passed (345 ms)
#   ✔ Your runtime beats 5.06 % of java submissions
#   ✔ Your memory usage beats 27.53 % of java submissions (100.2 MB)
# Submitting: java_solutions/2331.evaluate-boolean-binary-tree.java
# - Downloading evaluate-boolean-binary-tree
#   ✔ Accepted
#   ✔ 75/75 cases passed (1 ms)
#   ✔ Your runtime beats 3.17 % of java submissions
#   ✔ Your memory usage beats 39.48 % of java submissions (46.4 MB)
# Submitting: java_solutions/2332.the-latest-time-to-catch-a-bus.java
# - Downloading the-latest-time-to-catch-a-bus
#   ✔ Accepted
#   ✔ 65/65 cases passed (41 ms)
#   ✔ Your runtime beats 59.86 % of java submissions
#   ✔ Your memory usage beats 97.96 % of java submissions (95.9 MB)
# Submitting: java_solutions/2333.minimum-sum-of-squared-difference.java
# - Downloading minimum-sum-of-squared-difference
#   ✔ Accepted
#   ✔ 39/39 cases passed (26 ms)
#   ✔ Your runtime beats 22.03 % of java submissions
#   ✔ Your memory usage beats 47.46 % of java submissions (119.3 MB)
# Submitting: java_solutions/2334.subarray-with-elements-greater-than-varying-threshold.java
# - Downloading subarray-with-elements-greater-than-varying-threshold
#   ✔ Accepted
#   ✔ 68/68 cases passed (285 ms)
#   ✔ Your runtime beats 6.74 % of java submissions
#   ✔ Your memory usage beats 22.47 % of java submissions (99.2 MB)
# Submitting: java_solutions/2335.minimum-amount-of-time-to-fill-cups.java
# - Downloading minimum-amount-of-time-to-fill-cups
#   ✔ Accepted
#   ✔ 280/280 cases passed (1 ms)
#   ✔ Your runtime beats 61.16 % of java submissions
#   ✔ Your memory usage beats 75.67 % of java submissions (42.8 MB)
# Submitting: java_solutions/2336.smallest-number-in-infinite-set.java
# - Downloading smallest-number-in-infinite-set
#   ✔ Accepted
#   ✔ 138/138 cases passed (15 ms)
#   ✔ Your runtime beats 26.46 % of java submissions
#   ✔ Your memory usage beats 82.28 % of java submissions (47 MB)
# Submitting: java_solutions/2337.move-pieces-to-obtain-a-string.java
# - Downloading move-pieces-to-obtain-a-string
#   ✔ Accepted
#   ✔ 139/139 cases passed (49 ms)
#   ✔ Your runtime beats 6.2 % of java submissions
#   ✔ Your memory usage beats 9.69 % of java submissions (48.2 MB)
# Submitting: java_solutions/2338.count-the-number-of-ideal-arrays.java
# - Downloading count-the-number-of-ideal-arrays
#   ✔ Accepted
#   ✔ 47/47 cases passed (327 ms)
#   ✔ Your runtime beats 19.23 % of java submissions
#   ✔ Your memory usage beats 23.42 % of java submissions (60.4 MB)
# Submitting: java_solutions/2341.maximum-number-of-pairs-in-array.java
# - Downloading maximum-number-of-pairs-in-array
#   ✔ Accepted
#   ✔ 128/128 cases passed (15 ms)
#   ✔ Your runtime beats 3.77 % of java submissions
#   ✔ Your memory usage beats 11.47 % of java submissions (50.3 MB)
# Submitting: java_solutions/2342.max-sum-of-a-pair-with-equal-sum-of-digits.java
# - Downloading max-sum-of-a-pair-with-equal-sum-of-digits
#   ✔ Accepted
#   ✔ 84/84 cases passed (26 ms)
#   ✔ Your runtime beats 91.41 % of java submissions
#   ✔ Your memory usage beats 88.89 % of java submissions (86.9 MB)
# Submitting: java_solutions/2343.query-kth-smallest-trimmed-number.java
# - Downloading query-kth-smallest-trimmed-number
#   ✔ Accepted
#   ✔ 251/251 cases passed (374 ms)
#   ✔ Your runtime beats 33.2 % of java submissions
#   ✔ Your memory usage beats 44.81 % of java submissions (48 MB)
# Submitting: java_solutions/2344.minimum-deletions-to-make-array-divisible.java
# - Downloading minimum-deletions-to-make-array-divisible
#   ✔ Accepted
#   ✔ 49/49 cases passed (49 ms)
#   ✔ Your runtime beats 5.11 % of java submissions
#   ✔ Your memory usage beats 5.24 % of java submissions (110.6 MB)
# Submitting: java_solutions/2347.best-poker-hand.java
# - Downloading best-poker-hand
#   ✔ Accepted
#   ✔ 98/98 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 98.76 % of java submissions (42.4 MB)
# Submitting: java_solutions/2348.number-of-zero-filled-subarrays.java
# - Downloading number-of-zero-filled-subarrays
#   ✔ Accepted
#   ✔ 48/48 cases passed (7 ms)
#   ✔ Your runtime beats 3.26 % of java submissions
#   ✔ Your memory usage beats 66.07 % of java submissions (115.6 MB)
# Submitting: java_solutions/2349.design-a-number-container-system.java
# - Downloading design-a-number-container-system
#   ✔ Accepted
#   ✔ 46/46 cases passed (123 ms)
#   ✔ Your runtime beats 9.47 % of java submissions
#   ✔ Your memory usage beats 11.58 % of java submissions (178.2 MB)
# Submitting: java_solutions/2350.shortest-impossible-sequence-of-rolls.java
# - Downloading shortest-impossible-sequence-of-rolls
#   ✔ Accepted
#   ✔ 65/65 cases passed (15 ms)
#   ✔ Your runtime beats 79.37 % of java submissions
#   ✔ Your memory usage beats 80.95 % of java submissions (81.6 MB)
# Submitting: java_solutions/2351.first-letter-to-appear-twice.java
# - Downloading first-letter-to-appear-twice
#   ✔ Accepted
#   ✔ 92/92 cases passed (4 ms)
#   ✔ Your runtime beats 1.11 % of java submissions
#   ✔ Your memory usage beats 15.45 % of java submissions (43 MB)
# Submitting: java_solutions/2352.equal-row-and-column-pairs.java
# - Downloading equal-row-and-column-pairs
#   ✔ Accepted
#   ✔ 80/80 cases passed (65 ms)
#   ✔ Your runtime beats 15 % of java submissions
#   ✔ Your memory usage beats 87.02 % of java submissions (50.3 MB)

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-05-05 10:50:21
