# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME')
    user_cookie = userdata.get('LEETCODE_TOKEN')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME'] = user_name
    os.environ['LEETCODE_TOKEN'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME" "$LEETCODE_TOKEN" | leetcode user -c

# %%
# %%bash
#
#
# # top 100 answers
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v kotlin_solutions_1/*.kt | head -n 100); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 7
# done
# Out:
# Submitting: kotlin_solutions_1/853.car-fleet.kt
# - Downloading problems
# - Downloading car-fleet
#   ✔ Accepted
#   ✔ 49/49 cases passed (120 ms)
#   ✔ Your runtime beats 78 % of kotlin submissions
#   ✔ Your memory usage beats 54 % of kotlin submissions (69.2 MB)
# Submitting: kotlin_solutions_1/860.lemonade-change.kt
# - Downloading lemonade-change
#   ✔ Accepted
#   ✔ 62/62 cases passed (7 ms)
#   ✔ Your runtime beats 27.27 % of kotlin submissions
#   ✔ Your memory usage beats 27.27 % of kotlin submissions (61 MB)
# Submitting: kotlin_solutions_1/905.sort-array-by-parity.kt
# - Downloading sort-array-by-parity
#   ✔ Accepted
#   ✔ 286/286 cases passed (28 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 11.76 % of kotlin submissions (49.2 MB)
# Submitting: kotlin_solutions_1/906.super-palindromes.kt
# - Downloading super-palindromes
#   ✔ Accepted
#   ✔ 49/49 cases passed (1287 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/912.sort-an-array.kt
# - Downloading sort-an-array
#   ✔ Accepted
#   ✔ 21/21 cases passed (37 ms)
#   ✔ Your runtime beats 84.4 % of kotlin submissions
#   ✔ Your memory usage beats 38.53 % of kotlin submissions (62.3 MB)
# Submitting: kotlin_solutions_1/913.cat-and-mouse.kt
# - Downloading cat-and-mouse
#   ✔ Accepted
#   ✔ 92/92 cases passed (35 ms)
#   ✔ Your runtime beats 66.67 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (49.5 MB)
# Submitting: kotlin_solutions_1/917.reverse-only-letters.kt
# - Downloading reverse-only-letters
#   ✔ Accepted
#   ✔ 115/115 cases passed (10 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
#   ✔ Your memory usage beats 23.33 % of kotlin submissions (42.5 MB)
# Submitting: kotlin_solutions_1/920.number-of-music-playlists.kt
# - Downloading number-of-music-playlists
#   ✔ Accepted
#   ✔ 83/83 cases passed (12 ms)
#   ✔ Your runtime beats 12.5 % of kotlin submissions
#   ✔ Your memory usage beats 87.5 % of kotlin submissions (41.7 MB)
# Submitting: kotlin_solutions_1/921.minimum-add-to-make-parentheses-valid.kt
# - Downloading minimum-add-to-make-parentheses-valid
#   ✔ Accepted
#   ✔ 116/116 cases passed (12 ms)
#   ✔ Your runtime beats 8 % of kotlin submissions
#   ✔ Your memory usage beats 8 % of kotlin submissions (45 MB)
# Submitting: kotlin_solutions_1/924.minimize-malware-spread.kt
# - Downloading minimize-malware-spread
#   ✔ Accepted
#   ✔ 70/70 cases passed (37 ms)
#   ✔ Your runtime beats 44.44 % of kotlin submissions
#   ✔ Your memory usage beats 11.11 % of kotlin submissions (83.6 MB)
# Submitting: kotlin_solutions_1/927.three-equal-parts.kt
# - Downloading three-equal-parts
#   ✔ Accepted
#   ✔ 121/121 cases passed (26 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (52.5 MB)
# Submitting: kotlin_solutions_1/928.minimize-malware-spread-ii.kt
# - Downloading minimize-malware-spread-ii
#   ✔ Accepted
#   ✔ 48/48 cases passed (172 ms)
#   ✔ Your runtime beats 11.11 % of kotlin submissions
#   ✔ Your memory usage beats 44.44 % of kotlin submissions (75.9 MB)
# Submitting: kotlin_solutions_1/929.unique-email-addresses.kt
# - Downloading unique-email-addresses
#   ✔ Accepted
#   ✔ 188/188 cases passed (30 ms)
#   ✔ Your runtime beats 65.52 % of kotlin submissions
#   ✔ Your memory usage beats 58.62 % of kotlin submissions (47.6 MB)
# Submitting: kotlin_solutions_1/938.range-sum-of-bst.kt
# - Downloading range-sum-of-bst
#   ✔ Accepted
#   ✔ 41/41 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 38.1 % of kotlin submissions (55.5 MB)
# Submitting: kotlin_solutions_1/940.distinct-subsequences-ii.kt
# - Downloading distinct-subsequences-ii
#   ✔ Accepted
#   ✔ 110/110 cases passed (16 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/941.valid-mountain-array.kt
# - Downloading valid-mountain-array
#   ✔ Accepted
#   ✔ 55/55 cases passed (194 ms)
#   ✔ Your runtime beats 68.29 % of kotlin submissions
#   ✔ Your memory usage beats 17.07 % of kotlin submissions (48.6 MB)
# Submitting: kotlin_solutions_1/943.find-the-shortest-superstring.kt
# - Downloading find-the-shortest-superstring
#   ✔ Accepted
#   ✔ 85/85 cases passed (85 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/944.delete-columns-to-make-sorted.kt
# - Downloading delete-columns-to-make-sorted
#   ✔ Accepted
#   ✔ 86/86 cases passed (44 ms)
#   ✔ Your runtime beats 5.56 % of kotlin submissions
#   ✔ Your memory usage beats 27.78 % of kotlin submissions (47.8 MB)
# Submitting: kotlin_solutions_1/952.largest-component-size-by-common-factor.kt
# - Downloading largest-component-size-by-common-factor
#   ✔ Accepted
#   ✔ 108/108 cases passed (480 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (63.7 MB)
# Submitting: kotlin_solutions_1/953.verifying-an-alien-dictionary.kt
# - Downloading verifying-an-alien-dictionary
#   ✔ Accepted
#   ✔ 125/125 cases passed (20 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/956.tallest-billboard.kt
# - Downloading tallest-billboard
#   ✔ Accepted
#   ✔ 80/80 cases passed (22 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (46.6 MB)
# Submitting: kotlin_solutions_1/960.delete-columns-to-make-sorted-iii.kt
# - Downloading delete-columns-to-make-sorted-iii
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 3: Char 211: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 3: Char 211: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 3: Char 218: ERROR: Unresolved reference 'j'.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/961.n-repeated-element-in-size-2n-array.kt
# - Downloading n-repeated-element-in-size-2n-array
#   ✔ Accepted
#   ✔ 106/106 cases passed (1 ms)
#   ✔ Your runtime beats 75 % of kotlin submissions
#   ✔ Your memory usage beats 68.75 % of kotlin submissions (48.5 MB)
# Submitting: kotlin_solutions_1/964.least-operators-to-express-number.kt
# - Downloading least-operators-to-express-number
#   ✔ Accepted
#   ✔ 162/162 cases passed (8 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (41 MB)
# Submitting: kotlin_solutions_1/965.univalued-binary-tree.kt
# - Downloading univalued-binary-tree
#   ✔ Accepted
#   ✔ 72/72 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 21.05 % of kotlin submissions (41.1 MB)
# Submitting: kotlin_solutions_1/968.binary-tree-cameras.kt
# - Downloading binary-tree-cameras
#   ✔ Accepted
#   ✔ 171/171 cases passed (3 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (45.8 MB)
# Submitting: kotlin_solutions_1/972.equal-rational-numbers.kt
# - Downloading equal-rational-numbers
#   ✔ Accepted
#   ✔ 74/74 cases passed (12 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (44.6 MB)
# Submitting: kotlin_solutions_1/973.k-closest-points-to-origin.kt
# - Downloading k-closest-points-to-origin
#   ✔ Accepted
#   ✔ 87/87 cases passed (56 ms)
#   ✔ Your runtime beats 8.61 % of kotlin submissions
#   ✔ Your memory usage beats 6.62 % of kotlin submissions (78.9 MB)
# Submitting: kotlin_solutions_1/975.odd-even-jump.kt
# - Downloading odd-even-jump
#   ✔ Accepted
#   ✔ 65/65 cases passed (62 ms)
#   ✔ Your runtime beats 76.92 % of kotlin submissions
#   ✔ Your memory usage beats 30.77 % of kotlin submissions (57.3 MB)
# Submitting: kotlin_solutions_1/976.largest-perimeter-triangle.kt
# - Downloading largest-perimeter-triangle
#   ✔ Accepted
#   ✔ 84/84 cases passed (28 ms)
#   ✔ Your runtime beats 7.14 % of kotlin submissions
#   ✔ Your memory usage beats 57.14 % of kotlin submissions (49.8 MB)
# Submitting: kotlin_solutions_1/977.squares-of-a-sorted-array.kt
# - Downloading squares-of-a-sorted-array
#   ✔ Accepted
#   ✔ 137/137 cases passed (28 ms)
#   ✔ Your runtime beats 8.24 % of kotlin submissions
#   ✔ Your memory usage beats 6.09 % of kotlin submissions (53.1 MB)
# Submitting: kotlin_solutions_1/980.unique-paths-iii.kt
# - Downloading unique-paths-iii
#   ✔ Accepted
#   ✔ 39/39 cases passed (46 ms)
#   ✔ Your runtime beats 8.33 % of kotlin submissions
#   ✔ Your memory usage beats 8.33 % of kotlin submissions (48.9 MB)
# Submitting: kotlin_solutions_1/982.triples-with-bitwise-and-equal-to-zero.kt
# - Downloading triples-with-bitwise-and-equal-to-zero
#   ✔ Accepted
#   ✔ 28/28 cases passed (284 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (45.7 MB)
# Submitting: kotlin_solutions_1/987.vertical-order-traversal-of-a-binary-tree.kt
# - Downloading vertical-order-traversal-of-a-binary-tree
#   ✔ Accepted
#   ✔ 34/34 cases passed (36 ms)
#   ✔ Your runtime beats 9.09 % of kotlin submissions
#   ✔ Your memory usage beats 9.09 % of kotlin submissions (48.2 MB)
# Submitting: kotlin_solutions_1/989.add-to-array-form-of-integer.kt
# - Downloading add-to-array-form-of-integer
#   ✔ Accepted
#   ✔ 152/152 cases passed (84 ms)
#   ✔ Your runtime beats 8.33 % of kotlin submissions
#   ✔ Your memory usage beats 8.33 % of kotlin submissions (53.8 MB)
# Submitting: kotlin_solutions_1/992.subarrays-with-k-different-integers.kt
# - Downloading subarrays-with-k-different-integers
#   ✔ Accepted
#   ✔ 57/57 cases passed (15 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 68.75 % of kotlin submissions (51.3 MB)
# Submitting: kotlin_solutions_1/995.minimum-number-of-k-consecutive-bit-flips.kt
# - Downloading minimum-number-of-k-consecutive-bit-flips
#   ✔ Accepted
#   ✔ 113/113 cases passed (27 ms)
#   ✔ Your runtime beats 40 % of kotlin submissions
#   ✔ Your memory usage beats 40 % of kotlin submissions (64.2 MB)
# Submitting: kotlin_solutions_1/996.number-of-squareful-arrays.kt
# - Downloading number-of-squareful-arrays
#   ✘ Runtime Error
#   ✘ 0/78 cases passed (N/A)
#   ✘ Error: Line 8: Exception in thread "main" java.lang.ArrayIndexOutOfBoundsException: Index 8 out of bounds for length 3
#   ✘ Error: Line 8: Exception in thread "main" java.lang.ArrayIndexOutOfBoundsException: Index 8 out of bounds for length 3
#   ✘ Testcase: [1,17,8]
#   ✘ Answer:
#   ✘ Expected Answer: 2
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/997.find-the-town-judge.kt
# - Downloading find-the-town-judge
#   ✔ Accepted
#   ✔ 92/92 cases passed (120 ms)
#   ✔ Your runtime beats 5.88 % of kotlin submissions
#   ✔ Your memory usage beats 64.71 % of kotlin submissions (66 MB)
# Submitting: kotlin_solutions_1/1000.minimum-cost-to-merge-stones.kt
# - Downloading minimum-cost-to-merge-stones
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 4: Char 380: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
#   ✘ Error: Line 4: Char 380: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 4: Char 398: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 4: Char 442: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 4: Char 506: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 4: Char 527: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 4: Char 558: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 4: Char 579: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 4: Char 600: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 4: Char 618: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 4: Char 663: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 4: Char 729: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 4: Char 747: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 4: Char 792: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 4: Char 928: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 4: Char 956: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 4: Char 977: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 4: Char 1052: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 4: Char 1073: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 4: Char 1094: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 4: Char 1138: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 4: Char 1140: ERROR: Unresolved reference 'res'.
# Line 4: Char 1140: ERROR: Argument type mismatch: actual type is 'V?', but 'kotlin.Int' was expected.
# Line 4: Char 1140: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1001.grid-illumination.kt
# - Downloading grid-illumination
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 4: Char 130: ERROR: Argument type mismatch: actual type is 'it(R#2 (type parameter of fun <T, R> T.let(block: (T) -> R): R
#   ✘ Error: Line 4: Char 130: ERROR: Argument type mismatch: actual type is 'it(R#2 (type parameter of fun <T, R> T.let(block: (T) -> R): R
#     [R|Contract description]
#      <
#         CallsInPlace(block, EXACTLY_ONCE)
#     >) & Any & R#2 (type parameter of fun <T, R> T.let(block: (T) -> R): R
#     [R|Contract description]
#      <
#         CallsInPlace(block, EXACTLY_ONCE)
#     >) & Any & R#2 (type parameter of fun <T, R> T.let(block: (T) -> R): R
#     [R|Contract description]
#      <
#         CallsInPlace(block, EXACTLY_ONCE)
#     >) & Any & R#2 (type parameter of fun <T, R> T.let(block: (T) -> R): R
#     [R|Contract description]
#      <
#         CallsInPlace(block, EXACTLY_ONCE)
#     >) & Any & kotlin.collections.List<R#1 (type parameter of fun <T, R> Array<out T>.map(transform: (T) -> R): List<R>)>)', but 'kotlin.IntArray' was expected.
# Line 4: Char 150: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 4: Char 184: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 4: Char 216: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 4: Char 244: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 4: Char 365: WARNING: Parameter 'it: Boolean' is never used, could be renamed to '_'.
# Line 4: Char 424: WARNING: Parameter 'it: Int?' is never used, could be renamed to '_'.
# Line 4: Char 483: WARNING: Parameter 'it: Int?' is never used, could be renamed to '_'.
# Line 4: Char 558: WARNING: Parameter 'it: Int?' is never used, could be renamed to '_'.
# Line 4: Char 641: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 4: Char 645: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 4: Char 655: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 4: Char 972: WARNING: Parameter 'it: Long' is never used, could be renamed to '_'.
# Line 4: Char 1063: WARNING: Parameter 'it: Boolean' is never used, could be renamed to '_'.
# Line 4: Char 1103: WARNING: Parameter 'it: Int?' is never used, could be renamed to '_'.
# Line 4: Char 1143: WARNING: Parameter 'it: Int?' is never used, could be renamed to '_'.
# Line 4: Char 1189: WARNING: Parameter 'it: Int?' is never used, could be renamed to '_'.
# Line 4: Char 1253: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 4: Char 1281: ERROR: None of the following candidates is applicable:
# fun Array<out Int>.toIntArray(): IntArray
# fun Collection<Int>.toIntArray(): IntArray
# fun UIntArray.toIntArray(): IntArray
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1002.find-common-characters.kt
# - Downloading find-common-characters
#   ✔ Accepted
#   ✔ 88/88 cases passed (23 ms)
#   ✔ Your runtime beats 16.13 % of kotlin submissions
#   ✔ Your memory usage beats 19.35 % of kotlin submissions (46.4 MB)
# Submitting: kotlin_solutions_1/1003.check-if-word-is-valid-after-substitutions.kt
# - Downloading check-if-word-is-valid-after-substitutions
#   ✔ Accepted
#   ✔ 97/97 cases passed (18 ms)
#   ✔ Your runtime beats 87.5 % of kotlin submissions
#   ✔ Your memory usage beats 37.5 % of kotlin submissions (47.7 MB)
# Submitting: kotlin_solutions_1/1004.max-consecutive-ones-iii.kt
# - Downloading max-consecutive-ones-iii
#   ✔ Accepted
#   ✔ 63/63 cases passed (23 ms)
#   ✔ Your runtime beats 7.92 % of kotlin submissions
#   ✔ Your memory usage beats 99.5 % of kotlin submissions (53.9 MB)
# Submitting: kotlin_solutions_1/1005.maximize-sum-of-array-after-k-negations.kt
# - Downloading maximize-sum-of-array-after-k-negations
#   ✔ Accepted
#   ✔ 84/84 cases passed (17 ms)
#   ✔ Your runtime beats 53.33 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (46 MB)
# Submitting: kotlin_solutions_1/1006.clumsy-factorial.kt
# - Downloading clumsy-factorial
#   ✔ Accepted
#   ✔ 84/84 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (39.7 MB)
# Submitting: kotlin_solutions_1/1007.minimum-domino-rotations-for-equal-row.kt
# - Downloading minimum-domino-rotations-for-equal-row
#   ✔ Accepted
#   ✔ 93/93 cases passed (34 ms)
#   ✔ Your runtime beats 37.5 % of kotlin submissions
#   ✔ Your memory usage beats 37.5 % of kotlin submissions (56.4 MB)
# Submitting: kotlin_solutions_1/1008.construct-binary-search-tree-from-preorder-traversal.kt
# - Downloading construct-binary-search-tree-from-preorder-traversal
#   ✔ Accepted
#   ✔ 111/111 cases passed (12 ms)
#   ✔ Your runtime beats 17.39 % of kotlin submissions
#   ✔ Your memory usage beats 30.43 % of kotlin submissions (42.8 MB)
# Submitting: kotlin_solutions_1/1009.complement-of-base-10-integer.kt
# - Downloading complement-of-base-10-integer
#   ✔ Accepted
#   ✔ 128/128 cases passed (15 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1010.pairs-of-songs-with-total-durations-divisible-by-60.kt
# - Downloading pairs-of-songs-with-total-durations-divisible-by-60
#   ✔ Accepted
#   ✔ 35/35 cases passed (5 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (57.7 MB)
# Submitting: kotlin_solutions_1/1011.capacity-to-ship-packages-within-d-days.kt
# - Downloading capacity-to-ship-packages-within-d-days
#   ✔ Accepted
#   ✔ 90/90 cases passed (68 ms)
#   ✔ Your runtime beats 6.06 % of kotlin submissions
#   ✔ Your memory usage beats 78.79 % of kotlin submissions (53.3 MB)
# Submitting: kotlin_solutions_1/1012.numbers-with-repeated-digits.kt
# - Downloading numbers-with-repeated-digits
#   ✔ Accepted
#   ✔ 130/130 cases passed (12 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (42.5 MB)
# Submitting: kotlin_solutions_1/1013.partition-array-into-three-parts-with-equal-sum.kt
# - Downloading partition-array-into-three-parts-with-equal-sum
#   ✔ Accepted
#   ✔ 72/72 cases passed (33 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 8.33 % of kotlin submissions (62.7 MB)
# Submitting: kotlin_solutions_1/1014.best-sightseeing-pair.kt
# - Downloading best-sightseeing-pair
#   ✔ Accepted
#   ✔ 55/55 cases passed (22 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1015.smallest-integer-divisible-by-k.kt
# - Downloading smallest-integer-divisible-by-k
#   ✔ Accepted
#   ✔ 71/71 cases passed (30 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1016.binary-string-with-substrings-representing-1-to-n.kt
# - Downloading binary-string-with-substrings-representing-1-to-n
#   ✔ Accepted
#   ✔ 30/30 cases passed (11 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1017.convert-to-base-2.kt
# - Downloading convert-to-base-2
#   ✔ Accepted
#   ✔ 170/170 cases passed (8 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/1018.binary-prefix-divisible-by-5.kt
# - Downloading binary-prefix-divisible-by-5
#   ✔ Accepted
#   ✔ 24/24 cases passed (14 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (51.5 MB)
# Submitting: kotlin_solutions_1/1019.next-greater-node-in-linked-list.kt
# - Downloading next-greater-node-in-linked-list
#   ✔ Accepted
#   ✔ 76/76 cases passed (140 ms)
#   ✔ Your runtime beats 12.5 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (58.5 MB)
# Submitting: kotlin_solutions_1/1020.number-of-enclaves.kt
# - Downloading number-of-enclaves
#   ✔ Accepted
#   ✔ 60/60 cases passed (76 ms)
#   ✔ Your runtime beats 14.81 % of kotlin submissions
#   ✔ Your memory usage beats 40.74 % of kotlin submissions (74.3 MB)
# Submitting: kotlin_solutions_1/1021.remove-outermost-parentheses.kt
# - Downloading remove-outermost-parentheses
#   ✔ Accepted
#   ✔ 59/59 cases passed (5 ms)
#   ✔ Your runtime beats 40.54 % of kotlin submissions
#   ✔ Your memory usage beats 75.68 % of kotlin submissions (41.5 MB)
# Submitting: kotlin_solutions_1/1022.sum-of-root-to-leaf-binary-numbers.kt
# - Downloading sum-of-root-to-leaf-binary-numbers
#   ✔ Accepted
#   ✔ 63/63 cases passed (14 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1023.camelcase-matching.kt
# - Downloading camelcase-matching
#   ✔ Accepted
#   ✔ 39/39 cases passed (3 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
#   ✔ Your memory usage beats 20 % of kotlin submissions (41.2 MB)
# Submitting: kotlin_solutions_1/1024.video-stitching.kt
# - Downloading video-stitching
#   ✔ Accepted
#   ✔ 60/60 cases passed (9 ms)
#   ✔ Your runtime beats 57.14 % of kotlin submissions
#   ✔ Your memory usage beats 57.14 % of kotlin submissions (42 MB)
# Submitting: kotlin_solutions_1/1025.divisor-game.kt
# - Downloading divisor-game
#   ✔ Accepted
#   ✔ 40/40 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 35.29 % of kotlin submissions (39.9 MB)
# Submitting: kotlin_solutions_1/1026.maximum-difference-between-node-and-ancestor.kt
# - Downloading maximum-difference-between-node-and-ancestor
#   ✔ Accepted
#   ✔ 30/30 cases passed (14 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1027.longest-arithmetic-subsequence.kt
# - Downloading longest-arithmetic-subsequence
#   ✔ Accepted
#   ✔ 65/65 cases passed (61 ms)
#   ✔ Your runtime beats 66.67 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (60.6 MB)
# Submitting: kotlin_solutions_1/1028.recover-a-tree-from-preorder-traversal.kt
# - Downloading recover-a-tree-from-preorder-traversal
#   ✔ Accepted
#   ✔ 105/105 cases passed (44 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1029.two-city-scheduling.kt
# - Downloading two-city-scheduling
#   ✔ Accepted
#   ✔ 50/50 cases passed (20 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1030.matrix-cells-in-distance-order.kt
# - Downloading matrix-cells-in-distance-order
#   ✔ Accepted
#   ✔ 66/66 cases passed (39 ms)
#   ✔ Your runtime beats 14.29 % of kotlin submissions
#   ✔ Your memory usage beats 28.57 % of kotlin submissions (53.1 MB)
# Submitting: kotlin_solutions_1/1031.maximum-sum-of-two-non-overlapping-subarrays.kt
# - Downloading maximum-sum-of-two-non-overlapping-subarrays
#   ✔ Accepted
#   ✔ 51/51 cases passed (17 ms)
#   ✔ Your runtime beats 8.33 % of kotlin submissions
#   ✔ Your memory usage beats 8.33 % of kotlin submissions (45.5 MB)
# Submitting: kotlin_solutions_1/1032.stream-of-characters.kt
# - Downloading stream-of-characters
#   ✔ Accepted
#   ✔ 20/20 cases passed (277 ms)
#   ✔ Your runtime beats 63.64 % of kotlin submissions
#   ✔ Your memory usage beats 9.09 % of kotlin submissions (234.8 MB)
# Submitting: kotlin_solutions_1/1033.moving-stones-until-consecutive.kt
# - Downloading moving-stones-until-consecutive
#   ✔ Accepted
#   ✔ 187/187 cases passed (12 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1035.uncrossed-lines.kt
# - Downloading uncrossed-lines
#   ✔ Accepted
#   ✔ 74/74 cases passed (27 ms)
#   ✔ Your runtime beats 28.57 % of kotlin submissions
#   ✔ Your memory usage beats 28.57 % of kotlin submissions (46.3 MB)
# Submitting: kotlin_solutions_1/1036.escape-a-large-maze.kt
# - Downloading escape-a-large-maze
#   ✔ Accepted
#   ✔ 31/31 cases passed (298 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1037.valid-boomerang.kt
# - Downloading valid-boomerang
#   ✔ Accepted
#   ✔ 206/206 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 16.67 % of kotlin submissions (41.4 MB)
# Submitting: kotlin_solutions_1/1038.binary-search-tree-to-greater-sum-tree.kt
# - Downloading binary-search-tree-to-greater-sum-tree
#   ✔ Accepted
#   ✔ 32/32 cases passed (12 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1039.minimum-score-triangulation-of-polygon.kt
# - Downloading minimum-score-triangulation-of-polygon
#   ✔ Accepted
#   ✔ 94/94 cases passed (14 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1040.moving-stones-until-consecutive-ii.kt
# - Downloading moving-stones-until-consecutive-ii
#   ✔ Accepted
#   ✔ 27/27 cases passed (78 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1041.robot-bounded-in-circle.kt
# - Downloading robot-bounded-in-circle
#   ✔ Accepted
#   ✔ 117/117 cases passed (1 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1042.flower-planting-with-no-adjacent.kt
# - Downloading flower-planting-with-no-adjacent
#   ✔ Accepted
#   ✔ 51/51 cases passed (26 ms)
#   ✔ Your runtime beats 57.14 % of kotlin submissions
#   ✔ Your memory usage beats 28.57 % of kotlin submissions (73.3 MB)
# Submitting: kotlin_solutions_1/1043.partition-array-for-maximum-sum.kt
# - Downloading partition-array-for-maximum-sum
#   ✔ Accepted
#   ✔ 52/52 cases passed (15 ms)
#   ✔ Your runtime beats 42.86 % of kotlin submissions
#   ✔ Your memory usage beats 42.86 % of kotlin submissions (43.1 MB)
# Submitting: kotlin_solutions_1/1044.longest-duplicate-substring.kt
# - Downloading longest-duplicate-substring
#   ✔ Accepted
#   ✔ 69/69 cases passed (332 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1046.last-stone-weight.kt
# - Downloading last-stone-weight
#   ✔ Accepted
#   ✔ 74/74 cases passed (3 ms)
#   ✔ Your runtime beats 89.91 % of kotlin submissions
#   ✔ Your memory usage beats 91.74 % of kotlin submissions (40.5 MB)
# Submitting: kotlin_solutions_1/1047.remove-all-adjacent-duplicates-in-string.kt
# - Downloading remove-all-adjacent-duplicates-in-string
#   ✔ Accepted
#   ✔ 106/106 cases passed (27 ms)
#   ✔ Your runtime beats 77.14 % of kotlin submissions
#   ✔ Your memory usage beats 92.86 % of kotlin submissions (45.7 MB)
# Submitting: kotlin_solutions_1/1048.longest-string-chain.kt
# - Downloading longest-string-chain
#   ✔ Accepted
#   ✔ 86/86 cases passed (70 ms)
#   ✔ Your runtime beats 28.57 % of kotlin submissions
#   ✔ Your memory usage beats 42.86 % of kotlin submissions (49.3 MB)
# Submitting: kotlin_solutions_1/1049.last-stone-weight-ii.kt
# - Downloading last-stone-weight-ii
#   ✔ Accepted
#   ✔ 90/90 cases passed (35 ms)
#   ✔ Your runtime beats 22.22 % of kotlin submissions
#   ✔ Your memory usage beats 11.11 % of kotlin submissions (48.7 MB)
# Submitting: kotlin_solutions_1/1051.height-checker.kt
# - Downloading height-checker
#   ✔ Accepted
#   ✔ 81/81 cases passed (16 ms)
#   ✔ Your runtime beats 23.08 % of kotlin submissions
#   ✔ Your memory usage beats 11.54 % of kotlin submissions (46.2 MB)
# Submitting: kotlin_solutions_1/1052.grumpy-bookstore-owner.kt
# - Downloading grumpy-bookstore-owner
#   ✔ Accepted
#   ✔ 78/78 cases passed (28 ms)
#   ✔ Your runtime beats 9.09 % of kotlin submissions
#   ✔ Your memory usage beats 9.09 % of kotlin submissions (54.6 MB)
# Submitting: kotlin_solutions_1/1053.previous-permutation-with-one-swap.kt
# - Downloading previous-permutation-with-one-swap
#   ✔ Accepted
#   ✔ 55/55 cases passed (4 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1054.distant-barcodes.kt
# - Downloading distant-barcodes
#   ✔ Accepted
#   ✔ 59/59 cases passed (97 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (52.9 MB)
# Submitting: kotlin_solutions_1/1061.lexicographically-smallest-equivalent-string.kt
# - Downloading lexicographically-smallest-equivalent-string
#   ✔ Accepted
#   ✔ 117/117 cases passed (39 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1071.greatest-common-divisor-of-strings.kt
# - Downloading greatest-common-divisor-of-strings
#   ✔ Accepted
#   ✔ 129/129 cases passed (2 ms)
#   ✔ Your runtime beats 43.37 % of kotlin submissions
#   ✔ Your memory usage beats 65.06 % of kotlin submissions (42.1 MB)
# Submitting: kotlin_solutions_1/1072.flip-columns-for-maximum-number-of-equal-rows.kt
# - Downloading flip-columns-for-maximum-number-of-equal-rows
#   ✔ Accepted
#   ✔ 90/90 cases passed (37 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1073.adding-two-negabinary-numbers.kt
# - Downloading adding-two-negabinary-numbers
#   ✔ Accepted
#   ✔ 267/267 cases passed (20 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1074.number-of-submatrices-that-sum-to-target.kt
# - Downloading number-of-submatrices-that-sum-to-target
#   ✔ Accepted
#   ✔ 40/40 cases passed (321 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1078.occurrences-after-bigram.kt
# - Downloading occurrences-after-bigram
#   ✔ Accepted
#   ✔ 31/31 cases passed (15 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1079.letter-tile-possibilities.kt
# - Downloading letter-tile-possibilities
#   ✔ Accepted
#   ✔ 86/86 cases passed (54 ms)
#   ✔ Your runtime beats 12.5 % of kotlin submissions
#   ✔ Your memory usage beats 37.5 % of kotlin submissions (48.5 MB)
# Submitting: kotlin_solutions_1/1080.insufficient-nodes-in-root-to-leaf-paths.kt
# - Downloading insufficient-nodes-in-root-to-leaf-paths
#   ✔ Accepted
#   ✔ 117/117 cases passed (1 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (48.9 MB)
# Submitting: kotlin_solutions_1/1081.smallest-subsequence-of-distinct-characters.kt
# - Downloading smallest-subsequence-of-distinct-characters
#   ✔ Accepted
#   ✔ 68/68 cases passed (12 ms)
#   ✔ Your runtime beats 48.92 % of kotlin submissions
#   ✔ Your memory usage beats 42.47 % of kotlin submissions (42.7 MB)

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-08-17 11:24:27
