# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME_3')
    user_cookie = userdata.get('LEETCODE_TOKEN_3')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME_3'] = user_name
    os.environ['LEETCODE_TOKEN_3'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME_3" "$LEETCODE_TOKEN_3" | leetcode user -c

# %%
# %%bash
#
# # top 400-500 answers (5th batch)
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v kotlin_solutions_1/*.kt | sed -n '1001,1100p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 7
# done
# Out:
# Submitting: kotlin_solutions_1/2321.maximum-score-of-spliced-array.kt
# - Downloading problems
# - Downloading maximum-score-of-spliced-array
#   ✔ Accepted
#   ✔ 34/34 cases passed (50 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2322.minimum-score-after-removals-on-a-tree.kt
# - Downloading minimum-score-after-removals-on-a-tree
#   ✘ Runtime Error
#   ✘ 0/65 cases passed (N/A)
#   ✘ Error: Line 2: Exception in thread "main" java.util.NoSuchElementException
#   ✘ Error: Line 2: Exception in thread "main" java.util.NoSuchElementException
#   ✘ Testcase: [1,5,5,4,11]
# [[0,1],[1,2],[1,3],[3,4]]
#   ✘ Answer:
#   ✘ Expected Answer: 9
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2325.decode-the-message.kt
# - Downloading decode-the-message
#   ✔ Accepted
#   ✔ 69/69 cases passed (25 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (44.3 MB)
# Submitting: kotlin_solutions_1/2326.spiral-matrix-iv.kt
# - Downloading spiral-matrix-iv
#   ✔ Accepted
#   ✔ 50/50 cases passed (18 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/2327.number-of-people-aware-of-a-secret.kt
# - Downloading number-of-people-aware-of-a-secret
#   ✔ Accepted
#   ✔ 82/82 cases passed (10 ms)
#   ✔ Your runtime beats 75 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (40.2 MB)
# Submitting: kotlin_solutions_1/2328.number-of-increasing-paths-in-a-grid.kt
# - Downloading number-of-increasing-paths-in-a-grid
#   ✔ Accepted
#   ✔ 36/36 cases passed (182 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2331.evaluate-boolean-binary-tree.kt
# - Downloading evaluate-boolean-binary-tree
#   ✔ Accepted
#   ✔ 75/75 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2333.minimum-sum-of-squared-difference.kt
# - Downloading minimum-sum-of-squared-difference
#   ✔ Accepted
#   ✔ 39/39 cases passed (42 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/2334.subarray-with-elements-greater-than-varying-threshold.kt
# - Downloading subarray-with-elements-greater-than-varying-threshold
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 142: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 2: Char 142: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 362: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 2: Char 607: ERROR: Unresolved reference 'it'.
# Line 2: Char 615: ERROR: Unresolved reference 'it'.
# Line 38: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2335.minimum-amount-of-time-to-fill-cups.kt
# - Downloading minimum-amount-of-time-to-fill-cups
#   ✔ Accepted
#   ✔ 280/280 cases passed (17 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2336.smallest-number-in-infinite-set.kt
# - Downloading smallest-number-in-infinite-set
#   ✔ Accepted
#   ✔ 138/138 cases passed (27 ms)
#   ✔ Your runtime beats 64 % of kotlin submissions
#   ✔ Your memory usage beats 94 % of kotlin submissions (49.2 MB)
# Submitting: kotlin_solutions_1/2337.move-pieces-to-obtain-a-string.kt
# - Downloading move-pieces-to-obtain-a-string
#   ✔ Accepted
#   ✔ 139/139 cases passed (144 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (61 MB)
# Submitting: kotlin_solutions_1/2338.count-the-number-of-ideal-arrays.kt
# - Downloading count-the-number-of-ideal-arrays
#   ✔ Accepted
#   ✔ 47/47 cases passed (119 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (59.1 MB)
# Submitting: kotlin_solutions_1/2341.maximum-number-of-pairs-in-array.kt
# - Downloading maximum-number-of-pairs-in-array
#   ✔ Accepted
#   ✔ 128/128 cases passed (7 ms)
#   ✔ Your runtime beats 75 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (42.7 MB)
# Submitting: kotlin_solutions_1/2342.max-sum-of-a-pair-with-equal-sum-of-digits.kt
# - Downloading max-sum-of-a-pair-with-equal-sum-of-digits
#   ✔ Accepted
#   ✔ 84/84 cases passed (199 ms)
#   ✔ Your runtime beats 60 % of kotlin submissions
#   ✔ Your memory usage beats 20 % of kotlin submissions (86.4 MB)
# Submitting: kotlin_solutions_1/2343.query-kth-smallest-trimmed-number.kt
# - Downloading query-kth-smallest-trimmed-number
#   ✔ Accepted
#   ✔ 251/251 cases passed (271 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (59.9 MB)
# Submitting: kotlin_solutions_1/2344.minimum-deletions-to-make-array-divisible.kt
# - Downloading minimum-deletions-to-make-array-divisible
#   ✔ Accepted
#   ✔ 49/49 cases passed (112 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (63.2 MB)
# Submitting: kotlin_solutions_1/2347.best-poker-hand.kt
# - Downloading best-poker-hand
#   ✔ Accepted
#   ✔ 98/98 cases passed (20 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2348.number-of-zero-filled-subarrays.kt
# - Downloading number-of-zero-filled-subarrays
#   ✔ Accepted
#   ✔ 48/48 cases passed (29 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2349.design-a-number-container-system.kt
# - Downloading design-a-number-container-system
#   ✔ Accepted
#   ✔ 46/46 cases passed (153 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (138.6 MB)
# Submitting: kotlin_solutions_1/2350.shortest-impossible-sequence-of-rolls.kt
# - Downloading shortest-impossible-sequence-of-rolls
#   ✔ Accepted
#   ✔ 65/65 cases passed (49 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (64.8 MB)
# Submitting: kotlin_solutions_1/2351.first-letter-to-appear-twice.kt
# - Downloading first-letter-to-appear-twice
#   ✔ Accepted
#   ✔ 92/92 cases passed (8 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 6.67 % of kotlin submissions (42.5 MB)
# Submitting: kotlin_solutions_1/2352.equal-row-and-column-pairs.kt
# - Downloading equal-row-and-column-pairs
#   ✔ Accepted
#   ✔ 80/80 cases passed (86 ms)
#   ✔ Your runtime beats 15.38 % of kotlin submissions
#   ✔ Your memory usage beats 33.84 % of kotlin submissions (62.9 MB)
# Submitting: kotlin_solutions_1/2353.design-a-food-rating-system.kt
# - Downloading design-a-food-rating-system
#   ✔ Accepted
#   ✔ 80/80 cases passed (323 ms)
#   ✔ Your runtime beats 36.36 % of kotlin submissions
#   ✔ Your memory usage beats 9.09 % of kotlin submissions (108.8 MB)
# Submitting: kotlin_solutions_1/2354.number-of-excellent-pairs.kt
# - Downloading number-of-excellent-pairs
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 238: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 2: Char 238: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 244: ERROR: Unresolved reference 'j'.
# Line 2: Char 246: ERROR: 'operator' modifier is required on 'FirNamedFunctionSymbol kotlin/compareTo' in 'compareTo'.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2357.make-array-zero-by-subtracting-equal-amounts.kt
# - Downloading make-array-zero-by-subtracting-equal-amounts
#   ✔ Accepted
#   ✔ 95/95 cases passed (8 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (41.9 MB)
# Submitting: kotlin_solutions_1/2358.maximum-number-of-groups-entering-a-competition.kt
# - Downloading maximum-number-of-groups-entering-a-competition
#   ✔ Accepted
#   ✔ 69/69 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (61.4 MB)
# Submitting: kotlin_solutions_1/2359.find-closest-node-to-given-two-nodes.kt
# - Downloading find-closest-node-to-given-two-nodes
#   ✔ Accepted
#   ✔ 78/78 cases passed (144 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (80.7 MB)
# Submitting: kotlin_solutions_1/2360.longest-cycle-in-a-graph.kt
# - Downloading longest-cycle-in-a-graph
#   ✔ Accepted
#   ✔ 81/81 cases passed (132 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (65.1 MB)
# Submitting: kotlin_solutions_1/2363.merge-similar-items.kt
# - Downloading merge-similar-items
#   ✔ Accepted
#   ✔ 49/49 cases passed (33 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (55.2 MB)
# Submitting: kotlin_solutions_1/2364.count-number-of-bad-pairs.kt
# - Downloading count-number-of-bad-pairs
#   ✔ Accepted
#   ✔ 65/65 cases passed (71 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2365.task-scheduler-ii.kt
# - Downloading task-scheduler-ii
#   ✔ Accepted
#   ✔ 61/61 cases passed (65 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (62.2 MB)
# Submitting: kotlin_solutions_1/2366.minimum-replacements-to-sort-the-array.kt
# - Downloading minimum-replacements-to-sort-the-array
#   ✔ Accepted
#   ✔ 48/48 cases passed (56 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (66.3 MB)
# Submitting: kotlin_solutions_1/2367.number-of-arithmetic-triplets.kt
# - Downloading number-of-arithmetic-triplets
#   ✔ Accepted
#   ✔ 104/104 cases passed (15 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 13.33 % of kotlin submissions (46 MB)
# Submitting: kotlin_solutions_1/2368.reachable-nodes-with-restrictions.kt
# - Downloading reachable-nodes-with-restrictions
#   ✔ Accepted
#   ✔ 62/62 cases passed (193 ms)
#   ✔ Your runtime beats 30.77 % of kotlin submissions
#   ✔ Your memory usage beats 46.15 % of kotlin submissions (138.8 MB)
# Submitting: kotlin_solutions_1/2369.check-if-there-is-a-valid-partition-for-the-array.kt
# - Downloading check-if-there-is-a-valid-partition-for-the-array
#   ✔ Accepted
#   ✔ 118/118 cases passed (58 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (64.9 MB)
# Submitting: kotlin_solutions_1/2370.longest-ideal-subsequence.kt
# - Downloading longest-ideal-subsequence
#   ✔ Accepted
#   ✔ 85/85 cases passed (36 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2373.largest-local-values-in-a-matrix.kt
# - Downloading largest-local-values-in-a-matrix
#   ✔ Accepted
#   ✔ 50/50 cases passed (20 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (54.2 MB)
# Submitting: kotlin_solutions_1/2374.node-with-highest-edge-score.kt
# - Downloading node-with-highest-edge-score
#   ✔ Accepted
#   ✔ 118/118 cases passed (26 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2375.construct-smallest-number-from-di-string.kt
# - Downloading construct-smallest-number-from-di-string
#   ✔ Accepted
#   ✔ 104/104 cases passed (12 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (42.4 MB)
# Submitting: kotlin_solutions_1/2376.count-special-integers.kt
# - Downloading count-special-integers
#   ✔ Accepted
#   ✔ 120/120 cases passed (12 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (42.4 MB)
# Submitting: kotlin_solutions_1/2379.minimum-recolors-to-get-k-consecutive-black-blocks.kt
# - Downloading minimum-recolors-to-get-k-consecutive-black-blocks
#   ✔ Accepted
#   ✔ 122/122 cases passed (9 ms)
#   ✔ Your runtime beats 17.65 % of kotlin submissions
#   ✔ Your memory usage beats 17.65 % of kotlin submissions (41.4 MB)
# Submitting: kotlin_solutions_1/2380.time-needed-to-rearrange-a-binary-string.kt
# - Downloading time-needed-to-rearrange-a-binary-string
#   ✔ Accepted
#   ✔ 103/103 cases passed (11 ms)
#   ✔ Your runtime beats 75 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (44.6 MB)
# Submitting: kotlin_solutions_1/2381.shifting-letters-ii.kt
# - Downloading shifting-letters-ii
#   ✔ Accepted
#   ✔ 39/39 cases passed (25 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (86.7 MB)
# Submitting: kotlin_solutions_1/2382.maximum-segment-sum-after-removals.kt
# - Downloading maximum-segment-sum-after-removals
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 654: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 2: Char 654: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 38: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2383.minimum-hours-of-training-to-win-a-competition.kt
# - Downloading minimum-hours-of-training-to-win-a-competition
#   ✔ Accepted
#   ✔ 111/111 cases passed (17 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2384.largest-palindromic-number.kt
# - Downloading largest-palindromic-number
#   ✔ Accepted
#   ✔ 67/67 cases passed (62 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (49.1 MB)
# Submitting: kotlin_solutions_1/2385.amount-of-time-for-binary-tree-to-be-infected.kt
# - Downloading amount-of-time-for-binary-tree-to-be-infected
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 224: WARNING: Parameter 'it: TreeNode' is never used, could be renamed to '_'.
#   ✘ Error: Line 2: Char 224: WARNING: Parameter 'it: TreeNode' is never used, could be renamed to '_'.
# Line 2: Char 269: ERROR: No value passed for parameter 'defaultValue'.
# Line 2: Char 278: ERROR: No receiver can be passed to this function or property.
# Line 2: Char 280: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char
ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 492: ERROR: Syntax error: Type expected.
# Line 2: Char 492: ERROR: Syntax error: Expecting '.' before a property name.
# Line 2: Char 493: ERROR: Syntax error: Expecting property name.
# Line 2: Char 494: ERROR: Too many arguments for 'fun <T, R> DeepRecursiveFunction<T, R>.invoke(value: T): R'.
# Line 2: Char 496: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 514: ERROR: Unresolved reference 'add'.
# Line 2: Char 520: ERROR: The expression cannot be a selector (cannot occur after a dot).
# Line 2: Char 523: ERROR: Syntax error: Expecting property name or receiver type.
# Line 2: Char 524: ERROR: Syntax error: Expecting ')'.
# Line 2: Char 527: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 532: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 532: WARNING: Parameter 'it: <ERROR TYPE REF: Cannot infer argument for type parameter T>' is never used, could be renamed to '_'.
# Line 2: Char 544: ERROR: Syntax error: Expecting ')'.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2386.find-the-k-sum-of-an-array.kt
# - Downloading find-the-k-sum-of-an-array
#   ✔ Accepted
#   ✔ 111/111 cases passed (196 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (72.3 MB)
# Submitting: kotlin_solutions_1/2389.longest-subsequence-with-limited-sum.kt
# - Downloading longest-subsequence-with-limited-sum
#   ✔ Accepted
#   ✔ 57/57 cases passed (53 ms)
#   ✔ Your runtime beats 5.56 % of kotlin submissions
#   ✔ Your memory usage beats 5.56 % of kotlin submissions (51.3 MB)
# Submitting: kotlin_solutions_1/2390.removing-stars-from-a-string.kt
# - Downloading removing-stars-from-a-string
#   ✔ Accepted
#   ✔ 65/65 cases passed (25 ms)
#   ✔ Your runtime beats 74.42 % of kotlin submissions
#   ✔ Your memory usage beats 77.91 % of kotlin submissions (47.7 MB)
# Submitting: kotlin_solutions_1/2391.minimum-amount-of-time-to-collect-garbage.kt
# - Downloading minimum-amount-of-time-to-collect-garbage
#   ✔ Accepted
#   ✔ 75/75 cases passed (33 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (71.1 MB)
# Submitting: kotlin_solutions_1/2392.build-a-matrix-with-conditions.kt
# - Downloading build-a-matrix-with-conditions
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 287: ERROR: Argument type mismatch: actual type is 'kotlin.Function1<kotlin.Int, kotlin.Unit>', but 'kotlin.Function1<kotlin.Int, kotlin.Boolean>' was expected.
#   ✘ Error: Line 2: Char 287: ERROR: Argument type mismatch: actual type is 'kotlin.Function1<kotlin.Int, kotlin.Unit>', but 'kotlin.Function1<kotlin.Int, kotlin.Boolean>' was expected.
# Line 2: Char 329: ERROR: Argument type mismatch: actual type is 'kotlin.Boolean', but 'kotlin.Int' was expected.
# Line 2: Char 435: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 516: WARNING: Parameter 'it: Boolean' is never used, could be renamed to '_'.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2395.find-subarrays-with-equal-sum.kt
# - Downloading find-subarrays-with-equal-sum
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 68: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
#   ✘ Error: Line 2: Char 68: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun CharSequence.zipWithNext(): List<Pair<Char, Char>>
# Line 2: Char 82: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 85: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2396.strictly-palindromic-number.kt
# - Downloading strictly-palindromic-number
#   ✔ Accepted
#   ✔ 67/67 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (40 MB)
# Submitting: kotlin_solutions_1/2397.maximum-rows-covered-by-columns.kt
# - Downloading maximum-rows-covered-by-columns
#   ✔ Accepted
#   ✔ 103/103 cases passed (12 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (42.8 MB)
# Submitting: kotlin_solutions_1/2398.maximum-number-of-robots-within-budget.kt
# - Downloading maximum-number-of-robots-within-budget
#   ✔ Accepted
#   ✔ 82/82 cases passed (187 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (62.6 MB)
# Submitting: kotlin_solutions_1/2399.check-distances-between-same-letters.kt
# - Downloading check-distances-between-same-letters
#   ✔ Accepted
#   ✔ 335/335 cases passed (12 ms)
#   ✔ Your runtime beats 28.57 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (47.1 MB)
# Submitting: kotlin_solutions_1/2400.number-of-ways-to-reach-a-position-after-exactly-k-steps.kt
# - Downloading number-of-ways-to-reach-a-position-after-exactly-k-steps
#   ✔ Accepted
#   ✔ 35/35 cases passed (47 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (46.6 MB)
# Submitting: kotlin_solutions_1/2401.longest-nice-subarray.kt
# - Downloading longest-nice-subarray
#   ✔ Accepted
#   ✔ 66/66 cases passed (103 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2402.meeting-rooms-iii.kt
# - Downloading meeting-rooms-iii
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 94: WARNING: Parameter 't: LongArray' is never used, could be renamed to '_'.
#   ✘ Error: Line 2: Char 94: WARNING: Parameter 't: LongArray' is never used, could be renamed to '_'.
# Line 2: Char 395: WARNING: Parameter 'it: Pair<Long, Int>' is never used, could be renamed to '_'.
# Line 38: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2404.most-frequent-even-element.kt
# - Downloading most-frequent-even-element
#   ✔ Accepted
#   ✔ 219/219 cases passed (57 ms)
#   ✔ Your runtime beats 11.11 % of kotlin submissions
#   ✔ Your memory usage beats 22.22 % of kotlin submissions (49.7 MB)
# Submitting: kotlin_solutions_1/2405.optimal-partition-of-string.kt
# - Downloading optimal-partition-of-string
#   ✔ Accepted
#   ✔ 62/62 cases passed (37 ms)
#   ✔ Your runtime beats 22.22 % of kotlin submissions
#   ✔ Your memory usage beats 22.22 % of kotlin submissions (47.8 MB)
# Submitting: kotlin_solutions_1/2406.divide-intervals-into-minimum-number-of-groups.kt
# - Downloading divide-intervals-into-minimum-number-of-groups
#   ✔ Accepted
#   ✔ 35/35 cases passed (268 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (108.4 MB)
# Submitting: kotlin_solutions_1/2407.longest-increasing-subsequence-ii.kt
# - Downloading longest-increasing-subsequence-ii
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 7: Char 303: WARNING: Parameter '<unused var>: IntArray' is never used, could be renamed to '_'.
#   ✘ Error: Line 7: Char 303: WARNING: Parameter '<unused var>: IntArray' is never used, could be renamed to '_'.
# Line 7: Char 526: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 43: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2409.count-days-spent-together.kt
# - Downloading count-days-spent-together
#   ✔ Accepted
#   ✔ 51/51 cases passed (15 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2410.maximum-matching-of-players-with-trainers.kt
# - Downloading maximum-matching-of-players-with-trainers
#   ✔ Accepted
#   ✔ 36/36 cases passed (137 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2411.smallest-subarrays-with-maximum-bitwise-or.kt
# - Downloading smallest-subarrays-with-maximum-bitwise-or
#   ✔ Accepted
#   ✔ 59/59 cases passed (73 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (62.6 MB)
# Submitting: kotlin_solutions_1/2412.minimum-money-required-before-transactions.kt
# - Downloading minimum-money-required-before-transactions
#   ✔ Accepted
#   ✔ 56/56 cases passed (21 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (109.4 MB)
# Submitting: kotlin_solutions_1/2413.smallest-even-multiple.kt
# - Downloading smallest-even-multiple
#   ✔ Accepted
#   ✔ 150/150 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 29.41 % of kotlin submissions (40.3 MB)
# Submitting: kotlin_solutions_1/2414.length-of-the-longest-alphabetical-continuous-substring.kt
# - Downloading length-of-the-longest-alphabetical-continuous-substring
#   ✔ Accepted
#   ✔ 123/123 cases passed (47 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (48 MB)
# Submitting: kotlin_solutions_1/2415.reverse-odd-levels-of-binary-tree.kt
# - Downloading reverse-odd-levels-of-binary-tree
#   ✔ Accepted
#   ✔ 57/57 cases passed (51 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2416.sum-of-prefix-scores-of-strings.kt
# - Downloading sum-of-prefix-scores-of-strings
#   ✔ Accepted
#   ✔ 38/38 cases passed (230 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (173.2 MB)
# Submitting: kotlin_solutions_1/2418.sort-the-people.kt
# - Downloading sort-the-people
#   ✔ Accepted
#   ✔ 68/68 cases passed (34 ms)
#   ✔ Your runtime beats 11.11 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (50.2 MB)
# Submitting: kotlin_solutions_1/2419.longest-subarray-with-maximum-bitwise-and.kt
# - Downloading longest-subarray-with-maximum-bitwise-and
#   ✔ Accepted
#   ✔ 53/53 cases passed (35 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2420.find-all-good-indices.kt
# - Downloading find-all-good-indices
#   ✔ Accepted
#   ✔ 68/68 cases passed (17 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (64.9 MB)
# Submitting: kotlin_solutions_1/2421.number-of-good-paths.kt
# - Downloading number-of-good-paths
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 7: Char 155: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 7: Char 155: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 43: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2423.remove-letter-to-equalize-frequency.kt
# - Downloading remove-letter-to-equalize-frequency
#   ✔ Accepted
#   ✔ 51/51 cases passed (28 ms)
#   ✔ Your runtime beats 12.5 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (46.3 MB)
# Submitting: kotlin_solutions_1/2424.longest-uploaded-prefix.kt
# - Downloading longest-uploaded-prefix
#   ✔ Accepted
#   ✔ 24/24 cases passed (66 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 75 % of kotlin submissions (160.2 MB)
# Submitting: kotlin_solutions_1/2425.bitwise-xor-of-all-pairings.kt
# - Downloading bitwise-xor-of-all-pairings
#   ✔ Accepted
#   ✔ 42/42 cases passed (11 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (62 MB)
# Submitting: kotlin_solutions_1/2426.number-of-pairs-satisfying-inequality.kt
# - Downloading number-of-pairs-satisfying-inequality
#   ✔ Accepted
#   ✔ 61/61 cases passed (226 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (67.3 MB)
# Submitting: kotlin_solutions_1/2427.number-of-common-factors.kt
# - Downloading number-of-common-factors
#   ✔ Accepted
#   ✔ 76/76 cases passed (5 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2428.maximum-sum-of-an-hourglass.kt
# - Downloading maximum-sum-of-an-hourglass
#   ✔ Accepted
#   ✔ 41/41 cases passed (16 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2429.minimize-xor.kt
# - Downloading minimize-xor
#   ✔ Accepted
#   ✔ 280/280 cases passed (8 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2430.maximum-deletions-on-a-string.kt
# - Downloading maximum-deletions-on-a-string
#   ✔ Accepted
#   ✔ 129/129 cases passed (638 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (217.1 MB)
# Submitting: kotlin_solutions_1/2432.the-employee-that-worked-on-the-longest-task.kt
# - Downloading the-employee-that-worked-on-the-longest-task
#   ✔ Accepted
#   ✔ 514/514 cases passed (22 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (66.4 MB)
# Submitting: kotlin_solutions_1/2433.find-the-original-array-of-prefix-xor.kt
# - Downloading find-the-original-array-of-prefix-xor
#   ✔ Accepted
#   ✔ 46/46 cases passed (3 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (71.5 MB)
# Submitting: kotlin_solutions_1/2434.using-a-robot-to-print-the-lexicographically-smallest-string.kt
# - Downloading using-a-robot-to-print-the-lexicographically-smallest-string
#   ✔ Accepted
#   ✔ 62/62 cases passed (122 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (51.6 MB)
# Submitting: kotlin_solutions_1/2435.paths-in-matrix-whose-sum-is-divisible-by-k.kt
# - Downloading paths-in-matrix-whose-sum-is-divisible-by-k
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 6: Char 94: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 6: Char 94: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 6: Char 523: ERROR: Unresolved reference 'it'.
# Line 6: Char 523: ERROR: Argument type mismatch: actual type is 'V?', but 'kotlin.Int' was expected.
# Line 6: Char 523: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 42: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2438.range-product-queries-of-powers.kt
# - Downloading range-product-queries-of-powers
#   ✔ Accepted
#   ✔ 70/70 cases passed (62 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (97.6 MB)
# Submitting: kotlin_solutions_1/2439.minimize-maximum-of-array.kt
# - Downloading minimize-maximum-of-array
#   ✔ Accepted
#   ✔ 68/68 cases passed (22 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (68.3 MB)
# Submitting: kotlin_solutions_1/2440.create-components-with-same-value.kt
# - Downloading create-components-with-same-value
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 6: Char 125: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 6: Char 125: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 6: Char 204: WARNING: Parameter 'it: Boolean' is never used, could be renamed to '_'.
# Line 6: Char 601: ERROR: Unresolved reference 'callRecursive'.
# Line 42: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2442.count-number-of-distinct-integers-after-reverse-operations.kt
# - Downloading count-number-of-distinct-integers-after-reverse-operations
#   ✔ Accepted
#   ✔ 44/44 cases passed (159 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2443.sum-of-number-and-its-reverse.kt
# - Downloading sum-of-number-and-its-reverse
#   ✔ Accepted
#   ✔ 258/258 cases passed (321 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (48.6 MB)
# Submitting: kotlin_solutions_1/2444.count-subarrays-with-fixed-bounds.kt
# - Downloading count-subarrays-with-fixed-bounds
#   ✔ Accepted
#   ✔ 53/53 cases passed (33 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2462.total-cost-to-hire-k-workers.kt
# - Downloading total-cost-to-hire-k-workers
#   ✔ Accepted
#   ✔ 163/163 cases passed (160 ms)
#   ✔ Your runtime beats 9.68 % of kotlin submissions
#   ✔ Your memory usage beats 12.9 % of kotlin submissions (74.8 MB)
# Submitting: kotlin_solutions_1/2463.minimum-total-distance-traveled.kt
# - Downloading minimum-total-distance-traveled
#   ✘ Wrong Answer
#   ✘ 4/40 cases passed (N/A)
#   ✘ Testcase: [0,4,6]
# [[2,2],[6,2]]
#   ✘ Answer: 8
#   ✘ Expected Answer: 4
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2466.count-ways-to-build-good-strings.kt
# - Downloading count-ways-to-build-good-strings
#   ✔ Accepted
#   ✔ 36/36 cases passed (14 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2467.most-profitable-path-in-a-tree.kt
# - Downloading most-profitable-path-in-a-tree
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 263: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 2: Char 263: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 505: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 538: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 561: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 2: Char 575: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 1122: ERROR: Unresolved reference 'callRecursive'.
# Line 40: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-08-17 18:47:43
