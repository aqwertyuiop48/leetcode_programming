# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME_3')
    user_cookie = userdata.get('LEETCODE_TOKEN_3')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME_3'] = user_name
    os.environ['LEETCODE_TOKEN_3'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME_3" "$LEETCODE_TOKEN_3" | leetcode user -c

# %%
# %%bash
#
# # top 400-500 answers (5th batch)
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v kotlin_solutions_1/*.kt | sed -n '1001,1100p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 7
# done
# Out:
# Submitting: kotlin_solutions_1/2549.count-distinct-numbers-on-board.kt
# - Downloading problems
# - Downloading count-distinct-numbers-on-board
#   ✔ Accepted
#   ✔ 100/100 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 20 % of kotlin submissions (40.2 MB)
# Submitting: kotlin_solutions_1/2550.count-collisions-of-monkeys-on-a-polygon.kt
# - Downloading count-collisions-of-monkeys-on-a-polygon
#   ✔ Accepted
#   ✔ 83/83 cases passed (5 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2551.put-marbles-in-bags.kt
# - Downloading put-marbles-in-bags
#   ✔ Accepted
#   ✔ 103/103 cases passed (296 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2552.count-increasing-quadruplets.kt
# - Downloading count-increasing-quadruplets
#   ✔ Accepted
#   ✔ 121/121 cases passed (87 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (50.5 MB)
# Submitting: kotlin_solutions_1/2554.maximum-number-of-integers-to-choose-from-a-range-i.kt
# - Downloading maximum-number-of-integers-to-choose-from-a-range-i
#   ✔ Accepted
#   ✔ 208/208 cases passed (87 ms)
#   ✔ Your runtime beats 24.14 % of kotlin submissions
#   ✔ Your memory usage beats 13.79 % of kotlin submissions (64.2 MB)
# Submitting: kotlin_solutions_1/2556.disconnect-path-in-a-binary-matrix-by-at-most-one-flip.kt
# - Downloading disconnect-path-in-a-binary-matrix-by-at-most-one-flip
#   ✔ Accepted
#   ✔ 55/55 cases passed (23 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (81 MB)
# Submitting: kotlin_solutions_1/2558.take-gifts-from-the-richest-pile.kt
# - Downloading take-gifts-from-the-richest-pile
# [ERROR] session expired, please login again [code=-1]
# Submitting: kotlin_solutions_1/2560.house-robber-iv.kt
# - Downloading house-robber-iv
#   ✔ Accepted
#   ✔ 64/64 cases passed (132 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (62.3 MB)
# Submitting: kotlin_solutions_1/2564.substring-xor-queries.kt
# - Downloading substring-xor-queries
#   ✔ Accepted
#   ✔ 59/59 cases passed (50 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (126.3 MB)
# Submitting: kotlin_solutions_1/2565.subsequence-with-the-minimum-score.kt
# - Downloading subsequence-with-the-minimum-score
#   ✔ Accepted
#   ✔ 54/54 cases passed (118 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (54.7 MB)
# Submitting: kotlin_solutions_1/2567.minimum-score-by-changing-two-elements.kt
# - Downloading minimum-score-by-changing-two-elements
#   ✔ Accepted
#   ✔ 70/70 cases passed (128 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (61.6 MB)
# Submitting: kotlin_solutions_1/2568.minimum-impossible-or.kt
# - Downloading minimum-impossible-or
#   ✔ Accepted
#   ✔ 73/73 cases passed (41 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (63.2 MB)
# Submitting: kotlin_solutions_1/2571.minimum-operations-to-reduce-an-integer-to-0.kt
# - Downloading minimum-operations-to-reduce-an-integer-to-0
#   ✔ Accepted
#   ✔ 41/41 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (39.7 MB)
# Submitting: kotlin_solutions_1/2572.count-the-number-of-square-free-subsets.kt
# - Downloading count-the-number-of-square-free-subsets
#   ✔ Accepted
#   ✔ 44/44 cases passed (36 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (47.9 MB)
# Submitting: kotlin_solutions_1/2576.find-the-maximum-number-of-marked-indices.kt
# - Downloading find-the-maximum-number-of-marked-indices
#   ✔ Accepted
#   ✔ 68/68 cases passed (254 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (66.3 MB)
# Submitting: kotlin_solutions_1/2577.minimum-time-to-visit-a-cell-in-a-grid.kt
# - Downloading minimum-time-to-visit-a-cell-in-a-grid
#   ✔ Accepted
#   ✔ 42/42 cases passed (300 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (71.5 MB)
# Submitting: kotlin_solutions_1/2579.count-total-number-of-colored-cells.kt
# - Downloading count-total-number-of-colored-cells
#   ✔ Accepted
#   ✔ 94/94 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/2580.count-ways-to-group-overlapping-ranges.kt
# - Downloading count-ways-to-group-overlapping-ranges
#   ✔ Accepted
#   ✔ 32/32 cases passed (61 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2581.count-number-of-possible-root-nodes.kt
# - Downloading count-number-of-possible-root-nodes
#   ✔ Accepted
#   ✔ 52/52 cases passed (207 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2584.split-the-array-to-make-coprime-products.kt
# - Downloading split-the-array-to-make-coprime-products
#   ✔ Accepted
#   ✔ 75/75 cases passed (670 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (58.3 MB)
# Submitting: kotlin_solutions_1/2585.number-of-ways-to-earn-points.kt
# - Downloading number-of-ways-to-earn-points
#   ✔ Accepted
#   ✔ 63/63 cases passed (106 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2588.count-the-number-of-beautiful-subarrays.kt
# - Downloading count-the-number-of-beautiful-subarrays
#   ✔ Accepted
#   ✔ 114/114 cases passed (104 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2591.distribute-money-to-maximum-children.kt
# - Downloading distribute-money-to-maximum-children
#   ✔ Accepted
#   ✔ 3802/3802 cases passed (2 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (42.9 MB)
# Submitting: kotlin_solutions_1/2592.maximize-greatness-of-an-array.kt
# - Downloading maximize-greatness-of-an-array
#   ✔ Accepted
#   ✔ 1072/1072 cases passed (59 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2593.find-score-of-an-array-after-marking-all-elements.kt
# - Downloading find-score-of-an-array-after-marking-all-elements
#   ✔ Accepted
#   ✔ 1044/1044 cases passed (215 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2594.minimum-time-to-repair-cars.kt
# - Downloading minimum-time-to-repair-cars
#   ✔ Accepted
#   ✔ 1072/1072 cases passed (65 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (61.3 MB)
# Submitting: kotlin_solutions_1/2596.check-knight-tour-configuration.kt
# - Downloading check-knight-tour-configuration
#   ✔ Accepted
#   ✔ 1029/1029 cases passed (8 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (50.6 MB)
# Submitting: kotlin_solutions_1/2597.the-number-of-beautiful-subsets.kt
# - Downloading the-number-of-beautiful-subsets
#   ✔ Accepted
#   ✔ 1308/1308 cases passed (1115 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2601.prime-subtraction-operation.kt
# - Downloading prime-subtraction-operation
#   ✔ Accepted
#   ✔ 654/654 cases passed (39 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (49.6 MB)
# Submitting: kotlin_solutions_1/2602.minimum-operations-to-make-all-array-elements-equal.kt
# - Downloading minimum-operations-to-make-all-array-elements-equal
#   ✔ Accepted
#   ✔ 31/31 cases passed (681 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (69.9 MB)
# Submitting: kotlin_solutions_1/2606.find-the-substring-with-maximum-cost.kt
# - Downloading find-the-substring-with-maximum-cost
#   ✔ Accepted
#   ✔ 1054/1054 cases passed (24 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (49.1 MB)
# Submitting: kotlin_solutions_1/2607.make-k-subarray-sums-equal.kt
# - Downloading make-k-subarray-sums-equal
#   ✔ Accepted
#   ✔ 1040/1040 cases passed (287 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (91.9 MB)
# Submitting: kotlin_solutions_1/2610.convert-an-array-into-a-2d-array-with-conditions.kt
# - Downloading convert-an-array-into-a-2d-array-with-conditions
#   ✔ Accepted
#   ✔ 1035/1035 cases passed (35 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2611.mice-and-cheese.kt
# - Downloading mice-and-cheese
#   ✔ Accepted
#   ✔ 564/564 cases passed (108 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (69.7 MB)
# Submitting: kotlin_solutions_1/2612.minimum-reverse-operations.kt
# - Downloading minimum-reverse-operations
#   ✔ Accepted
#   ✔ 711/711 cases passed (322 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (100.2 MB)
# Submitting: kotlin_solutions_1/2614.prime-in-diagonal.kt
# - Downloading prime-in-diagonal
#   ✔ Accepted
#   ✔ 82/82 cases passed (38 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
#   ✔ Your memory usage beats 40 % of kotlin submissions (71.8 MB)
# Submitting: kotlin_solutions_1/2639.find-the-width-of-columns-of-a-grid.kt
# - Downloading find-the-width-of-columns-of-a-grid
#   ✔ Accepted
#   ✔ 50/50 cases passed (23 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2645.minimum-additions-to-make-valid-string.kt
# - Downloading minimum-additions-to-make-valid-string
#   ✔ Accepted
#   ✔ 1523/1523 cases passed (11 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2646.minimize-the-total-price-of-the-trips.kt
# - Downloading minimize-the-total-price-of-the-trips
#   ✔ Accepted
#   ✔ 407/407 cases passed (81 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (67.7 MB)
# Submitting: kotlin_solutions_1/2653.sliding-subarray-beauty.kt
# - Downloading sliding-subarray-beauty
#   ✔ Accepted
#   ✔ 717/717 cases passed (331 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2654.minimum-number-of-operations-to-make-all-array-elements-equal-to-1.kt
# - Downloading minimum-number-of-operations-to-make-all-array-elements-equal-to-1
#   ✔ Accepted
#   ✔ 1070/1070 cases passed (36 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2658.maximum-number-of-fish-in-a-grid.kt
# - Downloading maximum-number-of-fish-in-a-grid
#   ✔ Accepted
#   ✔ 3842/3842 cases passed (58 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2659.make-array-empty.kt
# - Downloading make-array-empty
#   ✔ Accepted
#   ✔ 514/514 cases passed (119 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (79.8 MB)
# Submitting: kotlin_solutions_1/2660.determine-the-winner-of-a-bowling-game.kt
# - Downloading determine-the-winner-of-a-bowling-game
#   ✔ Accepted
#   ✔ 1206/1206 cases passed (19 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2663.lexicographically-smallest-beautiful-string.kt
# - Downloading lexicographically-smallest-beautiful-string
#   ✔ Accepted
#   ✔ 1054/1054 cases passed (56 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/2670.find-the-distinct-difference-array.kt
# - Downloading find-the-distinct-difference-array
#   ✔ Accepted
#   ✔ 4512/4512 cases passed (50 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2671.frequency-tracker.kt
# - Downloading frequency-tracker
#   ✔ Accepted
#   ✔ 1118/1118 cases passed (62 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (133.6 MB)
# Submitting: kotlin_solutions_1/2673.make-costs-of-paths-equal-in-a-binary-tree.kt
# - Downloading make-costs-of-paths-equal-in-a-binary-tree
#   ✔ Accepted
#   ✔ 1565/1565 cases passed (13 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (66.7 MB)
# Submitting: kotlin_solutions_1/2678.number-of-senior-citizens.kt
# - Downloading number-of-senior-citizens
#   ✔ Accepted
#   ✔ 303/303 cases passed (2 ms)
#   ✔ Your runtime beats 83.33 % of kotlin submissions
#   ✔ Your memory usage beats 16.67 % of kotlin submissions (44.2 MB)
# Submitting: kotlin_solutions_1/2679.sum-in-a-matrix.kt
# - Downloading sum-in-a-matrix
#   ✔ Accepted
#   ✔ 1057/1057 cases passed (36 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2680.maximum-or.kt
# - Downloading maximum-or
#   ✔ Accepted
#   ✔ 1215/1215 cases passed (27 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (64.6 MB)
# Submitting: kotlin_solutions_1/2681.power-of-heroes.kt
# - Downloading power-of-heroes
#   ✔ Accepted
#   ✔ 2584/2584 cases passed (64 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (79.3 MB)
# Submitting: kotlin_solutions_1/2683.neighboring-bitwise-xor.kt
# - Downloading neighboring-bitwise-xor
#   ✔ Accepted
#   ✔ 1425/1425 cases passed (5 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (87.7 MB)
# Submitting: kotlin_solutions_1/2684.maximum-number-of-moves-in-a-grid.kt
# - Downloading maximum-number-of-moves-in-a-grid
#   ✔ Accepted
#   ✔ 814/814 cases passed (85 ms)
#   ✔ Your runtime beats 12.5 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (79.1 MB)
# Submitting: kotlin_solutions_1/2696.minimum-string-length-after-removing-substrings.kt
# - Downloading minimum-string-length-after-removing-substrings
#   ✔ Accepted
#   ✔ 1542/1542 cases passed (6 ms)
#   ✔ Your runtime beats 90.91 % of kotlin submissions
#   ✔ Your memory usage beats 81.82 % of kotlin submissions (43.8 MB)
# Submitting: kotlin_solutions_1/2697.lexicographically-smallest-palindrome.kt
# - Downloading lexicographically-smallest-palindrome
#   ✔ Accepted
#   ✔ 4519/4519 cases passed (31 ms)
#   ✔ Your runtime beats 14.29 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (48.4 MB)
# Submitting: kotlin_solutions_1/2706.buy-two-chocolates.kt
# - Downloading buy-two-chocolates
#   ✔ Accepted
#   ✔ 2003/2003 cases passed (17 ms)
#   ✔ Your runtime beats 18.18 % of kotlin submissions
#   ✔ Your memory usage beats 36.36 % of kotlin submissions (48.3 MB)
# Submitting: kotlin_solutions_1/2707.extra-characters-in-a-string.kt
# - Downloading extra-characters-in-a-string
#   ✔ Accepted
#   ✔ 2028/2028 cases passed (73 ms)
#   ✔ Your runtime beats 27.27 % of kotlin submissions
#   ✔ Your memory usage beats 18.18 % of kotlin submissions (58.2 MB)
# Submitting: kotlin_solutions_1/2708.maximum-strength-of-a-group.kt
# - Downloading maximum-strength-of-a-group
#   ✔ Accepted
#   ✔ 2012/2012 cases passed (27 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/2710.remove-trailing-zeros-from-a-string.kt
# - Downloading remove-trailing-zeros-from-a-string
#   ✔ Accepted
#   ✔ 756/756 cases passed (15 ms)
#   ✔ Your runtime beats 9.09 % of kotlin submissions
#   ✔ Your memory usage beats 9.09 % of kotlin submissions (47.8 MB)
# Submitting: kotlin_solutions_1/2712.minimum-cost-to-make-all-characters-equal.kt
# - Downloading minimum-cost-to-make-all-characters-equal
#   ✔ Accepted
#   ✔ 1574/1574 cases passed (28 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2713.maximum-strictly-increasing-cells-in-a-matrix.kt
# - Downloading maximum-strictly-increasing-cells-in-a-matrix
#   ✔ Accepted
#   ✔ 566/566 cases passed (335 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (128.1 MB)
# Submitting: kotlin_solutions_1/2716.minimize-string-length.kt
# - Downloading minimize-string-length
#   ✔ Accepted
#   ✔ 5013/5013 cases passed (22 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 16.67 % of kotlin submissions (47.6 MB)
# Submitting: kotlin_solutions_1/2717.semi-ordered-permutation.kt
# - Downloading semi-ordered-permutation
#   ✔ Accepted
#   ✔ 1977/1977 cases passed (12 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 16.67 % of kotlin submissions (48 MB)
# Submitting: kotlin_solutions_1/2718.sum-of-matrix-after-queries.kt
# - Downloading sum-of-matrix-after-queries
#   ✔ Accepted
#   ✔ 2688/2688 cases passed (64 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (92.3 MB)
# Submitting: kotlin_solutions_1/2729.check-if-the-number-is-fascinating.kt
# - Downloading check-if-the-number-is-fascinating
#   ✔ Accepted
#   ✔ 900/900 cases passed (12 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2730.find-the-longest-semi-repetitive-substring.kt
# - Downloading find-the-longest-semi-repetitive-substring
#   ✔ Accepted
#   ✔ 12264/12264 cases passed (28 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2731.movement-of-robots.kt
# - Downloading movement-of-robots
#   ✔ Accepted
#   ✔ 2567/2567 cases passed (54 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (81.1 MB)
# Submitting: kotlin_solutions_1/2732.find-a-good-subset-of-the-matrix.kt
# - Downloading find-a-good-subset-of-the-matrix
#   ✔ Accepted
#   ✔ 685/685 cases passed (2100 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (85.9 MB)
# Submitting: kotlin_solutions_1/2733.neither-minimum-nor-maximum.kt
# - Downloading neither-minimum-nor-maximum
#   ✔ Accepted
#   ✔ 9558/9558 cases passed (24 ms)
#   ✔ Your runtime beats 14.29 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (69.6 MB)
# Submitting: kotlin_solutions_1/2734.lexicographically-smallest-string-after-substring-operation.kt
# - Downloading lexicographically-smallest-string-after-substring-operation
#   ✔ Accepted
#   ✔ 2241/2241 cases passed (76 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2735.collecting-chocolates.kt
# - Downloading collecting-chocolates
#   ✔ Accepted
#   ✔ 2564/2564 cases passed (89 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (56.4 MB)
# Submitting: kotlin_solutions_1/2739.total-distance-traveled.kt
# - Downloading total-distance-traveled
#   ✔ Accepted
#   ✔ 10000/10000 cases passed (4 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 10 % of kotlin submissions (45.9 MB)
# Submitting: kotlin_solutions_1/2740.find-the-value-of-the-partition.kt
# - Downloading find-the-value-of-the-partition
#   ✔ Accepted
#   ✔ 806/806 cases passed (189 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2741.special-permutations.kt
# - Downloading special-permutations
#   ✔ Accepted
#   ✔ 590/590 cases passed (393 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (53.3 MB)
# Submitting: kotlin_solutions_1/2742.painting-the-walls.kt
# - Downloading painting-the-walls
#   ✔ Accepted
#   ✔ 2559/2559 cases passed (40 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2744.find-maximum-number-of-string-pairs.kt
# - Downloading find-maximum-number-of-string-pairs
#   ✔ Accepted
#   ✔ 659/659 cases passed (27 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2745.construct-the-longest-new-string.kt
# - Downloading construct-the-longest-new-string
#   ✔ Accepted
#   ✔ 2003/2003 cases passed (1 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (41.2 MB)
# Submitting: kotlin_solutions_1/2746.decremental-string-concatenation.kt
# - Downloading decremental-string-concatenation
#   ✔ Accepted
#   ✔ 1332/1332 cases passed (123 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (53.3 MB)
# Submitting: kotlin_solutions_1/2747.count-zero-request-servers.kt
# - Downloading count-zero-request-servers
#   ✔ Accepted
#   ✔ 3129/3129 cases passed (93 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (138.1 MB)
# Submitting: kotlin_solutions_1/2748.number-of-beautiful-pairs.kt
# - Downloading number-of-beautiful-pairs
#   ✔ Accepted
#   ✔ 3005/3005 cases passed (117 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2749.minimum-operations-to-make-the-integer-zero.kt
# - Downloading minimum-operations-to-make-the-integer-zero
#   ✔ Accepted
#   ✔ 543/543 cases passed (4 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (40.8 MB)
# Submitting: kotlin_solutions_1/2750.ways-to-split-array-into-good-subarrays.kt
# - Downloading ways-to-split-array-into-good-subarrays
#   ✔ Accepted
#   ✔ 553/553 cases passed (72 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (82.6 MB)
# Submitting: kotlin_solutions_1/2751.robot-collisions.kt
# - Downloading robot-collisions
#   ✔ Accepted
#   ✔ 2433/2433 cases passed (103 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (91 MB)
# Submitting: kotlin_solutions_1/2760.longest-even-odd-subarray-with-threshold.kt
# - Downloading longest-even-odd-subarray-with-threshold
#   ✔ Accepted
#   ✔ 6873/6873 cases passed (89 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2761.prime-pairs-with-target-sum.kt
# - Downloading prime-pairs-with-target-sum
#   ✔ Accepted
#   ✔ 554/554 cases passed (192 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (81.2 MB)
# Submitting: kotlin_solutions_1/2762.continuous-subarrays.kt
# - Downloading continuous-subarrays
#   ✔ Accepted
#   ✔ 2139/2139 cases passed (737 ms)
#   ✔ Your runtime beats 11.11 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (75.7 MB)
# Submitting: kotlin_solutions_1/2765.longest-alternating-subarray.kt
# - Downloading longest-alternating-subarray
#   ✔ Accepted
#   ✔ 2880/2880 cases passed (41 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (51.6 MB)
# Submitting: kotlin_solutions_1/2766.relocate-marbles.kt
# - Downloading relocate-marbles
#   ✔ Accepted
#   ✔ 2129/2129 cases passed (101 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (90.5 MB)
# Submitting: kotlin_solutions_1/2767.partition-string-into-minimum-beautiful-substrings.kt
# - Downloading partition-string-into-minimum-beautiful-substrings
#   ✔ Accepted
#   ✔ 561/561 cases passed (71 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (50.1 MB)
# Submitting: kotlin_solutions_1/2768.number-of-black-blocks.kt
# - Downloading number-of-black-blocks
#   ✔ Accepted
#   ✔ 2145/2145 cases passed (367 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2769.find-the-maximum-achievable-number.kt
# - Downloading find-the-maximum-achievable-number
#   ✔ Accepted
#   ✔ 2502/2502 cases passed (1 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 23.08 % of kotlin submissions (41.7 MB)
# Submitting: kotlin_solutions_1/2770.maximum-number-of-jumps-to-reach-the-last-index.kt
# - Downloading maximum-number-of-jumps-to-reach-the-last-index
#   ✔ Accepted
#   ✔ 2639/2639 cases passed (45 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (50.5 MB)
# Submitting: kotlin_solutions_1/2771.longest-non-decreasing-subarray-from-two-arrays.kt
# - Downloading longest-non-decreasing-subarray-from-two-arrays
#   ✔ Accepted
#   ✔ 2973/2973 cases passed (71 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2772.apply-operations-to-make-all-array-elements-equal-to-zero.kt
# - Downloading apply-operations-to-make-all-array-elements-equal-to-zero
#   ✔ Accepted
#   ✔ 1029/1029 cases passed (26 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (68.8 MB)
# Submitting: kotlin_solutions_1/2778.sum-of-squares-of-special-elements.kt
# - Downloading sum-of-squares-of-special-elements
#   ✔ Accepted
#   ✔ 1437/1437 cases passed (19 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2779.maximum-beauty-of-an-array-after-applying-operation.kt
# - Downloading maximum-beauty-of-an-array-after-applying-operation
#   ✔ Accepted
#   ✔ 622/622 cases passed (236 ms)
#   ✔ Your runtime beats 14.29 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (90 MB)
# Submitting: kotlin_solutions_1/2780.minimum-index-of-a-valid-split.kt
# - Downloading minimum-index-of-a-valid-split
#   ✔ Accepted
#   ✔ 917/917 cases passed (101 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/2784.check-if-array-is-good.kt
# - Downloading check-if-array-is-good
#   ✔ Accepted
#   ✔ 838/838 cases passed (26 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 16.67 % of kotlin submissions (47.3 MB)
# Submitting: kotlin_solutions_1/2786.visit-array-positions-to-maximize-score.kt
# - Downloading visit-array-positions-to-maximize-score
#   ✔ Accepted
#   ✔ 744/744 cases passed (38 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (85.1 MB)

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-08-18 14:43:13
