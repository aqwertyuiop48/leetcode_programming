# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME_3')
    user_cookie = userdata.get('LEETCODE_TOKEN_3')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME_3'] = user_name
    os.environ['LEETCODE_TOKEN_3'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME_3" "$LEETCODE_TOKEN_3" | leetcode user -c

# %%
# %%bash
#
# # top 400-500 answers (5th batch)
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v kotlin_solutions_1/*.kt | sed -n '401,500p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 7
# done
# Out:
# Submitting: kotlin_solutions_1/1521.find-a-value-of-a-mysterious-function-closest-to-target.kt
# - Downloading find-a-value-of-a-mysterious-function-closest-to-target
#   ✔ Accepted
#   ✔ 43/43 cases passed (228 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1523.count-odd-numbers-in-an-interval-range.kt
# - Downloading count-odd-numbers-in-an-interval-range
#   ✔ Accepted
#   ✔ 84/84 cases passed (69 ms)
#   ✔ Your runtime beats 93.75 % of kotlin submissions
#   ✔ Your memory usage beats 6.25 % of kotlin submissions (39.5 MB)
# Submitting: kotlin_solutions_1/1524.number-of-sub-arrays-with-odd-sum.kt
# - Downloading number-of-sub-arrays-with-odd-sum
#   ✔ Accepted
#   ✔ 151/151 cases passed (38 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1525.number-of-good-ways-to-split-a-string.kt
# - Downloading number-of-good-ways-to-split-a-string
#   ✔ Accepted
#   ✔ 61/61 cases passed (28 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (47 MB)
# Submitting: kotlin_solutions_1/1526.minimum-number-of-increments-on-subarrays-to-form-a-target-array.kt
# - Downloading minimum-number-of-increments-on-subarrays-to-form-a-target-array
#   ✔ Accepted
#   ✔ 129/129 cases passed (7 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (60.2 MB)
# Submitting: kotlin_solutions_1/1528.shuffle-string.kt
# - Downloading shuffle-string
#   ✔ Accepted
#   ✔ 399/399 cases passed (1 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 61.76 % of kotlin submissions (45.6 MB)
# Submitting: kotlin_solutions_1/1529.minimum-suffix-flips.kt
# - Downloading minimum-suffix-flips
#   ✔ Accepted
#   ✔ 79/79 cases passed (29 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1530.number-of-good-leaf-nodes-pairs.kt
# - Downloading number-of-good-leaf-nodes-pairs
#   ✔ Accepted
#   ✔ 113/113 cases passed (69 ms)
#   ✔ Your runtime beats 40 % of kotlin submissions
#   ✔ Your memory usage beats 20 % of kotlin submissions (53 MB)
# Submitting: kotlin_solutions_1/1531.string-compression-ii.kt
# - Downloading string-compression-ii
#   ✔ Accepted
#   ✔ 144/144 cases passed (148 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1534.count-good-triplets.kt
# - Downloading count-good-triplets
#   ✔ Accepted
#   ✔ 92/92 cases passed (163 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1535.find-the-winner-of-an-array-game.kt
# - Downloading find-the-winner-of-an-array-game
#   ✔ Accepted
#   ✔ 185/185 cases passed (35 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1536.minimum-swaps-to-arrange-a-binary-grid.kt
# - Downloading minimum-swaps-to-arrange-a-binary-grid
#   ✔ Accepted
#   ✔ 130/130 cases passed (29 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1537.get-the-maximum-score.kt
# - Downloading get-the-maximum-score
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 7: Char 122: ERROR: Only expressions are allowed here.
#   ✘ Error: Line 7: Char 122: ERROR: Only expressions are allowed here.
# Line 7: Char 340: WARNING: Parameter 'it: Long' is never used, could be renamed to '_'.
# Line 7: Char 439: WARNING: Parameter 'it: Long' is never used, could be renamed to '_'.
# Line 7: Char 459: WARNING: Parameter 'it: Long' is never used, could be renamed to '_'.
# Line 7: Char 480: WARNING: Parameter 'it: Long' is never used, could be renamed to '_'.
# Line 7: Char 499: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 7: Char 499: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun <T> T.also(block: (T) -> Unit): T
#     [R|Contract description]
#      <
#         CallsInPlace(block, EXACTLY_ONCE)
#     >
# Line 7: Char 504: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 7: Char 504: WARNING: Parameter 'it: <ERROR TYPE REF: Cannot infer argument for type parameter T>' is never used, could be renamed to '_'.
# Line 7: Char 572: WARNING: Parameter 'it: Long' is never used, could be renamed to '_'.
# Line 7: Char 590: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 7: Char 590: ERROR: Not enough information to infer type argument for 'T'.
# Line 7: Char 595: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 7: Char 595: WARNING: Parameter 'it: <ERROR TYPE REF: Cannot infer argument for type parameter T>' is never used, could be renamed to '_'.
# Line 7: Char 663: WARNING: Parameter 'it: Long' is never used, could be renamed to '_'.
# Line 7: Char 681: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 7: Char 681: ERROR: Not enough information to infer type argument for 'T'.
# Line 7: Char 685: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 7: Char 685: WARNING: Parameter 'it: <ERROR TYPE REF: Cannot infer argument for type parameter T>' is never used, could be renamed to '_'.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1539.kth-missing-positive-number.kt
# - Downloading kth-missing-positive-number
#   ✔ Accepted
#   ✔ 87/87 cases passed (14 ms)
#   ✔ Your runtime beats 5.56 % of kotlin submissions
#   ✔ Your memory usage beats 5.56 % of kotlin submissions (46 MB)
# Submitting: kotlin_solutions_1/1540.can-convert-string-in-k-moves.kt
# - Downloading can-convert-string-in-k-moves
#   ✔ Accepted
#   ✔ 155/155 cases passed (31 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (48 MB)
# Submitting: kotlin_solutions_1/1541.minimum-insertions-to-balance-a-parentheses-string.kt
# - Downloading minimum-insertions-to-balance-a-parentheses-string
#   ✔ Accepted
#   ✔ 102/102 cases passed (31 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 83.33 % of kotlin submissions (46.6 MB)
# Submitting: kotlin_solutions_1/1542.find-longest-awesome-substring.kt
# - Downloading find-longest-awesome-substring
#   ✔ Accepted
#   ✔ 153/153 cases passed (41 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (47.7 MB)
# Submitting: kotlin_solutions_1/1544.make-the-string-great.kt
# - Downloading make-the-string-great
#   ✔ Accepted
#   ✔ 335/335 cases passed (12 ms)
#   ✔ Your runtime beats 53.85 % of kotlin submissions
#   ✔ Your memory usage beats 73.08 % of kotlin submissions (43.5 MB)
# Submitting: kotlin_solutions_1/1545.find-kth-bit-in-nth-binary-string.kt
# - Downloading find-kth-bit-in-nth-binary-string
#   ✔ Accepted
#   ✔ 63/63 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 37.5 % of kotlin submissions (40.6 MB)
# Submitting: kotlin_solutions_1/1546.maximum-number-of-non-overlapping-subarrays-with-sum-equals-target.kt
# - Downloading maximum-number-of-non-overlapping-subarrays-with-sum-equals-target
#   ✔ Accepted
#   ✔ 69/69 cases passed (72 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1547.minimum-cost-to-cut-a-stick.kt
# - Downloading minimum-cost-to-cut-a-stick
#   ✔ Accepted
#   ✔ 101/101 cases passed (41 ms)
#   ✔ Your runtime beats 27.27 % of kotlin submissions
#   ✔ Your memory usage beats 18.18 % of kotlin submissions (48.4 MB)
# Submitting: kotlin_solutions_1/1550.three-consecutive-odds.kt
# - Downloading three-consecutive-odds
#   ✔ Accepted
#   ✔ 38/38 cases passed (3 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (42.9 MB)
# Submitting: kotlin_solutions_1/1551.minimum-operations-to-make-array-equal.kt
# - Downloading minimum-operations-to-make-array-equal
#   ✔ Accepted
#   ✔ 301/301 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (40.6 MB)
# Submitting: kotlin_solutions_1/1552.magnetic-force-between-two-balls.kt
# - Downloading magnetic-force-between-two-balls
#   ✔ Accepted
#   ✔ 98/98 cases passed (143 ms)
#   ✔ Your runtime beats 9.09 % of kotlin submissions
#   ✔ Your memory usage beats 18.18 % of kotlin submissions (64 MB)
# Submitting: kotlin_solutions_1/1553.minimum-number-of-days-to-eat-n-oranges.kt
# - Downloading minimum-number-of-days-to-eat-n-oranges
#   ✔ Accepted
#   ✔ 176/176 cases passed (7 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1556.thousand-separator.kt
# - Downloading thousand-separator
#   ✔ Accepted
#   ✔ 69/69 cases passed (15 ms)
#   ✔ Your runtime beats 11.11 % of kotlin submissions
#   ✔ Your memory usage beats 11.11 % of kotlin submissions (43.1 MB)
# Submitting: kotlin_solutions_1/1557.minimum-number-of-vertices-to-reach-all-nodes.kt
# - Downloading minimum-number-of-vertices-to-reach-all-nodes
#   ✔ Accepted
#   ✔ 66/66 cases passed (42 ms)
#   ✔ Your runtime beats 27.27 % of kotlin submissions
#   ✔ Your memory usage beats 45.45 % of kotlin submissions (107.5 MB)
# Submitting: kotlin_solutions_1/1558.minimum-numbers-of-function-calls-to-make-target-array.kt
# - Downloading minimum-numbers-of-function-calls-to-make-target-array
#   ✔ Accepted
#   ✔ 58/58 cases passed (16 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 10 % of kotlin submissions (55.7 MB)
# Submitting: kotlin_solutions_1/1559.detect-cycles-in-2d-grid.kt
# - Downloading detect-cycles-in-2d-grid
#   ✔ Accepted
#   ✔ 78/78 cases passed (119 ms)
#   ✔ Your runtime beats 44.44 % of kotlin submissions
#   ✔ Your memory usage beats 55.56 % of kotlin submissions (105.3 MB)
# Submitting: kotlin_solutions_1/1560.most-visited-sector-in-a-circular-track.kt
# - Downloading most-visited-sector-in-a-circular-track
#   ✔ Accepted
#   ✔ 204/204 cases passed (20 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1561.maximum-number-of-coins-you-can-get.kt
# - Downloading maximum-number-of-coins-you-can-get
#   ✔ Accepted
#   ✔ 116/116 cases passed (236 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (61 MB)
# Submitting: kotlin_solutions_1/1562.find-latest-group-of-size-m.kt
# - Downloading find-latest-group-of-size-m
#   ✔ Accepted
#   ✔ 114/114 cases passed (49 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1563.stone-game-v.kt
# - Downloading stone-game-v
#   ✔ Accepted
#   ✔ 132/132 cases passed (445 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (50.3 MB)
# Submitting: kotlin_solutions_1/1566.detect-pattern-of-length-m-repeated-k-or-more-times.kt
# - Downloading detect-pattern-of-length-m-repeated-k-or-more-times
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 122: ERROR: None of the following candidates is applicable:
#   ✘ Error: Line 2: Char 122: ERROR: None of the following candidates is applicable:
# fun <T> Array<out T>.dropLast(n: Int): List<T>
# fun ByteArray.dropLast(n: Int): List<Byte>
# fun ShortArray.dropLast(n: Int): List<Short>
# fun IntArray.dropLast(n: Int): List<Int>
# fun LongArray.dropLast(n: Int): List<Long>
# fun FloatArray.dropLast(n: Int): List<Float>
# fun DoubleArray.dropLast(n: Int): List<Double>
# fun BooleanArray.dropLast(n: Int): List<Boolean>
# fun CharArray.dropLast(n: Int): List<Char>
# fun <T> List<T>.dropLast(n: Int): List<T>
# fun UIntArray.dropLast(n: Int): List<UInt>
# fun ULongArray.dropLast(n: Int): List<ULong>
# fun UByteArray.dropLast(n: Int): List<UByte>
# fun UShortArray.dropLast(n: Int): List<UShort>
# fun CharSequence.dropLast(n: Int): CharSequence
# fun String.dropLast(n: Int): String
# Line 2: Char 144: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 151: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 207: ERROR: Argument type mismatch: actual type is 'kotlin.IntArray', but 'kotlin.Int' was expected.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1567.maximum-length-of-subarray-with-positive-product.kt
# - Downloading maximum-length-of-subarray-with-positive-product
#   ✔ Accepted
#   ✔ 112/112 cases passed (39 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
#   ✔ Your memory usage beats 60 % of kotlin submissions (64.4 MB)
# Submitting: kotlin_solutions_1/1568.minimum-number-of-days-to-disconnect-island.kt
# - Downloading minimum-number-of-days-to-disconnect-island
#   ✔ Accepted
#   ✔ 104/104 cases passed (180 ms)
#   ✔ Your runtime beats 11.11 % of kotlin submissions
#   ✔ Your memory usage beats 22.22 % of kotlin submissions (51.6 MB)
# Submitting: kotlin_solutions_1/1569.number-of-ways-to-reorder-array-to-get-same-bst.kt
# - Downloading number-of-ways-to-reorder-array-to-get-same-bst
#   ✔ Accepted
#   ✔ 161/161 cases passed (120 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1572.matrix-diagonal-sum.kt
# - Downloading matrix-diagonal-sum
#   ✔ Accepted
#   ✔ 114/114 cases passed (13 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1573.number-of-ways-to-split-a-string.kt
# - Downloading number-of-ways-to-split-a-string
#   ✔ Accepted
#   ✔ 164/164 cases passed (36 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1574.shortest-subarray-to-be-removed-to-make-array-sorted.kt
# - Downloading shortest-subarray-to-be-removed-to-make-array-sorted
#   ✔ Accepted
#   ✔ 637/637 cases passed (34 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1575.count-all-possible-routes.kt
# - Downloading count-all-possible-routes
#   ✔ Accepted
#   ✔ 109/109 cases passed (275 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1576.replace-all-s-to-avoid-consecutive-repeating-characters.kt
# - Downloading replace-all-s-to-avoid-consecutive-repeating-characters
#   ✔ Accepted
#   ✔ 777/777 cases passed (21 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1577.number-of-ways-where-square-of-number-is-equal-to-product-of-two-numbers.kt
# - Downloading number-of-ways-where-square-of-number-is-equal-to-product-of-two-numbers
#   ✔ Accepted
#   ✔ 93/93 cases passed (57 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (49.9 MB)
# Submitting: kotlin_solutions_1/1578.minimum-time-to-make-rope-colorful.kt
# - Downloading minimum-time-to-make-rope-colorful
#   ✔ Accepted
#   ✔ 114/114 cases passed (45 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1579.remove-max-number-of-edges-to-keep-graph-fully-traversable.kt
# - Downloading remove-max-number-of-edges-to-keep-graph-fully-traversable
#   ✔ Accepted
#   ✔ 86/86 cases passed (120 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1582.special-positions-in-a-binary-matrix.kt
# - Downloading special-positions-in-a-binary-matrix
#   ✔ Accepted
#   ✔ 95/95 cases passed (25 ms)
#   ✔ Your runtime beats 11.11 % of kotlin submissions
#   ✔ Your memory usage beats 11.11 % of kotlin submissions (54.3 MB)
# Submitting: kotlin_solutions_1/1583.count-unhappy-friends.kt
# - Downloading count-unhappy-friends
#   ✔ Accepted
#   ✔ 99/99 cases passed (23 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 75 % of kotlin submissions (72.2 MB)
# Submitting: kotlin_solutions_1/1584.min-cost-to-connect-all-points.kt
# - Downloading min-cost-to-connect-all-points
#   ✔ Accepted
#   ✔ 72/72 cases passed (60 ms)
#   ✔ Your runtime beats 88.89 % of kotlin submissions
#   ✔ Your memory usage beats 88.89 % of kotlin submissions (49 MB)
# Submitting: kotlin_solutions_1/1585.check-if-string-is-transformable-with-substring-sort-operations.kt
# - Downloading check-if-string-is-transformable-with-substring-sort-operations
#   ✔ Accepted
#   ✔ 138/138 cases passed (63 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1588.sum-of-all-odd-length-subarrays.kt
# - Downloading sum-of-all-odd-length-subarrays
#   ✔ Accepted
#   ✔ 96/96 cases passed (13 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1589.maximum-sum-obtained-of-any-permutation.kt
# - Downloading maximum-sum-obtained-of-any-permutation
#   ✔ Accepted
#   ✔ 84/84 cases passed (177 ms)
#   ✔ Your runtime beats 12.5 % of kotlin submissions
#   ✔ Your memory usage beats 75 % of kotlin submissions (91.8 MB)
# Submitting: kotlin_solutions_1/1590.make-sum-divisible-by-p.kt
# - Downloading make-sum-divisible-by-p
#   ✔ Accepted
#   ✔ 145/145 cases passed (65 ms)
#   ✔ Your runtime beats 12.5 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (69.2 MB)
# Submitting: kotlin_solutions_1/1591.strange-printer-ii.kt
# - Downloading strange-printer-ii
#   ✔ Accepted
#   ✔ 153/153 cases passed (101 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1592.rearrange-spaces-between-words.kt
# - Downloading rearrange-spaces-between-words
#   ✔ Accepted
#   ✔ 90/90 cases passed (16 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 8.33 % of kotlin submissions (43.5 MB)
# Submitting: kotlin_solutions_1/1593.split-a-string-into-the-max-number-of-unique-substrings.kt
# - Downloading split-a-string-into-the-max-number-of-unique-substrings
#   ✔ Accepted
#   ✔ 96/96 cases passed (195 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (55 MB)
# Submitting: kotlin_solutions_1/1594.maximum-non-negative-product-in-a-matrix.kt
# - Downloading maximum-non-negative-product-in-a-matrix
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 41: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Error: Line 41: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1595.minimum-cost-to-connect-two-groups-of-points.kt
# - Downloading minimum-cost-to-connect-two-groups-of-points
#   ✔ Accepted
#   ✔ 84/84 cases passed (70 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1598.crawler-log-folder.kt
# - Downloading crawler-log-folder
#   ✔ Accepted
#   ✔ 99/99 cases passed (1 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (42.5 MB)
# Submitting: kotlin_solutions_1/1599.maximum-profit-of-operating-a-centennial-wheel.kt
# - Downloading maximum-profit-of-operating-a-centennial-wheel
#   ✔ Accepted
#   ✔ 145/145 cases passed (56 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1600.throne-inheritance.kt
# - Downloading throne-inheritance
#   ✔ Accepted
#   ✔ 49/49 cases passed (334 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (138.4 MB)
# Submitting: kotlin_solutions_1/1601.maximum-number-of-achievable-transfer-requests.kt
# - Downloading maximum-number-of-achievable-transfer-requests
#   ✔ Accepted
#   ✔ 117/117 cases passed (169 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1603.design-parking-system.kt
# - Downloading design-parking-system
#   ✔ Accepted
#   ✔ 102/102 cases passed (20 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 16.67 % of kotlin submissions (58 MB)
# Submitting: kotlin_solutions_1/1604.alert-using-same-key-card-three-or-more-times-in-a-one-hour-period.kt
# - Downloading alert-using-same-key-card-three-or-more-times-in-a-one-hour-period
#   ✔ Accepted
#   ✔ 78/78 cases passed (181 ms)
#   ✔ Your runtime beats 41.67 % of kotlin submissions
#   ✔ Your memory usage beats 8.33 % of kotlin submissions (98.2 MB)
# Submitting: kotlin_solutions_1/1605.find-valid-matrix-given-row-and-column-sums.kt
# - Downloading find-valid-matrix-given-row-and-column-sums
#   ✔ Accepted
#   ✔ 85/85 cases passed (9 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (54.6 MB)
# Submitting: kotlin_solutions_1/1606.find-servers-that-handled-most-number-of-requests.kt
# - Downloading find-servers-that-handled-most-number-of-requests
#   ✔ Accepted
#   ✔ 108/108 cases passed (279 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1608.special-array-with-x-elements-greater-than-or-equal-x.kt
# - Downloading special-array-with-x-elements-greater-than-or-equal-x
#   ✔ Accepted
#   ✔ 98/98 cases passed (5 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 75 % of kotlin submissions (41.3 MB)
# Submitting: kotlin_solutions_1/1609.even-odd-tree.kt
# - Downloading even-odd-tree
#   ✔ Accepted
#   ✔ 107/107 cases passed (77 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1610.maximum-number-of-visible-points.kt
# - Downloading maximum-number-of-visible-points
#   ✔ Accepted
#   ✔ 119/119 cases passed (333 ms)
#   ✔ Your runtime beats 42.86 % of kotlin submissions
#   ✔ Your memory usage beats 57.14 % of kotlin submissions (122.4 MB)
# Submitting: kotlin_solutions_1/1611.minimum-one-bit-operations-to-make-integers-zero.kt
# - Downloading minimum-one-bit-operations-to-make-integers-zero
#   ✔ Accepted
#   ✔ 308/308 cases passed (7 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1614.maximum-nesting-depth-of-the-parentheses.kt
# - Downloading maximum-nesting-depth-of-the-parentheses
#   ✔ Accepted
#   ✔ 168/168 cases passed (3 ms)
#   ✔ Your runtime beats 40 % of kotlin submissions
#   ✔ Your memory usage beats 53.33 % of kotlin submissions (41.1 MB)
# Submitting: kotlin_solutions_1/1615.maximal-network-rank.kt
# - Downloading maximal-network-rank
#   ✔ Accepted
#   ✔ 83/83 cases passed (72 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1616.split-two-strings-to-make-palindrome.kt
# - Downloading split-two-strings-to-make-palindrome
#   ✔ Accepted
#   ✔ 112/112 cases passed (26 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1617.count-subtrees-with-max-distance-between-cities.kt
# - Downloading count-subtrees-with-max-distance-between-cities
#   ✔ Accepted
#   ✔ 31/31 cases passed (325 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1619.mean-of-array-after-removing-some-elements.kt
# - Downloading mean-of-array-after-removing-some-elements
#   ✔ Accepted
#   ✔ 50/50 cases passed (25 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1620.coordinate-with-maximum-network-quality.kt
# - Downloading coordinate-with-maximum-network-quality
#   ✔ Accepted
#   ✔ 101/101 cases passed (58 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1621.number-of-sets-of-k-non-overlapping-line-segments.kt
# - Downloading number-of-sets-of-k-non-overlapping-line-segments
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 8: Char 266: ERROR: Unresolved reference 'longValue'.
#   ✘ Error: Line 8: Char 266: ERROR: Unresolved reference 'longValue'.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1622.fancy-sequence.kt
# - Downloading fancy-sequence
#   ✔ Accepted
#   ✔ 106/106 cases passed (87 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (125.6 MB)
# Submitting: kotlin_solutions_1/1624.largest-substring-between-two-equal-characters.kt
# - Downloading largest-substring-between-two-equal-characters
#   ✔ Accepted
#   ✔ 59/59 cases passed (11 ms)
#   ✔ Your runtime beats 14.29 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (42.5 MB)
# Submitting: kotlin_solutions_1/1625.lexicographically-smallest-string-after-applying-operations.kt
# - Downloading lexicographically-smallest-string-after-applying-operations
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 7: Char 181: ERROR: Unresolved reference 'call'.
#   ✘ Error: Line 7: Char 181: ERROR: Unresolved reference 'call'.
# Line 7: Char 181: ERROR: Argument type mismatch: actual type is 'T', but 'K' was expected.
# Line 7: Char 221: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 7: Char 226: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 7: Char 228: ERROR: Unresolved reference 'call'.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1626.best-team-with-no-conflicts.kt
# - Downloading best-team-with-no-conflicts
#   ✔ Accepted
#   ✔ 150/150 cases passed (202 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (64.6 MB)
# Submitting: kotlin_solutions_1/1627.graph-connectivity-with-threshold.kt
# - Downloading graph-connectivity-with-threshold
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 7: Char 190: ERROR: Argument type mismatch: actual type is 'kotlin.Int', but 'K' was expected.
#   ✘ Error: Line 7: Char 190: ERROR: Argument type mismatch: actual type is 'kotlin.Int', but 'K' was expected.
# Line 7: Char 197: ERROR: Unresolved reference 'call'.
# Line 7: Char 197: ERROR: Argument type mismatch: actual type is 'kotlin.Int', but 'K' was expected.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1629.slowest-key.kt
# - Downloading slowest-key
#   ✔ Accepted
#   ✔ 109/109 cases passed (23 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1630.arithmetic-subarrays.kt
# - Downloading arithmetic-subarrays
#   ✔ Accepted
#   ✔ 104/104 cases passed (123 ms)
#   ✔ Your runtime beats 10 % of kotlin submissions
#   ✔ Your memory usage beats 10 % of kotlin submissions (52.8 MB)
# Submitting: kotlin_solutions_1/1632.rank-transform-of-a-matrix.kt
# - Downloading rank-transform-of-a-matrix
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 7: Char 200: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 7: Char 200: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 7: Char 460: ERROR: Argument type mismatch: actual type is 'kotlin.Int', but 'K' was expected.
# Line 7: Char 467: ERROR: Unresolved reference 'call'.
# Line 7: Char 467: ERROR: Argument type mismatch: actual type is 'kotlin.Int', but 'K' was expected.
# Line 7: Char 619: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 7: Char 814: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 7: Char 840: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 41: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1636.sort-array-by-increasing-frequency.kt
# - Downloading sort-array-by-increasing-frequency
#   ✔ Accepted
#   ✔ 180/180 cases passed (31 ms)
#   ✔ Your runtime beats 18.18 % of kotlin submissions
#   ✔ Your memory usage beats 18.18 % of kotlin submissions (47.7 MB)
# Submitting: kotlin_solutions_1/1637.widest-vertical-area-between-two-points-containing-no-points.kt
# - Downloading widest-vertical-area-between-two-points-containing-no-points
#   ✔ Accepted
#   ✔ 56/56 cases passed (78 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (96.2 MB)
# Submitting: kotlin_solutions_1/1638.count-substrings-that-differ-by-one-character.kt
# - Downloading count-substrings-that-differ-by-one-character
#   ✔ Accepted
#   ✔ 63/63 cases passed (47 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1639.number-of-ways-to-form-a-target-string-given-a-dictionary.kt
# - Downloading number-of-ways-to-form-a-target-string-given-a-dictionary
#   ✔ Accepted
#   ✔ 90/90 cases passed (69 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1640.check-array-formation-through-concatenation.kt
# - Downloading check-array-formation-through-concatenation
#   ✔ Accepted
#   ✔ 85/85 cases passed (21 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1641.count-sorted-vowel-strings.kt
# - Downloading count-sorted-vowel-strings
#   ✔ Accepted
#   ✔ 41/41 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (39.8 MB)
# Submitting: kotlin_solutions_1/1642.furthest-building-you-can-reach.kt
# - Downloading furthest-building-you-can-reach
#   ✔ Accepted
#   ✔ 80/80 cases passed (36 ms)
#   ✔ Your runtime beats 12.5 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (60.6 MB)
# Submitting: kotlin_solutions_1/1643.kth-smallest-instructions.kt
# - Downloading kth-smallest-instructions
#   ✔ Accepted
#   ✔ 462/462 cases passed (10 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (43.5 MB)
# Submitting: kotlin_solutions_1/1646.get-maximum-in-generated-array.kt
# - Downloading get-maximum-in-generated-array
#   ✔ Accepted
#   ✔ 101/101 cases passed (15 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1647.minimum-deletions-to-make-character-frequencies-unique.kt
# - Downloading minimum-deletions-to-make-character-frequencies-unique
#   ✔ Accepted
#   ✔ 103/103 cases passed (88 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (48.2 MB)
# Submitting: kotlin_solutions_1/1648.sell-diminishing-valued-colored-balls.kt
# - Downloading sell-diminishing-valued-colored-balls
#   ✔ Accepted
#   ✔ 95/95 cases passed (157 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1649.create-sorted-array-through-instructions.kt
# - Downloading create-sorted-array-through-instructions
#   ✔ Accepted
#   ✔ 65/65 cases passed (680 ms)
#   ✔ Your runtime beats 75 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (63.2 MB)
# Submitting: kotlin_solutions_1/1652.defuse-the-bomb.kt
# - Downloading defuse-the-bomb
#   ✔ Accepted
#   ✔ 74/74 cases passed (9 ms)
#   ✔ Your runtime beats 42.86 % of kotlin submissions
#   ✔ Your memory usage beats 47.62 % of kotlin submissions (42.2 MB)
# Submitting: kotlin_solutions_1/1653.minimum-deletions-to-make-string-balanced.kt
# - Downloading minimum-deletions-to-make-string-balanced
#   ✔ Accepted
#   ✔ 158/158 cases passed (55 ms)
#   ✔ Your runtime beats 12.5 % of kotlin submissions
#   ✔ Your memory usage beats 37.5 % of kotlin submissions (48 MB)
# Submitting: kotlin_solutions_1/1655.distribute-repeating-integers.kt
# - Downloading distribute-repeating-integers
#   ✔ Accepted
#   ✔ 109/109 cases passed (232 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1656.design-an-ordered-stream.kt
# - Downloading design-an-ordered-stream
#   ✔ Accepted
#   ✔ 101/101 cases passed (124 ms)
#   ✔ Your runtime beats 92.31 % of kotlin submissions
#   ✔ Your memory usage beats 15.38 % of kotlin submissions (69.4 MB)

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-08-17 17:26:23
