# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME_2')
    user_cookie = userdata.get('LEETCODE_TOKEN_2')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME_2'] = user_name
    os.environ['LEETCODE_TOKEN_2'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME_2" "$LEETCODE_TOKEN_2" | leetcode user -c

# %%
# %%bash
#
# # top 300-400 answers (next batch)
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v kotlin_solutions_1/*.kt | sed -n '901,1000p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 7
# done
# Out:
# Submitting: kotlin_solutions_1/2193.minimum-number-of-moves-to-make-palindrome.kt
# - Downloading minimum-number-of-moves-to-make-palindrome
#   ✔ Accepted
#   ✔ 129/129 cases passed (49 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2194.cells-in-a-range-on-an-excel-sheet.kt
# - Downloading cells-in-a-range-on-an-excel-sheet
#   ✔ Accepted
#   ✔ 251/251 cases passed (10 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2195.append-k-integers-with-minimal-sum.kt
# - Downloading append-k-integers-with-minimal-sum
#   ✔ Accepted
#   ✔ 108/108 cases passed (152 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (69.3 MB)
# Submitting: kotlin_solutions_1/2196.create-binary-tree-from-descriptions.kt
# - Downloading create-binary-tree-from-descriptions
#   ✔ Accepted
#   ✔ 85/85 cases passed (62 ms)
#   ✔ Your runtime beats 93.33 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (68.2 MB)
# Submitting: kotlin_solutions_1/2197.replace-non-coprime-numbers-in-array.kt
# - Downloading replace-non-coprime-numbers-in-array
#   ✔ Accepted
#   ✔ 74/74 cases passed (95 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (65.1 MB)
# Submitting: kotlin_solutions_1/2200.find-all-k-distant-indices-in-an-array.kt
# - Downloading find-all-k-distant-indices-in-an-array
#   ✔ Accepted
#   ✔ 87/87 cases passed (34 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 71.43 % of kotlin submissions (47.1 MB)
# Submitting: kotlin_solutions_1/2201.count-artifacts-that-can-be-extracted.kt
# - Downloading count-artifacts-that-can-be-extracted
#   ✔ Accepted
#   ✔ 97/97 cases passed (157 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (135.2 MB)
# Submitting: kotlin_solutions_1/2202.maximize-the-topmost-element-after-k-moves.kt
# - Downloading maximize-the-topmost-element-after-k-moves
#   ✔ Accepted
#   ✔ 197/197 cases passed (30 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2203.minimum-weighted-subgraph-with-the-required-paths.kt
# - Downloading minimum-weighted-subgraph-with-the-required-paths
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 6: Char 118: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 6: Char 118: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 6: Char 173: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 6: Char 206: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 6: Char 206: ERROR: Not enough information to infer type argument for 'R'.
# Line 6: Char 347: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 6: Char 347: ERROR: Not enough information to infer type argument for 'R'.
# Line 6: Char 424: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 6: Char 445: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 6: Char 445: ERROR: Not enough information to infer type argument for 'R'.
# Line 6: Char 479: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 6: Char 479: ERROR: Not enough information to infer type argument for 'R'.
# Line 6: Char 551: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 6: Char 551: ERROR: Not enough information to infer type argument for 'R'.
# Line 6: Char 583: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 6: Char 583: ERROR: Not enough information to infer type argument for 'R'.
# Line 6: Char 630: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 6: Char 811: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 6: Char 811: ERROR: Not enough information to infer type argument for 'R'.
# Line 6: Char 817: ERROR: Unresolved reference 'callRecursive'.
# Line 6: Char 841: ERROR: Syntax error: Unexpected tokens (use ';' to separate expressions on the same line).
# Line 6: Char 853: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 6: Char 853: ERROR: Not enough information to infer type argument for 'R'.
# Line 6: Char 870: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 6: Char 870: ERROR: Not enough information to infer type argument for 'T'.
# Line 6: Char 870: ERROR: Not enough information to infer type argument for 'R'.
# Line 6: Char 874: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 6: Char 876: ERROR: Unresolved reference 'dist'.
# Line 6: Char 889: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 6: Char 889: ERROR: Not enough information to infer type argument for 'T'.
# Line 6: Char 895: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 6: Char 895: WARNING: Parameter 'dijkstra: <ERROR TYPE REF: Cannot infer argument for type parameter T>' is never used, could be renamed to '_'.
# Line 6: Char 907: ERROR: Unresolved reference 'dijkstra'.
# Line 6: Char 927: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 6: Char 933: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 6: Char 939: ERROR: Unresolved reference 'dijkstra'.
# Line 6: Char 959: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 6: Char 965: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 6: Char 971: ERROR: Unresolved reference 'dijkstra'.
# Line 6: Char 986: ERROR: Unresolved reference 'radj'.
# Line 6: Char 992: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 6: Char 998: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 6: Char 1016: ERROR: Overload resolution ambiguity between candidates:
# fun <T> Iterable<T>.minOf(selector: (T) -> Double): Double
# fun <T> Iterable<T>.minOf(selector: (T) -> Float): Float
# fun <T, R : Comparable<R>> Iterable<T>.minOf(selector: (T) -> R): R
# Line 6: Char 1029: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 6: Char 1029: ERROR: Not enough information to infer type argument for 'V'.
# Line 6: Char 1037: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 6: Char 1045: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 6: Char 1053: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 6: Char 1053: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun <T, R> T.let(block: (T) -> R): R
#     [R|Contract description]
#      <
#         CallsInPlace(block, EXACTLY_ONCE)
#     >
# Line 6: Char 1059: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 6: Char 1074: ERROR: 'operator' modifier is required on 'FirNamedFunctionSymbol kotlin/compareTo' in 'compareTo'.
# Line 6: Char 1122: ERROR: Syntax error: Expecting a top level declaration.
# Line 6: Char 1124: ERROR: Syntax error: Expecting a top level declaration.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2206.divide-array-into-equal-pairs.kt
# - Downloading divide-array-into-equal-pairs
#   ✔ Accepted
#   ✔ 138/138 cases passed (9 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 20 % of kotlin submissions (48 MB)
# Submitting: kotlin_solutions_1/2207.maximize-number-of-subsequences-in-a-string.kt
# - Downloading maximize-number-of-subsequences-in-a-string
#   ✔ Accepted
#   ✔ 172/172 cases passed (51 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2208.minimum-operations-to-halve-array-sum.kt
# - Downloading minimum-operations-to-halve-array-sum
#   ✔ Accepted
#   ✔ 62/62 cases passed (117 ms)
#   ✔ Your runtime beats 10 % of kotlin submissions
#   ✔ Your memory usage beats 10 % of kotlin submissions (65.8 MB)
# Submitting: kotlin_solutions_1/2209.minimum-white-tiles-after-covering-with-carpets.kt
# - Downloading minimum-white-tiles-after-covering-with-carpets
#   ✔ Accepted
#   ✔ 2706/2706 cases passed (74 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (50.3 MB)
# Submitting: kotlin_solutions_1/2210.count-hills-and-valleys-in-an-array.kt
# - Downloading count-hills-and-valleys-in-an-array
#   ✔ Accepted
#   ✔ 121/121 cases passed (22 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (47.7 MB)
# Submitting: kotlin_solutions_1/2211.count-collisions-on-a-road.kt
# - Downloading count-collisions-on-a-road
#   ✔ Accepted
#   ✔ 120/120 cases passed (31 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2212.maximum-points-in-an-archery-competition.kt
# - Downloading maximum-points-in-an-archery-competition
#   ✔ Accepted
#   ✔ 177/177 cases passed (129 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2213.longest-substring-of-one-repeating-character.kt
# - Downloading longest-substring-of-one-repeating-character
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 4: Char 131: ERROR: Argument type mismatch: actual type is 'kotlin.Array<kotlin.Any?>', but 'kotlin.IntArray' was expected.
#   ✘ Error: Line 4: Char 131: ERROR: Argument type mismatch: actual type is 'kotlin.Array<kotlin.Any?>', but 'kotlin.IntArray' was expected.
# Line 4: Char 143: ERROR: No value passed for parameter 'init'.
# Line 4: Char 602: WARNING: Parameter 'it: CharArray' is never used, could be renamed to '_'.
# Line 4: Char 650: WARNING: Parameter 'it: CharArray' is never used, could be renamed to '_'.
# Line 4: Char 785: WARNING: Parameter 'it: IntArray' is never used, could be renamed to '_'.
# Line 4: Char 920: WARNING: Parameter 'it: IntArray' is never used, could be renamed to '_'.
# Line 4: Char 1272: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 4: Char 1316: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 4: Char 1360: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 4: Char 1409: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 4: Char 1590: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 4: Char 1607: WARNING: Unchecked cast of 'kotlin.Any?' to 'kotlin.Function4<kotlin.Int, kotlin.Int, kotlin.Int, kotlin.Int, kotlin.Any>'.
# Line 4: Char 1674: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun StringBuilder.set(index: Int, value: Char): Unit
# Line 4: Char 1858: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun MatchGroupCollection.get(name: String): MatchGroup?
# Line 4: Char 1862: WARNING: There is more than one label with such a name in this scope.
# Line 4: Char 1920: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 4: Char 1923: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun MatchGroupCollection.get(name: String): MatchGroup?
# Line 4: Char 1927: WARNING: There is more than one label with such a name in this scope.
# Line 4: Char 2176: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun MatchGroupCollection.get(name: String): MatchGroup?
# Line 4: Char 2180: WARNING: There is more than one label with such a name in this scope.
# Line 4: Char 2265: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun MatchGroupCollection.get(name: String): MatchGroup?
# Line 4: Char 2395: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun MatchGroupCollection.get(name: String): MatchGroup?
# Line 4: Char 2554: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun MatchGroupCollection.get(name: String): MatchGroup?
# Line 42: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2215.find-the-difference-of-two-arrays.kt
# - Downloading find-the-difference-of-two-arrays
#   ✔ Accepted
#   ✔ 202/202 cases passed (30 ms)
#   ✔ Your runtime beats 66.42 % of kotlin submissions
#   ✔ Your memory usage beats 12.69 % of kotlin submissions (52.6 MB)
# Submitting: kotlin_solutions_1/2216.minimum-deletions-to-make-array-beautiful.kt
# - Downloading minimum-deletions-to-make-array-beautiful
#   ✔ Accepted
#   ✔ 114/114 cases passed (23 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2217.find-palindrome-with-fixed-length.kt
# - Downloading find-palindrome-with-fixed-length
#   ✘ Wrong Answer
#   ✘ 87/162 cases passed (N/A)
#   ✘ Testcase: [2,4,6]
# 4
#   ✘ Answer: [3223,3443,3663]
#   ✘ Expected Answer: [1111,1331,1551]
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2218.maximum-value-of-k-coins-from-piles.kt
# - Downloading maximum-value-of-k-coins-from-piles
#   ✔ Accepted
#   ✔ 123/123 cases passed (108 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2220.minimum-bit-flips-to-convert-number.kt
# - Downloading minimum-bit-flips-to-convert-number
#   ✔ Accepted
#   ✔ 250/250 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 62.5 % of kotlin submissions (40.2 MB)
# Submitting: kotlin_solutions_1/2221.find-triangular-sum-of-an-array.kt
# - Downloading find-triangular-sum-of-an-array
#   ✔ Accepted
#   ✔ 300/300 cases passed (35 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2222.number-of-ways-to-select-buildings.kt
# - Downloading number-of-ways-to-select-buildings
#   ✔ Accepted
#   ✔ 108/108 cases passed (37 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2223.sum-of-scores-of-built-strings.kt
# - Downloading sum-of-scores-of-built-strings
#   ✔ Accepted
#   ✔ 150/150 cases passed (67 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2224.minimum-number-of-operations-to-convert-time.kt
# - Downloading minimum-number-of-operations-to-convert-time
#   ✔ Accepted
#   ✔ 256/256 cases passed (1 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 20 % of kotlin submissions (41.5 MB)
# Submitting: kotlin_solutions_1/2225.find-players-with-zero-or-one-losses.kt
# - Downloading find-players-with-zero-or-one-losses
#   ✔ Accepted
#   ✔ 127/127 cases passed (267 ms)
#   ✔ Your runtime beats 15.38 % of kotlin submissions
#   ✔ Your memory usage beats 61.54 % of kotlin submissions (123.4 MB)
# Submitting: kotlin_solutions_1/2226.maximum-candies-allocated-to-k-children.kt
# - Downloading maximum-candies-allocated-to-k-children
#   ✔ Accepted
#   ✔ 101/101 cases passed (46 ms)
#   ✔ Your runtime beats 8.33 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (62.3 MB)
# Submitting: kotlin_solutions_1/2227.encrypt-and-decrypt-strings.kt
# - Downloading encrypt-and-decrypt-strings
#   ✔ Accepted
#   ✔ 211/211 cases passed (165 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2231.largest-number-after-digit-swaps-by-parity.kt
# - Downloading largest-number-after-digit-swaps-by-parity
#   ✔ Accepted
#   ✔ 238/238 cases passed (27 ms)
#   ✔ Your runtime beats 12.5 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (46.3 MB)
# Submitting: kotlin_solutions_1/2232.minimize-result-by-adding-parentheses-to-expression.kt
# - Downloading minimize-result-by-adding-parentheses-to-expression
#   ✔ Accepted
#   ✔ 124/124 cases passed (18 ms)
#   ✔ Your runtime beats 15.38 % of kotlin submissions
#   ✔ Your memory usage beats 15.38 % of kotlin submissions (43.2 MB)
# Submitting: kotlin_solutions_1/2233.maximum-product-after-k-increments.kt
# - Downloading maximum-product-after-k-increments
#   ✔ Accepted
#   ✔ 73/73 cases passed (161 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2234.maximum-total-beauty-of-the-gardens.kt
# - Downloading maximum-total-beauty-of-the-gardens
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 409: ERROR: Not enough information to infer type argument for 'K'.
#   ✘ Error: Line 2: Char 409: ERROR: Not enough information to infer type argument for 'K'.
# Line 2: Char 422: ERROR: Argument type mismatch: actual type is 'kotlin.Long', but 'K' was expected.
# Line 2: Char 432: ERROR: Argument type mismatch: actual type is 'R', but 'K' was expected.
# Line 2: Char 882: ERROR: Unresolved reference 'mid'.
# Line 2: Char 897: ERROR: Unresolved reference 'mid'.
# Line 2: Char 939: ERROR: Unresolved reference 'mid'.
# Line 2: Char 962: ERROR: Unresolved reference 'invoke'.
# Line 2: Char 1015: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 1015: ERROR: Not enough information to infer type argument for 'R'.
# Line 2: Char 1021: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2235.add-two-integers.kt
# - Downloading add-two-integers
#   ✔ Accepted
#   ✔ 262/262 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 14.75 % of kotlin submissions (40.6 MB)
# Submitting: kotlin_solutions_1/2236.root-equals-sum-of-children.kt
# - Downloading root-equals-sum-of-children
#   ✔ Accepted
#   ✔ 309/309 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 27.78 % of kotlin submissions (41.2 MB)
# Submitting: kotlin_solutions_1/2239.find-closest-number-to-zero.kt
# - Downloading find-closest-number-to-zero
#   ✔ Accepted
#   ✔ 227/227 cases passed (20 ms)
#   ✔ Your runtime beats 4.17 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (50 MB)
# Submitting: kotlin_solutions_1/2240.number-of-ways-to-buy-pens-and-pencils.kt
# - Downloading number-of-ways-to-buy-pens-and-pencils
#   ✔ Accepted
#   ✔ 145/145 cases passed (25 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (41.3 MB)
# Submitting: kotlin_solutions_1/2241.design-an-atm-machine.kt
# - Downloading design-an-atm-machine
#   ✔ Accepted
#   ✔ 111/111 cases passed (96 ms)
#   ✔ Your runtime beats 84.21 % of kotlin submissions
#   ✔ Your memory usage beats 57.89 % of kotlin submissions (62.1 MB)
# Submitting: kotlin_solutions_1/2242.maximum-score-of-a-node-sequence.kt
# - Downloading maximum-score-of-a-node-sequence
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 93: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 2: Char 93: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 207: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun MatchGroupCollection.get(name: String): MatchGroup?
# Line 2: Char 218: ERROR: Unresolved reference 'size'.
# Line 2: Char 228: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun MatchGroupCollection.get(name: String): MatchGroup?
# Line 2: Char 239: ERROR: Unresolved reference 'poll'.
# Line 2: Char 248: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 254: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun MatchGroupCollection.get(name: String): MatchGroup?
# Line 2: Char 265: ERROR: Unresolved reference 'add'.
# Line 2: Char 277: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 277: ERROR: Not enough information to infer type argument for 'T'.
# Line 2: Char 281: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 287: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 287: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 287: ERROR: Not enough information to infer type argument for 'V'.
# Line 2: Char 298: ERROR: Unresolved reference 'size'.
# Line 2: Char 308: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 308: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 308: ERROR: Not enough information to infer type argument for 'V'.
# Line 2: Char 319: ERROR: Unresolved reference 'poll'.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2243.calculate-digit-sum-of-a-string.kt
# - Downloading calculate-digit-sum-of-a-string
#   ✔ Accepted
#   ✔ 121/121 cases passed (20 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (44.3 MB)
# Submitting: kotlin_solutions_1/2244.minimum-rounds-to-complete-all-tasks.kt
# - Downloading minimum-rounds-to-complete-all-tasks
#   ✔ Accepted
#   ✔ 79/79 cases passed (77 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2245.maximum-trailing-zeros-in-a-cornered-path.kt
# - Downloading maximum-trailing-zeros-in-a-cornered-path
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 14: Char 1: ERROR: Argument type mismatch: actual type is 'kotlin.Unit', but 'kotlin.Int' was expected.
#   ✘ Error: Line 14: Char 1: ERROR: Argument type mismatch: actual type is 'kotlin.Unit', but 'kotlin.Int' was expected.
# Line 41: Char 2: ERROR: Syntax error: Expecting '}'.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2246.longest-path-with-different-adjacent-characters.kt
# - Downloading longest-path-with-different-adjacent-characters
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 370: ERROR: Argument type mismatch: actual type is 'kotlin.Function1<kotlin.collections.List<kotlin.Int>, kotlin.Unit>', but 'kotlin.Function1<kotlin.collections.List<kotlin.Int>, R>' was expected.
#   ✘ Error: Line 2: Char 370: ERROR: Argument type mismatch: actual type is 'kotlin.Function1<kotlin.collections.List<kotlin.Int>, kotlin.Unit>', but 'kotlin.Function1<kotlin.collections.List<kotlin.Int>, R>' was expected.
# Line 38: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2248.intersection-of-multiple-arrays.kt
# - Downloading intersection-of-multiple-arrays
#   ✔ Accepted
#   ✔ 151/151 cases passed (28 ms)
#   ✔ Your runtime beats 22.22 % of kotlin submissions
#   ✔ Your memory usage beats 55.56 % of kotlin submissions (48.2 MB)
# Submitting: kotlin_solutions_1/2249.count-lattice-points-inside-a-circle.kt
# - Downloading count-lattice-points-inside-a-circle
#   ✔ Accepted
#   ✔ 60/60 cases passed (44 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2250.count-number-of-rectangles-containing-each-point.kt
# - Downloading count-number-of-rectangles-containing-each-point
#   ✔ Accepted
#   ✔ 47/47 cases passed (256 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (95 MB)
# Submitting: kotlin_solutions_1/2251.number-of-flowers-in-full-bloom.kt
# - Downloading number-of-flowers-in-full-bloom
#   ✔ Accepted
#   ✔ 53/53 cases passed (204 ms)
#   ✔ Your runtime beats 15.38 % of kotlin submissions
#   ✔ Your memory usage beats 38.46 % of kotlin submissions (91.9 MB)
# Submitting: kotlin_solutions_1/2255.count-prefixes-of-a-given-string.kt
# - Downloading count-prefixes-of-a-given-string
#   ✔ Accepted
#   ✔ 123/123 cases passed (7 ms)
#   ✔ Your runtime beats 60 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/2256.minimum-average-difference.kt
# - Downloading minimum-average-difference
#   ✔ Accepted
#   ✔ 78/78 cases passed (36 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (65 MB)
# Submitting: kotlin_solutions_1/2257.count-unguarded-cells-in-the-grid.kt
# - Downloading count-unguarded-cells-in-the-grid
#   ✔ Accepted
#   ✔ 49/49 cases passed (253 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2258.escape-the-spreading-fire.kt
# - Downloading escape-the-spreading-fire
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 400: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
#   ✘ Error: Line 2: Char 400: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 2: Char 806: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 932: ERROR: Unresolved reference 'c'.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2259.remove-digit-from-number-to-maximize-result.kt
# - Downloading remove-digit-from-number-to-maximize-result
#   ✔ Accepted
#   ✔ 112/112 cases passed (18 ms)
#   ✔ Your runtime beats 14.29 % of kotlin submissions
#   ✔ Your memory usage beats 28.57 % of kotlin submissions (44 MB)
# Submitting: kotlin_solutions_1/2260.minimum-consecutive-cards-to-pick-up.kt
# - Downloading minimum-consecutive-cards-to-pick-up
#   ✔ Accepted
#   ✔ 80/80 cases passed (84 ms)
#   ✔ Your runtime beats 23.53 % of kotlin submissions
#   ✔ Your memory usage beats 41.18 % of kotlin submissions (67.7 MB)
# Submitting: kotlin_solutions_1/2261.k-divisible-elements-subarrays.kt
# - Downloading k-divisible-elements-subarrays
#   ✔ Accepted
#   ✔ 152/152 cases passed (1387 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (69.4 MB)
# Submitting: kotlin_solutions_1/2262.total-appeal-of-a-string.kt
# - Downloading total-appeal-of-a-string
#   ✔ Accepted
#   ✔ 77/77 cases passed (41 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2264.largest-3-same-digit-number-in-string.kt
# - Downloading largest-3-same-digit-number-in-string
#   ✔ Accepted
#   ✔ 141/141 cases passed (16 ms)
#   ✔ Your runtime beats 12.5 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (44 MB)
# Submitting: kotlin_solutions_1/2265.count-nodes-equal-to-average-of-subtree.kt
# - Downloading count-nodes-equal-to-average-of-subtree
#   ✔ Accepted
#   ✔ 139/139 cases passed (170 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (45.2 MB)
# Submitting: kotlin_solutions_1/2266.count-number-of-texts.kt
# - Downloading count-number-of-texts
#   ✔ Accepted
#   ✔ 107/107 cases passed (71 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2267.check-if-there-is-a-valid-parentheses-string-path.kt
# - Downloading check-if-there-is-a-valid-parentheses-string-path
#   ✔ Accepted
#   ✔ 81/81 cases passed (303 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (75.1 MB)
# Submitting: kotlin_solutions_1/2269.find-the-k-beauty-of-a-number.kt
# - Downloading find-the-k-beauty-of-a-number
#   ✔ Accepted
#   ✔ 183/183 cases passed (3 ms)
#   ✔ Your runtime beats 8.33 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (40.5 MB)
# Submitting: kotlin_solutions_1/2270.number-of-ways-to-split-array.kt
# - Downloading number-of-ways-to-split-array
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 122: ERROR: None of the following candidates is applicable:
#   ✘ Error: Line 2: Char 122: ERROR: None of the following candidates is applicable:
# fun <T> Array<out T>.dropLast(n: Int): List<T>
# fun ByteArray.dropLast(n: Int): List<Byte>
# fun ShortArray.dropLast(n: Int): List<Short>
# fun IntArray.dropLast(n: Int): List<Int>
# fun LongArray.dropLast(n: Int): List<Long>
# fun FloatArray.dropLast(n: Int): List<Float>
# fun DoubleArray.dropLast(n: Int): List<Double>
# fun BooleanArray.dropLast(n: Int): List<Boolean>
# fun CharArray.dropLast(n: Int): List<Char>
# fun <T> List<T>.dropLast(n: Int): List<T>
# fun UIntArray.dropLast(n: Int): List<UInt>
# fun ULongArray.dropLast(n: Int): List<ULong>
# fun UByteArray.dropLast(n: Int): List<UByte>
# fun UShortArray.dropLast(n: Int): List<UShort>
# fun CharSequence.dropLast(n: Int): CharSequence
# fun String.dropLast(n: Int): String
# Line 2: Char 150: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 150: ERROR: Function 'component1()' is ambiguous for this expression:
# fun <T> Array<out T>.component1(): T
# fun ByteArray.component1(): Byte
# fun ShortArray.component1(): Short
# fun IntArray.component1(): Int
# fun LongArray.component1(): Long
# fun FloatArray.component1(): Float
# fun DoubleArray.component1(): Double
# fun BooleanArray.component1(): Boolean
# fun CharArray.component1(): Char
# fun <T> List<T>.component1(): T
# fun <K, V> Map.Entry<K, V>.component1(): K
# fun UIntArray.component1(): UInt
# fun ULongArray.component1(): ULong
# fun UByteArray.component1(): UByte
# fun UShortArray.component1(): UShort.
# Line 2: Char 150: ERROR: Function 'component2()' is ambiguous for this expression:
# fun <T> Array<out T>.component2(): T
# fun ByteArray.component2(): Byte
# fun ShortArray.component2(): Short
# fun IntArray.component2(): Int
# fun LongArray.component2(): Long
# fun FloatArray.component2(): Float
# fun DoubleArray.component2(): Double
# fun BooleanArray.component2(): Boolean
# fun CharArray.component2(): Char
# fun <T> List<T>.component2(): T
# fun <K, V> Map.Entry<K, V>.component2(): V
# fun UIntArray.component2(): UInt
# fun ULongArray.component2(): ULong
# fun UByteArray.component2(): UByte
# fun UShortArray.component2(): UShort.
# Line 2: Char 164: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 185: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 200: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 200: ERROR: Not enough information to infer type argument for 'B'.
# Line 2: Char 219: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun String.compareTo(other: String, ignoreCase: Boolean = ...): Int
# Line 2: Char 228: ERROR: None of the following candidates is applicable:
# fun minus(other: Byte): Long
# fun minus(other: Short): Long
# fun minus(other: Int): Long
# fun minus(other: Long): Long
# fun minus(other: Float): Float
# fun minus(other: Double): Double
# Line 2: Char 248: ERROR: Unresolved reference 'second'.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2271.maximum-white-tiles-covered-by-a-carpet.kt
# - Downloading maximum-white-tiles-covered-by-a-carpet
#   ✔ Accepted
#   ✔ 51/51 cases passed (94 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (87.7 MB)
# Submitting: kotlin_solutions_1/2272.substring-with-largest-variance.kt
# - Downloading substring-with-largest-variance
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 353: ERROR: Argument type mismatch: actual type is 'kotlin.IntArray', but 'kotlin.Int' was expected.
#   ✘ Error: Line 2: Char 353: ERROR: Argument type mismatch: actual type is 'kotlin.IntArray', but 'kotlin.Int' was expected.
# Line 2: Char 414: ERROR: Argument type mismatch: actual type is 'kotlin.Any', but 'kotlin.IntArray' was expected.
# Line 2: Char 418: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun MatchGroupCollection.get(name: String): MatchGroup?
# Line 2: Char 424: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun String.compareTo(other: String, ignoreCase: Boolean = ...): Int
# Line 2: Char 426: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun MatchGroupCollection.get(name: String): MatchGroup?
# Line 2: Char 435: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun MatchGroupCollection.get(name: String): MatchGroup?
# Line 2: Char 441: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun String.compareTo(other: String, ignoreCase: Boolean = ...): Int
# Line 2: Char 463: ERROR: Argument type mismatch: actual type is 'kotlin.text.MatchGroup?', but 'kotlin.Int' was expected.
# Line 2: Char 463: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun MatchGroupCollection.get(name: String): MatchGroup?
# Line 2: Char 470: ERROR: Argument type mismatch: actual type is 'kotlin.text.MatchGroup?', but 'kotlin.Int' was expected.
# Line 2: Char 470: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun MatchGroupCollection.get(name: String): MatchGroup?
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2273.find-resultant-array-after-removing-anagrams.kt
# - Downloading find-resultant-array-after-removing-anagrams
#   ✔ Accepted
#   ✔ 202/202 cases passed (50 ms)
#   ✔ Your runtime beats 12.5 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (50.1 MB)
# Submitting: kotlin_solutions_1/2274.maximum-consecutive-floors-without-special-floors.kt
# - Downloading maximum-consecutive-floors-without-special-floors
#   ✔ Accepted
#   ✔ 81/81 cases passed (286 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (69.4 MB)
# Submitting: kotlin_solutions_1/2275.largest-combination-with-bitwise-and-greater-than-zero.kt
# - Downloading largest-combination-with-bitwise-and-greater-than-zero
#   ✔ Accepted
#   ✔ 80/80 cases passed (23 ms)
#   ✔ Your runtime beats 66.67 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (59.9 MB)
# Submitting: kotlin_solutions_1/2276.count-integers-in-intervals.kt
# - Downloading count-integers-in-intervals
#   ✔ Accepted
#   ✔ 73/73 cases passed (169 ms)
#   ✔ Your runtime beats 12.5 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (125.1 MB)
# Submitting: kotlin_solutions_1/2278.percentage-of-letter-in-string.kt
# - Downloading percentage-of-letter-in-string
#   ✔ Accepted
#   ✔ 86/86 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (40.9 MB)
# Submitting: kotlin_solutions_1/2279.maximum-bags-with-full-capacity-of-rocks.kt
# - Downloading maximum-bags-with-full-capacity-of-rocks
#   ✔ Accepted
#   ✔ 79/79 cases passed (99 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2280.minimum-lines-to-represent-a-line-chart.kt
# - Downloading minimum-lines-to-represent-a-line-chart
#   ✔ Accepted
#   ✔ 82/82 cases passed (83 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2281.sum-of-total-strength-of-wizards.kt
# - Downloading sum-of-total-strength-of-wizards
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 699: WARNING: Parameter 'it: Long' is never used, could be renamed to '_'.
#   ✘ Error: Line 2: Char 699: WARNING: Parameter 'it: Long' is never used, could be renamed to '_'.
# Line 36: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2283.check-if-number-has-equal-digit-count-and-digit-value.kt
# - Downloading check-if-number-has-equal-digit-count-and-digit-value
#   ✔ Accepted
#   ✔ 433/433 cases passed (10 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/2284.sender-with-largest-word-count.kt
# - Downloading sender-with-largest-word-count
#   ✔ Accepted
#   ✔ 70/70 cases passed (116 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2285.maximum-total-importance-of-roads.kt
# - Downloading maximum-total-importance-of-roads
#   ✔ Accepted
#   ✔ 58/58 cases passed (59 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2286.booking-concert-tickets-in-groups.kt
# - Downloading booking-concert-tickets-in-groups
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 70: ERROR: Syntax error: Property getter or setter expected.
#   ✘ Error: Line 2: Char 70: ERROR: Syntax error: Property getter or setter expected.
# Line 2: Char 97: ERROR: Syntax error: Property getter or setter expected.
# Line 2: Char 180: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 2: Char 304: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 2: Char 354: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 2: Char 437: ERROR: Syntax error: Property getter or setter expected.
# Line 2: Char 738: WARNING: Parameter 'it: IntArray' is never used, could be renamed to '_'.
# Line 2: Char 937: WARNING: Parameter 'it: IntArray' is never used, could be renamed to '_'.
# Line 2: Char 987: WARNING: Parameter 'it: IntArray' is never used, could be renamed to '_'.
# Line 2: Char 1487: WARNING: Parameter 'it: Long' is never used, could be renamed to '_'.
# Line 2: Char 1664: WARNING: Parameter 'it: Long' is never used, could be renamed to '_'.
# Line 2: Char 1714: WARNING: Parameter 'it: Long' is never used, could be renamed to '_'.
# Line 53: Char 32: WARNING: 'static fun readFrom(p0: String!): JsonArray!' is deprecated. Deprecated in Java.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2287.rearrange-characters-to-make-target-string.kt
# - Downloading rearrange-characters-to-make-target-string
#   ✔ Accepted
#   ✔ 116/116 cases passed (19 ms)
#   ✔ Your runtime beats 5.56 % of kotlin submissions
#   ✔ Your memory usage beats 11.11 % of kotlin submissions (43.5 MB)
# Submitting: kotlin_solutions_1/2288.apply-discount-to-prices.kt
# - Downloading apply-discount-to-prices
#   ✘ Wrong Answer
#   ✘ 22/151 cases passed (N/A)
#   ✘ Testcase: "there are $1 $2 and 5$ candies in the shop"
# 50
#   ✘ Answer: "there are $$0.50 $$1.00 and 5$ candies in the shop"
#   ✘ Expected Answer: "there are $0.50 $1.00 and 5$ candies in the shop"
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2289.steps-to-make-array-non-decreasing.kt
# - Downloading steps-to-make-array-non-decreasing
#   ✔ Accepted
#   ✔ 87/87 cases passed (134 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2290.minimum-obstacle-removal-to-reach-corner.kt
# - Downloading minimum-obstacle-removal-to-reach-corner
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 772: ERROR: Syntax error: Unexpected tokens (use ';' to separate expressions on the same line).
#   ✘ Error: Line 2: Char 772: ERROR: Syntax error: Unexpected tokens (use ';' to separate expressions on the same line).
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2293.min-max-game.kt
# - Downloading min-max-game
#   ✔ Accepted
#   ✔ 96/96 cases passed (6 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2294.partition-array-such-that-maximum-difference-is-k.kt
# - Downloading partition-array-such-that-maximum-difference-is-k
#   ✔ Accepted
#   ✔ 93/93 cases passed (106 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (68.6 MB)
# Submitting: kotlin_solutions_1/2295.replace-elements-in-an-array.kt
# - Downloading replace-elements-in-an-array
#   ✔ Accepted
#   ✔ 80/80 cases passed (77 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (124.2 MB)
# Submitting: kotlin_solutions_1/2296.design-a-text-editor.kt
# - Downloading design-a-text-editor
#   ✔ Accepted
#   ✔ 45/45 cases passed (157 ms)
#   ✔ Your runtime beats 83.33 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (84.9 MB)
# Submitting: kotlin_solutions_1/2299.strong-password-checker-ii.kt
# - Downloading strong-password-checker-ii
# [ERROR] session expired, please login again [code=-1]
# Submitting: kotlin_solutions_1/2300.successful-pairs-of-spells-and-potions.kt
# - Downloading successful-pairs-of-spells-and-potions
#   ✘ Time Limit Exceeded
#   ✘ 54/57 cases passed (N/A)
#   ✘ Testcase: [100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,10 ...
#   ✘ Answer:
#   ✘ Expected Answer: [100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,100000,10 ...
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2301.match-substring-after-replacement.kt
# - Downloading match-substring-after-replacement
#   ✔ Accepted
#   ✔ 117/117 cases passed (84 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (48.4 MB)
# Submitting: kotlin_solutions_1/2302.count-subarrays-with-score-less-than-k.kt
# - Downloading count-subarrays-with-score-less-than-k
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 97: ERROR: Argument type mismatch: actual type is 'kotlin.text.MatchGroup?', but 'kotlin.Long' was expected.
#   ✘ Error: Line 2: Char 97: ERROR: Argument type mismatch: actual type is 'kotlin.text.MatchGroup?', but 'kotlin.Long' was expected.
# Line 2: Char 200: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 2: Char 206: WARNING: There is more than one label with such a name in this scope.
# Line 2: Char 225: WARNING: There is more than one label with such a name in this scope.
# Line 2: Char 253: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 2: Char 259: WARNING: There is more than one label with such a name in this scope.
# Line 2: Char 278: WARNING: There is more than one label with such a name in this scope.
# Line 2: Char 315: WARNING: There is more than one label with such a name in this scope.
# Line 2: Char 356: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun MatchGroupCollection.get(name: String): MatchGroup?
# Line 2: Char 360: WARNING: There is more than one label with such a name in this scope.
# Line 2: Char 368: ERROR: Unresolved reference '+='.
# Line 2: Char 374: ERROR: None of the following candidates is applicable:
# fun minus(other: Byte): Int
# fun minus(other: Short): Int
# fun minus(other: Int): Int
# fun minus(other: Long): Long
# fun minus(other: Float): Float
# fun minus(other: Double): Double
# Line 2: Char 376: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun MatchGroupCollection.get(name: String): MatchGroup?
# Line 2: Char 380: WARNING: There is more than one label with such a name in this scope.
# Line 2: Char 403: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun MatchGroupCollection.get(name: String): MatchGroup?
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2304.minimum-path-cost-in-a-grid.kt
# - Downloading minimum-path-cost-in-a-grid
#   ✔ Accepted
#   ✔ 34/34 cases passed (34 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2305.fair-distribution-of-cookies.kt
# - Downloading fair-distribution-of-cookies
#   ✔ Accepted
#   ✔ 38/38 cases passed (1325 ms)
#   ✔ Your runtime beats 12.5 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (49.5 MB)
# Submitting: kotlin_solutions_1/2306.naming-a-company.kt
# - Downloading naming-a-company
#   ✔ Accepted
#   ✔ 89/89 cases passed (135 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (63.5 MB)
# Submitting: kotlin_solutions_1/2309.greatest-english-letter-in-upper-and-lower-case.kt
# - Downloading greatest-english-letter-in-upper-and-lower-case
#   ✔ Accepted
#   ✔ 113/113 cases passed (22 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/2310.sum-of-numbers-with-units-digit-k.kt
# - Downloading sum-of-numbers-with-units-digit-k
#   ✔ Accepted
#   ✔ 298/298 cases passed (4 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (40.8 MB)
# Submitting: kotlin_solutions_1/2311.longest-binary-subsequence-less-than-or-equal-to-k.kt
# - Downloading longest-binary-subsequence-less-than-or-equal-to-k
#   ✔ Accepted
#   ✔ 155/155 cases passed (13 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (45.5 MB)
# Submitting: kotlin_solutions_1/2312.selling-pieces-of-wood.kt
# - Downloading selling-pieces-of-wood
#   ✔ Accepted
#   ✔ 60/60 cases passed (88 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (65.5 MB)
# Submitting: kotlin_solutions_1/2315.count-asterisks.kt
# - Downloading count-asterisks
#   ✔ Accepted
#   ✔ 69/69 cases passed (14 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2316.count-unreachable-pairs-of-nodes-in-an-undirected-graph.kt
# - Downloading count-unreachable-pairs-of-nodes-in-an-undirected-graph
#   ✔ Accepted
#   ✔ 66/66 cases passed (197 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2317.maximum-xor-after-operations.kt
# - Downloading maximum-xor-after-operations
#   ✔ Accepted
#   ✔ 73/73 cases passed (11 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2318.number-of-distinct-roll-sequences.kt
# - Downloading number-of-distinct-roll-sequences
#   ✔ Accepted
#   ✔ 64/64 cases passed (92 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (49.6 MB)
# Submitting: kotlin_solutions_1/2319.check-if-matrix-is-x-matrix.kt
# - Downloading check-if-matrix-is-x-matrix
#   ✔ Accepted
#   ✔ 84/84 cases passed (19 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2320.count-number-of-ways-to-place-houses.kt
# - Downloading count-number-of-ways-to-place-houses
#   ✔ Accepted
#   ✔ 150/150 cases passed (22 ms)
# [WARN] Failed to get runtime percentile.

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-08-17 18:47:49
