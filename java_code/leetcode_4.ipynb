# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME_4')
    user_cookie = userdata.get('LEETCODE_TOKEN_4')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME_4'] = user_name
    os.environ['LEETCODE_TOKEN_4'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME_4" "$LEETCODE_TOKEN_4" | leetcode user -c

# %%
# %%bash
#
#
# # top 100 answers
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v java_solutions/*.java | sed -n '451,600p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 8
# done
# Out:
# Submitting: java_solutions/854.k-similar-strings.java
# - Downloading problems
# - Downloading k-similar-strings
#   ✔ Accepted
#   ✔ 66/66 cases passed (71 ms)
#   ✔ Your runtime beats 35.21 % of java submissions
#   ✔ Your memory usage beats 27.16 % of java submissions (51.5 MB)
# Submitting: java_solutions/857.minimum-cost-to-hire-k-workers.java
# - Downloading minimum-cost-to-hire-k-workers
#   ✔ Accepted
#   ✔ 49/49 cases passed (51 ms)
#   ✔ Your runtime beats 5.38 % of java submissions
#   ✔ Your memory usage beats 6.45 % of java submissions (48.8 MB)
# Submitting: java_solutions/860.lemonade-change.java
# - Downloading lemonade-change
#   ✔ Accepted
#   ✔ 62/62 cases passed (14 ms)
#   ✔ Your runtime beats 5.09 % of java submissions
#   ✔ Your memory usage beats 5.61 % of java submissions (73.1 MB)
# Submitting: java_solutions/862.shortest-subarray-with-sum-at-least-k.java
# - Downloading shortest-subarray-with-sum-at-least-k
#   ✔ Accepted
#   ✔ 99/99 cases passed (41 ms)
#   ✔ Your runtime beats 15.65 % of java submissions
#   ✔ Your memory usage beats 87.83 % of java submissions (90.8 MB)
# Submitting: java_solutions/864.shortest-path-to-get-all-keys.java
# - Downloading shortest-path-to-get-all-keys
#   ✔ Accepted
#   ✔ 36/36 cases passed (41 ms)
#   ✔ Your runtime beats 32.88 % of java submissions
#   ✔ Your memory usage beats 34.52 % of java submissions (48 MB)
# Submitting: java_solutions/867.transpose-matrix.java
# - Downloading transpose-matrix
#   ✔ Accepted
#   ✔ 36/36 cases passed (7 ms)
#   ✔ Your runtime beats 0.56 % of java submissions
#   ✔ Your memory usage beats 47.26 % of java submissions (46.7 MB)
# Submitting: java_solutions/868.binary-gap.java
# - Downloading binary-gap
#   ✔ Accepted
#   ✔ 261/261 cases passed (10 ms)
#   ✔ Your runtime beats 1.66 % of java submissions
#   ✔ Your memory usage beats 14.32 % of java submissions (43.3 MB)
# Submitting: java_solutions/869.reordered-power-of-2.java
# - Downloading reordered-power-of-2
#   ✔ Accepted
#   ✔ 138/138 cases passed (13 ms)
#   ✔ Your runtime beats 5.19 % of java submissions
#   ✔ Your memory usage beats 6.3 % of java submissions (44.8 MB)
# Submitting: java_solutions/871.minimum-number-of-refueling-stops.java
# - Downloading minimum-number-of-refueling-stops
#   ✔ Accepted
#   ✔ 198/198 cases passed (45 ms)
#   ✔ Your runtime beats 7.45 % of java submissions
#   ✔ Your memory usage beats 94.75 % of java submissions (46.4 MB)
# Submitting: java_solutions/876.middle-of-the-linked-list.java
# - Downloading middle-of-the-linked-list
#   ✔ Accepted
#   ✔ 36/36 cases passed (2 ms)
#   ✔ Your runtime beats 0.27 % of java submissions
#   ✔ Your memory usage beats 16.28 % of java submissions (43.1 MB)
# Submitting: java_solutions/877.stone-game.java
# - Downloading stone-game
#   ✔ Accepted
#   ✔ 46/46 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 74.45 % of java submissions (43 MB)
# Submitting: java_solutions/878.nth-magical-number.java
# - Downloading nth-magical-number
#   ✔ Accepted
#   ✔ 70/70 cases passed (1 ms)
#   ✔ Your runtime beats 6.6 % of java submissions
#   ✔ Your memory usage beats 74.65 % of java submissions (42 MB)
# Submitting: java_solutions/879.profitable-schemes.java
# - Downloading profitable-schemes
#   ✔ Accepted
#   ✔ 45/45 cases passed (93 ms)
#   ✔ Your runtime beats 40.79 % of java submissions
#   ✔ Your memory usage beats 81.24 % of java submissions (43.5 MB)
# Submitting: java_solutions/882.reachable-nodes-in-subdivided-graph.java
# - Downloading reachable-nodes-in-subdivided-graph
#   ✔ Accepted
#   ✔ 50/50 cases passed (826 ms)
#   ✔ Your runtime beats 5.29 % of java submissions
#   ✔ Your memory usage beats 6.25 % of java submissions (276.5 MB)
# Submitting: java_solutions/884.uncommon-words-from-two-sentences.java
# - Downloading uncommon-words-from-two-sentences
#   ✔ Accepted
#   ✔ 55/55 cases passed (13 ms)
#   ✔ Your runtime beats 5.86 % of java submissions
#   ✔ Your memory usage beats 6.52 % of java submissions (50.2 MB)
# Submitting: java_solutions/887.super-egg-drop.java
# - Downloading super-egg-drop
#   ✔ Accepted
#   ✔ 121/121 cases passed (1 ms)
#   ✔ Your runtime beats 60.26 % of java submissions
#   ✔ Your memory usage beats 63.46 % of java submissions (42.3 MB)
# Submitting: java_solutions/888.fair-candy-swap.java
# - Downloading fair-candy-swap
#   ✔ Accepted
#   ✔ 76/76 cases passed (22 ms)
#   ✔ Your runtime beats 21.63 % of java submissions
#   ✔ Your memory usage beats 48.81 % of java submissions (48.4 MB)
# Submitting: java_solutions/890.find-and-replace-pattern.java
# - Downloading find-and-replace-pattern
#   ✔ Accepted
#   ✔ 50/50 cases passed (9 ms)
#   ✔ Your runtime beats 1.33 % of java submissions
#   ✔ Your memory usage beats 8.22 % of java submissions (44.6 MB)
# Submitting: java_solutions/891.sum-of-subsequence-widths.java
# - Downloading sum-of-subsequence-widths
#   ✔ Accepted
#   ✔ 68/68 cases passed (49 ms)
#   ✔ Your runtime beats 5.63 % of java submissions
#   ✔ Your memory usage beats 67.61 % of java submissions (64.4 MB)
# Submitting: java_solutions/895.maximum-frequency-stack.java
# - Downloading maximum-frequency-stack
#   ✔ Accepted
#   ✔ 38/38 cases passed (50 ms)
#   ✔ Your runtime beats 5.35 % of java submissions
#   ✔ Your memory usage beats 5.07 % of java submissions (81.3 MB)
# Submitting: java_solutions/896.monotonic-array.java
# - Downloading monotonic-array
#   ✔ Accepted
#   ✔ 371/371 cases passed (271 ms)
#   ✔ Your runtime beats 1.72 % of java submissions
#   ✔ Your memory usage beats 6.34 % of java submissions (97.1 MB)
# Submitting: java_solutions/899.orderly-queue.java
# - Downloading orderly-queue
#   ✔ Accepted
#   ✔ 112/112 cases passed (9 ms)
#   ✔ Your runtime beats 6.16 % of java submissions
#   ✔ Your memory usage beats 8.39 % of java submissions (47.7 MB)
# Submitting: java_solutions/902.numbers-at-most-n-given-digit-set.java
# - Downloading numbers-at-most-n-given-digit-set
#   ✔ Accepted
#   ✔ 84/84 cases passed (1 ms)
#   ✔ Your runtime beats 46.89 % of java submissions
#   ✔ Your memory usage beats 49.38 % of java submissions (42.7 MB)
# Submitting: java_solutions/903.valid-permutations-for-di-sequence.java
# - Downloading valid-permutations-for-di-sequence
#   ✔ Accepted
#   ✔ 83/83 cases passed (15 ms)
#   ✔ Your runtime beats 36 % of java submissions
#   ✔ Your memory usage beats 97.6 % of java submissions (42.9 MB)
# Submitting: java_solutions/905.sort-array-by-parity.java
# - Downloading sort-array-by-parity
#   ✔ Accepted
#   ✔ 286/286 cases passed (15 ms)
#   ✔ Your runtime beats 5.43 % of java submissions
#   ✔ Your memory usage beats 5.69 % of java submissions (47.8 MB)
# Submitting: java_solutions/906.super-palindromes.java
# - Downloading super-palindromes
#   ✔ Accepted
#   ✔ 49/49 cases passed (567 ms)
#   ✔ Your runtime beats 14.06 % of java submissions
#   ✔ Your memory usage beats 71.09 % of java submissions (43.2 MB)
# Submitting: java_solutions/912.sort-an-array.java
# - Downloading sort-an-array
#   ✔ Accepted
#   ✔ 21/21 cases passed (34 ms)
#   ✔ Your runtime beats 26.23 % of java submissions
#   ✔ Your memory usage beats 82.78 % of java submissions (81.9 MB)
# Submitting: java_solutions/913.cat-and-mouse.java
# - Downloading cat-and-mouse
#   ✔ Accepted
#   ✔ 92/92 cases passed (52 ms)
#   ✔ Your runtime beats 26.54 % of java submissions
#   ✔ Your memory usage beats 26.85 % of java submissions (47.9 MB)
# Submitting: java_solutions/917.reverse-only-letters.java
# - Downloading reverse-only-letters
#   ✔ Accepted
#   ✔ 115/115 cases passed (13 ms)
#   ✔ Your runtime beats 1.84 % of java submissions
#   ✔ Your memory usage beats 5.55 % of java submissions (45 MB)
# Submitting: java_solutions/920.number-of-music-playlists.java
# - Downloading number-of-music-playlists
#   ✔ Accepted
#   ✔ 83/83 cases passed (16 ms)
#   ✔ Your runtime beats 5.19 % of java submissions
#   ✔ Your memory usage beats 25 % of java submissions (44.2 MB)
# Submitting: java_solutions/921.minimum-add-to-make-parentheses-valid.java
# - Downloading minimum-add-to-make-parentheses-valid
#   ✔ Accepted
#   ✔ 116/116 cases passed (4 ms)
#   ✔ Your runtime beats 0.89 % of java submissions
#   ✔ Your memory usage beats 8.31 % of java submissions (43.5 MB)
# Submitting: java_solutions/924.minimize-malware-spread.java
# - Downloading minimize-malware-spread
#   ✔ Accepted
#   ✔ 70/70 cases passed (13 ms)
#   ✔ Your runtime beats 17.41 % of java submissions
#   ✔ Your memory usage beats 63.85 % of java submissions (121.3 MB)
# Submitting: java_solutions/927.three-equal-parts.java
# - Downloading three-equal-parts
#   ✔ Accepted
#   ✔ 121/121 cases passed (4 ms)
#   ✔ Your runtime beats 6.35 % of java submissions
#   ✔ Your memory usage beats 96.83 % of java submissions (49.9 MB)
# Submitting: java_solutions/928.minimize-malware-spread-ii.java
# - Downloading minimize-malware-spread-ii
#   ✔ Accepted
#   ✔ 48/48 cases passed (56 ms)
#   ✔ Your runtime beats 6.56 % of java submissions
#   ✔ Your memory usage beats 67.76 % of java submissions (93.7 MB)
# Submitting: java_solutions/929.unique-email-addresses.java
# - Downloading unique-email-addresses
#   ✔ Accepted
#   ✔ 188/188 cases passed (16 ms)
#   ✔ Your runtime beats 20.96 % of java submissions
#   ✔ Your memory usage beats 29.13 % of java submissions (47 MB)
# Submitting: java_solutions/936.stamping-the-sequence.java
# - Downloading stamping-the-sequence
#   ✔ Accepted
#   ✔ 262/262 cases passed (10 ms)
#   ✔ Your runtime beats 10.38 % of java submissions
#   ✔ Your memory usage beats 9.75 % of java submissions (46.9 MB)
# Submitting: java_solutions/938.range-sum-of-bst.java
# - Downloading range-sum-of-bst
#   ✔ Accepted
#   ✔ 41/41 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 44.7 % of java submissions (54 MB)
# Submitting: java_solutions/940.distinct-subsequences-ii.java
# - Downloading distinct-subsequences-ii
#   ✔ Accepted
#   ✔ 110/110 cases passed (14 ms)
#   ✔ Your runtime beats 10.81 % of java submissions
#   ✔ Your memory usage beats 32.09 % of java submissions (43.7 MB)
# Submitting: java_solutions/941.valid-mountain-array.java
# - Downloading valid-mountain-array
#   ✔ Accepted
#   ✔ 53/53 cases passed (7 ms)
#   ✔ Your runtime beats 1.91 % of java submissions
#   ✔ Your memory usage beats 14.68 % of java submissions (47.7 MB)
# Submitting: java_solutions/943.find-the-shortest-superstring.java
# - Downloading find-the-shortest-superstring
#   ✔ Accepted
#   ✔ 85/85 cases passed (92 ms)
#   ✔ Your runtime beats 31.71 % of java submissions
#   ✔ Your memory usage beats 33.54 % of java submissions (48.5 MB)
# Submitting: java_solutions/944.delete-columns-to-make-sorted.java
# - Downloading delete-columns-to-make-sorted
#   ✔ Accepted
#   ✔ 86/86 cases passed (25 ms)
#   ✔ Your runtime beats 5.45 % of java submissions
#   ✔ Your memory usage beats 5.09 % of java submissions (47.8 MB)
# Submitting: java_solutions/952.largest-component-size-by-common-factor.java
# - Downloading largest-component-size-by-common-factor
#   ✔ Accepted
#   ✔ 108/108 cases passed (384 ms)
#   ✔ Your runtime beats 5.64 % of java submissions
#   ✔ Your memory usage beats 47.09 % of java submissions (51 MB)
# Submitting: java_solutions/953.verifying-an-alien-dictionary.java
# - Downloading verifying-an-alien-dictionary
#   ✔ Accepted
#   ✔ 125/125 cases passed (8 ms)
#   ✔ Your runtime beats 3.44 % of java submissions
#   ✔ Your memory usage beats 5.03 % of java submissions (44 MB)
# Submitting: java_solutions/956.tallest-billboard.java
# - Downloading tallest-billboard
#   ✔ Accepted
#   ✔ 80/80 cases passed (53 ms)
#   ✔ Your runtime beats 39.74 % of java submissions
#   ✔ Your memory usage beats 98.72 % of java submissions (46.2 MB)
# Submitting: java_solutions/960.delete-columns-to-make-sorted-iii.java
# - Downloading delete-columns-to-make-sorted-iii
#   ✔ Accepted
#   ✔ 131/131 cases passed (102 ms)
#   ✔ Your runtime beats 5.76 % of java submissions
#   ✔ Your memory usage beats 77.37 % of java submissions (44.2 MB)
# Submitting: java_solutions/961.n-repeated-element-in-size-2n-array.java
# - Downloading n-repeated-element-in-size-2n-array
#   ✔ Accepted
#   ✔ 106/106 cases passed (5 ms)
#   ✔ Your runtime beats 34.17 % of java submissions
#   ✔ Your memory usage beats 41.01 % of java submissions (47.6 MB)
# Submitting: java_solutions/964.least-operators-to-express-number.java
# - Downloading least-operators-to-express-number
#   ✔ Accepted
#   ✔ 162/162 cases passed (1 ms)
#   ✔ Your runtime beats 59.72 % of java submissions
#   ✔ Your memory usage beats 75 % of java submissions (42.3 MB)
# Submitting: java_solutions/965.univalued-binary-tree.java
# - Downloading univalued-binary-tree
#   ✔ Accepted
#   ✔ 72/72 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 38.16 % of java submissions (43 MB)
# Submitting: java_solutions/968.binary-tree-cameras.java
# - Downloading binary-tree-cameras
#   ✔ Accepted
#   ✔ 171/171 cases passed (3 ms)
#   ✔ Your runtime beats 3.12 % of java submissions
#   ✔ Your memory usage beats 11.9 % of java submissions (45.2 MB)
# Submitting: java_solutions/972.equal-rational-numbers.java
# - Downloading equal-rational-numbers
#   ✔ Accepted
#   ✔ 74/74 cases passed (2 ms)
#   ✔ Your runtime beats 70.21 % of java submissions
#   ✔ Your memory usage beats 52.13 % of java submissions (43 MB)
# Submitting: java_solutions/973.k-closest-points-to-origin.java
# - Downloading k-closest-points-to-origin
#   ✔ Accepted
#   ✔ 87/87 cases passed (32 ms)
#   ✔ Your runtime beats 36.74 % of java submissions
#   ✔ Your memory usage beats 24.73 % of java submissions (58.2 MB)
# Submitting: java_solutions/975.odd-even-jump.java
# - Downloading odd-even-jump
#   ✔ Accepted
#   ✔ 65/65 cases passed (103 ms)
#   ✔ Your runtime beats 5.5 % of java submissions
#   ✔ Your memory usage beats 69.42 % of java submissions (49.7 MB)
# Submitting: java_solutions/976.largest-perimeter-triangle.java
# - Downloading largest-perimeter-triangle
#   ✔ Accepted
#   ✔ 84/84 cases passed (53 ms)
#   ✔ Your runtime beats 7.26 % of java submissions
#   ✔ Your memory usage beats 59.34 % of java submissions (47.6 MB)
# Submitting: java_solutions/977.squares-of-a-sorted-array.java
# - Downloading squares-of-a-sorted-array
#   ✔ Accepted
#   ✔ 137/137 cases passed (20 ms)
#   ✔ Your runtime beats 5.04 % of java submissions
#   ✔ Your memory usage beats 25.12 % of java submissions (47.8 MB)
# Submitting: java_solutions/980.unique-paths-iii.java
# - Downloading unique-paths-iii
#   ✔ Accepted
#   ✔ 39/39 cases passed (18 ms)
#   ✔ Your runtime beats 5.28 % of java submissions
#   ✔ Your memory usage beats 17.92 % of java submissions (43 MB)
# Submitting: java_solutions/982.triples-with-bitwise-and-equal-to-zero.java
# - Downloading triples-with-bitwise-and-equal-to-zero
#   ✔ Accepted
#   ✔ 28/28 cases passed (1730 ms)
#   ✔ Your runtime beats 6.2 % of java submissions
#   ✔ Your memory usage beats 51.94 % of java submissions (46.8 MB)
# Submitting: java_solutions/987.vertical-order-traversal-of-a-binary-tree.java
# - Downloading vertical-order-traversal-of-a-binary-tree
#   ✔ Accepted
#   ✔ 34/34 cases passed (4 ms)
#   ✔ Your runtime beats 58.43 % of java submissions
#   ✔ Your memory usage beats 35.84 % of java submissions (44.2 MB)
# Submitting: java_solutions/989.add-to-array-form-of-integer.java
# - Downloading add-to-array-form-of-integer
#   ✔ Accepted
#   ✔ 152/152 cases passed (104 ms)
#   ✔ Your runtime beats 6.53 % of java submissions
#   ✔ Your memory usage beats 5.38 % of java submissions (48.4 MB)
# Submitting: java_solutions/992.subarrays-with-k-different-integers.java
# - Downloading subarrays-with-k-different-integers
#   ✔ Accepted
#   ✔ 57/57 cases passed (12 ms)
#   ✔ Your runtime beats 92.96 % of java submissions
#   ✔ Your memory usage beats 88.22 % of java submissions (49.1 MB)
# Submitting: java_solutions/995.minimum-number-of-k-consecutive-bit-flips.java
# - Downloading minimum-number-of-k-consecutive-bit-flips
#   ✔ Accepted
#   ✔ 113/113 cases passed (13 ms)
#   ✔ Your runtime beats 21.28 % of java submissions
#   ✔ Your memory usage beats 47.37 % of java submissions (73.3 MB)
# Submitting: java_solutions/996.number-of-squareful-arrays.java
# - Downloading number-of-squareful-arrays
#   ✔ Accepted
#   ✔ 77/77 cases passed (4 ms)
#   ✔ Your runtime beats 10.7 % of java submissions
#   ✔ Your memory usage beats 44.04 % of java submissions (43 MB)
# Submitting: java_solutions/997.find-the-town-judge.java
# - Downloading find-the-town-judge
#   ✔ Accepted
#   ✔ 92/92 cases passed (466 ms)
#   ✔ Your runtime beats 5.06 % of java submissions
#   ✔ Your memory usage beats 5.41 % of java submissions (57.2 MB)
# Submitting: java_solutions/1000.minimum-cost-to-merge-stones.java
# - Downloading minimum-cost-to-merge-stones
#   ✔ Accepted
#   ✔ 84/84 cases passed (13 ms)
#   ✔ Your runtime beats 6.79 % of java submissions
#   ✔ Your memory usage beats 5.16 % of java submissions (45.2 MB)
# Submitting: java_solutions/1001.grid-illumination.java
# - Downloading grid-illumination
#   ✔ Accepted
#   ✔ 45/45 cases passed (113 ms)
#   ✔ Your runtime beats 10.88 % of java submissions
#   ✔ Your memory usage beats 30.61 % of java submissions (107 MB)
# Submitting: java_solutions/1002.find-common-characters.java
# - Downloading find-common-characters
#   ✔ Accepted
#   ✔ 88/88 cases passed (23 ms)
#   ✔ Your runtime beats 5.49 % of java submissions
#   ✔ Your memory usage beats 6.61 % of java submissions (53 MB)
# Submitting: java_solutions/1003.check-if-word-is-valid-after-substitutions.java
# - Downloading check-if-word-is-valid-after-substitutions
#   ✔ Accepted
#   ✔ 96/96 cases passed (8 ms)
#   ✔ Your runtime beats 88.11 % of java submissions
#   ✔ Your memory usage beats 43.36 % of java submissions (46.6 MB)
# Submitting: java_solutions/1004.max-consecutive-ones-iii.java
# - Downloading max-consecutive-ones-iii
#   ✔ Accepted
#   ✔ 60/60 cases passed (19 ms)
#   ✔ Your runtime beats 6.6 % of java submissions
#   ✔ Your memory usage beats 7.14 % of java submissions (53.5 MB)
# Submitting: java_solutions/1005.maximize-sum-of-array-after-k-negations.java
# - Downloading maximize-sum-of-array-after-k-negations
#   ✔ Accepted
#   ✔ 84/84 cases passed (11 ms)
#   ✔ Your runtime beats 7.2 % of java submissions
#   ✔ Your memory usage beats 8.37 % of java submissions (45 MB)
# Submitting: java_solutions/1006.clumsy-factorial.java
# - Downloading clumsy-factorial
#   ✔ Accepted
#   ✔ 84/84 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 53.85 % of java submissions (42.4 MB)
# Submitting: java_solutions/1007.minimum-domino-rotations-for-equal-row.java
# - Downloading minimum-domino-rotations-for-equal-row
#   ✔ Accepted
#   ✔ 92/92 cases passed (14 ms)
#   ✔ Your runtime beats 9.09 % of java submissions
#   ✔ Your memory usage beats 87.5 % of java submissions (51.5 MB)
# Submitting: java_solutions/1008.construct-binary-search-tree-from-preorder-traversal.java
# - Downloading construct-binary-search-tree-from-preorder-traversal
#   ✔ Accepted
#   ✔ 111/111 cases passed (1 ms)
#   ✔ Your runtime beats 14.65 % of java submissions
#   ✔ Your memory usage beats 58.38 % of java submissions (43.4 MB)
# Submitting: java_solutions/1009.complement-of-base-10-integer.java
# - Downloading complement-of-base-10-integer
#   ✔ Accepted
#   ✔ 128/128 cases passed (5 ms)
#   ✔ Your runtime beats 2.07 % of java submissions
#   ✔ Your memory usage beats 7.51 % of java submissions (43.6 MB)
# Submitting: java_solutions/1010.pairs-of-songs-with-total-durations-divisible-by-60.java
# - Downloading pairs-of-songs-with-total-durations-divisible-by-60
#   ✔ Accepted
#   ✔ 35/35 cases passed (7 ms)
#   ✔ Your runtime beats 39.36 % of java submissions
#   ✔ Your memory usage beats 42.25 % of java submissions (50.4 MB)
# Submitting: java_solutions/1011.capacity-to-ship-packages-within-d-days.java
# - Downloading capacity-to-ship-packages-within-d-days
#   ✔ Accepted
#   ✔ 90/90 cases passed (19 ms)
#   ✔ Your runtime beats 5.99 % of java submissions
#   ✔ Your memory usage beats 75.02 % of java submissions (50.1 MB)
# Submitting: java_solutions/1012.numbers-with-repeated-digits.java
# - Downloading numbers-with-repeated-digits
#   ✔ Accepted
#   ✔ 130/130 cases passed (1 ms)
#   ✔ Your runtime beats 93.1 % of java submissions
#   ✔ Your memory usage beats 70.5 % of java submissions (42.3 MB)
# Submitting: java_solutions/1013.partition-array-into-three-parts-with-equal-sum.java
# - Downloading partition-array-into-three-parts-with-equal-sum
#   ✔ Accepted
#   ✔ 72/72 cases passed (4 ms)
#   ✔ Your runtime beats 9.14 % of java submissions
#   ✔ Your memory usage beats 25.72 % of java submissions (55.6 MB)
# Submitting: java_solutions/1014.best-sightseeing-pair.java
# - Downloading best-sightseeing-pair
#   ✔ Accepted
#   ✔ 55/55 cases passed (5 ms)
#   ✔ Your runtime beats 16.51 % of java submissions
#   ✔ Your memory usage beats 65.85 % of java submissions (54 MB)
# Submitting: java_solutions/1015.smallest-integer-divisible-by-k.java
# - Downloading smallest-integer-divisible-by-k
#   ✔ Accepted
#   ✔ 71/71 cases passed (5 ms)
#   ✔ Your runtime beats 7.15 % of java submissions
#   ✔ Your memory usage beats 12.49 % of java submissions (42.4 MB)
# Submitting: java_solutions/1016.binary-string-with-substrings-representing-1-to-n.java
# - Downloading binary-string-with-substrings-representing-1-to-n
#   ✔ Accepted
#   ✔ 30/30 cases passed (1 ms)
#   ✔ Your runtime beats 28.38 % of java submissions
#   ✔ Your memory usage beats 30.07 % of java submissions (42.8 MB)
# Submitting: java_solutions/1017.convert-to-base-2.java
# - Downloading convert-to-base-2
#   ✔ Accepted
#   ✔ 170/170 cases passed (1 ms)
#   ✔ Your runtime beats 99.03 % of java submissions
#   ✔ Your memory usage beats 59.74 % of java submissions (42.7 MB)
# Submitting: java_solutions/1018.binary-prefix-divisible-by-5.java
# - Downloading binary-prefix-divisible-by-5
#   ✔ Accepted
#   ✔ 24/24 cases passed (5 ms)
#   ✔ Your runtime beats 1.79 % of java submissions
#   ✔ Your memory usage beats 26.97 % of java submissions (47.7 MB)
# Submitting: java_solutions/1019.next-greater-node-in-linked-list.java
# - Downloading next-greater-node-in-linked-list
#   ✔ Accepted
#   ✔ 76/76 cases passed (17 ms)
#   ✔ Your runtime beats 91.19 % of java submissions
#   ✔ Your memory usage beats 5.97 % of java submissions (51.4 MB)
# Submitting: java_solutions/1020.number-of-enclaves.java
# - Downloading number-of-enclaves
#   ✔ Accepted
#   ✔ 60/60 cases passed (15 ms)
#   ✔ Your runtime beats 6.27 % of java submissions
#   ✔ Your memory usage beats 5.14 % of java submissions (67.1 MB)
# Submitting: java_solutions/1021.remove-outermost-parentheses.java
# - Downloading remove-outermost-parentheses
#   ✔ Accepted
#   ✔ 59/59 cases passed (6 ms)
#   ✔ Your runtime beats 31.14 % of java submissions
#   ✔ Your memory usage beats 72.14 % of java submissions (43.5 MB)
# Submitting: java_solutions/1022.sum-of-root-to-leaf-binary-numbers.java
# - Downloading sum-of-root-to-leaf-binary-numbers
#   ✔ Accepted
#   ✔ 63/63 cases passed (14 ms)
#   ✔ Your runtime beats 5.6 % of java submissions
#   ✔ Your memory usage beats 5.08 % of java submissions (46.6 MB)
# Submitting: java_solutions/1023.camelcase-matching.java
# - Downloading camelcase-matching
#   ✔ Accepted
#   ✔ 39/39 cases passed (1 ms)
#   ✔ Your runtime beats 29.26 % of java submissions
#   ✔ Your memory usage beats 6 % of java submissions (43.3 MB)
# Submitting: java_solutions/1024.video-stitching.java
# - Downloading video-stitching
#   ✔ Accepted
#   ✔ 60/60 cases passed (4 ms)
#   ✔ Your runtime beats 9.97 % of java submissions
#   ✔ Your memory usage beats 91.3 % of java submissions (42.8 MB)
# Submitting: java_solutions/1025.divisor-game.java
# - Downloading divisor-game
#   ✔ Accepted
#   ✔ 40/40 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 70.93 % of java submissions (42 MB)
# Submitting: java_solutions/1026.maximum-difference-between-node-and-ancestor.java
# - Downloading maximum-difference-between-node-and-ancestor
#   ✔ Accepted
#   ✔ 30/30 cases passed (17 ms)
#   ✔ Your runtime beats 9.5 % of java submissions
#   ✔ Your memory usage beats 5.94 % of java submissions (46.9 MB)
# Submitting: java_solutions/1027.longest-arithmetic-subsequence.java
# - Downloading longest-arithmetic-subsequence
#   ✔ Accepted
#   ✔ 65/65 cases passed (62 ms)
#   ✔ Your runtime beats 79.5 % of java submissions
#   ✔ Your memory usage beats 77.36 % of java submissions (68.1 MB)
# Submitting: java_solutions/1028.recover-a-tree-from-preorder-traversal.java
# - Downloading recover-a-tree-from-preorder-traversal
#   ✔ Accepted
#   ✔ 105/105 cases passed (8 ms)
#   ✔ Your runtime beats 23.8 % of java submissions
#   ✔ Your memory usage beats 27.27 % of java submissions (46.7 MB)
# Submitting: java_solutions/1029.two-city-scheduling.java
# - Downloading two-city-scheduling
#   ✔ Accepted
#   ✔ 50/50 cases passed (4 ms)
#   ✔ Your runtime beats 10.57 % of java submissions
#   ✔ Your memory usage beats 8.81 % of java submissions (43.8 MB)
# Submitting: java_solutions/1030.matrix-cells-in-distance-order.java
# - Downloading matrix-cells-in-distance-order
#   ✔ Accepted
#   ✔ 66/66 cases passed (25 ms)
#   ✔ Your runtime beats 5.33 % of java submissions
#   ✔ Your memory usage beats 5.54 % of java submissions (54.4 MB)
# Submitting: java_solutions/1031.maximum-sum-of-two-non-overlapping-subarrays.java
# - Downloading maximum-sum-of-two-non-overlapping-subarrays
#   ✔ Accepted
#   ✔ 51/51 cases passed (2 ms)
#   ✔ Your runtime beats 36.97 % of java submissions
#   ✔ Your memory usage beats 80.3 % of java submissions (43.8 MB)
# Submitting: java_solutions/1032.stream-of-characters.java
# - Downloading stream-of-characters
#   ✔ Accepted
#   ✔ 20/20 cases passed (325 ms)
#   ✔ Your runtime beats 5.13 % of java submissions
#   ✔ Your memory usage beats 5.61 % of java submissions (280.9 MB)
# Submitting: java_solutions/1033.moving-stones-until-consecutive.java
# - Downloading moving-stones-until-consecutive
#   ✔ Accepted
#   ✔ 187/187 cases passed (5 ms)
#   ✔ Your runtime beats 1.49 % of java submissions
#   ✔ Your memory usage beats 7.46 % of java submissions (43.1 MB)
# Submitting: java_solutions/1035.uncrossed-lines.java
# - Downloading uncrossed-lines
#   ✔ Accepted
#   ✔ 74/74 cases passed (11 ms)
#   ✔ Your runtime beats 5 % of java submissions
#   ✔ Your memory usage beats 7 % of java submissions (46.4 MB)
# Submitting: java_solutions/1036.escape-a-large-maze.java
# - Downloading escape-a-large-maze
#   ✔ Accepted
#   ✔ 31/31 cases passed (154 ms)
#   ✔ Your runtime beats 60.92 % of java submissions
#   ✔ Your memory usage beats 43.68 % of java submissions (76.9 MB)
# Submitting: java_solutions/1037.valid-boomerang.java
# - Downloading valid-boomerang
#   ✔ Accepted
#   ✔ 206/206 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 12.8 % of java submissions (43.2 MB)
# Submitting: java_solutions/1038.binary-search-tree-to-greater-sum-tree.java
# - Downloading binary-search-tree-to-greater-sum-tree
#   ✔ Accepted
#   ✔ 32/32 cases passed (1 ms)
#   ✔ Your runtime beats 4.48 % of java submissions
#   ✔ Your memory usage beats 6.16 % of java submissions (43.4 MB)
# Submitting: java_solutions/1039.minimum-score-triangulation-of-polygon.java
# - Downloading minimum-score-triangulation-of-polygon
#   ✔ Accepted
#   ✔ 94/94 cases passed (10 ms)
#   ✔ Your runtime beats 5.56 % of java submissions
#   ✔ Your memory usage beats 62.09 % of java submissions (43 MB)
# Submitting: java_solutions/1040.moving-stones-until-consecutive-ii.java
# - Downloading moving-stones-until-consecutive-ii
#   ✔ Accepted
#   ✔ 27/27 cases passed (19 ms)
#   ✔ Your runtime beats 3.33 % of java submissions
#   ✔ Your memory usage beats 69.17 % of java submissions (47.7 MB)
# Submitting: java_solutions/1041.robot-bounded-in-circle.java
# - Downloading robot-bounded-in-circle
#   ✔ Accepted
#   ✔ 117/117 cases passed (1 ms)
#   ✔ Your runtime beats 16.72 % of java submissions
#   ✔ Your memory usage beats 89.59 % of java submissions (42.6 MB)
# Submitting: java_solutions/1042.flower-planting-with-no-adjacent.java
# - Downloading flower-planting-with-no-adjacent
#   ✔ Accepted
#   ✔ 51/51 cases passed (13 ms)
#   ✔ Your runtime beats 71.55 % of java submissions
#   ✔ Your memory usage beats 86.87 % of java submissions (53.5 MB)
# Submitting: java_solutions/1043.partition-array-for-maximum-sum.java
# - Downloading partition-array-for-maximum-sum
#   ✔ Accepted
#   ✔ 52/52 cases passed (10 ms)
#   ✔ Your runtime beats 10 % of java submissions
#   ✔ Your memory usage beats 45.53 % of java submissions (43.9 MB)
# Submitting: java_solutions/1044.longest-duplicate-substring.java
# - Downloading longest-duplicate-substring
#   ✔ Accepted
#   ✔ 69/69 cases passed (965 ms)
#   ✔ Your runtime beats 5.13 % of java submissions
#   ✔ Your memory usage beats 5.13 % of java submissions (261.2 MB)
# Submitting: java_solutions/1046.last-stone-weight.java
# - Downloading last-stone-weight
#   ✔ Accepted
#   ✔ 74/74 cases passed (2 ms)
#   ✔ Your runtime beats 36.23 % of java submissions
#   ✔ Your memory usage beats 16.35 % of java submissions (43.1 MB)
# Submitting: java_solutions/1047.remove-all-adjacent-duplicates-in-string.java
# - Downloading remove-all-adjacent-duplicates-in-string
#   ✔ Accepted
#   ✔ 106/106 cases passed (17 ms)
#   ✔ Your runtime beats 71.61 % of java submissions
#   ✔ Your memory usage beats 65.72 % of java submissions (47 MB)
# Submitting: java_solutions/1048.longest-string-chain.java
# - Downloading longest-string-chain
#   ✔ Accepted
#   ✔ 86/86 cases passed (55 ms)
#   ✔ Your runtime beats 32.77 % of java submissions
#   ✔ Your memory usage beats 14.16 % of java submissions (48 MB)
# Submitting: java_solutions/1049.last-stone-weight-ii.java
# - Downloading last-stone-weight-ii
#   ✔ Accepted
#   ✔ 90/90 cases passed (47 ms)
#   ✔ Your runtime beats 5.06 % of java submissions
#   ✔ Your memory usage beats 5.56 % of java submissions (47.5 MB)
# Submitting: java_solutions/1051.height-checker.java
# - Downloading height-checker
#   ✔ Accepted
#   ✔ 81/81 cases passed (9 ms)
#   ✔ Your runtime beats 35.73 % of java submissions
#   ✔ Your memory usage beats 13.88 % of java submissions (43.8 MB)
# Submitting: java_solutions/1052.grumpy-bookstore-owner.java
# - Downloading grumpy-bookstore-owner
#   ✔ Accepted
#   ✔ 78/78 cases passed (5 ms)
#   ✔ Your runtime beats 13.83 % of java submissions
#   ✔ Your memory usage beats 55.65 % of java submissions (48.7 MB)
# Submitting: java_solutions/1053.previous-permutation-with-one-swap.java
# - Downloading previous-permutation-with-one-swap
#   ✔ Accepted
#   ✔ 55/55 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 92.16 % of java submissions (47.2 MB)
# Submitting: java_solutions/1054.distant-barcodes.java
# - Downloading distant-barcodes
#   ✔ Accepted
#   ✔ 58/58 cases passed (744 ms)
#   ✔ Your runtime beats 5.14 % of java submissions
#   ✔ Your memory usage beats 37.14 % of java submissions (48.6 MB)
# Submitting: java_solutions/1061.lexicographically-smallest-equivalent-string.java
# - Downloading lexicographically-smallest-equivalent-string
#   ✔ Accepted
#   ✔ 117/117 cases passed (4 ms)
#   ✔ Your runtime beats 25.87 % of java submissions
#   ✔ Your memory usage beats 23.78 % of java submissions (43.7 MB)
# Submitting: java_solutions/1071.greatest-common-divisor-of-strings.java
# - Downloading greatest-common-divisor-of-strings
#   ✔ Accepted
#   ✔ 128/128 cases passed (2 ms)
#   ✔ Your runtime beats 16.31 % of java submissions
#   ✔ Your memory usage beats 41.33 % of java submissions (43.7 MB)
# Submitting: java_solutions/1072.flip-columns-for-maximum-number-of-equal-rows.java
# - Downloading flip-columns-for-maximum-number-of-equal-rows
#   ✔ Accepted
#   ✔ 90/90 cases passed (25 ms)
#   ✔ Your runtime beats 73.83 % of java submissions
#   ✔ Your memory usage beats 61.07 % of java submissions (104.3 MB)
# Submitting: java_solutions/1073.adding-two-negabinary-numbers.java
# - Downloading adding-two-negabinary-numbers
#   ✔ Accepted
#   ✔ 267/267 cases passed (2 ms)
#   ✔ Your runtime beats 57 % of java submissions
#   ✔ Your memory usage beats 49 % of java submissions (46.6 MB)
# Submitting: java_solutions/1074.number-of-submatrices-that-sum-to-target.java
# - Downloading number-of-submatrices-that-sum-to-target
#   ✔ Accepted
#   ✔ 40/40 cases passed (162 ms)
#   ✔ Your runtime beats 11.61 % of java submissions
#   ✔ Your memory usage beats 6.4 % of java submissions (47.6 MB)
# Submitting: java_solutions/1078.occurrences-after-bigram.java
# - Downloading occurrences-after-bigram
#   ✔ Accepted
#   ✔ 31/31 cases passed (5 ms)
#   ✔ Your runtime beats 1.22 % of java submissions
#   ✔ Your memory usage beats 5.37 % of java submissions (43.6 MB)
# Submitting: java_solutions/1079.letter-tile-possibilities.java
# - Downloading letter-tile-possibilities
#   ✔ Accepted
#   ✔ 86/86 cases passed (51 ms)
#   ✔ Your runtime beats 5.07 % of java submissions
#   ✔ Your memory usage beats 5.44 % of java submissions (52.2 MB)
# Submitting: java_solutions/1080.insufficient-nodes-in-root-to-leaf-paths.java
# - Downloading insufficient-nodes-in-root-to-leaf-paths
#   ✔ Accepted
#   ✔ 117/117 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 11.35 % of java submissions (47.5 MB)
# Submitting: java_solutions/1081.smallest-subsequence-of-distinct-characters.java
# - Downloading smallest-subsequence-of-distinct-characters
#   ✔ Accepted
#   ✔ 68/68 cases passed (3 ms)
#   ✔ Your runtime beats 75.62 % of java submissions
#   ✔ Your memory usage beats 53.01 % of java submissions (43 MB)
# Submitting: java_solutions/1089.duplicate-zeros.java
# - Downloading duplicate-zeros
#   ✔ Accepted
#   ✔ 33/33 cases passed (26 ms)
#   ✔ Your runtime beats 10.2 % of java submissions
#   ✔ Your memory usage beats 9.05 % of java submissions (48.7 MB)
# Submitting: java_solutions/1090.largest-values-from-labels.java
# - Downloading largest-values-from-labels
#   ✔ Accepted
#   ✔ 81/81 cases passed (26 ms)
#   ✔ Your runtime beats 7.11 % of java submissions
#   ✔ Your memory usage beats 5.58 % of java submissions (49.2 MB)
# Submitting: java_solutions/1091.shortest-path-in-binary-matrix.java
# - Downloading shortest-path-in-binary-matrix
#   ✔ Accepted
#   ✔ 90/90 cases passed (21 ms)
#   ✔ Your runtime beats 20.44 % of java submissions
#   ✔ Your memory usage beats 6.49 % of java submissions (48.1 MB)
# Submitting: java_solutions/1092.shortest-common-supersequence.java
# - Downloading shortest-common-supersequence
#   ✔ Accepted
#   ✔ 50/50 cases passed (32 ms)
#   ✔ Your runtime beats 6.13 % of java submissions
#   ✔ Your memory usage beats 23.53 % of java submissions (54.1 MB)
# Submitting: java_solutions/1093.statistics-from-a-large-sample.java
# - Downloading statistics-from-a-large-sample
#   ✔ Accepted
#   ✔ 52/52 cases passed (52 ms)
#   ✔ Your runtime beats 3.05 % of java submissions
#   ✔ Your memory usage beats 6.11 % of java submissions (53.9 MB)
# Submitting: java_solutions/1094.car-pooling.java
# - Downloading car-pooling
#   ✔ Accepted
#   ✔ 59/59 cases passed (4 ms)
#   ✔ Your runtime beats 43.26 % of java submissions
#   ✔ Your memory usage beats 44.4 % of java submissions (46.3 MB)
# Submitting: java_solutions/1095.find-in-mountain-array.java
# - Downloading find-in-mountain-array
#   ✔ Accepted
#   ✔ 80/80 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 90.2 % of java submissions (46.3 MB)
# Submitting: java_solutions/1096.brace-expansion-ii.java
# - Downloading brace-expansion-ii
#   ✔ Accepted
#   ✔ 115/115 cases passed (43 ms)
#   ✔ Your runtime beats 5.38 % of java submissions
#   ✔ Your memory usage beats 8.6 % of java submissions (53.2 MB)
# Submitting: java_solutions/1103.distribute-candies-to-people.java
# - Downloading distribute-candies-to-people
#   ✔ Accepted
#   ✔ 27/27 cases passed (4 ms)
#   ✔ Your runtime beats 1.42 % of java submissions
#   ✔ Your memory usage beats 6.49 % of java submissions (43 MB)
# Submitting: java_solutions/1104.path-in-zigzag-labelled-binary-tree.java
# - Downloading path-in-zigzag-labelled-binary-tree
#   ✔ Accepted
#   ✔ 44/44 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 17.58 % of java submissions (42.7 MB)
# Submitting: java_solutions/1105.filling-bookcase-shelves.java
# - Downloading filling-bookcase-shelves
#   ✔ Accepted
#   ✔ 20/20 cases passed (5 ms)
#   ✔ Your runtime beats 8.95 % of java submissions
#   ✔ Your memory usage beats 37.35 % of java submissions (44.2 MB)
# Submitting: java_solutions/1106.parsing-a-boolean-expression.java
# - Downloading parsing-a-boolean-expression
#   ✔ Accepted
#   ✔ 78/78 cases passed (12 ms)
#   ✔ Your runtime beats 54.47 % of java submissions
#   ✔ Your memory usage beats 81.62 % of java submissions (43.9 MB)
# Submitting: java_solutions/1108.defanging-an-ip-address.java
# - Downloading defanging-an-ip-address
#   ✔ Accepted
#   ✔ 62/62 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 89.4 % of java submissions (42.6 MB)
# Submitting: java_solutions/1109.corporate-flight-bookings.java
# - Downloading corporate-flight-bookings
#   ✔ Accepted
#   ✔ 63/63 cases passed (6 ms)
#   ✔ Your runtime beats 27.2 % of java submissions
#   ✔ Your memory usage beats 5.39 % of java submissions (85.1 MB)
# Submitting: java_solutions/1110.delete-nodes-and-return-forest.java
# - Downloading delete-nodes-and-return-forest
#   ✔ Accepted
#   ✔ 112/112 cases passed (4 ms)
#   ✔ Your runtime beats 6.79 % of java submissions
#   ✔ Your memory usage beats 5.59 % of java submissions (47 MB)
# Submitting: java_solutions/1111.maximum-nesting-depth-of-two-valid-parentheses-strings.java
# - Downloading maximum-nesting-depth-of-two-valid-parentheses-strings
#   ✔ Accepted
#   ✔ 31/31 cases passed (3 ms)
#   ✔ Your runtime beats 21.21 % of java submissions
#   ✔ Your memory usage beats 5.05 % of java submissions (45.7 MB)
# Submitting: java_solutions/1114.print-in-order.java
# - Downloading print-in-order
#   ✔ Accepted
#   ✔ 36/36 cases passed (16 ms)
#   ✔ Your runtime beats 11.02 % of java submissions
#   ✔ Your memory usage beats 18.93 % of java submissions (44.2 MB)
# Submitting: java_solutions/1115.print-foobar-alternately.java
# - Downloading print-foobar-alternately
#   ✔ Accepted
#   ✔ 144/144 cases passed (23 ms)
#   ✔ Your runtime beats 18.41 % of java submissions
#   ✔ Your memory usage beats 7.57 % of java submissions (52 MB)
# Submitting: java_solutions/1116.print-zero-even-odd.java
# - Downloading print-zero-even-odd
#   ✔ Accepted
#   ✔ 14/14 cases passed (5 ms)
#   ✔ Your runtime beats 98.16 % of java submissions
#   ✔ Your memory usage beats 8.61 % of java submissions (51 MB)
# Submitting: java_solutions/1117.building-h2o.java
# - Downloading building-h2o
#   ✔ Accepted
#   ✔ 11/11 cases passed (19 ms)
#   ✔ Your runtime beats 26.85 % of java submissions
#   ✔ Your memory usage beats 5.93 % of java submissions (54.2 MB)
# Submitting: java_solutions/1122.relative-sort-array.java
# - Downloading relative-sort-array
#   ✔ Accepted
#   ✔ 17/17 cases passed (10 ms)
#   ✔ Your runtime beats 7.79 % of java submissions
#   ✔ Your memory usage beats 6.91 % of java submissions (44.5 MB)
# Submitting: java_solutions/1123.lowest-common-ancestor-of-deepest-leaves.java
# - Downloading lowest-common-ancestor-of-deepest-leaves
#   ✔ Accepted
#   ✔ 81/81 cases passed (18 ms)
#   ✔ Your runtime beats 3.23 % of java submissions
#   ✔ Your memory usage beats 6.34 % of java submissions (46.8 MB)
# Submitting: java_solutions/1124.longest-well-performing-interval.java
# - Downloading longest-well-performing-interval
#   ✔ Accepted
#   ✔ 98/98 cases passed (15 ms)
#   ✔ Your runtime beats 20.77 % of java submissions
#   ✔ Your memory usage beats 61.82 % of java submissions (47.3 MB)
# Submitting: java_solutions/1125.smallest-sufficient-team.java
# - Downloading smallest-sufficient-team
#   ✔ Accepted
#   ✔ 38/38 cases passed (25 ms)
#   ✔ Your runtime beats 67.29 % of java submissions
#   ✔ Your memory usage beats 84.06 % of java submissions (44.8 MB)
# Submitting: java_solutions/1128.number-of-equivalent-domino-pairs.java
# - Downloading number-of-equivalent-domino-pairs
#   ✔ Accepted
#   ✔ 19/19 cases passed (16 ms)
#   ✔ Your runtime beats 36.77 % of java submissions
#   ✔ Your memory usage beats 7.62 % of java submissions (64.7 MB)
# Submitting: java_solutions/1129.shortest-path-with-alternating-colors.java
# - Downloading shortest-path-with-alternating-colors
#   ✔ Accepted
#   ✔ 90/90 cases passed (10 ms)
#   ✔ Your runtime beats 16.81 % of java submissions
#   ✔ Your memory usage beats 15.77 % of java submissions (46.9 MB)
# Submitting: java_solutions/1130.minimum-cost-tree-from-leaf-values.java
# - Downloading minimum-cost-tree-from-leaf-values
#   ✔ Accepted
#   ✔ 103/103 cases passed (1 ms)
#   ✔ Your runtime beats 98.75 % of java submissions
#   ✔ Your memory usage beats 72.73 % of java submissions (43 MB)

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-05-04 17:37:51
