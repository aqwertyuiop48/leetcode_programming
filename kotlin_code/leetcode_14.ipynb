# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME_2')
    user_cookie = userdata.get('LEETCODE_TOKEN_2')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME_2'] = user_name
    os.environ['LEETCODE_TOKEN_2'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME_2" "$LEETCODE_TOKEN_2" | leetcode user -c

# %%
# %%bash
#
# # top 500-600 answers (6th batch)
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v kotlin_solutions_1/*.kt | sed -n '501,600p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 7
# done
# Out:
# Submitting: kotlin_solutions_1/1657.determine-if-two-strings-are-close.kt
# - Downloading determine-if-two-strings-are-close
#   ✔ Accepted
#   ✔ 169/169 cases passed (163 ms)
#   ✔ Your runtime beats 6.58 % of kotlin submissions
#   ✔ Your memory usage beats 55.26 % of kotlin submissions (51.1 MB)
# Submitting: kotlin_solutions_1/1658.minimum-operations-to-reduce-x-to-zero.kt
# - Downloading minimum-operations-to-reduce-x-to-zero
#   ✔ Accepted
#   ✔ 97/97 cases passed (114 ms)
#   ✔ Your runtime beats 7.14 % of kotlin submissions
#   ✔ Your memory usage beats 7.14 % of kotlin submissions (70.6 MB)
# Submitting: kotlin_solutions_1/1659.maximize-grid-happiness.kt
# - Downloading maximize-grid-happiness
#   ✔ Accepted
#   ✔ 67/67 cases passed (129 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1662.check-if-two-string-arrays-are-equivalent.kt
# - Downloading check-if-two-string-arrays-are-equivalent
#   ✔ Accepted
#   ✔ 113/113 cases passed (17 ms)
#   ✔ Your runtime beats 11.11 % of kotlin submissions
#   ✔ Your memory usage beats 11.11 % of kotlin submissions (45.7 MB)
# Submitting: kotlin_solutions_1/1663.smallest-string-with-a-given-numeric-value.kt
# - Downloading smallest-string-with-a-given-numeric-value
#   ✔ Accepted
#   ✔ 94/94 cases passed (12 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/1664.ways-to-make-a-fair-array.kt
# - Downloading ways-to-make-a-fair-array
#   ✔ Accepted
#   ✔ 105/105 cases passed (66 ms)
#   ✔ Your runtime beats 5.56 % of kotlin submissions
#   ✔ Your memory usage beats 5.55 % of kotlin submissions (66.4 MB)
# Submitting: kotlin_solutions_1/1665.minimum-initial-energy-to-finish-tasks.kt
# - Downloading minimum-initial-energy-to-finish-tasks
# [ERROR] session expired, please login again [code=-1]
# Submitting: kotlin_solutions_1/1668.maximum-repeating-substring.kt
# - Downloading maximum-repeating-substring
#   ✔ Accepted
#   ✔ 212/212 cases passed (17 ms)
#   ✔ Your runtime beats 6.67 % of kotlin submissions
#   ✔ Your memory usage beats 13.33 % of kotlin submissions (43.6 MB)
# Submitting: kotlin_solutions_1/1669.merge-in-between-linked-lists.kt
# - Downloading merge-in-between-linked-lists
#   ✔ Accepted
#   ✔ 61/61 cases passed (445 ms)
#   ✔ Your runtime beats 12.5 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/1670.design-front-middle-back-queue.kt
# - Downloading design-front-middle-back-queue
#   ✔ Accepted
#   ✔ 95/95 cases passed (24 ms)
#   ✔ Your runtime beats 88.24 % of kotlin submissions
#   ✔ Your memory usage beats 82.35 % of kotlin submissions (48.7 MB)
# Submitting: kotlin_solutions_1/1671.minimum-number-of-removals-to-make-mountain-array.kt
# - Downloading minimum-number-of-removals-to-make-mountain-array
#   ✔ Accepted
#   ✔ 91/91 cases passed (252 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1672.richest-customer-wealth.kt
# - Downloading richest-customer-wealth
#   ✔ Accepted
#   ✔ 34/34 cases passed (11 ms)
#   ✔ Your runtime beats 23.33 % of kotlin submissions
#   ✔ Your memory usage beats 51.67 % of kotlin submissions (46.1 MB)
# Submitting: kotlin_solutions_1/1673.find-the-most-competitive-subsequence.kt
# - Downloading find-the-most-competitive-subsequence
#   ✔ Accepted
#   ✔ 88/88 cases passed (74 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1674.minimum-moves-to-make-array-complementary.kt
# - Downloading minimum-moves-to-make-array-complementary
#   ✔ Accepted
#   ✔ 114/114 cases passed (36 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1675.minimize-deviation-in-array.kt
# - Downloading minimize-deviation-in-array
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 7: Char 62: ERROR: Return type mismatch: expected 'kotlin.Int', actual 'java.util.PriorityQueue<kotlin.Int>'.
#   ✘ Error: Line 7: Char 62: ERROR: Return type mismatch: expected 'kotlin.Int', actual 'java.util.PriorityQueue<kotlin.Int>'.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1678.goal-parser-interpretation.kt
# - Downloading goal-parser-interpretation
#   ✔ Accepted
#   ✔ 105/105 cases passed (90 ms)
#   ✔ Your runtime beats 83.33 % of kotlin submissions
#   ✔ Your memory usage beats 8.33 % of kotlin submissions (41.2 MB)
# Submitting: kotlin_solutions_1/1679.max-number-of-k-sum-pairs.kt
# - Downloading max-number-of-k-sum-pairs
#   ✔ Accepted
#   ✔ 51/51 cases passed (590 ms)
#   ✔ Your runtime beats 6.56 % of kotlin submissions
#   ✔ Your memory usage beats 36.89 % of kotlin submissions (61.3 MB)
# Submitting: kotlin_solutions_1/1680.concatenation-of-consecutive-binary-numbers.kt
# - Downloading concatenation-of-consecutive-binary-numbers
#   ✔ Accepted
#   ✔ 403/403 cases passed (117 ms)
#   ✔ Your runtime beats 75 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (40 MB)
# Submitting: kotlin_solutions_1/1681.minimum-incompatibility.kt
# - Downloading minimum-incompatibility
#   ✔ Accepted
#   ✔ 59/59 cases passed (376 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/1684.count-the-number-of-consistent-strings.kt
# - Downloading count-the-number-of-consistent-strings
#   ✔ Accepted
#   ✔ 74/74 cases passed (203 ms)
#   ✔ Your runtime beats 58.62 % of kotlin submissions
#   ✔ Your memory usage beats 20.69 % of kotlin submissions (47.6 MB)
# Submitting: kotlin_solutions_1/1685.sum-of-absolute-differences-in-a-sorted-array.kt
# - Downloading sum-of-absolute-differences-in-a-sorted-array
#   ✔ Accepted
#   ✔ 59/59 cases passed (508 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (66 MB)
# Submitting: kotlin_solutions_1/1686.stone-game-vi.kt
# - Downloading stone-game-vi
#   ✔ Accepted
#   ✔ 95/95 cases passed (160 ms)
#   ✔ Your runtime beats 57.14 % of kotlin submissions
#   ✔ Your memory usage beats 85.71 % of kotlin submissions (74.3 MB)
# Submitting: kotlin_solutions_1/1687.delivering-boxes-from-storage-to-ports.kt
# - Downloading delivering-boxes-from-storage-to-ports
#   ✔ Accepted
#   ✔ 39/39 cases passed (28 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/1688.count-of-matches-in-tournament.kt
# - Downloading count-of-matches-in-tournament
#   ✔ Accepted
#   ✔ 200/200 cases passed (75 ms)
#   ✔ Your runtime beats 72.73 % of kotlin submissions
#   ✔ Your memory usage beats 36.36 % of kotlin submissions (39.5 MB)
# Submitting: kotlin_solutions_1/1689.partitioning-into-minimum-number-of-deci-binary-numbers.kt
# - Downloading partitioning-into-minimum-number-of-deci-binary-numbers
#   ✔ Accepted
#   ✔ 97/97 cases passed (14 ms)
#   ✔ Your runtime beats 87.5 % of kotlin submissions
#   ✔ Your memory usage beats 37.5 % of kotlin submissions (47.4 MB)
# Submitting: kotlin_solutions_1/1690.stone-game-vii.kt
# - Downloading stone-game-vii
#   ✔ Accepted
#   ✔ 68/68 cases passed (190 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (46.1 MB)
# Submitting: kotlin_solutions_1/1691.maximum-height-by-stacking-cuboids.kt
# - Downloading maximum-height-by-stacking-cuboids
#   ✔ Accepted
#   ✔ 83/83 cases passed (200 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1694.reformat-phone-number.kt
# - Downloading reformat-phone-number
#   ✔ Accepted
#   ✔ 108/108 cases passed (21 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 16.67 % of kotlin submissions (45.1 MB)
# Submitting: kotlin_solutions_1/1695.maximum-erasure-value.kt
# - Downloading maximum-erasure-value
#   ✔ Accepted
#   ✔ 62/62 cases passed (13 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 71.43 % of kotlin submissions (63.1 MB)
# Submitting: kotlin_solutions_1/1696.jump-game-vi.kt
# - Downloading jump-game-vi
#   ✔ Accepted
#   ✔ 73/73 cases passed (63 ms)
#   ✔ Your runtime beats 42.86 % of kotlin submissions
#   ✔ Your memory usage beats 28.57 % of kotlin submissions (66.8 MB)
# Submitting: kotlin_solutions_1/1697.checking-existence-of-edge-length-limited-paths.kt
# - Downloading checking-existence-of-edge-length-limited-paths
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 584: WARNING: Parameter 'it: IntArray' is never used, could be renamed to '_'.
#   ✘ Error: Line 2: Char 584: WARNING: Parameter 'it: IntArray' is never used, could be renamed to '_'.
# Line 2: Char 727: WARNING: Parameter 'it: IntArray' is never used, could be renamed to '_'.
# Line 2: Char 754: WARNING: Parameter 'it: IntArray' is never used, could be renamed to '_'.
# Line 40: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1700.number-of-students-unable-to-eat-lunch.kt
# - Downloading number-of-students-unable-to-eat-lunch
#   ✔ Accepted
#   ✔ 55/55 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 65.12 % of kotlin submissions (41.5 MB)
# Submitting: kotlin_solutions_1/1701.average-waiting-time.kt
# - Downloading average-waiting-time
#   ✔ Accepted
#   ✔ 38/38 cases passed (8 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1702.maximum-binary-string-after-change.kt
# - Downloading maximum-binary-string-after-change
#   ✔ Accepted
#   ✔ 76/76 cases passed (32 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1703.minimum-adjacent-swaps-for-k-consecutive-ones.kt
# - Downloading minimum-adjacent-swaps-for-k-consecutive-ones
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 38: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Error: Line 38: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1704.determine-if-string-halves-are-alike.kt
# - Downloading determine-if-string-halves-are-alike
# [ERROR] http error [code=429]
# Submitting: kotlin_solutions_1/1705.maximum-number-of-eaten-apples.kt
# - Downloading maximum-number-of-eaten-apples
#   ✔ Accepted
#   ✔ 73/73 cases passed (181 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (56.8 MB)
# Submitting: kotlin_solutions_1/1706.where-will-the-ball-fall.kt
# - Downloading where-will-the-ball-fall
#   ✔ Accepted
#   ✔ 64/64 cases passed (10 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
#   ✔ Your memory usage beats 20 % of kotlin submissions (54.7 MB)
# Submitting: kotlin_solutions_1/1707.maximum-xor-with-an-element-from-array.kt
# - Downloading maximum-xor-with-an-element-from-array
#   ✔ Accepted
#   ✔ 67/67 cases passed (364 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (274.4 MB)
# Submitting: kotlin_solutions_1/1710.maximum-units-on-a-truck.kt
# - Downloading maximum-units-on-a-truck
#   ✔ Accepted
#   ✔ 77/77 cases passed (29 ms)
#   ✔ Your runtime beats 15 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (50.3 MB)
# Submitting: kotlin_solutions_1/1711.count-good-meals.kt
# - Downloading count-good-meals
#   ✔ Accepted
#   ✔ 72/72 cases passed (127 ms)
#   ✔ Your runtime beats 8.7 % of kotlin submissions
#   ✔ Your memory usage beats 8.7 % of kotlin submissions (64.9 MB)
# Submitting: kotlin_solutions_1/1712.ways-to-split-array-into-three-subarrays.kt
# - Downloading ways-to-split-array-into-three-subarrays
#   ✔ Accepted
#   ✔ 89/89 cases passed (183 ms)
#   ✔ Your runtime beats 10 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (64.3 MB)
# Submitting: kotlin_solutions_1/1713.minimum-operations-to-make-a-subsequence.kt
# - Downloading minimum-operations-to-make-a-subsequence
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 8: Char 137: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
#   ✘ Error: Line 8: Char 137: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 8: Char 137: ERROR: Not enough information to infer type argument for 'R'.
# Line 8: Char 154: ERROR: None of the following candidates is applicable:
# fun <T, R : Any> Array<out T>.mapNotNull(transform: (T) -> R?): List<R>
# fun <T, R : Any> Iterable<T>.mapNotNull(transform: (T) -> R?): List<R>
# fun <K, V, R : Any> Map<out K, V>.mapNotNull(transform: (Map.Entry<K, V>) -> R?): List<R>
# fun <T, R : Any> Sequence<T>.mapNotNull(transform: (T) -> R?): Sequence<R>
# fun <R : Any> CharSequence.mapNotNull(transform: (Char) -> R?): List<R>
# Line 8: Char 171: ERROR: Unresolved reference 'it'.
# Line 8: Char 187: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 8: Char 192: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 8: Char 314: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 8: Char 325: ERROR: Not enough information to infer type argument for 'K'.
# Line 8: Char 360: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 8: Char 360: ERROR: Not enough information to infer type argument for 'R'.
# Line 8: Char 360: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun <T, R> T.let(block: (T) -> R): R
#     [R|Contract description]
#      <
#         CallsInPlace(block, EXACTLY_ONCE)
#     >
# Line 8: Char 364: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1716.calculate-money-in-leetcode-bank.kt
# - Downloading calculate-money-in-leetcode-bank
#   ✔ Accepted
#   ✔ 106/106 cases passed (9 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1717.maximum-score-from-removing-substrings.kt
# - Downloading maximum-score-from-removing-substrings
#   ✔ Accepted
#   ✔ 77/77 cases passed (87 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1718.construct-the-lexicographically-largest-valid-sequence.kt
# - Downloading construct-the-lexicographically-largest-valid-sequence
#   ✔ Accepted
#   ✔ 20/20 cases passed (21 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1719.number-of-ways-to-reconstruct-a-tree.kt
# - Downloading number-of-ways-to-reconstruct-a-tree
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 41: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Error: Line 41: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1720.decode-xored-array.kt
# - Downloading decode-xored-array
#   ✔ Accepted
#   ✔ 76/76 cases passed (2 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (49.1 MB)
# Submitting: kotlin_solutions_1/1721.swapping-nodes-in-a-linked-list.kt
# - Downloading swapping-nodes-in-a-linked-list
#   ✔ Accepted
#   ✔ 132/132 cases passed (27 ms)
#   ✔ Your runtime beats 6.67 % of kotlin submissions
#   ✔ Your memory usage beats 46.67 % of kotlin submissions (68.5 MB)
# Submitting: kotlin_solutions_1/1722.minimize-hamming-distance-after-swap-operations.kt
# - Downloading minimize-hamming-distance-after-swap-operations
#   ✔ Accepted
#   ✔ 70/70 cases passed (264 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (97.7 MB)
# Submitting: kotlin_solutions_1/1723.find-minimum-time-to-finish-all-jobs.kt
# - Downloading find-minimum-time-to-finish-all-jobs
#   ✔ Accepted
#   ✔ 65/65 cases passed (380 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (51.9 MB)
# Submitting: kotlin_solutions_1/1725.number-of-rectangles-that-can-form-the-largest-square.kt
# - Downloading number-of-rectangles-that-can-form-the-largest-square
#   ✔ Accepted
#   ✔ 68/68 cases passed (289 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (56.7 MB)
# Submitting: kotlin_solutions_1/1726.tuple-with-same-product.kt
# - Downloading tuple-with-same-product
#   ✔ Accepted
#   ✔ 37/37 cases passed (265 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/
4788,2104,5205,3975,3573,6441,4511,9798,5621,1641,9432,7645,2446,5724,418,5965,5633,556,9705,7004,6998,8141,6579,99,1203,4781,1736,759,6424,6471,6262,4102,8548,2949,7679,8587,8284,357,4421,7953,7345,9954,9767,8093,5024,3596,1581,4257,1422,8079,1482,4267,8206,8283,4137,2580,8667,8998,7015,9019,3535,9674,3342,274,5205,6769,7183,87,7948,2363,816,6858,5390,150,1468,5572,1360,7187,9811,3171,2432,4086,1091,4994,455,3236,2181,3795,1644,7585,2467,9992,3843,2760,9141,9568,5449,2324,3854,2197,838,1939,4860,1604,3483,3905,9523,2961,7514,5769,6509,8183,8322,1551,7138,4344,1107,6746,9195,8699,6156,9894,9166,4170,1292,1691,7841,6199,6682,3035,2511,8572,2188,3077,832,526,4659,5845,9298,1621,3069,9014,2094,74,8387,4224,9393,2511,4226,9297,2196,6500,6284,3421,1617,2944,7849,1522,7575,4451,3468,7690,4863,5568,2619,8131,2909,8197,7638,4668,2601,2947,5989,2673,182,7121,1786,92,3083,6628,8176,1752,7833,2427,2440,6162,5344,5546,1148,3036,8521,3148,5345,577,947,2879,811,8295,9538,7185,32,1027,868,5031,6067,7805,5886,3363,5680,6187,5707,1847,5011,9909,4223,2325,2235,1424,8916,1964,7580,5478,7449,6506,5551,562,516,7953,8254,7188,8671,9906,9556,1810,2580,2842,2936,1706,4141,2316,6516,7632,3917,5416,5629,3871,1065,5336,3301,1380,6279,618,2929,8954,6392,5438,5717,8544,8675,2577,5265,7298,7308,6150,6025,3252,3529,3110,5769,8173,4438,2917,933,2600,6034,2979,5267,8655,3698,7799,5686,7261,652,3698,1351,8043,3949,895 ...
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1736.latest-time-by-replacing-hidden-digits.kt
# - Downloading latest-time-by-replacing-hidden-digits
# [ERROR] session expired, please login again [code=-1]
# Submitting: kotlin_solutions_1/1737.change-minimum-characters-to-satisfy-one-of-three-conditions.kt
# - Downloading change-minimum-characters-to-satisfy-one-of-three-conditions
#   ✔ Accepted
#   ✔ 72/72 cases passed (43 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1738.find-kth-largest-xor-coordinate-value.kt
# - Downloading find-kth-largest-xor-coordinate-value
#   ✔ Accepted
#   ✔ 49/49 cases passed (266 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1739.building-boxes.kt
# - Downloading building-boxes
#   ✔ Accepted
#   ✔ 86/86 cases passed (15 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1742.maximum-number-of-balls-in-a-box.kt
# - Downloading maximum-number-of-balls-in-a-box
#   ✔ Accepted
#   ✔ 97/97 cases passed (62 ms)
#   ✔ Your runtime beats 14.29 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (49.3 MB)
# Submitting: kotlin_solutions_1/1743.restore-the-array-from-adjacent-pairs.kt
# - Downloading restore-the-array-from-adjacent-pairs
#   ✔ Accepted
#   ✔ 46/46 cases passed (168 ms)
#   ✔ Your runtime beats 40.91 % of kotlin submissions
#   ✔ Your memory usage beats 13.64 % of kotlin submissions (118.1 MB)
# Submitting: kotlin_solutions_1/1744.can-you-eat-your-favorite-candy-on-your-favorite-day.kt
# - Downloading can-you-eat-your-favorite-candy-on-your-favorite-day
#   ✔ Accepted
#   ✔ 64/64 cases passed (22 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1745.palindrome-partitioning-iv.kt
# - Downloading palindrome-partitioning-iv
#   ✔ Accepted
#   ✔ 92/92 cases passed (98 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1748.sum-of-unique-elements.kt
# - Downloading sum-of-unique-elements
#   ✔ Accepted
#   ✔ 73/73 cases passed (9 ms)
#   ✔ Your runtime beats 9.09 % of kotlin submissions
#   ✔ Your memory usage beats 18.18 % of kotlin submissions (42.2 MB)
# Submitting: kotlin_solutions_1/1749.maximum-absolute-sum-of-any-subarray.kt
# - Downloading maximum-absolute-sum-of-any-subarray
#   ✔ Accepted
#   ✔ 67/67 cases passed (33 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1750.minimum-length-of-string-after-deleting-similar-ends.kt
# - Downloading minimum-length-of-string-after-deleting-similar-ends
#   ✘ Time Limit Exceeded
#   ✘ 100/103 cases passed (N/A)
#   ✘ Testcase: "...'... 89998 more character
#   ✘ Answer:
#   ✘ Expected Answer: 0
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1751.maximum-number-of-events-that-can-be-attended-ii.kt
# - Downloading maximum-number-of-events-that-can-be-attended-ii
#   ✔ Accepted
#   ✔ 70/70 cases passed (332 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1752.check-if-array-is-sorted-and-rotated.kt
# - Downloading check-if-array-is-sorted-and-rotated
#   ✔ Accepted
#   ✔ 113/113 cases passed (13 ms)
#   ✔ Your runtime beats 2.33 % of kotlin submissions
#   ✔ Your memory usage beats 9.3 % of kotlin submissions (45.6 MB)
# Submitting: kotlin_solutions_1/1753.maximum-score-from-removing-stones.kt
# - Downloading maximum-score-from-removing-stones
#   ✔ Accepted
#   ✔ 96/96 cases passed (12 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1754.largest-merge-of-two-strings.kt
# - Downloading largest-merge-of-two-strings
#   ✔ Accepted
#   ✔ 102/102 cases passed (26 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (45.7 MB)
# Submitting: kotlin_solutions_1/1755.closest-subsequence-sum.kt
# - Downloading closest-subsequence-sum
#   ✔ Accepted
#   ✔ 74/74 cases passed (282 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (74.4 MB)
# Submitting: kotlin_solutions_1/1758.minimum-changes-to-make-alternating-binary-string.kt
# - Downloading minimum-changes-to-make-alternating-binary-string
#   ✔ Accepted
#   ✔ 89/89 cases passed (15 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1759.count-number-of-homogenous-substrings.kt
# - Downloading count-number-of-homogenous-substrings
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 232: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
#   ✘ Error: Line 2: Char 232: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 36: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1760.minimum-limit-of-balls-in-a-bag.kt
# - Downloading minimum-limit-of-balls-in-a-bag
#   ✔ Accepted
#   ✔ 61/61 cases passed (33 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 42.86 % of kotlin submissions (63 MB)
# Submitting: kotlin_solutions_1/1761.minimum-degree-of-a-connected-trio-in-a-graph.kt
# - Downloading minimum-degree-of-a-connected-trio-in-a-graph
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 38: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Error: Line 38: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1763.longest-nice-substring.kt
# - Downloading longest-nice-substring
#   ✔ Accepted
#   ✔ 73/73 cases passed (42 ms)
#   ✔ Your runtime beats 23.81 % of kotlin submissions
#   ✔ Your memory usage beats 9.52 % of kotlin submissions (49.7 MB)
# Submitting: kotlin_solutions_1/1764.form-array-by-concatenating-subarrays-of-another-array.kt
# - Downloading form-array-by-concatenating-subarrays-of-another-array
#   ✔ Accepted
#   ✔ 98/98 cases passed (22 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1765.map-of-highest-peak.kt
# - Downloading map-of-highest-peak
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 667: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
#   ✘ Error: Line 2: Char 667: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 36: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1766.tree-of-coprimes.kt
# - Downloading tree-of-coprimes
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 103: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 2: Char 103: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 274: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 571: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 2: Char 835: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 835: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# suspend fun <U, S> DeepRecursiveFunction<U, S>.callRecursive(value: U): S
# Line 2: Char 867: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 867: ERROR: Not enough information to infer type argument for 'T'.
# Line 2: Char 871: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 871: WARNING: Parameter 'it: <ERROR TYPE REF: Cannot infer argument for type parameter T>' is never used, could be renamed to '_'.
# Line 9: Char 1: ERROR: Argument type mismatch: actual type is 'kotlin.Unit', but 'kotlin.IntArray' was expected.
# Line 38: Char 2: ERROR: Syntax error: Expecting '}'.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1768.merge-strings-alternately.kt
# - Downloading merge-strings-alternately
#   ✔ Accepted
#   ✔ 108/108 cases passed (115 ms)
#   ✔ Your runtime beats 8.6 % of kotlin submissions
#   ✔ Your memory usage beats 5.38 % of kotlin submissions (45.2 MB)
# Submitting: kotlin_solutions_1/1769.minimum-number-of-operations-to-move-all-balls-to-each-box.kt
# - Downloading minimum-number-of-operations-to-move-all-balls-to-each-box
#   ✔ Accepted
#   ✔ 95/95 cases passed (283 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1770.maximum-score-from-performing-multiplication-operations.kt
# - Downloading maximum-score-from-performing-multiplication-operations
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 38: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Error: Line 38: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1771.maximize-palindrome-length-from-subsequences.kt
# - Downloading maximize-palindrome-length-from-subsequences
#   ✔ Accepted
#   ✔ 109/109 cases passed (142 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1773.count-items-matching-a-rule.kt
# - Downloading count-items-matching-a-rule
#   ✔ Accepted
#   ✔ 92/92 cases passed (5 ms)
#   ✔ Your runtime beats 75 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (53.4 MB)
# Submitting: kotlin_solutions_1/1774.closest-dessert-cost.kt
# - Downloading closest-dessert-cost
#   ✘ Wrong Answer
#   ✘ 72/89 cases passed (N/A)
#   ✘ Testcase: [10]
# [1]
# 1
#   ✘ Answer: 0
#   ✘ Expected Answer: 10
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1775.equal-sum-arrays-with-minimum-number-of-operations.kt
# - Downloading equal-sum-arrays-with-minimum-number-of-operations
#   ✔ Accepted
#   ✔ 65/65 cases passed (139 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1776.car-fleet-ii.kt
# - Downloading car-fleet-ii
#   ✔ Accepted
#   ✔ 85/85 cases passed (138 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1779.find-nearest-point-that-has-the-same-x-or-y-coordinate.kt
# - Downloading find-nearest-point-that-has-the-same-x-or-y-coordinate
#   ✔ Accepted
#   ✔ 102/102 cases passed (22 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1780.check-if-number-is-a-sum-of-powers-of-three.kt
# - Downloading check-if-number-is-a-sum-of-powers-of-three
#   ✔ Accepted
#   ✔ 129/129 cases passed (8 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1781.sum-of-beauty-of-all-substrings.kt
# - Downloading sum-of-beauty-of-all-substrings
#   ✔ Accepted
#   ✔ 57/57 cases passed (418 ms)
#   ✔ Your runtime beats 7.14 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (49.4 MB)
# Submitting: kotlin_solutions_1/1782.count-pairs-of-nodes.kt
# - Downloading count-pairs-of-nodes
#   ✔ Accepted
#   ✔ 63/63 cases passed (251 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1784.check-if-binary-string-has-at-most-one-segment-of-ones.kt
# - Downloading check-if-binary-string-has-at-most-one-segment-of-ones
#   ✔ Accepted
#   ✔ 191/191 cases passed (6 ms)
#   ✔ Your runtime beats 37.5 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (42.2 MB)
# Submitting: kotlin_solutions_1/1785.minimum-elements-to-add-to-form-a-given-sum.kt
# - Downloading minimum-elements-to-add-to-form-a-given-sum
#   ✔ Accepted
#   ✔ 78/78 cases passed (2 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (62.6 MB)
# Submitting: kotlin_solutions_1/1787.make-the-xor-of-all-segments-equal-to-zero.kt
# - Downloading make-the-xor-of-all-segments-equal-to-zero
#   ✔ Accepted
#   ✔ 81/81 cases passed (1647 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1790.check-if-one-string-swap-can-make-strings-equal.kt
# - Downloading check-if-one-string-swap-can-make-strings-equal
#   ✔ Accepted
#   ✔ 137/137 cases passed (11 ms)
#   ✔ Your runtime beats 5.88 % of kotlin submissions
#   ✔ Your memory usage beats 17.65 % of kotlin submissions (42.1 MB)
# Submitting: kotlin_solutions_1/1791.find-center-of-star-graph.kt
# - Downloading find-center-of-star-graph
#   ✔ Accepted
#   ✔ 61/61 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (98.8 MB)

# %%
# %%bash
#
# # top 500-600 answers (6th batch)
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v kotlin_solutions/*.kt | sed -n '501,505p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 7
# done
# Out:
# Submitting: kotlin_solutions/668.kth-smallest-number-in-multiplication-table.kt
#   ✔ Accepted
#   ✔ 71/71 cases passed (27 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/669.trim-a-binary-search-tree.kt
#   ✔ Accepted
#   ✔ 78/78 cases passed (11 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/670.maximum-swap.kt
#   ✔ Accepted
#   ✔ 112/112 cases passed (20 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (45.7 MB)
# Submitting: kotlin_solutions/671.second-minimum-node-in-a-binary-tree.kt
#   ✔ Accepted
#   ✔ 39/39 cases passed (31 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/672.bulb-switcher-ii.kt
#   ✔ Accepted
#   ✔ 80/80 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (40.2 MB)

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-08-17 17:27:23
