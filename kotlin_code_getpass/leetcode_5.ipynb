# %%
# %%capture
import os
import getpass

# 2. Interactive input (Safe and hidden)
print("Please enter your LeetCode credentials:")
user_name = getpass.getpass('LeetCode Username: ')
user_cookie = getpass.getpass('LeetCode Session Token: ')

# 1. Install and Clone
# !npm install -g leetcode-tools/leetcode-cli
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME'] = user_name
    os.environ['LEETCODE_TOKEN'] = user_cookie

    # 4. Run the login silently
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME" "$LEETCODE_TOKEN" | leetcode user -c

# %%
# %%bash
#
# # top 400-500 answers (5th batch)
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v kotlin_solutions/*.kt | sed -n '401,450p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 6
# done
# Out:
# Submitting: kotlin_solutions/507.perfect-number.kt
# - Downloading problems
# - Downloading perfect-number
#   ✔ Accepted
#   ✔ 98/98 cases passed (10 ms)
#   ✔ Your runtime beats 62.86 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (42.4 MB)
# Submitting: kotlin_solutions/508.most-frequent-subtree-sum.kt
# - Downloading most-frequent-subtree-sum
#   ✔ Accepted
#   ✔ 58/58 cases passed (29 ms)
#   ✔ Your runtime beats 41.18 % of kotlin submissions
#   ✔ Your memory usage beats 23.53 % of kotlin submissions (49.1 MB)
# Submitting: kotlin_solutions/509.fibonacci-number.kt
# - Downloading fibonacci-number
#   ✔ Accepted
#   ✔ 31/31 cases passed (57 ms)
#   ✔ Your runtime beats 98.63 % of kotlin submissions
#   ✔ Your memory usage beats 87.97 % of kotlin submissions (38.9 MB)
# Submitting: kotlin_solutions/513.find-bottom-left-tree-value.kt
# - Downloading find-bottom-left-tree-value
#   ✔ Accepted
#   ✔ 79/79 cases passed (10 ms)
#   ✔ Your runtime beats 57.89 % of kotlin submissions
#   ✔ Your memory usage beats 57.89 % of kotlin submissions (47.3 MB)
# Submitting: kotlin_solutions/514.freedom-trail.kt
# - Downloading freedom-trail
#   ✔ Accepted
#   ✔ 303/303 cases passed (98 ms)
#   ✔ Your runtime beats 37.5 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (52.1 MB)
# Submitting: kotlin_solutions/515.find-largest-value-in-each-tree-row.kt
# - Downloading find-largest-value-in-each-tree-row
#   ✔ Accepted
#   ✔ 78/78 cases passed (21 ms)
#   ✔ Your runtime beats 42.5 % of kotlin submissions
#   ✔ Your memory usage beats 87.5 % of kotlin submissions (46.1 MB)
# Submitting: kotlin_solutions/516.longest-palindromic-subsequence.kt
# - Downloading longest-palindromic-subsequence
#   ✔ Accepted
#   ✔ 86/86 cases passed (45 ms)
#   ✔ Your runtime beats 43.18 % of kotlin submissions
#   ✔ Your memory usage beats 13.64 % of kotlin submissions (59.6 MB)
# Submitting: kotlin_solutions/517.super-washing-machines.kt
# - Downloading super-washing-machines
#   ✔ Accepted
#   ✔ 120/120 cases passed (13 ms)
#   ✔ Your runtime beats 87.5 % of kotlin submissions
#   ✔ Your memory usage beats 87.5 % of kotlin submissions (48.4 MB)
# Submitting: kotlin_solutions/518.coin-change-ii.kt
# - Downloading coin-change-ii
#   ✔ Accepted
#   ✔ 31/31 cases passed (13 ms)
#   ✔ Your runtime beats 60 % of kotlin submissions
#   ✔ Your memory usage beats 56.84 % of kotlin submissions (42.1 MB)
# Submitting: kotlin_solutions/519.random-flip-matrix.kt
# - Downloading random-flip-matrix
#   ✔ Accepted
#   ✔ 20/20 cases passed (61 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (52 MB)
# Submitting: kotlin_solutions/520.detect-capital.kt
# - Downloading detect-capital
#   ✔ Accepted
#   ✔ 553/553 cases passed (9 ms)
#   ✔ Your runtime beats 24.62 % of kotlin submissions
#   ✔ Your memory usage beats 6.15 % of kotlin submissions (43.5 MB)
# Submitting: kotlin_solutions/521.longest-uncommon-subsequence-i.kt
# - Downloading longest-uncommon-subsequence-i
#   ✔ Accepted
#   ✔ 41/41 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 5.26 % of kotlin submissions (41 MB)
# Submitting: kotlin_solutions/522.longest-uncommon-subsequence-ii.kt
# - Downloading longest-uncommon-subsequence-ii
#   ✔ Accepted
#   ✔ 101/101 cases passed (28 ms)
#   ✔ Your runtime beats 30.77 % of kotlin submissions
#   ✔ Your memory usage beats 7.69 % of kotlin submissions (46 MB)
# Submitting: kotlin_solutions/523.continuous-subarray-sum.kt
# - Downloading continuous-subarray-sum
#   ✔ Accepted
#   ✔ 102/102 cases passed (48 ms)
#   ✔ Your runtime beats 15.38 % of kotlin submissions
#   ✔ Your memory usage beats 94.87 % of kotlin submissions (61.2 MB)
# Submitting: kotlin_solutions/524.longest-word-in-dictionary-through-deleting.kt
# - Downloading longest-word-in-dictionary-through-deleting
#   ✔ Accepted
#   ✔ 31/31 cases passed (171 ms)
#   ✔ Your runtime beats 35.71 % of kotlin submissions
#   ✔ Your memory usage beats 7.14 % of kotlin submissions (55.4 MB)
# Submitting: kotlin_solutions/525.contiguous-array.kt
# - Downloading contiguous-array
#   ✔ Accepted
#   ✔ 566/566 cases passed (75 ms)
#   ✔ Your runtime beats 5.13 % of kotlin submissions
#   ✔ Your memory usage beats 7.69 % of kotlin submissions (61 MB)
# Submitting: kotlin_solutions/526.beautiful-arrangement.kt
# - Downloading beautiful-arrangement
#   ✔ Accepted
#   ✔ 15/15 cases passed (20 ms)
#   ✔ Your runtime beats 88.46 % of kotlin submissions
#   ✔ Your memory usage beats 34.62 % of kotlin submissions (42.2 MB)
# Submitting: kotlin_solutions/528.random-pick-with-weight.kt
# - Downloading random-pick-with-weight
#   ✔ Accepted
#   ✔ 57/57 cases passed (78 ms)
#   ✔ Your runtime beats 27.27 % of kotlin submissions
#   ✔ Your memory usage beats 30 % of kotlin submissions (65.3 MB)
# Submitting: kotlin_solutions/529.minesweeper.kt
# - Downloading minesweeper
#   ✔ Accepted
#   ✔ 54/54 cases passed (36 ms)
#   ✔ Your runtime beats 14.81 % of kotlin submissions
#   ✔ Your memory usage beats 7.41 % of kotlin submissions (55.3 MB)
# Submitting: kotlin_solutions/530.minimum-absolute-difference-in-bst.kt
# - Downloading minimum-absolute-difference-in-bst
#   ✔ Accepted
#   ✔ 190/190 cases passed (41 ms)
#   ✔ Your runtime beats 8.54 % of kotlin submissions
#   ✔ Your memory usage beats 8.54 % of kotlin submissions (50.8 MB)
# Submitting: kotlin_solutions/532.k-diff-pairs-in-an-array.kt
# - Downloading k-diff-pairs-in-an-array
#   ✔ Accepted
#   ✔ 60/60 cases passed (79 ms)
#   ✔ Your runtime beats 13.79 % of kotlin submissions
#   ✔ Your memory usage beats 37.93 % of kotlin submissions (49.6 MB)
# Submitting: kotlin_solutions/535.encode-and-decode-tiny-url.kt
# - Downloading encode-and-decode-tinyurl
#   ✔ Accepted
#   ✔ 739/739 cases passed (124 ms)
#   ✔ Your runtime beats 88.64 % of kotlin submissions
#   ✔ Your memory usage beats 70.45 % of kotlin submissions (42.8 MB)
# Submitting: kotlin_solutions/537.complex-number-multiplication.kt
# - Downloading complex-number-multiplication
#   ✔ Accepted
#   ✔ 56/56 cases passed (29 ms)
#   ✔ Your runtime beats 66.67 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (46.9 MB)
# Submitting: kotlin_solutions/538.convert-bst-to-greater-tree.kt
# - Downloading convert-bst-to-greater-tree
#   ✔ Accepted
#   ✔ 215/215 cases passed (19 ms)
#   ✔ Your runtime beats 43.75 % of kotlin submissions
#   ✔ Your memory usage beats 56.25 % of kotlin submissions (46.7 MB)
# Submitting: kotlin_solutions/539.minimum-time-difference.kt
# - Downloading minimum-time-difference
#   ✔ Accepted
#   ✔ 116/116 cases passed (53 ms)
#   ✔ Your runtime beats 27.78 % of kotlin submissions
#   ✔ Your memory usage beats 38.89 % of kotlin submissions (51.2 MB)
# Submitting: kotlin_solutions/540.single-element-in-a-sorted-array.kt
# - Downloading single-element-in-a-sorted-array
#   ✔ Accepted
#   ✔ 16/16 cases passed (16 ms)
#   ✔ Your runtime beats 6.85 % of kotlin submissions
#   ✔ Your memory usage beats 21.92 % of kotlin submissions (56.4 MB)
# Submitting: kotlin_solutions/541.reverse-string-ii.kt
# - Downloading reverse-string-ii
#   ✔ Accepted
#   ✔ 60/60 cases passed (15 ms)
#   ✔ Your runtime beats 32.2 % of kotlin submissions
#   ✔ Your memory usage beats 54.24 % of kotlin submissions (45.3 MB)
# Submitting: kotlin_solutions/542.01-matrix.kt
# - Downloading 01-matrix
#   ✔ Accepted
#   ✔ 50/50 cases passed (125 ms)
#   ✔ Your runtime beats 19.59 % of kotlin submissions
#   ✔ Your memory usage beats 10.13 % of kotlin submissions (72.7 MB)
# Submitting: kotlin_solutions/543.diameter-of-binary-tree.kt
# - Downloading diameter-of-binary-tree
#   ✔ Accepted
#   ✔ 106/106 cases passed (19 ms)
#   ✔ Your runtime beats 8.63 % of kotlin submissions
#   ✔ Your memory usage beats 23.21 % of kotlin submissions (47.4 MB)
# Submitting: kotlin_solutions/546.remove-boxes.kt
# - Downloading remove-boxes
#   ✔ Accepted
#   ✔ 63/63 cases passed (669 ms)
#   ✔ Your runtime beats 10 % of kotlin submissions
#   ✔ Your memory usage beats 20 % of kotlin submissions (73.8 MB)
# Submitting: kotlin_solutions/547.number-of-provinces.kt
# - Downloading number-of-provinces
#   ✔ Accepted
#   ✔ 114/114 cases passed (45 ms)
#   ✔ Your runtime beats 5.2 % of kotlin submissions
#   ✔ Your memory usage beats 6.36 % of kotlin submissions (60.8 MB)
# Submitting: kotlin_solutions/551.student-attendance-record-i.kt
# - Downloading student-attendance-record-i
#   ✔ Accepted
#   ✔ 115/115 cases passed (7 ms)
#   ✔ Your runtime beats 41.38 % of kotlin submissions
#   ✔ Your memory usage beats 31.03 % of kotlin submissions (42 MB)
# Submitting: kotlin_solutions/552.student-attendance-record-ii.kt
# - Downloading student-attendance-record-ii
#   ✔ Accepted
#   ✔ 59/59 cases passed (49 ms)
#   ✔ Your runtime beats 42.86 % of kotlin submissions
#   ✔ Your memory usage beats 57.14 % of kotlin submissions (58.6 MB)
# Submitting: kotlin_solutions/553.optimal-division.kt
# - Downloading optimal-division
#   ✔ Accepted
#   ✔ 93/93 cases passed (25 ms)
#   ✔ Your runtime beats 42.86 % of kotlin submissions
#   ✔ Your memory usage beats 35.71 % of kotlin submissions (46.4 MB)
# Submitting: kotlin_solutions/554.brick-wall.kt
# - Downloading brick-wall
#   ✔ Accepted
#   ✔ 88/88 cases passed (60 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 70.83 % of kotlin submissions (55.3 MB)
# Submitting: kotlin_solutions/556.next-greater-element-iii.kt
# - Downloading next-greater-element-iii
#   ✔ Accepted
#   ✔ 39/39 cases passed (20 ms)
#   ✔ Your runtime beats 61.54 % of kotlin submissions
#   ✔ Your memory usage beats 38.46 % of kotlin submissions (45.7 MB)
# Submitting: kotlin_solutions/557.reverse-words-in-a-string-iii.kt
# - Downloading reverse-words-in-a-string-iii
#   ✔ Accepted
#   ✔ 29/29 cases passed (20 ms)
#   ✔ Your runtime beats 45.79 % of kotlin submissions
#   ✔ Your memory usage beats 57.94 % of kotlin submissions (46.4 MB)
# Submitting: kotlin_solutions/558.logical-or-of-two-binary-grids-represented-as-quad-trees.kt
# - Downloading logical-or-of-two-binary-grids-represented-as-quad-trees
#   ✔ Accepted
#   ✔ 61/61 cases passed (202 ms)
#   ✔ Your runtime beats 45.45 % of kotlin submissions
#   ✔ Your memory usage beats 9.09 % of kotlin submissions (55.5 MB)
# Submitting: kotlin_solutions/559.maximum-depth-of-n-ary-tree.kt
# - Downloading maximum-depth-of-n-ary-tree
#   ✔ Accepted
#   ✔ 38/38 cases passed (136 ms)
#   ✔ Your runtime beats 76.74 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (45.2 MB)
# Submitting: kotlin_solutions/560.subarray-sum-equals-k.kt
# - Downloading subarray-sum-equals-k
#   ✔ Accepted
#   ✔ 93/93 cases passed (54 ms)
#   ✔ Your runtime beats 22.92 % of kotlin submissions
#   ✔ Your memory usage beats 14.58 % of kotlin submissions (54.6 MB)
# Submitting: kotlin_solutions/561.array-partition.kt
# - Downloading array-partition
#   ✔ Accepted
#   ✔ 85/85 cases passed (73 ms)
#   ✔ Your runtime beats 7.41 % of kotlin submissions
#   ✔ Your memory usage beats 62.96 % of kotlin submissions (52.5 MB)
# Submitting: kotlin_solutions/563.binary-tree-tilt.kt
# - Downloading binary-tree-tilt
#   ✔ Accepted
#   ✔ 77/77 cases passed (24 ms)
#   ✔ Your runtime beats 21.74 % of kotlin submissions
#   ✔ Your memory usage beats 17.39 % of kotlin submissions (49.5 MB)
# Submitting: kotlin_solutions/564.find-the-closest-palindrome.kt
# - Downloading find-the-closest-palindrome
#   ✔ Accepted
#   ✔ 232/232 cases passed (30 ms)
#   ✔ Your runtime beats 40 % of kotlin submissions
#   ✔ Your memory usage beats 20 % of kotlin submissions (47.7 MB)
# Submitting: kotlin_solutions/565.array-nesting.kt
# - Downloading array-nesting
#   ✔ Accepted
#   ✔ 885/885 cases passed (81 ms)
#   ✔ Your runtime beats 28.57 % of kotlin submissions
#   ✔ Your memory usage beats 28.57 % of kotlin submissions (76.7 MB)
# Submitting: kotlin_solutions/566.reshape-the-matrix.kt
# - Downloading reshape-the-matrix
#   ✔ Accepted
#   ✔ 57/57 cases passed (22 ms)
#   ✔ Your runtime beats 14.29 % of kotlin submissions
#   ✔ Your memory usage beats 7.14 % of kotlin submissions (56.2 MB)
# Submitting: kotlin_solutions/567.permutation-in-string.kt
# - Downloading permutation-in-string
#   ✔ Accepted
#   ✔ 110/110 cases passed (89 ms)
#   ✔ Your runtime beats 14.62 % of kotlin submissions
#   ✔ Your memory usage beats 31.62 % of kotlin submissions (47.2 MB)
# Submitting: kotlin_solutions/572.subtree-of-another-tree.kt
# - Downloading subtree-of-another-tree
#   ✔ Accepted
#   ✔ 185/185 cases passed (3 ms)
#   ✔ Your runtime beats 94.83 % of kotlin submissions
#   ✔ Your memory usage beats 25.86 % of kotlin submissions (50.1 MB)
# Submitting: kotlin_solutions/575.distribute-candies.kt
# - Downloading distribute-candies
#   ✔ Accepted
#   ✔ 206/206 cases passed (42 ms)
#   ✔ Your runtime beats 46.51 % of kotlin submissions
#   ✔ Your memory usage beats 32.56 % of kotlin submissions (59.1 MB)
# Submitting: kotlin_solutions/576.out-of-boundary-paths.kt
# - Downloading out-of-boundary-paths
#   ✔ Accepted
#   ✔ 94/94 cases passed (30 ms)
#   ✔ Your runtime beats 21.43 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (54.3 MB)
# Submitting: kotlin_solutions/581.shortest-unsorted-continuous-subarray.kt
# - Downloading shortest-unsorted-continuous-subarray
#   ✔ Accepted
#   ✔ 307/307 cases passed (47 ms)
#   ✔ Your runtime beats 6.06 % of kotlin submissions
#   ✔ Your memory usage beats 12.12 % of kotlin submissions (52.5 MB)

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-03-18 15:32:36
