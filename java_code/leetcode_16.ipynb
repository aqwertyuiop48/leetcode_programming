# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME_4')
    user_cookie = userdata.get('LEETCODE_TOKEN_4')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME_4'] = user_name
    os.environ['LEETCODE_TOKEN_4'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME_4" "$LEETCODE_TOKEN_4" | leetcode user -c

# %%
# %%bash
#
#
# # top 100 answers
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v java_solutions/*.java | sed -n '2201,2350p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 8
# done
# Out:
# Submitting: java_solutions/3326.minimum-division-operations-to-make-array-non-decreasing.java
# - Downloading minimum-division-operations-to-make-array-non-decreasing
#   ✔ Accepted
#   ✔ 720/720 cases passed (16 ms)
#   ✔ Your runtime beats 97.92 % of java submissions
#   ✔ Your memory usage beats 8.33 % of java submissions (108.1 MB)
# Submitting: java_solutions/3327.check-if-dfs-strings-are-palindromes.java
# - Downloading check-if-dfs-strings-are-palindromes
#   ✔ Accepted
#   ✔ 584/584 cases passed (693 ms)
#   ✔ Your runtime beats 5 % of java submissions
#   ✔ Your memory usage beats 5 % of java submissions (394.3 MB)
# Submitting: java_solutions/3330.find-the-original-typed-string-i.java
# - Downloading find-the-original-typed-string-i
#   ✔ Accepted
#   ✔ 780/780 cases passed (3 ms)
#   ✔ Your runtime beats 2.1 % of java submissions
#   ✔ Your memory usage beats 12.61 % of java submissions (43.9 MB)
# Submitting: java_solutions/3331.find-subtree-sizes-after-changes.java
# - Downloading find-subtree-sizes-after-changes
#   ✔ Accepted
#   ✔ 632/632 cases passed (434 ms)
#   ✔ Your runtime beats 5.55 % of java submissions
#   ✔ Your memory usage beats 29.17 % of java submissions (286.1 MB)
# Submitting: java_solutions/3332.maximum-points-tourist-can-earn.java
# - Downloading maximum-points-tourist-can-earn
#   ✔ Accepted
#   ✔ 545/545 cases passed (155 ms)
#   ✔ Your runtime beats 53.23 % of java submissions
#   ✔ Your memory usage beats 8.06 % of java submissions (64.3 MB)
# Submitting: java_solutions/3333.find-the-original-typed-string-ii.java
# - Downloading find-the-original-typed-string-ii
#   ✔ Accepted
#   ✔ 846/846 cases passed (461 ms)
#   ✔ Your runtime beats 5.13 % of java submissions
#   ✔ Your memory usage beats 30.77 % of java submissions (69.8 MB)
# Submitting: java_solutions/3334.find-the-maximum-factor-score-of-array.java
# - Downloading find-the-maximum-factor-score-of-array
#   ✔ Accepted
#   ✔ 752/752 cases passed (6 ms)
#   ✔ Your runtime beats 76.56 % of java submissions
#   ✔ Your memory usage beats 10.94 % of java submissions (46.6 MB)
# Submitting: java_solutions/3335.total-characters-in-string-after-transformations-i.java
# - Downloading total-characters-in-string-after-transformations-i
#   ✔ Accepted
#   ✔ 824/824 cases passed (137 ms)
#   ✔ Your runtime beats 62.22 % of java submissions
#   ✔ Your memory usage beats 33.33 % of java submissions (47.9 MB)
# Submitting: java_solutions/3336.find-the-number-of-subsequences-with-equal-gcd.java
# - Downloading find-the-number-of-subsequences-with-equal-gcd
#   ✔ Accepted
#   ✔ 622/622 cases passed (909 ms)
#   ✔ Your runtime beats 31.03 % of java submissions
#   ✔ Your memory usage beats 62.07 % of java submissions (58.3 MB)
# Submitting: java_solutions/3337.total-characters-in-string-after-transformations-ii.java
# - Downloading total-characters-in-string-after-transformations-ii
#   ✔ Accepted
#   ✔ 536/536 cases passed (1662 ms)
#   ✔ Your runtime beats 5 % of java submissions
#   ✔ Your memory usage beats 7.5 % of java submissions (53.6 MB)
# Submitting: java_solutions/3340.check-balanced-string.java
# - Downloading check-balanced-string
#   ✔ Accepted
#   ✔ 868/868 cases passed (3 ms)
#   ✔ Your runtime beats 3.36 % of java submissions
#   ✔ Your memory usage beats 7.27 % of java submissions (44.2 MB)
# Submitting: java_solutions/3341.find-minimum-time-to-reach-last-room-i.java
# - Downloading find-minimum-time-to-reach-last-room-i
#   ✔ Accepted
#   ✔ 744/744 cases passed (14 ms)
#   ✔ Your runtime beats 19.15 % of java submissions
#   ✔ Your memory usage beats 5.53 % of java submissions (47.4 MB)
# Submitting: java_solutions/3342.find-minimum-time-to-reach-last-room-ii.java
# - Downloading find-minimum-time-to-reach-last-room-ii
#   ✔ Accepted
#   ✔ 717/717 cases passed (218 ms)
#   ✔ Your runtime beats 51.35 % of java submissions
#   ✔ Your memory usage beats 70.81 % of java submissions (169.3 MB)
# Submitting: java_solutions/3343.count-number-of-balanced-permutations.java
# - Downloading count-number-of-balanced-permutations
#   ✔ Accepted
#   ✔ 792/792 cases passed (1052 ms)
#   ✔ Your runtime beats 11.11 % of java submissions
#   ✔ Your memory usage beats 25.93 % of java submissions (53.8 MB)
# Submitting: java_solutions/3345.smallest-divisible-digit-product-i.java
# - Downloading smallest-divisible-digit-product-i
#   ✔ Accepted
#   ✔ 1000/1000 cases passed (6 ms)
#   ✔ Your runtime beats 0.69 % of java submissions
#   ✔ Your memory usage beats 13.79 % of java submissions (43.2 MB)
# Submitting: java_solutions/3346.maximum-frequency-of-an-element-after-performing-operations-i.java
# - Downloading maximum-frequency-of-an-element-after-performing-operations-i
#   ✔ Accepted
#   ✔ 637/637 cases passed (486 ms)
#   ✔ Your runtime beats 14.81 % of java submissions
#   ✔ Your memory usage beats 5.41 % of java submissions (272 MB)
# Submitting: java_solutions/3347.maximum-frequency-of-an-element-after-performing-operations-ii.java
# - Downloading maximum-frequency-of-an-element-after-performing-operations-ii
#   ✔ Accepted
#   ✔ 634/634 cases passed (950 ms)
#   ✔ Your runtime beats 31.75 % of java submissions
#   ✔ Your memory usage beats 53.56 % of java submissions (187.9 MB)
# Submitting: java_solutions/3348.smallest-divisible-digit-product-ii.java
# - Downloading smallest-divisible-digit-product-ii
#   ✔ Accepted
#   ✔ 954/954 cases passed (141 ms)
#   ✔ Your runtime beats 21.74 % of java submissions
#   ✔ Your memory usage beats 13.04 % of java submissions (56.5 MB)
# Submitting: java_solutions/3349.adjacent-increasing-subarrays-detection-i.java
# - Downloading adjacent-increasing-subarrays-detection-i
#   ✔ Accepted
#   ✔ 1422/1422 cases passed (6 ms)
#   ✔ Your runtime beats 3.14 % of java submissions
#   ✔ Your memory usage beats 5.61 % of java submissions (47.7 MB)
# Submitting: java_solutions/3350.adjacent-increasing-subarrays-detection-ii.java
# - Downloading adjacent-increasing-subarrays-detection-ii
#   ✔ Accepted
#   ✔ 1111/1111 cases passed (29 ms)
#   ✔ Your runtime beats 6.91 % of java submissions
#   ✔ Your memory usage beats 8.88 % of java submissions (166.9 MB)
# Submitting: java_solutions/3351.sum-of-good-subsequences.java
# - Downloading sum-of-good-subsequences
#   ✔ Accepted
#   ✔ 679/679 cases passed (277 ms)
#   ✔ Your runtime beats 6.52 % of java submissions
#   ✔ Your memory usage beats 6.52 % of java submissions (177.9 MB)
# Submitting: java_solutions/3352.count-k-reducible-numbers-less-than-n.java
# - Downloading count-k-reducible-numbers-less-than-n
#   ✔ Accepted
#   ✔ 774/774 cases passed (275 ms)
#   ✔ Your runtime beats 20 % of java submissions
#   ✔ Your memory usage beats 56 % of java submissions (53.3 MB)
# Submitting: java_solutions/3354.make-array-elements-equal-to-zero.java
# - Downloading make-array-elements-equal-to-zero
#   ✔ Accepted
#   ✔ 584/584 cases passed (4 ms)
#   ✔ Your runtime beats 47.21 % of java submissions
#   ✔ Your memory usage beats 93.51 % of java submissions (43.5 MB)
# Submitting: java_solutions/3355.zero-array-transformation-i.java
# - Downloading zero-array-transformation-i
#   ✔ Accepted
#   ✔ 668/668 cases passed (23 ms)
#   ✔ Your runtime beats 4 % of java submissions
#   ✔ Your memory usage beats 6.35 % of java submissions (233.1 MB)
# Submitting: java_solutions/3356.zero-array-transformation-ii.java
# - Downloading zero-array-transformation-ii
#   ✔ Accepted
#   ✔ 627/627 cases passed (62 ms)
#   ✔ Your runtime beats 5.22 % of java submissions
#   ✔ Your memory usage beats 40.96 % of java submissions (240.3 MB)
# Submitting: java_solutions/3357.minimize-the-maximum-adjacent-element-difference.java
# - Downloading minimize-the-maximum-adjacent-element-difference
#   ✔ Accepted
#   ✔ 958/958 cases passed (93 ms)
#   ✔ Your runtime beats 9.52 % of java submissions
#   ✔ Your memory usage beats 9.52 % of java submissions (97.1 MB)
# Submitting: java_solutions/3360.stone-removal-game.java
# - Downloading stone-removal-game
#   ✔ Accepted
#   ✔ 53/53 cases passed (2 ms)
#   ✔ Your runtime beats 1.72 % of java submissions
#   ✔ Your memory usage beats 16.38 % of java submissions (42.4 MB)
# Submitting: java_solutions/3361.shift-distance-between-two-strings.java
# - Downloading shift-distance-between-two-strings
#   ✔ Accepted
#   ✔ 741/741 cases passed (120 ms)
#   ✔ Your runtime beats 5.26 % of java submissions
#   ✔ Your memory usage beats 26.32 % of java submissions (48 MB)
# Submitting: java_solutions/3362.zero-array-transformation-iii.java
# - Downloading zero-array-transformation-iii
#   ✔ Accepted
#   ✔ 824/824 cases passed (111 ms)
#   ✔ Your runtime beats 6.41 % of java submissions
#   ✔ Your memory usage beats 93.59 % of java submissions (185.9 MB)
# Submitting: java_solutions/3363.find-the-maximum-number-of-fruits-collected.java
# - Downloading find-the-maximum-number-of-fruits-collected
#   ✔ Accepted
#   ✔ 549/549 cases passed (456 ms)
#   ✔ Your runtime beats 6.09 % of java submissions
#   ✔ Your memory usage beats 5.22 % of java submissions (290.1 MB)
# Submitting: java_solutions/3364.minimum-positive-sum-subarray.java
# - Downloading minimum-positive-sum-subarray
#   ✔ Accepted
#   ✔ 889/889 cases passed (6 ms)
#   ✔ Your runtime beats 28.94 % of java submissions
#   ✔ Your memory usage beats 9.88 % of java submissions (46.7 MB)
# Submitting: java_solutions/3365.rearrange-k-substrings-to-form-target-string.java
# - Downloading rearrange-k-substrings-to-form-target-string
#   ✔ Accepted
#   ✔ 771/771 cases passed (85 ms)
#   ✔ Your runtime beats 42.03 % of java submissions
#   ✔ Your memory usage beats 81.16 % of java submissions (53.6 MB)
# Submitting: java_solutions/3366.minimum-array-sum.java
# - Downloading minimum-array-sum
#   ✔ Accepted
#   ✔ 772/772 cases passed (70 ms)
#   ✔ Your runtime beats 14.63 % of java submissions
#   ✔ Your memory usage beats 54.47 % of java submissions (50.3 MB)
# Submitting: java_solutions/3367.maximize-sum-of-weights-after-edge-removals.java
# - Downloading maximize-sum-of-weights-after-edge-removals
#   ✔ Accepted
#   ✔ 714/714 cases passed (1211 ms)
#   ✔ Your runtime beats 10 % of java submissions
#   ✔ Your memory usage beats 6.67 % of java submissions (413.5 MB)
# Submitting: java_solutions/3370.smallest-number-with-all-set-bits.java
# - Downloading smallest-number-with-all-set-bits
#   ✔ Accepted
#   ✔ 608/608 cases passed (4 ms)
#   ✔ Your runtime beats 5.58 % of java submissions
#   ✔ Your memory usage beats 16.65 % of java submissions (42.7 MB)
# Submitting: java_solutions/3371.identify-the-largest-outlier-in-an-array.java
# - Downloading identify-the-largest-outlier-in-an-array
#   ✔ Accepted
#   ✔ 873/873 cases passed (30 ms)
#   ✔ Your runtime beats 96.43 % of java submissions
#   ✔ Your memory usage beats 83.57 % of java submissions (109.5 MB)
# Submitting: java_solutions/3372.maximize-the-number-of-target-nodes-after-connecting-trees-i.java
# - Downloading maximize-the-number-of-target-nodes-after-connecting-trees-i
#   ✔ Accepted
#   ✔ 817/817 cases passed (336 ms)
#   ✔ Your runtime beats 62.86 % of java submissions
#   ✔ Your memory usage beats 12.86 % of java submissions (49.9 MB)
# Submitting: java_solutions/3373.maximize-the-number-of-target-nodes-after-connecting-trees-ii.java
# - Downloading maximize-the-number-of-target-nodes-after-connecting-trees-ii
#   ✔ Accepted
#   ✔ 825/825 cases passed (300 ms)
#   ✔ Your runtime beats 6.35 % of java submissions
#   ✔ Your memory usage beats 31.75 % of java submissions (287.6 MB)
# Submitting: java_solutions/3375.minimum-operations-to-make-array-values-equal-to-k.java
# - Downloading minimum-operations-to-make-array-values-equal-to-k
#   ✔ Accepted
#   ✔ 969/969 cases passed (5 ms)
#   ✔ Your runtime beats 26.9 % of java submissions
#   ✔ Your memory usage beats 73.1 % of java submissions (46.3 MB)
# Submitting: java_solutions/3376.minimum-time-to-break-locks-i.java
# - Downloading minimum-time-to-break-locks-i
#   ✔ Accepted
#   ✔ 763/763 cases passed (10 ms)
#   ✔ Your runtime beats 80.39 % of java submissions
#   ✔ Your memory usage beats 37.25 % of java submissions (44.5 MB)
# Submitting: java_solutions/3377.digit-operations-to-make-two-integers-equal.java
# - Downloading digit-operations-to-make-two-integers-equal
#   ✔ Accepted
#   ✔ 573/573 cases passed (87 ms)
#   ✔ Your runtime beats 87.62 % of java submissions
#   ✔ Your memory usage beats 26.67 % of java submissions (47.9 MB)
# Submitting: java_solutions/3378.count-connected-components-in-lcm-graph.java
# - Downloading count-connected-components-in-lcm-graph
#   ✔ Accepted
#   ✔ 697/697 cases passed (990 ms)
#   ✔ Your runtime beats 10.71 % of java submissions
#   ✔ Your memory usage beats 28.57 % of java submissions (100.3 MB)
# Submitting: java_solutions/3379.transformed-array.java
# - Downloading transformed-array
#   ✔ Accepted
#   ✔ 696/696 cases passed (4 ms)
#   ✔ Your runtime beats 0.58 % of java submissions
#   ✔ Your memory usage beats 53.23 % of java submissions (46.6 MB)
# Submitting: java_solutions/3380.maximum-area-rectangle-with-point-constraints-i.java
# - Downloading maximum-area-rectangle-with-point-constraints-i
#   ✔ Accepted
#   ✔ 1002/1002 cases passed (7 ms)
#   ✔ Your runtime beats 76.19 % of java submissions
#   ✔ Your memory usage beats 13.1 % of java submissions (47.2 MB)
# Submitting: java_solutions/3381.maximum-subarray-sum-with-length-divisible-by-k.java
# - Downloading maximum-subarray-sum-with-length-divisible-by-k
#   ✔ Accepted
#   ✔ 660/660 cases passed (9 ms)
#   ✔ Your runtime beats 14.64 % of java submissions
#   ✔ Your memory usage beats 84.53 % of java submissions (150.1 MB)
# Submitting: java_solutions/3382.maximum-area-rectangle-with-point-constraints-ii.java
# - Downloading maximum-area-rectangle-with-point-constraints-ii
#   ✔ Accepted
#   ✔ 594/594 cases passed (1509 ms)
#   ✔ Your runtime beats 18.92 % of java submissions
#   ✔ Your memory usage beats 27.03 % of java submissions (284.3 MB)
# Submitting: java_solutions/3386.button-with-longest-push-time.java
# - Downloading button-with-longest-push-time
#   ✔ Accepted
#   ✔ 588/588 cases passed (4 ms)
#   ✔ Your runtime beats 4.9 % of java submissions
#   ✔ Your memory usage beats 5.39 % of java submissions (47.1 MB)
# Submitting: java_solutions/3387.maximize-amount-after-two-days-of-conversions.java
# - Downloading maximize-amount-after-two-days-of-conversions
#   ✔ Accepted
#   ✔ 767/767 cases passed (10 ms)
#   ✔ Your runtime beats 59.02 % of java submissions
#   ✔ Your memory usage beats 14.75 % of java submissions (50.3 MB)
# Submitting: java_solutions/3388.count-beautiful-splits-in-an-array.java
# - Downloading count-beautiful-splits-in-an-array
#   ✔ Accepted
#   ✔ 583/583 cases passed (159 ms)
#   ✔ Your runtime beats 56.82 % of java submissions
#   ✔ Your memory usage beats 38.64 % of java submissions (274.7 MB)
# Submitting: java_solutions/3389.minimum-operations-to-make-character-frequencies-equal.java
# - Downloading minimum-operations-to-make-character-frequencies-equal
#   ✔ Accepted
#   ✔ 773/773 cases passed (91 ms)
#   ✔ Your runtime beats 13.79 % of java submissions
#   ✔ Your memory usage beats 13.79 % of java submissions (47.2 MB)
# Submitting: java_solutions/3392.count-subarrays-of-length-three-with-a-condition.java
# - Downloading count-subarrays-of-length-three-with-a-condition
#   ✔ Accepted
#   ✔ 1691/1691 cases passed (5 ms)
#   ✔ Your runtime beats 1.89 % of java submissions
#   ✔ Your memory usage beats 39.15 % of java submissions (47 MB)
# Submitting: java_solutions/3393.count-paths-with-the-given-xor-value.java
# - Downloading count-paths-with-the-given-xor-value
#   ✔ Accepted
#   ✔ 585/585 cases passed (61 ms)
#   ✔ Your runtime beats 75.61 % of java submissions
#   ✔ Your memory usage beats 89.02 % of java submissions (69.8 MB)
# Submitting: java_solutions/3394.check-if-grid-can-be-cut-into-sections.java
# - Downloading check-if-grid-can-be-cut-into-sections
#   ✔ Accepted
#   ✔ 698/698 cases passed (133 ms)
#   ✔ Your runtime beats 17.02 % of java submissions
#   ✔ Your memory usage beats 41.49 % of java submissions (228.7 MB)
# Submitting: java_solutions/3395.subsequences-with-a-unique-middle-mode-i.java
# - Downloading subsequences-with-a-unique-middle-mode-i
#   ✔ Accepted
#   ✔ 947/947 cases passed (2686 ms)
#   ✔ Your runtime beats 6.45 % of java submissions
#   ✔ Your memory usage beats 6.45 % of java submissions (53.6 MB)
# Submitting: java_solutions/3396.minimum-number-of-operations-to-make-elements-in-array-distinct.java
# - Downloading minimum-number-of-operations-to-make-elements-in-array-distinct
#   ✔ Accepted
#   ✔ 781/781 cases passed (5 ms)
#   ✔ Your runtime beats 22.58 % of java submissions
#   ✔ Your memory usage beats 45.62 % of java submissions (46.3 MB)
# Submitting: java_solutions/3397.maximum-number-of-distinct-elements-after-operations.java
# - Downloading maximum-number-of-distinct-elements-after-operations
#   ✔ Accepted
#   ✔ 633/633 cases passed (30 ms)
#   ✔ Your runtime beats 10.12 % of java submissions
#   ✔ Your memory usage beats 10.69 % of java submissions (94.1 MB)
# Submitting: java_solutions/3398.smallest-substring-with-identical-characters-i.java
# - Downloading smallest-substring-with-identical-characters-i
#   ✔ Accepted
#   ✔ 949/949 cases passed (175 ms)
#   ✔ Your runtime beats 3.85 % of java submissions
#   ✔ Your memory usage beats 7.69 % of java submissions (48.1 MB)
# Submitting: java_solutions/3399.smallest-substring-with-identical-characters-ii.java
# - Downloading smallest-substring-with-identical-characters-ii
#   ✔ Accepted
#   ✔ 970/970 cases passed (133 ms)
#   ✔ Your runtime beats 18.75 % of java submissions
#   ✔ Your memory usage beats 18.75 % of java submissions (53.1 MB)
# Submitting: java_solutions/3402.minimum-operations-to-make-columns-strictly-increasing.java
# - Downloading minimum-operations-to-make-columns-strictly-increasing
#   ✔ Accepted
#   ✔ 722/722 cases passed (5 ms)
#   ✔ Your runtime beats 0.8 % of java submissions
#   ✔ Your memory usage beats 96.78 % of java submissions (46.5 MB)
# Submitting: java_solutions/3403.find-the-lexicographically-largest-string-from-the-box-i.java
# - Downloading find-the-lexicographically-largest-string-from-the-box-i
#   ✔ Accepted
#   ✔ 787/787 cases passed (22 ms)
#   ✔ Your runtime beats 20.33 % of java submissions
#   ✔ Your memory usage beats 5.69 % of java submissions (47.5 MB)
# Submitting: java_solutions/3404.count-special-subsequences.java
# - Downloading count-special-subsequences
#   ✔ Accepted
#   ✔ 557/557 cases passed (640 ms)
#   ✔ Your runtime beats 27.27 % of java submissions
#   ✔ Your memory usage beats 24.24 % of java submissions (85.8 MB)
# Submitting: java_solutions/3405.count-the-number-of-arrays-with-k-matching-adjacent-elements.java
# - Downloading count-the-number-of-arrays-with-k-matching-adjacent-elements
#   ✔ Accepted
#   ✔ 809/809 cases passed (101 ms)
#   ✔ Your runtime beats 27.78 % of java submissions
#   ✔ Your memory usage beats 38.89 % of java submissions (44.5 MB)
# Submitting: java_solutions/3407.substring-matching-pattern.java
# - Downloading substring-matching-pattern
#   ✔ Accepted
#   ✔ 969/969 cases passed (6 ms)
#   ✔ Your runtime beats 6.85 % of java submissions
#   ✔ Your memory usage beats 12.5 % of java submissions (44.7 MB)
# Submitting: java_solutions/3408.design-task-manager.java
# - Downloading design-task-manager
#   ✔ Accepted
#   ✔ 667/667 cases passed (485 ms)
#   ✔ Your runtime beats 14.54 % of java submissions
#   ✔ Your memory usage beats 63.88 % of java submissions (270 MB)
# Submitting: java_solutions/3409.longest-subsequence-with-decreasing-adjacent-difference.java
# - Downloading longest-subsequence-with-decreasing-adjacent-difference
#   ✔ Accepted
#   ✔ 586/586 cases passed (2391 ms)
#   ✔ Your runtime beats 5 % of java submissions
#   ✔ Your memory usage beats 27.5 % of java submissions (85.1 MB)
# Submitting: java_solutions/3410.maximize-subarray-sum-after-removing-all-occurrences-of-one-element.java
# - Downloading maximize-subarray-sum-after-removing-all-occurrences-of-one-element
#   ✔ Accepted
#   ✔ 660/660 cases passed (1870 ms)
#   ✔ Your runtime beats 8.7 % of java submissions
#   ✔ Your memory usage beats 8.7 % of java submissions (289.2 MB)
# Submitting: java_solutions/3411.maximum-subarray-with-equal-products.java
# - Downloading maximum-subarray-with-equal-products
#   ✔ Accepted
#   ✔ 865/865 cases passed (11 ms)
#   ✔ Your runtime beats 9.52 % of java submissions
#   ✔ Your memory usage beats 8.06 % of java submissions (46 MB)
# Submitting: java_solutions/3412.find-mirror-score-of-a-string.java
# - Downloading find-mirror-score-of-a-string
#   ✔ Accepted
#   ✔ 581/581 cases passed (300 ms)
#   ✔ Your runtime beats 5.6 % of java submissions
#   ✔ Your memory usage beats 5.6 % of java submissions (285.6 MB)
# Submitting: java_solutions/3413.maximum-coins-from-k-consecutive-bags.java
# - Downloading maximum-coins-from-k-consecutive-bags
#   ✔ Accepted
#   ✔ 605/605 cases passed (146 ms)
#   ✔ Your runtime beats 12.5 % of java submissions
#   ✔ Your memory usage beats 6.25 % of java submissions (235.8 MB)
# Submitting: java_solutions/3414.maximum-score-of-non-overlapping-intervals.java
# - Downloading maximum-score-of-non-overlapping-intervals
#   ✔ Accepted
#   ✔ 581/581 cases passed (747 ms)
#   ✔ Your runtime beats 8 % of java submissions
#   ✔ Your memory usage beats 68 % of java submissions (186 MB)
# Submitting: java_solutions/3417.zigzag-grid-traversal-with-skip.java
# - Downloading zigzag-grid-traversal-with-skip
#   ✔ Accepted
#   ✔ 840/840 cases passed (5 ms)
#   ✔ Your runtime beats 0.81 % of java submissions
#   ✔ Your memory usage beats 52.83 % of java submissions (47.3 MB)
# Submitting: java_solutions/3418.maximum-amount-of-money-robot-can-earn.java
# - Downloading maximum-amount-of-money-robot-can-earn
#   ✔ Accepted
#   ✔ 579/579 cases passed (147 ms)
#   ✔ Your runtime beats 36.67 % of java submissions
#   ✔ Your memory usage beats 85.75 % of java submissions (238 MB)
# Submitting: java_solutions/3419.minimize-the-maximum-edge-weight-of-graph.java
# - Downloading minimize-the-maximum-edge-weight-of-graph
#   ✔ Accepted
#   ✔ 671/671 cases passed (543 ms)
#   ✔ Your runtime beats 34.01 % of java submissions
#   ✔ Your memory usage beats 64.98 % of java submissions (262.9 MB)
# Submitting: java_solutions/3420.count-non-decreasing-subarrays-after-k-operations.java
# - Downloading count-non-decreasing-subarrays-after-k-operations
#   ✔ Accepted
#   ✔ 731/731 cases passed (665 ms)
#   ✔ Your runtime beats 6.45 % of java submissions
#   ✔ Your memory usage beats 96.77 % of java submissions (116.8 MB)
# Submitting: java_solutions/3423.maximum-difference-between-adjacent-elements-in-a-circular-array.java
# - Downloading maximum-difference-between-adjacent-elements-in-a-circular-array
#   ✔ Accepted
#   ✔ 962/962 cases passed (5 ms)
#   ✔ Your runtime beats 1.09 % of java submissions
#   ✔ Your memory usage beats 51.64 % of java submissions (45.1 MB)
# Submitting: java_solutions/3424.minimum-cost-to-make-arrays-identical.java
# - Downloading minimum-cost-to-make-arrays-identical
#   ✔ Accepted
#   ✔ 955/955 cases passed (91 ms)
#   ✔ Your runtime beats 5.45 % of java submissions
#   ✔ Your memory usage beats 5.45 % of java submissions (95.1 MB)
# Submitting: java_solutions/3425.longest-special-path.java
# - Downloading longest-special-path
#   ✔ Accepted
#   ✔ 675/675 cases passed (441 ms)
#   ✔ Your runtime beats 13.04 % of java submissions
#   ✔ Your memory usage beats 8.7 % of java submissions (401.7 MB)
# Submitting: java_solutions/3426.manhattan-distances-of-all-arrangements-of-pieces.java
# - Downloading manhattan-distances-of-all-arrangements-of-pieces
#   ✔ Accepted
#   ✔ 919/919 cases passed (63 ms)
#   ✔ Your runtime beats 27.78 % of java submissions
#   ✔ Your memory usage beats 44.44 % of java submissions (44.5 MB)
# Submitting: java_solutions/3427.sum-of-variable-length-subarrays.java
# - Downloading sum-of-variable-length-subarrays
#   ✔ Accepted
#   ✔ 773/773 cases passed (6 ms)
#   ✔ Your runtime beats 0.85 % of java submissions
#   ✔ Your memory usage beats 30.69 % of java submissions (45.4 MB)
# Submitting: java_solutions/3428.maximum-and-minimum-sums-of-at-most-size-k-subsequences.java
# - Downloading maximum-and-minimum-sums-of-at-most-size-k-subsequences
#   ✔ Accepted
#   ✔ 812/812 cases passed (225 ms)
#   ✔ Your runtime beats 34.09 % of java submissions
#   ✔ Your memory usage beats 50 % of java submissions (163.1 MB)
# Submitting: java_solutions/3429.paint-house-iv.java
# - Downloading paint-house-iv
#   ✔ Accepted
#   ✔ 956/956 cases passed (51 ms)
#   ✔ Your runtime beats 84.4 % of java submissions
#   ✔ Your memory usage beats 87.16 % of java submissions (141.8 MB)
# Submitting: java_solutions/3430.maximum-and-minimum-sums-of-at-most-size-k-subarrays.java
# - Downloading maximum-and-minimum-sums-of-at-most-size-k-subarrays
#   ✔ Accepted
#   ✔ 684/684 cases passed (512 ms)
#   ✔ Your runtime beats 9.3 % of java submissions
#   ✔ Your memory usage beats 34.88 % of java submissions (120.8 MB)
# Submitting: java_solutions/3432.count-partitions-with-even-sum-difference.java
# - Downloading count-partitions-with-even-sum-difference
#   ✔ Accepted
#   ✔ 616/616 cases passed (4 ms)
#   ✔ Your runtime beats 5.56 % of java submissions
#   ✔ Your memory usage beats 7.13 % of java submissions (44 MB)
# Submitting: java_solutions/3433.count-mentions-per-user.java
# - Downloading count-mentions-per-user
#   ✔ Accepted
#   ✔ 673/673 cases passed (47 ms)
#   ✔ Your runtime beats 7.04 % of java submissions
#   ✔ Your memory usage beats 59.8 % of java submissions (47.5 MB)
# Submitting: java_solutions/3434.maximum-frequency-after-subarray-operation.java
# - Downloading maximum-frequency-after-subarray-operation
#   ✔ Accepted
#   ✔ 749/749 cases passed (84 ms)
#   ✔ Your runtime beats 5.13 % of java submissions
#   ✔ Your memory usage beats 17.31 % of java submissions (87.7 MB)
# Submitting: java_solutions/3435.frequencies-of-shortest-supersequences.java
# - Downloading frequencies-of-shortest-supersequences
#   ✔ Accepted
#   ✔ 808/808 cases passed (120 ms)
#   ✔ Your runtime beats 26.92 % of java submissions
#   ✔ Your memory usage beats 11.54 % of java submissions (53.4 MB)
# Submitting: java_solutions/3438.find-valid-pair-of-adjacent-digits-in-string.java
# - Downloading find-valid-pair-of-adjacent-digits-in-string
#   ✔ Accepted
#   ✔ 826/826 cases passed (7 ms)
#   ✔ Your runtime beats 7.27 % of java submissions
#   ✔ Your memory usage beats 5.23 % of java submissions (46.4 MB)
# Submitting: java_solutions/3439.reschedule-meetings-for-maximum-free-time-i.java
# - Downloading reschedule-meetings-for-maximum-free-time-i
#   ✔ Accepted
#   ✔ 689/689 cases passed (6 ms)
#   ✔ Your runtime beats 9.09 % of java submissions
#   ✔ Your memory usage beats 29.09 % of java submissions (100.6 MB)
# Submitting: java_solutions/3440.reschedule-meetings-for-maximum-free-time-ii.java
# - Downloading reschedule-meetings-for-maximum-free-time-ii
#   ✔ Accepted
#   ✔ 695/695 cases passed (8 ms)
#   ✔ Your runtime beats 31.25 % of java submissions
#   ✔ Your memory usage beats 95.83 % of java submissions (114.5 MB)
# Submitting: java_solutions/3441.minimum-cost-good-caption.java
# - Downloading minimum-cost-good-caption
#   ✔ Accepted
#   ✔ 714/714 cases passed (1824 ms)
#   ✔ Your runtime beats 11.11 % of java submissions
#   ✔ Your memory usage beats 66.67 % of java submissions (77.1 MB)
# Submitting: java_solutions/3442.maximum-difference-between-even-and-odd-frequency-i.java
# - Downloading maximum-difference-between-even-and-odd-frequency-i
#   ✔ Accepted
#   ✔ 805/805 cases passed (3 ms)
#   ✔ Your runtime beats 52.05 % of java submissions
#   ✔ Your memory usage beats 6.85 % of java submissions (44.3 MB)
# Submitting: java_solutions/3443.maximum-manhattan-distance-after-k-changes.java
# - Downloading maximum-manhattan-distance-after-k-changes
#   ✔ Accepted
#   ✔ 828/828 cases passed (701 ms)
#   ✔ Your runtime beats 5.56 % of java submissions
#   ✔ Your memory usage beats 13.89 % of java submissions (48.1 MB)
# Submitting: java_solutions/3444.minimum-increments-for-target-multiples-in-an-array.java
# - Downloading minimum-increments-for-target-multiples-in-an-array
#   ✔ Accepted
#   ✔ 590/590 cases passed (1113 ms)
#   ✔ Your runtime beats 8 % of java submissions
#   ✔ Your memory usage beats 52 % of java submissions (54.4 MB)
# Submitting: java_solutions/3445.maximum-difference-between-even-and-odd-frequency-ii.java
# - Downloading maximum-difference-between-even-and-odd-frequency-ii
#   ✔ Accepted
#   ✔ 693/693 cases passed (1266 ms)
#   ✔ Your runtime beats 5.72 % of java submissions
#   ✔ Your memory usage beats 17.14 % of java submissions (53.6 MB)
# Submitting: java_solutions/3446.sort-matrix-by-diagonals.java
# - Downloading sort-matrix-by-diagonals
#   ✔ Accepted
#   ✔ 1306/1306 cases passed (12 ms)
#   ✔ Your runtime beats 5.17 % of java submissions
#   ✔ Your memory usage beats 12.07 % of java submissions (47.6 MB)
# Submitting: java_solutions/3447.assign-elements-to-groups-with-constraints.java
# - Downloading assign-elements-to-groups-with-constraints
#   ✔ Accepted
#   ✔ 572/572 cases passed (410 ms)
#   ✔ Your runtime beats 71.88 % of java submissions
#   ✔ Your memory usage beats 20.31 % of java submissions (210.6 MB)
# Submitting: java_solutions/3448.count-substrings-divisible-by-last-digit.java
# - Downloading count-substrings-divisible-by-last-digit
#   ✔ Accepted
#   ✔ 699/699 cases passed (47 ms)
#   ✔ Your runtime beats 64 % of java submissions
#   ✔ Your memory usage beats 72 % of java submissions (48.1 MB)
# Submitting: java_solutions/3449.maximize-the-minimum-game-score.java
# - Downloading maximize-the-minimum-game-score
#   ✔ Accepted
#   ✔ 692/692 cases passed (618 ms)
#   ✔ Your runtime beats 11.76 % of java submissions
#   ✔ Your memory usage beats 11.76 % of java submissions (61.2 MB)
# Submitting: java_solutions/3452.sum-of-good-numbers.java
# - Downloading sum-of-good-numbers
#   ✔ Accepted
#   ✔ 803/803 cases passed (4 ms)
#   ✔ Your runtime beats 1.36 % of java submissions
#   ✔ Your memory usage beats 7.01 % of java submissions (46 MB)
# Submitting: java_solutions/3453.separate-squares-i.java
# - Downloading separate-squares-i
#   ✔ Accepted
#   ✔ 916/916 cases passed (153 ms)
#   ✔ Your runtime beats 39.47 % of java submissions
#   ✔ Your memory usage beats 56.14 % of java submissions (145.3 MB)
# Submitting: java_solutions/3454.separate-squares-ii.java
# - Downloading separate-squares-ii
#   ✔ Accepted
#   ✔ 763/763 cases passed (1694 ms)
#   ✔ Your runtime beats 5.35 % of java submissions
#   ✔ Your memory usage beats 83.04 % of java submissions (149.2 MB)
# Submitting: java_solutions/3455.shortest-matching-substring.java
# - Downloading shortest-matching-substring
#   ✔ Accepted
#   ✔ 795/795 cases passed (462 ms)
#   ✔ Your runtime beats 6.9 % of java submissions
#   ✔ Your memory usage beats 44.83 % of java submissions (71.9 MB)
# Submitting: java_solutions/3456.find-special-substring-of-length-k.java
# - Downloading find-special-substring-of-length-k
#   ✔ Accepted
#   ✔ 812/812 cases passed (5 ms)
#   ✔ Your runtime beats 6.56 % of java submissions
#   ✔ Your memory usage beats 6.01 % of java submissions (45.2 MB)
# Submitting: java_solutions/3457.eat-pizzas.java
# - Downloading eat-pizzas
#   ✔ Accepted
#   ✔ 1005/1005 cases passed (87 ms)
#   ✔ Your runtime beats 6.5 % of java submissions
#   ✔ Your memory usage beats 7.32 % of java submissions (128.5 MB)
# Submitting: java_solutions/3458.select-k-disjoint-special-substrings.java
# - Downloading select-k-disjoint-special-substrings
#   ✔ Accepted
#   ✔ 990/990 cases passed (12 ms)
#   ✔ Your runtime beats 65.79 % of java submissions
#   ✔ Your memory usage beats 31.58 % of java submissions (47.7 MB)
# Submitting: java_solutions/3459.length-of-longest-v-shaped-diagonal-segment.java
# - Downloading length-of-longest-v-shaped-diagonal-segment
#   ✔ Accepted
#   ✔ 561/561 cases passed (102 ms)
#   ✔ Your runtime beats 82.54 % of java submissions
#   ✔ Your memory usage beats 80.95 % of java submissions (204.2 MB)
# Submitting: java_solutions/3461.check-if-digits-are-equal-in-string-after-operations-i.java
# - Downloading check-if-digits-are-equal-in-string-after-operations-i
#   ✔ Accepted
#   ✔ 706/706 cases passed (5 ms)
#   ✔ Your runtime beats 71.36 % of java submissions
#   ✔ Your memory usage beats 88.37 % of java submissions (43.4 MB)
# Submitting: java_solutions/3462.maximum-sum-with-at-most-k-elements.java
# - Downloading maximum-sum-with-at-most-k-elements
#   ✔ Accepted
#   ✔ 594/594 cases passed (267 ms)
#   ✔ Your runtime beats 16.23 % of java submissions
#   ✔ Your memory usage beats 51.3 % of java submissions (136.2 MB)
# Submitting: java_solutions/3463.check-if-digits-are-equal-in-string-after-operations-ii.java
# - Downloading check-if-digits-are-equal-in-string-after-operations-ii
#   ✔ Accepted
#   ✔ 684/684 cases passed (599 ms)
#   ✔ Your runtime beats 9.52 % of java submissions
#   ✔ Your memory usage beats 7.14 % of java submissions (48.8 MB)
# Submitting: java_solutions/3464.maximize-the-distance-between-points-on-a-square.java
# - Downloading maximize-the-distance-between-points-on-a-square
#   ✔ Accepted
#   ✔ 619/619 cases passed (1670 ms)
#   ✔ Your runtime beats 5.01 % of java submissions
#   ✔ Your memory usage beats 5.01 % of java submissions (64.4 MB)
# Submitting: java_solutions/3467.transform-array-by-parity.java
# - Downloading transform-array-by-parity
#   ✔ Accepted
#   ✔ 804/804 cases passed (4 ms)
#   ✔ Your runtime beats 58.81 % of java submissions
#   ✔ Your memory usage beats 91.48 % of java submissions (46.6 MB)
# Submitting: java_solutions/3468.find-the-number-of-copy-arrays.java
# - Downloading find-the-number-of-copy-arrays
#   ✔ Accepted
#   ✔ 740/740 cases passed (7 ms)
#   ✔ Your runtime beats 3.85 % of java submissions
#   ✔ Your memory usage beats 98.08 % of java submissions (155.8 MB)
# Submitting: java_solutions/3469.find-minimum-cost-to-remove-array-elements.java
# - Downloading find-minimum-cost-to-remove-array-elements
#   ✔ Accepted
#   ✔ 807/807 cases passed (55 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 95.92 % of java submissions (58.5 MB)
# Submitting: java_solutions/3470.permutations-iv.java
# - Downloading permutations-iv
#   ✔ Accepted
#   ✔ 999/999 cases passed (62 ms)
#   ✔ Your runtime beats 14.29 % of java submissions
#   ✔ Your memory usage beats 10.71 % of java submissions (52.8 MB)
# Submitting: java_solutions/3471.find-the-largest-almost-missing-integer.java
# - Downloading find-the-largest-almost-missing-integer
#   ✔ Accepted
#   ✔ 900/900 cases passed (7 ms)
#   ✔ Your runtime beats 9.89 % of java submissions
#   ✔ Your memory usage beats 10.44 % of java submissions (46.7 MB)
# Submitting: java_solutions/3472.longest-palindromic-subsequence-after-at-most-k-operations.java
# - Downloading longest-palindromic-subsequence-after-at-most-k-operations
#   ✔ Accepted
#   ✔ 550/550 cases passed (219 ms)
#   ✔ Your runtime beats 18 % of java submissions
#   ✔ Your memory usage beats 25 % of java submissions (121.8 MB)
# Submitting: java_solutions/3473.sum-of-k-subarrays-with-length-at-least-m.java
# - Downloading sum-of-k-subarrays-with-length-at-least-m
#   ✔ Accepted
#   ✔ 624/624 cases passed (293 ms)
#   ✔ Your runtime beats 47.37 % of java submissions
#   ✔ Your memory usage beats 63.16 % of java submissions (161.6 MB)
# Submitting: java_solutions/3474.lexicographically-smallest-generated-string.java
# - Downloading lexicographically-smallest-generated-string
#   ✔ Accepted
#   ✔ 739/739 cases passed (246 ms)
#   ✔ Your runtime beats 5.03 % of java submissions
#   ✔ Your memory usage beats 6.84 % of java submissions (53 MB)
# Submitting: java_solutions/3477.fruits-into-baskets-ii.java
# - Downloading fruits-into-baskets-ii
#   ✔ Accepted
#   ✔ 904/904 cases passed (7 ms)
#   ✔ Your runtime beats 5.69 % of java submissions
#   ✔ Your memory usage beats 30.2 % of java submissions (46.5 MB)
# Submitting: java_solutions/3478.choose-k-elements-with-maximum-sum.java
# - Downloading choose-k-elements-with-maximum-sum
#   ✔ Accepted
#   ✔ 635/635 cases passed (182 ms)
#   ✔ Your runtime beats 20.98 % of java submissions
#   ✔ Your memory usage beats 36.36 % of java submissions (159.6 MB)
# Submitting: java_solutions/3479.fruits-into-baskets-iii.java
# - Downloading fruits-into-baskets-iii
#   ✔ Accepted
#   ✔ 742/742 cases passed (59 ms)
#   ✔ Your runtime beats 96.04 % of java submissions
#   ✔ Your memory usage beats 96.48 % of java submissions (110.9 MB)
# Submitting: java_solutions/3480.maximize-subarrays-after-removing-one-conflicting-pair.java
# - Downloading maximize-subarrays-after-removing-one-conflicting-pair
#   ✔ Accepted
#   ✔ 642/642 cases passed (293 ms)
#   ✔ Your runtime beats 6.52 % of java submissions
#   ✔ Your memory usage beats 54.35 % of java submissions (280.5 MB)
# Submitting: java_solutions/3483.unique-3-digit-even-numbers.java
# - Downloading unique-3-digit-even-numbers
#   ✔ Accepted
#   ✔ 930/930 cases passed (14 ms)
#   ✔ Your runtime beats 11.16 % of java submissions
#   ✔ Your memory usage beats 15.4 % of java submissions (46.7 MB)
# Submitting: java_solutions/3484.design-spreadsheet.java
# - Downloading design-spreadsheet
#   ✔ Accepted
#   ✔ 658/658 cases passed (153 ms)
#   ✔ Your runtime beats 24.08 % of java submissions
#   ✔ Your memory usage beats 5.24 % of java submissions (123.8 MB)
# Submitting: java_solutions/3485.longest-common-prefix-of-k-strings-after-removal.java
# - Downloading longest-common-prefix-of-k-strings-after-removal
#   ✔ Accepted
#   ✔ 667/667 cases passed (671 ms)
#   ✔ Your runtime beats 25 % of java submissions
#   ✔ Your memory usage beats 7.14 % of java submissions (286.7 MB)
# Submitting: java_solutions/3486.longest-special-path-ii.java
# - Downloading longest-special-path-ii
#   ✔ Accepted
#   ✔ 678/678 cases passed (360 ms)
#   ✔ Your runtime beats 26.32 % of java submissions
#   ✔ Your memory usage beats 15.79 % of java submissions (365.6 MB)
# Submitting: java_solutions/3487.maximum-unique-subarray-sum-after-deletion.java
# - Downloading maximum-unique-subarray-sum-after-deletion
#   ✔ Accepted
#   ✔ 927/927 cases passed (5 ms)
#   ✔ Your runtime beats 19.27 % of java submissions
#   ✔ Your memory usage beats 26.15 % of java submissions (44.5 MB)
# Submitting: java_solutions/3488.closest-equal-element-queries.java
# - Downloading closest-equal-element-queries
#   ✔ Accepted
#   ✔ 614/614 cases passed (156 ms)
#   ✔ Your runtime beats 6.77 % of java submissions
#   ✔ Your memory usage beats 5.52 % of java submissions (195.5 MB)
# Submitting: java_solutions/3489.zero-array-transformation-iv.java
# - Downloading zero-array-transformation-iv
#   ✔ Accepted
#   ✔ 714/714 cases passed (44 ms)
#   ✔ Your runtime beats 68.75 % of java submissions
#   ✔ Your memory usage beats 66.67 % of java submissions (47.4 MB)
# Submitting: java_solutions/3490.count-beautiful-numbers.java
# - Downloading count-beautiful-numbers
#   ✔ Accepted
#   ✔ 554/554 cases passed (725 ms)
#   ✔ Your runtime beats 17.65 % of java submissions
#   ✔ Your memory usage beats 15.69 % of java submissions (88.3 MB)
# Submitting: java_solutions/3492.maximum-containers-on-a-ship.java
# - Downloading maximum-containers-on-a-ship
#   ✔ Accepted
#   ✔ 686/686 cases passed (5 ms)
#   ✔ Your runtime beats 18.65 % of java submissions
#   ✔ Your memory usage beats 66.22 % of java submissions (42.5 MB)
# Submitting: java_solutions/3493.properties-graph.java
# - Downloading properties-graph
#   ✔ Accepted
#   ✔ 668/668 cases passed (19 ms)
#   ✔ Your runtime beats 95.49 % of java submissions
#   ✔ Your memory usage beats 8.27 % of java submissions (48.7 MB)
# Submitting: java_solutions/3494.find-the-minimum-amount-of-time-to-brew-potions.java
# - Downloading find-the-minimum-amount-of-time-to-brew-potions
#   ✔ Accepted
#   ✔ 744/744 cases passed (187 ms)
#   ✔ Your runtime beats 20.13 % of java submissions
#   ✔ Your memory usage beats 65.58 % of java submissions (46.5 MB)
# Submitting: java_solutions/3495.minimum-operations-to-make-array-elements-zero.java
# - Downloading minimum-operations-to-make-array-elements-zero
#   ✔ Accepted
#   ✔ 646/646 cases passed (31 ms)
#   ✔ Your runtime beats 22.86 % of java submissions
#   ✔ Your memory usage beats 8.57 % of java submissions (144.5 MB)
# Submitting: java_solutions/3498.reverse-degree-of-a-string.java
# - Downloading reverse-degree-of-a-string
#   ✔ Accepted
#   ✔ 933/933 cases passed (3 ms)
#   ✔ Your runtime beats 10.16 % of java submissions
#   ✔ Your memory usage beats 6.88 % of java submissions (44.9 MB)
# Submitting: java_solutions/3499.maximize-active-section-with-trade-i.java
# - Downloading maximize-active-section-with-trade-i
#   ✔ Accepted
#   ✔ 996/996 cases passed (100 ms)
#   ✔ Your runtime beats 66 % of java submissions
#   ✔ Your memory usage beats 70 % of java submissions (47.9 MB)
# Submitting: java_solutions/3500.minimum-cost-to-divide-array-into-subarrays.java
# - Downloading minimum-cost-to-divide-array-into-subarrays
#   ✔ Accepted
#   ✔ 759/759 cases passed (205 ms)
#   ✔ Your runtime beats 41.67 % of java submissions
#   ✔ Your memory usage beats 58.33 % of java submissions (52.8 MB)
# Submitting: java_solutions/3501.maximize-active-section-with-trade-ii.java
# - Downloading maximize-active-section-with-trade-ii
#   ✔ Accepted
#   ✔ 592/592 cases passed (552 ms)
#   ✔ Your runtime beats 29.41 % of java submissions
#   ✔ Your memory usage beats 64.71 % of java submissions (262.7 MB)
# Submitting: java_solutions/3502.minimum-cost-to-reach-every-position.java
# - Downloading minimum-cost-to-reach-every-position
#   ✔ Accepted
#   ✔ 724/724 cases passed (4 ms)
#   ✔ Your runtime beats 0.95 % of java submissions
#   ✔ Your memory usage beats 56.65 % of java submissions (46.8 MB)
# Submitting: java_solutions/3503.longest-palindrome-after-substring-concatenation-i.java
# - Downloading longest-palindrome-after-substring-concatenation-i
#   ✔ Accepted
#   ✔ 584/584 cases passed (1397 ms)
#   ✔ Your runtime beats 6 % of java submissions
#   ✔ Your memory usage beats 6 % of java submissions (48.1 MB)
# Submitting: java_solutions/3504.longest-palindrome-after-substring-concatenation-ii.java
# - Downloading longest-palindrome-after-substring-concatenation-ii
#   ✔ Accepted
#   ✔ 904/904 cases passed (1710 ms)
#   ✔ Your runtime beats 7.41 % of java submissions
#   ✔ Your memory usage beats 25.93 % of java submissions (282.8 MB)
# Submitting: java_solutions/3505.minimum-operations-to-make-elements-within-k-subarrays-equal.java
# - Downloading minimum-operations-to-make-elements-within-k-subarrays-equal
#   ✔ Accepted
#   ✔ 774/774 cases passed (1282 ms)
#   ✔ Your runtime beats 18.52 % of java submissions
#   ✔ Your memory usage beats 40.74 % of java submissions (287.5 MB)
# Submitting: java_solutions/3507.minimum-pair-removal-to-sort-array-i.java
# - Downloading minimum-pair-removal-to-sort-array-i
#   ✔ Accepted
#   ✔ 806/806 cases passed (6 ms)
#   ✔ Your runtime beats 10.06 % of java submissions
#   ✔ Your memory usage beats 5.81 % of java submissions (45.6 MB)
# Submitting: java_solutions/3508.implement-router.java
# - Downloading implement-router
#   ✔ Accepted
#   ✔ 753/753 cases passed (411 ms)
#   ✔ Your runtime beats 5.74 % of java submissions
#   ✔ Your memory usage beats 6.56 % of java submissions (204.2 MB)
# Submitting: java_solutions/3509.maximum-product-of-subsequences-with-an-alternating-sum-equal-to-k.java
# - Downloading maximum-product-of-subsequences-with-an-alternating-sum-equal-to-k
#   ✔ Accepted
#   ✔ 665/665 cases passed (828 ms)
#   ✔ Your runtime beats 25.72 % of java submissions
#   ✔ Your memory usage beats 22.86 % of java submissions (276.8 MB)
# Submitting: java_solutions/3510.minimum-pair-removal-to-sort-array-ii.java
# - Downloading minimum-pair-removal-to-sort-array-ii
#   ✔ Accepted
#   ✔ 681/681 cases passed (1100 ms)
#   ✔ Your runtime beats 8.92 % of java submissions
#   ✔ Your memory usage beats 26.76 % of java submissions (180.4 MB)
# Submitting: java_solutions/3512.minimum-operations-to-make-array-sum-divisible-by-k.java
# - Downloading minimum-operations-to-make-array-sum-divisible-by-k
#   ✔ Accepted
#   ✔ 855/855 cases passed (5 ms)
#   ✔ Your runtime beats 3.49 % of java submissions
#   ✔ Your memory usage beats 6.49 % of java submissions (47.2 MB)
# Submitting: java_solutions/3513.number-of-unique-xor-triplets-i.java
# - Downloading number-of-unique-xor-triplets-i
#   ✔ Accepted
#   ✔ 785/785 cases passed (4 ms)
#   ✔ Your runtime beats 8 % of java submissions
#   ✔ Your memory usage beats 98 % of java submissions (125.1 MB)
# Submitting: java_solutions/3514.number-of-unique-xor-triplets-ii.java
# - Downloading number-of-unique-xor-triplets-ii
#   ✔ Accepted
#   ✔ 825/825 cases passed (1188 ms)
#   ✔ Your runtime beats 42.1 % of java submissions
#   ✔ Your memory usage beats 10.53 % of java submissions (47.3 MB)
# Submitting: java_solutions/3515.shortest-path-in-a-weighted-tree.java
# - Downloading shortest-path-in-a-weighted-tree
#   ✔ Accepted
#   ✔ 571/571 cases passed (675 ms)
#   ✔ Your runtime beats 16 % of java submissions
#   ✔ Your memory usage beats 8 % of java submissions (430.1 MB)

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-05-05 15:04:53
