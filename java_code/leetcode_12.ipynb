# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME_3')
    user_cookie = userdata.get('LEETCODE_TOKEN_3')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME_3'] = user_name
    os.environ['LEETCODE_TOKEN_3'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME_3" "$LEETCODE_TOKEN_3" | leetcode user -c

# %%
# %%bash
#
#
# # top 100 answers
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v java_solutions/*.java | sed -n '1651,1800p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 8
# done
# Out:
# Submitting: java_solutions/2540.minimum-common-value.java
# - Downloading problems
# - Downloading minimum-common-value
#   ✔ Accepted
#   ✔ 41/41 cases passed (9 ms)
#   ✔ Your runtime beats 23.15 % of java submissions
#   ✔ Your memory usage beats 21.48 % of java submissions (80.8 MB)
# Submitting: java_solutions/2541.minimum-operations-to-make-array-equal-ii.java
# - Downloading minimum-operations-to-make-array-equal-ii
#   ✔ Accepted
#   ✔ 68/68 cases passed (12 ms)
#   ✔ Your runtime beats 7.96 % of java submissions
#   ✔ Your memory usage beats 7.08 % of java submissions (95.8 MB)
# Submitting: java_solutions/2542.maximum-subsequence-score.java
# - Downloading maximum-subsequence-score
#   ✔ Accepted
#   ✔ 28/28 cases passed (97 ms)
#   ✔ Your runtime beats 5.86 % of java submissions
#   ✔ Your memory usage beats 14.7 % of java submissions (108.8 MB)
# Submitting: java_solutions/2543.check-if-point-is-reachable.java
# - Downloading check-if-point-is-reachable
#   ✔ Accepted
#   ✔ 60/60 cases passed (2 ms)
#   ✔ Your runtime beats 11.9 % of java submissions
#   ✔ Your memory usage beats 19.05 % of java submissions (42.3 MB)
# Submitting: java_solutions/2544.alternating-digit-sum.java
# - Downloading alternating-digit-sum
#   ✔ Accepted
#   ✔ 118/118 cases passed (4 ms)
#   ✔ Your runtime beats 0.85 % of java submissions
#   ✔ Your memory usage beats 13.48 % of java submissions (42.4 MB)
# Submitting: java_solutions/2545.sort-the-students-by-their-kth-score.java
# - Downloading sort-the-students-by-their-kth-score
#   ✔ Accepted
#   ✔ 33/33 cases passed (4 ms)
#   ✔ Your runtime beats 21.57 % of java submissions
#   ✔ Your memory usage beats 73.22 % of java submissions (55.9 MB)
# Submitting: java_solutions/2546.apply-bitwise-operations-to-make-strings-equal.java
# - Downloading apply-bitwise-operations-to-make-strings-equal
#   ✔ Accepted
#   ✔ 71/71 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 93.65 % of java submissions (47.3 MB)
# Submitting: java_solutions/2547.minimum-cost-to-split-an-array.java
# - Downloading minimum-cost-to-split-an-array
#   ✔ Accepted
#   ✔ 59/59 cases passed (511 ms)
#   ✔ Your runtime beats 28.33 % of java submissions
#   ✔ Your memory usage beats 32.5 % of java submissions (53.2 MB)
# Submitting: java_solutions/2549.count-distinct-numbers-on-board.java
# - Downloading count-distinct-numbers-on-board
#   ✔ Accepted
#   ✔ 100/100 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 46.12 % of java submissions (42.1 MB)
# Submitting: java_solutions/2550.count-collisions-of-monkeys-on-a-polygon.java
# - Downloading count-collisions-of-monkeys-on-a-polygon
#   ✔ Accepted
#   ✔ 83/83 cases passed (3 ms)
#   ✔ Your runtime beats 3.54 % of java submissions
#   ✔ Your memory usage beats 77.88 % of java submissions (42 MB)
# Submitting: java_solutions/2551.put-marbles-in-bags.java
# - Downloading put-marbles-in-bags
#   ✔ Accepted
#   ✔ 103/103 cases passed (62 ms)
#   ✔ Your runtime beats 31.61 % of java submissions
#   ✔ Your memory usage beats 59.2 % of java submissions (78.9 MB)
# Submitting: java_solutions/2552.count-increasing-quadruplets.java
# - Downloading count-increasing-quadruplets
#   ✔ Accepted
#   ✔ 121/121 cases passed (328 ms)
#   ✔ Your runtime beats 15.56 % of java submissions
#   ✔ Your memory usage beats 53.33 % of java submissions (53.1 MB)
# Submitting: java_solutions/2553.separate-the-digits-in-an-array.java
# - Downloading separate-the-digits-in-an-array
#   ✔ Accepted
#   ✔ 52/52 cases passed (11 ms)
#   ✔ Your runtime beats 7.12 % of java submissions
#   ✔ Your memory usage beats 10.91 % of java submissions (47 MB)
# Submitting: java_solutions/2554.maximum-number-of-integers-to-choose-from-a-range-i.java
# - Downloading maximum-number-of-integers-to-choose-from-a-range-i
#   ✔ Accepted
#   ✔ 208/208 cases passed (60 ms)
#   ✔ Your runtime beats 14.55 % of java submissions
#   ✔ Your memory usage beats 57.09 % of java submissions (48.3 MB)
# Submitting: java_solutions/2555.maximize-win-from-two-segments.java
# - Downloading maximize-win-from-two-segments
#   ✔ Accepted
#   ✔ 72/72 cases passed (11 ms)
#   ✔ Your runtime beats 7.23 % of java submissions
#   ✔ Your memory usage beats 55.42 % of java submissions (60.6 MB)
# Submitting: java_solutions/2556.disconnect-path-in-a-binary-matrix-by-at-most-one-flip.java
# - Downloading disconnect-path-in-a-binary-matrix-by-at-most-one-flip
#   ✔ Accepted
#   ✔ 55/55 cases passed (28 ms)
#   ✔ Your runtime beats 3.13 % of java submissions
#   ✔ Your memory usage beats 6.25 % of java submissions (92.7 MB)
# Submitting: java_solutions/2558.take-gifts-from-the-richest-pile.java
# - Downloading take-gifts-from-the-richest-pile
#   ✔ Accepted
#   ✔ 103/103 cases passed (8 ms)
#   ✔ Your runtime beats 31.72 % of java submissions
#   ✔ Your memory usage beats 68.03 % of java submissions (44.1 MB)
# Submitting: java_solutions/2559.count-vowel-strings-in-ranges.java
# - Downloading count-vowel-strings-in-ranges
#   ✔ Accepted
#   ✔ 94/94 cases passed (14 ms)
#   ✔ Your runtime beats 10.48 % of java submissions
#   ✔ Your memory usage beats 18.76 % of java submissions (89.4 MB)
# Submitting: java_solutions/2560.house-robber-iv.java
# - Downloading house-robber-iv
#   ✔ Accepted
#   ✔ 64/64 cases passed (34 ms)
#   ✔ Your runtime beats 6.26 % of java submissions
#   ✔ Your memory usage beats 62.85 % of java submissions (76.2 MB)
# Submitting: java_solutions/2561.rearranging-fruits.java
# - Downloading rearranging-fruits
#   ✔ Accepted
#   ✔ 41/41 cases passed (103 ms)
#   ✔ Your runtime beats 23.51 % of java submissions
#   ✔ Your memory usage beats 16.05 % of java submissions (110.4 MB)
# Submitting: java_solutions/2562.find-the-array-concatenation-value.java
# - Downloading find-the-array-concatenation-value
#   ✔ Accepted
#   ✔ 53/53 cases passed (8 ms)
#   ✔ Your runtime beats 7.1 % of java submissions
#   ✔ Your memory usage beats 8.45 % of java submissions (46.7 MB)
# Submitting: java_solutions/2563.count-the-number-of-fair-pairs.java
# - Downloading count-the-number-of-fair-pairs
#   ✔ Accepted
#   ✔ 55/55 cases passed (94 ms)
#   ✔ Your runtime beats 5.01 % of java submissions
#   ✔ Your memory usage beats 13.84 % of java submissions (94 MB)
# Submitting: java_solutions/2564.substring-xor-queries.java
# - Downloading substring-xor-queries
#   ✔ Accepted
#   ✔ 59/59 cases passed (43 ms)
#   ✔ Your runtime beats 21.88 % of java submissions
#   ✔ Your memory usage beats 65.63 % of java submissions (138.7 MB)
# Submitting: java_solutions/2565.subsequence-with-the-minimum-score.java
# - Downloading subsequence-with-the-minimum-score
#   ✔ Accepted
#   ✔ 54/54 cases passed (63 ms)
#   ✔ Your runtime beats 8.7 % of java submissions
#   ✔ Your memory usage beats 8.7 % of java submissions (55.1 MB)
# Submitting: java_solutions/2566.maximum-difference-by-remapping-a-digit.java
# - Downloading maximum-difference-by-remapping-a-digit
#   ✔ Accepted
#   ✔ 214/214 cases passed (6 ms)
#   ✔ Your runtime beats 6.33 % of java submissions
#   ✔ Your memory usage beats 5.96 % of java submissions (42.6 MB)
# Submitting: java_solutions/2567.minimum-score-by-changing-two-elements.java
# - Downloading minimum-score-by-changing-two-elements
#   ✔ Accepted
#   ✔ 70/70 cases passed (26 ms)
#   ✔ Your runtime beats 5.47 % of java submissions
#   ✔ Your memory usage beats 18.75 % of java submissions (66.3 MB)
# Submitting: java_solutions/2568.minimum-impossible-or.java
# - Downloading minimum-impossible-or
#   ✔ Accepted
#   ✔ 73/73 cases passed (28 ms)
#   ✔ Your runtime beats 16.88 % of java submissions
#   ✔ Your memory usage beats 5.19 % of java submissions (90.7 MB)
# Submitting: java_solutions/2569.handling-sum-queries-after-update.java
# - Downloading handling-sum-queries-after-update
#   ✔ Accepted
#   ✔ 77/77 cases passed (195 ms)
#   ✔ Your runtime beats 21.13 % of java submissions
#   ✔ Your memory usage beats 25.35 % of java submissions (149.9 MB)
# Submitting: java_solutions/2570.merge-two-2d-arrays-by-summing-values.java
# - Downloading merge-two-2d-arrays-by-summing-values
#   ✔ Accepted
#   ✔ 39/39 cases passed (9 ms)
#   ✔ Your runtime beats 9.74 % of java submissions
#   ✔ Your memory usage beats 5.21 % of java submissions (47.7 MB)
# Submitting: java_solutions/2571.minimum-operations-to-reduce-an-integer-to-0.java
# - Downloading minimum-operations-to-reduce-an-integer-to-0
#   ✔ Accepted
#   ✔ 41/41 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 54.89 % of java submissions (42 MB)
# Submitting: java_solutions/2572.count-the-number-of-square-free-subsets.java
# - Downloading count-the-number-of-square-free-subsets
#   ✔ Accepted
#   ✔ 44/44 cases passed (22 ms)
#   ✔ Your runtime beats 58 % of java submissions
#   ✔ Your memory usage beats 80 % of java submissions (44.1 MB)
# Submitting: java_solutions/2573.find-the-string-with-lcp.java
# - Downloading find-the-string-with-lcp
#   ✔ Accepted
#   ✔ 55/55 cases passed (23 ms)
#   ✔ Your runtime beats 5.25 % of java submissions
#   ✔ Your memory usage beats 27.13 % of java submissions (178.1 MB)
# Submitting: java_solutions/2574.left-and-right-sum-differences.java
# - Downloading left-and-right-sum-differences
#   ✔ Accepted
#   ✔ 53/53 cases passed (250 ms)
#   ✔ Your runtime beats 6.4 % of java submissions
#   ✔ Your memory usage beats 15.31 % of java submissions (47.2 MB)
# Submitting: java_solutions/2575.find-the-divisibility-array-of-a-string.java
# - Downloading find-the-divisibility-array-of-a-string
#   ✔ Accepted
#   ✔ 51/51 cases passed (21 ms)
#   ✔ Your runtime beats 1.95 % of java submissions
#   ✔ Your memory usage beats 12.89 % of java submissions (82.5 MB)
# Submitting: java_solutions/2576.find-the-maximum-number-of-marked-indices.java
# - Downloading find-the-maximum-number-of-marked-indices
#   ✔ Accepted
#   ✔ 68/68 cases passed (48 ms)
#   ✔ Your runtime beats 5.59 % of java submissions
#   ✔ Your memory usage beats 98.76 % of java submissions (86.4 MB)
# Submitting: java_solutions/2577.minimum-time-to-visit-a-cell-in-a-grid.java
# - Downloading minimum-time-to-visit-a-cell-in-a-grid
#   ✔ Accepted
#   ✔ 42/42 cases passed (522 ms)
#   ✔ Your runtime beats 5.45 % of java submissions
#   ✔ Your memory usage beats 5.45 % of java submissions (119.8 MB)
# Submitting: java_solutions/2578.split-with-minimum-sum.java
# - Downloading split-with-minimum-sum
#   ✔ Accepted
#   ✔ 140/140 cases passed (12 ms)
#   ✔ Your runtime beats 9.78 % of java submissions
#   ✔ Your memory usage beats 8.31 % of java submissions (42.9 MB)
# Submitting: java_solutions/2579.count-total-number-of-colored-cells.java
# - Downloading count-total-number-of-colored-cells
#   ✔ Accepted
#   ✔ 94/94 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 28.73 % of java submissions (42.2 MB)
# Submitting: java_solutions/2580.count-ways-to-group-overlapping-ranges.java
# - Downloading count-ways-to-group-overlapping-ranges
#   ✔ Accepted
#   ✔ 32/32 cases passed (35 ms)
#   ✔ Your runtime beats 6.3 % of java submissions
#   ✔ Your memory usage beats 12.6 % of java submissions (111.9 MB)
# Submitting: java_solutions/2581.count-number-of-possible-root-nodes.java
# - Downloading count-number-of-possible-root-nodes
#   ✔ Accepted
#   ✔ 52/52 cases passed (453 ms)
#   ✔ Your runtime beats 6.98 % of java submissions
#   ✔ Your memory usage beats 6.98 % of java submissions (405.2 MB)
# Submitting: java_solutions/2582.pass-the-pillow.java
# - Downloading pass-the-pillow
#   ✔ Accepted
#   ✔ 68/68 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 56.22 % of java submissions (42 MB)
# Submitting: java_solutions/2583.kth-largest-sum-in-a-binary-tree.java
# - Downloading kth-largest-sum-in-a-binary-tree
#   ✔ Accepted
#   ✔ 51/51 cases passed (333 ms)
#   ✔ Your runtime beats 5.18 % of java submissions
#   ✔ Your memory usage beats 5.28 % of java submissions (160.8 MB)
# Submitting: java_solutions/2584.split-the-array-to-make-coprime-products.java
# - Downloading split-the-array-to-make-coprime-products
#   ✔ Accepted
#   ✔ 75/75 cases passed (1120 ms)
#   ✔ Your runtime beats 10.26 % of java submissions
#   ✔ Your memory usage beats 30.77 % of java submissions (58.1 MB)
# Submitting: java_solutions/2585.number-of-ways-to-earn-points.java
# - Downloading number-of-ways-to-earn-points
#   ✔ Accepted
#   ✔ 63/63 cases passed (429 ms)
#   ✔ Your runtime beats 5.29 % of java submissions
#   ✔ Your memory usage beats 7.69 % of java submissions (53.2 MB)
# Submitting: java_solutions/2586.count-the-number-of-vowel-strings-in-range.java
# - Downloading count-the-number-of-vowel-strings-in-range
#   ✔ Accepted
#   ✔ 1053/1053 cases passed (11 ms)
#   ✔ Your runtime beats 1.67 % of java submissions
#   ✔ Your memory usage beats 46.87 % of java submissions (46.5 MB)
# Submitting: java_solutions/2587.rearrange-array-to-maximize-prefix-score.java
# - Downloading rearrange-array-to-maximize-prefix-score
#   ✔ Accepted
#   ✔ 1071/1071 cases passed (160 ms)
#   ✔ Your runtime beats 5.75 % of java submissions
#   ✔ Your memory usage beats 13.72 % of java submissions (82.4 MB)
# Submitting: java_solutions/2588.count-the-number-of-beautiful-subarrays.java
# - Downloading count-the-number-of-beautiful-subarrays
#   ✔ Accepted
#   ✔ 114/114 cases passed (71 ms)
#   ✔ Your runtime beats 7.14 % of java submissions
#   ✔ Your memory usage beats 12.86 % of java submissions (118.2 MB)
# Submitting: java_solutions/2589.minimum-time-to-complete-all-tasks.java
# - Downloading minimum-time-to-complete-all-tasks
#   ✔ Accepted
#   ✔ 1059/1059 cases passed (197 ms)
#   ✔ Your runtime beats 5.77 % of java submissions
#   ✔ Your memory usage beats 9.62 % of java submissions (48 MB)
# Submitting: java_solutions/2591.distribute-money-to-maximum-children.java
# - Downloading distribute-money-to-maximum-children
#   ✔ Accepted
#   ✔ 3802/3802 cases passed (2 ms)
#   ✔ Your runtime beats 97.48 % of java submissions
#   ✔ Your memory usage beats 28.06 % of java submissions (43.9 MB)
# Submitting: java_solutions/2592.maximize-greatness-of-an-array.java
# - Downloading maximize-greatness-of-an-array
#   ✔ Accepted
#   ✔ 1072/1072 cases passed (31 ms)
#   ✔ Your runtime beats 11.91 % of java submissions
#   ✔ Your memory usage beats 14.08 % of java submissions (77.7 MB)
# Submitting: java_solutions/2593.find-score-of-an-array-after-marking-all-elements.java
# - Downloading find-score-of-an-array-after-marking-all-elements
#   ✔ Accepted
#   ✔ 1044/1044 cases passed (128 ms)
#   ✔ Your runtime beats 76.65 % of java submissions
#   ✔ Your memory usage beats 25.55 % of java submissions (99 MB)
# Submitting: java_solutions/2594.minimum-time-to-repair-cars.java
# - Downloading minimum-time-to-repair-cars
#   ✔ Accepted
#   ✔ 1072/1072 cases passed (71 ms)
#   ✔ Your runtime beats 9.61 % of java submissions
#   ✔ Your memory usage beats 5.56 % of java submissions (61.6 MB)
# Submitting: java_solutions/2595.number-of-even-and-odd-bits.java
# - Downloading number-of-even-and-odd-bits
#   ✔ Accepted
#   ✔ 1003/1003 cases passed (1 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 85.14 % of java submissions (43.8 MB)
# Submitting: java_solutions/2596.check-knight-tour-configuration.java
# - Downloading check-knight-tour-configuration
#   ✔ Accepted
#   ✔ 1029/1029 cases passed (5 ms)
#   ✔ Your runtime beats 1.2 % of java submissions
#   ✔ Your memory usage beats 12.93 % of java submissions (47 MB)
# Submitting: java_solutions/2597.the-number-of-beautiful-subsets.java
# - Downloading the-number-of-beautiful-subsets
#   ✔ Accepted
#   ✔ 1308/1308 cases passed (1212 ms)
#   ✔ Your runtime beats 8.05 % of java submissions
#   ✔ Your memory usage beats 93.96 % of java submissions (45.4 MB)
# Submitting: java_solutions/2598.smallest-missing-non-negative-integer-after-operations.java
# - Downloading smallest-missing-non-negative-integer-after-operations
#   ✔ Accepted
#   ✔ 1063/1063 cases passed (15 ms)
#   ✔ Your runtime beats 26.02 % of java submissions
#   ✔ Your memory usage beats 59.87 % of java submissions (112.3 MB)
# Submitting: java_solutions/2600.k-items-with-the-maximum-sum.java
# - Downloading k-items-with-the-maximum-sum
#   ✔ Accepted
#   ✔ 1310/1310 cases passed (1 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 74.48 % of java submissions (42.7 MB)
# Submitting: java_solutions/2601.prime-subtraction-operation.java
# - Downloading prime-subtraction-operation
#   ✔ Accepted
#   ✔ 654/654 cases passed (21 ms)
#   ✔ Your runtime beats 27.06 % of java submissions
#   ✔ Your memory usage beats 23.53 % of java submissions (47 MB)
# Submitting: java_solutions/2602.minimum-operations-to-make-all-array-elements-equal.java
# - Downloading minimum-operations-to-make-all-array-elements-equal
#   ✔ Accepted
#   ✔ 31/31 cases passed (80 ms)
#   ✔ Your runtime beats 5.06 % of java submissions
#   ✔ Your memory usage beats 5.06 % of java submissions (112.4 MB)
# Submitting: java_solutions/2603.collect-coins-in-a-tree.java
# - Downloading collect-coins-in-a-tree
#   ✔ Accepted
#   ✔ 4986/4986 cases passed (66 ms)
#   ✔ Your runtime beats 45.4 % of java submissions
#   ✔ Your memory usage beats 99.39 % of java submissions (86.5 MB)
# Submitting: java_solutions/2605.form-smallest-number-from-two-digit-arrays.java
# - Downloading form-smallest-number-from-two-digit-arrays
#   ✔ Accepted
#   ✔ 388/388 cases passed (10 ms)
#   ✔ Your runtime beats 10.55 % of java submissions
#   ✔ Your memory usage beats 5.01 % of java submissions (44.1 MB)
# Submitting: java_solutions/2606.find-the-substring-with-maximum-cost.java
# - Downloading find-the-substring-with-maximum-cost
#   ✔ Accepted
#   ✔ 1054/1054 cases passed (8 ms)
#   ✔ Your runtime beats 56.3 % of java submissions
#   ✔ Your memory usage beats 17.78 % of java submissions (47.4 MB)
# Submitting: java_solutions/2607.make-k-subarray-sums-equal.java
# - Downloading make-k-subarray-sums-equal
#   ✔ Accepted
#   ✔ 1040/1040 cases passed (164 ms)
#   ✔ Your runtime beats 6.25 % of java submissions
#   ✔ Your memory usage beats 6.25 % of java submissions (107.7 MB)
# Submitting: java_solutions/2608.shortest-cycle-in-a-graph.java
# - Downloading shortest-cycle-in-a-graph
#   ✔ Accepted
#   ✔ 89/89 cases passed (2055 ms)
#   ✔ Your runtime beats 5.09 % of java submissions
#   ✔ Your memory usage beats 6.18 % of java submissions (52.6 MB)
# Submitting: java_solutions/2609.find-the-longest-balanced-substring-of-a-binary-string.java
# - Downloading find-the-longest-balanced-substring-of-a-binary-string
#   ✔ Accepted
#   ✔ 1848/1848 cases passed (18 ms)
#   ✔ Your runtime beats 5.68 % of java submissions
#   ✔ Your memory usage beats 7.39 % of java submissions (47.2 MB)
# Submitting: java_solutions/2610.convert-an-array-into-a-2d-array-with-conditions.java
# - Downloading convert-an-array-into-a-2d-array-with-conditions
#   ✔ Accepted
#   ✔ 1035/1035 cases passed (5 ms)
#   ✔ Your runtime beats 22.84 % of java submissions
#   ✔ Your memory usage beats 13.37 % of java submissions (47 MB)
# Submitting: java_solutions/2611.mice-and-cheese.java
# - Downloading mice-and-cheese
#   ✔ Accepted
#   ✔ 564/564 cases passed (27 ms)
#   ✔ Your runtime beats 59.54 % of java submissions
#   ✔ Your memory usage beats 99.71 % of java submissions (75.1 MB)
# Submitting: java_solutions/2612.minimum-reverse-operations.java
# - Downloading minimum-reverse-operations
#   ✔ Accepted
#   ✔ 711/711 cases passed (244 ms)
#   ✔ Your runtime beats 45 % of java submissions
#   ✔ Your memory usage beats 96.67 % of java submissions (140.4 MB)
# Submitting: java_solutions/2614.prime-in-diagonal.java
# - Downloading prime-in-diagonal
#   ✔ Accepted
#   ✔ 82/82 cases passed (2 ms)
#   ✔ Your runtime beats 95.08 % of java submissions
#   ✔ Your memory usage beats 55.89 % of java submissions (82.5 MB)
# Submitting: java_solutions/2615.sum-of-distances.java
# - Downloading sum-of-distances
#   ✔ Accepted
#   ✔ 1068/1068 cases passed (144 ms)
#   ✔ Your runtime beats 5.26 % of java submissions
#   ✔ Your memory usage beats 96.22 % of java submissions (115.3 MB)
# Submitting: java_solutions/2616.minimize-the-maximum-difference-of-pairs.java
# - Downloading minimize-the-maximum-difference-of-pairs
#   ✔ Accepted
#   ✔ 1582/1582 cases passed (33 ms)
#   ✔ Your runtime beats 5 % of java submissions
#   ✔ Your memory usage beats 9.29 % of java submissions (79.3 MB)
# Submitting: java_solutions/2617.minimum-number-of-visited-cells-in-a-grid.java
# - Downloading minimum-number-of-visited-cells-in-a-grid
#   ✔ Accepted
#   ✔ 1072/1072 cases passed (612 ms)
#   ✔ Your runtime beats 58.7 % of java submissions
#   ✔ Your memory usage beats 100 % of java submissions (152 MB)
# Submitting: java_solutions/2639.find-the-width-of-columns-of-a-grid.java
# - Downloading find-the-width-of-columns-of-a-grid
#   ✔ Accepted
#   ✔ 50/50 cases passed (9 ms)
#   ✔ Your runtime beats 11.03 % of java submissions
#   ✔ Your memory usage beats 28.97 % of java submissions (47.8 MB)
# Submitting: java_solutions/2640.find-the-score-of-all-prefixes-of-an-array.java
# - Downloading find-the-score-of-all-prefixes-of-an-array
#   ✔ Accepted
#   ✔ 43/43 cases passed (10 ms)
#   ✔ Your runtime beats 1.05 % of java submissions
#   ✔ Your memory usage beats 78.27 % of java submissions (94.9 MB)
# Submitting: java_solutions/2641.cousins-in-binary-tree-ii.java
# - Downloading cousins-in-binary-tree-ii
#   ✔ Accepted
#   ✔ 41/41 cases passed (36 ms)
#   ✔ Your runtime beats 23.2 % of java submissions
#   ✔ Your memory usage beats 29.47 % of java submissions (117.1 MB)
# Submitting: java_solutions/2642.design-graph-with-shortest-path-calculator.java
# - Downloading design-graph-with-shortest-path-calculator
#   ✔ Accepted
#   ✔ 36/36 cases passed (272 ms)
#   ✔ Your runtime beats 8.84 % of java submissions
#   ✔ Your memory usage beats 5.3 % of java submissions (71.1 MB)
# Submitting: java_solutions/2643.row-with-maximum-ones.java
# - Downloading row-with-maximum-ones
#   ✔ Accepted
#   ✔ 1049/1049 cases passed (21 ms)
#   ✔ Your runtime beats 6.36 % of java submissions
#   ✔ Your memory usage beats 5.77 % of java submissions (48.8 MB)
# Submitting: java_solutions/2644.find-the-maximum-divisibility-score.java
# - Downloading find-the-maximum-divisibility-score
#   ✔ Accepted
#   ✔ 160/160 cases passed (1419 ms)
#   ✔ Your runtime beats 5.09 % of java submissions
#   ✔ Your memory usage beats 6.78 % of java submissions (48.1 MB)
# Submitting: java_solutions/2645.minimum-additions-to-make-valid-string.java
# - Downloading minimum-additions-to-make-valid-string
#   ✔ Accepted
#   ✔ 1523/1523 cases passed (2 ms)
#   ✔ Your runtime beats 15.29 % of java submissions
#   ✔ Your memory usage beats 59.87 % of java submissions (44.1 MB)
# Submitting: java_solutions/2646.minimize-the-total-price-of-the-trips.java
# - Downloading minimize-the-total-price-of-the-trips
#   ✔ Accepted
#   ✔ 407/407 cases passed (154 ms)
#   ✔ Your runtime beats 8.33 % of java submissions
#   ✔ Your memory usage beats 10 % of java submissions (53.9 MB)
# Submitting: java_solutions/2651.calculate-delayed-arrival-time.java
# - Downloading calculate-delayed-arrival-time
#   ✔ Accepted
#   ✔ 556/556 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 44.29 % of java submissions (42.4 MB)
# Submitting: java_solutions/2652.sum-multiples.java
# - Downloading sum-multiples
#   ✔ Accepted
#   ✔ 1000/1000 cases passed (10 ms)
#   ✔ Your runtime beats 1.46 % of java submissions
#   ✔ Your memory usage beats 8.64 % of java submissions (42.9 MB)
# Submitting: java_solutions/2653.sliding-subarray-beauty.java
# - Downloading sliding-subarray-beauty
#   ✔ Accepted
#   ✔ 717/717 cases passed (65 ms)
#   ✔ Your runtime beats 21.3 % of java submissions
#   ✔ Your memory usage beats 6.28 % of java submissions (185 MB)
# Submitting: java_solutions/2654.minimum-number-of-operations-to-make-all-array-elements-equal-to-1.java
# - Downloading minimum-number-of-operations-to-make-all-array-elements-equal-to-1
#   ✔ Accepted
#   ✔ 1070/1070 cases passed (7 ms)
#   ✔ Your runtime beats 6.51 % of java submissions
#   ✔ Your memory usage beats 59.9 % of java submissions (43.9 MB)
# Submitting: java_solutions/2656.maximum-sum-with-exactly-k-elements.java
# - Downloading maximum-sum-with-exactly-k-elements
#   ✔ Accepted
#   ✔ 3004/3004 cases passed (6 ms)
#   ✔ Your runtime beats 42.43 % of java submissions
#   ✔ Your memory usage beats 28.51 % of java submissions (47.2 MB)
# Submitting: java_solutions/2657.find-the-prefix-common-array-of-two-arrays.java
# - Downloading find-the-prefix-common-array-of-two-arrays
#   ✔ Accepted
#   ✔ 1773/1773 cases passed (14 ms)
#   ✔ Your runtime beats 19.14 % of java submissions
#   ✔ Your memory usage beats 5.15 % of java submissions (47.7 MB)
# Submitting: java_solutions/2658.maximum-number-of-fish-in-a-grid.java
# - Downloading maximum-number-of-fish-in-a-grid
#   ✔ Accepted
#   ✔ 3842/3842 cases passed (6 ms)
#   ✔ Your runtime beats 31.25 % of java submissions
#   ✔ Your memory usage beats 10.94 % of java submissions (47.3 MB)
# Submitting: java_solutions/2659.make-array-empty.java
# - Downloading make-array-empty
#   ✔ Accepted
#   ✔ 514/514 cases passed (70 ms)
#   ✔ Your runtime beats 22.67 % of java submissions
#   ✔ Your memory usage beats 96 % of java submissions (74.3 MB)
# Submitting: java_solutions/2660.determine-the-winner-of-a-bowling-game.java
# - Downloading determine-the-winner-of-a-bowling-game
#   ✔ Accepted
#   ✔ 1206/1206 cases passed (3 ms)
#   ✔ Your runtime beats 5.21 % of java submissions
#   ✔ Your memory usage beats 20.38 % of java submissions (47.2 MB)
# Submitting: java_solutions/2661.first-completely-painted-row-or-column.java
# - Downloading first-completely-painted-row-or-column
#   ✔ Accepted
#   ✔ 1058/1058 cases passed (8 ms)
#   ✔ Your runtime beats 93.46 % of java submissions
#   ✔ Your memory usage beats 96.73 % of java submissions (95.4 MB)
# Submitting: java_solutions/2662.minimum-cost-of-a-path-with-special-roads.java
# - Downloading minimum-cost-of-a-path-with-special-roads
#   ✔ Accepted
#   ✔ 1045/1045 cases passed (22 ms)
#   ✔ Your runtime beats 71.57 % of java submissions
#   ✔ Your memory usage beats 80.39 % of java submissions (47.1 MB)
# Submitting: java_solutions/2663.lexicographically-smallest-beautiful-string.java
# - Downloading lexicographically-smallest-beautiful-string
#   ✔ Accepted
#   ✔ 1054/1054 cases passed (124 ms)
#   ✔ Your runtime beats 5.36 % of java submissions
#   ✔ Your memory usage beats 5.36 % of java submissions (56 MB)
# Submitting: java_solutions/2670.find-the-distinct-difference-array.java
# - Downloading find-the-distinct-difference-array
#   ✔ Accepted
#   ✔ 4512/4512 cases passed (4 ms)
#   ✔ Your runtime beats 95.34 % of java submissions
#   ✔ Your memory usage beats 73.58 % of java submissions (47.2 MB)
# Submitting: java_solutions/2671.frequency-tracker.java
# - Downloading frequency-tracker
#   ✔ Accepted
#   ✔ 1118/1118 cases passed (48 ms)
#   ✔ Your runtime beats 14.6 % of java submissions
#   ✔ Your memory usage beats 5.11 % of java submissions (194.2 MB)
# Submitting: java_solutions/2672.number-of-adjacent-elements-with-the-same-color.java
# - Downloading number-of-adjacent-elements-with-the-same-color
#   ✔ Accepted
#   ✔ 183/183 cases passed (11 ms)
#   ✔ Your runtime beats 5.13 % of java submissions
#   ✔ Your memory usage beats 5.53 % of java submissions (208.6 MB)
# Submitting: java_solutions/2673.make-costs-of-paths-equal-in-a-binary-tree.java
# - Downloading make-costs-of-paths-equal-in-a-binary-tree
#   ✔ Accepted
#   ✔ 1565/1565 cases passed (9 ms)
#   ✔ Your runtime beats 22.47 % of java submissions
#   ✔ Your memory usage beats 100 % of java submissions (63.7 MB)
# Submitting: java_solutions/2678.number-of-senior-citizens.java
# - Downloading number-of-senior-citizens
#   ✔ Accepted
#   ✔ 303/303 cases passed (4 ms)
#   ✔ Your runtime beats 7.96 % of java submissions
#   ✔ Your memory usage beats 24.85 % of java submissions (44.5 MB)
# Submitting: java_solutions/2679.sum-in-a-matrix.java
# - Downloading sum-in-a-matrix
#   ✔ Accepted
#   ✔ 1057/1057 cases passed (32 ms)
#   ✔ Your runtime beats 11.96 % of java submissions
#   ✔ Your memory usage beats 9.71 % of java submissions (79.6 MB)
# Submitting: java_solutions/2680.maximum-or.java
# - Downloading maximum-or
#   ✔ Accepted
#   ✔ 1215/1215 cases passed (9 ms)
#   ✔ Your runtime beats 9.84 % of java submissions
#   ✔ Your memory usage beats 25.41 % of java submissions (93.7 MB)
# Submitting: java_solutions/2681.power-of-heroes.java
# - Downloading power-of-heroes
#   ✔ Accepted
#   ✔ 2584/2584 cases passed (31 ms)
#   ✔ Your runtime beats 3.7 % of java submissions
#   ✔ Your memory usage beats 96.3 % of java submissions (63.9 MB)
# Submitting: java_solutions/2682.find-the-losers-of-the-circular-game.java
# - Downloading find-the-losers-of-the-circular-game
#   ✔ Accepted
#   ✔ 1277/1277 cases passed (5 ms)
#   ✔ Your runtime beats 29.17 % of java submissions
#   ✔ Your memory usage beats 33.33 % of java submissions (46.5 MB)
# Submitting: java_solutions/2683.neighboring-bitwise-xor.java
# - Downloading neighboring-bitwise-xor
#   ✔ Accepted
#   ✔ 1425/1425 cases passed (9 ms)
#   ✔ Your runtime beats 13.95 % of java submissions
#   ✔ Your memory usage beats 60.46 % of java submissions (199.1 MB)
# Submitting: java_solutions/2684.maximum-number-of-moves-in-a-grid.java
# - Downloading maximum-number-of-moves-in-a-grid
#   ✔ Accepted
#   ✔ 814/814 cases passed (19 ms)
#   ✔ Your runtime beats 11.81 % of java submissions
#   ✔ Your memory usage beats 30.56 % of java submissions (66.5 MB)
# Submitting: java_solutions/2685.count-the-number-of-complete-components.java
# - Downloading count-the-number-of-complete-components
#   ✔ Accepted
#   ✔ 3356/3356 cases passed (9 ms)
#   ✔ Your runtime beats 82.27 % of java submissions
#   ✔ Your memory usage beats 42.68 % of java submissions (47.7 MB)
# Submitting: java_solutions/2696.minimum-string-length-after-removing-substrings.java
# - Downloading minimum-string-length-after-removing-substrings
#   ✔ Accepted
#   ✔ 1542/1542 cases passed (5 ms)
#   ✔ Your runtime beats 59.91 % of java submissions
#   ✔ Your memory usage beats 11.79 % of java submissions (45.5 MB)
# Submitting: java_solutions/2697.lexicographically-smallest-palindrome.java
# - Downloading lexicographically-smallest-palindrome
#   ✔ Accepted
#   ✔ 4519/4519 cases passed (10 ms)
#   ✔ Your runtime beats 16.42 % of java submissions
#   ✔ Your memory usage beats 7.64 % of java submissions (47.5 MB)
# Submitting: java_solutions/2698.find-the-punishment-number-of-an-integer.java
# - Downloading find-the-punishment-number-of-an-integer
#   ✔ Accepted
#   ✔ 216/216 cases passed (64 ms)
#   ✔ Your runtime beats 35.35 % of java submissions
#   ✔ Your memory usage beats 9.05 % of java submissions (46.6 MB)
# Submitting: java_solutions/2699.modify-graph-edge-weights.java
# - Downloading modify-graph-edge-weights
#   ✔ Accepted
#   ✔ 882/882 cases passed (1174 ms)
#   ✔ Your runtime beats 9.52 % of java submissions
#   ✔ Your memory usage beats 7.14 % of java submissions (60 MB)
# Submitting: java_solutions/2706.buy-two-chocolates.java
# - Downloading buy-two-chocolates
#   ✔ Accepted
#   ✔ 2003/2003 cases passed (6 ms)
#   ✔ Your runtime beats 0.87 % of java submissions
#   ✔ Your memory usage beats 91.51 % of java submissions (46.2 MB)
# Submitting: java_solutions/2707.extra-characters-in-a-string.java
# - Downloading extra-characters-in-a-string
#   ✔ Accepted
#   ✔ 2028/2028 cases passed (39 ms)
#   ✔ Your runtime beats 56.64 % of java submissions
#   ✔ Your memory usage beats 38.15 % of java submissions (47 MB)
# Submitting: java_solutions/2708.maximum-strength-of-a-group.java
# - Downloading maximum-strength-of-a-group
#   ✔ Accepted
#   ✔ 2012/2012 cases passed (3 ms)
#   ✔ Your runtime beats 75.32 % of java submissions
#   ✔ Your memory usage beats 43.67 % of java submissions (45.5 MB)
# Submitting: java_solutions/2709.greatest-common-divisor-traversal.java
# - Downloading greatest-common-divisor-traversal
#   ✔ Accepted
#   ✔ 929/929 cases passed (2000 ms)
#   ✔ Your runtime beats 5.61 % of java submissions
#   ✔ Your memory usage beats 38.32 % of java submissions (93.8 MB)
# Submitting: java_solutions/2710.remove-trailing-zeros-from-a-string.java
# - Downloading remove-trailing-zeros-from-a-string
#   ✔ Accepted
#   ✔ 756/756 cases passed (9 ms)
#   ✔ Your runtime beats 9.75 % of java submissions
#   ✔ Your memory usage beats 5.88 % of java submissions (47.4 MB)
# Submitting: java_solutions/2711.difference-of-number-of-distinct-values-on-diagonals.java
# - Downloading difference-of-number-of-distinct-values-on-diagonals
#   ✔ Accepted
#   ✔ 709/709 cases passed (25 ms)
#   ✔ Your runtime beats 12.77 % of java submissions
#   ✔ Your memory usage beats 34.04 % of java submissions (47.7 MB)
# Submitting: java_solutions/2712.minimum-cost-to-make-all-characters-equal.java
# - Downloading minimum-cost-to-make-all-characters-equal
#   ✔ Accepted
#   ✔ 1574/1574 cases passed (8 ms)
#   ✔ Your runtime beats 18.29 % of java submissions
#   ✔ Your memory usage beats 75.61 % of java submissions (47.7 MB)
# Submitting: java_solutions/2713.maximum-strictly-increasing-cells-in-a-matrix.java
# - Downloading maximum-strictly-increasing-cells-in-a-matrix
#   ✔ Accepted
#   ✔ 566/566 cases passed (168 ms)
#   ✔ Your runtime beats 62.5 % of java submissions
#   ✔ Your memory usage beats 87.5 % of java submissions (122.5 MB)
# Submitting: java_solutions/2716.minimize-string-length.java
# - Downloading minimize-string-length
#   ✔ Accepted
#   ✔ 5013/5013 cases passed (22 ms)
#   ✔ Your runtime beats 5.94 % of java submissions
#   ✔ Your memory usage beats 11.89 % of java submissions (47.4 MB)
# Submitting: java_solutions/2717.semi-ordered-permutation.java
# - Downloading semi-ordered-permutation
#   ✔ Accepted
#   ✔ 1977/1977 cases passed (2 ms)
#   ✔ Your runtime beats 6.6 % of java submissions
#   ✔ Your memory usage beats 53.77 % of java submissions (46.4 MB)
# Submitting: java_solutions/2718.sum-of-matrix-after-queries.java
# - Downloading sum-of-matrix-after-queries
#   ✔ Accepted
#   ✔ 2688/2688 cases passed (5 ms)
#   ✔ Your runtime beats 29.45 % of java submissions
#   ✔ Your memory usage beats 25.77 % of java submissions (113.6 MB)
# Submitting: java_solutions/2719.count-of-integers.java
# - Downloading count-of-integers
#   ✔ Accepted
#   ✔ 616/616 cases passed (391 ms)
#   ✔ Your runtime beats 5.14 % of java submissions
#   ✔ Your memory usage beats 5.71 % of java submissions (53.3 MB)
# Submitting: java_solutions/2729.check-if-the-number-is-fascinating.java
# - Downloading check-if-the-number-is-fascinating
#   ✔ Accepted
#   ✔ 900/900 cases passed (12 ms)
#   ✔ Your runtime beats 5.85 % of java submissions
#   ✔ Your memory usage beats 5.62 % of java submissions (49.2 MB)
# Submitting: java_solutions/2730.find-the-longest-semi-repetitive-substring.java
# - Downloading find-the-longest-semi-repetitive-substring
#   ✔ Accepted
#   ✔ 12264/12264 cases passed (7 ms)
#   ✔ Your runtime beats 9.3 % of java submissions
#   ✔ Your memory usage beats 68.22 % of java submissions (46.9 MB)
# Submitting: java_solutions/2731.movement-of-robots.java
# - Downloading movement-of-robots
#   ✔ Accepted
#   ✔ 2567/2567 cases passed (27 ms)
#   ✔ Your runtime beats 8.65 % of java submissions
#   ✔ Your memory usage beats 96.15 % of java submissions (71.9 MB)
# Submitting: java_solutions/2732.find-a-good-subset-of-the-matrix.java
# - Downloading find-a-good-subset-of-the-matrix
#   ✔ Accepted
#   ✔ 685/685 cases passed (88 ms)
#   ✔ Your runtime beats 20 % of java submissions
#   ✔ Your memory usage beats 46.67 % of java submissions (83.1 MB)
# Submitting: java_solutions/2733.neither-minimum-nor-maximum.java
# - Downloading neither-minimum-nor-maximum
#   ✔ Accepted
#   ✔ 9558/9558 cases passed (18 ms)
#   ✔ Your runtime beats 5.12 % of java submissions
#   ✔ Your memory usage beats 23.94 % of java submissions (47.5 MB)
# Submitting: java_solutions/2734.lexicographically-smallest-string-after-substring-operation.java
# - Downloading lexicographically-smallest-string-after-substring-operation
#   ✔ Accepted
#   ✔ 2241/2241 cases passed (13 ms)
#   ✔ Your runtime beats 15.79 % of java submissions
#   ✔ Your memory usage beats 5.92 % of java submissions (52.1 MB)
# Submitting: java_solutions/2735.collecting-chocolates.java
# - Downloading collecting-chocolates
#   ✔ Accepted
#   ✔ 2564/2564 cases passed (54 ms)
#   ✔ Your runtime beats 17.57 % of java submissions
#   ✔ Your memory usage beats 25.68 % of java submissions (46.9 MB)
# Submitting: java_solutions/2736.maximum-sum-queries.java
# - Downloading maximum-sum-queries
#   ✔ Accepted
#   ✔ 1415/1415 cases passed (332 ms)
#   ✔ Your runtime beats 6.45 % of java submissions
#   ✔ Your memory usage beats 8.06 % of java submissions (205 MB)
# Submitting: java_solutions/2739.total-distance-traveled.java
# - Downloading total-distance-traveled
#   ✔ Accepted
#   ✔ 10000/10000 cases passed (5 ms)
#   ✔ Your runtime beats 29.26 % of java submissions
#   ✔ Your memory usage beats 32.42 % of java submissions (46.1 MB)
# Submitting: java_solutions/2740.find-the-value-of-the-partition.java
# - Downloading find-the-value-of-the-partition
#   ✔ Accepted
#   ✔ 806/806 cases passed (33 ms)
#   ✔ Your runtime beats 1.46 % of java submissions
#   ✔ Your memory usage beats 99.27 % of java submissions (58 MB)
# Submitting: java_solutions/2741.special-permutations.java
# - Downloading special-permutations
#   ✔ Accepted
#   ✔ 590/590 cases passed (180 ms)
#   ✔ Your runtime beats 41.54 % of java submissions
#   ✔ Your memory usage beats 61.54 % of java submissions (49.8 MB)
# Submitting: java_solutions/2742.painting-the-walls.java
# - Downloading painting-the-walls
#   ✔ Accepted
#   ✔ 2558/2558 cases passed (89 ms)
#   ✔ Your runtime beats 7.54 % of java submissions
#   ✔ Your memory usage beats 24.58 % of java submissions (53.1 MB)
# Submitting: java_solutions/2744.find-maximum-number-of-string-pairs.java
# - Downloading find-maximum-number-of-string-pairs
#   ✔ Accepted
#   ✔ 659/659 cases passed (4 ms)
#   ✔ Your runtime beats 55.56 % of java submissions
#   ✔ Your memory usage beats 84.33 % of java submissions (44.7 MB)
# Submitting: java_solutions/2745.construct-the-longest-new-string.java
# - Downloading construct-the-longest-new-string
#   ✔ Accepted
#   ✔ 2003/2003 cases passed (1 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 85.06 % of java submissions (43 MB)
# Submitting: java_solutions/2746.decremental-string-concatenation.java
# - Downloading decremental-string-concatenation
#   ✔ Accepted
#   ✔ 1332/1332 cases passed (102 ms)
#   ✔ Your runtime beats 16.22 % of java submissions
#   ✔ Your memory usage beats 86.49 % of java submissions (47.7 MB)
# Submitting: java_solutions/2747.count-zero-request-servers.java
# - Downloading count-zero-request-servers
#   ✔ Accepted
#   ✔ 3129/3129 cases passed (41 ms)
#   ✔ Your runtime beats 65.57 % of java submissions
#   ✔ Your memory usage beats 65.57 % of java submissions (138.1 MB)
# Submitting: java_solutions/2748.number-of-beautiful-pairs.java
# - Downloading number-of-beautiful-pairs
#   ✔ Accepted
#   ✔ 3005/3005 cases passed (16 ms)
#   ✔ Your runtime beats 40.15 % of java submissions
#   ✔ Your memory usage beats 64.23 % of java submissions (46.4 MB)
# Submitting: java_solutions/2749.minimum-operations-to-make-the-integer-zero.java
# - Downloading minimum-operations-to-make-the-integer-zero
#   ✔ Accepted
#   ✔ 543/543 cases passed (1 ms)
#   ✔ Your runtime beats 91.35 % of java submissions
#   ✔ Your memory usage beats 25 % of java submissions (42.6 MB)
# Submitting: java_solutions/2750.ways-to-split-array-into-good-subarrays.java
# - Downloading ways-to-split-array-into-good-subarrays
#   ✔ Accepted
#   ✔ 553/553 cases passed (9 ms)
#   ✔ Your runtime beats 27.68 % of java submissions
#   ✔ Your memory usage beats 53.57 % of java submissions (184.7 MB)
# Submitting: java_solutions/2751.robot-collisions.java
# - Downloading robot-collisions
#   ✔ Accepted
#   ✔ 2433/2433 cases passed (178 ms)
#   ✔ Your runtime beats 5.03 % of java submissions
#   ✔ Your memory usage beats 99.94 % of java submissions (100.3 MB)
# Submitting: java_solutions/2760.longest-even-odd-subarray-with-threshold.java
# - Downloading longest-even-odd-subarray-with-threshold
#   ✔ Accepted
#   ✔ 6873/6873 cases passed (5 ms)
#   ✔ Your runtime beats 48.56 % of java submissions
#   ✔ Your memory usage beats 48.56 % of java submissions (46.9 MB)
# Submitting: java_solutions/2761.prime-pairs-with-target-sum.java
# - Downloading prime-pairs-with-target-sum
#   ✔ Accepted
#   ✔ 554/554 cases passed (200 ms)
#   ✔ Your runtime beats 44.94 % of java submissions
#   ✔ Your memory usage beats 19.85 % of java submissions (77.1 MB)
# Submitting: java_solutions/2762.continuous-subarrays.java
# - Downloading continuous-subarrays
#   ✔ Accepted
#   ✔ 2139/2139 cases passed (48 ms)
#   ✔ Your runtime beats 13.57 % of java submissions
#   ✔ Your memory usage beats 85.93 % of java submissions (84.1 MB)
# Submitting: java_solutions/2763.sum-of-imbalance-numbers-of-all-subarrays.java
# - Downloading sum-of-imbalance-numbers-of-all-subarrays
#   ✔ Accepted
#   ✔ 1303/1303 cases passed (50 ms)
#   ✔ Your runtime beats 47.06 % of java submissions
#   ✔ Your memory usage beats 8.82 % of java submissions (47.4 MB)
# Submitting: java_solutions/2765.longest-alternating-subarray.java
# - Downloading longest-alternating-subarray
#   ✔ Accepted
#   ✔ 2880/2880 cases passed (3 ms)
#   ✔ Your runtime beats 6.1 % of java submissions
#   ✔ Your memory usage beats 10.8 % of java submissions (46.6 MB)
# Submitting: java_solutions/2766.relocate-marbles.java
# - Downloading relocate-marbles
#   ✔ Accepted
#   ✔ 2129/2129 cases passed (74 ms)
#   ✔ Your runtime beats 16.87 % of java submissions
#   ✔ Your memory usage beats 53.01 % of java submissions (101 MB)
# Submitting: java_solutions/2767.partition-string-into-minimum-beautiful-substrings.java
# - Downloading partition-string-into-minimum-beautiful-substrings
#   ✔ Accepted
#   ✔ 561/561 cases passed (5 ms)
#   ✔ Your runtime beats 38.39 % of java submissions
#   ✔ Your memory usage beats 60.71 % of java submissions (44.9 MB)
# Submitting: java_solutions/2768.number-of-black-blocks.java
# - Downloading number-of-black-blocks
#   ✔ Accepted
#   ✔ 2145/2145 cases passed (169 ms)
#   ✔ Your runtime beats 42.01 % of java submissions
#   ✔ Your memory usage beats 32.88 % of java submissions (84.6 MB)
# Submitting: java_solutions/2769.find-the-maximum-achievable-number.java
# - Downloading find-the-maximum-achievable-number
#   ✔ Accepted
#   ✔ 2502/2502 cases passed (1 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 46.91 % of java submissions (43.3 MB)
# Submitting: java_solutions/2770.maximum-number-of-jumps-to-reach-the-last-index.java
# - Downloading maximum-number-of-jumps-to-reach-the-last-index
#   ✔ Accepted
#   ✔ 2639/2639 cases passed (20 ms)
#   ✔ Your runtime beats 29.56 % of java submissions
#   ✔ Your memory usage beats 98.74 % of java submissions (46.6 MB)

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-05-05 10:51:20
