# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME_2')
    user_cookie = userdata.get('LEETCODE_TOKEN_2')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME_2'] = user_name
    os.environ['LEETCODE_TOKEN_2'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME_2" "$LEETCODE_TOKEN_2" | leetcode user -c

# %%
# %%bash
#
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v kotlin_solutions_1/*.kt | sed -n '701,800p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 7
# done
# Out:
# Submitting: kotlin_solutions_1/2038.remove-colored-pieces-if-both-neighbors-are-the-same-color.kt
# - Downloading problems
# - Downloading remove-colored-pieces-if-both-neighbors-are-the-same-color
#   ✔ Accepted
#   ✔ 84/84 cases passed (58 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2042.check-if-numbers-are-ascending-in-a-sentence.kt
# - Downloading check-if-numbers-are-ascending-in-a-sentence
#   ✔ Accepted
#   ✔ 98/98 cases passed (16 ms)
#   ✔ Your runtime beats 14.29 % of kotlin submissions
#   ✔ Your memory usage beats 28.57 % of kotlin submissions (42.9 MB)
# Submitting: kotlin_solutions_1/2043.simple-bank-system.kt
# - Downloading simple-bank-system
#   ✔ Accepted
#   ✔ 23/23 cases passed (139 ms)
#   ✔ Your runtime beats 36.84 % of kotlin submissions
#   ✔ Your memory usage beats 76.32 % of kotlin submissions (112.8 MB)
# Submitting: kotlin_solutions_1/2044.count-number-of-maximum-bitwise-or-subsets.kt
# - Downloading count-number-of-maximum-bitwise-or-subsets
#   ✔ Accepted
#   ✔ 111/111 cases passed (181 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (49.1 MB)
# Submitting: kotlin_solutions_1/2045.second-minimum-time-to-reach-destination.kt
# - Downloading second-minimum-time-to-reach-destination
#   ✔ Accepted
#   ✔ 77/77 cases passed (157 ms)
#   ✔ Your runtime beats 66.67 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (76.8 MB)
# Submitting: kotlin_solutions_1/2047.number-of-valid-words-in-a-sentence.kt
# - Downloading number-of-valid-words-in-a-sentence
#   ✔ Accepted
#   ✔ 244/244 cases passed (71 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2048.next-greater-numerically-balanced-number.kt
# - Downloading next-greater-numerically-balanced-number
#   ✔ Accepted
#   ✔ 145/145 cases passed (440 ms)
#   ✔ Your runtime beats 12.5 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (50.9 MB)
# Submitting: kotlin_solutions_1/2053.kth-distinct-string-in-an-array.kt
# - Downloading kth-distinct-string-in-an-array
#   ✔ Accepted
#   ✔ 66/66 cases passed (20 ms)
#   ✔ Your runtime beats 12.5 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (47.9 MB)
# Submitting: kotlin_solutions_1/2057.smallest-index-with-equal-value.kt
# - Downloading smallest-index-with-equal-value
#   ✔ Accepted
#   ✔ 663/663 cases passed (15 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2058.find-the-minimum-and-maximum-number-of-nodes-between-critical-points.kt
# - Downloading find-the-minimum-and-maximum-number-of-nodes-between-critical-points
#   ✔ Accepted
#   ✔ 139/139 cases passed (134 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2059.minimum-operations-to-convert-number.kt
# - Downloading minimum-operations-to-convert-number
#   ✔ Accepted
#   ✔ 60/60 cases passed (277 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (53.6 MB)
# Submitting: kotlin_solutions_1/2060.check-if-an-original-string-exists-given-two-encoded-strings.kt
# - Downloading check-if-an-original-string-exists-given-two-encoded-strings
#   ✔ Accepted
#   ✔ 215/215 cases passed (313 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2062.count-vowel-substrings-of-a-string.kt
# - Downloading count-vowel-substrings-of-a-string
#   ✔ Accepted
#   ✔ 88/88 cases passed (47 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2063.vowels-of-all-substrings.kt
# - Downloading vowels-of-all-substrings
#   ✔ Accepted
#   ✔ 51/51 cases passed (47 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (49.3 MB)
# Submitting: kotlin_solutions_1/2064.minimized-maximum-of-products-distributed-to-any-store.kt
# - Downloading minimized-maximum-of-products-distributed-to-any-store
#   ✔ Accepted
#   ✔ 220/220 cases passed (40 ms)
#   ✔ Your runtime beats 45.45 % of kotlin submissions
#   ✔ Your memory usage beats 18.18 % of kotlin submissions (72.4 MB)
# Submitting: kotlin_solutions_1/2065.maximum-path-quality-of-a-graph.kt
# - Downloading maximum-path-quality-of-a-graph
#   ✔ Accepted
#   ✔ 62/62 cases passed (102 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (55 MB)
# Submitting: kotlin_solutions_1/2068.check-whether-two-strings-are-almost-equivalent.kt
# - Downloading check-whether-two-strings-are-almost-equivalent
#   ✔ Accepted
#   ✔ 196/196 cases passed (10 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (41.2 MB)
# Submitting: kotlin_solutions_1/2070.most-beautiful-item-for-each-query.kt
# - Downloading most-beautiful-item-for-each-query
#   ✔ Accepted
#   ✔ 35/35 cases passed (177 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2071.maximum-number-of-tasks-you-can-assign.kt
# - Downloading maximum-number-of-tasks-you-can-assign
#   ✔ Accepted
#   ✔ 49/49 cases passed (209 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/2073.time-needed-to-buy-tickets.kt
# - Downloading time-needed-to-buy-tickets
#   ✔ Accepted
#   ✔ 65/65 cases passed (13 ms)
#   ✔ Your runtime beats 26.92 % of kotlin submissions
#   ✔ Your memory usage beats 23.08 % of kotlin submissions (45.5 MB)
# Submitting: kotlin_solutions_1/2074.reverse-nodes-in-even-length-groups.kt
# - Downloading reverse-nodes-in-even-length-groups
#   ✔ Accepted
#   ✔ 165/165 cases passed (142 ms)
#   ✔ Your runtime beats 10 % of kotlin submissions
#   ✔ Your memory usage beats 80 % of kotlin submissions (79.7 MB)
# Submitting: kotlin_solutions_1/2075.decode-the-slanted-ciphertext.kt
# - Downloading decode-the-slanted-ciphertext
#   ✔ Accepted
#   ✔ 40/40 cases passed (286 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2076.process-restricted-friend-requests.kt
# - Downloading process-restricted-friend-requests
#   ✔ Accepted
#   ✔ 49/49 cases passed (484 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2079.watering-plants.kt
# - Downloading watering-plants
#   ✔ Accepted
#   ✔ 40/40 cases passed (18 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2080.range-frequency-queries.kt
# - Downloading range-frequency-queries
#   ✔ Accepted
#   ✔ 20/20 cases passed (163 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 40 % of kotlin submissions (184.8 MB)
# Submitting: kotlin_solutions_1/2081.sum-of-k-mirror-numbers.kt
# - Downloading sum-of-k-mirror-numbers
#   ✔ Accepted
#   ✔ 97/97 cases passed (460 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2085.count-common-words-with-one-occurrence.kt
# - Downloading count-common-words-with-one-occurrence
#   ✔ Accepted
#   ✔ 61/61 cases passed (21 ms)
#   ✔ Your runtime beats 10 % of kotlin submissions
#   ✔ Your memory usage beats 40 % of kotlin submissions (46.5 MB)
# Submitting: kotlin_solutions_1/2087.minimum-cost-homecoming-of-a-robot-in-a-grid.kt
# - Downloading minimum-cost-homecoming-of-a-robot-in-a-grid
#   ✔ Accepted
#   ✔ 69/69 cases passed (13 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2088.count_fertile_pyramids_in_a_land.kt
# - Downloading count-fertile-pyramids-in-a-land
#   ✔ Accepted
#   ✔ 49/49 cases passed (47 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2089.find_target_indices_after_sorting_array.kt
# - Downloading find-target-indices-after-sorting-array
#   ✔ Accepted
#   ✔ 216/216 cases passed (1 ms)
#   ✔ Your runtime beats 95.45 % of kotlin submissions
#   ✔ Your memory usage beats 95.45 % of kotlin submissions (43.4 MB)
# Submitting: kotlin_solutions_1/2090.k_radius_subarray_averages.kt
# - Downloading k-radius-subarray-averages
#   ✔ Accepted
#   ✔ 41/41 cases passed (20 ms)
#   ✔ Your runtime beats 11.76 % of kotlin submissions
#   ✔ Your memory usage beats 41.18 % of kotlin submissions (67.5 MB)
# Submitting: kotlin_solutions_1/2091.removing_minimum_and_maximum_from_array.kt
# - Downloading removing-minimum-and-maximum-from-array
#   ✔ Accepted
#   ✔ 62/62 cases passed (19 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/2094.finding_3_digit_even_numbers.kt
# - Downloading finding-3-digit-even-numbers
#   ✔ Accepted
#   ✔ 79/79 cases passed (25 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (48.1 MB)
# Submitting: kotlin_solutions_1/2095.delete-the-middle-node-of-a-linked-list.kt
# - Downloading delete-the-middle-node-of-a-linked-list
#   ✔ Accepted
#   ✔ 70/70 cases passed (65 ms)
#   ✔ Your runtime beats 6.41 % of kotlin submissions
#   ✔ Your memory usage beats 14.1 % of kotlin submissions (70 MB)
# Submitting: kotlin_solutions_1/2095.delete_the_middle_node_of_a_linked_list.kt
#   ✔ Accepted
#   ✔ 70/70 cases passed (22 ms)
#   ✔ Your runtime beats 6.41 % of kotlin submissions
#   ✔ Your memory usage beats 11.54 % of kotlin submissions (70.9 MB)
# Submitting: kotlin_solutions_1/2099.find_subsequence_of_length_k_with_the_largest_sum.kt
# - Downloading find-subsequence-of-length-k-with-the-largest-sum
#   ✔ Accepted
#   ✔ 49/49 cases passed (34 ms)
#   ✔ Your runtime beats 28.57 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (48.8 MB)
# Submitting: kotlin_solutions_1/2100.find-good-days-to-rob-the-bank.kt
# - Downloading find-good-days-to-rob-the-bank
#   ✔ Accepted
#   ✔ 144/144 cases passed (30 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (66.6 MB)
# Submitting: kotlin_solutions_1/2102.sequentially-ordinal-rank-tracker.kt
# - Downloading sequentially-ordinal-rank-tracker
#   ✔ Accepted
#   ✔ 81/81 cases passed (293 ms)
#   ✔ Your runtime beats 40 % of kotlin submissions
#   ✔ Your memory usage beats 60 % of kotlin submissions (102.7 MB)
# Submitting: kotlin_solutions_1/2103.rings-and-rods.kt
# - Downloading rings-and-rods
#   ✔ Accepted
#   ✔ 66/66 cases passed (16 ms)
#   ✔ Your runtime beats 7.14 % of kotlin submissions
#   ✔ Your memory usage beats 7.14 % of kotlin submissions (43.4 MB)
# Submitting: kotlin_solutions_1/2104.sum-of-subarray-ranges.kt
# - Downloading sum-of-subarray-ranges
#   ✔ Accepted
#   ✔ 71/71 cases passed (305 ms)
#   ✔ Your runtime beats 10 % of kotlin submissions
#   ✔ Your memory usage beats 10 % of kotlin submissions (51.8 MB)
# Submitting: kotlin_solutions_1/2105.watering-plants-ii.kt
# - Downloading watering-plants-ii
#   ✔ Accepted
#   ✔ 57/57 cases passed (35 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2106.maximum-fruits-harvested-after-at-most-k-steps.kt
# - Downloading maximum-fruits-harvested-after-at-most-k-steps
#   ✔ Accepted
#   ✔ 202/202 cases passed (98 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2108.find-first-palindromic-string-in-the-array.kt
# - Downloading find-first-palindromic-string-in-the-array
#   ✔ Accepted
#   ✔ 266/266 cases passed (13 ms)
#   ✔ Your runtime beats 15.38 % of kotlin submissions
#   ✔ Your memory usage beats 7.69 % of kotlin submissions (50.3 MB)
# Submitting: kotlin_solutions_1/2109.adding-spaces-to-a-string.kt
# - Downloading adding-spaces-to-a-string
#   ✔ Accepted
#   ✔ 66/66 cases passed (80 ms)
#   ✔ Your runtime beats 14.29 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (89.9 MB)
# Submitting: kotlin_solutions_1/2110.number-of-smooth-descent-periods-of-a-stock.kt
# - Downloading number-of-smooth-descent-periods-of-a-stock
#   ✔ Accepted
#   ✔ 168/168 cases passed (37 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (66.9 MB)
# Submitting: kotlin_solutions_1/2111.minimum-operations-to-make-the-array-k-increasing.kt
# - Downloading minimum-operations-to-make-the-array-k-increasing
#   ✔ Accepted
#   ✔ 90/90 cases passed (96 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2114.maximum-number-of-words-found-in-sentences.kt
# - Downloading maximum-number-of-words-found-in-sentences
#   ✔ Accepted
#   ✔ 90/90 cases passed (32 ms)
#   ✔ Your runtime beats 12.5 % of kotlin submissions
#   ✔ Your memory usage beats 6.25 % of kotlin submissions (48.8 MB)
# Submitting: kotlin_solutions_1/2116.check-if-a-parentheses-string-can-be-valid.kt
# - Downloading check-if-a-parentheses-string-can-be-valid
#   ✔ Accepted
#   ✔ 260/260 cases passed (38 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2117.abbreviating-the-product-of-a-range.kt
# - Downloading abbreviating-the-product-of-a-range
#   ✔ Accepted
#   ✔ 292/292 cases passed (59 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2119.a-number-after-a-double-reversal.kt
# - Downloading a-number-after-a-double-reversal
#   ✔ Accepted
#   ✔ 129/129 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/2120.execution-of-all-suffix-instructions-staying-in-a-grid.kt
# - Downloading execution-of-all-suffix-instructions-staying-in-a-grid
#   ✔ Accepted
#   ✔ 113/113 cases passed (182 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2121.intervals-between-identical-elements.kt
# - Downloading intervals-between-identical-elements
#   ✔ Accepted
#   ✔ 61/61 cases passed (24 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (69.7 MB)
# Submitting: kotlin_solutions_1/2122.recover-the-original-array.kt
# - Downloading recover-the-original-array
#   ✔ Accepted
#   ✔ 110/110 cases passed (89 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (52.1 MB)
# Submitting: kotlin_solutions_1/2124.check-if-all-as-appears-before-all-bs.kt
# - Downloading check-if-all-as-appears-before-all-bs
#   ✔ Accepted
#   ✔ 216/216 cases passed (7 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (42.2 MB)
# Submitting: kotlin_solutions_1/2125.number_of_laser_beams_in_a_bank.kt
# - Downloading number-of-laser-beams-in-a-bank
#   ✔ Accepted
#   ✔ 147/147 cases passed (34 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (50.7 MB)
# Submitting: kotlin_solutions_1/2126.destroying_asteroids.kt
# - Downloading destroying-asteroids
#   ✔ Accepted
#   ✔ 75/75 cases passed (201 ms)
#   ✔ Your runtime beats 13.33 % of kotlin submissions
#   ✔ Your memory usage beats 60 % of kotlin submissions (65.7 MB)
# Submitting: kotlin_solutions_1/2129.capitalize_the_title.kt
# - Downloading capitalize-the-title
#   ✔ Accepted
#   ✔ 200/200 cases passed (18 ms)
#   ✔ Your runtime beats 22.22 % of kotlin submissions
#   ✔ Your memory usage beats 44.44 % of kotlin submissions (45.7 MB)
# Submitting: kotlin_solutions_1/2130.maximum_twin_sum_of_a_linked_list.kt
# - Downloading maximum-twin-sum-of-a-linked-list
#   ✔ Accepted
#   ✔ 46/46 cases passed (47 ms)
#   ✔ Your runtime beats 5.45 % of kotlin submissions
#   ✔ Your memory usage beats 16.36 % of kotlin submissions (69.2 MB)
# Submitting: kotlin_solutions_1/2131.longest_palindrome_by_concatenating_two_letter_words.kt
# - Downloading longest-palindrome-by-concatenating-two-letter-words
#   ✔ Accepted
#   ✔ 120/120 cases passed (42 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 55.56 % of kotlin submissions (68.4 MB)
# Submitting: kotlin_solutions_1/2132.stamping_the_grid.kt
# - Downloading stamping-the-grid
#   ✔ Accepted
#   ✔ 77/77 cases passed (69 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2133.check_if_every_row_and_column_contains_all_numbers.kt
# - Downloading check-if-every-row-and-column-contains-all-numbers
#   ✔ Accepted
#   ✔ 227/227 cases passed (55 ms)
#   ✔ Your runtime beats 13.33 % of kotlin submissions
#   ✔ Your memory usage beats 40 % of kotlin submissions (54.6 MB)
# Submitting: kotlin_solutions_1/2134.minimum_swaps_to_group_all_1s_together_ii.kt
# - Downloading minimum-swaps-to-group-all-1s-together-ii
#   ✔ Accepted
#   ✔ 63/63 cases passed (23 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (61.1 MB)
# Submitting: kotlin_solutions_1/2136.earliest-possible-day-of-full-bloom.kt
# - Downloading earliest-possible-day-of-full-bloom
#   ✔ Accepted
#   ✔ 185/185 cases passed (107 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (69.5 MB)
# Submitting: kotlin_solutions_1/2138.divide-a-string-into-groups-of-size-k.kt
# - Downloading divide-a-string-into-groups-of-size-k
#   ✔ Accepted
#   ✔ 157/157 cases passed (9 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
#   ✔ Your memory usage beats 75 % of kotlin submissions (42.9 MB)
# Submitting: kotlin_solutions_1/2139.minimum-moves-to-reach-target-score.kt
# - Downloading minimum-moves-to-reach-target-score
#   ✔ Accepted
#   ✔ 145/145 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 62.5 % of kotlin submissions (40.2 MB)
# Submitting: kotlin_solutions_1/2140.solving-questions-with-brainpower.kt
# - Downloading solving-questions-with-brainpower
#   ✔ Accepted
#   ✔ 54/54 cases passed (14 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 76.19 % of kotlin submissions (120.1 MB)
# Submitting: kotlin_solutions_1/2141.maximum-running-time-of-n-computers.kt
# - Downloading maximum-running-time-of-n-computers
#   ✔ Accepted
#   ✔ 52/52 cases passed (21 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (60.9 MB)
# Submitting: kotlin_solutions_1/2144.minimum-cost-of-buying-candies-with-discount.kt
# - Downloading minimum-cost-of-buying-candies-with-discount
#   ✔ Accepted
#   ✔ 192/192 cases passed (23 ms)
#   ✔ Your runtime beats 10.53 % of kotlin submissions
#   ✔ Your memory usage beats 36.84 % of kotlin submissions (46.5 MB)
# Submitting: kotlin_solutions_1/2145.count-the-hidden-sequences.kt
# - Downloading count-the-hidden-sequences
#   ✔ Accepted
#   ✔ 86/86 cases passed (40 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 16.67 % of kotlin submissions (70.2 MB)
# Submitting: kotlin_solutions_1/2147.number-of-ways-to-divide-a-long-corridor.kt
# - Downloading number-of-ways-to-divide-a-long-corridor
#   ✔ Accepted
#   ✔ 248/248 cases passed (102 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2148.count-elements-with-strictly-smaller-and-greater-elements.kt
# - Downloading count-elements-with-strictly-smaller-and-greater-elements
#   ✔ Accepted
#   ✔ 127/127 cases passed (15 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2149.rearrange-array-elements-by-sign.kt
# - Downloading rearrange-array-elements-by-sign
#   ✔ Accepted
#   ✔ 133/133 cases passed (15 ms)
#   ✔ Your runtime beats 20.69 % of kotlin submissions
#   ✔ Your memory usage beats 24.14 % of kotlin submissions (90.4 MB)
# Submitting: kotlin_solutions_1/2150.find-all-lonely-numbers-in-the-array.kt
# - Downloading find-all-lonely-numbers-in-the-array
#   ✔ Accepted
#   ✔ 75/75 cases passed (157 ms)
#   ✔ Your runtime beats 14.29 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (82.6 MB)
# Submitting: kotlin_solutions_1/2151.maximum-good-people-based-on-statements.kt
# - Downloading maximum-good-people-based-on-statements
#   ✔ Accepted
#   ✔ 91/91 cases passed (72 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2154.keep-multiplying-found-values-by-two.kt
# - Downloading keep-multiplying-found-values-by-two
#   ✔ Accepted
#   ✔ 82/82 cases passed (22 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 16.67 % of kotlin submissions (47.5 MB)
# Submitting: kotlin_solutions_1/2155.all-divisions-with-the-highest-score-of-a-binary-array.kt
# - Downloading all-divisions-with-the-highest-score-of-a-binary-array
#   ✔ Accepted
#   ✔ 58/58 cases passed (106 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (76.3 MB)
# Submitting: kotlin_solutions_1/2156.find-substring-with-given-hash-value.kt
# - Downloading find-substring-with-given-hash-value
#   ✔ Accepted
#   ✔ 90/90 cases passed (33 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2160.minimum-sum-of-four-digit-number-after-splitting-digits.kt
# - Downloading minimum-sum-of-four-digit-number-after-splitting-digits
#   ✔ Accepted
#   ✔ 99/99 cases passed (14 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 22.22 % of kotlin submissions (45.2 MB)
# Submitting: kotlin_solutions_1/2161.partition-array-according-to-given-pivot.kt
# - Downloading partition-array-according-to-given-pivot
#   ✔ Accepted
#   ✔ 44/44 cases passed (30 ms)
#   ✔ Your runtime beats 26.92 % of kotlin submissions
#   ✔ Your memory usage beats 84.62 % of kotlin submissions (65.3 MB)
# Submitting: kotlin_solutions_1/2162.minimum-cost-to-set-cooking-time.kt
# - Downloading minimum-cost-to-set-cooking-time
#   ✔ Accepted
#   ✔ 239/239 cases passed (26 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2163.minimum-difference-in-sums-after-removal-of-elements.kt
# - Downloading minimum-difference-in-sums-after-removal-of-elements
#   ✔ Accepted
#   ✔ 110/110 cases passed (166 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/2164.sort-even-and-odd-indices-independently.kt
# - Downloading sort-even-and-odd-indices-independently
#   ✔ Accepted
#   ✔ 218/218 cases passed (24 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (46.3 MB)
# Submitting: kotlin_solutions_1/2165.smallest-value-of-the-rearranged-number.kt
# - Downloading smallest-value-of-the-rearranged-number
#   ✔ Accepted
#   ✔ 413/413 cases passed (29 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2167.minimum-time-to-remove-all-cars-containing-illegal-goods.kt
# - Downloading minimum-time-to-remove-all-cars-containing-illegal-goods
#   ✔ Accepted
#   ✔ 89/89 cases passed (91 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (56.1 MB)
# Submitting: kotlin_solutions_1/2169.count-operations-to-obtain-zero.kt
# - Downloading count-operations-to-obtain-zero
#   ✔ Accepted
#   ✔ 161/161 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (40.2 MB)
# Submitting: kotlin_solutions_1/2170.minimum-operations-to-make-the-array-alternating.kt
# - Downloading minimum-operations-to-make-the-array-alternating
#   ✔ Accepted
#   ✔ 153/153 cases passed (200 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2171.removing-minimum-number-of-magic-beans.kt
# - Downloading removing-minimum-number-of-magic-beans
#   ✔ Accepted
#   ✔ 64/64 cases passed (70 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2176.count-equal-and-divisible-pairs-in-an-array.kt
# - Downloading count-equal-and-divisible-pairs-in-an-array
#   ✔ Accepted
#   ✔ 238/238 cases passed (28 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2177.find-three-consecutive-integers-that-sum-to-a-given-number.kt
# - Downloading find-three-consecutive-integers-that-sum-to-a-given-number
#   ✔ Accepted
#   ✔ 379/379 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/2178.maximum-split-of-positive-even-integers.kt
# - Downloading maximum-split-of-positive-even-integers
#   ✔ Accepted
#   ✔ 56/56 cases passed (25 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2179.count-good-triplets-in-an-array.kt
# - Downloading count-good-triplets-in-an-array
#   ✔ Accepted
#   ✔ 148/148 cases passed (530 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2180.count-integers-with-even-digit-sum.kt
# - Downloading count-integers-with-even-digit-sum
#   ✔ Accepted
#   ✔ 71/71 cases passed (10 ms)
#   ✔ Your runtime beats 10 % of kotlin submissions
#   ✔ Your memory usage beats 10 % of kotlin submissions (41.9 MB)
# Submitting: kotlin_solutions_1/2181.merge-nodes-in-between-zeros.kt
# - Downloading merge-nodes-in-between-zeros
#   ✔ Accepted
#   ✔ 39/39 cases passed (146 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (89.6 MB)
# Submitting: kotlin_solutions_1/2182.construct-string-with-repeat-limit.kt
# - Downloading construct-string-with-repeat-limit
#   ✔ Accepted
#   ✔ 150/150 cases passed (53 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 75 % of kotlin submissions (48.2 MB)
# Submitting: kotlin_solutions_1/2185.counting-words-with-a-given-prefix.kt
# - Downloading counting-words-with-a-given-prefix
#   ✔ Accepted
#   ✔ 95/95 cases passed (6 ms)
#   ✔ Your runtime beats 60 % of kotlin submissions
#   ✔ Your memory usage beats 40 % of kotlin submissions (44.1 MB)
# Submitting: kotlin_solutions_1/2187.minimum-time-to-complete-trips.kt
# - Downloading minimum-time-to-complete-trips
#   ✔ Accepted
#   ✔ 124/124 cases passed (59 ms)
#   ✔ Your runtime beats 73.33 % of kotlin submissions
#   ✔ Your memory usage beats 93.33 % of kotlin submissions (62.3 MB)
# Submitting: kotlin_solutions_1/2190.most-frequent-number-following-key-in-an-array.kt
# - Downloading most-frequent-number-following-key-in-an-array
#   ✔ Accepted
#   ✔ 101/101 cases passed (32 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (49.9 MB)
# Submitting: kotlin_solutions_1/2191.sort-the-jumbled-numbers.kt
# - Downloading sort-the-jumbled-numbers
#   ✘ Time Limit Exceeded
#   ✘ 65/68 cases passed (N/A)
#   ✘ Testcase: [4,0,6,7,9,3,2,8,1,5]
# ' +
#   '[902819004,865027171,929189924,780164882,628079903,540626870,404371843,974878036,402308463,247529323,585736771,443387194,851261175,218583078,718291490,840429777,767125878,294791079,183984821,360736604,543811665,311849412,594618457,734957540,783192567,288977026,926277941,731175931,741580327,843124271,815193115,196804000,396283828,992843785,902468161,24807611,516988866,889246945,350324171,204273964,695982510,359024900,611889166,686387955,146778792,311397708,699005820,11541795,390858932,106023777,360631029,929387797,596809653,128664551,579798709,319261911,52095425,383538770,908619686,46438673,95032561,391675329,571086103,153431090,636748053,874298362,143153492,135416394,977280883,297922688,803020204,219031043,914061187,68081164,596762320,692709138,936497679,327979985,23196765,177058344,739534754,619178875,474238849,525337297,385149686,168957564,136950306,17779258,527405620,581363904,707010688,386100652,50110257,125994694,997211644,900086739,901638614,874356587,446512806,87387786,161203015,660445517,183481912,945500424,448715600,320994730,279019150,796278864,772389435,604836202,321465649,443013787,958236929,420252265,717671842,559553957,28570442,796749046,278469046,730188669,889906652,587642853,23308612,673118172,204950336,230308168,583871099,154789225,994570340,92310024,442125180,433211876,696979694,115888657,757128051,689461924,297807071,460946922,978418656,436111143,213911003,408766575,176414502,656227727,149442799,47679394,487755176,560635172,356185725,411311844,613605020,624118555,802475417,77523535,208537141,270687244,875856408,209438137,857784601,159352593,201610482,128566578,268106060,895838647,277686829,12510655,63814037,236918037,480119380,902675277,569316701,209544530,806606917,700094736,668371580,476495503,110777631,908028424,87438372,111242899,273173173,980167071,193476712,194306231,958622748,533950352,439897991,454418069,329136611,517823113,985843578,434737369,371786491,381567426,635474283,107969563,608324165,433192992,801886473,450958763,44938818,541522549,66467575,22349971,833652364,737237699,44729131,467091514,57669494,128849183,699023934,625965777,375712455,52958952,594127562,321395628,407077628,897887376,292780002,370110164,361829824,913868909,203439672,337370993,255990573,311036027,305548000,95684193,139748645,16058220,164528478,869221659,510773415,507779817,332967843,929602610,820877658,579813060,344670823,918781780,873471589,181083637,948853849,665117984,64375417,343737549,270455084,21243239,107022913,25202127,122573895,650767279,337352902,336908562,748636621,222389982,667944357,219442482,456436786,547092354,640857059,632444471,249351656,57524823,649159342,929626377,983605928,195267436,271800856,115047996,234971417,840622400,333176856,158951729,614045124,8853626,305062420,402279393,361778759,780504498,640241704,419923396,698005311,720604799,930304358,314874079,257829915,911054160,592721232,746070363,800121106,17895804,532688696,475018654,406446881,596047212,766940582,615356977,621965080,41412163,435329087,905630016,374859826,403194002,655032335,501190856,752462206,68539285,785080556,801644409,468092303,18960346,747271266,616200140,92649750,910095322,8340584,930752132,756365548,138903547,207357813,480860098,87563986,388795871,753502156,631889431,835157737,407497186,17890354,783224926,791058355,655064779,72993673,158061036,650289430,831561430,614309525,364521409,79623182,221582957,31566602,9538392,118072808,740649424,362702291,690841289,427173417,984853023,90371275,741613269,186871664,749911797,236661745,801133286,712316361,713122918,841177092,631490047,645633343,748963232,302784597,444215003,491029490,343200137,655844880,406455377,995626453,892040587,96431627,233682649,912066797,262713583,245098051,808214063,88836826,77984485,226424891,677836913,91310352,607278230,161236500,173817452,410876095,570718706,215752816,533683130,721270554,229992311,211245388,78886935,501854691,641999480,64046310,199572231,243017598,384304098,943155152,117740776,85246091,165327852,237415307,706585060,76212640,739543259,743968247,8 ...
#   ✘ Answer:
#   ✘ Expected Answer: [1110060,68934,111164503,50268,152844,11153160,106309,105407,75260,1179364,850071,1891639,111891596,897065,1897269,1821909,829431,111878545,1610840,11681902,1686068,1689212,11669896,1662188,11654577,601133,601284,11609528,1692235,1694201,11626293,111624453,11638594,639512,1639992,1677098,674677,641857,1641299,643887,583925,11583473,1587726,111521120,11528381,525631,537674,11572636,11541795,545255,11015749,1083978,111068687,1055206,11054172,1022448,111042783,916836,913250,111917682,111989630,1987944,968951,111959044,1953538,11957057,111907853,1998369,1995634,1936420,11932342,933405,111937440,1934466,1971887,11971349,1216942,1212437,262383,111264670,11251816,111250861,254128,11204842,204724,1296683,111297804,294419,1236236,111235649,233146,11237663,11273417,111242899,315481,1317240,111381921,111385229,361787,1360534,1367191,11351669,11358623,352196,308713,303737,11307971,11395099,1339412,11337496,1343202,1712629,11712042,783088,111784442,11762014,759924,1793690,111728686,111722245,738716,736616,735492,1777044,416088,111414402,11488160,485670,111462456,11458017,452378,11457954,1454087,1498778,495696,111425906,1476271,11441813,111441547,11441000,118116665,118182291,118150780,18192132,18132734,8176111,8179930,8179391,18886569,8880986,18889193,118883561,18887903,118866202,118863120,18863939,18851776,8853626,8854411,118828659,18822184,8831083,18870578,18846282,18840176,18665777,118605621,118698394,118695635,118631510,18631468,8565204,18536334,18548738,8080352,18065355,18058949,8096820,118028681,8028984,118071598,118072808,118049733,8918632,18918089,118910172,118919960,8919216,118917100,118985091,118982318,18983336,18968259,18960346,118281760,118280216,118269510,18267183,18250081,8202248,118204994,118221024,18223604,8224404,118234518,8246678,18247635,118389907,8362937,118364389,8329022,8322628,118337935,8334229,18371666,8340584,8716065,18712471,8759377,8754508,18721320,118723652,118727542,118724452,8736669,18770546,8417938,18455439,8427553,18433672,118471760,18472583,118477581,118446332,8440847,116188983,6186737,116168756,6109117,116104394,6193214,6193393,6131464,16135702,16133002,116178799,6176086,6176025,16173775,6146718,6147762,116813975,116865176,116809639,16803136,116896593,116829301,16870561,116877044,6843174,6612690,116613488,16682745,16660727,16662458,116664876,16608241,6624531,6671216,6674780,116643271,116644327,16588625,116580258,16568726,6563828,116563036,16591603,116598341,6536837,6082014,6087286,16058220,16055847,16021304,116020054,6022541,116024663,116042281,16987567,16966444,16964821,16954217,116906078,116992213,116921803,116923818,6932732,6978590,116970977,16215709,116210169,16212334,6201155,116290956,116293574,16294366,6224441,16385937,6382145,16361333,6325422,116323384,16335700,16374664,6341999,116346147,116713673,116751525,116796763,16728053,16745107,16742512,116742399,6489978,116462360,16456333,6420691,16438899,116438306,16439784,16433389,116477190,15111904,5118795,5180278,115101677,5106739,5176498,5818855,115888657,115864521,15854147,115806718,115894913,15831100,15870970,5614325,115687890,15656613,15650879,115606772,115634839,15671064,15671700,15679166,115646572,5646398,115645955,15640021,115588927,5588746,5583954,5583209,15568590,15569104,15556922,5538774,15541011,15085767,5001842,15008813,5099246,15022394,5027633,5035682,115047996,15964221,15950796,15905219,115909259,5937471,15946152,15264918,115259028,115209891,5203018,115203317,5223011,115227153,5236958,15239077,115278670,15277377,15274776,5241815,115318169,5366570,15305213,15303577,115307404,115321112,15374407,115341370,5343953,5718218,15768523,5755022,15724194,5740884,15486576,5464049,15450509,15454248,115400361,5409835,15404532,15492616,10110362,110110335,110184627,110165542,110108717,10100775,110102511,10103310,10198745,10174381,110813148,10827658,10872498,10842210,10656717,10602858,110698183,110690186,110620170,110585638,10582739,10554305,10505781,110509985,110528482,110016716,110010442,10017945,10085850,10087240,110068699,110067525,1 ...
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2192.all-ancestors-of-a-node-in-a-directed-acyclic-graph.kt
# - Downloading all-ancestors-of-a-node-in-a-directed-acyclic-graph
#   ✔ Accepted
#   ✔ 80/80 cases passed (320 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2193.minimum-number-of-moves-to-make-palindrome.kt
# - Downloading minimum-number-of-moves-to-make-palindrome
#   ✔ Accepted
#   ✔ 129/129 cases passed (44 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
# [WARN] Failed to get memory percentile.

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-08-18 13:09:34
