# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME')
    user_cookie = userdata.get('LEETCODE_TOKEN')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME'] = user_name
    os.environ['LEETCODE_TOKEN'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME" "$LEETCODE_TOKEN" | leetcode user -c

# %%
# %%bash
#
#
# # top 100 answers
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v java_solutions/*.java | head -n 150); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 8
# done
# Out:
# Submitting: java_solutions/1.two-sum.java
# - Downloading problems
# - Downloading two-sum
#   ✘ Time Limit Exceeded
#   ✘ 62/63 cases passed (N/A)
#   ✘ Testcase: [-500000000,2,4,-500000000]
# -1000000000
#   ✘ Answer: [0,3]
#   ✘ Expected Answer: [0,3]
#   ✘ Stdout:
# Submitting: java_solutions/2.add-two-numbers.java
# - Downloading add-two-numbers
#   ✔ Accepted
#   ✔ 1569/1569 cases passed (36 ms)
#   ✔ Your runtime beats 2.25 % of java submissions
#   ✔ Your memory usage beats 6.86 % of java submissions (47.9 MB)
# Submitting: java_solutions/3.longest-substring-without-repeating-characters.java
# - Downloading longest-substring-without-repeating-characters
#   ✔ Accepted
#   ✔ 988/988 cases passed (15 ms)
#   ✔ Your runtime beats 9.89 % of java submissions
#   ✔ Your memory usage beats 6.79 % of java submissions (47.5 MB)
# Submitting: java_solutions/4.median-of-two-sorted-arrays.java
# - Downloading median-of-two-sorted-arrays
#   ✔ Accepted
#   ✔ 2098/2098 cases passed (3 ms)
#   ✔ Your runtime beats 25.53 % of java submissions
#   ✔ Your memory usage beats 70.45 % of java submissions (48.8 MB)
# Submitting: java_solutions/5.longest-palindromic-substring.java
# - Downloading longest-palindromic-substring
#   ✔ Accepted
#   ✔ 143/143 cases passed (84 ms)
#   ✔ Your runtime beats 28.61 % of java submissions
#   ✔ Your memory usage beats 12.08 % of java submissions (47.3 MB)
# Submitting: java_solutions/6.zigzag-conversion.java
# - Downloading zigzag-conversion
#   ✔ Accepted
#   ✔ 1157/1157 cases passed (25 ms)
#   ✔ Your runtime beats 6.05 % of java submissions
#   ✔ Your memory usage beats 5.31 % of java submissions (47.8 MB)
# Submitting: java_solutions/7.reverse-integer.java
# - Downloading reverse-integer
#   ✔ Accepted
#   ✔ 1045/1045 cases passed (7 ms)
#   ✔ Your runtime beats 2.43 % of java submissions
#   ✔ Your memory usage beats 12.09 % of java submissions (43.3 MB)
# Submitting: java_solutions/8.string-to-integer-atoi.java
# - Downloading string-to-integer-atoi
#   ✔ Accepted
#   ✔ 1096/1096 cases passed (7 ms)
#   ✔ Your runtime beats 3.52 % of java submissions
#   ✔ Your memory usage beats 5.5 % of java submissions (44.5 MB)
# Submitting: java_solutions/9.palindrome-number.java
# - Downloading palindrome-number
#   ✔ Accepted
#   ✔ 11511/11511 cases passed (22 ms)
#   ✔ Your runtime beats 5.93 % of java submissions
#   ✔ Your memory usage beats 6.91 % of java submissions (46.6 MB)
# Submitting: java_solutions/10.regular-expression-matching.java
# - Downloading regular-expression-matching
#   ✔ Accepted
#   ✔ 354/354 cases passed (455 ms)
#   ✔ Your runtime beats 10.73 % of java submissions
#   ✔ Your memory usage beats 9.97 % of java submissions (44.2 MB)
# Submitting: java_solutions/11.container-with-most-water.java
# - Downloading container-with-most-water
#   ✔ Accepted
#   ✔ 65/65 cases passed (18 ms)
#   ✔ Your runtime beats 5.54 % of java submissions
#   ✔ Your memory usage beats 99.7 % of java submissions (74.4 MB)
# Submitting: java_solutions/12.integer-to-roman.java
# - Downloading integer-to-roman
#   ✔ Accepted
#   ✔ 3999/3999 cases passed (33 ms)
#   ✔ Your runtime beats 6.67 % of java submissions
#   ✔ Your memory usage beats 5.43 % of java submissions (48.1 MB)
# Submitting: java_solutions/13.roman-to-integer.java
# - Downloading roman-to-integer
#   ✔ Accepted
#   ✔ 3999/3999 cases passed (15 ms)
#   ✔ Your runtime beats 5.3 % of java submissions
#   ✔ Your memory usage beats 9.8 % of java submissions (47 MB)
# Submitting: java_solutions/14.longest-common-prefix.java
# - Downloading longest-common-prefix
#   ✔ Accepted
#   ✔ 126/126 cases passed (17 ms)
#   ✔ Your runtime beats 5.64 % of java submissions
#   ✔ Your memory usage beats 5.38 % of java submissions (46.8 MB)
# Submitting: java_solutions/15.3-sum.java
# - Downloading 3sum
#   ✔ Accepted
#   ✔ 316/316 cases passed (180 ms)
#   ✔ Your runtime beats 14.82 % of java submissions
#   ✔ Your memory usage beats 16.54 % of java submissions (60 MB)
# Submitting: java_solutions/16.3sum-closest.java
# - Downloading 3sum-closest
#   ✔ Accepted
#   ✔ 107/107 cases passed (110 ms)
#   ✔ Your runtime beats 5 % of java submissions
#   ✔ Your memory usage beats 14.22 % of java submissions (53 MB)
# Submitting: java_solutions/17.letter-combinations-of-a-phone-number.java
# - Downloading letter-combinations-of-a-phone-number
#   ✔ Accepted
#   ✔ 24/24 cases passed (8 ms)
#   ✔ Your runtime beats 1.47 % of java submissions
#   ✔ Your memory usage beats 5.04 % of java submissions (49.6 MB)
# Submitting: java_solutions/18.4sum.java
# - Downloading 4sum
#   ✔ Accepted
#   ✔ 294/294 cases passed (1296 ms)
#   ✔ Your runtime beats 5.09 % of java submissions
#   ✔ Your memory usage beats 5.5 % of java submissions (54 MB)
# Submitting: java_solutions/19.remove-nth-node-from-end-of-list.java
# - Downloading remove-nth-node-from-end-of-list
#   ✔ Accepted
#   ✔ 208/208 cases passed (23 ms)
#   ✔ Your runtime beats 0.69 % of java submissions
#   ✔ Your memory usage beats 6.38 % of java submissions (52.2 MB)
# Submitting: java_solutions/20.valid-parentheses.java
# - Downloading valid-parentheses
#   ✔ Accepted
#   ✔ 102/102 cases passed (31 ms)
#   ✔ Your runtime beats 5.7 % of java submissions
#   ✔ Your memory usage beats 5.64 % of java submissions (52.9 MB)
# Submitting: java_solutions/21.merge-two-sorted-lists.java
# - Downloading merge-two-sorted-lists
#   ✔ Accepted
#   ✔ 208/208 cases passed (16 ms)
#   ✔ Your runtime beats 0.55 % of java submissions
#   ✔ Your memory usage beats 6.94 % of java submissions (46.6 MB)
# Submitting: java_solutions/22.generate-parentheses.java
# - Downloading generate-parentheses
#   ✔ Accepted
#   ✔ 8/8 cases passed (14 ms)
#   ✔ Your runtime beats 5.12 % of java submissions
#   ✔ Your memory usage beats 5.21 % of java submissions (52.6 MB)
# Submitting: java_solutions/23.merge-k-sorted-lists.java
# - Downloading merge-k-sorted-lists
#   ✔ Accepted
#   ✔ 134/134 cases passed (5 ms)
#   ✔ Your runtime beats 38.2 % of java submissions
#   ✔ Your memory usage beats 28.97 % of java submissions (47 MB)
# Submitting: java_solutions/24.swap-nodes-in-pairs.java
# - Downloading swap-nodes-in-pairs
#   ✔ Accepted
#   ✔ 55/55 cases passed (14 ms)
#   ✔ Your runtime beats 0.41 % of java submissions
#   ✔ Your memory usage beats 12.1 % of java submissions (45.2 MB)
# Submitting: java_solutions/25.reverse-nodes-in-k-group.java
# - Downloading reverse-nodes-in-k-group
#   ✔ Accepted
#   ✔ 62/62 cases passed (6 ms)
#   ✔ Your runtime beats 1.02 % of java submissions
#   ✔ Your memory usage beats 54.5 % of java submissions (46.3 MB)
# Submitting: java_solutions/26.remove-duplicates-from-sorted-array.java
# - Downloading remove-duplicates-from-sorted-array
#   ✔ Accepted
#   ✔ 362/362 cases passed (9 ms)
#   ✔ Your runtime beats 3.89 % of java submissions
#   ✔ Your memory usage beats 8.57 % of java submissions (47.2 MB)
# Submitting: java_solutions/27.remove-element.java
# - Downloading remove-element
#   ✔ Accepted
#   ✔ 116/116 cases passed (8 ms)
#   ✔ Your runtime beats 0.89 % of java submissions
#   ✔ Your memory usage beats 8.47 % of java submissions (50.1 MB)
# Submitting: java_solutions/28.find-the-index-of-the-first-occurrence-in-a-string.java
# - Downloading find-the-index-of-the-first-occurrence-in-a-string
#   ✔ Accepted
#   ✔ 85/85 cases passed (4 ms)
#   ✔ Your runtime beats 6.39 % of java submissions
#   ✔ Your memory usage beats 10 % of java submissions (43.5 MB)
# Submitting: java_solutions/29.divide-two-integers.java
# - Downloading divide-two-integers
#   ✔ Accepted
#   ✔ 994/994 cases passed (1 ms)
#   ✔ Your runtime beats 94.4 % of java submissions
#   ✔ Your memory usage beats 13.34 % of java submissions (42.9 MB)
# Submitting: java_solutions/30.substring-with-concatenation-of-all-words.java
# - Downloading substring-with-concatenation-of-all-words
#   ✔ Accepted
#   ✔ 182/182 cases passed (15 ms)
#   ✔ Your runtime beats 12.22 % of java submissions
#   ✔ Your memory usage beats 9.96 % of java submissions (47.6 MB)
# Submitting: java_solutions/31.next-permutation.java
# - Downloading next-permutation
#   ✔ Accepted
#   ✔ 266/266 cases passed (25 ms)
#   ✔ Your runtime beats 1.76 % of java submissions
#   ✔ Your memory usage beats 5.02 % of java submissions (53 MB)
# Submitting: java_solutions/32.longest-valid-parentheses.java
# - Downloading longest-valid-parentheses
#   ✔ Accepted
#   ✔ 235/235 cases passed (3 ms)
#   ✔ Your runtime beats 85.16 % of java submissions
#   ✔ Your memory usage beats 89.48 % of java submissions (44.8 MB)
# Submitting: java_solutions/33.search-in-rotated-sorted-array.java
# - Downloading search-in-rotated-sorted-array
#   ✔ Accepted
#   ✔ 196/196 cases passed (4 ms)
#   ✔ Your runtime beats 1.51 % of java submissions
#   ✔ Your memory usage beats 10.52 % of java submissions (44.4 MB)
# Submitting: java_solutions/34.find-first-and-last-position-of-element-in-sorted-array.java
# - Downloading find-first-and-last-position-of-element-in-sorted-array
#   ✔ Accepted
#   ✔ 88/88 cases passed (6 ms)
#   ✔ Your runtime beats 0.82 % of java submissions
#   ✔ Your memory usage beats 30.42 % of java submissions (48.3 MB)
# Submitting: java_solutions/35.search-insert-position.java
# - Downloading search-insert-position
#   ✔ Accepted
#   ✔ 66/66 cases passed (7 ms)
#   ✔ Your runtime beats 0.47 % of java submissions
#   ✔ Your memory usage beats 11.96 % of java submissions (45.9 MB)
# Submitting: java_solutions/36.valid-sudoku.java
# - Downloading valid-sudoku
#   ✔ Accepted
#   ✔ 507/507 cases passed (32 ms)
#   ✔ Your runtime beats 8.2 % of java submissions
#   ✔ Your memory usage beats 7.13 % of java submissions (53.3 MB)
# Submitting: java_solutions/37.sudoku-solver.java
# - Downloading sudoku-solver
#   ✔ Accepted
#   ✔ 8/8 cases passed (956 ms)
#   ✔ Your runtime beats 5.03 % of java submissions
#   ✔ Your memory usage beats 6.76 % of java submissions (47.1 MB)
# Submitting: java_solutions/38.count-and-say.java
# - Downloading count-and-say
#   ✔ Accepted
#   ✔ 30/30 cases passed (28 ms)
#   ✔ Your runtime beats 5.55 % of java submissions
#   ✔ Your memory usage beats 6.52 % of java submissions (48.1 MB)
# Submitting: java_solutions/39.combination-sum.java
# - Downloading combination-sum
#   ✔ Accepted
#   ✔ 160/160 cases passed (63 ms)
#   ✔ Your runtime beats 4.17 % of java submissions
#   ✔ Your memory usage beats 5.33 % of java submissions (53.6 MB)
# Submitting: java_solutions/40.combination-sum-ii.java
# - Downloading combination-sum-ii
#   ✔ Accepted
#   ✔ 176/176 cases passed (71 ms)
#   ✔ Your runtime beats 14.76 % of java submissions
#   ✔ Your memory usage beats 5.64 % of java submissions (53.8 MB)
# Submitting: java_solutions/41.first-missing-positive.java
# - Downloading first-missing-positive
#   ✔ Accepted
#   ✔ 179/179 cases passed (2 ms)
#   ✔ Your runtime beats 35.03 % of java submissions
#   ✔ Your memory usage beats 57.86 % of java submissions (71.3 MB)
# Submitting: java_solutions/42.trapping-rain-water.java
# - Downloading trapping-rain-water
#   ✔ Accepted
#   ✔ 324/324 cases passed (1 ms)
#   ✔ Your runtime beats 59 % of java submissions
#   ✔ Your memory usage beats 90.46 % of java submissions (47.4 MB)
# Submitting: java_solutions/43.multiply-strings.java
# - Downloading multiply-strings
#   ✔ Accepted
#   ✔ 311/311 cases passed (12 ms)
#   ✔ Your runtime beats 5.41 % of java submissions
#   ✔ Your memory usage beats 6.26 % of java submissions (45 MB)
# Submitting: java_solutions/44.wildcard-matching.java
# - Downloading wildcard-matching
#   ✔ Accepted
#   ✔ 1812/1812 cases passed (61 ms)
#   ✔ Your runtime beats 11.88 % of java submissions
#   ✔ Your memory usage beats 25.91 % of java submissions (48 MB)
# Submitting: java_solutions/45.jump-game-ii.java
# - Downloading jump-game-ii
#   ✔ Accepted
#   ✔ 110/110 cases passed (3 ms)
#   ✔ Your runtime beats 17.72 % of java submissions
#   ✔ Your memory usage beats 55.74 % of java submissions (47.3 MB)
# Submitting: java_solutions/46.permutations.java
# - Downloading permutations
#   ✔ Accepted
#   ✔ 26/26 cases passed (35 ms)
#   ✔ Your runtime beats 2.43 % of java submissions
#   ✔ Your memory usage beats 6.41 % of java submissions (53.5 MB)
# Submitting: java_solutions/47.permutations-ii.java
# - Downloading permutations-ii
#   ✔ Accepted
#   ✔ 33/33 cases passed (460 ms)
#   ✔ Your runtime beats 5.67 % of java submissions
#   ✔ Your memory usage beats 6.64 % of java submissions (91.9 MB)
# Submitting: java_solutions/48.rotate-image.java
# - Downloading rotate-image
#   ✔ Accepted
#   ✔ 21/21 cases passed (12 ms)
#   ✔ Your runtime beats 1.21 % of java submissions
#   ✔ Your memory usage beats 15.47 % of java submissions (50.9 MB)
# Submitting: java_solutions/49.group-anagrams.java
# - Downloading group-anagrams
#   ✔ Accepted
#   ✔ 128/128 cases passed (51 ms)
#   ✔ Your runtime beats 5.06 % of java submissions
#   ✔ Your memory usage beats 6.06 % of java submissions (56.7 MB)
# Submitting: java_solutions/50.pow-x-n.java
# - Downloading powx-n
#   ✔ Accepted
#   ✔ 307/307 cases passed (13 ms)
#   ✔ Your runtime beats 1.4 % of java submissions
#   ✔ Your memory usage beats 10.82 % of java submissions (48.6 MB)
# Submitting: java_solutions/51.n-queens.java
# - Downloading n-queens
#   ✔ Accepted
#   ✔ 9/9 cases passed (11 ms)
#   ✔ Your runtime beats 5.78 % of java submissions
#   ✔ Your memory usage beats 6.13 % of java submissions (47 MB)
# Submitting: java_solutions/52.n-queens-ii.java
# - Downloading n-queens-ii
#   ✔ Accepted
#   ✔ 9/9 cases passed (11 ms)
#   ✔ Your runtime beats 5.27 % of java submissions
#   ✔ Your memory usage beats 20.33 % of java submissions (42.4 MB)
# Submitting: java_solutions/53.maximum-subarray.java
# - Downloading maximum-subarray
#   ✔ Accepted
#   ✔ 210/210 cases passed (2 ms)
#   ✔ Your runtime beats 4.53 % of java submissions
#   ✔ Your memory usage beats 81.73 % of java submissions (77 MB)
# Submitting: java_solutions/54.spiral-matrix.java
# - Downloading spiral-matrix
#   ✔ Accepted
#   ✔ 26/26 cases passed (6 ms)
#   ✔ Your runtime beats 0.9 % of java submissions
#   ✔ Your memory usage beats 8.29 % of java submissions (43.5 MB)
# Submitting: java_solutions/55.jump-game.java
# - Downloading jump-game
#   ✔ Accepted
#   ✔ 178/178 cases passed (11 ms)
#   ✔ Your runtime beats 11.8 % of java submissions
#   ✔ Your memory usage beats 8.59 % of java submissions (48.6 MB)
# Submitting: java_solutions/56.merge-intervals.java
# - Downloading merge-intervals
#   ✔ Accepted
#   ✔ 172/172 cases passed (24 ms)
#   ✔ Your runtime beats 6.07 % of java submissions
#   ✔ Your memory usage beats 5.52 % of java submissions (56.2 MB)
# Submitting: java_solutions/57.insert-interval.java
# - Downloading insert-interval
#   ✔ Accepted
#   ✔ 158/158 cases passed (15 ms)
#   ✔ Your runtime beats 3.86 % of java submissions
#   ✔ Your memory usage beats 6.96 % of java submissions (48 MB)
# Submitting: java_solutions/58.length-of-last-word.java
# - Downloading length-of-last-word
#   ✔ Accepted
#   ✔ 60/60 cases passed (5 ms)
#   ✔ Your runtime beats 0.8 % of java submissions
#   ✔ Your memory usage beats 6.1 % of java submissions (43.4 MB)
# Submitting: java_solutions/59.spiral-matrix-ii.java
# - Downloading spiral-matrix-ii
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 9: error: array required, but Object found
#   ✘ Error: Line 9: error: array required, but Object found
#         return java.util.stream.Stream.of(new Object[]{new int[n][n], new int[]{0, n - 1, 0, n - 1, 0, 0, 0}}).map(arr -> java.util.stream.IntStream.rangeClosed(1, n * n).mapToObj(i -> java.util.stream.Stream.of((int[])arr[1]).map(s -> (((int[][])arr[0])[s[4]][s[5]] = i) > -1 && (s[6] == 0 ? (s[5] == s[3] ? (s[6] = 1) + (s[0]++) + (s[4]++) : s[5]++) : s[6] == 1 ? (s[4] == s[1] ? (s[6] = 2) + (s[3]--) + (s[5]--) : s[4]++) : s[6] == 2 ? (s[5] == s[2] ? (s[6] = 3) + (s[1]--) + (s[4]--) : s[5]--) : (s[4] == s[0] ? (s[6] = 0) + (s[2]++) + (s[5]++) : s[4]--)) > -100).findFirst().get()).count() > -1 ? (int[][])arr[0] : null).findFirst().get();
#                                                                                                                                                                                                                               ^
# Line 9: error: array required, but Object found
#         return java.util.stream.Stream.of(new Object[]{new int[n][n], new int[]{0, n - 1, 0, n - 1, 0, 0, 0}}).map(arr -> java.util.stream.IntStream.rangeClosed(1, n * n).mapToObj(i -> java.util.stream.Stream.of((int[])arr[1]).map(s -> (((int[][])arr[0])[s[4]][s[5]] = i) > -1 && (s[6] == 0 ? (s[5] == s[3] ? (s[6] = 1) + (s[0]++) + (s[4]++) : s[5]++) : s[6] == 1 ? (s[4] == s[1] ? (s[6] = 2) + (s[3]--) + (s[5]--) : s[4]++) : s[6] == 2 ? (s[5] == s[2] ? (s[6] = 3) + (s[1]--) + (s[4]--) : s[5]--) : (s[4] == s[0] ? (s[6] = 0) + (s[2]++) + (s[5]++) : s[4]--)) > -100).findFirst().get()).count() > -1 ? (int[][])arr[0] : null).findFirst().get();
#                                                                                                                                                                                                                                                           ^
# Line 9: error: array required, but Object found
#         return java.util.stream.Stream.of(new Object[]{new int[n][n], new int[]{0, n - 1, 0, n - 1, 0, 0, 0}}).map(arr -> java.util.stream.IntStream.rangeClosed(1, n * n).mapToObj(i -> java.util.stream.Stream.of((int[])arr[1]).map(s -> (((int[][])arr[0])[s[4]][s[5]] = i) > -1 && (s[6] == 0 ? (s[5] == s[3] ? (s[6] = 1) + (s[0]++) + (s[4]++) : s[5]++) : s[6] == 1 ? (s[4] == s[1] ? (s[6] = 2) + (s[3]--) + (s[5]--) : s[4]++) : s[6] == 2 ? (s[5] == s[2] ? (s[6] = 3) + (s[1]--) + (s[4]--) : s[5]--) : (s[4] == s[0] ? (s[6] = 0) + (s[2]++) + (s[5]++) : s[4]--)) > -100).findFirst().get()).count() > -1 ? (int[][])arr[0] : null).findFirst().get();
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ^
# 3 errors
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: java_solutions/60.permutation-sequence.java
# - Downloading permutation-sequence
#   ✔ Accepted
#   ✔ 200/200 cases passed (5 ms)
#   ✔ Your runtime beats 12.42 % of java submissions
#   ✔ Your memory usage beats 8.61 % of java submissions (43.3 MB)
# Submitting: java_solutions/61.rotate-list.java
# - Downloading rotate-list
#   ✔ Accepted
#   ✔ 232/232 cases passed (21 ms)
#   ✔ Your runtime beats 1.27 % of java submissions
#   ✔ Your memory usage beats 7.81 % of java submissions (46.6 MB)
# Submitting: java_solutions/62.unique-paths.java
# - Downloading unique-paths
#   ✔ Accepted
#   ✔ 64/64 cases passed (8 ms)
#   ✔ Your runtime beats 0.96 % of java submissions
#   ✔ Your memory usage beats 12.35 % of java submissions (43.2 MB)
# Submitting: java_solutions/63.unique-paths-ii.java
# - Downloading unique-paths-ii
#   ✔ Accepted
#   ✔ 42/42 cases passed (7 ms)
#   ✔ Your runtime beats 3.41 % of java submissions
#   ✔ Your memory usage beats 10.75 % of java submissions (44.2 MB)
# Submitting: java_solutions/64.minimum-path-sum.java
# - Downloading minimum-path-sum
#   ✔ Accepted
#   ✔ 66/66 cases passed (10 ms)
#   ✔ Your runtime beats 9.94 % of java submissions
#   ✔ Your memory usage beats 83.69 % of java submissions (50.1 MB)
# Submitting: java_solutions/65.valid-number.java
# - Downloading valid-number
#   ✔ Accepted
#   ✔ 1499/1499 cases passed (12 ms)
#   ✔ Your runtime beats 5.32 % of java submissions
#   ✔ Your memory usage beats 5.14 % of java submissions (47.8 MB)
# Submitting: java_solutions/66.plus-one.java
# - Downloading plus-one
#   ✔ Accepted
#   ✔ 114/114 cases passed (12 ms)
#   ✔ Your runtime beats 0.81 % of java submissions
#   ✔ Your memory usage beats 8.56 % of java submissions (44.2 MB)
# Submitting: java_solutions/67.add-binary.java
# - Downloading add-binary
#   ✔ Accepted
#   ✔ 296/296 cases passed (10 ms)
#   ✔ Your runtime beats 7.35 % of java submissions
#   ✔ Your memory usage beats 10.74 % of java submissions (44.5 MB)
# Submitting: java_solutions/68.text-justification.java
# - Downloading text-justification
#   ✔ Accepted
#   ✔ 29/29 cases passed (1 ms)
#   ✔ Your runtime beats 37.15 % of java submissions
#   ✔ Your memory usage beats 62.53 % of java submissions (43.2 MB)
# Submitting: java_solutions/69.sqrtx.java
# - Downloading sqrtx
#   ✔ Accepted
#   ✔ 1019/1019 cases passed (328 ms)
#   ✔ Your runtime beats 5.04 % of java submissions
#   ✔ Your memory usage beats 8.63 % of java submissions (43.4 MB)
# Submitting: java_solutions/70.climbing-stairs.java
# - Downloading climbing-stairs
#   ✔ Accepted
#   ✔ 45/45 cases passed (9 ms)
#   ✔ Your runtime beats 0.28 % of java submissions
#   ✔ Your memory usage beats 16.84 % of java submissions (42.8 MB)
# Submitting: java_solutions/71.simplify-path.java
# - Downloading simplify-path
#   ✔ Accepted
#   ✔ 264/264 cases passed (13 ms)
#   ✔ Your runtime beats 5.03 % of java submissions
#   ✔ Your memory usage beats 12.05 % of java submissions (46.5 MB)
# Submitting: java_solutions/72.edit-distance.java
# - Downloading edit-distance
#   ✘ Wrong Answer
#   ✘ 10/1149 cases passed (N/A)
#   ✘ Testcase: "intention"
# "execution"
#   ✘ Answer: 9
#   ✘ Expected Answer: 5
#   ✘ Stdout:
# Submitting: java_solutions/73.set-matrix-zeroes.java
# - Downloading set-matrix-zeroes
#   ✔ Accepted
#   ✔ 203/203 cases passed (27 ms)
#   ✔ Your runtime beats 5.16 % of java submissions
#   ✔ Your memory usage beats 5.21 % of java submissions (53.8 MB)
# Submitting: java_solutions/74.search-a-2d-matrix.java
# - Downloading search-a-2d-matrix
#   ✔ Accepted
#   ✔ 133/133 cases passed (6 ms)
#   ✔ Your runtime beats 1.18 % of java submissions
#   ✔ Your memory usage beats 8.44 % of java submissions (44.6 MB)
# Submitting: java_solutions/75.sort-colors.java
# - Downloading sort-colors
#   ✔ Accepted
#   ✔ 89/89 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 59.42 % of java submissions (43.4 MB)
# Submitting: java_solutions/76.minimum-window-substring.java
# - Downloading minimum-window-substring
#   ✔ Accepted
#   ✔ 268/268 cases passed (3 ms)
#   ✔ Your runtime beats 76.74 % of java submissions
#   ✔ Your memory usage beats 79.72 % of java submissions (45.6 MB)
# Submitting: java_solutions/77.combinations.java
# - Downloading combinations
#   ✔ Accepted
#   ✔ 27/27 cases passed (333 ms)
#   ✔ Your runtime beats 5.19 % of java submissions
#   ✔ Your memory usage beats 5.15 % of java submissions (144.4 MB)
# Submitting: java_solutions/78.subsets.java
# - Downloading subsets
#   ✔ Accepted
#   ✔ 10/10 cases passed (7 ms)
#   ✔ Your runtime beats 1.06 % of java submissions
#   ✔ Your memory usage beats 7.15 % of java submissions (45.1 MB)
# Submitting: java_solutions/79.word-search.java
# - Downloading word-search
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 9: error: array required, but Object found
#   ✘ Error: Line 9: error: array required, but Object found
#         return java.util.stream.Stream.<java.util.function.Function<int[], Boolean>[]>of(new java.util.function.Function[1]).map(f -> java.util.stream.Stream.of(f[0] = (java.util.function.Function<int[], Boolean>) (a -> a[2] == word.length() ? true : (a[0] < 0 || a[1] < 0 || a[0] >= board.length || a[1] >= board[0].length || board[a[0]][a[1]] != word.charAt(a[2]) ? false : java.util.stream.Stream.of(board[a[0]][a[1]]).map(t -> java.util.stream.Stream.of(board[a[0]][a[1]] = '*').map(dummy -> f[0].apply(new int[]{a[0]+1, a[1], a[2]+1}) || f[0].apply(new int[]{a[0]-1, a[1], a[2]+1}) || f[0].apply(new int[]{a[0], a[1]+1, a[2]+1}) || f[0].apply(new int[]{a[0], a[1]-1, a[2]+1})).map(res -> java.util.stream.Stream.of(board[a[0]][a[1]] = t).map(dummy -> res).findFirst().get()).findFirst().get()).findFirst().get()))).findFirst().get()).map(func -> java.util.stream.IntStream.range(0, board.length).boxed().flatMap(i -> java.util.stream.IntStream.range(0, board[0].length).mapToObj(j -> new int[]{i, j, 0})).anyMatch(func::apply)).findFirst().get();
#                                                                                                                                                                   ^
# Line 9: error: array required, but Object found
#         return java.util.stream.Stream.<java.util.function.Function<int[], Boolean>[]>of(new java.util.function.Function[1]).map(f -> java.util.stream.Stream.of(f[0] = (java.util.function.Function<int[], Boolean>) (a -> a[2] == word.length() ? true : (a[0] < 0 || a[1] < 0 || a[0] >= board.length || a[1] >= board[0].length || board[a[0]][a[1]] != word.charAt(a[2]) ? false : java.util.stream.Stream.of(board[a[0]][a[1]]).map(t -> java.util.stream.Stream.of(board[a[0]][a[1]] = '*').map(dummy -> f[0].apply(new int[]{a[0]+1, a[1], a[2]+1}) || f[0].apply(new int[]{a[0]-1, a[1], a[2]+1}) || f[0].apply(new int[]{a[0], a[1]+1, a[2]+1}) || f[0].apply(new int[]{a[0], a[1]-1, a[2]+1})).map(res -> java.util.stream.Stream.of(board[a[0]][a[1]] = t).map(dummy -> res).findFirst().get()).findFirst().get()).findFirst().get()))).findFirst().get()).map(func -> java.util.stream.IntStream.range(0, board.length).boxed().flatMap(i -> java.util.stream.IntStream.range(0, board[0].length).mapToObj(j -> new int[]{i, j, 0})).anyMatch(func::apply)).findFirst().get();
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ^
# Line 9: error: array required, but Object found
#         return java.util.stream.Stream.<java.util.function.Function<int[], Boolean>[]>of(new java.util.function.Function[1]).map(f -> java.util.stream.Stream.of(f[0] = (java.util.function.Function<int[], Boolean>) (a -> a[2] == word.length() ? true : (a[0] < 0 || a[1] < 0 || a[0] >= board.length || a[1] >= board[0].length || board[a[0]][a[1]] != word.charAt(a[2]) ? false : java.util.stream.Stream.of(board[a[0]][a[1]]).map(t -> java.util.stream.Stream.of(board[a[0]][a[1]] = '*').map(dummy -> f[0].apply(new int[]{a[0]+1, a[1], a[2]+1}) || f[0].apply(new int[]{a[0]-1, a[1], a[2]+1}) || f[0].apply(new int[]{a[0], a[1]+1, a[2]+1}) || f[0].apply(new int[]{a[0], a[1]-1, a[2]+1})).map(res -> java.util.stream.Stream.of(board[a[0]][a[1]] = t).map(dummy -> res).findFirst().get()).findFirst().get()).findFirst().get()))).findFirst().get()).map(func -> java.util.stream.IntStream.range(0, board.length).boxed().flatMap(i -> java.util.stream.IntStream.range(0, board[0].length).mapToObj(j -> new int[]{i, j, 0})).anyMatch(func::apply)).findFirst().get();
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ^
# Line 9: error: array required, but Object found
#         return java.util.stream.Stream.<java.util.function.Function<int[], Boolean>[]>of(new java.util.function.Function[1]).map(f -> java.util.stream.Stream.of(f[0] = (java.util.function.Function<int[], Boolean>) (a -> a[2] == word.length() ? true : (a[0] < 0 || a[1] < 0 || a[0] >= board.length || a[1] >= board[0].length || board[a[0]][a[1]] != word.charAt(a[2]) ? false : java.util.stream.Stream.of(board[a[0]][a[1]]).map(t -> java.util.stream.Stream.of(board[a[0]][a[1]] = '*').map(dummy -> f[0].apply(new int[]{a[0]+1, a[1], a[2]+1}) || f[0].apply(new int[]{a[0]-1, a[1], a[2]+1}) || f[0].apply(new int[]{a[0], a[1]+1, a[2]+1}) || f[0].apply(new int[]{a[0], a[1]-1, a[2]+1})).map(res -> java.util.stream.Stream.of(board[a[0]][a[1]] = t).map(dummy -> res).findFirst().get()).findFirst().get()).findFirst().get()))).findFirst().get()).map(func -> java.util.stream.IntStream.range(0, board.length).boxed().flatMap(i -> java.util.stream.IntStream.range(0, board[0].length).mapToObj(j -> new int[]{i, j, 0})).anyMatch(func::apply)).findFirst().get();
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ^
# Line 9: error: array required, but Object found
#         return java.util.stream.Stream.<java.util.function.Function<int[], Boolean>[]>of(new java.util.function.Function[1]).map(f -> java.util.stream.Stream.of(f[0] = (java.util.function.Function<int[], Boolean>) (a -> a[2] == word.length() ? true : (a[0] < 0 || a[1] < 0 || a[0] >= board.length || a[1] >= board[0].length || board[a[0]][a[1]] != word.charAt(a[2]) ? false : java.util.stream.Stream.of(board[a[0]][a[1]]).map(t -> java.util.stream.Stream.of(board[a[0]][a[1]] = '*').map(dummy -> f[0].apply(new int[]{a[0]+1, a[1], a[2]+1}) || f[0].apply(new int[]{a[0]-1, a[1], a[2]+1}) || f[0].apply(new int[]{a[0], a[1]+1, a[2]+1}) || f[0].apply(new int[]{a[0], a[1]-1, a[2]+1})).map(res -> java.util.stream.Stream.of(board[a[0]][a[1]] = t).map(dummy -> res).findFirst().get()).findFirst().get()).findFirst().get()))).findFirst().get()).map(func -> java.util.stream.IntStream.range(0, board.length).boxed().flatMap(i -> java.util.stream.IntStream.range(0, board[0].length).mapToObj(j -> new int[]{i, j, 0})).anyMatch(func::apply)).findFirst().get();
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ^
# Line 9: error: incompatible types: bad return type in lambda expression
#         return java.util.stream.Stream.<java.util.function.Function<int[], Boolean>[]>of(new java.util.function.Function[1]).map(f -> java.util.stream.Stream.of(f[0] = (java.util.function.Function<int[], Boolean>) (a -> a[2] == word.length() ? true : (a[0] < 0 || a[1] < 0 || a[0] >= board.length || a[1] >= board[0].length || board[a[0]][a[1]] != word.charAt(a[2]) ? false : java.util.stream.Stream.of(board[a[0]][a[1]]).map(t -> java.util.stream.Stream.of(board[a[0]][a[1]] = '*').map(dummy -> f[0].apply(new int[]{a[0]+1, a[1], a[2]+1}) || f[0].apply(new int[]{a[0]-1, a[1], a[2]+1}) || f[0].apply(new int[]{a[0], a[1]+1, a[2]+1}) || f[0].apply(new int[]{a[0], a[1]-1, a[2]+1})).map(res -> java.util.stream.Stream.of(board[a[0]][a[1]] = t).map(dummy -> res).findFirst().get()).findFirst().get()).findFirst().get()))).findFirst().get()).map(func -> java.util.stream.IntStream.range(0, board.length).boxed().flatMap(i -> java.util.stream.IntStream.range(0, board[0].length).mapToObj(j -> new int[]{i, j, 0})).anyMatch(func::apply)).findFirst().get();
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ^
#     bad type in conditional expression
#       bad type in conditional expression
#         Object cannot be converted to Boolean
# Line 9: error: invalid method reference
#         return java.util.stream.Stream.<java.util.function.Function<int[], Boolean>[]>of(new java.util.function.Function[1]).map(f -> java.util.stream.Stream.of(f[0] = (java.util.function.Function<int[], Boolean>) (a -> a[2] == word.length() ? true : (a[0] < 0 || a[1] < 0 || a[0] >= board.length || a[1] >= board[0].length || board[a[0]][a[1]] != word.charAt(a[2]) ? false : java.util.stream.Stream.of(board[a[0]][a[1]]).map(t -> java.util.stream.Stream.of(board[a[0]][a[1]] = '*').map(dummy -> f[0].apply(new int[]{a[0]+1, a[1], a[2]+1}) || f[0].apply(new int[]{a[0]-1, a[1], a[2]+1}) || f[0].apply(new int[]{a[0], a[1]+1, a[2]+1}) || f[0].apply(new int[]{a[0], a[1]-1, a[2]+1})).map(res -> java.util.stream.Stream.of(board[a[0]][a[1]] = t).map(dummy -> res).findFirst().get()).findFirst().get()).findFirst().get()))).findFirst().get()).map(func -> java.util.stream.IntStream.range(0, board.length).boxed().flatMap(i -> java.util.stream.IntStream.range(0, board[0].length).mapToObj(j -> new int[]{i, j, 0})).anyMatch(func::apply)).findFirst().get();
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ^
#   cannot find symbol
#     symbol:   method apply(T)
#     location: class Object
#   where T is a type-variable:
#     T extends Object declared in interface Stream
# Line 9: error: incompatible types: Object cannot be converted to boolean
#         return java.util.stream.Stream.<java.util.function.Function<int[], Boolean>[]>of(new java.util.function.Function[1]).map(f -> java.util.stream.Stream.of(f[0] = (java.util.function.Function<int[], Boolean>) (a -> a[2] == word.length() ? true : (a[0] < 0 || a[1] < 0 || a[0] >= board.length || a[1] >= board[0].length || board[a[0]][a[1]] != word.charAt(a[2]) ? false : java.util.stream.Stream.of(board[a[0]][a[1]]).map(t -> java.util.stream.Stream.of(board[a[0]][a[1]] = '*').map(dummy -> f[0].apply(new int[]{a[0]+1, a[1], a[2]+1}) || f[0].apply(new int[]{a[0]-1, a[1], a[2]+1}) || f[0].apply(new int[]{a[0], a[1]+1, a[2]+1}) || f[0].apply(new int[]{a[0], a[1]-1, a[2]+1})).map(res -> java.util.stream.Stream.of(board[a[0]][a[1]] = t).map(dummy -> res).findFirst().get()).findFirst().get()).findFirst().get()))).findFirst().get()).map(func -> java.util.stream.IntStream.range(0, board.length).boxed().flatMap(i -> java.util.stream.IntStream.range(0, board[0].length).mapToObj(j -> new int[]{i, j, 0})).anyMatch(func::apply)).findFirst().get();
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ^
# 8 errors
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: java_solutions/80.remove-duplicates-from-sorted-array-ii.java
# - Downloading remove-duplicates-from-sorted-array-ii
#   ✔ Accepted
#   ✔ 170/170 cases passed (29 ms)
#   ✔ Your runtime beats 4 % of java submissions
#   ✔ Your memory usage beats 14.71 % of java submissions (55.7 MB)
# Submitting: java_solutions/81.search-in-rotated-sorted-array-ii.java
# - Downloading search-in-rotated-sorted-array-ii
#   ✔ Accepted
#   ✔ 284/284 cases passed (4 ms)
#   ✔ Your runtime beats 3.39 % of java submissions
#   ✔ Your memory usage beats 27.77 % of java submissions (45.1 MB)
# Submitting: java_solutions/82.remove-duplicates-from-sorted-list-ii.java
# - Downloading remove-duplicates-from-sorted-list-ii
#   ✔ Accepted
#   ✔ 166/166 cases passed (15 ms)
#   ✔ Your runtime beats 1.99 % of java submissions
#   ✔ Your memory usage beats 8.27 % of java submissions (52.6 MB)
# Submitting: java_solutions/83.remove-duplicates-from-sorted-list.java
# - Downloading remove-duplicates-from-sorted-list
#   ✔ Accepted
#   ✔ 168/168 cases passed (11 ms)
#   ✔ Your runtime beats 0.54 % of java submissions
#   ✔ Your memory usage beats 6.17 % of java submissions (46.7 MB)
# Submitting: java_solutions/84.largest-rectangle-in-histogram.java
# - Downloading largest-rectangle-in-histogram
#   ✔ Accepted
#   ✔ 99/99 cases passed (14 ms)
#   ✔ Your runtime beats 97.59 % of java submissions
#   ✔ Your memory usage beats 99.49 % of java submissions (73.5 MB)
# Submitting: java_solutions/85.maximal-rectangle.java
# - Downloading maximal-rectangle
#   ✔ Accepted
#   ✔ 76/76 cases passed (9 ms)
#   ✔ Your runtime beats 88.02 % of java submissions
#   ✔ Your memory usage beats 16.85 % of java submissions (51.7 MB)
# Submitting: java_solutions/86.partition-list.java
# - Downloading partition-list
#   ✘ Runtime Error
#   ✘ 2/168 cases passed (N/A)
#   ✘ Error: Line 9: java.lang.NullPointerException
#   ✘ Error: java.lang.NullPointerException
#   at line 220, java.base/java.util.Objects.requireNonNull
#   at line 113, java.base/java.util.Optional.of
#   at line 194, java.base/java.util.stream.FindOps$FindSink$OfRef.get
#   at line 191, java.base/java.util.stream.FindOps$FindSink$OfRef.get
#   at line 150, java.base/java.util.stream.FindOps$FindOp.evaluateSequential
#   at line 265, java.base/java.util.stream.AbstractPipeline.evaluate
#   at line 683, java.base/java.util.stream.ReferencePipeline.findFirst
#   at line 9, Solution.partition
#   at line 56, __DriverSolution__.__helper__
#   at line 89, __Driver__.main
#   ✘ Testcase: []
# 0
#   ✘ Answer:
#   ✘ Expected Answer: []
#   ✘ Stdout:
# Submitting: java_solutions/87.scramble-string.java
# - Downloading scramble-string
#   ✔ Accepted
#   ✔ 290/290 cases passed (9 ms)
#   ✔ Your runtime beats 32.12 % of java submissions
#   ✔ Your memory usage beats 91.54 % of java submissions (45.4 MB)
# Submitting: java_solutions/88.merge-sorted-array.java
# - Downloading merge-sorted-array
#   ✔ Accepted
#   ✔ 59/59 cases passed (6 ms)
#   ✔ Your runtime beats 3.51 % of java submissions
#   ✔ Your memory usage beats 7.08 % of java submissions (47.4 MB)
# Submitting: java_solutions/89.gray-code.java
# - Downloading gray-code
#   ✔ Accepted
#   ✔ 16/16 cases passed (7 ms)
#   ✔ Your runtime beats 21.11 % of java submissions
#   ✔ Your memory usage beats 99.64 % of java submissions (49.9 MB)
# Submitting: java_solutions/90.subsets-ii.java
# - Downloading subsets-ii
#   ✔ Accepted
#   ✔ 20/20 cases passed (13 ms)
#   ✔ Your runtime beats 6.53 % of java submissions
#   ✔ Your memory usage beats 10.25 % of java submissions (50 MB)
# Submitting: java_solutions/91.decode-ways.java
# - Downloading decode-ways
#   ✔ Accepted
#   ✔ 269/269 cases passed (5 ms)
#   ✔ Your runtime beats 3.93 % of java submissions
#   ✔ Your memory usage beats 35.75 % of java submissions (43.2 MB)
# Submitting: java_solutions/92.reverse-linked-list-ii.java
# - Downloading reverse-linked-list-ii
#   ✔ Accepted
#   ✔ 44/44 cases passed (8 ms)
#   ✔ Your runtime beats 0.51 % of java submissions
#   ✔ Your memory usage beats 12.52 % of java submissions (43.5 MB)
# Submitting: java_solutions/93.restore-ip-addresses.java
# - Downloading restore-ip-addresses
#   ✔ Accepted
#   ✔ 146/146 cases passed (13 ms)
#   ✔ Your runtime beats 5.01 % of java submissions
#   ✔ Your memory usage beats 48.64 % of java submissions (45.3 MB)
# Submitting: java_solutions/94.binary-tree-inorder-traversal.java
# - Downloading binary-tree-inorder-traversal
#   ✔ Accepted
#   ✔ 71/71 cases passed (7 ms)
#   ✔ Your runtime beats 0.11 % of java submissions
#   ✔ Your memory usage beats 14.33 % of java submissions (44 MB)
# Submitting: java_solutions/96.unique-binary-search-trees.java
# - Downloading unique-binary-search-trees
#   ✔ Accepted
#   ✔ 19/19 cases passed (5 ms)
#   ✔ Your runtime beats 7.44 % of java submissions
#   ✔ Your memory usage beats 13.63 % of java submissions (42.5 MB)
# Submitting: java_solutions/97.interleaving-string.java
# - Downloading interleaving-string
#   ✔ Accepted
#   ✔ 107/107 cases passed (13 ms)
#   ✔ Your runtime beats 5.58 % of java submissions
#   ✔ Your memory usage beats 5.04 % of java submissions (49.4 MB)
# Submitting: java_solutions/100.same-tree.java
# - Downloading same-tree
#   ✔ Accepted
#   ✔ 67/67 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 70.2 % of java submissions (42.7 MB)
# Submitting: java_solutions/101.symmetric-tree.java
# - Downloading symmetric-tree
#   ✔ Accepted
#   ✔ 200/200 cases passed (13 ms)
#   ✔ Your runtime beats 0.43 % of java submissions
#   ✔ Your memory usage beats 15.5 % of java submissions (44.8 MB)
# Submitting: java_solutions/102.binary-tree-level-order-traversal.java
# - Downloading binary-tree-level-order-traversal
#   ✔ Accepted
#   ✔ 35/35 cases passed (11 ms)
#   ✔ Your runtime beats 1.79 % of java submissions
#   ✔ Your memory usage beats 40.52 % of java submissions (46.9 MB)
# Submitting: java_solutions/103.binary-tree-zigzag-level-order-traversal.java
# - Downloading binary-tree-zigzag-level-order-traversal
#   ✔ Accepted
#   ✔ 33/33 cases passed (11 ms)
#   ✔ Your runtime beats 0.44 % of java submissions
#   ✔ Your memory usage beats 9.47 % of java submissions (44.7 MB)
# Submitting: java_solutions/104.maximum-depth-of-binary-tree.java
# - Downloading maximum-depth-of-binary-tree
#   ✔ Accepted
#   ✔ 39/39 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 64.36 % of java submissions (44.4 MB)
# Submitting: java_solutions/107.binary-tree-level-order-traversal-ii.java
# - Downloading binary-tree-level-order-traversal-ii
#   ✔ Accepted
#   ✔ 34/34 cases passed (12 ms)
#   ✔ Your runtime beats 0.54 % of java submissions
#   ✔ Your memory usage beats 7.97 % of java submissions (46.7 MB)
# Submitting: java_solutions/110.balanced-binary-tree.java
# - Downloading balanced-binary-tree
#   ✔ Accepted
#   ✔ 228/228 cases passed (12 ms)
#   ✔ Your runtime beats 2.33 % of java submissions
#   ✔ Your memory usage beats 5.16 % of java submissions (46.9 MB)
# Submitting: java_solutions/111.minimum-depth-of-binary-tree.java
# - Downloading minimum-depth-of-binary-tree
#   ✔ Accepted
#   ✔ 53/53 cases passed (128 ms)
#   ✔ Your runtime beats 6.36 % of java submissions
#   ✔ Your memory usage beats 11.92 % of java submissions (99.1 MB)
# Submitting: java_solutions/112.path-sum.java
# - Downloading path-sum
#   ✔ Accepted
#   ✔ 118/118 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 48.89 % of java submissions (45 MB)
# Submitting: java_solutions/114.flatten-binary-tree-to-linked-list.java
# - Downloading flatten-binary-tree-to-linked-list
#   ✔ Accepted
#   ✔ 225/225 cases passed (20 ms)
#   ✔ Your runtime beats 0.48 % of java submissions
#   ✔ Your memory usage beats 15.55 % of java submissions (46.7 MB)
# Submitting: java_solutions/115.distinct-subsequences.java
# - Downloading distinct-subsequences
#   ✔ Accepted
#   ✔ 66/66 cases passed (18 ms)
#   ✔ Your runtime beats 77.88 % of java submissions
#   ✔ Your memory usage beats 91.69 % of java submissions (42.9 MB)
# Submitting: java_solutions/116.populating-next-right-pointers-in-each-node.java
# - Downloading populating-next-right-pointers-in-each-node
#   ✔ Accepted
#   ✔ 59/59 cases passed (16 ms)
#   ✔ Your runtime beats 4.96 % of java submissions
#   ✔ Your memory usage beats 6.09 % of java submissions (47.5 MB)
# Submitting: java_solutions/117.populating-next-right-pointers-in-each-node-ii.java
# - Downloading populating-next-right-pointers-in-each-node-ii
#   ✔ Accepted
#   ✔ 55/55 cases passed (13 ms)
#   ✔ Your runtime beats 1.39 % of java submissions
#   ✔ Your memory usage beats 6.34 % of java submissions (46.9 MB)
# Submitting: java_solutions/118.pascals-triangle.java
# - Downloading pascals-triangle
#   ✔ Accepted
#   ✔ 30/30 cases passed (6 ms)
#   ✔ Your runtime beats 0.71 % of java submissions
#   ✔ Your memory usage beats 15.77 % of java submissions (43.9 MB)
# Submitting: java_solutions/119.pascals-triangle-ii.java
# - Downloading pascals-triangle-ii
#   ✔ Accepted
#   ✔ 34/34 cases passed (7 ms)
#   ✔ Your runtime beats 1.14 % of java submissions
#   ✔ Your memory usage beats 6.44 % of java submissions (43.3 MB)
# Submitting: java_solutions/120.triangle.java
# - Downloading triangle
#   ✔ Accepted
#   ✔ 46/46 cases passed (7 ms)
#   ✔ Your runtime beats 20.88 % of java submissions
#   ✔ Your memory usage beats 8.22 % of java submissions (46.8 MB)
# Submitting: java_solutions/121.best-time-to-buy-and-sell-stock.java
# - Downloading best-time-to-buy-and-sell-stock
#   ✔ Accepted
#   ✔ 212/212 cases passed (18 ms)
#   ✔ Your runtime beats 1.48 % of java submissions
#   ✔ Your memory usage beats 14.9 % of java submissions (100.1 MB)
# Submitting: java_solutions/122.best-time-to-buy-and-sell-stock-ii.java
# - Downloading best-time-to-buy-and-sell-stock-ii
#   ✔ Accepted
#   ✔ 203/203 cases passed (5 ms)
#   ✔ Your runtime beats 4.91 % of java submissions
#   ✔ Your memory usage beats 16.33 % of java submissions (46.6 MB)
# Submitting: java_solutions/123.best-time-to-buy-and-sell-stock-iii.java
# - Downloading best-time-to-buy-and-sell-stock-iii
#   ✔ Accepted
#   ✔ 214/214 cases passed (4 ms)
#   ✔ Your runtime beats 51.62 % of java submissions
#   ✔ Your memory usage beats 88.19 % of java submissions (75.6 MB)
# Submitting: java_solutions/124.binary-tree-maximum-path-sum.java
# - Downloading binary-tree-maximum-path-sum
#   ✔ Accepted
#   ✔ 96/96 cases passed (31 ms)
#   ✔ Your runtime beats 2.09 % of java submissions
#   ✔ Your memory usage beats 7.59 % of java submissions (49.6 MB)
# Submitting: java_solutions/125.valid-palindrome.java
# - Downloading valid-palindrome
#   ✔ Accepted
#   ✔ 488/488 cases passed (18 ms)
#   ✔ Your runtime beats 10.04 % of java submissions
#   ✔ Your memory usage beats 11.06 % of java submissions (47.4 MB)
# Submitting: java_solutions/126.word-ladder-ii.java
# - Downloading word-ladder-ii
#   ✔ Accepted
#   ✔ 38/38 cases passed (31 ms)
#   ✔ Your runtime beats 5.06 % of java submissions
#   ✔ Your memory usage beats 5.16 % of java submissions (48.7 MB)
# Submitting: java_solutions/127.word-ladder.java
# - Downloading word-ladder
#   ✔ Accepted
#   ✔ 52/52 cases passed (103 ms)
#   ✔ Your runtime beats 25.73 % of java submissions
#   ✔ Your memory usage beats 17.17 % of java submissions (49.8 MB)
# Submitting: java_solutions/128.longest-consecutive-sequence.java
# - Downloading longest-consecutive-sequence
#   ✔ Accepted
#   ✔ 85/85 cases passed (108 ms)
#   ✔ Your runtime beats 5.05 % of java submissions
#   ✔ Your memory usage beats 71.72 % of java submissions (94.5 MB)
# Submitting: java_solutions/129.sum-root-to-leaf-numbers.java
# - Downloading sum-root-to-leaf-numbers
#   ✔ Accepted
#   ✔ 108/108 cases passed (13 ms)
#   ✔ Your runtime beats 1.59 % of java submissions
#   ✔ Your memory usage beats 13.25 % of java submissions (44 MB)
# Submitting: java_solutions/132.palindrome-partitioning-ii.java
# - Downloading palindrome-partitioning-ii
#   ✔ Accepted
#   ✔ 37/37 cases passed (31 ms)
#   ✔ Your runtime beats 66.23 % of java submissions
#   ✔ Your memory usage beats 42.86 % of java submissions (47.6 MB)
# Submitting: java_solutions/134.gas-station.java
# - Downloading gas-station
#   ✔ Accepted
#   ✔ 40/40 cases passed (19 ms)
#   ✔ Your runtime beats 5.02 % of java submissions
#   ✔ Your memory usage beats 9.73 % of java submissions (120.9 MB)
# Submitting: java_solutions/135.candy.java
# - Downloading candy
#   ✔ Accepted
#   ✔ 50/50 cases passed (5 ms)
#   ✔ Your runtime beats 9.56 % of java submissions
#   ✔ Your memory usage beats 84.24 % of java submissions (47.5 MB)
# Submitting: java_solutions/136.single-number.java
# - Downloading single-number
#   ✔ Accepted
#   ✔ 61/61 cases passed (28 ms)
#   ✔ Your runtime beats 7.98 % of java submissions
#   ✔ Your memory usage beats 5.21 % of java submissions (53.5 MB)
# Submitting: java_solutions/137.single-number-ii.java
# - Downloading single-number-ii
#   ✔ Accepted
#   ✔ 15/15 cases passed (17 ms)
#   ✔ Your runtime beats 5.51 % of java submissions
#   ✔ Your memory usage beats 5.12 % of java submissions (53.3 MB)
# Submitting: java_solutions/138.copy-list-with-random-pointer.java
# - Downloading copy-list-with-random-pointer
#   ✔ Accepted
#   ✔ 19/19 cases passed (6 ms)
#   ✔ Your runtime beats 0.57 % of java submissions
#   ✔ Your memory usage beats 13.99 % of java submissions (46.9 MB)
# Submitting: java_solutions/139.word-break.java
# - Downloading word-break
#   ✔ Accepted
#   ✔ 48/48 cases passed (25 ms)
#   ✔ Your runtime beats 6.61 % of java submissions
#   ✔ Your memory usage beats 11.4 % of java submissions (52.3 MB)
# Submitting: java_solutions/140.word-break-ii.java
# - Downloading word-break-ii
#   ✔ Accepted
#   ✔ 29/29 cases passed (3 ms)
#   ✔ Your runtime beats 51.36 % of java submissions
#   ✔ Your memory usage beats 29.88 % of java submissions (48.6 MB)
# Submitting: java_solutions/141.linked-list-cycle.java
# - Downloading linked-list-cycle
#   ✔ Accepted
#   ✔ 29/29 cases passed (12 ms)
#   ✔ Your runtime beats 9.49 % of java submissions
#   ✔ Your memory usage beats 92.57 % of java submissions (46.4 MB)
# Submitting: java_solutions/142.linked-list-cycle-ii.java
# - Downloading linked-list-cycle-ii
#   ✔ Accepted
#   ✔ 18/18 cases passed (10 ms)
#   ✔ Your runtime beats 9.91 % of java submissions
#   ✔ Your memory usage beats 85.3 % of java submissions (46.4 MB)
# Submitting: java_solutions/143.reorder-list.java
# - Downloading reorder-list
#   ✔ Accepted
#   ✔ 12/12 cases passed (16 ms)
#   ✔ Your runtime beats 5.44 % of java submissions
#   ✔ Your memory usage beats 98.77 % of java submissions (48.7 MB)
# Submitting: java_solutions/144.binary-tree-preorder-traversal.java
# - Downloading binary-tree-preorder-traversal
#   ✔ Accepted
#   ✔ 71/71 cases passed (4 ms)
#   ✔ Your runtime beats 0.13 % of java submissions
#   ✔ Your memory usage beats 14.27 % of java submissions (43.5 MB)
# Submitting: java_solutions/145.binary-tree-postorder-traversal.java
# - Downloading binary-tree-postorder-traversal
#   ✔ Accepted
#   ✔ 71/71 cases passed (4 ms)
#   ✔ Your runtime beats 0.1 % of java submissions
#   ✔ Your memory usage beats 14.21 % of java submissions (43.6 MB)
# Submitting: java_solutions/146.lru-cache.java
# - Downloading lru-cache
#   ✔ Accepted
#   ✔ 24/24 cases passed (45 ms)
#   ✔ Your runtime beats 74.3 % of java submissions
#   ✔ Your memory usage beats 82.51 % of java submissions (130.8 MB)
# Submitting: java_solutions/147.insertion-sort-list.java
# - Downloading insertion-sort-list
#   ✔ Accepted
#   ✔ 19/19 cases passed (11 ms)
#   ✔ Your runtime beats 74.58 % of java submissions
#   ✔ Your memory usage beats 9.96 % of java submissions (46.8 MB)
# Submitting: java_solutions/148.sort-list.java
# - Downloading sort-list
#   ✔ Accepted
#   ✔ 30/30 cases passed (29 ms)
#   ✔ Your runtime beats 6.86 % of java submissions
#   ✔ Your memory usage beats 5.36 % of java submissions (65.5 MB)
# Submitting: java_solutions/149.max-points-on-a-line.java
# - Downloading max-points-on-a-line
#   ✔ Accepted
#   ✔ 42/42 cases passed (40 ms)
#   ✔ Your runtime beats 8.36 % of java submissions
#   ✔ Your memory usage beats 5.95 % of java submissions (47.6 MB)
# Submitting: java_solutions/150.evaluate-reverse-polish-notation.java
# - Downloading evaluate-reverse-polish-notation
#   ✔ Accepted
#   ✔ 22/22 cases passed (20 ms)
#   ✔ Your runtime beats 5.92 % of java submissions
#   ✔ Your memory usage beats 6.28 % of java submissions (47.8 MB)
# Submitting: java_solutions/151.reverse-words-in-a-string.java
# - Downloading reverse-words-in-a-string
#   ✔ Accepted
#   ✔ 62/62 cases passed (9 ms)
#   ✔ Your runtime beats 23.56 % of java submissions
#   ✔ Your memory usage beats 23.92 % of java submissions (45 MB)
# Submitting: java_solutions/152.maximum-product-subarray.java
# - Downloading maximum-product-subarray
#   ✔ Accepted
#   ✔ 191/191 cases passed (6 ms)
#   ✔ Your runtime beats 11.93 % of java submissions
#   ✔ Your memory usage beats 98.55 % of java submissions (46.6 MB)
# Submitting: java_solutions/153.find-minimum-in-rotated-sorted-array.java
# - Downloading find-minimum-in-rotated-sorted-array
#   ✔ Accepted
#   ✔ 150/150 cases passed (2 ms)
#   ✔ Your runtime beats 4.62 % of java submissions
#   ✔ Your memory usage beats 36.3 % of java submissions (43.8 MB)
# Submitting: java_solutions/154.find-minimum-in-rotated-sorted-array-ii.java
# - Downloading find-minimum-in-rotated-sorted-array-ii
#   ✔ Accepted
#   ✔ 193/193 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 54.36 % of java submissions (44.8 MB)
# Submitting: java_solutions/160.intersection-of-two-linked-lists.java
# - Downloading intersection-of-two-linked-lists
#   ✔ Accepted
#   ✔ 41/41 cases passed (23 ms)
#   ✔ Your runtime beats 5.84 % of java submissions
#   ✔ Your memory usage beats 12.32 % of java submissions (56.6 MB)
# Submitting: java_solutions/162.find-peak-element.java
# - Downloading find-peak-element
#   ✔ Accepted
#   ✔ 73/73 cases passed (4 ms)
#   ✔ Your runtime beats 0.58 % of java submissions
#   ✔ Your memory usage beats 5.42 % of java submissions (44.4 MB)
# Submitting: java_solutions/164.maximum-gap.java
# - Downloading maximum-gap
#   ✔ Accepted
#   ✔ 46/46 cases passed (65 ms)
#   ✔ Your runtime beats 5.21 % of java submissions
#   ✔ Your memory usage beats 78.25 % of java submissions (88.6 MB)
# Submitting: java_solutions/165.compare-version-numbers.java
# - Downloading compare-version-numbers
#   ✔ Accepted
#   ✔ 90/90 cases passed (14 ms)
#   ✔ Your runtime beats 2.71 % of java submissions
#   ✔ Your memory usage beats 10.72 % of java submissions (47.3 MB)
# Submitting: java_solutions/167.two-sum-ii-input-array-is-sorted.java
# - Downloading two-sum-ii-input-array-is-sorted
#   ✔ Accepted
#   ✔ 24/24 cases passed (8 ms)
#   ✔ Your runtime beats 7.91 % of java submissions
#   ✔ Your memory usage beats 41.23 % of java submissions (48.4 MB)
# Submitting: java_solutions/168.excel-sheet-column-title.java
# - Downloading excel-sheet-column-title
#   ✔ Accepted
#   ✔ 22/22 cases passed (4 ms)
#   ✔ Your runtime beats 1.3 % of java submissions
#   ✔ Your memory usage beats 8.2 % of java submissions (42.7 MB)
# Submitting: java_solutions/169.majority-element.java
# - Downloading majority-element
#   ✔ Accepted
#   ✔ 53/53 cases passed (27 ms)
#   ✔ Your runtime beats 7.98 % of java submissions
#   ✔ Your memory usage beats 6.63 % of java submissions (57.1 MB)

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-05-12 16:49:38
