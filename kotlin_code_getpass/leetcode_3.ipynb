# %%
# %%capture
import os
import getpass

# 2. Interactive input (Safe and hidden)
print("Please enter your LeetCode credentials:")
user_name = getpass.getpass('LeetCode Username: ')
user_cookie = getpass.getpass('LeetCode Session Token: ')

# 1. Install and Clone
# !npm install -g leetcode-tools/leetcode-cli
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME'] = user_name
    os.environ['LEETCODE_TOKEN'] = user_cookie

    # 4. Run the login silently
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME" "$LEETCODE_TOKEN" | leetcode user -c

# %%
# %%bash
#
# # top 200-300 answers (next batch)
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v kotlin_solutions/*.kt | sed -n '201,300p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 7
# done
# Out:
# Submitting: kotlin_solutions/225.implement-stack-using-queues.kt
# - Downloading implement-stack-using-queues
#   ✔ Accepted
#   ✔ 20/20 cases passed (29 ms)
#   ✔ Your runtime beats 6.9 % of kotlin submissions
#   ✔ Your memory usage beats 31.9 % of kotlin submissions (46.3 MB)
# Submitting: kotlin_solutions/226.invert-binary-tree.kt
# - Downloading invert-binary-tree
#   ✔ Accepted
#   ✔ 77/77 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 89.68 % of kotlin submissions (40.4 MB)
# Submitting: kotlin_solutions/227.basic-calculator-ii.kt
# - Downloading basic-calculator-ii
#   ✔ Accepted
#   ✔ 111/111 cases passed (61 ms)
#   ✔ Your runtime beats 26.36 % of kotlin submissions
#   ✔ Your memory usage beats 31.82 % of kotlin submissions (53.2 MB)
# Submitting: kotlin_solutions/228.summary-ranges.kt
# - Downloading summary-ranges
#   ✔ Accepted
#   ✔ 34/34 cases passed (13 ms)
#   ✔ Your runtime beats 18.18 % of kotlin submissions
#   ✔ Your memory usage beats 22.97 % of kotlin submissions (43.2 MB)
# Submitting: kotlin_solutions/229.majority-element-ii.kt
# - Downloading majority-element-ii
#   ✔ Accepted
#   ✔ 95/95 cases passed (21 ms)
#   ✔ Your runtime beats 36.78 % of kotlin submissions
#   ✔ Your memory usage beats 10.34 % of kotlin submissions (56.9 MB)
# Submitting: kotlin_solutions/230.kth-smallest-element-in-a-bst.kt
# - Downloading kth-smallest-element-in-a-bst
#   ✔ Accepted
#   ✔ 93/93 cases passed (28 ms)
#   ✔ Your runtime beats 5.28 % of kotlin submissions
#   ✔ Your memory usage beats 6.41 % of kotlin submissions (49.6 MB)
# Submitting: kotlin_solutions/231.power-of-two.kt
# - Downloading power-of-two
#   ✔ Accepted
#   ✔ 1110/1110 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 70.83 % of kotlin submissions (40.9 MB)
# Submitting: kotlin_solutions/232.implement-queue-using-stacks.kt
# - Downloading implement-queue-using-stacks
#   ✔ Accepted
#   ✔ 22/22 cases passed (15 ms)
#   ✔ Your runtime beats 65.5 % of kotlin submissions
#   ✔ Your memory usage beats 61.14 % of kotlin submissions (42.9 MB)
# Submitting: kotlin_solutions/233.number-of-digit-one.kt
# - Downloading number-of-digit-one
#   ✔ Accepted
#   ✔ 38/38 cases passed (8 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
#   ✔ Your memory usage beats 41.67 % of kotlin submissions (41 MB)
# Submitting: kotlin_solutions/234.palindrome-linked-list.kt
# - Downloading palindrome-linked-list
#   ✔ Accepted
#   ✔ 93/93 cases passed (39 ms)
#   ✔ Your runtime beats 8.75 % of kotlin submissions
#   ✔ Your memory usage beats 20.42 % of kotlin submissions (63 MB)
# Submitting: kotlin_solutions/235.lowest-common-ancestor-of-a-binary-search-tree.kt
# - Downloading lowest-common-ancestor-of-a-binary-search-tree
#   ✔ Accepted
#   ✔ 30/30 cases passed (187 ms)
#   ✔ Your runtime beats 68.44 % of kotlin submissions
#   ✔ Your memory usage beats 42.59 % of kotlin submissions (48 MB)
# Submitting: kotlin_solutions/236.lowest-common-ancestor-of-a-binary-tree.kt
# - Downloading lowest-common-ancestor-of-a-binary-tree
#   ✔ Accepted
#   ✔ 32/32 cases passed (158 ms)
#   ✔ Your runtime beats 63.96 % of kotlin submissions
#   ✔ Your memory usage beats 77.67 % of kotlin submissions (45.9 MB)
# Submitting: kotlin_solutions/237.delete-node-in-a-linked-list.kt
# - Downloading delete-node-in-a-linked-list
#   ✔ Accepted
#   ✔ 41/41 cases passed (127 ms)
#   ✔ Your runtime beats 31.76 % of kotlin submissions
#   ✔ Your memory usage beats 14.12 % of kotlin submissions (43.8 MB)
# Submitting: kotlin_solutions/238.product-of-array-except-self.kt
# - Downloading product-of-array-except-self
#   ✔ Accepted
#   ✔ 24/24 cases passed (52 ms)
#   ✔ Your runtime beats 5.09 % of kotlin submissions
#   ✔ Your memory usage beats 12.79 % of kotlin submissions (64 MB)
# Submitting: kotlin_solutions/239.sliding-window-maximum.kt
# - Downloading sliding-window-maximum
#   ✔ Accepted
#   ✔ 52/52 cases passed (116 ms)
#   ✔ Your runtime beats 20.43 % of kotlin submissions
#   ✔ Your memory usage beats 5.11 % of kotlin submissions (72.1 MB)
# Submitting: kotlin_solutions/240.search-a-2-d-matrix-ii.kt
# - Downloading search-a-2d-matrix-ii
#   ✔ Accepted
#   ✔ 130/130 cases passed (215 ms)
#   ✔ Your runtime beats 34.88 % of kotlin submissions
#   ✔ Your memory usage beats 69.77 % of kotlin submissions (51 MB)
# Submitting: kotlin_solutions/241.different-ways-to-add-parentheses.kt
# - Downloading different-ways-to-add-parentheses
#   ✔ Accepted
#   ✔ 25/25 cases passed (18 ms)
#   ✔ Your runtime beats 64.71 % of kotlin submissions
#   ✔ Your memory usage beats 58.82 % of kotlin submissions (44.7 MB)
# Submitting: kotlin_solutions/242.valid-anagram.kt
# - Downloading valid-anagram
#   ✔ Accepted
#   ✔ 54/54 cases passed (20 ms)
#   ✔ Your runtime beats 52.28 % of kotlin submissions
#   ✔ Your memory usage beats 32.87 % of kotlin submissions (46.1 MB)
# Submitting: kotlin_solutions/257.binary-tree-paths.kt
# - Downloading binary-tree-paths
#   ✔ Accepted
#   ✔ 208/208 cases passed (27 ms)
#   ✔ Your runtime beats 6.96 % of kotlin submissions
#   ✔ Your memory usage beats 5.22 % of kotlin submissions (47.5 MB)
# Submitting: kotlin_solutions/258.add-digits.kt
# - Downloading add-digits
#   ✔ Accepted
#   ✔ 1101/1101 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 68 % of kotlin submissions (40.9 MB)
# Submitting: kotlin_solutions/260.single-number-iii.kt
# - Downloading single-number-iii
#   ✔ Accepted
#   ✔ 35/35 cases passed (16 ms)
#   ✔ Your runtime beats 12.5 % of kotlin submissions
#   ✔ Your memory usage beats 54.17 % of kotlin submissions (46.9 MB)
# Submitting: kotlin_solutions/263.ugly-number.kt
# - Downloading ugly-number
#   ✔ Accepted
#   ✔ 1013/1013 cases passed (10 ms)
#   ✔ Your runtime beats 18.67 % of kotlin submissions
#   ✔ Your memory usage beats 18.67 % of kotlin submissions (42 MB)
# Submitting: kotlin_solutions/264.ugly-number-ii.kt
# - Downloading ugly-number-ii
#   ✔ Accepted
#   ✔ 596/596 cases passed (57 ms)
#   ✔ Your runtime beats 30 % of kotlin submissions
#   ✔ Your memory usage beats 6.67 % of kotlin submissions (52.2 MB)
# Submitting: kotlin_solutions/268.missing-number.kt
# - Downloading missing-number
#   ✔ Accepted
#   ✔ 122/122 cases passed (10 ms)
#   ✔ Your runtime beats 48.59 % of kotlin submissions
#   ✔ Your memory usage beats 72.64 % of kotlin submissions (47.8 MB)
# Submitting: kotlin_solutions/273.integer-to-english-words.kt
# - Downloading integer-to-english-words
#   ✔ Accepted
#   ✔ 601/601 cases passed (33 ms)
#   ✔ Your runtime beats 17.39 % of kotlin submissions
#   ✔ Your memory usage beats 6.52 % of kotlin submissions (47.7 MB)
# Submitting: kotlin_solutions/274.h-index.kt
# - Downloading h-index
#   ✔ Accepted
#   ✔ 83/83 cases passed (21 ms)
#   ✔ Your runtime beats 10.09 % of kotlin submissions
#   ✔ Your memory usage beats 10.09 % of kotlin submissions (46.2 MB)
# Submitting: kotlin_solutions/275.h-index-ii.kt
# - Downloading h-index-ii
#   ✔ Accepted
#   ✔ 83/83 cases passed (19 ms)
#   ✔ Your runtime beats 35 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (54.6 MB)
# Submitting: kotlin_solutions/278.first-bad-version.kt
# - Downloading first-bad-version
#   ✔ Accepted
#   ✔ 24/24 cases passed (200 ms)
#   ✔ Your runtime beats 80.14 % of kotlin submissions
#   ✔ Your memory usage beats 6.86 % of kotlin submissions (40.1 MB)
# Submitting: kotlin_solutions/279.perfect-squares.kt
# - Downloading perfect-squares
#   ✔ Accepted
#   ✔ 589/589 cases passed (48 ms)
#   ✔ Your runtime beats 48.78 % of kotlin submissions
#   ✔ Your memory usage beats 52.44 % of kotlin submissions (46.3 MB)
# Submitting: kotlin_solutions/282.expression-add-operators.kt
# - Downloading expression-add-operators
#   ✔ Accepted
#   ✔ 25/25 cases passed (92 ms)
#   ✔ Your runtime beats 88.89 % of kotlin submissions
#   ✔ Your memory usage beats 77.78 % of kotlin submissions (55.7 MB)
# Submitting: kotlin_solutions/283.move-zeroes.kt
# - Downloading move-zeroes
#   ✔ Accepted
#   ✔ 75/75 cases passed (19 ms)
#   ✔ Your runtime beats 12.81 % of kotlin submissions
#   ✔ Your memory usage beats 18.43 % of kotlin submissions (52.1 MB)
# Submitting: kotlin_solutions/284.peeking-iterator.kt
# - Downloading peeking-iterator
#   ✔ Accepted
#   ✔ 15/15 cases passed (134 ms)
#   ✔ Your runtime beats 5.26 % of kotlin submissions
#   ✔ Your memory usage beats 26.32 % of kotlin submissions (43.4 MB)
# Submitting: kotlin_solutions/287.find-the-duplicate-number.kt
# - Downloading find-the-duplicate-number
#   ✔ Accepted
#   ✔ 59/59 cases passed (44 ms)
#   ✔ Your runtime beats 14.8 % of kotlin submissions
#   ✔ Your memory usage beats 85.71 % of kotlin submissions (62.1 MB)
# Submitting: kotlin_solutions/289.game-of-life.kt
# - Downloading game-of-life
#   ✔ Accepted
#   ✔ 23/23 cases passed (23 ms)
#   ✔ Your runtime beats 5.08 % of kotlin submissions
#   ✔ Your memory usage beats 13.56 % of kotlin submissions (45.8 MB)
# Submitting: kotlin_solutions/290.word-pattern.kt
# - Downloading word-pattern
#   ✔ Accepted
#   ✔ 44/44 cases passed (17 ms)
#   ✔ Your runtime beats 10.58 % of kotlin submissions
#   ✔ Your memory usage beats 7.41 % of kotlin submissions (43.4 MB)
# Submitting: kotlin_solutions/292.nim-game.kt
# - Downloading nim-game
#   ✔ Accepted
#   ✔ 60/60 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 58.54 % of kotlin submissions (40.1 MB)
# Submitting: kotlin_solutions/295.find-median-from-data-stream.kt
# - Downloading find-median-from-data-stream
#   ✔ Accepted
#   ✔ 22/22 cases passed (503 ms)
#   ✔ Your runtime beats 6.12 % of kotlin submissions
#   ✔ Your memory usage beats 35.71 % of kotlin submissions (111.2 MB)
# Submitting: kotlin_solutions/297.serialize-and-deserialize-binary-tree.kt
# - Downloading serialize-and-deserialize-binary-tree
#   ✔ Accepted
#   ✔ 53/53 cases passed (271 ms)
#   ✔ Your runtime beats 13.1 % of kotlin submissions
#   ✔ Your memory usage beats 52.41 % of kotlin submissions (50 MB)
# Submitting: kotlin_solutions/299.bulls-and-cows.kt
# - Downloading bulls-and-cows
#   ✔ Accepted
#   ✔ 152/152 cases passed (22 ms)
#   ✔ Your runtime beats 35.71 % of kotlin submissions
#   ✔ Your memory usage beats 10.71 % of kotlin submissions (47 MB)
# Submitting: kotlin_solutions/300.longest-increasing-subsequence.kt
# - Downloading longest-increasing-subsequence
#   ✔ Accepted
#   ✔ 56/56 cases passed (16 ms)
#   ✔ Your runtime beats 77.07 % of kotlin submissions
#   ✔ Your memory usage beats 87.97 % of kotlin submissions (46.7 MB)
# Submitting: kotlin_solutions/301.remove-invalid-parentheses.kt
# - Downloading remove-invalid-parentheses
#   ✔ Accepted
#   ✔ 129/129 cases passed (1402 ms)
#   ✔ Your runtime beats 8.33 % of kotlin submissions
#   ✔ Your memory usage beats 18.75 % of kotlin submissions (65.1 MB)
# Submitting: kotlin_solutions/303.range-sum-query-immutable.kt
# - Downloading range-sum-query-immutable
#   ✔ Accepted
#   ✔ 15/15 cases passed (24 ms)
#   ✔ Your runtime beats 75.14 % of kotlin submissions
#   ✔ Your memory usage beats 33.51 % of kotlin submissions (53 MB)
# Submitting: kotlin_solutions/304.range-sum-query-2-d-immutable.kt
# - Downloading range-sum-query-2d-immutable
#   ✔ Accepted
#   ✔ 22/22 cases passed (141 ms)
#   ✔ Your runtime beats 58.18 % of kotlin submissions
#   ✔ Your memory usage beats 38.18 % of kotlin submissions (97.2 MB)
# Submitting: kotlin_solutions/306.additive-number.kt
# - Downloading additive-number
#   ✔ Accepted
#   ✔ 47/47 cases passed (16 ms)
#   ✔ Your runtime beats 10 % of kotlin submissions
#   ✔ Your memory usage beats 40 % of kotlin submissions (42.8 MB)
# Submitting: kotlin_solutions/307.range-sum-query-mutable.kt
# - Downloading range-sum-query-mutable
#   ✔ Accepted
#   ✔ 16/16 cases passed (209 ms)
#   ✔ Your runtime beats 24.56 % of kotlin submissions
#   ✔ Your memory usage beats 78.95 % of kotlin submissions (93.9 MB)
# Submitting: kotlin_solutions/309.best-time-to-buy-and-sell-stock-with-cooldown.kt
# - Downloading best-time-to-buy-and-sell-stock-with-cooldown
#   ✔ Accepted
#   ✔ 210/210 cases passed (20 ms)
#   ✔ Your runtime beats 16.09 % of kotlin submissions
#   ✔ Your memory usage beats 26.44 % of kotlin submissions (46.7 MB)
# Submitting: kotlin_solutions/310.minimum-height-trees.kt
# - Downloading minimum-height-trees
#   ✔ Accepted
#   ✔ 71/71 cases passed (62 ms)
#   ✔ Your runtime beats 25.76 % of kotlin submissions
#   ✔ Your memory usage beats 30.3 % of kotlin submissions (78.2 MB)
# Submitting: kotlin_solutions/312.burst-balloons.kt
# - Downloading burst-balloons
#   ✔ Accepted
#   ✔ 73/73 cases passed (168 ms)
#   ✔ Your runtime beats 23.4 % of kotlin submissions
#   ✔ Your memory usage beats 27.66 % of kotlin submissions (51.4 MB)
# Submitting: kotlin_solutions/313.super-ugly-number.kt
# - Downloading super-ugly-number
#   ✔ Accepted
#   ✔ 87/87 cases passed (110 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (48.1 MB)
# Submitting: kotlin_solutions/315.count-of-smaller-numbers-after-self.kt
# - Downloading count-of-smaller-numbers-after-self
#   ✔ Accepted
#   ✔ 66/66 cases passed (353 ms)
#   ✔ Your runtime beats 10.34 % of kotlin submissions
#   ✔ Your memory usage beats 68.97 % of kotlin submissions (67.5 MB)
# Submitting: kotlin_solutions/316.remove-duplicate-letters.kt
# - Downloading remove-duplicate-letters
#   ✔ Accepted
#   ✔ 290/290 cases passed (40 ms)
#   ✔ Your runtime beats 12.07 % of kotlin submissions
#   ✔ Your memory usage beats 20.69 % of kotlin submissions (47.9 MB)
# Submitting: kotlin_solutions/318.maximum-product-of-word-lengths.kt
# - Downloading maximum-product-of-word-lengths
#   ✔ Accepted
#   ✔ 168/168 cases passed (2071 ms)
#   ✔ Your runtime beats 5.26 % of kotlin submissions
#   ✔ Your memory usage beats 10.53 % of kotlin submissions (140.2 MB)
# Submitting: kotlin_solutions/319.bulb-switcher.kt
# - Downloading bulb-switcher
#   ✔ Accepted
#   ✔ 35/35 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 75 % of kotlin submissions (39.9 MB)
# Submitting: kotlin_solutions/321.create-maximum-number.kt
# - Downloading create-maximum-number
#   ✔ Accepted
#   ✔ 102/102 cases passed (95 ms)
#   ✔ Your runtime beats 37.5 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (55.2 MB)
# Submitting: kotlin_solutions/322.coin-change.kt
# - Downloading coin-change
#   ✔ Accepted
#   ✔ 189/189 cases passed (26 ms)
#   ✔ Your runtime beats 39.36 % of kotlin submissions
#   ✔ Your memory usage beats 44.55 % of kotlin submissions (45.8 MB)
# Submitting: kotlin_solutions/324.wiggle-sort-ii.kt
# - Downloading wiggle-sort-ii
#   ✔ Accepted
#   ✔ 52/52 cases passed (32 ms)
#   ✔ Your runtime beats 52.94 % of kotlin submissions
#   ✔ Your memory usage beats 94.12 % of kotlin submissions (50.7 MB)
# Submitting: kotlin_solutions/326.power-of-three.kt
# - Downloading power-of-three
#   ✔ Accepted
#   ✔ 21040/21040 cases passed (7 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 11.63 % of kotlin submissions (47.2 MB)
# Submitting: kotlin_solutions/327.count-of-range-sum.kt
# - Downloading count-of-range-sum
#   ✔ Accepted
#   ✔ 67/67 cases passed (129 ms)
#   ✔ Your runtime beats 68.18 % of kotlin submissions
#   ✔ Your memory usage beats 72.73 % of kotlin submissions (65.5 MB)
# Submitting: kotlin_solutions/328.odd-even-linked-list.kt
# - Downloading odd-even-linked-list
#   ✔ Accepted
#   ✔ 70/70 cases passed (7 ms)
#   ✔ Your runtime beats 4.27 % of kotlin submissions
#   ✔ Your memory usage beats 27.44 % of kotlin submissions (45.4 MB)
# Submitting: kotlin_solutions/329.longest-increasing-path-in-a-matrix.kt
# - Downloading longest-increasing-path-in-a-matrix
#   ✔ Accepted
#   ✔ 139/139 cases passed (95 ms)
#   ✔ Your runtime beats 11.83 % of kotlin submissions
#   ✔ Your memory usage beats 17.2 % of kotlin submissions (55.4 MB)
# Submitting: kotlin_solutions/330.patching-array.kt
# - Downloading patching-array
#   ✔ Accepted
#   ✔ 150/150 cases passed (11 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 44.44 % of kotlin submissions (47 MB)
# Submitting: kotlin_solutions/331.verify-preorder-serialization-of-a-binary-tree.kt
# - Downloading verify-preorder-serialization-of-a-binary-tree
#   ✔ Accepted
#   ✔ 152/152 cases passed (20 ms)
#   ✔ Your runtime beats 60 % of kotlin submissions
#   ✔ Your memory usage beats 30 % of kotlin submissions (46.2 MB)
# Submitting: kotlin_solutions/332.reconstruct-itinerary.kt
# - Downloading reconstruct-itinerary
#   ✔ Accepted
#   ✔ 82/82 cases passed (50 ms)
#   ✔ Your runtime beats 5.56 % of kotlin submissions
#   ✔ Your memory usage beats 5.56 % of kotlin submissions (56.8 MB)
# Submitting: kotlin_solutions/334.increasing-triplet-subsequence.kt
# - Downloading increasing-triplet-subsequence
#   ✔ Accepted
#   ✔ 86/86 cases passed (22 ms)
#   ✔ Your runtime beats 11.54 % of kotlin submissions
#   ✔ Your memory usage beats 87.69 % of kotlin submissions (130.3 MB)
# Submitting: kotlin_solutions/335.self-crossing.kt
# - Downloading self-crossing
#   ✔ Accepted
#   ✔ 31/31 cases passed (42 ms)
#   ✔ Your runtime beats 71.43 % of kotlin submissions
#   ✔ Your memory usage beats 71.43 % of kotlin submissions (62.2 MB)
# Submitting: kotlin_solutions/336.palindrome-pairs.kt
# - Downloading palindrome-pairs
#   ✔ Accepted
#   ✔ 136/136 cases passed (1085 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 41.67 % of kotlin submissions (90.4 MB)
# Submitting: kotlin_solutions/337.house-robber-iii.kt
# - Downloading house-robber-iii
#   ✔ Accepted
#   ✔ 124/124 cases passed (19 ms)
#   ✔ Your runtime beats 12 % of kotlin submissions
#   ✔ Your memory usage beats 60 % of kotlin submissions (46.1 MB)
# Submitting: kotlin_solutions/338.counting-bits.kt
# - Downloading counting-bits
#   ✔ Accepted
#   ✔ 15/15 cases passed (2 ms)
#   ✔ Your runtime beats 90.41 % of kotlin submissions
#   ✔ Your memory usage beats 57.53 % of kotlin submissions (51.3 MB)
# Submitting: kotlin_solutions/341.flatten-nested-list-iterator.kt
# - Downloading flatten-nested-list-iterator
#   ✔ Accepted
#   ✔ 43/43 cases passed (154 ms)
#   ✔ Your runtime beats 64.15 % of kotlin submissions
#   ✔ Your memory usage beats 64.15 % of kotlin submissions (46.1 MB)
# Submitting: kotlin_solutions/342.power-of-four.kt
# - Downloading power-of-four
#   ✔ Accepted
#   ✔ 1063/1063 cases passed (1 ms)
#   ✔ Your runtime beats 62.22 % of kotlin submissions
#   ✔ Your memory usage beats 77.78 % of kotlin submissions (40.8 MB)
# Submitting: kotlin_solutions/343.integer-break.kt
# - Downloading integer-break
#   ✔ Accepted
#   ✔ 50/50 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 62.5 % of kotlin submissions (40 MB)
# Submitting: kotlin_solutions/344.reverse-string.kt
# - Downloading reverse-string
#   ✔ Accepted
#   ✔ 477/477 cases passed (6 ms)
#   ✔ Your runtime beats 22.33 % of kotlin submissions
#   ✔ Your memory usage beats 5.46 % of kotlin submissions (60.8 MB)
# Submitting: kotlin_solutions/345.reverse-vowels-of-a-string.kt
# - Downloading reverse-vowels-of-a-string
#   ✔ Accepted
#   ✔ 480/480 cases passed (35 ms)
#   ✔ Your runtime beats 14.95 % of kotlin submissions
#   ✔ Your memory usage beats 22.92 % of kotlin submissions (48.9 MB)
# Submitting: kotlin_solutions/347.top-k-frequent-elements.kt
# - Downloading top-k-frequent-elements
#   ✔ Accepted
#   ✔ 23/23 cases passed (24 ms)
#   ✔ Your runtime beats 55.13 % of kotlin submissions
#   ✔ Your memory usage beats 29.02 % of kotlin submissions (52.2 MB)
# Submitting: kotlin_solutions/349.intersection-of-two-arrays.kt
# - Downloading intersection-of-two-arrays
#   ✔ Accepted
#   ✔ 57/57 cases passed (22 ms)
#   ✔ Your runtime beats 25.62 % of kotlin submissions
#   ✔ Your memory usage beats 9.92 % of kotlin submissions (47.2 MB)
# Submitting: kotlin_solutions/350.intersection-of-two-arrays-ii.kt
# - Downloading intersection-of-two-arrays-ii
#   ✔ Accepted
#   ✔ 61/61 cases passed (19 ms)
#   ✔ Your runtime beats 16.42 % of kotlin submissions
#   ✔ Your memory usage beats 16.92 % of kotlin submissions (46.4 MB)
# Submitting: kotlin_solutions/352.data-stream-as-disjoint-intervals.kt
# - Downloading data-stream-as-disjoint-intervals
#   ✔ Accepted
#   ✔ 8/8 cases passed (55 ms)
#   ✔ Your runtime beats 12.5 % of kotlin submissions
#   ✔ Your memory usage beats 8.33 % of kotlin submissions (47.9 MB)
# Submitting: kotlin_solutions/354.russian-doll-envelopes.kt
# - Downloading russian-doll-envelopes
#   ✔ Accepted
#   ✔ 87/87 cases passed (99 ms)
#   ✔ Your runtime beats 9.09 % of kotlin submissions
#   ✔ Your memory usage beats 81.82 % of kotlin submissions (116.6 MB)
# Submitting: kotlin_solutions/355.design-twitter.kt
# - Downloading design-twitter
#   ✔ Accepted
#   ✔ 19/19 cases passed (97 ms)
#   ✔ Your runtime beats 26.96 % of kotlin submissions
#   ✔ Your memory usage beats 42.61 % of kotlin submissions (65.9 MB)
# Submitting: kotlin_solutions/357.count-numbers-with-unique-digits.kt
# - Downloading count-numbers-with-unique-digits
#   ✔ Accepted
#   ✔ 9/9 cases passed (3 ms)
#   ✔ Your runtime beats 28.57 % of kotlin submissions
#   ✔ Your memory usage beats 32.14 % of kotlin submissions (40.4 MB)
# Submitting: kotlin_solutions/363.max-sum-of-rectangle-no-larger-than-k.kt
# - Downloading max-sum-of-rectangle-no-larger-than-k
#   ✔ Accepted
#   ✔ 36/36 cases passed (421 ms)
#   ✔ Your runtime beats 66.67 % of kotlin submissions
#   ✔ Your memory usage beats 22.22 % of kotlin submissions (67.4 MB)
# Submitting: kotlin_solutions/365.water-and-jug-problem.kt
# - Downloading water-and-jug-problem
#   ✔ Accepted
#   ✔ 32/32 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 37.5 % of kotlin submissions (40.5 MB)
# Submitting: kotlin_solutions/367.valid-perfect-square.kt
# - Downloading valid-perfect-square
#   ✔ Accepted
#   ✔ 72/72 cases passed (12 ms)
#   ✔ Your runtime beats 15.19 % of kotlin submissions
#   ✔ Your memory usage beats 5.06 % of kotlin submissions (45 MB)
# Submitting: kotlin_solutions/368.largest-divisible-subset.kt
# - Downloading largest-divisible-subset
#   ✔ Accepted
#   ✔ 49/49 cases passed (73 ms)
#   ✔ Your runtime beats 26.09 % of kotlin submissions
#   ✔ Your memory usage beats 8.7 % of kotlin submissions (53.1 MB)
# Submitting: kotlin_solutions/371.sum-of-two-integers.kt
# - Downloading sum-of-two-integers
#   ✔ Accepted
#   ✔ 31/31 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 33.87 % of kotlin submissions (40.3 MB)
# Submitting: kotlin_solutions/372.super-pow.kt
# - Downloading super-pow
#   ✔ Accepted
#   ✔ 57/57 cases passed (51 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (47.9 MB)
# Submitting: kotlin_solutions/373.find-k-pairs-with-smallest-sums.kt
# - Downloading find-k-pairs-with-smallest-sums
#   ✔ Accepted
#   ✔ 31/31 cases passed (72 ms)
#   ✔ Your runtime beats 44.35 % of kotlin submissions
#   ✔ Your memory usage beats 80 % of kotlin submissions (70.8 MB)
# Submitting: kotlin_solutions/374.guess-number-higher-or-lower.kt
# - Downloading guess-number-higher-or-lower
#   ✔ Accepted
#   ✔ 25/25 cases passed (67 ms)
#   ✔ Your runtime beats 80.75 % of kotlin submissions
#   ✔ Your memory usage beats 8.7 % of kotlin submissions (39.8 MB)
# Submitting: kotlin_solutions/375.guess-number-higher-or-lower-ii.kt
# - Downloading guess-number-higher-or-lower-ii
#   ✔ Accepted
#   ✔ 27/27 cases passed (37 ms)
#   ✔ Your runtime beats 75 % of kotlin submissions
#   ✔ Your memory usage beats 37.5 % of kotlin submissions (47 MB)
# Submitting: kotlin_solutions/376.wiggle-subsequence.kt
# - Downloading wiggle-subsequence
#   ✔ Accepted
#   ✔ 32/32 cases passed (19 ms)
#   ✔ Your runtime beats 52.63 % of kotlin submissions
#   ✔ Your memory usage beats 36.84 % of kotlin submissions (46.1 MB)
# Submitting: kotlin_solutions/377.combination-sum-iv.kt
# - Downloading combination-sum-iv
#   ✔ Accepted
#   ✔ 17/17 cases passed (91 ms)
#   ✔ Your runtime beats 55.32 % of kotlin submissions
#   ✔ Your memory usage beats 36.17 % of kotlin submissions (40.4 MB)
# Submitting: kotlin_solutions/378.kth-smallest-element-in-a-sorted-matrix.kt
# - Downloading kth-smallest-element-in-a-sorted-matrix
#   ✔ Accepted
#   ✔ 87/87 cases passed (39 ms)
#   ✔ Your runtime beats 30.23 % of kotlin submissions
#   ✔ Your memory usage beats 8.14 % of kotlin submissions (56.4 MB)
# Submitting: kotlin_solutions/380.insert-delete-get-random-o-1.kt
# - Downloading insert-delete-getrandom-o1
#   ✔ Accepted
#   ✔ 21/21 cases passed (153 ms)
#   ✔ Your runtime beats 8.84 % of kotlin submissions
#   ✔ Your memory usage beats 8.84 % of kotlin submissions (121.9 MB)
# Submitting: kotlin_solutions/381.insert-delete-get-random-o-1-duplicates-allowed.kt
# - Downloading insert-delete-getrandom-o1-duplicates-allowed
#   ✔ Accepted
#   ✔ 32/32 cases passed (256 ms)
#   ✔ Your runtime beats 7.5 % of kotlin submissions
#   ✔ Your memory usage beats 17.5 % of kotlin submissions (117.4 MB)
# Submitting: kotlin_solutions/382.linked-list-random-node.kt
# - Downloading linked-list-random-node
#   ✔ Accepted
#   ✔ 8/8 cases passed (45 ms)
#   ✔ Your runtime beats 15.38 % of kotlin submissions
#   ✔ Your memory usage beats 23.08 % of kotlin submissions (50.2 MB)
# Submitting: kotlin_solutions/383.ransom-note.kt
# - Downloading ransom-note
#   ✔ Accepted
#   ✔ 130/130 cases passed (41 ms)
#   ✔ Your runtime beats 5.82 % of kotlin submissions
#   ✔ Your memory usage beats 53.17 % of kotlin submissions (46.7 MB)
# Submitting: kotlin_solutions/384.shuffle-an-array.kt
# - Downloading shuffle-an-array
#   ✔ Accepted
#   ✔ 8/8 cases passed (134 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
#   ✔ Your memory usage beats 20 % of kotlin submissions (62.1 MB)
# Submitting: kotlin_solutions/385.mini-parser.kt
# - Downloading mini-parser
#   ✔ Accepted
#   ✔ 58/58 cases passed (25 ms)
#   ✔ Your runtime beats 75 % of kotlin submissions
#   ✔ Your memory usage beats 58.33 % of kotlin submissions (49.4 MB)
# Submitting: kotlin_solutions/386.lexicographical-numbers.kt
# - Downloading lexicographical-numbers
#   ✔ Accepted
#   ✔ 27/27 cases passed (37 ms)
#   ✔ Your runtime beats 38.89 % of kotlin submissions
#   ✔ Your memory usage beats 72.22 % of kotlin submissions (51.1 MB)
# Submitting: kotlin_solutions/387.first-unique-character-in-a-string.kt
# - Downloading first-unique-character-in-a-string
#   ✔ Accepted
#   ✔ 107/107 cases passed (64 ms)
#   ✔ Your runtime beats 6.95 % of kotlin submissions
#   ✔ Your memory usage beats 5.3 % of kotlin submissions (49.3 MB)

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-03-17 16:39:24
