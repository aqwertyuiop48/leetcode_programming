# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME_3')
    user_cookie = userdata.get('LEETCODE_TOKEN_3')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME_3'] = user_name
    os.environ['LEETCODE_TOKEN_3'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME_3" "$LEETCODE_TOKEN_3" | leetcode user -c

# %%
# %%bash
#
# # top 500-650 answers (6th batch)
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v kotlin_solutions/*.kt | sed -n '501,650p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 7
# done
# Out:
# Submitting: kotlin_solutions/668.kth-smallest-number-in-multiplication-table.kt
# - Downloading problems
# - Downloading kth-smallest-number-in-multiplication-table
#   ✔ Accepted
#   ✔ 71/71 cases passed (29 ms)
#   ✔ Your runtime beats 14.29 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (41.6 MB)
# Submitting: kotlin_solutions/669.trim-a-binary-search-tree.kt
# - Downloading trim-a-binary-search-tree
#   ✔ Accepted
#   ✔ 78/78 cases passed (12 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/670.maximum-swap.kt
# - Downloading maximum-swap
#   ✔ Accepted
#   ✔ 112/112 cases passed (21 ms)
#   ✔ Your runtime beats 8.82 % of kotlin submissions
#   ✔ Your memory usage beats 5.88 % of kotlin submissions (45.5 MB)
# Submitting: kotlin_solutions/671.second-minimum-node-in-a-binary-tree.kt
# - Downloading second-minimum-node-in-a-binary-tree
#   ✔ Accepted
#   ✔ 39/39 cases passed (28 ms)
#   ✔ Your runtime beats 7.69 % of kotlin submissions
#   ✔ Your memory usage beats 7.69 % of kotlin submissions (46.7 MB)
# Submitting: kotlin_solutions/672.bulb-switcher-ii.kt
# - Downloading bulb-switcher-ii
#   ✔ Accepted
#   ✔ 80/80 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (40.4 MB)
# Submitting: kotlin_solutions/673.number-of-longest-increasing-subsequence.kt
# - Downloading number-of-longest-increasing-subsequence
#   ✔ Accepted
#   ✔ 223/223 cases passed (126 ms)
#   ✔ Your runtime beats 8 % of kotlin submissions
#   ✔ Your memory usage beats 8 % of kotlin submissions (51.6 MB)
# Submitting: kotlin_solutions/674.longest-continuous-increasing-subsequence.kt
# - Downloading longest-continuous-increasing-subsequence
#   ✔ Accepted
#   ✔ 35/35 cases passed (32 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 5.13 % of kotlin submissions (50.7 MB)
# Submitting: kotlin_solutions/675.cut-off-trees-for-golf-event.kt
# - Downloading cut-off-trees-for-golf-event
#   ✔ Accepted
#   ✔ 55/55 cases passed (1465 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (60.1 MB)
# Submitting: kotlin_solutions/676.implement-magic-dictionary.kt
# - Downloading implement-magic-dictionary
#   ✔ Accepted
#   ✔ 83/83 cases passed (105 ms)
#   ✔ Your runtime beats 27.27 % of kotlin submissions
#   ✔ Your memory usage beats 63.64 % of kotlin submissions (53.9 MB)
# Submitting: kotlin_solutions/677.map-sum-pairs.kt
# - Downloading map-sum-pairs
#   ✔ Accepted
#   ✔ 35/35 cases passed (24 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (46.3 MB)
# Submitting: kotlin_solutions/678.valid-parenthesis-string.kt
# - Downloading valid-parenthesis-string
#   ✔ Accepted
#   ✔ 83/83 cases passed (2 ms)
#   ✔ Your runtime beats 32.08 % of kotlin submissions
#   ✔ Your memory usage beats 30.19 % of kotlin submissions (41.2 MB)
# Submitting: kotlin_solutions/679.24-game.kt
# - Downloading 24-game
#   ✔ Accepted
#   ✔ 71/71 cases passed (121 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/680.valid-palindrome-ii.kt
# - Downloading valid-palindrome-ii
#   ✔ Accepted
#   ✔ 477/477 cases passed (70 ms)
#   ✔ Your runtime beats 5.67 % of kotlin submissions
#   ✔ Your memory usage beats 5.67 % of kotlin submissions (59.6 MB)
# Submitting: kotlin_solutions/682.baseball-game.kt
# - Downloading baseball-game
#   ✔ Accepted
#   ✔ 39/39 cases passed (10 ms)
#   ✔ Your runtime beats 64.37 % of kotlin submissions
#   ✔ Your memory usage beats 86.21 % of kotlin submissions (42.2 MB)
# Submitting: kotlin_solutions/684.redundant-connection.kt
# - Downloading redundant-connection
#   ✔ Accepted
#   ✔ 39/39 cases passed (13 ms)
#   ✔ Your runtime beats 16 % of kotlin submissions
#   ✔ Your memory usage beats 25.33 % of kotlin submissions (45.9 MB)
# Submitting: kotlin_solutions/685.redundant-connection-ii.kt
# - Downloading redundant-connection-ii
#   ✔ Accepted
#   ✔ 58/58 cases passed (38 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/686.repeated-string-match.kt
# - Downloading repeated-string-match
#   ✔ Accepted
#   ✔ 61/61 cases passed (216 ms)
#   ✔ Your runtime beats 28.57 % of kotlin submissions
#   ✔ Your memory usage beats 7.14 % of kotlin submissions (48.3 MB)
# Submitting: kotlin_solutions/687.longest-univalue-path.kt
# - Downloading longest-univalue-path
#   ✔ Accepted
#   ✔ 71/71 cases passed (68 ms)
#   ✔ Your runtime beats 9.09 % of kotlin submissions
#   ✔ Your memory usage beats 13.64 % of kotlin submissions (53.5 MB)
# Submitting: kotlin_solutions/688.knight-probability-in-chessboard.kt
# - Downloading knight-probability-in-chessboard
#   ✔ Accepted
#   ✔ 22/22 cases passed (87 ms)
#   ✔ Your runtime beats 12.5 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (52.1 MB)
# Submitting: kotlin_solutions/689.maximum-sum-of-3-non-overlapping-subarrays.kt
# - Downloading maximum-sum-of-3-non-overlapping-subarrays
#   ✔ Accepted
#   ✔ 43/43 cases passed (159 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/690.employee-importance.kt
# - Downloading employee-importance
#   ✔ Accepted
#   ✔ 102/102 cases passed (267 ms)
#   ✔ Your runtime beats 22.22 % of kotlin submissions
#   ✔ Your memory usage beats 11.11 % of kotlin submissions (59.3 MB)
# Submitting: kotlin_solutions/691.stickers-to-spell-word.kt
# - Downloading stickers-to-spell-word
#   ✔ Accepted
#   ✔ 102/102 cases passed (405 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/692.top-k-frequent-words.kt
# - Downloading top-k-frequent-words
#   ✔ Accepted
#   ✔ 111/111 cases passed (26 ms)
#   ✔ Your runtime beats 20.33 % of kotlin submissions
#   ✔ Your memory usage beats 8.13 % of kotlin submissions (48.7 MB)
# Submitting: kotlin_solutions/693.binary-number-with-alternating-bits.kt
# - Downloading binary-number-with-alternating-bits
#   ✔ Accepted
#   ✔ 204/204 cases passed (9 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/695.max-area-of-island.kt
# - Downloading max-area-of-island
#   ✔ Accepted
#   ✔ 728/728 cases passed (48 ms)
#   ✔ Your runtime beats 6.14 % of kotlin submissions
#   ✔ Your memory usage beats 48.04 % of kotlin submissions (49.4 MB)
# Submitting: kotlin_solutions/696.count-binary-substrings.kt
# - Downloading count-binary-substrings
#   ✔ Accepted
#   ✔ 91/91 cases passed (42 ms)
#   ✔ Your runtime beats 12.2 % of kotlin submissions
#   ✔ Your memory usage beats 7.32 % of kotlin submissions (48 MB)
# Submitting: kotlin_solutions/697.degree-of-an-array.kt
# - Downloading degree-of-an-array
#   ✔ Accepted
#   ✔ 89/89 cases passed (42 ms)
#   ✔ Your runtime beats 20.69 % of kotlin submissions
#   ✔ Your memory usage beats 6.9 % of kotlin submissions (55.4 MB)
# Submitting: kotlin_solutions/698.partition-to-k-equal-sum-subsets.kt
# - Downloading partition-to-k-equal-sum-subsets
#   ✔ Accepted
#   ✔ 164/164 cases passed (72 ms)
#   ✔ Your runtime beats 58.82 % of kotlin submissions
#   ✔ Your memory usage beats 11.76 % of kotlin submissions (52.6 MB)
# Submitting: kotlin_solutions/699.falling-squares.kt
# - Downloading falling-squares
#   ✔ Accepted
#   ✔ 48/48 cases passed (122 ms)
#   ✔ Your runtime beats 14.29 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (52.5 MB)
# Submitting: kotlin_solutions/700.search-in-a-binary-search-tree.kt
# - Downloading search-in-a-binary-search-tree
#   ✔ Accepted
#   ✔ 36/36 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 37.16 % of kotlin submissions (48.9 MB)
# Submitting: kotlin_solutions/701.insert-into-a-binary-search-tree.kt
# - Downloading insert-into-a-binary-search-tree
#   ✔ Accepted
#   ✔ 36/36 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 24.74 % of kotlin submissions (49.1 MB)
# Submitting: kotlin_solutions/703.kth-largest-element-in-a-stream.kt
# - Downloading kth-largest-element-in-a-stream
#   ✔ Accepted
#   ✔ 12/12 cases passed (49 ms)
#   ✔ Your runtime beats 58.49 % of kotlin submissions
#   ✔ Your memory usage beats 81.6 % of kotlin submissions (61.9 MB)
# Submitting: kotlin_solutions/704.binary-search.kt
# - Downloading binary-search
#   ✔ Accepted
#   ✔ 47/47 cases passed (20 ms)
#   ✔ Your runtime beats 6.33 % of kotlin submissions
#   ✔ Your memory usage beats 6.33 % of kotlin submissions (51 MB)
# Submitting: kotlin_solutions/705.design-hash-set.kt
# - Downloading design-hashset
#   ✔ Accepted
#   ✔ 34/34 cases passed (34 ms)
#   ✔ Your runtime beats 80.77 % of kotlin submissions
#   ✔ Your memory usage beats 73.08 % of kotlin submissions (58.4 MB)
# Submitting: kotlin_solutions/706.design-hash-map.kt
# - Downloading design-hashmap
#   ✔ Accepted
#   ✔ 37/37 cases passed (50 ms)
#   ✔ Your runtime beats 31.31 % of kotlin submissions
#   ✔ Your memory usage beats 67.68 % of kotlin submissions (69.3 MB)
# Submitting: kotlin_solutions/707.design-linked-list.kt
# - Downloading design-linked-list
#   ✔ Accepted
#   ✔ 66/66 cases passed (54 ms)
#   ✔ Your runtime beats 5.88 % of kotlin submissions
#   ✔ Your memory usage beats 10.59 % of kotlin submissions (51.9 MB)
# Submitting: kotlin_solutions/709.to-lower-case.kt
# - Downloading to-lower-case
#   ✔ Accepted
#   ✔ 114/114 cases passed (12 ms)
#   ✔ Your runtime beats 6.38 % of kotlin submissions
#   ✔ Your memory usage beats 6.38 % of kotlin submissions (43.6 MB)
# Submitting: kotlin_solutions/710.random-pick-with-blacklist.kt
# - Downloading random-pick-with-blacklist
#   ✔ Accepted
#   ✔ 68/68 cases passed (134 ms)
#   ✔ Your runtime beats 10 % of kotlin submissions
#   ✔ Your memory usage beats 10 % of kotlin submissions (83.2 MB)
# Submitting: kotlin_solutions/712.minimum-ascii-delete-sum-for-two-strings.kt
# - Downloading minimum-ascii-delete-sum-for-two-strings
#   ✔ Accepted
#   ✔ 93/93 cases passed (487 ms)
#   ✔ Your runtime beats 5.09 % of kotlin submissions
#   ✔ Your memory usage beats 5.09 % of kotlin submissions (87.2 MB)
# Submitting: kotlin_solutions/713.subarray-product-less-than-k.kt
# - Downloading subarray-product-less-than-k
#   ✔ Accepted
#   ✔ 98/98 cases passed (107 ms)
#   ✔ Your runtime beats 9.46 % of kotlin submissions
#   ✔ Your memory usage beats 6.76 % of kotlin submissions (53.5 MB)
# Submitting: kotlin_solutions/714.best-time-to-buy-and-sell-stock-with-transaction-fee.kt
# - Downloading best-time-to-buy-and-sell-stock-with-transaction-fee
#   ✔ Accepted
#   ✔ 45/45 cases passed (23 ms)
#   ✔ Your runtime beats 19.05 % of kotlin submissions
#   ✔ Your memory usage beats 55.56 % of kotlin submissions (59.8 MB)
# Submitting: kotlin_solutions/715.range-module.kt
# - Downloading range-module
#   ✔ Accepted
#   ✔ 56/56 cases passed (523 ms)
#   ✔ Your runtime beats 11.11 % of kotlin submissions
#   ✔ Your memory usage beats 5.55 % of kotlin submissions (83.3 MB)
# Submitting: kotlin_solutions/717.1-bit-and-2-bit-characters.kt
# - Downloading 1-bit-and-2-bit-characters
#   ✔ Accepted
#   ✔ 95/95 cases passed (19 ms)
#   ✔ Your runtime beats 4 % of kotlin submissions
#   ✔ Your memory usage beats 12 % of kotlin submissions (46.5 MB)
# Submitting: kotlin_solutions/718.maximum-length-of-repeated-subarray.kt
# - Downloading maximum-length-of-repeated-subarray
#   ✔ Accepted
#   ✔ 55/55 cases passed (62 ms)
#   ✔ Your runtime beats 6.67 % of kotlin submissions
#   ✔ Your memory usage beats 6.67 % of kotlin submissions (60.4 MB)
# Submitting: kotlin_solutions/719.find-k-th-smallest-pair-distance.kt
# - Downloading find-k-th-smallest-pair-distance
#   ✔ Accepted
#   ✔ 21/21 cases passed (3126 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 16.67 % of kotlin submissions (50.7 MB)
# Submitting: kotlin_solutions/720.longest-word-in-dictionary.kt
# - Downloading longest-word-in-dictionary
#   ✔ Accepted
#   ✔ 59/59 cases passed (74 ms)
#   ✔ Your runtime beats 9.09 % of kotlin submissions
#   ✔ Your memory usage beats 27.27 % of kotlin submissions (50.1 MB)
# Submitting: kotlin_solutions/721.accounts-merge.kt
# - Downloading accounts-merge
#   ✔ Accepted
#   ✔ 50/50 cases passed (50 ms)
#   ✔ Your runtime beats 67.02 % of kotlin submissions
#   ✔ Your memory usage beats 79.79 % of kotlin submissions (54.1 MB)
# Submitting: kotlin_solutions/722.remove-comments.kt
# - Downloading remove-comments
#   ✔ Accepted
#   ✔ 55/55 cases passed (19 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/724.find-pivot-index.kt
# - Downloading find-pivot-index
#   ✔ Accepted
#   ✔ 747/747 cases passed (15 ms)
#   ✔ Your runtime beats 11.31 % of kotlin submissions
#   ✔ Your memory usage beats 18.98 % of kotlin submissions (50.9 MB)
# Submitting: kotlin_solutions/725.split-linked-list-in-parts.kt
# - Downloading split-linked-list-in-parts
#   ✔ Accepted
#   ✔ 43/43 cases passed (11 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/726.number-of-atoms.kt
# - Downloading number-of-atoms
#   ✔ Accepted
#   ✔ 39/39 cases passed (42 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/728.self-dividing-numbers.kt
# - Downloading self-dividing-numbers
#   ✔ Accepted
#   ✔ 31/31 cases passed (15 ms)
#   ✔ Your runtime beats 12.73 % of kotlin submissions
#   ✔ Your memory usage beats 20 % of kotlin submissions (44.7 MB)
# Submitting: kotlin_solutions/729.my-calendar-i.kt
# - Downloading my-calendar-i
#   ✔ Accepted
#   ✔ 107/107 cases passed (43 ms)
#   ✔ Your runtime beats 73.58 % of kotlin submissions
#   ✔ Your memory usage beats 90.57 % of kotlin submissions (49.9 MB)
# Submitting: kotlin_solutions/730.count-different-palindromic-subsequences.kt
# - Downloading count-different-palindromic-subsequences
#   ✔ Accepted
#   ✔ 367/367 cases passed (55 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions/731.my-calendar-ii.kt
# - Downloading my-calendar-ii
#   ✔ Accepted
#   ✔ 97/97 cases passed (116 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 68.75 % of kotlin submissions (51.3 MB)
# Submitting: kotlin_solutions/732.my-calendar-iii.kt
# - Downloading my-calendar-iii
#   ✔ Accepted
#   ✔ 98/98 cases passed (272 ms)
#   ✔ Your runtime beats 7.14 % of kotlin submissions
#   ✔ Your memory usage beats 7.14 % of kotlin submissions (68.5 MB)
# Submitting: kotlin_solutions/733.flood-fill.kt
# - Downloading flood-fill
#   ✔ Accepted
#   ✔ 278/278 cases passed (13 ms)
#   ✔ Your runtime beats 47.73 % of kotlin submissions
#   ✔ Your memory usage beats 74.43 % of kotlin submissions (47 MB)
# Submitting: kotlin_solutions/735.asteroid-collision.kt
# - Downloading asteroid-collision
#   ✔ Accepted
#   ✔ 276/276 cases passed (27 ms)
#   ✔ Your runtime beats 7.08 % of kotlin submissions
#   ✔ Your memory usage beats 69.91 % of kotlin submissions (48 MB)
# Submitting: kotlin_solutions/736.parse-lisp-expression.kt
# - Downloading parse-lisp-expression
#   ✔ Accepted
#   ✔ 66/66 cases passed (60 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/738.monotone-increasing-digits.kt
# - Downloading monotone-increasing-digits
#   ✔ Accepted
#   ✔ 308/308 cases passed (19 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/739.daily-temperatures.kt
# - Downloading daily-temperatures
#   ✔ Accepted
#   ✔ 48/48 cases passed (114 ms)
#   ✔ Your runtime beats 14.57 % of kotlin submissions
#   ✔ Your memory usage beats 64.44 % of kotlin submissions (63.6 MB)
# Submitting: kotlin_solutions/740.delete-and-earn.kt
# - Downloading delete-and-earn
#   ✔ Accepted
#   ✔ 52/52 cases passed (37 ms)
#   ✔ Your runtime beats 23.81 % of kotlin submissions
#   ✔ Your memory usage beats 26.19 % of kotlin submissions (49.7 MB)
# Submitting: kotlin_solutions/741.cherry-pickup.kt
# - Downloading cherry-pickup
#   ✔ Accepted
#   ✔ 60/60 cases passed (231 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (67.1 MB)
# Submitting: kotlin_solutions/743.network-delay-time.kt
# - Downloading network-delay-time
#   ✔ Accepted
#   ✔ 56/56 cases passed (317 ms)
#   ✔ Your runtime beats 35.32 % of kotlin submissions
#   ✔ Your memory usage beats 16.42 % of kotlin submissions (68.7 MB)
# Submitting: kotlin_solutions/744.find-smallest-letter-greater-than-target.kt
# - Downloading find-smallest-letter-greater-than-target
#   ✔ Accepted
#   ✔ 167/167 cases passed (10 ms)
#   ✔ Your runtime beats 26.64 % of kotlin submissions
#   ✔ Your memory usage beats 34.67 % of kotlin submissions (46.6 MB)
# Submitting: kotlin_solutions/745.prefix-and-suffix-search.kt
# - Downloading prefix-and-suffix-search
#   ✔ Accepted
#   ✔ 17/17 cases passed (681 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 83.33 % of kotlin submissions (134.5 MB)
# Submitting: kotlin_solutions/746.min-cost-climbing-stairs.kt
# - Downloading min-cost-climbing-stairs
#   ✔ Accepted
#   ✔ 285/285 cases passed (24 ms)
#   ✔ Your runtime beats 7.29 % of kotlin submissions
#   ✔ Your memory usage beats 15.62 % of kotlin submissions (46.2 MB)
# Submitting: kotlin_solutions/747.largest-number-at-least-twice-of-others.kt
# - Downloading largest-number-at-least-twice-of-others
#   ✔ Accepted
#   ✔ 231/231 cases passed (14 ms)
#   ✔ Your runtime beats 3.7 % of kotlin submissions
#   ✔ Your memory usage beats 11.11 % of kotlin submissions (45.5 MB)
# Submitting: kotlin_solutions/748.shortest-completing-word.kt
# - Downloading shortest-completing-word
#   ✔ Accepted
#   ✔ 102/102 cases passed (36 ms)
#   ✔ Your runtime beats 10.34 % of kotlin submissions
#   ✔ Your memory usage beats 17.24 % of kotlin submissions (48.3 MB)
# Submitting: kotlin_solutions/749.contain-virus.kt
# - Downloading contain-virus
#   ✔ Accepted
#   ✔ 32/32 cases passed (101 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/752.open-the-lock.kt
# - Downloading open-the-lock
#   ✔ Accepted
#   ✔ 48/48 cases passed (261 ms)
#   ✔ Your runtime beats 9.43 % of kotlin submissions
#   ✔ Your memory usage beats 7.55 % of kotlin submissions (72.8 MB)
# Submitting: kotlin_solutions/753.cracking-the-safe.kt
# - Downloading cracking-the-safe
#   ✔ Accepted
#   ✔ 38/38 cases passed (245 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/754.reach-a-number.kt
# - Downloading reach-a-number
#   ✔ Accepted
#   ✔ 73/73 cases passed (32 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/756.pyramid-transition-matrix.kt
# - Downloading pyramid-transition-matrix
#   ✔ Accepted
#   ✔ 67/67 cases passed (1940 ms)
#   ✔ Your runtime beats 5.05 % of kotlin submissions
#   ✔ Your memory usage beats 33.67 % of kotlin submissions (56 MB)
# Submitting: kotlin_solutions/757.set-intersection-size-at-least-two.kt
# - Downloading set-intersection-size-at-least-two
#   ✔ Accepted
#   ✔ 118/118 cases passed (38 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions/761.special-binary-string.kt
# - Downloading special-binary-string
#   ✔ Accepted
#   ✔ 87/87 cases passed (31 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (47.3 MB)
# Submitting: kotlin_solutions/762.prime-number-of-set-bits-in-binary-representation.kt
# - Downloading prime-number-of-set-bits-in-binary-representation
#   ✔ Accepted
#   ✔ 202/202 cases passed (121 ms)
#   ✔ Your runtime beats 9.09 % of kotlin submissions
#   ✔ Your memory usage beats 18.18 % of kotlin submissions (48.2 MB)
# Submitting: kotlin_solutions/763.partition-labels.kt
# - Downloading partition-labels
#   ✔ Accepted
#   ✔ 118/118 cases passed (14 ms)
#   ✔ Your runtime beats 35.9 % of kotlin submissions
#   ✔ Your memory usage beats 20.51 % of kotlin submissions (44.9 MB)
# Submitting: kotlin_solutions/764.largest-plus-sign.kt
# - Downloading largest-plus-sign
#   ✔ Accepted
#   ✔ 56/56 cases passed (349 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/765.couples-holding-hands.kt
# - Downloading couples-holding-hands
#   ✔ Accepted
#   ✔ 56/56 cases passed (21 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (45.6 MB)
# Submitting: kotlin_solutions/766.toeplitz-matrix.kt
# - Downloading toeplitz-matrix
#   ✔ Accepted
#   ✔ 483/483 cases passed (15 ms)
#   ✔ Your runtime beats 6.25 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (50.8 MB)
# Submitting: kotlin_solutions/767.reorganize-string.kt
# - Downloading reorganize-string
#   ✔ Accepted
#   ✔ 71/71 cases passed (25 ms)
#   ✔ Your runtime beats 13.64 % of kotlin submissions
#   ✔ Your memory usage beats 20.45 % of kotlin submissions (44.3 MB)
# Submitting: kotlin_solutions/768.max-chunks-to-make-sorted-ii.kt
# - Downloading max-chunks-to-make-sorted-ii
# [ERROR] session expired, please login again [code=-1]
# Submitting: kotlin_solutions/769.max-chunks-to-make-sorted.kt
# - Downloading max-chunks-to-make-sorted
#   ✔ Accepted
#   ✔ 53/53 cases passed (13 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/770.basic-calculator-iv.kt
# - Downloading basic-calculator-iv
#   ✔ Accepted
#   ✔ 158/158 cases passed (67 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (49.6 MB)
# Submitting: kotlin_solutions/771.jewels-and-stones.kt
# - Downloading jewels-and-stones
#   ✔ Accepted
#   ✔ 255/255 cases passed (13 ms)
#   ✔ Your runtime beats 20.86 % of kotlin submissions
#   ✔ Your memory usage beats 14.39 % of kotlin submissions (43.4 MB)
# Submitting: kotlin_solutions/773.sliding-puzzle.kt
# - Downloading sliding-puzzle
#   ✔ Accepted
#   ✔ 32/32 cases passed (227 ms)
#   ✔ Your runtime beats 14.29 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (55.8 MB)
# Submitting: kotlin_solutions/775.global-and-local-inversions.kt
# - Downloading global-and-local-inversions
#   ✔ Accepted
#   ✔ 226/226 cases passed (27 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/777.swap-adjacent-in-lr-string.kt
# - Downloading swap-adjacent-in-lr-string
#   ✔ Accepted
#   ✔ 99/99 cases passed (44 ms)
#   ✔ Your runtime beats 9.09 % of kotlin submissions
#   ✔ Your memory usage beats 9.09 % of kotlin submissions (48.3 MB)
# Submitting: kotlin_solutions/778.swim-in-rising-water.kt
# - Downloading swim-in-rising-water
#   ✔ Accepted
#   ✔ 43/43 cases passed (924 ms)
#   ✔ Your runtime beats 6 % of kotlin submissions
#   ✔ Your memory usage beats 6 % of kotlin submissions (60.7 MB)
# Submitting: kotlin_solutions/779.k-th-symbol-in-grammar.kt
# - Downloading k-th-symbol-in-grammar
#   ✔ Accepted
#   ✔ 55/55 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (40.4 MB)
# Submitting: kotlin_solutions/780.reaching-points.kt
# - Downloading reaching-points
#   ✔ Accepted
#   ✔ 197/197 cases passed (13 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/781.rabbits-in-forest.kt
# - Downloading rabbits-in-forest
#   ✔ Accepted
#   ✔ 56/56 cases passed (20 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/782.transform-to-chessboard.kt
# - Downloading transform-to-chessboard
#   ✔ Accepted
#   ✔ 127/127 cases passed (30 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (52.4 MB)
# Submitting: kotlin_solutions/783.minimum-distance-between-bst-nodes.kt
# - Downloading minimum-distance-between-bst-nodes
#   ✔ Accepted
#   ✔ 49/49 cases passed (18 ms)
#   ✔ Your runtime beats 6.25 % of kotlin submissions
#   ✔ Your memory usage beats 6.25 % of kotlin submissions (43.5 MB)
# Submitting: kotlin_solutions/784.letter-case-permutation.kt
# - Downloading letter-case-permutation
#   ✔ Accepted
#   ✔ 63/63 cases passed (42 ms)
#   ✔ Your runtime beats 7.14 % of kotlin submissions
#   ✔ Your memory usage beats 7.14 % of kotlin submissions (52.8 MB)
# Submitting: kotlin_solutions/785.is-graph-bipartite.kt
# - Downloading is-graph-bipartite
#   ✔ Accepted
#   ✔ 86/86 cases passed (27 ms)
#   ✔ Your runtime beats 6.49 % of kotlin submissions
#   ✔ Your memory usage beats 38.96 % of kotlin submissions (50.8 MB)
# Submitting: kotlin_solutions/786.k-th-smallest-prime-fraction.kt
# - Downloading k-th-smallest-prime-fraction
#   ✔ Accepted
#   ✔ 59/59 cases passed (511 ms)
#   ✔ Your runtime beats 37.5 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (117.8 MB)
# Submitting: kotlin_solutions/787.cheapest-flights-within-k-stops.kt
# - Downloading cheapest-flights-within-k-stops
#   ✔ Accepted
#   ✔ 59/59 cases passed (11 ms)
#   ✔ Your runtime beats 87.25 % of kotlin submissions
#   ✔ Your memory usage beats 77.45 % of kotlin submissions (47 MB)
# Submitting: kotlin_solutions/788.rotated-digits.kt
# - Downloading rotated-digits
#   ✔ Accepted
#   ✔ 50/50 cases passed (28 ms)
#   ✔ Your runtime beats 60 % of kotlin submissions
#   ✔ Your memory usage beats 60 % of kotlin submissions (45.1 MB)
# Submitting: kotlin_solutions/789.escape-the-ghosts.kt
# - Downloading escape-the-ghosts
#   ✔ Accepted
#   ✔ 77/77 cases passed (1 ms)
#   ✔ Your runtime beats 66.67 % of kotlin submissions
#   ✔ Your memory usage beats 44.44 % of kotlin submissions (43.2 MB)
# Submitting: kotlin_solutions/790.domino-and-tromino-tiling.kt
# - Downloading domino-and-tromino-tiling
#   ✔ Accepted
#   ✔ 39/39 cases passed (6 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
#   ✔ Your memory usage beats 36 % of kotlin submissions (40.9 MB)
# Submitting: kotlin_solutions/791.custom-sort-string.kt
# - Downloading custom-sort-string
#   ✔ Accepted
#   ✔ 41/41 cases passed (34 ms)
#   ✔ Your runtime beats 5.71 % of kotlin submissions
#   ✔ Your memory usage beats 5.71 % of kotlin submissions (47.4 MB)
# Submitting: kotlin_solutions/792.number-of-matching-subsequences.kt
# - Downloading number-of-matching-subsequences
#   ✔ Accepted
#   ✔ 53/53 cases passed (76 ms)
#   ✔ Your runtime beats 59.52 % of kotlin submissions
#   ✔ Your memory usage beats 26.19 % of kotlin submissions (51.1 MB)
# Submitting: kotlin_solutions/793.preimage-size-of-factorial-zeroes-function.kt
# - Downloading preimage-size-of-factorial-zeroes-function
#   ✔ Accepted
#   ✔ 44/44 cases passed (20 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions/794.valid-tic-tac-toe-state.kt
# - Downloading valid-tic-tac-toe-state
# [ERROR] session expired, please login again [code=-1]
# Submitting: kotlin_solutions/795.number-of-subarrays-with-bounded-maximum.kt
# - Downloading number-of-subarrays-with-bounded-maximum
#   ✔ Accepted
#   ✔ 46/46 cases passed (48 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (62.1 MB)
# Submitting: kotlin_solutions/796.rotate-string.kt
# - Downloading rotate-string
#   ✔ Accepted
#   ✔ 58/58 cases passed (6 ms)
#   ✔ Your runtime beats 65.43 % of kotlin submissions
#   ✔ Your memory usage beats 44.44 % of kotlin submissions (42 MB)
# Submitting: kotlin_solutions/797.all-paths-from-source-to-target.kt
# - Downloading all-paths-from-source-to-target
#   ✔ Accepted
#   ✔ 30/30 cases passed (32 ms)
#   ✔ Your runtime beats 9.23 % of kotlin submissions
#   ✔ Your memory usage beats 32.31 % of kotlin submissions (53.3 MB)
# Submitting: kotlin_solutions/798.smallest-rotation-with-highest-score.kt
# - Downloading smallest-rotation-with-highest-score
#   ✔ Accepted
#   ✔ 44/44 cases passed (25 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/799.champagne-tower.kt
# - Downloading champagne-tower
#   ✔ Accepted
#   ✔ 312/312 cases passed (147 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (45.7 MB)
# Submitting: kotlin_solutions/801.minimum-swaps-to-make-sequences-increasing.kt
# - Downloading minimum-swaps-to-make-sequences-increasing
#   ✔ Accepted
#   ✔ 117/117 cases passed (262 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/802.find-eventual-safe-states.kt
# - Downloading find-eventual-safe-states
#   ✔ Accepted
#   ✔ 113/113 cases passed (60 ms)
#   ✔ Your runtime beats 32 % of kotlin submissions
#   ✔ Your memory usage beats 70 % of kotlin submissions (74.6 MB)
# Submitting: kotlin_solutions/803.bricks-falling-when-hit.kt
# - Downloading bricks-falling-when-hit
#   ✔ Accepted
#   ✔ 40/40 cases passed (114 ms)
#   ✔ Your runtime beats 22.22 % of kotlin submissions
#   ✔ Your memory usage beats 22.22 % of kotlin submissions (81.9 MB)
# Submitting: kotlin_solutions/804.unique-morse-code-words.kt
# - Downloading unique-morse-code-words
#   ✔ Accepted
#   ✔ 82/82 cases passed (20 ms)
#   ✔ Your runtime beats 31.43 % of kotlin submissions
#   ✔ Your memory usage beats 51.43 % of kotlin submissions (45.4 MB)
# Submitting: kotlin_solutions/805.split-array-with-same-average.kt
# - Downloading split-array-with-same-average
#   ✔ Accepted
#   ✔ 111/111 cases passed (1933 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (146.8 MB)
# Submitting: kotlin_solutions/806.number-of-lines-to-write-string.kt
# - Downloading number-of-lines-to-write-string
#   ✔ Accepted
#   ✔ 27/27 cases passed (92 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 18.75 % of kotlin submissions (40.5 MB)
# Submitting: kotlin_solutions/807.max-increase-to-keep-city-skyline.kt
# - Downloading max-increase-to-keep-city-skyline
#   ✔ Accepted
#   ✔ 133/133 cases passed (21 ms)
#   ✔ Your runtime beats 21.05 % of kotlin submissions
#   ✔ Your memory usage beats 31.58 % of kotlin submissions (46.8 MB)
# Submitting: kotlin_solutions/808.soup-servings.kt
# - Downloading soup-servings
#   ✔ Accepted
#   ✔ 43/43 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (40.4 MB)
# Submitting: kotlin_solutions/809.expressive-words.kt
# - Downloading expressive-words
#   ✔ Accepted
#   ✔ 36/36 cases passed (29 ms)
#   ✔ Your runtime beats 6.67 % of kotlin submissions
#   ✔ Your memory usage beats 6.67 % of kotlin submissions (48.9 MB)
# Submitting: kotlin_solutions/810.chalkboard-xor-game.kt
# - Downloading chalkboard-xor-game
#   ✔ Accepted
#   ✔ 168/168 cases passed (10 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (46.8 MB)
# Submitting: kotlin_solutions/811.subdomain-visit-count.kt
# - Downloading subdomain-visit-count
#   ✔ Accepted
#   ✔ 52/52 cases passed (45 ms)
#   ✔ Your runtime beats 8.33 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (47.6 MB)
# Submitting: kotlin_solutions/812.largest-triangle-area.kt
# - Downloading largest-triangle-area
#   ✔ Accepted
#   ✔ 57/57 cases passed (47 ms)
#   ✔ Your runtime beats 7.69 % of kotlin submissions
#   ✔ Your memory usage beats 7.69 % of kotlin submissions (47.7 MB)
# Submitting: kotlin_solutions/813.largest-sum-of-averages.kt
# - Downloading largest-sum-of-averages
#   ✔ Accepted
#   ✔ 51/51 cases passed (43 ms)
#   ✔ Your runtime beats 7.14 % of kotlin submissions
#   ✔ Your memory usage beats 7.14 % of kotlin submissions (47.8 MB)
# Submitting: kotlin_solutions/814.binary-tree-pruning.kt
# - Downloading binary-tree-pruning
#   ✔ Accepted
#   ✔ 31/31 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (41.2 MB)
# Submitting: kotlin_solutions/815.bus-routes.kt
# - Downloading bus-routes
#   ✔ Accepted
#   ✔ 54/54 cases passed (362 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
#   ✔ Your memory usage beats 5.72 % of kotlin submissions (124.7 MB)
# Submitting: kotlin_solutions/816.ambiguous-coordinates.kt
# - Downloading ambiguous-coordinates
#   ✔ Accepted
#   ✔ 346/346 cases passed (23 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/817.linked-list-components.kt
# - Downloading linked-list-components
#   ✔ Accepted
#   ✔ 57/57 cases passed (58 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/818.race-car.kt
# - Downloading race-car
#   ✔ Accepted
#   ✔ 55/55 cases passed (4444 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/819.most-common-word.kt
# - Downloading most-common-word
#   ✔ Accepted
#   ✔ 50/50 cases passed (37 ms)
#   ✔ Your runtime beats 59.18 % of kotlin submissions
#   ✔ Your memory usage beats 26.53 % of kotlin submissions (47.8 MB)
# Submitting: kotlin_solutions/820.short-encoding-of-words.kt
# - Downloading short-encoding-of-words
#   ✔ Accepted
#   ✔ 39/39 cases passed (238 ms)
#   ✔ Your runtime beats 11.11 % of kotlin submissions
#   ✔ Your memory usage beats 55.56 % of kotlin submissions (51.3 MB)
# Submitting: kotlin_solutions/821.shortest-distance-to-a-character.kt
# - Downloading shortest-distance-to-a-character
#   ✔ Accepted
#   ✔ 76/76 cases passed (88 ms)
#   ✔ Your runtime beats 6.67 % of kotlin submissions
#   ✔ Your memory usage beats 6.67 % of kotlin submissions (50.4 MB)
# Submitting: kotlin_solutions/822.card-flipping-game.kt
# - Downloading card-flipping-game
#   ✔ Accepted
#   ✔ 169/169 cases passed (36 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (49.9 MB)
# Submitting: kotlin_solutions/823.binary-trees-with-factors.kt
# - Downloading binary-trees-with-factors
#   ✔ Accepted
#   ✔ 48/48 cases passed (66 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/824.goat-latin.kt
# - Downloading goat-latin
# [ERROR] session expired, please login again [code=-1]
# Submitting: kotlin_solutions/825.friends-of-appropriate-ages.kt
# - Downloading friends-of-appropriate-ages
#   ✔ Accepted
#   ✔ 89/89 cases passed (17 ms)
#   ✔ Your runtime beats 36.36 % of kotlin submissions
#   ✔ Your memory usage beats 45.45 % of kotlin submissions (51.3 MB)
# Submitting: kotlin_solutions/826.most-profit-assigning-work.kt
# - Downloading most-profit-assigning-work
#   ✔ Accepted
#   ✔ 60/60 cases passed (433 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions/827.making-a-large-island.kt
# - Downloading making-a-large-island
#   ✔ Accepted
#   ✔ 75/75 cases passed (636 ms)
#   ✔ Your runtime beats 10.35 % of kotlin submissions
#   ✔ Your memory usage beats 12.07 % of kotlin submissions (109.2 MB)
# Submitting: kotlin_solutions/828.count-unique-characters-of-all-substrings-of-a-given-string.kt
# - Downloading count-unique-characters-of-all-substrings-of-a-given-string
#   ✔ Accepted
#   ✔ 76/76 cases passed (57 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (46.9 MB)
# Submitting: kotlin_solutions/829.consecutive-numbers-sum.kt
# - Downloading consecutive-numbers-sum
#   ✔ Accepted
#   ✔ 170/170 cases passed (30 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (46.8 MB)
# Submitting: kotlin_solutions/830.positions-of-large-groups.kt
# - Downloading positions-of-large-groups
#   ✔ Accepted
#   ✔ 202/202 cases passed (17 ms)
#   ✔ Your runtime beats 34.78 % of kotlin submissions
#   ✔ Your memory usage beats 34.78 % of kotlin submissions (47.1 MB)
# Submitting: kotlin_solutions/831.masking-personal-information.kt
# - Downloading masking-personal-information
#   ✔ Accepted
#   ✔ 66/66 cases passed (8 ms)
#   ✔ Your runtime beats 55.56 % of kotlin submissions
#   ✔ Your memory usage beats 55.56 % of kotlin submissions (42 MB)
# Submitting: kotlin_solutions/832.flipping-an-image.kt
# - Downloading flipping-an-image
#   ✔ Accepted
#   ✔ 82/82 cases passed (15 ms)
#   ✔ Your runtime beats 6.9 % of kotlin submissions
#   ✔ Your memory usage beats 48.28 % of kotlin submissions (47.9 MB)
# Submitting: kotlin_solutions/833.find-and-replace-in-string.kt
# - Downloading find-and-replace-in-string
#   ✔ Accepted
#   ✔ 59/59 cases passed (35 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/834.sum-of-distances-in-tree.kt
# - Downloading sum-of-distances-in-tree
#   ✔ Accepted
#   ✔ 74/74 cases passed (145 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/835.image-overlap.kt
# - Downloading image-overlap
#   ✔ Accepted
#   ✔ 60/60 cases passed (61 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (54.5 MB)
# Submitting: kotlin_solutions/836.rectangle-overlap.kt
# - Downloading rectangle-overlap
#   ✔ Accepted
#   ✔ 41/41 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (40.7 MB)
# Submitting: kotlin_solutions/837.new-21-game.kt
# - Downloading new-21-game
#   ✔ Accepted
#   ✔ 152/152 cases passed (25 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/838.push-dominoes.kt
# - Downloading push-dominoes
#   ✔ Accepted
#   ✔ 45/45 cases passed (42 ms)
#   ✔ Your runtime beats 22.22 % of kotlin submissions
#   ✔ Your memory usage beats 44.44 % of kotlin submissions (47.6 MB)
# Submitting: kotlin_solutions/839.similar-string-groups.kt
# - Downloading similar-string-groups
#   ✔ Accepted
#   ✔ 77/77 cases passed (263 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (50.8 MB)

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-02-14 21:25:41
