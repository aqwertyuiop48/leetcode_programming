# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME_2')
    user_cookie = userdata.get('LEETCODE_TOKEN_2')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME_2'] = user_name
    os.environ['LEETCODE_TOKEN_2'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME_2" "$LEETCODE_TOKEN_2" | leetcode user -c

# %%
# %%bash
#
# # top 500-600 answers (6th batch)
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v kotlin_solutions_1/*.kt | sed -n '1101,1200p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 7
# done
# Out:
# Submitting: kotlin_solutions_1/2787.ways-to-express-an-integer-as-sum-of-powers.kt
# - Downloading problems
# - Downloading ways-to-express-an-integer-as-sum-of-powers
#   ✔ Accepted
#   ✔ 1502/1502 cases passed (40 ms)
#   ✔ Your runtime beats 75 % of kotlin submissions
#   ✔ Your memory usage beats 62.5 % of kotlin submissions (48.4 MB)
# Submitting: kotlin_solutions_1/2788.split-strings-by-separator.kt
# - Downloading split-strings-by-separator
#   ✔ Accepted
#   ✔ 1036/1036 cases passed (28 ms)
#   ✔ Your runtime beats 14.29 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (49.4 MB)
# Submitting: kotlin_solutions_1/2789.largest-element-in-an-array-after-merge-operations.kt
# - Downloading largest-element-in-an-array-after-merge-operations
#   ✔ Accepted
#   ✔ 1023/1023 cases passed (13 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (65.9 MB)
# Submitting: kotlin_solutions_1/2790.maximum-number-of-groups-with-increasing-length.kt
# - Downloading maximum-number-of-groups-with-increasing-length
#   ✔ Accepted
#   ✔ 2027/2027 cases passed (333 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (70.9 MB)
# Submitting: kotlin_solutions_1/2798.number-of-employees-who-met-the-target.kt
# - Downloading number-of-employees-who-met-the-target
#   ✔ Accepted
#   ✔ 707/707 cases passed (1 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 42.86 % of kotlin submissions (43.1 MB)
# Submitting: kotlin_solutions_1/2800.shortest-string-that-contains-three-strings.kt
# - Downloading shortest-string-that-contains-three-strings
#   ✔ Accepted
#   ✔ 5324/5324 cases passed (74 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2806.account-balance-after-rounded-purchase.kt
# - Downloading account-balance-after-rounded-purchase
#   ✔ Accepted
#   ✔ 101/101 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (40.2 MB)
# Submitting: kotlin_solutions_1/2807.insert-greatest-common-divisors-in-linked-list.kt
# - Downloading insert-greatest-common-divisors-in-linked-list
#   ✔ Accepted
#   ✔ 582/582 cases passed (21 ms)
#   ✔ Your runtime beats 18.18 % of kotlin submissions
#   ✔ Your memory usage beats 45.45 % of kotlin submissions (47.1 MB)
# Submitting: kotlin_solutions_1/2808.minimum-seconds-to-equalize-a-circular-array.kt
# - Downloading minimum-seconds-to-equalize-a-circular-array
#   ✔ Accepted
#   ✔ 579/579 cases passed (234 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2809.minimum-time-to-make-array-sum-at-most-x.kt
# - Downloading minimum-time-to-make-array-sum-at-most-x
#   ✔ Accepted
#   ✔ 1274/1274 cases passed (134 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (69.3 MB)
# Submitting: kotlin_solutions_1/2810.faulty-keyboard.kt
# - Downloading faulty-keyboard
#   ✔ Accepted
#   ✔ 3005/3005 cases passed (5 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (45.1 MB)
# Submitting: kotlin_solutions_1/2811.check-if-it-is-possible-to-split-array.kt
# - Downloading check-if-it-is-possible-to-split-array
#   ✔ Accepted
#   ✔ 531/531 cases passed (11 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (45.9 MB)
# Submitting: kotlin_solutions_1/2815.max-pair-sum-in-an-array.kt
# - Downloading max-pair-sum-in-an-array
#   ✔ Accepted
#   ✔ 3008/3008 cases passed (41 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2816.double-a-number-represented-as-a-linked-list.kt
# - Downloading double-a-number-represented-as-a-linked-list
#   ✔ Accepted
#   ✔ 1265/1265 cases passed (20 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2817.minimum-absolute-difference-between-elements-with-constraint.kt
# - Downloading minimum-absolute-difference-between-elements-with-constraint
#   ✔ Accepted
#   ✔ 2013/2013 cases passed (103 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/2818.apply-operations-to-maximize-score.kt
# - Downloading apply-operations-to-maximize-score
#   ✔ Accepted
#   ✔ 870/870 cases passed (1643 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (86 MB)
# Submitting: kotlin_solutions_1/2824.count-pairs-whose-sum-is-less-than-target.kt
# - Downloading count-pairs-whose-sum-is-less-than-target
#   ✔ Accepted
#   ✔ 707/707 cases passed (29 ms)
#   ✔ Your runtime beats 10 % of kotlin submissions
#   ✔ Your memory usage beats 10 % of kotlin submissions (47.1 MB)
# Submitting: kotlin_solutions_1/2825.make-string-a-subsequence-using-cyclic-increments.kt
# - Downloading make-string-a-subsequence-using-cyclic-increments
#   ✔ Accepted
#   ✔ 1128/1128 cases passed (36 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2826.sorting-three-groups.kt
# - Downloading sorting-three-groups
#   ✔ Accepted
#   ✔ 7414/7414 cases passed (7 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/2828.check-if-a-string-is-an-acronym-of-words.kt
# - Downloading check-if-a-string-is-an-acronym-of-words
#   ✔ Accepted
#   ✔ 1519/1519 cases passed (20 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (47.7 MB)
# Submitting: kotlin_solutions_1/2829.determine-the-minimum-sum-of-a-k-avoiding-array.kt
# - Downloading determine-the-minimum-sum-of-a-k-avoiding-array
#   ✔ Accepted
#   ✔ 2502/2502 cases passed (1 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (41.7 MB)
# Submitting: kotlin_solutions_1/2830.maximize-the-profit-as-the-salesman.kt
# - Downloading maximize-the-profit-as-the-salesman
#   ✔ Accepted
#   ✔ 435/435 cases passed (87 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2833.furthest-point-from-origin.kt
# - Downloading furthest-point-from-origin
#   ✔ Accepted
#   ✔ 1254/1254 cases passed (3 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2834.find-the-minimum-possible-sum-of-a-beautiful-array.kt
# - Downloading find-the-minimum-possible-sum-of-a-beautiful-array
#   ✔ Accepted
#   ✔ 577/577 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (40.7 MB)
# Submitting: kotlin_solutions_1/2836.maximize-value-of-function-in-a-ball-passing-game.kt
# - Downloading maximize-value-of-function-in-a-ball-passing-game
#   ✔ Accepted
#   ✔ 948/948 cases passed (120 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (164 MB)
# Submitting: kotlin_solutions_1/2840.check-if-strings-can-be-made-equal-with-operations-ii.kt
# - Downloading check-if-strings-can-be-made-equal-with-operations-ii
#   ✔ Accepted
#   ✔ 756/756 cases passed (395 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2841.maximum-sum-of-almost-unique-subarray.kt
# - Downloading maximum-sum-of-almost-unique-subarray
#   ✔ Accepted
#   ✔ 767/767 cases passed (64 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (59.3 MB)
# Submitting: kotlin_solutions_1/2842.count-k-subsequences-of-a-string-with-maximum-beauty.kt
# - Downloading count-k-subsequences-of-a-string-with-maximum-beauty
#   ✔ Accepted
#   ✔ 611/611 cases passed (61 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (51.8 MB)
# Submitting: kotlin_solutions_1/2843.count-symmetric-integers.kt
# - Downloading count-symmetric-integers
#   ✔ Accepted
#   ✔ 1967/1967 cases passed (54 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (47.4 MB)
# Submitting: kotlin_solutions_1/2844.minimum-operations-to-make-a-special-number.kt
# - Downloading minimum-operations-to-make-a-special-number
#   ✔ Accepted
#   ✔ 814/814 cases passed (24 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (47.7 MB)
# Submitting: kotlin_solutions_1/2845.count-of-interesting-subarrays.kt
# - Downloading count-of-interesting-subarrays
#   ✔ Accepted
#   ✔ 617/617 cases passed (70 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (71.4 MB)
# Submitting: kotlin_solutions_1/2848.points-that-intersect-with-cars.kt
# - Downloading points-that-intersect-with-cars
#   ✔ Accepted
#   ✔ 807/807 cases passed (24 ms)
#   ✔ Your runtime beats 10 % of kotlin submissions
#   ✔ Your memory usage beats 90 % of kotlin submissions (47.8 MB)
# Submitting: kotlin_solutions_1/2849.determine-if-a-cell-is-reachable-at-a-given-time.kt
# - Downloading determine-if-a-cell-is-reachable-at-a-given-time
#   ✔ Accepted
#   ✔ 806/806 cases passed (86 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/2855.minimum_right_shifts_to_sort_the_array.kt
# - Downloading minimum-right-shifts-to-sort-the-array
#   ✔ Accepted
#   ✔ 814/814 cases passed (10 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2856.minimum_array_length_after_pair_removals.kt
# - Downloading minimum-array-length-after-pair-removals
#   ✔ Accepted
#   ✔ 636/636 cases passed (66 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 75 % of kotlin submissions (67.6 MB)
# Submitting: kotlin_solutions_1/2857.count_pairs_of_points_with_distance_k.kt
# - Downloading count-pairs-of-points-with-distance-k
#   ✔ Accepted
#   ✔ 1007/1007 cases passed (650 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (97.2 MB)
# Submitting: kotlin_solutions_1/2859.sum_of_values_at_indices_with_k_set_bits.kt
# - Downloading sum-of-values-at-indices-with-k-set-bits
#   ✔ Accepted
#   ✔ 639/639 cases passed (11 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2860.happy_students.kt
# - Downloading happy-students
#   ✔ Accepted
#   ✔ 727/727 cases passed (90 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (66.2 MB)
# Submitting: kotlin_solutions_1/2861.maximum_number_of_alloys.kt
# - Downloading maximum-number-of-alloys
#   ✔ Accepted
#   ✔ 731/731 cases passed (42 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (50.1 MB)
# Submitting: kotlin_solutions_1/2862.maximum_element_sum_of_a_complete_subset_of_indices.kt
# - Downloading maximum-element-sum-of-a-complete-subset-of-indices
#   ✔ Accepted
#   ✔ 663/663 cases passed (232 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (74.9 MB)
# Submitting: kotlin_solutions_1/2866.beautiful-towers-ii.kt
# - Downloading beautiful-towers-ii
#   ✔ Accepted
#   ✔ 785/785 cases passed (366 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (78 MB)
# Submitting: kotlin_solutions_1/2869.minimum-operations-to-collect-elements.kt
# - Downloading minimum-operations-to-collect-elements
#   ✔ Accepted
#   ✔ 619/619 cases passed (19 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2870.minimum-number-of-operations-to-make-array-empty.kt
# - Downloading minimum-number-of-operations-to-make-array-empty
#   ✔ Accepted
#   ✔ 748/748 cases passed (76 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (75.6 MB)
# Submitting: kotlin_solutions_1/2871.split-array-into-maximum-number-of-subarrays.kt
# - Downloading split-array-into-maximum-number-of-subarrays
#   ✔ Accepted
#   ✔ 887/887 cases passed (26 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (67.3 MB)
# Submitting: kotlin_solutions_1/2873.maximum-value-of-an-ordered-triplet-i.kt
# - Downloading maximum-value-of-an-ordered-triplet-i
#   ✔ Accepted
#   ✔ 564/564 cases passed (4 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/2874.maximum-value-of-an-ordered-triplet-ii.kt
# - Downloading maximum-value-of-an-ordered-triplet-ii
#   ✔ Accepted
#   ✔ 599/599 cases passed (20 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2875.minimum-size-subarray-in-infinite-array.kt
# - Downloading minimum-size-subarray-in-infinite-array
#   ✔ Accepted
#   ✔ 535/535 cases passed (81 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (81 MB)
# Submitting: kotlin_solutions_1/2894.divisible-and-non-divisible-sums-difference.kt
# - Downloading divisible-and-non-divisible-sums-difference
#   ✔ Accepted
#   ✔ 737/737 cases passed (1 ms)
#   ✔ Your runtime beats 77.78 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (41.1 MB)
# Submitting: kotlin_solutions_1/2895.minimum-processing-time.kt
# - Downloading minimum-processing-time
#   ✔ Accepted
#   ✔ 716/716 cases passed (117 ms)
#   ✔ Your runtime beats 71.43 % of kotlin submissions
#   ✔ Your memory usage beats 71.43 % of kotlin submissions (68.5 MB)
# Submitting: kotlin_solutions_1/2896.apply-operations-to-make-two-strings-equal.kt
# - Downloading apply-operations-to-make-two-strings-equal
#   ✔ Accepted
#   ✔ 729/729 cases passed (19 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2897.apply-operations-on-array-to-maximize-sum-of-squares.kt
# - Downloading apply-operations-on-array-to-maximize-sum-of-squares
#   ✔ Accepted
#   ✔ 918/918 cases passed (87 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2900.longest-unequal-adjacent-groups-subsequence-i.kt
# - Downloading longest-unequal-adjacent-groups-subsequence-i
#   ✔ Accepted
#   ✔ 382/382 cases passed (22 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (53.4 MB)
# Submitting: kotlin_solutions_1/2901.longest-unequal-adjacent-groups-subsequence-ii.kt
# - Downloading longest-unequal-adjacent-groups-subsequence-ii
#   ✔ Accepted
#   ✔ 443/443 cases passed (244 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (68 MB)
# Submitting: kotlin_solutions_1/2902.count-of-sub-multisets-with-bounded-sum.kt
# - Downloading count-of-sub-multisets-with-bounded-sum
#   ✔ Accepted
#   ✔ 643/643 cases passed (419 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (51.8 MB)
# Submitting: kotlin_solutions_1/2903.find-indices-with-index-and-value-difference-i.kt
# - Downloading find-indices-with-index-and-value-difference-i
#   ✔ Accepted
#   ✔ 525/525 cases passed (21 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 16.67 % of kotlin submissions (48 MB)
# Submitting: kotlin_solutions_1/2904.shortest-and-lexicographically-smallest-beautiful-string.kt
# - Downloading shortest-and-lexicographically-smallest-beautiful-string
#   ✔ Accepted
#   ✔ 674/674 cases passed (59 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2908.minimum-sum-of-mountain-triplets-i.kt
# - Downloading minimum-sum-of-mountain-triplets-i
#   ✔ Accepted
#   ✔ 724/724 cases passed (144 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2909.minimum-sum-of-mountain-triplets-ii.kt
# - Downloading minimum-sum-of-mountain-triplets-ii
#   ✔ Accepted
#   ✔ 788/788 cases passed (37 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2910.minimum-number-of-groups-to-create-a-valid-assignment.kt
# - Downloading minimum-number-of-groups-to-create-a-valid-assignment
#   ✔ Accepted
#   ✔ 631/631 cases passed (54 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/2911.minimum-changes-to-make-k-semi-palindromes.kt
# - Downloading minimum-changes-to-make-k-semi-palindromes
#   ✔ Accepted
#   ✔ 558/558 cases passed (485 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2913.subarrays-distinct-element-sum-of-squares-i.kt
# - Downloading subarrays-distinct-element-sum-of-squares-i
#   ✔ Accepted
#   ✔ 707/707 cases passed (87 ms)
#   ✔ Your runtime beats 30 % of kotlin submissions
#   ✔ Your memory usage beats 20 % of kotlin submissions (50.5 MB)
# Submitting: kotlin_solutions_1/2914.minimum-number-of-changes-to-make-binary-string-beautiful.kt
# - Downloading minimum-number-of-changes-to-make-binary-string-beautiful
#   ✔ Accepted
#   ✔ 577/577 cases passed (12 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (47.3 MB)
# Submitting: kotlin_solutions_1/2915.length-of-the-longest-subsequence-that-sums-to-target.kt
# - Downloading length-of-the-longest-subsequence-that-sums-to-target
#   ✔ Accepted
#   ✔ 941/941 cases passed (73 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (50 MB)
# Submitting: kotlin_solutions_1/2917.find-the-k-or-of-an-array.kt
# - Downloading find-the-k-or-of-an-array
#   ✔ Accepted
#   ✔ 951/951 cases passed (12 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (47.1 MB)
# Submitting: kotlin_solutions_1/2918.minimum-equal-sum-of-two-arrays-after-replacing-zeros.kt
# - Downloading minimum-equal-sum-of-two-arrays-after-replacing-zeros
#   ✔ Accepted
#   ✔ 638/638 cases passed (566 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 75 % of kotlin submissions (73.5 MB)
# Submitting: kotlin_solutions_1/2919.minimum-increment-operations-to-make-array-beautiful.kt
# - Downloading minimum-increment-operations-to-make-array-beautiful
#   ✔ Accepted
#   ✔ 570/570 cases passed (7 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/2920.maximum-points-after-collecting-coins-from-all-nodes.kt
# - Downloading maximum-points-after-collecting-coins-from-all-nodes
#   ✔ Accepted
#   ✔ 542/542 cases passed (292 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (132.2 MB)
# Submitting: kotlin_solutions_1/2923.find-champion-i.kt
# - Downloading find-champion-i
#   ✔ Accepted
#   ✔ 587/587 cases passed (12 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (67 MB)
# Submitting: kotlin_solutions_1/2924.find-champion-ii.kt
# - Downloading find-champion-ii
#   ✔ Accepted
#   ✔ 758/758 cases passed (8 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2925.maximum-score-after-applying-operations-on-a-tree.kt
# - Downloading maximum-score-after-applying-operations-on-a-tree
#   ✔ Accepted
#   ✔ 821/821 cases passed (120 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (80.7 MB)
# Submitting: kotlin_solutions_1/2926.maximum-balanced-subsequence-sum.kt
# - Downloading maximum-balanced-subsequence-sum
#   ✔ Accepted
#   ✔ 346/346 cases passed (644 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (66.5 MB)
# Submitting: kotlin_solutions_1/2928.distribute-candies-among-children-i.kt
# - Downloading distribute-candies-among-children-i
#   ✔ Accepted
#   ✔ 827/827 cases passed (3 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (41.5 MB)
# Submitting: kotlin_solutions_1/2929.distribute-candies-among-children-ii.kt
# - Downloading distribute-candies-among-children-ii
#   ✔ Accepted
#   ✔ 958/958 cases passed (106 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2931.maximum-spending-after-buying-items.kt
# - Downloading maximum-spending-after-buying-items
#   ✔ Accepted
#   ✔ 779/779 cases passed (88 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (76.3 MB)
# Submitting: kotlin_solutions_1/2932.maximum-strong-pair-xor-i.kt
# - Downloading maximum-strong-pair-xor-i
#   ✔ Accepted
#   ✔ 861/861 cases passed (48 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2933.high-access-employees.kt
# - Downloading high-access-employees
#   ✔ Accepted
#   ✔ 1143/1143 cases passed (302 ms)
#   ✔ Your runtime beats 12.5 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (55.3 MB)
# Submitting: kotlin_solutions_1/2934.minimum-operations-to-maximize-last-elements-in-arrays.kt
# - Downloading minimum-operations-to-maximize-last-elements-in-arrays
#   ✔ Accepted
#   ✔ 702/702 cases passed (30 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (52 MB)
# Submitting: kotlin_solutions_1/2937.make-three-strings-equal.kt
# - Downloading make-three-strings-equal
#   ✔ Accepted
#   ✔ 1935/1935 cases passed (12 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (46.4 MB)
# Submitting: kotlin_solutions_1/2938.separate-black-and-white-balls.kt
# - Downloading separate-black-and-white-balls
#   ✔ Accepted
#   ✔ 581/581 cases passed (36 ms)
#   ✔ Your runtime beats 11.11 % of kotlin submissions
#   ✔ Your memory usage beats 11.11 % of kotlin submissions (48.2 MB)
# Submitting: kotlin_solutions_1/2939.maximum-xor-product.kt
# - Downloading maximum-xor-product
#   ✔ Accepted
#   ✔ 863/863 cases passed (8 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (42.7 MB)
# Submitting: kotlin_solutions_1/2942.find-words-containing-character.kt
# - Downloading find-words-containing-character
#   ✔ Accepted
#   ✔ 912/912 cases passed (25 ms)
#   ✔ Your runtime beats 9.09 % of kotlin submissions
#   ✔ Your memory usage beats 9.09 % of kotlin submissions (51.4 MB)
# Submitting: kotlin_solutions_1/2943.maximize-area-of-square-hole-in-grid.kt
# - Downloading maximize-area-of-square-hole-in-grid
#   ✔ Accepted
#   ✔ 524/524 cases passed (26 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (47.6 MB)
# Submitting: kotlin_solutions_1/2944.minimum-number-of-coins-for-fruits.kt
# - Downloading minimum-number-of-coins-for-fruits
#   ✔ Accepted
#   ✔ 578/578 cases passed (16 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (45.5 MB)
# Submitting: kotlin_solutions_1/2945.find-maximum-non-decreasing-array-length.kt
# - Downloading find-maximum-non-decreasing-array-length
#   ✔ Accepted
#   ✔ 553/553 cases passed (63 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (67.6 MB)
# Submitting: kotlin_solutions_1/2946.matrix-similarity-after-cyclic-shifts.kt
# - Downloading matrix-similarity-after-cyclic-shifts
#   ✔ Accepted
#   ✔ 920/920 cases passed (16 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2947.count-beautiful-substrings-i.kt
# - Downloading count-beautiful-substrings-i
#   ✔ Accepted
#   ✔ 619/619 cases passed (311 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (48.7 MB)
# Submitting: kotlin_solutions_1/2948.make-lexicographically-smallest-array-by-swapping-elements.kt
# - Downloading make-lexicographically-smallest-array-by-swapping-elements
#   ✔ Accepted
#   ✔ 523/523 cases passed (351 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2949.count-beautiful-substrings-ii.kt
# - Downloading count-beautiful-substrings-ii
#   ✔ Accepted
#   ✔ 684/684 cases passed (444 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (52.6 MB)
# Submitting: kotlin_solutions_1/2951.find-the-peaks.kt
# - Downloading find-the-peaks
#   ✔ Accepted
#   ✔ 648/648 cases passed (8 ms)
#   ✔ Your runtime beats 12.5 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (48.2 MB)
# Submitting: kotlin_solutions_1/2952.minimum-number-of-coins-to-be-added.kt
# - Downloading minimum-number-of-coins-to-be-added
#   ✔ Accepted
#   ✔ 628/628 cases passed (189 ms)
#   ✔ Your runtime beats 60 % of kotlin submissions
#   ✔ Your memory usage beats 80 % of kotlin submissions (65.8 MB)
# Submitting: kotlin_solutions_1/2954.count-the-number-of-infection-sequences.kt
# - Downloading count-the-number-of-infection-sequences
#   ✔ Accepted
#   ✔ 1000/1000 cases passed (318 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (73.5 MB)
# Submitting: kotlin_solutions_1/2956.find-common-elements-between-two-arrays.kt
# - Downloading find-common-elements-between-two-arrays
#   ✔ Accepted
#   ✔ 1208/1208 cases passed (17 ms)
#   ✔ Your runtime beats 14.29 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (57.3 MB)
# Submitting: kotlin_solutions_1/2957.remove-adjacent-almost-equal-characters.kt
# - Downloading remove-adjacent-almost-equal-characters
#   ✔ Accepted
#   ✔ 779/779 cases passed (8 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2958.length-of-longest-subarray-with-at-most-k-frequency.kt
# - Downloading length-of-longest-subarray-with-at-most-k-frequency
#   ✔ Accepted
#   ✔ 994/994 cases passed (235 ms)
#   ✔ Your runtime beats 5.1 % of kotlin submissions
#   ✔ Your memory usage beats 9.53 % of kotlin submissions (82.2 MB)
# Submitting: kotlin_solutions_1/2959.number-of-possible-sets-of-closing-branches.kt
# - Downloading number-of-possible-sets-of-closing-branches
#   ✔ Accepted
#   ✔ 533/533 cases passed (98 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (48.7 MB)
# Submitting: kotlin_solutions_1/2960.count-tested-devices-after-test-operations.kt
# - Downloading count-tested-devices-after-test-operations
#   ✔ Accepted
#   ✔ 520/520 cases passed (1 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (44.3 MB)
# Submitting: kotlin_solutions_1/2961.double-modular-exponentiation.kt
# - Downloading double-modular-exponentiation
#   ✔ Accepted
#   ✔ 524/524 cases passed (42 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (56.6 MB)
# Submitting: kotlin_solutions_1/2962.count-subarrays-where-max-element-appears-at-least-k-times.kt
# - Downloading count-subarrays-where-max-element-appears-at-least-k-times
#   ✔ Accepted
#   ✔ 634/634 cases passed (46 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2963.count-the-number-of-good-partitions.kt
# - Downloading count-the-number-of-good-partitions
#   ✔ Accepted
#   ✔ 813/813 cases passed (79 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2965.find-missing-and-repeated-values.kt
# - Downloading find-missing-and-repeated-values
#   ✔ Accepted
#   ✔ 584/584 cases passed (52 ms)
#   ✔ Your runtime beats 7.14 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (51.7 MB)

# %%
# %%bash
#
# # top 500-600 answers (6th batch)
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v kotlin_solutions/*.kt | sed -n '501,505p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 7
# done
# Out:
# Submitting: kotlin_solutions/668.kth-smallest-number-in-multiplication-table.kt
# - Downloading kth-smallest-number-in-multiplication-table
#   ✔ Accepted
#   ✔ 71/71 cases passed (24 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/669.trim-a-binary-search-tree.kt
# - Downloading trim-a-binary-search-tree
#   ✔ Accepted
#   ✔ 78/78 cases passed (12 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/670.maximum-swap.kt
# - Downloading maximum-swap
#   ✔ Accepted
#   ✔ 112/112 cases passed (22 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (46.1 MB)
# Submitting: kotlin_solutions/671.second-minimum-node-in-a-binary-tree.kt
# - Downloading second-minimum-node-in-a-binary-tree
#   ✔ Accepted
#   ✔ 39/39 cases passed (30 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/672.bulb-switcher-ii.kt
# - Downloading bulb-switcher-ii
#   ✔ Accepted
#   ✔ 80/80 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (40.2 MB)

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-08-18 14:44:18
