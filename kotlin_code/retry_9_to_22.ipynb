# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME_3')
    user_cookie = userdata.get('LEETCODE_TOKEN_3')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME_3'] = user_name
    os.environ['LEETCODE_TOKEN_3'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME_3" "$LEETCODE_TOKEN_3" | leetcode user -c

# %%
# %%bash
#
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Enter the directory
# cd leetcode_programming
#
# # 3. Define the specific files you want to run here
# # You can add more files by separating them with a space or a newline
# files=(
#     "kotlin_solutions_1/1002.find-common-characters.kt"
#     "kotlin_solutions_1/989.add-to-array-form-of-integer.kt"
#     "kotlin_solutions_1/1036.escape-a-large-maze.kt"
#     "kotlin_solutions_1/1110.delete-nodes-and-return-forest.kt"
#     "kotlin_solutions_1/1292.maximum-side-length-of-a-square-with-sum-less-than-or-equal-to-threshold.kt"
#     "kotlin_solutions_1/1293.shortest-path-in-a-grid-with-obstacles-elimination.kt"
#     "kotlin_solutions_1/1296.divide-array-in-sets-of-k-consecutive-numbers.kt"
#     "kotlin_solutions_1/1298.maximum-candies-you-can-get-from-boxes.kt"
#     "kotlin_solutions_1/1300.sum-of-mutated-array-closest-to-target.kt"
#     "kotlin_solutions_1/1302.deepest-leaves-sum.kt"
#     "kotlin_solutions_1/1486.xor-operation-in-an-array.kt"
#     "kotlin_solutions_1/1489.find-critical-and-pseudo-critical-edges-in-minimum-spanning-tree.kt"
#     "kotlin_solutions_1/1576.replace-all-s-to-avoid-consecutive-repeating-characters.kt"
#     "kotlin_solutions_1/1736.latest-time-by-replacing-hidden-digits.kt"
#     "kotlin_solutions_1/1845.seat-reservation-manager.kt"
#     "kotlin_solutions_1/1899.merge-triplets-to-form-target-triplet.kt"
#     "kotlin_solutions_1/2191.sort-the-jumbled-numbers.kt"
#     "kotlin_solutions_1/2353.design-a-food-rating-system.kt"
#     "kotlin_solutions_1/2424.longest-uploaded-prefix.kt"
#     "kotlin_solutions_1/2482.difference-between-ones-and-zeros-in-row-and-column.kt"
#     "kotlin_solutions_1/2558.take-gifts-from-the-richest-pile.kt"
# )
#
# # 4. Run the loop over your specific list
# for f in "${files[@]}"; do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 7
# done
# Out:
# Submitting: kotlin_solutions_1/1002.find-common-characters.kt
#   ✔ Accepted
#   ✔ 88/88 cases passed (27 ms)
#   ✔ Your runtime beats 6.45 % of kotlin submissions
#   ✔ Your memory usage beats 6.45 % of kotlin submissions (47.8 MB)
# Submitting: kotlin_solutions_1/989.add-to-array-form-of-integer.kt
#   ✔ Accepted
#   ✔ 152/152 cases passed (83 ms)
#   ✔ Your runtime beats 8.33 % of kotlin submissions
#   ✔ Your memory usage beats 8.33 % of kotlin submissions (52.8 MB)
# Submitting: kotlin_solutions_1/1036.escape-a-large-maze.kt
#   ✔ Accepted
#   ✔ 31/31 cases passed (254 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
#   ✔ Your memory usage beats 80 % of kotlin submissions (67.4 MB)
# Submitting: kotlin_solutions_1/1110.delete-nodes-and-return-forest.kt
#   ✔ Accepted
#   ✔ 112/112 cases passed (182 ms)
#   ✔ Your runtime beats 40.74 % of kotlin submissions
#   ✔ Your memory usage beats 14.81 % of kotlin submissions (46.8 MB)
# ...

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-08-18 21:22:52
