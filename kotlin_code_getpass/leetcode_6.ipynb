# %%
# %%capture
import os
import getpass

# 2. Interactive input (Safe and hidden)
print("Please enter your LeetCode credentials:")
user_name = getpass.getpass('LeetCode Username: ')
user_cookie = getpass.getpass('LeetCode Session Token: ')

# 1. Install and Clone
# !npm install -g leetcode-tools/leetcode-cli
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME'] = user_name
    os.environ['LEETCODE_TOKEN'] = user_cookie

    # 4. Run the login silently
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME" "$LEETCODE_TOKEN" | leetcode user -c

# %%
# %%bash
#
# # top 500-600 answers (6th batch)
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v kotlin_solutions/*.kt | sed -n '501,550p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 7
# done
# Out:
# Submitting: kotlin_solutions/668.kth-smallest-number-in-multiplication-table.kt
# - Downloading problems
# - Downloading kth-smallest-number-in-multiplication-table
#   ✔ Accepted
#   ✔ 71/71 cases passed (28 ms)
#   ✔ Your runtime beats 54.55 % of kotlin submissions
#   ✔ Your memory usage beats 54.55 % of kotlin submissions (41.8 MB)
# Submitting: kotlin_solutions/669.trim-a-binary-search-tree.kt
# - Downloading trim-a-binary-search-tree
#   ✔ Accepted
#   ✔ 78/78 cases passed (12 ms)
#   ✔ Your runtime beats 42.86 % of kotlin submissions
#   ✔ Your memory usage beats 57.14 % of kotlin submissions (46.8 MB)
# Submitting: kotlin_solutions/670.maximum-swap.kt
# - Downloading maximum-swap
#   ✔ Accepted
#   ✔ 112/112 cases passed (22 ms)
#   ✔ Your runtime beats 19.51 % of kotlin submissions
#   ✔ Your memory usage beats 34.15 % of kotlin submissions (45.1 MB)
# Submitting: kotlin_solutions/671.second-minimum-node-in-a-binary-tree.kt
# - Downloading second-minimum-node-in-a-binary-tree
#   ✔ Accepted
#   ✔ 39/39 cases passed (28 ms)
#   ✔ Your runtime beats 46.15 % of kotlin submissions
#   ✔ Your memory usage beats 19.23 % of kotlin submissions (47.2 MB)
# Submitting: kotlin_solutions/672.bulb-switcher-ii.kt
# - Downloading bulb-switcher-ii
#   ✔ Accepted
#   ✔ 80/80 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 38.1 % of kotlin submissions (40.2 MB)
# Submitting: kotlin_solutions/673.number-of-longest-increasing-subsequence.kt
# - Downloading number-of-longest-increasing-subsequence
#   ✔ Accepted
#   ✔ 223/223 cases passed (122 ms)
#   ✔ Your runtime beats 31.03 % of kotlin submissions
#   ✔ Your memory usage beats 27.59 % of kotlin submissions (51.8 MB)
# Submitting: kotlin_solutions/674.longest-continuous-increasing-subsequence.kt
# - Downloading longest-continuous-increasing-subsequence
#   ✔ Accepted
#   ✔ 35/35 cases passed (36 ms)
#   ✔ Your runtime beats 9.62 % of kotlin submissions
#   ✔ Your memory usage beats 13.46 % of kotlin submissions (50.2 MB)
# Submitting: kotlin_solutions/675.cut-off-trees-for-golf-event.kt
# - Downloading cut-off-trees-for-golf-event
#   ✔ Accepted
#   ✔ 55/55 cases passed (1494 ms)
#   ✔ Your runtime beats 69.23 % of kotlin submissions
#   ✔ Your memory usage beats 7.69 % of kotlin submissions (71.1 MB)
# Submitting: kotlin_solutions/676.implement-magic-dictionary.kt
# - Downloading implement-magic-dictionary
#   ✔ Accepted
#   ✔ 83/83 cases passed (112 ms)
#   ✔ Your runtime beats 19.05 % of kotlin submissions
#   ✔ Your memory usage beats 71.43 % of kotlin submissions (51.8 MB)
# Submitting: kotlin_solutions/677.map-sum-pairs.kt
# - Downloading map-sum-pairs
#   ✔ Accepted
#   ✔ 35/35 cases passed (25 ms)
#   ✔ Your runtime beats 42.11 % of kotlin submissions
#   ✔ Your memory usage beats 36.84 % of kotlin submissions (45.9 MB)
# Submitting: kotlin_solutions/678.valid-parenthesis-string.kt
# - Downloading valid-parenthesis-string
#   ✔ Accepted
#   ✔ 84/84 cases passed (2 ms)
#   ✔ Your runtime beats 44.59 % of kotlin submissions
#   ✔ Your memory usage beats 58.11 % of kotlin submissions (40.7 MB)
# Submitting: kotlin_solutions/679.24-game.kt
# - Downloading 24-game
#   ✔ Accepted
#   ✔ 71/71 cases passed (125 ms)
#   ✔ Your runtime beats 5.88 % of kotlin submissions
#   ✔ Your memory usage beats 17.65 % of kotlin submissions (60.6 MB)
# Submitting: kotlin_solutions/680.valid-palindrome-ii.kt
# - Downloading valid-palindrome-ii
#   ✔ Accepted
#   ✔ 477/477 cases passed (73 ms)
#   ✔ Your runtime beats 5.2 % of kotlin submissions
#   ✔ Your memory usage beats 5.78 % of kotlin submissions (59.1 MB)
# Submitting: kotlin_solutions/682.baseball-game.kt
# - Downloading baseball-game
#   ✔ Accepted
#   ✔ 39/39 cases passed (10 ms)
#   ✔ Your runtime beats 56.32 % of kotlin submissions
#   ✔ Your memory usage beats 64.37 % of kotlin submissions (42.7 MB)
# Submitting: kotlin_solutions/684.redundant-connection.kt
# - Downloading redundant-connection
#   ✔ Accepted
#   ✔ 40/40 cases passed (19 ms)
#   ✔ Your runtime beats 7.34 % of kotlin submissions
#   ✔ Your memory usage beats 34.86 % of kotlin submissions (45.4 MB)
# Submitting: kotlin_solutions/685.redundant-connection-ii.kt
# - Downloading redundant-connection-ii
#   ✔ Accepted
#   ✔ 58/58 cases passed (38 ms)
#   ✔ Your runtime beats 68.75 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (53.8 MB)
# Submitting: kotlin_solutions/686.repeated-string-match.kt
# - Downloading repeated-string-match
#   ✔ Accepted
#   ✔ 61/61 cases passed (229 ms)
#   ✔ Your runtime beats 15.15 % of kotlin submissions
#   ✔ Your memory usage beats 30.3 % of kotlin submissions (48.1 MB)
# Submitting: kotlin_solutions/687.longest-univalue-path.kt
# - Downloading longest-univalue-path
#   ✔ Accepted
#   ✔ 71/71 cases passed (74 ms)
#   ✔ Your runtime beats 5.56 % of kotlin submissions
#   ✔ Your memory usage beats 8.33 % of kotlin submissions (53.7 MB)
# Submitting: kotlin_solutions/688.knight-probability-in-chessboard.kt
# - Downloading knight-probability-in-chessboard
#   ✔ Accepted
#   ✔ 22/22 cases passed (90 ms)
#   ✔ Your runtime beats 6.67 % of kotlin submissions
#   ✔ Your memory usage beats 6.67 % of kotlin submissions (52.3 MB)
# Submitting: kotlin_solutions/689.maximum-sum-of-3-non-overlapping-subarrays.kt
# - Downloading maximum-sum-of-3-non-overlapping-subarrays
#   ✔ Accepted
#   ✔ 43/43 cases passed (164 ms)
#   ✔ Your runtime beats 61.54 % of kotlin submissions
#   ✔ Your memory usage beats 84.62 % of kotlin submissions (51.1 MB)
# Submitting: kotlin_solutions/690.employee-importance.kt
# - Downloading employee-importance
#   ✔ Accepted
#   ✔ 102/102 cases passed (269 ms)
#   ✔ Your runtime beats 9.52 % of kotlin submissions
#   ✔ Your memory usage beats 21.43 % of kotlin submissions (58.1 MB)
# Submitting: kotlin_solutions/691.stickers-to-spell-word.kt
# - Downloading stickers-to-spell-word
#   ✔ Accepted
#   ✔ 102/102 cases passed (345 ms)
#   ✔ Your runtime beats 55.56 % of kotlin submissions
#   ✔ Your memory usage beats 38.89 % of kotlin submissions (55.5 MB)
# Submitting: kotlin_solutions/692.top-k-frequent-words.kt
# - Downloading top-k-frequent-words
#   ✔ Accepted
#   ✔ 111/111 cases passed (27 ms)
#   ✔ Your runtime beats 16.41 % of kotlin submissions
#   ✔ Your memory usage beats 18.75 % of kotlin submissions (48.3 MB)
# Submitting: kotlin_solutions/693.binary-number-with-alternating-bits.kt
# - Downloading binary-number-with-alternating-bits
#   ✔ Accepted
#   ✔ 204/204 cases passed (9 ms)
#   ✔ Your runtime beats 6.99 % of kotlin submissions
#   ✔ Your memory usage beats 29.53 % of kotlin submissions (40.7 MB)
# Submitting: kotlin_solutions/695.max-area-of-island.kt
# - Downloading max-area-of-island
#   ✔ Accepted
#   ✔ 728/728 cases passed (46 ms)
#   ✔ Your runtime beats 5.1 % of kotlin submissions
#   ✔ Your memory usage beats 11.74 % of kotlin submissions (52.9 MB)
# Submitting: kotlin_solutions/696.count-binary-substrings.kt
# - Downloading count-binary-substrings
#   ✔ Accepted
#   ✔ 91/91 cases passed (51 ms)
#   ✔ Your runtime beats 9.44 % of kotlin submissions
#   ✔ Your memory usage beats 42.09 % of kotlin submissions (46.9 MB)
# Submitting: kotlin_solutions/697.degree-of-an-array.kt
# - Downloading degree-of-an-array
#   ✔ Accepted
#   ✔ 89/89 cases passed (41 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 15.56 % of kotlin submissions (55.1 MB)
# Submitting: kotlin_solutions/698.partition-to-k-equal-sum-subsets.kt
# - Downloading partition-to-k-equal-sum-subsets
#   ✔ Accepted
#   ✔ 164/164 cases passed (75 ms)
#   ✔ Your runtime beats 45.71 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (53.9 MB)
# Submitting: kotlin_solutions/699.falling-squares.kt
# - Downloading falling-squares
#   ✔ Accepted
#   ✔ 48/48 cases passed (120 ms)
#   ✔ Your runtime beats 40 % of kotlin submissions
#   ✔ Your memory usage beats 13.33 % of kotlin submissions (52.8 MB)
# Submitting: kotlin_solutions/700.search-in-a-binary-search-tree.kt
# - Downloading search-in-a-binary-search-tree
#   ✔ Accepted
#   ✔ 36/36 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 99.26 % of kotlin submissions (46.9 MB)
# Submitting: kotlin_solutions/701.insert-into-a-binary-search-tree.kt
# - Downloading insert-into-a-binary-search-tree
#   ✔ Accepted
#   ✔ 36/36 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 86.32 % of kotlin submissions (48.6 MB)
# Submitting: kotlin_solutions/703.kth-largest-element-in-a-stream.kt
# - Downloading kth-largest-element-in-a-stream
#   ✔ Accepted
#   ✔ 12/12 cases passed (42 ms)
#   ✔ Your runtime beats 98.51 % of kotlin submissions
#   ✔ Your memory usage beats 67.16 % of kotlin submissions (62.2 MB)
# Submitting: kotlin_solutions/704.binary-search.kt
# - Downloading binary-search
#   ✔ Accepted
#   ✔ 47/47 cases passed (19 ms)
#   ✔ Your runtime beats 7.77 % of kotlin submissions
#   ✔ Your memory usage beats 6.91 % of kotlin submissions (51.3 MB)
# Submitting: kotlin_solutions/705.design-hash-set.kt
# - Downloading design-hashset
#   ✔ Accepted
#   ✔ 34/34 cases passed (33 ms)
#   ✔ Your runtime beats 86.57 % of kotlin submissions
#   ✔ Your memory usage beats 35.82 % of kotlin submissions (66.8 MB)
# Submitting: kotlin_solutions/706.design-hash-map.kt
# - Downloading design-hashmap
#   ✔ Accepted
#   ✔ 37/37 cases passed (48 ms)
#   ✔ Your runtime beats 47.5 % of kotlin submissions
#   ✔ Your memory usage beats 57.5 % of kotlin submissions (69.9 MB)
# Submitting: kotlin_solutions/707.design-linked-list.kt
# - Downloading design-linked-list
#   ✔ Accepted
#   ✔ 66/66 cases passed (59 ms)
#   ✔ Your runtime beats 5.66 % of kotlin submissions
#   ✔ Your memory usage beats 13.21 % of kotlin submissions (52.2 MB)
# Submitting: kotlin_solutions/709.to-lower-case.kt
# - Downloading to-lower-case
#   ✔ Accepted
#   ✔ 114/114 cases passed (13 ms)
#   ✔ Your runtime beats 17.78 % of kotlin submissions
#   ✔ Your memory usage beats 6.67 % of kotlin submissions (44.1 MB)
# Submitting: kotlin_solutions/710.random-pick-with-blacklist.kt
# - Downloading random-pick-with-blacklist
#   ✔ Accepted
#   ✔ 68/68 cases passed (135 ms)
#   ✔ Your runtime beats 21.05 % of kotlin submissions
#   ✔ Your memory usage beats 57.89 % of kotlin submissions (79.6 MB)
# Submitting: kotlin_solutions/712.minimum-ascii-delete-sum-for-two-strings.kt
# - Downloading minimum-ascii-delete-sum-for-two-strings
#   ✔ Accepted
#   ✔ 93/93 cases passed (470 ms)
#   ✔ Your runtime beats 16.28 % of kotlin submissions
#   ✔ Your memory usage beats 25.58 % of kotlin submissions (79.3 MB)
# Submitting: kotlin_solutions/713.subarray-product-less-than-k.kt
# - Downloading subarray-product-less-than-k
#   ✔ Accepted
#   ✔ 98/98 cases passed (129 ms)
#   ✔ Your runtime beats 16.09 % of kotlin submissions
#   ✔ Your memory usage beats 10.34 % of kotlin submissions (52.9 MB)
# Submitting: kotlin_solutions/714.best-time-to-buy-and-sell-stock-with-transaction-fee.kt
# - Downloading best-time-to-buy-and-sell-stock-with-transaction-fee
#   ✔ Accepted
#   ✔ 45/45 cases passed (22 ms)
#   ✔ Your runtime beats 19.32 % of kotlin submissions
#   ✔ Your memory usage beats 93.18 % of kotlin submissions (59.1 MB)
# Submitting: kotlin_solutions/715.range-module.kt
# - Downloading range-module
#   ✔ Accepted
#   ✔ 56/56 cases passed (425 ms)
#   ✔ Your runtime beats 57.14 % of kotlin submissions
#   ✔ Your memory usage beats 42.86 % of kotlin submissions (79 MB)
# Submitting: kotlin_solutions/717.1-bit-and-2-bit-characters.kt
# - Downloading 1-bit-and-2-bit-characters
#   ✔ Accepted
#   ✔ 95/95 cases passed (18 ms)
#   ✔ Your runtime beats 32.26 % of kotlin submissions
#   ✔ Your memory usage beats 48.39 % of kotlin submissions (45.9 MB)
# Submitting: kotlin_solutions/718.maximum-length-of-repeated-subarray.kt
# - Downloading maximum-length-of-repeated-subarray
#   ✔ Accepted
#   ✔ 55/55 cases passed (63 ms)
#   ✔ Your runtime beats 37.04 % of kotlin submissions
#   ✔ Your memory usage beats 37.04 % of kotlin submissions (59.7 MB)
# Submitting: kotlin_solutions/719.find-k-th-smallest-pair-distance.kt
# - Downloading find-k-th-smallest-pair-distance
#   ✔ Accepted
#   ✔ 21/21 cases passed (3113 ms)
#   ✔ Your runtime beats 23.53 % of kotlin submissions
#   ✔ Your memory usage beats 52.94 % of kotlin submissions (50.9 MB)
# Submitting: kotlin_solutions/720.longest-word-in-dictionary.kt
# - Downloading longest-word-in-dictionary
#   ✔ Accepted
#   ✔ 59/59 cases passed (73 ms)
#   ✔ Your runtime beats 25.93 % of kotlin submissions
#   ✔ Your memory usage beats 18.52 % of kotlin submissions (50.5 MB)
# Submitting: kotlin_solutions/721.accounts-merge.kt
# - Downloading accounts-merge
#   ✔ Accepted
#   ✔ 50/50 cases passed (49 ms)
#   ✔ Your runtime beats 82.84 % of kotlin submissions
#   ✔ Your memory usage beats 64.18 % of kotlin submissions (55 MB)
# Submitting: kotlin_solutions/722.remove-comments.kt
# - Downloading remove-comments
#   ✔ Accepted
#   ✔ 55/55 cases passed (18 ms)
#   ✔ Your runtime beats 90.91 % of kotlin submissions
#   ✔ Your memory usage beats 45.45 % of kotlin submissions (45.5 MB)
# Submitting: kotlin_solutions/724.find-pivot-index.kt
# - Downloading find-pivot-index
#   ✔ Accepted
#   ✔ 747/747 cases passed (16 ms)
#   ✔ Your runtime beats 11.58 % of kotlin submissions
#   ✔ Your memory usage beats 74.52 % of kotlin submissions (48.6 MB)
# Submitting: kotlin_solutions/725.split-linked-list-in-parts.kt
# - Downloading split-linked-list-in-parts
#   ✔ Accepted
#   ✔ 43/43 cases passed (11 ms)
#   ✔ Your runtime beats 83.33 % of kotlin submissions
#   ✔ Your memory usage beats 16.67 % of kotlin submissions (45.7 MB)

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-03-18 19:24:19
