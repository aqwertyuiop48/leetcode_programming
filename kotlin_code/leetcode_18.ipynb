# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME_2')
    user_cookie = userdata.get('LEETCODE_TOKEN_2')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME_2'] = user_name
    os.environ['LEETCODE_TOKEN_2'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME_2" "$LEETCODE_TOKEN_2" | leetcode user -c

# %%
# %%bash
#
# # top 300-400 answers (next batch)
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v kotlin_solutions_1/*.kt | sed -n '901,1000p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 7
# done
# Out:
# Submitting: kotlin_solutions_1/2350.shortest-impossible-sequence-of-rolls.kt
# - Downloading problems
# - Downloading shortest-impossible-sequence-of-rolls
#   ✔ Accepted
#   ✔ 65/65 cases passed (46 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (65.7 MB)
# Submitting: kotlin_solutions_1/2351.first-letter-to-appear-twice.kt
# - Downloading first-letter-to-appear-twice
#   ✔ Accepted
#   ✔ 92/92 cases passed (8 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 6.67 % of kotlin submissions (41.9 MB)
# Submitting: kotlin_solutions_1/2352.equal-row-and-column-pairs.kt
# - Downloading equal-row-and-column-pairs
#   ✔ Accepted
#   ✔ 80/80 cases passed (63 ms)
#   ✔ Your runtime beats 28.79 % of kotlin submissions
#   ✔ Your memory usage beats 87.88 % of kotlin submissions (54.6 MB)
# Submitting: kotlin_solutions_1/2353.design-a-food-rating-system.kt
# - Downloading design-a-food-rating-system
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 1: Char 241: ERROR: Syntax error: Property getter or setter expected.
#   ✘ Error: Line 1: Char 241: ERROR: Syntax error: Property getter or setter expected.
# Line 1: Char 349: ERROR: Syntax error: Property getter or setter expected.
# Line 1: Char 580: ERROR: Syntax error: Property getter or setter expected.
# Line 53: Char 32: WARNING: 'static fun readFrom(p0: String!): JsonArray!' is deprecated. Deprecated in Java.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2357.make-array-zero-by-subtracting-equal-amounts.kt
# - Downloading make-array-zero-by-subtracting-equal-amounts
#   ✔ Accepted
#   ✔ 95/95 cases passed (8 ms)
#   ✔ Your runtime beats 52.38 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (42.4 MB)
# Submitting: kotlin_solutions_1/2358.maximum-number-of-groups-entering-a-competition.kt
# - Downloading maximum-number-of-groups-entering-a-competition
#   ✔ Accepted
#   ✔ 69/69 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (63.3 MB)
# Submitting: kotlin_solutions_1/2359.find-closest-node-to-given-two-nodes.kt
# - Downloading find-closest-node-to-given-two-nodes
#   ✔ Accepted
#   ✔ 78/78 cases passed (162 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (80.9 MB)
# Submitting: kotlin_solutions_1/2360.longest-cycle-in-a-graph.kt
# - Downloading longest-cycle-in-a-graph
#   ✔ Accepted
#   ✔ 81/81 cases passed (137 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (66.4 MB)
# Submitting: kotlin_solutions_1/2363.merge-similar-items.kt
# - Downloading merge-similar-items
#   ✔ Accepted
#   ✔ 49/49 cases passed (34 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/2364.count-number-of-bad-pairs.kt
# - Downloading count-number-of-bad-pairs
#   ✔ Accepted
#   ✔ 65/65 cases passed (82 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2365.task-scheduler-ii.kt
# - Downloading task-scheduler-ii
#   ✔ Accepted
#   ✔ 61/61 cases passed (62 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2366.minimum-replacements-to-sort-the-array.kt
# - Downloading minimum-replacements-to-sort-the-array
#   ✔ Accepted
#   ✔ 48/48 cases passed (58 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (65.7 MB)
# Submitting: kotlin_solutions_1/2367.number-of-arithmetic-triplets.kt
# - Downloading number-of-arithmetic-triplets
#   ✔ Accepted
#   ✔ 104/104 cases passed (15 ms)
#   ✔ Your runtime beats 29.41 % of kotlin submissions
#   ✔ Your memory usage beats 5.88 % of kotlin submissions (46.3 MB)
# Submitting: kotlin_solutions_1/2368.reachable-nodes-with-restrictions.kt
# - Downloading reachable-nodes-with-restrictions
#   ✔ Accepted
#   ✔ 62/62 cases passed (218 ms)
#   ✔ Your runtime beats 30.77 % of kotlin submissions
#   ✔ Your memory usage beats 38.46 % of kotlin submissions (146.2 MB)
# Submitting: kotlin_solutions_1/2369.check-if-there-is-a-valid-partition-for-the-array.kt
# - Downloading check-if-there-is-a-valid-partition-for-the-array
#   ✔ Accepted
#   ✔ 118/118 cases passed (56 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (62.2 MB)
# Submitting: kotlin_solutions_1/2370.longest-ideal-subsequence.kt
# - Downloading longest-ideal-subsequence
#   ✔ Accepted
#   ✔ 85/85 cases passed (33 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2373.largest-local-values-in-a-matrix.kt
# - Downloading largest-local-values-in-a-matrix
#   ✔ Accepted
#   ✔ 50/50 cases passed (18 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (54.5 MB)
# Submitting: kotlin_solutions_1/2374.node-with-highest-edge-score.kt
# - Downloading node-with-highest-edge-score
#   ✔ Accepted
#   ✔ 118/118 cases passed (26 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2375.construct-smallest-number-from-di-string.kt
# - Downloading construct-smallest-number-from-di-string
#   ✔ Accepted
#   ✔ 104/104 cases passed (11 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (42.2 MB)
# Submitting: kotlin_solutions_1/2376.count-special-integers.kt
# - Downloading count-special-integers
#   ✔ Accepted
#   ✔ 120/120 cases passed (13 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (42.2 MB)
# Submitting: kotlin_solutions_1/2379.minimum-recolors-to-get-k-consecutive-black-blocks.kt
# - Downloading minimum-recolors-to-get-k-consecutive-black-blocks
#   ✔ Accepted
#   ✔ 122/122 cases passed (9 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 27.78 % of kotlin submissions (40.9 MB)
# Submitting: kotlin_solutions_1/2380.time-needed-to-rearrange-a-binary-string.kt
# - Downloading time-needed-to-rearrange-a-binary-string
#   ✔ Accepted
#   ✔ 103/103 cases passed (12 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (44.2 MB)
# Submitting: kotlin_solutions_1/2381.shifting-letters-ii.kt
# - Downloading shifting-letters-ii
#   ✔ Accepted
#   ✔ 39/39 cases passed (28 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (92.6 MB)
# Submitting: kotlin_solutions_1/2383.minimum-hours-of-training-to-win-a-competition.kt
# - Downloading minimum-hours-of-training-to-win-a-competition
#   ✔ Accepted
#   ✔ 111/111 cases passed (15 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2384.largest-palindromic-number.kt
# - Downloading largest-palindromic-number
#   ✔ Accepted
#   ✔ 67/67 cases passed (54 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (49.1 MB)
# Submitting: kotlin_solutions_1/2386.find-the-k-sum-of-an-array.kt
# - Downloading find-the-k-sum-of-an-array
#   ✔ Accepted
#   ✔ 111/111 cases passed (197 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (71.7 MB)
# Submitting: kotlin_solutions_1/2389.longest-subsequence-with-limited-sum.kt
# - Downloading longest-subsequence-with-limited-sum
#   ✔ Accepted
#   ✔ 57/57 cases passed (50 ms)
#   ✔ Your runtime beats 5.26 % of kotlin submissions
#   ✔ Your memory usage beats 5.26 % of kotlin submissions (50.5 MB)
# Submitting: kotlin_solutions_1/2390.removing-stars-from-a-string.kt
# - Downloading removing-stars-from-a-string
#   ✔ Accepted
#   ✔ 65/65 cases passed (21 ms)
#   ✔ Your runtime beats 80.23 % of kotlin submissions
#   ✔ Your memory usage beats 77.91 % of kotlin submissions (47.8 MB)
# Submitting: kotlin_solutions_1/2391.minimum-amount-of-time-to-collect-garbage.kt
# - Downloading minimum-amount-of-time-to-collect-garbage
#   ✔ Accepted
#   ✔ 75/75 cases passed (30 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (68.9 MB)
# Submitting: kotlin_solutions_1/2396.strictly-palindromic-number.kt
# - Downloading strictly-palindromic-number
#   ✔ Accepted
#   ✔ 67/67 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (40 MB)
# Submitting: kotlin_solutions_1/2397.maximum-rows-covered-by-columns.kt
# - Downloading maximum-rows-covered-by-columns
#   ✔ Accepted
#   ✔ 103/103 cases passed (12 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (42.8 MB)
# Submitting: kotlin_solutions_1/2398.maximum-number-of-robots-within-budget.kt
# - Downloading maximum-number-of-robots-within-budget
#   ✔ Accepted
#   ✔ 82/82 cases passed (170 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (63.2 MB)
# Submitting: kotlin_solutions_1/2399.check-distances-between-same-letters.kt
# - Downloading check-distances-between-same-letters
#   ✔ Accepted
#   ✔ 335/335 cases passed (13 ms)
#   ✔ Your runtime beats 28.57 % of kotlin submissions
#   ✔ Your memory usage beats 28.57 % of kotlin submissions (44.6 MB)
# Submitting: kotlin_solutions_1/2400.number-of-ways-to-reach-a-position-after-exactly-k-steps.kt
# - Downloading number-of-ways-to-reach-a-position-after-exactly-k-steps
#   ✔ Accepted
#   ✔ 35/35 cases passed (48 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (47.2 MB)
# Submitting: kotlin_solutions_1/2401.longest-nice-subarray.kt
# - Downloading longest-nice-subarray
#   ✔ Accepted
#   ✔ 66/66 cases passed (116 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2404.most-frequent-even-element.kt
# - Downloading most-frequent-even-element
#   ✔ Accepted
#   ✔ 219/219 cases passed (56 ms)
#   ✔ Your runtime beats 11.11 % of kotlin submissions
#   ✔ Your memory usage beats 22.22 % of kotlin submissions (50.2 MB)
# Submitting: kotlin_solutions_1/2405.optimal-partition-of-string.kt
# - Downloading optimal-partition-of-string
#   ✔ Accepted
#   ✔ 62/62 cases passed (31 ms)
#   ✔ Your runtime beats 55.56 % of kotlin submissions
#   ✔ Your memory usage beats 44.44 % of kotlin submissions (47.3 MB)
# Submitting: kotlin_solutions_1/2406.divide-intervals-into-minimum-number-of-groups.kt
# - Downloading divide-intervals-into-minimum-number-of-groups
#   ✔ Accepted
#   ✔ 35/35 cases passed (297 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (100.4 MB)
# Submitting: kotlin_solutions_1/2409.count-days-spent-together.kt
# - Downloading count-days-spent-together
#   ✔ Accepted
#   ✔ 51/51 cases passed (15 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2410.maximum-matching-of-players-with-trainers.kt
# - Downloading maximum-matching-of-players-with-trainers
#   ✔ Accepted
#   ✔ 36/36 cases passed (217 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2411.smallest-subarrays-with-maximum-bitwise-or.kt
# - Downloading smallest-subarrays-with-maximum-bitwise-or
#   ✔ Accepted
#   ✔ 59/59 cases passed (73 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (63 MB)
# Submitting: kotlin_solutions_1/2412.minimum-money-required-before-transactions.kt
# - Downloading minimum-money-required-before-transactions
#   ✔ Accepted
#   ✔ 56/56 cases passed (21 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (116.4 MB)
# Submitting: kotlin_solutions_1/2413.smallest-even-multiple.kt
# - Downloading smallest-even-multiple
#   ✔ Accepted
#   ✔ 150/150 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 17.65 % of kotlin submissions (40.5 MB)
# Submitting: kotlin_solutions_1/2414.length-of-the-longest-alphabetical-continuous-substring.kt
# - Downloading length-of-the-longest-alphabetical-continuous-substring
#   ✔ Accepted
#   ✔ 123/123 cases passed (54 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (47.8 MB)
# Submitting: kotlin_solutions_1/2415.reverse-odd-levels-of-binary-tree.kt
# - Downloading reverse-odd-levels-of-binary-tree
#   ✔ Accepted
#   ✔ 57/57 cases passed (54 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2416.sum-of-prefix-scores-of-strings.kt
# - Downloading sum-of-prefix-scores-of-strings
#   ✔ Accepted
#   ✔ 38/38 cases passed (240 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (172.8 MB)
# Submitting: kotlin_solutions_1/2418.sort-the-people.kt
# - Downloading sort-the-people
#   ✔ Accepted
#   ✔ 68/68 cases passed (37 ms)
#   ✔ Your runtime beats 11.11 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (49.5 MB)
# Submitting: kotlin_solutions_1/2419.longest-subarray-with-maximum-bitwise-and.kt
# - Downloading longest-subarray-with-maximum-bitwise-and
#   ✔ Accepted
#   ✔ 53/53 cases passed (41 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2420.find-all-good-indices.kt
# - Downloading find-all-good-indices
#   ✔ Accepted
#   ✔ 68/68 cases passed (16 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (67.4 MB)
# Submitting: kotlin_solutions_1/2423.remove-letter-to-equalize-frequency.kt
# - Downloading remove-letter-to-equalize-frequency
#   ✔ Accepted
#   ✔ 51/51 cases passed (30 ms)
#   ✔ Your runtime beats 11.11 % of kotlin submissions
#   ✔ Your memory usage beats 11.11 % of kotlin submissions (46.8 MB)
# Submitting: kotlin_solutions_1/2424.longest-uploaded-prefix.kt
# - Downloading longest-uploaded-prefix
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 1: Char 96: ERROR: Syntax error: Property getter or setter expected.
#   ✘ Error: Line 1: Char 96: ERROR: Syntax error: Property getter or setter expected.
# Line 1: Char 117: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 1: Char 122: ERROR: Syntax error: Property getter or setter expected.
# Line 1: Char 172: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 49: Char 32: WARNING: 'static fun readFrom(p0: String!): JsonArray!' is deprecated. Deprecated in Java.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2425.bitwise-xor-of-all-pairings.kt
# - Downloading bitwise-xor-of-all-pairings
#   ✔ Accepted
#   ✔ 42/42 cases passed (12 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (61.1 MB)
# Submitting: kotlin_solutions_1/2426.number-of-pairs-satisfying-inequality.kt
# - Downloading number-of-pairs-satisfying-inequality
#   ✔ Accepted
#   ✔ 61/61 cases passed (177 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (67.8 MB)
# Submitting: kotlin_solutions_1/2427.number-of-common-factors.kt
# - Downloading number-of-common-factors
#   ✔ Accepted
#   ✔ 76/76 cases passed (5 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 13.33 % of kotlin submissions (40.5 MB)
# Submitting: kotlin_solutions_1/2428.maximum-sum-of-an-hourglass.kt
# - Downloading maximum-sum-of-an-hourglass
#   ✔ Accepted
#   ✔ 41/41 cases passed (14 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2429.minimize-xor.kt
# - Downloading minimize-xor
#   ✔ Accepted
#   ✔ 280/280 cases passed (9 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2430.maximum-deletions-on-a-string.kt
# - Downloading maximum-deletions-on-a-string
#   ✔ Accepted
#   ✔ 129/129 cases passed (602 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (220.6 MB)
# Submitting: kotlin_solutions_1/2432.the-employee-that-worked-on-the-longest-task.kt
# - Downloading the-employee-that-worked-on-the-longest-task
#   ✔ Accepted
#   ✔ 514/514 cases passed (25 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2433.find-the-original-array-of-prefix-xor.kt
# - Downloading find-the-original-array-of-prefix-xor
#   ✔ Accepted
#   ✔ 46/46 cases passed (3 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (71.7 MB)
# Submitting: kotlin_solutions_1/2434.using-a-robot-to-print-the-lexicographically-smallest-string.kt
# - Downloading using-a-robot-to-print-the-lexicographically-smallest-string
#   ✔ Accepted
#   ✔ 62/62 cases passed (129 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (49.2 MB)
# Submitting: kotlin_solutions_1/2438.range-product-queries-of-powers.kt
# - Downloading range-product-queries-of-powers
#   ✔ Accepted
#   ✔ 70/70 cases passed (83 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (104.5 MB)
# Submitting: kotlin_solutions_1/2439.minimize-maximum-of-array.kt
# - Downloading minimize-maximum-of-array
#   ✔ Accepted
#   ✔ 68/68 cases passed (18 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (67.4 MB)
# Submitting: kotlin_solutions_1/2442.count-number-of-distinct-integers-after-reverse-operations.kt
# - Downloading count-number-of-distinct-integers-after-reverse-operations
#   ✔ Accepted
#   ✔ 44/44 cases passed (149 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2443.sum-of-number-and-its-reverse.kt
# - Downloading sum-of-number-and-its-reverse
#   ✔ Accepted
#   ✔ 258/258 cases passed (322 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (48.1 MB)
# Submitting: kotlin_solutions_1/2444.count-subarrays-with-fixed-bounds.kt
# - Downloading count-subarrays-with-fixed-bounds
#   ✔ Accepted
#   ✔ 53/53 cases passed (32 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2462.total-cost-to-hire-k-workers.kt
# - Downloading total-cost-to-hire-k-workers
#   ✔ Accepted
#   ✔ 163/163 cases passed (175 ms)
#   ✔ Your runtime beats 9.68 % of kotlin submissions
#   ✔ Your memory usage beats 6.45 % of kotlin submissions (76.2 MB)
# Submitting: kotlin_solutions_1/2466.count-ways-to-build-good-strings.kt
# - Downloading count-ways-to-build-good-strings
#   ✔ Accepted
#   ✔ 36/36 cases passed (14 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2472.maximum-number-of-non-overlapping-palindrome-substrings.kt
# - Downloading maximum-number-of-non-overlapping-palindrome-substrings
#   ✔ Accepted
#   ✔ 56/56 cases passed (14 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (43.2 MB)
# Submitting: kotlin_solutions_1/2477.minimum-fuel-cost-to-report-to-the-capital.kt
# - Downloading minimum-fuel-cost-to-report-to-the-capital
#   ✔ Accepted
#   ✔ 131/131 cases passed (133 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (100.2 MB)
# Submitting: kotlin_solutions_1/2478.number-of-beautiful-partitions.kt
# - Downloading number-of-beautiful-partitions
#   ✔ Accepted
#   ✔ 74/74 cases passed (208 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (56.9 MB)
# Submitting: kotlin_solutions_1/2482.difference-between-ones-and-zeros-in-row-and-column.kt
# - Downloading difference-between-ones-and-zeros-in-row-and-column
# [ERROR] session expired, please login again [code=-1]
# Submitting: kotlin_solutions_1/2484.count-palindromic-subsequences.kt
# - Downloading count-palindromic-subsequences
#   ✔ Accepted
#   ✔ 63/63 cases passed (80 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (61.4 MB)
# Submitting: kotlin_solutions_1/2485.find-the-pivot-integer.kt
# - Downloading find-the-pivot-integer
#   ✔ Accepted
#   ✔ 428/428 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 80 % of kotlin submissions (40.6 MB)
# Submitting: kotlin_solutions_1/2486.append-characters-to-string-to-make-subsequence.kt
# - Downloading append-characters-to-string-to-make-subsequence
#   ✔ Accepted
#   ✔ 86/86 cases passed (9 ms)
#   ✔ Your runtime beats 40 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/2488.count-subarrays-with-median-k.kt
# - Downloading count-subarrays-with-median-k
#   ✔ Accepted
#   ✔ 45/45 cases passed (56 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (63.2 MB)
# Submitting: kotlin_solutions_1/2491.divide-players-into-teams-of-equal-skill.kt
# - Downloading divide-players-into-teams-of-equal-skill
#   ✔ Accepted
#   ✔ 89/89 cases passed (119 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
#   ✔ Your memory usage beats 40 % of kotlin submissions (65.6 MB)
# Submitting: kotlin_solutions_1/2498.frog-jump-ii.kt
# - Downloading frog-jump-ii
#   ✔ Accepted
#   ✔ 34/34 cases passed (13 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (64 MB)
# Submitting: kotlin_solutions_1/2499.minimum-total-cost-to-make-arrays-unequal.kt
# - Downloading minimum-total-cost-to-make-arrays-unequal
#   ✔ Accepted
#   ✔ 104/104 cases passed (76 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (74.4 MB)
# Submitting: kotlin_solutions_1/2501.longest-square-streak-in-an-array.kt
# - Downloading longest-square-streak-in-an-array
#   ✔ Accepted
#   ✔ 88/88 cases passed (136 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 75 % of kotlin submissions (71.4 MB)
# Submitting: kotlin_solutions_1/2502.design-memory-allocator.kt
# - Downloading design-memory-allocator
#   ✔ Accepted
#   ✔ 109/109 cases passed (2263 ms)
#   ✔ Your runtime beats 5.26 % of kotlin submissions
#   ✔ Your memory usage beats 5.26 % of kotlin submissions (70.7 MB)
# Submitting: kotlin_solutions_1/2503.maximum-number-of-points-from-grid-queries.kt
# - Downloading maximum-number-of-points-from-grid-queries
#   ✔ Accepted
#   ✔ 22/22 cases passed (274 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2507.smallest-value-after-replacing-with-sum-of-prime-factors.kt
# - Downloading smallest-value-after-replacing-with-sum-of-prime-factors
#   ✔ Accepted
#   ✔ 209/209 cases passed (97 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (48.7 MB)
# Submitting: kotlin_solutions_1/2508.add-edges-to-make-degrees-of-all-nodes-even.kt
# - Downloading add-edges-to-make-degrees-of-all-nodes-even
#   ✔ Accepted
#   ✔ 52/52 cases passed (114 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (125.8 MB)
# Submitting: kotlin_solutions_1/2511.maximum-enemy-forts-that-can-be-captured.kt
# - Downloading maximum-enemy-forts-that-can-be-captured
#   ✔ Accepted
#   ✔ 45/45 cases passed (15 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2514.count-anagrams.kt
# - Downloading count-anagrams
#   ✔ Accepted
#   ✔ 41/41 cases passed (80 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2515.shortest-distance-to-target-string-in-a-circular-array.kt
# - Downloading shortest-distance-to-target-string-in-a-circular-array
#   ✔ Accepted
#   ✔ 668/668 cases passed (24 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2516.take-k-of-each-character-from-left-and-right.kt
# - Downloading take-k-of-each-character-from-left-and-right
#   ✔ Accepted
#   ✔ 142/142 cases passed (105 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (53.2 MB)
# Submitting: kotlin_solutions_1/2517.maximum-tastiness-of-candy-basket.kt
# - Downloading maximum-tastiness-of-candy-basket
#   ✔ Accepted
#   ✔ 40/40 cases passed (332 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (61.3 MB)
# Submitting: kotlin_solutions_1/2518.number-of-great-partitions.kt
# - Downloading number-of-great-partitions
#   ✔ Accepted
#   ✔ 46/46 cases passed (27 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (45.7 MB)
# Submitting: kotlin_solutions_1/2522.partition-string-into-substrings-with-values-at-most-k.kt
# - Downloading partition-string-into-substrings-with-values-at-most-k
#   ✔ Accepted
#   ✔ 56/56 cases passed (23 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (46.2 MB)
# Submitting: kotlin_solutions_1/2523.closest-prime-numbers-in-range.kt
# - Downloading closest-prime-numbers-in-range
#   ✔ Accepted
#   ✔ 68/68 cases passed (160 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/2526.find-consecutive-integers-from-a-data-stream.kt
# - Downloading find-consecutive-integers-from-a-data-stream
#   ✔ Accepted
#   ✔ 38/38 cases passed (48 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (114 MB)
# Submitting: kotlin_solutions_1/2530.maximal-score-after-applying-k-operations.kt
# - Downloading maximal-score-after-applying-k-operations
#   ✔ Accepted
#   ✔ 40/40 cases passed (88 ms)
#   ✔ Your runtime beats 66.67 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (67.1 MB)
# Submitting: kotlin_solutions_1/2531.make-number-of-distinct-characters-equal.kt
# - Downloading make-number-of-distinct-characters-equal
#   ✔ Accepted
#   ✔ 99/99 cases passed (28 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (47.2 MB)
# Submitting: kotlin_solutions_1/2532.time-to-cross-a-bridge.kt
# - Downloading time-to-cross-a-bridge
#   ✔ Accepted
#   ✔ 65/65 cases passed (126 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (62.8 MB)
# Submitting: kotlin_solutions_1/2541.minimum-operations-to-make-array-equal-ii.kt
# - Downloading minimum-operations-to-make-array-equal-ii
#   ✔ Accepted
#   ✔ 68/68 cases passed (42 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2542.maximum-subsequence-score.kt
# - Downloading maximum-subsequence-score
#   ✔ Accepted
#   ✔ 28/28 cases passed (144 ms)
#   ✔ Your runtime beats 10 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (66.8 MB)
# Submitting: kotlin_solutions_1/2543.check-if-point-is-reachable.kt
# - Downloading check-if-point-is-reachable
#   ✔ Accepted
#   ✔ 60/60 cases passed (7 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (41.3 MB)
# Submitting: kotlin_solutions_1/2546.apply-bitwise-operations-to-make-strings-equal.kt
# - Downloading apply-bitwise-operations-to-make-strings-equal
#   ✔ Accepted
#   ✔ 71/71 cases passed (7 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (47 MB)
# Submitting: kotlin_solutions_1/2547.minimum-cost-to-split-an-array.kt
# - Downloading minimum-cost-to-split-an-array
#   ✔ Accepted
#   ✔ 59/59 cases passed (268 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (49.9 MB)

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-08-18 13:24:41
