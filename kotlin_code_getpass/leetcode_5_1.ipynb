# %%
# %%capture
import os
import getpass

# 2. Interactive input (Safe and hidden)
print("Please enter your LeetCode credentials:")
user_name = getpass.getpass('LeetCode Username: ')
user_cookie = getpass.getpass('LeetCode Session Token: ')

# 1. Install and Clone
# !npm install -g leetcode-tools/leetcode-cli
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME'] = user_name
    os.environ['LEETCODE_TOKEN'] = user_cookie

    # 4. Run the login silently
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME" "$LEETCODE_TOKEN" | leetcode user -c

# %%
# %%bash
#
# # top 400-500 answers (5th batch)
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v kotlin_solutions/*.kt | sed -n '451,500p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 6
# done
# Out:
# Submitting: kotlin_solutions/583.delete-operation-for-two-strings.kt
# - Downloading delete-operation-for-two-strings
#   ✔ Accepted
#   ✔ 1306/1306 cases passed (22 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
#   ✔ Your memory usage beats 40 % of kotlin submissions (46.8 MB)
# Submitting: kotlin_solutions/587.erect-the-fence.kt
# - Downloading erect-the-fence
#   ✔ Accepted
#   ✔ 88/88 cases passed (67 ms)
#   ✔ Your runtime beats 60 % of kotlin submissions
#   ✔ Your memory usage beats 40 % of kotlin submissions (60 MB)
# Submitting: kotlin_solutions/589.n-ary-tree-preorder-traversal.kt
# - Downloading n-ary-tree-preorder-traversal
#   ✔ Accepted
#   ✔ 39/39 cases passed (155 ms)
#   ✔ Your runtime beats 90 % of kotlin submissions
#   ✔ Your memory usage beats 93.33 % of kotlin submissions (47.8 MB)
# Submitting: kotlin_solutions/590.n-ary-tree-postorder-traversal.kt
# - Downloading n-ary-tree-postorder-traversal
#   ✔ Accepted
#   ✔ 38/38 cases passed (197 ms)
#   ✔ Your runtime beats 10.34 % of kotlin submissions
#   ✔ Your memory usage beats 17.24 % of kotlin submissions (50.6 MB)
# Submitting: kotlin_solutions/591.tag-validator.kt
# - Downloading tag-validator
#   ✔ Accepted
#   ✔ 261/261 cases passed (37 ms)
#   ✔ Your runtime beats 44.44 % of kotlin submissions
#   ✔ Your memory usage beats 44.44 % of kotlin submissions (47.3 MB)
# Submitting: kotlin_solutions/592.fraction-addition-and-subtraction.kt
# - Downloading fraction-addition-and-subtraction
#   ✔ Accepted
#   ✔ 105/105 cases passed (38 ms)
#   ✔ Your runtime beats 77.78 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (46.5 MB)
# Submitting: kotlin_solutions/593.valid-square.kt
# - Downloading valid-square
#   ✔ Accepted
#   ✔ 256/256 cases passed (17 ms)
#   ✔ Your runtime beats 18.18 % of kotlin submissions
#   ✔ Your memory usage beats 27.27 % of kotlin submissions (44.1 MB)
# Submitting: kotlin_solutions/594.longest-harmonious-subsequence.kt
# - Downloading longest-harmonious-subsequence
#   ✔ Accepted
#   ✔ 208/208 cases passed (47 ms)
#   ✔ Your runtime beats 17.91 % of kotlin submissions
#   ✔ Your memory usage beats 20.9 % of kotlin submissions (54.8 MB)
# Submitting: kotlin_solutions/598.range-addition-ii.kt
# - Downloading range-addition-ii
#   ✔ Accepted
#   ✔ 69/69 cases passed (3 ms)
#   ✔ Your runtime beats 45 % of kotlin submissions
#   ✔ Your memory usage beats 90 % of kotlin submissions (46.4 MB)
# Submitting: kotlin_solutions/599.minimum-index-sum-of-two-lists.kt
# - Downloading minimum-index-sum-of-two-lists
#   ✔ Accepted
#   ✔ 137/137 cases passed (43 ms)
#   ✔ Your runtime beats 31.58 % of kotlin submissions
#   ✔ Your memory usage beats 44.74 % of kotlin submissions (50.7 MB)
# Submitting: kotlin_solutions/600.non-negative-integers-without-consecutive-ones.kt
# - Downloading non-negative-integers-without-consecutive-ones
#   ✔ Accepted
#   ✔ 527/527 cases passed (8 ms)
#   ✔ Your runtime beats 31.25 % of kotlin submissions
#   ✔ Your memory usage beats 62.5 % of kotlin submissions (41.4 MB)
# Submitting: kotlin_solutions/605.can-place-flowers.kt
# - Downloading can-place-flowers
# [ERROR] http error [code=429]
# Submitting: kotlin_solutions/606.construct-string-from-binary-tree.kt
# - Downloading construct-string-from-binary-tree
#   ✔ Accepted
#   ✔ 160/160 cases passed (7 ms)
#   ✔ Your runtime beats 26.67 % of kotlin submissions
#   ✔ Your memory usage beats 80 % of kotlin submissions (45.3 MB)
# Submitting: kotlin_solutions/609.find-duplicate-file-in-system.kt
# - Downloading find-duplicate-file-in-system
#   ✔ Accepted
#   ✔ 162/162 cases passed (64 ms)
#   ✔ Your runtime beats 19.05 % of kotlin submissions
#   ✔ Your memory usage beats 28.57 % of kotlin submissions (61.4 MB)
# Submitting: kotlin_solutions/611.valid-triangle-number.kt
# - Downloading valid-triangle-number
#   ✔ Accepted
#   ✔ 241/241 cases passed (710 ms)
#   ✔ Your runtime beats 28.57 % of kotlin submissions
#   ✔ Your memory usage beats 11.43 % of kotlin submissions (68 MB)
# Submitting: kotlin_solutions/617.merge-two-binary-trees.kt
# - Downloading merge-two-binary-trees
#   ✔ Accepted
#   ✔ 182/182 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 61.36 % of kotlin submissions (48.2 MB)
# Submitting: kotlin_solutions/621.task-scheduler.kt
# - Downloading task-scheduler
#   ✔ Accepted
#   ✔ 72/72 cases passed (31 ms)
#   ✔ Your runtime beats 69.23 % of kotlin submissions
#   ✔ Your memory usage beats 24.79 % of kotlin submissions (51 MB)
# Submitting: kotlin_solutions/622.design-circular-queue.kt
# - Downloading design-circular-queue
#   ✔ Accepted
#   ✔ 59/59 cases passed (18 ms)
#   ✔ Your runtime beats 48.57 % of kotlin submissions
#   ✔ Your memory usage beats 5.71 % of kotlin submissions (53.8 MB)
# Submitting: kotlin_solutions/623.add-one-row-to-tree.kt
# - Downloading add-one-row-to-tree
#   ✔ Accepted
#   ✔ 109/109 cases passed (18 ms)
#   ✔ Your runtime beats 87.5 % of kotlin submissions
#   ✔ Your memory usage beats 75 % of kotlin submissions (45.4 MB)
# Submitting: kotlin_solutions/624.maximum-distance-in-arrays.kt
# - Downloading maximum-distance-in-arrays
#   ✔ Accepted
#   ✔ 136/136 cases passed (40 ms)
#   ✔ Your runtime beats 36.36 % of kotlin submissions
#   ✔ Your memory usage beats 18.18 % of kotlin submissions (93.4 MB)
# Submitting: kotlin_solutions/628.maximum-product-of-three-numbers.kt
# - Downloading maximum-product-of-three-numbers
#   ✔ Accepted
#   ✔ 93/93 cases passed (71 ms)
#   ✔ Your runtime beats 13.33 % of kotlin submissions
#   ✔ Your memory usage beats 13.33 % of kotlin submissions (51.9 MB)
# Submitting: kotlin_solutions/629.k-inverse-pairs-array.kt
# - Downloading k-inverse-pairs-array
#   ✔ Accepted
#   ✔ 81/81 cases passed (916 ms)
#   ✔ Your runtime beats 37.5 % of kotlin submissions
#   ✔ Your memory usage beats 81.25 % of kotlin submissions (46 MB)
# Submitting: kotlin_solutions/630.course-schedule-iii.kt
# - Downloading course-schedule-iii
#   ✔ Accepted
#   ✔ 97/97 cases passed (69 ms)
#   ✔ Your runtime beats 73.33 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (72.8 MB)
# Submitting: kotlin_solutions/632.smallest-range-covering-elements-from-k-lists.kt
# - Downloading smallest-range-covering-elements-from-k-lists
#   ✔ Accepted
#   ✔ 94/94 cases passed (267 ms)
#   ✔ Your runtime beats 39.13 % of kotlin submissions
#   ✔ Your memory usage beats 34.78 % of kotlin submissions (97.5 MB)
# Submitting: kotlin_solutions/633.sum-of-square-numbers.kt
# - Downloading sum-of-square-numbers
#   ✔ Accepted
#   ✔ 127/127 cases passed (28 ms)
#   ✔ Your runtime beats 55.56 % of kotlin submissions
#   ✔ Your memory usage beats 22.22 % of kotlin submissions (46.4 MB)
# Submitting: kotlin_solutions/636.exclusive-time-of-functions.kt
# - Downloading exclusive-time-of-functions
#   ✔ Accepted
#   ✔ 120/120 cases passed (49 ms)
#   ✔ Your runtime beats 18.84 % of kotlin submissions
#   ✔ Your memory usage beats 5.8 % of kotlin submissions (50.2 MB)
# Submitting: kotlin_solutions/637.average-of-levels-in-binary-tree.kt
# - Downloading average-of-levels-in-binary-tree
#   ✔ Accepted
#   ✔ 66/66 cases passed (36 ms)
#   ✔ Your runtime beats 7.69 % of kotlin submissions
#   ✔ Your memory usage beats 7.69 % of kotlin submissions (51.9 MB)
# Submitting: kotlin_solutions/638.shopping-offers.kt
# - Downloading shopping-offers
#   ✔ Accepted
#   ✔ 65/65 cases passed (36 ms)
#   ✔ Your runtime beats 46.88 % of kotlin submissions
#   ✔ Your memory usage beats 93.75 % of kotlin submissions (46.4 MB)
# Submitting: kotlin_solutions/639.decode-ways-ii.kt
# - Downloading decode-ways-ii
#   ✔ Accepted
#   ✔ 218/218 cases passed (310 ms)
#   ✔ Your runtime beats 60 % of kotlin submissions
#   ✔ Your memory usage beats 10 % of kotlin submissions (83 MB)
# Submitting: kotlin_solutions/640.solve-the-equation.kt
# - Downloading solve-the-equation
#   ✔ Accepted
#   ✔ 59/59 cases passed (14 ms)
#   ✔ Your runtime beats 47.06 % of kotlin submissions
#   ✔ Your memory usage beats 5.88 % of kotlin submissions (43.8 MB)
# Submitting: kotlin_solutions/641.design-circular-deque.kt
# - Downloading design-circular-deque
#   ✔ Accepted
#   ✔ 54/54 cases passed (17 ms)
#   ✔ Your runtime beats 94.12 % of kotlin submissions
#   ✔ Your memory usage beats 17.65 % of kotlin submissions (49.7 MB)
# Submitting: kotlin_solutions/643.maximum-average-subarray-i.kt
# - Downloading maximum-average-subarray-i
#   ✔ Accepted
#   ✔ 128/128 cases passed (62 ms)
#   ✔ Your runtime beats 9.3 % of kotlin submissions
#   ✔ Your memory usage beats 5.22 % of kotlin submissions (67 MB)
# Submitting: kotlin_solutions/645.set-mismatch.kt
# - Downloading set-mismatch
#   ✔ Accepted
#   ✔ 49/49 cases passed (34 ms)
#   ✔ Your runtime beats 20.82 % of kotlin submissions
#   ✔ Your memory usage beats 14.5 % of kotlin submissions (50.8 MB)
# Submitting: kotlin_solutions/646.maximum-length-of-pair-chain.kt
# - Downloading maximum-length-of-pair-chain
#   ✔ Accepted
#   ✔ 206/206 cases passed (26 ms)
#   ✔ Your runtime beats 67.74 % of kotlin submissions
#   ✔ Your memory usage beats 38.71 % of kotlin submissions (56.6 MB)
# Submitting: kotlin_solutions/647.palindromic-substrings.kt
# - Downloading palindromic-substrings
#   ✔ Accepted
#   ✔ 132/132 cases passed (44 ms)
#   ✔ Your runtime beats 14.91 % of kotlin submissions
#   ✔ Your memory usage beats 5.59 % of kotlin submissions (49.1 MB)
# Submitting: kotlin_solutions/648.replace-words.kt
# - Downloading replace-words
#   ✔ Accepted
#   ✔ 130/130 cases passed (109 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
#   ✔ Your memory usage beats 53.33 % of kotlin submissions (59.7 MB)
# Submitting: kotlin_solutions/649.dota-2-senate.kt
# - Downloading dota2-senate
#   ✔ Accepted
#   ✔ 83/83 cases passed (18 ms)
#   ✔ Your runtime beats 87.1 % of kotlin submissions
#   ✔ Your memory usage beats 9.68 % of kotlin submissions (48.2 MB)
# Submitting: kotlin_solutions/650.2-keys-keyboard.kt
# - Downloading 2-keys-keyboard
#   ✔ Accepted
#   ✔ 126/126 cases passed (16 ms)
#   ✔ Your runtime beats 53.33 % of kotlin submissions
#   ✔ Your memory usage beats 60 % of kotlin submissions (41.9 MB)
# Submitting: kotlin_solutions/652.find-duplicate-subtrees.kt
# - Downloading find-duplicate-subtrees
#   ✔ Accepted
#   ✔ 175/175 cases passed (106 ms)
#   ✔ Your runtime beats 27.27 % of kotlin submissions
#   ✔ Your memory usage beats 72.73 % of kotlin submissions (53 MB)
# Submitting: kotlin_solutions/653.two-sum-iv-input-is-a-bst.kt
# - Downloading two-sum-iv-input-is-a-bst
#   ✔ Accepted
#   ✔ 423/423 cases passed (6 ms)
#   ✔ Your runtime beats 43.64 % of kotlin submissions
#   ✔ Your memory usage beats 89.09 % of kotlin submissions (46.9 MB)
# Submitting: kotlin_solutions/654.maximum-binary-tree.kt
# - Downloading maximum-binary-tree
#   ✔ Accepted
#   ✔ 107/107 cases passed (40 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 36.67 % of kotlin submissions (53.1 MB)
# Submitting: kotlin_solutions/655.print-binary-tree.kt
# - Downloading print-binary-tree
#   ✔ Accepted
#   ✔ 73/73 cases passed (13 ms)
#   ✔ Your runtime beats 77.78 % of kotlin submissions
#   ✔ Your memory usage beats 88.89 % of kotlin submissions (44.9 MB)
# Submitting: kotlin_solutions/657.robot-return-to-origin.kt
# - Downloading robot-return-to-origin
#   ✔ Accepted
#   ✔ 78/78 cases passed (21 ms)
#   ✔ Your runtime beats 26.19 % of kotlin submissions
#   ✔ Your memory usage beats 26.19 % of kotlin submissions (46.2 MB)
# Submitting: kotlin_solutions/658.find-k-closest-elements.kt
# - Downloading find-k-closest-elements
#   ✔ Accepted
#   ✔ 70/70 cases passed (39 ms)
#   ✔ Your runtime beats 33.81 % of kotlin submissions
#   ✔ Your memory usage beats 36.69 % of kotlin submissions (51.1 MB)
# Submitting: kotlin_solutions/659.split-array-into-consecutive-subsequences.kt
# - Downloading split-array-into-consecutive-subsequences
#   ✔ Accepted
#   ✔ 187/187 cases passed (39 ms)
#   ✔ Your runtime beats 72.22 % of kotlin submissions
#   ✔ Your memory usage beats 61.11 % of kotlin submissions (51.8 MB)
# Submitting: kotlin_solutions/661.image-smoother.kt
# - Downloading image-smoother
#   ✔ Accepted
#   ✔ 203/203 cases passed (86 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 75 % of kotlin submissions (54.7 MB)
# Submitting: kotlin_solutions/662.maximum-width-of-binary-tree.kt
# - Downloading maximum-width-of-binary-tree
#   ✔ Accepted
#   ✔ 117/117 cases passed (28 ms)
#   ✔ Your runtime beats 12.25 % of kotlin submissions
#   ✔ Your memory usage beats 28.57 % of kotlin submissions (48.3 MB)
# Submitting: kotlin_solutions/664.strange-printer.kt
# - Downloading strange-printer
#   ✔ Accepted
#   ✔ 200/200 cases passed (109 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
#   ✔ Your memory usage beats 70 % of kotlin submissions (53.3 MB)
# Submitting: kotlin_solutions/665.non-decreasing-array.kt
# - Downloading non-decreasing-array
#   ✔ Accepted
#   ✔ 335/335 cases passed (31 ms)
#   ✔ Your runtime beats 31.25 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (52.7 MB)
# Submitting: kotlin_solutions/667.beautiful-arrangement-ii.kt
# - Downloading beautiful-arrangement-ii
#   ✔ Accepted
#   ✔ 70/70 cases passed (1 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (45.9 MB)

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-03-18 15:50:11
