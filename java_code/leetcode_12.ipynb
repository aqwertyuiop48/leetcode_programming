# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME_3')
    user_cookie = userdata.get('LEETCODE_TOKEN_3')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME_3'] = user_name
    os.environ['LEETCODE_TOKEN_3'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME_3" "$LEETCODE_TOKEN_3" | leetcode user -c

# %%
# %%bash
#
#
# # top 100 answers
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v java_solutions/*.java | sed -n '1101,1200p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 7
# done
# Out:
# Submitting: java_solutions/3333.find-the-original-typed-string-ii.java
# - Downloading find-the-original-typed-string-ii
#   ✔ Accepted
#   ✔ 846/846 cases passed (479 ms)
#   ✔ Your runtime beats 5.41 % of java submissions
#   ✔ Your memory usage beats 37.84 % of java submissions (69.9 MB)
# Submitting: java_solutions/3336.find-the-number-of-subsequences-with-equal-gcd.java
# - Downloading find-the-number-of-subsequences-with-equal-gcd
#   ✔ Accepted
#   ✔ 622/622 cases passed (909 ms)
#   ✔ Your runtime beats 17.2 % of java submissions
#   ✔ Your memory usage beats 77.42 % of java submissions (58 MB)
# Submitting: java_solutions/3337.total-characters-in-string-after-transformations-ii.java
# - Downloading total-characters-in-string-after-transformations-ii
#   ✔ Accepted
#   ✔ 536/536 cases passed (1651 ms)
#   ✔ Your runtime beats 5.55 % of java submissions
#   ✔ Your memory usage beats 5.56 % of java submissions (53.8 MB)
# Submitting: java_solutions/3343.count-number-of-balanced-permutations.java
# - Downloading count-number-of-balanced-permutations
#   ✔ Accepted
#   ✔ 792/792 cases passed (1074 ms)
#   ✔ Your runtime beats 9.52 % of java submissions
#   ✔ Your memory usage beats 19.05 % of java submissions (53.9 MB)
# Submitting: java_solutions/3347.maximum-frequency-of-an-element-after-performing-operations-ii.java
# - Downloading maximum-frequency-of-an-element-after-performing-operations-ii
#   ✔ Accepted
#   ✔ 634/634 cases passed (904 ms)
#   ✔ Your runtime beats 31.69 % of java submissions
#   ✔ Your memory usage beats 52.68 % of java submissions (188 MB)
# Submitting: java_solutions/3348.smallest-divisible-digit-product-ii.java
# - Downloading smallest-divisible-digit-product-ii
#   ✔ Accepted
#   ✔ 954/954 cases passed (148 ms)
#   ✔ Your runtime beats 16 % of java submissions
#   ✔ Your memory usage beats 16 % of java submissions (56.7 MB)
# Submitting: java_solutions/3351.sum-of-good-subsequences.java
# - Downloading sum-of-good-subsequences
#   ✔ Accepted
#   ✔ 679/679 cases passed (275 ms)
#   ✔ Your runtime beats 5.88 % of java submissions
#   ✔ Your memory usage beats 5.88 % of java submissions (178 MB)
# Submitting: java_solutions/3352.count-k-reducible-numbers-less-than-n.java
# - Downloading count-k-reducible-numbers-less-than-n
#   ✔ Accepted
#   ✔ 774/774 cases passed (264 ms)
#   ✔ Your runtime beats 19.23 % of java submissions
#   ✔ Your memory usage beats 46.15 % of java submissions (53.2 MB)
# Submitting: java_solutions/3357.minimize-the-maximum-adjacent-element-difference.java
# - Downloading minimize-the-maximum-adjacent-element-difference
#   ✔ Accepted
#   ✔ 958/958 cases passed (92 ms)
#   ✔ Your runtime beats 5.56 % of java submissions
#   ✔ Your memory usage beats 5.56 % of java submissions (90.3 MB)
# Submitting: java_solutions/3363.find-the-maximum-number-of-fruits-collected.java
# - Downloading find-the-maximum-number-of-fruits-collected
#   ✔ Accepted
#   ✔ 549/549 cases passed (536 ms)
#   ✔ Your runtime beats 5.05 % of java submissions
#   ✔ Your memory usage beats 5.05 % of java submissions (290.5 MB)
# Submitting: java_solutions/3367.maximize-sum-of-weights-after-edge-removals.java
# - Downloading maximize-sum-of-weights-after-edge-removals
#   ✔ Accepted
#   ✔ 714/714 cases passed (1229 ms)
#   ✔ Your runtime beats 6.9 % of java submissions
#   ✔ Your memory usage beats 6.9 % of java submissions (413.5 MB)
# Submitting: java_solutions/3373.maximize-the-number-of-target-nodes-after-connecting-trees-ii.java
# - Downloading maximize-the-number-of-target-nodes-after-connecting-trees-ii
#   ✔ Accepted
#   ✔ 825/825 cases passed (276 ms)
#   ✔ Your runtime beats 5.36 % of java submissions
#   ✔ Your memory usage beats 33.93 % of java submissions (287.1 MB)
# Submitting: java_solutions/3378.count-connected-components-in-lcm-graph.java
# - Downloading count-connected-components-in-lcm-graph
#   ✔ Accepted
#   ✔ 697/697 cases passed (1010 ms)
#   ✔ Your runtime beats 8.11 % of java submissions
#   ✔ Your memory usage beats 37.84 % of java submissions (100.2 MB)
# Submitting: java_solutions/3382.maximum-area-rectangle-with-point-constraints-ii.java
# - Downloading maximum-area-rectangle-with-point-constraints-ii
#   ✘ Time Limit Exceeded
#   ✘ 593/594 cases passed (N/A)
25001,25001,25001,14472,25001,16832,7080,25001,20622,9147,25001,25001,25001,25001,25001,25001,5270,25001,25001,18940,1567,25001,25001,6268,25001,8634,926,25001,17139,5130,9386,25001,25001,7684,25001,25001,13207,18983,25001,25001,25001,25001,25001,25001,25001,8111,20485,25001,25001,25001,15479,25001,25001,25001,6494,6693,25001,22379,25001,25001,25001,25001,20740,25001,25001,25001,7241,21524,21423,25001,25001,25001,19421,6814,25001,14839,922,25001,18036,25001,25001,25001,25001,25001,25001,25001,16736,13460,25001,25001,25001,22540,2798,6193,25001,23102,15880,25001,25001,24536,14534,9688,25001,20511,25001,25001,7662,25001,19195,25001,25001,25001,2619,22562,17214,25001,25001,24479,25001,8936,25001,15495,22 ...
#   ✘ Answer: 25000
#   ✘ Expected Answer: 25000
#   ✘ Stdout:
# Submitting: java_solutions/3389.minimum-operations-to-make-character-frequencies-equal.java
# - Downloading minimum-operations-to-make-character-frequencies-equal
#   ✔ Accepted
#   ✔ 773/773 cases passed (99 ms)
#   ✔ Your runtime beats 18.18 % of java submissions
#   ✔ Your memory usage beats 13.64 % of java submissions (47.5 MB)
# Submitting: java_solutions/3395.subsequences-with-a-unique-middle-mode-i.java
# - Downloading subsequences-with-a-unique-middle-mode-i
#   ✔ Accepted
#   ✔ 947/947 cases passed (2732 ms)
#   ✔ Your runtime beats 8.7 % of java submissions
#   ✔ Your memory usage beats 8.7 % of java submissions (53.3 MB)
# Submitting: java_solutions/3398.smallest-substring-with-identical-characters-i.java
# - Downloading smallest-substring-with-identical-characters-i
#   ✔ Accepted
#   ✔ 949/949 cases passed (173 ms)
#   ✔ Your runtime beats 6.9 % of java submissions
#   ✔ Your memory usage beats 6.9 % of java submissions (48.5 MB)
# Submitting: java_solutions/3399.smallest-substring-with-identical-characters-ii.java
# - Downloading smallest-substring-with-identical-characters-ii
#   ✔ Accepted
#   ✔ 970/970 cases passed (131 ms)
#   ✔ Your runtime beats 26.32 % of java submissions
#   ✔ Your memory usage beats 10.53 % of java submissions (53.6 MB)
# Submitting: java_solutions/3405.count-the-number-of-arrays-with-k-matching-adjacent-elements.java
# - Downloading count-the-number-of-arrays-with-k-matching-adjacent-elements
#   ✔ Accepted
#   ✔ 809/809 cases passed (94 ms)
#   ✔ Your runtime beats 58.06 % of java submissions
#   ✔ Your memory usage beats 58.06 % of java submissions (44.8 MB)
# Submitting: java_solutions/3410.maximize-subarray-sum-after-removing-all-occurrences-of-one-element.java
# - Downloading maximize-subarray-sum-after-removing-all-occurrences-of-one-element
#   ✔ Accepted
#   ✔ 660/660 cases passed (1851 ms)
#   ✔ Your runtime beats 8.33 % of java submissions
#   ✔ Your memory usage beats 8.33 % of java submissions (289.1 MB)
# Submitting: java_solutions/3414.maximum-score-of-non-overlapping-intervals.java
# - Downloading maximum-score-of-non-overlapping-intervals
#   ✔ Accepted
#   ✔ 581/581 cases passed (788 ms)
#   ✔ Your runtime beats 6.98 % of java submissions
#   ✔ Your memory usage beats 67.44 % of java submissions (186.3 MB)
# Submitting: java_solutions/3420.count-non-decreasing-subarrays-after-k-operations.java
# - Downloading count-non-decreasing-subarrays-after-k-operations
#   ✔ Accepted
#   ✔ 731/731 cases passed (659 ms)
#   ✔ Your runtime beats 11.76 % of java submissions
#   ✔ Your memory usage beats 97.06 % of java submissions (124.8 MB)
# Submitting: java_solutions/3425.longest-special-path.java
# - Downloading longest-special-path
#   ✔ Accepted
#   ✔ 675/675 cases passed (452 ms)
#   ✔ Your runtime beats 5.55 % of java submissions
#   ✔ Your memory usage beats 5.56 % of java submissions (401.9 MB)
# Submitting: java_solutions/3426.manhattan-distances-of-all-arrangements-of-pieces.java
# - Downloading manhattan-distances-of-all-arrangements-of-pieces
#   ✔ Accepted
#   ✔ 919/919 cases passed (65 ms)
#   ✔ Your runtime beats 25 % of java submissions
#   ✔ Your memory usage beats 43.75 % of java submissions (44.6 MB)
# Submitting: java_solutions/3430.maximum-and-minimum-sums-of-at-most-size-k-subarrays.java
# - Downloading maximum-and-minimum-sums-of-at-most-size-k-subarrays
#   ✔ Accepted
#   ✔ 684/684 cases passed (545 ms)
#   ✔ Your runtime beats 7.41 % of java submissions
#   ✔ Your memory usage beats 44.44 % of java submissions (120.9 MB)
# Submitting: java_solutions/3435.frequencies-of-shortest-supersequences.java
# - Downloading frequencies-of-shortest-supersequences
#   ✔ Accepted
#   ✔ 808/808 cases passed (115 ms)
#   ✔ Your runtime beats 52.38 % of java submissions
#   ✔ Your memory usage beats 9.52 % of java submissions (53.4 MB)
# Submitting: java_solutions/3441.minimum-cost-good-caption.java
# - Downloading minimum-cost-good-caption
#   ✔ Accepted
#   ✔ 714/714 cases passed (1722 ms)
#   ✔ Your runtime beats 31.25 % of java submissions
#   ✔ Your memory usage beats 75 % of java submissions (77.1 MB)
# Submitting: java_solutions/3444.minimum-increments-for-target-multiples-in-an-array.java
# - Downloading minimum-increments-for-target-multiples-in-an-array
#   ✔ Accepted
#   ✔ 590/590 cases passed (1085 ms)
#   ✔ Your runtime beats 7.69 % of java submissions
#   ✔ Your memory usage beats 34.62 % of java submissions (54.7 MB)
# Submitting: java_solutions/3445.maximum-difference-between-even-and-odd-frequency-ii.java
# - Downloading maximum-difference-between-even-and-odd-frequency-ii
#   ✔ Accepted
#   ✔ 693/693 cases passed (1198 ms)
#   ✔ Your runtime beats 6.06 % of java submissions
#   ✔ Your memory usage beats 18.18 % of java submissions (53.7 MB)
# Submitting: java_solutions/3448.count-substrings-divisible-by-last-digit.java
# - Downloading count-substrings-divisible-by-last-digit
#   ✔ Accepted
#   ✔ 699/699 cases passed (47 ms)
#   ✔ Your runtime beats 66.67 % of java submissions
#   ✔ Your memory usage beats 71.43 % of java submissions (48.3 MB)
# Submitting: java_solutions/3449.maximize-the-minimum-game-score.java
# - Downloading maximize-the-minimum-game-score
#   ✔ Accepted
#   ✔ 692/692 cases passed (607 ms)
#   ✔ Your runtime beats 19.35 % of java submissions
#   ✔ Your memory usage beats 6.45 % of java submissions (62.5 MB)
# Submitting: java_solutions/3451.find-invalid-ip-addresses.java
# - Downloading find-invalid-ip-addresses
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: java_solutions/3454.separate-squares-ii.java
# - Downloading separate-squares-ii
#   ✔ Accepted
#   ✔ 763/763 cases passed (1580 ms)
#   ✔ Your runtime beats 5.08 % of java submissions
#   ✔ Your memory usage beats 50 % of java submissions (155.1 MB)
# Submitting: java_solutions/3455.shortest-matching-substring.java
# - Downloading shortest-matching-substring
#   ✔ Accepted
#   ✔ 795/795 cases passed (452 ms)
#   ✔ Your runtime beats 26.32 % of java submissions
#   ✔ Your memory usage beats 39.47 % of java submissions (72.3 MB)
# Submitting: java_solutions/3459.length-of-longest-v-shaped-diagonal-segment.java
# - Downloading length-of-longest-v-shaped-diagonal-segment
#   ✔ Accepted
#   ✔ 561/561 cases passed (99 ms)
#   ✔ Your runtime beats 87.69 % of java submissions
#   ✔ Your memory usage beats 69.23 % of java submissions (204.4 MB)
# Submitting: java_solutions/3463.check-if-digits-are-equal-in-string-after-operations-ii.java
# - Downloading check-if-digits-are-equal-in-string-after-operations-ii
#   ✔ Accepted
#   ✔ 684/684 cases passed (566 ms)
#   ✔ Your runtime beats 8 % of java submissions
#   ✔ Your memory usage beats 16 % of java submissions (48.4 MB)
# Submitting: java_solutions/3464.maximize-the-distance-between-points-on-a-square.java
# - Downloading maximize-the-distance-between-points-on-a-square
#   ✔ Accepted
#   ✔ 619/619 cases passed (1679 ms)
#   ✔ Your runtime beats 16.67 % of java submissions
#   ✔ Your memory usage beats 5.56 % of java submissions (64.2 MB)
# Submitting: java_solutions/3470.permutations-iv.java
# - Downloading permutations-iv
#   ✔ Accepted
#   ✔ 999/999 cases passed (64 ms)
#   ✔ Your runtime beats 11.11 % of java submissions
#   ✔ Your memory usage beats 7.41 % of java submissions (53.4 MB)
# Submitting: java_solutions/3474.lexicographically-smallest-generated-string.java
# - Downloading lexicographically-smallest-generated-string
#   ✔ Accepted
#   ✔ 739/739 cases passed (246 ms)
#   ✔ Your runtime beats 5.01 % of java submissions
#   ✔ Your memory usage beats 6.88 % of java submissions (53.3 MB)
# Submitting: java_solutions/3480.maximize-subarrays-after-removing-one-conflicting-pair.java
# - Downloading maximize-subarrays-after-removing-one-conflicting-pair
#   ✔ Accepted
#   ✔ 642/642 cases passed (307 ms)
#   ✔ Your runtime beats 5 % of java submissions
#   ✔ Your memory usage beats 47.5 % of java submissions (280.4 MB)
# Submitting: java_solutions/3482.analyze-organization-hierarchy.java
# - Downloading analyze-organization-hierarchy
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: java_solutions/3485.longest-common-prefix-of-k-strings-after-removal.java
# - Downloading longest-common-prefix-of-k-strings-after-removal
#   ✔ Accepted
#   ✔ 667/667 cases passed (678 ms)
#   ✔ Your runtime beats 14.81 % of java submissions
#   ✔ Your memory usage beats 11.11 % of java submissions (286.7 MB)
# Submitting: java_solutions/3486.longest-special-path-ii.java
# - Downloading longest-special-path-ii
#   ✔ Accepted
#   ✔ 678/678 cases passed (360 ms)
#   ✔ Your runtime beats 10.53 % of java submissions
#   ✔ Your memory usage beats 10.53 % of java submissions (365.9 MB)
# Submitting: java_solutions/3490.count-beautiful-numbers.java
# - Downloading count-beautiful-numbers
#   ✔ Accepted
#   ✔ 554/554 cases passed (741 ms)
#   ✔ Your runtime beats 22.45 % of java submissions
#   ✔ Your memory usage beats 24.49 % of java submissions (88.4 MB)
# Submitting: java_solutions/3495.minimum-operations-to-make-array-elements-zero.java
# - Downloading minimum-operations-to-make-array-elements-zero
#   ✔ Accepted
#   ✔ 646/646 cases passed (31 ms)
#   ✔ Your runtime beats 29.79 % of java submissions
#   ✔ Your memory usage beats 8.51 % of java submissions (144.9 MB)
# Submitting: java_solutions/3500.minimum-cost-to-divide-array-into-subarrays.java
# - Downloading minimum-cost-to-divide-array-into-subarrays
#   ✔ Accepted
#   ✔ 759/759 cases passed (202 ms)
#   ✔ Your runtime beats 52 % of java submissions
#   ✔ Your memory usage beats 44 % of java submissions (53.4 MB)
# Submitting: java_solutions/3501.maximize-active-section-with-trade-ii.java
# - Downloading maximize-active-section-with-trade-ii
#   ✔ Accepted
#   ✔ 592/592 cases passed (533 ms)
#   ✔ Your runtime beats 27.78 % of java submissions
#   ✔ Your memory usage beats 55.56 % of java submissions (262.8 MB)
# Submitting: java_solutions/3504.longest-palindrome-after-substring-concatenation-ii.java
# - Downloading longest-palindrome-after-substring-concatenation-ii
#   ✔ Accepted
#   ✔ 904/904 cases passed (1675 ms)
#   ✔ Your runtime beats 6.98 % of java submissions
#   ✔ Your memory usage beats 9.3 % of java submissions (286.8 MB)
# Submitting: java_solutions/3505.minimum-operations-to-make-elements-within-k-subarrays-equal.java
# - Downloading minimum-operations-to-make-elements-within-k-subarrays-equal
#   ✔ Accepted
#   ✔ 774/774 cases passed (1337 ms)
#   ✔ Your runtime beats 16.67 % of java submissions
#   ✔ Your memory usage beats 13.33 % of java submissions (288.2 MB)
# Submitting: java_solutions/3509.maximum-product-of-subsequences-with-an-alternating-sum-equal-to-k.java
# - Downloading maximum-product-of-subsequences-with-an-alternating-sum-equal-to-k
#   ✔ Accepted
#   ✔ 665/665 cases passed (989 ms)
#   ✔ Your runtime beats 18.92 % of java submissions
#   ✔ Your memory usage beats 29.73 % of java submissions (274.1 MB)
# Submitting: java_solutions/3510.minimum-pair-removal-to-sort-array-ii.java
# - Downloading minimum-pair-removal-to-sort-array-ii
#   ✔ Accepted
#   ✔ 681/681 cases passed (1091 ms)
#   ✔ Your runtime beats 11.85 % of java submissions
#   ✔ Your memory usage beats 28.85 % of java submissions (180.1 MB)
# Submitting: java_solutions/3515.shortest-path-in-a-weighted-tree.java
# - Downloading shortest-path-in-a-weighted-tree
#   ✔ Accepted
#   ✔ 571/571 cases passed (767 ms)
#   ✔ Your runtime beats 5.55 % of java submissions
#   ✔ Your memory usage beats 5.55 % of java submissions (435.5 MB)
# Submitting: java_solutions/3518.smallest-palindromic-rearrangement-ii.java
# - Downloading smallest-palindromic-rearrangement-ii
#   ✔ Accepted
#   ✔ 812/812 cases passed (1215 ms)
#   ✔ Your runtime beats 7.14 % of java submissions
#   ✔ Your memory usage beats 7.14 % of java submissions (54 MB)
# Submitting: java_solutions/3519.count-numbers-with-non-decreasing-digits.java
# - Downloading count-numbers-with-non-decreasing-digits
#   ✔ Accepted
#   ✔ 973/973 cases passed (180 ms)
#   ✔ Your runtime beats 6.67 % of java submissions
#   ✔ Your memory usage beats 10 % of java submissions (53.8 MB)
# Submitting: java_solutions/3525.find-x-value-of-array-ii.java
# - Downloading find-x-value-of-array-ii
#   ✔ Accepted
#   ✔ 783/783 cases passed (832 ms)
#   ✔ Your runtime beats 12.5 % of java submissions
#   ✔ Your memory usage beats 75 % of java submissions (157.1 MB)
# Submitting: java_solutions/3530.maximum-profit-from-valid-topological-order-in-dag.java
# - Downloading maximum-profit-from-valid-topological-order-in-dag
#   ✔ Accepted
#   ✔ 804/804 cases passed (2039 ms)
#   ✔ Your runtime beats 10.77 % of java submissions
#   ✔ Your memory usage beats 46.15 % of java submissions (160.1 MB)
# Submitting: java_solutions/3533.concatenated-divisibility.java
# - Downloading concatenated-divisibility
#   ✔ Accepted
#   ✔ 622/622 cases passed (359 ms)
#   ✔ Your runtime beats 9.09 % of java submissions
#   ✔ Your memory usage beats 27.27 % of java submissions (63.2 MB)
# Submitting: java_solutions/3534.path-existence-queries-in-a-graph-ii.java
# - Downloading path-existence-queries-in-a-graph-ii
#   ✔ Accepted
#   ✔ 682/682 cases passed (962 ms)
#   ✔ Your runtime beats 8.33 % of java submissions
#   ✔ Your memory usage beats 8.33 % of java submissions (282.4 MB)
# Submitting: java_solutions/3538.merge-operations-for-minimum-travel-time.java
# - Downloading merge-operations-for-minimum-travel-time
#   ✔ Accepted
#   ✔ 997/997 cases passed (149 ms)
#   ✔ Your runtime beats 33.33 % of java submissions
#   ✔ Your memory usage beats 33.33 % of java submissions (53.6 MB)
# Submitting: java_solutions/3539.find-sum-of-array-product-of-magical-sequences.java
# - Downloading find-sum-of-array-product-of-magical-sequences
#   ✔ Accepted
#   ✔ 528/528 cases passed (387 ms)
#   ✔ Your runtime beats 12.97 % of java submissions
#   ✔ Your memory usage beats 45.41 % of java submissions (54.1 MB)
# Submitting: java_solutions/3544.subtree-inversion-sum.java
# - Downloading subtree-inversion-sum
#   ✔ Accepted
#   ✔ 676/676 cases passed (789 ms)
#   ✔ Your runtime beats 62.5 % of java submissions
#   ✔ Your memory usage beats 95.83 % of java submissions (222 MB)
# Submitting: java_solutions/3547.maximum-sum-of-edge-values-in-a-graph.java
# - Downloading maximum-sum-of-edge-values-in-a-graph
#   ✔ Accepted
#   ✔ 1837/1837 cases passed (1 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 74.42 % of java submissions (135.5 MB)
# Submitting: java_solutions/3548.equal-sum-grid-partition-ii.java
# - Downloading equal-sum-grid-partition-ii
#   ✔ Accepted
#   ✔ 942/942 cases passed (1447 ms)
#   ✔ Your runtime beats 5.02 % of java submissions
#   ✔ Your memory usage beats 24.21 % of java submissions (280.8 MB)
# Submitting: java_solutions/3553.minimum-weighted-subgraph-with-the-required-paths-ii.java
# - Downloading minimum-weighted-subgraph-with-the-required-paths-ii
#   ✔ Accepted
#   ✔ 670/670 cases passed (11 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 94.74 % of java submissions (270.8 MB)
# Submitting: java_solutions/3554.find-category-recommendation-pairs.java
# - Downloading find-category-recommendation-pairs
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: java_solutions/3559.number-of-ways-to-assign-edge-weights-ii.java
# - Downloading number-of-ways-to-assign-edge-weights-ii
#   ✔ Accepted
#   ✔ 589/589 cases passed (830 ms)
#   ✔ Your runtime beats 6.45 % of java submissions
#   ✔ Your memory usage beats 83.87 % of java submissions (275.7 MB)
# Submitting: java_solutions/3562.maximum-profit-from-trading-stocks-with-discounts.java
# - Downloading maximum-profit-from-trading-stocks-with-discounts
#   ✔ Accepted
#   ✔ 790/790 cases passed (17 ms)
#   ✔ Your runtime beats 95.92 % of java submissions
#   ✔ Your memory usage beats 5.1 % of java submissions (54.7 MB)
# Submitting: java_solutions/3563.lexicographically-smallest-string-after-adjacent-removals.java
# - Downloading lexicographically-smallest-string-after-adjacent-removals
#   ✔ Accepted
#   ✔ 930/930 cases passed (12 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 44 % of java submissions (54.3 MB)
# Submitting: java_solutions/3569.maximize-count-of-distinct-primes-after-split.java
# - Downloading maximize-count-of-distinct-primes-after-split
#   ✘ Time Limit Exceeded
#   ✘ 749/750 cases passed (N/A)
#   ✘ Testcase: [20147,86539,57241,83833,36683,769,95869,62137,92153,64189,99371,52889,52433,29881,33619,79451,9349,14747,55927,26687,89057,56663,10337,30781,56701,6947,91639,63839,33029,75989,85297,41777,70201,35117,63067,15377,63097,94573,2687,76343,56951,81047,87211,5471,33347,16787,49823,21589,3779,91631,59333,127,84061,31649,12841,67153,35339,95917,7109,91291,85621,1217,59557,50333,95089,21529,78929,94687,12007,73847,55619,9907,1811,37571,53939,6883,2677,35317,71971,14029,54377,14083,79967,18661,34589,93479,9043,66959,48989,95957,68141,91811,62011,21767,45413,15731,41081,60737,87179,19219,12641,31481,40847,71987,4957,94153,38153,9221,22247,62141,87547,45503,53917,39443,94687,60631,85213,89491,95153,66221,41399,56113,47809,90523,13469,11239,25903,91951,8629,10139,58943,54851,20543,37243,85909,39181,2689,26693,42193,20431,93983,87481,13723,55901,95507,85523,75793,52237,14891,6569,57191,50957,69593,63589,49801,85601,73309,13619,93497,70373,21529,36191,8233,4621,2693,30697,
#   ✔ 510/510 cases passed (12 ms)
#   ✔ Your runtime beats 92.86 % of java submissions
#   ✔ Your memory usage beats 57.14 % of java submissions (269.1 MB)
# Submitting: java_solutions/3590.kth-smallest-path-xor-sum.java
# - Downloading kth-smallest-path-xor-sum
#   ✔ Accepted
#   ✔ 595/595 cases passed (12 ms)
#   ✔ Your runtime beats 83.33 % of java submissions
#   ✔ Your memory usage beats 41.67 % of java submissions (221.4 MB)
# Submitting: java_solutions/3591.check-if-any-element-has-prime-frequency.java
# - Downloading check-if-any-element-has-prime-frequency
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 4: error: missing return statement
#   ✘ Error: Line 4: error: missing return statement
#     }
#     ^
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: java_solutions/3592.inverse-coin-change.java
# - Downloading inverse-coin-change
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 4: error: missing return statement
#   ✘ Error: Line 4: error: missing return statement
#     }
#     ^
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: java_solutions/3593.minimum-increments-to-equalize-leaf-paths.java
# - Downloading minimum-increments-to-equalize-leaf-paths
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 4: error: missing return statement
#   ✘ Error: Line 4: error: missing return statement
#     }
#     ^
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: java_solutions/3594.minimum-time-to-transport-all-individuals.java
# - Downloading minimum-time-to-transport-all-individuals
#   ✔ Accepted
#   ✔ 601/601 cases passed (11 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 55 % of java submissions (67.2 MB)
# Submitting: java_solutions/3597.partition-string.java
# - Downloading partition-string
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 4: error: missing return statement
#   ✘ Error: Line 4: error: missing return statement
#     }
#     ^
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: java_solutions/3598.longest-common-prefix-between-adjacent-strings-after-removals.java
# - Downloading longest-common-prefix-between-adjacent-strings-after-removals
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 4: error: missing return statement
#   ✘ Error: Line 4: error: missing return statement
#     }
#     ^
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: java_solutions/3599.partition-array-to-minimize-xor.java
# - Downloading partition-array-to-minimize-xor
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 4: error: missing return statement
#   ✘ Error: Line 4: error: missing return statement
#     }
#     ^
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: java_solutions/3600.maximize-spanning-tree-stability-with-upgrades.java
# - Downloading maximize-spanning-tree-stability-with-upgrades
#   ✔ Accepted
#   ✔ 569/569 cases passed (10 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 5.04 % of java submissions (284.9 MB)
# Submitting: java_solutions/3601.find-drivers-with-improved-fuel-efficiency.java
# - Downloading find-drivers-with-improved-fuel-efficiency
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: java_solutions/3602.hexadecimal-and-hexatrigesimal-conversion.java
# - Downloading hexadecimal-and-hexatrigesimal-conversion
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 4: error: missing return statement
#   ✘ Error: Line 4: error: missing return statement
#     }
#     ^
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: java_solutions/3603.minimum-cost-path-with-alternating-directions-ii.java
# - Downloading minimum-cost-path-with-alternating-directions-ii
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 4: error: missing return statement
#   ✘ Error: Line 4: error: missing return statement
#     }
#     ^
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: java_solutions/3604.minimum-time-to-reach-destination-in-directed-graph.java
# - Downloading minimum-time-to-reach-destination-in-directed-graph
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 4: error: missing return statement
#   ✘ Error: Line 4: error: missing return statement
#     }
#     ^
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: java_solutions/3605.minimum-stability-factor-of-array.java
# - Downloading minimum-stability-factor-of-array
#   ✔ Accepted
#   ✔ 1000/1000 cases passed (14 ms)
#   ✔ Your runtime beats 96.97 % of java submissions
#   ✔ Your memory usage beats 39.39 % of java submissions (136.9 MB)
# Submitting: java_solutions/3606.coupon-code-validator.java
# - Downloading coupon-code-validator
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 4: error: missing return statement
#   ✘ Error: Line 4: error: missing return statement
#     }
#     ^
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: java_solutions/3607.power-grid-maintenance.java
# - Downloading power-grid-maintenance
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 4: error: missing return statement
#   ✘ Error: Line 4: error: missing return statement
#     }
#     ^
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: java_solutions/3608.minimum-time-for-k-connected-components.java
# - Downloading minimum-time-for-k-connected-components
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 4: error: missing return statement
#   ✘ Error: Line 4: error: missing return statement
#     }
#     ^
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: java_solutions/3609.minimum-moves-to-reach-target-in-grid.java
# - Downloading minimum-moves-to-reach-target-in-grid
#   ✔ Accepted
#   ✔ 1000/1000 cases passed (11 ms)
#   ✔ Your runtime beats 11.76 % of java submissions
#   ✔ Your memory usage beats 5.88 % of java submissions (50.2 MB)
# Submitting: java_solutions/3611.find-overbooked-employees.java
# - Downloading find-overbooked-employees
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: java_solutions/3612.process-string-with-special-operations-i.java
# - Downloading process-string-with-special-operations-i
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 4: error: missing return statement
#   ✘ Error: Line 4: error: missing return statement
#     }
#     ^
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: java_solutions/3613.minimize-maximum-component-cost.java
# - Downloading minimize-maximum-component-cost
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 4: error: missing return statement
#   ✘ Error: Line 4: error: missing return statement
#     }
#     ^
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: java_solutions/3614.process-string-with-special-operations-ii.java
# - Downloading process-string-with-special-operations-ii
#   ✔ Accepted
#   ✔ 934/934 cases passed (12 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 24 % of java submissions (54 MB)
# Submitting: java_solutions/3615.longest-palindromic-path-in-graph.java
# - Downloading longest-palindromic-path-in-graph
#   ✔ Accepted
#   ✔ 542/542 cases passed (2748 ms)
#   ✔ Your runtime beats 17.24 % of java submissions
#   ✔ Your memory usage beats 96.55 % of java submissions (74 MB)
# Submitting: java_solutions/3617.find-students-with-study-spiral-pattern.java
# - Downloading find-students-with-study-spiral-pattern
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: java_solutions/3618.split-array-by-prime-indices.java
# - Downloading split-array-by-prime-indices
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 4: error: missing return statement
#   ✘ Error: Line 4: error: missing return statement
#     }
#     ^
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: java_solutions/3619.count-islands-with-total-value-divisible-by-k.java
# - Downloading count-islands-with-total-value-divisible-by-k
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 4: error: missing return statement
#   ✘ Error: Line 4: error: missing return statement
#     }
#     ^
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: java_solutions/3620.network-recovery-pathways.java
# - Downloading network-recovery-pathways
#   ✔ Accepted
#   ✔ 637/637 cases passed (526 ms)
#   ✔ Your runtime beats 29.17 % of java submissions
#   ✔ Your memory usage beats 56.94 % of java submissions (190.9 MB)

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-04-14 15:10:55
