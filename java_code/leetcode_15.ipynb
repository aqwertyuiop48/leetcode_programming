# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME_3')
    user_cookie = userdata.get('LEETCODE_TOKEN_3')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME_3'] = user_name
    os.environ['LEETCODE_TOKEN_3'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME_3" "$LEETCODE_TOKEN_3" | leetcode user -c

# %%
# %%bash
#
#
# # top 100 answers
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v java_solutions/*.java | sed -n '2051,2200p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 8
# done
# Out:
# Submitting: java_solutions/3131.find-the-integer-added-to-array-i.java
# - Downloading problems
# - Downloading find-the-integer-added-to-array-i
#   ✔ Accepted
#   ✔ 605/605 cases passed (5 ms)
#   ✔ Your runtime beats 52.74 % of java submissions
#   ✔ Your memory usage beats 45.57 % of java submissions (45.3 MB)
# Submitting: java_solutions/3132.find-the-integer-added-to-array-ii.java
# - Downloading find-the-integer-added-to-array-ii
#   ✔ Accepted
#   ✔ 560/560 cases passed (27 ms)
#   ✔ Your runtime beats 22.47 % of java submissions
#   ✔ Your memory usage beats 22.47 % of java submissions (47 MB)
# Submitting: java_solutions/3133.minimum-array-end.java
# - Downloading minimum-array-end
#   ✔ Accepted
#   ✔ 765/765 cases passed (4 ms)
#   ✔ Your runtime beats 34.2 % of java submissions
#   ✔ Your memory usage beats 5.18 % of java submissions (42.9 MB)
# Submitting: java_solutions/3134.find-the-median-of-the-uniqueness-array.java
# - Downloading find-the-median-of-the-uniqueness-array
#   ✔ Accepted
#   ✔ 792/792 cases passed (1924 ms)
#   ✔ Your runtime beats 8.33 % of java submissions
#   ✔ Your memory usage beats 87.5 % of java submissions (98 MB)
# Submitting: java_solutions/3136.valid-word.java
# - Downloading valid-word
#   ✔ Accepted
#   ✔ 678/678 cases passed (3 ms)
#   ✔ Your runtime beats 10.7 % of java submissions
#   ✔ Your memory usage beats 8.2 % of java submissions (44.2 MB)
# Submitting: java_solutions/3137.minimum-number-of-operations-to-make-word-k-periodic.java
# - Downloading minimum-number-of-operations-to-make-word-k-periodic
#   ✔ Accepted
#   ✔ 820/820 cases passed (37 ms)
#   ✔ Your runtime beats 45.92 % of java submissions
#   ✔ Your memory usage beats 96.94 % of java submissions (47.6 MB)
# Submitting: java_solutions/3138.minimum-length-of-anagram-concatenation.java
# - Downloading minimum-length-of-anagram-concatenation
#   ✔ Accepted
#   ✔ 560/560 cases passed (70 ms)
#   ✔ Your runtime beats 27.08 % of java submissions
#   ✔ Your memory usage beats 13.54 % of java submissions (48.1 MB)
# Submitting: java_solutions/3139.minimum-cost-to-equalize-array.java
# - Downloading minimum-cost-to-equalize-array
#   ✔ Accepted
#   ✔ 636/636 cases passed (17 ms)
#   ✔ Your runtime beats 64.29 % of java submissions
#   ✔ Your memory usage beats 10.71 % of java submissions (97.3 MB)
# Submitting: java_solutions/3142.check-if-grid-satisfies-conditions.java
# - Downloading check-if-grid-satisfies-conditions
#   ✔ Accepted
#   ✔ 882/882 cases passed (7 ms)
#   ✔ Your runtime beats 1.14 % of java submissions
#   ✔ Your memory usage beats 6.06 % of java submissions (47.1 MB)
# Submitting: java_solutions/3143.maximum-points-inside-the-square.java
# - Downloading maximum-points-inside-the-square
#   ✔ Accepted
#   ✔ 576/576 cases passed (5 ms)
#   ✔ Your runtime beats 77.88 % of java submissions
#   ✔ Your memory usage beats 69.91 % of java submissions (100.3 MB)
# Submitting: java_solutions/3144.minimum-substring-partition-of-equal-character-frequency.java
# - Downloading minimum-substring-partition-of-equal-character-frequency
#   ✔ Accepted
#   ✔ 694/694 cases passed (186 ms)
#   ✔ Your runtime beats 45.45 % of java submissions
#   ✔ Your memory usage beats 14.77 % of java submissions (46.9 MB)
# Submitting: java_solutions/3145.find-products-of-elements-of-big-array.java
# - Downloading find-products-of-elements-of-big-array
#   ✔ Accepted
#   ✔ 758/758 cases passed (711 ms)
#   ✔ Your runtime beats 6.9 % of java submissions
#   ✔ Your memory usage beats 6.9 % of java submissions (53.9 MB)
# Submitting: java_solutions/3146.permutation-difference-between-two-strings.java
# - Downloading permutation-difference-between-two-strings
#   ✔ Accepted
#   ✔ 823/823 cases passed (3 ms)
#   ✔ Your runtime beats 8.42 % of java submissions
#   ✔ Your memory usage beats 24.85 % of java submissions (44.2 MB)
# Submitting: java_solutions/3147.taking-maximum-energy-from-the-mystic-dungeon.java
# - Downloading taking-maximum-energy-from-the-mystic-dungeon
#   ✔ Accepted
#   ✔ 534/534 cases passed (8 ms)
#   ✔ Your runtime beats 11.73 % of java submissions
#   ✔ Your memory usage beats 8.38 % of java submissions (135.2 MB)
# Submitting: java_solutions/3148.maximum-difference-score-in-a-grid.java
# - Downloading maximum-difference-score-in-a-grid
#   ✔ Accepted
#   ✔ 564/564 cases passed (31 ms)
#   ✔ Your runtime beats 38.55 % of java submissions
#   ✔ Your memory usage beats 71.08 % of java submissions (109.4 MB)
# Submitting: java_solutions/3149.find-the-minimum-cost-array-permutation.java
# - Downloading find-the-minimum-cost-array-permutation
#   ✔ Accepted
#   ✔ 939/939 cases passed (1856 ms)
#   ✔ Your runtime beats 19.57 % of java submissions
#   ✔ Your memory usage beats 13.04 % of java submissions (98.4 MB)
# Submitting: java_solutions/3151.special-array-i.java
# - Downloading special-array-i
#   ✔ Accepted
#   ✔ 852/852 cases passed (5 ms)
#   ✔ Your runtime beats 0.11 % of java submissions
#   ✔ Your memory usage beats 19.64 % of java submissions (46.5 MB)
# Submitting: java_solutions/3152.special-array-ii.java
# - Downloading special-array-ii
#   ✔ Accepted
#   ✔ 536/536 cases passed (8 ms)
#   ✔ Your runtime beats 18.82 % of java submissions
#   ✔ Your memory usage beats 59.41 % of java submissions (120.3 MB)
# Submitting: java_solutions/3153.sum-of-digit-differences-of-all-pairs.java
# - Downloading sum-of-digit-differences-of-all-pairs
#   ✔ Accepted
#   ✔ 643/643 cases passed (31 ms)
#   ✔ Your runtime beats 31.03 % of java submissions
#   ✔ Your memory usage beats 81.9 % of java submissions (99.8 MB)
# Submitting: java_solutions/3154.find-number-of-ways-to-reach-the-k-th-stair.java
# - Downloading find-number-of-ways-to-reach-the-k-th-stair
#   ✔ Accepted
#   ✔ 600/600 cases passed (11 ms)
#   ✔ Your runtime beats 68.63 % of java submissions
#   ✔ Your memory usage beats 74.51 % of java submissions (44.1 MB)
# Submitting: java_solutions/3158.find-the-xor-of-numbers-which-appear-twice.java
# - Downloading find-the-xor-of-numbers-which-appear-twice
#   ✔ Accepted
#   ✔ 833/833 cases passed (4 ms)
#   ✔ Your runtime beats 13.64 % of java submissions
#   ✔ Your memory usage beats 67.86 % of java submissions (44.8 MB)
# Submitting: java_solutions/3159.find-occurrences-of-an-element-in-an-array.java
# - Downloading find-occurrences-of-an-element-in-an-array
#   ✔ Accepted
#   ✔ 527/527 cases passed (8 ms)
#   ✔ Your runtime beats 34.09 % of java submissions
#   ✔ Your memory usage beats 93.15 % of java submissions (160 MB)
# Submitting: java_solutions/3160.find-the-number-of-distinct-colors-among-the-balls.java
# - Downloading find-the-number-of-distinct-colors-among-the-balls
#   ✔ Accepted
#   ✔ 551/551 cases passed (138 ms)
#   ✔ Your runtime beats 5.61 % of java submissions
#   ✔ Your memory usage beats 5.61 % of java submissions (279.6 MB)
# Submitting: java_solutions/3161.block-placement-queries.java
# - Downloading block-placement-queries
#   ✔ Accepted
#   ✔ 745/745 cases passed (977 ms)
#   ✔ Your runtime beats 5.32 % of java submissions
#   ✔ Your memory usage beats 94.68 % of java submissions (261.5 MB)
# Submitting: java_solutions/3162.find-the-number-of-good-pairs-i.java
# - Downloading find-the-number-of-good-pairs-i
#   ✔ Accepted
#   ✔ 783/783 cases passed (5 ms)
#   ✔ Your runtime beats 1.89 % of java submissions
#   ✔ Your memory usage beats 5.78 % of java submissions (45 MB)
# Submitting: java_solutions/3163.string-compression-iii.java
# - Downloading string-compression-iii
#   ✔ Accepted
#   ✔ 744/744 cases passed (18 ms)
#   ✔ Your runtime beats 65.51 % of java submissions
#   ✔ Your memory usage beats 97.21 % of java submissions (48.1 MB)
# Submitting: java_solutions/3164.find-the-number-of-good-pairs-ii.java
# - Downloading find-the-number-of-good-pairs-ii
#   ✔ Accepted
#   ✔ 687/687 cases passed (538 ms)
#   ✔ Your runtime beats 49.33 % of java submissions
#   ✔ Your memory usage beats 84 % of java submissions (115.2 MB)
# Submitting: java_solutions/3165.maximum-sum-of-subsequence-with-non-adjacent-elements.java
# - Downloading maximum-sum-of-subsequence-with-non-adjacent-elements
#   ✔ Accepted
#   ✔ 527/527 cases passed (1471 ms)
#   ✔ Your runtime beats 5 % of java submissions
#   ✔ Your memory usage beats 46.25 % of java submissions (180.2 MB)
# Submitting: java_solutions/3168.minimum-number-of-chairs-in-a-waiting-room.java
# - Downloading minimum-number-of-chairs-in-a-waiting-room
#   ✔ Accepted
#   ✔ 852/852 cases passed (3 ms)
#   ✔ Your runtime beats 0.95 % of java submissions
#   ✔ Your memory usage beats 9.85 % of java submissions (44.3 MB)
# Submitting: java_solutions/3169.count-days-without-meetings.java
# - Downloading count-days-without-meetings
#   ✔ Accepted
#   ✔ 578/578 cases passed (50 ms)
#   ✔ Your runtime beats 14.69 % of java submissions
#   ✔ Your memory usage beats 8.05 % of java submissions (131.2 MB)
# Submitting: java_solutions/3170.lexicographically-minimum-string-after-removing-stars.java
# - Downloading lexicographically-minimum-string-after-removing-stars
#   ✔ Accepted
#   ✔ 602/602 cases passed (427 ms)
#   ✔ Your runtime beats 5.14 % of java submissions
#   ✔ Your memory usage beats 5.14 % of java submissions (286.3 MB)
# Submitting: java_solutions/3171.find-subarray-with-bitwise-or-closest-to-k.java
# - Downloading find-subarray-with-bitwise-or-closest-to-k
#   ✔ Accepted
#   ✔ 814/814 cases passed (166 ms)
#   ✔ Your runtime beats 57.41 % of java submissions
#   ✔ Your memory usage beats 7.41 % of java submissions (109.3 MB)
# Submitting: java_solutions/3174.clear-digits.java
# - Downloading clear-digits
#   ✔ Accepted
#   ✔ 688/688 cases passed (4 ms)
#   ✔ Your runtime beats 9.07 % of java submissions
#   ✔ Your memory usage beats 78.55 % of java submissions (43.7 MB)
# Submitting: java_solutions/3175.find-the-first-player-to-win-k-games-in-a-row.java
# - Downloading find-the-first-player-to-win-k-games-in-a-row
#   ✔ Accepted
#   ✔ 684/684 cases passed (6 ms)
#   ✔ Your runtime beats 20.93 % of java submissions
#   ✔ Your memory usage beats 45.74 % of java submissions (108 MB)
# Submitting: java_solutions/3176.find-the-maximum-length-of-a-good-subsequence-i.java
# - Downloading find-the-maximum-length-of-a-good-subsequence-i
#   ✔ Accepted
#   ✔ 543/543 cases passed (135 ms)
#   ✔ Your runtime beats 53.85 % of java submissions
#   ✔ Your memory usage beats 60.44 % of java submissions (46 MB)
# Submitting: java_solutions/3177.find-the-maximum-length-of-a-good-subsequence-ii.java
# - Downloading find-the-maximum-length-of-a-good-subsequence-ii
#   ✔ Accepted
#   ✔ 551/551 cases passed (487 ms)
#   ✔ Your runtime beats 5.77 % of java submissions
#   ✔ Your memory usage beats 11.54 % of java submissions (133.5 MB)
# Submitting: java_solutions/3178.find-the-child-who-has-the-ball-after-k-seconds.java
# - Downloading find-the-child-who-has-the-ball-after-k-seconds
#   ✔ Accepted
#   ✔ 803/803 cases passed (5 ms)
#   ✔ Your runtime beats 2.18 % of java submissions
#   ✔ Your memory usage beats 53.13 % of java submissions (42.5 MB)
# Submitting: java_solutions/3179.find-the-n-th-value-after-k-seconds.java
# - Downloading find-the-n-th-value-after-k-seconds
#   ✔ Accepted
#   ✔ 708/708 cases passed (208 ms)
#   ✔ Your runtime beats 32.73 % of java submissions
#   ✔ Your memory usage beats 20.61 % of java submissions (43.6 MB)
# Submitting: java_solutions/3180.maximum-total-reward-using-operations-i.java
# - Downloading maximum-total-reward-using-operations-i
#   ✔ Accepted
#   ✔ 586/586 cases passed (78 ms)
#   ✔ Your runtime beats 79.76 % of java submissions
#   ✔ Your memory usage beats 85.71 % of java submissions (46.5 MB)
# Submitting: java_solutions/3181.maximum-total-reward-using-operations-ii.java
# - Downloading maximum-total-reward-using-operations-ii
#   ✔ Accepted
#   ✔ 583/583 cases passed (65 ms)
#   ✔ Your runtime beats 57.14 % of java submissions
#   ✔ Your memory usage beats 9.52 % of java submissions (69.6 MB)
# Submitting: java_solutions/3184.count-pairs-that-form-a-complete-day-i.java
# - Downloading count-pairs-that-form-a-complete-day-i
#   ✔ Accepted
#   ✔ 667/667 cases passed (5 ms)
#   ✔ Your runtime beats 1.83 % of java submissions
#   ✔ Your memory usage beats 7.33 % of java submissions (44.7 MB)
# Submitting: java_solutions/3185.count-pairs-that-form-a-complete-day-ii.java
# - Downloading count-pairs-that-form-a-complete-day-ii
#   ✔ Accepted
#   ✔ 714/714 cases passed (10 ms)
#   ✔ Your runtime beats 44.2 % of java submissions
#   ✔ Your memory usage beats 47.51 % of java submissions (135.9 MB)
# Submitting: java_solutions/3186.maximum-total-damage-with-spell-casting.java
# - Downloading maximum-total-damage-with-spell-casting
#   ✔ Accepted
#   ✔ 555/555 cases passed (79 ms)
#   ✔ Your runtime beats 89.68 % of java submissions
#   ✔ Your memory usage beats 98.39 % of java submissions (113.9 MB)
# Submitting: java_solutions/3187.peaks-in-array.java
# - Downloading peaks-in-array
#   ✔ Accepted
#   ✔ 681/681 cases passed (278 ms)
#   ✔ Your runtime beats 5.48 % of java submissions
#   ✔ Your memory usage beats 6.85 % of java submissions (231.9 MB)
# Submitting: java_solutions/3190.find-minimum-operations-to-make-all-elements-divisible-by-three.java
# - Downloading find-minimum-operations-to-make-all-elements-divisible-by-three
#   ✔ Accepted
#   ✔ 660/660 cases passed (4 ms)
#   ✔ Your runtime beats 1.29 % of java submissions
#   ✔ Your memory usage beats 14.86 % of java submissions (44 MB)
# Submitting: java_solutions/3191.minimum-operations-to-make-binary-array-elements-equal-to-one-i.java
# - Downloading minimum-operations-to-make-binary-array-elements-equal-to-one-i
#   ✔ Accepted
#   ✔ 689/689 cases passed (11 ms)
#   ✔ Your runtime beats 4.82 % of java submissions
#   ✔ Your memory usage beats 98.19 % of java submissions (98.6 MB)
# Submitting: java_solutions/3192.minimum-operations-to-make-binary-array-elements-equal-to-one-ii.java
# - Downloading minimum-operations-to-make-binary-array-elements-equal-to-one-ii
#   ✔ Accepted
#   ✔ 691/691 cases passed (14 ms)
#   ✔ Your runtime beats 4.79 % of java submissions
#   ✔ Your memory usage beats 96.58 % of java submissions (117.2 MB)
# Submitting: java_solutions/3193.count-the-number-of-inversions.java
# - Downloading count-the-number-of-inversions
#   ✔ Accepted
#   ✔ 719/719 cases passed (748 ms)
#   ✔ Your runtime beats 5.29 % of java submissions
#   ✔ Your memory usage beats 43.71 % of java submissions (47.4 MB)
# Submitting: java_solutions/3194.minimum-average-of-smallest-and-largest-elements.java
# - Downloading minimum-average-of-smallest-and-largest-elements
#   ✔ Accepted
#   ✔ 720/720 cases passed (4 ms)
#   ✔ Your runtime beats 96.37 % of java submissions
#   ✔ Your memory usage beats 79.92 % of java submissions (48.1 MB)
# Submitting: java_solutions/3195.find-the-minimum-area-to-cover-all-ones-i.java
# - Downloading find-the-minimum-area-to-cover-all-ones-i
#   ✔ Accepted
#   ✔ 713/713 cases passed (14 ms)
#   ✔ Your runtime beats 7.18 % of java submissions
#   ✔ Your memory usage beats 60.77 % of java submissions (239.7 MB)
# Submitting: java_solutions/3196.maximize-total-cost-of-alternating-subarrays.java
# - Downloading maximize-total-cost-of-alternating-subarrays
#   ✔ Accepted
#   ✔ 692/692 cases passed (6 ms)
#   ✔ Your runtime beats 65.33 % of java submissions
#   ✔ Your memory usage beats 94.67 % of java submissions (86.1 MB)
# Submitting: java_solutions/3197.find-the-minimum-area-to-cover-all-ones-ii.java
# - Downloading find-the-minimum-area-to-cover-all-ones-ii
#   ✔ Accepted
#   ✔ 663/663 cases passed (1262 ms)
#   ✔ Your runtime beats 5.41 % of java submissions
#   ✔ Your memory usage beats 10.81 % of java submissions (52.9 MB)
# Submitting: java_solutions/3200.maximum-height-of-a-triangle.java
# - Downloading maximum-height-of-a-triangle
#   ✔ Accepted
#   ✔ 857/857 cases passed (4 ms)
#   ✔ Your runtime beats 2.54 % of java submissions
#   ✔ Your memory usage beats 5.93 % of java submissions (43.5 MB)
# Submitting: java_solutions/3201.find-the-maximum-length-of-valid-subsequence-i.java
# - Downloading find-the-maximum-length-of-valid-subsequence-i
#   ✔ Accepted
#   ✔ 951/951 cases passed (9 ms)
#   ✔ Your runtime beats 31.2 % of java submissions
#   ✔ Your memory usage beats 5.6 % of java submissions (93.4 MB)
# Submitting: java_solutions/3202.find-the-maximum-length-of-valid-subsequence-ii.java
# - Downloading find-the-maximum-length-of-valid-subsequence-ii
#   ✔ Accepted
#   ✔ 734/734 cases passed (67 ms)
#   ✔ Your runtime beats 13.95 % of java submissions
#   ✔ Your memory usage beats 11.63 % of java submissions (62.2 MB)
# Submitting: java_solutions/3203.find-minimum-diameter-after-merging-two-trees.java
# - Downloading find-minimum-diameter-after-merging-two-trees
#   ✔ Accepted
#   ✔ 723/723 cases passed (392 ms)
#   ✔ Your runtime beats 6.67 % of java submissions
#   ✔ Your memory usage beats 97.78 % of java submissions (210.1 MB)
# Submitting: java_solutions/3206.alternating-groups-i.java
# - Downloading alternating-groups-i
#   ✔ Accepted
#   ✔ 795/795 cases passed (5 ms)
#   ✔ Your runtime beats 3.15 % of java submissions
#   ✔ Your memory usage beats 6.72 % of java submissions (45.2 MB)
# Submitting: java_solutions/3207.maximum-points-after-enemy-battles.java
# - Downloading maximum-points-after-enemy-battles
#   ✔ Accepted
#   ✔ 579/579 cases passed (39 ms)
#   ✔ Your runtime beats 5.8 % of java submissions
#   ✔ Your memory usage beats 5.8 % of java submissions (91.5 MB)
# Submitting: java_solutions/3208.alternating-groups-ii.java
# - Downloading alternating-groups-ii
#   ✔ Accepted
#   ✔ 625/625 cases passed (9 ms)
#   ✔ Your runtime beats 7.64 % of java submissions
#   ✔ Your memory usage beats 14.18 % of java submissions (101.1 MB)
# Submitting: java_solutions/3209.number-of-subarrays-with-and-value-of-k.java
# - Downloading number-of-subarrays-with-and-value-of-k
#   ✔ Accepted
#   ✔ 902/902 cases passed (326 ms)
#   ✔ Your runtime beats 21.28 % of java submissions
#   ✔ Your memory usage beats 27.66 % of java submissions (85.2 MB)
# Submitting: java_solutions/3210.find-the-encrypted-string.java
# - Downloading find-the-encrypted-string
#   ✔ Accepted
#   ✔ 704/704 cases passed (3 ms)
#   ✔ Your runtime beats 20.2 % of java submissions
#   ✔ Your memory usage beats 99.67 % of java submissions (42.7 MB)
# Submitting: java_solutions/3211.generate-binary-strings-without-adjacent-zeros.java
# - Downloading generate-binary-strings-without-adjacent-zeros
#   ✔ Accepted
#   ✔ 20/20 cases passed (12 ms)
#   ✔ Your runtime beats 8.97 % of java submissions
#   ✔ Your memory usage beats 71.93 % of java submissions (47.6 MB)
# Submitting: java_solutions/3212.count-submatrices-with-equal-frequency-of-x-and-y.java
# - Downloading count-submatrices-with-equal-frequency-of-x-and-y
#   ✔ Accepted
#   ✔ 770/770 cases passed (46 ms)
#   ✔ Your runtime beats 14.23 % of java submissions
#   ✔ Your memory usage beats 43.1 % of java submissions (249.8 MB)
# Submitting: java_solutions/3213.construct-string-with-minimum-cost.java
# - Downloading construct-string-with-minimum-cost
#   ✔ Accepted
#   ✔ 808/808 cases passed (1731 ms)
#   ✔ Your runtime beats 12.5 % of java submissions
#   ✔ Your memory usage beats 97.5 % of java submissions (60.8 MB)
# Submitting: java_solutions/3216.lexicographically-smallest-string-after-a-swap.java
# - Downloading lexicographically-smallest-string-after-a-swap
#   ✔ Accepted
#   ✔ 895/895 cases passed (4 ms)
#   ✔ Your runtime beats 6.97 % of java submissions
#   ✔ Your memory usage beats 6.97 % of java submissions (44.7 MB)
# Submitting: java_solutions/3217.delete-nodes-from-linked-list-present-in-array.java
# - Downloading delete-nodes-from-linked-list-present-in-array
#   ✔ Accepted
#   ✔ 582/582 cases passed (48 ms)
#   ✔ Your runtime beats 5.04 % of java submissions
#   ✔ Your memory usage beats 79.84 % of java submissions (137.2 MB)
# Submitting: java_solutions/3218.minimum-cost-for-cutting-cake-i.java
# - Downloading minimum-cost-for-cutting-cake-i
#   ✔ Accepted
#   ✔ 533/533 cases passed (4 ms)
#   ✔ Your runtime beats 23.53 % of java submissions
#   ✔ Your memory usage beats 11.76 % of java submissions (44.5 MB)
# Submitting: java_solutions/3219.minimum-cost-for-cutting-cake-ii.java
# - Downloading minimum-cost-for-cutting-cake-ii
#   ✔ Accepted
#   ✔ 566/566 cases passed (117 ms)
#   ✔ Your runtime beats 9.76 % of java submissions
#   ✔ Your memory usage beats 12.2 % of java submissions (164.1 MB)
# Submitting: java_solutions/3222.find-the-winning-player-in-coin-game.java
# - Downloading find-the-winning-player-in-coin-game
#   ✔ Accepted
#   ✔ 852/852 cases passed (4 ms)
#   ✔ Your runtime beats 1.11 % of java submissions
#   ✔ Your memory usage beats 14.67 % of java submissions (44.2 MB)
# Submitting: java_solutions/3223.minimum-length-of-string-after-operations.java
# - Downloading minimum-length-of-string-after-operations
#   ✔ Accepted
#   ✔ 702/702 cases passed (17 ms)
#   ✔ Your runtime beats 49.16 % of java submissions
#   ✔ Your memory usage beats 82.12 % of java submissions (48.3 MB)
# Submitting: java_solutions/3224.minimum-array-changes-to-make-differences-equal.java
# - Downloading minimum-array-changes-to-make-differences-equal
#   ✔ Accepted
#   ✔ 682/682 cases passed (15 ms)
#   ✔ Your runtime beats 35.71 % of java submissions
#   ✔ Your memory usage beats 50 % of java submissions (85.8 MB)
# Submitting: java_solutions/3225.maximum-score-from-grid-operations.java
# - Downloading maximum-score-from-grid-operations
#   ✔ Accepted
#   ✔ 794/794 cases passed (1772 ms)
#   ✔ Your runtime beats 5.03 % of java submissions
#   ✔ Your memory usage beats 5.19 % of java submissions (145.8 MB)
# Submitting: java_solutions/3226.number-of-bit-changes-to-make-two-integers-equal.java
# - Downloading number-of-bit-changes-to-make-two-integers-equal
#   ✔ Accepted
#   ✔ 682/682 cases passed (5 ms)
#   ✔ Your runtime beats 5.03 % of java submissions
#   ✔ Your memory usage beats 64.32 % of java submissions (42.5 MB)
# Submitting: java_solutions/3227.vowels-game-in-a-string.java
# - Downloading vowels-game-in-a-string
#   ✔ Accepted
#   ✔ 697/697 cases passed (72 ms)
#   ✔ Your runtime beats 6.07 % of java submissions
#   ✔ Your memory usage beats 14.7 % of java submissions (48.3 MB)
# Submitting: java_solutions/3228.maximum-number-of-operations-to-move-ones-to-the-end.java
# - Downloading maximum-number-of-operations-to-move-ones-to-the-end
#   ✔ Accepted
#   ✔ 694/694 cases passed (10 ms)
#   ✔ Your runtime beats 5.53 % of java submissions
#   ✔ Your memory usage beats 25.66 % of java submissions (47.8 MB)
# Submitting: java_solutions/3229.minimum-operations-to-make-array-equal-to-target.java
# - Downloading minimum-operations-to-make-array-equal-to-target
#   ✔ Accepted
#   ✔ 554/554 cases passed (15 ms)
#   ✔ Your runtime beats 13.18 % of java submissions
#   ✔ Your memory usage beats 26.36 % of java submissions (137.5 MB)
# Submitting: java_solutions/3232.find-if-digit-game-can-be-won.java
# - Downloading find-if-digit-game-can-be-won
#   ✔ Accepted
#   ✔ 897/897 cases passed (5 ms)
#   ✔ Your runtime beats 1.49 % of java submissions
#   ✔ Your memory usage beats 7.42 % of java submissions (46.5 MB)
# Submitting: java_solutions/3233.find-the-count-of-numbers-which-are-not-special.java
# - Downloading find-the-count-of-numbers-which-are-not-special
#   ✔ Accepted
#   ✔ 855/855 cases passed (64 ms)
#   ✔ Your runtime beats 14.58 % of java submissions
#   ✔ Your memory usage beats 21.25 % of java submissions (46.2 MB)
# Submitting: java_solutions/3234.count-the-number-of-substrings-with-dominant-ones.java
# - Downloading count-the-number-of-substrings-with-dominant-ones
#   ✔ Accepted
#   ✔ 881/881 cases passed (244 ms)
#   ✔ Your runtime beats 57.14 % of java submissions
#   ✔ Your memory usage beats 45.51 % of java submissions (47.1 MB)
# Submitting: java_solutions/3235.check-if-the-rectangle-corner-is-reachable.java
# - Downloading check-if-the-rectangle-corner-is-reachable
#   ✔ Accepted
#   ✔ 933/933 cases passed (248 ms)
#   ✔ Your runtime beats 6.25 % of java submissions
#   ✔ Your memory usage beats 12.5 % of java submissions (52.9 MB)
# Submitting: java_solutions/3238.find-the-number-of-winning-players.java
# - Downloading find-the-number-of-winning-players
#   ✔ Accepted
#   ✔ 839/839 cases passed (5 ms)
#   ✔ Your runtime beats 31.79 % of java submissions
#   ✔ Your memory usage beats 94.8 % of java submissions (46.6 MB)
# Submitting: java_solutions/3239.minimum-number-of-flips-to-make-binary-grid-palindromic-i.java
# - Downloading minimum-number-of-flips-to-make-binary-grid-palindromic-i
#   ✔ Accepted
#   ✔ 625/625 cases passed (13 ms)
#   ✔ Your runtime beats 5.71 % of java submissions
#   ✔ Your memory usage beats 12.38 % of java submissions (187.1 MB)
# Submitting: java_solutions/3240.minimum-number-of-flips-to-make-binary-grid-palindromic-ii.java
# - Downloading minimum-number-of-flips-to-make-binary-grid-palindromic-ii
#   ✔ Accepted
#   ✔ 661/661 cases passed (8 ms)
#   ✔ Your runtime beats 4.55 % of java submissions
#   ✔ Your memory usage beats 9.09 % of java submissions (191.6 MB)
# Submitting: java_solutions/3241.time-taken-to-mark-all-nodes.java
# - Downloading time-taken-to-mark-all-nodes
#   ✔ Accepted
#   ✔ 804/804 cases passed (567 ms)
#   ✔ Your runtime beats 20 % of java submissions
#   ✔ Your memory usage beats 5.72 % of java submissions (386.5 MB)
# Submitting: java_solutions/3242.design-neighbor-sum-service.java
# - Downloading design-neighbor-sum-service
#   ✔ Accepted
#   ✔ 652/652 cases passed (41 ms)
#   ✔ Your runtime beats 8.14 % of java submissions
#   ✔ Your memory usage beats 9.05 % of java submissions (48 MB)
# Submitting: java_solutions/3243.shortest-distance-after-road-addition-queries-i.java
# - Downloading shortest-distance-after-road-addition-queries-i
#   ✔ Accepted
#   ✔ 972/972 cases passed (125 ms)
#   ✔ Your runtime beats 41.94 % of java submissions
#   ✔ Your memory usage beats 6.45 % of java submissions (47.9 MB)
# Submitting: java_solutions/3244.shortest-distance-after-road-addition-queries-ii.java
# - Downloading shortest-distance-after-road-addition-queries-ii
#   ✔ Accepted
#   ✔ 644/644 cases passed (59 ms)
#   ✔ Your runtime beats 52.08 % of java submissions
#   ✔ Your memory usage beats 45.83 % of java submissions (151.4 MB)
# Submitting: java_solutions/3245.alternating-groups-iii.java
# - Downloading alternating-groups-iii
#   ✔ Accepted
#   ✔ 731/731 cases passed (477 ms)
#   ✔ Your runtime beats 29.17 % of java submissions
#   ✔ Your memory usage beats 70.83 % of java submissions (206 MB)
# Submitting: java_solutions/3248.snake-in-matrix.java
# - Downloading snake-in-matrix
#   ✔ Accepted
#   ✔ 983/983 cases passed (5 ms)
#   ✔ Your runtime beats 1.99 % of java submissions
#   ✔ Your memory usage beats 5.97 % of java submissions (46.7 MB)
# Submitting: java_solutions/3249.count-the-number-of-good-nodes.java
# - Downloading count-the-number-of-good-nodes
#   ✔ Accepted
#   ✔ 621/621 cases passed (108 ms)
#   ✔ Your runtime beats 80 % of java submissions
#   ✔ Your memory usage beats 93.85 % of java submissions (276.4 MB)
# Submitting: java_solutions/3250.find-the-count-of-monotonic-pairs-i.java
# - Downloading find-the-count-of-monotonic-pairs-i
#   ✔ Accepted
#   ✔ 801/801 cases passed (984 ms)
#   ✔ Your runtime beats 9.26 % of java submissions
#   ✔ Your memory usage beats 50 % of java submissions (52.7 MB)
# Submitting: java_solutions/3251.find-the-count-of-monotonic-pairs-ii.java
# - Downloading find-the-count-of-monotonic-pairs-ii
#   ✔ Accepted
#   ✔ 801/801 cases passed (251 ms)
#   ✔ Your runtime beats 33.33 % of java submissions
#   ✔ Your memory usage beats 51.52 % of java submissions (53.4 MB)
# Submitting: java_solutions/3254.find-the-power-of-k-size-subarrays-i.java
# - Downloading find-the-power-of-k-size-subarrays-i
#   ✔ Accepted
#   ✔ 857/857 cases passed (8 ms)
#   ✔ Your runtime beats 5.44 % of java submissions
#   ✔ Your memory usage beats 96.15 % of java submissions (46.9 MB)
# Submitting: java_solutions/3255.find-the-power-of-k-size-subarrays-ii.java
# - Downloading find-the-power-of-k-size-subarrays-ii
#   ✔ Accepted
#   ✔ 653/653 cases passed (7 ms)
#   ✔ Your runtime beats 12.84 % of java submissions
#   ✔ Your memory usage beats 7.34 % of java submissions (180.1 MB)
# Submitting: java_solutions/3256.maximum-value-sum-by-placing-three-rooks-i.java
# - Downloading maximum-value-sum-by-placing-three-rooks-i
#   ✔ Accepted
#   ✔ 849/849 cases passed (61 ms)
#   ✔ Your runtime beats 65.52 % of java submissions
#   ✔ Your memory usage beats 24.14 % of java submissions (53.8 MB)
# Submitting: java_solutions/3257.maximum-value-sum-by-placing-three-rooks-ii.java
# - Downloading maximum-value-sum-by-placing-three-rooks-ii
#   ✔ Accepted
#   ✔ 857/857 cases passed (316 ms)
#   ✔ Your runtime beats 55.56 % of java submissions
#   ✔ Your memory usage beats 33.33 % of java submissions (165.3 MB)
# Submitting: java_solutions/3258.count-substrings-that-satisfy-k-constraint-i.java
# - Downloading count-substrings-that-satisfy-k-constraint-i
#   ✔ Accepted
#   ✔ 780/780 cases passed (6 ms)
#   ✔ Your runtime beats 12.05 % of java submissions
#   ✔ Your memory usage beats 79.47 % of java submissions (43.5 MB)
# Submitting: java_solutions/3259.maximum-energy-boost-from-two-drinks.java
# - Downloading maximum-energy-boost-from-two-drinks
#   ✔ Accepted
#   ✔ 563/563 cases passed (10 ms)
#   ✔ Your runtime beats 55.26 % of java submissions
#   ✔ Your memory usage beats 67.54 % of java submissions (155.6 MB)
# Submitting: java_solutions/3260.find-the-largest-palindrome-divisible-by-k.java
# - Downloading find-the-largest-palindrome-divisible-by-k
#   ✔ Accepted
#   ✔ 632/632 cases passed (23 ms)
#   ✔ Your runtime beats 64.71 % of java submissions
#   ✔ Your memory usage beats 35.29 % of java submissions (53 MB)
# Submitting: java_solutions/3261.count-substrings-that-satisfy-k-constraint-ii.java
# - Downloading count-substrings-that-satisfy-k-constraint-ii
#   ✔ Accepted
#   ✔ 627/627 cases passed (188 ms)
#   ✔ Your runtime beats 15.38 % of java submissions
#   ✔ Your memory usage beats 50 % of java submissions (158.2 MB)
# Submitting: java_solutions/3264.final-array-state-after-k-multiplication-operations-i.java
# - Downloading final-array-state-after-k-multiplication-operations-i
#   ✔ Accepted
#   ✔ 737/737 cases passed (4 ms)
#   ✔ Your runtime beats 22.44 % of java submissions
#   ✔ Your memory usage beats 22.23 % of java submissions (46.9 MB)
# Submitting: java_solutions/3265.count-almost-equal-pairs-i.java
# - Downloading count-almost-equal-pairs-i
#   ✔ Accepted
#   ✔ 686/686 cases passed (30 ms)
#   ✔ Your runtime beats 75 % of java submissions
#   ✔ Your memory usage beats 45.45 % of java submissions (47.3 MB)
# Submitting: java_solutions/3266.final-array-state-after-k-multiplication-operations-ii.java
# - Downloading final-array-state-after-k-multiplication-operations-ii
#   ✔ Accepted
#   ✔ 695/695 cases passed (148 ms)
#   ✔ Your runtime beats 9.09 % of java submissions
#   ✔ Your memory usage beats 7.27 % of java submissions (54.6 MB)
# Submitting: java_solutions/3267.count-almost-equal-pairs-ii.java
# - Downloading count-almost-equal-pairs-ii
#   ✔ Accepted
#   ✔ 631/631 cases passed (3716 ms)
#   ✔ Your runtime beats 79.59 % of java submissions
#   ✔ Your memory usage beats 14.29 % of java submissions (53.8 MB)
# Submitting: java_solutions/3270.find-the-key-of-the-numbers.java
# - Downloading find-the-key-of-the-numbers
#   ✔ Accepted
#   ✔ 757/757 cases passed (4 ms)
#   ✔ Your runtime beats 33.44 % of java submissions
#   ✔ Your memory usage beats 33.44 % of java submissions (43.1 MB)
# Submitting: java_solutions/3271.hash-divided-string.java
# - Downloading hash-divided-string
#   ✔ Accepted
#   ✔ 1066/1066 cases passed (5 ms)
#   ✔ Your runtime beats 21.56 % of java submissions
#   ✔ Your memory usage beats 27.96 % of java submissions (46.7 MB)
# Submitting: java_solutions/3272.find-the-count-of-good-integers.java
# - Downloading find-the-count-of-good-integers
#   ✔ Accepted
#   ✔ 90/90 cases passed (229 ms)
#   ✔ Your runtime beats 89.13 % of java submissions
#   ✔ Your memory usage beats 26.09 % of java submissions (53.8 MB)
# Submitting: java_solutions/3273.minimum-amount-of-damage-dealt-to-bob.java
# - Downloading minimum-amount-of-damage-dealt-to-bob
#   ✔ Accepted
#   ✔ 897/897 cases passed (130 ms)
#   ✔ Your runtime beats 35.18 % of java submissions
#   ✔ Your memory usage beats 100 % of java submissions (81.1 MB)
# Submitting: java_solutions/3274.check-if-two-chessboard-squares-have-the-same-color.java
# - Downloading check-if-two-chessboard-squares-have-the-same-color
#   ✔ Accepted
#   ✔ 506/506 cases passed (3 ms)
#   ✔ Your runtime beats 2.54 % of java submissions
#   ✔ Your memory usage beats 74.08 % of java submissions (43.3 MB)
# Submitting: java_solutions/3275.k-th-nearest-obstacle-queries.java
# - Downloading k-th-nearest-obstacle-queries
#   ✔ Accepted
#   ✔ 591/591 cases passed (184 ms)
#   ✔ Your runtime beats 16.03 % of java submissions
#   ✔ Your memory usage beats 89.31 % of java submissions (274.2 MB)
# Submitting: java_solutions/3276.select-cells-in-grid-with-maximum-score.java
# - Downloading select-cells-in-grid-with-maximum-score
#   ✔ Accepted
#   ✔ 546/546 cases passed (2438 ms)
#   ✔ Your runtime beats 5.45 % of java submissions
#   ✔ Your memory usage beats 16.36 % of java submissions (53.4 MB)
# Submitting: java_solutions/3277.maximum-xor-score-subarray-queries.java
# - Downloading maximum-xor-score-subarray-queries
#   ✔ Accepted
#   ✔ 635/635 cases passed (135 ms)
#   ✔ Your runtime beats 40 % of java submissions
#   ✔ Your memory usage beats 94.29 % of java submissions (228.1 MB)
# Submitting: java_solutions/3280.convert-date-to-binary.java
# - Downloading convert-date-to-binary
#   ✔ Accepted
#   ✔ 503/503 cases passed (6 ms)
#   ✔ Your runtime beats 22.78 % of java submissions
#   ✔ Your memory usage beats 67.52 % of java submissions (43.9 MB)
# Submitting: java_solutions/3281.maximize-score-of-numbers-in-ranges.java
# - Downloading maximize-score-of-numbers-in-ranges
#   ✔ Accepted
#   ✔ 686/686 cases passed (58 ms)
#   ✔ Your runtime beats 6.25 % of java submissions
#   ✔ Your memory usage beats 9.38 % of java submissions (104.8 MB)
# Submitting: java_solutions/3282.reach-end-of-array-with-max-score.java
# - Downloading reach-end-of-array-with-max-score
#   ✔ Accepted
#   ✔ 626/626 cases passed (15 ms)
#   ✔ Your runtime beats 20.72 % of java submissions
#   ✔ Your memory usage beats 50.45 % of java submissions (162.8 MB)
# Submitting: java_solutions/3283.maximum-number-of-moves-to-kill-all-pawns.java
# - Downloading maximum-number-of-moves-to-kill-all-pawns
#   ✔ Accepted
#   ✔ 692/692 cases passed (2501 ms)
#   ✔ Your runtime beats 6.67 % of java submissions
#   ✔ Your memory usage beats 46.67 % of java submissions (57.5 MB)
# Submitting: java_solutions/3285.find-indices-of-stable-mountains.java
# - Downloading find-indices-of-stable-mountains
#   ✔ Accepted
#   ✔ 805/805 cases passed (4 ms)
#   ✔ Your runtime beats 0.48 % of java submissions
#   ✔ Your memory usage beats 7.21 % of java submissions (46.5 MB)
# Submitting: java_solutions/3286.find-a-safe-walk-through-a-grid.java
# - Downloading find-a-safe-walk-through-a-grid
#   ✔ Accepted
#   ✔ 691/691 cases passed (26 ms)
#   ✔ Your runtime beats 57 % of java submissions
#   ✔ Your memory usage beats 14.98 % of java submissions (48.1 MB)
# Submitting: java_solutions/3287.find-the-maximum-sequence-value-of-array.java
# - Downloading find-the-maximum-sequence-value-of-array
#   ✔ Accepted
#   ✔ 641/641 cases passed (1278 ms)
#   ✔ Your runtime beats 19.23 % of java submissions
#   ✔ Your memory usage beats 80.77 % of java submissions (53.1 MB)
# Submitting: java_solutions/3288.length-of-the-longest-increasing-path.java
# - Downloading length-of-the-longest-increasing-path
#   ✔ Accepted
#   ✔ 725/725 cases passed (76 ms)
#   ✔ Your runtime beats 28.57 % of java submissions
#   ✔ Your memory usage beats 38.1 % of java submissions (173 MB)
# Submitting: java_solutions/3289.the-two-sneaky-numbers-of-digitville.java
# - Downloading the-two-sneaky-numbers-of-digitville
#   ✔ Accepted
#   ✔ 707/707 cases passed (5 ms)
#   ✔ Your runtime beats 15.91 % of java submissions
#   ✔ Your memory usage beats 40.62 % of java submissions (46.4 MB)
# Submitting: java_solutions/3290.maximum-multiplication-score.java
# - Downloading maximum-multiplication-score
#   ✔ Accepted
#   ✔ 675/675 cases passed (10 ms)
#   ✔ Your runtime beats 75.81 % of java submissions
#   ✔ Your memory usage beats 91.94 % of java submissions (105.1 MB)
# Submitting: java_solutions/3291.minimum-number-of-valid-strings-to-form-target-i.java
# - Downloading minimum-number-of-valid-strings-to-form-target-i
#   ✔ Accepted
#   ✔ 929/929 cases passed (901 ms)
#   ✔ Your runtime beats 29.73 % of java submissions
#   ✔ Your memory usage beats 5.4 % of java submissions (260.1 MB)
# Submitting: java_solutions/3292.minimum-number-of-valid-strings-to-form-target-ii.java
# - Downloading minimum-number-of-valid-strings-to-form-target-ii
#   ✔ Accepted
#   ✔ 807/807 cases passed (3242 ms)
#   ✔ Your runtime beats 5.26 % of java submissions
#   ✔ Your memory usage beats 78.95 % of java submissions (58.1 MB)
# Submitting: java_solutions/3295.report-spam-message.java
# - Downloading report-spam-message
#   ✔ Accepted
#   ✔ 526/526 cases passed (67 ms)
#   ✔ Your runtime beats 8.76 % of java submissions
#   ✔ Your memory usage beats 98.62 % of java submissions (133 MB)
# Submitting: java_solutions/3296.minimum-number-of-seconds-to-make-mountain-height-zero.java
# - Downloading minimum-number-of-seconds-to-make-mountain-height-zero
#   ✔ Accepted
#   ✔ 571/571 cases passed (39 ms)
#   ✔ Your runtime beats 25.03 % of java submissions
#   ✔ Your memory usage beats 5.86 % of java submissions (48.4 MB)
# Submitting: java_solutions/3297.count-substrings-that-can-be-rearranged-to-contain-a-string-i.java
# - Downloading count-substrings-that-can-be-rearranged-to-contain-a-string-i
#   ✔ Accepted
#   ✔ 758/758 cases passed (10 ms)
#   ✔ Your runtime beats 52.59 % of java submissions
#   ✔ Your memory usage beats 6.03 % of java submissions (48 MB)
# Submitting: java_solutions/3298.count-substrings-that-can-be-rearranged-to-contain-a-string-ii.java
# - Downloading count-substrings-that-can-be-rearranged-to-contain-a-string-ii
#   ✔ Accepted
#   ✔ 760/760 cases passed (181 ms)
#   ✔ Your runtime beats 48.91 % of java submissions
#   ✔ Your memory usage beats 66.3 % of java submissions (66.1 MB)
# Submitting: java_solutions/3300.minimum-element-after-replacement-with-digit-sum.java
# - Downloading minimum-element-after-replacement-with-digit-sum
#   ✔ Accepted
#   ✔ 835/835 cases passed (5 ms)
#   ✔ Your runtime beats 13.38 % of java submissions
#   ✔ Your memory usage beats 19.46 % of java submissions (45.2 MB)
# Submitting: java_solutions/3301.maximize-the-total-height-of-unique-towers.java
# - Downloading maximize-the-total-height-of-unique-towers
#   ✔ Accepted
#   ✔ 583/583 cases passed (42 ms)
#   ✔ Your runtime beats 98.77 % of java submissions
#   ✔ Your memory usage beats 19.75 % of java submissions (105.9 MB)
# Submitting: java_solutions/3302.find-the-lexicographically-smallest-valid-sequence.java
# - Downloading find-the-lexicographically-smallest-valid-sequence
#   ✔ Accepted
#   ✔ 905/905 cases passed (44 ms)
#   ✔ Your runtime beats 15.63 % of java submissions
#   ✔ Your memory usage beats 96.88 % of java submissions (135.6 MB)
# Submitting: java_solutions/3303.find-the-occurrence-of-first-almost-equal-substring.java
# - Downloading find-the-occurrence-of-first-almost-equal-substring
#   ✔ Accepted
#   ✔ 778/778 cases passed (1306 ms)
#   ✔ Your runtime beats 7.69 % of java submissions
#   ✔ Your memory usage beats 7.69 % of java submissions (93.1 MB)
# Submitting: java_solutions/3304.find-the-k-th-character-in-string-game-i.java
# - Downloading find-the-k-th-character-in-string-game-i
#   ✔ Accepted
#   ✔ 502/502 cases passed (4 ms)
#   ✔ Your runtime beats 39.8 % of java submissions
#   ✔ Your memory usage beats 72.41 % of java submissions (43.2 MB)
# Submitting: java_solutions/3305.count-of-substrings-containing-every-vowel-and-k-consonants-i.java
# - Downloading count-of-substrings-containing-every-vowel-and-k-consonants-i
#   ✔ Accepted
#   ✔ 815/815 cases passed (5 ms)
#   ✔ Your runtime beats 75.81 % of java submissions
#   ✔ Your memory usage beats 31.45 % of java submissions (46.5 MB)
# Submitting: java_solutions/3306.count-of-substrings-containing-every-vowel-and-k-consonants-ii.java
# - Downloading count-of-substrings-containing-every-vowel-and-k-consonants-ii
#   ✔ Accepted
#   ✔ 768/768 cases passed (126 ms)
#   ✔ Your runtime beats 75.8 % of java submissions
#   ✔ Your memory usage beats 97.45 % of java submissions (47.9 MB)
# Submitting: java_solutions/3307.find-the-k-th-character-in-string-game-ii.java
# - Downloading find-the-k-th-character-in-string-game-ii
#   ✔ Accepted
#   ✔ 902/902 cases passed (8 ms)
#   ✔ Your runtime beats 3.23 % of java submissions
#   ✔ Your memory usage beats 7.26 % of java submissions (45.8 MB)
# Submitting: java_solutions/3309.maximum-possible-number-by-binary-concatenation.java
# - Downloading maximum-possible-number-by-binary-concatenation
#   ✔ Accepted
#   ✔ 752/752 cases passed (10 ms)
#   ✔ Your runtime beats 8.97 % of java submissions
#   ✔ Your memory usage beats 14.1 % of java submissions (45.6 MB)
# Submitting: java_solutions/3310.remove-methods-from-project.java
# - Downloading remove-methods-from-project
#   ✔ Accepted
#   ✔ 775/775 cases passed (53 ms)
#   ✔ Your runtime beats 91.58 % of java submissions
#   ✔ Your memory usage beats 84.21 % of java submissions (277.4 MB)
# Submitting: java_solutions/3311.construct-2d-grid-matching-graph-layout.java
# - Downloading construct-2d-grid-matching-graph-layout
#   ✔ Accepted
#   ✔ 785/785 cases passed (294 ms)
#   ✔ Your runtime beats 34.78 % of java submissions
#   ✔ Your memory usage beats 65.22 % of java submissions (229.8 MB)
# Submitting: java_solutions/3312.sorted-gcd-pair-queries.java
# - Downloading sorted-gcd-pair-queries
#   ✔ Accepted
#   ✔ 721/721 cases passed (833 ms)
#   ✔ Your runtime beats 14.02 % of java submissions
#   ✔ Your memory usage beats 6.54 % of java submissions (114.2 MB)
# Submitting: java_solutions/3314.construct-the-minimum-bitwise-array-i.java
# - Downloading construct-the-minimum-bitwise-array-i
#   ✔ Accepted
#   ✔ 658/658 cases passed (33 ms)
#   ✔ Your runtime beats 7.37 % of java submissions
#   ✔ Your memory usage beats 38.94 % of java submissions (46.7 MB)
# Submitting: java_solutions/3315.construct-the-minimum-bitwise-array-ii.java
# - Downloading construct-the-minimum-bitwise-array-ii
#   ✔ Accepted
#   ✔ 776/776 cases passed (5 ms)
#   ✔ Your runtime beats 3.45 % of java submissions
#   ✔ Your memory usage beats 58.62 % of java submissions (46.8 MB)
# Submitting: java_solutions/3316.find-maximum-removals-from-source-string.java
# - Downloading find-maximum-removals-from-source-string
#   ✔ Accepted
#   ✔ 755/755 cases passed (86 ms)
#   ✔ Your runtime beats 60 % of java submissions
#   ✔ Your memory usage beats 77.5 % of java submissions (46.1 MB)
# Submitting: java_solutions/3317.find-the-number-of-possible-ways-for-an-event.java
# - Downloading find-the-number-of-possible-ways-for-an-event
#   ✔ Accepted
#   ✔ 568/568 cases passed (128 ms)
#   ✔ Your runtime beats 21.74 % of java submissions
#   ✔ Your memory usage beats 78.26 % of java submissions (53.1 MB)
# Submitting: java_solutions/3318.find-x-sum-of-all-k-long-subarrays-i.java
# - Downloading find-x-sum-of-all-k-long-subarrays-i
#   ✔ Accepted
#   ✔ 906/906 cases passed (49 ms)
#   ✔ Your runtime beats 5.12 % of java submissions
#   ✔ Your memory usage beats 88.06 % of java submissions (46.9 MB)
# Submitting: java_solutions/3319.k-th-largest-perfect-subtree-size-in-binary-tree.java
# - Downloading k-th-largest-perfect-subtree-size-in-binary-tree
#   ✔ Accepted
#   ✔ 766/766 cases passed (29 ms)
#   ✔ Your runtime beats 7.36 % of java submissions
#   ✔ Your memory usage beats 7.36 % of java submissions (47.7 MB)
# Submitting: java_solutions/3320.count-the-number-of-winning-sequences.java
# - Downloading count-the-number-of-winning-sequences
#   ✔ Accepted
#   ✔ 691/691 cases passed (2523 ms)
#   ✔ Your runtime beats 5.88 % of java submissions
#   ✔ Your memory usage beats 82.35 % of java submissions (53.1 MB)
# Submitting: java_solutions/3321.find-x-sum-of-all-k-long-subarrays-ii.java
# - Downloading find-x-sum-of-all-k-long-subarrays-ii
#   ✔ Accepted
#   ✔ 784/784 cases passed (654 ms)
#   ✔ Your runtime beats 31.5 % of java submissions
#   ✔ Your memory usage beats 70 % of java submissions (182 MB)
# Submitting: java_solutions/3324.find-the-sequence-of-strings-appeared-on-the-screen.java
# - Downloading find-the-sequence-of-strings-appeared-on-the-screen
#   ✔ Accepted
#   ✔ 742/742 cases passed (16 ms)
#   ✔ Your runtime beats 7.51 % of java submissions
#   ✔ Your memory usage beats 13.3 % of java submissions (68.6 MB)
# Submitting: java_solutions/3325.count-substrings-with-k-frequency-characters-i.java
# - Downloading count-substrings-with-k-frequency-characters-i
#   ✔ Accepted
#   ✔ 571/571 cases passed (4 ms)
#   ✔ Your runtime beats 56.73 % of java submissions
#   ✔ Your memory usage beats 39.59 % of java submissions (44.4 MB)

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-05-05 15:01:57
