# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME_2')
    user_cookie = userdata.get('LEETCODE_TOKEN_2')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME_2'] = user_name
    os.environ['LEETCODE_TOKEN_2'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME_2" "$LEETCODE_TOKEN_2" | leetcode user -c

# %%
# %%bash
#
# # top 300-400 answers (next batch)
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v kotlin_solutions_1/*.kt | sed -n '301,400p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 7
# done
# Out:
# Submitting: kotlin_solutions_1/1392.longest-happy-prefix.kt
# - Downloading longest-happy-prefix
#   ✔ Accepted
#   ✔ 83/83 cases passed (92 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/1394.find-lucky-integer-in-an-array.kt
# - Downloading find-lucky-integer-in-an-array
#   ✔ Accepted
#   ✔ 102/102 cases passed (13 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (47.2 MB)
# Submitting: kotlin_solutions_1/1395.count-number-of-teams.kt
# - Downloading count-number-of-teams
#   ✔ Accepted
#   ✔ 72/72 cases passed (93 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1396.design-underground-system.kt
# - Downloading design-underground-system
#   ✔ Accepted
#   ✔ 57/57 cases passed (148 ms)
#   ✔ Your runtime beats 85.71 % of kotlin submissions
#   ✔ Your memory usage beats 67.86 % of kotlin submissions (81.5 MB)
# Submitting: kotlin_solutions_1/1397.find-all-good-strings.kt
# - Downloading find-all-good-strings
#   ✔ Accepted
#   ✔ 55/55 cases passed (218 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1399.count-largest-group.kt
# - Downloading count-largest-group
#   ✔ Accepted
#   ✔ 75/75 cases passed (33 ms)
#   ✔ Your runtime beats 14.29 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (48 MB)
# Submitting: kotlin_solutions_1/1400.construct-k-palindrome-strings.kt
# - Downloading construct-k-palindrome-strings
#   ✔ Accepted
#   ✔ 112/112 cases passed (51 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1401.circle-and-rectangle-overlapping.kt
# - Downloading circle-and-rectangle-overlapping
#   ✔ Accepted
#   ✔ 90/90 cases passed (1 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (40.4 MB)
# Submitting: kotlin_solutions_1/1402.reducing-dishes.kt
# - Downloading reducing-dishes
#   ✔ Accepted
#   ✔ 60/60 cases passed (22 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1403.minimum-subsequence-in-non-increasing-order.kt
# - Downloading minimum-subsequence-in-non-increasing-order
#   ✔ Accepted
#   ✔ 103/103 cases passed (37 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (50 MB)
# Submitting: kotlin_solutions_1/1404.number-of-steps-to-reduce-a-number-in-binary-representation-to-one.kt
# - Downloading number-of-steps-to-reduce-a-number-in-binary-representation-to-one
#   ✔ Accepted
#   ✔ 75/75 cases passed (10 ms)
#   ✔ Your runtime beats 46.15 % of kotlin submissions
#   ✔ Your memory usage beats 46.15 % of kotlin submissions (42.7 MB)
# Submitting: kotlin_solutions_1/1405.longest-happy-string.kt
# - Downloading longest-happy-string
#   ✔ Accepted
#   ✔ 36/36 cases passed (13 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
#   ✔ Your memory usage beats 30 % of kotlin submissions (41.6 MB)
# Submitting: kotlin_solutions_1/1406.stone-game-iii.kt
# - Downloading stone-game-iii
#   ✔ Accepted
#   ✔ 187/187 cases passed (167 ms)
#   ✔ Your runtime beats 5.34 % of kotlin submissions
#   ✔ Your memory usage beats 19.9 % of kotlin submissions (73.7 MB)
# Submitting: kotlin_solutions_1/1408.string-matching-in-an-array.kt
# - Downloading string-matching-in-an-array
#   ✔ Accepted
#   ✔ 69/69 cases passed (13 ms)
#   ✔ Your runtime beats 61.54 % of kotlin submissions
#   ✔ Your memory usage beats 46.15 % of kotlin submissions (43.4 MB)
# Submitting: kotlin_solutions_1/1409.queries-on-a-permutation-with-key.kt
# - Downloading queries-on-a-permutation-with-key
#   ✔ Accepted
#   ✔ 53/53 cases passed (13 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1410.html-entity-parser.kt
# - Downloading html-entity-parser
#   ✔ Accepted
#   ✔ 171/171 cases passed (40 ms)
#   ✔ Your runtime beats 71.43 % of kotlin submissions
#   ✔ Your memory usage beats 71.43 % of kotlin submissions (49.7 MB)
# Submitting: kotlin_solutions_1/1411.number-of-ways-to-paint-n-3-grid.kt
# - Downloading number-of-ways-to-paint-n-3-grid
#   ✔ Accepted
#   ✔ 50/50 cases passed (22 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1413.minimum-value-to-get-positive-step-by-step-sum.kt
# - Downloading minimum-value-to-get-positive-step-by-step-sum
#   ✔ Accepted
#   ✔ 57/57 cases passed (7 ms)
#   ✔ Your runtime beats 8.7 % of kotlin submissions
#   ✔ Your memory usage beats 8.7 % of kotlin submissions (41.7 MB)
# Submitting: kotlin_solutions_1/1414.find-the-minimum-number-of-fibonacci-numbers-whose-sum-is-k.kt
# - Downloading find-the-minimum-number-of-fibonacci-numbers-whose-sum-is-k
#   ✔ Accepted
#   ✔ 504/504 cases passed (26 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1415.the-k-th-lexicographical-string-of-all-happy-strings-of-length-n.kt
# - Downloading the-k-th-lexicographical-string-of-all-happy-strings-of-length-n
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 7: Char 94: WARNING: Parameter '<unused var>: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 7: Char 94: WARNING: Parameter '<unused var>: Int' is never used, could be renamed to '_'.
# Line 7: Char 189: WARNING: Parameter 'it: Char' is never used, could be renamed to '_'.
# Line 7: Char 195: ERROR: Unresolved reference 'c'.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1416.restore-the-array.kt
# - Downloading restore-the-array
#   ✔ Accepted
#   ✔ 86/86 cases passed (106 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1417.reformat-the-string.kt
# - Downloading reformat-the-string
#   ✔ Accepted
#   ✔ 302/302 cases passed (38 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1418.display-table-of-food-orders-in-a-restaurant.kt
# - Downloading display-table-of-food-orders-in-a-restaurant
#   ✔ Accepted
#   ✔ 53/53 cases passed (825 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (81.9 MB)
# Submitting: kotlin_solutions_1/1419.minimum-number-of-frogs-croaking.kt
# - Downloading minimum-number-of-frogs-croaking
#   ✔ Accepted
#   ✔ 61/61 cases passed (63 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1420.build-array-where-you-can-find-the-maximum-exactly-k-comparisons.kt
# - Downloading build-array-where-you-can-find-the-maximum-exactly-k-comparisons
#   ✔ Accepted
#   ✔ 31/31 cases passed (92 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1422.maximum-score-after-splitting-a-string.kt
# - Downloading maximum-score-after-splitting-a-string
#   ✔ Accepted
#   ✔ 104/104 cases passed (22 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1423.maximum-points-you-can-obtain-from-cards.kt
# - Downloading maximum-points-you-can-obtain-from-cards
#   ✔ Accepted
#   ✔ 41/41 cases passed (24 ms)
#   ✔ Your runtime beats 15.15 % of kotlin submissions
#   ✔ Your memory usage beats 60.61 % of kotlin submissions (60.6 MB)
# Submitting: kotlin_solutions_1/1424.diagonal-traverse-ii.kt
# - Downloading diagonal-traverse-ii
#   ✔ Accepted
#   ✔ 56/56 cases passed (109 ms)
#   ✔ Your runtime beats 12.5 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (75.1 MB)
# Submitting: kotlin_solutions_1/1425.constrained-subsequence-sum.kt
# - Downloading constrained-subsequence-sum
#   ✔ Accepted
#   ✔ 40/40 cases passed (69 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (65.3 MB)
# Submitting: kotlin_solutions_1/1431.kids-with-the-greatest-number-of-candies.kt
# - Downloading kids-with-the-greatest-number-of-candies
#   ✔ Accepted
#   ✔ 103/103 cases passed (11 ms)
#   ✔ Your runtime beats 61.5 % of kotlin submissions
#   ✔ Your memory usage beats 42.5 % of kotlin submissions (45.7 MB)
# Submitting: kotlin_solutions_1/1432.max-difference-you-can-get-from-changing-an-integer.kt
# - Downloading max-difference-you-can-get-from-changing-an-integer
#   ✔ Accepted
#   ✔ 211/211 cases passed (10 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1433.check-if-a-string-can-break-another-string.kt
# - Downloading check-if-a-string-can-break-another-string
#   ✔ Accepted
#   ✔ 103/103 cases passed (268 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/1434.number-of-ways-to-wear-different-hats-to-each-other.kt
# - Downloading number-of-ways-to-wear-different-hats-to-each-other
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 7: Char 276: WARNING: Parameter 'it: IntArray' is never used, could be renamed to '_'.
#   ✘ Error: Line 7: Char 276: WARNING: Parameter 'it: IntArray' is never used, could be renamed to '_'.
# Line 7: Char 547: ERROR: Syntax error: Expecting a top level declaration.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1436.destination-city.kt
# - Downloading destination-city
#   ✔ Accepted
#   ✔ 104/104 cases passed (13 ms)
#   ✔ Your runtime beats 5 % of kotlin submissions
#   ✔ Your memory usage beats 10 % of kotlin submissions (46.8 MB)
# Submitting: kotlin_solutions_1/1437.check-if-all-1s-are-at-least-length-k-places-away.kt
# - Downloading check-if-all-1s-are-at-least-length-k-places-away
#   ✔ Accepted
#   ✔ 71/71 cases passed (48 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (60.2 MB)
# Submitting: kotlin_solutions_1/1438.longest-continuous-subarray-with-absolute-diff-less-than-or-equal-to-limit.kt
# - Downloading longest-continuous-subarray-with-absolute-diff-less-than-or-equal-to-limit
#   ✔ Accepted
#   ✔ 63/63 cases passed (87 ms)
#   ✔ Your runtime beats 30 % of kotlin submissions
#   ✔ Your memory usage beats 56.67 % of kotlin submissions (63.2 MB)
# Submitting: kotlin_solutions_1/1439.find-the-kth-smallest-sum-of-a-matrix-with-sorted-rows.kt
# - Downloading find-the-kth-smallest-sum-of-a-matrix-with-sorted-rows
#   ✔ Accepted
#   ✔ 72/72 cases passed (313 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/1441.build-an-array-with-stack-operations.kt
# - Downloading build-an-array-with-stack-operations
#   ✔ Accepted
#   ✔ 49/49 cases passed (19 ms)
#   ✔ Your runtime beats 7.06 % of kotlin submissions
#   ✔ Your memory usage beats 9.41 % of kotlin submissions (46.1 MB)
# Submitting: kotlin_solutions_1/1442.count-triplets-that-can-form-two-arrays-of-equal-xor.kt
# - Downloading count-triplets-that-can-form-two-arrays-of-equal-xor
#   ✔ Accepted
#   ✔ 47/47 cases passed (36 ms)
#   ✔ Your runtime beats 10 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/1443.minimum-time-to-collect-all-apples-in-a-tree.kt
# - Downloading minimum-time-to-collect-all-apples-in-a-tree
#   ✔ Accepted
#   ✔ 63/63 cases passed (87 ms)
#   ✔ Your runtime beats 10 % of kotlin submissions
#   ✔ Your memory usage beats 10 % of kotlin submissions (121.7 MB)
# Submitting: kotlin_solutions_1/1444.number-of-ways-of-cutting-a-pizza.kt
# - Downloading number-of-ways-of-cutting-a-pizza
#   ✔ Accepted
#   ✔ 54/54 cases passed (89 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1446.consecutive-characters.kt
# - Downloading consecutive-characters
#   ✔ Accepted
#   ✔ 333/333 cases passed (18 ms)
#   ✔ Your runtime beats 2.27 % of kotlin submissions
#   ✔ Your memory usage beats 6.82 % of kotlin submissions (46.1 MB)
# Submitting: kotlin_solutions_1/1447.simplified-fractions.kt
# - Downloading simplified-fractions
#   ✔ Accepted
#   ✔ 100/100 cases passed (52 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 7.69 % of kotlin submissions (49.4 MB)
# Submitting: kotlin_solutions_1/1448.count-good-nodes-in-binary-tree.kt
# - Downloading count-good-nodes-in-binary-tree
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 7: Char 314: ERROR: Unresolved reference 'callRecursive'.
#   ✘ Error: Line 7: Char 314: ERROR: Unresolved reference 'callRecursive'.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1449.form-largest-integer-with-digits-that-add-up-to-target.kt
# - Downloading form-largest-integer-with-digits-that-add-up-to-target
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 7: Char 96: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 7: Char 96: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 7: Char 541: ERROR: Unresolved reference 'callRecursive'.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1450.number-of-students-doing-homework-at-a-given-time.kt
# - Downloading number-of-students-doing-homework-at-a-given-time
#   ✔ Accepted
#   ✔ 111/111 cases passed (13 ms)
#   ✔ Your runtime beats 7.14 % of kotlin submissions
#   ✔ Your memory usage beats 7.14 % of kotlin submissions (45.4 MB)
# Submitting: kotlin_solutions_1/1451.rearrange-words-in-a-sentence.kt
# - Downloading rearrange-words-in-a-sentence
#   ✔ Accepted
#   ✔ 74/74 cases passed (49 ms)
#   ✔ Your runtime beats 93.75 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (48.2 MB)
# Submitting: kotlin_solutions_1/1452.people-whose-list-of-favorite-companies-is-not-a-subset-of-another-list.kt
# - Downloading people-whose-list-of-favorite-companies-is-not-a-subset-of-another-list
#   ✔ Accepted
#   ✔ 55/55 cases passed (212 ms)
#   ✔ Your runtime beats 29.41 % of kotlin submissions
#   ✔ Your memory usage beats 41.18 % of kotlin submissions (70.5 MB)
# Submitting: kotlin_solutions_1/1453.maximum-number-of-darts-inside-of-a-circular-dartboard.kt
# - Downloading maximum-number-of-darts-inside-of-a-circular-dartboard
#   ✔ Accepted
#   ✔ 65/65 cases passed (75 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1455.check-if-a-word-occurs-as-a-prefix-of-any-word-in-a-sentence.kt
# - Downloading check-if-a-word-occurs-as-a-prefix-of-any-word-in-a-sentence
#   ✔ Accepted
#   ✔ 45/45 cases passed (11 ms)
#   ✔ Your runtime beats 30 % of kotlin submissions
#   ✔ Your memory usage beats 40 % of kotlin submissions (42.5 MB)
# Submitting: kotlin_solutions_1/1456.maximum-number-of-vowels-in-a-substring-of-given-length.kt
# - Downloading maximum-number-of-vowels-in-a-substring-of-given-length
#   ✔ Accepted
#   ✔ 107/107 cases passed (57 ms)
#   ✔ Your runtime beats 10.34 % of kotlin submissions
#   ✔ Your memory usage beats 64.83 % of kotlin submissions (47.6 MB)
# Submitting: kotlin_solutions_1/1457.pseudo-palindromic-paths-in-a-binary-tree.kt
# - Downloading pseudo-palindromic-paths-in-a-binary-tree
#   ✔ Accepted
#   ✔ 56/56 cases passed (53 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1458.max-dot-product-of-two-subsequences.kt
# - Downloading max-dot-product-of-two-subsequences
#   ✔ Accepted
#   ✔ 70/70 cases passed (10 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (44.7 MB)
# Submitting: kotlin_solutions_1/1460.make-two-arrays-equal-by-reversing-subarrays.kt
# - Downloading make-two-arrays-equal-by-reversing-subarrays
#   ✔ Accepted
#   ✔ 109/109 cases passed (24 ms)
#   ✔ Your runtime beats 10 % of kotlin submissions
#   ✔ Your memory usage beats 20 % of kotlin submissions (48.4 MB)
# Submitting: kotlin_solutions_1/1461.check-if-a-string-contains-all-binary-codes-of-size-k.kt
# - Downloading check-if-a-string-contains-all-binary-codes-of-size-k
#   ✔ Accepted
#   ✔ 201/201 cases passed (161 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 16.67 % of kotlin submissions (115.6 MB)
# Submitting: kotlin_solutions_1/1462.course-schedule-iv.kt
# - Downloading course-schedule-iv
#   ✔ Accepted
#   ✔ 101/101 cases passed (44 ms)
#   ✔ Your runtime beats 8.33 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (51.5 MB)
# Submitting: kotlin_solutions_1/1463.cherry-pickup-ii.kt
# - Downloading cherry-pickup-ii
#   ✔ Accepted
#   ✔ 59/59 cases passed (269 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1464.maximum-product-of-two-elements-in-an-array.kt
# - Downloading maximum-product-of-two-elements-in-an-array
#   ✔ Accepted
#   ✔ 106/106 cases passed (19 ms)
#   ✔ Your runtime beats 8.75 % of kotlin submissions
#   ✔ Your memory usage beats 16.25 % of kotlin submissions (46.5 MB)
# Submitting: kotlin_solutions_1/1465.maximum-area-of-a-piece-of-cake-after-horizontal-and-vertical-cuts.kt
# - Downloading maximum-area-of-a-piece-of-cake-after-horizontal-and-vertical-cuts
#   ✔ Accepted
#   ✔ 56/56 cases passed (97 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (70 MB)
# Submitting: kotlin_solutions_1/1466.reorder-routes-to-make-all-paths-lead-to-the-city-zero.kt
# - Downloading reorder-routes-to-make-all-paths-lead-to-the-city-zero
#   ✔ Accepted
#   ✔ 77/77 cases passed (144 ms)
#   ✔ Your runtime beats 26.47 % of kotlin submissions
#   ✔ Your memory usage beats 41.18 % of kotlin submissions (93.6 MB)
# Submitting: kotlin_solutions_1/1467.probability-of-a-two-boxes-having-the-same-number-of-distinct-balls.kt
# - Downloading probability-of-a-two-boxes-having-the-same-number-of-distinct-balls
#   ✔ Accepted
#   ✔ 21/21 cases passed (38 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1470.shuffle-the-array.kt
# - Downloading shuffle-the-array
#   ✔ Accepted
#   ✔ 53/53 cases passed (142 ms)
#   ✔ Your runtime beats 74.02 % of kotlin submissions
#   ✔ Your memory usage beats 5.88 % of kotlin submissions (47.1 MB)
# Submitting: kotlin_solutions_1/1471.the-k-strongest-values-in-an-array.kt
# - Downloading the-k-strongest-values-in-an-array
#   ✔ Accepted
#   ✔ 71/71 cases passed (314 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (68.8 MB)
# Submitting: kotlin_solutions_1/1472.design-browser-history.kt
# - Downloading design-browser-history
#   ✔ Accepted
#   ✔ 73/73 cases passed (100 ms)
#   ✔ Your runtime beats 30.43 % of kotlin submissions
#   ✔ Your memory usage beats 95.65 % of kotlin submissions (64.2 MB)
# Submitting: kotlin_solutions_1/1473.paint-house-iii.kt
# - Downloading paint-house-iii
#   ✔ Accepted
#   ✔ 62/62 cases passed (215 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1475.final-prices-with-a-special-discount-in-a-shop.kt
# - Downloading final-prices-with-a-special-discount-in-a-shop
#   ✔ Accepted
#   ✔ 103/103 cases passed (12 ms)
#   ✔ Your runtime beats 48.15 % of kotlin submissions
#   ✔ Your memory usage beats 71.6 % of kotlin submissions (44.7 MB)
# Submitting: kotlin_solutions_1/1476.subrectangle-queries.kt
# - Downloading subrectangle-queries
#   ✔ Accepted
#   ✔ 52/52 cases passed (241 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (50.9 MB)
# Submitting: kotlin_solutions_1/1477.find-two-non-overlapping-sub-arrays-each-with-target-sum.kt
# - Downloading find-two-non-overlapping-sub-arrays-each-with-target-sum
#   ✔ Accepted
#   ✔ 61/61 cases passed (106 ms)
#   ✔ Your runtime beats 42.86 % of kotlin submissions
#   ✔ Your memory usage beats 71.43 % of kotlin submissions (69.6 MB)
# Submitting: kotlin_solutions_1/1478.allocate-mailboxes.kt
# - Downloading allocate-mailboxes
#   ✔ Accepted
#   ✔ 69/69 cases passed (50 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1480.running-sum-of-1d-array.kt
# - Downloading running-sum-of-1d-array
#   ✔ Accepted
#   ✔ 54/54 cases passed (4 ms)
#   ✔ Your runtime beats 10.14 % of kotlin submissions
#   ✔ Your memory usage beats 10.14 % of kotlin submissions (43 MB)
# Submitting: kotlin_solutions_1/1481.least-number-of-unique-integers-after-k-removals.kt
# - Downloading least-number-of-unique-integers-after-k-removals
#   ✔ Accepted
#   ✔ 43/43 cases passed (583 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1482.minimum-number-of-days-to-make-m-bouquets.kt
# - Downloading minimum-number-of-days-to-make-m-bouquets
#   ✔ Accepted
#   ✔ 94/94 cases passed (79 ms)
#   ✔ Your runtime beats 6.45 % of kotlin submissions
#   ✔ Your memory usage beats 6.45 % of kotlin submissions (65.5 MB)
# Submitting: kotlin_solutions_1/1483.kth-ancestor-of-a-tree-node.kt
# - Downloading kth-ancestor-of-a-tree-node
#   ✔ Accepted
#   ✔ 17/17 cases passed (140 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1486.xor-operation-in-an-array.kt
# - Downloading xor-operation-in-an-array
#   ✔ Accepted
#   ✔ 54/54 cases passed (5 ms)
#   ✔ Your runtime beats 10 % of kotlin submissions
#   ✔ Your memory usage beats 20 % of kotlin submissions (40.7 MB)
# Submitting: kotlin_solutions_1/1487.making-file-names-unique.kt
# - Downloading making-file-names-unique
#   ✔ Accepted
#   ✔ 34/34 cases passed (111 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1488.avoid-flood-in-the-city.kt
# - Downloading avoid-flood-in-the-city
#   ✘ Runtime Error
#   ✘ 2/86 cases passed (N/A)
#   ✘ Error: Line 7: Exception in thread "main" java.lang.NullPointerException
#   ✘ Error: Line 7: Exception in thread "main" java.lang.NullPointerException
#   ✘ Testcase: [1,2,0,1,2]
#   ✘ Answer:
#   ✘ Expected Answer: []
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1489.find-critical-and-pseudo-critical-edges-in-minimum-spanning-tree.kt
# - Downloading find-critical-and-pseudo-critical-edges-in-minimum-spanning-tree
#   ✔ Accepted
#   ✔ 66/66 cases passed (209 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1491.average-salary-excluding-the-minimum-and-maximum-salary.kt
# - Downloading average-salary-excluding-the-minimum-and-maximum-salary
#   ✔ Accepted
#   ✔ 43/43 cases passed (19 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1492.the-kth-factor-of-n.kt
# - Downloading the-kth-factor-of-n
#   ✔ Accepted
#   ✔ 209/209 cases passed (12 ms)
#   ✔ Your runtime beats 7.14 % of kotlin submissions
#   ✔ Your memory usage beats 7.14 % of kotlin submissions (43 MB)
# Submitting: kotlin_solutions_1/1493.longest-subarray-of-1s-after-deleting-one-element.kt
# - Downloading longest-subarray-of-1s-after-deleting-one-element
#   ✔ Accepted
#   ✔ 86/86 cases passed (20 ms)
#   ✔ Your runtime beats 6.06 % of kotlin submissions
#   ✔ Your memory usage beats 6.06 % of kotlin submissions (64 MB)
# Submitting: kotlin_solutions_1/1494.parallel-courses-ii.kt
# - Downloading parallel-courses-ii
#   ✔ Accepted
#   ✔ 82/82 cases passed (332 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1496.path-crossing.kt
# - Downloading path-crossing
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 1: Char 176: ERROR: None of the following candidates is applicable:
#   ✘ Error: Line 1: Char 176: ERROR: None of the following candidates is applicable:
# fun plus(other: Byte): Int
# fun plus(other: Short): Int
# fun plus(other: Int): Int
# fun plus(other: Long): Long
# fun plus(other: Float): Float
# fun plus(other: Double): Double
# Line 1: Char 285: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 1: Char 285: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun <T, R> T.let(block: (T) -> R): R
#     [R|Contract description]
#      <
#         CallsInPlace(block, EXACTLY_ONCE)
#     >
# Line 1: Char 291: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 1: Char 314: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun <A, B> A.to(that: B): Pair<A, B>
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1497.check-if-array-pairs-are-divisible-by-k.kt
# - Downloading check-if-array-pairs-are-divisible-by-k
#   ✔ Accepted
#   ✔ 99/99 cases passed (10 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1498.number-of-subsequences-that-satisfy-the-given-sum-condition.kt
# - Downloading number-of-subsequences-that-satisfy-the-given-sum-condition
#   ✘ Wrong Answer
#   ✘ 2/63 cases passed (N/A)
#   ✘ Testcase: [3,5,6,7]
# 9
#   ✘ Answer: 0
#   ✘ Expected Answer: 4
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1499.max-value-of-equation.kt
# - Downloading max-value-of-equation
#   ✔ Accepted
#   ✔ 66/66 cases passed (180 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1502.can-make-arithmetic-progression-from-sequence.kt
# - Downloading can-make-arithmetic-progression-from-sequence
#   ✔ Accepted
#   ✔ 114/114 cases passed (25 ms)
#   ✔ Your runtime beats 16.13 % of kotlin submissions
#   ✔ Your memory usage beats 12.9 % of kotlin submissions (46.5 MB)
# Submitting: kotlin_solutions_1/1503.last-moment-before-all-ants-fall-out-of-a-plank.kt
# - Downloading last-moment-before-all-ants-fall-out-of-a-plank
#   ✔ Accepted
#   ✔ 167/167 cases passed (12 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1504.count-submatrices-with-all-ones.kt
# - Downloading count-submatrices-with-all-ones
#   ✔ Accepted
#   ✔ 73/73 cases passed (176 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1505.minimum-possible-integer-after-at-most-k-adjacent-swaps-on-digits.kt
# - Downloading minimum-possible-integer-after-at-most-k-adjacent-swaps-on-digits
#   ✔ Accepted
#   ✔ 50/50 cases passed (177 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1507.reformat-date.kt
# - Downloading reformat-date
#   ✔ Accepted
#   ✔ 110/110 cases passed (14 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
#   ✔ Your memory usage beats 40 % of kotlin submissions (42.6 MB)
# Submitting: kotlin_solutions_1/1508.range-sum-of-sorted-subarray-sums.kt
# - Downloading range-sum-of-sorted-subarray-sums
#   ✔ Accepted
#   ✔ 54/54 cases passed (510 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1509.minimum-difference-between-largest-and-smallest-value-in-three-moves.kt
# - Downloading minimum-difference-between-largest-and-smallest-value-in-three-moves
#   ✔ Accepted
#   ✔ 73/73 cases passed (130 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/1510.stone-game-iv.kt
# - Downloading stone-game-iv
#   ✔ Accepted
#   ✔ 72/72 cases passed (120 ms)
#   ✔ Your runtime beats 22.64 % of kotlin submissions
#   ✔ Your memory usage beats 24.53 % of kotlin submissions (47.8 MB)
# Submitting: kotlin_solutions_1/1512.number-of-good-pairs.kt
# - Downloading number-of-good-pairs
#   ✔ Accepted
#   ✔ 49/49 cases passed (1 ms)
#   ✔ Your runtime beats 96.43 % of kotlin submissions
#   ✔ Your memory usage beats 64.29 % of kotlin submissions (40.8 MB)
# Submitting: kotlin_solutions_1/1513.number-of-substrings-with-only-1s.kt
# - Downloading number-of-substrings-with-only-1s
#   ✔ Accepted
#   ✔ 57/57 cases passed (27 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (47.1 MB)
# Submitting: kotlin_solutions_1/1514.path-with-maximum-probability.kt
# - Downloading path-with-maximum-probability
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 7: Char 143: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 7: Char 143: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 7: Char 349: ERROR: Argument type mismatch: actual type is 'kotlin.text.MatchGroup?', but 'kotlin.Double' was expected.
# Line 7: Char 409: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun MatchGroupCollection.get(name: String): MatchGroup?
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1515.best-position-for-a-service-centre.kt
# - Downloading best-position-for-a-service-centre
#   ✔ Accepted
#   ✔ 56/56 cases passed (38 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1518.water-bottles.kt
# - Downloading water-bottles
#   ✔ Accepted
#   ✔ 70/70 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 22.22 % of kotlin submissions (40.2 MB)
# Submitting: kotlin_solutions_1/1519.number-of-nodes-in-the-sub-tree-with-the-same-label.kt
# - Downloading number-of-nodes-in-the-sub-tree-with-the-same-label
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 8: Char 118: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 8: Char 118: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 8: Char 198: WARNING: Parameter 'it: Boolean' is never used, could be renamed to '_'.
# Line 47: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1520.maximum-number-of-non-overlapping-substrings.kt
# - Downloading maximum-number-of-non-overlapping-substrings
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 8: Char 68: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 8: Char 68: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 8: Char 103: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 8: Char 220: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 43: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-08-17 17:26:50
