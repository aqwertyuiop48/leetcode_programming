# %%
# %%capture
import os
import getpass

# 2. Interactive input (Safe and hidden)
print("Please enter your LeetCode credentials:")
user_name = getpass.getpass('LeetCode Username: ')
user_cookie = getpass.getpass('LeetCode Session Token: ')

# 1. Install and Clone
# !npm install -g leetcode-tools/leetcode-cli
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME'] = user_name
    os.environ['LEETCODE_TOKEN'] = user_cookie

    # 4. Run the login silently
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME" "$LEETCODE_TOKEN" | leetcode user -c

# %%
# %%bash
#
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Enter the directory
# cd leetcode_programming
#
# # 3. Define the specific files you want to run here
# # You can add more files by separating them with a space or a newline
# files=(
#     "kotlin_solutions/53.maximum-subarray.kt"
#     "kotlin_solutions/424.longest-repeating-character-replacement.kt"
#     "kotlin_solutions/605.can-place-flowers.kt"
#     "kotlin_solutions/849.maximize-distance-to-closest-person.kt"
#     #"kotlin_solutions/2536.increment-submatrices-by-one.kt"
# )
#
# # 4. Run the loop over your specific list
# for f in "${files[@]}"; do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 7
# done
# Out:
# Submitting: kotlin_solutions/53.maximum-subarray.kt
# - Downloading maximum-subarray
#   ✔ Accepted
#   ✔ 210/210 cases passed (51 ms)
#   ✔ Your runtime beats 5.06 % of kotlin submissions
#   ✔ Your memory usage beats 26.26 % of kotlin submissions (67.3 MB)
# Submitting: kotlin_solutions/424.longest-repeating-character-replacement.kt
# - Downloading longest-repeating-character-replacement
#   ✔ Accepted
#   ✔ 50/50 cases passed (141 ms)
#   ✔ Your runtime beats 5.13 % of kotlin submissions
#   ✔ Your memory usage beats 8.48 % of kotlin submissions (50.5 MB)
# Submitting: kotlin_solutions/605.can-place-flowers.kt
# - Downloading can-place-flowers
#   ✔ Accepted
#   ✔ 130/130 cases passed (15 ms)
#   ✔ Your runtime beats 8.87 % of kotlin submissions
#   ✔ Your memory usage beats 11.29 % of kotlin submissions (49.9 MB)
# Submitting: kotlin_solutions/849.maximize-distance-to-closest-person.kt
# - Downloading maximize-distance-to-closest-person
#   ✔ Accepted
#   ✔ 82/82 cases passed (35 ms)
#   ✔ Your runtime beats 6.25 % of kotlin submissions
#   ✔ Your memory usage beats 35 % of kotlin submissions (50 MB)

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-03-20 13:43:54
