# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME_3')
    user_cookie = userdata.get('LEETCODE_TOKEN_3')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME_3'] = user_name
    os.environ['LEETCODE_TOKEN_3'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME_3" "$LEETCODE_TOKEN_3" | leetcode user -c

# %%
# %%bash
#
# # top 400-500 answers (5th batch)
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v kotlin_solutions/*.kt | sed -n '401,500p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 7
# done
# Out:
# Submitting: kotlin_solutions/507.perfect-number.kt
#   ✔ Accepted
#   ✔ 98/98 cases passed (10 ms)
#   ✔ Your runtime beats 56.25 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (42 MB)
# Submitting: kotlin_solutions/508.most-frequent-subtree-sum.kt
#   ✔ Accepted
#   ✔ 58/58 cases passed (32 ms)
#   ✔ Your runtime beats 11.11 % of kotlin submissions
#   ✔ Your memory usage beats 11.11 % of kotlin submissions (49 MB)
# Submitting: kotlin_solutions/509.fibonacci-number.kt
#   ✔ Accepted
#   ✔ 31/31 cases passed (88 ms)
#   ✔ Your runtime beats 10.62 % of kotlin submissions
#   ✔ Your memory usage beats 68.84 % of kotlin submissions (39.1 MB)
# Submitting: kotlin_solutions/513.find-bottom-left-tree-value.kt
#   ✔ Accepted
#   ✔ 79/79 cases passed (9 ms)
#   ✔ Your runtime beats 42.86 % of kotlin submissions
#   ✔ Your memory usage beats 42.86 % of kotlin submissions (47.5 MB)
# Submitting: kotlin_solutions/514.freedom-trail.kt
#   ✔ Accepted
#   ✔ 303/303 cases passed (64 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/515.find-largest-value-in-each-tree-row.kt
#   ✔ Accepted
#   ✔ 78/78 cases passed (20 ms)
#   ✔ Your runtime beats 39.13 % of kotlin submissions
#   ✔ Your memory usage beats 84.78 % of kotlin submissions (46.5 MB)
# Submitting: kotlin_solutions/516.longest-palindromic-subsequence.kt
#   ✔ Accepted
#   ✔ 86/86 cases passed (49 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 11.11 % of kotlin submissions (59.7 MB)
# Submitting: kotlin_solutions/517.super-washing-machines.kt
#   ✔ Accepted
#   ✔ 120/120 cases passed (18 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/518.coin-change-ii.kt
#   ✔ Accepted
#   ✔ 31/31 cases passed (14 ms)
#   ✔ Your runtime beats 63.54 % of kotlin submissions
#   ✔ Your memory usage beats 68.75 % of kotlin submissions (41.9 MB)
# Submitting: kotlin_solutions/519.random-flip-matrix.kt
#   ✔ Accepted
#   ✔ 20/20 cases passed (51 ms)
#   ✔ Your runtime beats 66.67 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (48.3 MB)
# Submitting: kotlin_solutions/520.detect-capital.kt
#   ✔ Accepted
#   ✔ 552/552 cases passed (9 ms)
#   ✔ Your runtime beats 12.35 % of kotlin submissions
#   ✔ Your memory usage beats 17.28 % of kotlin submissions (42.8 MB)
# Submitting: kotlin_solutions/521.longest-uncommon-subsequence-i.kt
#   ✔ Accepted
#   ✔ 41/41 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 5.56 % of kotlin submissions (40.9 MB)
# Submitting: kotlin_solutions/522.longest-uncommon-subsequence-ii.kt
#   ✔ Accepted
#   ✔ 101/101 cases passed (29 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/523.continuous-subarray-sum.kt
#   ✔ Accepted
#   ✔ 102/102 cases passed (47 ms)
#   ✔ Your runtime beats 19.48 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (60.9 MB)
# Submitting: kotlin_solutions/524.longest-word-in-dictionary-through-deleting.kt
#   ✔ Accepted
#   ✔ 31/31 cases passed (209 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/525.contiguous-array.kt
#   ✔ Accepted
#   ✔ 566/566 cases passed (70 ms)
#   ✔ Your runtime beats 6.42 % of kotlin submissions
#   ✔ Your memory usage beats 19.27 % of kotlin submissions (60.4 MB)
# Submitting: kotlin_solutions/526.beautiful-arrangement.kt
#   ✔ Accepted
#   ✔ 15/15 cases passed (28 ms)
#   ✔ Your runtime beats 84.62 % of kotlin submissions
#   ✔ Your memory usage beats 38.46 % of kotlin submissions (44.9 MB)
# Submitting: kotlin_solutions/528.random-pick-with-weight.kt
#   ✔ Accepted
#   ✔ 57/57 cases passed (69 ms)
#   ✔ Your runtime beats 25.3 % of kotlin submissions
#   ✔ Your memory usage beats 26.51 % of kotlin submissions (63 MB)
# Submitting: kotlin_solutions/529.minesweeper.kt
#   ✔ Accepted
#   ✔ 54/54 cases passed (35 ms)
#   ✔ Your runtime beats 6.67 % of kotlin submissions
#   ✔ Your memory usage beats 6.67 % of kotlin submissions (54.1 MB)
# Submitting: kotlin_solutions/530.minimum-absolute-difference-in-bst.kt
#   ✔ Accepted
#   ✔ 190/190 cases passed (39 ms)
#   ✔ Your runtime beats 5.95 % of kotlin submissions
#   ✔ Your memory usage beats 5.95 % of kotlin submissions (50.7 MB)
# Submitting: kotlin_solutions/532.k-diff-pairs-in-an-array.kt
#   ✔ Accepted
#   ✔ 60/60 cases passed (78 ms)
#   ✔ Your runtime beats 16 % of kotlin submissions
#   ✔ Your memory usage beats 24 % of kotlin submissions (50 MB)
# Submitting: kotlin_solutions/535.encode-and-decode-tiny-url.kt
#   ✔ Accepted
#   ✔ 739/739 cases passed (146 ms)
#   ✔ Your runtime beats 67.86 % of kotlin submissions
#   ✔ Your memory usage beats 92.86 % of kotlin submissions (42.5 MB)
# Submitting: kotlin_solutions/537.complex-number-multiplication.kt
#   ✔ Accepted
#   ✔ 56/56 cases passed (29 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/538.convert-bst-to-greater-tree.kt
#   ✔ Accepted
#   ✔ 215/215 cases passed (21 ms)
#   ✔ Your runtime beats 8.33 % of kotlin submissions
#   ✔ Your memory usage beats 58.33 % of kotlin submissions (46.7 MB)
# Submitting: kotlin_solutions/539.minimum-time-difference.kt
#   ✔ Accepted
#   ✔ 116/116 cases passed (41 ms)
#   ✔ Your runtime beats 38.46 % of kotlin submissions
#   ✔ Your memory usage beats 30.77 % of kotlin submissions (51 MB)
# Submitting: kotlin_solutions/540.single-element-in-a-sorted-array.kt
#   ✔ Accepted
#   ✔ 16/16 cases passed (16 ms)
#   ✔ Your runtime beats 1.82 % of kotlin submissions
#   ✔ Your memory usage beats 7.27 % of kotlin submissions (57.3 MB)
# Submitting: kotlin_solutions/541.reverse-string-ii.kt
#   ✔ Accepted
#   ✔ 60/60 cases passed (14 ms)
#   ✔ Your runtime beats 29.41 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (45.5 MB)
# Submitting: kotlin_solutions/542.01-matrix.kt
#   ✔ Accepted
#   ✔ 50/50 cases passed (137 ms)
#   ✔ Your runtime beats 15.97 % of kotlin submissions
#   ✔ Your memory usage beats 7.64 % of kotlin submissions (72.4 MB)
# Submitting: kotlin_solutions/543.diameter-of-binary-tree.kt
#   ✔ Accepted
#   ✔ 106/106 cases passed (17 ms)
#   ✔ Your runtime beats 11.11 % of kotlin submissions
#   ✔ Your memory usage beats 16.67 % of kotlin submissions (48.7 MB)
# Submitting: kotlin_solutions/546.remove-boxes.kt
#   ✔ Accepted
#   ✔ 63/63 cases passed (630 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (74 MB)
# Submitting: kotlin_solutions/547.number-of-provinces.kt
#   ✔ Accepted
#   ✔ 114/114 cases passed (42 ms)
#   ✔ Your runtime beats 5.76 % of kotlin submissions
#   ✔ Your memory usage beats 79.06 % of kotlin submissions (56.1 MB)
# Submitting: kotlin_solutions/551.student-attendance-record-i.kt
#   ✔ Accepted
#   ✔ 115/115 cases passed (7 ms)
#   ✔ Your runtime beats 19.35 % of kotlin submissions
#   ✔ Your memory usage beats 22.58 % of kotlin submissions (41.8 MB)
# Submitting: kotlin_solutions/552.student-attendance-record-ii.kt
#   ✔ Accepted
#   ✔ 59/59 cases passed (46 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 40 % of kotlin submissions (59.3 MB)
# Submitting: kotlin_solutions/553.optimal-division.kt
#   ✔ Accepted
#   ✔ 93/93 cases passed (25 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (46.2 MB)
# Submitting: kotlin_solutions/554.brick-wall.kt
#   ✔ Accepted
#   ✔ 88/88 cases passed (55 ms)
#   ✔ Your runtime beats 9.09 % of kotlin submissions
#   ✔ Your memory usage beats 45.45 % of kotlin submissions (57.5 MB)
# Submitting: kotlin_solutions/556.next-greater-element-iii.kt
#   ✔ Accepted
#   ✔ 39/39 cases passed (20 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
#   ✔ Your memory usage beats 10 % of kotlin submissions (45.9 MB)
# Submitting: kotlin_solutions/557.reverse-words-in-a-string-iii.kt
#   ✔ Accepted
#   ✔ 29/29 cases passed (20 ms)
#   ✔ Your runtime beats 40.98 % of kotlin submissions
#   ✔ Your memory usage beats 26.23 % of kotlin submissions (47.3 MB)
# Submitting: kotlin_solutions/558.logical-or-of-two-binary-grids-represented-as-quad-trees.kt
#   ✔ Accepted
#   ✔ 61/61 cases passed (193 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (51.7 MB)
# Submitting: kotlin_solutions/559.maximum-depth-of-n-ary-tree.kt
#   ✔ Accepted
#   ✔ 38/38 cases passed (143 ms)
#   ✔ Your runtime beats 37.5 % of kotlin submissions
#   ✔ Your memory usage beats 59.38 % of kotlin submissions (47 MB)
# Submitting: kotlin_solutions/560.subarray-sum-equals-k.kt
#   ✔ Accepted
#   ✔ 93/93 cases passed (54 ms)
#   ✔ Your runtime beats 20.31 % of kotlin submissions
#   ✔ Your memory usage beats 43.67 % of kotlin submissions (53.2 MB)
# Submitting: kotlin_solutions/561.array-partition.kt
#   ✔ Accepted
#   ✔ 85/85 cases passed (70 ms)
#   ✔ Your runtime beats 12.5 % of kotlin submissions
#   ✔ Your memory usage beats 46.43 % of kotlin submissions (53.1 MB)
# Submitting: kotlin_solutions/563.binary-tree-tilt.kt
#   ✔ Accepted
#   ✔ 77/77 cases passed (26 ms)
#   ✔ Your runtime beats 7.14 % of kotlin submissions
#   ✔ Your memory usage beats 7.14 % of kotlin submissions (50.9 MB)
# Submitting: kotlin_solutions/564.find-the-closest-palindrome.kt
#   ✔ Accepted
#   ✔ 232/232 cases passed (29 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/565.array-nesting.kt
#   ✔ Accepted
#   ✔ 885/885 cases passed (81 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (74.7 MB)
# Submitting: kotlin_solutions/566.reshape-the-matrix.kt
#   ✔ Accepted
#   ✔ 57/57 cases passed (22 ms)
#   ✔ Your runtime beats 4 % of kotlin submissions
#   ✔ Your memory usage beats 8 % of kotlin submissions (56.5 MB)
# Submitting: kotlin_solutions/567.permutation-in-string.kt
#   ✔ Accepted
#   ✔ 110/110 cases passed (101 ms)
#   ✔ Your runtime beats 8.44 % of kotlin submissions
#   ✔ Your memory usage beats 14.35 % of kotlin submissions (48.2 MB)
# Submitting: kotlin_solutions/572.subtree-of-another-tree.kt
#   ✔ Accepted
#   ✔ 185/185 cases passed (4 ms)
#   ✔ Your runtime beats 78.24 % of kotlin submissions
#   ✔ Your memory usage beats 29.02 % of kotlin submissions (50.2 MB)
# Submitting: kotlin_solutions/575.distribute-candies.kt
#   ✔ Accepted
#   ✔ 206/206 cases passed (44 ms)
#   ✔ Your runtime beats 36.96 % of kotlin submissions
#   ✔ Your memory usage beats 23.91 % of kotlin submissions (59.5 MB)
# Submitting: kotlin_solutions/576.out-of-boundary-paths.kt
#   ✔ Accepted
#   ✔ 94/94 cases passed (29 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions/581.shortest-unsorted-continuous-subarray.kt
#   ✔ Accepted
#   ✔ 307/307 cases passed (44 ms)
#   ✔ Your runtime beats 9.09 % of kotlin submissions
#   ✔ Your memory usage beats 22.73 % of kotlin submissions (51.7 MB)
# Submitting: kotlin_solutions/583.delete-operation-for-two-strings.kt
#   ✔ Accepted
#   ✔ 1306/1306 cases passed (21 ms)
#   ✔ Your runtime beats 15.79 % of kotlin submissions
#   ✔ Your memory usage beats 78.95 % of kotlin submissions (45.7 MB)
# Submitting: kotlin_solutions/587.erect-the-fence.kt
#   ✔ Accepted
#   ✔ 88/88 cases passed (66 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (66.5 MB)
# Submitting: kotlin_solutions/589.n-ary-tree-preorder-traversal.kt
#   ✔ Accepted
#   ✔ 39/39 cases passed (183 ms)
#   ✔ Your runtime beats 39.13 % of kotlin submissions
#   ✔ Your memory usage beats 52.17 % of kotlin submissions (49.1 MB)
# Submitting: kotlin_solutions/590.n-ary-tree-postorder-traversal.kt
#   ✔ Accepted
#   ✔ 38/38 cases passed (171 ms)
#   ✔ Your runtime beats 53.33 % of kotlin submissions
#   ✔ Your memory usage beats 6.67 % of kotlin submissions (49.9 MB)
# Submitting: kotlin_solutions/591.tag-validator.kt
#   ✔ Accepted
#   ✔ 261/261 cases passed (37 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/592.fraction-addition-and-subtraction.kt
#   ✔ Accepted
#   ✔ 105/105 cases passed (40 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/593.valid-square.kt
#   ✔ Accepted
#   ✔ 256/256 cases passed (18 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (43.7 MB)
# Submitting: kotlin_solutions/594.longest-harmonious-subsequence.kt
# - Downloading longest-harmonious-subsequence
#   ✔ Accepted
#   ✔ 208/208 cases passed (88 ms)
#   ✔ Your runtime beats 9.26 % of kotlin submissions
#   ✔ Your memory usage beats 5.55 % of kotlin submissions (70 MB)
# Submitting: kotlin_solutions/598.range-addition-ii.kt
#   ✔ Accepted
#   ✔ 69/69 cases passed (3 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/599.minimum-index-sum-of-two-lists.kt
#   ✔ Accepted
#   ✔ 137/137 cases passed (47 ms)
#   ✔ Your runtime beats 17.95 % of kotlin submissions
#   ✔ Your memory usage beats 15.38 % of kotlin submissions (51.6 MB)
# Submitting: kotlin_solutions/600.non-negative-integers-without-consecutive-ones.kt
#   ✔ Accepted
#   ✔ 527/527 cases passed (8 ms)
#   ✔ Your runtime beats 63.64 % of kotlin submissions
#   ✔ Your memory usage beats 18.18 % of kotlin submissions (42.1 MB)
# Submitting: kotlin_solutions/605.can-place-flowers.kt
#   ✔ Accepted
#   ✔ 130/130 cases passed (17 ms)
#   ✔ Your runtime beats 7.48 % of kotlin submissions
#   ✔ Your memory usage beats 19.29 % of kotlin submissions (49.6 MB)
# Submitting: kotlin_solutions/606.construct-string-from-binary-tree.kt
#   ✔ Accepted
#   ✔ 160/160 cases passed (8 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/609.find-duplicate-file-in-system.kt
#   ✔ Accepted
#   ✔ 162/162 cases passed (49 ms)
#   ✔ Your runtime beats 66.67 % of kotlin submissions
#   ✔ Your memory usage beats 44.44 % of kotlin submissions (60.8 MB)
# Submitting: kotlin_solutions/611.valid-triangle-number.kt
#   ✔ Accepted
#   ✔ 241/241 cases passed (673 ms)
#   ✔ Your runtime beats 6.25 % of kotlin submissions
#   ✔ Your memory usage beats 6.25 % of kotlin submissions (68.4 MB)
# Submitting: kotlin_solutions/617.merge-two-binary-trees.kt
#   ✔ Accepted
#   ✔ 182/182 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 85.37 % of kotlin submissions (45.8 MB)
# Submitting: kotlin_solutions/621.task-scheduler.kt
# - Downloading task-scheduler
#   ✔ Accepted
#   ✔ 72/72 cases passed (31 ms)
#   ✔ Your runtime beats 73.03 % of kotlin submissions
#   ✔ Your memory usage beats 31.46 % of kotlin submissions (50.8 MB)
# Submitting: kotlin_solutions/622.design-circular-queue.kt
#   ✔ Accepted
#   ✔ 59/59 cases passed (17 ms)
#   ✔ Your runtime beats 90.14 % of kotlin submissions
#   ✔ Your memory usage beats 74.65 % of kotlin submissions (47.3 MB)
# Submitting: kotlin_solutions/623.add-one-row-to-tree.kt
#   ✔ Accepted
#   ✔ 109/109 cases passed (21 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/624.maximum-distance-in-arrays.kt
#   ✔ Accepted
#   ✔ 136/136 cases passed (45 ms)
#   ✔ Your runtime beats 23.53 % of kotlin submissions
#   ✔ Your memory usage beats 5.88 % of kotlin submissions (96.1 MB)
# Submitting: kotlin_solutions/628.maximum-product-of-three-numbers.kt
#   ✔ Accepted
#   ✔ 93/93 cases passed (74 ms)
#   ✔ Your runtime beats 7.69 % of kotlin submissions
#   ✔ Your memory usage beats 30.77 % of kotlin submissions (51.6 MB)
# Submitting: kotlin_solutions/629.k-inverse-pairs-array.kt
#   ✔ Accepted
#   ✔ 81/81 cases passed (953 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/630.course-schedule-iii.kt
#   ✔ Accepted
#   ✔ 97/97 cases passed (80 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
#   ✔ Your memory usage beats 30 % of kotlin submissions (73.5 MB)
# Submitting: kotlin_solutions/632.smallest-range-covering-elements-from-k-lists.kt
#   ✔ Accepted
#   ✔ 94/94 cases passed (275 ms)
#   ✔ Your runtime beats 7.32 % of kotlin submissions
#   ✔ Your memory usage beats 7.32 % of kotlin submissions (97.4 MB)
# Submitting: kotlin_solutions/633.sum-of-square-numbers.kt
#   ✔ Accepted
#   ✔ 127/127 cases passed (31 ms)
#   ✔ Your runtime beats 26.32 % of kotlin submissions
#   ✔ Your memory usage beats 10.53 % of kotlin submissions (45.5 MB)
# Submitting: kotlin_solutions/636.exclusive-time-of-functions.kt
#   ✔ Accepted
#   ✔ 120/120 cases passed (50 ms)
#   ✔ Your runtime beats 16.22 % of kotlin submissions
#   ✔ Your memory usage beats 8.11 % of kotlin submissions (50 MB)
# Submitting: kotlin_solutions/637.average-of-levels-in-binary-tree.kt
#   ✔ Accepted
#   ✔ 66/66 cases passed (28 ms)
#   ✔ Your runtime beats 9.18 % of kotlin submissions
#   ✔ Your memory usage beats 6.12 % of kotlin submissions (51.5 MB)
# Submitting: kotlin_solutions/638.shopping-offers.kt
#   ✔ Accepted
#   ✔ 65/65 cases passed (33 ms)
#   ✔ Your runtime beats 44.44 % of kotlin submissions
#   ✔ Your memory usage beats 55.56 % of kotlin submissions (50.3 MB)
# Submitting: kotlin_solutions/639.decode-ways-ii.kt
#   ✔ Accepted
#   ✔ 218/218 cases passed (385 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/640.solve-the-equation.kt
#   ✔ Accepted
#   ✔ 59/59 cases passed (15 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (42.8 MB)
# Submitting: kotlin_solutions/641.design-circular-deque.kt
#   ✔ Accepted
#   ✔ 54/54 cases passed (18 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 87.5 % of kotlin submissions (47.7 MB)
# Submitting: kotlin_solutions/643.maximum-average-subarray-i.kt
#   ✔ Accepted
#   ✔ 128/128 cases passed (60 ms)
#   ✔ Your runtime beats 9.66 % of kotlin submissions
#   ✔ Your memory usage beats 5.17 % of kotlin submissions (66.5 MB)
# Submitting: kotlin_solutions/645.set-mismatch.kt
#   ✔ Accepted
#   ✔ 49/49 cases passed (28 ms)
#   ✔ Your runtime beats 31.2 % of kotlin submissions
#   ✔ Your memory usage beats 16.54 % of kotlin submissions (50.8 MB)
# Submitting: kotlin_solutions/646.maximum-length-of-pair-chain.kt
#   ✔ Accepted
#   ✔ 206/206 cases passed (27 ms)
#   ✔ Your runtime beats 53.85 % of kotlin submissions
#   ✔ Your memory usage beats 76.92 % of kotlin submissions (51.1 MB)
# Submitting: kotlin_solutions/647.palindromic-substrings.kt
#   ✔ Accepted
#   ✔ 132/132 cases passed (46 ms)
#   ✔ Your runtime beats 18.31 % of kotlin submissions
#   ✔ Your memory usage beats 10.56 % of kotlin submissions (48 MB)
# Submitting: kotlin_solutions/648.replace-words.kt
#   ✔ Accepted
#   ✔ 130/130 cases passed (98 ms)
#   ✔ Your runtime beats 17.39 % of kotlin submissions
#   ✔ Your memory usage beats 43.48 % of kotlin submissions (61.7 MB)
# Submitting: kotlin_solutions/649.dota-2-senate.kt
#   ✔ Accepted
#   ✔ 83/83 cases passed (23 ms)
#   ✔ Your runtime beats 85.96 % of kotlin submissions
#   ✔ Your memory usage beats 70.18 % of kotlin submissions (46.5 MB)
# Submitting: kotlin_solutions/650.2-keys-keyboard.kt
#   ✔ Accepted
#   ✔ 126/126 cases passed (19 ms)
#   ✔ Your runtime beats 22.22 % of kotlin submissions
#   ✔ Your memory usage beats 22.22 % of kotlin submissions (42.8 MB)
# Submitting: kotlin_solutions/652.find-duplicate-subtrees.kt
#   ✔ Accepted
#   ✔ 175/175 cases passed (109 ms)
#   ✔ Your runtime beats 13.64 % of kotlin submissions
#   ✔ Your memory usage beats 63.64 % of kotlin submissions (53.2 MB)
# Submitting: kotlin_solutions/653.two-sum-iv-input-is-a-bst.kt
#   ✔ Accepted
#   ✔ 423/423 cases passed (5 ms)
#   ✔ Your runtime beats 51.02 % of kotlin submissions
#   ✔ Your memory usage beats 97.96 % of kotlin submissions (46.2 MB)
# Submitting: kotlin_solutions/654.maximum-binary-tree.kt
#   ✔ Accepted
#   ✔ 107/107 cases passed (45 ms)
#   ✔ Your runtime beats 7.69 % of kotlin submissions
#   ✔ Your memory usage beats 7.69 % of kotlin submissions (53.2 MB)
# Submitting: kotlin_solutions/655.print-binary-tree.kt
#   ✔ Accepted
#   ✔ 73/73 cases passed (12 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (45.4 MB)
# Submitting: kotlin_solutions/657.robot-return-to-origin.kt
#   ✔ Accepted
#   ✔ 77/77 cases passed (22 ms)
#   ✔ Your runtime beats 5.77 % of kotlin submissions
#   ✔ Your memory usage beats 5.77 % of kotlin submissions (46.7 MB)
# Submitting: kotlin_solutions/658.find-k-closest-elements.kt
# - Downloading find-k-closest-elements
#   ✔ Accepted
#   ✔ 70/70 cases passed (40 ms)
#   ✔ Your runtime beats 29.88 % of kotlin submissions
#   ✔ Your memory usage beats 51.72 % of kotlin submissions (50.7 MB)
# Submitting: kotlin_solutions/659.split-array-into-consecutive-subsequences.kt
#   ✔ Accepted
#   ✔ 187/187 cases passed (38 ms)
#   ✔ Your runtime beats 75 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions/661.image-smoother.kt
#   ✔ Accepted
#   ✔ 203/203 cases passed (108 ms)
#   ✔ Your runtime beats 30 % of kotlin submissions
#   ✔ Your memory usage beats 10 % of kotlin submissions (68.8 MB)
# Submitting: kotlin_solutions/662.maximum-width-of-binary-tree.kt
#   ✔ Accepted
#   ✔ 117/117 cases passed (30 ms)
#   ✔ Your runtime beats 8.57 % of kotlin submissions
#   ✔ Your memory usage beats 5.71 % of kotlin submissions (50.5 MB)
# Submitting: kotlin_solutions/664.strange-printer.kt
#   ✔ Accepted
#   ✔ 200/200 cases passed (106 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (55.2 MB)
# Submitting: kotlin_solutions/665.non-decreasing-array.kt
#   ✔ Accepted
#   ✔ 335/335 cases passed (31 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/667.beautiful-arrangement-ii.kt
#   ✔ Accepted
#   ✔ 70/70 cases passed (1 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
# [WARN] Failed to get memory percentile.

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-02-14 19:03:21
