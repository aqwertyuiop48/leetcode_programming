# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME')
    user_cookie = userdata.get('LEETCODE_TOKEN')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME'] = user_name
    os.environ['LEETCODE_TOKEN'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME" "$LEETCODE_TOKEN" | leetcode user -c

# %%
# %%bash
#
#
# # top 100 answers
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v java_solutions_1/*.java | sed -n '1,$p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 8
# done
# Out:
# Submitting: java_solutions_1/95.unique-binary-search-trees-ii.java
# - Downloading problems
# - Downloading unique-binary-search-trees-ii
#   ✔ Accepted
#   ✔ 8/8 cases passed (25 ms)
#   ✔ Your runtime beats 1.95 % of java submissions
#   ✔ Your memory usage beats 5.08 % of java submissions (53.3 MB)
# Submitting: java_solutions_1/98.validate-binary-search-tree.java
# - Downloading validate-binary-search-tree
#   ✔ Accepted
#   ✔ 86/86 cases passed (4 ms)
#   ✔ Your runtime beats 1.97 % of java submissions
#   ✔ Your memory usage beats 5.27 % of java submissions (46.6 MB)
# Submitting: java_solutions_1/99.recover-binary-search-tree.java
# - Downloading recover-binary-search-tree
#   ✔ Accepted
#   ✔ 1919/1919 cases passed (27 ms)
#   ✔ Your runtime beats 1.95 % of java submissions
#   ✔ Your memory usage beats 12.27 % of java submissions (47.5 MB)
# Submitting: java_solutions_1/105.construct-binary-tree-from-preorder-and-inorder-traversal.java
# - Downloading construct-binary-tree-from-preorder-and-inorder-traversal
#   ✔ Accepted
#   ✔ 203/203 cases passed (45 ms)
#   ✔ Your runtime beats 5.78 % of java submissions
#   ✔ Your memory usage beats 5.15 % of java submissions (63.2 MB)
# Submitting: java_solutions_1/106.construct-binary-tree-from-inorder-and-postorder-traversal.java
# - Downloading construct-binary-tree-from-inorder-and-postorder-traversal
#   ✔ Accepted
#   ✔ 202/202 cases passed (45 ms)
#   ✔ Your runtime beats 4.34 % of java submissions
#   ✔ Your memory usage beats 8.83 % of java submissions (63.3 MB)
# Submitting: java_solutions_1/108.convert-sorted-array-to-binary-search-tree.java
# - Downloading convert-sorted-array-to-binary-search-tree
#   ✔ Accepted
#   ✔ 31/31 cases passed (9 ms)
#   ✔ Your runtime beats 0.51 % of java submissions
#   ✔ Your memory usage beats 11.2 % of java submissions (46.7 MB)
# Submitting: java_solutions_1/109.convert-sorted-list-to-binary-search-tree.java
# - Downloading convert-sorted-list-to-binary-search-tree
#   ✔ Accepted
#   ✔ 32/32 cases passed (17 ms)
#   ✔ Your runtime beats 1.07 % of java submissions
#   ✔ Your memory usage beats 7.38 % of java submissions (49.1 MB)
# Submitting: java_solutions_1/113.path-sum-ii.java
# - Downloading path-sum-ii
#   ✔ Accepted
#   ✔ 115/115 cases passed (24 ms)
#   ✔ Your runtime beats 2.95 % of java submissions
#   ✔ Your memory usage beats 5.06 % of java submissions (54.6 MB)
# Submitting: java_solutions_1/130.surrounded-regions.java
# - Downloading surrounded-regions
#   ✔ Accepted
#   ✔ 59/59 cases passed (28 ms)
#   ✔ Your runtime beats 5.03 % of java submissions
#   ✔ Your memory usage beats 5.08 % of java submissions (54.7 MB)
# Submitting: java_solutions_1/131.palindrome-partitioning.java
# - Downloading palindrome-partitioning
#   ✔ Accepted
#   ✔ 32/32 cases passed (179 ms)
#   ✔ Your runtime beats 5.63 % of java submissions
#   ✔ Your memory usage beats 5.19 % of java submissions (71.5 MB)
# Submitting: java_solutions_1/133.clone-graph.java
# - Downloading clone-graph
#   ✔ Accepted
#   ✔ 22/22 cases passed (41 ms)
#   ✔ Your runtime beats 6.75 % of java submissions
#   ✔ Your memory usage beats 8.21 % of java submissions (50.9 MB)
# Submitting: java_solutions_1/155.min-stack.java
# - Downloading min-stack
#   ✔ Accepted
#   ✔ 44/44 cases passed (34 ms)
#   ✔ Your runtime beats 5.72 % of java submissions
#   ✔ Your memory usage beats 5.03 % of java submissions (102.4 MB)
# Submitting: java_solutions_1/166.fraction-to-recurring-decimal.java
# - Downloading fraction-to-recurring-decimal
#   ✔ Accepted
#   ✔ 41/41 cases passed (18 ms)
#   ✔ Your runtime beats 2.88 % of java submissions
#   ✔ Your memory usage beats 10.54 % of java submissions (50.4 MB)
# Submitting: java_solutions_1/173.binary-search-tree-iterator.java
# - Downloading binary-search-tree-iterator
#   ✔ Accepted
#   ✔ 61/61 cases passed (36 ms)
#   ✔ Your runtime beats 2.91 % of java submissions
#   ✔ Your memory usage beats 7.28 % of java submissions (50.5 MB)
# Submitting: java_solutions_1/207.course-schedule.java
# - Downloading course-schedule
#   ✔ Accepted
#   ✔ 54/54 cases passed (28 ms)
#   ✔ Your runtime beats 5.08 % of java submissions
#   ✔ Your memory usage beats 5.72 % of java submissions (56.9 MB)
# Submitting: java_solutions_1/208.implement-trie-prefix-tree.java
# - Downloading implement-trie-prefix-tree
#   ✔ Accepted
#   ✔ 16/16 cases passed (56 ms)
#   ✔ Your runtime beats 5.53 % of java submissions
#   ✔ Your memory usage beats 15.06 % of java submissions (63.1 MB)
# Submitting: java_solutions_1/210.course-schedule-ii.java
# - Downloading course-schedule-ii
#   ✔ Accepted
#   ✔ 47/47 cases passed (30 ms)
#   ✔ Your runtime beats 5.68 % of java submissions
#   ✔ Your memory usage beats 7.64 % of java submissions (57 MB)
# Submitting: java_solutions_1/211.design-add-and-search-words-data-structure.java
# - Downloading design-add-and-search-words-data-structure
#   ✔ Accepted
#   ✔ 30/30 cases passed (457 ms)
#   ✔ Your runtime beats 5.02 % of java submissions
#   ✔ Your memory usage beats 5.06 % of java submissions (284.6 MB)
# Submitting: java_solutions_1/221.maximal-square.java
# - Downloading maximal-square
#   ✔ Accepted
#   ✔ 81/81 cases passed (15 ms)
#   ✔ Your runtime beats 7.34 % of java submissions
#   ✔ Your memory usage beats 16.45 % of java submissions (72.2 MB)
# Submitting: java_solutions_1/223.rectangle-area.java
# - Downloading rectangle-area
#   ✔ Accepted
#   ✔ 3080/3080 cases passed (1 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 64.41 % of java submissions (44.2 MB)
# Submitting: java_solutions_1/225.implement-stack-using-queues.java
# - Downloading implement-stack-using-queues
#   ✔ Accepted
#   ✔ 20/20 cases passed (3 ms)
#   ✔ Your runtime beats 0.1 % of java submissions
#   ✔ Your memory usage beats 7.87 % of java submissions (43.1 MB)
# Submitting: java_solutions_1/227.basic-calculator-ii.java
# - Downloading basic-calculator-ii
#   ✔ Accepted
#   ✔ 111/111 cases passed (16 ms)
#   ✔ Your runtime beats 80.58 % of java submissions
#   ✔ Your memory usage beats 23.13 % of java submissions (48.6 MB)
# Submitting: java_solutions_1/236.lowest-common-ancestor-of-a-binary-tree.java
# - Downloading lowest-common-ancestor-of-a-binary-tree
#   ✔ Accepted
#   ✔ 33/33 cases passed (103 ms)
#   ✔ Your runtime beats 5.18 % of java submissions
#   ✔ Your memory usage beats 5.14 % of java submissions (203.5 MB)
# Submitting: java_solutions_1/264.ugly-number-ii.java
# - Downloading ugly-number-ii
#   ✔ Accepted
#   ✔ 596/596 cases passed (122 ms)
#   ✔ Your runtime beats 5.08 % of java submissions
#   ✔ Your memory usage beats 5.91 % of java submissions (47 MB)
# Submitting: java_solutions_1/289.game-of-life.java
# - Downloading game-of-life
#   ✔ Accepted
#   ✔ 23/23 cases passed (22 ms)
#   ✔ Your runtime beats 2.43 % of java submissions
#   ✔ Your memory usage beats 11.06 % of java submissions (50.8 MB)
# Submitting: java_solutions_1/299.bulls-and-cows.java
# - Downloading bulls-and-cows
#   ✔ Accepted
#   ✔ 152/152 cases passed (37 ms)
#   ✔ Your runtime beats 5.19 % of java submissions
#   ✔ Your memory usage beats 5.3 % of java submissions (53.2 MB)
# Submitting: java_solutions_1/304.range-sum-query-2d-immutable.java
# - Downloading range-sum-query-2d-immutable
#   ✔ Accepted
#   ✔ 22/22 cases passed (111 ms)
#   ✔ Your runtime beats 28.23 % of java submissions
#   ✔ Your memory usage beats 5.37 % of java submissions (145.6 MB)
# Submitting: java_solutions_1/306.additive-number.java
# - Downloading additive-number
#   ✔ Accepted
#   ✔ 47/47 cases passed (16 ms)
#   ✔ Your runtime beats 10.97 % of java submissions
#   ✔ Your memory usage beats 7.62 % of java submissions (44.3 MB)
# Submitting: java_solutions_1/307.range-sum-query-mutable.java
# - Downloading range-sum-query-mutable
#   ✔ Accepted
#   ✔ 16/16 cases passed (274 ms)
#   ✔ Your runtime beats 5.36 % of java submissions
#   ✔ Your memory usage beats 5.19 % of java submissions (146.6 MB)
# Submitting: java_solutions_1/309.best-time-to-buy-and-sell-stock-with-cooldown.java
# - Downloading best-time-to-buy-and-sell-stock-with-cooldown
#   ✔ Accepted
#   ✔ 210/210 cases passed (9 ms)
#   ✔ Your runtime beats 7.09 % of java submissions
#   ✔ Your memory usage beats 5.84 % of java submissions (44 MB)
# Submitting: java_solutions_1/310.minimum-height-trees.java
# - Downloading minimum-height-trees
#   ✔ Accepted
#   ✔ 71/71 cases passed (115 ms)
#   ✔ Your runtime beats 5.07 % of java submissions
#   ✔ Your memory usage beats 6.51 % of java submissions (78 MB)
# Submitting: java_solutions_1/313.super-ugly-number.java
# - Downloading super-ugly-number
#   ✔ Accepted
#   ✔ 87/87 cases passed (391 ms)
#   ✔ Your runtime beats 5.12 % of java submissions
#   ✔ Your memory usage beats 5.43 % of java submissions (55 MB)
# Submitting: java_solutions_1/316.remove-duplicate-letters.java
# - Downloading remove-duplicate-letters
#   ✔ Accepted
#   ✔ 290/290 cases passed (28 ms)
#   ✔ Your runtime beats 6.56 % of java submissions
#   ✔ Your memory usage beats 5.29 % of java submissions (53.3 MB)
# Submitting: java_solutions_1/322.coin-change.java
# - Downloading coin-change
#   ✔ Accepted
#   ✔ 189/189 cases passed (205 ms)
#   ✔ Your runtime beats 5.04 % of java submissions
#   ✔ Your memory usage beats 5.17 % of java submissions (53.2 MB)
# Submitting: java_solutions_1/324.wiggle-sort-ii.java
# - Downloading wiggle-sort-ii
#   ✔ Accepted
#   ✔ 52/52 cases passed (15 ms)
#   ✔ Your runtime beats 9.87 % of java submissions
#   ✔ Your memory usage beats 5.92 % of java submissions (55.6 MB)
# Submitting: java_solutions_1/337.house-robber-iii.java
# - Downloading house-robber-iii
#   ✔ Accepted
#   ✔ 124/124 cases passed (12 ms)
#   ✔ Your runtime beats 4.09 % of java submissions
#   ✔ Your memory usage beats 5.09 % of java submissions (47.6 MB)
# Submitting: java_solutions_1/368.largest-divisible-subset.java
# - Downloading largest-divisible-subset
#   ✔ Accepted
#   ✔ 49/49 cases passed (73 ms)
#   ✔ Your runtime beats 5.12 % of java submissions
#   ✔ Your memory usage beats 5.52 % of java submissions (53.4 MB)
# Submitting: java_solutions_1/373.find-k-pairs-with-smallest-sums.java
# - Downloading find-k-pairs-with-smallest-sums
#   ✔ Accepted
#   ✔ 32/32 cases passed (97 ms)
#   ✔ Your runtime beats 5.52 % of java submissions
#   ✔ Your memory usage beats 22.52 % of java submissions (136.5 MB)
# Submitting: java_solutions_1/375.guess-number-higher-or-lower-ii.java
# - Downloading guess-number-higher-or-lower-ii
#   ✔ Accepted
#   ✔ 27/27 cases passed (117 ms)
#   ✔ Your runtime beats 5.23 % of java submissions
#   ✔ Your memory usage beats 5.58 % of java submissions (53 MB)
# Submitting: java_solutions_1/376.wiggle-subsequence.java
# - Downloading wiggle-subsequence
#   ✔ Accepted
#   ✔ 32/32 cases passed (4 ms)
#   ✔ Your runtime beats 17.24 % of java submissions
#   ✔ Your memory usage beats 40.79 % of java submissions (43.1 MB)
# Submitting: java_solutions_1/377.combination-sum-iv.java
# - Downloading combination-sum-iv
#   ✔ Accepted
#   ✔ 17/17 cases passed (19 ms)
#   ✔ Your runtime beats 5.89 % of java submissions
#   ✔ Your memory usage beats 5.5 % of java submissions (45.5 MB)
# Submitting: java_solutions_1/378.kth-smallest-element-in-a-sorted-matrix.java
# - Downloading kth-smallest-element-in-a-sorted-matrix
#   ✔ Accepted
#   ✔ 87/87 cases passed (28 ms)
#   ✔ Your runtime beats 12.06 % of java submissions
#   ✔ Your memory usage beats 47.53 % of java submissions (51.6 MB)
# Submitting: java_solutions_1/380.insert-delete-getrandom-o1.java
# - Downloading insert-delete-getrandom-o1
#   ✔ Accepted
#   ✔ 21/21 cases passed (50 ms)
#   ✔ Your runtime beats 14.06 % of java submissions
#   ✔ Your memory usage beats 5.11 % of java submissions (105 MB)
# Submitting: java_solutions_1/382.linked-list-random-node.java
# - Downloading linked-list-random-node
#   ✔ Accepted
#   ✔ 8/8 cases passed (15 ms)
#   ✔ Your runtime beats 7.09 % of java submissions
#   ✔ Your memory usage beats 84.58 % of java submissions (48 MB)
# Submitting: java_solutions_1/384.shuffle-an-array.java
# - Downloading shuffle-an-array
#   ✔ Accepted
#   ✔ 8/8 cases passed (90 ms)
#   ✔ Your runtime beats 5.5 % of java submissions
#   ✔ Your memory usage beats 10.91 % of java submissions (58.3 MB)
# Submitting: java_solutions_1/386.lexicographical-numbers.java
# - Downloading lexicographical-numbers
#   ✔ Accepted
#   ✔ 27/27 cases passed (69 ms)
#   ✔ Your runtime beats 6.68 % of java submissions
#   ✔ Your memory usage beats 5.04 % of java submissions (56.5 MB)
# Submitting: java_solutions_1/394.decode-string.java
# - Downloading decode-string
#   ✔ Accepted
#   ✔ 34/34 cases passed (20 ms)
#   ✔ Your runtime beats 2.82 % of java submissions
#   ✔ Your memory usage beats 5.85 % of java submissions (50.7 MB)
# Submitting: java_solutions_1/398.random-pick-index.java
# - Downloading random-pick-index
#   ✔ Accepted
#   ✔ 17/17 cases passed (1974 ms)
#   ✔ Your runtime beats 5.39 % of java submissions
#   ✔ Your memory usage beats 56.33 % of java submissions (61.6 MB)
# Submitting: java_solutions_1/416.partition-equal-subset-sum.java
# - Downloading partition-equal-subset-sum
#   ✔ Accepted
#   ✔ 147/147 cases passed (109 ms)
#   ✔ Your runtime beats 10.01 % of java submissions
#   ✔ Your memory usage beats 40.15 % of java submissions (52.5 MB)
# Submitting: java_solutions_1/424.longest-repeating-character-replacement.java
# - Downloading longest-repeating-character-replacement
#   ✔ Accepted
#   ✔ 50/50 cases passed (202 ms)
#   ✔ Your runtime beats 5.01 % of java submissions
#   ✔ Your memory usage beats 7.04 % of java submissions (53.4 MB)
# Submitting: java_solutions_1/430.flatten-a-multilevel-doubly-linked-list.java
# - Downloading flatten-a-multilevel-doubly-linked-list
#   ✔ Accepted
#   ✔ 26/26 cases passed (17 ms)
#   ✔ Your runtime beats 0.95 % of java submissions
#   ✔ Your memory usage beats 5.8 % of java submissions (52.4 MB)
# Submitting: java_solutions_1/433.minimum-genetic-mutation.java
# - Downloading minimum-genetic-mutation
#   ✔ Accepted
#   ✔ 20/20 cases passed (23 ms)
#   ✔ Your runtime beats 8.73 % of java submissions
#   ✔ Your memory usage beats 8 % of java submissions (50.7 MB)
# Submitting: java_solutions_1/435.non-overlapping-intervals.java
# - Downloading non-overlapping-intervals
#   ✔ Accepted
#   ✔ 60/60 cases passed (56 ms)
#   ✔ Your runtime beats 13.17 % of java submissions
#   ✔ Your memory usage beats 5.28 % of java submissions (117.3 MB)
# Submitting: java_solutions_1/437.path-sum-iii.java
# - Downloading path-sum-iii
#   ✔ Accepted
#   ✔ 130/130 cases passed (35 ms)
#   ✔ Your runtime beats 5.67 % of java submissions
#   ✔ Your memory usage beats 8.08 % of java submissions (54.9 MB)
# Submitting: java_solutions_1/438.find-all-anagrams-in-a-string.java
# - Downloading find-all-anagrams-in-a-string
#   ✔ Accepted
#   ✔ 65/65 cases passed (69 ms)
#   ✔ Your runtime beats 18.55 % of java submissions
#   ✔ Your memory usage beats 6.02 % of java submissions (53.1 MB)
# Submitting: java_solutions_1/442.find-all-duplicates-in-an-array.java
# - Downloading find-all-duplicates-in-an-array
#   ✔ Accepted
#   ✔ 29/29 cases passed (143 ms)
#   ✔ Your runtime beats 5.66 % of java submissions
#   ✔ Your memory usage beats 5.36 % of java submissions (76.7 MB)
# Submitting: java_solutions_1/443.string-compression.java
# - Downloading string-compression
#   ✔ Accepted
#   ✔ 77/77 cases passed (20 ms)
#   ✔ Your runtime beats 5.88 % of java submissions
#   ✔ Your memory usage beats 5.14 % of java submissions (53.3 MB)
# Submitting: java_solutions_1/445.add-two-numbers-ii.java
# - Downloading add-two-numbers-ii
#   ✔ Accepted
#   ✔ 1563/1563 cases passed (37 ms)
#   ✔ Your runtime beats 2.97 % of java submissions
#   ✔ Your memory usage beats 5.07 % of java submissions (53.3 MB)
# Submitting: java_solutions_1/449.serialize-and-deserialize-bst.java
# - Downloading serialize-and-deserialize-bst
#   ✔ Accepted
#   ✔ 62/62 cases passed (47 ms)
#   ✔ Your runtime beats 5.1 % of java submissions
#   ✔ Your memory usage beats 6.57 % of java submissions (55.1 MB)
# Submitting: java_solutions_1/450.delete-node-in-a-bst.java
# - Downloading delete-node-in-a-bst
#   ✔ Accepted
#   ✔ 95/95 cases passed (8 ms)
#   ✔ Your runtime beats 0.23 % of java submissions
#   ✔ Your memory usage beats 5.13 % of java submissions (48.3 MB)
# Submitting: java_solutions_1/451.sort-characters-by-frequency.java
# - Downloading sort-characters-by-frequency
#   ✔ Accepted
#   ✔ 33/33 cases passed (33 ms)
#   ✔ Your runtime beats 9.67 % of java submissions
#   ✔ Your memory usage beats 64.28 % of java submissions (46.5 MB)
# Submitting: java_solutions_1/452.minimum-number-of-arrows-to-burst-balloons.java
# - Downloading minimum-number-of-arrows-to-burst-balloons
#   ✔ Accepted
#   ✔ 50/50 cases passed (62 ms)
#   ✔ Your runtime beats 7.3 % of java submissions
#   ✔ Your memory usage beats 5.08 % of java submissions (100.5 MB)
# Submitting: java_solutions_1/454.4sum-ii.java
# - Downloading 4sum-ii
#   ✔ Accepted
#   ✔ 133/133 cases passed (176 ms)
#   ✔ Your runtime beats 5.08 % of java submissions
#   ✔ Your memory usage beats 6.96 % of java submissions (53.1 MB)
# Submitting: java_solutions_1/456.132-pattern.java
# - Downloading 132-pattern
#   ✔ Accepted
#   ✔ 109/109 cases passed (289 ms)
#   ✔ Your runtime beats 5.43 % of java submissions
#   ✔ Your memory usage beats 5.25 % of java submissions (110.2 MB)
# Submitting: java_solutions_1/464.can-i-win.java
# - Downloading can-i-win
#   ✔ Accepted
#   ✔ 58/58 cases passed (2023 ms)
#   ✔ Your runtime beats 5.02 % of java submissions
#   ✔ Your memory usage beats 5.02 % of java submissions (121.6 MB)
# Submitting: java_solutions_1/467.unique-substrings-in-wraparound-string.java
# - Downloading unique-substrings-in-wraparound-string
#   ✔ Accepted
#   ✔ 82/82 cases passed (63 ms)
#   ✔ Your runtime beats 5.14 % of java submissions
#   ✔ Your memory usage beats 6.51 % of java submissions (47.5 MB)
# Submitting: java_solutions_1/473.matchsticks-to-square.java
# - Downloading matchsticks-to-square
#   ✔ Accepted
#   ✔ 195/195 cases passed (205 ms)
#   ✔ Your runtime beats 13.03 % of java submissions
#   ✔ Your memory usage beats 5.88 % of java submissions (53.6 MB)
# Submitting: java_solutions_1/474.ones-and-zeroes.java
# - Downloading ones-and-zeroes
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 9: error: array required, but int found
#   ✘ Error: Line 9: error: array required, but int found
#         return java.util.stream.Stream.of(new int[m + 1][n + 1]).peek(dp -> java.util.Arrays.stream(strs).map(s -> new int[]{(int) s.chars().filter(c -> c == '0').count(), (int) s.chars().filter(c -> c == '1').count()}).forEach(counts -> java.util.stream.IntStream.iterate(m, i -> i >= counts[0], i -> i - 1).forEach(i -> java.util.stream.IntStream.iterate(n, j -> j >= counts[1], j -> j - 1).forEach(j -> dp[i][j] = Math.max(dp[i][j], dp[i - counts[0]][j - counts[1]] + 1))))).map(dp -> dp[m][n]).findFirst().get();
#                                                                                                                                                                                                                                                                                                                                                                                                                            ^
# Line 9: error: array required, but int found
#         return java.util.stream.Stream.of(new int[m + 1][n + 1]).peek(dp -> java.util.Arrays.stream(strs).map(s -> new int[]{(int) s.chars().filter(c -> c == '0').count(), (int) s.chars().filter(c -> c == '1').count()}).forEach(counts -> java.util.stream.IntStream.iterate(m, i -> i >= counts[0], i -> i - 1).forEach(i -> java.util.stream.IntStream.iterate(n, j -> j >= counts[1], j -> j - 1).forEach(j -> dp[i][j] = Math.max(dp[i][j], dp[i - counts[0]][j - counts[1]] + 1))))).map(dp -> dp[m][n]).findFirst().get();
#                                                                                                                                                                                                                                                                                                                                                                                                                                                ^
# Line 9: error: array required, but int found
#         return java.util.stream.Stream.of(new int[m + 1][n + 1]).peek(dp -> java.util.Arrays.stream(strs).map(s -> new int[]{(int) s.chars().filter(c -> c == '0').count(), (int) s.chars().filter(c -> c == '1').count()}).forEach(counts -> java.util.stream.IntStream.iterate(m, i -> i >= counts[0], i -> i - 1).forEach(i -> java.util.stream.IntStream.iterate(n, j -> j >= counts[1], j -> j - 1).forEach(j -> dp[i][j] = Math.max(dp[i][j], dp[i - counts[0]][j - counts[1]] + 1))))).map(dp -> dp[m][n]).findFirst().get();
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ^
# Line 9: error: array required, but int found
#         return java.util.stream.Stream.of(new int[m + 1][n + 1]).peek(dp -> java.util.Arrays.stream(strs).map(s -> new int[]{(int) s.chars().filter(c -> c == '0').count(), (int) s.chars().filter(c -> c == '1').count()}).forEach(counts -> java.util.stream.IntStream.iterate(m, i -> i >= counts[0], i -> i - 1).forEach(i -> java.util.stream.IntStream.iterate(n, j -> j >= counts[1], j -> j - 1).forEach(j -> dp[i][j] = Math.max(dp[i][j], dp[i - counts[0]][j - counts[1]] + 1))))).map(dp -> dp[m][n]).findFirst().get();
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ^
# Line 9: error: incompatible types: Object cannot be converted to int
#         return java.util.stream.Stream.of(new int[m + 1][n + 1]).peek(dp -> java.util.Arrays.stream(strs).map(s -> new int[]{(int) s.chars().filter(c -> c == '0').count(), (int) s.chars().filter(c -> c == '1').count()}).forEach(counts -> java.util.stream.IntStream.iterate(m, i -> i >= counts[0], i -> i - 1).forEach(i -> java.util.stream.IntStream.iterate(n, j -> j >= counts[1], j -> j - 1).forEach(j -> dp[i][j] = Math.max(dp[i][j], dp[i - counts[0]][j - counts[1]] + 1))))).map(dp -> dp[m][n]).findFirst().get();
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ^
# 5 errors
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: java_solutions_1/495.teemo-attacking.java
# - Downloading teemo-attacking
#   ✔ Accepted
#   ✔ 40/40 cases passed (6 ms)
#   ✔ Your runtime beats 1.77 % of java submissions
#   ✔ Your memory usage beats 88.87 % of java submissions (48.1 MB)
# Submitting: java_solutions_1/496.next-greater-element-i.java
# - Downloading next-greater-element-i
#   ✔ Accepted
#   ✔ 17/17 cases passed (20 ms)
#   ✔ Your runtime beats 5.52 % of java submissions
#   ✔ Your memory usage beats 11.11 % of java submissions (52.9 MB)
# Submitting: java_solutions_1/498.diagonal-traverse.java
# - Downloading diagonal-traverse
#   ✔ Accepted
#   ✔ 33/33 cases passed (21 ms)
#   ✔ Your runtime beats 5.55 % of java submissions
#   ✔ Your memory usage beats 89.47 % of java submissions (47.7 MB)
# Submitting: java_solutions_1/501.find-mode-in-binary-search-tree.java
# - Downloading find-mode-in-binary-search-tree
#   ✔ Accepted
#   ✔ 24/24 cases passed (31 ms)
#   ✔ Your runtime beats 5.2 % of java submissions
#   ✔ Your memory usage beats 6 % of java submissions (55.1 MB)
# Submitting: java_solutions_1/502.ipo.java
# - Downloading ipo
#   ✔ Accepted
#   ✔ 40/40 cases passed (284 ms)
#   ✔ Your runtime beats 5.08 % of java submissions
#   ✔ Your memory usage beats 97.59 % of java submissions (125.4 MB)
# Submitting: java_solutions_1/503.next-greater-element-ii.java
# - Downloading next-greater-element-ii
#   ✔ Accepted
#   ✔ 223/223 cases passed (116 ms)
#   ✔ Your runtime beats 6.09 % of java submissions
#   ✔ Your memory usage beats 6 % of java submissions (53.9 MB)
# Submitting: java_solutions_1/506.relative-ranks.java
# - Downloading relative-ranks
#   ✔ Accepted
#   ✔ 18/18 cases passed (22 ms)
#   ✔ Your runtime beats 11.57 % of java submissions
#   ✔ Your memory usage beats 9.19 % of java submissions (53.4 MB)
# Submitting: java_solutions_1/508.most-frequent-subtree-sum.java
# - Downloading most-frequent-subtree-sum
#   ✔ Accepted
#   ✔ 58/58 cases passed (24 ms)
#   ✔ Your runtime beats 5.09 % of java submissions
#   ✔ Your memory usage beats 5.42 % of java submissions (52.9 MB)
# Submitting: java_solutions_1/513.find-bottom-left-tree-value.java
# - Downloading find-bottom-left-tree-value
#   ✔ Accepted
#   ✔ 79/79 cases passed (25 ms)
#   ✔ Your runtime beats 13.05 % of java submissions
#   ✔ Your memory usage beats 5.62 % of java submissions (47.4 MB)
# Submitting: java_solutions_1/515.find-largest-value-in-each-tree-row.java
# - Downloading find-largest-value-in-each-tree-row
#   ✔ Accepted
#   ✔ 78/78 cases passed (24 ms)
#   ✔ Your runtime beats 3.34 % of java submissions
#   ✔ Your memory usage beats 14.98 % of java submissions (53.6 MB)
# Submitting: java_solutions_1/516.longest-palindromic-subsequence.java
# - Downloading longest-palindromic-subsequence
#   ✔ Accepted
#   ✔ 86/86 cases passed (73 ms)
#   ✔ Your runtime beats 5.37 % of java submissions
#   ✔ Your memory usage beats 6.8 % of java submissions (69.5 MB)
# Submitting: java_solutions_1/518.coin-change-ii.java
# - Downloading coin-change-ii
#   ✔ Accepted
#   ✔ 31/31 cases passed (42 ms)
#   ✔ Your runtime beats 5.02 % of java submissions
#   ✔ Your memory usage beats 58.94 % of java submissions (49.9 MB)
# Submitting: java_solutions_1/523.continuous-subarray-sum.java
# - Downloading continuous-subarray-sum
#   ✔ Accepted
#   ✔ 102/102 cases passed (149 ms)
#   ✔ Your runtime beats 5.02 % of java submissions
#   ✔ Your memory usage beats 6.96 % of java submissions (142.9 MB)
# Submitting: java_solutions_1/524.longest-word-in-dictionary-through-deleting.java
# - Downloading longest-word-in-dictionary-through-deleting
#   ✔ Accepted
#   ✔ 31/31 cases passed (57 ms)
#   ✔ Your runtime beats 5.08 % of java submissions
#   ✔ Your memory usage beats 10.89 % of java submissions (48.4 MB)
# Submitting: java_solutions_1/525.contiguous-array.java
# - Downloading contiguous-array
#   ✔ Accepted
#   ✔ 566/566 cases passed (359 ms)
#   ✔ Your runtime beats 5.64 % of java submissions
#   ✔ Your memory usage beats 5.11 % of java submissions (81.9 MB)
# Submitting: java_solutions_1/526.beautiful-arrangement.java
# - Downloading beautiful-arrangement
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 9: error: array required, but Object found
#   ✘ Error: Line 9: error: array required, but Object found
#         return java.util.stream.Stream.of(new Object[]{new java.util.concurrent.atomic.AtomicReference<java.util.function.BiFunction<Integer, Integer, Integer>>()}).peek(a -> ((java.util.concurrent.atomic.AtomicReference<java.util.function.BiFunction<Integer, Integer, Integer>>) a[0]).set((mask, idx) -> idx > n ? 1 : java.util.stream.IntStream.rangeClosed(1, n).filter(i -> (mask & (1 << i)) == 0 && (i % idx == 0 || idx % i == 0)).map(i -> ((java.util.concurrent.atomic.AtomicReference<java.util.function.BiFunction<Integer, Integer, Integer>>) a[0]).get().apply(mask | (1 << i), idx + 1)).sum())).map(a -> ((java.util.concurrent.atomic.AtomicReference<java.util.function.BiFunction<Integer, Integer, Integer>>) a[0]).get().apply(0, 1)).findFirst().get();
#                                                                                                                                                                                                                                                                                          ^
# Line 9: error: array required, but Object found
#         return java.util.stream.Stream.of(new Object[]{new java.util.concurrent.atomic.AtomicReference<java.util.function.BiFunction<Integer, Integer, Integer>>()}).peek(a -> ((java.util.concurrent.atomic.AtomicReference<java.util.function.BiFunction<Integer, Integer, Integer>>) a[0]).set((mask, idx) -> idx > n ? 1 : java.util.stream.IntStream.rangeClosed(1, n).filter(i -> (mask & (1 << i)) == 0 && (i % idx == 0 || idx % i == 0)).map(i -> ((java.util.concurrent.atomic.AtomicReference<java.util.function.BiFunction<Integer, Integer, Integer>>) a[0]).get().apply(mask | (1 << i), idx + 1)).sum())).map(a -> ((java.util.concurrent.atomic.AtomicReference<java.util.function.BiFunction<Integer, Integer, Integer>>) a[0]).get().apply(0, 1)).findFirst().get();
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ^
# Line 9: error: array required, but Object found
#         return java.util.stream.Stream.of(new Object[]{new java.util.concurrent.atomic.AtomicReference<java.util.function.BiFunction<Integer, Integer, Integer>>()}).peek(a -> ((java.util.concurrent.atomic.AtomicReference<java.util.function.BiFunction<Integer, Integer, Integer>>) a[0]).set((mask, idx) -> idx > n ? 1 : java.util.stream.IntStream.rangeClosed(1, n).filter(i -> (mask & (1 << i)) == 0 && (i % idx == 0 || idx % i == 0)).map(i -> ((java.util.concurrent.atomic.AtomicReference<java.util.function.BiFunction<Integer, Integer, Integer>>) a[0]).get().apply(mask | (1 << i), idx + 1)).sum())).map(a -> ((java.util.concurrent.atomic.AtomicReference<java.util.function.BiFunction<Integer, Integer, Integer>>) a[0]).get().apply(0, 1)).findFirst().get();
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ^
# 3 errors
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: java_solutions_1/528.random-pick-with-weight.java
# - Downloading random-pick-with-weight
#   ✔ Accepted
#   ✔ 57/57 cases passed (44 ms)
#   ✔ Your runtime beats 12.89 % of java submissions
#   ✔ Your memory usage beats 12.1 % of java submissions (52.9 MB)
# Submitting: java_solutions_1/529.minesweeper.java
# - Downloading minesweeper
#   ✔ Accepted
#   ✔ 54/54 cases passed (51 ms)
#   ✔ Your runtime beats 8.85 % of java submissions
#   ✔ Your memory usage beats 6.07 % of java submissions (62.3 MB)
# Submitting: java_solutions_1/530.minimum-absolute-difference-in-bst.java
# - Downloading minimum-absolute-difference-in-bst
#   ✔ Accepted
#   ✔ 190/190 cases passed (42 ms)
#   ✔ Your runtime beats 5.41 % of java submissions
#   ✔ Your memory usage beats 15.35 % of java submissions (53.8 MB)
# Submitting: java_solutions_1/532.k-diff-pairs-in-an-array.java
# - Downloading k-diff-pairs-in-an-array
#   ✔ Accepted
#   ✔ 60/60 cases passed (14 ms)
#   ✔ Your runtime beats 18.2 % of java submissions
#   ✔ Your memory usage beats 23.18 % of java submissions (46.8 MB)
# Submitting: java_solutions_1/535.encode-and-decode-tinyurl.java
# - Downloading encode-and-decode-tinyurl
#   ✔ Accepted
#   ✔ 739/739 cases passed (10 ms)
#   ✔ Your runtime beats 6.89 % of java submissions
#   ✔ Your memory usage beats 9.61 % of java submissions (44.8 MB)
# Submitting: java_solutions_1/538.convert-bst-to-greater-tree.java
# - Downloading convert-bst-to-greater-tree
#   ✘ Runtime Error
#   ✘ 7/215 cases passed (N/A)
#   ✘ Error: Line 9: java.lang.NullPointerException
#   ✘ Error: java.lang.NullPointerException
#   at line 220, java.base/java.util.Objects.requireNonNull
#   at line 113, java.base/java.util.Optional.of
#   at line 194, java.base/java.util.stream.FindOps$FindSink$OfRef.get
#   at line 191, java.base/java.util.stream.FindOps$FindSink$OfRef.get
#   at line 150, java.base/java.util.stream.FindOps$FindOp.evaluateSequential
#   at line 265, java.base/java.util.stream.AbstractPipeline.evaluate
#   at line 683, java.base/java.util.stream.ReferencePipeline.findFirst
#   at line 9, Solution.convertBST
#   at line 56, __DriverSolution__.__helper__
#   at line 86, __Driver__.main
#   ✘ Testcase: []
#   ✘ Answer:
#   ✘ Expected Answer: []
#   ✘ Stdout:
# Submitting: java_solutions_1/539.minimum-time-difference.java
# - Downloading minimum-time-difference
#   ✔ Accepted
#   ✔ 116/116 cases passed (18 ms)
#   ✔ Your runtime beats 12.36 % of java submissions
#   ✔ Your memory usage beats 47.08 % of java submissions (48.1 MB)
# Submitting: java_solutions_1/540.single-element-in-a-sorted-array.java
# - Downloading single-element-in-a-sorted-array
#   ✔ Accepted
#   ✔ 16/16 cases passed (3 ms)
#   ✔ Your runtime beats 5.71 % of java submissions
#   ✔ Your memory usage beats 7.98 % of java submissions (53.2 MB)
# Submitting: java_solutions_1/542.01-matrix.java
# - Downloading 01-matrix
#   ✔ Accepted
#   ✔ 50/50 cases passed (164 ms)
#   ✔ Your runtime beats 5.21 % of java submissions
#   ✔ Your memory usage beats 5.01 % of java submissions (55.4 MB)
# Submitting: java_solutions_1/543.diameter-of-binary-tree.java
# - Downloading diameter-of-binary-tree
#   ✔ Accepted
#   ✔ 106/106 cases passed (15 ms)
#   ✔ Your runtime beats 11.02 % of java submissions
#   ✔ Your memory usage beats 5.09 % of java submissions (51.3 MB)
# Submitting: java_solutions_1/547.number-of-provinces.java
# - Downloading number-of-provinces
#   ✔ Accepted
#   ✔ 114/114 cases passed (18 ms)
#   ✔ Your runtime beats 6.59 % of java submissions
#   ✔ Your memory usage beats 5.7 % of java submissions (55.3 MB)
# Submitting: java_solutions_1/553.optimal-division.java
# - Downloading optimal-division
#   ✔ Accepted
#   ✔ 93/93 cases passed (9 ms)
#   ✔ Your runtime beats 13.86 % of java submissions
#   ✔ Your memory usage beats 12.7 % of java submissions (49.1 MB)
# Submitting: java_solutions_1/554.brick-wall.java
# - Downloading brick-wall
#   ✔ Accepted
#   ✔ 88/88 cases passed (41 ms)
#   ✔ Your runtime beats 5.36 % of java submissions
#   ✔ Your memory usage beats 8.39 % of java submissions (55.1 MB)
# Submitting: java_solutions_1/556.next-greater-element-iii.java
# - Downloading next-greater-element-iii
#   ✔ Accepted
#   ✔ 39/39 cases passed (18 ms)
#   ✔ Your runtime beats 2.44 % of java submissions
#   ✔ Your memory usage beats 10.09 % of java submissions (49 MB)
# Submitting: java_solutions_1/560.subarray-sum-equals-k.java
# - Downloading subarray-sum-equals-k
#   ✔ Accepted
#   ✔ 93/93 cases passed (93 ms)
#   ✔ Your runtime beats 23.2 % of java submissions
#   ✔ Your memory usage beats 5.69 % of java submissions (61.6 MB)
# Submitting: java_solutions_1/565.array-nesting.java
# - Downloading array-nesting
#   ✔ Accepted
#   ✔ 885/885 cases passed (150 ms)
#   ✔ Your runtime beats 5.27 % of java submissions
#   ✔ Your memory usage beats 16.88 % of java submissions (73.1 MB)
# Submitting: java_solutions_1/567.permutation-in-string.java
# - Downloading permutation-in-string
#   ✔ Accepted
#   ✔ 110/110 cases passed (51 ms)
#   ✔ Your runtime beats 15.18 % of java submissions
#   ✔ Your memory usage beats 5.84 % of java submissions (53.4 MB)
# Submitting: java_solutions_1/576.out-of-boundary-paths.java
# - Downloading out-of-boundary-paths
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 9: error: ';' expected
#   ✘ Error: Line 9: error: ';' expected
#         return java.util.stream.Stream.of(0).map(_v -> new Object[]{new int[m][n], new int[]{0}}).peek(a -> ((int[][])a[0])[startRow][startColumn] = 1).peek(a -> java.util.stream.IntStream.range(0, maxMove).forEach(step -> java.util.stream.Stream.of(new int[m][n]).peek(temp -> java.util.stream.IntStream.range(0, m).forEach(i -> java.util.stream.IntStream.range(0, n).forEach(j -> java.util.stream.Stream.of(0).filter(_x -> ((int[][])a[0])[i][j] > 0).forEach(_x -> java.util.Arrays.stream(new int[][]{{i-1, j}, {i+1, j}, {i, j-1}, {i, j+1}}).forEach(d -> java.util.stream.Stream.of(0).filter(_y -> d[0] < 0 || d[0] >= m || d[1] < 0 || d[1] >= n).peek(_y -> ((int[])a[1])[0] = (((int[])a[1])[0] + ((int[][])a[0])[i][j]) % 1000000007).forEach(_y -> {}))).forEach(_x -> java.util.Arrays.stream(new int[][]{{i-1, j}, {i+1, j}, {i, j-1}, {i, j+1}}).filter(d -> d[0] >= 0 && d[0] < m && d[1] >= 0 && d[1] < n).forEach(d -> temp[d[0]][d[1]] = (temp[d[0]][d[1]] + ((int[][])a[0])[i][j]) % 1000000007)))))).forEach(temp -> a[0] = temp))).map(a -> ((int[])a[1])[0]).findFirst().get();
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ^
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: java_solutions_1/581.shortest-unsorted-continuous-subarray.java
# - Downloading shortest-unsorted-continuous-subarray
#   ✔ Accepted
#   ✔ 307/307 cases passed (27 ms)
#   ✔ Your runtime beats 5.24 % of java submissions
#   ✔ Your memory usage beats 8.53 % of java submissions (48.3 MB)
# Submitting: java_solutions_1/583.delete-operation-for-two-strings.java
# - Downloading delete-operation-for-two-strings
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 9: error: array required, but int found
#   ✘ Error: Line 9: error: array required, but int found
#         return word1.length() + word2.length() - 2 * java.util.stream.Stream.of(new int[word1.length() + 1][word2.length() + 1]).peek(dp -> java.util.stream.IntStream.rangeClosed(1, word1.length()).forEach(i -> java.util.stream.IntStream.rangeClosed(1, word2.length()).forEach(j -> dp[i][j] = word1.charAt(i - 1) == word2.charAt(j - 1) ? dp[i - 1][j - 1] + 1 : Math.max(dp[i - 1][j], dp[i][j - 1])))).map(dp -> dp[word1.length()][word2.length()]).findFirst().get();
#                                                                                                                                                                                                                                                                                                ^
# Line 9: error: array required, but int found
#         return word1.length() + word2.length() - 2 * java.util.stream.Stream.of(new int[word1.length() + 1][word2.length() + 1]).peek(dp -> java.util.stream.IntStream.rangeClosed(1, word1.length()).forEach(i -> java.util.stream.IntStream.rangeClosed(1, word2.length()).forEach(j -> dp[i][j] = word1.charAt(i - 1) == word2.charAt(j - 1) ? dp[i - 1][j - 1] + 1 : Math.max(dp[i - 1][j], dp[i][j - 1])))).map(dp -> dp[word1.length()][word2.length()]).findFirst().get();
#                                                                                                                                                                                                                                                                                                                                                            ^
# Line 9: error: array required, but int found
#         return word1.length() + word2.length() - 2 * java.util.stream.Stream.of(new int[word1.length() + 1][word2.length() + 1]).peek(dp -> java.util.stream.IntStream.rangeClosed(1, word1.length()).forEach(i -> java.util.stream.IntStream.rangeClosed(1, word2.length()).forEach(j -> dp[i][j] = word1.charAt(i - 1) == word2.charAt(j - 1) ? dp[i - 1][j - 1] + 1 : Math.max(dp[i - 1][j], dp[i][j - 1])))).map(dp -> dp[word1.length()][word2.length()]).findFirst().get();
#                                                                                                                                                                                                                                                                                                                                                                                            ^
# Line 9: error: array required, but int found
#         return word1.length() + word2.length() - 2 * java.util.stream.Stream.of(new int[word1.length() + 1][word2.length() + 1]).peek(dp -> java.util.stream.IntStream.rangeClosed(1, word1.length()).forEach(i -> java.util.stream.IntStream.rangeClosed(1, word2.length()).forEach(j -> dp[i][j] = word1.charAt(i - 1) == word2.charAt(j - 1) ? dp[i - 1][j - 1] + 1 : Math.max(dp[i - 1][j], dp[i][j - 1])))).map(dp -> dp[word1.length()][word2.length()]).findFirst().get();
#                                                                                                                                                                                                                                                                                                                                                                                                      ^
# Line 9: error: array required, but int found
#         return word1.length() + word2.length() - 2 * java.util.stream.Stream.of(new int[word1.length() + 1][word2.length() + 1]).peek(dp -> java.util.stream.IntStream.rangeClosed(1, word1.length()).forEach(i -> java.util.stream.IntStream.rangeClosed(1, word2.length()).forEach(j -> dp[i][j] = word1.charAt(i - 1) == word2.charAt(j - 1) ? dp[i - 1][j - 1] + 1 : Math.max(dp[i - 1][j], dp[i][j - 1])))).map(dp -> dp[word1.length()][word2.length()]).findFirst().get();
#                                                                                                                                                                                                                                                                                                                                                                                                                                              ^
# Line 9: error: bad operand types for binary operator '*'
#         return word1.length() + word2.length() - 2 * java.util.stream.Stream.of(new int[word1.length() + 1][word2.length() + 1]).peek(dp -> java.util.stream.IntStream.rangeClosed(1, word1.length()).forEach(i -> java.util.stream.IntStream.rangeClosed(1, word2.length()).forEach(j -> dp[i][j] = word1.charAt(i - 1) == word2.charAt(j - 1) ? dp[i - 1][j - 1] + 1 : Math.max(dp[i - 1][j], dp[i][j - 1])))).map(dp -> dp[word1.length()][word2.length()]).findFirst().get();
#                                                    ^
#   first type:  int
#   second type: Object
# 6 errors
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: java_solutions_1/592.fraction-addition-and-subtraction.java
# - Downloading fraction-addition-and-subtraction
#   ✘ Runtime Error
#   ✘ 0/105 cases passed (N/A)
#   ✘ Error: Line 9: java.util.NoSuchElementException: No value present
#   ✘ Error: java.util.NoSuchElementException: No value present
#   at line 143, java.base/java.util.Optional.get
#   at line 9, Solution.lambda$fractionAddition$9
#   at line 214, java.base/java.util.stream.ReferencePipeline$3$1.accept
#   at line 577, java.base/java.util.stream.ReferencePipeline$15$1.accept
#   at line 214, java.base/java.util.stream.ReferencePipeline$3$1.accept
#   at line 397, java.base/java.util.stream.Streams$StreamBuilderImpl.tryAdvance
#   at line 147, java.base/java.util.stream.ReferencePipeline.forEachWithCancel
#   at line 588, java.base/java.util.stream.AbstractPipeline.copyIntoWithCancel
#   at line 574, java.base/java.util.stream.AbstractPipeline.copyInto
#   at line 560, java.base/java.util.stream.AbstractPipeline.wrapAndCopyInto
#   at line 150, java.base/java.util.stream.FindOps$FindOp.evaluateSequential
#   at line 265, java.base/java.util.stream.AbstractPipeline.evaluate
#   at line 683, java.base/java.util.stream.ReferencePipeline.findFirst
#   at line 9, Solution.fractionAddition
#   at line 56, __DriverSolution__.__helper__
#   at line 86, __Driver__.main
#   ✘ Testcase: "-1/2+1/2"
#   ✘ Answer:
#   ✘ Expected Answer: "0/1"
#   ✘ Stdout:
# Submitting: java_solutions_1/593.valid-square.java
# - Downloading valid-square
#   ✔ Accepted
#   ✔ 256/256 cases passed (26 ms)
#   ✔ Your runtime beats 4.55 % of java submissions
#   ✔ Your memory usage beats 12.34 % of java submissions (50.9 MB)
# Submitting: java_solutions_1/594.longest-harmonious-subsequence.java
# - Downloading longest-harmonious-subsequence
#   ✔ Accepted
#   ✔ 208/208 cases passed (25 ms)
#   ✔ Your runtime beats 8.68 % of java submissions
#   ✔ Your memory usage beats 39.89 % of java submissions (48.3 MB)
# Submitting: java_solutions_1/599.minimum-index-sum-of-two-lists.java
# - Downloading minimum-index-sum-of-two-lists
#   ✔ Accepted
#   ✔ 137/137 cases passed (28 ms)
#   ✔ Your runtime beats 24.52 % of java submissions
#   ✔ Your memory usage beats 13.42 % of java submissions (53.6 MB)

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-06-09 17:11:45
