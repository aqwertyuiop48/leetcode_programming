# %%
# %%capture
import os
import getpass

# 2. Interactive input (Safe and hidden)
print("Please enter your LeetCode credentials:")
user_name = getpass.getpass('LeetCode Username: ')
user_cookie = getpass.getpass('LeetCode Session Token: ')

# 1. Install and Clone
# !npm install -g leetcode-tools/leetcode-cli
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME'] = user_name
    os.environ['LEETCODE_TOKEN'] = user_cookie

    # 4. Run the login silently
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME" "$LEETCODE_TOKEN" | leetcode user -c

# %%
# %%bash
#
# # top 500-600 answers (6th batch)
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v kotlin_solutions/*.kt | sed -n '551,600p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 7
# done
# Out:
# Submitting: kotlin_solutions/726.number-of-atoms.kt
# - Downloading number-of-atoms
#   ✔ Accepted
#   ✔ 39/39 cases passed (43 ms)
#   ✔ Your runtime beats 66.67 % of kotlin submissions
#   ✔ Your memory usage beats 83.33 % of kotlin submissions (46.8 MB)
# Submitting: kotlin_solutions/728.self-dividing-numbers.kt
# - Downloading self-dividing-numbers
#   ✔ Accepted
#   ✔ 31/31 cases passed (15 ms)
#   ✔ Your runtime beats 28.57 % of kotlin submissions
#   ✔ Your memory usage beats 32.65 % of kotlin submissions (44.6 MB)
# Submitting: kotlin_solutions/729.my-calendar-i.kt
# - Downloading my-calendar-i
#   ✔ Accepted
#   ✔ 107/107 cases passed (44 ms)
#   ✔ Your runtime beats 64.06 % of kotlin submissions
#   ✔ Your memory usage beats 92.19 % of kotlin submissions (50 MB)
# Submitting: kotlin_solutions/730.count-different-palindromic-subsequences.kt
# - Downloading count-different-palindromic-subsequences
#   ✔ Accepted
#   ✔ 367/367 cases passed (55 ms)
#   ✔ Your runtime beats 66.67 % of kotlin submissions
#   ✔ Your memory usage beats 77.78 % of kotlin submissions (62 MB)
# Submitting: kotlin_solutions/731.my-calendar-ii.kt
# - Downloading my-calendar-ii
#   ✔ Accepted
#   ✔ 97/97 cases passed (146 ms)
#   ✔ Your runtime beats 34.29 % of kotlin submissions
#   ✔ Your memory usage beats 11.43 % of kotlin submissions (68.3 MB)
# Submitting: kotlin_solutions/732.my-calendar-iii.kt
# - Downloading my-calendar-iii
#   ✔ Accepted
#   ✔ 98/98 cases passed (285 ms)
#   ✔ Your runtime beats 29.41 % of kotlin submissions
#   ✔ Your memory usage beats 47.06 % of kotlin submissions (68.5 MB)
# Submitting: kotlin_solutions/733.flood-fill.kt
# - Downloading flood-fill
#   ✔ Accepted
#   ✔ 278/278 cases passed (13 ms)
#   ✔ Your runtime beats 41.27 % of kotlin submissions
#   ✔ Your memory usage beats 72.49 % of kotlin submissions (46.8 MB)
# Submitting: kotlin_solutions/735.asteroid-collision.kt
# - Downloading asteroid-collision
#   ✔ Accepted
#   ✔ 276/276 cases passed (29 ms)
#   ✔ Your runtime beats 9.74 % of kotlin submissions
#   ✔ Your memory usage beats 7.69 % of kotlin submissions (51.4 MB)
# Submitting: kotlin_solutions/736.parse-lisp-expression.kt
# - Downloading parse-lisp-expression
#   ✔ Accepted
#   ✔ 66/66 cases passed (56 ms)
#   ✔ Your runtime beats 58.33 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (48.2 MB)
# Submitting: kotlin_solutions/738.monotone-increasing-digits.kt
# - Downloading monotone-increasing-digits
#   ✔ Accepted
#   ✔ 308/308 cases passed (19 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 31.25 % of kotlin submissions (45.7 MB)
# Submitting: kotlin_solutions/739.daily-temperatures.kt
# - Downloading daily-temperatures
#   ✔ Accepted
#   ✔ 48/48 cases passed (120 ms)
#   ✔ Your runtime beats 16.22 % of kotlin submissions
#   ✔ Your memory usage beats 54.44 % of kotlin submissions (63.8 MB)
# Submitting: kotlin_solutions/740.delete-and-earn.kt
# - Downloading delete-and-earn
#   ✔ Accepted
#   ✔ 52/52 cases passed (37 ms)
#   ✔ Your runtime beats 23.4 % of kotlin submissions
#   ✔ Your memory usage beats 61.7 % of kotlin submissions (48.2 MB)
# Submitting: kotlin_solutions/741.cherry-pickup.kt
# - Downloading cherry-pickup
#   ✔ Accepted
#   ✔ 60/60 cases passed (242 ms)
#   ✔ Your runtime beats 11.11 % of kotlin submissions
#   ✔ Your memory usage beats 88.89 % of kotlin submissions (66.5 MB)
# Submitting: kotlin_solutions/743.network-delay-time.kt
# - Downloading network-delay-time
#   ✔ Accepted
#   ✔ 56/56 cases passed (280 ms)
#   ✔ Your runtime beats 66.67 % of kotlin submissions
#   ✔ Your memory usage beats 78.67 % of kotlin submissions (55.1 MB)
# Submitting: kotlin_solutions/744.find-smallest-letter-greater-than-target.kt
# - Downloading find-smallest-letter-greater-than-target
#   ✔ Accepted
#   ✔ 167/167 cases passed (11 ms)
#   ✔ Your runtime beats 16.87 % of kotlin submissions
#   ✔ Your memory usage beats 30.25 % of kotlin submissions (46.8 MB)
# Submitting: kotlin_solutions/745.prefix-and-suffix-search.kt
# - Downloading prefix-and-suffix-search
#   ✔ Accepted
#   ✔ 17/17 cases passed (671 ms)
#   ✔ Your runtime beats 63.64 % of kotlin submissions
#   ✔ Your memory usage beats 36.36 % of kotlin submissions (129.3 MB)
# Submitting: kotlin_solutions/746.min-cost-climbing-stairs.kt
# - Downloading min-cost-climbing-stairs
#   ✔ Accepted
#   ✔ 285/285 cases passed (24 ms)
#   ✔ Your runtime beats 5.38 % of kotlin submissions
#   ✔ Your memory usage beats 9.87 % of kotlin submissions (46.7 MB)
# Submitting: kotlin_solutions/747.largest-number-at-least-twice-of-others.kt
# - Downloading largest-number-at-least-twice-of-others
#   ✔ Accepted
#   ✔ 231/231 cases passed (15 ms)
#   ✔ Your runtime beats 14.29 % of kotlin submissions
#   ✔ Your memory usage beats 35.71 % of kotlin submissions (45.5 MB)
# Submitting: kotlin_solutions/748.shortest-completing-word.kt
# - Downloading shortest-completing-word
#   ✔ Accepted
#   ✔ 102/102 cases passed (32 ms)
#   ✔ Your runtime beats 71.43 % of kotlin submissions
#   ✔ Your memory usage beats 57.14 % of kotlin submissions (47.9 MB)
# Submitting: kotlin_solutions/749.contain-virus.kt
# - Downloading contain-virus
#   ✔ Accepted
#   ✔ 32/32 cases passed (118 ms)
#   ✔ Your runtime beats 11.11 % of kotlin submissions
#   ✔ Your memory usage beats 22.22 % of kotlin submissions (57.9 MB)
# Submitting: kotlin_solutions/752.open-the-lock.kt
# - Downloading open-the-lock
#   ✔ Accepted
#   ✔ 48/48 cases passed (260 ms)
#   ✔ Your runtime beats 9.88 % of kotlin submissions
#   ✔ Your memory usage beats 7.41 % of kotlin submissions (75.4 MB)
# Submitting: kotlin_solutions/753.cracking-the-safe.kt
# - Downloading cracking-the-safe
#   ✔ Accepted
#   ✔ 38/38 cases passed (253 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 90 % of kotlin submissions (53.2 MB)
# Submitting: kotlin_solutions/754.reach-a-number.kt
# - Downloading reach-a-number
#   ✔ Accepted
#   ✔ 73/73 cases passed (31 ms)
#   ✔ Your runtime beats 69.23 % of kotlin submissions
#   ✔ Your memory usage beats 38.46 % of kotlin submissions (46.1 MB)
# Submitting: kotlin_solutions/756.pyramid-transition-matrix.kt
# - Downloading pyramid-transition-matrix
#   ✔ Accepted
#   ✔ 67/67 cases passed (1935 ms)
#   ✔ Your runtime beats 8.7 % of kotlin submissions
#   ✔ Your memory usage beats 56.52 % of kotlin submissions (56.4 MB)
# Submitting: kotlin_solutions/757.set-intersection-size-at-least-two.kt
# - Downloading set-intersection-size-at-least-two
#   ✔ Accepted
#   ✔ 118/118 cases passed (38 ms)
#   ✔ Your runtime beats 87.5 % of kotlin submissions
#   ✔ Your memory usage beats 62.5 % of kotlin submissions (50.1 MB)
# Submitting: kotlin_solutions/761.special-binary-string.kt
# - Downloading special-binary-string
#   ✔ Accepted
#   ✔ 87/87 cases passed (30 ms)
#   ✔ Your runtime beats 9.34 % of kotlin submissions
#   ✔ Your memory usage beats 9.89 % of kotlin submissions (46.6 MB)
# Submitting: kotlin_solutions/762.prime-number-of-set-bits-in-binary-representation.kt
# - Downloading prime-number-of-set-bits-in-binary-representation
#   ✔ Accepted
#   ✔ 202/202 cases passed (112 ms)
#   ✔ Your runtime beats 7.69 % of kotlin submissions
#   ✔ Your memory usage beats 11.03 % of kotlin submissions (47.9 MB)
# Submitting: kotlin_solutions/763.partition-labels.kt
# - Downloading partition-labels
#   ✔ Accepted
#   ✔ 118/118 cases passed (14 ms)
#   ✔ Your runtime beats 33.98 % of kotlin submissions
#   ✔ Your memory usage beats 20.39 % of kotlin submissions (44.8 MB)
# Submitting: kotlin_solutions/764.largest-plus-sign.kt
# - Downloading largest-plus-sign
#   ✔ Accepted
#   ✔ 57/57 cases passed (406 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
#   ✔ Your memory usage beats 60 % of kotlin submissions (77.6 MB)
# Submitting: kotlin_solutions/765.couples-holding-hands.kt
# - Downloading couples-holding-hands
#   ✔ Accepted
#   ✔ 56/56 cases passed (23 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (45.9 MB)
# Submitting: kotlin_solutions/766.toeplitz-matrix.kt
# - Downloading toeplitz-matrix
#   ✔ Accepted
#   ✔ 483/483 cases passed (14 ms)
#   ✔ Your runtime beats 22.22 % of kotlin submissions
#   ✔ Your memory usage beats 22.22 % of kotlin submissions (51.2 MB)
# Submitting: kotlin_solutions/767.reorganize-string.kt
# - Downloading reorganize-string
#   ✔ Accepted
#   ✔ 71/71 cases passed (24 ms)
#   ✔ Your runtime beats 14.29 % of kotlin submissions
#   ✔ Your memory usage beats 22.08 % of kotlin submissions (44.5 MB)
# Submitting: kotlin_solutions/768.max-chunks-to-make-sorted-ii.kt
# - Downloading max-chunks-to-make-sorted-ii
#   ✔ Accepted
#   ✔ 139/139 cases passed (9 ms)
#   ✔ Your runtime beats 90 % of kotlin submissions
#   ✔ Your memory usage beats 80 % of kotlin submissions (45.7 MB)
# Submitting: kotlin_solutions/769.max-chunks-to-make-sorted.kt
# - Downloading max-chunks-to-make-sorted
#   ✔ Accepted
#   ✔ 53/53 cases passed (13 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (44.4 MB)
# Submitting: kotlin_solutions/770.basic-calculator-iv.kt
# - Downloading basic-calculator-iv
#   ✔ Accepted
#   ✔ 158/158 cases passed (66 ms)
#   ✔ Your runtime beats 75 % of kotlin submissions
#   ✔ Your memory usage beats 37.5 % of kotlin submissions (51.1 MB)
# Submitting: kotlin_solutions/771.jewels-and-stones.kt
# - Downloading jewels-and-stones
#   ✔ Accepted
#   ✔ 255/255 cases passed (13 ms)
#   ✔ Your runtime beats 23.31 % of kotlin submissions
#   ✔ Your memory usage beats 6.01 % of kotlin submissions (44.1 MB)
# Submitting: kotlin_solutions/773.sliding-puzzle.kt
# - Downloading sliding-puzzle
#   ✔ Accepted
#   ✔ 32/32 cases passed (216 ms)
#   ✔ Your runtime beats 53.85 % of kotlin submissions
#   ✔ Your memory usage beats 46.15 % of kotlin submissions (55.9 MB)
# Submitting: kotlin_solutions/775.global-and-local-inversions.kt
# - Downloading global-and-local-inversions
#   ✔ Accepted
#   ✔ 226/226 cases passed (27 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (64.9 MB)
# Submitting: kotlin_solutions/777.swap-adjacent-in-lr-string.kt
# - Downloading swap-adjacent-in-lr-string
#   ✔ Accepted
#   ✔ 99/99 cases passed (46 ms)
#   ✔ Your runtime beats 13.04 % of kotlin submissions
#   ✔ Your memory usage beats 30.43 % of kotlin submissions (47.8 MB)
# Submitting: kotlin_solutions/778.swim-in-rising-water.kt
# - Downloading swim-in-rising-water
#   ✔ Accepted
#   ✔ 43/43 cases passed (950 ms)
#   ✔ Your runtime beats 8.33 % of kotlin submissions
#   ✔ Your memory usage beats 11.67 % of kotlin submissions (60.6 MB)
# Submitting: kotlin_solutions/779.k-th-symbol-in-grammar.kt
# - Downloading k-th-symbol-in-grammar
#   ✔ Accepted
#   ✔ 55/55 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 52.63 % of kotlin submissions (40.2 MB)
# Submitting: kotlin_solutions/780.reaching-points.kt
# - Downloading reaching-points
#   ✔ Accepted
#   ✔ 197/197 cases passed (13 ms)
#   ✔ Your runtime beats 88.89 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (41.4 MB)
# Submitting: kotlin_solutions/781.rabbits-in-forest.kt
# - Downloading rabbits-in-forest
#   ✔ Accepted
#   ✔ 56/56 cases passed (20 ms)
#   ✔ Your runtime beats 54.55 % of kotlin submissions
#   ✔ Your memory usage beats 9.09 % of kotlin submissions (46.9 MB)
# Submitting: kotlin_solutions/782.transform-to-chessboard.kt
# - Downloading transform-to-chessboard
#   ✔ Accepted
#   ✔ 127/127 cases passed (30 ms)
#   ✔ Your runtime beats 88.89 % of kotlin submissions
#   ✔ Your memory usage beats 88.89 % of kotlin submissions (50.2 MB)
# Submitting: kotlin_solutions/783.minimum-distance-between-bst-nodes.kt
# - Downloading minimum-distance-between-bst-nodes
#   ✔ Accepted
#   ✔ 49/49 cases passed (18 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 25.93 % of kotlin submissions (43.1 MB)
# Submitting: kotlin_solutions/784.letter-case-permutation.kt
# - Downloading letter-case-permutation
#   ✔ Accepted
#   ✔ 63/63 cases passed (38 ms)
#   ✔ Your runtime beats 31.03 % of kotlin submissions
#   ✔ Your memory usage beats 13.79 % of kotlin submissions (52.4 MB)
# Submitting: kotlin_solutions/785.is-graph-bipartite.kt
# - Downloading is-graph-bipartite
#   ✔ Accepted
#   ✔ 86/86 cases passed (29 ms)
#   ✔ Your runtime beats 11.43 % of kotlin submissions
#   ✔ Your memory usage beats 35.71 % of kotlin submissions (50.7 MB)
# Submitting: kotlin_solutions/786.k-th-smallest-prime-fraction.kt
# - Downloading k-th-smallest-prime-fraction
#   ✔ Accepted
#   ✔ 59/59 cases passed (513 ms)
#   ✔ Your runtime beats 46.67 % of kotlin submissions
#   ✔ Your memory usage beats 60 % of kotlin submissions (103.4 MB)
# Submitting: kotlin_solutions/787.cheapest-flights-within-k-stops.kt
# - Downloading cheapest-flights-within-k-stops
#   ✔ Accepted
#   ✔ 59/59 cases passed (11 ms)
#   ✔ Your runtime beats 82.95 % of kotlin submissions
#   ✔ Your memory usage beats 68.22 % of kotlin submissions (47.1 MB)
# Submitting: kotlin_solutions/788.rotated-digits.kt
# - Downloading rotated-digits
#   ✔ Accepted
#   ✔ 50/50 cases passed (26 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 71.43 % of kotlin submissions (45.2 MB)

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-03-18 19:45:01
