# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME_3')
    user_cookie = userdata.get('LEETCODE_TOKEN_3')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME_3'] = user_name
    os.environ['LEETCODE_TOKEN_3'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME_3" "$LEETCODE_TOKEN_3" | leetcode user -c

# %%
# %%bash
#
# # top 400-500 answers (5th batch)
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v java_solutions/*.java | sed -n '401,500p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 7
# done
# Out:
# Submitting: java_solutions/507.perfect-number.java
#   ✔ Accepted
#   ✔ 98/98 cases passed (10 ms)
#   ✔ Your runtime beats 56.25 % of java submissions
#   ✔ Your memory usage beats 12.5 % of java submissions (42 MB)
# Submitting: java_solutions/508.most-frequent-subtree-sum.java
#   ✔ Accepted
#   ✔ 58/58 cases passed (32 ms)
#   ✔ Your runtime beats 11.11 % of java submissions
#   ✔ Your memory usage beats 11.11 % of java submissions (49 MB)
# Submitting: java_solutions/509.fibonacci-number.java
#   ✔ Accepted
#   ✔ 31/31 cases passed (88 ms)
#   ✔ Your runtime beats 10.62 % of java submissions
#   ✔ Your memory usage beats 68.84 % of java submissions (39.1 MB)
# Submitting: java_solutions/513.find-bottom-left-tree-value.java
#   ✔ Accepted
#   ✔ 79/79 cases passed (9 ms)
#   ✔ Your runtime beats 42.86 % of java submissions
#   ✔ Your memory usage beats 42.86 % of java submissions (47.5 MB)
# Submitting: java_solutions/514.freedom-trail.java
#   ✔ Accepted
#   ✔ 303/303 cases passed (64 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: java_solutions/515.find-largest-value-in-each-tree-row.java
#   ✔ Accepted
#   ✔ 78/78 cases passed (20 ms)
#   ✔ Your runtime beats 39.13 % of java submissions
#   ✔ Your memory usage beats 84.78 % of java submissions (46.5 MB)
# Submitting: java_solutions/516.longest-palindromic-subsequence.java
#   ✔ Accepted
#   ✔ 86/86 cases passed (49 ms)
#   ✔ Your runtime beats 16.67 % of java submissions
#   ✔ Your memory usage beats 11.11 % of java submissions (59.7 MB)
# Submitting: java_solutions/517.super-washing-machines.java
#   ✔ Accepted
#   ✔ 120/120 cases passed (18 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: java_solutions/518.coin-change-ii.java
#   ✔ Accepted
#   ✔ 31/31 cases passed (14 ms)
#   ✔ Your runtime beats 63.54 % of java submissions
#   ✔ Your memory usage beats 68.75 % of java submissions (41.9 MB)
# Submitting: java_solutions/519.random-flip-matrix.java
#   ✔ Accepted
#   ✔ 20/20 cases passed (51 ms)
#   ✔ Your runtime beats 66.67 % of java submissions
#   ✔ Your memory usage beats 66.67 % of java submissions (48.3 MB)
# Submitting: java_solutions/520.detect-capital.java
#   ✔ Accepted
#   ✔ 552/552 cases passed (9 ms)
#   ✔ Your runtime beats 12.35 % of java submissions
#   ✔ Your memory usage beats 17.28 % of java submissions (42.8 MB)
# Submitting: java_solutions/521.longest-uncommon-subsequence-i.java
#   ✔ Accepted
#   ✔ 41/41 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 5.56 % of java submissions (40.9 MB)
# Submitting: java_solutions/522.longest-uncommon-subsequence-ii.java
#   ✔ Accepted
#   ✔ 101/101 cases passed (29 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: java_solutions/523.continuous-subarray-sum.java
#   ✔ Accepted
#   ✔ 102/102 cases passed (47 ms)
#   ✔ Your runtime beats 19.48 % of java submissions
#   ✔ Your memory usage beats 100 % of java submissions (60.9 MB)
# Submitting: java_solutions/524.longest-word-in-dictionary-through-deleting.java
#   ✔ Accepted
#   ✔ 31/31 cases passed (209 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: java_solutions/525.contiguous-array.java
#   ✔ Accepted
#   ✔ 566/566 cases passed (70 ms)
#   ✔ Your runtime beats 6.42 % of java submissions
#   ✔ Your memory usage beats 19.27 % of java submissions (60.4 MB)
# Submitting: java_solutions/526.beautiful-arrangement.java
#   ✔ Accepted
#   ✔ 15/15 cases passed (28 ms)
#   ✔ Your runtime beats 84.62 % of java submissions
#   ✔ Your memory usage beats 38.46 % of java submissions (44.9 MB)
# Submitting: java_solutions/528.random-pick-with-weight.java
#   ✔ Accepted
#   ✔ 57/57 cases passed (69 ms)
#   ✔ Your runtime beats 25.3 % of java submissions
#   ✔ Your memory usage beats 26.51 % of java submissions (63 MB)
# Submitting: java_solutions/529.minesweeper.java
#   ✔ Accepted
#   ✔ 54/54 cases passed (35 ms)
#   ✔ Your runtime beats 6.67 % of java submissions
#   ✔ Your memory usage beats 6.67 % of java submissions (54.1 MB)
# Submitting: java_solutions/530.minimum-absolute-difference-in-bst.java
#   ✔ Accepted
#   ✔ 190/190 cases passed (39 ms)
#   ✔ Your runtime beats 5.95 % of java submissions
#   ✔ Your memory usage beats 5.95 % of java submissions (50.7 MB)
# Submitting: java_solutions/532.k-diff-pairs-in-an-array.java
#   ✔ Accepted
#   ✔ 60/60 cases passed (78 ms)
#   ✔ Your runtime beats 16 % of java submissions
#   ✔ Your memory usage beats 24 % of java submissions (50 MB)
# Submitting: java_solutions/535.encode-and-decode-tiny-url.java
#   ✔ Accepted
#   ✔ 739/739 cases passed (146 ms)
#   ✔ Your runtime beats 67.86 % of java submissions
#   ✔ Your memory usage beats 92.86 % of java submissions (42.5 MB)
# Submitting: java_solutions/537.complex-number-multiplication.java
#   ✔ Accepted
#   ✔ 56/56 cases passed (29 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: java_solutions/538.convert-bst-to-greater-tree.java
#   ✔ Accepted
#   ✔ 215/215 cases passed (21 ms)
#   ✔ Your runtime beats 8.33 % of java submissions
#   ✔ Your memory usage beats 58.33 % of java submissions (46.7 MB)
# Submitting: java_solutions/539.minimum-time-difference.java
#   ✔ Accepted
#   ✔ 116/116 cases passed (41 ms)
#   ✔ Your runtime beats 38.46 % of java submissions
#   ✔ Your memory usage beats 30.77 % of java submissions (51 MB)
# Submitting: java_solutions/540.single-element-in-a-sorted-array.java
#   ✔ Accepted
#   ✔ 16/16 cases passed (16 ms)
#   ✔ Your runtime beats 1.82 % of java submissions
#   ✔ Your memory usage beats 7.27 % of java submissions (57.3 MB)
# Submitting: java_solutions/541.reverse-string-ii.java
#   ✔ Accepted
#   ✔ 60/60 cases passed (14 ms)
#   ✔ Your runtime beats 29.41 % of java submissions
#   ✔ Your memory usage beats 33.33 % of java submissions (45.5 MB)
# Submitting: java_solutions/542.01-matrix.java
#   ✔ Accepted
#   ✔ 50/50 cases passed (137 ms)
#   ✔ Your runtime beats 15.97 % of java submissions
#   ✔ Your memory usage beats 7.64 % of java submissions (72.4 MB)
# Submitting: java_solutions/543.diameter-of-binary-tree.java
#   ✔ Accepted
#   ✔ 106/106 cases passed (17 ms)
#   ✔ Your runtime beats 11.11 % of java submissions
#   ✔ Your memory usage beats 16.67 % of java submissions (48.7 MB)
# Submitting: java_solutions/546.remove-boxes.java
#   ✔ Accepted
#   ✔ 63/63 cases passed (630 ms)
#   ✔ Your runtime beats 0 % of java submissions
#   ✔ Your memory usage beats 0 % of java submissions (74 MB)
# Submitting: java_solutions/547.number-of-provinces.java
#   ✔ Accepted
#   ✔ 114/114 cases passed (42 ms)
#   ✔ Your runtime beats 5.76 % of java submissions
#   ✔ Your memory usage beats 79.06 % of java submissions (56.1 MB)
# Submitting: java_solutions/551.student-attendance-record-i.java
#   ✔ Accepted
#   ✔ 115/115 cases passed (7 ms)
#   ✔ Your runtime beats 19.35 % of java submissions
#   ✔ Your memory usage beats 22.58 % of java submissions (41.8 MB)
# Submitting: java_solutions/552.student-attendance-record-ii.java
#   ✔ Accepted
#   ✔ 59/59 cases passed (46 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 40 % of java submissions (59.3 MB)
# Submitting: java_solutions/553.optimal-division.java
#   ✔ Accepted
#   ✔ 93/93 cases passed (25 ms)
#   ✔ Your runtime beats 0 % of java submissions
#   ✔ Your memory usage beats 14.29 % of java submissions (46.2 MB)
# Submitting: java_solutions/554.brick-wall.java
#   ✔ Accepted
#   ✔ 88/88 cases passed (55 ms)
#   ✔ Your runtime beats 9.09 % of java submissions
#   ✔ Your memory usage beats 45.45 % of java submissions (57.5 MB)
# Submitting: java_solutions/556.next-greater-element-iii.java
#   ✔ Accepted
#   ✔ 39/39 cases passed (20 ms)
#   ✔ Your runtime beats 20 % of java submissions
#   ✔ Your memory usage beats 10 % of java submissions (45.9 MB)
# Submitting: java_solutions/557.reverse-words-in-a-string-iii.java
#   ✔ Accepted
#   ✔ 29/29 cases passed (20 ms)
#   ✔ Your runtime beats 40.98 % of java submissions
#   ✔ Your memory usage beats 26.23 % of java submissions (47.3 MB)
# Submitting: java_solutions/558.logical-or-of-two-binary-grids-represented-as-quad-trees.java
#   ✔ Accepted
#   ✔ 61/61 cases passed (193 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 100 % of java submissions (51.7 MB)
# Submitting: java_solutions/559.maximum-depth-of-n-ary-tree.java
#   ✔ Accepted
#   ✔ 38/38 cases passed (143 ms)
#   ✔ Your runtime beats 37.5 % of java submissions
#   ✔ Your memory usage beats 59.38 % of java submissions (47 MB)
# Submitting: java_solutions/560.subarray-sum-equals-k.java
#   ✔ Accepted
#   ✔ 93/93 cases passed (54 ms)
#   ✔ Your runtime beats 20.31 % of java submissions
#   ✔ Your memory usage beats 43.67 % of java submissions (53.2 MB)
# Submitting: java_solutions/561.array-partition.java
#   ✔ Accepted
#   ✔ 85/85 cases passed (70 ms)
#   ✔ Your runtime beats 12.5 % of java submissions
#   ✔ Your memory usage beats 46.43 % of java submissions (53.1 MB)
# Submitting: java_solutions/563.binary-tree-tilt.java
#   ✔ Accepted
#   ✔ 77/77 cases passed (26 ms)
#   ✔ Your runtime beats 7.14 % of java submissions
#   ✔ Your memory usage beats 7.14 % of java submissions (50.9 MB)
# Submitting: java_solutions/564.find-the-closest-palindrome.java
#   ✔ Accepted
#   ✔ 232/232 cases passed (29 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: java_solutions/565.array-nesting.java
#   ✔ Accepted
#   ✔ 885/885 cases passed (81 ms)
#   ✔ Your runtime beats 16.67 % of java submissions
#   ✔ Your memory usage beats 33.33 % of java submissions (74.7 MB)
# Submitting: java_solutions/566.reshape-the-matrix.java
#   ✔ Accepted
#   ✔ 57/57 cases passed (22 ms)
#   ✔ Your runtime beats 4 % of java submissions
#   ✔ Your memory usage beats 8 % of java submissions (56.5 MB)
# Submitting: java_solutions/567.permutation-in-string.java
#   ✔ Accepted
#   ✔ 110/110 cases passed (101 ms)
#   ✔ Your runtime beats 8.44 % of java submissions
#   ✔ Your memory usage beats 14.35 % of java submissions (48.2 MB)
# Submitting: java_solutions/572.subtree-of-another-tree.java
#   ✔ Accepted
#   ✔ 185/185 cases passed (4 ms)
#   ✔ Your runtime beats 78.24 % of java submissions
#   ✔ Your memory usage beats 29.02 % of java submissions (50.2 MB)
# Submitting: java_solutions/575.distribute-candies.java
#   ✔ Accepted
#   ✔ 206/206 cases passed (44 ms)
#   ✔ Your runtime beats 36.96 % of java submissions
#   ✔ Your memory usage beats 23.91 % of java submissions (59.5 MB)
# Submitting: java_solutions/576.out-of-boundary-paths.java
#   ✔ Accepted
#   ✔ 94/94 cases passed (29 ms)
#   ✔ Your runtime beats 33.33 % of java submissions
# [WARN] Failed to get memory percentile.
# Submitting: java_solutions/581.shortest-unsorted-continuous-subarray.java
#   ✔ Accepted
#   ✔ 307/307 cases passed (44 ms)
#   ✔ Your runtime beats 9.09 % of java submissions
#   ✔ Your memory usage beats 22.73 % of java submissions (51.7 MB)
# Submitting: java_solutions/583.delete-operation-for-two-strings.java
#   ✔ Accepted
#   ✔ 1306/1306 cases passed (21 ms)
#   ✔ Your runtime beats 15.79 % of java submissions
#   ✔ Your memory usage beats 78.95 % of java submissions (45.7 MB)
# Submitting: java_solutions/587.erect-the-fence.java
#   ✔ Accepted
#   ✔ 88/88 cases passed (66 ms)
#   ✔ Your runtime beats 0 % of java submissions
#   ✔ Your memory usage beats 0 % of java submissions (66.5 MB)
# Submitting: java_solutions/589.n-ary-tree-preorder-traversal.java
#   ✔ Accepted
#   ✔ 39/39 cases passed (183 ms)
#   ✔ Your runtime beats 39.13 % of java submissions
#   ✔ Your memory usage beats 52.17 % of java submissions (49.1 MB)
# Submitting: java_solutions/590.n-ary-tree-postorder-traversal.java
#   ✔ Accepted
#   ✔ 38/38 cases passed (171 ms)
#   ✔ Your runtime beats 53.33 % of java submissions
#   ✔ Your memory usage beats 6.67 % of java submissions (49.9 MB)
# Submitting: java_solutions/591.tag-validator.java
#   ✔ Accepted
#   ✔ 261/261 cases passed (37 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: java_solutions/592.fraction-addition-and-subtraction.java
#   ✔ Accepted
#   ✔ 105/105 cases passed (40 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: java_solutions/593.valid-square.java
#   ✔ Accepted
#   ✔ 256/256 cases passed (18 ms)
#   ✔ Your runtime beats 33.33 % of java submissions
#   ✔ Your memory usage beats 50 % of java submissions (43.7 MB)
# Submitting: java_solutions/594.longest-harmonious-subsequence.java
# - Downloading longest-harmonious-subsequence
#   ✔ Accepted
#   ✔ 208/208 cases passed (88 ms)
#   ✔ Your runtime beats 9.26 % of java submissions
#   ✔ Your memory usage beats 5.55 % of java submissions (70 MB)
# Submitting: java_solutions/598.range-addition-ii.java
#   ✔ Accepted
#   ✔ 69/69 cases passed (3 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: java_solutions/599.minimum-index-sum-of-two-lists.java
#   ✔ Accepted
#   ✔ 137/137 cases passed (47 ms)
#   ✔ Your runtime beats 17.95 % of java submissions
#   ✔ Your memory usage beats 15.38 % of java submissions (51.6 MB)
# Submitting: java_solutions/600.non-negative-integers-without-consecutive-ones.java
#   ✔ Accepted
#   ✔ 527/527 cases passed (8 ms)
#   ✔ Your runtime beats 63.64 % of java submissions
#   ✔ Your memory usage beats 18.18 % of java submissions (42.1 MB)
# Submitting: java_solutions/605.can-place-flowers.java
#   ✔ Accepted
#   ✔ 130/130 cases passed (17 ms)
#   ✔ Your runtime beats 7.48 % of java submissions
#   ✔ Your memory usage beats 19.29 % of java submissions (49.6 MB)
# Submitting: java_solutions/606.construct-string-from-binary-tree.java
#   ✔ Accepted
#   ✔ 160/160 cases passed (8 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: java_solutions/609.find-duplicate-file-in-system.java
#   ✔ Accepted
#   ✔ 162/162 cases passed (49 ms)
#   ✔ Your runtime beats 66.67 % of java submissions
#   ✔ Your memory usage beats 44.44 % of java submissions (60.8 MB)
# Submitting: java_solutions/611.valid-triangle-number.java
#   ✔ Accepted
#   ✔ 241/241 cases passed (673 ms)
#   ✔ Your runtime beats 6.25 % of java submissions
#   ✔ Your memory usage beats 6.25 % of java submissions (68.4 MB)
# Submitting: java_solutions/617.merge-two-binary-trees.java
#   ✔ Accepted
#   ✔ 182/182 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 85.37 % of java submissions (45.8 MB)
# Submitting: java_solutions/621.task-scheduler.java
# - Downloading task-scheduler
#   ✔ Accepted
#   ✔ 72/72 cases passed (31 ms)
#   ✔ Your runtime beats 73.03 % of java submissions
#   ✔ Your memory usage beats 31.46 % of java submissions (50.8 MB)
# Submitting: java_solutions/622.design-circular-queue.java
#   ✔ Accepted
#   ✔ 59/59 cases passed (17 ms)
#   ✔ Your runtime beats 90.14 % of java submissions
#   ✔ Your memory usage beats 74.65 % of java submissions (47.3 MB)
# Submitting: java_solutions/623.add-one-row-to-tree.java
#   ✔ Accepted
#   ✔ 109/109 cases passed (21 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: java_solutions/624.maximum-distance-in-arrays.java
#   ✔ Accepted
#   ✔ 136/136 cases passed (45 ms)
#   ✔ Your runtime beats 23.53 % of java submissions
#   ✔ Your memory usage beats 5.88 % of java submissions (96.1 MB)
# Submitting: java_solutions/628.maximum-product-of-three-numbers.java
#   ✔ Accepted
#   ✔ 93/93 cases passed (74 ms)
#   ✔ Your runtime beats 7.69 % of java submissions
#   ✔ Your memory usage beats 30.77 % of java submissions (51.6 MB)
# Submitting: java_solutions/629.k-inverse-pairs-array.java
#   ✔ Accepted
#   ✔ 81/81 cases passed (953 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: java_solutions/630.course-schedule-iii.java
#   ✔ Accepted
#   ✔ 97/97 cases passed (80 ms)
#   ✔ Your runtime beats 20 % of java submissions
#   ✔ Your memory usage beats 30 % of java submissions (73.5 MB)
# Submitting: java_solutions/632.smallest-range-covering-elements-from-k-lists.java
#   ✔ Accepted
#   ✔ 94/94 cases passed (275 ms)
#   ✔ Your runtime beats 7.32 % of java submissions
#   ✔ Your memory usage beats 7.32 % of java submissions (97.4 MB)
# Submitting: java_solutions/633.sum-of-square-numbers.java
#   ✔ Accepted
#   ✔ 127/127 cases passed (31 ms)
#   ✔ Your runtime beats 26.32 % of java submissions
#   ✔ Your memory usage beats 10.53 % of java submissions (45.5 MB)
# Submitting: java_solutions/636.exclusive-time-of-functions.java
#   ✔ Accepted
#   ✔ 120/120 cases passed (50 ms)
#   ✔ Your runtime beats 16.22 % of java submissions
#   ✔ Your memory usage beats 8.11 % of java submissions (50 MB)
# Submitting: java_solutions/637.average-of-levels-in-binary-tree.java
#   ✔ Accepted
#   ✔ 66/66 cases passed (28 ms)
#   ✔ Your runtime beats 9.18 % of java submissions
#   ✔ Your memory usage beats 6.12 % of java submissions (51.5 MB)
# Submitting: java_solutions/638.shopping-offers.java
#   ✔ Accepted
#   ✔ 65/65 cases passed (33 ms)
#   ✔ Your runtime beats 44.44 % of java submissions
#   ✔ Your memory usage beats 55.56 % of java submissions (50.3 MB)
# Submitting: java_solutions/639.decode-ways-ii.java
#   ✔ Accepted
#   ✔ 218/218 cases passed (385 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: java_solutions/640.solve-the-equation.java
#   ✔ Accepted
#   ✔ 59/59 cases passed (15 ms)
#   ✔ Your runtime beats 50 % of java submissions
#   ✔ Your memory usage beats 50 % of java submissions (42.8 MB)
# Submitting: java_solutions/641.design-circular-deque.java
#   ✔ Accepted
#   ✔ 54/54 cases passed (18 ms)
#   ✔ Your runtime beats 50 % of java submissions
#   ✔ Your memory usage beats 87.5 % of java submissions (47.7 MB)
# Submitting: java_solutions/643.maximum-average-subarray-i.java
#   ✔ Accepted
#   ✔ 128/128 cases passed (60 ms)
#   ✔ Your runtime beats 9.66 % of java submissions
#   ✔ Your memory usage beats 5.17 % of java submissions (66.5 MB)
# Submitting: java_solutions/645.set-mismatch.java
#   ✔ Accepted
#   ✔ 49/49 cases passed (28 ms)
#   ✔ Your runtime beats 31.2 % of java submissions
#   ✔ Your memory usage beats 16.54 % of java submissions (50.8 MB)
# Submitting: java_solutions/646.maximum-length-of-pair-chain.java
#   ✔ Accepted
#   ✔ 206/206 cases passed (27 ms)
#   ✔ Your runtime beats 53.85 % of java submissions
#   ✔ Your memory usage beats 76.92 % of java submissions (51.1 MB)
# Submitting: java_solutions/647.palindromic-substrings.java
#   ✔ Accepted
#   ✔ 132/132 cases passed (46 ms)
#   ✔ Your runtime beats 18.31 % of java submissions
#   ✔ Your memory usage beats 10.56 % of java submissions (48 MB)
# Submitting: java_solutions/648.replace-words.java
#   ✔ Accepted
#   ✔ 130/130 cases passed (98 ms)
#   ✔ Your runtime beats 17.39 % of java submissions
#   ✔ Your memory usage beats 43.48 % of java submissions (61.7 MB)
# Submitting: java_solutions/649.dota-2-senate.java
#   ✔ Accepted
#   ✔ 83/83 cases passed (23 ms)
#   ✔ Your runtime beats 85.96 % of java submissions
#   ✔ Your memory usage beats 70.18 % of java submissions (46.5 MB)
# Submitting: java_solutions/650.2-keys-keyboard.java
#   ✔ Accepted
#   ✔ 126/126 cases passed (19 ms)
#   ✔ Your runtime beats 22.22 % of java submissions
#   ✔ Your memory usage beats 22.22 % of java submissions (42.8 MB)
# Submitting: java_solutions/652.find-duplicate-subtrees.java
#   ✔ Accepted
#   ✔ 175/175 cases passed (109 ms)
#   ✔ Your runtime beats 13.64 % of java submissions
#   ✔ Your memory usage beats 63.64 % of java submissions (53.2 MB)
# Submitting: java_solutions/653.two-sum-iv-input-is-a-bst.java
#   ✔ Accepted
#   ✔ 423/423 cases passed (5 ms)
#   ✔ Your runtime beats 51.02 % of java submissions
#   ✔ Your memory usage beats 97.96 % of java submissions (46.2 MB)
# Submitting: java_solutions/654.maximum-binary-tree.java
#   ✔ Accepted
#   ✔ 107/107 cases passed (45 ms)
#   ✔ Your runtime beats 7.69 % of java submissions
#   ✔ Your memory usage beats 7.69 % of java submissions (53.2 MB)
# Submitting: java_solutions/655.print-binary-tree.java
#   ✔ Accepted
#   ✔ 73/73 cases passed (12 ms)
#   ✔ Your runtime beats 33.33 % of java submissions
#   ✔ Your memory usage beats 33.33 % of java submissions (45.4 MB)
# Submitting: java_solutions/657.robot-return-to-origin.java
#   ✔ Accepted
#   ✔ 77/77 cases passed (22 ms)
#   ✔ Your runtime beats 5.77 % of java submissions
#   ✔ Your memory usage beats 5.77 % of java submissions (46.7 MB)
# Submitting: java_solutions/658.find-k-closest-elements.java
# - Downloading find-k-closest-elements
#   ✔ Accepted
#   ✔ 70/70 cases passed (40 ms)
#   ✔ Your runtime beats 29.88 % of java submissions
#   ✔ Your memory usage beats 51.72 % of java submissions (50.7 MB)
# Submitting: java_solutions/659.split-array-into-consecutive-subsequences.java
#   ✔ Accepted
#   ✔ 187/187 cases passed (38 ms)
#   ✔ Your runtime beats 75 % of java submissions
# [WARN] Failed to get memory percentile.
# Submitting: java_solutions/661.image-smoother.java
#   ✔ Accepted
#   ✔ 203/203 cases passed (108 ms)
#   ✔ Your runtime beats 30 % of java submissions
#   ✔ Your memory usage beats 10 % of java submissions (68.8 MB)
# Submitting: java_solutions/662.maximum-width-of-binary-tree.java
#   ✔ Accepted
#   ✔ 117/117 cases passed (30 ms)
#   ✔ Your runtime beats 8.57 % of java submissions
#   ✔ Your memory usage beats 5.71 % of java submissions (50.5 MB)
# Submitting: java_solutions/664.strange-printer.java
#   ✔ Accepted
#   ✔ 200/200 cases passed (106 ms)
#   ✔ Your runtime beats 0 % of java submissions
#   ✔ Your memory usage beats 0 % of java submissions (55.2 MB)
# Submitting: java_solutions/665.non-decreasing-array.java
#   ✔ Accepted
#   ✔ 335/335 cases passed (31 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: java_solutions/667.beautiful-arrangement-ii.java
#   ✔ Accepted
#   ✔ 70/70 cases passed (1 ms)
#   ✔ Your runtime beats 100 % of java submissions
# [WARN] Failed to get memory percentile.

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-02-14 19:03:21
