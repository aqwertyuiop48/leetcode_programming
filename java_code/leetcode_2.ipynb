# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME')
    user_cookie = userdata.get('LEETCODE_TOKEN')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME'] = user_name
    os.environ['LEETCODE_TOKEN'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME" "$LEETCODE_TOKEN" | leetcode user -c

# %%
# %%bash
#
#
# # top 100 answers
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v java_solutions/*.java | sed -n '101,200p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 7
# done
# Out:
# Submitting: java_solutions/145.binary-tree-postorder-traversal.java
# - Downloading binary-tree-postorder-traversal
#   ✔ Accepted
#   ✔ 71/71 cases passed (4 ms)
#   ✔ Your runtime beats 0.12 % of java submissions
#   ✔ Your memory usage beats 6.33 % of java submissions (43.8 MB)
# Submitting: java_solutions/146.lru-cache.java
# - Downloading lru-cache
#   ✔ Accepted
#   ✔ 24/24 cases passed (45 ms)
#   ✔ Your runtime beats 73.51 % of java submissions
#   ✔ Your memory usage beats 64.03 % of java submissions (131.2 MB)
# Submitting: java_solutions/147.insertion-sort-list.java
# - Downloading insertion-sort-list
#   ✔ Accepted
#   ✔ 19/19 cases passed (10 ms)
#   ✔ Your runtime beats 72.91 % of java submissions
#   ✔ Your memory usage beats 43.35 % of java submissions (46.4 MB)
# Submitting: java_solutions/148.sort-list.java
# - Downloading sort-list
#   ✔ Accepted
#   ✔ 30/30 cases passed (29 ms)
#   ✔ Your runtime beats 7.07 % of java submissions
#   ✔ Your memory usage beats 5.7 % of java submissions (65.4 MB)
# Submitting: java_solutions/149.max-points-on-a-line.java
# - Downloading max-points-on-a-line
#   ✔ Accepted
#   ✔ 42/42 cases passed (38 ms)
#   ✔ Your runtime beats 12.56 % of java submissions
#   ✔ Your memory usage beats 6.03 % of java submissions (47.6 MB)
# Submitting: java_solutions/151.reverse-words-in-a-string.java
# - Downloading reverse-words-in-a-string
#   ✔ Accepted
#   ✔ 62/62 cases passed (9 ms)
#   ✔ Your runtime beats 25.03 % of java submissions
#   ✔ Your memory usage beats 29.48 % of java submissions (44.9 MB)
# Submitting: java_solutions/152.maximum-product-subarray.java
# - Downloading maximum-product-subarray
#   ✔ Accepted
#   ✔ 191/191 cases passed (7 ms)
#   ✔ Your runtime beats 12.03 % of java submissions
#   ✔ Your memory usage beats 97.97 % of java submissions (46.7 MB)
# Submitting: java_solutions/153.find-minimum-in-rotated-sorted-array.java
# - Downloading find-minimum-in-rotated-sorted-array
#   ✔ Accepted
#   ✔ 150/150 cases passed (3 ms)
#   ✔ Your runtime beats 4.46 % of java submissions
#   ✔ Your memory usage beats 24.81 % of java submissions (43.9 MB)
# Submitting: java_solutions/154.find-minimum-in-rotated-sorted-array-ii.java
# - Downloading find-minimum-in-rotated-sorted-array-ii
#   ✔ Accepted
#   ✔ 193/193 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 61.49 % of java submissions (44.8 MB)
# Submitting: java_solutions/160.intersection-of-two-linked-lists.java
# - Downloading intersection-of-two-linked-lists
#   ✔ Accepted
#   ✔ 41/41 cases passed (21 ms)
#   ✔ Your runtime beats 6.03 % of java submissions
#   ✔ Your memory usage beats 6.84 % of java submissions (56.2 MB)
# Submitting: java_solutions/162.find-peak-element.java
# - Downloading find-peak-element
#   ✔ Accepted
#   ✔ 73/73 cases passed (4 ms)
#   ✔ Your runtime beats 0.65 % of java submissions
#   ✔ Your memory usage beats 43.22 % of java submissions (44.3 MB)
# Submitting: java_solutions/164.maximum-gap.java
# - Downloading maximum-gap
#   ✔ Accepted
#   ✔ 46/46 cases passed (64 ms)
#   ✔ Your runtime beats 6.06 % of java submissions
#   ✔ Your memory usage beats 79.62 % of java submissions (88.9 MB)
# Submitting: java_solutions/165.compare-version-numbers.java
# - Downloading compare-version-numbers
#   ✔ Accepted
#   ✔ 90/90 cases passed (15 ms)
#   ✔ Your runtime beats 2.78 % of java submissions
#   ✔ Your memory usage beats 14.23 % of java submissions (47 MB)
# Submitting: java_solutions/167.two-sum-ii-input-array-is-sorted.java
# - Downloading two-sum-ii-input-array-is-sorted
#   ✔ Accepted
#   ✔ 24/24 cases passed (9 ms)
#   ✔ Your runtime beats 8.62 % of java submissions
#   ✔ Your memory usage beats 7.89 % of java submissions (48.7 MB)
# Submitting: java_solutions/168.excel-sheet-column-title.java
# - Downloading excel-sheet-column-title
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 7: error: cannot find symbol [in __Driver__.java]
#   ✘ Error: Line 7: error: cannot find symbol [in __Driver__.java]
#       String ret = new Solution().convertToTitle(param_1);
#                                  ^
#   symbol:   method convertToTitle(int)
#   location: class Solution
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: java_solutions/169.majority-element.java
# - Downloading majority-element
#   ✔ Accepted
#   ✔ 53/53 cases passed (29 ms)
#   ✔ Your runtime beats 7.99 % of java submissions
#   ✔ Your memory usage beats 10.66 % of java submissions (57.3 MB)
# Submitting: java_solutions/171.excel-sheet-column-number.java
# - Downloading excel-sheet-column-number
#   ✔ Accepted
#   ✔ 1002/1002 cases passed (4 ms)
#   ✔ Your runtime beats 1.31 % of java submissions
#   ✔ Your memory usage beats 22.25 % of java submissions (43.7 MB)
# Submitting: java_solutions/172.factorial-trailing-zeroes.java
# - Downloading factorial-trailing-zeroes
#   ✔ Accepted
#   ✔ 500/500 cases passed (7 ms)
#   ✔ Your runtime beats 1.91 % of java submissions
#   ✔ Your memory usage beats 7.32 % of java submissions (42.7 MB)
# Submitting: java_solutions/174.dungeon-game.java
# - Downloading dungeon-game
#   ✔ Accepted
#   ✔ 45/45 cases passed (5 ms)
#   ✔ Your runtime beats 3.86 % of java submissions
#   ✔ Your memory usage beats 59.93 % of java submissions (45.2 MB)
# Submitting: java_solutions/179.largest-number.java
# - Downloading largest-number
#   ✔ Accepted
#   ✔ 236/236 cases passed (14 ms)
#   ✔ Your runtime beats 5.64 % of java submissions
#   ✔ Your memory usage beats 8.71 % of java submissions (45.7 MB)
# Submitting: java_solutions/187.repeated-dna-sequences.java
# - Downloading repeated-dna-sequences
#   ✔ Accepted
#   ✔ 32/32 cases passed (43 ms)
#   ✔ Your runtime beats 5.53 % of java submissions
#   ✔ Your memory usage beats 5.62 % of java submissions (63.7 MB)
# Submitting: java_solutions/188.best-time-to-buy-and-sell-stock-iv.java
# - Downloading best-time-to-buy-and-sell-stock-iv
#   ✔ Accepted
#   ✔ 211/211 cases passed (6 ms)
#   ✔ Your runtime beats 40.76 % of java submissions
#   ✔ Your memory usage beats 91.06 % of java submissions (43.2 MB)
# Submitting: java_solutions/189.rotate-array.java
# - Downloading rotate-array
#   ✔ Accepted
#   ✔ 40/40 cases passed (7 ms)
#   ✔ Your runtime beats 3.76 % of java submissions
#   ✔ Your memory usage beats 13.74 % of java submissions (63.2 MB)
# Submitting: java_solutions/190.reverse-bits.java
# - Downloading reverse-bits
#   ✔ Accepted
#   ✔ 600/600 cases passed (4 ms)
#   ✔ Your runtime beats 8.31 % of java submissions
#   ✔ Your memory usage beats 9.13 % of java submissions (42.9 MB)
# Submitting: java_solutions/191.number-of-1-bits.java
# - Downloading number-of-1-bits
#   ✔ Accepted
#   ✔ 598/598 cases passed (13 ms)
#   ✔ Your runtime beats 1.74 % of java submissions
#   ✔ Your memory usage beats 6.69 % of java submissions (44.6 MB)
# Submitting: java_solutions/198.house-robber.java
# - Downloading house-robber
#   ✔ Accepted
#   ✔ 70/70 cases passed (3 ms)
#   ✔ Your runtime beats 0.65 % of java submissions
#   ✔ Your memory usage beats 9.04 % of java submissions (43.1 MB)
# Submitting: java_solutions/202.happy-number.java
# - Downloading happy-number
#   ✔ Accepted
#   ✔ 420/420 cases passed (12 ms)
#   ✔ Your runtime beats 2.36 % of java submissions
#   ✔ Your memory usage beats 7.6 % of java submissions (44.5 MB)
# Submitting: java_solutions/203.remove-linked-list-elements.java
# - Downloading remove-linked-list-elements
#   ✔ Accepted
#   ✔ 66/66 cases passed (1 ms)
#   ✔ Your runtime beats 95.79 % of java submissions
#   ✔ Your memory usage beats 11.43 % of java submissions (48.3 MB)
# Submitting: java_solutions/204.count-primes.java
# - Downloading count-primes
#   ✔ Accepted
#   ✔ 66/66 cases passed (601 ms)
#   ✔ Your runtime beats 5.01 % of java submissions
#   ✔ Your memory usage beats 99.09 % of java submissions (46.2 MB)
# Submitting: java_solutions/205.isomorphic-strings.java
# - Downloading isomorphic-strings
#   ✔ Accepted
#   ✔ 47/47 cases passed (9 ms)
#   ✔ Your runtime beats 69.66 % of java submissions
#   ✔ Your memory usage beats 19.26 % of java submissions (44.1 MB)
# Submitting: java_solutions/206.reverse-linked-list.java
# - Downloading reverse-linked-list
#   ✔ Accepted
#   ✔ 28/28 cases passed (7 ms)
#   ✔ Your runtime beats 0.54 % of java submissions
#   ✔ Your memory usage beats 6.46 % of java submissions (44.9 MB)
# Submitting: java_solutions/212.word-search-ii.java
# - Downloading word-search-ii
#   ✔ Accepted
#   ✔ 65/65 cases passed (1388 ms)
#   ✔ Your runtime beats 5.01 % of java submissions
#   ✔ Your memory usage beats 8.17 % of java submissions (51 MB)
# Submitting: java_solutions/214.shortest-palindrome.java
# - Downloading shortest-palindrome
#   ✔ Accepted
#   ✔ 126/126 cases passed (11 ms)
#   ✔ Your runtime beats 14.33 % of java submissions
#   ✔ Your memory usage beats 19.04 % of java submissions (47.1 MB)
# Submitting: java_solutions/215.kth-largest-element-in-an-array.java
# - Downloading kth-largest-element-in-an-array
#   ✔ Accepted
#   ✔ 45/45 cases passed (130 ms)
#   ✔ Your runtime beats 5.02 % of java submissions
#   ✔ Your memory usage beats 21.07 % of java submissions (70.1 MB)
# Submitting: java_solutions/217.contains-duplicate.java
# - Downloading contains-duplicate
#   ✔ Accepted
#   ✔ 77/77 cases passed (26 ms)
#   ✔ Your runtime beats 6.49 % of java submissions
#   ✔ Your memory usage beats 76.27 % of java submissions (80.6 MB)
# Submitting: java_solutions/218.the-skyline-problem.java
# - Downloading the-skyline-problem
#   ✔ Accepted
#   ✔ 44/44 cases passed (40 ms)
#   ✔ Your runtime beats 57.3 % of java submissions
#   ✔ Your memory usage beats 45.18 % of java submissions (54.2 MB)
# Submitting: java_solutions/219.contains-duplicate-ii.java
# - Downloading contains-duplicate-ii
#   ✔ Accepted
#   ✔ 65/65 cases passed (47 ms)
#   ✔ Your runtime beats 11.57 % of java submissions
#   ✔ Your memory usage beats 6.25 % of java submissions (92.8 MB)
# Submitting: java_solutions/220.contains-duplicate-iii.java
# - Downloading contains-duplicate-iii
#   ✔ Accepted
#   ✔ 56/56 cases passed (162 ms)
#   ✔ Your runtime beats 38.48 % of java submissions
#   ✔ Your memory usage beats 7.76 % of java submissions (127.7 MB)
# Submitting: java_solutions/222.count-complete-tree-nodes.java
# - Downloading count-complete-tree-nodes
#   ✔ Accepted
#   ✔ 18/18 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 53.82 % of java submissions (49.4 MB)
# Submitting: java_solutions/224.basic-calculator.java
# - Downloading basic-calculator
#   ✔ Accepted
#   ✔ 49/49 cases passed (22 ms)
#   ✔ Your runtime beats 6.4 % of java submissions
#   ✔ Your memory usage beats 5.7 % of java submissions (48.3 MB)
# Submitting: java_solutions/226.invert-binary-tree.java
# - Downloading invert-binary-tree
#   ✔ Accepted
#   ✔ 77/77 cases passed (7 ms)
#   ✔ Your runtime beats 0.07 % of java submissions
#   ✔ Your memory usage beats 15.41 % of java submissions (43.6 MB)
# Submitting: java_solutions/228.summary-ranges.java
# - Downloading summary-ranges
#   ✔ Accepted
#   ✔ 34/34 cases passed (9 ms)
#   ✔ Your runtime beats 1.08 % of java submissions
#   ✔ Your memory usage beats 5.83 % of java submissions (49.6 MB)
# Submitting: java_solutions/229.majority-element-ii.java
# - Downloading majority-element-ii
#   ✔ Accepted
#   ✔ 95/95 cases passed (16 ms)
#   ✔ Your runtime beats 22.12 % of java submissions
#   ✔ Your memory usage beats 78.79 % of java submissions (52.3 MB)
# Submitting: java_solutions/230.kth-smallest-element-in-a-bst.java
# - Downloading kth-smallest-element-in-a-bst
#   ✔ Accepted
#   ✔ 93/93 cases passed (11 ms)
#   ✔ Your runtime beats 3.18 % of java submissions
#   ✔ Your memory usage beats 56.35 % of java submissions (46.8 MB)
# Submitting: java_solutions/231.power-of-two.java
# - Downloading power-of-two
#   ✔ Accepted
#   ✔ 1110/1110 cases passed (1 ms)
#   ✔ Your runtime beats 96.57 % of java submissions
#   ✔ Your memory usage beats 61.78 % of java submissions (42.5 MB)
# Submitting: java_solutions/233.number-of-digit-one.java
# - Downloading number-of-digit-one
#   ✔ Accepted
#   ✔ 38/38 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 58.68 % of java submissions (42.1 MB)
# Submitting: java_solutions/234.palindrome-linked-list.java
# - Downloading palindrome-linked-list
#   ✔ Accepted
#   ✔ 93/93 cases passed (31 ms)
#   ✔ Your runtime beats 5.87 % of java submissions
#   ✔ Your memory usage beats 16.23 % of java submissions (100 MB)
# Submitting: java_solutions/237.delete-node-in-a-linked-list.java
# - Downloading delete-node-in-a-linked-list
#   ✔ Accepted
#   ✔ 41/41 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 47.77 % of java submissions (45.2 MB)
# Submitting: java_solutions/238.product-of-array-except-self.java
# - Downloading product-of-array-except-self
#   ✔ Accepted
#   ✔ 24/24 cases passed (21 ms)
#   ✔ Your runtime beats 3.29 % of java submissions
#   ✔ Your memory usage beats 63.58 % of java submissions (71.6 MB)
# Submitting: java_solutions/239.sliding-window-maximum.java
# - Downloading sliding-window-maximum
#   ✔ Accepted
#   ✔ 52/52 cases passed (38 ms)
#   ✔ Your runtime beats 19.55 % of java submissions
#   ✔ Your memory usage beats 44.14 % of java submissions (147.5 MB)
# Submitting: java_solutions/240.search-a-2d-matrix-ii.java
# - Downloading search-a-2d-matrix-ii
#   ✔ Accepted
#   ✔ 130/130 cases passed (196 ms)
#   ✔ Your runtime beats 7.01 % of java submissions
#   ✔ Your memory usage beats 14.33 % of java submissions (59.4 MB)
# Submitting: java_solutions/242.valid-anagram.java
# - Downloading valid-anagram
#   ✔ Accepted
#   ✔ 54/54 cases passed (21 ms)
#   ✔ Your runtime beats 8.07 % of java submissions
#   ✔ Your memory usage beats 18.15 % of java submissions (46.6 MB)
# Submitting: java_solutions/257.binary-tree-paths.java
# - Downloading binary-tree-paths
#   ✔ Accepted
#   ✔ 208/208 cases passed (14 ms)
#   ✔ Your runtime beats 10.91 % of java submissions
#   ✔ Your memory usage beats 5.75 % of java submissions (50.5 MB)
# Submitting: java_solutions/258.add-digits.java
# - Downloading add-digits
#   ✔ Accepted
#   ✔ 1101/1101 cases passed (7 ms)
#   ✔ Your runtime beats 0.73 % of java submissions
#   ✔ Your memory usage beats 14.37 % of java submissions (43.1 MB)
# Submitting: java_solutions/260.single-number-iii.java
# - Downloading single-number-iii
#   ✔ Accepted
#   ✔ 35/35 cases passed (6 ms)
#   ✔ Your runtime beats 35.47 % of java submissions
#   ✔ Your memory usage beats 94.99 % of java submissions (47.7 MB)
# Submitting: java_solutions/263.ugly-number.java
# - Downloading ugly-number
#   ✔ Accepted
#   ✔ 1013/1013 cases passed (1 ms)
#   ✔ Your runtime beats 99.37 % of java submissions
#   ✔ Your memory usage beats 39.59 % of java submissions (42.6 MB)
# Submitting: java_solutions/268.missing-number.java
# - Downloading missing-number
#   ✔ Accepted
#   ✔ 122/122 cases passed (3 ms)
#   ✔ Your runtime beats 21.47 % of java submissions
#   ✔ Your memory usage beats 72.06 % of java submissions (47.2 MB)
# Submitting: java_solutions/273.integer-to-english-words.java
# - Downloading integer-to-english-words
#   ✔ Accepted
#   ✔ 601/601 cases passed (16 ms)
#   ✔ Your runtime beats 6.38 % of java submissions
#   ✔ Your memory usage beats 5.22 % of java submissions (50.3 MB)
# Submitting: java_solutions/274.h-index.java
# - Downloading h-index
#   ✔ Accepted
#   ✔ 83/83 cases passed (13 ms)
#   ✔ Your runtime beats 6.19 % of java submissions
#   ✔ Your memory usage beats 19.44 % of java submissions (43.7 MB)
# Submitting: java_solutions/275.h-index-ii.java
# - Downloading h-index-ii
#   ✔ Accepted
#   ✔ 83/83 cases passed (19 ms)
#   ✔ Your runtime beats 4.56 % of java submissions
#   ✔ Your memory usage beats 6.23 % of java submissions (50.8 MB)
# Submitting: java_solutions/278.first-bad-version.java
# - Downloading first-bad-version
#   ✔ Accepted
#   ✔ 24/24 cases passed (15 ms)
#   ✔ Your runtime beats 13.79 % of java submissions
#   ✔ Your memory usage beats 8.73 % of java submissions (42.4 MB)
# Submitting: java_solutions/282.expression-add-operators.java
# - Downloading expression-add-operators
#   ✔ Accepted
#   ✔ 25/25 cases passed (235 ms)
#   ✔ Your runtime beats 5.01 % of java submissions
#   ✔ Your memory usage beats 10.96 % of java submissions (53.3 MB)
# Submitting: java_solutions/283.move-zeroes.java
# - Downloading move-zeroes
#   ✔ Accepted
#   ✔ 75/75 cases passed (9 ms)
#   ✔ Your runtime beats 7.97 % of java submissions
#   ✔ Your memory usage beats 10.93 % of java submissions (48.6 MB)
# Submitting: java_solutions/287.find-the-duplicate-number.java
# - Downloading find-the-duplicate-number
#   ✔ Accepted
#   ✔ 59/59 cases passed (7 ms)
#   ✔ Your runtime beats 43.15 % of java submissions
#   ✔ Your memory usage beats 39.26 % of java submissions (83 MB)
# Submitting: java_solutions/290.word-pattern.java
# - Downloading word-pattern
#   ✔ Accepted
#   ✔ 44/44 cases passed (9 ms)
#   ✔ Your runtime beats 1.97 % of java submissions
#   ✔ Your memory usage beats 9.54 % of java submissions (43.8 MB)
# Submitting: java_solutions/295.find-median-from-data-stream.java
# - Downloading find-median-from-data-stream
#   ✔ Accepted
#   ✔ 22/22 cases passed (187 ms)
#   ✔ Your runtime beats 34.57 % of java submissions
#   ✔ Your memory usage beats 5.04 % of java submissions (115.8 MB)
# Submitting: java_solutions/297.serialize-and-deserialize-binary-tree.java
# - Downloading serialize-and-deserialize-binary-tree
#   ✔ Accepted
#   ✔ 53/53 cases passed (24 ms)
#   ✔ Your runtime beats 9.48 % of java submissions
#   ✔ Your memory usage beats 59.16 % of java submissions (47.8 MB)
# Submitting: java_solutions/301.remove-invalid-parentheses.java
# - Downloading remove-invalid-parentheses
#   ✔ Accepted
#   ✔ 129/129 cases passed (61 ms)
#   ✔ Your runtime beats 30.52 % of java submissions
#   ✔ Your memory usage beats 22.67 % of java submissions (48 MB)
# Submitting: java_solutions/303.range-sum-query-immutable.java
# - Downloading range-sum-query-immutable
#   ✔ Accepted
#   ✔ 15/15 cases passed (155 ms)
#   ✔ Your runtime beats 9.42 % of java submissions
#   ✔ Your memory usage beats 5.21 % of java submissions (51.1 MB)
# Submitting: java_solutions/312.burst-balloons.java
# - Downloading burst-balloons
#   ✔ Accepted
#   ✔ 73/73 cases passed (118 ms)
#   ✔ Your runtime beats 20.47 % of java submissions
#   ✔ Your memory usage beats 36.18 % of java submissions (44.5 MB)
# Submitting: java_solutions/315.count-of-smaller-numbers-after-self.java
# - Downloading count-of-smaller-numbers-after-self
#   ✔ Accepted
#   ✔ 66/66 cases passed (105 ms)
#   ✔ Your runtime beats 42.79 % of java submissions
#   ✔ Your memory usage beats 48.69 % of java submissions (104.3 MB)
# Submitting: java_solutions/318.maximum-product-of-word-lengths.java
# - Downloading maximum-product-of-word-lengths
#   ✔ Accepted
#   ✔ 168/168 cases passed (62 ms)
#   ✔ Your runtime beats 24.96 % of java submissions
#   ✔ Your memory usage beats 70.02 % of java submissions (49.1 MB)
# Submitting: java_solutions/321.create-maximum-number.java
# - Downloading create-maximum-number
#   ✔ Accepted
#   ✔ 102/102 cases passed (18 ms)
#   ✔ Your runtime beats 21.46 % of java submissions
#   ✔ Your memory usage beats 99.44 % of java submissions (45.7 MB)
# Submitting: java_solutions/326.power-of-three.java
# - Downloading power-of-three
#   ✔ Accepted
#   ✔ 21040/21040 cases passed (8 ms)
#   ✔ Your runtime beats 91.92 % of java submissions
#   ✔ Your memory usage beats 53.24 % of java submissions (46.1 MB)
# Submitting: java_solutions/327.count-of-range-sum.java
# - Downloading count-of-range-sum
#   ✔ Accepted
#   ✔ 67/67 cases passed (240 ms)
#   ✔ Your runtime beats 21.47 % of java submissions
#   ✔ Your memory usage beats 13.4 % of java submissions (132.9 MB)
# Submitting: java_solutions/328.odd-even-linked-list.java
# - Downloading odd-even-linked-list
#   ✔ Accepted
#   ✔ 70/70 cases passed (21 ms)
#   ✔ Your runtime beats 0.94 % of java submissions
#   ✔ Your memory usage beats 8.19 % of java submissions (53 MB)
# Submitting: java_solutions/329.longest-increasing-path-in-a-matrix.java
# - Downloading longest-increasing-path-in-a-matrix
#   ✔ Accepted
#   ✔ 139/139 cases passed (54 ms)
#   ✔ Your runtime beats 7.3 % of java submissions
#   ✔ Your memory usage beats 34.5 % of java submissions (47.3 MB)
# Submitting: java_solutions/330.patching-array.java
# - Downloading patching-array
#   ✔ Accepted
#   ✔ 150/150 cases passed (1 ms)
#   ✔ Your runtime beats 2.94 % of java submissions
#   ✔ Your memory usage beats 51.32 % of java submissions (45.4 MB)
# Submitting: java_solutions/332.reconstruct-itinerary.java
# - Downloading reconstruct-itinerary
#   ✔ Accepted
#   ✔ 82/82 cases passed (12 ms)
#   ✔ Your runtime beats 10.9 % of java submissions
#   ✔ Your memory usage beats 74.77 % of java submissions (47.1 MB)
# Submitting: java_solutions/335.self-crossing.java
# - Downloading self-crossing
#   ✔ Accepted
#   ✔ 31/31 cases passed (10 ms)
#   ✔ Your runtime beats 23.35 % of java submissions
#   ✔ Your memory usage beats 16.99 % of java submissions (59.5 MB)
# Submitting: java_solutions/336.palindrome-pairs.java
# - Downloading palindrome-pairs
#   ✔ Accepted
#   ✔ 136/136 cases passed (2638 ms)
#   ✔ Your runtime beats 5.3 % of java submissions
#   ✔ Your memory usage beats 16.02 % of java submissions (65.4 MB)
# Submitting: java_solutions/338.counting-bits.java
# - Downloading counting-bits
#   ✔ Accepted
#   ✔ 15/15 cases passed (31 ms)
#   ✔ Your runtime beats 8.63 % of java submissions
#   ✔ Your memory usage beats 76.57 % of java submissions (48.6 MB)
# Submitting: java_solutions/342.power-of-four.java
# - Downloading power-of-four
#   ✔ Accepted
#   ✔ 1063/1063 cases passed (1 ms)
#   ✔ Your runtime beats 90.95 % of java submissions
#   ✔ Your memory usage beats 97.4 % of java submissions (42.2 MB)
# Submitting: java_solutions/344.reverse-string.java
# - Downloading reverse-string
#   ✔ Accepted
#   ✔ 477/477 cases passed (4 ms)
#   ✔ Your runtime beats 5.33 % of java submissions
#   ✔ Your memory usage beats 79.43 % of java submissions (48.1 MB)
# Submitting: java_solutions/345.reverse-vowels-of-a-string.java
# - Downloading reverse-vowels-of-a-string
#   ✔ Accepted
#   ✔ 480/480 cases passed (22 ms)
#   ✔ Your runtime beats 6.2 % of java submissions
#   ✔ Your memory usage beats 7.56 % of java submissions (47.6 MB)
# Submitting: java_solutions/347.top-k-frequent-elements.java
# - Downloading top-k-frequent-elements
#   ✔ Accepted
#   ✔ 23/23 cases passed (24 ms)
#   ✔ Your runtime beats 5.4 % of java submissions
#   ✔ Your memory usage beats 5.12 % of java submissions (56.3 MB)
# Submitting: java_solutions/349.intersection-of-two-arrays.java
# - Downloading intersection-of-two-arrays
#   ✔ Accepted
#   ✔ 57/57 cases passed (89 ms)
#   ✔ Your runtime beats 8.98 % of java submissions
#   ✔ Your memory usage beats 8.06 % of java submissions (47.1 MB)
# Submitting: java_solutions/350.intersection-of-two-arrays-ii.java
# - Downloading intersection-of-two-arrays-ii
#   ✔ Accepted
#   ✔ 61/61 cases passed (59 ms)
#   ✔ Your runtime beats 5.19 % of java submissions
#   ✔ Your memory usage beats 6.18 % of java submissions (47 MB)
# Submitting: java_solutions/352.data-stream-as-disjoint-intervals.java
# - Downloading data-stream-as-disjoint-intervals
#   ✔ Accepted
#   ✔ 8/8 cases passed (21 ms)
#   ✔ Your runtime beats 74.85 % of java submissions
#   ✔ Your memory usage beats 77.46 % of java submissions (45.3 MB)
# Submitting: java_solutions/354.russian-doll-envelopes.java
# - Downloading russian-doll-envelopes
#   ✔ Accepted
#   ✔ 87/87 cases passed (55 ms)
#   ✔ Your runtime beats 18.24 % of java submissions
#   ✔ Your memory usage beats 19.04 % of java submissions (104 MB)
# Submitting: java_solutions/363.max-sum-of-rectangle-no-larger-than-k.java
# - Downloading max-sum-of-rectangle-no-larger-than-k
#   ✔ Accepted
#   ✔ 36/36 cases passed (376 ms)
#   ✔ Your runtime beats 14.76 % of java submissions
#   ✔ Your memory usage beats 7.56 % of java submissions (47.6 MB)
# Submitting: java_solutions/367.valid-perfect-square.java
# - Downloading valid-perfect-square
#   ✔ Accepted
#   ✔ 72/72 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 44.78 % of java submissions (42.2 MB)
# Submitting: java_solutions/371.sum-of-two-integers.java
# - Downloading sum-of-two-integers
#   ✔ Accepted
#   ✔ 31/31 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 20.68 % of java submissions (42.3 MB)
# Submitting: java_solutions/372.super-pow.java
# - Downloading super-pow
#   ✔ Accepted
#   ✔ 57/57 cases passed (44 ms)
#   ✔ Your runtime beats 5.07 % of java submissions
#   ✔ Your memory usage beats 7.09 % of java submissions (47.6 MB)
# Submitting: java_solutions/374.guess-number-higher-or-lower.java
# - Downloading guess-number-higher-or-lower
#   ✔ Accepted
#   ✔ 25/25 cases passed (4 ms)
#   ✔ Your runtime beats 0.78 % of java submissions
#   ✔ Your memory usage beats 20.86 % of java submissions (42.2 MB)
# Submitting: java_solutions/381.insert-delete-getrandom-o1-duplicates-allowed.java
# - Downloading insert-delete-getrandom-o1-duplicates-allowed
#   ✔ Accepted
#   ✔ 32/32 cases passed (38 ms)
#   ✔ Your runtime beats 10.95 % of java submissions
#   ✔ Your memory usage beats 7.5 % of java submissions (100.7 MB)
# Submitting: java_solutions/383.ransom-note.java
# - Downloading ransom-note
#   ✔ Accepted
#   ✔ 130/130 cases passed (16 ms)
#   ✔ Your runtime beats 19.28 % of java submissions
#   ✔ Your memory usage beats 49.03 % of java submissions (46.6 MB)
# Submitting: java_solutions/386.lexicographical-numbers.java
# - Downloading lexicographical-numbers
#   ✔ Accepted
#   ✔ 27/27 cases passed (41 ms)
#   ✔ Your runtime beats 5.24 % of java submissions
#   ✔ Your memory usage beats 5.52 % of java submissions (55.3 MB)
# Submitting: java_solutions/387.first-unique-character-in-a-string.java
# - Downloading first-unique-character-in-a-string
#   ✔ Accepted
#   ✔ 107/107 cases passed (76 ms)
#   ✔ Your runtime beats 5.66 % of java submissions
#   ✔ Your memory usage beats 8.83 % of java submissions (53.1 MB)
# Submitting: java_solutions/389.find-the-difference.java
# - Downloading find-the-difference
#   ✔ Accepted
#   ✔ 54/54 cases passed (4 ms)
#   ✔ Your runtime beats 19.38 % of java submissions
#   ✔ Your memory usage beats 26.05 % of java submissions (43.3 MB)

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-04-13 22:54:55
