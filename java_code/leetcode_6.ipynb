# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME_2')
    user_cookie = userdata.get('LEETCODE_TOKEN_2')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME_2'] = user_name
    os.environ['LEETCODE_TOKEN_2'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME_2" "$LEETCODE_TOKEN_2" | leetcode user -c

# %%
# %%bash
#
#
# # top 100 answers
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v java_solutions/*.java | sed -n '501,600p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 7
# done
# Out:
# Submitting: java_solutions/1365.how-many-numbers-are-smaller-than-the-current-number.java
#   ✔ Accepted
#   ✔ 103/103 cases passed (25 ms)
#   ✔ Your runtime beats 7.52 % of java submissions
#   ✔ Your memory usage beats 11.11 % of java submissions (46.7 MB)
# Submitting: java_solutions/1368.minimum-cost-to-make-at-least-one-valid-path-in-a-grid.java
#   ✔ Accepted
#   ✔ 69/69 cases passed (21 ms)
#   ✔ Your runtime beats 49.5 % of java submissions
#   ✔ Your memory usage beats 13.28 % of java submissions (47.5 MB)
# Submitting: java_solutions/1373.maximum-sum-bst-in-binary-tree.java
#   ✔ Accepted
#   ✔ 60/60 cases passed (86 ms)
#   ✔ Your runtime beats 5.21 % of java submissions
#   ✔ Your memory usage beats 5.12 % of java submissions (72.7 MB)
# Submitting: java_solutions/1374.generate-a-string-with-characters-that-have-odd-counts.java
#   ✔ Accepted
#   ✔ 103/103 cases passed (2 ms)
#   ✔ Your runtime beats 39.62 % of java submissions
#   ✔ Your memory usage beats 25.85 % of java submissions (43.1 MB)
# Submitting: java_solutions/1377.frog-position-after-t-seconds.java
#   ✔ Accepted
#   ✔ 207/207 cases passed (11 ms)
#   ✔ Your runtime beats 8.33 % of java submissions
#   ✔ Your memory usage beats 6.75 % of java submissions (48.4 MB)
# Submitting: java_solutions/1380.lucky-numbers-in-a-matrix.java
#   ✔ Accepted
#   ✔ 106/106 cases passed (76 ms)
#   ✔ Your runtime beats 7.35 % of java submissions
#   ✔ Your memory usage beats 9.3 % of java submissions (53.4 MB)
# Submitting: java_solutions/1383.maximum-performance-of-a-team.java
#   ✔ Accepted
#   ✔ 55/55 cases passed (42 ms)
#   ✔ Your runtime beats 41.42 % of java submissions
#   ✔ Your memory usage beats 84.43 % of java submissions (66.4 MB)
# Submitting: java_solutions/1385.find-the-distance-value-between-two-arrays.java
#   ✔ Accepted
#   ✔ 103/103 cases passed (23 ms)
#   ✔ Your runtime beats 6.96 % of java submissions
#   ✔ Your memory usage beats 26.91 % of java submissions (46.5 MB)
# Submitting: java_solutions/1388.pizza-with-3n-slices.java
#   ✔ Accepted
#   ✔ 69/69 cases passed (17 ms)
#   ✔ Your runtime beats 7.14 % of java submissions
#   ✔ Your memory usage beats 70.13 % of java submissions (46.4 MB)
# Submitting: java_solutions/1388.pizza-with-3-n-slices.java
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 4: error: missing return statement
#   ✘ Error: Line 4: error: missing return statement
#     }
#     ^
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: java_solutions/1389.create-target-array-in-the-given-order.java
#   ✔ Accepted
#   ✔ 45/45 cases passed (6 ms)
#   ✔ Your runtime beats 0.32 % of java submissions
#   ✔ Your memory usage beats 13.99 % of java submissions (50.4 MB)
# Submitting: java_solutions/1392.longest-happy-prefix.java
#   ✔ Accepted
#   ✔ 83/83 cases passed (16 ms)
#   ✔ Your runtime beats 6.95 % of java submissions
#   ✔ Your memory usage beats 66.83 % of java submissions (47.6 MB)
# Submitting: java_solutions/1397.find-all-good-strings.java
#   ✔ Accepted
#   ✔ 55/55 cases passed (76 ms)
#   ✔ Your runtime beats 6.31 % of java submissions
#   ✔ Your memory usage beats 65.77 % of java submissions (45.8 MB)
# Submitting: java_solutions/1402.reducing-dishes.java
#   ✔ Accepted
#   ✔ 60/60 cases passed (9 ms)
#   ✔ Your runtime beats 32.49 % of java submissions
#   ✔ Your memory usage beats 29.23 % of java submissions (44.5 MB)
# Submitting: java_solutions/1406.stone-game-iii.java
#   ✔ Accepted
#   ✔ 185/185 cases passed (18 ms)
#   ✔ Your runtime beats 56.6 % of java submissions
#   ✔ Your memory usage beats 93.25 % of java submissions (82.1 MB)
# Submitting: java_solutions/1408.string-matching-in-an-array.java
#   ✔ Accepted
#   ✔ 69/69 cases passed (8 ms)
#   ✔ Your runtime beats 7.42 % of java submissions
#   ✔ Your memory usage beats 7.83 % of java submissions (44.2 MB)
# Submitting: java_solutions/1411.number-of-ways-to-paint-n-3-grid.java
#   ✔ Accepted
#   ✔ 50/50 cases passed (10 ms)
#   ✔ Your runtime beats 17.99 % of java submissions
#   ✔ Your memory usage beats 23.85 % of java submissions (42.5 MB)
# Submitting: java_solutions/1413.minimum-value-to-get-positive-step-by-step-sum.java
#   ✔ Accepted
#   ✔ 57/57 cases passed (4 ms)
#   ✔ Your runtime beats 1.06 % of java submissions
#   ✔ Your memory usage beats 34.75 % of java submissions (43 MB)
# Submitting: java_solutions/1416.restore-the-array.java
#   ✔ Accepted
#   ✔ 86/86 cases passed (30 ms)
#   ✔ Your runtime beats 64.52 % of java submissions
#   ✔ Your memory usage beats 98.16 % of java submissions (46.1 MB)
# Submitting: java_solutions/1417.reformat-the-string.java
#   ✔ Accepted
#   ✔ 302/302 cases passed (18 ms)
#   ✔ Your runtime beats 5.01 % of java submissions
#   ✔ Your memory usage beats 15.93 % of java submissions (47 MB)
# Submitting: java_solutions/1420.build-array-where-you-can-find-the-maximum-exactly-k-comparisons.java
#   ✔ Accepted
#   ✔ 31/31 cases passed (127 ms)
#   ✔ Your runtime beats 45.29 % of java submissions
#   ✔ Your memory usage beats 76.47 % of java submissions (45.9 MB)
# Submitting: java_solutions/1422.maximum-score-after-splitting-a-string.java
#   ✔ Accepted
#   ✔ 104/104 cases passed (36 ms)
#   ✔ Your runtime beats 5.99 % of java submissions
#   ✔ Your memory usage beats 5.64 % of java submissions (47 MB)
# Submitting: java_solutions/1425.constrained-subsequence-sum.java
#   ✔ Accepted
#   ✔ 40/40 cases passed (99 ms)
#   ✔ Your runtime beats 5.08 % of java submissions
#   ✔ Your memory usage beats 6.03 % of java submissions (141.9 MB)
# Submitting: java_solutions/1434.number-of-ways-to-wear-different-hats-to-each-other.java
#   ✔ Accepted
#   ✔ 65/65 cases passed (25 ms)
#   ✔ Your runtime beats 27.91 % of java submissions
#   ✔ Your memory usage beats 97.09 % of java submissions (43.2 MB)
# Submitting: java_solutions/1436.destination-city.java
#   ✔ Accepted
#   ✔ 104/104 cases passed (10 ms)
#   ✔ Your runtime beats 5.8 % of java submissions
#   ✔ Your memory usage beats 8.38 % of java submissions (46.1 MB)
# Submitting: java_solutions/1437.check-if-all-1s-are-at-least-length-k-places-away.java
#   ✔ Accepted
#   ✔ 71/71 cases passed (19 ms)
#   ✔ Your runtime beats 2.99 % of java submissions
#   ✔ Your memory usage beats 5.02 % of java submissions (69.4 MB)
# Submitting: java_solutions/1439.find-the-kth-smallest-sum-of-a-matrix-with-sorted-rows.java
#   ✔ Accepted
#   ✔ 72/72 cases passed (221 ms)
#   ✔ Your runtime beats 10.94 % of java submissions
#   ✔ Your memory usage beats 68.23 % of java submissions (46.8 MB)
# Submitting: java_solutions/1444.number-of-ways-of-cutting-a-pizza.java
#   ✔ Accepted
#   ✔ 54/54 cases passed (23 ms)
#   ✔ Your runtime beats 5.03 % of java submissions
#   ✔ Your memory usage beats 7.55 % of java submissions (44 MB)
# Submitting: java_solutions/1446.consecutive-characters.java
#   ✔ Accepted
#   ✔ 333/333 cases passed (21 ms)
#   ✔ Your runtime beats 2.43 % of java submissions
#   ✔ Your memory usage beats 7.11 % of java submissions (47.1 MB)
# Submitting: java_solutions/1449.form-largest-integer-with-digits-that-add-up-to-target.java
#   ✔ Accepted
#   ✔ 96/96 cases passed (10 ms)
#   ✔ Your runtime beats 50.51 % of java submissions
#   ✔ Your memory usage beats 53.54 % of java submissions (43.7 MB)
# Submitting: java_solutions/1453.maximum-number-of-darts-inside-of-a-circular-dartboard.java
#   ✔ Accepted
#   ✔ 65/65 cases passed (43 ms)
#   ✔ Your runtime beats 59.74 % of java submissions
#   ✔ Your memory usage beats 22.73 % of java submissions (43.7 MB)
# Submitting: java_solutions/1455.check-if-a-word-occurs-as-a-prefix-of-any-word-in-a-sentence.java
#   ✔ Accepted
#   ✔ 45/45 cases passed (4 ms)
#   ✔ Your runtime beats 0.29 % of java submissions
#   ✔ Your memory usage beats 11.31 % of java submissions (43.2 MB)
# Submitting: java_solutions/1458.max-dot-product-of-two-subsequences.java
#   ✔ Accepted
#   ✔ 70/70 cases passed (15 ms)
#   ✔ Your runtime beats 11.03 % of java submissions
#   ✔ Your memory usage beats 78.12 % of java submissions (46.4 MB)
# Submitting: java_solutions/1460.make-two-arrays-equal-by-reversing-subarrays.java
#   ✔ Accepted
#   ✔ 109/109 cases passed (10 ms)
#   ✔ Your runtime beats 8.57 % of java submissions
#   ✔ Your memory usage beats 39.02 % of java submissions (46.8 MB)
# Submitting: java_solutions/1463.cherry-pickup-ii.java
#   ✔ Accepted
#   ✔ 59/59 cases passed (48 ms)
#   ✔ Your runtime beats 5.16 % of java submissions
#   ✔ Your memory usage beats 15.36 % of java submissions (48.1 MB)
# Submitting: java_solutions/1464.maximum-product-of-two-elements-in-an-array.java
#   ✔ Accepted
#   ✔ 104/104 cases passed (11 ms)
#   ✔ Your runtime beats 13.04 % of java submissions
#   ✔ Your memory usage beats 7.79 % of java submissions (45.6 MB)
# Submitting: java_solutions/1467.probability-of-a-two-boxes-having-the-same-number-of-distinct-balls.java
#   ✔ Accepted
#   ✔ 21/21 cases passed (17 ms)
#   ✔ Your runtime beats 81.58 % of java submissions
#   ✔ Your memory usage beats 7.89 % of java submissions (47.3 MB)
# Submitting: java_solutions/1470.shuffle-the-array.java
#   ✔ Accepted
#   ✔ 53/53 cases passed (4 ms)
#   ✔ Your runtime beats 1.14 % of java submissions
#   ✔ Your memory usage beats 29.16 % of java submissions (46.7 MB)
# Submitting: java_solutions/1473.paint-house-iii.java
#   ✔ Accepted
#   ✔ 62/62 cases passed (34 ms)
#   ✔ Your runtime beats 13.85 % of java submissions
#   ✔ Your memory usage beats 51.3 % of java submissions (46.5 MB)
# Submitting: java_solutions/1478.allocate-mailboxes.java
#   ✔ Accepted
#   ✔ 69/69 cases passed (26 ms)
#   ✔ Your runtime beats 20.69 % of java submissions
#   ✔ Your memory usage beats 28.28 % of java submissions (44.2 MB)
# Submitting: java_solutions/1480.running-sum-of-1d-array.java
#   ✔ Accepted
#   ✔ 54/54 cases passed (3 ms)
#   ✔ Your runtime beats 1.82 % of java submissions
#   ✔ Your memory usage beats 8.56 % of java submissions (44.6 MB)
# Submitting: java_solutions/1483.kth-ancestor-of-a-tree-node.java
#   ✔ Accepted
#   ✔ 17/17 cases passed (85 ms)
#   ✔ Your runtime beats 9.41 % of java submissions
#   ✔ Your memory usage beats 52.23 % of java submissions (110.8 MB)
# Submitting: java_solutions/1486.xor-operation-in-an-array.java
#   ✔ Accepted
#   ✔ 54/54 cases passed (3 ms)
#   ✔ Your runtime beats 0.91 % of java submissions
#   ✔ Your memory usage beats 44.87 % of java submissions (42.2 MB)
# Submitting: java_solutions/1489.find-critical-and-pseudo-critical-edges-in-minimum-spanning-tree.java
#   ✔ Accepted
#   ✔ 66/66 cases passed (37 ms)
#   ✔ Your runtime beats 20.46 % of java submissions
#   ✔ Your memory usage beats 5.02 % of java submissions (52.7 MB)
# Submitting: java_solutions/1491.average-salary-excluding-the-minimum-and-maximum-salary.java
#   ✔ Accepted
#   ✔ 43/43 cases passed (7 ms)
#   ✔ Your runtime beats 0.85 % of java submissions
#   ✔ Your memory usage beats 6.41 % of java submissions (46.2 MB)
# Submitting: java_solutions/1494.parallel-courses-ii.java
#   ✔ Accepted
#   ✔ 82/82 cases passed (204 ms)
#   ✔ Your runtime beats 18.88 % of java submissions
#   ✔ Your memory usage beats 65.31 % of java submissions (45 MB)
# Submitting: java_solutions/1496.path-crossing.java
#   ✔ Accepted
#   ✔ 85/85 cases passed (6 ms)
#   ✔ Your runtime beats 6.73 % of java submissions
#   ✔ Your memory usage beats 57.19 % of java submissions (43.5 MB)
# Submitting: java_solutions/1499.max-value-of-equation.java
#   ✔ Accepted
#   ✔ 66/66 cases passed (18 ms)
#   ✔ Your runtime beats 68.67 % of java submissions
#   ✔ Your memory usage beats 90.67 % of java submissions (113.4 MB)
# Submitting: java_solutions/1502.can-make-arithmetic-progression-from-sequence.java
#   ✔ Accepted
#   ✔ 113/113 cases passed (5 ms)
#   ✔ Your runtime beats 83.58 % of java submissions
#   ✔ Your memory usage beats 5.44 % of java submissions (45.5 MB)
# Submitting: java_solutions/1505.minimum-possible-integer-after-at-most-k-adjacent-swaps-on-digits.java
#   ✔ Accepted
#   ✔ 50/50 cases passed (28 ms)
#   ✔ Your runtime beats 38.84 % of java submissions
#   ✔ Your memory usage beats 19.42 % of java submissions (48.3 MB)
# Submitting: java_solutions/1507.reformat-date.java
#   ✔ Accepted
#   ✔ 110/110 cases passed (6 ms)
#   ✔ Your runtime beats 25.12 % of java submissions
#   ✔ Your memory usage beats 15.81 % of java submissions (44 MB)
# Submitting: java_solutions/1510.stone-game-iv.java
#   ✔ Accepted
#   ✔ 72/72 cases passed (27 ms)
#   ✔ Your runtime beats 46.03 % of java submissions
#   ✔ Your memory usage beats 58.73 % of java submissions (42.6 MB)
# Submitting: java_solutions/1512.number-of-good-pairs.java
#   ✔ Accepted
#   ✔ 49/49 cases passed (10 ms)
#   ✔ Your runtime beats 0.61 % of java submissions
#   ✔ Your memory usage beats 13.93 % of java submissions (49.6 MB)
# Submitting: java_solutions/1515.best-position-for-a-service-centre.java
#   ✔ Accepted
#   ✔ 56/56 cases passed (12 ms)
#   ✔ Your runtime beats 23.94 % of java submissions
#   ✔ Your memory usage beats 22.53 % of java submissions (46.8 MB)
# Submitting: java_solutions/1520.maximum-number-of-non-overlapping-substrings.java
#   ✔ Accepted
#   ✔ 285/285 cases passed (19 ms)
#   ✔ Your runtime beats 40.14 % of java submissions
#   ✔ Your memory usage beats 20.41 % of java submissions (48.5 MB)
# Submitting: java_solutions/1521.find-a-value-of-a-mysterious-function-closest-to-target.java
#   ✔ Accepted
#   ✔ 43/43 cases passed (21 ms)
#   ✔ Your runtime beats 88.06 % of java submissions
#   ✔ Your memory usage beats 94.03 % of java submissions (73.9 MB)
# Submitting: java_solutions/1523.count-odd-numbers-in-an-interval-range.java
#   ✔ Accepted
#   ✔ 84/84 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 12.01 % of java submissions (42.3 MB)
# Submitting: java_solutions/1526.minimum-number-of-increments-on-subarrays-to-form-a-target-array.java
#   ✔ Accepted
#   ✔ 129/129 cases passed (6 ms)
#   ✔ Your runtime beats 4.29 % of java submissions
#   ✔ Your memory usage beats 43.34 % of java submissions (74.8 MB)
# Submitting: java_solutions/1528.shuffle-string.java
#   ✔ Accepted
#   ✔ 399/399 cases passed (23 ms)
#   ✔ Your runtime beats 6.79 % of java submissions
#   ✔ Your memory usage beats 5.78 % of java submissions (47.6 MB)
# Submitting: java_solutions/1531.string-compression-ii.java
#   ✔ Accepted
#   ✔ 144/144 cases passed (79 ms)
#   ✔ Your runtime beats 21.26 % of java submissions
#   ✔ Your memory usage beats 64.57 % of java submissions (44.3 MB)
# Submitting: java_solutions/1534.count-good-triplets.java
#   ✔ Accepted
#   ✔ 92/92 cases passed (76 ms)
#   ✔ Your runtime beats 8.31 % of java submissions
#   ✔ Your memory usage beats 6.92 % of java submissions (53 MB)
# Submitting: java_solutions/1537.get-the-maximum-score.java
#   ✔ Accepted
#   ✔ 82/82 cases passed (11 ms)
#   ✔ Your runtime beats 7.3 % of java submissions
#   ✔ Your memory usage beats 95.51 % of java submissions (60.8 MB)
# Submitting: java_solutions/1539.kth-missing-positive-number.java
#   ✔ Accepted
#   ✔ 87/87 cases passed (7 ms)
#   ✔ Your runtime beats 5.39 % of java submissions
#   ✔ Your memory usage beats 6.15 % of java submissions (45.9 MB)
# Submitting: java_solutions/1542.find-longest-awesome-substring.java
#   ✔ Accepted
#   ✔ 153/153 cases passed (21 ms)
#   ✔ Your runtime beats 55.76 % of java submissions
#   ✔ Your memory usage beats 52.12 % of java submissions (46.8 MB)
# Submitting: java_solutions/1544.make-the-string-great.java
#   ✔ Accepted
#   ✔ 335/335 cases passed (10 ms)
#   ✔ Your runtime beats 6.57 % of java submissions
#   ✔ Your memory usage beats 5.39 % of java submissions (45 MB)
# Submitting: java_solutions/1547.minimum-cost-to-cut-a-stick.java
#   ✔ Accepted
#   ✔ 101/101 cases passed (34 ms)
#   ✔ Your runtime beats 11.12 % of java submissions
#   ✔ Your memory usage beats 12.68 % of java submissions (44.9 MB)
# Submitting: java_solutions/1550.three-consecutive-odds.java
#   ✔ Accepted
#   ✔ 38/38 cases passed (4 ms)
#   ✔ Your runtime beats 0.26 % of java submissions
#   ✔ Your memory usage beats 8.51 % of java submissions (45 MB)
# Submitting: java_solutions/1553.minimum-number-of-days-to-eat-n-oranges.java
#   ✔ Accepted
#   ✔ 176/176 cases passed (14 ms)
#   ✔ Your runtime beats 11.59 % of java submissions
#   ✔ Your memory usage beats 15.22 % of java submissions (44.8 MB)
# Submitting: java_solutions/1556.thousand-separator.java
#   ✔ Accepted
#   ✔ 69/69 cases passed (9 ms)
#   ✔ Your runtime beats 4.19 % of java submissions
#   ✔ Your memory usage beats 10.38 % of java submissions (43.4 MB)
# Submitting: java_solutions/1563.stone-game-v.java
#   ✔ Accepted
#   ✔ 132/132 cases passed (1215 ms)
#   ✔ Your runtime beats 5.19 % of java submissions
#   ✔ Your memory usage beats 79.22 % of java submissions (47.5 MB)
# Submitting: java_solutions/1568.minimum-number-of-days-to-disconnect-island.java
#   ✔ Accepted
#   ✔ 104/104 cases passed (53 ms)
#   ✔ Your runtime beats 5.75 % of java submissions
#   ✔ Your memory usage beats 5.11 % of java submissions (47.5 MB)
# Submitting: java_solutions/1569.number-of-ways-to-reorder-array-to-get-same-bst.java
#   ✔ Accepted
#   ✔ 161/161 cases passed (91 ms)
#   ✔ Your runtime beats 29.56 % of java submissions
#   ✔ Your memory usage beats 57.14 % of java submissions (169.9 MB)
# Submitting: java_solutions/1572.matrix-diagonal-sum.java
#   ✔ Accepted
#   ✔ 114/114 cases passed (7 ms)
#   ✔ Your runtime beats 0.65 % of java submissions
#   ✔ Your memory usage beats 38.66 % of java submissions (46.4 MB)
# Submitting: java_solutions/1575.count-all-possible-routes.java
#   ✔ Accepted
#   ✔ 109/109 cases passed (132 ms)
#   ✔ Your runtime beats 5.74 % of java submissions
#   ✔ Your memory usage beats 36.36 % of java submissions (46.4 MB)
# Submitting: java_solutions/1579.remove-max-number-of-edges-to-keep-graph-fully-traversable.java
#   ✔ Accepted
#   ✔ 86/86 cases passed (19 ms)
#   ✔ Your runtime beats 41.67 % of java submissions
#   ✔ Your memory usage beats 96.93 % of java submissions (135.2 MB)
# Submitting: java_solutions/1585.check-if-string-is-transformable-with-substring-sort-operations.java
#   ✔ Accepted
#   ✔ 138/138 cases passed (25 ms)
#   ✔ Your runtime beats 52.63 % of java submissions
#   ✔ Your memory usage beats 56.14 % of java submissions (51.7 MB)
# Submitting: java_solutions/1591.strange-printer-ii.java
#   ✔ Accepted
#   ✔ 153/153 cases passed (19 ms)
#   ✔ Your runtime beats 77 % of java submissions
#   ✔ Your memory usage beats 34 % of java submissions (47.4 MB)
# Submitting: java_solutions/1592.rearrange-spaces-between-words.java
#   ✔ Accepted
#   ✔ 90/90 cases passed (5 ms)
#   ✔ Your runtime beats 15.98 % of java submissions
#   ✔ Your memory usage beats 5.23 % of java submissions (44.2 MB)
# Submitting: java_solutions/1595.minimum-cost-to-connect-two-groups-of-points.java
# - Downloading minimum-cost-to-connect-two-groups-of-points
#   ✔ Accepted
#   ✔ 84/84 cases passed (78 ms)
#   ✔ Your runtime beats 29.07 % of java submissions
#   ✔ Your memory usage beats 97.67 % of java submissions (43.6 MB)
# Submitting: java_solutions/1601.maximum-number-of-achievable-transfer-requests.java
# - Downloading maximum-number-of-achievable-transfer-requests
#   ✔ Accepted
#   ✔ 117/117 cases passed (222 ms)
#   ✔ Your runtime beats 6.92 % of java submissions
#   ✔ Your memory usage beats 40.88 % of java submissions (43.2 MB)
# Submitting: java_solutions/1606.find-servers-that-handled-most-number-of-requests.java
# - Downloading find-servers-that-handled-most-number-of-requests
#   ✔ Accepted
#   ✔ 108/108 cases passed (151 ms)
#   ✔ Your runtime beats 17.79 % of java submissions
#   ✔ Your memory usage beats 6.13 % of java submissions (110.2 MB)
# Submitting: java_solutions/1610.maximum-number-of-visible-points.java
# - Downloading maximum-number-of-visible-points
#   ✔ Accepted
#   ✔ 119/119 cases passed (120 ms)
#   ✔ Your runtime beats 90.98 % of java submissions
#   ✔ Your memory usage beats 86.89 % of java submissions (159.1 MB)
# Submitting: java_solutions/1611.minimum-one-bit-operations-to-make-integers-zero.java
# - Downloading minimum-one-bit-operations-to-make-integers-zero
#   ✔ Accepted
#   ✔ 308/308 cases passed (5 ms)
#   ✔ Your runtime beats 1.33 % of java submissions
#   ✔ Your memory usage beats 10.44 % of java submissions (42.6 MB)
# Submitting: java_solutions/1614.maximum-nesting-depth-of-the-parentheses.java
# - Downloading maximum-nesting-depth-of-the-parentheses
#   ✔ Accepted
#   ✔ 168/168 cases passed (5 ms)
#   ✔ Your runtime beats 0.36 % of java submissions
#   ✔ Your memory usage beats 6.81 % of java submissions (47.2 MB)
# Submitting: java_solutions/1617.count-subtrees-with-max-distance-between-cities.java
# - Downloading count-subtrees-with-max-distance-between-cities
#   ✔ Accepted
#   ✔ 31/31 cases passed (37 ms)
#   ✔ Your runtime beats 67.69 % of java submissions
#   ✔ Your memory usage beats 75.38 % of java submissions (43.6 MB)
# Submitting: java_solutions/1619.mean-of-array-after-removing-some-elements.java
# - Downloading mean-of-array-after-removing-some-elements
#   ✔ Accepted
#   ✔ 50/50 cases passed (3 ms)
#   ✔ Your runtime beats 99.51 % of java submissions
#   ✔ Your memory usage beats 10.2 % of java submissions (47.6 MB)
# Submitting: java_solutions/1622.fancy-sequence.java
# - Downloading fancy-sequence
#   ✔ Accepted
#   ✔ 107/107 cases passed (68 ms)
#   ✔ Your runtime beats 9.52 % of java submissions
#   ✔ Your memory usage beats 5.55 % of java submissions (128.7 MB)
# Submitting: java_solutions/1624.largest-substring-between-two-equal-characters.java
# - Downloading largest-substring-between-two-equal-characters
#   ✔ Accepted
#   ✔ 59/59 cases passed (3 ms)
#   ✔ Your runtime beats 33.1 % of java submissions
#   ✔ Your memory usage beats 5.15 % of java submissions (43.6 MB)
# Submitting: java_solutions/1627.graph-connectivity-with-threshold.java
# - Downloading graph-connectivity-with-threshold
#   ✔ Accepted
#   ✔ 67/67 cases passed (16 ms)
#   ✔ Your runtime beats 23.77 % of java submissions
#   ✔ Your memory usage beats 7.38 % of java submissions (82.5 MB)
# Submitting: java_solutions/1629.slowest-key.java
# - Downloading slowest-key
#   ✔ Accepted
#   ✔ 109/109 cases passed (5 ms)
#   ✔ Your runtime beats 7.17 % of java submissions
#   ✔ Your memory usage beats 5.87 % of java submissions (52.9 MB)
# Submitting: java_solutions/1632.rank-transform-of-a-matrix.java
# - Downloading rank-transform-of-a-matrix
#   ✔ Accepted
#   ✔ 41/41 cases passed (112 ms)
#   ✔ Your runtime beats 32.14 % of java submissions
#   ✔ Your memory usage beats 52.38 % of java submissions (111.3 MB)
# Submitting: java_solutions/1636.sort-array-by-increasing-frequency.java
# - Downloading sort-array-by-increasing-frequency
#   ✔ Accepted
#   ✔ 180/180 cases passed (21 ms)
#   ✔ Your runtime beats 5.23 % of java submissions
#   ✔ Your memory usage beats 5.38 % of java submissions (52.7 MB)
# Submitting: java_solutions/1639.number-of-ways-to-form-a-target-string-given-a-dictionary.java
# - Downloading number-of-ways-to-form-a-target-string-given-a-dictionary
#   ✔ Accepted
#   ✔ 90/90 cases passed (66 ms)
#   ✔ Your runtime beats 18.03 % of java submissions
#   ✔ Your memory usage beats 96.72 % of java submissions (50.7 MB)
# Submitting: java_solutions/1643.kth-smallest-instructions.java
# - Downloading kth-smallest-instructions
#   ✔ Accepted
#   ✔ 462/462 cases passed (8 ms)
#   ✔ Your runtime beats 5.36 % of java submissions
#   ✔ Your memory usage beats 5.36 % of java submissions (46.6 MB)
# Submitting: java_solutions/1646.get-maximum-in-generated-array.java
# - Downloading get-maximum-in-generated-array
#   ✔ Accepted
#   ✔ 101/101 cases passed (7 ms)
#   ✔ Your runtime beats 4.93 % of java submissions
#   ✔ Your memory usage beats 8.92 % of java submissions (42.9 MB)
# Submitting: java_solutions/1649.create-sorted-array-through-instructions.java
# - Downloading create-sorted-array-through-instructions
#   ✔ Accepted
#   ✔ 65/65 cases passed (56 ms)
#   ✔ Your runtime beats 42.71 % of java submissions
#   ✔ Your memory usage beats 92.46 % of java submissions (98.6 MB)
# Submitting: java_solutions/1652.defuse-the-bomb.java
# - Downloading defuse-the-bomb
#   ✔ Accepted
#   ✔ 74/74 cases passed (17 ms)
#   ✔ Your runtime beats 2.39 % of java submissions
#   ✔ Your memory usage beats 6.41 % of java submissions (51.3 MB)
# Submitting: java_solutions/1655.distribute-repeating-integers.java
# - Downloading distribute-repeating-integers
#   ✔ Accepted
#   ✔ 109/109 cases passed (75 ms)
#   ✔ Your runtime beats 62.64 % of java submissions
#   ✔ Your memory usage beats 6.59 % of java submissions (277.2 MB)
# Submitting: java_solutions/1659.maximize-grid-happiness.java
# - Downloading maximize-grid-happiness
#   ✔ Accepted
#   ✔ 67/67 cases passed (72 ms)
#   ✔ Your runtime beats 71.43 % of java submissions
#   ✔ Your memory usage beats 55.1 % of java submissions (51 MB)
# Submitting: java_solutions/1662.check-if-two-string-arrays-are-equivalent.java
# - Downloading check-if-two-string-arrays-are-equivalent
#   ✔ Accepted
#   ✔ 113/113 cases passed (3 ms)
#   ✔ Your runtime beats 8.64 % of java submissions
#   ✔ Your memory usage beats 77.18 % of java submissions (43.1 MB)

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-04-14 11:52:09
