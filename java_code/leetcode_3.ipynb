# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME')
    user_cookie = userdata.get('LEETCODE_TOKEN')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME'] = user_name
    os.environ['LEETCODE_TOKEN'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME" "$LEETCODE_TOKEN" | leetcode user -c

# %%
# %%bash
#
#
# # top 100 answers
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v java_solutions/*.java | sed -n '201,300p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 7
# done
# Out:
# Submitting: java_solutions/391.perfect-rectangle.java
# - Downloading problems
# - Downloading perfect-rectangle
#   ✔ Accepted
#   ✔ 49/49 cases passed (48 ms)
#   ✔ Your runtime beats 20.53 % of java submissions
#   ✔ Your memory usage beats 26.04 % of java submissions (57 MB)
# Submitting: java_solutions/392.is-subsequence.java
# - Downloading is-subsequence
#   ✔ Accepted
#   ✔ 22/22 cases passed (4 ms)
#   ✔ Your runtime beats 3.69 % of java submissions
#   ✔ Your memory usage beats 5.16 % of java submissions (43.3 MB)
# Submitting: java_solutions/394.decode-string.java
# - Downloading decode-string
#   ✔ Accepted
#   ✔ 34/34 cases passed (6 ms)
#   ✔ Your runtime beats 2.65 % of java submissions
#   ✔ Your memory usage beats 6.72 % of java submissions (43.4 MB)
# Submitting: java_solutions/397.integer-replacement.java
# - Downloading integer-replacement
#   ✔ Accepted
#   ✔ 47/47 cases passed (2 ms)
#   ✔ Your runtime beats 15.34 % of java submissions
#   ✔ Your memory usage beats 6.11 % of java submissions (42.5 MB)
# Submitting: java_solutions/403.frog-jump.java
# - Downloading frog-jump
#   ✔ Accepted
#   ✔ 55/55 cases passed (24 ms)
#   ✔ Your runtime beats 86.66 % of java submissions
#   ✔ Your memory usage beats 47.41 % of java submissions (50.5 MB)
# Submitting: java_solutions/404.sum-of-left-leaves.java
# - Downloading sum-of-left-leaves
#   ✔ Accepted
#   ✔ 100/100 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 86.11 % of java submissions (43 MB)
# Submitting: java_solutions/405.convert-a-number-to-hexadecimal.java
# - Downloading convert-a-number-to-hexadecimal
#   ✔ Accepted
#   ✔ 100/100 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 71.58 % of java submissions (42.5 MB)
# Submitting: java_solutions/407.trapping-rain-water-ii.java
# - Downloading trapping-rain-water-ii
#   ✔ Accepted
#   ✔ 42/42 cases passed (40 ms)
#   ✔ Your runtime beats 6.13 % of java submissions
#   ✔ Your memory usage beats 10.27 % of java submissions (50 MB)
# Submitting: java_solutions/409.longest-palindrome.java
# - Downloading longest-palindrome
#   ✔ Accepted
#   ✔ 98/98 cases passed (18 ms)
#   ✔ Your runtime beats 8.34 % of java submissions
#   ✔ Your memory usage beats 5.34 % of java submissions (50.3 MB)
# Submitting: java_solutions/410.split-array-largest-sum.java
# - Downloading split-array-largest-sum
#   ✔ Accepted
#   ✔ 35/35 cases passed (8 ms)
#   ✔ Your runtime beats 5.54 % of java submissions
#   ✔ Your memory usage beats 22.36 % of java submissions (43.3 MB)
# Submitting: java_solutions/412.fizz-buzz.java
# - Downloading fizz-buzz
#   ✔ Accepted
#   ✔ 8/8 cases passed (2 ms)
#   ✔ Your runtime beats 19.76 % of java submissions
#   ✔ Your memory usage beats 16.84 % of java submissions (47.1 MB)
# Submitting: java_solutions/414.third-maximum-number.java
# - Downloading third-maximum-number
#   ✔ Accepted
#   ✔ 34/34 cases passed (17 ms)
#   ✔ Your runtime beats 5.32 % of java submissions
#   ✔ Your memory usage beats 6.89 % of java submissions (47.2 MB)
# Submitting: java_solutions/415.add-strings.java
# - Downloading add-strings
#   ✔ Accepted
#   ✔ 317/317 cases passed (19 ms)
#   ✔ Your runtime beats 9.12 % of java submissions
#   ✔ Your memory usage beats 12.83 % of java submissions (45.9 MB)
# Submitting: java_solutions/420.strong-password-checker.java
# - Downloading strong-password-checker
#   ✔ Accepted
#   ✔ 54/54 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 51.57 % of java submissions (42.7 MB)
# Submitting: java_solutions/432.all-oone-data-structure.java
# - Downloading all-oone-data-structure
#   ✔ Accepted
#   ✔ 25/25 cases passed (97 ms)
#   ✔ Your runtime beats 14.42 % of java submissions
#   ✔ Your memory usage beats 9.51 % of java submissions (80.7 MB)
# Submitting: java_solutions/434.number-of-segments-in-a-string.java
# - Downloading number-of-segments-in-a-string
#   ✔ Accepted
#   ✔ 28/28 cases passed (1 ms)
#   ✔ Your runtime beats 30.62 % of java submissions
#   ✔ Your memory usage beats 74.36 % of java submissions (42.5 MB)
# Submitting: java_solutions/438.find-all-anagrams-in-a-string.java
# - Downloading find-all-anagrams-in-a-string
#   ✔ Accepted
#   ✔ 65/65 cases passed (42 ms)
#   ✔ Your runtime beats 27.09 % of java submissions
#   ✔ Your memory usage beats 5.05 % of java submissions (53.5 MB)
# Submitting: java_solutions/440.k-th-smallest-in-lexicographical-order.java
# - Downloading k-th-smallest-in-lexicographical-order
#   ✔ Accepted
#   ✔ 70/70 cases passed (1 ms)
#   ✔ Your runtime beats 5.53 % of java submissions
#   ✔ Your memory usage beats 45.91 % of java submissions (42.2 MB)
# Submitting: java_solutions/441.arranging-coins.java
# - Downloading arranging-coins
#   ✔ Accepted
#   ✔ 1336/1336 cases passed (1 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 49.3 % of java submissions (42.8 MB)
# Submitting: java_solutions/442.find-all-duplicates-in-an-array.java
# - Downloading find-all-duplicates-in-an-array
#   ✔ Accepted
#   ✔ 29/29 cases passed (10 ms)
#   ✔ Your runtime beats 43.51 % of java submissions
#   ✔ Your memory usage beats 47.61 % of java submissions (60.3 MB)
# Submitting: java_solutions/443.string-compression.java
# - Downloading string-compression
#   ✔ Accepted
#   ✔ 77/77 cases passed (17 ms)
#   ✔ Your runtime beats 5.89 % of java submissions
#   ✔ Your memory usage beats 5.07 % of java submissions (52.6 MB)
# Submitting: java_solutions/445.add-two-numbers-ii.java
# - Downloading add-two-numbers-ii
#   ✔ Accepted
#   ✔ 1563/1563 cases passed (24 ms)
#   ✔ Your runtime beats 2.87 % of java submissions
#   ✔ Your memory usage beats 5.68 % of java submissions (47.5 MB)
# Submitting: java_solutions/446.arithmetic-slices-ii-subsequence.java
# - Downloading arithmetic-slices-ii-subsequence
#   ✔ Accepted
#   ✔ 101/101 cases passed (234 ms)
#   ✔ Your runtime beats 8.78 % of java submissions
#   ✔ Your memory usage beats 7.39 % of java submissions (112.2 MB)
# Submitting: java_solutions/448.find-all-numbers-disappeared-in-an-array.java
# - Downloading find-all-numbers-disappeared-in-an-array
#   ✔ Accepted
#   ✔ 35/35 cases passed (20 ms)
#   ✔ Your runtime beats 32.79 % of java submissions
#   ✔ Your memory usage beats 99.72 % of java submissions (65.4 MB)
# Submitting: java_solutions/451.sort-characters-by-frequency.java
# - Downloading sort-characters-by-frequency
#   ✔ Accepted
#   ✔ 33/33 cases passed (27 ms)
#   ✔ Your runtime beats 12.3 % of java submissions
#   ✔ Your memory usage beats 5.08 % of java submissions (53.7 MB)
# Submitting: java_solutions/455.assign-cookies.java
# - Downloading assign-cookies
#   ✔ Accepted
#   ✔ 25/25 cases passed (24 ms)
#   ✔ Your runtime beats 12.29 % of java submissions
#   ✔ Your memory usage beats 43.1 % of java submissions (51.5 MB)
# Submitting: java_solutions/458.poor-pigs.java
# - Downloading poor-pigs
#   ✔ Accepted
#   ✔ 26/26 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 54.32 % of java submissions (42.1 MB)
# Submitting: java_solutions/459.repeated-substring-pattern.java
# - Downloading repeated-substring-pattern
#   ✔ Accepted
#   ✔ 130/130 cases passed (517 ms)
#   ✔ Your runtime beats 5.04 % of java submissions
#   ✔ Your memory usage beats 96.06 % of java submissions (46.4 MB)
# Submitting: java_solutions/460.lfu-cache.java
# - Downloading lfu-cache
#   ✔ Accepted
#   ✔ 25/25 cases passed (77 ms)
#   ✔ Your runtime beats 15.45 % of java submissions
#   ✔ Your memory usage beats 29.12 % of java submissions (139.7 MB)
# Submitting: java_solutions/461.hamming-distance.java
# - Downloading hamming-distance
#   ✔ Accepted
#   ✔ 149/149 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 88.78 % of java submissions (42 MB)
# Submitting: java_solutions/463.island-perimeter.java
# - Downloading island-perimeter
#   ✔ Accepted
#   ✔ 5833/5833 cases passed (35 ms)
#   ✔ Your runtime beats 7.29 % of java submissions
#   ✔ Your memory usage beats 7.03 % of java submissions (47.8 MB)
# Submitting: java_solutions/466.count-the-repetitions.java
# - Downloading count-the-repetitions
#   ✔ Accepted
#   ✔ 49/49 cases passed (8 ms)
#   ✔ Your runtime beats 22.93 % of java submissions
#   ✔ Your memory usage beats 7.96 % of java submissions (97.4 MB)
# Submitting: java_solutions/472.concatenated-words.java
# - Downloading concatenated-words
#   ✔ Accepted
#   ✔ 43/43 cases passed (91 ms)
#   ✔ Your runtime beats 13.09 % of java submissions
#   ✔ Your memory usage beats 88.98 % of java submissions (50.4 MB)
# Submitting: java_solutions/476.number-complement.java
# - Downloading number-complement
#   ✔ Accepted
#   ✔ 154/154 cases passed (6 ms)
#   ✔ Your runtime beats 2.17 % of java submissions
#   ✔ Your memory usage beats 5.7 % of java submissions (43.6 MB)
# Submitting: java_solutions/479.largest-palindrome-product.java
# - Downloading largest-palindrome-product
#   ✔ Accepted
#   ✔ 8/8 cases passed (103 ms)
#   ✔ Your runtime beats 17.46 % of java submissions
#   ✔ Your memory usage beats 33.65 % of java submissions (45.2 MB)
# Submitting: java_solutions/480.sliding-window-median.java
# - Downloading sliding-window-median
#   ✔ Accepted
#   ✔ 45/45 cases passed (105 ms)
#   ✔ Your runtime beats 36.32 % of java submissions
#   ✔ Your memory usage beats 88.96 % of java submissions (62.3 MB)
# Submitting: java_solutions/482.license-key-formatting.java
# - Downloading license-key-formatting
#   ✔ Accepted
#   ✔ 40/40 cases passed (39 ms)
#   ✔ Your runtime beats 17.57 % of java submissions
#   ✔ Your memory usage beats 6.67 % of java submissions (47.8 MB)
# Submitting: java_solutions/483.smallest-good-base.java
# - Downloading smallest-good-base
#   ✔ Accepted
#   ✔ 109/109 cases passed (7 ms)
#   ✔ Your runtime beats 16.27 % of java submissions
#   ✔ Your memory usage beats 11.75 % of java submissions (43.2 MB)
# Submitting: java_solutions/485.max-consecutive-ones.java
# - Downloading max-consecutive-ones
#   ✔ Accepted
#   ✔ 45/45 cases passed (8 ms)
#   ✔ Your runtime beats 1.21 % of java submissions
#   ✔ Your memory usage beats 15.18 % of java submissions (52.8 MB)
# Submitting: java_solutions/488.zuma-game.java
# - Downloading zuma-game
#   ✔ Accepted
#   ✔ 57/57 cases passed (321 ms)
#   ✔ Your runtime beats 43.7 % of java submissions
#   ✔ Your memory usage beats 6.72 % of java submissions (290.1 MB)
# Submitting: java_solutions/493.reverse-pairs.java
# - Downloading reverse-pairs
#   ✔ Accepted
#   ✔ 140/140 cases passed (68 ms)
#   ✔ Your runtime beats 29.65 % of java submissions
#   ✔ Your memory usage beats 59.17 % of java submissions (61.3 MB)
# Submitting: java_solutions/495.teemo-attacking.java
# - Downloading teemo-attacking
#   ✔ Accepted
#   ✔ 40/40 cases passed (7 ms)
#   ✔ Your runtime beats 2.02 % of java submissions
#   ✔ Your memory usage beats 63.13 % of java submissions (48.3 MB)
# Submitting: java_solutions/496.next-greater-element-i.java
# - Downloading next-greater-element-i
#   ✔ Accepted
#   ✔ 17/17 cases passed (103 ms)
#   ✔ Your runtime beats 5.23 % of java submissions
#   ✔ Your memory usage beats 5.94 % of java submissions (47.3 MB)
# Submitting: java_solutions/500.keyboard-row.java
# - Downloading keyboard-row
#   ✔ Accepted
#   ✔ 25/25 cases passed (4 ms)
#   ✔ Your runtime beats 2.23 % of java submissions
#   ✔ Your memory usage beats 23.69 % of java submissions (43 MB)
# Submitting: java_solutions/501.find-mode-in-binary-search-tree.java
# - Downloading find-mode-in-binary-search-tree
#   ✔ Accepted
#   ✔ 24/24 cases passed (32 ms)
#   ✔ Your runtime beats 6.31 % of java submissions
#   ✔ Your memory usage beats 6.6 % of java submissions (54.4 MB)
# Submitting: java_solutions/502.ipo.java
# - Downloading ipo
#   ✔ Accepted
#   ✔ 40/40 cases passed (34 ms)
#   ✔ Your runtime beats 99.96 % of java submissions
#   ✔ Your memory usage beats 98.39 % of java submissions (117 MB)
# Submitting: java_solutions/504.base-7.java
# - Downloading base-7
#   ✔ Accepted
#   ✔ 241/241 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 18.48 % of java submissions (43 MB)
# Submitting: java_solutions/506.relative-ranks.java
# - Downloading relative-ranks
#   ✔ Accepted
#   ✔ 18/18 cases passed (150 ms)
#   ✔ Your runtime beats 5.16 % of java submissions
#   ✔ Your memory usage beats 74.73 % of java submissions (47.4 MB)
# Submitting: java_solutions/507.perfect-number.java
# - Downloading perfect-number
#   ✔ Accepted
#   ✔ 98/98 cases passed (6 ms)
#   ✔ Your runtime beats 65.2 % of java submissions
#   ✔ Your memory usage beats 15.09 % of java submissions (42.4 MB)
# Submitting: java_solutions/509.fibonacci-number.java
# - Downloading fibonacci-number
#   ✔ Accepted
#   ✔ 31/31 cases passed (13 ms)
#   ✔ Your runtime beats 9.37 % of java submissions
#   ✔ Your memory usage beats 74.08 % of java submissions (42 MB)
# Submitting: java_solutions/514.freedom-trail.java
# - Downloading freedom-trail
#   ✔ Accepted
#   ✔ 303/303 cases passed (284 ms)
#   ✔ Your runtime beats 5.25 % of java submissions
#   ✔ Your memory usage beats 17 % of java submissions (47.3 MB)
# Submitting: java_solutions/517.super-washing-machines.java
# - Downloading super-washing-machines
#   ✔ Accepted
#   ✔ 120/120 cases passed (4 ms)
#   ✔ Your runtime beats 0.34 % of java submissions
#   ✔ Your memory usage beats 13.99 % of java submissions (46.9 MB)
# Submitting: java_solutions/520.detect-capital.java
# - Downloading detect-capital
# [ERROR] session expired, please login again [code=-1]
# Submitting: java_solutions/521.longest-uncommon-subsequence-i.java
# - Downloading longest-uncommon-subsequence-i
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 7: error: cannot find symbol [in __Driver__.java]
#   ✘ Error: Line 7: error: cannot find symbol [in __Driver__.java]
#       int ret = new Solution().findLUSlength(param_1, param_2);
#                               ^
#   symbol:   method findLUSlength(String,String)
#   location: class Solution
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: java_solutions/524.longest-word-in-dictionary-through-deleting.java
# - Downloading longest-word-in-dictionary-through-deleting
#   ✔ Accepted
#   ✔ 31/31 cases passed (28 ms)
#   ✔ Your runtime beats 6.36 % of java submissions
#   ✔ Your memory usage beats 6.07 % of java submissions (53 MB)
# Submitting: java_solutions/530.minimum-absolute-difference-in-bst.java
# - Downloading minimum-absolute-difference-in-bst
#   ✔ Accepted
#   ✔ 190/190 cases passed (27 ms)
#   ✔ Your runtime beats 5.57 % of java submissions
#   ✔ Your memory usage beats 7.9 % of java submissions (48 MB)
# Submitting: java_solutions/535.encode-and-decode-tinyurl.java
# - Downloading encode-and-decode-tinyurl
#   ✔ Accepted
#   ✔ 739/739 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 81.32 % of java submissions (44.2 MB)
# Submitting: java_solutions/537.complex-number-multiplication.java
# - Downloading complex-number-multiplication
#   ✔ Accepted
#   ✔ 56/56 cases passed (6 ms)
#   ✔ Your runtime beats 10.41 % of java submissions
#   ✔ Your memory usage beats 31.92 % of java submissions (43 MB)
# Submitting: java_solutions/541.reverse-string-ii.java
# - Downloading reverse-string-ii
#   ✔ Accepted
#   ✔ 60/60 cases passed (7 ms)
#   ✔ Your runtime beats 5.64 % of java submissions
#   ✔ Your memory usage beats 5.02 % of java submissions (46.3 MB)
# Submitting: java_solutions/543.diameter-of-binary-tree.java
# - Downloading diameter-of-binary-tree
#   ✔ Accepted
#   ✔ 106/106 cases passed (35 ms)
#   ✔ Your runtime beats 11.14 % of java submissions
#   ✔ Your memory usage beats 5.15 % of java submissions (53.4 MB)
# Submitting: java_solutions/546.remove-boxes.java
# - Downloading remove-boxes
#   ✔ Accepted
#   ✔ 63/63 cases passed (189 ms)
#   ✔ Your runtime beats 5.16 % of java submissions
#   ✔ Your memory usage beats 5.16 % of java submissions (171.4 MB)
# Submitting: java_solutions/551.student-attendance-record-i.java
# - Downloading student-attendance-record-i
#   ✔ Accepted
#   ✔ 115/115 cases passed (10 ms)
#   ✔ Your runtime beats 3.48 % of java submissions
#   ✔ Your memory usage beats 6.3 % of java submissions (44.7 MB)
# Submitting: java_solutions/552.student-attendance-record-ii.java
# - Downloading student-attendance-record-ii
#   ✔ Accepted
#   ✔ 59/59 cases passed (174 ms)
#   ✔ Your runtime beats 85.32 % of java submissions
#   ✔ Your memory usage beats 99.26 % of java submissions (42 MB)
# Submitting: java_solutions/557.reverse-words-in-a-string-iii.java
# - Downloading reverse-words-in-a-string-iii
#   ✔ Accepted
#   ✔ 29/29 cases passed (6 ms)
#   ✔ Your runtime beats 49.69 % of java submissions
#   ✔ Your memory usage beats 58.89 % of java submissions (46.9 MB)
# Submitting: java_solutions/559.maximum-depth-of-n-ary-tree.java
# - Downloading maximum-depth-of-n-ary-tree
#   ✔ Accepted
#   ✔ 38/38 cases passed (7 ms)
#   ✔ Your runtime beats 1.62 % of java submissions
#   ✔ Your memory usage beats 6.26 % of java submissions (46.8 MB)
# Submitting: java_solutions/561.array-partition.java
# - Downloading array-partition
#   ✔ Accepted
#   ✔ 85/85 cases passed (31 ms)
#   ✔ Your runtime beats 12.26 % of java submissions
#   ✔ Your memory usage beats 98.54 % of java submissions (48.4 MB)
# Submitting: java_solutions/564.find-the-closest-palindrome.java
# - Downloading find-the-closest-palindrome
#   ✔ Accepted
#   ✔ 232/232 cases passed (2 ms)
#   ✔ Your runtime beats 95.25 % of java submissions
#   ✔ Your memory usage beats 84.49 % of java submissions (43.2 MB)
# Submitting: java_solutions/566.reshape-the-matrix.java
# - Downloading reshape-the-matrix
#   ✔ Accepted
#   ✔ 57/57 cases passed (7 ms)
#   ✔ Your runtime beats 0.89 % of java submissions
#   ✔ Your memory usage beats 46.9 % of java submissions (47.5 MB)
# Submitting: java_solutions/575.distribute-candies.java
# - Downloading distribute-candies
#   ✔ Accepted
#   ✔ 206/206 cases passed (36 ms)
#   ✔ Your runtime beats 17.54 % of java submissions
#   ✔ Your memory usage beats 86.36 % of java submissions (48.3 MB)
# Submitting: java_solutions/587.erect-the-fence.java
# - Downloading erect-the-fence
#   ✔ Accepted
#   ✔ 88/88 cases passed (25 ms)
#   ✔ Your runtime beats 23.72 % of java submissions
#   ✔ Your memory usage beats 6.98 % of java submissions (48.5 MB)
# Submitting: java_solutions/591.tag-validator.java
# - Downloading tag-validator
#   ✔ Accepted
#   ✔ 261/261 cases passed (3 ms)
#   ✔ Your runtime beats 5.53 % of java submissions
#   ✔ Your memory usage beats 5.53 % of java submissions (44.4 MB)
# Submitting: java_solutions/594.longest-harmonious-subsequence.java
# - Downloading longest-harmonious-subsequence
#   ✔ Accepted
#   ✔ 208/208 cases passed (43 ms)
#   ✔ Your runtime beats 5.09 % of java submissions
#   ✔ Your memory usage beats 9.04 % of java submissions (53.9 MB)
# Submitting: java_solutions/599.minimum-index-sum-of-two-lists.java
# - Downloading minimum-index-sum-of-two-lists
#   ✔ Accepted
#   ✔ 137/137 cases passed (25 ms)
#   ✔ Your runtime beats 25.32 % of java submissions
#   ✔ Your memory usage beats 7 % of java submissions (53.1 MB)
# Submitting: java_solutions/600.non-negative-integers-without-consecutive-ones.java
# - Downloading non-negative-integers-without-consecutive-ones
#   ✔ Accepted
#   ✔ 527/527 cases passed (1 ms)
#   ✔ Your runtime beats 98.86 % of java submissions
#   ✔ Your memory usage beats 76.66 % of java submissions (42.5 MB)
# Submitting: java_solutions/628.maximum-product-of-three-numbers.java
# - Downloading maximum-product-of-three-numbers
#   ✔ Accepted
#   ✔ 93/93 cases passed (24 ms)
#   ✔ Your runtime beats 9.33 % of java submissions
#   ✔ Your memory usage beats 66.61 % of java submissions (48 MB)
# Submitting: java_solutions/629.k-inverse-pairs-array.java
# - Downloading k-inverse-pairs-array
#   ✔ Accepted
#   ✔ 81/81 cases passed (27 ms)
#   ✔ Your runtime beats 27.49 % of java submissions
#   ✔ Your memory usage beats 76.89 % of java submissions (46.4 MB)
# Submitting: java_solutions/630.course-schedule-iii.java
# - Downloading course-schedule-iii
#   ✔ Accepted
#   ✔ 97/97 cases passed (52 ms)
#   ✔ Your runtime beats 11.19 % of java submissions
#   ✔ Your memory usage beats 9.39 % of java submissions (58.7 MB)
# Submitting: java_solutions/632.smallest-range-covering-elements-from-k-lists.java
# - Downloading smallest-range-covering-elements-from-k-lists
#   ✔ Accepted
#   ✔ 94/94 cases passed (106 ms)
#   ✔ Your runtime beats 28.34 % of java submissions
#   ✔ Your memory usage beats 9.1 % of java submissions (97 MB)
# Submitting: java_solutions/639.decode-ways-ii.java
# - Downloading decode-ways-ii
#   ✔ Accepted
#   ✔ 218/218 cases passed (17 ms)
#   ✔ Your runtime beats 51.32 % of java submissions
#   ✔ Your memory usage beats 39 % of java submissions (47.9 MB)
# Submitting: java_solutions/643.maximum-average-subarray-i.java
# - Downloading maximum-average-subarray-i
#   ✔ Accepted
#   ✔ 128/128 cases passed (17 ms)
#   ✔ Your runtime beats 5.59 % of java submissions
#   ✔ Your memory usage beats 92.14 % of java submissions (69.2 MB)
# Submitting: java_solutions/645.set-mismatch.java
# - Downloading set-mismatch
#   ✔ Accepted
#   ✔ 49/49 cases passed (16 ms)
#   ✔ Your runtime beats 19.17 % of java submissions
#   ✔ Your memory usage beats 11.23 % of java submissions (48.1 MB)
# Submitting: java_solutions/653.two-sum-iv-input-is-a-bst.java
# - Downloading two-sum-iv-input-is-a-bst
#   ✔ Accepted
#   ✔ 423/423 cases passed (34 ms)
#   ✔ Your runtime beats 5.95 % of java submissions
#   ✔ Your memory usage beats 13.74 % of java submissions (47.5 MB)
# Submitting: java_solutions/657.robot-return-to-origin.java
# - Downloading robot-return-to-origin
#   ✔ Accepted
#   ✔ 78/78 cases passed (14 ms)
#   ✔ Your runtime beats 5.21 % of java submissions
#   ✔ Your memory usage beats 11.23 % of java submissions (46.5 MB)
# Submitting: java_solutions/664.strange-printer.java
# - Downloading strange-printer
#   ✔ Accepted
#   ✔ 200/200 cases passed (33 ms)
#   ✔ Your runtime beats 13.5 % of java submissions
#   ✔ Your memory usage beats 32.3 % of java submissions (45 MB)
# Submitting: java_solutions/668.kth-smallest-number-in-multiplication-table.java
# - Downloading kth-smallest-number-in-multiplication-table
#   ✔ Accepted
#   ✔ 71/71 cases passed (14 ms)
#   ✔ Your runtime beats 7.08 % of java submissions
#   ✔ Your memory usage beats 63.59 % of java submissions (42.1 MB)
# Submitting: java_solutions/671.second-minimum-node-in-a-binary-tree.java
# - Downloading second-minimum-node-in-a-binary-tree
#   ✔ Accepted
#   ✔ 39/39 cases passed (11 ms)
#   ✔ Your runtime beats 0.76 % of java submissions
#   ✔ Your memory usage beats 14.58 % of java submissions (43.3 MB)
# Submitting: java_solutions/674.longest-continuous-increasing-subsequence.java
# - Downloading longest-continuous-increasing-subsequence
#   ✔ Accepted
#   ✔ 35/35 cases passed (5 ms)
#   ✔ Your runtime beats 2.03 % of java submissions
#   ✔ Your memory usage beats 89.45 % of java submissions (46.7 MB)
# Submitting: java_solutions/675.cut-off-trees-for-golf-event.java
# - Downloading cut-off-trees-for-golf-event
#   ✔ Accepted
#   ✔ 55/55 cases passed (523 ms)
#   ✔ Your runtime beats 35.92 % of java submissions
#   ✔ Your memory usage beats 6.43 % of java submissions (48.7 MB)
# Submitting: java_solutions/679.24-game.java
# - Downloading 24-game
#   ✔ Accepted
#   ✔ 71/71 cases passed (60 ms)
#   ✔ Your runtime beats 5.07 % of java submissions
#   ✔ Your memory usage beats 7.3 % of java submissions (48.5 MB)
# Submitting: java_solutions/680.valid-palindrome-ii.java
# - Downloading valid-palindrome-ii
#   ✔ Accepted
#   ✔ 477/477 cases passed (23 ms)
#   ✔ Your runtime beats 5.16 % of java submissions
#   ✔ Your memory usage beats 17.85 % of java submissions (48 MB)
# Submitting: java_solutions/682.baseball-game.java
# - Downloading baseball-game
#   ✔ Accepted
#   ✔ 39/39 cases passed (7 ms)
#   ✔ Your runtime beats 3.99 % of java submissions
#   ✔ Your memory usage beats 34.27 % of java submissions (43.7 MB)
# Submitting: java_solutions/685.redundant-connection-ii.java
# - Downloading redundant-connection-ii
#   ✔ Accepted
#   ✔ 58/58 cases passed (3 ms)
#   ✔ Your runtime beats 16.78 % of java submissions
#   ✔ Your memory usage beats 55.87 % of java submissions (45.2 MB)
# Submitting: java_solutions/689.maximum-sum-of-3-non-overlapping-subarrays.java
# - Downloading maximum-sum-of-3-non-overlapping-subarrays
#   ✔ Accepted
#   ✔ 43/43 cases passed (11 ms)
#   ✔ Your runtime beats 14.91 % of java submissions
#   ✔ Your memory usage beats 52.03 % of java submissions (49 MB)
# Submitting: java_solutions/691.stickers-to-spell-word.java
# - Downloading stickers-to-spell-word
#   ✔ Accepted
#   ✔ 102/102 cases passed (13 ms)
#   ✔ Your runtime beats 90.79 % of java submissions
#   ✔ Your memory usage beats 95.39 % of java submissions (45.1 MB)
# Submitting: java_solutions/693.binary-number-with-alternating-bits.java
# - Downloading binary-number-with-alternating-bits
#   ✔ Accepted
#   ✔ 204/204 cases passed (6 ms)
#   ✔ Your runtime beats 0.95 % of java submissions
#   ✔ Your memory usage beats 16.54 % of java submissions (43 MB)
# Submitting: java_solutions/697.degree-of-an-array.java
# - Downloading degree-of-an-array
#   ✔ Accepted
#   ✔ 89/89 cases passed (29 ms)
#   ✔ Your runtime beats 40.87 % of java submissions
#   ✔ Your memory usage beats 9.67 % of java submissions (51.5 MB)
# Submitting: java_solutions/699.falling-squares.java
# - Downloading falling-squares
#   ✔ Accepted
#   ✔ 48/48 cases passed (18 ms)
#   ✔ Your runtime beats 70.39 % of java submissions
#   ✔ Your memory usage beats 82.57 % of java submissions (46.5 MB)
# Submitting: java_solutions/700.search-in-a-binary-search-tree.java
# - Downloading search-in-a-binary-search-tree
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 9: error: incompatible types: boolean cannot be converted to TreeNode
#   ✘ Error: Line 9: error: incompatible types: boolean cannot be converted to TreeNode
#         return node_to_list(root).contains(val);
#                                           ^
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: java_solutions/704.binary-search.java
# - Downloading binary-search
#   ✔ Accepted
#   ✔ 47/47 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 92.21 % of java submissions (48.1 MB)
# Submitting: java_solutions/709.to-lower-case.java
# - Downloading to-lower-case
#   ✔ Accepted
#   ✔ 114/114 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 73.08 % of java submissions (42.9 MB)

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-04-14 09:56:35
