# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME_2')
    user_cookie = userdata.get('LEETCODE_TOKEN_2')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME_2'] = user_name
    os.environ['LEETCODE_TOKEN_2'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME_2" "$LEETCODE_TOKEN_2" | leetcode user -c

# %%
# %%bash
#
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v kotlin_solutions_1/*.kt | sed -n '701,800p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 7
# done
# Out:
# Submitting: kotlin_solutions_1/1932.merge-bsts-to-create-single-bst.kt
# - Downloading merge-bsts-to-create-single-bst
#   ✔ Accepted
#   ✔ 475/475 cases passed (793 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/1935.maximum-number-of-words-you-can-type.kt
# - Downloading maximum-number-of-words-you-can-type
#   ✔ Accepted
#   ✔ 20/20 cases passed (14 ms)
#   ✔ Your runtime beats 66.67 % of kotlin submissions
#   ✔ Your memory usage beats 55.56 % of kotlin submissions (44 MB)
# Submitting: kotlin_solutions_1/1936.add-minimum-number-of-rungs.kt
# - Downloading add-minimum-number-of-rungs
#   ✔ Accepted
#   ✔ 117/117 cases passed (13 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1938.maximum-genetic-difference-query.kt
# - Downloading maximum-genetic-difference-query
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 218: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 2: Char 218: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 272: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 514: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 977: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 38: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1941.check-if-all-characters-have-equal-number-of-occurrences.kt
# - Downloading check-if-all-characters-have-equal-number-of-occurrences
#   ✔ Accepted
#   ✔ 134/134 cases passed (28 ms)
#   ✔ Your runtime beats 7.14 % of kotlin submissions
#   ✔ Your memory usage beats 7.14 % of kotlin submissions (45.1 MB)
# Submitting: kotlin_solutions_1/1942.the-number-of-the-smallest-unoccupied-chair.kt
# - Downloading the-number-of-the-smallest-unoccupied-chair
#   ✔ Accepted
#   ✔ 65/65 cases passed (106 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1943.describe-the-painting.kt
# - Downloading describe-the-painting
#   ✔ Accepted
#   ✔ 68/68 cases passed (114 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (84.5 MB)
# Submitting: kotlin_solutions_1/1944.number-of-visible-people-in-a-queue.kt
# - Downloading number-of-visible-people-in-a-queue
#   ✔ Accepted
#   ✔ 42/42 cases passed (118 ms)
#   ✔ Your runtime beats 13.64 % of kotlin submissions
#   ✔ Your memory usage beats 9.09 % of kotlin submissions (71.7 MB)
# Submitting: kotlin_solutions_1/1945.sum-of-digits-of-string-after-convert.kt
# - Downloading sum-of-digits-of-string-after-convert
#   ✔ Accepted
#   ✔ 216/216 cases passed (21 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 11.11 % of kotlin submissions (46.6 MB)
# Submitting: kotlin_solutions_1/1946.largest-number-after-mutating-substring.kt
# - Downloading largest-number-after-mutating-substring
#   ✔ Accepted
#   ✔ 279/279 cases passed (57 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (48.8 MB)
# Submitting: kotlin_solutions_1/1947.maximum-compatibility-score-sum.kt
# - Downloading maximum-compatibility-score-sum
#   ✔ Accepted
#   ✔ 86/86 cases passed (23 ms)
#   ✔ Your runtime beats 60 % of kotlin submissions
#   ✔ Your memory usage beats 40 % of kotlin submissions (51.3 MB)
# Submitting: kotlin_solutions_1/1948.delete-duplicate-folders-in-system.kt
# - Downloading delete-duplicate-folders-in-system
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 403: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 2: Char 403: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 407: WARNING: Parameter '<unused var>: Node' is never used, could be renamed to '_'.
# Line 2: Char 663: WARNING: Parameter 'it: String' is never used, could be renamed to '_'.
# Line 2: Char 755: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 759: WARNING: Parameter '<unused var>: Node' is never used, could be renamed to '_'.
# Line 2: Char 762: WARNING: Parameter '<unused var>: MutableList<String>' is never used, could be renamed to '_'.
# Line 2: Char 950: WARNING: Parameter 'it: Boolean' is never used, could be renamed to '_'.
# Line 36: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1952.three-divisors.kt
# - Downloading three-divisors
#   ✔ Accepted
#   ✔ 229/229 cases passed (8 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1953.maximum-number-of-weeks-for-which-you-can-work.kt
# - Downloading maximum-number-of-weeks-for-which-you-can-work
#   ✔ Accepted
#   ✔ 74/74 cases passed (22 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1954.minimum-garden-perimeter-to-collect-enough-apples.kt
# - Downloading minimum-garden-perimeter-to-collect-enough-apples
#   ✔ Accepted
#   ✔ 306/306 cases passed (44 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1955.count-number-of-special-subsequences.kt
# - Downloading count-number-of-special-subsequences
#   ✔ Accepted
#   ✔ 99/99 cases passed (11 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (59.6 MB)
# Submitting: kotlin_solutions_1/1957.delete-characters-to-make-fancy-string.kt
# - Downloading delete-characters-to-make-fancy-string
#   ✔ Accepted
#   ✔ 306/306 cases passed (152 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/1958.check-if-move-is-legal.kt
# - Downloading check-if-move-is-legal
#   ✔ Accepted
#   ✔ 220/220 cases passed (16 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1959.minimum-total-space-wasted-with-k-resizing-operations.kt
# - Downloading minimum-total-space-wasted-with-k-resizing-operations
#   ✘ Wrong Answer
#   ✘ 4/73 cases passed (N/A)
#   ✘ Testcase: [10,20]
# 0
#   ✘ Answer: 1000000000
#   ✘ Expected Answer: 10
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1960.maximum-product-of-the-length-of-two-palindromic-substrings.kt
# - Downloading maximum-product-of-the-length-of-two-palindromic-substrings
#   ✔ Accepted
#   ✔ 67/67 cases passed (148 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1961.check-if-string-is-a-prefix-of-array.kt
# - Downloading check-if-string-is-a-prefix-of-array
#   ✔ Accepted
#   ✔ 349/349 cases passed (34 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 7.69 % of kotlin submissions (48.6 MB)
# Submitting: kotlin_solutions_1/1962.remove-stones-to-minimize-the-total.kt
# - Downloading remove-stones-to-minimize-the-total
#   ✔ Accepted
#   ✔ 60/60 cases passed (220 ms)
#   ✔ Your runtime beats 55 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (60.3 MB)
# Submitting: kotlin_solutions_1/1963.minimum-number-of-swaps-to-make-the-string-balanced.kt
# - Downloading minimum-number-of-swaps-to-make-the-string-balanced
#   ✔ Accepted
#   ✔ 59/59 cases passed (25 ms)
#   ✔ Your runtime beats 66.67 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (57.7 MB)
# Submitting: kotlin_solutions_1/1964.find-the-longest-valid-obstacle-course-at-each-position.kt
# - Downloading find-the-longest-valid-obstacle-course-at-each-position
#   ✔ Accepted
#   ✔ 78/78 cases passed (236 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1967.number-of-strings-that-appear-as-substrings-in-word.kt
# - Downloading number-of-strings-that-appear-as-substrings-in-word
#   ✔ Accepted
#   ✔ 83/83 cases passed (9 ms)
#   ✔ Your runtime beats 36.74 % of kotlin submissions
#   ✔ Your memory usage beats 61.6 % of kotlin submissions (42.8 MB)
# Submitting: kotlin_solutions_1/1968.array-with-elements-not-equal-to-average-of-neighbors.kt
# - Downloading array-with-elements-not-equal-to-average-of-neighbors
#   ✔ Accepted
#   ✔ 293/293 cases passed (366 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1969.minimum-non-zero-product-of-the-array-elements.kt
# - Downloading minimum-non-zero-product-of-the-array-elements
#   ✔ Accepted
#   ✔ 60/60 cases passed (1 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1970.last-day-where-you-can-still-cross.kt
# - Downloading last-day-where-you-can-still-cross
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 595: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 2: Char 595: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 658: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 727: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 786: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 851: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 885: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 40: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1971.find-if-path-exists-in-graph.kt
# - Downloading find-if-path-exists-in-graph
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 42: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Error: Line 42: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1974.minimum-time-to-type-word-using-special-typewriter.kt
# - Downloading minimum-time-to-type-word-using-special-typewriter
#   ✔ Accepted
#   ✔ 135/135 cases passed (5 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 16.67 % of kotlin submissions (41.2 MB)
# Submitting: kotlin_solutions_1/1975.maximum-matrix-sum.kt
# - Downloading maximum-matrix-sum
#   ✔ Accepted
#   ✔ 98/98 cases passed (73 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1976.number-of-ways-to-arrive-at-destination.kt
# - Downloading number-of-ways-to-arrive-at-destination
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 81: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 2: Char 81: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 262: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 655: WARNING: Parameter 'it: Long' is never used, could be renamed to '_'.
# Line 2: Char 682: WARNING: Parameter 'it: Long' is never used, could be renamed to '_'.
# Line 38: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1977.number-of-ways-to-separate-numbers.kt
# - Downloading number-of-ways-to-separate-numbers
#   ✔ Accepted
#   ✔ 257/257 cases passed (133 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (150.1 MB)
# Submitting: kotlin_solutions_1/1979.find-greatest-common-divisor-of-array.kt
# - Downloading find-greatest-common-divisor-of-array
#   ✔ Accepted
#   ✔ 215/215 cases passed (12 ms)
#   ✔ Your runtime beats 12.06 % of kotlin submissions
#   ✔ Your memory usage beats 25.29 % of kotlin submissions (46.1 MB)
# Submitting: kotlin_solutions_1/1980.find-unique-binary-string.kt
# - Downloading find-unique-binary-string
# [ERROR] session expired, please login again [code=-1]
# Submitting: kotlin_solutions_1/1981.minimize-the-difference-between-target-and-chosen-elements.kt
# - Downloading minimize-the-difference-between-target-and-chosen-elements
#   ✔ Accepted
#   ✔ 81/81 cases passed (568 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1982.find-array-given-subset-sums.kt
# - Downloading find-array-given-subset-sums
#   ✘ Runtime Error
#   ✘ 1/131 cases passed (N/A)
#   ✘ Error: Line 7: Exception in thread "main" java.lang.ArrayIndexOutOfBoundsException: Index 2 out of bounds for length 2
#   ✘ Error: Line 7: Exception in thread "main" java.lang.ArrayIndexOutOfBoundsException: Index 2 out of bounds for length 2
#   ✘ Testcase: 2
# [0,0,0,0]
#   ✘ Answer:
#   ✘ Expected Answer: [0,0]
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1984.minimum-difference-between-highest-and-lowest-of-k-scores.kt
# - Downloading minimum-difference-between-highest-and-lowest-of-k-scores
#   ✔ Accepted
#   ✔ 118/118 cases passed (32 ms)
#   ✔ Your runtime beats 11.11 % of kotlin submissions
#   ✔ Your memory usage beats 7.41 % of kotlin submissions (50.2 MB)
# Submitting: kotlin_solutions_1/1985.find-the-kth-largest-integer-in-the-array.kt
# - Downloading find-the-kth-largest-integer-in-the-array
#   ✔ Accepted
#   ✔ 219/219 cases passed (37 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 70 % of kotlin submissions (58.2 MB)
# Submitting: kotlin_solutions_1/1986.minimum-number-of-work-sessions-to-finish-the-tasks.kt
# - Downloading minimum-number-of-work-sessions-to-finish-the-tasks
#   ✔ Accepted
#   ✔ 96/96 cases passed (76 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (49.9 MB)
# Submitting: kotlin_solutions_1/1987.number-of-unique-good-subsequences.kt
# - Downloading number-of-unique-good-subsequences
#   ✔ Accepted
#   ✔ 69/69 cases passed (16 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (47.1 MB)
# Submitting: kotlin_solutions_1/1992.find-all-groups-of-farmland.kt
# - Downloading find-all-groups-of-farmland
#   ✔ Accepted
#   ✔ 220/220 cases passed (47 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1993.operations-on-tree.kt
# - Downloading operations-on-tree
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 7: Char 77: ERROR: Syntax error: Property getter or setter expected.
#   ✘ Error: Line 7: Char 77: ERROR: Syntax error: Property getter or setter expected.
# Line 62: Char 32: WARNING: 'static fun readFrom(p0: String!): JsonArray!' is deprecated. Deprecated in Java.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1994.the-number-of-good-subsets.kt
# - Downloading the-number-of-good-subsets
#   ✔ Accepted
#   ✔ 92/92 cases passed (19 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1995.count-special-quadruplets.kt
# - Downloading count-special-quadruplets
#   ✔ Accepted
#   ✔ 211/211 cases passed (10 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 15.38 % of kotlin submissions (44 MB)
# Submitting: kotlin_solutions_1/1996.the-number-of-weak-characters-in-the-game.kt
# - Downloading the-number-of-weak-characters-in-the-game
#   ✔ Accepted
#   ✔ 44/44 cases passed (283 ms)
#   ✔ Your runtime beats 6.67 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (117.3 MB)
# Submitting: kotlin_solutions_1/1997.first_day_where_you_have_been_in_all_the_rooms.kt
# - Downloading first-day-where-you-have-been-in-all-the-rooms
#   ✔ Accepted
#   ✔ 239/239 cases passed (11 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1998.gcd_sort_of_an_array.kt
# - Downloading gcd-sort-of-an-array
#   ✔ Accepted
#   ✔ 92/92 cases passed (221 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2000.reverse_prefix_of_word.kt
# - Downloading reverse-prefix-of-word
#   ✔ Accepted
#   ✔ 113/113 cases passed (7 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 27.78 % of kotlin submissions (42.3 MB)
# Submitting: kotlin_solutions_1/2001.number_of_pairs_of_interchangeable_rectangles.kt
# - Downloading number-of-pairs-of-interchangeable-rectangles
#   ✔ Accepted
#   ✔ 46/46 cases passed (62 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/2002.maximum_product_of_the_length_of_two_palindromic_subsequences.kt
# - Downloading maximum-product-of-the-length-of-two-palindromic-subsequences
#   ✔ Accepted
#   ✔ 226/226 cases passed (152 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (52.9 MB)
# Submitting: kotlin_solutions_1/2003.smallest_missing_genetic_value_in_each_subtree.kt
# - Downloading smallest-missing-genetic-value-in-each-subtree
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 120: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 2: Char 120: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 250: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 397: ERROR: Return type mismatch: expected 'kotlin.Unit', actual 'kotlin.Any'.
# Line 2: Char 442: WARNING: Parameter 'it: Boolean' is never used, could be renamed to '_'.
# Line 2: Char 599: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2006.count_number_of_pairs_with_absolute_difference_k.kt
# - Downloading count-number-of-pairs-with-absolute-difference-k
#   ✔ Accepted
#   ✔ 237/237 cases passed (25 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2007.find_original_array_from_doubled_array.kt
# - Downloading find-original-array-from-doubled-array
#   ✔ Accepted
#   ✔ 180/180 cases passed (94 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 11.11 % of kotlin submissions (79.4 MB)
# Submitting: kotlin_solutions_1/2008.maximum_earnings_from_taxi.kt
# - Downloading maximum-earnings-from-taxi
#   ✔ Accepted
#   ✔ 84/84 cases passed (88 ms)
#   ✔ Your runtime beats 60 % of kotlin submissions
#   ✔ Your memory usage beats 80 % of kotlin submissions (85.3 MB)
# Submitting: kotlin_solutions_1/2009.minimum_number_of_operations_to_make_array_continuous.kt
# - Downloading minimum-number-of-operations-to-make-array-continuous
#   ✔ Accepted
#   ✔ 62/62 cases passed (322 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (71.6 MB)
# Submitting: kotlin_solutions_1/2011.final-value-of-variable-after-performing-operations.kt
# - Downloading final-value-of-variable-after-performing-operations
#   ✔ Accepted
#   ✔ 259/259 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 38.89 % of kotlin submissions (44.8 MB)
# Submitting: kotlin_solutions_1/2012.sum-of-beauty-in-the-array.kt
# - Downloading sum-of-beauty-in-the-array
#   ✔ Accepted
#   ✔ 62/62 cases passed (16 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 16.67 % of kotlin submissions (65.4 MB)
# Submitting: kotlin_solutions_1/2013.detect-squares.kt
# - Downloading detect-squares
#   ✔ Accepted
#   ✔ 55/55 cases passed (141 ms)
#   ✔ Your runtime beats 18.75 % of kotlin submissions
#   ✔ Your memory usage beats 6.25 % of kotlin submissions (80.4 MB)
# Submitting: kotlin_solutions_1/2014.longest-subsequence-repeated-k-times.kt
# - Downloading longest-subsequence-repeated-k-times
#   ✔ Accepted
#   ✔ 314/314 cases passed (264 ms)
#   ✔ Your runtime beats 60 % of kotlin submissions
#   ✔ Your memory usage beats 80 % of kotlin submissions (51.1 MB)
# Submitting: kotlin_solutions_1/2016.maximum-difference-between-increasing-elements.kt
# - Downloading maximum-difference-between-increasing-elements
#   ✔ Accepted
#   ✔ 54/54 cases passed (23 ms)
#   ✔ Your runtime beats 8.33 % of kotlin submissions
#   ✔ Your memory usage beats 16.67 % of kotlin submissions (45.8 MB)
# Submitting: kotlin_solutions_1/2017.grid-game.kt
# - Downloading grid-game
#   ✔ Accepted
#   ✔ 109/109 cases passed (57 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (80.9 MB)
# Submitting: kotlin_solutions_1/2018.check-if-word-can-be-placed-in-crossword.kt
# - Downloading check-if-word-can-be-placed-in-crossword
#   ✔ Accepted
#   ✔ 154/154 cases passed (228 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2019.the-score-of-students-solving-math-expression.kt
# - Downloading the-score-of-students-solving-math-expression
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 153: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
#   ✘ Error: Line 2: Char 153: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 153: ERROR: Not enough information to infer type argument for 'R'.
# Line 2: Char 190: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 212: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 700: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 700: ERROR: Not enough information to infer type argument for 'R'.
# Line 2: Char 720: ERROR: Overload resolution ambiguity between candidates:
# fun IntArray.sumOf(selector: (Int) -> Int): Int
# fun IntArray.sumOf(selector: (Int) -> Long): Long
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2022.convert-1d-array-into-2d-array.kt
# - Downloading convert-1d-array-into-2d-array
#   ✔ Accepted
#   ✔ 107/107 cases passed (11 ms)
#   ✔ Your runtime beats 9.09 % of kotlin submissions
#   ✔ Your memory usage beats 9.09 % of kotlin submissions (62.5 MB)
# Submitting: kotlin_solutions_1/2023.number-of-pairs-of-strings-with-concatenation-equal-to-target.kt
# - Downloading number-of-pairs-of-strings-with-concatenation-equal-to-target
#   ✔ Accepted
#   ✔ 117/117 cases passed (50 ms)
#   ✔ Your runtime beats 8 % of kotlin submissions
#   ✔ Your memory usage beats 12 % of kotlin submissions (48.8 MB)
# Submitting: kotlin_solutions_1/2024.maximize-the-confusion-of-an-exam.kt
# - Downloading maximize-the-confusion-of-an-exam
#   ✔ Accepted
#   ✔ 93/93 cases passed (60 ms)
#   ✔ Your runtime beats 13.33 % of kotlin submissions
#   ✔ Your memory usage beats 6.67 % of kotlin submissions (49.8 MB)
# Submitting: kotlin_solutions_1/2025.maximum-number-of-ways-to-partition-an-array.kt
# - Downloading maximum-number-of-ways-to-partition-an-array
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 38: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Error: Line 38: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2027.minimum-moves-to-convert-string.kt
# - Downloading minimum-moves-to-convert-string
#   ✔ Accepted
#   ✔ 55/55 cases passed (16 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2028.find-missing-observations.kt
# - Downloading find-missing-observations
#   ✔ Accepted
#   ✔ 64/64 cases passed (18 ms)
#   ✔ Your runtime beats 80 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (64.7 MB)
# Submitting: kotlin_solutions_1/2029.stone-game-ix.kt
# - Downloading stone-game-ix
#   ✔ Accepted
#   ✔ 106/106 cases passed (5 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2030.smallest-k-length-subsequence-with-occurrences-of-a-letter.kt
# - Downloading smallest-k-length-subsequence-with-occurrences-of-a-letter
#   ✔ Accepted
#   ✔ 152/152 cases passed (155 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (50.5 MB)
# Submitting: kotlin_solutions_1/2032.two-out-of-three.kt
# - Downloading two-out-of-three
#   ✔ Accepted
#   ✔ 288/288 cases passed (30 ms)
#   ✔ Your runtime beats 14.29 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (50.8 MB)
# Submitting: kotlin_solutions_1/2033.minimum-operations-to-make-a-uni-value-grid.kt
# - Downloading minimum-operations-to-make-a-uni-value-grid
#   ✔ Accepted
#   ✔ 43/43 cases passed (265 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
#   ✔ Your memory usage beats 75 % of kotlin submissions (90.7 MB)
# Submitting: kotlin_solutions_1/2034.stock-price-fluctuation.kt
# - Downloading stock-price-fluctuation
#   ✔ Accepted
#   ✔ 18/18 cases passed (170 ms)
#   ✔ Your runtime beats 40 % of kotlin submissions
#   ✔ Your memory usage beats 10 % of kotlin submissions (132.8 MB)
# Submitting: kotlin_solutions_1/2035.partition-array-into-two-arrays-to-minimize-sum-difference.kt
# - Downloading partition-array-into-two-arrays-to-minimize-sum-difference
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 3: Char 151: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 3: Char 151: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 3: Char 486: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 3: Char 486: ERROR: Not enough information to infer type argument for 'R'.
# Line 3: Char 504: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 3: Char 513: ERROR: None of the following candidates is applicable:
# fun <T : Comparable<T>> Array<out T>.sorted(): List<T>
# fun ByteArray.sorted(): List<Byte>
# fun ShortArray.sorted(): List<Short>
# fun IntArray.sorted(): List<Int>
# fun LongArray.sorted(): List<Long>
# fun FloatArray.sorted(): List<Float>
# fun DoubleArray.sorted(): List<Double>
# fun CharArray.sorted(): List<Char>
# fun <T : Comparable<T>> Iterable<T>.sorted(): List<T>
# fun UIntArray.sorted(): List<UInt>
# fun ULongArray.sorted(): List<ULong>
# fun UByteArray.sorted(): List<UByte>
# fun UShortArray.sorted(): List<UShort>
# fun <T : Comparable<T>> Sequence<T>.sorted(): Sequence<T>
# Line 3: Char 537: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 3: Char 537: ERROR: Not enough information to infer type argument for 'A'.
# Line 3: Char 537: ERROR: Not enough information to infer type argument for 'B'.
# Line 3: Char 542: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 3: Char 542: ERROR: Not enough information to infer type argument for 'R'.
# Line 3: Char 551: ERROR: None of the following candidates is applicable:
# fun <T : Comparable<T>> Array<out T>.sorted(): List<T>
# fun ByteArray.sorted(): List<Byte>
# fun ShortArray.sorted(): List<Short>
# fun IntArray.sorted(): List<Int>
# fun LongArray.sorted(): List<Long>
# fun FloatArray.sorted(): List<Float>
# fun DoubleArray.sorted(): List<Double>
# fun CharArray.sorted(): List<Char>
# fun <T : Comparable<T>> Iterable<T>.sorted(): List<T>
# fun UIntArray.sorted(): List<UInt>
# fun ULongArray.sorted(): List<ULong>
# fun UByteArray.sorted(): List<UByte>
# fun UShortArray.sorted(): List<UShort>
# fun <T : Comparable<T>> Sequence<T>.sorted(): Sequence<T>
# Line 3: Char 577: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 3: Char 577: ERROR: Not enough information to infer type argument for 'T'.
# Line 3: Char 583: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 3: Char 583: ERROR: Function 'component1()' is ambiguous for this expression:
# fun <T> Array<out T>.component1(): T
# fun ByteArray.component1(): Byte
# fun ShortArray.component1(): Short
# fun IntArray.component1(): Int
# fun LongArray.component1(): Long
# fun FloatArray.component1(): Float
# fun DoubleArray.component1(): Double
# fun BooleanArray.component1(): Boolean
# fun CharArray.component1(): Char
# fun <T> List<T>.component1(): T
# fun <K, V> Map.Entry<K, V>.component1(): K
# fun UIntArray.component1(): UInt
# fun ULongArray.component1(): ULong
# fun UByteArray.component1(): UByte
# fun UShortArray.component1(): UShort.
# Line 3: Char 583: ERROR: Function 'component2()' is ambiguous for this expression:
# fun <T> Array<out T>.component2(): T
# fun ByteArray.component2(): Byte
# fun ShortArray.component2(): Short
# fun IntArray.component2(): Int
# fun LongArray.component2(): Long
# fun FloatArray.component2(): Float
# fun DoubleArray.component2(): Double
# fun BooleanArray.component2(): Boolean
# fun CharArray.component2(): Char
# fun <T> List<T>.component2(): T
# fun <K, V> Map.Entry<K, V>.component2(): V
# fun UIntArray.component2(): UInt
# fun ULongArray.component2(): ULong
# fun UByteArray.component2(): UByte
# fun UShortArray.component2(): UShort.
# Line 3: Char 622: ERROR: Overload resolution ambiguity between candidates:
# fun <T> Iterable<T>.minOf(selector: (T) -> Double): Double
# fun <T> Iterable<T>.minOf(selector: (T) -> Float): Float
# fun <T, R : Comparable<R>> Iterable<T>.minOf(selector: (T) -> R): R
# Line 3: Char 635: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 3: Char 635: ERROR: Not enough information to infer type argument for 'V'.
# Line 3: Char 648: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 3: Char 654: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 3: Char 654: ERROR: Not enough information to infer type argument for 'V'.
# Line 3: Char 663: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 3: Char 663: ERROR: Not enough information to infer type argument for 'T'.
# Line 3: Char 669: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 3: Char 709: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 3: Char 709: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun <T, R> T.let(block: (T) -> R): R
#     [R|Contract description]
#      <
#         CallsInPlace(block, EXACTLY_ONCE)
#     >
# Line 3: Char 715: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 3: Char 727: ERROR: 'operator' modifier is required on 'FirNamedFunctionSymbol kotlin/compareTo' in 'compareTo'.
# Line 3: Char 749: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 3: Char 749: ERROR: Not enough information to infer type argument for 'T'.
# Line 3: Char 749: ERROR: Not enough information to infer type argument for 'R'.
# Line 3: Char 755: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 3: Char 762: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 3: Char 776: ERROR: Argument type mismatch: actual type is 'T?', but 'kotlin.Any' was expected.
# Line 3: Char 776: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 3: Char 780: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 3: Char 787: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 3: Char 792: ERROR: 'operator' modifier is required on 'FirNamedFunctionSymbol kotlin/text/compareTo' in 'compareTo'.
# Line 3: Char 797: ERROR: Unresolved reference 'size'.
# Line 3: Char 805: ERROR: Argument type mismatch: actual type is 'T?', but 'kotlin.Any' was expected.
# Line 3: Char 815: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 3: Char 815: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun <T> T.takeIf(predicate: (T) -> Boolean): T?
#     [R|Contract description]
#      <
#         CallsInPlace(predicate, EXACTLY_ONCE)
#     >
# Line 3: Char 822: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 3: Char 827: ERROR: 'operator' modifier is required on 'FirNamedFunctionSymbol kotlin/compareTo' in 'compareTo'.
# Line 3: Char 869: ERROR: Unresolved reference 'it'.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2037.minimum-number-of-moves-to-seat-everyone.kt
# - Downloading minimum-number-of-moves-to-seat-everyone
#   ✔ Accepted
#   ✔ 262/262 cases passed (33 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (48.5 MB)
# Submitting: kotlin_solutions_1/2038.remove-colored-pieces-if-both-neighbors-are-the-same-color.kt
# - Downloading remove-colored-pieces-if-both-neighbors-are-the-same-color
#   ✔ Accepted
#   ✔ 84/84 cases passed (54 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2039.the-time-when-the-network-becomes-idle.kt
# - Downloading the-time-when-the-network-becomes-idle
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 3: Char 248: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 3: Char 248: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 3: Char 280: ERROR: Argument type mismatch: actual type is 'kotlin.Unit', but 'kotlin.Int' was expected.
# Line 3: Char 420: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2040.kth-smallest-product-of-two-sorted-arrays.kt
# - Downloading kth-smallest-product-of-two-sorted-arrays
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 3: Char 418: ERROR: Argument type mismatch: actual type is 'kotlin.Long', but 'K' was expected.
#   ✘ Error: Line 3: Char 418: ERROR: Argument type mismatch: actual type is 'kotlin.Long', but 'K' was expected.
# Line 3: Char 427: ERROR: Argument type mismatch: actual type is 'kotlin.Long', but 'K' was expected.
# Line 3: Char 471: ERROR: Overload resolution ambiguity between candidates:
# fun IntArray.sumOf(selector: (Int) -> BigDecimal): BigDecimal
# fun IntArray.sumOf(selector: (Int) -> BigInteger): BigInteger
# fun IntArray.sumOf(selector: (Int) -> Double): Double
# fun IntArray.sumOf(selector: (Int) -> Int): Int
# fun IntArray.sumOf(selector: (Int) -> Long): Long
# fun IntArray.sumOf(selector: (Int) -> UInt): UInt
# fun IntArray.sumOf(selector: (Int) -> ULong): ULong
# Line 3: Char 574: ERROR: 'fun DeepRecursiveFunction<*, *>.invoke(value: Any?): Nothing' is deprecated. 'invoke' should not be called from DeepRecursiveScope. Use 'callRecursive' to do recursion in the heap instead of the call stack.
# Line 3: Char 628: ERROR: Unresolved reference 'it'.
# Line 3: Char 643: WARNING: Unreachable code.
# Line 3: Char 673: ERROR: None of the following candidates is applicable:
# fun minus(other: Byte): Long
# fun minus(other: Short): Long
# fun minus(other: Int): Long
# fun minus(other: Long): Long
# fun minus(other: Float): Float
# fun minus(other: Double): Double
# Line 3: Char 673: WARNING: Unreachable code.
# Line 3: Char 685: ERROR: 'fun DeepRecursiveFunction<*, *>.invoke(value: Any?): Nothing' is deprecated. 'invoke' should not be called from DeepRecursiveScope. Use 'callRecursive' to do recursion in the heap instead of the call stack.
# Line 3: Char 739: ERROR: Unresolved reference 'it'.
# Line 3: Char 761: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 3: Char 761: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun <T, R> T.let(block: (T) -> R): R
#     [R|Contract description]
#      <
#         CallsInPlace(block, EXACTLY_ONCE)
#     >
# Line 3: Char 767: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 3: Char 778: ERROR: 'operator' modifier is required on 'FirNamedFunctionSymbol kotlin/compareTo' in 'compareTo'.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2042.check-if-numbers-are-ascending-in-a-sentence.kt
# - Downloading check-if-numbers-are-ascending-in-a-sentence
#   ✔ Accepted
#   ✔ 98/98 cases passed (16 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (42.8 MB)
# Submitting: kotlin_solutions_1/2043.simple-bank-system.kt
# - Downloading simple-bank-system
#   ✔ Accepted
#   ✔ 23/23 cases passed (126 ms)
#   ✔ Your runtime beats 75.68 % of kotlin submissions
#   ✔ Your memory usage beats 86.49 % of kotlin submissions (110.2 MB)
# Submitting: kotlin_solutions_1/2044.count-number-of-maximum-bitwise-or-subsets.kt
# - Downloading count-number-of-maximum-bitwise-or-subsets
#   ✔ Accepted
#   ✔ 111/111 cases passed (185 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2045.second-minimum-time-to-reach-destination.kt
# - Downloading second-minimum-time-to-reach-destination
#   ✔ Accepted
#   ✔ 77/77 cases passed (155 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (76.2 MB)
# Submitting: kotlin_solutions_1/2047.number-of-valid-words-in-a-sentence.kt
# - Downloading number-of-valid-words-in-a-sentence
#   ✔ Accepted
#   ✔ 244/244 cases passed (71 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (48.4 MB)
# Submitting: kotlin_solutions_1/2048.next-greater-numerically-balanced-number.kt
# - Downloading next-greater-numerically-balanced-number
#   ✔ Accepted
#   ✔ 145/145 cases passed (447 ms)
#   ✔ Your runtime beats 14.29 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (50.9 MB)
# Submitting: kotlin_solutions_1/2049.count-nodes-with-the-highest-score.kt
# - Downloading count-nodes-with-the-highest-score
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 36: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Error: Line 36: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2050.parallel-courses-iii.kt
# - Downloading parallel-courses-iii
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 129: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 2: Char 129: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 40: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2053.kth-distinct-string-in-an-array.kt
# - Downloading kth-distinct-string-in-an-array
#   ✔ Accepted
#   ✔ 66/66 cases passed (19 ms)
#   ✔ Your runtime beats 12.5 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (47.8 MB)
# Submitting: kotlin_solutions_1/2054.two-best-non-overlapping-events.kt
# - Downloading two-best-non-overlapping-events
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 404: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 2: Char 404: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 36: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2055.plates-between-candles.kt
# - Downloading plates-between-candles
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 38: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Error: Line 38: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2056.number-of-valid-move-combinations-on-chessboard.kt
# - Downloading number-of-valid-move-combinations-on-chessboard
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 1056: ERROR: Unresolved reference 'callRecursive'.
#   ✘ Error: Line 2: Char 1056: ERROR: Unresolved reference 'callRecursive'.
# Line 2: Char 1072: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 1075: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2057.smallest-index-with-equal-value.kt
# - Downloading smallest-index-with-equal-value
#   ✔ Accepted
#   ✔ 663/663 cases passed (14 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2058.find-the-minimum-and-maximum-number-of-nodes-between-critical-points.kt
# - Downloading find-the-minimum-and-maximum-number-of-nodes-between-critical-points
#   ✔ Accepted
#   ✔ 139/139 cases passed (139 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2059.minimum-operations-to-convert-number.kt
# - Downloading minimum-operations-to-convert-number
#   ✔ Accepted
#   ✔ 60/60 cases passed (273 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (54.4 MB)
# Submitting: kotlin_solutions_1/2060.check-if-an-original-string-exists-given-two-encoded-strings.kt
# - Downloading check-if-an-original-string-exists-given-two-encoded-strings
#   ✔ Accepted
#   ✔ 215/215 cases passed (264 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/2062.count-vowel-substrings-of-a-string.kt
# - Downloading count-vowel-substrings-of-a-string
#   ✔ Accepted
#   ✔ 88/88 cases passed (54 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2063.vowels-of-all-substrings.kt
# - Downloading vowels-of-all-substrings
#   ✔ Accepted
#   ✔ 51/51 cases passed (45 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (49.1 MB)
# Submitting: kotlin_solutions_1/2064.minimized-maximum-of-products-distributed-to-any-store.kt
# - Downloading minimized-maximum-of-products-distributed-to-any-store
#   ✔ Accepted
#   ✔ 220/220 cases passed (40 ms)
#   ✔ Your runtime beats 45.45 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (65.7 MB)
# Submitting: kotlin_solutions_1/2065.maximum-path-quality-of-a-graph.kt
# - Downloading maximum-path-quality-of-a-graph
#   ✔ Accepted
#   ✔ 62/62 cases passed (104 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (60.1 MB)

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-08-17 18:46:28
