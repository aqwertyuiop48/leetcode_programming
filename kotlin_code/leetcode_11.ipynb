# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME_3')
    user_cookie = userdata.get('LEETCODE_TOKEN_3')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME_3'] = user_name
    os.environ['LEETCODE_TOKEN_3'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME_3" "$LEETCODE_TOKEN_3" | leetcode user -c

# %%
# %%bash
#
# # top 200-300 answers (next batch)
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v kotlin_solutions_1/*.kt | sed -n '201,300p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 7
# done
# Out:
# Submitting: kotlin_solutions_1/1290.convert-binary-number-in-a-linked-list-to-integer.kt
#   ✔ Accepted
#   ✔ 102/102 cases passed (6 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1291.sequential-digits.kt
#   ✔ Accepted
#   ✔ 24/24 cases passed (20 ms)
#   ✔ Your runtime beats 9.78 % of kotlin submissions
#   ✔ Your memory usage beats 20.11 % of kotlin submissions (45.3 MB)
# Submitting: kotlin_solutions_1/1292.maximum-side-length-of-a-square-with-sum-less-than-or-equal-to-threshold.kt
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 1: Char 230: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 1: Char 230: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 1: Char 266: ERROR: Unresolved reference 'invoke'.
# Line 1: Char 441: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 1: Char 446: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 1: Char 468: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 1: Char 480: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 1: Char 496: ERROR: 'operator' modifier is required on 'FirNamedFunctionSymbol kotlin/text/compareTo' in 'compareTo'.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1293.shortest-path-in-a-grid-with-obstacles-elimination.kt
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 1: Char 197: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 1: Char 197: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 1: Char 222: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 1: Char 235: ERROR: Argument type mismatch: actual type is 'kotlin.Function1<kotlin.Array<kotlin.IntArray>, kotlin.Unit>', but 'kotlin.Function1<kotlin.Array<kotlin.IntArray>, R>' was expected.
# Line 1: Char 258: ERROR: Expression 'java' of type 'java.lang.Class<T>' cannot be invoked as a function. Function 'invoke()' is not found.
# Line 1: Char 262: ERROR: Syntax error: Expecting an element.
# Line 1: Char 263: ERROR: Unresolved reference 'util'.
# Line 1: Char 267: ERROR: Syntax error: Expecting an element.
# Line 1: Char 278: ERROR: Syntax error: Expecting an element.
# Line 1: Char 287: ERROR: Syntax error: Expecting an element.
# Line 1: Char 299: ERROR: Unresolved reference 'add'.
# Line 1: Char 340: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 1: Char 361: ERROR: Unresolved reference 'poll'.
# Line 1: Char 371: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 1: Char 371: ERROR: Not enough information to infer type argument for 'T'.
# Line 1: Char 385: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 1: Char 385: ERROR: Function 'component1()' is ambiguous for this expression:
# fun <T> Array<out T>.component1(): T
# fun ByteArray.component1(): Byte
# fun ShortArray.component1(): Short
# fun IntArray.component1(): Int
# fun LongArray.component1(): Long
# fun FloatArray.component1(): Float
# fun DoubleArray.component1(): Double
# fun BooleanArray.component1(): Boolean
# fun CharArray.component1(): Char
# fun <T> List<T>.component1(): T
# fun <K, V> Map.Entry<K, V>.component1(): K
# fun UIntArray.component1(): UInt
# fun ULongArray.component1(): ULong
# fun UByteArray.component1(): UByte
# fun UShortArray.component1(): UShort.
# Line 1: Char 385: ERROR: Function 'component2()' is ambiguous for this expression:
# fun <T> Array<out T>.component2(): T
# fun ByteArray.component2(): Byte
# fun ShortArray.component2(): Short
# fun IntArray.component2(): Int
# fun LongArray.component2(): Long
# fun FloatArray.component2(): Float
# fun DoubleArray.component2(): Double
# fun BooleanArray.component2(): Boolean
# fun CharArray.component2(): Char
# fun <T> List<T>.component2(): T
# fun <K, V> Map.Entry<K, V>.component2(): V
# fun UIntArray.component2(): UInt
# fun ULongArray.component2(): ULong
# fun UByteArray.component2(): UByte
# fun UShortArray.component2(): UShort.
# Line 1: Char 385: ERROR: Function 'component3()' is ambiguous for this expression:
# fun <T> Array<out T>.component3(): T
# fun ByteArray.component3(): Byte
# fun ShortArray.component3(): Short
# fun IntArray.component3(): Int
# fun LongArray.component3(): Long
# fun FloatArray.component3(): Float
# fun DoubleArray.component3(): Double
# fun BooleanArray.component3(): Boolean
# fun CharArray.component3(): Char
# fun <T> List<T>.component3(): T
# fun UIntArray.component3(): UInt
# fun ULongArray.component3(): ULong
# fun UByteArray.component3(): UByte
# fun UShortArray.component3(): UShort.
# Line 1: Char 385: ERROR: Function 'component4()' is ambiguous for this expression:
# fun <T> Array<out T>.component4(): T
# fun ByteArray.component4(): Byte
# fun ShortArray.component4(): Short
# fun IntArray.component4(): Int
# fun LongArray.component4(): Long
# fun FloatArray.component4(): Float
# fun DoubleArray.component4(): Double
# fun BooleanArray.component4(): Boolean
# fun CharArray.component4(): Char
# fun <T> List<T>.component4(): T
# fun UIntArray.component4(): UInt
# fun ULongArray.component4(): ULong
# fun UByteArray.component4(): UByte
# fun UShortArray.component4(): UShort.
# Line 1: Char 543: ERROR: Syntax error: Unexpected tokens (use ';' to separate expressions on the same line).
# Line 1: Char 559: ERROR: Syntax error: Unexpected tokens (use ';' to separate expressions on the same line).
# Line 1: Char 567: ERROR: Type inference failed. The value of the type parameter 'T' should be mentioned in input types (argument types, receiver type, or expected type). Try to specify it explicitly.
# Line 1: Char 589: ERROR: Type inference failed. The value of the type parameter 'T' should be mentioned in input types (argument types, receiver type, or expected type). Try to specify it explicitly.
# Line 1: Char 622: ERROR: Argument type mismatch: actual type is 'kotlin.IntArray', but 'kotlin.Int' was expected.
# Line 1: Char 626: ERROR: Argument type mismatch: actual type is 'kotlin.IntArray', but 'kotlin.Int' was expected.
# Line 1: Char 630: ERROR: 'operator' modifier is required on 'FirNamedFunctionSymbol kotlin/compareTo' in 'compareTo'.
# Line 1: Char 636: ERROR: Argument type mismatch: actual type is 'kotlin.IntArray', but 'kotlin.Int' was expected.
# Line 1: Char 640: ERROR: Argument type mismatch: actual type is 'kotlin.IntArray', but 'kotlin.Int' was expected.
# Line 1: Char 651: ERROR: Argument type mismatch: actual type is 'kotlin.IntArray', but 'kotlin.Int' was expected.
# Line 1: Char 655: ERROR: Argument type mismatch: actual type is 'kotlin.IntArray', but 'kotlin.Int' was expected.
# Line 1: Char 672: ERROR: Argument type mismatch: actual type is 'kotlin.IntArray', but 'kotlin.Int' was expected.
# Line 1: Char 676: ERROR: Argument type mismatch: actual type is 'kotlin.IntArray', but 'kotlin.Int' was expected.
# Line 1: Char 680: ERROR: Unresolved reference 'q'.
# Line 1: Char 681: ERROR: Syntax error: Expecting an element.
# Line 1: Char 697: ERROR: Argument type mismatch: actual type is 'kotlin.IntArray', but 'kotlin.Int' was expected.
# Line 1: Char 701: ERROR: Argument type mismatch: actual type is 'kotlin.IntArray', but 'kotlin.Int' was expected.
# Line 1: Char 716: ERROR: Argument type mismatch: actual type is 'kotlin.IntArray', but 'kotlin.Int' was expected.
# Line 1: Char 720: ERROR: Argument type mismatch: actual type is 'kotlin.IntArray', but 'kotlin.Int' was expected.
# Line 1: Char 736: ERROR: Syntax error: Unexpected tokens (use ';' to separate expressions on the same line).
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1295.find-numbers-with-even-number-of-digits.kt
#   ✔ Accepted
#   ✔ 105/105 cases passed (2 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (45 MB)
# Submitting: kotlin_solutions_1/1296.divide-array-in-sets-of-k-consecutive-numbers.kt
# - Downloading divide-array-in-sets-of-k-consecutive-numbers
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 1: Char 290: ERROR: Unresolved reference 'keys'.
#   ✘ Error: Line 1: Char 290: ERROR: Unresolved reference 'keys'.
# Line 1: Char 294: ERROR: Syntax error: Expecting an element.
# Line 1: Char 301: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 1: Char 329: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 1: Char 382: ERROR: Type inference failed. The value of the type parameter 'K' should be mentioned in input types (argument types, receiver type, or expected type). Try to specify it explicitly.
# Line 1: Char 424: ERROR: Argument type mismatch: actual type is 'kotlin.IntArray', but 'kotlin.Int' was expected.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1297.maximum-number-of-occurrences-of-a-substring.kt
# - Downloading maximum-number-of-occurrences-of-a-substring
#   ✔ Accepted
#   ✔ 40/40 cases passed (87 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1298.maximum-candies-you-can-get-from-boxes.kt
# - Downloading maximum-candies-you-can-get-from-boxes
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 1: Char 412: ERROR: Syntax error: Unexpected tokens (use ';' to separate expressions on the same line).
#   ✘ Error: Line 1: Char 412: ERROR: Syntax error: Unexpected tokens (use ';' to separate expressions on the same line).
# Line 1: Char 510: ERROR: Argument type mismatch: actual type is 'kotlin.Any', but 'kotlin.Int' was expected.
# Line 1: Char 555: ERROR: Unresolved reference 'keys'.
# Line 1: Char 559: ERROR: Unsupported [Collection literals outside of annotations].
# Line 1: Char 591: ERROR: Syntax error: Unexpected tokens (use ';' to separate expressions on the same line).
# Line 1: Char 646: ERROR: Unsupported [Collection literals outside of annotations].
# Line 1: Char 683: ERROR: Syntax error: Unexpected tokens (use ';' to separate expressions on the same line).
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1299.replace-elements-with-greatest-element-on-right-side.kt
# - Downloading replace-elements-with-greatest-element-on-right-side
#   ✔ Accepted
#   ✔ 90/90 cases passed (11 ms)
#   ✔ Your runtime beats 51.85 % of kotlin submissions
#   ✔ Your memory usage beats 70.37 % of kotlin submissions (49.8 MB)
# Submitting: kotlin_solutions_1/1300.sum-of-mutated-array-closest-to-target.kt
# - Downloading sum-of-mutated-array-closest-to-target
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 1: Char 289: WARNING: Parameter '<unused var>: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 1: Char 289: WARNING: Parameter '<unused var>: Int' is never used, could be renamed to '_'.
# Line 1: Char 433: ERROR: None of the following candidates is applicable:
# fun MatchResult.range(): IntRange
# fun MatchResult.range(groupIndex: Int): IntRange
# Line 1: Char 438: ERROR: Unsupported [Collection literals outside of annotations].
# Line 1: Char 494: ERROR: None of the following candidates is applicable:
# fun <T> Iterable<T>.minus(element: T): List<T>
# fun <T> Iterable<T>.minus(elements: Array<out T>): List<T>
# fun <T> Iterable<T>.minus(elements: Iterable<T>): List<T>
# fun <T> Iterable<T>.minus(elements: Sequence<T>): List<T>
# fun <K, V> Map<out K, V>.minus(key: K): Map<K, V>
# fun <K, V> Map<out K, V>.minus(keys: Iterable<K>): Map<K, V>
# fun <K, V> Map<out K, V>.minus(keys: Array<out K>): Map<K, V>
# fun <K, V> Map<out K, V>.minus(keys: Sequence<K>): Map<K, V>
# fun <T> Set<T>.minus(element: T): Set<T>
# fun <T> Set<T>.minus(elements: Array<out T>): Set<T>
# fun <T> Set<T>.minus(elements: Iterable<T>): Set<T>
# fun <T> Set<T>.minus(elements: Sequence<T>): Set<T>
# fun <T> Sequence<T>.minus(element: T): Sequence<T>
# fun <T> Sequence<T>.minus(elements: Array<out T>): Sequence<T>
# fun <T> Sequence<T>.minus(elements: Iterable<T>): Sequence<T>
# fun <T> Sequence<T>.minus(elements: Sequence<T>): Sequence<T>
# Line 1: Char 527: ERROR: Overload resolution ambiguity between candidates:
# fun IntArray.sumOf(selector: (Int) -> BigDecimal): BigDecimal
# fun IntArray.sumOf(selector: (Int) -> BigInteger): BigInteger
# fun IntArray.sumOf(selector: (Int) -> Double): Double
# fun IntArray.sumOf(selector: (Int) -> Int): Int
# fun IntArray.sumOf(selector: (Int) -> Long): Long
# fun IntArray.sumOf(selector: (Int) -> UInt): UInt
# fun IntArray.sumOf(selector: (Int) -> ULong): ULong
# Line 1: Char 535: ERROR: None of the following candidates is applicable:
# fun <T : Comparable<T>> minOf(a: T, b: T): T
# fun minOf(a: Byte, b: Byte): Byte
# fun minOf(a: Short, b: Short): Short
# fun minOf(a: Int, b: Int): Int
# fun minOf(a: Long, b: Long): Long
# fun minOf(a: Float, b: Float): Float
# fun minOf(a: Double, b: Double): Double
# fun <T : Comparable<T>> minOf(a: T, vararg other: T): T
# fun minOf(a: Byte, vararg other: Byte): Byte
# fun minOf(a: Short, vararg other: Short): Short
# fun minOf(a: Int, vararg other: Int): Int
# fun minOf(a: Long, vararg other: Long): Long
# fun minOf(a: Float, vararg other: Float): Float
# fun minOf(a: Double, vararg other: Double): Double
# fun minOf(a: UInt, b: UInt): UInt
# fun minOf(a: ULong, b: ULong): ULong
# fun minOf(a: UByte, b: UByte): UByte
# fun minOf(a: UShort, b: UShort): UShort
# fun minOf(a: UInt, vararg other: UInt): UInt
# fun minOf(a: ULong, vararg other: ULong): ULong
# fun minOf(a: UByte, vararg other: UByte): UByte
# fun minOf(a: UShort, vararg other: UShort): UShort
# Line 1: Char 567: ERROR: None of the following candidates is applicable:
# fun <T> Iterable<T>.minus(element: T): List<T>
# fun <T> Iterable<T>.minus(elements: Array<out T>): List<T>
# fun <T> Iterable<T>.minus(elements: Iterable<T>): List<T>
# fun <T> Iterable<T>.minus(elements: Sequence<T>): List<T>
# fun <K, V> Map<out K, V>.minus(key: K): Map<K, V>
# fun <K, V> Map<out K, V>.minus(keys: Iterable<K>): Map<K, V>
# fun <K, V> Map<out K, V>.minus(keys: Array<out K>): Map<K, V>
# fun <K, V> Map<out K, V>.minus(keys: Sequence<K>): Map<K, V>
# fun <T> Set<T>.minus(element: T): Set<T>
# fun <T> Set<T>.minus(elements: Array<out T>): Set<T>
# fun <T> Set<T>.minus(elements: Iterable<T>): Set<T>
# fun <T> Set<T>.minus(elements: Sequence<T>): Set<T>
# fun <T> Sequence<T>.minus(element: T): Sequence<T>
# fun <T> Sequence<T>.minus(elements: Array<out T>): Sequence<T>
# fun <T> Sequence<T>.minus(elements: Iterable<T>): Sequence<T>
# fun <T> Sequence<T>.minus(elements: Sequence<T>): Sequence<T>
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1301.number-of-paths-with-max-score.kt
# - Downloading number-of-paths-with-max-score
#   ✔ Accepted
#   ✔ 36/36 cases passed (274 ms)
#   ✔ Your runtime beats 5.55 % of kotlin submissions
#   ✔ Your memory usage beats 5.55 % of kotlin submissions (55.7 MB)
# Submitting: kotlin_solutions_1/1302.deepest-leaves-sum.kt
# - Downloading deepest-leaves-sum
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 1: Char 263: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
#   ✘ Error: Line 1: Char 263: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 1: Char 267: WARNING: Parameter 'it: ArrayDeque<TreeNode>' is never used, could be renamed to '_'.
# Line 1: Char 286: ERROR: Overload resolution ambiguity between candidates:
# fun <T> Iterable<T>.sumOf(selector: (T) -> BigDecimal): BigDecimal
# fun <T> Iterable<T>.sumOf(selector: (T) -> BigInteger): BigInteger
# fun <T> Iterable<T>.sumOf(selector: (T) -> Double): Double
# fun <T> Iterable<T>.sumOf(selector: (T) -> Int): Int
# fun <T> Iterable<T>.sumOf(selector: (T) -> Long): Long
# fun <T> Iterable<T>.sumOf(selector: (T) -> UInt): UInt
# fun <T> Iterable<T>.sumOf(selector: (T) -> ULong): ULong
# Line 1: Char 292: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 1: Char 303: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 1: Char 346: ERROR: Unresolved reference 'node'.
# Line 1: Char 350: ERROR: Syntax error: Expecting an element.
# Line 1: Char 356: ERROR: Syntax error: Expecting an element.
# Line 1: Char 358: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 1: Char 362: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 1: Char 376: ERROR: Unresolved reference 'node'.
# Line 1: Char 380: ERROR: Syntax error: Expecting an element.
# Line 1: Char 386: ERROR: Syntax error: Expecting an element.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1304.find-n-unique-integers-sum-up-to-zero.kt
# - Downloading find-n-unique-integers-sum-up-to-zero
#   ✔ Accepted
#   ✔ 43/43 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 83.33 % of kotlin submissions (40.9 MB)
# Submitting: kotlin_solutions_1/1305.all-elements-in-two-binary-search-trees.kt
# - Downloading all-elements-in-two-binary-search-trees
#   ✔ Accepted
#   ✔ 48/48 cases passed (113 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1306.jump-game-iii.kt
# - Downloading jump-game-iii
#   ✔ Accepted
#   ✔ 56/56 cases passed (10 ms)
#   ✔ Your runtime beats 69.77 % of kotlin submissions
#   ✔ Your memory usage beats 62.79 % of kotlin submissions (56.7 MB)
# Submitting: kotlin_solutions_1/1307.verbal-arithmetic-puzzle.kt
# - Downloading verbal-arithmetic-puzzle
#   ✔ Accepted
#   ✔ 35/35 cases passed (1387 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1309.decrypt-string-from-alphabet-to-integer-mapping.kt
# - Downloading decrypt-string-from-alphabet-to-integer-mapping
#   ✔ Accepted
#   ✔ 41/41 cases passed (35 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1310.xor-queries-of-a-subarray.kt
# - Downloading xor-queries-of-a-subarray
#   ✔ Accepted
#   ✔ 46/46 cases passed (346 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (77.5 MB)
# Submitting: kotlin_solutions_1/1311.get-watched-videos-by-your-friends.kt
# - Downloading get-watched-videos-by-your-friends
#   ✔ Accepted
#   ✔ 52/52 cases passed (79 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (65.7 MB)
# Submitting: kotlin_solutions_1/1312.minimum-insertion-steps-to-make-a-string-palindrome.kt
# - Downloading minimum-insertion-steps-to-make-a-string-palindrome
#   ✔ Accepted
#   ✔ 58/58 cases passed (59 ms)
#   ✔ Your runtime beats 10 % of kotlin submissions
#   ✔ Your memory usage beats 10 % of kotlin submissions (49.3 MB)
# Submitting: kotlin_solutions_1/1313.decompress-run-length-encoded-list.kt
# - Downloading decompress-run-length-encoded-list
#   ✔ Accepted
#   ✔ 53/53 cases passed (19 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
#   ✔ Your memory usage beats 62.5 % of kotlin submissions (47.4 MB)
# Submitting: kotlin_solutions_1/1314.matrix-block-sum.kt
# - Downloading matrix-block-sum
#   ✔ Accepted
#   ✔ 12/12 cases passed (13 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (51.4 MB)
# Submitting: kotlin_solutions_1/1315.sum-of-nodes-with-even-valued-grandparent.kt
# - Downloading sum-of-nodes-with-even-valued-grandparent
#   ✔ Accepted
#   ✔ 76/76 cases passed (40 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1316.distinct-echo-substrings.kt
# - Downloading distinct-echo-substrings
#   ✔ Accepted
#   ✔ 40/40 cases passed (1092 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1317.convert-integer-to-the-sum-of-two-no-zero-integers.kt
# - Downloading convert-integer-to-the-sum-of-two-no-zero-integers
#   ✔ Accepted
#   ✔ 206/206 cases passed (12 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (42.4 MB)
# Submitting: kotlin_solutions_1/1318.minimum-flips-to-make-a-or-b-equal-to-c.kt
# - Downloading minimum-flips-to-make-a-or-b-equal-to-c
#   ✔ Accepted
#   ✔ 64/64 cases passed (84 ms)
#   ✔ Your runtime beats 21.74 % of kotlin submissions
#   ✔ Your memory usage beats 30.43 % of kotlin submissions (39.6 MB)
# Submitting: kotlin_solutions_1/1319.number-of-operations-to-make-network-connected.kt
# - Downloading number-of-operations-to-make-network-connected
#   ✔ Accepted
#   ✔ 36/36 cases passed (48 ms)
#   ✔ Your runtime beats 17.65 % of kotlin submissions
#   ✔ Your memory usage beats 58.82 % of kotlin submissions (72.4 MB)
# Submitting: kotlin_solutions_1/1320.minimum-distance-to-type-a-word-using-two-fingers.kt
# - Downloading minimum-distance-to-type-a-word-using-two-fingers
#   ✔ Accepted
#   ✔ 55/55 cases passed (25 ms)
#   ✔ Your runtime beats 75 % of kotlin submissions
#   ✔ Your memory usage beats 75 % of kotlin submissions (46.4 MB)
# Submitting: kotlin_solutions_1/1323.maximum-69-number.kt
# - Downloading maximum-69-number
#   ✔ Accepted
#   ✔ 153/153 cases passed (8 ms)
#   ✔ Your runtime beats 27.27 % of kotlin submissions
#   ✔ Your memory usage beats 36.36 % of kotlin submissions (41.4 MB)
# Submitting: kotlin_solutions_1/1324.print-words-vertically.kt
# - Downloading print-words-vertically
#   ✔ Accepted
#   ✔ 32/32 cases passed (122 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1325.delete-leaves-with-a-given-value.kt
# - Downloading delete-leaves-with-a-given-value
#   ✔ Accepted
#   ✔ 51/51 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 13.33 % of kotlin submissions (46.4 MB)
# Submitting: kotlin_solutions_1/1326.minimum-number-of-taps-to-open-to-water-a-garden.kt
# - Downloading minimum-number-of-taps-to-open-to-water-a-garden
#   ✔ Accepted
#   ✔ 42/42 cases passed (19 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (48.7 MB)
# Submitting: kotlin_solutions_1/1328.break-a-palindrome.kt
# - Downloading break-a-palindrome
#   ✔ Accepted
#   ✔ 33/33 cases passed (9 ms)
#   ✔ Your runtime beats 28.57 % of kotlin submissions
#   ✔ Your memory usage beats 28.57 % of kotlin submissions (42.6 MB)
# Submitting: kotlin_solutions_1/1330.reverse-subarray-to-maximize-array-value.kt
# - Downloading reverse-subarray-to-maximize-array-value
#   ✔ Accepted
#   ✔ 28/28 cases passed (24 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1331.rank-transform-of-an-array.kt
# - Downloading rank-transform-of-an-array
#   ✔ Accepted
#   ✔ 43/43 cases passed (107 ms)
#   ✔ Your runtime beats 19.09 % of kotlin submissions
#   ✔ Your memory usage beats 19.09 % of kotlin submissions (72.9 MB)
# Submitting: kotlin_solutions_1/1332.remove-palindromic-subsequences.kt
# - Downloading remove-palindromic-subsequences
#   ✔ Accepted
#   ✔ 48/48 cases passed (7 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
#   ✔ Your memory usage beats 10 % of kotlin submissions (42.4 MB)
# Submitting: kotlin_solutions_1/1333.filter-restaurants-by-vegan-friendly-price-and-distance.kt
# - Downloading filter-restaurants-by-vegan-friendly-price-and-distance
#   ✔ Accepted
#   ✔ 53/53 cases passed (22 ms)
#   ✔ Your runtime beats 14.29 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (63.2 MB)
# Submitting: kotlin_solutions_1/1334.find-the-city-with-the-smallest-number-of-neighbors-at-a-threshold-distance.kt
# - Downloading find-the-city-with-the-smallest-number-of-neighbors-at-a-threshold-distance
#   ✔ Accepted
#   ✔ 54/54 cases passed (39 ms)
#   ✔ Your runtime beats 60.87 % of kotlin submissions
#   ✔ Your memory usage beats 78.26 % of kotlin submissions (48.6 MB)
# Submitting: kotlin_solutions_1/1335.minimum-difficulty-of-a-job-schedule.kt
# - Downloading minimum-difficulty-of-a-job-schedule
#   ✔ Accepted
#   ✔ 34/34 cases passed (33 ms)
#   ✔ Your runtime beats 18.18 % of kotlin submissions
#   ✔ Your memory usage beats 9.09 % of kotlin submissions (44.3 MB)
# Submitting: kotlin_solutions_1/1337.the-k-weakest-rows-in-a-matrix.kt
# - Downloading the-k-weakest-rows-in-a-matrix
#   ✔ Accepted
#   ✔ 52/52 cases passed (22 ms)
#   ✔ Your runtime beats 21.43 % of kotlin submissions
#   ✔ Your memory usage beats 57.14 % of kotlin submissions (52.9 MB)
# Submitting: kotlin_solutions_1/1338.reduce-array-size-to-the-half.kt
# - Downloading reduce-array-size-to-the-half
#   ✔ Accepted
#   ✔ 33/33 cases passed (92 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (81.8 MB)
# Submitting: kotlin_solutions_1/1339.maximum-product-of-splitted-binary-tree.kt
# - Downloading maximum-product-of-splitted-binary-tree
#   ✔ Accepted
#   ✔ 56/56 cases passed (81 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1340.jump-game-v.kt
# - Downloading jump-game-v
#   ✔ Accepted
#   ✔ 129/129 cases passed (110 ms)
#   ✔ Your runtime beats 14.29 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (54.5 MB)
# Submitting: kotlin_solutions_1/1342.number-of-steps-to-reduce-a-number-to-zero.kt
# - Downloading number-of-steps-to-reduce-a-number-to-zero
#   ✔ Accepted
#   ✔ 204/204 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 58.06 % of kotlin submissions (40.2 MB)
# Submitting: kotlin_solutions_1/1343.number-of-sub-arrays-of-size-k-and-average-greater-than-or-equal-to-threshold.kt
# - Downloading number-of-sub-arrays-of-size-k-and-average-greater-than-or-equal-to-threshold
#   ✔ Accepted
#   ✔ 69/69 cases passed (22 ms)
#   ✔ Your runtime beats 26.67 % of kotlin submissions
#   ✔ Your memory usage beats 6.67 % of kotlin submissions (64.3 MB)
# Submitting: kotlin_solutions_1/1344.angle-between-hands-of-a-clock.kt
# - Downloading angle-between-hands-of-a-clock
#   ✔ Accepted
#   ✔ 105/105 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 13.7 % of kotlin submissions (40.8 MB)
# Submitting: kotlin_solutions_1/1345.jump-game-iv.kt
# - Downloading jump-game-iv
#   ✔ Accepted
#   ✔ 535/535 cases passed (244 ms)
#   ✔ Your runtime beats 5.26 % of kotlin submissions
#   ✔ Your memory usage beats 10.53 % of kotlin submissions (82.8 MB)
# Submitting: kotlin_solutions_1/1346.check-if-n-and-its-double-exist.kt
# - Downloading check-if-n-and-its-double-exist
#   ✔ Accepted
#   ✔ 113/113 cases passed (20 ms)
#   ✔ Your runtime beats 5.56 % of kotlin submissions
#   ✔ Your memory usage beats 5.56 % of kotlin submissions (46.8 MB)
# Submitting: kotlin_solutions_1/1347.minimum-number-of-steps-to-make-two-strings-anagram.kt
# - Downloading minimum-number-of-steps-to-make-two-strings-anagram
#   ✔ Accepted
#   ✔ 63/63 cases passed (29 ms)
#   ✔ Your runtime beats 28.57 % of kotlin submissions
#   ✔ Your memory usage beats 57.14 % of kotlin submissions (47.6 MB)
# Submitting: kotlin_solutions_1/1349.maximum-students-taking-exam.kt
# - Downloading maximum-students-taking-exam
#   ✔ Accepted
#   ✔ 57/57 cases passed (32 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1351.count-negative-numbers-in-a-sorted-matrix.kt
# - Downloading count-negative-numbers-in-a-sorted-matrix
#   ✔ Accepted
#   ✔ 44/44 cases passed (1 ms)
#   ✔ Your runtime beats 45 % of kotlin submissions
#   ✔ Your memory usage beats 40 % of kotlin submissions (49 MB)
# Submitting: kotlin_solutions_1/1352.product-of-the-last-k-numbers.kt
# - Downloading product-of-the-last-k-numbers
#   ✔ Accepted
#   ✔ 35/35 cases passed (55 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (91.1 MB)
# Submitting: kotlin_solutions_1/1353.maximum-number-of-events-that-can-be-attended.kt
# - Downloading maximum-number-of-events-that-can-be-attended
#   ✔ Accepted
#   ✔ 45/45 cases passed (101 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (100.5 MB)
# Submitting: kotlin_solutions_1/1354.construct-target-array-with-multiple-sums.kt
# - Downloading construct-target-array-with-multiple-sums
#   ✔ Accepted
#   ✔ 73/73 cases passed (12 ms)
#   ✔ Your runtime beats 66.67 % of kotlin submissions
#   ✔ Your memory usage beats 55.56 % of kotlin submissions (53.5 MB)
# Submitting: kotlin_solutions_1/1356.sort-integers-by-the-number-of-1-bits.kt
# - Downloading sort-integers-by-the-number-of-1-bits
#   ✔ Accepted
#   ✔ 77/77 cases passed (30 ms)
#   ✔ Your runtime beats 10 % of kotlin submissions
#   ✔ Your memory usage beats 10 % of kotlin submissions (50.2 MB)
# Submitting: kotlin_solutions_1/1357.apply-discount-every-n-orders.kt
# - Downloading apply-discount-every-n-orders
#   ✔ Accepted
#   ✔ 25/25 cases passed (243 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (103.5 MB)
# Submitting: kotlin_solutions_1/1358.number-of-substrings-containing-all-three-characters.kt
# - Downloading number-of-substrings-containing-all-three-characters
#   ✔ Accepted
#   ✔ 55/55 cases passed (25 ms)
#   ✔ Your runtime beats 26.36 % of kotlin submissions
#   ✔ Your memory usage beats 27.99 % of kotlin submissions (46.5 MB)
# Submitting: kotlin_solutions_1/1359.count-all-valid-pickup-and-delivery-options.kt
# - Downloading count-all-valid-pickup-and-delivery-options
#   ✔ Accepted
#   ✔ 36/36 cases passed (4 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1360.number-of-days-between-two-dates.kt
# - Downloading number-of-days-between-two-dates
#   ✔ Accepted
#   ✔ 105/105 cases passed (9 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1362.closest-divisors.kt
# - Downloading closest-divisors
#   ✔ Accepted
#   ✔ 113/113 cases passed (14 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1363.largest-multiple-of-three.kt
# - Downloading largest-multiple-of-three
#   ✔ Accepted
#   ✔ 45/45 cases passed (31 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1365.how-many-numbers-are-smaller-than-the-current-number.kt
# - Downloading how-many-numbers-are-smaller-than-the-current-number
#   ✔ Accepted
#   ✔ 103/103 cases passed (25 ms)
#   ✔ Your runtime beats 16.28 % of kotlin submissions
#   ✔ Your memory usage beats 5.43 % of kotlin submissions (49.2 MB)
# Submitting: kotlin_solutions_1/1366.rank-teams-by-votes.kt
# - Downloading rank-teams-by-votes
#   ✔ Accepted
#   ✔ 37/37 cases passed (37 ms)
#   ✔ Your runtime beats 40 % of kotlin submissions
#   ✔ Your memory usage beats 80 % of kotlin submissions (47.3 MB)
# Submitting: kotlin_solutions_1/1368.minimum-cost-to-make-at-least-one-valid-path-in-a-grid.kt
# - Downloading minimum-cost-to-make-at-least-one-valid-path-in-a-grid
#   ✔ Accepted
#   ✔ 69/69 cases passed (51 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (57.3 MB)
# Submitting: kotlin_solutions_1/1370.increasing-decreasing-string.kt
# - Downloading increasing-decreasing-string
#   ✔ Accepted
#   ✔ 323/323 cases passed (22 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1371.find-the-longest-substring-containing-vowels-in-even-counts.kt
# - Downloading find-the-longest-substring-containing-vowels-in-even-counts
#   ✔ Accepted
#   ✔ 55/55 cases passed (33 ms)
#   ✔ Your runtime beats 66.67 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (51.5 MB)
# Submitting: kotlin_solutions_1/1372.longest-zigzag-path-in-a-binary-tree.kt
# - Downloading longest-zigzag-path-in-a-binary-tree
#   ✔ Accepted
#   ✔ 58/58 cases passed (69 ms)
#   ✔ Your runtime beats 8.33 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (61.8 MB)
# Submitting: kotlin_solutions_1/1373.maximum-sum-bst-in-binary-tree.kt
# - Downloading maximum-sum-bst-in-binary-tree
#   ✔ Accepted
#   ✔ 60/60 cases passed (82 ms)
#   ✔ Your runtime beats 12.5 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (69.7 MB)
# Submitting: kotlin_solutions_1/1374.generate-a-string-with-characters-that-have-odd-counts.kt
# - Downloading generate-a-string-with-characters-that-have-odd-counts
#   ✔ Accepted
#   ✔ 103/103 cases passed (6 ms)
#   ✔ Your runtime beats 53.85 % of kotlin submissions
#   ✔ Your memory usage beats 46.15 % of kotlin submissions (41.7 MB)
# Submitting: kotlin_solutions_1/1375.number-of-times-binary-string-is-prefix-aligned.kt
# - Downloading number-of-times-binary-string-is-prefix-aligned
#   ✔ Accepted
#   ✔ 63/63 cases passed (34 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1376.time-needed-to-inform-all-employees.kt
# - Downloading time-needed-to-inform-all-employees
#   ✔ Accepted
#   ✔ 39/39 cases passed (135 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 38.89 % of kotlin submissions (72.5 MB)
# Submitting: kotlin_solutions_1/1377.frog-position-after-t-seconds.kt
# - Downloading frog-position-after-t-seconds
#   ✔ Accepted
#   ✔ 207/207 cases passed (19 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1380.lucky-numbers-in-a-matrix.kt
# - Downloading lucky-numbers-in-a-matrix
#   ✔ Accepted
#   ✔ 106/106 cases passed (26 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1381.design-a-stack-with-increment-operation.kt
# - Downloading design-a-stack-with-increment-operation
#   ✔ Accepted
#   ✔ 34/34 cases passed (19 ms)
#   ✔ Your runtime beats 77.78 % of kotlin submissions
#   ✔ Your memory usage beats 55.56 % of kotlin submissions (48.3 MB)
# Submitting: kotlin_solutions_1/1382.balance-a-binary-search-tree.kt
# - Downloading balance-a-binary-search-tree
#   ✔ Accepted
#   ✔ 17/17 cases passed (66 ms)
#   ✔ Your runtime beats 14.29 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (52.2 MB)
# Submitting: kotlin_solutions_1/1383.maximum-performance-of-a-team.kt
# - Downloading maximum-performance-of-a-team
#   ✔ Accepted
#   ✔ 55/55 cases passed (100 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1385.find-the-distance-value-between-two-arrays.kt
# - Downloading find-the-distance-value-between-two-arrays
#   ✔ Accepted
#   ✔ 103/103 cases passed (7 ms)
#   ✔ Your runtime beats 55.56 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (44.8 MB)
# Submitting: kotlin_solutions_1/1387.sort-integers-by-the-power-value.kt
# - Downloading sort-integers-by-the-power-value
#   ✔ Accepted
#   ✔ 333/333 cases passed (873 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1388.pizza-with-3n-slices.kt
# - Downloading pizza-with-3n-slices
#   ✔ Accepted
#   ✔ 69/69 cases passed (118 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (58.7 MB)
# Submitting: kotlin_solutions_1/1390.four-divisors.kt
# - Downloading four-divisors
#   ✔ Accepted
#   ✔ 19/19 cases passed (160 ms)
#   ✔ Your runtime beats 60 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/1392.longest-happy-prefix.kt
# - Downloading longest-happy-prefix
#   ✔ Accepted
#   ✔ 83/83 cases passed (112 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/1394.find-lucky-integer-in-an-array.kt
# - Downloading find-lucky-integer-in-an-array
#   ✔ Accepted
#   ✔ 102/102 cases passed (13 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (46.5 MB)
# Submitting: kotlin_solutions_1/1395.count-number-of-teams.kt
# - Downloading count-number-of-teams
#   ✔ Accepted
#   ✔ 72/72 cases passed (64 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1396.design-underground-system.kt
# - Downloading design-underground-system
#   ✔ Accepted
#   ✔ 57/57 cases passed (164 ms)
#   ✔ Your runtime beats 25.81 % of kotlin submissions
#   ✔ Your memory usage beats 51.61 % of kotlin submissions (82 MB)
# Submitting: kotlin_solutions_1/1397.find-all-good-strings.kt
# - Downloading find-all-good-strings
#   ✔ Accepted
#   ✔ 55/55 cases passed (254 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1399.count-largest-group.kt
# - Downloading count-largest-group
#   ✔ Accepted
#   ✔ 75/75 cases passed (28 ms)
#   ✔ Your runtime beats 28.57 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (45.8 MB)
# Submitting: kotlin_solutions_1/1400.construct-k-palindrome-strings.kt
# - Downloading construct-k-palindrome-strings
#   ✔ Accepted
#   ✔ 112/112 cases passed (46 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1401.circle-and-rectangle-overlapping.kt
# - Downloading circle-and-rectangle-overlapping
#   ✔ Accepted
#   ✔ 90/90 cases passed (1 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (40.5 MB)
# Submitting: kotlin_solutions_1/1402.reducing-dishes.kt
# - Downloading reducing-dishes
#   ✔ Accepted
#   ✔ 60/60 cases passed (22 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1403.minimum-subsequence-in-non-increasing-order.kt
# - Downloading minimum-subsequence-in-non-increasing-order
#   ✔ Accepted
#   ✔ 103/103 cases passed (28 ms)
#   ✔ Your runtime beats 14.29 % of kotlin submissions
#   ✔ Your memory usage beats 28.57 % of kotlin submissions (48.7 MB)
# Submitting: kotlin_solutions_1/1404.number-of-steps-to-reduce-a-number-in-binary-representation-to-one.kt
# - Downloading number-of-steps-to-reduce-a-number-in-binary-representation-to-one
#   ✔ Accepted
#   ✔ 75/75 cases passed (11 ms)
#   ✔ Your runtime beats 38.46 % of kotlin submissions
#   ✔ Your memory usage beats 46.15 % of kotlin submissions (42.3 MB)
# Submitting: kotlin_solutions_1/1405.longest-happy-string.kt
# - Downloading longest-happy-string
#   ✔ Accepted
#   ✔ 36/36 cases passed (13 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
#   ✔ Your memory usage beats 30 % of kotlin submissions (42.4 MB)
# Submitting: kotlin_solutions_1/1406.stone-game-iii.kt
# - Downloading stone-game-iii
#   ✔ Accepted
#   ✔ 187/187 cases passed (94 ms)
#   ✔ Your runtime beats 11.17 % of kotlin submissions
#   ✔ Your memory usage beats 85.92 % of kotlin submissions (64.7 MB)
# Submitting: kotlin_solutions_1/1408.string-matching-in-an-array.kt
# - Downloading string-matching-in-an-array
#   ✔ Accepted
#   ✔ 69/69 cases passed (16 ms)
#   ✔ Your runtime beats 30.77 % of kotlin submissions
#   ✔ Your memory usage beats 46.15 % of kotlin submissions (43.4 MB)
# Submitting: kotlin_solutions_1/1409.queries-on-a-permutation-with-key.kt
# - Downloading queries-on-a-permutation-with-key
#   ✔ Accepted
#   ✔ 53/53 cases passed (13 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1410.html-entity-parser.kt
# - Downloading html-entity-parser
#   ✔ Accepted
#   ✔ 171/171 cases passed (36 ms)
#   ✔ Your runtime beats 85.71 % of kotlin submissions
#   ✔ Your memory usage beats 57.14 % of kotlin submissions (50.1 MB)
# Submitting: kotlin_solutions_1/1411.number-of-ways-to-paint-n-3-grid.kt
# - Downloading number-of-ways-to-paint-n-3-grid
#   ✔ Accepted
#   ✔ 50/50 cases passed (22 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1413.minimum-value-to-get-positive-step-by-step-sum.kt
# - Downloading minimum-value-to-get-positive-step-by-step-sum
#   ✔ Accepted
#   ✔ 57/57 cases passed (6 ms)
#   ✔ Your runtime beats 8.7 % of kotlin submissions
#   ✔ Your memory usage beats 8.7 % of kotlin submissions (41.9 MB)
# Submitting: kotlin_solutions_1/1414.find-the-minimum-number-of-fibonacci-numbers-whose-sum-is-k.kt
# - Downloading find-the-minimum-number-of-fibonacci-numbers-whose-sum-is-k
#   ✔ Accepted
#   ✔ 504/504 cases passed (23 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1416.restore-the-array.kt
# - Downloading restore-the-array
#   ✔ Accepted
#   ✔ 86/86 cases passed (105 ms)
# [WARN] Failed to get runtime percentile.

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-08-18 12:50:58
