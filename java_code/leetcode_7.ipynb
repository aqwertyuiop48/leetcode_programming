# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME_2')
    user_cookie = userdata.get('LEETCODE_TOKEN_2')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME_2'] = user_name
    os.environ['LEETCODE_TOKEN_2'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME_2" "$LEETCODE_TOKEN_2" | leetcode user -c

# %%
# %%bash
#
#
# # top 100 answers
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v java_solutions/*.java | sed -n '601,700p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 7
# done
# Out:
# Submitting: java_solutions/1665.minimum-initial-energy-to-finish-tasks.java
# - Downloading minimum-initial-energy-to-finish-tasks
#   ✔ Accepted
#   ✔ 42/42 cases passed (39 ms)
#   ✔ Your runtime beats 9.17 % of java submissions
#   ✔ Your memory usage beats 98.17 % of java submissions (111.5 MB)
# Submitting: java_solutions/1668.maximum-repeating-substring.java
# - Downloading maximum-repeating-substring
#   ✔ Accepted
#   ✔ 212/212 cases passed (5 ms)
#   ✔ Your runtime beats 0.72 % of java submissions
#   ✔ Your memory usage beats 10.52 % of java submissions (43.5 MB)
# Submitting: java_solutions/1669.merge-in-between-linked-lists.java
# - Downloading merge-in-between-linked-lists
#   ✔ Accepted
#   ✔ 61/61 cases passed (6 ms)
#   ✔ Your runtime beats 3.91 % of java submissions
#   ✔ Your memory usage beats 5.51 % of java submissions (55.1 MB)
# Submitting: java_solutions/1671.minimum-number-of-removals-to-make-mountain-array.java
# - Downloading minimum-number-of-removals-to-make-mountain-array
#   ✔ Accepted
#   ✔ 91/91 cases passed (64 ms)
#   ✔ Your runtime beats 5.18 % of java submissions
#   ✔ Your memory usage beats 48.5 % of java submissions (46.5 MB)
# Submitting: java_solutions/1675.minimize-deviation-in-array.java
# - Downloading minimize-deviation-in-array
#   ✔ Accepted
#   ✔ 76/76 cases passed (410 ms)
#   ✔ Your runtime beats 60.9 % of java submissions
#   ✔ Your memory usage beats 29.32 % of java submissions (66.9 MB)
# Submitting: java_solutions/1678.goal-parser-interpretation.java
# - Downloading goal-parser-interpretation
#   ✔ Accepted
#   ✔ 105/105 cases passed (3 ms)
#   ✔ Your runtime beats 7.28 % of java submissions
#   ✔ Your memory usage beats 6.17 % of java submissions (44.2 MB)
# Submitting: java_solutions/1681.minimum-incompatibility.java
# - Downloading minimum-incompatibility
#   ✔ Accepted
#   ✔ 59/59 cases passed (56 ms)
#   ✔ Your runtime beats 83.87 % of java submissions
#   ✔ Your memory usage beats 46.77 % of java submissions (47.9 MB)
# Submitting: java_solutions/1687.delivering-boxes-from-storage-to-ports.java
# - Downloading delivering-boxes-from-storage-to-ports
#   ✔ Accepted
#   ✔ 39/39 cases passed (23 ms)
#   ✔ Your runtime beats 61.33 % of java submissions
#   ✔ Your memory usage beats 40 % of java submissions (150.8 MB)
# Submitting: java_solutions/1691.maximum-height-by-stacking-cuboids.java
# - Downloading maximum-height-by-stacking-cuboids
#   ✔ Accepted
#   ✔ 83/83 cases passed (26 ms)
#   ✔ Your runtime beats 5.03 % of java submissions
#   ✔ Your memory usage beats 5.03 % of java submissions (46.9 MB)
# Submitting: java_solutions/1694.reformat-phone-number.java
# - Downloading reformat-phone-number
#   ✔ Accepted
#   ✔ 108/108 cases passed (9 ms)
#   ✔ Your runtime beats 6.61 % of java submissions
#   ✔ Your memory usage beats 6.61 % of java submissions (44.6 MB)
# Submitting: java_solutions/1697.checking-existence-of-edge-length-limited-paths.java
# - Downloading checking-existence-of-edge-length-limited-paths
#   ✔ Accepted
#   ✔ 24/24 cases passed (91 ms)
#   ✔ Your runtime beats 8.69 % of java submissions
#   ✔ Your memory usage beats 23.3 % of java submissions (131.1 MB)
# Submitting: java_solutions/1703.minimum-adjacent-swaps-for-k-consecutive-ones.java
# - Downloading minimum-adjacent-swaps-for-k-consecutive-ones
#   ✔ Accepted
#   ✔ 117/117 cases passed (17 ms)
#   ✔ Your runtime beats 31.15 % of java submissions
#   ✔ Your memory usage beats 67.21 % of java submissions (104.6 MB)
# Submitting: java_solutions/1704.determine-if-string-halves-are-alike.java
# - Downloading determine-if-string-halves-are-alike
#   ✔ Accepted
#   ✔ 113/113 cases passed (5 ms)
#   ✔ Your runtime beats 39.62 % of java submissions
#   ✔ Your memory usage beats 42.05 % of java submissions (43.2 MB)
# Submitting: java_solutions/1707.maximum-xor-with-an-element-from-array.java
# - Downloading maximum-xor-with-an-element-from-array
#   ✔ Accepted
#   ✔ 67/67 cases passed (285 ms)
#   ✔ Your runtime beats 5.03 % of java submissions
#   ✔ Your memory usage beats 5.25 % of java submissions (268.1 MB)
# Submitting: java_solutions/1710.maximum-units-on-a-truck.java
# - Downloading maximum-units-on-a-truck
#   ✔ Accepted
#   ✔ 77/77 cases passed (13 ms)
#   ✔ Your runtime beats 12.34 % of java submissions
#   ✔ Your memory usage beats 30.35 % of java submissions (47 MB)
# Submitting: java_solutions/1713.minimum-operations-to-make-a-subsequence.java
# - Downloading minimum-operations-to-make-a-subsequence
#   ✔ Accepted
#   ✔ 82/82 cases passed (67 ms)
#   ✔ Your runtime beats 75.47 % of java submissions
#   ✔ Your memory usage beats 6.6 % of java submissions (136.6 MB)
# Submitting: java_solutions/1716.calculate-money-in-leetcode-bank.java
# - Downloading calculate-money-in-leetcode-bank
#   ✔ Accepted
#   ✔ 106/106 cases passed (5 ms)
#   ✔ Your runtime beats 2.38 % of java submissions
#   ✔ Your memory usage beats 16.25 % of java submissions (42.3 MB)
# Submitting: java_solutions/1719.number-of-ways-to-reconstruct-a-tree.java
# - Downloading number-of-ways-to-reconstruct-a-tree
#   ✔ Accepted
#   ✔ 81/81 cases passed (25 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 90.57 % of java submissions (114.9 MB)
# Submitting: java_solutions/1720.decode-xored-array.java
# - Downloading decode-xored-array
#   ✔ Accepted
#   ✔ 76/76 cases passed (8 ms)
#   ✔ Your runtime beats 1.37 % of java submissions
#   ✔ Your memory usage beats 93.56 % of java submissions (47.7 MB)
# Submitting: java_solutions/1721.swapping-nodes-in-a-linked-list.java
# - Downloading swapping-nodes-in-a-linked-list
#   ✔ Accepted
#   ✔ 132/132 cases passed (20 ms)
#   ✔ Your runtime beats 4.32 % of java submissions
#   ✔ Your memory usage beats 15.89 % of java submissions (119.8 MB)
# Submitting: java_solutions/1723.find-minimum-time-to-finish-all-jobs.java
# - Downloading find-minimum-time-to-finish-all-jobs
#   ✔ Accepted
#   ✔ 65/65 cases passed (180 ms)
#   ✔ Your runtime beats 20.54 % of java submissions
#   ✔ Your memory usage beats 25.38 % of java submissions (43.9 MB)
# Submitting: java_solutions/1728.cat-and-mouse-ii.java
# - Downloading cat-and-mouse-ii
#   ✔ Accepted
#   ✔ 180/180 cases passed (22 ms)
#   ✔ Your runtime beats 79.49 % of java submissions
#   ✔ Your memory usage beats 67.52 % of java submissions (48.1 MB)
# Submitting: java_solutions/1732.find-the-highest-altitude.java
# - Downloading find-the-highest-altitude
#   ✔ Accepted
#   ✔ 80/80 cases passed (11 ms)
#   ✔ Your runtime beats 1.36 % of java submissions
#   ✔ Your memory usage beats 10.25 % of java submissions (44.8 MB)
# Submitting: java_solutions/1735.count-ways-to-make-array-with-product.java
# - Downloading count-ways-to-make-array-with-product
#   ✔ Accepted
#   ✔ 67/67 cases passed (27 ms)
#   ✔ Your runtime beats 54 % of java submissions
#   ✔ Your memory usage beats 88 % of java submissions (48.2 MB)
# Submitting: java_solutions/1736.latest-time-by-replacing-hidden-digits.java
# - Downloading latest-time-by-replacing-hidden-digits
# [ERROR] session expired, please login again [code=-1]
# Submitting: java_solutions/1739.building-boxes.java
# - Downloading building-boxes
#   ✔ Accepted
#   ✔ 86/86 cases passed (86 ms)
#   ✔ Your runtime beats 8.57 % of java submissions
#   ✔ Your memory usage beats 28.57 % of java submissions (42.3 MB)
# Submitting: java_solutions/1742.maximum-number-of-balls-in-a-box.java
# - Downloading maximum-number-of-balls-in-a-box
#   ✔ Accepted
#   ✔ 97/97 cases passed (220 ms)
#   ✔ Your runtime beats 5.27 % of java submissions
#   ✔ Your memory usage beats 9.61 % of java submissions (52.6 MB)
# Submitting: java_solutions/1745.palindrome-partitioning-iv.java
# - Downloading palindrome-partitioning-iv
#   ✔ Accepted
#   ✔ 92/92 cases passed (138 ms)
#   ✔ Your runtime beats 9.65 % of java submissions
#   ✔ Your memory usage beats 44.67 % of java submissions (48.2 MB)
# Submitting: java_solutions/1748.sum-of-unique-elements.java
# - Downloading sum-of-unique-elements
#   ✔ Accepted
#   ✔ 73/73 cases passed (16 ms)
#   ✔ Your runtime beats 3.11 % of java submissions
#   ✔ Your memory usage beats 11.61 % of java submissions (50.1 MB)
# Submitting: java_solutions/1751.maximum-number-of-events-that-can-be-attended-ii.java
# - Downloading maximum-number-of-events-that-can-be-attended-ii
#   ✔ Accepted
#   ✔ 70/70 cases passed (91 ms)
#   ✔ Your runtime beats 72.43 % of java submissions
#   ✔ Your memory usage beats 83.78 % of java submissions (180.1 MB)
# Submitting: java_solutions/1752.check-if-array-is-sorted-and-rotated.java
# - Downloading check-if-array-is-sorted-and-rotated
#   ✔ Accepted
#   ✔ 113/113 cases passed (3 ms)
#   ✔ Your runtime beats 3.43 % of java submissions
#   ✔ Your memory usage beats 70.39 % of java submissions (43 MB)
# Submitting: java_solutions/1755.closest-subsequence-sum.java
# - Downloading closest-subsequence-sum
#   ✔ Accepted
#   ✔ 74/74 cases passed (219 ms)
#   ✔ Your runtime beats 87.88 % of java submissions
#   ✔ Your memory usage beats 82.32 % of java submissions (86.5 MB)
# Submitting: java_solutions/1758.minimum-changes-to-make-alternating-binary-string.java
# - Downloading minimum-changes-to-make-alternating-binary-string
#   ✔ Accepted
#   ✔ 89/89 cases passed (6 ms)
#   ✔ Your runtime beats 30.13 % of java submissions
#   ✔ Your memory usage beats 9.12 % of java submissions (44.2 MB)
# Submitting: java_solutions/1761.minimum-degree-of-a-connected-trio-in-a-graph.java
# - Downloading minimum-degree-of-a-connected-trio-in-a-graph
#   ✔ Accepted
#   ✔ 68/68 cases passed (62 ms)
#   ✔ Your runtime beats 52.83 % of java submissions
#   ✔ Your memory usage beats 80.19 % of java submissions (70.2 MB)
# Submitting: java_solutions/1766.tree-of-coprimes.java
# - Downloading tree-of-coprimes
#   ✔ Accepted
#   ✔ 37/37 cases passed (124 ms)
#   ✔ Your runtime beats 57.9 % of java submissions
#   ✔ Your memory usage beats 98.95 % of java submissions (142.1 MB)
# Submitting: java_solutions/1768.merge-strings-alternately.java
# - Downloading merge-strings-alternately
#   ✔ Accepted
#   ✔ 108/108 cases passed (6 ms)
#   ✔ Your runtime beats 6.01 % of java submissions
#   ✔ Your memory usage beats 8.18 % of java submissions (44.2 MB)
# Submitting: java_solutions/1770.maximum-score-from-performing-multiplication-operations.java
# - Downloading maximum-score-from-performing-multiplication-operations
#   ✔ Accepted
#   ✔ 59/59 cases passed (19 ms)
#   ✔ Your runtime beats 32.84 % of java submissions
#   ✔ Your memory usage beats 83.03 % of java submissions (64 MB)
# Submitting: java_solutions/1771.maximize-palindrome-length-from-subsequences.java
# - Downloading maximize-palindrome-length-from-subsequences
#   ✔ Accepted
#   ✔ 109/109 cases passed (54 ms)
#   ✔ Your runtime beats 47.76 % of java submissions
#   ✔ Your memory usage beats 34.33 % of java submissions (82.3 MB)
# Submitting: java_solutions/1776.car-fleet-ii.java
# - Downloading car-fleet-ii
#   ✔ Accepted
#   ✔ 85/85 cases passed (12 ms)
#   ✔ Your runtime beats 99.29 % of java submissions
#   ✔ Your memory usage beats 95.71 % of java submissions (180 MB)
# Submitting: java_solutions/1779.find-nearest-point-that-has-the-same-x-or-y-coordinate.java
# - Downloading find-nearest-point-that-has-the-same-x-or-y-coordinate
#   ✔ Accepted
#   ✔ 102/102 cases passed (13 ms)
#   ✔ Your runtime beats 3.72 % of java submissions
#   ✔ Your memory usage beats 5.41 % of java submissions (57.6 MB)
# Submitting: java_solutions/1782.count-pairs-of-nodes.java
# - Downloading count-pairs-of-nodes
#   ✔ Accepted
#   ✔ 63/63 cases passed (1024 ms)
#   ✔ Your runtime beats 25.49 % of java submissions
#   ✔ Your memory usage beats 84.31 % of java submissions (177.6 MB)
# Submitting: java_solutions/1784.check-if-binary-string-has-at-most-one-segment-of-ones.java
# - Downloading check-if-binary-string-has-at-most-one-segment-of-ones
#   ✔ Accepted
#   ✔ 191/191 cases passed (5 ms)
#   ✔ Your runtime beats 0.36 % of java submissions
#   ✔ Your memory usage beats 16.33 % of java submissions (43.2 MB)
# Submitting: java_solutions/1787.make-the-xor-of-all-segments-equal-to-zero.java
# - Downloading make-the-xor-of-all-segments-equal-to-zero
#   ✔ Accepted
#   ✔ 81/81 cases passed (1294 ms)
#   ✔ Your runtime beats 5.13 % of java submissions
#   ✔ Your memory usage beats 12.82 % of java submissions (74.8 MB)
# Submitting: java_solutions/1793.maximum-score-of-a-good-subarray.java
# - Downloading maximum-score-of-a-good-subarray
#   ✔ Accepted
#   ✔ 73/73 cases passed (13 ms)
#   ✔ Your runtime beats 29.09 % of java submissions
#   ✔ Your memory usage beats 84.85 % of java submissions (83.1 MB)
# Submitting: java_solutions/1796.second-largest-digit-in-a-string.java
# - Downloading second-largest-digit-in-a-string
#   ✔ Accepted
#   ✔ 301/301 cases passed (15 ms)
#   ✔ Your runtime beats 5 % of java submissions
#   ✔ Your memory usage beats 10.21 % of java submissions (44.1 MB)
# Submitting: java_solutions/1799.maximize-score-after-n-operations.java
# - Downloading maximize-score-after-n-operations
#   ✔ Accepted
#   ✔ 77/77 cases passed (625 ms)
#   ✔ Your runtime beats 9.16 % of java submissions
#   ✔ Your memory usage beats 9.16 % of java submissions (54.1 MB)
# Submitting: java_solutions/1800.maximum-ascending-subarray-sum.java
# - Downloading maximum-ascending-subarray-sum
#   ✔ Accepted
#   ✔ 104/104 cases passed (4 ms)
#   ✔ Your runtime beats 1.08 % of java submissions
#   ✔ Your memory usage beats 12.78 % of java submissions (43.8 MB)
# Submitting: java_solutions/1803.count-pairs-with-xor-in-a-range.java
# - Downloading count-pairs-with-xor-in-a-range
#   ✔ Accepted
#   ✔ 63/63 cases passed (635 ms)
#   ✔ Your runtime beats 5.13 % of java submissions
#   ✔ Your memory usage beats 5.13 % of java submissions (282.7 MB)
# Submitting: java_solutions/1805.number-of-different-integers-in-a-string.java
# - Downloading number-of-different-integers-in-a-string
#   ✔ Accepted
#   ✔ 86/86 cases passed (12 ms)
#   ✔ Your runtime beats 9.49 % of java submissions
#   ✔ Your memory usage beats 46.25 % of java submissions (43.6 MB)
# Submitting: java_solutions/1808.maximize-number-of-nice-divisors.java
# - Downloading maximize-number-of-nice-divisors
#   ✔ Accepted
#   ✔ 213/213 cases passed (6 ms)
#   ✔ Your runtime beats 1.54 % of java submissions
#   ✔ Your memory usage beats 9.23 % of java submissions (43 MB)
# Submitting: java_solutions/1812.determine-color-of-a-chessboard-square.java
# - Downloading determine-color-of-a-chessboard-square
#   ✔ Accepted
#   ✔ 64/64 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 22.16 % of java submissions (42.9 MB)
# Submitting: java_solutions/1815.maximum-number-of-groups-getting-fresh-donuts.java
# - Downloading maximum-number-of-groups-getting-fresh-donuts
#   ✔ Accepted
#   ✔ 74/74 cases passed (1126 ms)
#   ✔ Your runtime beats 32.08 % of java submissions
#   ✔ Your memory usage beats 35.85 % of java submissions (103.2 MB)
# Submitting: java_solutions/1816.truncate-sentence.java
# - Downloading truncate-sentence
#   ✔ Accepted
#   ✔ 72/72 cases passed (2 ms)
#   ✔ Your runtime beats 42.64 % of java submissions
#   ✔ Your memory usage beats 42.64 % of java submissions (43.4 MB)
# Submitting: java_solutions/1819.number-of-different-subsequences-gcds.java
# - Downloading number-of-different-subsequences-gcds
#   ✔ Accepted
#   ✔ 39/39 cases passed (2698 ms)
#   ✔ Your runtime beats 5.62 % of java submissions
#   ✔ Your memory usage beats 19.1 % of java submissions (99.1 MB)
# Submitting: java_solutions/1819.number-of-different-subsequences-gc-ds.java
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 4: error: missing return statement
#   ✘ Error: Line 4: error: missing return statement
#     }
#     ^
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: java_solutions/1822.sign-of-the-product-of-an-array.java
# - Downloading sign-of-the-product-of-an-array
#   ✔ Accepted
#   ✔ 76/76 cases passed (4 ms)
#   ✔ Your runtime beats 0.97 % of java submissions
#   ✔ Your memory usage beats 24.62 % of java submissions (45.4 MB)
# Submitting: java_solutions/1825.finding-mk-average.java
# - Downloading finding-mk-average
#   ✔ Accepted
#   ✔ 18/18 cases passed (444 ms)
#   ✔ Your runtime beats 17.81 % of java submissions
#   ✔ Your memory usage beats 5.48 % of java submissions (122.6 MB)
# Submitting: java_solutions/1827.minimum-operations-to-make-the-array-increasing.java
# - Downloading minimum-operations-to-make-the-array-increasing
#   ✔ Accepted
#   ✔ 94/94 cases passed (6 ms)
#   ✔ Your runtime beats 11.21 % of java submissions
#   ✔ Your memory usage beats 11.13 % of java submissions (47.3 MB)
# Submitting: java_solutions/1830.minimum-number-of-operations-to-make-string-sorted.java
# - Downloading minimum-number-of-operations-to-make-string-sorted
#   ✔ Accepted
#   ✔ 73/73 cases passed (201 ms)
#   ✔ Your runtime beats 38.64 % of java submissions
#   ✔ Your memory usage beats 11.36 % of java submissions (53.4 MB)
# Submitting: java_solutions/1832.check-if-the-sentence-is-pangram.java
# - Downloading check-if-the-sentence-is-pangram
#   ✔ Accepted
#   ✔ 79/79 cases passed (6 ms)
#   ✔ Your runtime beats 5.85 % of java submissions
#   ✔ Your memory usage beats 24.94 % of java submissions (43.1 MB)
# Submitting: java_solutions/1835.find-xor-sum-of-all-pairs-bitwise-and.java
# - Downloading find-xor-sum-of-all-pairs-bitwise-and
#   ✔ Accepted
#   ✔ 84/84 cases passed (6 ms)
#   ✔ Your runtime beats 6.8 % of java submissions
#   ✔ Your memory usage beats 98.64 % of java submissions (81.7 MB)
# Submitting: java_solutions/1837.sum-of-digits-in-base-k.java
# - Downloading sum-of-digits-in-base-k
#   ✔ Accepted
#   ✔ 65/65 cases passed (4 ms)
#   ✔ Your runtime beats 0.74 % of java submissions
#   ✔ Your memory usage beats 61.6 % of java submissions (42.1 MB)
# Submitting: java_solutions/1840.maximum-building-height.java
# - Downloading maximum-building-height
#   ✔ Accepted
#   ✔ 50/50 cases passed (75 ms)
#   ✔ Your runtime beats 8.11 % of java submissions
#   ✔ Your memory usage beats 5.41 % of java submissions (131.5 MB)
# Submitting: java_solutions/1847.closest-room.java
# - Downloading closest-room
#   ✔ Accepted
#   ✔ 43/43 cases passed (126 ms)
#   ✔ Your runtime beats 31.71 % of java submissions
#   ✔ Your memory usage beats 7.32 % of java submissions (185.6 MB)
# Submitting: java_solutions/1851.minimum-interval-to-include-each-query.java
# - Downloading minimum-interval-to-include-each-query
#   ✔ Accepted
#   ✔ 42/42 cases passed (489 ms)
#   ✔ Your runtime beats 5.11 % of java submissions
#   ✔ Your memory usage beats 30.55 % of java submissions (145.1 MB)
# Submitting: java_solutions/1857.largest-color-value-in-a-directed-graph.java
# - Downloading largest-color-value-in-a-directed-graph
#   ✔ Accepted
#   ✔ 84/84 cases passed (412 ms)
#   ✔ Your runtime beats 5.2 % of java submissions
#   ✔ Your memory usage beats 5.89 % of java submissions (324.5 MB)
# Submitting: java_solutions/1859.sorting-the-sentence.java
# - Downloading sorting-the-sentence
#   ✔ Accepted
#   ✔ 45/45 cases passed (5 ms)
#   ✔ Your runtime beats 2.62 % of java submissions
#   ✔ Your memory usage beats 7.74 % of java submissions (43.2 MB)
# Submitting: java_solutions/1862.sum-of-floored-pairs.java
# - Downloading sum-of-floored-pairs
#   ✔ Accepted
#   ✔ 51/51 cases passed (102 ms)
#   ✔ Your runtime beats 11.34 % of java submissions
#   ✔ Your memory usage beats 5.15 % of java submissions (119.7 MB)
# Submitting: java_solutions/1866.number-of-ways-to-rearrange-sticks-with-k-sticks-visible.java
# - Downloading number-of-ways-to-rearrange-sticks-with-k-sticks-visible
#   ✔ Accepted
#   ✔ 50/50 cases passed (66 ms)
#   ✔ Your runtime beats 10.67 % of java submissions
#   ✔ Your memory usage beats 94.94 % of java submissions (46.1 MB)
# Submitting: java_solutions/1869.longer-contiguous-segments-of-ones-than-zeros.java
# - Downloading longer-contiguous-segments-of-ones-than-zeros
#   ✔ Accepted
#   ✔ 141/141 cases passed (6 ms)
#   ✔ Your runtime beats 3.12 % of java submissions
#   ✔ Your memory usage beats 13.57 % of java submissions (43.7 MB)
# Submitting: java_solutions/1872.stone-game-viii.java
# - Downloading stone-game-viii
#   ✔ Accepted
#   ✔ 78/78 cases passed (21 ms)
#   ✔ Your runtime beats 20.51 % of java submissions
#   ✔ Your memory usage beats 76.92 % of java submissions (85.1 MB)
# Submitting: java_solutions/1876.substrings-of-size-three-with-distinct-characters.java
# - Downloading substrings-of-size-three-with-distinct-characters
#   ✔ Accepted
#   ✔ 160/160 cases passed (3 ms)
#   ✔ Your runtime beats 32.75 % of java submissions
#   ✔ Your memory usage beats 40.92 % of java submissions (43.2 MB)
# Submitting: java_solutions/1879.minimum-xor-sum-of-two-arrays.java
# - Downloading minimum-xor-sum-of-two-arrays
#   ✔ Accepted
#   ✔ 64/64 cases passed (59 ms)
#   ✔ Your runtime beats 13.76 % of java submissions
#   ✔ Your memory usage beats 9.52 % of java submissions (53.1 MB)
# Submitting: java_solutions/1880.check-if-word-equals-summation-of-two-words.java
# - Downloading check-if-word-equals-summation-of-two-words
#   ✔ Accepted
#   ✔ 100/100 cases passed (5 ms)
#   ✔ Your runtime beats 2.51 % of java submissions
#   ✔ Your memory usage beats 17.83 % of java submissions (43.1 MB)
# Submitting: java_solutions/1883.minimum-skips-to-arrive-at-meeting-on-time.java
# - Downloading minimum-skips-to-arrive-at-meeting-on-time
#   ✔ Accepted
#   ✔ 61/61 cases passed (148 ms)
#   ✔ Your runtime beats 6.38 % of java submissions
#   ✔ Your memory usage beats 65.96 % of java submissions (52.7 MB)
# Submitting: java_solutions/1886.determine-whether-matrix-can-be-obtained-by-rotation.java
# - Downloading determine-whether-matrix-can-be-obtained-by-rotation
#   ✔ Accepted
#   ✔ 113/113 cases passed (10 ms)
#   ✔ Your runtime beats 0.93 % of java submissions
#   ✔ Your memory usage beats 7.42 % of java submissions (50 MB)
# Submitting: java_solutions/1889.minimum-space-wasted-from-packaging.java
# - Downloading minimum-space-wasted-from-packaging
#   ✔ Accepted
#   ✔ 42/42 cases passed (494 ms)
#   ✔ Your runtime beats 5.61 % of java submissions
#   ✔ Your memory usage beats 5.61 % of java submissions (137.8 MB)
# Submitting: java_solutions/1893.check-if-all-the-integers-in-a-range-are-covered.java
# - Downloading check-if-all-the-integers-in-a-range-are-covered
#   ✔ Accepted
#   ✔ 106/106 cases passed (7 ms)
#   ✔ Your runtime beats 3.95 % of java submissions
#   ✔ Your memory usage beats 7.73 % of java submissions (44 MB)
# Submitting: java_solutions/1896.minimum-cost-to-change-the-final-value-of-expression.java
# - Downloading minimum-cost-to-change-the-final-value-of-expression
#   ✔ Accepted
#   ✔ 70/70 cases passed (213 ms)
#   ✔ Your runtime beats 7.69 % of java submissions
#   ✔ Your memory usage beats 38.46 % of java submissions (66.1 MB)
# Submitting: java_solutions/1900.the-earliest-and-latest-rounds-where-players-compete.java
# - Downloading the-earliest-and-latest-rounds-where-players-compete
#   ✔ Accepted
#   ✔ 139/139 cases passed (12 ms)
#   ✔ Your runtime beats 46.94 % of java submissions
#   ✔ Your memory usage beats 14.29 % of java submissions (51 MB)
# Submitting: java_solutions/1903.largest-odd-number-in-string.java
# - Downloading largest-odd-number-in-string
#   ✔ Accepted
#   ✔ 196/196 cases passed (10 ms)
#   ✔ Your runtime beats 5.51 % of java submissions
#   ✔ Your memory usage beats 5.35 % of java submissions (47.6 MB)
# Submitting: java_solutions/1909.remove-one-element-to-make-the-array-strictly-increasing.java
# - Downloading remove-one-element-to-make-the-array-strictly-increasing
#   ✔ Accepted
#   ✔ 109/109 cases passed (115 ms)
#   ✔ Your runtime beats 5.03 % of java submissions
#   ✔ Your memory usage beats 5.03 % of java submissions (46.3 MB)
# Submitting: java_solutions/1912.design-movie-rental-system.java
# - Downloading design-movie-rental-system
#   ✔ Accepted
#   ✔ 42/42 cases passed (605 ms)
#   ✔ Your runtime beats 7.41 % of java submissions
#   ✔ Your memory usage beats 42.96 % of java submissions (280.9 MB)
# Submitting: java_solutions/1913.maximum-product-difference-between-two-pairs.java
# - Downloading maximum-product-difference-between-two-pairs
#   ✔ Accepted
#   ✔ 96/96 cases passed (23 ms)
#   ✔ Your runtime beats 8.64 % of java submissions
#   ✔ Your memory usage beats 7.85 % of java submissions (48.1 MB)
# Submitting: java_solutions/1916.count-ways-to-build-rooms-in-an-ant-colony.java
# - Downloading count-ways-to-build-rooms-in-an-ant-colony
#   ✔ Accepted
#   ✔ 66/66 cases passed (1242 ms)
#   ✔ Your runtime beats 6.56 % of java submissions
#   ✔ Your memory usage beats 37.71 % of java submissions (160.3 MB)
# Submitting: java_solutions/1920.build-array-from-permutation.java
# - Downloading build-array-from-permutation
#   ✔ Accepted
#   ✔ 140/140 cases passed (5 ms)
#   ✔ Your runtime beats 0.81 % of java submissions
#   ✔ Your memory usage beats 38.03 % of java submissions (47.2 MB)
# Submitting: java_solutions/1923.longest-common-subpath.java
# - Downloading longest-common-subpath
#   ✔ Accepted
#   ✔ 81/81 cases passed (217 ms)
#   ✔ Your runtime beats 95.31 % of java submissions
#   ✔ Your memory usage beats 79.69 % of java submissions (158.7 MB)
# Submitting: java_solutions/1925.count-square-sum-triples.java
# - Downloading count-square-sum-triples
#   ✔ Accepted
#   ✔ 91/91 cases passed (42 ms)
#   ✔ Your runtime beats 28.6 % of java submissions
#   ✔ Your memory usage beats 6.48 % of java submissions (45.5 MB)
# Submitting: java_solutions/1928.minimum-cost-to-reach-destination-in-time.java
# - Downloading minimum-cost-to-reach-destination-in-time
#   ✔ Accepted
#   ✔ 96/96 cases passed (1391 ms)
#   ✔ Your runtime beats 13.98 % of java submissions
#   ✔ Your memory usage beats 49.34 % of java submissions (53.3 MB)
# Submitting: java_solutions/1929.concatenation-of-array.java
# - Downloading concatenation-of-array
#   ✔ Accepted
#   ✔ 92/92 cases passed (6 ms)
#   ✔ Your runtime beats 1.34 % of java submissions
#   ✔ Your memory usage beats 23.98 % of java submissions (47.4 MB)
# Submitting: java_solutions/1931.painting-a-grid-with-three-different-colors.java
# - Downloading painting-a-grid-with-three-different-colors
#   ✔ Accepted
#   ✔ 84/84 cases passed (320 ms)
#   ✔ Your runtime beats 9.04 % of java submissions
#   ✔ Your memory usage beats 13.25 % of java submissions (53.7 MB)
# Submitting: java_solutions/1932.merge-bsts-to-create-single-bst.java
# - Downloading merge-bsts-to-create-single-bst
#   ✔ Accepted
#   ✔ 475/475 cases passed (63 ms)
#   ✔ Your runtime beats 5.86 % of java submissions
#   ✔ Your memory usage beats 19.78 % of java submissions (143.3 MB)
# Submitting: java_solutions/1935.maximum-number-of-words-you-can-type.java
# - Downloading maximum-number-of-words-you-can-type
#   ✔ Accepted
#   ✔ 20/20 cases passed (7 ms)
#   ✔ Your runtime beats 9.91 % of java submissions
#   ✔ Your memory usage beats 6.4 % of java submissions (44.9 MB)
# Submitting: java_solutions/1938.maximum-genetic-difference-query.java
# - Downloading maximum-genetic-difference-query
#   ✔ Accepted
#   ✔ 59/59 cases passed (810 ms)
#   ✔ Your runtime beats 5.05 % of java submissions
#   ✔ Your memory usage beats 6.06 % of java submissions (280.1 MB)
# Submitting: java_solutions/1941.check-if-all-characters-have-equal-number-of-occurrences.java
# - Downloading check-if-all-characters-have-equal-number-of-occurrences
#   ✔ Accepted
#   ✔ 134/134 cases passed (21 ms)
#   ✔ Your runtime beats 6.11 % of java submissions
#   ✔ Your memory usage beats 9.27 % of java submissions (50.9 MB)
# Submitting: java_solutions/1944.number-of-visible-people-in-a-queue.java
# - Downloading number-of-visible-people-in-a-queue
#   ✔ Accepted
#   ✔ 42/42 cases passed (172 ms)
#   ✔ Your runtime beats 5.29 % of java submissions
#   ✔ Your memory usage beats 5.19 % of java submissions (130.3 MB)
# Submitting: java_solutions/1945.sum-of-digits-of-string-after-convert.java
# - Downloading sum-of-digits-of-string-after-convert
#   ✔ Accepted
#   ✔ 216/216 cases passed (10 ms)
#   ✔ Your runtime beats 6.82 % of java submissions
#   ✔ Your memory usage beats 12.27 % of java submissions (44.5 MB)
# Submitting: java_solutions/1948.delete-duplicate-folders-in-system.java
# - Downloading delete-duplicate-folders-in-system
#   ✔ Accepted
#   ✔ 109/109 cases passed (236 ms)
#   ✔ Your runtime beats 5.69 % of java submissions
#   ✔ Your memory usage beats 8.13 % of java submissions (141.3 MB)
# Submitting: java_solutions/1952.three-divisors.java
# - Downloading three-divisors
#   ✔ Accepted
#   ✔ 229/229 cases passed (5 ms)
#   ✔ Your runtime beats 0.61 % of java submissions
#   ✔ Your memory usage beats 42.16 % of java submissions (42.3 MB)
# Submitting: java_solutions/1955.count-number-of-special-subsequences.java
# - Downloading count-number-of-special-subsequences
#   ✔ Accepted
#   ✔ 99/99 cases passed (18 ms)
#   ✔ Your runtime beats 44.16 % of java submissions
#   ✔ Your memory usage beats 100 % of java submissions (110.8 MB)

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-04-14 12:11:34
