# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME_2')
    user_cookie = userdata.get('LEETCODE_TOKEN_2')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME_2'] = user_name
    os.environ['LEETCODE_TOKEN_2'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME_2" "$LEETCODE_TOKEN_2" | leetcode user -c

# %%
# %%bash
#
#
# # top 100 answers
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v java_solutions/*.java | sed -n '901,1000p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 7
# done
# Out:
# Submitting: java_solutions/2496.maximum-value-of-a-string-in-an-array.java
# - Downloading maximum-value-of-a-string-in-an-array
#   ✔ Accepted
#   ✔ 64/64 cases passed (8 ms)
#   ✔ Your runtime beats 10.34 % of java submissions
#   ✔ Your memory usage beats 25.32 % of java submissions (43.5 MB)
# Submitting: java_solutions/2499.minimum-total-cost-to-make-arrays-unequal.java
# - Downloading minimum-total-cost-to-make-arrays-unequal
#   ✔ Accepted
#   ✔ 104/104 cases passed (21 ms)
#   ✔ Your runtime beats 54.84 % of java submissions
#   ✔ Your memory usage beats 12.9 % of java submissions (112.5 MB)
# Submitting: java_solutions/2500.delete-greatest-value-in-each-row.java
# - Downloading delete-greatest-value-in-each-row
#   ✔ Accepted
#   ✔ 55/55 cases passed (65 ms)
#   ✔ Your runtime beats 5.18 % of java submissions
#   ✔ Your memory usage beats 11.99 % of java submissions (47.9 MB)
# Submitting: java_solutions/2503.maximum-number-of-points-from-grid-queries.java
# - Downloading maximum-number-of-points-from-grid-queries
#   ✔ Accepted
#   ✔ 22/22 cases passed (339 ms)
#   ✔ Your runtime beats 5.15 % of java submissions
#   ✔ Your memory usage beats 5.88 % of java submissions (99 MB)
# Submitting: java_solutions/2506.count-pairs-of-similar-strings.java
# - Downloading count-pairs-of-similar-strings
#   ✔ Accepted
#   ✔ 225/225 cases passed (38 ms)
#   ✔ Your runtime beats 46.02 % of java submissions
#   ✔ Your memory usage beats 9.96 % of java submissions (53.1 MB)
# Submitting: java_solutions/2508.add-edges-to-make-degrees-of-all-nodes-even.java
# - Downloading add-edges-to-make-degrees-of-all-nodes-even
#   ✔ Accepted
#   ✔ 52/52 cases passed (103 ms)
#   ✔ Your runtime beats 19.85 % of java submissions
#   ✔ Your memory usage beats 68.87 % of java submissions (197.4 MB)
# Submitting: java_solutions/2509.cycle-length-queries-in-a-tree.java
# - Downloading cycle-length-queries-in-a-tree
#   ✔ Accepted
#   ✔ 27/27 cases passed (75 ms)
#   ✔ Your runtime beats 10.24 % of java submissions
#   ✔ Your memory usage beats 6.02 % of java submissions (104.2 MB)
# Submitting: java_solutions/2514.count-anagrams.java
# - Downloading count-anagrams
#   ✔ Accepted
#   ✔ 41/41 cases passed (100 ms)
#   ✔ Your runtime beats 11.28 % of java submissions
#   ✔ Your memory usage beats 8.21 % of java submissions (56.3 MB)
# Submitting: java_solutions/2515.shortest-distance-to-target-string-in-a-circular-array.java
# - Downloading shortest-distance-to-target-string-in-a-circular-array
#   ✔ Accepted
#   ✔ 164/164 cases passed (7 ms)
#   ✔ Your runtime beats 1.97 % of java submissions
#   ✔ Your memory usage beats 16.45 % of java submissions (47.1 MB)
# Submitting: java_solutions/2518.number-of-great-partitions.java
# - Downloading number-of-great-partitions
#   ✔ Accepted
#   ✔ 46/46 cases passed (34 ms)
#   ✔ Your runtime beats 20.83 % of java submissions
#   ✔ Your memory usage beats 19.44 % of java submissions (52.9 MB)
# Submitting: java_solutions/2520.count-the-digits-that-divide-a-number.java
# - Downloading count-the-digits-that-divide-a-number
#   ✔ Accepted
#   ✔ 56/56 cases passed (4 ms)
#   ✔ Your runtime beats 0.44 % of java submissions
#   ✔ Your memory usage beats 43.11 % of java submissions (42.1 MB)
# Submitting: java_solutions/2521.distinct-prime-factors-of-product-of-array.java
# - Downloading distinct-prime-factors-of-product-of-array
#   ✔ Accepted
#   ✔ 81/81 cases passed (639 ms)
#   ✔ Your runtime beats 5.19 % of java submissions
#   ✔ Your memory usage beats 68.64 % of java submissions (47.5 MB)
# Submitting: java_solutions/2525.categorize-box-according-to-criteria.java
# - Downloading categorize-box-according-to-criteria
#   ✔ Accepted
#   ✔ 50/50 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 15.84 % of java submissions (42.8 MB)
# Submitting: java_solutions/2527.find-xor-beauty-of-array.java
# - Downloading find-xor-beauty-of-array
#   ✔ Accepted
#   ✔ 32/32 cases passed (4 ms)
#   ✔ Your runtime beats 3.45 % of java submissions
#   ✔ Your memory usage beats 7.47 % of java submissions (71 MB)
# Submitting: java_solutions/2528.maximize-the-minimum-powered-city.java
# - Downloading maximize-the-minimum-powered-city
#   ✔ Accepted
#   ✔ 30/30 cases passed (213 ms)
#   ✔ Your runtime beats 7.72 % of java submissions
#   ✔ Your memory usage beats 5.05 % of java submissions (94.7 MB)
# Submitting: java_solutions/2529.maximum-count-of-positive-integer-and-negative-integer.java
# - Downloading maximum-count-of-positive-integer-and-negative-integer
#   ✔ Accepted
#   ✔ 169/169 cases passed (5 ms)
#   ✔ Your runtime beats 0.83 % of java submissions
#   ✔ Your memory usage beats 23.77 % of java submissions (47.2 MB)
# Submitting: java_solutions/2532.time-to-cross-a-bridge.java
# - Downloading time-to-cross-a-bridge
#   ✔ Accepted
#   ✔ 65/65 cases passed (235 ms)
#   ✔ Your runtime beats 7.14 % of java submissions
#   ✔ Your memory usage beats 7.14 % of java submissions (65.2 MB)
# Submitting: java_solutions/2535.difference-between-element-sum-and-digit-sum-of-an-array.java
# - Downloading difference-between-element-sum-and-digit-sum-of-an-array
#   ✔ Accepted
#   ✔ 142/142 cases passed (22 ms)
#   ✔ Your runtime beats 2.07 % of java submissions
#   ✔ Your memory usage beats 6.19 % of java submissions (47.2 MB)
# Submitting: java_solutions/2536.increment-submatrices-by-one.java
# - Downloading increment-submatrices-by-one
#   ✔ Accepted
#   ✔ 32/32 cases passed (32 ms)
#   ✔ Your runtime beats 25.1 % of java submissions
#   ✔ Your memory usage beats 6.64 % of java submissions (96.2 MB)
# Submitting: java_solutions/2538.difference-between-maximum-and-minimum-price-sum.java
# - Downloading difference-between-maximum-and-minimum-price-sum
#   ✔ Accepted
#   ✔ 58/58 cases passed (187 ms)
#   ✔ Your runtime beats 5.8 % of java submissions
#   ✔ Your memory usage beats 7.25 % of java submissions (181.5 MB)
# Submitting: java_solutions/2540.minimum-common-value.java
# - Downloading minimum-common-value
#   ✔ Accepted
#   ✔ 41/41 cases passed (9 ms)
#   ✔ Your runtime beats 21.06 % of java submissions
#   ✔ Your memory usage beats 41.1 % of java submissions (80.6 MB)
# Submitting: java_solutions/2543.check-if-point-is-reachable.java
# - Downloading check-if-point-is-reachable
#   ✔ Accepted
#   ✔ 60/60 cases passed (3 ms)
#   ✔ Your runtime beats 6.9 % of java submissions
#   ✔ Your memory usage beats 34.48 % of java submissions (42.2 MB)
# Submitting: java_solutions/2544.alternating-digit-sum.java
# - Downloading alternating-digit-sum
#   ✔ Accepted
#   ✔ 118/118 cases passed (3 ms)
#   ✔ Your runtime beats 1.44 % of java submissions
#   ✔ Your memory usage beats 35.59 % of java submissions (42.3 MB)
# Submitting: java_solutions/2545.sort-the-students-by-their-kth-score.java
# - Downloading sort-the-students-by-their-kth-score
#   ✔ Accepted
#   ✔ 33/33 cases passed (4 ms)
#   ✔ Your runtime beats 19.26 % of java submissions
#   ✔ Your memory usage beats 15.94 % of java submissions (56.4 MB)
# Submitting: java_solutions/2547.minimum-cost-to-split-an-array.java
# - Downloading minimum-cost-to-split-an-array
#   ✔ Accepted
#   ✔ 59/59 cases passed (540 ms)
#   ✔ Your runtime beats 28.09 % of java submissions
#   ✔ Your memory usage beats 33.71 % of java submissions (53.4 MB)
# Submitting: java_solutions/2551.put-marbles-in-bags.java
# - Downloading put-marbles-in-bags
#   ✔ Accepted
#   ✔ 103/103 cases passed (63 ms)
#   ✔ Your runtime beats 34.46 % of java submissions
#   ✔ Your memory usage beats 68.93 % of java submissions (78.9 MB)
# Submitting: java_solutions/2552.count-increasing-quadruplets.java
# - Downloading count-increasing-quadruplets
#   ✔ Accepted
#   ✔ 121/121 cases passed (327 ms)
#   ✔ Your runtime beats 13.89 % of java submissions
#   ✔ Your memory usage beats 52.78 % of java submissions (53.4 MB)
# Submitting: java_solutions/2553.separate-the-digits-in-an-array.java
# - Downloading separate-the-digits-in-an-array
#   ✔ Accepted
#   ✔ 52/52 cases passed (11 ms)
#   ✔ Your runtime beats 7.97 % of java submissions
#   ✔ Your memory usage beats 7.55 % of java submissions (47.3 MB)
# Submitting: java_solutions/2559.count-vowel-strings-in-ranges.java
# - Downloading count-vowel-strings-in-ranges
#   ✔ Accepted
#   ✔ 94/94 cases passed (14 ms)
#   ✔ Your runtime beats 9.89 % of java submissions
#   ✔ Your memory usage beats 34.42 % of java submissions (89.1 MB)
# Submitting: java_solutions/2561.rearranging-fruits.java
# - Downloading rearranging-fruits
#   ✔ Accepted
#   ✔ 41/41 cases passed (99 ms)
#   ✔ Your runtime beats 19.37 % of java submissions
#   ✔ Your memory usage beats 12.32 % of java submissions (110.6 MB)
# Submitting: java_solutions/2562.find-the-array-concatenation-value.java
# - Downloading find-the-array-concatenation-value
#   ✔ Accepted
#   ✔ 53/53 cases passed (9 ms)
#   ✔ Your runtime beats 5.1 % of java submissions
#   ✔ Your memory usage beats 22.32 % of java submissions (46.4 MB)
# Submitting: java_solutions/2563.count-the-number-of-fair-pairs.java
# - Downloading count-the-number-of-fair-pairs
#   ✔ Accepted
#   ✔ 55/55 cases passed (95 ms)
#   ✔ Your runtime beats 5.01 % of java submissions
#   ✔ Your memory usage beats 5.49 % of java submissions (94.3 MB)
# Submitting: java_solutions/2565.subsequence-with-the-minimum-score.java
# - Downloading subsequence-with-the-minimum-score
#   ✔ Accepted
#   ✔ 54/54 cases passed (61 ms)
#   ✔ Your runtime beats 10 % of java submissions
#   ✔ Your memory usage beats 10 % of java submissions (54.9 MB)
# Submitting: java_solutions/2566.maximum-difference-by-remapping-a-digit.java
# - Downloading maximum-difference-by-remapping-a-digit
#   ✔ Accepted
#   ✔ 214/214 cases passed (6 ms)
#   ✔ Your runtime beats 6.29 % of java submissions
#   ✔ Your memory usage beats 30.93 % of java submissions (42.4 MB)
# Submitting: java_solutions/2569.handling-sum-queries-after-update.java
# - Downloading handling-sum-queries-after-update
#   ✔ Accepted
#   ✔ 77/77 cases passed (184 ms)
#   ✔ Your runtime beats 18.33 % of java submissions
#   ✔ Your memory usage beats 35 % of java submissions (149.6 MB)
# Submitting: java_solutions/2570.merge-two-2d-arrays-by-summing-values.java
# - Downloading merge-two-2d-arrays-by-summing-values
#   ✔ Accepted
#   ✔ 39/39 cases passed (9 ms)
#   ✔ Your runtime beats 9.28 % of java submissions
#   ✔ Your memory usage beats 8.55 % of java submissions (47.4 MB)
# Submitting: java_solutions/2573.find-the-string-with-lcp.java
# - Downloading find-the-string-with-lcp
#   ✔ Accepted
#   ✔ 55/55 cases passed (21 ms)
#   ✔ Your runtime beats 6.04 % of java submissions
#   ✔ Your memory usage beats 26.42 % of java submissions (178.2 MB)
# Submitting: java_solutions/2574.left-and-right-sum-differences.java
# - Downloading left-and-right-sum-differences
#   ✔ Accepted
#   ✔ 53/53 cases passed (243 ms)
#   ✔ Your runtime beats 5.35 % of java submissions
#   ✔ Your memory usage beats 7.75 % of java submissions (47.6 MB)
# Submitting: java_solutions/2575.find-the-divisibility-array-of-a-string.java
# - Downloading find-the-divisibility-array-of-a-string
#   ✔ Accepted
#   ✔ 51/51 cases passed (20 ms)
#   ✔ Your runtime beats 1.45 % of java submissions
#   ✔ Your memory usage beats 5.8 % of java submissions (82.5 MB)
# Submitting: java_solutions/2577.minimum-time-to-visit-a-cell-in-a-grid.java
# - Downloading minimum-time-to-visit-a-cell-in-a-grid
#   ✔ Accepted
#   ✔ 42/42 cases passed (533 ms)
#   ✔ Your runtime beats 5.33 % of java submissions
#   ✔ Your memory usage beats 5.33 % of java submissions (119.8 MB)
# Submitting: java_solutions/2578.split-with-minimum-sum.java
# - Downloading split-with-minimum-sum
#   ✔ Accepted
#   ✔ 140/140 cases passed (12 ms)
#   ✔ Your runtime beats 9.87 % of java submissions
#   ✔ Your memory usage beats 5.7 % of java submissions (43.2 MB)
# Submitting: java_solutions/2581.count-number-of-possible-root-nodes.java
# - Downloading count-number-of-possible-root-nodes
#   ✔ Accepted
#   ✔ 52/52 cases passed (437 ms)
#   ✔ Your runtime beats 7.14 % of java submissions
#   ✔ Your memory usage beats 7.14 % of java submissions (404.8 MB)
# Submitting: java_solutions/2583.kth-largest-sum-in-a-binary-tree.java
# - Downloading kth-largest-sum-in-a-binary-tree
#   ✔ Accepted
#   ✔ 51/51 cases passed (334 ms)
#   ✔ Your runtime beats 5.26 % of java submissions
#   ✔ Your memory usage beats 5.04 % of java submissions (160.5 MB)
# Submitting: java_solutions/2584.split-the-array-to-make-coprime-products.java
# - Downloading split-the-array-to-make-coprime-products
#   ✔ Accepted
#   ✔ 75/75 cases passed (1128 ms)
#   ✔ Your runtime beats 7.69 % of java submissions
#   ✔ Your memory usage beats 38.46 % of java submissions (57.9 MB)
# Submitting: java_solutions/2585.number-of-ways-to-earn-points.java
# - Downloading number-of-ways-to-earn-points
#   ✔ Accepted
#   ✔ 63/63 cases passed (428 ms)
#   ✔ Your runtime beats 5 % of java submissions
#   ✔ Your memory usage beats 6.67 % of java submissions (53.3 MB)
# Submitting: java_solutions/2586.count-the-number-of-vowel-strings-in-range.java
# - Downloading count-the-number-of-vowel-strings-in-range
#   ✔ Accepted
#   ✔ 1053/1053 cases passed (10 ms)
#   ✔ Your runtime beats 1.84 % of java submissions
#   ✔ Your memory usage beats 32.93 % of java submissions (46.6 MB)
# Submitting: java_solutions/2587.rearrange-array-to-maximize-prefix-score.java
# - Downloading rearrange-array-to-maximize-prefix-score
#   ✔ Accepted
#   ✔ 1071/1071 cases passed (162 ms)
#   ✔ Your runtime beats 5.36 % of java submissions
#   ✔ Your memory usage beats 13.84 % of java submissions (82.4 MB)
# Submitting: java_solutions/2589.minimum-time-to-complete-all-tasks.java
# - Downloading minimum-time-to-complete-all-tasks
#   ✔ Accepted
#   ✔ 1059/1059 cases passed (199 ms)
#   ✔ Your runtime beats 5.63 % of java submissions
#   ✔ Your memory usage beats 8.45 % of java submissions (47.8 MB)
# Submitting: java_solutions/2595.number-of-even-and-odd-bits.java
# - Downloading number-of-even-and-odd-bits
#   ✔ Accepted
#   ✔ 1003/1003 cases passed (1 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 88.19 % of java submissions (43.7 MB)
# Submitting: java_solutions/2600.k-items-with-the-maximum-sum.java
# - Downloading k-items-with-the-maximum-sum
#   ✔ Accepted
#   ✔ 1310/1310 cases passed (1 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 26.74 % of java submissions (43 MB)
# Submitting: java_solutions/2603.collect-coins-in-a-tree.java
# - Downloading collect-coins-in-a-tree
#   ✔ Accepted
#   ✔ 4986/4986 cases passed (70 ms)
#   ✔ Your runtime beats 41.09 % of java submissions
#   ✔ Your memory usage beats 100 % of java submissions (86.5 MB)
# Submitting: java_solutions/2605.form-smallest-number-from-two-digit-arrays.java
# - Downloading form-smallest-number-from-two-digit-arrays
#   ✔ Accepted
#   ✔ 388/388 cases passed (11 ms)
#   ✔ Your runtime beats 7.36 % of java submissions
#   ✔ Your memory usage beats 5.94 % of java submissions (44.2 MB)
# Submitting: java_solutions/2608.shortest-cycle-in-a-graph.java
# - Downloading shortest-cycle-in-a-graph
#   ✔ Accepted
#   ✔ 89/89 cases passed (1950 ms)
#   ✔ Your runtime beats 5 % of java submissions
#   ✔ Your memory usage beats 5 % of java submissions (54.2 MB)
# Submitting: java_solutions/2609.find-the-longest-balanced-substring-of-a-binary-string.java
# - Downloading find-the-longest-balanced-substring-of-a-binary-string
#   ✔ Accepted
#   ✔ 1848/1848 cases passed (22 ms)
#   ✔ Your runtime beats 5.42 % of java submissions
#   ✔ Your memory usage beats 5.42 % of java submissions (47 MB)
# Submitting: java_solutions/2612.minimum-reverse-operations.java
# - Downloading minimum-reverse-operations
#   ✔ Accepted
#   ✔ 711/711 cases passed (241 ms)
#   ✔ Your runtime beats 46.3 % of java submissions
#   ✔ Your memory usage beats 96.3 % of java submissions (140.6 MB)
# Submitting: java_solutions/2615.sum-of-distances.java
# - Downloading sum-of-distances
#   ✔ Accepted
#   ✔ 1068/1068 cases passed (134 ms)
#   ✔ Your runtime beats 5 % of java submissions
#   ✔ Your memory usage beats 91.36 % of java submissions (115.3 MB)
# Submitting: java_solutions/2617.minimum-number-of-visited-cells-in-a-grid.java
# - Downloading minimum-number-of-visited-cells-in-a-grid
#   ✔ Accepted
#   ✔ 1072/1072 cases passed (618 ms)
#   ✔ Your runtime beats 58.33 % of java submissions
#   ✔ Your memory usage beats 97.92 % of java submissions (153.8 MB)
# Submitting: java_solutions/2640.find-the-score-of-all-prefixes-of-an-array.java
# - Downloading find-the-score-of-all-prefixes-of-an-array
#   ✔ Accepted
#   ✔ 43/43 cases passed (11 ms)
#   ✔ Your runtime beats 0.96 % of java submissions
#   ✔ Your memory usage beats 91.92 % of java submissions (94.8 MB)
# Submitting: java_solutions/2642.design-graph-with-shortest-path-calculator.java
# - Downloading design-graph-with-shortest-path-calculator
#   ✔ Accepted
#   ✔ 36/36 cases passed (261 ms)
#   ✔ Your runtime beats 9.77 % of java submissions
#   ✔ Your memory usage beats 5.12 % of java submissions (70.7 MB)
# Submitting: java_solutions/2643.row-with-maximum-ones.java
# - Downloading row-with-maximum-ones
#   ✔ Accepted
#   ✔ 1049/1049 cases passed (21 ms)
#   ✔ Your runtime beats 5.9 % of java submissions
#   ✔ Your memory usage beats 5.21 % of java submissions (49.2 MB)
# Submitting: java_solutions/2644.find-the-maximum-divisibility-score.java
# - Downloading find-the-maximum-divisibility-score
#   ✔ Accepted
#   ✔ 160/160 cases passed (1389 ms)
#   ✔ Your runtime beats 5.24 % of java submissions
#   ✔ Your memory usage beats 9.05 % of java submissions (48.4 MB)
# Submitting: java_solutions/2646.minimize-the-total-price-of-the-trips.java
# - Downloading minimize-the-total-price-of-the-trips
#   ✔ Accepted
#   ✔ 407/407 cases passed (148 ms)
#   ✔ Your runtime beats 6.67 % of java submissions
#   ✔ Your memory usage beats 6.67 % of java submissions (53.8 MB)
# Submitting: java_solutions/2651.calculate-delayed-arrival-time.java
# - Downloading calculate-delayed-arrival-time
#   ✔ Accepted
#   ✔ 556/556 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 51.87 % of java submissions (42.4 MB)
# Submitting: java_solutions/2652.sum-multiples.java
# - Downloading sum-multiples
#   ✔ Accepted
#   ✔ 1000/1000 cases passed (8 ms)
#   ✔ Your runtime beats 1.32 % of java submissions
#   ✔ Your memory usage beats 12.72 % of java submissions (43.1 MB)
# Submitting: java_solutions/2656.maximum-sum-with-exactly-k-elements.java
# - Downloading maximum-sum-with-exactly-k-elements
#   ✔ Accepted
#   ✔ 3004/3004 cases passed (6 ms)
#   ✔ Your runtime beats 43.63 % of java submissions
#   ✔ Your memory usage beats 55.13 % of java submissions (47.1 MB)
# Submitting: java_solutions/2657.find-the-prefix-common-array-of-two-arrays.java
# - Downloading find-the-prefix-common-array-of-two-arrays
#   ✔ Accepted
#   ✔ 1773/1773 cases passed (15 ms)
#   ✔ Your runtime beats 17.05 % of java submissions
#   ✔ Your memory usage beats 9.48 % of java submissions (47.9 MB)
# Submitting: java_solutions/2659.make-array-empty.java
# - Downloading make-array-empty
#   ✔ Accepted
#   ✔ 514/514 cases passed (67 ms)
#   ✔ Your runtime beats 23.96 % of java submissions
#   ✔ Your memory usage beats 98.96 % of java submissions (74 MB)
# Submitting: java_solutions/2663.lexicographically-smallest-beautiful-string.java
# - Downloading lexicographically-smallest-beautiful-string
#   ✔ Accepted
#   ✔ 1054/1054 cases passed (126 ms)
#   ✔ Your runtime beats 8.16 % of java submissions
#   ✔ Your memory usage beats 12.24 % of java submissions (55.8 MB)
# Submitting: java_solutions/2681.power-of-heroes.java
# - Downloading power-of-heroes
#   ✔ Accepted
#   ✔ 2584/2584 cases passed (32 ms)
#   ✔ Your runtime beats 7.32 % of java submissions
#   ✔ Your memory usage beats 95.12 % of java submissions (63.9 MB)
# Submitting: java_solutions/2699.modify-graph-edge-weights.java
# - Downloading modify-graph-edge-weights
#   ✔ Accepted
#   ✔ 882/882 cases passed (1199 ms)
#   ✔ Your runtime beats 5.71 % of java submissions
#   ✔ Your memory usage beats 5.71 % of java submissions (59.3 MB)
# Submitting: java_solutions/2709.greatest-common-divisor-traversal.java
# - Downloading greatest-common-divisor-traversal
#   ✔ Accepted
#   ✔ 929/929 cases passed (2000 ms)
#   ✔ Your runtime beats 5.05 % of java submissions
#   ✔ Your memory usage beats 43.43 % of java submissions (93.9 MB)
# Submitting: java_solutions/2713.maximum-strictly-increasing-cells-in-a-matrix.java
# - Downloading maximum-strictly-increasing-cells-in-a-matrix
#   ✔ Accepted
#   ✔ 566/566 cases passed (160 ms)
#   ✔ Your runtime beats 78.72 % of java submissions
#   ✔ Your memory usage beats 87.23 % of java submissions (121.5 MB)
# Submitting: java_solutions/2719.count-of-integers.java
# - Downloading count-of-integers
#   ✔ Accepted
#   ✔ 616/616 cases passed (371 ms)
#   ✔ Your runtime beats 6.67 % of java submissions
#   ✔ Your memory usage beats 5 % of java submissions (53.4 MB)
# Submitting: java_solutions/2732.find-a-good-subset-of-the-matrix.java
# - Downloading find-a-good-subset-of-the-matrix
#   ✔ Accepted
#   ✔ 685/685 cases passed (83 ms)
#   ✔ Your runtime beats 22.73 % of java submissions
#   ✔ Your memory usage beats 59.09 % of java submissions (82.9 MB)
# Submitting: java_solutions/2736.maximum-sum-queries.java
# - Downloading maximum-sum-queries
#   ✔ Accepted
#   ✔ 1415/1415 cases passed (332 ms)
#   ✔ Your runtime beats 6.52 % of java submissions
#   ✔ Your memory usage beats 86.96 % of java submissions (180.8 MB)
# Submitting: java_solutions/2742.painting-the-walls.java
# - Downloading painting-the-walls
#   ✔ Accepted
#   ✔ 2558/2558 cases passed (92 ms)
#   ✔ Your runtime beats 9.03 % of java submissions
#   ✔ Your memory usage beats 24.92 % of java submissions (53.1 MB)
# Submitting: java_solutions/2751.robot-collisions.java
# - Downloading robot-collisions
#   ✔ Accepted
#   ✔ 2433/2433 cases passed (175 ms)
#   ✔ Your runtime beats 5.05 % of java submissions
#   ✔ Your memory usage beats 99.95 % of java submissions (100.2 MB)
# Submitting: java_solutions/2763.sum-of-imbalance-numbers-of-all-subarrays.java
# - Downloading sum-of-imbalance-numbers-of-all-subarrays
#   ✔ Accepted
#   ✔ 1303/1303 cases passed (48 ms)
#   ✔ Your runtime beats 64 % of java submissions
#   ✔ Your memory usage beats 8 % of java submissions (47.6 MB)
# Submitting: java_solutions/2781.length-of-the-longest-valid-substring.java
# - Downloading length-of-the-longest-valid-substring
#   ✔ Accepted
#   ✔ 763/763 cases passed (596 ms)
#   ✔ Your runtime beats 5.63 % of java submissions
#   ✔ Your memory usage beats 22.53 % of java submissions (92.5 MB)
# Submitting: java_solutions/2790.maximum-number-of-groups-with-increasing-length.java
# - Downloading maximum-number-of-groups-with-increasing-length
#   ✔ Accepted
#   ✔ 2027/2027 cases passed (66 ms)
#   ✔ Your runtime beats 92.59 % of java submissions
#   ✔ Your memory usage beats 92.59 % of java submissions (100 MB)
# Submitting: java_solutions/2791.count-paths-that-can-form-a-palindrome-in-a-tree.java
# - Downloading count-paths-that-can-form-a-palindrome-in-a-tree
#   ✔ Accepted
#   ✔ 666/666 cases passed (1734 ms)
#   ✔ Your runtime beats 5.08 % of java submissions
#   ✔ Your memory usage beats 90.85 % of java submissions (88 MB)
# Submitting: java_solutions/2801.count-stepping-numbers-in-range.java
# - Downloading count-stepping-numbers-in-range
#   ✔ Accepted
#   ✔ 2523/2523 cases passed (332 ms)
#   ✔ Your runtime beats 5.88 % of java submissions
#   ✔ Your memory usage beats 7.84 % of java submissions (53.2 MB)
# Submitting: java_solutions/2809.minimum-time-to-make-array-sum-at-most-x.java
# - Downloading minimum-time-to-make-array-sum-at-most-x
#   ✔ Accepted
#   ✔ 1274/1274 cases passed (119 ms)
#   ✔ Your runtime beats 6.67 % of java submissions
#   ✔ Your memory usage beats 6.67 % of java submissions (53.5 MB)
# Submitting: java_solutions/2813.maximum-elegance-of-a-k-length-subsequence.java
# - Downloading maximum-elegance-of-a-k-length-subsequence
#   ✔ Accepted
#   ✔ 2729/2729 cases passed (66 ms)
#   ✔ Your runtime beats 6.45 % of java submissions
#   ✔ Your memory usage beats 98.39 % of java submissions (87 MB)
# Submitting: java_solutions/2816.double-a-number-represented-as-a-linked-list.java
# - Downloading double-a-number-represented-as-a-linked-list
#   ✔ Accepted
#   ✔ 1265/1265 cases passed (16 ms)
#   ✔ Your runtime beats 14.05 % of java submissions
#   ✔ Your memory usage beats 91.4 % of java submissions (48 MB)
# Submitting: java_solutions/2818.apply-operations-to-maximize-score.java
# - Downloading apply-operations-to-maximize-score
#   ✔ Accepted
#   ✔ 870/870 cases passed (1372 ms)
#   ✔ Your runtime beats 5.26 % of java submissions
#   ✔ Your memory usage beats 78.95 % of java submissions (111.3 MB)
# Submitting: java_solutions/2827.number-of-beautiful-integers-in-the-range.java
# - Downloading number-of-beautiful-integers-in-the-range
#   ✔ Accepted
#   ✔ 595/595 cases passed (136 ms)
#   ✔ Your runtime beats 26.14 % of java submissions
#   ✔ Your memory usage beats 10.23 % of java submissions (53.8 MB)
# Submitting: java_solutions/2835.minimum-operations-to-form-subsequence-with-target-sum.java
# - Downloading minimum-operations-to-form-subsequence-with-target-sum
#   ✔ Accepted
#   ✔ 754/754 cases passed (25 ms)
#   ✔ Your runtime beats 13.64 % of java submissions
#   ✔ Your memory usage beats 9.09 % of java submissions (47.1 MB)
# Submitting: java_solutions/2836.maximize-value-of-function-in-a-ball-passing-game.java
# - Downloading maximize-value-of-function-in-a-ball-passing-game
#   ✔ Accepted
#   ✔ 948/948 cases passed (338 ms)
#   ✔ Your runtime beats 52.17 % of java submissions
#   ✔ Your memory usage beats 69.57 % of java submissions (240.9 MB)
# Submitting: java_solutions/2842.count-k-subsequences-of-a-string-with-maximum-beauty.java
# - Downloading count-k-subsequences-of-a-string-with-maximum-beauty
#   ✔ Accepted
#   ✔ 611/611 cases passed (29 ms)
#   ✔ Your runtime beats 20.83 % of java submissions
#   ✔ Your memory usage beats 6.25 % of java submissions (53.6 MB)
# Submitting: java_solutions/2846.minimum-edge-weight-equilibrium-queries-in-a-tree.java
# - Downloading minimum-edge-weight-equilibrium-queries-in-a-tree
#   ✔ Accepted
#   ✔ 733/733 cases passed (674 ms)
#   ✔ Your runtime beats 8.97 % of java submissions
#   ✔ Your memory usage beats 17.95 % of java submissions (103.5 MB)
# Submitting: java_solutions/2851.string-transformation.java
# - Downloading string-transformation
#   ✔ Accepted
#   ✔ 726/726 cases passed (1233 ms)
#   ✔ Your runtime beats 5.17 % of java submissions
#   ✔ Your memory usage beats 5.17 % of java submissions (105.1 MB)
# Submitting: java_solutions/2858.minimum-edge-reversals-so-every-node-is-reachable.java
# - Downloading minimum-edge-reversals-so-every-node-is-reachable
#   ✔ Accepted
#   ✔ 421/421 cases passed (551 ms)
#   ✔ Your runtime beats 5.05 % of java submissions
#   ✔ Your memory usage beats 5.05 % of java submissions (421.8 MB)
# Submitting: java_solutions/2862.maximum-element-sum-of-a-complete-subset-of-indices.java
# - Downloading maximum-element-sum-of-a-complete-subset-of-indices
#   ✔ Accepted
#   ✔ 663/663 cases passed (2485 ms)
#   ✔ Your runtime beats 6.9 % of java submissions
#   ✔ Your memory usage beats 6.9 % of java submissions (59.3 MB)
# Submitting: java_solutions/2867.count-valid-paths-in-a-tree.java
# - Downloading count-valid-paths-in-a-tree
#   ✔ Accepted
#   ✔ 922/922 cases passed (219 ms)
#   ✔ Your runtime beats 7.14 % of java submissions
#   ✔ Your memory usage beats 46.43 % of java submissions (143.7 MB)
# Submitting: java_solutions/2872.maximum-number-of-k-divisible-components.java
# - Downloading maximum-number-of-k-divisible-components
#   ✔ Accepted
#   ✔ 737/737 cases passed (137 ms)
#   ✔ Your runtime beats 5.03 % of java submissions
#   ✔ Your memory usage beats 5.03 % of java submissions (144.8 MB)
# Submitting: java_solutions/2876.count-visited-nodes-in-a-directed-graph.java
# - Downloading count-visited-nodes-in-a-directed-graph
#   ✔ Accepted
#   ✔ 941/941 cases passed (237 ms)
#   ✔ Your runtime beats 5.81 % of java submissions
#   ✔ Your memory usage beats 5.81 % of java submissions (228.1 MB)
# Submitting: java_solutions/2897.apply-operations-on-array-to-maximize-sum-of-squares.java
# - Downloading apply-operations-on-array-to-maximize-sum-of-squares
#   ✔ Accepted
#   ✔ 918/918 cases passed (467 ms)
#   ✔ Your runtime beats 5.41 % of java submissions
#   ✔ Your memory usage beats 5.41 % of java submissions (105.8 MB)
# Submitting: java_solutions/2902.count-of-sub-multisets-with-bounded-sum.java
# - Downloading count-of-sub-multisets-with-bounded-sum
#   ✔ Accepted
#   ✔ 643/643 cases passed (449 ms)
#   ✔ Your runtime beats 24.32 % of java submissions
#   ✔ Your memory usage beats 18.92 % of java submissions (54.3 MB)
# Submitting: java_solutions/2911.minimum-changes-to-make-k-semi-palindromes.java
# - Downloading minimum-changes-to-make-k-semi-palindromes
#   ✔ Accepted
#   ✔ 558/558 cases passed (2325 ms)
#   ✔ Your runtime beats 7.69 % of java submissions
#   ✔ Your memory usage beats 7.69 % of java submissions (55 MB)

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-04-14 13:20:10
