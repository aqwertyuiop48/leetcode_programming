# %%
# %%capture
import os
import getpass

# 2. Interactive input (Safe and hidden)
print("Please enter your LeetCode credentials:")
user_name = getpass.getpass('LeetCode Username: ')
user_cookie = getpass.getpass('LeetCode Session Token: ')

# 1. Install and Clone
# !npm install -g leetcode-tools/leetcode-cli
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME'] = user_name
    os.environ['LEETCODE_TOKEN'] = user_cookie

    # 4. Run the login silently
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME" "$LEETCODE_TOKEN" | leetcode user -c

# %%
# %%bash
#
# # top 100-200 answers (2nd batch)
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v kotlin_solutions/*.kt | sed -n '101,200p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 7
# done
# Out:
# Submitting: kotlin_solutions/101.symmetric-tree.kt
# - Downloading problems
# - Downloading symmetric-tree
#   ✔ Accepted
#   ✔ 200/200 cases passed (13 ms)
#   ✔ Your runtime beats 10.32 % of kotlin submissions
#   ✔ Your memory usage beats 12.26 % of kotlin submissions (43.1 MB)
# Submitting: kotlin_solutions/102.binary-tree-level-order-traversal.kt
# - Downloading binary-tree-level-order-traversal
#   ✔ Accepted
#   ✔ 35/35 cases passed (26 ms)
#   ✔ Your runtime beats 5.12 % of kotlin submissions
#   ✔ Your memory usage beats 6.01 % of kotlin submissions (50.4 MB)
# Submitting: kotlin_solutions/103.binary-tree-zigzag-level-order-traversal.kt
# - Downloading binary-tree-zigzag-level-order-traversal
#   ✔ Accepted
#   ✔ 33/33 cases passed (26 ms)
#   ✔ Your runtime beats 7.14 % of kotlin submissions
#   ✔ Your memory usage beats 9.09 % of kotlin submissions (46.7 MB)
# Submitting: kotlin_solutions/104.maximum-depth-of-binary-tree.kt
# - Downloading maximum-depth-of-binary-tree
#   ✔ Accepted
#   ✔ 39/39 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 91.28 % of kotlin submissions (42.5 MB)
# Submitting: kotlin_solutions/105.construct-binary-tree-from-preorder-and-inorder-traversal.kt
# - Downloading construct-binary-tree-from-preorder-and-inorder-traversal
#   ✔ Accepted
#   ✔ 203/203 cases passed (19 ms)
#   ✔ Your runtime beats 34.7 % of kotlin submissions
#   ✔ Your memory usage beats 14.61 % of kotlin submissions (78.1 MB)
# Submitting: kotlin_solutions/106.construct-binary-tree-from-inorder-and-postorder-traversal.kt
# - Downloading construct-binary-tree-from-inorder-and-postorder-traversal
#   ✔ Accepted
#   ✔ 202/202 cases passed (19 ms)
#   ✔ Your runtime beats 35.23 % of kotlin submissions
#   ✔ Your memory usage beats 14.77 % of kotlin submissions (77.8 MB)
# Submitting: kotlin_solutions/107.binary-tree-level-order-traversal-ii.kt
# - Downloading binary-tree-level-order-traversal-ii
#   ✔ Accepted
#   ✔ 34/34 cases passed (26 ms)
#   ✔ Your runtime beats 8.33 % of kotlin submissions
#   ✔ Your memory usage beats 6.67 % of kotlin submissions (47.9 MB)
# Submitting: kotlin_solutions/108.convert-sorted-array-to-binary-search-tree.kt
# - Downloading convert-sorted-array-to-binary-search-tree
#   ✔ Accepted
#   ✔ 31/31 cases passed (8 ms)
#   ✔ Your runtime beats 43.15 % of kotlin submissions
#   ✔ Your memory usage beats 35.03 % of kotlin submissions (45.7 MB)
# Submitting: kotlin_solutions/109.convert-sorted-list-to-binary-search-tree.kt
# - Downloading convert-sorted-list-to-binary-search-tree
#   ✔ Accepted
#   ✔ 32/32 cases passed (25 ms)
#   ✔ Your runtime beats 11.43 % of kotlin submissions
#   ✔ Your memory usage beats 5.72 % of kotlin submissions (51.7 MB)
# Submitting: kotlin_solutions/110.balanced-binary-tree.kt
# - Downloading balanced-binary-tree
#   ✔ Accepted
#   ✔ 228/228 cases passed (18 ms)
#   ✔ Your runtime beats 5.91 % of kotlin submissions
#   ✔ Your memory usage beats 57.69 % of kotlin submissions (45.2 MB)
# Submitting: kotlin_solutions/111.minimum-depth-of-binary-tree.kt
# - Downloading minimum-depth-of-binary-tree
#   ✔ Accepted
#   ✔ 53/53 cases passed (8 ms)
#   ✔ Your runtime beats 38.86 % of kotlin submissions
#   ✔ Your memory usage beats 42.65 % of kotlin submissions (67.6 MB)
# Submitting: kotlin_solutions/112.path-sum.kt
# - Downloading path-sum
#   ✔ Accepted
#   ✔ 118/118 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 62.24 % of kotlin submissions (43.2 MB)
# Submitting: kotlin_solutions/113.path-sum-ii.kt
# - Downloading path-sum-ii
#   ✔ Accepted
#   ✔ 115/115 cases passed (24 ms)
#   ✔ Your runtime beats 5.71 % of kotlin submissions
#   ✔ Your memory usage beats 24.29 % of kotlin submissions (48.3 MB)
# Submitting: kotlin_solutions/114.flatten-binary-tree-to-linked-list.kt
# - Downloading flatten-binary-tree-to-linked-list
#   ✔ Accepted
#   ✔ 225/225 cases passed (12 ms)
#   ✔ Your runtime beats 17.71 % of kotlin submissions
#   ✔ Your memory usage beats 19.79 % of kotlin submissions (43.3 MB)
# Submitting: kotlin_solutions/115.distinct-subsequences.kt
# - Downloading distinct-subsequences
#   ✔ Accepted
#   ✔ 66/66 cases passed (29 ms)
#   ✔ Your runtime beats 41.67 % of kotlin submissions
#   ✔ Your memory usage beats 80.56 % of kotlin submissions (42.1 MB)
# Submitting: kotlin_solutions/116.populating-next-right-pointers-in-each-node.kt
# - Downloading populating-next-right-pointers-in-each-node
#   ✔ Accepted
#   ✔ 59/59 cases passed (161 ms)
#   ✔ Your runtime beats 48.21 % of kotlin submissions
#   ✔ Your memory usage beats 99.11 % of kotlin submissions (43.8 MB)
# Submitting: kotlin_solutions/117.populating-next-right-pointers-in-each-node-ii.kt
# - Downloading populating-next-right-pointers-in-each-node-ii
#   ✔ Accepted
#   ✔ 55/55 cases passed (161 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
#   ✔ Your memory usage beats 81.25 % of kotlin submissions (44.9 MB)
# Submitting: kotlin_solutions/118.pascals-triangle.kt
# - Downloading pascals-triangle
#   ✔ Accepted
#   ✔ 30/30 cases passed (12 ms)
#   ✔ Your runtime beats 23.26 % of kotlin submissions
#   ✔ Your memory usage beats 28.29 % of kotlin submissions (43.5 MB)
# Submitting: kotlin_solutions/119.pascals-triangle-ii.kt
# - Downloading pascals-triangle-ii
#   ✔ Accepted
#   ✔ 34/34 cases passed (9 ms)
#   ✔ Your runtime beats 24.37 % of kotlin submissions
#   ✔ Your memory usage beats 51.26 % of kotlin submissions (41.4 MB)
# Submitting: kotlin_solutions/120.triangle.kt
# - Downloading triangle
#   ✔ Accepted
#   ✔ 46/46 cases passed (19 ms)
#   ✔ Your runtime beats 9.76 % of kotlin submissions
#   ✔ Your memory usage beats 17.07 % of kotlin submissions (52.6 MB)
# Submitting: kotlin_solutions/121.best-time-to-buy-and-sell-stock.kt
# - Downloading best-time-to-buy-and-sell-stock
#   ✔ Accepted
#   ✔ 212/212 cases passed (20 ms)
#   ✔ Your runtime beats 6.74 % of kotlin submissions
#   ✔ Your memory usage beats 13.88 % of kotlin submissions (67.9 MB)
# Submitting: kotlin_solutions/122.best-time-to-buy-and-sell-stock-ii.kt
# - Downloading best-time-to-buy-and-sell-stock-ii
#   ✔ Accepted
#   ✔ 203/203 cases passed (27 ms)
#   ✔ Your runtime beats 5.07 % of kotlin submissions
#   ✔ Your memory usage beats 16.27 % of kotlin submissions (49 MB)
# Submitting: kotlin_solutions/123.best-time-to-buy-and-sell-stock-iii.kt
# - Downloading best-time-to-buy-and-sell-stock-iii
#   ✔ Accepted
#   ✔ 214/214 cases passed (9 ms)
#   ✔ Your runtime beats 48.72 % of kotlin submissions
#   ✔ Your memory usage beats 44.87 % of kotlin submissions (65.8 MB)
# Submitting: kotlin_solutions/124.binary-tree-maximum-path-sum.kt
# - Downloading binary-tree-maximum-path-sum
#   ✔ Accepted
#   ✔ 96/96 cases passed (4 ms)
#   ✔ Your runtime beats 16.15 % of kotlin submissions
#   ✔ Your memory usage beats 7.81 % of kotlin submissions (51.4 MB)
# Submitting: kotlin_solutions/125.valid-palindrome.kt
# - Downloading valid-palindrome
#   ✔ Accepted
#   ✔ 488/488 cases passed (14 ms)
#   ✔ Your runtime beats 25.98 % of kotlin submissions
#   ✔ Your memory usage beats 48.03 % of kotlin submissions (45.9 MB)
# Submitting: kotlin_solutions/126.word-ladder-ii.kt
# - Downloading word-ladder-ii
#   ✔ Accepted
#   ✔ 38/38 cases passed (156 ms)
#   ✔ Your runtime beats 21.88 % of kotlin submissions
#   ✔ Your memory usage beats 6.25 % of kotlin submissions (56.4 MB)
# Submitting: kotlin_solutions/127.word-ladder.kt
# - Downloading word-ladder
#   ✔ Accepted
#   ✔ 52/52 cases passed (138 ms)
#   ✔ Your runtime beats 35.32 % of kotlin submissions
#   ✔ Your memory usage beats 39.13 % of kotlin submissions (55.6 MB)
# Submitting: kotlin_solutions/128.longest-consecutive-sequence.kt
# - Downloading longest-consecutive-sequence
#   ✔ Accepted
#   ✔ 84/84 cases passed (102 ms)
#   ✔ Your runtime beats 33.28 % of kotlin submissions
#   ✔ Your memory usage beats 11.75 % of kotlin submissions (70.9 MB)
# Submitting: kotlin_solutions/129.sum-root-to-leaf-numbers.kt
# - Downloading sum-root-to-leaf-numbers
#   ✔ Accepted
#   ✔ 108/108 cases passed (12 ms)
#   ✔ Your runtime beats 9.56 % of kotlin submissions
#   ✔ Your memory usage beats 22.79 % of kotlin submissions (41.8 MB)
# Submitting: kotlin_solutions/130.surrounded-regions.kt
# - Downloading surrounded-regions
#   ✔ Accepted
#   ✔ 59/59 cases passed (43 ms)
#   ✔ Your runtime beats 9.47 % of kotlin submissions
#   ✔ Your memory usage beats 40.53 % of kotlin submissions (50.1 MB)
# Submitting: kotlin_solutions/131.palindrome-partitioning.kt
# - Downloading palindrome-partitioning
#   ✔ Accepted
#   ✔ 32/32 cases passed (70 ms)
#   ✔ Your runtime beats 10.28 % of kotlin submissions
#   ✔ Your memory usage beats 7.48 % of kotlin submissions (76 MB)
# Submitting: kotlin_solutions/132.palindrome-partitioning-ii.kt
# - Downloading palindrome-partitioning-ii
#   ✔ Accepted
#   ✔ 37/37 cases passed (3452 ms)
#   ✔ Your runtime beats 10.53 % of kotlin submissions
#   ✔ Your memory usage beats 21.05 % of kotlin submissions (114.6 MB)
# Submitting: kotlin_solutions/133.clone-graph.kt
# - Downloading clone-graph
#   ✔ Accepted
#   ✔ 22/22 cases passed (155 ms)
#   ✔ Your runtime beats 26.67 % of kotlin submissions
#   ✔ Your memory usage beats 39.74 % of kotlin submissions (43.7 MB)
# Submitting: kotlin_solutions/134.gas-station.kt
# - Downloading gas-station
#   ✔ Accepted
#   ✔ 40/40 cases passed (42 ms)
#   ✔ Your runtime beats 7.95 % of kotlin submissions
#   ✔ Your memory usage beats 20.53 % of kotlin submissions (66.7 MB)
# Submitting: kotlin_solutions/135.candy.kt
# - Downloading candy
#   ✔ Accepted
#   ✔ 50/50 cases passed (21 ms)
#   ✔ Your runtime beats 24.75 % of kotlin submissions
#   ✔ Your memory usage beats 49.5 % of kotlin submissions (49.9 MB)
# Submitting: kotlin_solutions/136.single-number.kt
# - Downloading single-number
#   ✔ Accepted
#   ✔ 61/61 cases passed (1 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 46.44 % of kotlin submissions (49.6 MB)
# Submitting: kotlin_solutions/137.single-number-ii.kt
# - Downloading single-number-ii
#   ✔ Accepted
#   ✔ 15/15 cases passed (5 ms)
#   ✔ Your runtime beats 52.5 % of kotlin submissions
#   ✔ Your memory usage beats 42.5 % of kotlin submissions (46.4 MB)
# Submitting: kotlin_solutions/138.copy-list-with-random-pointer.kt
# - Downloading copy-list-with-random-pointer
#   ✔ Accepted
#   ✔ 19/19 cases passed (158 ms)
#   ✔ Your runtime beats 8.56 % of kotlin submissions
#   ✔ Your memory usage beats 39.19 % of kotlin submissions (45.4 MB)
# Submitting: kotlin_solutions/139.word-break.kt
# - Downloading word-break
#   ✔ Accepted
#   ✔ 48/48 cases passed (26 ms)
#   ✔ Your runtime beats 13.4 % of kotlin submissions
#   ✔ Your memory usage beats 30.53 % of kotlin submissions (45.5 MB)
# Submitting: kotlin_solutions/140.word-break-ii.kt
# - Downloading word-break-ii
#   ✔ Accepted
#   ✔ 29/29 cases passed (25 ms)
#   ✔ Your runtime beats 18.87 % of kotlin submissions
#   ✔ Your memory usage beats 13.21 % of kotlin submissions (46.6 MB)
# Submitting: kotlin_solutions/141.linked-list-cycle.kt
# - Downloading linked-list-cycle
#   ✔ Accepted
#   ✔ 29/29 cases passed (174 ms)
#   ✔ Your runtime beats 5.23 % of kotlin submissions
#   ✔ Your memory usage beats 6.85 % of kotlin submissions (47.7 MB)
# Submitting: kotlin_solutions/142.linked-list-cycle-ii.kt
# - Downloading linked-list-cycle-ii
#   ✔ Accepted
#   ✔ 18/18 cases passed (120 ms)
#   ✔ Your runtime beats 30.26 % of kotlin submissions
#   ✔ Your memory usage beats 17.1 % of kotlin submissions (45.7 MB)
# Submitting: kotlin_solutions/143.reorder-list.kt
# - Downloading reorder-list
#   ✔ Accepted
#   ✔ 12/12 cases passed (43 ms)
#   ✔ Your runtime beats 5.37 % of kotlin submissions
#   ✔ Your memory usage beats 5.37 % of kotlin submissions (53.4 MB)
# Submitting: kotlin_solutions/144.binary-tree-preorder-traversal.kt
# - Downloading binary-tree-preorder-traversal
#   ✔ Accepted
#   ✔ 71/71 cases passed (8 ms)
#   ✔ Your runtime beats 19.81 % of kotlin submissions
#   ✔ Your memory usage beats 5.19 % of kotlin submissions (42.6 MB)
# Submitting: kotlin_solutions/145.binary-tree-postorder-traversal.kt
# - Downloading binary-tree-postorder-traversal
#   ✔ Accepted
#   ✔ 71/71 cases passed (7 ms)
#   ✔ Your runtime beats 35.26 % of kotlin submissions
#   ✔ Your memory usage beats 32.95 % of kotlin submissions (42.1 MB)
# Submitting: kotlin_solutions/146.lru-cache.kt
# - Downloading lru-cache
#   ✔ Accepted
#   ✔ 24/24 cases passed (170 ms)
#   ✔ Your runtime beats 12.93 % of kotlin submissions
#   ✔ Your memory usage beats 9.5 % of kotlin submissions (158.5 MB)
# Submitting: kotlin_solutions/147.insertion-sort-list.kt
# - Downloading insertion-sort-list
#   ✔ Accepted
#   ✔ 19/19 cases passed (42 ms)
#   ✔ Your runtime beats 5.45 % of kotlin submissions
#   ✔ Your memory usage beats 40 % of kotlin submissions (47.8 MB)
# Submitting: kotlin_solutions/148.sort-list.kt
# - Downloading sort-list
#   ✔ Accepted
#   ✔ 30/30 cases passed (92 ms)
#   ✔ Your runtime beats 15.56 % of kotlin submissions
#   ✔ Your memory usage beats 11.11 % of kotlin submissions (67.8 MB)
# Submitting: kotlin_solutions/149.max-points-on-a-line.kt
# - Downloading max-points-on-a-line
#   ✔ Accepted
#   ✔ 42/42 cases passed (65 ms)
#   ✔ Your runtime beats 13.64 % of kotlin submissions
#   ✔ Your memory usage beats 11.36 % of kotlin submissions (50 MB)
# Submitting: kotlin_solutions/150.evaluate-reverse-polish-notation.kt
# - Downloading evaluate-reverse-polish-notation
#   ✔ Accepted
#   ✔ 22/22 cases passed (12 ms)
#   ✔ Your runtime beats 75.99 % of kotlin submissions
#   ✔ Your memory usage beats 67.55 % of kotlin submissions (46.5 MB)
# Submitting: kotlin_solutions/151.reverse-words-in-a-string.kt
# - Downloading reverse-words-in-a-string
#   ✔ Accepted
#   ✔ 62/62 cases passed (20 ms)
#   ✔ Your runtime beats 63.4 % of kotlin submissions
#   ✔ Your memory usage beats 63.03 % of kotlin submissions (45.7 MB)
# Submitting: kotlin_solutions/152.maximum-product-subarray.kt
# - Downloading maximum-product-subarray
#   ✔ Accepted
#   ✔ 191/191 cases passed (37 ms)
#   ✔ Your runtime beats 9.57 % of kotlin submissions
#   ✔ Your memory usage beats 5.65 % of kotlin submissions (50.6 MB)
# Submitting: kotlin_solutions/153.find-minimum-in-rotated-sorted-array.kt
# - Downloading find-minimum-in-rotated-sorted-array
#   ✔ Accepted
#   ✔ 150/150 cases passed (19 ms)
#   ✔ Your runtime beats 11.39 % of kotlin submissions
#   ✔ Your memory usage beats 7.59 % of kotlin submissions (46.2 MB)
# Submitting: kotlin_solutions/154.find-minimum-in-rotated-sorted-array-ii.kt
# - Downloading find-minimum-in-rotated-sorted-array-ii
#   ✔ Accepted
#   ✔ 193/193 cases passed (18 ms)
#   ✔ Your runtime beats 15 % of kotlin submissions
#   ✔ Your memory usage beats 20 % of kotlin submissions (46 MB)
# Submitting: kotlin_solutions/155.min-stack.kt
# - Downloading min-stack
#   ✔ Accepted
#   ✔ 33/33 cases passed (26 ms)
#   ✔ Your runtime beats 47.34 % of kotlin submissions
#   ✔ Your memory usage beats 7.85 % of kotlin submissions (57.2 MB)
# Submitting: kotlin_solutions/160.intersection-of-two-linked-lists.kt
# - Downloading intersection-of-two-linked-lists
#   ✔ Accepted
#   ✔ 41/41 cases passed (213 ms)
#   ✔ Your runtime beats 44.2 % of kotlin submissions
#   ✔ Your memory usage beats 14.92 % of kotlin submissions (57 MB)
# Submitting: kotlin_solutions/162.find-peak-element.kt
# - Downloading find-peak-element
#   ✔ Accepted
#   ✔ 73/73 cases passed (17 ms)
#   ✔ Your runtime beats 13.27 % of kotlin submissions
#   ✔ Your memory usage beats 5.56 % of kotlin submissions (49.2 MB)
# Submitting: kotlin_solutions/164.maximum-gap.kt
# - Downloading maximum-gap
#   ✔ Accepted
#   ✔ 46/46 cases passed (340 ms)
#   ✔ Your runtime beats 26.67 % of kotlin submissions
#   ✔ Your memory usage beats 6.67 % of kotlin submissions (70.4 MB)
# Submitting: kotlin_solutions/165.compare-version-numbers.kt
# - Downloading compare-version-numbers
#   ✔ Accepted
#   ✔ 90/90 cases passed (17 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
#   ✔ Your memory usage beats 31.43 % of kotlin submissions (43.3 MB)
# Submitting: kotlin_solutions/166.fraction-to-recurring-decimal.kt
# - Downloading fraction-to-recurring-decimal
#   ✔ Accepted
#   ✔ 41/41 cases passed (10 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (44.7 MB)
# Submitting: kotlin_solutions/167.two-sum-ii-input-array-is-sorted.kt
# - Downloading two-sum-ii-input-array-is-sorted
#   ✔ Accepted
#   ✔ 24/24 cases passed (30 ms)
#   ✔ Your runtime beats 9.91 % of kotlin submissions
#   ✔ Your memory usage beats 80.89 % of kotlin submissions (50.2 MB)
# Submitting: kotlin_solutions/168.excel-sheet-column-title.kt
# - Downloading excel-sheet-column-title
#   ✔ Accepted
#   ✔ 22/22 cases passed (15 ms)
#   ✔ Your runtime beats 10.29 % of kotlin submissions
#   ✔ Your memory usage beats 7.35 % of kotlin submissions (42.6 MB)
# Submitting: kotlin_solutions/169.majority-element.kt
# - Downloading majority-element
#   ✔ Accepted
#   ✔ 53/53 cases passed (1480 ms)
#   ✔ Your runtime beats 5.01 % of kotlin submissions
#   ✔ Your memory usage beats 5.26 % of kotlin submissions (57.1 MB)
# Submitting: kotlin_solutions/171.excel-sheet-column-number.kt
# - Downloading excel-sheet-column-number
#   ✔ Accepted
#   ✔ 1002/1002 cases passed (1 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 53.52 % of kotlin submissions (42.1 MB)
# Submitting: kotlin_solutions/172.factorial-trailing-zeroes.kt
# - Downloading factorial-trailing-zeroes
#   ✔ Accepted
#   ✔ 500/500 cases passed (10 ms)
#   ✔ Your runtime beats 11.36 % of kotlin submissions
#   ✔ Your memory usage beats 13.64 % of kotlin submissions (41.5 MB)
# Submitting: kotlin_solutions/173.binary-search-tree-iterator.kt
# - Downloading binary-search-tree-iterator
#   ✔ Accepted
#   ✔ 61/61 cases passed (45 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 68.03 % of kotlin submissions (58.8 MB)
# Submitting: kotlin_solutions/174.dungeon-game.kt
# - Downloading dungeon-game
#   ✔ Accepted
#   ✔ 45/45 cases passed (17 ms)
#   ✔ Your runtime beats 38.46 % of kotlin submissions
#   ✔ Your memory usage beats 69.23 % of kotlin submissions (46.2 MB)
# Submitting: kotlin_solutions/179.largest-number.kt
# - Downloading largest-number
#   ✔ Accepted
#   ✔ 236/236 cases passed (26 ms)
#   ✔ Your runtime beats 54.67 % of kotlin submissions
#   ✔ Your memory usage beats 37.33 % of kotlin submissions (47.7 MB)
# Submitting: kotlin_solutions/187.repeated-dna-sequences.kt
# - Downloading repeated-dna-sequences
#   ✔ Accepted
#   ✔ 32/32 cases passed (63 ms)
#   ✔ Your runtime beats 14.75 % of kotlin submissions
#   ✔ Your memory usage beats 29.51 % of kotlin submissions (57.7 MB)
# Submitting: kotlin_solutions/188.best-time-to-buy-and-sell-stock-iv.kt
# - Downloading best-time-to-buy-and-sell-stock-iv
#   ✔ Accepted
#   ✔ 211/211 cases passed (23 ms)
#   ✔ Your runtime beats 19.57 % of kotlin submissions
#   ✔ Your memory usage beats 58.7 % of kotlin submissions (45.5 MB)
# Submitting: kotlin_solutions/189.rotate-array.kt
# - Downloading rotate-array
#   ✔ Accepted
#   ✔ 40/40 cases passed (15 ms)
#   ✔ Your runtime beats 22.65 % of kotlin submissions
#   ✔ Your memory usage beats 52.45 % of kotlin submissions (60.7 MB)
# Submitting: kotlin_solutions/190.reverse-bits.kt
# - Downloading reverse-bits
#   ✔ Accepted
#   ✔ 600/600 cases passed (98 ms)
#   ✔ Your runtime beats 43.37 % of kotlin submissions
#   ✔ Your memory usage beats 51.97 % of kotlin submissions (40.1 MB)
# Submitting: kotlin_solutions/191.number-of-1-bits.kt
# - Downloading number-of-1-bits
#   ✔ Accepted
#   ✔ 598/598 cases passed (10 ms)
#   ✔ Your runtime beats 7.65 % of kotlin submissions
#   ✔ Your memory usage beats 8.24 % of kotlin submissions (42.2 MB)
# Submitting: kotlin_solutions/198.house-robber.kt
# - Downloading house-robber
#   ✔ Accepted
#   ✔ 70/70 cases passed (1 ms)
#   ✔ Your runtime beats 33.94 % of kotlin submissions
#   ✔ Your memory usage beats 54.02 % of kotlin submissions (40.8 MB)
# Submitting: kotlin_solutions/199.binary-tree-right-side-view.kt
# - Downloading binary-tree-right-side-view
#   ✔ Accepted
#   ✔ 217/217 cases passed (26 ms)
#   ✔ Your runtime beats 5.71 % of kotlin submissions
#   ✔ Your memory usage beats 11.71 % of kotlin submissions (46.9 MB)
# Submitting: kotlin_solutions/200.number-of-islands.kt
# - Downloading number-of-islands
#   ✔ Accepted
#   ✔ 49/49 cases passed (268 ms)
#   ✔ Your runtime beats 14.65 % of kotlin submissions
#   ✔ Your memory usage beats 13.58 % of kotlin submissions (59.2 MB)
# Submitting: kotlin_solutions/201.bitwise-and-of-numbers-range.kt
# - Downloading bitwise-and-of-numbers-range
#   ✔ Accepted
#   ✔ 8272/8272 cases passed (16 ms)
#   ✔ Your runtime beats 36 % of kotlin submissions
#   ✔ Your memory usage beats 40 % of kotlin submissions (45.7 MB)
# Submitting: kotlin_solutions/202.happy-number.kt
# - Downloading happy-number
#   ✔ Accepted
#   ✔ 420/420 cases passed (15 ms)
#   ✔ Your runtime beats 10.45 % of kotlin submissions
#   ✔ Your memory usage beats 9.41 % of kotlin submissions (43.5 MB)
# Submitting: kotlin_solutions/203.remove-linked-list-elements.kt
# - Downloading remove-linked-list-elements
#   ✔ Accepted
#   ✔ 66/66 cases passed (11 ms)
#   ✔ Your runtime beats 6.14 % of kotlin submissions
#   ✔ Your memory usage beats 41.23 % of kotlin submissions (48.3 MB)
# Submitting: kotlin_solutions/204.count-primes.kt
# - Downloading count-primes
#   ✔ Accepted
#   ✔ 66/66 cases passed (115 ms)
#   ✔ Your runtime beats 45.65 % of kotlin submissions
#   ✔ Your memory usage beats 23.91 % of kotlin submissions (51.3 MB)
# Submitting: kotlin_solutions/205.isomorphic-strings.kt
# - Downloading isomorphic-strings
#   ✔ Accepted
#   ✔ 47/47 cases passed (30 ms)
#   ✔ Your runtime beats 19.45 % of kotlin submissions
#   ✔ Your memory usage beats 5.46 % of kotlin submissions (47.2 MB)
# Submitting: kotlin_solutions/206.reverse-linked-list.kt
# - Downloading reverse-linked-list
#   ✔ Accepted
#   ✔ 28/28 cases passed (8 ms)
#   ✔ Your runtime beats 3.27 % of kotlin submissions
#   ✔ Your memory usage beats 7.64 % of kotlin submissions (43.7 MB)
# Submitting: kotlin_solutions/207.course-schedule.kt
# - Downloading course-schedule
#   ✔ Accepted
#   ✔ 54/54 cases passed (28 ms)
#   ✔ Your runtime beats 27.46 % of kotlin submissions
#   ✔ Your memory usage beats 60.64 % of kotlin submissions (52.6 MB)
# Submitting: kotlin_solutions/208.implement-trie-prefix-tree.kt
# - Downloading implement-trie-prefix-tree
#   ✔ Accepted
#   ✔ 16/16 cases passed (78 ms)
#   ✔ Your runtime beats 35.04 % of kotlin submissions
#   ✔ Your memory usage beats 75.21 % of kotlin submissions (61.7 MB)
# Submitting: kotlin_solutions/209.minimum-size-subarray-sum.kt
# - Downloading minimum-size-subarray-sum
#   ✔ Accepted
#   ✔ 21/21 cases passed (94 ms)
#   ✔ Your runtime beats 9.21 % of kotlin submissions
#   ✔ Your memory usage beats 12.1 % of kotlin submissions (63.6 MB)
# Submitting: kotlin_solutions/210.course-schedule-ii.kt
# - Downloading course-schedule-ii
#   ✔ Accepted
#   ✔ 47/47 cases passed (27 ms)
#   ✔ Your runtime beats 26.44 % of kotlin submissions
#   ✔ Your memory usage beats 37.93 % of kotlin submissions (53.9 MB)
# Submitting: kotlin_solutions/211.design-add-and-search-words-data-structure.kt
# - Downloading design-add-and-search-words-data-structure
#   ✔ Accepted
#   ✔ 30/30 cases passed (330 ms)
#   ✔ Your runtime beats 25.39 % of kotlin submissions
#   ✔ Your memory usage beats 51.58 % of kotlin submissions (124 MB)
# Submitting: kotlin_solutions/212.word-search-ii.kt
# - Downloading word-search-ii
#   ✔ Accepted
#   ✔ 65/65 cases passed (1680 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 43.14 % of kotlin submissions (57 MB)
# Submitting: kotlin_solutions/213.house-robber-ii.kt
# - Downloading house-robber-ii
#   ✔ Accepted
#   ✔ 75/75 cases passed (17 ms)
#   ✔ Your runtime beats 8.4 % of kotlin submissions
#   ✔ Your memory usage beats 6.11 % of kotlin submissions (46.2 MB)
# Submitting: kotlin_solutions/214.shortest-palindrome.kt
# - Downloading shortest-palindrome
#   ✔ Accepted
#   ✔ 126/126 cases passed (59 ms)
#   ✔ Your runtime beats 41.67 % of kotlin submissions
#   ✔ Your memory usage beats 8.33 % of kotlin submissions (54.2 MB)
# Submitting: kotlin_solutions/215.kth-largest-element-in-an-array.kt
# - Downloading kth-largest-element-in-an-array
#   ✔ Accepted
#   ✔ 45/45 cases passed (64 ms)
#   ✔ Your runtime beats 25.55 % of kotlin submissions
#   ✔ Your memory usage beats 18.61 % of kotlin submissions (63.5 MB)
# Submitting: kotlin_solutions/216.combination-sum-iii.kt
# - Downloading combination-sum-iii
#   ✔ Accepted
#   ✔ 19/19 cases passed (21 ms)
#   ✔ Your runtime beats 19.19 % of kotlin submissions
#   ✔ Your memory usage beats 19.19 % of kotlin submissions (44.3 MB)
# Submitting: kotlin_solutions/217.contains-duplicate.kt
# - Downloading contains-duplicate
#   ✔ Accepted
#   ✔ 77/77 cases passed (31 ms)
#   ✔ Your runtime beats 26.71 % of kotlin submissions
#   ✔ Your memory usage beats 17.31 % of kotlin submissions (68.2 MB)
# Submitting: kotlin_solutions/218.the-skyline-problem.kt
# - Downloading the-skyline-problem
#   ✔ Accepted
#   ✔ 44/44 cases passed (824 ms)
#   ✔ Your runtime beats 22.22 % of kotlin submissions
#   ✔ Your memory usage beats 16.67 % of kotlin submissions (75.4 MB)
# Submitting: kotlin_solutions/219.contains-duplicate-ii.kt
# - Downloading contains-duplicate-ii
#   ✔ Accepted
#   ✔ 65/65 cases passed (121 ms)
#   ✔ Your runtime beats 13.8 % of kotlin submissions
#   ✔ Your memory usage beats 5.47 % of kotlin submissions (82.1 MB)
# Submitting: kotlin_solutions/220.contains-duplicate-iii.kt
# - Downloading contains-duplicate-iii
#   ✔ Accepted
#   ✔ 56/56 cases passed (118 ms)
#   ✔ Your runtime beats 28 % of kotlin submissions
#   ✔ Your memory usage beats 68 % of kotlin submissions (65.1 MB)
# Submitting: kotlin_solutions/221.maximal-square.kt
# - Downloading maximal-square
#   ✔ Accepted
#   ✔ 81/81 cases passed (64 ms)
#   ✔ Your runtime beats 13.46 % of kotlin submissions
#   ✔ Your memory usage beats 9.62 % of kotlin submissions (78.4 MB)
# Submitting: kotlin_solutions/222.count-complete-tree-nodes.kt
# - Downloading count-complete-tree-nodes
#   ✔ Accepted
#   ✔ 18/18 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 6.48 % of kotlin submissions (51.6 MB)
# Submitting: kotlin_solutions/223.rectangle-area.kt
# - Downloading rectangle-area
#   ✔ Accepted
#   ✔ 3080/3080 cases passed (2 ms)
#   ✔ Your runtime beats 80 % of kotlin submissions
#   ✔ Your memory usage beats 56 % of kotlin submissions (43.7 MB)
# Submitting: kotlin_solutions/224.basic-calculator.kt
# - Downloading basic-calculator
#   ✔ Accepted
#   ✔ 49/49 cases passed (129 ms)
#   ✔ Your runtime beats 9.23 % of kotlin submissions
#   ✔ Your memory usage beats 7.69 % of kotlin submissions (53.5 MB)

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-03-17 15:47:15
