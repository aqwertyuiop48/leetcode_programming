# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME_2')
    user_cookie = userdata.get('LEETCODE_TOKEN_2')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME_2'] = user_name
    os.environ['LEETCODE_TOKEN_2'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME_2" "$LEETCODE_TOKEN_2" | leetcode user -c

# %%
# %%bash
#
# # top 300-400 answers (next batch)
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v kotlin_solutions/*.kt | sed -n '301,400p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 7
# done
# Out:
# Submitting: kotlin_solutions/388.longest-absolute-file-path.kt
# - Downloading problems
# - Downloading longest-absolute-file-path
#   ✔ Accepted
#   ✔ 26/26 cases passed (14 ms)
#   ✔ Your runtime beats 66.67 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (43.3 MB)
# Submitting: kotlin_solutions/389.find-the-difference.kt
# - Downloading find-the-difference
#   ✔ Accepted
#   ✔ 54/54 cases passed (3 ms)
#   ✔ Your runtime beats 63.1 % of kotlin submissions
#   ✔ Your memory usage beats 38.1 % of kotlin submissions (41.9 MB)
# Submitting: kotlin_solutions/390.elimination-game.kt
# - Downloading elimination-game
#   ✔ Accepted
#   ✔ 3377/3377 cases passed (24 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (47.5 MB)
# Submitting: kotlin_solutions/391.perfect-rectangle.kt
# - Downloading perfect-rectangle
#   ✔ Accepted
#   ✔ 49/49 cases passed (98 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions/392.is-subsequence.kt
# - Downloading is-subsequence
#   ✔ Accepted
#   ✔ 22/22 cases passed (6 ms)
#   ✔ Your runtime beats 10.82 % of kotlin submissions
#   ✔ Your memory usage beats 5.65 % of kotlin submissions (42 MB)
# Submitting: kotlin_solutions/393.utf-8-validation.kt
# - Downloading utf-8-validation
#   ✔ Accepted
#   ✔ 53/53 cases passed (1 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (48 MB)
# Submitting: kotlin_solutions/394.decode-string.kt
# - Downloading decode-string
#   ✔ Accepted
#   ✔ 34/34 cases passed (21 ms)
#   ✔ Your runtime beats 10.27 % of kotlin submissions
#   ✔ Your memory usage beats 17.84 % of kotlin submissions (43.6 MB)
# Submitting: kotlin_solutions/395.longest-substring-with-at-least-k-repeating-characters.kt
# - Downloading longest-substring-with-at-least-k-repeating-characters
#   ✔ Accepted
#   ✔ 38/38 cases passed (44 ms)
#   ✔ Your runtime beats 37.93 % of kotlin submissions
#   ✔ Your memory usage beats 27.59 % of kotlin submissions (48.3 MB)
# Submitting: kotlin_solutions/396.rotate-function.kt
# - Downloading rotate-function
#   ✔ Accepted
#   ✔ 58/58 cases passed (38 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (62.4 MB)
# Submitting: kotlin_solutions/397.integer-replacement.kt
# - Downloading integer-replacement
#   ✔ Accepted
#   ✔ 47/47 cases passed (3 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
#   ✔ Your memory usage beats 87.5 % of kotlin submissions (39.9 MB)
# Submitting: kotlin_solutions/398.random-pick-index.kt
# - Downloading random-pick-index
#   ✔ Accepted
#   ✔ 17/17 cases passed (977 ms)
#   ✔ Your runtime beats 13.33 % of kotlin submissions
#   ✔ Your memory usage beats 13.33 % of kotlin submissions (84.9 MB)
# Submitting: kotlin_solutions/399.evaluate-division.kt
# - Downloading evaluate-division
#   ✔ Accepted
#   ✔ 29/29 cases passed (23 ms)
#   ✔ Your runtime beats 5.93 % of kotlin submissions
#   ✔ Your memory usage beats 17.04 % of kotlin submissions (45.4 MB)
# Submitting: kotlin_solutions/400.nth-digit.kt
# - Downloading nth-digit
#   ✔ Accepted
#   ✔ 72/72 cases passed (7 ms)
#   ✔ Your runtime beats 22.22 % of kotlin submissions
#   ✔ Your memory usage beats 22.22 % of kotlin submissions (41 MB)
# Submitting: kotlin_solutions/401.binary-watch.kt
# - Downloading binary-watch
#   ✔ Accepted
#   ✔ 11/11 cases passed (15 ms)
#   ✔ Your runtime beats 41.67 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (43.9 MB)
# Submitting: kotlin_solutions/402.remove-k-digits.kt
# - Downloading remove-k-digits
#   ✔ Accepted
#   ✔ 44/44 cases passed (102 ms)
#   ✔ Your runtime beats 25.64 % of kotlin submissions
#   ✔ Your memory usage beats 30.77 % of kotlin submissions (49.9 MB)
# Submitting: kotlin_solutions/403.frog-jump.kt
# - Downloading frog-jump
#   ✔ Accepted
#   ✔ 55/55 cases passed (247 ms)
#   ✔ Your runtime beats 14.29 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (59.8 MB)
# Submitting: kotlin_solutions/404.sum-of-left-leaves.kt
# - Downloading sum-of-left-leaves
#   ✔ Accepted
#   ✔ 100/100 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 55 % of kotlin submissions (41.5 MB)
# Submitting: kotlin_solutions/405.convert-a-number-to-hexadecimal.kt
# - Downloading convert-a-number-to-hexadecimal
#   ✔ Accepted
#   ✔ 100/100 cases passed (15 ms)
#   ✔ Your runtime beats 13.33 % of kotlin submissions
#   ✔ Your memory usage beats 13.33 % of kotlin submissions (42.8 MB)
# Submitting: kotlin_solutions/406.queue-reconstruction-by-height.kt
# - Downloading queue-reconstruction-by-height
#   ✔ Accepted
#   ✔ 36/36 cases passed (22 ms)
#   ✔ Your runtime beats 46.67 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (50.4 MB)
# Submitting: kotlin_solutions/407.trapping-rain-water-ii.kt
# - Downloading trapping-rain-water-ii
#   ✔ Accepted
#   ✔ 42/42 cases passed (54 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (50.1 MB)
# Submitting: kotlin_solutions/409.longest-palindrome.kt
# - Downloading longest-palindrome
#   ✔ Accepted
#   ✔ 97/97 cases passed (18 ms)
#   ✔ Your runtime beats 6.42 % of kotlin submissions
#   ✔ Your memory usage beats 5.5 % of kotlin submissions (44 MB)
# Submitting: kotlin_solutions/410.split-array-largest-sum.kt
# - Downloading split-array-largest-sum
#   ✔ Accepted
#   ✔ 34/34 cases passed (23 ms)
#   ✔ Your runtime beats 6.15 % of kotlin submissions
#   ✔ Your memory usage beats 6.15 % of kotlin submissions (46.1 MB)
# Submitting: kotlin_solutions/412.fizz-buzz.kt
# - Downloading fizz-buzz
#   ✔ Accepted
#   ✔ 8/8 cases passed (9 ms)
#   ✔ Your runtime beats 15.32 % of kotlin submissions
#   ✔ Your memory usage beats 9.91 % of kotlin submissions (46.7 MB)
# Submitting: kotlin_solutions/413.arithmetic-slices.kt
# - Downloading arithmetic-slices
#   ✔ Accepted
#   ✔ 16/16 cases passed (39 ms)
#   ✔ Your runtime beats 5.41 % of kotlin submissions
#   ✔ Your memory usage beats 5.41 % of kotlin submissions (47 MB)
# Submitting: kotlin_solutions/414.third-maximum-number.kt
# - Downloading third-maximum-number
#   ✔ Accepted
#   ✔ 34/34 cases passed (32 ms)
#   ✔ Your runtime beats 17.07 % of kotlin submissions
#   ✔ Your memory usage beats 14.63 % of kotlin submissions (48 MB)
# Submitting: kotlin_solutions/415.add-strings.kt
# - Downloading add-strings
#   ✔ Accepted
#   ✔ 317/317 cases passed (26 ms)
#   ✔ Your runtime beats 6.9 % of kotlin submissions
#   ✔ Your memory usage beats 8.05 % of kotlin submissions (47 MB)
# Submitting: kotlin_solutions/416.partition-equal-subset-sum.kt
# - Downloading partition-equal-subset-sum
#   ✔ Accepted
#   ✔ 147/147 cases passed (436 ms)
#   ✔ Your runtime beats 5.63 % of kotlin submissions
#   ✔ Your memory usage beats 19.01 % of kotlin submissions (59.9 MB)
# Submitting: kotlin_solutions/417.pacific-atlantic-water-flow.kt
# - Downloading pacific-atlantic-water-flow
#   ✔ Accepted
#   ✔ 114/114 cases passed (85 ms)
#   ✔ Your runtime beats 15 % of kotlin submissions
#   ✔ Your memory usage beats 47.14 % of kotlin submissions (53.5 MB)
# Submitting: kotlin_solutions/419.battleships-in-a-board.kt
# - Downloading battleships-in-a-board
#   ✔ Accepted
#   ✔ 27/27 cases passed (15 ms)
#   ✔ Your runtime beats 15.79 % of kotlin submissions
#   ✔ Your memory usage beats 13.16 % of kotlin submissions (48.5 MB)
# Submitting: kotlin_solutions/420.strong-password-checker.kt
# - Downloading strong-password-checker
#   ✔ Accepted
#   ✔ 54/54 cases passed (25 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/421.maximum-xor-of-two-numbers-in-an-array.kt
# - Downloading maximum-xor-of-two-numbers-in-an-array
#   ✔ Accepted
#   ✔ 46/46 cases passed (1437 ms)
#   ✔ Your runtime beats 41.18 % of kotlin submissions
#   ✔ Your memory usage beats 82.35 % of kotlin submissions (98.6 MB)
# Submitting: kotlin_solutions/423.reconstruct-original-digits-from-english.kt
# - Downloading reconstruct-original-digits-from-english
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 27: Char 30: ERROR: Unresolved reference 'originalDigits'.
#   ✘ Error: Line 27: Char 30: ERROR: Unresolved reference 'originalDigits'.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions/424.longest-repeating-character-replacement.kt
# - Downloading longest-repeating-character-replacement
#   ✔ Accepted
#   ✔ 50/50 cases passed (138 ms)
#   ✔ Your runtime beats 5.12 % of kotlin submissions
#   ✔ Your memory usage beats 6.34 % of kotlin submissions (50.4 MB)
# Submitting: kotlin_solutions/427.construct-quad-tree.kt
# - Downloading construct-quad-tree
#   ✔ Accepted
#   ✔ 24/24 cases passed (163 ms)
#   ✔ Your runtime beats 54.05 % of kotlin submissions
#   ✔ Your memory usage beats 78.38 % of kotlin submissions (47.2 MB)
# Submitting: kotlin_solutions/429.n-ary-tree-level-order-traversal.kt
# - Downloading n-ary-tree-level-order-traversal
#   ✔ Accepted
#   ✔ 38/38 cases passed (222 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
#   ✔ Your memory usage beats 60 % of kotlin submissions (49.9 MB)
# Submitting: kotlin_solutions/430.flatten-a-multilevel-doubly-linked-list.kt
# - Downloading flatten-a-multilevel-doubly-linked-list
#   ✔ Accepted
#   ✔ 26/26 cases passed (127 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 16.67 % of kotlin submissions (42.5 MB)
# Submitting: kotlin_solutions/432.all-o-one-data-structure.kt
# - Downloading all-oone-data-structure
#   ✔ Accepted
#   ✔ 25/25 cases passed (2187 ms)
#   ✔ Your runtime beats 7.41 % of kotlin submissions
#   ✔ Your memory usage beats 14.81 % of kotlin submissions (93.8 MB)
# Submitting: kotlin_solutions/433.minimum-genetic-mutation.kt
# - Downloading minimum-genetic-mutation
#   ✔ Accepted
#   ✔ 20/20 cases passed (24 ms)
#   ✔ Your runtime beats 14.93 % of kotlin submissions
#   ✔ Your memory usage beats 29.85 % of kotlin submissions (46 MB)
# Submitting: kotlin_solutions/434.number-of-segments-in-a-string.kt
# - Downloading number-of-segments-in-a-string
#   ✔ Accepted
#   ✔ 28/28 cases passed (10 ms)
#   ✔ Your runtime beats 27.27 % of kotlin submissions
#   ✔ Your memory usage beats 13.64 % of kotlin submissions (42.8 MB)
# Submitting: kotlin_solutions/435.non-overlapping-intervals.kt
# - Downloading non-overlapping-intervals
#   ✔ Accepted
#   ✔ 59/59 cases passed (106 ms)
#   ✔ Your runtime beats 24.63 % of kotlin submissions
#   ✔ Your memory usage beats 5.22 % of kotlin submissions (119.2 MB)
# Submitting: kotlin_solutions/436.find-right-interval.kt
# - Downloading find-right-interval
#   ✔ Accepted
#   ✔ 20/20 cases passed (48 ms)
#   ✔ Your runtime beats 43.75 % of kotlin submissions
#   ✔ Your memory usage beats 56.25 % of kotlin submissions (57.6 MB)
# Submitting: kotlin_solutions/437.path-sum-iii.kt
# - Downloading path-sum-iii
#   ✔ Accepted
#   ✔ 130/130 cases passed (10 ms)
#   ✔ Your runtime beats 38.38 % of kotlin submissions
#   ✔ Your memory usage beats 52.53 % of kotlin submissions (45.4 MB)
# Submitting: kotlin_solutions/438.find-all-anagrams-in-a-string.kt
# - Downloading find-all-anagrams-in-a-string
#   ✔ Accepted
#   ✔ 65/65 cases passed (2366 ms)
#   ✔ Your runtime beats 5.09 % of kotlin submissions
#   ✔ Your memory usage beats 5.08 % of kotlin submissions (191.7 MB)
# Submitting: kotlin_solutions/440.k-th-smallest-in-lexicographical-order.kt
# - Downloading k-th-smallest-in-lexicographical-order
#   ✔ Accepted
#   ✔ 70/70 cases passed (11 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (42.5 MB)
# Submitting: kotlin_solutions/441.arranging-coins.kt
# - Downloading arranging-coins
#   ✔ Accepted
#   ✔ 1336/1336 cases passed (100 ms)
#   ✔ Your runtime beats 6.9 % of kotlin submissions
#   ✔ Your memory usage beats 10.34 % of kotlin submissions (46 MB)
# Submitting: kotlin_solutions/442.find-all-duplicates-in-an-array.kt
# - Downloading find-all-duplicates-in-an-array
#   ✔ Accepted
#   ✔ 29/29 cases passed (25 ms)
#   ✔ Your runtime beats 45.28 % of kotlin submissions
#   ✔ Your memory usage beats 5.66 % of kotlin submissions (62.3 MB)
# Submitting: kotlin_solutions/443.string-compression.kt
# - Downloading string-compression
#   ✔ Accepted
#   ✔ 77/77 cases passed (35 ms)
#   ✔ Your runtime beats 5.33 % of kotlin submissions
#   ✔ Your memory usage beats 5.33 % of kotlin submissions (48.5 MB)
# Submitting: kotlin_solutions/445.add-two-numbers-ii.kt
# - Downloading add-two-numbers-ii
#   ✔ Accepted
#   ✔ 1563/1563 cases passed (43 ms)
#   ✔ Your runtime beats 7.14 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (50 MB)
# Submitting: kotlin_solutions/446.arithmetic-slices-ii-subsequence.kt
# - Downloading arithmetic-slices-ii-subsequence
#   ✔ Accepted
#   ✔ 101/101 cases passed (242 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/447.number-of-boomerangs.kt
# - Downloading number-of-boomerangs
#   ✔ Accepted
#   ✔ 32/32 cases passed (180 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/448.find-all-numbers-disappeared-in-an-array.kt
# - Downloading find-all-numbers-disappeared-in-an-array
#   ✔ Accepted
#   ✔ 35/35 cases passed (48 ms)
#   ✔ Your runtime beats 30.82 % of kotlin submissions
#   ✔ Your memory usage beats 26.41 % of kotlin submissions (62.7 MB)
# Submitting: kotlin_solutions/449.serialize-and-deserialize-bst.kt
# - Downloading serialize-and-deserialize-bst
#   ✔ Accepted
#   ✔ 62/62 cases passed (185 ms)
#   ✔ Your runtime beats 74.07 % of kotlin submissions
#   ✔ Your memory usage beats 92.59 % of kotlin submissions (46 MB)
# Submitting: kotlin_solutions/450.delete-node-in-a-bst.kt
# - Downloading delete-node-in-a-bst
#   ✔ Accepted
#   ✔ 95/95 cases passed (5 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 94.06 % of kotlin submissions (47.5 MB)
# Submitting: kotlin_solutions/451.sort-characters-by-frequency.kt
# - Downloading sort-characters-by-frequency
#   ✔ Accepted
#   ✔ 33/33 cases passed (44 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
#   ✔ Your memory usage beats 22.06 % of kotlin submissions (49.3 MB)
# Submitting: kotlin_solutions/452.minimum-number-of-arrows-to-burst-balloons.kt
# - Downloading minimum-number-of-arrows-to-burst-balloons
#   ✔ Accepted
#   ✔ 50/50 cases passed (200 ms)
#   ✔ Your runtime beats 22.12 % of kotlin submissions
#   ✔ Your memory usage beats 5.77 % of kotlin submissions (113.9 MB)
# Submitting: kotlin_solutions/453.minimum-moves-to-equal-array-elements.kt
# - Downloading minimum-moves-to-equal-array-elements
#   ✔ Accepted
#   ✔ 84/84 cases passed (13 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 16.67 % of kotlin submissions (51.2 MB)
# Submitting: kotlin_solutions/454.4-sum-ii.kt
# - Downloading 4sum-ii
#   ✔ Accepted
#   ✔ 133/133 cases passed (203 ms)
#   ✔ Your runtime beats 7.69 % of kotlin submissions
#   ✔ Your memory usage beats 30.77 % of kotlin submissions (52.4 MB)
# Submitting: kotlin_solutions/455.assign-cookies.kt
# - Downloading assign-cookies
#   ✔ Accepted
#   ✔ 25/25 cases passed (22 ms)
#   ✔ Your runtime beats 62.24 % of kotlin submissions
#   ✔ Your memory usage beats 42.86 % of kotlin submissions (53.8 MB)
# Submitting: kotlin_solutions/456.132-pattern.kt
# - Downloading 132-pattern
#   ✔ Accepted
#   ✔ 108/108 cases passed (46 ms)
#   ✔ Your runtime beats 43.75 % of kotlin submissions
#   ✔ Your memory usage beats 37.5 % of kotlin submissions (79.1 MB)
# Submitting: kotlin_solutions/457.circular-array-loop.kt
# - Downloading circular-array-loop
#   ✔ Accepted
#   ✔ 45/45 cases passed (52 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
#   ✔ Your memory usage beats 26.67 % of kotlin submissions (47.5 MB)
# Submitting: kotlin_solutions/458.poor-pigs.kt
# - Downloading poor-pigs
#   ✔ Accepted
#   ✔ 26/26 cases passed (5 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/459.repeated-substring-pattern.kt
# - Downloading repeated-substring-pattern
#   ✔ Accepted
#   ✔ 130/130 cases passed (46 ms)
#   ✔ Your runtime beats 51.32 % of kotlin submissions
#   ✔ Your memory usage beats 42.11 % of kotlin submissions (47.5 MB)
# Submitting: kotlin_solutions/460.lfu-cache.kt
# - Downloading lfu-cache
#   ✔ Accepted
#   ✔ 25/25 cases passed (160 ms)
#   ✔ Your runtime beats 21.51 % of kotlin submissions
#   ✔ Your memory usage beats 5.38 % of kotlin submissions (163.1 MB)
# Submitting: kotlin_solutions/461.hamming-distance.kt
# - Downloading hamming-distance
#   ✔ Accepted
#   ✔ 149/149 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 78.57 % of kotlin submissions (40 MB)
# Submitting: kotlin_solutions/462.minimum-moves-to-equal-array-elements-ii.kt
# - Downloading minimum-moves-to-equal-array-elements-ii
#   ✔ Accepted
#   ✔ 33/33 cases passed (25 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (50.8 MB)
# Submitting: kotlin_solutions/463.island-perimeter.kt
# - Downloading island-perimeter
#   ✔ Accepted
#   ✔ 5833/5833 cases passed (57 ms)
#   ✔ Your runtime beats 18.18 % of kotlin submissions
#   ✔ Your memory usage beats 5.19 % of kotlin submissions (70.2 MB)
# Submitting: kotlin_solutions/464.can-i-win.kt
# - Downloading can-i-win
#   ✔ Accepted
#   ✔ 58/58 cases passed (497 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
#   ✔ Your memory usage beats 20 % of kotlin submissions (104.7 MB)
# Submitting: kotlin_solutions/466.count-the-repetitions.kt
# - Downloading count-the-repetitions
#   ✔ Accepted
#   ✔ 49/49 cases passed (14 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions/467.unique-substrings-in-wraparound-string.kt
# - Downloading unique-substrings-in-wraparound-string
#   ✔ Accepted
#   ✔ 82/82 cases passed (26 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/468.validate-ip-address.kt
# - Downloading validate-ip-address
#   ✔ Accepted
#   ✔ 79/79 cases passed (9 ms)
#   ✔ Your runtime beats 70.59 % of kotlin submissions
#   ✔ Your memory usage beats 64.71 % of kotlin submissions (42.5 MB)
# Submitting: kotlin_solutions/470.implement-rand-10-using-rand-7.kt
# - Downloading implement-rand10-using-rand7
#   ✔ Accepted
#   ✔ 12/12 cases passed (194 ms)
#   ✔ Your runtime beats 15.38 % of kotlin submissions
#   ✔ Your memory usage beats 7.69 % of kotlin submissions (53.1 MB)
# Submitting: kotlin_solutions/472.concatenated-words.kt
# - Downloading concatenated-words
#   ✔ Accepted
#   ✔ 43/43 cases passed (147 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (57.3 MB)
# Submitting: kotlin_solutions/473.matchsticks-to-square.kt
# - Downloading matchsticks-to-square
#   ✔ Accepted
#   ✔ 195/195 cases passed (727 ms)
#   ✔ Your runtime beats 27.27 % of kotlin submissions
#   ✔ Your memory usage beats 9.09 % of kotlin submissions (49.9 MB)
# Submitting: kotlin_solutions/474.ones-and-zeroes.kt
# - Downloading ones-and-zeroes
#   ✔ Accepted
#   ✔ 77/77 cases passed (46 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 44.44 % of kotlin submissions (47.2 MB)
# Submitting: kotlin_solutions/475.heaters.kt
# - Downloading heaters
#   ✔ Accepted
#   ✔ 30/30 cases passed (64 ms)
#   ✔ Your runtime beats 23.81 % of kotlin submissions
#   ✔ Your memory usage beats 9.52 % of kotlin submissions (52.8 MB)
# Submitting: kotlin_solutions/476.number-complement.kt
# - Downloading number-complement
#   ✔ Accepted
#   ✔ 154/154 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 73.68 % of kotlin submissions (40.2 MB)
# Submitting: kotlin_solutions/477.total-hamming-distance.kt
# - Downloading total-hamming-distance
#   ✔ Accepted
#   ✔ 46/46 cases passed (27 ms)
#   ✔ Your runtime beats 22.22 % of kotlin submissions
#   ✔ Your memory usage beats 11.11 % of kotlin submissions (49.9 MB)
# Submitting: kotlin_solutions/478.generate-random-point-in-a-circle.kt
# - Downloading generate-random-point-in-a-circle
#   ✔ Accepted
#   ✔ 8/8 cases passed (319 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (64.8 MB)
# Submitting: kotlin_solutions/479.largest-palindrome-product.kt
# - Downloading largest-palindrome-product
#   ✔ Accepted
#   ✔ 8/8 cases passed (202 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/480.sliding-window-median.kt
# - Downloading sliding-window-median
#   ✔ Accepted
#   ✔ 45/45 cases passed (800 ms)
#   ✔ Your runtime beats 14.81 % of kotlin submissions
#   ✔ Your memory usage beats 18.52 % of kotlin submissions (71.9 MB)
# Submitting: kotlin_solutions/481.magical-string.kt
# - Downloading magical-string
#   ✔ Accepted
#   ✔ 64/64 cases passed (50 ms)
#   ✔ Your runtime beats 26.32 % of kotlin submissions
#   ✔ Your memory usage beats 5.26 % of kotlin submissions (48.1 MB)
# Submitting: kotlin_solutions/482.license-key-formatting.kt
# - Downloading license-key-formatting
#   ✔ Accepted
#   ✔ 40/40 cases passed (38 ms)
#   ✔ Your runtime beats 39.19 % of kotlin submissions
#   ✔ Your memory usage beats 9.46 % of kotlin submissions (49.4 MB)
# Submitting: kotlin_solutions/483.smallest-good-base.kt
# - Downloading smallest-good-base
#   ✔ Accepted
#   ✔ 109/109 cases passed (10 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/485.max-consecutive-ones.kt
# - Downloading max-consecutive-ones
#   ✔ Accepted
#   ✔ 45/45 cases passed (51 ms)
#   ✔ Your runtime beats 5.61 % of kotlin submissions
#   ✔ Your memory usage beats 5.16 % of kotlin submissions (58.6 MB)
# Submitting: kotlin_solutions/486.predict-the-winner.kt
# - Downloading predict-the-winner
#   ✔ Accepted
#   ✔ 62/62 cases passed (16 ms)
#   ✔ Your runtime beats 15 % of kotlin submissions
#   ✔ Your memory usage beats 10 % of kotlin submissions (44.3 MB)
# Submitting: kotlin_solutions/488.zuma-game.kt
# - Downloading zuma-game
#   ✔ Accepted
#   ✔ 57/57 cases passed (812 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (94.5 MB)
# Submitting: kotlin_solutions/491.non-decreasing-subsequences.kt
# - Downloading non-decreasing-subsequences
#   ✔ Accepted
#   ✔ 58/58 cases passed (86 ms)
#   ✔ Your runtime beats 17.65 % of kotlin submissions
#   ✔ Your memory usage beats 35.29 % of kotlin submissions (64.1 MB)
# Submitting: kotlin_solutions/492.construct-the-rectangle.kt
# - Downloading construct-the-rectangle
#   ✔ Accepted
#   ✔ 52/52 cases passed (9 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 5.56 % of kotlin submissions (41.6 MB)
# Submitting: kotlin_solutions/493.reverse-pairs.kt
# - Downloading reverse-pairs
#   ✔ Accepted
#   ✔ 140/140 cases passed (233 ms)
#   ✔ Your runtime beats 9.09 % of kotlin submissions
#   ✔ Your memory usage beats 13.64 % of kotlin submissions (63.9 MB)
# Submitting: kotlin_solutions/494.target-sum.kt
# - Downloading target-sum
#   ✔ Accepted
#   ✔ 142/142 cases passed (76 ms)
#   ✔ Your runtime beats 60.95 % of kotlin submissions
#   ✔ Your memory usage beats 26.67 % of kotlin submissions (49.1 MB)
# Submitting: kotlin_solutions/495.teemo-attacking.kt
# - Downloading teemo-attacking
#   ✔ Accepted
#   ✔ 40/40 cases passed (47 ms)
#   ✔ Your runtime beats 9.09 % of kotlin submissions
#   ✔ Your memory usage beats 9.09 % of kotlin submissions (52.2 MB)
# Submitting: kotlin_solutions/496.next-greater-element-i.kt
# - Downloading next-greater-element-i
#   ✔ Accepted
#   ✔ 17/17 cases passed (42 ms)
#   ✔ Your runtime beats 5.83 % of kotlin submissions
#   ✔ Your memory usage beats 5.34 % of kotlin submissions (50.8 MB)
# Submitting: kotlin_solutions/497.random-point-in-non-overlapping-rectangles.kt
# - Downloading random-point-in-non-overlapping-rectangles
#   ✔ Accepted
#   ✔ 35/35 cases passed (122 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (62.9 MB)
# Submitting: kotlin_solutions/498.diagonal-traverse.kt
# - Downloading diagonal-traverse
#   ✔ Accepted
#   ✔ 33/33 cases passed (23 ms)
#   ✔ Your runtime beats 17.78 % of kotlin submissions
#   ✔ Your memory usage beats 48.89 % of kotlin submissions (57.7 MB)
# Submitting: kotlin_solutions/500.keyboard-row.kt
# - Downloading keyboard-row
#   ✔ Accepted
#   ✔ 25/25 cases passed (22 ms)
#   ✔ Your runtime beats 7.41 % of kotlin submissions
#   ✔ Your memory usage beats 7.41 % of kotlin submissions (45.8 MB)
# Submitting: kotlin_solutions/501.find-mode-in-binary-search-tree.kt
# - Downloading find-mode-in-binary-search-tree
#   ✔ Accepted
#   ✔ 24/24 cases passed (10 ms)
#   ✔ Your runtime beats 73.33 % of kotlin submissions
#   ✔ Your memory usage beats 90 % of kotlin submissions (46.7 MB)
# Submitting: kotlin_solutions/502.ipo.kt
# - Downloading ipo
#   ✔ Accepted
#   ✔ 40/40 cases passed (219 ms)
#   ✔ Your runtime beats 14.81 % of kotlin submissions
#   ✔ Your memory usage beats 51.85 % of kotlin submissions (69.3 MB)
# Submitting: kotlin_solutions/503.next-greater-element-ii.kt
# - Downloading next-greater-element-ii
#   ✔ Accepted
#   ✔ 223/223 cases passed (57 ms)
#   ✔ Your runtime beats 8.6 % of kotlin submissions
#   ✔ Your memory usage beats 8.6 % of kotlin submissions (55 MB)
# Submitting: kotlin_solutions/504.base-7.kt
# - Downloading base-7
#   ✔ Accepted
#   ✔ 241/241 cases passed (23 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/506.relative-ranks.kt
# - Downloading relative-ranks
#   ✔ Accepted
#   ✔ 18/18 cases passed (240 ms)
#   ✔ Your runtime beats 6.67 % of kotlin submissions
#   ✔ Your memory usage beats 20 % of kotlin submissions (50.1 MB)

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-02-14 14:46:41
