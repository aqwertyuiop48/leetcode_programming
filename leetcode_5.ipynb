# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME_2')
    user_cookie = userdata.get('LEETCODE_TOKEN_2')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME_2'] = user_name
    os.environ['LEETCODE_TOKEN_2'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME_2" "$LEETCODE_TOKEN_2" | leetcode user -c

# %%
# %%bash
#
# # top 400-500 answers (5th batch)
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v kotlin_solutions/*.kt | sed -n '401,500p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 7
# done
# Out:
# Submitting: kotlin_solutions/507.perfect-number.kt
# - Downloading problems
# - Downloading perfect-number
#   ✔ Accepted
#   ✔ 98/98 cases passed (12 ms)
#   ✔ Your runtime beats 56.25 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (41.9 MB)
# Submitting: kotlin_solutions/508.most-frequent-subtree-sum.kt
# - Downloading most-frequent-subtree-sum
#   ✔ Accepted
#   ✔ 58/58 cases passed (30 ms)
#   ✔ Your runtime beats 11.11 % of kotlin submissions
#   ✔ Your memory usage beats 22.22 % of kotlin submissions (47.4 MB)
# Submitting: kotlin_solutions/509.fibonacci-number.kt
# - Downloading fibonacci-number
#   ✔ Accepted
#   ✔ 31/31 cases passed (76 ms)
#   ✔ Your runtime beats 53.42 % of kotlin submissions
#   ✔ Your memory usage beats 6.16 % of kotlin submissions (40 MB)
# Submitting: kotlin_solutions/513.find-bottom-left-tree-value.kt
# - Downloading find-bottom-left-tree-value
#   ✔ Accepted
#   ✔ 79/79 cases passed (10 ms)
#   ✔ Your runtime beats 42.86 % of kotlin submissions
#   ✔ Your memory usage beats 57.14 % of kotlin submissions (47.2 MB)
# Submitting: kotlin_solutions/514.freedom-trail.kt
# - Downloading freedom-trail
#   ✔ Accepted
#   ✔ 303/303 cases passed (100 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/515.find-largest-value-in-each-tree-row.kt
# - Downloading find-largest-value-in-each-tree-row
#   ✔ Accepted
#   ✔ 78/78 cases passed (20 ms)
#   ✔ Your runtime beats 39.13 % of kotlin submissions
#   ✔ Your memory usage beats 67.39 % of kotlin submissions (47.1 MB)
# Submitting: kotlin_solutions/516.longest-palindromic-subsequence.kt
# - Downloading longest-palindromic-subsequence
#   ✔ Accepted
#   ✔ 86/86 cases passed (50 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 13.89 % of kotlin submissions (58.3 MB)
# Submitting: kotlin_solutions/517.super-washing-machines.kt
# - Downloading super-washing-machines
#   ✔ Accepted
#   ✔ 120/120 cases passed (15 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/518.coin-change-ii.kt
# - Downloading coin-change-ii
#   ✔ Accepted
#   ✔ 31/31 cases passed (11 ms)
#   ✔ Your runtime beats 67.71 % of kotlin submissions
#   ✔ Your memory usage beats 77.08 % of kotlin submissions (41.6 MB)
# Submitting: kotlin_solutions/519.random-flip-matrix.kt
# - Downloading random-flip-matrix
#   ✔ Accepted
#   ✔ 20/20 cases passed (55 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (48.4 MB)
# Submitting: kotlin_solutions/520.detect-capital.kt
# - Downloading detect-capital
#   ✔ Accepted
#   ✔ 552/552 cases passed (9 ms)
#   ✔ Your runtime beats 12.35 % of kotlin submissions
#   ✔ Your memory usage beats 11.11 % of kotlin submissions (43.1 MB)
# Submitting: kotlin_solutions/521.longest-uncommon-subsequence-i.kt
# - Downloading longest-uncommon-subsequence-i
#   ✔ Accepted
#   ✔ 41/41 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 38.89 % of kotlin submissions (40.6 MB)
# Submitting: kotlin_solutions/522.longest-uncommon-subsequence-ii.kt
# - Downloading longest-uncommon-subsequence-ii
#   ✔ Accepted
#   ✔ 101/101 cases passed (28 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/523.continuous-subarray-sum.kt
# - Downloading continuous-subarray-sum
#   ✔ Accepted
#   ✔ 102/102 cases passed (44 ms)
#   ✔ Your runtime beats 25.97 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (60.6 MB)
# Submitting: kotlin_solutions/524.longest-word-in-dictionary-through-deleting.kt
# - Downloading longest-word-in-dictionary-through-deleting
#   ✔ Accepted
#   ✔ 31/31 cases passed (187 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/525.contiguous-array.kt
# - Downloading contiguous-array
#   ✔ Accepted
#   ✔ 566/566 cases passed (73 ms)
#   ✔ Your runtime beats 6.42 % of kotlin submissions
#   ✔ Your memory usage beats 10.09 % of kotlin submissions (61.8 MB)
# Submitting: kotlin_solutions/526.beautiful-arrangement.kt
# - Downloading beautiful-arrangement
#   ✔ Accepted
#   ✔ 15/15 cases passed (25 ms)
#   ✔ Your runtime beats 84.62 % of kotlin submissions
#   ✔ Your memory usage beats 38.46 % of kotlin submissions (45 MB)
# Submitting: kotlin_solutions/528.random-pick-with-weight.kt
# - Downloading random-pick-with-weight
#   ✔ Accepted
#   ✔ 57/57 cases passed (76 ms)
#   ✔ Your runtime beats 18.07 % of kotlin submissions
#   ✔ Your memory usage beats 6.02 % of kotlin submissions (72.5 MB)
# Submitting: kotlin_solutions/529.minesweeper.kt
# - Downloading minesweeper
#   ✔ Accepted
#   ✔ 54/54 cases passed (33 ms)
#   ✔ Your runtime beats 6.67 % of kotlin submissions
#   ✔ Your memory usage beats 6.67 % of kotlin submissions (53.5 MB)
# Submitting: kotlin_solutions/530.minimum-absolute-difference-in-bst.kt
# - Downloading minimum-absolute-difference-in-bst
#   ✔ Accepted
#   ✔ 190/190 cases passed (41 ms)
#   ✔ Your runtime beats 5.95 % of kotlin submissions
#   ✔ Your memory usage beats 5.95 % of kotlin submissions (51.1 MB)
# Submitting: kotlin_solutions/532.k-diff-pairs-in-an-array.kt
# - Downloading k-diff-pairs-in-an-array
#   ✔ Accepted
#   ✔ 60/60 cases passed (79 ms)
#   ✔ Your runtime beats 16 % of kotlin submissions
#   ✔ Your memory usage beats 24 % of kotlin submissions (49.8 MB)
# Submitting: kotlin_solutions/535.encode-and-decode-tiny-url.kt
# - Downloading encode-and-decode-tinyurl
#   ✔ Accepted
#   ✔ 739/739 cases passed (134 ms)
#   ✔ Your runtime beats 82.14 % of kotlin submissions
#   ✔ Your memory usage beats 96.43 % of kotlin submissions (42.4 MB)
# Submitting: kotlin_solutions/537.complex-number-multiplication.kt
# - Downloading complex-number-multiplication
#   ✔ Accepted
#   ✔ 56/56 cases passed (28 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/538.convert-bst-to-greater-tree.kt
# - Downloading convert-bst-to-greater-tree
#   ✔ Accepted
#   ✔ 215/215 cases passed (19 ms)
#   ✔ Your runtime beats 8.33 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (47 MB)
# Submitting: kotlin_solutions/539.minimum-time-difference.kt
# - Downloading minimum-time-difference
#   ✔ Accepted
#   ✔ 116/116 cases passed (54 ms)
#   ✔ Your runtime beats 7.69 % of kotlin submissions
#   ✔ Your memory usage beats 15.38 % of kotlin submissions (51.3 MB)
# Submitting: kotlin_solutions/540.single-element-in-a-sorted-array.kt
# - Downloading single-element-in-a-sorted-array
#   ✔ Accepted
#   ✔ 16/16 cases passed (15 ms)
#   ✔ Your runtime beats 1.82 % of kotlin submissions
#   ✔ Your memory usage beats 7.27 % of kotlin submissions (57.6 MB)
# Submitting: kotlin_solutions/541.reverse-string-ii.kt
# - Downloading reverse-string-ii
#   ✔ Accepted
#   ✔ 60/60 cases passed (15 ms)
#   ✔ Your runtime beats 23.53 % of kotlin submissions
#   ✔ Your memory usage beats 29.41 % of kotlin submissions (45.5 MB)
# Submitting: kotlin_solutions/542.01-matrix.kt
# - Downloading 01-matrix
#   ✔ Accepted
#   ✔ 50/50 cases passed (130 ms)
#   ✔ Your runtime beats 15.97 % of kotlin submissions
#   ✔ Your memory usage beats 93.06 % of kotlin submissions (63.1 MB)
# Submitting: kotlin_solutions/543.diameter-of-binary-tree.kt
# - Downloading diameter-of-binary-tree
#   ✔ Accepted
#   ✔ 106/106 cases passed (19 ms)
#   ✔ Your runtime beats 11.11 % of kotlin submissions
#   ✔ Your memory usage beats 28.65 % of kotlin submissions (47 MB)
# Submitting: kotlin_solutions/546.remove-boxes.kt
# - Downloading remove-boxes
#   ✔ Accepted
#   ✔ 63/63 cases passed (643 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (74.1 MB)
# Submitting: kotlin_solutions/547.number-of-provinces.kt
# - Downloading number-of-provinces
#   ✔ Accepted
#   ✔ 114/114 cases passed (41 ms)
#   ✔ Your runtime beats 5.76 % of kotlin submissions
#   ✔ Your memory usage beats 5.76 % of kotlin submissions (60.2 MB)
# Submitting: kotlin_solutions/551.student-attendance-record-i.kt
# - Downloading student-attendance-record-i
#   ✔ Accepted
#   ✔ 115/115 cases passed (7 ms)
#   ✔ Your runtime beats 19.35 % of kotlin submissions
#   ✔ Your memory usage beats 12.9 % of kotlin submissions (42.1 MB)
# Submitting: kotlin_solutions/552.student-attendance-record-ii.kt
# - Downloading student-attendance-record-ii
#   ✔ Accepted
#   ✔ 59/59 cases passed (46 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 40 % of kotlin submissions (59.2 MB)
# Submitting: kotlin_solutions/553.optimal-division.kt
# - Downloading optimal-division
#   ✔ Accepted
#   ✔ 93/93 cases passed (25 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (46.2 MB)
# Submitting: kotlin_solutions/554.brick-wall.kt
# - Downloading brick-wall
#   ✔ Accepted
#   ✔ 88/88 cases passed (54 ms)
#   ✔ Your runtime beats 9.09 % of kotlin submissions
#   ✔ Your memory usage beats 9.09 % of kotlin submissions (69.4 MB)
# Submitting: kotlin_solutions/556.next-greater-element-iii.kt
# - Downloading next-greater-element-iii
#   ✔ Accepted
#   ✔ 39/39 cases passed (21 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
#   ✔ Your memory usage beats 30 % of kotlin submissions (45.4 MB)
# Submitting: kotlin_solutions/557.reverse-words-in-a-string-iii.kt
# - Downloading reverse-words-in-a-string-iii
#   ✔ Accepted
#   ✔ 29/29 cases passed (19 ms)
#   ✔ Your runtime beats 49.18 % of kotlin submissions
#   ✔ Your memory usage beats 37.7 % of kotlin submissions (46.8 MB)
# Submitting: kotlin_solutions/558.logical-or-of-two-binary-grids-represented-as-quad-trees.kt
# - Downloading logical-or-of-two-binary-grids-represented-as-quad-trees
#   ✔ Accepted
#   ✔ 61/61 cases passed (210 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (55.5 MB)
# Submitting: kotlin_solutions/559.maximum-depth-of-n-ary-tree.kt
# - Downloading maximum-depth-of-n-ary-tree
#   ✔ Accepted
#   ✔ 38/38 cases passed (135 ms)
#   ✔ Your runtime beats 75 % of kotlin submissions
#   ✔ Your memory usage beats 28.13 % of kotlin submissions (48 MB)
# Submitting: kotlin_solutions/560.subarray-sum-equals-k.kt
# - Downloading subarray-sum-equals-k
#   ✔ Accepted
#   ✔ 93/93 cases passed (52 ms)
#   ✔ Your runtime beats 20.52 % of kotlin submissions
#   ✔ Your memory usage beats 34.5 % of kotlin submissions (53.4 MB)
# Submitting: kotlin_solutions/561.array-partition.kt
# - Downloading array-partition
#   ✔ Accepted
#   ✔ 85/85 cases passed (70 ms)
#   ✔ Your runtime beats 12.5 % of kotlin submissions
#   ✔ Your memory usage beats 64.29 % of kotlin submissions (52.8 MB)
# Submitting: kotlin_solutions/563.binary-tree-tilt.kt
# - Downloading binary-tree-tilt
#   ✔ Accepted
#   ✔ 77/77 cases passed (24 ms)
#   ✔ Your runtime beats 7.14 % of kotlin submissions
#   ✔ Your memory usage beats 7.14 % of kotlin submissions (49.7 MB)
# Submitting: kotlin_solutions/564.find-the-closest-palindrome.kt
# - Downloading find-the-closest-palindrome
#   ✔ Accepted
#   ✔ 232/232 cases passed (31 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/565.array-nesting.kt
# - Downloading array-nesting
#   ✔ Accepted
#   ✔ 885/885 cases passed (72 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (68.2 MB)
# Submitting: kotlin_solutions/566.reshape-the-matrix.kt
# - Downloading reshape-the-matrix
#   ✔ Accepted
#   ✔ 57/57 cases passed (21 ms)
#   ✔ Your runtime beats 4 % of kotlin submissions
#   ✔ Your memory usage beats 12 % of kotlin submissions (48.8 MB)
# Submitting: kotlin_solutions/567.permutation-in-string.kt
# - Downloading permutation-in-string
#   ✔ Accepted
#   ✔ 110/110 cases passed (110 ms)
#   ✔ Your runtime beats 8.44 % of kotlin submissions
#   ✔ Your memory usage beats 14.77 % of kotlin submissions (47.9 MB)
# Submitting: kotlin_solutions/572.subtree-of-another-tree.kt
# - Downloading subtree-of-another-tree
#   ✔ Accepted
#   ✔ 185/185 cases passed (3 ms)
#   ✔ Your runtime beats 94.82 % of kotlin submissions
#   ✔ Your memory usage beats 94.82 % of kotlin submissions (45.3 MB)
# Submitting: kotlin_solutions/575.distribute-candies.kt
# - Downloading distribute-candies
#   ✔ Accepted
#   ✔ 206/206 cases passed (47 ms)
#   ✔ Your runtime beats 21.74 % of kotlin submissions
#   ✔ Your memory usage beats 71.74 % of kotlin submissions (54.3 MB)
# Submitting: kotlin_solutions/576.out-of-boundary-paths.kt
# - Downloading out-of-boundary-paths
#   ✔ Accepted
#   ✔ 94/94 cases passed (24 ms)
#   ✔ Your runtime beats 66.67 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions/581.shortest-unsorted-continuous-subarray.kt
# - Downloading shortest-unsorted-continuous-subarray
#   ✔ Accepted
#   ✔ 307/307 cases passed (45 ms)
#   ✔ Your runtime beats 9.09 % of kotlin submissions
#   ✔ Your memory usage beats 22.73 % of kotlin submissions (51.7 MB)
# Submitting: kotlin_solutions/583.delete-operation-for-two-strings.kt
# - Downloading delete-operation-for-two-strings
#   ✔ Accepted
#   ✔ 1306/1306 cases passed (11 ms)
#   ✔ Your runtime beats 78.95 % of kotlin submissions
#   ✔ Your memory usage beats 21.05 % of kotlin submissions (47.5 MB)
# Submitting: kotlin_solutions/587.erect-the-fence.kt
# - Downloading erect-the-fence
#   ✔ Accepted
#   ✔ 88/88 cases passed (75 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (59.4 MB)
# Submitting: kotlin_solutions/589.n-ary-tree-preorder-traversal.kt
# - Downloading n-ary-tree-preorder-traversal
#   ✔ Accepted
#   ✔ 39/39 cases passed (162 ms)
#   ✔ Your runtime beats 86.96 % of kotlin submissions
#   ✔ Your memory usage beats 78.26 % of kotlin submissions (48 MB)
# Submitting: kotlin_solutions/590.n-ary-tree-postorder-traversal.kt
# - Downloading n-ary-tree-postorder-traversal
#   ✔ Accepted
#   ✔ 38/38 cases passed (183 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 6.67 % of kotlin submissions (50 MB)
# Submitting: kotlin_solutions/591.tag-validator.kt
# - Downloading tag-validator
#   ✔ Accepted
#   ✔ 261/261 cases passed (35 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/592.fraction-addition-and-subtraction.kt
# - Downloading fraction-addition-and-subtraction
#   ✔ Accepted
#   ✔ 105/105 cases passed (39 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/593.valid-square.kt
# - Downloading valid-square
#   ✔ Accepted
#   ✔ 256/256 cases passed (16 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (43.7 MB)
# Submitting: kotlin_solutions/594.longest-harmonious-subsequence.kt
# - Downloading longest-harmonious-subsequence
#   ✔ Accepted
#   ✔ 208/208 cases passed (42 ms)
#   ✔ Your runtime beats 20.37 % of kotlin submissions
#   ✔ Your memory usage beats 14.81 % of kotlin submissions (54.8 MB)
# Submitting: kotlin_solutions/598.range-addition-ii.kt
# - Downloading range-addition-ii
#   ✔ Accepted
#   ✔ 69/69 cases passed (3 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/599.minimum-index-sum-of-two-lists.kt
# - Downloading minimum-index-sum-of-two-lists
#   ✔ Accepted
#   ✔ 137/137 cases passed (45 ms)
#   ✔ Your runtime beats 20.51 % of kotlin submissions
#   ✔ Your memory usage beats 12.82 % of kotlin submissions (52.8 MB)
# Submitting: kotlin_solutions/600.non-negative-integers-without-consecutive-ones.kt
# - Downloading non-negative-integers-without-consecutive-ones
#   ✔ Accepted
#   ✔ 527/527 cases passed (6 ms)
#   ✔ Your runtime beats 63.64 % of kotlin submissions
#   ✔ Your memory usage beats 27.27 % of kotlin submissions (41.9 MB)
# Submitting: kotlin_solutions/605.can-place-flowers.kt
# - Downloading can-place-flowers
#   ✔ Accepted
#   ✔ 130/130 cases passed (19 ms)
#   ✔ Your runtime beats 6.69 % of kotlin submissions
#   ✔ Your memory usage beats 13.39 % of kotlin submissions (49.9 MB)
# Submitting: kotlin_solutions/606.construct-string-from-binary-tree.kt
# - Downloading construct-string-from-binary-tree
#   ✔ Accepted
#   ✔ 160/160 cases passed (8 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/609.find-duplicate-file-in-system.kt
# - Downloading find-duplicate-file-in-system
#   ✔ Accepted
#   ✔ 162/162 cases passed (51 ms)
#   ✔ Your runtime beats 66.67 % of kotlin submissions
#   ✔ Your memory usage beats 55.56 % of kotlin submissions (60.2 MB)
# Submitting: kotlin_solutions/611.valid-triangle-number.kt
# - Downloading valid-triangle-number
#   ✔ Accepted
#   ✔ 241/241 cases passed (764 ms)
#   ✔ Your runtime beats 6.25 % of kotlin submissions
#   ✔ Your memory usage beats 6.25 % of kotlin submissions (67.7 MB)
# Submitting: kotlin_solutions/617.merge-two-binary-trees.kt
# - Downloading merge-two-binary-trees
#   ✔ Accepted
#   ✔ 182/182 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 75.61 % of kotlin submissions (47.2 MB)
# Submitting: kotlin_solutions/621.task-scheduler.kt
# - Downloading task-scheduler
#   ✔ Accepted
#   ✔ 72/72 cases passed (29 ms)
#   ✔ Your runtime beats 74.16 % of kotlin submissions
#   ✔ Your memory usage beats 43.82 % of kotlin submissions (50.1 MB)
# Submitting: kotlin_solutions/622.design-circular-queue.kt
# - Downloading design-circular-queue
#   ✔ Accepted
#   ✔ 59/59 cases passed (17 ms)
#   ✔ Your runtime beats 90.14 % of kotlin submissions
#   ✔ Your memory usage beats 29.58 % of kotlin submissions (48 MB)
# Submitting: kotlin_solutions/623.add-one-row-to-tree.kt
# - Downloading add-one-row-to-tree
#   ✔ Accepted
#   ✔ 109/109 cases passed (19 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/624.maximum-distance-in-arrays.kt
# - Downloading maximum-distance-in-arrays
#   ✔ Accepted
#   ✔ 136/136 cases passed (39 ms)
#   ✔ Your runtime beats 29.41 % of kotlin submissions
#   ✔ Your memory usage beats 41.18 % of kotlin submissions (86.2 MB)
# Submitting: kotlin_solutions/628.maximum-product-of-three-numbers.kt
# - Downloading maximum-product-of-three-numbers
#   ✔ Accepted
#   ✔ 93/93 cases passed (62 ms)
#   ✔ Your runtime beats 11.54 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (51.2 MB)
# Submitting: kotlin_solutions/629.k-inverse-pairs-array.kt
# - Downloading k-inverse-pairs-array
#   ✔ Accepted
#   ✔ 81/81 cases passed (872 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/630.course-schedule-iii.kt
# - Downloading course-schedule-iii
#   ✔ Accepted
#   ✔ 97/97 cases passed (73 ms)
#   ✔ Your runtime beats 40 % of kotlin submissions
#   ✔ Your memory usage beats 20 % of kotlin submissions (76.3 MB)
# Submitting: kotlin_solutions/632.smallest-range-covering-elements-from-k-lists.kt
# - Downloading smallest-range-covering-elements-from-k-lists
#   ✔ Accepted
#   ✔ 94/94 cases passed (282 ms)
#   ✔ Your runtime beats 7.32 % of kotlin submissions
#   ✔ Your memory usage beats 7.32 % of kotlin submissions (93.5 MB)
# Submitting: kotlin_solutions/633.sum-of-square-numbers.kt
# - Downloading sum-of-square-numbers
#   ✔ Accepted
#   ✔ 127/127 cases passed (30 ms)
#   ✔ Your runtime beats 26.32 % of kotlin submissions
#   ✔ Your memory usage beats 10.53 % of kotlin submissions (46.3 MB)
# Submitting: kotlin_solutions/636.exclusive-time-of-functions.kt
# - Downloading exclusive-time-of-functions
#   ✔ Accepted
#   ✔ 120/120 cases passed (46 ms)
#   ✔ Your runtime beats 24.32 % of kotlin submissions
#   ✔ Your memory usage beats 6.76 % of kotlin submissions (50.1 MB)
# Submitting: kotlin_solutions/637.average-of-levels-in-binary-tree.kt
# - Downloading average-of-levels-in-binary-tree
#   ✔ Accepted
#   ✔ 66/66 cases passed (35 ms)
#   ✔ Your runtime beats 5.1 % of kotlin submissions
#   ✔ Your memory usage beats 6.12 % of kotlin submissions (51.6 MB)
# Submitting: kotlin_solutions/638.shopping-offers.kt
# - Downloading shopping-offers
#   ✔ Accepted
#   ✔ 65/65 cases passed (33 ms)
#   ✔ Your runtime beats 44.44 % of kotlin submissions
#   ✔ Your memory usage beats 22.22 % of kotlin submissions (54.5 MB)
# Submitting: kotlin_solutions/639.decode-ways-ii.kt
# - Downloading decode-ways-ii
#   ✔ Accepted
#   ✔ 218/218 cases passed (327 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/640.solve-the-equation.kt
# - Downloading solve-the-equation
#   ✔ Accepted
#   ✔ 59/59 cases passed (17 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (43.2 MB)
# Submitting: kotlin_solutions/641.design-circular-deque.kt
# - Downloading design-circular-deque
#   ✔ Accepted
#   ✔ 54/54 cases passed (18 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (51.6 MB)
# Submitting: kotlin_solutions/643.maximum-average-subarray-i.kt
# - Downloading maximum-average-subarray-i
# [ERROR] http error [code=429]
# Submitting: kotlin_solutions/645.set-mismatch.kt
# - Downloading set-mismatch
#   ✔ Accepted
#   ✔ 49/49 cases passed (28 ms)
#   ✔ Your runtime beats 31.2 % of kotlin submissions
#   ✔ Your memory usage beats 11.65 % of kotlin submissions (51.1 MB)
# Submitting: kotlin_solutions/646.maximum-length-of-pair-chain.kt
# - Downloading maximum-length-of-pair-chain
#   ✔ Accepted
#   ✔ 206/206 cases passed (29 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 46.15 % of kotlin submissions (56.4 MB)
# Submitting: kotlin_solutions/647.palindromic-substrings.kt
# - Downloading palindromic-substrings
# [ERROR] http error [code=429]
# Submitting: kotlin_solutions/648.replace-words.kt
# - Downloading replace-words
#   ✔ Accepted
#   ✔ 130/130 cases passed (95 ms)
#   ✔ Your runtime beats 17.39 % of kotlin submissions
#   ✔ Your memory usage beats 78.26 % of kotlin submissions (58.6 MB)
# Submitting: kotlin_solutions/649.dota-2-senate.kt
# - Downloading dota2-senate
#   ✔ Accepted
#   ✔ 83/83 cases passed (19 ms)
#   ✔ Your runtime beats 85.96 % of kotlin submissions
#   ✔ Your memory usage beats 14.03 % of kotlin submissions (47.8 MB)
# Submitting: kotlin_solutions/650.2-keys-keyboard.kt
# - Downloading 2-keys-keyboard
#   ✔ Accepted
#   ✔ 126/126 cases passed (15 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 22.22 % of kotlin submissions (42.5 MB)
# Submitting: kotlin_solutions/652.find-duplicate-subtrees.kt
# - Downloading find-duplicate-subtrees
# [ERROR] http error [code=429]
# Submitting: kotlin_solutions/653.two-sum-iv-input-is-a-bst.kt
# - Downloading two-sum-iv-input-is-a-bst
#   ✔ Accepted
#   ✔ 423/423 cases passed (6 ms)
#   ✔ Your runtime beats 42.86 % of kotlin submissions
#   ✔ Your memory usage beats 91.84 % of kotlin submissions (47 MB)
# Submitting: kotlin_solutions/654.maximum-binary-tree.kt
# - Downloading maximum-binary-tree
#   ✔ Accepted
#   ✔ 107/107 cases passed (40 ms)
#   ✔ Your runtime beats 7.69 % of kotlin submissions
#   ✔ Your memory usage beats 7.69 % of kotlin submissions (53.6 MB)
# Submitting: kotlin_solutions/655.print-binary-tree.kt
# - Downloading print-binary-tree
#   ✔ Accepted
#   ✔ 73/73 cases passed (12 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (45.2 MB)
# Submitting: kotlin_solutions/657.robot-return-to-origin.kt
# - Downloading robot-return-to-origin
#   ✔ Accepted
#   ✔ 77/77 cases passed (22 ms)
#   ✔ Your runtime beats 5.77 % of kotlin submissions
#   ✔ Your memory usage beats 5.77 % of kotlin submissions (46.6 MB)
# Submitting: kotlin_solutions/658.find-k-closest-elements.kt
# - Downloading find-k-closest-elements
#   ✔ Accepted
#   ✔ 70/70 cases passed (42 ms)
#   ✔ Your runtime beats 29.88 % of kotlin submissions
#   ✔ Your memory usage beats 16.09 % of kotlin submissions (51.4 MB)
# Submitting: kotlin_solutions/659.split-array-into-consecutive-subsequences.kt
# - Downloading split-array-into-consecutive-subsequences
#   ✔ Accepted
#   ✔ 187/187 cases passed (40 ms)
#   ✔ Your runtime beats 75 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (51.9 MB)
# Submitting: kotlin_solutions/661.image-smoother.kt
# - Downloading image-smoother
#   ✔ Accepted
#   ✔ 203/203 cases passed (106 ms)
#   ✔ Your runtime beats 30 % of kotlin submissions
#   ✔ Your memory usage beats 10 % of kotlin submissions (67.8 MB)
# Submitting: kotlin_solutions/662.maximum-width-of-binary-tree.kt
# - Downloading maximum-width-of-binary-tree
#   ✔ Accepted
#   ✔ 117/117 cases passed (31 ms)
#   ✔ Your runtime beats 8.57 % of kotlin submissions
#   ✔ Your memory usage beats 11.43 % of kotlin submissions (48.2 MB)
# Submitting: kotlin_solutions/664.strange-printer.kt
# - Downloading strange-printer
#   ✔ Accepted
#   ✔ 200/200 cases passed (112 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (55.2 MB)
# Submitting: kotlin_solutions/665.non-decreasing-array.kt
# - Downloading non-decreasing-array
#   ✔ Accepted
#   ✔ 335/335 cases passed (32 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/667.beautiful-arrangement-ii.kt
# - Downloading beautiful-arrangement-ii
#   ✔ Accepted
#   ✔ 70/70 cases passed (1 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
# [WARN] Failed to get memory percentile.

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-02-14 18:25:05
