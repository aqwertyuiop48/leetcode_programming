# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME')
    user_cookie = userdata.get('LEETCODE_TOKEN')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME'] = user_name
    os.environ['LEETCODE_TOKEN'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME" "$LEETCODE_TOKEN" | leetcode user -c

# %%
# %%bash
#
#
# # top 100 answers
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v java_solutions/*.java | sed -n '401,500p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 7
# done
# Out:
# Submitting: java_solutions/980.unique-paths-iii.java
# - Downloading unique-paths-iii
#   ✔ Accepted
#   ✔ 39/39 cases passed (19 ms)
#   ✔ Your runtime beats 5.12 % of java submissions
#   ✔ Your memory usage beats 15.3 % of java submissions (43.4 MB)
# Submitting: java_solutions/982.triples-with-bitwise-and-equal-to-zero.java
# - Downloading triples-with-bitwise-and-equal-to-zero
#   ✔ Accepted
#   ✔ 28/28 cases passed (1745 ms)
#   ✔ Your runtime beats 5 % of java submissions
#   ✔ Your memory usage beats 91.67 % of java submissions (46.4 MB)
# Submitting: java_solutions/987.vertical-order-traversal-of-a-binary-tree.java
# - Downloading vertical-order-traversal-of-a-binary-tree
#   ✔ Accepted
#   ✔ 34/34 cases passed (4 ms)
#   ✔ Your runtime beats 59.98 % of java submissions
#   ✔ Your memory usage beats 94.62 % of java submissions (43.8 MB)
# Submitting: java_solutions/989.add-to-array-form-of-integer.java
# - Downloading add-to-array-form-of-integer
#   ✔ Accepted
#   ✔ 152/152 cases passed (102 ms)
#   ✔ Your runtime beats 6.42 % of java submissions
#   ✔ Your memory usage beats 6.22 % of java submissions (48.5 MB)
# Submitting: java_solutions/992.subarrays-with-k-different-integers.java
# - Downloading subarrays-with-k-different-integers
#   ✔ Accepted
#   ✔ 57/57 cases passed (13 ms)
#   ✔ Your runtime beats 92.99 % of java submissions
#   ✔ Your memory usage beats 90.56 % of java submissions (49 MB)
# Submitting: java_solutions/995.minimum-number-of-k-consecutive-bit-flips.java
# - Downloading minimum-number-of-k-consecutive-bit-flips
#   ✔ Accepted
#   ✔ 113/113 cases passed (13 ms)
#   ✔ Your runtime beats 21.06 % of java submissions
#   ✔ Your memory usage beats 43.62 % of java submissions (73.4 MB)
# Submitting: java_solutions/996.number-of-squareful-arrays.java
# - Downloading number-of-squareful-arrays
#   ✔ Accepted
#   ✔ 77/77 cases passed (4 ms)
#   ✔ Your runtime beats 9.24 % of java submissions
#   ✔ Your memory usage beats 32.01 % of java submissions (43.1 MB)
# Submitting: java_solutions/1000.minimum-cost-to-merge-stones.java
# - Downloading minimum-cost-to-merge-stones
#   ✔ Accepted
#   ✔ 84/84 cases passed (13 ms)
#   ✔ Your runtime beats 7.9 % of java submissions
#   ✔ Your memory usage beats 6.38 % of java submissions (45 MB)
# Submitting: java_solutions/1001.grid-illumination.java
# - Downloading grid-illumination
#   ✔ Accepted
#   ✔ 45/45 cases passed (101 ms)
#   ✔ Your runtime beats 13.33 % of java submissions
#   ✔ Your memory usage beats 44 % of java submissions (106.7 MB)
# Submitting: java_solutions/1002.find-common-characters.java
# - Downloading find-common-characters
#   ✔ Accepted
#   ✔ 88/88 cases passed (18 ms)
#   ✔ Your runtime beats 13.78 % of java submissions
#   ✔ Your memory usage beats 5.14 % of java submissions (52.5 MB)
# Submitting: java_solutions/1009.complement-of-base-10-integer.java
# - Downloading complement-of-base-10-integer
#   ✔ Accepted
#   ✔ 128/128 cases passed (5 ms)
#   ✔ Your runtime beats 2.06 % of java submissions
#   ✔ Your memory usage beats 7.61 % of java submissions (43.1 MB)
# Submitting: java_solutions/1012.numbers-with-repeated-digits.java
# - Downloading numbers-with-repeated-digits
#   ✔ Accepted
#   ✔ 130/130 cases passed (1 ms)
#   ✔ Your runtime beats 97.36 % of java submissions
#   ✔ Your memory usage beats 95.59 % of java submissions (42 MB)
# Submitting: java_solutions/1018.binary-prefix-divisible-by-5.java
# - Downloading binary-prefix-divisible-by-5
#   ✔ Accepted
#   ✔ 24/24 cases passed (5 ms)
#   ✔ Your runtime beats 2.3 % of java submissions
#   ✔ Your memory usage beats 5.82 % of java submissions (48 MB)
# Submitting: java_solutions/1025.divisor-game.java
# - Downloading divisor-game
#   ✔ Accepted
#   ✔ 40/40 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 59.29 % of java submissions (42.1 MB)
# Submitting: java_solutions/1028.recover-a-tree-from-preorder-traversal.java
# - Downloading recover-a-tree-from-preorder-traversal
#   ✔ Accepted
#   ✔ 105/105 cases passed (8 ms)
#   ✔ Your runtime beats 22.25 % of java submissions
#   ✔ Your memory usage beats 91.62 % of java submissions (46.3 MB)
# Submitting: java_solutions/1030.matrix-cells-in-distance-order.java
# - Downloading matrix-cells-in-distance-order
#   ✔ Accepted
#   ✔ 66/66 cases passed (29 ms)
#   ✔ Your runtime beats 8.57 % of java submissions
#   ✔ Your memory usage beats 5.78 % of java submissions (54.2 MB)
# Submitting: java_solutions/1032.stream-of-characters.java
# - Downloading stream-of-characters
#   ✔ Accepted
#   ✔ 20/20 cases passed (321 ms)
#   ✔ Your runtime beats 6.25 % of java submissions
#   ✔ Your memory usage beats 5.77 % of java submissions (278.2 MB)
# Submitting: java_solutions/1036.escape-a-large-maze.java
# - Downloading escape-a-large-maze
#   ✔ Accepted
#   ✔ 31/31 cases passed (158 ms)
#   ✔ Your runtime beats 61.04 % of java submissions
#   ✔ Your memory usage beats 48.05 % of java submissions (76.8 MB)
# Submitting: java_solutions/1037.valid-boomerang.java
# - Downloading valid-boomerang
#   ✔ Accepted
#   ✔ 206/206 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 20.64 % of java submissions (43.2 MB)
# Submitting: java_solutions/1044.longest-duplicate-substring.java
# - Downloading longest-duplicate-substring
#   ✔ Accepted
#   ✔ 69/69 cases passed (920 ms)
#   ✔ Your runtime beats 5.14 % of java submissions
#   ✔ Your memory usage beats 5.14 % of java submissions (261.4 MB)
# Submitting: java_solutions/1047.remove-all-adjacent-duplicates-in-string.java
# - Downloading remove-all-adjacent-duplicates-in-string
#   ✔ Accepted
#   ✔ 106/106 cases passed (17 ms)
#   ✔ Your runtime beats 71.92 % of java submissions
#   ✔ Your memory usage beats 84.06 % of java submissions (46.9 MB)
# Submitting: java_solutions/1051.height-checker.java
# - Downloading height-checker
#   ✔ Accepted
#   ✔ 81/81 cases passed (10 ms)
#   ✔ Your runtime beats 35.53 % of java submissions
#   ✔ Your memory usage beats 16.8 % of java submissions (43.7 MB)
# Submitting: java_solutions/1071.greatest-common-divisor-of-strings.java
# - Downloading greatest-common-divisor-of-strings
#   ✔ Accepted
#   ✔ 128/128 cases passed (2 ms)
#   ✔ Your runtime beats 16.44 % of java submissions
#   ✔ Your memory usage beats 30.75 % of java submissions (43.8 MB)
# Submitting: java_solutions/1074.number-of-submatrices-that-sum-to-target.java
# - Downloading number-of-submatrices-that-sum-to-target
#   ✔ Accepted
#   ✔ 40/40 cases passed (159 ms)
#   ✔ Your runtime beats 14.2 % of java submissions
#   ✔ Your memory usage beats 13.39 % of java submissions (47.5 MB)
# Submitting: java_solutions/1078.occurrences-after-bigram.java
# - Downloading occurrences-after-bigram
#   ✔ Accepted
#   ✔ 31/31 cases passed (5 ms)
#   ✔ Your runtime beats 0.7 % of java submissions
#   ✔ Your memory usage beats 22.27 % of java submissions (43.1 MB)
# Submitting: java_solutions/1089.duplicate-zeros.java
# - Downloading duplicate-zeros
#   ✔ Accepted
#   ✔ 33/33 cases passed (27 ms)
#   ✔ Your runtime beats 10.41 % of java submissions
#   ✔ Your memory usage beats 14.44 % of java submissions (48.2 MB)
# Submitting: java_solutions/1092.shortest-common-supersequence.java
# - Downloading shortest-common-supersequence
#   ✔ Accepted
#   ✔ 50/50 cases passed (33 ms)
#   ✔ Your runtime beats 5.78 % of java submissions
#   ✔ Your memory usage beats 17.65 % of java submissions (54.2 MB)
# Submitting: java_solutions/1095.find-in-mountain-array.java
# - Downloading find-in-mountain-array
#   ✔ Accepted
#   ✔ 80/80 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 47.38 % of java submissions (46.6 MB)
# Submitting: java_solutions/1096.brace-expansion-ii.java
# - Downloading brace-expansion-ii
#   ✔ Accepted
#   ✔ 115/115 cases passed (42 ms)
#   ✔ Your runtime beats 6.96 % of java submissions
#   ✔ Your memory usage beats 16.85 % of java submissions (52.9 MB)
# Submitting: java_solutions/1106.parsing-a-boolean-expression.java
# - Downloading parsing-a-boolean-expression
#   ✔ Accepted
#   ✔ 78/78 cases passed (12 ms)
#   ✔ Your runtime beats 53.58 % of java submissions
#   ✔ Your memory usage beats 80.98 % of java submissions (44.1 MB)
# Submitting: java_solutions/1114.print-in-order.java
# - Downloading print-in-order
#   ✔ Accepted
#   ✔ 36/36 cases passed (13 ms)
#   ✔ Your runtime beats 11.98 % of java submissions
#   ✔ Your memory usage beats 9.92 % of java submissions (44.7 MB)
# Submitting: java_solutions/1122.relative-sort-array.java
# - Downloading relative-sort-array
#   ✔ Accepted
#   ✔ 17/17 cases passed (10 ms)
#   ✔ Your runtime beats 7.73 % of java submissions
#   ✔ Your memory usage beats 8.61 % of java submissions (44.7 MB)
# Submitting: java_solutions/1125.smallest-sufficient-team.java
# - Downloading smallest-sufficient-team
#   ✔ Accepted
#   ✔ 38/38 cases passed (25 ms)
#   ✔ Your runtime beats 64.03 % of java submissions
#   ✔ Your memory usage beats 88.49 % of java submissions (44.5 MB)
# Submitting: java_solutions/1128.number-of-equivalent-domino-pairs.java
# - Downloading number-of-equivalent-domino-pairs
#   ✔ Accepted
#   ✔ 19/19 cases passed (15 ms)
#   ✔ Your runtime beats 48.41 % of java submissions
#   ✔ Your memory usage beats 8.25 % of java submissions (64.4 MB)
# Submitting: java_solutions/1137.n-th-tribonacci-number.java
# - Downloading n-th-tribonacci-number
#   ✔ Accepted
#   ✔ 38/38 cases passed (2 ms)
#   ✔ Your runtime beats 0.57 % of java submissions
#   ✔ Your memory usage beats 6.69 % of java submissions (42.4 MB)
# Submitting: java_solutions/1147.longest-chunked-palindrome-decomposition.java
# - Downloading longest-chunked-palindrome-decomposition
#   ✔ Accepted
#   ✔ 84/84 cases passed (3 ms)
#   ✔ Your runtime beats 47.53 % of java submissions
#   ✔ Your memory usage beats 84.57 % of java submissions (44.5 MB)
# Submitting: java_solutions/1157.online-majority-element-in-subarray.java
# - Downloading online-majority-element-in-subarray
#   ✔ Accepted
#   ✔ 37/37 cases passed (97 ms)
#   ✔ Your runtime beats 61.68 % of java submissions
#   ✔ Your memory usage beats 5.61 % of java submissions (119.4 MB)
# Submitting: java_solutions/1160.find-words-that-can-be-formed-by-characters.java
# - Downloading find-words-that-can-be-formed-by-characters
#   ✔ Accepted
#   ✔ 36/36 cases passed (96 ms)
#   ✔ Your runtime beats 5.11 % of java submissions
#   ✔ Your memory usage beats 8.15 % of java submissions (53.1 MB)
# Submitting: java_solutions/1163.last-substring-in-lexicographical-order.java
# - Downloading last-substring-in-lexicographical-order
#   ✔ Accepted
#   ✔ 36/36 cases passed (21 ms)
#   ✔ Your runtime beats 46.65 % of java submissions
#   ✔ Your memory usage beats 23.32 % of java submissions (49.6 MB)
# Submitting: java_solutions/1172.dinner-plate-stacks.java
# - Downloading dinner-plate-stacks
#   ✔ Accepted
#   ✔ 19/19 cases passed (123 ms)
#   ✔ Your runtime beats 14.95 % of java submissions
#   ✔ Your memory usage beats 66.85 % of java submissions (170.7 MB)
# Submitting: java_solutions/1178.number-of-valid-words-for-each-puzzle.java
# - Downloading number-of-valid-words-for-each-puzzle
#   ✔ Accepted
#   ✔ 11/11 cases passed (82 ms)
#   ✔ Your runtime beats 24.3 % of java submissions
#   ✔ Your memory usage beats 42.99 % of java submissions (79.9 MB)
# Submitting: java_solutions/1184.distance-between-bus-stops.java
# - Downloading distance-between-bus-stops
#   ✔ Accepted
#   ✔ 37/37 cases passed (2 ms)
#   ✔ Your runtime beats 4.37 % of java submissions
#   ✔ Your memory usage beats 12.01 % of java submissions (44.5 MB)
# Submitting: java_solutions/1185.day-of-the-week.java
# - Downloading day-of-the-week
#   ✔ Accepted
#   ✔ 44/44 cases passed (6 ms)
#   ✔ Your runtime beats 10.72 % of java submissions
#   ✔ Your memory usage beats 16.3 % of java submissions (42.9 MB)
# Submitting: java_solutions/1187.make-array-strictly-increasing.java
# - Downloading make-array-strictly-increasing
#   ✔ Accepted
#   ✔ 22/22 cases passed (42 ms)
#   ✔ Your runtime beats 90.76 % of java submissions
#   ✔ Your memory usage beats 50 % of java submissions (64.9 MB)
# Submitting: java_solutions/1189.maximum-number-of-balloons.java
# - Downloading maximum-number-of-balloons
# [ERROR] session expired, please login again [code=-1]
# Submitting: java_solutions/1192.critical-connections-in-a-network.java
# - Downloading critical-connections-in-a-network
#   ✔ Accepted
#   ✔ 18/18 cases passed (79 ms)
#   ✔ Your runtime beats 80.66 % of java submissions
#   ✔ Your memory usage beats 74.37 % of java submissions (207.4 MB)
# Submitting: java_solutions/1200.minimum-absolute-difference.java
# - Downloading minimum-absolute-difference
#   ✔ Accepted
#   ✔ 39/39 cases passed (58 ms)
#   ✔ Your runtime beats 5.89 % of java submissions
#   ✔ Your memory usage beats 6.25 % of java submissions (74 MB)
# Submitting: java_solutions/1203.sort-items-by-groups-respecting-dependencies.java
# - Downloading sort-items-by-groups-respecting-dependencies
#   ✔ Accepted
#   ✔ 18/18 cases passed (34 ms)
#   ✔ Your runtime beats 73.78 % of java submissions
#   ✔ Your memory usage beats 42.16 % of java submissions (75 MB)
# Submitting: java_solutions/1206.design-skiplist.java
# - Downloading design-skiplist
#   ✔ Accepted
#   ✔ 21/21 cases passed (12 ms)
#   ✔ Your runtime beats 99.38 % of java submissions
#   ✔ Your memory usage beats 66.67 % of java submissions (64.6 MB)
# Submitting: java_solutions/1207.unique-number-of-occurrences.java
# - Downloading unique-number-of-occurrences
#   ✔ Accepted
#   ✔ 72/72 cases passed (14 ms)
#   ✔ Your runtime beats 7.52 % of java submissions
#   ✔ Your memory usage beats 5.74 % of java submissions (50.4 MB)
# Submitting: java_solutions/1210.minimum-moves-to-reach-target-with-rotations.java
# - Downloading minimum-moves-to-reach-target-with-rotations
#   ✔ Accepted
#   ✔ 42/42 cases passed (33 ms)
#   ✔ Your runtime beats 23.68 % of java submissions
#   ✔ Your memory usage beats 15.79 % of java submissions (52.7 MB)
# Submitting: java_solutions/1217.minimum-cost-to-move-chips-to-the-same-position.java
# - Downloading minimum-cost-to-move-chips-to-the-same-position
#   ✘ Wrong Answer
#   ✘ 15/51 cases passed (N/A)
#   ✘ Testcase: [1,2,2,2,2]
#   ✘ Answer: 2
#   ✘ Expected Answer: 1
#   ✘ Stdout:
# Submitting: java_solutions/1220.count-vowels-permutation.java
# - Downloading count-vowels-permutation
#   ✔ Accepted
#   ✔ 64/64 cases passed (19 ms)
#   ✔ Your runtime beats 38.85 % of java submissions
#   ✔ Your memory usage beats 53.6 % of java submissions (42.4 MB)
# Submitting: java_solutions/1221.split-a-string-in-balanced-strings.java
# - Downloading split-a-string-in-balanced-strings
#   ✔ Accepted
#   ✔ 40/40 cases passed (4 ms)
#   ✔ Your runtime beats 1.64 % of java submissions
#   ✔ Your memory usage beats 47.7 % of java submissions (42.8 MB)
# Submitting: java_solutions/1223.dice-roll-simulation.java
# - Downloading dice-roll-simulation
#   ✔ Accepted
#   ✔ 32/32 cases passed (48 ms)
#   ✔ Your runtime beats 19.18 % of java submissions
#   ✔ Your memory usage beats 24.66 % of java submissions (51.9 MB)
# Submitting: java_solutions/1224.maximum-equal-frequency.java
# - Downloading maximum-equal-frequency
#   ✔ Accepted
#   ✔ 46/46 cases passed (26 ms)
#   ✔ Your runtime beats 76.76 % of java submissions
#   ✔ Your memory usage beats 99.3 % of java submissions (61.5 MB)
# Submitting: java_solutions/1232.check-if-it-is-a-straight-line.java
# - Downloading check-if-it-is-a-straight-line
#   ✔ Accepted
#   ✔ 82/82 cases passed (3 ms)
#   ✔ Your runtime beats 2.68 % of java submissions
#   ✔ Your memory usage beats 13.18 % of java submissions (45.4 MB)
# Submitting: java_solutions/1235.maximum-profit-in-job-scheduling.java
# - Downloading maximum-profit-in-job-scheduling
#   ✔ Accepted
#   ✔ 35/35 cases passed (49 ms)
#   ✔ Your runtime beats 31.73 % of java submissions
#   ✔ Your memory usage beats 60.49 % of java submissions (68.9 MB)
# Submitting: java_solutions/1240.tiling-a-rectangle-with-the-fewest-squares.java
# - Downloading tiling-a-rectangle-with-the-fewest-squares
#   ✔ Accepted
#   ✔ 38/38 cases passed (17 ms)
#   ✔ Your runtime beats 7.61 % of java submissions
#   ✔ Your memory usage beats 11.96 % of java submissions (43 MB)
# Submitting: java_solutions/1250.check-if-it-is-a-good-array.java
# - Downloading check-if-it-is-a-good-array
#   ✔ Accepted
#   ✔ 48/48 cases passed (10 ms)
#   ✔ Your runtime beats 2.26 % of java submissions
#   ✔ Your memory usage beats 41.89 % of java submissions (62.1 MB)
# Submitting: java_solutions/1252.cells-with-odd-values-in-a-matrix.java
# - Downloading cells-with-odd-values-in-a-matrix
#   ✔ Accepted
#   ✔ 45/45 cases passed (1111 ms)
#   ✔ Your runtime beats 2.27 % of java submissions
#   ✔ Your memory usage beats 6.55 % of java submissions (52.8 MB)
# Submitting: java_solutions/1255.maximum-score-words-formed-by-letters.java
# - Downloading maximum-score-words-formed-by-letters
#   ✔ Accepted
#   ✔ 53/53 cases passed (35 ms)
#   ✔ Your runtime beats 5.21 % of java submissions
#   ✔ Your memory usage beats 78.83 % of java submissions (43.3 MB)
# Submitting: java_solutions/1260.shift-2d-grid.java
# - Downloading shift-2d-grid
#   ✔ Accepted
#   ✔ 107/107 cases passed (13 ms)
#   ✔ Your runtime beats 8.39 % of java submissions
#   ✔ Your memory usage beats 7.55 % of java submissions (53.4 MB)
# Submitting: java_solutions/1263.minimum-moves-to-move-a-box-to-their-target-location.java
# - Downloading minimum-moves-to-move-a-box-to-their-target-location
#   ✔ Accepted
#   ✔ 30/30 cases passed (96 ms)
#   ✔ Your runtime beats 15.93 % of java submissions
#   ✔ Your memory usage beats 5.31 % of java submissions (59.8 MB)
# Submitting: java_solutions/1269.number-of-ways-to-stay-in-the-same-place-after-some-steps.java
# - Downloading number-of-ways-to-stay-in-the-same-place-after-some-steps
#   ✔ Accepted
#   ✔ 33/33 cases passed (11 ms)
#   ✔ Your runtime beats 44.02 % of java submissions
#   ✔ Your memory usage beats 92.34 % of java submissions (42.2 MB)
# Submitting: java_solutions/1278.palindrome-partitioning-iii.java
# - Downloading palindrome-partitioning-iii
#   ✔ Accepted
#   ✔ 33/33 cases passed (13 ms)
#   ✔ Your runtime beats 19.34 % of java submissions
#   ✔ Your memory usage beats 18.78 % of java submissions (43.4 MB)
# Submitting: java_solutions/1281.subtract-the-product-and-sum-of-digits-of-an-integer.java
# - Downloading subtract-the-product-and-sum-of-digits-of-an-integer
#   ✔ Accepted
#   ✔ 123/123 cases passed (5 ms)
#   ✔ Your runtime beats 0.36 % of java submissions
#   ✔ Your memory usage beats 15.2 % of java submissions (42.4 MB)
# Submitting: java_solutions/1284.minimum-number-of-flips-to-convert-binary-matrix-to-zero-matrix.java
# - Downloading minimum-number-of-flips-to-convert-binary-matrix-to-zero-matrix
#   ✔ Accepted
#   ✔ 26/26 cases passed (6 ms)
#   ✔ Your runtime beats 51.8 % of java submissions
#   ✔ Your memory usage beats 74.1 % of java submissions (42.9 MB)
# Submitting: java_solutions/1287.element-appearing-more-than-25-in-sorted-array.java
# - Downloading element-appearing-more-than-25-in-sorted-array
#   ✔ Accepted
#   ✔ 29/29 cases passed (4 ms)
#   ✔ Your runtime beats 33.4 % of java submissions
#   ✔ Your memory usage beats 34.35 % of java submissions (46.6 MB)
# Submitting: java_solutions/1289.minimum-falling-path-sum-ii.java
# - Downloading minimum-falling-path-sum-ii
#   ✔ Accepted
#   ✔ 19/19 cases passed (133 ms)
#   ✔ Your runtime beats 38.48 % of java submissions
#   ✔ Your memory usage beats 40.8 % of java submissions (54.3 MB)
# Submitting: java_solutions/1290.convert-binary-number-in-a-linked-list-to-integer.java
# - Downloading convert-binary-number-in-a-linked-list-to-integer
#   ✔ Accepted
#   ✔ 102/102 cases passed (3 ms)
#   ✔ Your runtime beats 5.46 % of java submissions
#   ✔ Your memory usage beats 40.56 % of java submissions (42.9 MB)
# Submitting: java_solutions/1293.shortest-path-in-a-grid-with-obstacles-elimination.java
# - Downloading shortest-path-in-a-grid-with-obstacles-elimination
#   ✔ Accepted
#   ✔ 55/55 cases passed (106 ms)
#   ✔ Your runtime beats 8.82 % of java submissions
#   ✔ Your memory usage beats 5.02 % of java submissions (276.2 MB)
# Submitting: java_solutions/1295.find-numbers-with-even-number-of-digits.java
# - Downloading find-numbers-with-even-number-of-digits
#   ✔ Accepted
#   ✔ 105/105 cases passed (4 ms)
#   ✔ Your runtime beats 1.26 % of java submissions
#   ✔ Your memory usage beats 8.9 % of java submissions (45.6 MB)
# Submitting: java_solutions/1298.maximum-candies-you-can-get-from-boxes.java
# - Downloading maximum-candies-you-can-get-from-boxes
#   ✔ Accepted
#   ✔ 44/44 cases passed (18 ms)
#   ✔ Your runtime beats 23.06 % of java submissions
#   ✔ Your memory usage beats 20.55 % of java submissions (66.5 MB)
# Submitting: java_solutions/1299.replace-elements-with-greatest-element-on-right-side.java
# - Downloading replace-elements-with-greatest-element-on-right-side
#   ✔ Accepted
#   ✔ 90/90 cases passed (17 ms)
#   ✔ Your runtime beats 26.8 % of java submissions
#   ✔ Your memory usage beats 16.04 % of java submissions (49.5 MB)
# Submitting: java_solutions/1301.number-of-paths-with-max-score.java
# - Downloading number-of-paths-with-max-score
#   ✔ Accepted
#   ✔ 25/25 cases passed (39 ms)
#   ✔ Your runtime beats 17.79 % of java submissions
#   ✔ Your memory usage beats 51.53 % of java submissions (45.2 MB)
# Submitting: java_solutions/1304.find-n-unique-integers-sum-up-to-zero.java
# - Downloading find-n-unique-integers-sum-up-to-zero
#   ✔ Accepted
#   ✔ 43/43 cases passed (3 ms)
#   ✔ Your runtime beats 2.18 % of java submissions
#   ✔ Your memory usage beats 36.38 % of java submissions (43.3 MB)
# Submitting: java_solutions/1307.verbal-arithmetic-puzzle.java
# - Downloading verbal-arithmetic-puzzle
#   ✔ Accepted
#   ✔ 34/34 cases passed (17 ms)
#   ✔ Your runtime beats 77.78 % of java submissions
#   ✔ Your memory usage beats 55.56 % of java submissions (44.3 MB)
# Submitting: java_solutions/1309.decrypt-string-from-alphabet-to-integer-mapping.java
# - Downloading decrypt-string-from-alphabet-to-integer-mapping
#   ✔ Accepted
#   ✔ 41/41 cases passed (10 ms)
#   ✔ Your runtime beats 5.32 % of java submissions
#   ✔ Your memory usage beats 5.2 % of java submissions (44.5 MB)
# Submitting: java_solutions/1312.minimum-insertion-steps-to-make-a-string-palindrome.java
# - Downloading minimum-insertion-steps-to-make-a-string-palindrome
#   ✔ Accepted
#   ✔ 58/58 cases passed (41 ms)
#   ✔ Your runtime beats 9.79 % of java submissions
#   ✔ Your memory usage beats 34.75 % of java submissions (47.6 MB)
# Submitting: java_solutions/1313.decompress-run-length-encoded-list.java
# - Downloading decompress-run-length-encoded-list
#   ✔ Accepted
#   ✔ 53/53 cases passed (11 ms)
#   ✔ Your runtime beats 5.36 % of java submissions
#   ✔ Your memory usage beats 42 % of java submissions (46.6 MB)
# Submitting: java_solutions/1316.distinct-echo-substrings.java
# - Downloading distinct-echo-substrings
#   ✔ Accepted
#   ✔ 40/40 cases passed (1428 ms)
#   ✔ Your runtime beats 44.92 % of java submissions
#   ✔ Your memory usage beats 52.34 % of java submissions (49.2 MB)
# Submitting: java_solutions/1317.convert-integer-to-the-sum-of-two-no-zero-integers.java
# - Downloading convert-integer-to-the-sum-of-two-no-zero-integers
#   ✔ Accepted
#   ✔ 210/210 cases passed (6 ms)
#   ✔ Your runtime beats 6.08 % of java submissions
#   ✔ Your memory usage beats 8.77 % of java submissions (43.2 MB)
# Submitting: java_solutions/1320.minimum-distance-to-type-a-word-using-two-fingers.java
# - Downloading minimum-distance-to-type-a-word-using-two-fingers
#   ✔ Accepted
#   ✔ 55/55 cases passed (86 ms)
#   ✔ Your runtime beats 5.11 % of java submissions
#   ✔ Your memory usage beats 21.34 % of java submissions (47.5 MB)
# Submitting: java_solutions/1323.maximum-69-number.java
# - Downloading maximum-69-number
#   ✔ Accepted
#   ✔ 153/153 cases passed (3 ms)
#   ✔ Your runtime beats 12.4 % of java submissions
#   ✔ Your memory usage beats 33.05 % of java submissions (42.3 MB)
# Submitting: java_solutions/1326.minimum-number-of-taps-to-open-to-water-a-garden.java
# - Downloading minimum-number-of-taps-to-open-to-water-a-garden
#   ✔ Accepted
#   ✔ 42/42 cases passed (8 ms)
#   ✔ Your runtime beats 27.81 % of java submissions
#   ✔ Your memory usage beats 44.53 % of java submissions (46.8 MB)
# Submitting: java_solutions/1330.reverse-subarray-to-maximize-array-value.java
# - Downloading reverse-subarray-to-maximize-array-value
#   ✔ Accepted
#   ✔ 28/28 cases passed (27 ms)
#   ✔ Your runtime beats 5.95 % of java submissions
#   ✔ Your memory usage beats 53.57 % of java submissions (51 MB)
# Submitting: java_solutions/1331.rank-transform-of-an-array.java
# - Downloading rank-transform-of-an-array
#   ✔ Accepted
#   ✔ 43/43 cases passed (53 ms)
#   ✔ Your runtime beats 13.19 % of java submissions
#   ✔ Your memory usage beats 5.87 % of java submissions (88.4 MB)
# Submitting: java_solutions/1335.minimum-difficulty-of-a-job-schedule.java
# - Downloading minimum-difficulty-of-a-job-schedule
#   ✔ Accepted
#   ✔ 34/34 cases passed (23 ms)
#   ✔ Your runtime beats 40.56 % of java submissions
#   ✔ Your memory usage beats 84.52 % of java submissions (43.2 MB)
# Submitting: java_solutions/1337.the-k-weakest-rows-in-a-matrix.java
# - Downloading the-k-weakest-rows-in-a-matrix
#   ✔ Accepted
#   ✔ 52/52 cases passed (12 ms)
#   ✔ Your runtime beats 5.36 % of java submissions
#   ✔ Your memory usage beats 6.29 % of java submissions (53.3 MB)
# Submitting: java_solutions/1340.jump-game-v.java
# - Downloading jump-game-v
#   ✔ Accepted
#   ✔ 127/127 cases passed (37 ms)
#   ✔ Your runtime beats 8.99 % of java submissions
#   ✔ Your memory usage beats 7.91 % of java submissions (47.2 MB)
# Submitting: java_solutions/1342.number-of-steps-to-reduce-a-number-to-zero.java
# - Downloading number-of-steps-to-reduce-a-number-to-zero
#   ✔ Accepted
#   ✔ 204/204 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 23.42 % of java submissions (42.3 MB)
# Submitting: java_solutions/1345.jump-game-iv.java
# - Downloading jump-game-iv
#   ✔ Accepted
#   ✔ 33/33 cases passed (79 ms)
#   ✔ Your runtime beats 14.51 % of java submissions
#   ✔ Your memory usage beats 100 % of java submissions (65.5 MB)
# Submitting: java_solutions/1346.check-if-n-and-its-double-exist.java
# - Downloading check-if-n-and-its-double-exist
#   ✔ Accepted
#   ✔ 113/113 cases passed (12 ms)
#   ✔ Your runtime beats 6.42 % of java submissions
#   ✔ Your memory usage beats 22.68 % of java submissions (45 MB)
# Submitting: java_solutions/1349.maximum-students-taking-exam.java
# - Downloading maximum-students-taking-exam
#   ✔ Accepted
#   ✔ 57/57 cases passed (8 ms)
#   ✔ Your runtime beats 27.81 % of java submissions
#   ✔ Your memory usage beats 33.73 % of java submissions (43.3 MB)
# Submitting: java_solutions/1351.count-negative-numbers-in-a-sorted-matrix.java
# - Downloading count-negative-numbers-in-a-sorted-matrix
#   ✔ Accepted
#   ✔ 44/44 cases passed (4 ms)
#   ✔ Your runtime beats 0.97 % of java submissions
#   ✔ Your memory usage beats 52.14 % of java submissions (47 MB)
# Submitting: java_solutions/1354.construct-target-array-with-multiple-sums.java
# - Downloading construct-target-array-with-multiple-sums
#   ✔ Accepted
#   ✔ 72/72 cases passed (15 ms)
#   ✔ Your runtime beats 6.87 % of java submissions
#   ✔ Your memory usage beats 98.94 % of java submissions (53.4 MB)
# Submitting: java_solutions/1356.sort-integers-by-the-number-of-1-bits.java
# - Downloading sort-integers-by-the-number-of-1-bits
#   ✔ Accepted
#   ✔ 77/77 cases passed (19 ms)
#   ✔ Your runtime beats 11.11 % of java submissions
#   ✔ Your memory usage beats 5.14 % of java submissions (52.7 MB)
# Submitting: java_solutions/1359.count-all-valid-pickup-and-delivery-options.java
# - Downloading count-all-valid-pickup-and-delivery-options
#   ✔ Accepted
#   ✔ 36/36 cases passed (1 ms)
#   ✔ Your runtime beats 16.99 % of java submissions
#   ✔ Your memory usage beats 58.82 % of java submissions (42 MB)
# Submitting: java_solutions/1363.largest-multiple-of-three.java
# - Downloading largest-multiple-of-three
#   ✔ Accepted
#   ✔ 45/45 cases passed (9 ms)
#   ✔ Your runtime beats 40.91 % of java submissions
#   ✔ Your memory usage beats 21.82 % of java submissions (47.5 MB)

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-04-14 10:44:08
