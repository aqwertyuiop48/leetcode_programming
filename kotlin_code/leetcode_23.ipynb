# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME_3')
    user_cookie = userdata.get('LEETCODE_TOKEN_3')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME_3'] = user_name
    os.environ['LEETCODE_TOKEN_3'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME_3" "$LEETCODE_TOKEN_3" | leetcode user -c

# %%
# %%bash
#
# # top 200-300 answers (next batch)
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v kotlin_solutions_1/*.kt | sed -n '1401,1500p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 7
# done
# Out:
# Submitting: kotlin_solutions_1/2967.minimum-cost-to-make-array-equalindromic.kt
# - Downloading minimum-cost-to-make-array-equalindromic
#   ✔ Accepted
#   ✔ 650/650 cases passed (104 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (68.4 MB)
# Submitting: kotlin_solutions_1/2968.apply-operations-to-maximize-frequency-score.kt
# - Downloading apply-operations-to-maximize-frequency-score
#   ✔ Accepted
#   ✔ 774/774 cases passed (261 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2970.count-the-number-of-incremovable-subarrays-i.kt
# - Downloading count-the-number-of-incremovable-subarrays-i
#   ✔ Accepted
#   ✔ 615/615 cases passed (134 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2971.find-polygon-with-the-largest-perimeter.kt
# - Downloading find-polygon-with-the-largest-perimeter
#   ✔ Accepted
#   ✔ 980/980 cases passed (334 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2972.count-the-number-of-incremovable-subarrays-ii.kt
# - Downloading count-the-number-of-incremovable-subarrays-ii
#   ✔ Accepted
#   ✔ 840/840 cases passed (69 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (76.5 MB)
# Submitting: kotlin_solutions_1/2973.find-number-of-coins-to-place-in-tree-nodes.kt
# - Downloading find-number-of-coins-to-place-in-tree-nodes
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 104: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 2: Char 104: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 251: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 251: ERROR: Not enough information to infer type argument for 'R'.
# Line 2: Char 729: ERROR: Unresolved reference 'callRecursive'.
# Line 2: Char 752: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 752: ERROR: Not enough information to infer type argument for 'R'.
# Line 2: Char 756: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 756: WARNING: Parameter 'it: <ERROR TYPE REF: Cannot infer argument for type parameter T>' is never used, could be renamed to '_'.
# Line 38: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2974.minimum-number-game.kt
# - Downloading minimum-number-game
#   ✔ Accepted
#   ✔ 804/804 cases passed (20 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (49 MB)
# Submitting: kotlin_solutions_1/2975.maximum-square-area-by-removing-fences-from-a-field.kt
# - Downloading maximum-square-area-by-removing-fences-from-a-field
#   ✔ Accepted
#   ✔ 648/648 cases passed (669 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (104.8 MB)
# Submitting: kotlin_solutions_1/2976.minimum-cost-to-convert-string-i.kt
# - Downloading minimum-cost-to-convert-string-i
#   ✔ Accepted
#   ✔ 582/582 cases passed (64 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/2977.minimum-cost-to-convert-string-ii.kt
# - Downloading minimum-cost-to-convert-string-ii
#   ✔ Accepted
#   ✔ 647/647 cases passed (592 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (76.6 MB)
# Submitting: kotlin_solutions_1/2980.check-if-bitwise-or-has-trailing-zeros.kt
# - Downloading check-if-bitwise-or-has-trailing-zeros
#   ✔ Accepted
#   ✔ 916/916 cases passed (1 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 60 % of kotlin submissions (45.7 MB)
# Submitting: kotlin_solutions_1/2981.find-longest-special-substring-that-occurs-thrice-i.kt
# - Downloading find-longest-special-substring-that-occurs-thrice-i
#   ✔ Accepted
#   ✔ 812/812 cases passed (47 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (51.9 MB)
# Submitting: kotlin_solutions_1/2982.find-longest-special-substring-that-occurs-thrice-ii.kt
# - Downloading find-longest-special-substring-that-occurs-thrice-ii
#   ✔ Accepted
#   ✔ 906/906 cases passed (45 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (55.7 MB)
# Submitting: kotlin_solutions_1/2983.palindrome-rearrangement-queries.kt
# - Downloading palindrome-rearrangement-queries
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 7: Char 193: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 7: Char 193: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 7: Char 351: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 7: Char 392: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 7: Char 428: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 7: Char 479: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 7: Char 555: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 43: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2996.smallest-missing-integer-greater-than-sequential-prefix-sum.kt
# - Downloading smallest-missing-integer-greater-than-sequential-prefix-sum
#   ✔ Accepted
#   ✔ 616/616 cases passed (32 ms)
#   ✔ Your runtime beats 6.02 % of kotlin submissions
#   ✔ Your memory usage beats 15.47 % of kotlin submissions (46.9 MB)
# Submitting: kotlin_solutions_1/2997.minimum-number-of-operations-to-make-array-xor-equal-to-k.kt
# - Downloading minimum-number-of-operations-to-make-array-xor-equal-to-k
#   ✔ Accepted
#   ✔ 684/684 cases passed (431 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (64.4 MB)
# Submitting: kotlin_solutions_1/2998.minimum-number-of-operations-to-make-x-and-y-equal.kt
# - Downloading minimum-number-of-operations-to-make-x-and-y-equal
#   ✔ Accepted
#   ✔ 949/949 cases passed (56 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (48.7 MB)
# Submitting: kotlin_solutions_1/2999.count-the-number-of-powerful-integers.kt
# - Downloading count-the-number-of-powerful-integers
#   ✔ Accepted
#   ✔ 933/933 cases passed (18 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (45.5 MB)
# Submitting: kotlin_solutions_1/3001.minimum-moves-to-capture-the-queen.kt
# - Downloading minimum-moves-to-capture-the-queen
#   ✔ Accepted
#   ✔ 744/744 cases passed (1 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (40.9 MB)
# Submitting: kotlin_solutions_1/3002.maximum-size-of-a-set-after-removals.kt
# - Downloading maximum-size-of-a-set-after-removals
#   ✔ Accepted
#   ✔ 970/970 cases passed (69 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (67.5 MB)
# Submitting: kotlin_solutions_1/3003.maximize-the-number-of-partitions-after-operations.kt
# - Downloading maximize-the-number-of-partitions-after-operations
#   ✔ Accepted
#   ✔ 278/278 cases passed (464 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (107.9 MB)
# Submitting: kotlin_solutions_1/3007.maximum-number-that-sum-of-the-prices-is-less-than-or-equal-to-k.kt
# - Downloading maximum-number-that-sum-of-the-prices-is-less-than-or-equal-to-k
#   ✔ Accepted
#   ✔ 932/932 cases passed (161 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3008.find-beautiful-indices-in-the-given-array-ii.kt
# - Downloading find-beautiful-indices-in-the-given-array-ii
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 7: Char 774: ERROR: Syntax error: Expecting an expression.
#   ✘ Error: Line 7: Char 774: ERROR: Syntax error: Expecting an expression.
# Line 7: Char 774: ERROR: Syntax error: Unexpected tokens (use ';' to separate expressions on the same line).
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/3010.divide-an-array-into-subarrays-with-minimum-cost-i.kt
# - Downloading divide-an-array-into-subarrays-with-minimum-cost-i
#   ✔ Accepted
#   ✔ 988/988 cases passed (29 ms)
#   ✔ Your runtime beats 8.33 % of kotlin submissions
#   ✔ Your memory usage beats 8.33 % of kotlin submissions (48.5 MB)
# Submitting: kotlin_solutions_1/3011.find-if-array-can-be-sorted.kt
# - Downloading find-if-array-can-be-sorted
#   ✔ Accepted
#   ✔ 999/999 cases passed (15 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (47.4 MB)
# Submitting: kotlin_solutions_1/3012.minimize-length-of-array-using-operations.kt
# - Downloading minimize-length-of-array-using-operations
#   ✔ Accepted
#   ✔ 523/523 cases passed (16 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (69.3 MB)
# Submitting: kotlin_solutions_1/3013.divide-an-array-into-subarrays-with-minimum-cost-ii.kt
# - Downloading divide-an-array-into-subarrays-with-minimum-cost-ii
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 7: Char 481: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
#   ✘ Error: Line 7: Char 481: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 7: Char 529: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 7: Char 578: WARNING: Parameter 'it: Int?' is never used, could be renamed to '_'.
# Line 7: Char 595: WARNING: Parameter 'it: Int?' is never used, could be renamed to '_'.
# Line 7: Char 616: WARNING: Parameter 'it: Int?' is never used, could be renamed to '_'.
# Line 7: Char 642: WARNING: Parameter 'it: Int?' is never used, could be renamed to '_'.
# Line 7: Char 695: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 7: Char 756: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 7: Char 808: WARNING: Parameter 'it: Int?' is never used, could be renamed to '_'.
# Line 7: Char 825: WARNING: Parameter 'it: Int?' is never used, could be renamed to '_'.
# Line 7: Char 850: WARNING: Parameter 'it: Int?' is never used, could be renamed to '_'.
# Line 7: Char 867: WARNING: Parameter 'it: Int?' is never used, could be renamed to '_'.
# Line 7: Char 980: WARNING: Parameter 'it: Int?' is never used, could be renamed to '_'.
# Line 7: Char 997: WARNING: Parameter 'it: Int?' is never used, could be renamed to '_'.
# Line 7: Char 1038: WARNING: Parameter 'it: Int?' is never used, could be renamed to '_'.
# Line 7: Char 1144: WARNING: Parameter 'it: Int?' is never used, could be renamed to '_'.
# Line 7: Char 1161: WARNING: Parameter 'it: Int?' is never used, could be renamed to '_'.
# Line 7: Char 1202: WARNING: Parameter 'it: Int?' is never used, could be renamed to '_'.
# Line 45: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/3014.minimum-number-of-pushes-to-type-word-i.kt
# - Downloading minimum-number-of-pushes-to-type-word-i
#   ✔ Accepted
#   ✔ 500/500 cases passed (10 ms)
#   ✔ Your runtime beats 25.66 % of kotlin submissions
#   ✔ Your memory usage beats 31.56 % of kotlin submissions (42.7 MB)
# Submitting: kotlin_solutions_1/3015.count-the-number-of-houses-at-a-certain-distance-i.kt
# - Downloading count-the-number-of-houses-at-a-certain-distance-i
#   ✔ Accepted
#   ✔ 880/880 cases passed (14 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (45.3 MB)
# Submitting: kotlin_solutions_1/3016.minimum-number-of-pushes-to-type-word-ii.kt
# - Downloading minimum-number-of-pushes-to-type-word-ii
#   ✔ Accepted
#   ✔ 877/877 cases passed (81 ms)
#   ✔ Your runtime beats 19.27 % of kotlin submissions
#   ✔ Your memory usage beats 17.19 % of kotlin submissions (51 MB)
# Submitting: kotlin_solutions_1/3017.count-the-number-of-houses-at-a-certain-distance-ii.kt
# - Downloading count-the-number-of-houses-at-a-certain-distance-ii
#   ✘ Wrong Answer
#   ✘ 0/549 cases passed (N/A)
#   ✘ Testcase: 3
# 1
# 3
#   ✘ Answer: [0,0,0]
#   ✘ Expected Answer: [6,0,0]
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/3020.find-the-maximum-number-of-elements-in-subset.kt
# - Downloading find-the-maximum-number-of-elements-in-subset
#   ✘ Runtime Error
#   ✘ 43/725 cases passed (N/A)
#   ✘ Error: Line 2: Exception in thread "main" java.lang.IndexOutOfBoundsException: Sequence doesn't contain element at index 3.
#   ✘ Error: Line 2: Exception in thread "main" java.lang.IndexOutOfBoundsException: Sequence doesn't contain element at index 3.
#   ✘ Testcase: [18,18,324,324,104976,104976]
#   ✘ Answer:
#   ✘ Expected Answer: 5
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/3021.alice-and-bob-playing-flower-game.kt
# - Downloading alice-and-bob-playing-flower-game
#   ✔ Accepted
#   ✔ 537/537 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (40.9 MB)
# Submitting: kotlin_solutions_1/3022.minimize-or-of-remaining-elements-using-operations.kt
# - Downloading minimize-or-of-remaining-elements-using-operations
#   ✘ Wrong Answer
#   ✘ 548/822 cases passed (N/A)
#   ✘ Testcase: [39,62,35,11,28,32]
# 3
#   ✘ Answer: 34
#   ✘ Expected Answer: 38
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/3025.find-the-number-of-ways-to-place-people-i.kt
# - Downloading find-the-number-of-ways-to-place-people-i
#   ✔ Accepted
#   ✔ 955/955 cases passed (40 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (55.4 MB)
# Submitting: kotlin_solutions_1/3026.maximum-good-subarray-sum.kt
# - Downloading maximum-good-subarray-sum
#   ✔ Accepted
#   ✔ 783/783 cases passed (185 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (69 MB)
# Submitting: kotlin_solutions_1/3027.find-the-number-of-ways-to-place-people-ii.kt
# - Downloading find-the-number-of-ways-to-place-people-ii
#   ✔ Accepted
#   ✔ 551/551 cases passed (815 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (66.1 MB)
# Submitting: kotlin_solutions_1/3028.ant-on-the-boundary.kt
# - Downloading ant-on-the-boundary
#   ✔ Accepted
#   ✔ 641/641 cases passed (118 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 16.67 % of kotlin submissions (42 MB)
# Submitting: kotlin_solutions_1/3029.minimum-time-to-revert-word-to-initial-state-i.kt
# - Downloading minimum-time-to-revert-word-to-initial-state-i
#   ✔ Accepted
#   ✔ 769/769 cases passed (15 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (44.1 MB)
# Submitting: kotlin_solutions_1/3030.find-the-grid-of-region-average.kt
# - Downloading find-the-grid-of-region-average
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 7: Char 110: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 7: Char 110: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 7: Char 170: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 7: Char 737: ERROR: 'infix' modifier is required on 'FirNamedFunctionSymbol kotlin/run'.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/3031.minimum-time-to-revert-word-to-initial-state-ii.kt
# - Downloading minimum-time-to-revert-word-to-initial-state-ii
#   ✔ Accepted
#   ✔ 911/911 cases passed (136 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (62.8 MB)
# Submitting: kotlin_solutions_1/3034.number-of-subarrays-that-match-a-pattern-i.kt
# - Downloading number-of-subarrays-that-match-a-pattern-i
#   ✔ Accepted
#   ✔ 792/792 cases passed (23 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
#   ✔ Your memory usage beats 20 % of kotlin submissions (49.2 MB)
# Submitting: kotlin_solutions_1/3035.maximum-palindromes-after-operations.kt
# - Downloading maximum-palindromes-after-operations
#   ✔ Accepted
#   ✔ 507/507 cases passed (83 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (51 MB)
# Submitting: kotlin_solutions_1/3036.number-of-subarrays-that-match-a-pattern-ii.kt
# - Downloading number-of-subarrays-that-match-a-pattern-ii
#   ✔ Accepted
#   ✔ 792/792 cases passed (147 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (207 MB)
# Submitting: kotlin_solutions_1/3038.maximum-number-of-operations-with-the-same-score-i.kt
# - Downloading maximum-number-of-operations-with-the-same-score-i
#   ✔ Accepted
#   ✔ 559/559 cases passed (6 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3039.apply-operations-to-make-string-empty.kt
# - Downloading apply-operations-to-make-string-empty
#   ✔ Accepted
#   ✔ 697/697 cases passed (181 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3040.maximum-number-of-operations-with-the-same-score-ii.kt
# - Downloading maximum-number-of-operations-with-the-same-score-ii
#   ✔ Accepted
#   ✔ 549/549 cases passed (465 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (100.6 MB)
# Submitting: kotlin_solutions_1/3041.maximize-consecutive-elements-in-an-array-after-modification.kt
# - Downloading maximize-consecutive-elements-in-an-array-after-modification
#   ✔ Accepted
#   ✔ 668/668 cases passed (338 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (93.8 MB)
# Submitting: kotlin_solutions_1/3042.count-prefix-and-suffix-pairs-i.kt
# - Downloading count-prefix-and-suffix-pairs-i
#   ✔ Accepted
#   ✔ 594/594 cases passed (25 ms)
#   ✔ Your runtime beats 10 % of kotlin submissions
#   ✔ Your memory usage beats 10 % of kotlin submissions (47.7 MB)
# Submitting: kotlin_solutions_1/3043.find-the-length-of-the-longest-common-prefix.kt
# - Downloading find-the-length-of-the-longest-common-prefix
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 7: Char 86: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
#   ✘ Error: Line 7: Char 86: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 7: Char 96: ERROR: Argument type mismatch: actual type is 'kotlin.sequences.Sequence<kotlin.Int>', but 'kotlin.collections.Iterable<R>' was expected.
# Line 7: Char 181: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 7: Char 181: ERROR: Not enough information to infer type argument for 'T'.
# Line 7: Char 189: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 7: Char 189: ERROR: Not enough information to infer type argument for 'T'.
# Line 7: Char 195: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/3044.most-frequent-prime.kt
# - Downloading most-frequent-prime
#   ✔ Accepted
#   ✔ 974/974 cases passed (111 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (52.8 MB)
# Submitting: kotlin_solutions_1/3045.count-prefix-and-suffix-pairs-ii.kt
# - Downloading count-prefix-and-suffix-pairs-ii
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 7: Char 75: WARNING: Type argument for reified type parameter 'T' was inferred to the intersection of ['kotlin.Cloneable' & 'java.io.Serializable']. Reification of an intersection type results in the common supertype being used. This may lead to subtle issues and an explicit type argument is encouraged. This will become an error in a future release.
#   ✘ Error: Line 7: Char 75: WARNING: Type argument for reified type parameter 'T' was inferred to the intersection of ['kotlin.Cloneable' & 'java.io.Serializable']. Reification of an intersection type results in the common supertype being used. This may lead to subtle issues and an explicit type argument is encouraged. This will become an error in a future release.
# Line 7: Char 217: WARNING: Unchecked cast of 'it(kotlin.Cloneable & java.io.Serializable)' to 'java.util.HashMap<kotlin.Int, kotlin.Array<kotlin.Any>>'.
# Line 7: Char 361: ERROR: Argument type mismatch: actual type is 'kotlin.Pair<kotlin.Array<kotlin.Any>, kotlin.Long>', but 'kotlin.Pair<kotlin.Array<it(kotlin.Cloneable & java.io.Serializable)>, kotlin.Long>' was expected.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/3046.split-the-array.kt
# - Downloading split-the-array
#   ✔ Accepted
#   ✔ 715/715 cases passed (5 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (45.5 MB)
# Submitting: kotlin_solutions_1/3047.find-the-largest-area-of-square-inside-two-rectangles.kt
# - Downloading find-the-largest-area-of-square-inside-two-rectangles
#   ✔ Accepted
#   ✔ 661/661 cases passed (288 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/3048.earliest-second-to-mark-indices-i.kt
# - Downloading earliest-second-to-mark-indices-i
#   ✔ Accepted
#   ✔ 570/570 cases passed (285 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3049.earliest-second-to-mark-indices-ii.kt
# - Downloading earliest-second-to-mark-indices-ii
#   ✔ Accepted
#   ✔ 510/510 cases passed (26 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (48.7 MB)
# Submitting: kotlin_solutions_1/3065.minimum-operations-to-exceed-threshold-value-i.kt
# - Downloading minimum-operations-to-exceed-threshold-value-i
#   ✔ Accepted
#   ✔ 724/724 cases passed (1 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 80 % of kotlin submissions (43 MB)
# Submitting: kotlin_solutions_1/3066.minimum-operations-to-exceed-threshold-value-ii.kt
# - Downloading minimum-operations-to-exceed-threshold-value-ii
#   ✔ Accepted
#   ✔ 677/677 cases passed (110 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3067.count-pairs-of-connectable-servers-in-a-weighted-tree-network.kt
# - Downloading count-pairs-of-connectable-servers-in-a-weighted-tree-network
#   ✔ Accepted
#   ✔ 716/716 cases passed (575 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (72.4 MB)
# Submitting: kotlin_solutions_1/3068.find-the-maximum-sum-of-node-values.kt
# - Downloading find-the-maximum-sum-of-node-values
#   ✔ Accepted
#   ✔ 718/718 cases passed (12 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (76 MB)
# Submitting: kotlin_solutions_1/3069.distribute-elements-into-two-arrays-i.kt
# - Downloading distribute-elements-into-two-arrays-i
#   ✔ Accepted
#   ✔ 622/622 cases passed (24 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3070.count-submatrices-with-top-left-element-and-sum-less-than-k.kt
# - Downloading count-submatrices-with-top-left-element-and-sum-less-than-k
#   ✘ Time Limit Exceeded
#   ✘ 858/859 cases passed (N/A)
#   ✘ Testcase: [[94,51,96,59,93,2,96,5,83,77,99,94,51,28,33,13,83,55,97,57,21,69,87,46,58,71,19,75,76,37,10,90,92,72,40,62,1,24,32,12,35,45,25,4,35,89,28,39,14,15,85,72,8,53,11,95,63,57,85,69,22,30,26,86,19,75,6,79,6,89,79,63,0,23,64,97,3,4,73,97,32,83,31,28,72,100,65,75,54,64,94,79,83,100,64,45,11,7,43,75,20,55,98,43,46,26,32,0,43,95,35,5,19,45,62,17,10,38,48,84,8,47,71,17,35,34,89,34,91,7,35,100,21,68,58,11,61,15,11,95,92,0,19,32,60,33,93,84,61,68,31,24,69,76,34,90,90,20,19,58,7,29,30,44,94,4,15,98,91,52,19,40,30,68,76,17,84,1,13,26,88,72,58,60,86,50,48,84,100,13,21,88,55,93,67,56,26,92,74,44,68,65,63,8,84,57,98,71,27,38,54,29,75,92,19,16,60,34,14,46,78,30,85,58,71,61,54,72,29,88,34,50,94,88,34,64,58,93,22,67,26,34,73,58,0,78,32,30,5,13,24,71,62,96,73,34,68,68,69,81,88,39,26,1,65,24,46,94,42,87,85,11,99,50,70,100,20,59,9,62,9,88,68,85,59,99,28,16,76,12,31,99,60,74,57,9,89,0,77,5,83,46,12,49,38,12,78,63,19,85,23,16,38,2,60,88,19,99,53,69,2,57,56,69,65,94,70,11,41,96,9,34,88,50,37,18,57,2,56,5,94,27,68,14,73,49,12,58,4,24,37,42,56,75,16,95,65,85,26,65,70,61,99,90,33,6,14,26,26,78,17,47,91,78,18,6,81,36,46,25,37,64,84,53,22,31,55,66,68,54,27,36,40,17,66,81,35,67,34,48,12,37,95,81,57,54,9,67,11,17,28,85,45,16,11,89,16,100,31,36,87,55,89,22,65,99,93,93,100,63,58,96,85,97,96,74,99,85,70,90,69,91,71,46,74,56,16,35,80,88,20,15,84,23,57,66,49,100,54,86,3,97,89,67,6,60,80,7,8,6,55,14,28,67,43,88,83,70,69,92,7,19,68,100,29,0,49,36,66,59,56,91,15,68,54,51,7,93,69,87,28,5,46,57,3,46,8,51,3,24,9,55,68,86,76,78,93,49,32,77,61,73,28,62,49,98,13,87,92,82,31,37,58,33,19,78,61,10,24,0,93,73,24,49,44,67,2,42,82,32,17,80,81,18,6,87,36,93,21,80,56,61,44,58,34,7,81,88,42,53,68,26,21,62,26,8,35,81,45,50,46,52,21,82,30,60,96,88,21,91,5,12,33,69,4,24,88,92,15,37,33,6,63,9,43,7,5,7,91,45,75,81,12,82,96,31,76,59,90,48,7,79,85,11,4,7,84,60,8,67,44,53,73,47,79,66,14,31,70,58,2,24,98,28,76,28,34,51,32,92,3,18,93,33,37,18,89,90,55,24,86,28,29,77,39,11,4,1,43,80,96,98,3,51,67,99,43,92,4,0,51,34,11,35,91,18,74,80,74,35,25,0,94,92,75,6,45,57,72,95,96,90,93,52,36,5,8,48,60,7,52,20,80,67,31,7,80,49,11,35,93,81,56,13,99,61,81,16,50,5,13,98,40,82,65,65,64,0,82,39,32,8,84,6,85,73,81,100,9,45,18,73,87,15,69,91,19,20,78,15,96,99,59,86,51,54,81,37,29,76,42,70,19,41,95,29,59,52,23,44,19,5,26,93,34,27,94,60,35,33,55,67,82,57,50,69,6,56,75,29,20,94,86,74,35,49,71,22,13,75,88,76,52,84,71,57,57,56,38,7,72,49,10,7,35,14,56,97,52,35,16,88,41,43,2,75,34,52,7,15,17,36,92,92,77,43,69,85,44,96,39,80,36,96,79,1,24,85,68,4,45,79,2,75,80,81,88,28,17,99,50,41,34,59,8,93,82,99,0,37,4,77,23,18,95,52,73,32,2,62,73,81,84,80,26,89,27,58,19,66,35,50,65,61,27,28,4,98,43,97,79,77,73,61,19,34,2,2,60,32,42,30,45,19,11,39,13,29,89,59,32,10,23,46,56,99,36,83,65,84,54,36,99,64,10,46,5,8,92,73,68,66,20,98,9,19,15,60,54,14,21,33,30,21,32,52,55,6,4,63,41,68,87,17,84,85,7,77,58,19,76,3,10,90,54,83,81,78,98,69,34,94,67,88,96,21,14,84,58,81],[64,12,78,62,87,72,82,82,64,73,24,88,50,81,32,85,12,52,10,51,7,69,17,45,15,46,60,45,53,24,93,97,84,43,74,49,95,66,49,77,70,66,46,68,37,85,9,35,49,88,54,51,86,33,11,45,45,76,95,76,51,65,54,2,11,15,67,46,88,61,3,96,95,75,53,53,60,35,88,3,80,69,51,99,16,0,73,6,18,47,54,69,82,11,70,27,92,59,26,99,63,55,88,44,91,2,49,76,98,66,32,2,34,3,66,73,97,34,76,99,96,81,65,29,32,91,49,71,60,80,47,44,57,76,40,82,98,60,98,58,78,7,53,59,81,0,10,72,70,68,72,97,61,50,84,33,21,88,27,24,0,46,85,53,14,6,82,13,78,0,49,86,71,88,77,31,64,69,9,22,34,28,44,1,18,67,60,53,22,25,92,92,71,58,64,95,96,79,76,43,78,89,97,97,81,33,41,36,99,0,56,6,43,46,97,65,8,97,48,87,3,36,73,97,46,76,25,59,20,2,67,35,76,37,72,42,49,45,82,47,7,45,35,13,15,18,26,38,77,42,34,2,60,7,35,67,32,31,41,40,18,29,37,42,60,68,15,29,51,35,26,27,60,74,53,40,16,1,42,63,96,52,15,68,74,36,34,21,70,40,80,0,18,91,0,83,99,57,18,23,0,56,78,100,94,22,32,73,96,81,76,3,24,2,23,82,50,55,50,61,77,70,5,34,84,76,30,72,14,23,35,5,68,51,46,9,5,32,0,0,79,90,69,96,64,52,39,1,71,51,3,38,100,1,50,48,32,61,97,24,26,13,7,37,21,12,62,27,24,8,60,98,76, ...
#   ✘ Answer: 999999
#   ✘ Expected Answer: 999999
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/3071.minimum-operations-to-write-the-letter-y-on-a-grid.kt
# - Downloading minimum-operations-to-write-the-letter-y-on-a-grid
#   ✔ Accepted
#   ✔ 909/909 cases passed (75 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3072.distribute-elements-into-two-arrays-ii.kt
# - Downloading distribute-elements-into-two-arrays-ii
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 7: Char 103: ERROR: Argument type mismatch: actual type is 'it(R & Any & R & Any & R & Any & R & Any & kotlin.Pair<A, B>)', but 'kotlin.IntArray' was expected.
#   ✘ Error: Line 7: Char 103: ERROR: Argument type mismatch: actual type is 'it(R & Any & R & Any & R & Any & R & Any & kotlin.Pair<A, B>)', but 'kotlin.IntArray' was expected.
# Line 7: Char 129: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 7: Char 169: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 7: Char 226: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 7: Char 369: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 7: Char 518: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 7: Char 558: WARNING: Parameter 'it: MutableList<Int>' is never used, could be renamed to '_'.
# Line 7: Char 581: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 7: Char 612: WARNING: Parameter 'it: MutableList<Int>' is never used, could be renamed to '_'.
# Line 7: Char 635: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 7: Char 710: ERROR: Unresolved reference 'size'.
# Line 7: Char 741: ERROR: Unresolved reference 'size'.
# Line 7: Char 795: ERROR: Unresolved reference 'size'.
# Line 7: Char 806: ERROR: Unresolved reference 'size'.
# Line 7: Char 828: ERROR: Argument type mismatch: actual type is 'kotlin.Int', but 'kotlin.IntArray' was expected.
# Line 7: Char 828: ERROR: No value passed for parameter 'p2'.
# Line 7: Char 838: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 7: Char 887: ERROR: Argument type mismatch: actual type is 'kotlin.Int', but 'kotlin.IntArray' was expected.
# Line 7: Char 887: ERROR: No value passed for parameter 'p2'.
# Line 7: Char 897: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 7: Char 918: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 7: Char 941: ERROR: None of the following candidates is applicable:
# fun Array<out Int>.toIntArray(): IntArray
# fun Collection<Int>.toIntArray(): IntArray
# fun UIntArray.toIntArray(): IntArray
# Line 41: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/3074.apple-redistribution-into-boxes.kt
# - Downloading apple-redistribution-into-boxes
#   ✔ Accepted
#   ✔ 567/567 cases passed (21 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3075.maximize-happiness-of-selected-children.kt
# - Downloading maximize-happiness-of-selected-children
#   ✔ Accepted
#   ✔ 674/674 cases passed (709 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (80.2 MB)
# Submitting: kotlin_solutions_1/3076.shortest-uncommon-substring-in-an-array.kt
# - Downloading shortest-uncommon-substring-in-an-array
#   ✔ Accepted
#   ✔ 631/631 cases passed (237 ms)
#   ✔ Your runtime beats 11.11 % of kotlin submissions
#   ✔ Your memory usage beats 11.11 % of kotlin submissions (58.5 MB)
# Submitting: kotlin_solutions_1/3077.maximum-strength-of-k-disjoint-subarrays.kt
# - Downloading maximum-strength-of-k-disjoint-subarrays
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 7: Char 174: WARNING: Parameter 'weight: Long' is never used, could be renamed to '_'.
#   ✘ Error: Line 7: Char 174: WARNING: Parameter 'weight: Long' is never used, could be renamed to '_'.
# Line 7: Char 291: ERROR: Argument type mismatch: actual type is 'kotlin.Function0<R>', but 'kotlin.Function2<@ParameterName(...) R, T, R>' was expected.
# Line 7: Char 295: ERROR: Unresolved reference 'nextDp'.
# Line 7: Char 301: ERROR: Syntax error: Expecting ')'.
# Line 7: Char 301: ERROR: Syntax error: Unexpected tokens (use ';' to separate expressions on the same line).
# Line 7: Char 345: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 7: Char 359: ERROR: Unresolved reference 'mx'.
# Line 7: Char 377: ERROR: Unresolved reference 'j'.
# Line 7: Char 388: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 7: Char 388: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun <T, R> T.let(block: (T) -> R): R
#     [R|Contract description]
#      <
#         CallsInPlace(block, EXACTLY_ONCE)
#     >
# Line 7: Char 394: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 7: Char 409: ERROR: Unresolved reference 'best'.
# Line 7: Char 422: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 7: Char 422: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun <T, R> T.let(block: (T) -> R): R
#     [R|Contract description]
#      <
#         CallsInPlace(block, EXACTLY_ONCE)
#     >
# Line 7: Char 428: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 7: Char 440: ERROR: Unresolved reference 'nextDp'.
# Line 7: Char 447: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 7: Char 452: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 7: Char 457: ERROR: Unresolved reference 'j'.
# Line 7: Char 476: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 7: Char 476: ERROR: Not enough information to infer type argument for 'A'.
# Line 7: Char 476: ERROR: Not enough information to infer type argument for 'B'.
# Line 7: Char 486: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 7: Char 486: ERROR: Not enough information to infer type argument for 'A'.
# Line 7: Char 486: ERROR: Not enough information to infer type argument for 'B'.
# Line 7: Char 505: ERROR: Function invocation 'first(...)' expected.
# Line 7: Char 511: ERROR: Function invocation 'first()' expected.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/3079.find-the-sum-of-encrypted-integers.kt
# - Downloading find-the-sum-of-encrypted-integers
#   ✔ Accepted
#   ✔ 865/865 cases passed (155 ms)
#   ✔ Your runtime beats 11.11 % of kotlin submissions
#   ✔ Your memory usage beats 11.11 % of kotlin submissions (45.9 MB)
# Submitting: kotlin_solutions_1/3080.mark-elements-on-array-by-performing-queries.kt
# - Downloading mark-elements-on-array-by-performing-queries
#   ✔ Accepted
#   ✔ 661/661 cases passed (1248 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (106.3 MB)
# Submitting: kotlin_solutions_1/3081.replace-question-marks-in-string-to-minimize-its-value.kt
# - Downloading replace-question-marks-in-string-to-minimize-its-value
#   ✔ Accepted
#   ✔ 548/548 cases passed (330 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (51.5 MB)
# Submitting: kotlin_solutions_1/3082.find-the-sum-of-the-power-of-all-subsequences.kt
# - Downloading find-the-sum-of-the-power-of-all-subsequences
#   ✔ Accepted
#   ✔ 577/577 cases passed (6 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (43.9 MB)
# Submitting: kotlin_solutions_1/3083.existence-of-a-substring-in-a-string-and-its-reverse.kt
# - Downloading existence-of-a-substring-in-a-string-and-its-reverse
#   ✔ Accepted
#   ✔ 719/719 cases passed (13 ms)
#   ✔ Your runtime beats 8.33 % of kotlin submissions
#   ✔ Your memory usage beats 41.67 % of kotlin submissions (43.4 MB)
# Submitting: kotlin_solutions_1/3084.count-substrings-starting-and-ending-with-given-character.kt
# - Downloading count-substrings-starting-and-ending-with-given-character
#   ✔ Accepted
#   ✔ 669/669 cases passed (4 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (45.3 MB)
# Submitting: kotlin_solutions_1/3085.minimum-deletions-to-make-string-k-special.kt
# - Downloading minimum-deletions-to-make-string-k-special
#   ✔ Accepted
#   ✔ 732/732 cases passed (13 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3086.minimum-moves-to-pick-k-ones.kt
# - Downloading minimum-moves-to-pick-k-ones
#   ✔ Accepted
#   ✔ 825/825 cases passed (37 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (69.3 MB)
# Submitting: kotlin_solutions_1/3090.maximum-length-substring-with-two-occurrences.kt
# - Downloading maximum-length-substring-with-two-occurrences
#   ✔ Accepted
#   ✔ 709/709 cases passed (12 ms)
#   ✔ Your runtime beats 11.41 % of kotlin submissions
#   ✔ Your memory usage beats 20.47 % of kotlin submissions (43.7 MB)
# Submitting: kotlin_solutions_1/3091.apply-operations-to-make-sum-of-array-greater-than-or-equal-to-k.kt
# - Downloading apply-operations-to-make-sum-of-array-greater-than-or-equal-to-k
#   ✔ Accepted
#   ✔ 658/658 cases passed (7 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (41.6 MB)
# Submitting: kotlin_solutions_1/3092.most-frequent-ids.kt
# - Downloading most-frequent-ids
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 38: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Error: Line 38: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/3093.longest-common-suffix-queries.kt
# - Downloading longest-common-suffix-queries
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 7: Char 122: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 7: Char 122: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 7: Char 357: WARNING: Unchecked cast of 'kotlin.Any?' to 'kotlin.Array<kotlin.Any?>'.
# Line 7: Char 733: ERROR: Argument type mismatch: actual type is 'kotlin.Pair<kotlin.Array<kotlin.Any?>?, kotlin.Int>', but 'kotlin.Pair<kotlin.Array<kotlin.Any?>, kotlin.Int>' was expected.
# Line 7: Char 733: ERROR: Type mismatch: inferred type is 'kotlin.Pair<kotlin.Nothing?, kotlin.Int>', but 'kotlin.Pair<kotlin.Array<kotlin.Any?>, kotlin.Int>' was expected.
# Line 7: Char 754: WARNING: Unchecked cast of 'kotlin.Any?' to 'kotlin.Array<kotlin.Any?>'.
# Line 7: Char 806: ERROR: Type mismatch: inferred type is 'kotlin.Array<kotlin.Any?>?', but 'kotlin.Array<kotlin.Any?>' was expected.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/3095.shortest-subarray-with-or-at-least-k-i.kt
# - Downloading shortest-subarray-with-or-at-least-k-i
#   ✔ Accepted
#   ✔ 834/834 cases passed (36 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3096.minimum-levels-to-gain-more-points.kt
# - Downloading minimum-levels-to-gain-more-points
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 7: Char 72: ERROR: Overload resolution ambiguity between candidates:
#   ✘ Error: Line 7: Char 72: ERROR: Overload resolution ambiguity between candidates:
# fun IntArray.sumOf(selector: (Int) -> Int): Int
# fun IntArray.sumOf(selector: (Int) -> Long): Long
# Line 7: Char 105: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 7: Char 105: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun <T, R> T.let(block: (T) -> R): R
#     [R|Contract description]
#      <
#         CallsInPlace(block, EXACTLY_ONCE)
#     >
# Line 7: Char 111: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/3097.shortest-subarray-with-or-at-least-k-ii.kt
# - Downloading shortest-subarray-with-or-at-least-k-ii
#   ✔ Accepted
#   ✔ 718/718 cases passed (103 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (93.5 MB)
# Submitting: kotlin_solutions_1/3098.find-the-sum-of-subsequence-powers.kt
# - Downloading find-the-sum-of-subsequence-powers
#   ✔ Accepted
#   ✔ 549/549 cases passed (344 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (62.8 MB)
# Submitting: kotlin_solutions_1/3099.harshad-number.kt
# - Downloading harshad-number
#   ✔ Accepted
#   ✔ 100/100 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/3100.water-bottles-ii.kt
# - Downloading water-bottles-ii
#   ✔ Accepted
#   ✔ 958/958 cases passed (102 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3101.count-alternating-subarrays.kt
# - Downloading count-alternating-subarrays
#   ✔ Accepted
#   ✔ 789/789 cases passed (39 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (83.8 MB)
# Submitting: kotlin_solutions_1/3102.minimize-manhattan-distances.kt
# - Downloading minimize-manhattan-distances
#   ✔ Accepted
#   ✔ 537/537 cases passed (156 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/3105.longest-strictly-increasing-or-strictly-decreasing-subarray.kt
# - Downloading longest-strictly-increasing-or-strictly-decreasing-subarray
#   ✔ Accepted
#   ✔ 868/868 cases passed (26 ms)
#   ✔ Your runtime beats 30.77 % of kotlin submissions
#   ✔ Your memory usage beats 7.69 % of kotlin submissions (46.7 MB)
# Submitting: kotlin_solutions_1/3106.lexicographically-smallest-string-after-operations-with-constraint.kt
# - Downloading lexicographically-smallest-string-after-operations-with-constraint
#   ✔ Accepted
#   ✔ 600/600 cases passed (9 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (46.5 MB)
# Submitting: kotlin_solutions_1/3107.minimum-operations-to-make-median-of-array-equal-to-k.kt
# - Downloading minimum-operations-to-make-median-of-array-equal-to-k
#   ✔ Accepted
#   ✔ 723/723 cases passed (245 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (86 MB)
# Submitting: kotlin_solutions_1/3108.minimum-cost-walk-in-weighted-graph.kt
# - Downloading minimum-cost-walk-in-weighted-graph
#   ✔ Accepted
#   ✔ 549/549 cases passed (169 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3110.score-of-a-string.kt
# - Downloading score-of-a-string
#   ✔ Accepted
#   ✔ 705/705 cases passed (5 ms)
#   ✔ Your runtime beats 28.57 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (42.3 MB)
# Submitting: kotlin_solutions_1/3111.minimum-rectangles-to-cover-points.kt
# - Downloading minimum-rectangles-to-cover-points
#   ✔ Accepted
#   ✔ 966/966 cases passed (37 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (132 MB)
# Submitting: kotlin_solutions_1/3112.minimum-time-to-visit-disappearing-nodes.kt
# - Downloading minimum-time-to-visit-disappearing-nodes
#   ✔ Accepted
#   ✔ 534/534 cases passed (203 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3113.find-the-number-of-subarrays-where-boundary-elements-are-maximum.kt
# - Downloading find-the-number-of-subarrays-where-boundary-elements-are-maximum
#   ✔ Accepted
#   ✔ 890/890 cases passed (88 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (90.1 MB)
# Submitting: kotlin_solutions_1/3114.latest-time-you-can-obtain-after-replacing-characters.kt
# - Downloading latest-time-you-can-obtain-after-replacing-characters
#   ✔ Accepted
#   ✔ 908/908 cases passed (142 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3115.maximum-prime-difference.kt
# - Downloading maximum-prime-difference
#   ✔ Accepted
#   ✔ 904/904 cases passed (657 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/3116.kth-smallest-amount-with-single-denomination-combination.kt
# - Downloading kth-smallest-amount-with-single-denomination-combination
#   ✔ Accepted
#   ✔ 561/561 cases passed (165 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (55.1 MB)
# Submitting: kotlin_solutions_1/3117.minimum-sum-of-values-by-dividing-array.kt
# - Downloading minimum-sum-of-values-by-dividing-array
#   ✔ Accepted
#   ✔ 512/512 cases passed (617 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (245 MB)

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-08-17 19:29:50
