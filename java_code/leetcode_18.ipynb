# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME_4')
    user_cookie = userdata.get('LEETCODE_TOKEN_4')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME_4'] = user_name
    os.environ['LEETCODE_TOKEN_4'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME_4" "$LEETCODE_TOKEN_4" | leetcode user -c

# %%
# %%bash
#
#
# # top 100 answers
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v java_solutions/*.java | sed -n '2501,$p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 8
# done
# Out:
# Submitting: java_solutions/3703.remove-k-balanced-substrings.java
# - Downloading remove-k-balanced-substrings
#   ✔ Accepted
#   ✔ 1014/1014 cases passed (89 ms)
#   ✔ Your runtime beats 57.48 % of java submissions
#   ✔ Your memory usage beats 5.51 % of java submissions (57.9 MB)
# Submitting: java_solutions/3704.count-no-zero-pairs-that-sum-to-n.java
# - Downloading count-no-zero-pairs-that-sum-to-n
#   ✔ Accepted
#   ✔ 1001/1001 cases passed (820 ms)
#   ✔ Your runtime beats 5.13 % of java submissions
#   ✔ Your memory usage beats 5.13 % of java submissions (53.5 MB)
# Submitting: java_solutions/3707.equal-score-substrings.java
# - Downloading equal-score-substrings
#   ✔ Accepted
#   ✔ 1000/1000 cases passed (4 ms)
#   ✔ Your runtime beats 8.6 % of java submissions
#   ✔ Your memory usage beats 11.02 % of java submissions (44.2 MB)
# Submitting: java_solutions/3708.longest-fibonacci-subarray.java
# - Downloading longest-fibonacci-subarray
#   ✔ Accepted
#   ✔ 882/882 cases passed (19 ms)
#   ✔ Your runtime beats 3.21 % of java submissions
#   ✔ Your memory usage beats 5.61 % of java submissions (105.4 MB)
# Submitting: java_solutions/3709.design-exam-scores-tracker.java
# - Downloading design-exam-scores-tracker
#   ✔ Accepted
#   ✔ 771/771 cases passed (231 ms)
#   ✔ Your runtime beats 7.32 % of java submissions
#   ✔ Your memory usage beats 5.69 % of java submissions (188.6 MB)
# Submitting: java_solutions/3710.maximum-partition-factor.java
# - Downloading maximum-partition-factor
#   ✔ Accepted
#   ✔ 741/741 cases passed (1336 ms)
#   ✔ Your runtime beats 5.75 % of java submissions
#   ✔ Your memory usage beats 83.91 % of java submissions (58.3 MB)
# Submitting: java_solutions/3712.sum-of-elements-with-frequency-divisible-by-k.java
# - Downloading sum-of-elements-with-frequency-divisible-by-k
#   ✔ Accepted
#   ✔ 755/755 cases passed (6 ms)
#   ✔ Your runtime beats 2.5 % of java submissions
#   ✔ Your memory usage beats 5 % of java submissions (44.9 MB)
# Submitting: java_solutions/3713.longest-balanced-substring-i.java
# - Downloading longest-balanced-substring-i
#   ✔ Accepted
#   ✔ 1701/1701 cases passed (152 ms)
#   ✔ Your runtime beats 32.36 % of java submissions
#   ✔ Your memory usage beats 10.01 % of java submissions (47.7 MB)
# Submitting: java_solutions/3714.longest-balanced-substring-ii.java
# - Downloading longest-balanced-substring-ii
#   ✔ Accepted
#   ✔ 1034/1034 cases passed (223 ms)
#   ✔ Your runtime beats 50.72 % of java submissions
#   ✔ Your memory usage beats 40.36 % of java submissions (122.5 MB)
# Submitting: java_solutions/3715.sum-of-perfect-square-ancestors.java
# - Downloading sum-of-perfect-square-ancestors
#   ✔ Accepted
#   ✔ 695/695 cases passed (1412 ms)
#   ✔ Your runtime beats 6.67 % of java submissions
#   ✔ Your memory usage beats 73.33 % of java submissions (292 MB)
# Submitting: java_solutions/3718.smallest-missing-multiple-of-k.java
# - Downloading smallest-missing-multiple-of-k
#   ✔ Accepted
#   ✔ 664/664 cases passed (12 ms)
#   ✔ Your runtime beats 5.62 % of java submissions
#   ✔ Your memory usage beats 8.21 % of java submissions (47.3 MB)
# Submitting: java_solutions/3719.longest-balanced-subarray-i.java
# - Downloading longest-balanced-subarray-i
#   ✔ Accepted
#   ✔ 1000/1000 cases passed (899 ms)
#   ✔ Your runtime beats 5.03 % of java submissions
#   ✔ Your memory usage beats 5.29 % of java submissions (48.2 MB)
# Submitting: java_solutions/3720.lexicographically-smallest-permutation-greater-than-target.java
# - Downloading lexicographically-smallest-permutation-greater-than-target
#   ✔ Accepted
#   ✔ 761/761 cases passed (8 ms)
#   ✔ Your runtime beats 37.25 % of java submissions
#   ✔ Your memory usage beats 39.22 % of java submissions (46.5 MB)
# Submitting: java_solutions/3721.longest-balanced-subarray-ii.java
# - Downloading longest-balanced-subarray-ii
#   ✔ Accepted
#   ✔ 999/999 cases passed (2196 ms)
#   ✔ Your runtime beats 5.36 % of java submissions
#   ✔ Your memory usage beats 39.29 % of java submissions (146.5 MB)
# Submitting: java_solutions/3722.lexicographically-smallest-string-after-reverse.java
# - Downloading lexicographically-smallest-string-after-reverse
#   ✔ Accepted
#   ✔ 999/999 cases passed (359 ms)
#   ✔ Your runtime beats 18.87 % of java submissions
#   ✔ Your memory usage beats 9.43 % of java submissions (48.7 MB)
# Submitting: java_solutions/3723.maximize-sum-of-squares-of-digits.java
# - Downloading maximize-sum-of-squares-of-digits
#   ✔ Accepted
#   ✔ 1000/1000 cases passed (28 ms)
#   ✔ Your runtime beats 88.07 % of java submissions
#   ✔ Your memory usage beats 38.53 % of java submissions (48.1 MB)
# Submitting: java_solutions/3724.minimum-operations-to-transform-array.java
# - Downloading minimum-operations-to-transform-array
#   ✔ Accepted
#   ✔ 1010/1010 cases passed (8 ms)
#   ✔ Your runtime beats 15.79 % of java submissions
#   ✔ Your memory usage beats 7.89 % of java submissions (132.1 MB)
# Submitting: java_solutions/3725.count-ways-to-choose-coprime-integers-from-rows.java
# - Downloading count-ways-to-choose-coprime-integers-from-rows
#   ✔ Accepted
#   ✔ 982/982 cases passed (1488 ms)
#   ✔ Your runtime beats 6.03 % of java submissions
#   ✔ Your memory usage beats 6.02 % of java submissions (55.7 MB)
# Submitting: java_solutions/3726.remove-zeros-in-decimal-representation.java
# - Downloading remove-zeros-in-decimal-representation
#   ✔ Accepted
#   ✔ 1000/1000 cases passed (4 ms)
#   ✔ Your runtime beats 19.2 % of java submissions
#   ✔ Your memory usage beats 25.64 % of java submissions (43 MB)
# Submitting: java_solutions/3727.maximum-alternating-sum-of-squares.java
# - Downloading maximum-alternating-sum-of-squares
#   ✔ Accepted
#   ✔ 691/691 cases passed (55 ms)
#   ✔ Your runtime beats 22.99 % of java submissions
#   ✔ Your memory usage beats 29.41 % of java submissions (137.5 MB)
# Submitting: java_solutions/3728.stable-subarrays-with-equal-boundary-and-interior-sum.java
# - Downloading stable-subarrays-with-equal-boundary-and-interior-sum
#   ✔ Accepted
#   ✔ 753/753 cases passed (263 ms)
#   ✔ Your runtime beats 16.25 % of java submissions
#   ✔ Your memory usage beats 20 % of java submissions (149.3 MB)
# Submitting: java_solutions/3729.count-distinct-subarrays-divisible-by-k-in-sorted-array.java
# - Downloading count-distinct-subarrays-divisible-by-k-in-sorted-array
#   ✔ Accepted
#   ✔ 1024/1024 cases passed (617 ms)
#   ✔ Your runtime beats 5.09 % of java submissions
#   ✔ Your memory usage beats 98.31 % of java submissions (118.4 MB)
# Submitting: java_solutions/3731.find-missing-elements.java
# - Downloading find-missing-elements
#   ✔ Accepted
#   ✔ 989/989 cases passed (5 ms)
#   ✔ Your runtime beats 52.43 % of java submissions
#   ✔ Your memory usage beats 69.22 % of java submissions (46.8 MB)
# Submitting: java_solutions/3732.maximum-product-of-three-elements-after-one-replacement.java
# - Downloading maximum-product-of-three-elements-after-one-replacement
#   ✔ Accepted
#   ✔ 821/821 cases passed (58 ms)
#   ✔ Your runtime beats 5.33 % of java submissions
#   ✔ Your memory usage beats 98.36 % of java submissions (92.9 MB)
# Submitting: java_solutions/3733.minimum-time-to-complete-all-deliveries.java
# - Downloading minimum-time-to-complete-all-deliveries
#   ✔ Accepted
#   ✔ 1026/1026 cases passed (6 ms)
#   ✔ Your runtime beats 3.23 % of java submissions
#   ✔ Your memory usage beats 5.16 % of java submissions (44.6 MB)
# Submitting: java_solutions/3734.lexicographically-smallest-palindromic-permutation-greater-than-target.java
# - Downloading lexicographically-smallest-palindromic-permutation-greater-than-target
#   ✔ Accepted
#   ✔ 1035/1035 cases passed (70 ms)
#   ✔ Your runtime beats 6.67 % of java submissions
#   ✔ Your memory usage beats 6.67 % of java submissions (53.3 MB)
# Submitting: java_solutions/3736.minimum-moves-to-equal-array-elements-iii.java
# - Downloading minimum-moves-to-equal-array-elements-iii
#   ✔ Accepted
#   ✔ 1016/1016 cases passed (5 ms)
#   ✔ Your runtime beats 24.37 % of java submissions
#   ✔ Your memory usage beats 13.91 % of java submissions (46.8 MB)
# Submitting: java_solutions/3737.count-subarrays-with-majority-element-i.java
# - Downloading count-subarrays-with-majority-element-i
#   ✔ Accepted
#   ✔ 1069/1069 cases passed (65 ms)
#   ✔ Your runtime beats 10.77 % of java submissions
#   ✔ Your memory usage beats 79.69 % of java submissions (46.9 MB)
# Submitting: java_solutions/3738.longest-non-decreasing-subarray-after-replacing-at-most-one-element.java
# - Downloading longest-non-decreasing-subarray-after-replacing-at-most-one-element
#   ✔ Accepted
#   ✔ 579/579 cases passed (25 ms)
#   ✔ Your runtime beats 9.23 % of java submissions
#   ✔ Your memory usage beats 99.23 % of java submissions (114.3 MB)
# Submitting: java_solutions/3739.count-subarrays-with-majority-element-ii.java
# - Downloading count-subarrays-with-majority-element-ii
#   ✔ Accepted
#   ✔ 516/516 cases passed (69 ms)
#   ✔ Your runtime beats 12.04 % of java submissions
#   ✔ Your memory usage beats 18.52 % of java submissions (114 MB)
# Submitting: java_solutions/3740.minimum-distance-between-three-equal-elements-i.java
# - Downloading minimum-distance-between-three-equal-elements-i
#   ✔ Accepted
#   ✔ 899/899 cases passed (138 ms)
#   ✔ Your runtime beats 5.03 % of java submissions
#   ✔ Your memory usage beats 6.65 % of java submissions (47.5 MB)
# Submitting: java_solutions/3741.minimum-distance-between-three-equal-elements-ii.java
# - Downloading minimum-distance-between-three-equal-elements-ii
#   ✔ Accepted
#   ✔ 979/979 cases passed (152 ms)
#   ✔ Your runtime beats 7.99 % of java submissions
#   ✔ Your memory usage beats 99.07 % of java submissions (157.9 MB)
# Submitting: java_solutions/3742.maximum-path-score-in-a-grid.java
# - Downloading maximum-path-score-in-a-grid
#   ✔ Accepted
#   ✔ 529/529 cases passed (583 ms)
#   ✔ Your runtime beats 5.09 % of java submissions
#   ✔ Your memory usage beats 25.65 % of java submissions (90.3 MB)
# Submitting: java_solutions/3743.maximize-cyclic-partition-score.java
# - Downloading maximize-cyclic-partition-score
#   ✔ Accepted
#   ✔ 1274/1274 cases passed (1464 ms)
#   ✔ Your runtime beats 5.81 % of java submissions
#   ✔ Your memory usage beats 13.95 % of java submissions (53.7 MB)
# Submitting: java_solutions/3745.maximize-expression-of-three-elements.java
# - Downloading maximize-expression-of-three-elements
#   ✔ Accepted
#   ✔ 1006/1006 cases passed (5 ms)
#   ✔ Your runtime beats 61.06 % of java submissions
#   ✔ Your memory usage beats 66.35 % of java submissions (45.2 MB)
# Submitting: java_solutions/3746.minimum-string-length-after-balanced-removals.java
# - Downloading minimum-string-length-after-balanced-removals
#   ✔ Accepted
#   ✔ 680/680 cases passed (8 ms)
#   ✔ Your runtime beats 25.54 % of java submissions
#   ✔ Your memory usage beats 11.49 % of java submissions (47.4 MB)
# Submitting: java_solutions/3747.count-distinct-integers-after-removing-zeros.java
# - Downloading count-distinct-integers-after-removing-zeros
#   ✔ Accepted
#   ✔ 1200/1200 cases passed (5 ms)
#   ✔ Your runtime beats 22.02 % of java submissions
#   ✔ Your memory usage beats 20.18 % of java submissions (44 MB)
# Submitting: java_solutions/3748.count-stable-subarrays.java
# - Downloading count-stable-subarrays
#   ✔ Accepted
#   ✔ 1041/1041 cases passed (182 ms)
#   ✔ Your runtime beats 5 % of java submissions
#   ✔ Your memory usage beats 100 % of java submissions (166.8 MB)
# Submitting: java_solutions/3750.minimum-number-of-flips-to-reverse-binary-string.java
# - Downloading minimum-number-of-flips-to-reverse-binary-string
#   ✔ Accepted
#   ✔ 1146/1146 cases passed (5 ms)
#   ✔ Your runtime beats 13.1 % of java submissions
#   ✔ Your memory usage beats 15.8 % of java submissions (43.2 MB)
# Submitting: java_solutions/3751.total-waviness-of-numbers-in-range-i.java
# - Downloading total-waviness-of-numbers-in-range-i
#   ✔ Accepted
#   ✔ 1029/1029 cases passed (19 ms)
#   ✔ Your runtime beats 88.74 % of java submissions
#   ✔ Your memory usage beats 10.24 % of java submissions (46.7 MB)
# Submitting: java_solutions/3752.lexicographically-smallest-negated-permutation-that-sums-to-target.java
# - Downloading lexicographically-smallest-negated-permutation-that-sums-to-target
#   ✔ Accepted
#   ✔ 831/831 cases passed (13 ms)
#   ✔ Your runtime beats 62.62 % of java submissions
#   ✔ Your memory usage beats 50.47 % of java submissions (163.6 MB)
# Submitting: java_solutions/3753.total-waviness-of-numbers-in-range-ii.java
# - Downloading total-waviness-of-numbers-in-range-ii
#   ✔ Accepted
#   ✔ 1013/1013 cases passed (2709 ms)
#   ✔ Your runtime beats 6.35 % of java submissions
#   ✔ Your memory usage beats 6.35 % of java submissions (277.4 MB)
# Submitting: java_solutions/3754.concatenate-non-zero-digits-and-multiply-by-sum-i.java
# - Downloading concatenate-non-zero-digits-and-multiply-by-sum-i
#   ✔ Accepted
#   ✔ 954/954 cases passed (4 ms)
#   ✔ Your runtime beats 16.21 % of java submissions
#   ✔ Your memory usage beats 8.63 % of java submissions (43.1 MB)
# Submitting: java_solutions/3755.find-maximum-balanced-xor-subarray-length.java
# - Downloading find-maximum-balanced-xor-subarray-length
#   ✔ Accepted
#   ✔ 598/598 cases passed (587 ms)
#   ✔ Your runtime beats 5.08 % of java submissions
#   ✔ Your memory usage beats 11.02 % of java submissions (275.6 MB)
# Submitting: java_solutions/3756.concatenate-non-zero-digits-and-multiply-by-sum-ii.java
# - Downloading concatenate-non-zero-digits-and-multiply-by-sum-ii
#   ✔ Accepted
#   ✔ 523/523 cases passed (250 ms)
#   ✔ Your runtime beats 5.97 % of java submissions
#   ✔ Your memory usage beats 32.84 % of java submissions (130.6 MB)
# Submitting: java_solutions/3757.number-of-effective-subsequences.java
# - Downloading number-of-effective-subsequences
#   ✔ Accepted
#   ✔ 1041/1041 cases passed (1416 ms)
#   ✔ Your runtime beats 5.33 % of java submissions
#   ✔ Your memory usage beats 14.67 % of java submissions (110.3 MB)
# Submitting: java_solutions/3759.count-elements-with-at-least-k-greater-values.java
# - Downloading count-elements-with-at-least-k-greater-values
#   ✔ Accepted
#   ✔ 927/927 cases passed (62 ms)
#   ✔ Your runtime beats 27.61 % of java submissions
#   ✔ Your memory usage beats 96.01 % of java submissions (130.2 MB)
# Submitting: java_solutions/3760.maximum-substrings-with-distinct-start.java
# - Downloading maximum-substrings-with-distinct-start
#   ✔ Accepted
#   ✔ 1163/1163 cases passed (55 ms)
#   ✔ Your runtime beats 6.59 % of java submissions
#   ✔ Your memory usage beats 36.61 % of java submissions (47.9 MB)
# Submitting: java_solutions/3761.minimum-absolute-distance-between-mirror-pairs.java
# - Downloading minimum-absolute-distance-between-mirror-pairs
#   ✔ Accepted
#   ✔ 741/741 cases passed (55 ms)
#   ✔ Your runtime beats 20.65 % of java submissions
#   ✔ Your memory usage beats 17.67 % of java submissions (96.7 MB)
# Submitting: java_solutions/3762.minimum-operations-to-equalize-subarrays.java
# - Downloading minimum-operations-to-equalize-subarrays
#   ✔ Accepted
#   ✔ 1118/1118 cases passed (2398 ms)
#   ✔ Your runtime beats 7.69 % of java submissions
#   ✔ Your memory usage beats 7.69 % of java submissions (290 MB)
# Submitting: java_solutions/3765.complete-prime-number.java
# - Downloading complete-prime-number
#   ✔ Accepted
#   ✔ 1857/1857 cases passed (12 ms)
#   ✔ Your runtime beats 5.25 % of java submissions
#   ✔ Your memory usage beats 5.25 % of java submissions (44.7 MB)
# Submitting: java_solutions/3766.minimum-operations-to-make-binary-palindrome.java
# - Downloading minimum-operations-to-make-binary-palindrome
#   ✔ Accepted
#   ✔ 1029/1029 cases passed (1655 ms)
#   ✔ Your runtime beats 5.45 % of java submissions
#   ✔ Your memory usage beats 7.27 % of java submissions (48.1 MB)
# Submitting: java_solutions/3767.maximize-points-after-choosing-k-tasks.java
# - Downloading maximize-points-after-choosing-k-tasks
#   ✔ Accepted
#   ✔ 590/590 cases passed (48 ms)
#   ✔ Your runtime beats 75.52 % of java submissions
#   ✔ Your memory usage beats 54.55 % of java submissions (141.2 MB)
# Submitting: java_solutions/3768.minimum-inversion-count-in-subarrays-of-fixed-length.java
# - Downloading minimum-inversion-count-in-subarrays-of-fixed-length
#   ✔ Accepted
#   ✔ 926/926 cases passed (1470 ms)
#   ✔ Your runtime beats 5.66 % of java submissions
#   ✔ Your memory usage beats 81.13 % of java submissions (143.5 MB)
# Submitting: java_solutions/3769.sort-integers-by-binary-reflection.java
# - Downloading sort-integers-by-binary-reflection
#   ✔ Accepted
#   ✔ 963/963 cases passed (14 ms)
#   ✔ Your runtime beats 60.38 % of java submissions
#   ✔ Your memory usage beats 12.74 % of java submissions (47.6 MB)
# Submitting: java_solutions/3770.largest-prime-from-consecutive-prime-sum.java
# - Downloading largest-prime-from-consecutive-prime-sum
#   ✔ Accepted
#   ✔ 1124/1124 cases passed (2474 ms)
#   ✔ Your runtime beats 5.47 % of java submissions
#   ✔ Your memory usage beats 26.23 % of java submissions (46.7 MB)
# Submitting: java_solutions/3771.total-score-of-dungeon-runs.java
# - Downloading total-score-of-dungeon-runs
#   ✔ Accepted
#   ✔ 976/976 cases passed (45 ms)
#   ✔ Your runtime beats 68.83 % of java submissions
#   ✔ Your memory usage beats 67.53 % of java submissions (174.6 MB)
# Submitting: java_solutions/3772.maximum-subgraph-score-in-a-tree.java
# - Downloading maximum-subgraph-score-in-a-tree
#   ✔ Accepted
#   ✔ 876/876 cases passed (1240 ms)
#   ✔ Your runtime beats 5.13 % of java submissions
#   ✔ Your memory usage beats 5.13 % of java submissions (290.6 MB)
# Submitting: java_solutions/3774.absolute-difference-between-maximum-and-minimum-k-elements.java
# - Downloading absolute-difference-between-maximum-and-minimum-k-elements
#   ✔ Accepted
#   ✔ 994/994 cases passed (15 ms)
#   ✔ Your runtime beats 15.84 % of java submissions
#   ✔ Your memory usage beats 12.82 % of java submissions (47.1 MB)
# Submitting: java_solutions/3775.reverse-words-with-same-vowel-count.java
# - Downloading reverse-words-with-same-vowel-count
#   ✔ Accepted
#   ✔ 1032/1032 cases passed (64 ms)
#   ✔ Your runtime beats 60.05 % of java submissions
#   ✔ Your memory usage beats 71.77 % of java submissions (64.4 MB)
# Submitting: java_solutions/3776.minimum-moves-to-balance-circular-array.java
# - Downloading minimum-moves-to-balance-circular-array
#   ✔ Accepted
#   ✔ 1014/1014 cases passed (12 ms)
#   ✔ Your runtime beats 16.81 % of java submissions
#   ✔ Your memory usage beats 15.93 % of java submissions (142.8 MB)
# Submitting: java_solutions/3777.minimum-deletions-to-make-alternating-substring.java
# - Downloading minimum-deletions-to-make-alternating-substring
#   ✔ Accepted
#   ✔ 1008/1008 cases passed (1442 ms)
#   ✔ Your runtime beats 6.67 % of java submissions
#   ✔ Your memory usage beats 6.67 % of java submissions (283.8 MB)
# Submitting: java_solutions/3779.minimum-number-of-operations-to-have-distinct-elements.java
# - Downloading minimum-number-of-operations-to-have-distinct-elements
#   ✔ Accepted
#   ✔ 728/728 cases passed (14 ms)
#   ✔ Your runtime beats 40.15 % of java submissions
#   ✔ Your memory usage beats 81.06 % of java submissions (137.6 MB)
# Submitting: java_solutions/3780.maximum-sum-of-three-numbers-divisible-by-three.java
# - Downloading maximum-sum-of-three-numbers-divisible-by-three
#   ✔ Accepted
#   ✔ 1037/1037 cases passed (17 ms)
#   ✔ Your runtime beats 90.43 % of java submissions
#   ✔ Your memory usage beats 91.3 % of java submissions (166.5 MB)
# Submitting: java_solutions/3781.maximum-score-after-binary-swaps.java
# - Downloading maximum-score-after-binary-swaps
#   ✘ Time Limit Exceeded
#   ✘ 0/865 cases passed (N/A)
#   ✘ Testcase: [2,1,5,2,3]
# "01010"
#   ✘ Answer:
#   ✘ Expected Answer: 7
#   ✘ Stdout:
# Submitting: java_solutions/3782.last-remaining-integer-after-alternating-deletion-operations.java
# - Downloading last-remaining-integer-after-alternating-deletion-operations
#   ✔ Accepted
#   ✔ 1310/1310 cases passed (1 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 93.65 % of java submissions (42.5 MB)
# Submitting: java_solutions/3783.mirror-distance-of-an-integer.java
# - Downloading mirror-distance-of-an-integer
#   ✔ Accepted
#   ✔ 999/999 cases passed (4 ms)
#   ✔ Your runtime beats 2.53 % of java submissions
#   ✔ Your memory usage beats 7.91 % of java submissions (43.1 MB)
# Submitting: java_solutions/3784.minimum-deletion-cost-to-make-all-characters-equal.java
# - Downloading minimum-deletion-cost-to-make-all-characters-equal
#   ✔ Accepted
#   ✔ 675/675 cases passed (9 ms)
#   ✔ Your runtime beats 41.24 % of java submissions
#   ✔ Your memory usage beats 76.8 % of java submissions (104.9 MB)
# Submitting: java_solutions/3785.minimum-swaps-to-avoid-forbidden-values.java
# - Downloading minimum-swaps-to-avoid-forbidden-values
#   ✔ Accepted
#   ✔ 1111/1111 cases passed (127 ms)
#   ✔ Your runtime beats 12.16 % of java submissions
#   ✔ Your memory usage beats 50 % of java submissions (173.5 MB)
# Submitting: java_solutions/3786.total-sum-of-interaction-cost-in-tree-groups.java
# - Downloading total-sum-of-interaction-cost-in-tree-groups
#   ✔ Accepted
#   ✔ 1147/1147 cases passed (1180 ms)
#   ✔ Your runtime beats 5.77 % of java submissions
#   ✔ Your memory usage beats 57.69 % of java submissions (291.7 MB)
# Submitting: java_solutions/3788.maximum-score-of-a-split.java
# - Downloading maximum-score-of-a-split
#   ✔ Accepted
#   ✔ 580/580 cases passed (8 ms)
#   ✔ Your runtime beats 7.62 % of java submissions
#   ✔ Your memory usage beats 93.81 % of java submissions (113.6 MB)
# Submitting: java_solutions/3789.minimum-cost-to-acquire-required-items.java
# - Downloading minimum-cost-to-acquire-required-items
#   ✔ Accepted
#   ✔ 1002/1002 cases passed (1 ms)
#   ✔ Your runtime beats 99 % of java submissions
#   ✔ Your memory usage beats 61 % of java submissions (42.8 MB)
# Submitting: java_solutions/3790.smallest-all-ones-multiple.java
# - Downloading smallest-all-ones-multiple
#   ✔ Accepted
#   ✔ 1000/1000 cases passed (13 ms)
#   ✔ Your runtime beats 36.99 % of java submissions
#   ✔ Your memory usage beats 16.18 % of java submissions (43.2 MB)
# Submitting: java_solutions/3791.number-of-balanced-integers-in-a-range.java
# - Downloading number-of-balanced-integers-in-a-range
#   ✔ Accepted
#   ✔ 1042/1042 cases passed (1663 ms)
#   ✔ Your runtime beats 6.52 % of java submissions
#   ✔ Your memory usage beats 35.87 % of java submissions (47.4 MB)
# Submitting: java_solutions/3794.reverse-string-prefix.java
# - Downloading reverse-string-prefix
#   ✔ Accepted
#   ✔ 999/999 cases passed (6 ms)
#   ✔ Your runtime beats 6.87 % of java submissions
#   ✔ Your memory usage beats 16.41 % of java submissions (45.2 MB)
# Submitting: java_solutions/3795.minimum-subarray-length-with-distinct-sum-at-least-k.java
# - Downloading minimum-subarray-length-with-distinct-sum-at-least-k
#   ✔ Accepted
#   ✔ 1028/1028 cases passed (26 ms)
#   ✔ Your runtime beats 86.11 % of java submissions
#   ✔ Your memory usage beats 48.61 % of java submissions (174.8 MB)
# Submitting: java_solutions/3796.find-maximum-value-in-a-constrained-sequence.java
# - Downloading find-maximum-value-in-a-constrained-sequence
#   ✔ Accepted
#   ✔ 844/844 cases passed (14 ms)
#   ✔ Your runtime beats 25 % of java submissions
#   ✔ Your memory usage beats 100 % of java submissions (199.7 MB)
# Submitting: java_solutions/3797.count-routes-to-climb-a-rectangular-grid.java
#   ✔ Accepted
#   ✔ 2254/2254 cases passed (424 ms)
#   ✔ Your runtime beats 6.82 % of java submissions
#   ✔ Your memory usage beats 43.18 % of java submissions (60.8 MB)
# Submitting: java_solutions/3798.largest-even-number.java
# - Downloading largest-even-number
#   ✔ Accepted
#   ✔ 775/775 cases passed (1 ms)
#   ✔ Your runtime beats 65.96 % of java submissions
#   ✔ Your memory usage beats 45.76 % of java submissions (44 MB)
# Submitting: java_solutions/3799.word-squares-ii.java
# - Downloading word-squares-ii
#   ✔ Accepted
#   ✔ 1012/1012 cases passed (14 ms)
#   ✔ Your runtime beats 83.19 % of java submissions
#   ✔ Your memory usage beats 23.01 % of java submissions (57.6 MB)
# Submitting: java_solutions/3800.minimum-cost-to-make-two-binary-strings-equal.java
# - Downloading minimum-cost-to-make-two-binary-strings-equal
#   ✔ Accepted
#   ✔ 783/783 cases passed (11 ms)
#   ✔ Your runtime beats 21.95 % of java submissions
#   ✔ Your memory usage beats 35.37 % of java submissions (47.9 MB)
# Submitting: java_solutions/3801.minimum-cost-to-merge-sorted-lists.java
# - Downloading minimum-cost-to-merge-sorted-lists
#   ✔ Accepted
#   ✔ 881/881 cases passed (2675 ms)
#   ✔ Your runtime beats 25 % of java submissions
#   ✔ Your memory usage beats 12.5 % of java submissions (55.5 MB)
# Submitting: java_solutions/3803.count-residue-prefixes.java
# - Downloading count-residue-prefixes
#   ✔ Accepted
#   ✔ 1101/1101 cases passed (4 ms)
#   ✔ Your runtime beats 14.84 % of java submissions
#   ✔ Your memory usage beats 52.23 % of java submissions (44 MB)
# Submitting: java_solutions/3804.number-of-centered-subarrays.java
# - Downloading number-of-centered-subarrays
#   ✔ Accepted
#   ✔ 1042/1042 cases passed (31 ms)
#   ✔ Your runtime beats 99.5 % of java submissions
#   ✔ Your memory usage beats 13.86 % of java submissions (47.2 MB)
# Submitting: java_solutions/3805.count-caesar-cipher-pairs.java
# - Downloading count-caesar-cipher-pairs
#   ✔ Accepted
#   ✔ 1004/1004 cases passed (46 ms)
#   ✔ Your runtime beats 75.3 % of java submissions
#   ✔ Your memory usage beats 81.93 % of java submissions (67.6 MB)
# Submitting: java_solutions/3806.maximum-bitwise-and-after-increment-operations.java
# - Downloading maximum-bitwise-and-after-increment-operations
#   ✔ Accepted
#   ✔ 1032/1032 cases passed (1456 ms)
#   ✔ Your runtime beats 6.98 % of java submissions
#   ✔ Your memory usage beats 9.3 % of java submissions (71 MB)
# Submitting: java_solutions/3809.best-reachable-tower.java
# - Downloading best-reachable-tower
#   ✔ Accepted
#   ✔ 1001/1001 cases passed (6 ms)
#   ✔ Your runtime beats 15.83 % of java submissions
#   ✔ Your memory usage beats 15.11 % of java submissions (220.4 MB)
# Submitting: java_solutions/3810.minimum-operations-to-reach-target-array.java
# - Downloading minimum-operations-to-reach-target-array
#   ✔ Accepted
#   ✔ 1014/1014 cases passed (17 ms)
#   ✔ Your runtime beats 92.65 % of java submissions
#   ✔ Your memory usage beats 18.38 % of java submissions (126.6 MB)
# Submitting: java_solutions/3811.number-of-alternating-xor-partitions.java
# - Downloading number-of-alternating-xor-partitions
#   ✔ Accepted
#   ✔ 1033/1033 cases passed (261 ms)
#   ✔ Your runtime beats 10.35 % of java submissions
#   ✔ Your memory usage beats 12.07 % of java submissions (277.3 MB)
# Submitting: java_solutions/3812.minimum-edge-toggles-on-a-tree.java
# - Downloading minimum-edge-toggles-on-a-tree
#   ✔ Accepted
#   ✔ 537/537 cases passed (585 ms)
#   ✔ Your runtime beats 5.19 % of java submissions
#   ✔ Your memory usage beats 5.19 % of java submissions (415.9 MB)
# Submitting: java_solutions/3813.vowel-consonant-score.java
# - Downloading vowel-consonant-score
#   ✔ Accepted
#   ✔ 793/793 cases passed (3 ms)
#   ✔ Your runtime beats 9.73 % of java submissions
#   ✔ Your memory usage beats 9.45 % of java submissions (44 MB)
# Submitting: java_solutions/3814.maximum-capacity-within-budget.java
# - Downloading maximum-capacity-within-budget
#   ✔ Accepted
#   ✔ 1023/1023 cases passed (160 ms)
#   ✔ Your runtime beats 13.29 % of java submissions
#   ✔ Your memory usage beats 78.48 % of java submissions (173.3 MB)
# Submitting: java_solutions/3815.design-auction-system.java
# - Downloading design-auction-system
#   ✔ Accepted
#   ✔ 509/509 cases passed (137 ms)
#   ✔ Your runtime beats 43.38 % of java submissions
#   ✔ Your memory usage beats 53.43 % of java submissions (209.5 MB)
# Submitting: java_solutions/3816.lexicographically-smallest-string-after-deleting-duplicate-characters.java
# - Downloading lexicographically-smallest-string-after-deleting-duplicate-characters
#   ✔ Accepted
#   ✔ 1017/1017 cases passed (1933 ms)
#   ✔ Your runtime beats 6.45 % of java submissions
#   ✔ Your memory usage beats 14.52 % of java submissions (57.1 MB)
# Submitting: java_solutions/3818.minimum-prefix-removal-to-make-array-strictly-increasing.java
# - Downloading minimum-prefix-removal-to-make-array-strictly-increasing
#   ✔ Accepted
#   ✔ 714/714 cases passed (5 ms)
#   ✔ Your runtime beats 2.96 % of java submissions
#   ✔ Your memory usage beats 99.77 % of java submissions (119.3 MB)
# Submitting: java_solutions/3819.rotate-non-negative-elements.java
# - Downloading rotate-non-negative-elements
#   ✔ Accepted
#   ✔ 1023/1023 cases passed (15 ms)
#   ✔ Your runtime beats 92.71 % of java submissions
#   ✔ Your memory usage beats 22.92 % of java submissions (272.8 MB)
# Submitting: java_solutions/3820.pythagorean-distance-nodes-in-a-tree.java
# - Downloading pythagorean-distance-nodes-in-a-tree
#   ✔ Accepted
#   ✔ 1014/1014 cases passed (45 ms)
#   ✔ Your runtime beats 94.96 % of java submissions
#   ✔ Your memory usage beats 69.07 % of java submissions (235.9 MB)
# Submitting: java_solutions/3821.find-nth-smallest-integer-with-k-one-bits.java
# - Downloading find-nth-smallest-integer-with-k-one-bits
#   ✔ Accepted
#   ✔ 1007/1007 cases passed (11 ms)
#   ✔ Your runtime beats 32.95 % of java submissions
#   ✔ Your memory usage beats 7.95 % of java submissions (53.4 MB)
# Submitting: java_solutions/3823.reverse-letters-then-special-characters-in-a-string.java
# - Downloading reverse-letters-then-special-characters-in-a-string
#   ✔ Accepted
#   ✔ 995/995 cases passed (4 ms)
#   ✔ Your runtime beats 30.46 % of java submissions
#   ✔ Your memory usage beats 33.02 % of java submissions (45.1 MB)
# Submitting: java_solutions/3824.minimum-k-to-reduce-array-within-limit.java
# - Downloading minimum-k-to-reduce-array-within-limit
#   ✔ Accepted
#   ✔ 1004/1004 cases passed (55 ms)
#   ✔ Your runtime beats 74.89 % of java submissions
#   ✔ Your memory usage beats 6.17 % of java submissions (133 MB)
# Submitting: java_solutions/3825.longest-strictly-increasing-subsequence-with-non-zero-bitwise-and.java
# - Downloading longest-strictly-increasing-subsequence-with-non-zero-bitwise-and
#   ✔ Accepted
#   ✔ 1016/1016 cases passed (596 ms)
#   ✔ Your runtime beats 68.36 % of java submissions
#   ✔ Your memory usage beats 100 % of java submissions (93.1 MB)
# Submitting: java_solutions/3826.minimum-partition-score.java
# - Downloading minimum-partition-score
#   ✔ Accepted
#   ✔ 822/822 cases passed (11 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 71.43 % of java submissions (54.4 MB)
# Submitting: java_solutions/3827.count-monobit-integers.java
# - Downloading count-monobit-integers
#   ✔ Accepted
#   ✔ 1001/1001 cases passed (4 ms)
#   ✔ Your runtime beats 28.38 % of java submissions
#   ✔ Your memory usage beats 25.1 % of java submissions (42.9 MB)
# Submitting: java_solutions/3828.final-element-after-subarray-deletions.java
# - Downloading final-element-after-subarray-deletions
#   ✔ Accepted
#   ✔ 1015/1015 cases passed (5 ms)
#   ✔ Your runtime beats 0.51 % of java submissions
#   ✔ Your memory usage beats 97.46 % of java submissions (113.6 MB)
# Submitting: java_solutions/3829.design-ride-sharing-system.java
# - Downloading design-ride-sharing-system
#   ✔ Accepted
#   ✔ 844/844 cases passed (52 ms)
#   ✔ Your runtime beats 45.44 % of java submissions
#   ✔ Your memory usage beats 32.6 % of java submissions (48.3 MB)
# Submitting: java_solutions/3830.longest-alternating-subarray-after-removing-at-most-one-element.java
# - Downloading longest-alternating-subarray-after-removing-at-most-one-element
#   ✔ Accepted
#   ✔ 1018/1018 cases passed (12 ms)
#   ✔ Your runtime beats 98.21 % of java submissions
#   ✔ Your memory usage beats 92.86 % of java submissions (176.7 MB)
# Submitting: java_solutions/3833.count-dominant-indices.java
# - Downloading count-dominant-indices
#   ✔ Accepted
#   ✔ 1045/1045 cases passed (5 ms)
#   ✔ Your runtime beats 3.54 % of java submissions
#   ✔ Your memory usage beats 36.28 % of java submissions (46.4 MB)
# Submitting: java_solutions/3834.merge-adjacent-equal-elements.java
# - Downloading merge-adjacent-equal-elements
#   ✔ Accepted
#   ✔ 1113/1113 cases passed (20 ms)
#   ✔ Your runtime beats 80.99 % of java submissions
#   ✔ Your memory usage beats 16.9 % of java submissions (135.3 MB)
# Submitting: java_solutions/3835.count-subarrays-with-cost-less-than-or-equal-to-k.java
# - Downloading count-subarrays-with-cost-less-than-or-equal-to-k
#   ✔ Accepted
#   ✔ 812/812 cases passed (25 ms)
#   ✔ Your runtime beats 99.15 % of java submissions
#   ✔ Your memory usage beats 46.58 % of java submissions (136.6 MB)
# Submitting: java_solutions/3836.maximum-score-using-exactly-k-pairs.java
# - Downloading maximum-score-using-exactly-k-pairs
#   ✔ Accepted
#   ✔ 884/884 cases passed (14 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 5.77 % of java submissions (291.9 MB)
# Submitting: java_solutions/3838.weighted-word-mapping.java
# - Downloading weighted-word-mapping
#   ✔ Accepted
#   ✔ 698/698 cases passed (5 ms)
#   ✔ Your runtime beats 27.78 % of java submissions
#   ✔ Your memory usage beats 37.69 % of java submissions (46.7 MB)
# Submitting: java_solutions/3839.number-of-prefix-connected-groups.java
# - Downloading number-of-prefix-connected-groups
#   ✔ Accepted
#   ✔ 1029/1029 cases passed (25 ms)
#   ✔ Your runtime beats 34.26 % of java submissions
#   ✔ Your memory usage beats 31.14 % of java submissions (49.7 MB)
# Submitting: java_solutions/3840.house-robber-v.java
# - Downloading house-robber-v
#   ✔ Accepted
#   ✔ 1014/1014 cases passed (8 ms)
#   ✔ Your runtime beats 39.66 % of java submissions
#   ✔ Your memory usage beats 65.69 % of java submissions (152.1 MB)
# Submitting: java_solutions/3841.palindromic-path-queries-in-a-tree.java
# - Downloading palindromic-path-queries-in-a-tree
#   ✔ Accepted
#   ✔ 1040/1040 cases passed (16 ms)
#   ✔ Your runtime beats 94.12 % of java submissions
#   ✔ Your memory usage beats 88.24 % of java submissions (207.3 MB)
# Submitting: java_solutions/3842.toggle-light-bulbs.java
# - Downloading toggle-light-bulbs
#   ✔ Accepted
#   ✔ 1000/1000 cases passed (6 ms)
#   ✔ Your runtime beats 54.32 % of java submissions
#   ✔ Your memory usage beats 59.28 % of java submissions (46.7 MB)
# Submitting: java_solutions/3843.first-element-with-unique-frequency.java
# - Downloading first-element-with-unique-frequency
#   ✔ Accepted
#   ✔ 958/958 cases passed (125 ms)
#   ✔ Your runtime beats 30.69 % of java submissions
#   ✔ Your memory usage beats 30.2 % of java submissions (215.4 MB)
# Submitting: java_solutions/3844.longest-almost-palindromic-substring.java
# - Downloading longest-almost-palindromic-substring
#   ✔ Accepted
#   ✔ 1069/1069 cases passed (53 ms)
#   ✔ Your runtime beats 42.58 % of java submissions
#   ✔ Your memory usage beats 23.92 % of java submissions (48 MB)
# Submitting: java_solutions/3845.maximum-subarray-xor-with-bounded-range.java
# - Downloading maximum-subarray-xor-with-bounded-range
#   ✔ Accepted
#   ✔ 1015/1015 cases passed (14 ms)
#   ✔ Your runtime beats 99.09 % of java submissions
#   ✔ Your memory usage beats 5.45 % of java submissions (288 MB)
# Submitting: java_solutions/3847.find-the-score-difference-in-a-game.java
# - Downloading find-the-score-difference-in-a-game
#   ✔ Accepted
#   ✔ 1053/1053 cases passed (6 ms)
#   ✔ Your runtime beats 3.39 % of java submissions
#   ✔ Your memory usage beats 35.16 % of java submissions (47.1 MB)
# Submitting: java_solutions/3848.check-digitorial-permutation.java
# - Downloading check-digitorial-permutation
#   ✔ Accepted
#   ✔ 1999/1999 cases passed (5 ms)
#   ✔ Your runtime beats 15.22 % of java submissions
#   ✔ Your memory usage beats 10.47 % of java submissions (44.2 MB)
# Submitting: java_solutions/3849.maximum-bitwise-xor-after-rearrangement.java
# - Downloading maximum-bitwise-xor-after-rearrangement
#   ✔ Accepted
#   ✔ 1019/1019 cases passed (57 ms)
#   ✔ Your runtime beats 86.57 % of java submissions
#   ✔ Your memory usage beats 12.86 % of java submissions (56.4 MB)
# Submitting: java_solutions/3850.count-sequences-to-k.java
# - Downloading count-sequences-to-k
#   ✔ Accepted
#   ✔ 999/999 cases passed (14 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 36.4 % of java submissions (54.1 MB)
# Submitting: java_solutions/3852.smallest-pair-with-different-frequencies.java
# - Downloading smallest-pair-with-different-frequencies
#   ✔ Accepted
#   ✔ 877/877 cases passed (5 ms)
#   ✔ Your runtime beats 71.08 % of java submissions
#   ✔ Your memory usage beats 40.26 % of java submissions (47.1 MB)
# Submitting: java_solutions/3853.merge-close-characters.java
# - Downloading merge-close-characters
#   ✔ Accepted
#   ✔ 1051/1051 cases passed (5 ms)
#   ✔ Your runtime beats 44.28 % of java submissions
#   ✔ Your memory usage beats 17.35 % of java submissions (45.5 MB)
# Submitting: java_solutions/3854.minimum-operations-to-make-array-parity-alternating.java
# - Downloading minimum-operations-to-make-array-parity-alternating
#   ✔ Accepted
#   ✔ 1028/1028 cases passed (123 ms)
#   ✔ Your runtime beats 19.23 % of java submissions
#   ✔ Your memory usage beats 98.6 % of java submissions (145.5 MB)
# Submitting: java_solutions/3855.sum-of-k-digit-numbers-in-a-range.java
# - Downloading sum-of-k-digit-numbers-in-a-range
#   ✔ Accepted
#   ✔ 1500/1500 cases passed (17 ms)
#   ✔ Your runtime beats 5.52 % of java submissions
#   ✔ Your memory usage beats 6.21 % of java submissions (53.3 MB)
# Submitting: java_solutions/3856.trim-trailing-vowels.java
# - Downloading trim-trailing-vowels
#   ✔ Accepted
#   ✔ 989/989 cases passed (3 ms)
#   ✔ Your runtime beats 12.24 % of java submissions
#   ✔ Your memory usage beats 6.89 % of java submissions (45.6 MB)
# Submitting: java_solutions/3857.minimum-cost-to-split-into-ones.java
# - Downloading minimum-cost-to-split-into-ones
#   ✔ Accepted
#   ✔ 500/500 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 49.88 % of java submissions (42.5 MB)
# Submitting: java_solutions/3858.minimum-bitwise-or-from-grid.java
# - Downloading minimum-bitwise-or-from-grid
#   ✔ Accepted
#   ✔ 1007/1007 cases passed (8 ms)
#   ✔ Your runtime beats 30.67 % of java submissions
#   ✔ Your memory usage beats 42.33 % of java submissions (136.7 MB)
# Submitting: java_solutions/3859.count-subarrays-with-k-distinct-integers.java
# - Downloading count-subarrays-with-k-distinct-integers
#   ✔ Accepted
#   ✔ 1078/1078 cases passed (15 ms)
#   ✔ Your runtime beats 97.33 % of java submissions
#   ✔ Your memory usage beats 8 % of java submissions (91.2 MB)
# Submitting: java_solutions/3861.minimum-capacity-box.java
# - Downloading minimum-capacity-box
#   ✔ Accepted
#   ✔ 630/630 cases passed (4 ms)
#   ✔ Your runtime beats 2.75 % of java submissions
#   ✔ Your memory usage beats 5.97 % of java submissions (45.2 MB)
# Submitting: java_solutions/3862.find-the-smallest-balanced-index.java
# - Downloading find-the-smallest-balanced-index
#   ✔ Accepted
#   ✔ 912/912 cases passed (10 ms)
#   ✔ Your runtime beats 23.64 % of java submissions
#   ✔ Your memory usage beats 77.63 % of java submissions (140.2 MB)
# Submitting: java_solutions/3863.minimum-operations-to-sort-a-string.java
# - Downloading minimum-operations-to-sort-a-string
#   ✔ Accepted
#   ✔ 1291/1291 cases passed (272 ms)
#   ✔ Your runtime beats 5.01 % of java submissions
#   ✔ Your memory usage beats 5.04 % of java submissions (79.6 MB)
# Submitting: java_solutions/3864.minimum-cost-to-partition-a-binary-string.java
# - Downloading minimum-cost-to-partition-a-binary-string
#   ✔ Accepted
#   ✔ 1009/1009 cases passed (13 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 20.9 % of java submissions (72.3 MB)
# Submitting: java_solutions/3866.first-unique-even-element.java
# - Downloading first-unique-even-element
#   ✔ Accepted
#   ✔ 824/824 cases passed (14 ms)
#   ✔ Your runtime beats 2.4 % of java submissions
#   ✔ Your memory usage beats 13.51 % of java submissions (47.3 MB)
# Submitting: java_solutions/3867.sum-of-gcd-of-formed-pairs.java
# - Downloading sum-of-gcd-of-formed-pairs
#   ✔ Accepted
#   ✔ 1012/1012 cases passed (76 ms)
#   ✔ Your runtime beats 7.06 % of java submissions
#   ✔ Your memory usage beats 6.43 % of java submissions (130.6 MB)
# Submitting: java_solutions/3868.minimum-cost-to-equalize-arrays-using-swaps.java
# - Downloading minimum-cost-to-equalize-arrays-using-swaps
#   ✔ Accepted
#   ✔ 960/960 cases passed (109 ms)
#   ✔ Your runtime beats 69.58 % of java submissions
#   ✔ Your memory usage beats 63.11 % of java submissions (169.2 MB)
# Submitting: java_solutions/3869.count-fancy-numbers-in-a-range.java
# - Downloading count-fancy-numbers-in-a-range
#   ✔ Accepted
#   ✔ 747/747 cases passed (14 ms)
#   ✔ Your runtime beats 98.64 % of java submissions
#   ✔ Your memory usage beats 22.93 % of java submissions (280.8 MB)
# Submitting: java_solutions/3870.count-commas-in-range.java
# - Downloading count-commas-in-range
#   ✔ Accepted
#   ✔ 999/999 cases passed (4 ms)
#   ✔ Your runtime beats 20.14 % of java submissions
#   ✔ Your memory usage beats 7.71 % of java submissions (43.2 MB)
# Submitting: java_solutions/3871.count-commas-in-range-ii.java
# - Downloading count-commas-in-range-ii
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 7: error: method countCommas in class Solution cannot be applied to given types; [in __Driver__.java]
#   ✘ Error: Line 7: error: method countCommas in class Solution cannot be applied to given types; [in __Driver__.java]
#       long ret = new Solution().countCommas(param_1);
#                                ^
#   required: long,long
#   found:    long
#   reason: actual and formal argument lists differ in length
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: java_solutions/3872.longest-arithmetic-sequence-after-changing-at-most-one-element.java
# - Downloading longest-arithmetic-sequence-after-changing-at-most-one-element
#   ✔ Accepted
#   ✔ 911/911 cases passed (32 ms)
#   ✔ Your runtime beats 10.92 % of java submissions
#   ✔ Your memory usage beats 69.81 % of java submissions (161.8 MB)
# Submitting: java_solutions/3873.maximum-points-activated-with-one-addition.java
# - Downloading maximum-points-activated-with-one-addition
#   ✔ Accepted
#   ✔ 1007/1007 cases passed (135 ms)
#   ✔ Your runtime beats 29.98 % of java submissions
#   ✔ Your memory usage beats 27.06 % of java submissions (279.5 MB)
# Submitting: java_solutions/3875.construct-uniform-parity-array-i.java
# - Downloading construct-uniform-parity-array-i
#   ✔ Accepted
#   ✔ 999/999 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 91.37 % of java submissions (44.9 MB)
# Submitting: java_solutions/3876.construct-uniform-parity-array-ii.java
# - Downloading construct-uniform-parity-array-ii
#   ✔ Accepted
#   ✔ 1019/1019 cases passed (10 ms)
#   ✔ Your runtime beats 37.81 % of java submissions
#   ✔ Your memory usage beats 54.61 % of java submissions (121.6 MB)
# Submitting: java_solutions/3877.minimum-removals-to-achieve-target-xor.java
# - Downloading minimum-removals-to-achieve-target-xor
#   ✔ Accepted
#   ✔ 1048/1048 cases passed (1354 ms)
#   ✔ Your runtime beats 5.01 % of java submissions
#   ✔ Your memory usage beats 86.71 % of java submissions (47.3 MB)
# Submitting: java_solutions/3878.count-good-subarrays.java
# - Downloading count-good-subarrays
#   ✔ Accepted
#   ✔ 787/787 cases passed (1724 ms)
#   ✔ Your runtime beats 8.9 % of java submissions
#   ✔ Your memory usage beats 23.56 % of java submissions (139.3 MB)
# Submitting: java_solutions/3880.minimum-absolute-difference-between-two-values.java
# - Downloading minimum-absolute-difference-between-two-values
#   ✔ Accepted
#   ✔ 708/708 cases passed (6 ms)
#   ✔ Your runtime beats 1.69 % of java submissions
#   ✔ Your memory usage beats 5.12 % of java submissions (47.4 MB)
# Submitting: java_solutions/3881.direction-assignments-with-exactly-k-visible-people.java
# - Downloading direction-assignments-with-exactly-k-visible-people
#   ✔ Accepted
#   ✔ 999/999 cases passed (810 ms)
#   ✔ Your runtime beats 5 % of java submissions
#   ✔ Your memory usage beats 11.85 % of java submissions (50.6 MB)
# Submitting: java_solutions/3882.minimum-xor-path-in-a-grid.java
# - Downloading minimum-xor-path-in-a-grid
#   ✔ Accepted
#   ✔ 999/999 cases passed (223 ms)
#   ✔ Your runtime beats 64.77 % of java submissions
#   ✔ Your memory usage beats 72.1 % of java submissions (48.5 MB)
# Submitting: java_solutions/3883.count-non-decreasing-arrays-with-given-digit-sums.java
# - Downloading count-non-decreasing-arrays-with-given-digit-sums
#   ✔ Accepted
#   ✔ 663/663 cases passed (1798 ms)
#   ✔ Your runtime beats 10.44 % of java submissions
#   ✔ Your memory usage beats 24.74 % of java submissions (53.4 MB)
# Submitting: java_solutions/3884.first-matching-character-from-both-ends.java
# - Downloading first-matching-character-from-both-ends
#   ✔ Accepted
#   ✔ 673/673 cases passed (3 ms)
#   ✔ Your runtime beats 0.4 % of java submissions
#   ✔ Your memory usage beats 5.15 % of java submissions (43.9 MB)
# Submitting: java_solutions/3885.design-event-manager.java
# - Downloading design-event-manager
#   ✔ Accepted
#   ✔ 788/788 cases passed (272 ms)
#   ✔ Your runtime beats 14.13 % of java submissions
#   ✔ Your memory usage beats 11.67 % of java submissions (235.5 MB)
# Submitting: java_solutions/3886.sum-of-sortable-integers.java
# - Downloading sum-of-sortable-integers
#   ✔ Accepted
#   ✔ 1053/1053 cases passed (661 ms)
#   ✔ Your runtime beats 9.06 % of java submissions
#   ✔ Your memory usage beats 12.48 % of java submissions (83.1 MB)
# Submitting: java_solutions/3887.incremental-even-weighted-cycle-queries.java
# - Downloading incremental-even-weighted-cycle-queries
#   ✔ Accepted
#   ✔ 1008/1008 cases passed (216 ms)
#   ✔ Your runtime beats 5.22 % of java submissions
#   ✔ Your memory usage beats 100 % of java submissions (167.4 MB)
# Submitting: java_solutions/3889.mirror-frequency-distance.java
# - Downloading mirror-frequency-distance
#   ✔ Accepted
#   ✔ 1000/1000 cases passed (22 ms)
#   ✔ Your runtime beats 84.25 % of java submissions
#   ✔ Your memory usage beats 98.02 % of java submissions (53.4 MB)
# Submitting: java_solutions/3890.integers-with-multiple-sum-of-two-cubes.java
# - Downloading integers-with-multiple-sum-of-two-cubes
#   ✔ Accepted
#   ✔ 653/653 cases passed (179 ms)
#   ✔ Your runtime beats 96.25 % of java submissions
#   ✔ Your memory usage beats 96.68 % of java submissions (86 MB)
# Submitting: java_solutions/3891.minimum-increase-to-maximize-special-indices.java
# - Downloading minimum-increase-to-maximize-special-indices
#   ✔ Accepted
#   ✔ 1027/1027 cases passed (58 ms)
#   ✔ Your runtime beats 10.36 % of java submissions
#   ✔ Your memory usage beats 10.51 % of java submissions (149.7 MB)
# Submitting: java_solutions/3892.minimum-operations-to-achieve-at-least-k-peaks.java
# - Downloading minimum-operations-to-achieve-at-least-k-peaks
#   ✔ Accepted
#   ✔ 1142/1142 cases passed (2547 ms)
#   ✔ Your runtime beats 5.04 % of java submissions
#   ✔ Your memory usage beats 57.42 % of java submissions (204.8 MB)
# Submitting: java_solutions/3894.traffic-signal-color.java
# - Downloading traffic-signal-color
#   ✔ Accepted
#   ✔ 999/999 cases passed (4 ms)
#   ✔ Your runtime beats 0.36 % of java submissions
#   ✔ Your memory usage beats 5.56 % of java submissions (43.9 MB)
# Submitting: java_solutions/3895.count-digit-appearances.java
# - Downloading count-digit-appearances
#   ✔ Accepted
#   ✔ 751/751 cases passed (8 ms)
#   ✔ Your runtime beats 9.28 % of java submissions
#   ✔ Your memory usage beats 42.62 % of java submissions (47.1 MB)
# Submitting: java_solutions/3896.minimum-operations-to-transform-array-into-alternating-prime.java
# - Downloading minimum-operations-to-transform-array-into-alternating-prime
#   ✔ Accepted
#   ✔ 530/530 cases passed (180 ms)
#   ✔ Your runtime beats 65.65 % of java submissions
#   ✔ Your memory usage beats 81.77 % of java submissions (92.5 MB)
# Submitting: java_solutions/3898.find-the-degree-of-each-vertex.java
# - Downloading find-the-degree-of-each-vertex
#   ✔ Accepted
#   ✔ 701/701 cases passed (3 ms)
#   ✔ Your runtime beats 61.2 % of java submissions
#   ✔ Your memory usage beats 31.82 % of java submissions (48.5 MB)
# Submitting: java_solutions/3899.angles-of-a-triangle.java
# - Downloading angles-of-a-triangle
#   ✔ Accepted
#   ✔ 918/918 cases passed (2 ms)
#   ✔ Your runtime beats 99.64 % of java submissions
#   ✔ Your memory usage beats 98.76 % of java submissions (49 MB)
# Submitting: java_solutions/3900.longest-balanced-substring-after-one-swap.java
# - Downloading longest-balanced-substring-after-one-swap
#   ✔ Accepted
#   ✔ 992/992 cases passed (46 ms)
#   ✔ Your runtime beats 74.02 % of java submissions
#   ✔ Your memory usage beats 78.91 % of java submissions (49.3 MB)
# Submitting: java_solutions/3903.smallest-stable-index-i.java
# - Downloading smallest-stable-index-i
#   ✔ Accepted
#   ✔ 941/941 cases passed (5 ms)
#   ✔ Your runtime beats 3.27 % of java submissions
#   ✔ Your memory usage beats 20.87 % of java submissions (46.5 MB)
# Submitting: java_solutions/3904.smallest-stable-index-ii.java
# - Downloading smallest-stable-index-ii
#   ✔ Accepted
#   ✔ 928/928 cases passed (10 ms)
#   ✔ Your runtime beats 4.43 % of java submissions
#   ✔ Your memory usage beats 30.96 % of java submissions (133.1 MB)
# Submitting: java_solutions/3905.multi-source-flood-fill.java
# - Downloading multi-source-flood-fill
#   ✔ Accepted
#   ✔ 530/530 cases passed (91 ms)
#   ✔ Your runtime beats 46.33 % of java submissions
#   ✔ Your memory usage beats 80.55 % of java submissions (96.7 MB)
# Submitting: java_solutions/3908.valid-digit-number.java
# - Downloading valid-digit-number
#   ✔ Accepted
#   ✔ 999/999 cases passed (1 ms)
#   ✔ Your runtime beats 99.11 % of java submissions
#   ✔ Your memory usage beats 7.23 % of java submissions (42.9 MB)
# Submitting: java_solutions/3909.compare-sums-of-bitonic-parts.java
# - Downloading compare-sums-of-bitonic-parts
#   ✔ Accepted
#   ✔ 1011/1011 cases passed (6 ms)
#   ✔ Your runtime beats 6.15 % of java submissions
#   ✔ Your memory usage beats 99.45 % of java submissions (98.7 MB)
# Submitting: java_solutions/3912.valid-elements-in-an-array.java
# - Downloading valid-elements-in-an-array
#   ✔ Accepted
#   ✔ 973/973 cases passed (2 ms)
#   ✔ Your runtime beats 20.42 % of java submissions
#   ✔ Your memory usage beats 92.33 % of java submissions (46.5 MB)
# Submitting: java_solutions/3913.sort-vowels-by-frequency.java
# - Downloading sort-vowels-by-frequency
#   ✔ Accepted
#   ✔ 999/999 cases passed (64 ms)
#   ✔ Your runtime beats 26.41 % of java submissions
#   ✔ Your memory usage beats 37.96 % of java submissions (48.5 MB)
# Submitting: java_solutions/3914.minimum-operations-to-make-array-non-decreasing.java
# - Downloading minimum-operations-to-make-array-non-decreasing
#   ✔ Accepted
#   ✔ 999/999 cases passed (8 ms)
#   ✔ Your runtime beats 2.06 % of java submissions
#   ✔ Your memory usage beats 22.48 % of java submissions (87.6 MB)

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-05-05 18:08:01
