# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME')
    user_cookie = userdata.get('LEETCODE_TOKEN')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME'] = user_name
    os.environ['LEETCODE_TOKEN'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME" "$LEETCODE_TOKEN" | leetcode user -c

# %%
# %%bash
#
#
# # top 100 answers
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v java_solutions/*.java | sed -n '1201,1350p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 8
# done
# Out:
# Submitting: java_solutions/1968.array-with-elements-not-equal-to-average-of-neighbors.java
# - Downloading problems
# - Downloading array-with-elements-not-equal-to-average-of-neighbors
#   ✔ Accepted
#   ✔ 293/293 cases passed (58 ms)
#   ✔ Your runtime beats 14.35 % of java submissions
#   ✔ Your memory usage beats 99.04 % of java submissions (158.3 MB)
# Submitting: java_solutions/1969.minimum-non-zero-product-of-the-array-elements.java
# - Downloading minimum-non-zero-product-of-the-array-elements
#   ✔ Accepted
#   ✔ 60/60 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 17.31 % of java submissions (42.2 MB)
# Submitting: java_solutions/1970.last-day-where-you-can-still-cross.java
# - Downloading last-day-where-you-can-still-cross
#   ✔ Accepted
#   ✔ 118/118 cases passed (125 ms)
#   ✔ Your runtime beats 8.84 % of java submissions
#   ✔ Your memory usage beats 5.05 % of java submissions (94.4 MB)
# Submitting: java_solutions/1971.find-if-path-exists-in-graph.java
# - Downloading find-if-path-exists-in-graph
#   ✔ Accepted
#   ✔ 35/35 cases passed (17 ms)
#   ✔ Your runtime beats 93.27 % of java submissions
#   ✔ Your memory usage beats 92.16 % of java submissions (249.7 MB)
# Submitting: java_solutions/1974.minimum-time-to-type-word-using-special-typewriter.java
# - Downloading minimum-time-to-type-word-using-special-typewriter
#   ✔ Accepted
#   ✔ 135/135 cases passed (4 ms)
#   ✔ Your runtime beats 2.25 % of java submissions
#   ✔ Your memory usage beats 10.51 % of java submissions (43.2 MB)
# Submitting: java_solutions/1975.maximum-matrix-sum.java
# - Downloading maximum-matrix-sum
#   ✔ Accepted
#   ✔ 98/98 cases passed (13 ms)
#   ✔ Your runtime beats 5.08 % of java submissions
#   ✔ Your memory usage beats 83.46 % of java submissions (67.8 MB)
# Submitting: java_solutions/1976.number-of-ways-to-arrive-at-destination.java
# - Downloading number-of-ways-to-arrive-at-destination
#   ✔ Accepted
#   ✔ 57/57 cases passed (19 ms)
#   ✔ Your runtime beats 8.74 % of java submissions
#   ✔ Your memory usage beats 5.55 % of java submissions (52.8 MB)
# Submitting: java_solutions/1977.number-of-ways-to-separate-numbers.java
# - Downloading number-of-ways-to-separate-numbers
#   ✔ Accepted
#   ✔ 257/257 cases passed (175 ms)
#   ✔ Your runtime beats 41.27 % of java submissions
#   ✔ Your memory usage beats 42.86 % of java submissions (143.4 MB)
# Submitting: java_solutions/1979.find-greatest-common-divisor-of-array.java
# - Downloading find-greatest-common-divisor-of-array
#   ✔ Accepted
#   ✔ 215/215 cases passed (6 ms)
#   ✔ Your runtime beats 20.4 % of java submissions
#   ✔ Your memory usage beats 17.81 % of java submissions (45.5 MB)
# Submitting: java_solutions/1980.find-unique-binary-string.java
# - Downloading find-unique-binary-string
#   ✔ Accepted
#   ✔ 186/186 cases passed (1 ms)
#   ✔ Your runtime beats 65.38 % of java submissions
#   ✔ Your memory usage beats 48.17 % of java submissions (43.3 MB)
# Submitting: java_solutions/1981.minimize-the-difference-between-target-and-chosen-elements.java
# - Downloading minimize-the-difference-between-target-and-chosen-elements
#   ✔ Accepted
#   ✔ 81/81 cases passed (1587 ms)
#   ✔ Your runtime beats 17.72 % of java submissions
#   ✔ Your memory usage beats 15.75 % of java submissions (53.2 MB)
# Submitting: java_solutions/1982.find-array-given-subset-sums.java
# - Downloading find-array-given-subset-sums
#   ✔ Accepted
#   ✔ 131/131 cases passed (307 ms)
#   ✔ Your runtime beats 12.34 % of java submissions
#   ✔ Your memory usage beats 32.1 % of java submissions (68.8 MB)
# Submitting: java_solutions/1984.minimum-difference-between-highest-and-lowest-of-k-scores.java
# - Downloading minimum-difference-between-highest-and-lowest-of-k-scores
#   ✔ Accepted
#   ✔ 118/118 cases passed (1321 ms)
#   ✔ Your runtime beats 6.07 % of java submissions
#   ✔ Your memory usage beats 5.37 % of java submissions (47.2 MB)
# Submitting: java_solutions/1985.find-the-kth-largest-integer-in-the-array.java
# - Downloading find-the-kth-largest-integer-in-the-array
#   ✔ Accepted
#   ✔ 219/219 cases passed (21 ms)
#   ✔ Your runtime beats 60.96 % of java submissions
#   ✔ Your memory usage beats 15.94 % of java submissions (55.1 MB)
# Submitting: java_solutions/1986.minimum-number-of-work-sessions-to-finish-the-tasks.java
# - Downloading minimum-number-of-work-sessions-to-finish-the-tasks
#   ✔ Accepted
#   ✔ 96/96 cases passed (31 ms)
#   ✔ Your runtime beats 43.81 % of java submissions
#   ✔ Your memory usage beats 61.43 % of java submissions (43.8 MB)
# Submitting: java_solutions/1987.number-of-unique-good-subsequences.java
# - Downloading number-of-unique-good-subsequences
#   ✔ Accepted
#   ✔ 69/69 cases passed (12 ms)
#   ✔ Your runtime beats 17.11 % of java submissions
#   ✔ Your memory usage beats 38.16 % of java submissions (47.8 MB)
# Submitting: java_solutions/1991.find-the-middle-index-in-array.java
# - Downloading find-the-middle-index-in-array
#   ✔ Accepted
#   ✔ 294/294 cases passed (15 ms)
#   ✔ Your runtime beats 0.8 % of java submissions
#   ✔ Your memory usage beats 8.11 % of java submissions (46.4 MB)
# Submitting: java_solutions/1992.find-all-groups-of-farmland.java
# - Downloading find-all-groups-of-farmland
#   ✔ Accepted
#   ✔ 220/220 cases passed (4 ms)
#   ✔ Your runtime beats 81.41 % of java submissions
#   ✔ Your memory usage beats 83.42 % of java submissions (91 MB)
# Submitting: java_solutions/1993.operations-on-tree.java
# - Downloading operations-on-tree
#   ✔ Accepted
#   ✔ 151/151 cases passed (1155 ms)
#   ✔ Your runtime beats 5.26 % of java submissions
#   ✔ Your memory usage beats 6.14 % of java submissions (93.1 MB)
# Submitting: java_solutions/1994.the-number-of-good-subsets.java
# - Downloading the-number-of-good-subsets
#   ✔ Accepted
#   ✔ 92/92 cases passed (82 ms)
#   ✔ Your runtime beats 12.37 % of java submissions
#   ✔ Your memory usage beats 5.15 % of java submissions (166.2 MB)
# Submitting: java_solutions/1995.count-special-quadruplets.java
# - Downloading count-special-quadruplets
#   ✔ Accepted
#   ✔ 211/211 cases passed (33 ms)
#   ✔ Your runtime beats 6.06 % of java submissions
#   ✔ Your memory usage beats 100 % of java submissions (42.1 MB)
# Submitting: java_solutions/1996.the-number-of-weak-characters-in-the-game.java
# - Downloading the-number-of-weak-characters-in-the-game
#   ✔ Accepted
#   ✔ 44/44 cases passed (99 ms)
#   ✔ Your runtime beats 13.14 % of java submissions
#   ✔ Your memory usage beats 5.13 % of java submissions (157.1 MB)
# Submitting: java_solutions/1997.first-day-where-you-have-been-in-all-the-rooms.java
# - Downloading first-day-where-you-have-been-in-all-the-rooms
#   ✔ Accepted
#   ✔ 239/239 cases passed (12 ms)
#   ✔ Your runtime beats 5.56 % of java submissions
#   ✔ Your memory usage beats 72.22 % of java submissions (81 MB)
# Submitting: java_solutions/1998.gcd-sort-of-an-array.java
# - Downloading gcd-sort-of-an-array
#   ✔ Accepted
#   ✔ 92/92 cases passed (695 ms)
#   ✔ Your runtime beats 5.26 % of java submissions
#   ✔ Your memory usage beats 20.12 % of java submissions (66 MB)
# Submitting: java_solutions/2000.reverse-prefix-of-word.java
# - Downloading reverse-prefix-of-word
#   ✔ Accepted
#   ✔ 113/113 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 42.16 % of java submissions (43.2 MB)
# Submitting: java_solutions/2001.number-of-pairs-of-interchangeable-rectangles.java
# - Downloading number-of-pairs-of-interchangeable-rectangles
#   ✔ Accepted
#   ✔ 46/46 cases passed (75 ms)
#   ✔ Your runtime beats 21.45 % of java submissions
#   ✔ Your memory usage beats 5.01 % of java submissions (161.4 MB)
# Submitting: java_solutions/2002.maximum-product-of-the-length-of-two-palindromic-subsequences.java
# - Downloading maximum-product-of-the-length-of-two-palindromic-subsequences
#   ✔ Accepted
#   ✔ 226/226 cases passed (79 ms)
#   ✔ Your runtime beats 71.64 % of java submissions
#   ✔ Your memory usage beats 85.07 % of java submissions (44.5 MB)
# Submitting: java_solutions/2003.smallest-missing-genetic-value-in-each-subtree.java
# - Downloading smallest-missing-genetic-value-in-each-subtree
#   ✔ Accepted
#   ✔ 68/68 cases passed (184 ms)
#   ✔ Your runtime beats 27.91 % of java submissions
#   ✔ Your memory usage beats 88.37 % of java submissions (137.7 MB)
# Submitting: java_solutions/2006.count-number-of-pairs-with-absolute-difference-k.java
# - Downloading count-number-of-pairs-with-absolute-difference-k
#   ✔ Accepted
#   ✔ 237/237 cases passed (34 ms)
#   ✔ Your runtime beats 5.55 % of java submissions
#   ✔ Your memory usage beats 6.89 % of java submissions (47.3 MB)
# Submitting: java_solutions/2007.find-original-array-from-doubled-array.java
# - Downloading find-original-array-from-doubled-array
#   ✔ Accepted
#   ✔ 180/180 cases passed (72 ms)
#   ✔ Your runtime beats 81.36 % of java submissions
#   ✔ Your memory usage beats 96.85 % of java submissions (120.4 MB)
# Submitting: java_solutions/2008.maximum-earnings-from-taxi.java
# - Downloading maximum-earnings-from-taxi
#   ✔ Accepted
#   ✔ 84/84 cases passed (45 ms)
#   ✔ Your runtime beats 92.36 % of java submissions
#   ✔ Your memory usage beats 14.65 % of java submissions (146.6 MB)
# Submitting: java_solutions/2009.minimum-number-of-operations-to-make-array-continuous.java
# - Downloading minimum-number-of-operations-to-make-array-continuous
#   ✔ Accepted
#   ✔ 62/62 cases passed (100 ms)
#   ✔ Your runtime beats 14.29 % of java submissions
#   ✔ Your memory usage beats 71.01 % of java submissions (90.9 MB)
# Submitting: java_solutions/2011.final-value-of-variable-after-performing-operations.java
# - Downloading final-value-of-variable-after-performing-operations
#   ✔ Accepted
#   ✔ 259/259 cases passed (4 ms)
#   ✔ Your runtime beats 1.45 % of java submissions
#   ✔ Your memory usage beats 12.91 % of java submissions (44.8 MB)
# Submitting: java_solutions/2012.sum-of-beauty-in-the-array.java
# - Downloading sum-of-beauty-in-the-array
#   ✔ Accepted
#   ✔ 62/62 cases passed (13 ms)
#   ✔ Your runtime beats 2.94 % of java submissions
#   ✔ Your memory usage beats 6.37 % of java submissions (98.7 MB)
# Submitting: java_solutions/2013.detect-squares.java
# - Downloading detect-squares
#   ✔ Accepted
#   ✔ 55/55 cases passed (175 ms)
#   ✔ Your runtime beats 21.18 % of java submissions
#   ✔ Your memory usage beats 5.16 % of java submissions (271.4 MB)
# Submitting: java_solutions/2014.longest-subsequence-repeated-k-times.java
# - Downloading longest-subsequence-repeated-k-times
#   ✔ Accepted
#   ✔ 314/314 cases passed (1644 ms)
#   ✔ Your runtime beats 6.01 % of java submissions
#   ✔ Your memory usage beats 9.02 % of java submissions (53.4 MB)
# Submitting: java_solutions/2016.maximum-difference-between-increasing-elements.java
# - Downloading maximum-difference-between-increasing-elements
#   ✔ Accepted
#   ✔ 54/54 cases passed (45 ms)
#   ✔ Your runtime beats 5.13 % of java submissions
#   ✔ Your memory usage beats 8.67 % of java submissions (46.7 MB)
# Submitting: java_solutions/2017.grid-game.java
# - Downloading grid-game
#   ✔ Accepted
#   ✔ 109/109 cases passed (12 ms)
#   ✔ Your runtime beats 9.09 % of java submissions
#   ✔ Your memory usage beats 92.42 % of java submissions (95.6 MB)
# Submitting: java_solutions/2018.check-if-word-can-be-placed-in-crossword.java
# - Downloading check-if-word-can-be-placed-in-crossword
#   ✔ Accepted
#   ✔ 154/154 cases passed (15 ms)
#   ✔ Your runtime beats 23 % of java submissions
#   ✔ Your memory usage beats 58 % of java submissions (104.3 MB)
# Submitting: java_solutions/2019.the-score-of-students-solving-math-expression.java
# - Downloading the-score-of-students-solving-math-expression
#   ✔ Accepted
#   ✔ 274/274 cases passed (905 ms)
#   ✔ Your runtime beats 5.66 % of java submissions
#   ✔ Your memory usage beats 5.66 % of java submissions (66.2 MB)
# Submitting: java_solutions/2022.convert-1d-array-into-2d-array.java
# - Downloading convert-1d-array-into-2d-array
#   ✔ Accepted
#   ✔ 107/107 cases passed (7 ms)
#   ✔ Your runtime beats 0.87 % of java submissions
#   ✔ Your memory usage beats 39.95 % of java submissions (67.2 MB)
# Submitting: java_solutions/2023.number-of-pairs-of-strings-with-concatenation-equal-to-target.java
# - Downloading number-of-pairs-of-strings-with-concatenation-equal-to-target
#   ✔ Accepted
#   ✔ 117/117 cases passed (11 ms)
#   ✔ Your runtime beats 53.97 % of java submissions
#   ✔ Your memory usage beats 82.71 % of java submissions (44.1 MB)
# Submitting: java_solutions/2024.maximize-the-confusion-of-an-exam.java
# - Downloading maximize-the-confusion-of-an-exam
#   ✔ Accepted
#   ✔ 93/93 cases passed (24 ms)
#   ✔ Your runtime beats 11.24 % of java submissions
#   ✔ Your memory usage beats 9.91 % of java submissions (46.9 MB)
# Submitting: java_solutions/2025.maximum-number-of-ways-to-partition-an-array.java
# - Downloading maximum-number-of-ways-to-partition-an-array
#   ✔ Accepted
#   ✔ 179/179 cases passed (383 ms)
#   ✔ Your runtime beats 6.67 % of java submissions
#   ✔ Your memory usage beats 8.89 % of java submissions (198.5 MB)
# Submitting: java_solutions/2027.minimum-moves-to-convert-string.java
# - Downloading minimum-moves-to-convert-string
#   ✔ Accepted
#   ✔ 55/55 cases passed (5 ms)
#   ✔ Your runtime beats 1.24 % of java submissions
#   ✔ Your memory usage beats 11.91 % of java submissions (43.1 MB)
# Submitting: java_solutions/2028.find-missing-observations.java
# - Downloading find-missing-observations
#   ✔ Accepted
#   ✔ 64/64 cases passed (9 ms)
#   ✔ Your runtime beats 6.11 % of java submissions
#   ✔ Your memory usage beats 57.78 % of java submissions (147 MB)
# Submitting: java_solutions/2029.stone-game-ix.java
# - Downloading stone-game-ix
#   ✔ Accepted
#   ✔ 106/106 cases passed (6 ms)
#   ✔ Your runtime beats 40.58 % of java submissions
#   ✔ Your memory usage beats 46.38 % of java submissions (114.8 MB)
# Submitting: java_solutions/2030.smallest-k-length-subsequence-with-occurrences-of-a-letter.java
# - Downloading smallest-k-length-subsequence-with-occurrences-of-a-letter
#   ✔ Accepted
#   ✔ 152/152 cases passed (580 ms)
#   ✔ Your runtime beats 16.98 % of java submissions
#   ✔ Your memory usage beats 7.55 % of java submissions (53.4 MB)
# Submitting: java_solutions/2032.two-out-of-three.java
# - Downloading two-out-of-three
#   ✔ Accepted
#   ✔ 288/288 cases passed (28 ms)
#   ✔ Your runtime beats 6.83 % of java submissions
#   ✔ Your memory usage beats 8.06 % of java submissions (53.3 MB)
# Submitting: java_solutions/2033.minimum-operations-to-make-a-uni-value-grid.java
# - Downloading minimum-operations-to-make-a-uni-value-grid
#   ✔ Accepted
#   ✔ 64/64 cases passed (64 ms)
#   ✔ Your runtime beats 49.77 % of java submissions
#   ✔ Your memory usage beats 23.49 % of java submissions (115.6 MB)
# Submitting: java_solutions/2034.stock-price-fluctuation.java
# - Downloading stock-price-fluctuation
#   ✔ Accepted
#   ✔ 18/18 cases passed (128 ms)
#   ✔ Your runtime beats 27.55 % of java submissions
#   ✔ Your memory usage beats 73.88 % of java submissions (129.7 MB)
# Submitting: java_solutions/2035.partition-array-into-two-arrays-to-minimize-sum-difference.java
# - Downloading partition-array-into-two-arrays-to-minimize-sum-difference
#   ✔ Accepted
#   ✔ 201/201 cases passed (2479 ms)
#   ✔ Your runtime beats 5.09 % of java submissions
#   ✔ Your memory usage beats 5.09 % of java submissions (224.7 MB)
# Submitting: java_solutions/2037.minimum-number-of-moves-to-seat-everyone.java
# - Downloading minimum-number-of-moves-to-seat-everyone
#   ✔ Accepted
#   ✔ 262/262 cases passed (12 ms)
#   ✔ Your runtime beats 5.57 % of java submissions
#   ✔ Your memory usage beats 10.34 % of java submissions (46.9 MB)
# Submitting: java_solutions/2038.remove-colored-pieces-if-both-neighbors-are-the-same-color.java
# - Downloading remove-colored-pieces-if-both-neighbors-are-the-same-color
#   ✔ Accepted
#   ✔ 84/84 cases passed (19 ms)
#   ✔ Your runtime beats 12.72 % of java submissions
#   ✔ Your memory usage beats 34.91 % of java submissions (47.7 MB)
# Submitting: java_solutions/2039.the-time-when-the-network-becomes-idle.java
# - Downloading the-time-when-the-network-becomes-idle
#   ✔ Accepted
#   ✔ 50/50 cases passed (23 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 97.76 % of java submissions (162.9 MB)
# Submitting: java_solutions/2040.kth-smallest-product-of-two-sorted-arrays.java
# - Downloading kth-smallest-product-of-two-sorted-arrays
#   ✔ Accepted
#   ✔ 112/112 cases passed (1254 ms)
#   ✔ Your runtime beats 5.56 % of java submissions
#   ✔ Your memory usage beats 44.44 % of java submissions (62.9 MB)
# Submitting: java_solutions/2042.check-if-numbers-are-ascending-in-a-sentence.java
# - Downloading check-if-numbers-are-ascending-in-a-sentence
#   ✔ Accepted
#   ✔ 98/98 cases passed (12 ms)
#   ✔ Your runtime beats 6.99 % of java submissions
#   ✔ Your memory usage beats 13.83 % of java submissions (44.4 MB)
# Submitting: java_solutions/2043.simple-bank-system.java
# - Downloading simple-bank-system
#   ✔ Accepted
#   ✔ 23/23 cases passed (114 ms)
#   ✔ Your runtime beats 7.77 % of java submissions
#   ✔ Your memory usage beats 99.04 % of java submissions (123 MB)
# Submitting: java_solutions/2044.count-number-of-maximum-bitwise-or-subsets.java
# - Downloading count-number-of-maximum-bitwise-or-subsets
#   ✔ Accepted
#   ✔ 111/111 cases passed (109 ms)
#   ✔ Your runtime beats 10.67 % of java submissions
#   ✔ Your memory usage beats 25.9 % of java submissions (43.4 MB)
# Submitting: java_solutions/2045.second-minimum-time-to-reach-destination.java
# - Downloading second-minimum-time-to-reach-destination
#   ✔ Accepted
#   ✔ 77/77 cases passed (427 ms)
#   ✔ Your runtime beats 5.2 % of java submissions
#   ✔ Your memory usage beats 6.4 % of java submissions (155.1 MB)
# Submitting: java_solutions/2047.number-of-valid-words-in-a-sentence.java
# - Downloading number-of-valid-words-in-a-sentence
#   ✔ Accepted
#   ✔ 244/244 cases passed (45 ms)
#   ✔ Your runtime beats 8.21 % of java submissions
#   ✔ Your memory usage beats 13.53 % of java submissions (47.5 MB)
# Submitting: java_solutions/2048.next-greater-numerically-balanced-number.java
# - Downloading next-greater-numerically-balanced-number
#   ✔ Accepted
#   ✔ 145/145 cases passed (168 ms)
#   ✔ Your runtime beats 22.2 % of java submissions
#   ✔ Your memory usage beats 14.8 % of java submissions (46.5 MB)
# Submitting: java_solutions/2049.count-nodes-with-the-highest-score.java
# - Downloading count-nodes-with-the-highest-score
#   ✔ Accepted
#   ✔ 206/206 cases passed (32 ms)
#   ✔ Your runtime beats 87.29 % of java submissions
#   ✔ Your memory usage beats 100 % of java submissions (69 MB)
# Submitting: java_solutions/2050.parallel-courses-iii.java
# - Downloading parallel-courses-iii
#   ✔ Accepted
#   ✔ 42/42 cases passed (74 ms)
#   ✔ Your runtime beats 5.73 % of java submissions
#   ✔ Your memory usage beats 99.59 % of java submissions (106.1 MB)
# Submitting: java_solutions/2053.kth-distinct-string-in-an-array.java
# - Downloading kth-distinct-string-in-an-array
#   ✔ Accepted
#   ✔ 66/66 cases passed (18 ms)
#   ✔ Your runtime beats 12.93 % of java submissions
#   ✔ Your memory usage beats 13.99 % of java submissions (52.5 MB)
# Submitting: java_solutions/2054.two-best-non-overlapping-events.java
# - Downloading two-best-non-overlapping-events
#   ✔ Accepted
#   ✔ 65/65 cases passed (79 ms)
#   ✔ Your runtime beats 27.34 % of java submissions
#   ✔ Your memory usage beats 57.55 % of java submissions (208.4 MB)
# Submitting: java_solutions/2055.plates-between-candles.java
# - Downloading plates-between-candles
#   ✔ Accepted
#   ✔ 37/37 cases passed (15 ms)
#   ✔ Your runtime beats 32.77 % of java submissions
#   ✔ Your memory usage beats 25.21 % of java submissions (152 MB)
# Submitting: java_solutions/2056.number-of-valid-move-combinations-on-chessboard.java
# - Downloading number-of-valid-move-combinations-on-chessboard
#   ✔ Accepted
#   ✔ 273/273 cases passed (1669 ms)
#   ✔ Your runtime beats 8 % of java submissions
#   ✔ Your memory usage beats 12 % of java submissions (53.5 MB)
# Submitting: java_solutions/2057.smallest-index-with-equal-value.java
# - Downloading smallest-index-with-equal-value
#   ✔ Accepted
#   ✔ 663/663 cases passed (6 ms)
#   ✔ Your runtime beats 0.31 % of java submissions
#   ✔ Your memory usage beats 9.95 % of java submissions (46.7 MB)
# Submitting: java_solutions/2058.find-the-minimum-and-maximum-number-of-nodes-between-critical-points.java
# - Downloading find-the-minimum-and-maximum-number-of-nodes-between-critical-points
#   ✔ Accepted
#   ✔ 139/139 cases passed (13 ms)
#   ✔ Your runtime beats 6.14 % of java submissions
#   ✔ Your memory usage beats 85.93 % of java submissions (105.9 MB)
# Submitting: java_solutions/2059.minimum-operations-to-convert-number.java
# - Downloading minimum-operations-to-convert-number
#   ✔ Accepted
#   ✔ 60/60 cases passed (74 ms)
#   ✔ Your runtime beats 26.02 % of java submissions
#   ✔ Your memory usage beats 21.95 % of java submissions (47.5 MB)
# Submitting: java_solutions/2060.check-if-an-original-string-exists-given-two-encoded-strings.java
# - Downloading check-if-an-original-string-exists-given-two-encoded-strings
#   ✔ Accepted
#   ✔ 215/215 cases passed (863 ms)
#   ✔ Your runtime beats 5.66 % of java submissions
#   ✔ Your memory usage beats 49.06 % of java submissions (279.5 MB)
# Submitting: java_solutions/2062.count-vowel-substrings-of-a-string.java
# - Downloading count-vowel-substrings-of-a-string
#   ✔ Accepted
#   ✔ 88/88 cases passed (12 ms)
#   ✔ Your runtime beats 48.64 % of java submissions
#   ✔ Your memory usage beats 77.62 % of java submissions (42.9 MB)
# Submitting: java_solutions/2063.vowels-of-all-substrings.java
# - Downloading vowels-of-all-substrings
#   ✔ Accepted
#   ✔ 51/51 cases passed (18 ms)
#   ✔ Your runtime beats 12.26 % of java submissions
#   ✔ Your memory usage beats 72.96 % of java submissions (46.6 MB)
# Submitting: java_solutions/2064.minimized-maximum-of-products-distributed-to-any-store.java
# - Downloading minimized-maximum-of-products-distributed-to-any-store
#   ✔ Accepted
#   ✔ 220/220 cases passed (27 ms)
#   ✔ Your runtime beats 53.79 % of java submissions
#   ✔ Your memory usage beats 33.84 % of java submissions (81.3 MB)
# Submitting: java_solutions/2065.maximum-path-quality-of-a-graph.java
# - Downloading maximum-path-quality-of-a-graph
#   ✔ Accepted
#   ✔ 62/62 cases passed (631 ms)
#   ✔ Your runtime beats 5.05 % of java submissions
#   ✔ Your memory usage beats 5.64 % of java submissions (53.8 MB)
# Submitting: java_solutions/2068.check-whether-two-strings-are-almost-equivalent.java
# - Downloading check-whether-two-strings-are-almost-equivalent
#   ✔ Accepted
#   ✔ 196/196 cases passed (9 ms)
#   ✔ Your runtime beats 2.66 % of java submissions
#   ✔ Your memory usage beats 5.8 % of java submissions (44.6 MB)
# Submitting: java_solutions/2069.walking-robot-simulation-ii.java
# - Downloading walking-robot-simulation-ii
#   ✔ Accepted
#   ✔ 142/142 cases passed (69 ms)
#   ✔ Your runtime beats 20.31 % of java submissions
#   ✔ Your memory usage beats 6.16 % of java submissions (61.3 MB)
# Submitting: java_solutions/2070.most-beautiful-item-for-each-query.java
# - Downloading most-beautiful-item-for-each-query
#   ✔ Accepted
#   ✔ 35/35 cases passed (57 ms)
#   ✔ Your runtime beats 19.56 % of java submissions
#   ✔ Your memory usage beats 55.2 % of java submissions (130.5 MB)
# Submitting: java_solutions/2071.maximum-number-of-tasks-you-can-assign.java
# - Downloading maximum-number-of-tasks-you-can-assign
#   ✔ Accepted
#   ✔ 49/49 cases passed (562 ms)
#   ✔ Your runtime beats 36.93 % of java submissions
#   ✔ Your memory usage beats 38.07 % of java submissions (70.5 MB)
# Submitting: java_solutions/2073.time-needed-to-buy-tickets.java
# - Downloading time-needed-to-buy-tickets
#   ✔ Accepted
#   ✔ 65/65 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 85.79 % of java submissions (42.9 MB)
# Submitting: java_solutions/2074.reverse-nodes-in-even-length-groups.java
# - Downloading reverse-nodes-in-even-length-groups
#   ✔ Accepted
#   ✔ 165/165 cases passed (17 ms)
#   ✔ Your runtime beats 8.59 % of java submissions
#   ✔ Your memory usage beats 37.88 % of java submissions (197.8 MB)
# Submitting: java_solutions/2075.decode-the-slanted-ciphertext.java
# - Downloading decode-the-slanted-ciphertext
#   ✔ Accepted
#   ✔ 40/40 cases passed (35 ms)
#   ✔ Your runtime beats 22.87 % of java submissions
#   ✔ Your memory usage beats 32.25 % of java submissions (58.3 MB)
# Submitting: java_solutions/2076.process-restricted-friend-requests.java
# - Downloading process-restricted-friend-requests
#   ✔ Accepted
#   ✔ 49/49 cases passed (1014 ms)
#   ✔ Your runtime beats 5.16 % of java submissions
#   ✔ Your memory usage beats 5.71 % of java submissions (53.4 MB)
# Submitting: java_solutions/2078.two-furthest-houses-with-different-colors.java
# - Downloading two-furthest-houses-with-different-colors
#   ✔ Accepted
#   ✔ 126/126 cases passed (14 ms)
#   ✔ Your runtime beats 1.15 % of java submissions
#   ✔ Your memory usage beats 8.02 % of java submissions (44.9 MB)
# Submitting: java_solutions/2079.watering-plants.java
# - Downloading watering-plants
#   ✔ Accepted
#   ✔ 40/40 cases passed (4 ms)
#   ✔ Your runtime beats 3.8 % of java submissions
#   ✔ Your memory usage beats 7.6 % of java submissions (44.4 MB)
# Submitting: java_solutions/2080.range-frequency-queries.java
# - Downloading range-frequency-queries
#   ✔ Accepted
#   ✔ 20/20 cases passed (212 ms)
#   ✔ Your runtime beats 9.8 % of java submissions
#   ✔ Your memory usage beats 17.21 % of java submissions (180.6 MB)
# Submitting: java_solutions/2081.sum-of-k-mirror-numbers.java
# - Downloading sum-of-k-mirror-numbers
#   ✔ Accepted
#   ✔ 97/97 cases passed (875 ms)
#   ✔ Your runtime beats 8.57 % of java submissions
#   ✔ Your memory usage beats 6.43 % of java submissions (53.3 MB)
# Submitting: java_solutions/2085.count-common-words-with-one-occurrence.java
# - Downloading count-common-words-with-one-occurrence
#   ✔ Accepted
#   ✔ 61/61 cases passed (480 ms)
#   ✔ Your runtime beats 5.18 % of java submissions
#   ✔ Your memory usage beats 11.04 % of java submissions (53.2 MB)
# Submitting: java_solutions/2086.minimum-number-of-food-buckets-to-feed-the-hamsters.java
# - Downloading minimum-number-of-food-buckets-to-feed-the-hamsters
#   ✔ Accepted
#   ✔ 208/208 cases passed (10 ms)
#   ✔ Your runtime beats 10.34 % of java submissions
#   ✔ Your memory usage beats 5.02 % of java submissions (47.7 MB)
# Submitting: java_solutions/2087.minimum-cost-homecoming-of-a-robot-in-a-grid.java
# - Downloading minimum-cost-homecoming-of-a-robot-in-a-grid
#   ✔ Accepted
#   ✔ 69/69 cases passed (8 ms)
#   ✔ Your runtime beats 2.08 % of java submissions
#   ✔ Your memory usage beats 26.3 % of java submissions (130.5 MB)
# Submitting: java_solutions/2088.count-fertile-pyramids-in-a-land.java
# - Downloading count-fertile-pyramids-in-a-land
#   ✔ Accepted
#   ✔ 49/49 cases passed (31 ms)
#   ✔ Your runtime beats 7.19 % of java submissions
#   ✔ Your memory usage beats 5.76 % of java submissions (74.5 MB)
# Submitting: java_solutions/2089.find-target-indices-after-sorting-array.java
# - Downloading find-target-indices-after-sorting-array
#   ✔ Accepted
#   ✔ 216/216 cases passed (8 ms)
#   ✔ Your runtime beats 26.96 % of java submissions
#   ✔ Your memory usage beats 67.07 % of java submissions (45.2 MB)
# Submitting: java_solutions/2090.k-radius-subarray-averages.java
# - Downloading k-radius-subarray-averages
#   ✔ Accepted
#   ✔ 40/40 cases passed (13 ms)
#   ✔ Your runtime beats 5.44 % of java submissions
#   ✔ Your memory usage beats 17.88 % of java submissions (175.9 MB)
# Submitting: java_solutions/2091.removing-minimum-and-maximum-from-array.java
# - Downloading removing-minimum-and-maximum-from-array
#   ✔ Accepted
#   ✔ 62/62 cases passed (7 ms)
#   ✔ Your runtime beats 2.72 % of java submissions
#   ✔ Your memory usage beats 38.09 % of java submissions (86.8 MB)
# Submitting: java_solutions/2092.find-all-people-with-secret.java
# - Downloading find-all-people-with-secret
#   ✔ Accepted
#   ✔ 63/63 cases passed (233 ms)
#   ✔ Your runtime beats 15.17 % of java submissions
#   ✔ Your memory usage beats 73.32 % of java submissions (268.2 MB)
# Submitting: java_solutions/2094.finding-3-digit-even-numbers.java
# - Downloading finding-3-digit-even-numbers
#   ✔ Accepted
#   ✔ 79/79 cases passed (10 ms)
#   ✔ Your runtime beats 61.99 % of java submissions
#   ✔ Your memory usage beats 54.39 % of java submissions (46.8 MB)
# Submitting: java_solutions/2095.delete-the-middle-node-of-a-linked-list.java
# - Downloading delete-the-middle-node-of-a-linked-list
#   ✔ Accepted
#   ✔ 70/70 cases passed (10 ms)
#   ✔ Your runtime beats 1.47 % of java submissions
#   ✔ Your memory usage beats 8.74 % of java submissions (204.1 MB)
# Submitting: java_solutions/2096.step-by-step-directions-from-a-binary-tree-node-to-another.java
# - Downloading step-by-step-directions-from-a-binary-tree-node-to-another
#   ✔ Accepted
#   ✔ 332/332 cases passed (140 ms)
#   ✔ Your runtime beats 13.22 % of java submissions
#   ✔ Your memory usage beats 7.73 % of java submissions (127.4 MB)
# Submitting: java_solutions/2097.valid-arrangement-of-pairs.java
# - Downloading valid-arrangement-of-pairs
#   ✔ Accepted
#   ✔ 41/41 cases passed (199 ms)
#   ✔ Your runtime beats 32.89 % of java submissions
#   ✔ Your memory usage beats 53.15 % of java submissions (278.1 MB)
# Submitting: java_solutions/2099.find-subsequence-of-length-k-with-the-largest-sum.java
# - Downloading find-subsequence-of-length-k-with-the-largest-sum
#   ✔ Accepted
#   ✔ 49/49 cases passed (17 ms)
#   ✔ Your runtime beats 8.51 % of java submissions
#   ✔ Your memory usage beats 70.95 % of java submissions (46 MB)
# Submitting: java_solutions/2100.find-good-days-to-rob-the-bank.java
# - Downloading find-good-days-to-rob-the-bank
#   ✔ Accepted
#   ✔ 144/144 cases passed (10 ms)
#   ✔ Your runtime beats 8.44 % of java submissions
#   ✔ Your memory usage beats 51.36 % of java submissions (99.2 MB)
# Submitting: java_solutions/2101.detonate-the-maximum-bombs.java
# - Downloading detonate-the-maximum-bombs
#   ✔ Accepted
#   ✔ 164/164 cases passed (82 ms)
#   ✔ Your runtime beats 84.61 % of java submissions
#   ✔ Your memory usage beats 14 % of java submissions (47.1 MB)
# Submitting: java_solutions/2102.sequentially-ordinal-rank-tracker.java
# - Downloading sequentially-ordinal-rank-tracker
#   ✔ Accepted
#   ✔ 81/81 cases passed (234 ms)
#   ✔ Your runtime beats 8.91 % of java submissions
#   ✔ Your memory usage beats 100 % of java submissions (96.3 MB)
# Submitting: java_solutions/2103.rings-and-rods.java
# - Downloading rings-and-rods
#   ✔ Accepted
#   ✔ 66/66 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 24.74 % of java submissions (42.9 MB)
# Submitting: java_solutions/2104.sum-of-subarray-ranges.java
# - Downloading sum-of-subarray-ranges
#   ✔ Accepted
#   ✔ 71/71 cases passed (38 ms)
#   ✔ Your runtime beats 26.82 % of java submissions
#   ✔ Your memory usage beats 64.89 % of java submissions (46.4 MB)
# Submitting: java_solutions/2105.watering-plants-ii.java
# - Downloading watering-plants-ii
#   ✔ Accepted
#   ✔ 57/57 cases passed (10 ms)
#   ✔ Your runtime beats 2.48 % of java submissions
#   ✔ Your memory usage beats 50.14 % of java submissions (98.3 MB)
# Submitting: java_solutions/2106.maximum-fruits-harvested-after-at-most-k-steps.java
# - Downloading maximum-fruits-harvested-after-at-most-k-steps
#   ✔ Accepted
#   ✔ 202/202 cases passed (79 ms)
#   ✔ Your runtime beats 17.43 % of java submissions
#   ✔ Your memory usage beats 5.5 % of java submissions (142.5 MB)
# Submitting: java_solutions/2108.find-first-palindromic-string-in-the-array.java
# - Downloading find-first-palindromic-string-in-the-array
#   ✔ Accepted
#   ✔ 266/266 cases passed (14 ms)
#   ✔ Your runtime beats 7.59 % of java submissions
#   ✔ Your memory usage beats 12.81 % of java submissions (47.8 MB)
# Submitting: java_solutions/2109.adding-spaces-to-a-string.java
# - Downloading adding-spaces-to-a-string
#   ✔ Accepted
#   ✔ 66/66 cases passed (18 ms)
#   ✔ Your runtime beats 92.91 % of java submissions
#   ✔ Your memory usage beats 18.58 % of java submissions (91.3 MB)
# Submitting: java_solutions/2110.number-of-smooth-descent-periods-of-a-stock.java
# - Downloading number-of-smooth-descent-periods-of-a-stock
#   ✔ Accepted
#   ✔ 168/168 cases passed (5 ms)
#   ✔ Your runtime beats 2.34 % of java submissions
#   ✔ Your memory usage beats 13.51 % of java submissions (84.5 MB)
# Submitting: java_solutions/2111.minimum-operations-to-make-the-array-k-increasing.java
# - Downloading minimum-operations-to-make-the-array-k-increasing
#   ✔ Accepted
#   ✔ 90/90 cases passed (1511 ms)
#   ✔ Your runtime beats 6.28 % of java submissions
#   ✔ Your memory usage beats 8.38 % of java submissions (107.3 MB)
# Submitting: java_solutions/2114.maximum-number-of-words-found-in-sentences.java
# - Downloading maximum-number-of-words-found-in-sentences
#   ✔ Accepted
#   ✔ 90/90 cases passed (6 ms)
#   ✔ Your runtime beats 6.71 % of java submissions
#   ✔ Your memory usage beats 27.32 % of java submissions (46.2 MB)
# Submitting: java_solutions/2115.find-all-possible-recipes-from-given-supplies.java
# - Downloading find-all-possible-recipes-from-given-supplies
#   ✔ Accepted
#   ✔ 114/114 cases passed (73 ms)
#   ✔ Your runtime beats 44.67 % of java submissions
#   ✔ Your memory usage beats 37.22 % of java submissions (49.2 MB)
# Submitting: java_solutions/2116.check-if-a-parentheses-string-can-be-valid.java
# - Downloading check-if-a-parentheses-string-can-be-valid
#   ✔ Accepted
#   ✔ 260/260 cases passed (19 ms)
#   ✔ Your runtime beats 25.97 % of java submissions
#   ✔ Your memory usage beats 82.23 % of java submissions (47.7 MB)
# Submitting: java_solutions/2117.abbreviating-the-product-of-a-range.java
# - Downloading abbreviating-the-product-of-a-range
#   ✔ Accepted
#   ✔ 292/292 cases passed (463 ms)
#   ✔ Your runtime beats 10.47 % of java submissions
#   ✔ Your memory usage beats 6.98 % of java submissions (53.5 MB)
# Submitting: java_solutions/2119.a-number-after-a-double-reversal.java
# - Downloading a-number-after-a-double-reversal
#   ✔ Accepted
#   ✔ 129/129 cases passed (1 ms)
#   ✔ Your runtime beats 3.18 % of java submissions
#   ✔ Your memory usage beats 10.74 % of java submissions (42.4 MB)
# Submitting: java_solutions/2120.execution-of-all-suffix-instructions-staying-in-a-grid.java
# - Downloading execution-of-all-suffix-instructions-staying-in-a-grid
#   ✔ Accepted
#   ✔ 113/113 cases passed (49 ms)
#   ✔ Your runtime beats 8.79 % of java submissions
#   ✔ Your memory usage beats 5.15 % of java submissions (47.1 MB)
# Submitting: java_solutions/2121.intervals-between-identical-elements.java
# - Downloading intervals-between-identical-elements
#   ✔ Accepted
#   ✔ 61/61 cases passed (23 ms)
#   ✔ Your runtime beats 99.15 % of java submissions
#   ✔ Your memory usage beats 95.95 % of java submissions (159.8 MB)
# Submitting: java_solutions/2122.recover-the-original-array.java
# - Downloading recover-the-original-array
#   ✔ Accepted
#   ✔ 110/110 cases passed (146 ms)
#   ✔ Your runtime beats 42.7 % of java submissions
#   ✔ Your memory usage beats 7.3 % of java submissions (53.7 MB)
# Submitting: java_solutions/2124.check-if-all-as-appears-before-all-bs.java
# - Downloading check-if-all-as-appears-before-all-bs
#   ✔ Accepted
#   ✔ 216/216 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 27.57 % of java submissions (43 MB)
# Submitting: java_solutions/2125.number-of-laser-beams-in-a-bank.java
# - Downloading number-of-laser-beams-in-a-bank
#   ✔ Accepted
#   ✔ 147/147 cases passed (23 ms)
#   ✔ Your runtime beats 6.72 % of java submissions
#   ✔ Your memory usage beats 14.5 % of java submissions (48.1 MB)
# Submitting: java_solutions/2126.destroying-asteroids.java
# - Downloading destroying-asteroids
#   ✔ Accepted
#   ✔ 75/75 cases passed (47 ms)
#   ✔ Your runtime beats 5.05 % of java submissions
#   ✔ Your memory usage beats 99.28 % of java submissions (104.7 MB)
# Submitting: java_solutions/2127.maximum-employees-to-be-invited-to-a-meeting.java
# - Downloading maximum-employees-to-be-invited-to-a-meeting
#   ✔ Accepted
#   ✔ 99/99 cases passed (90 ms)
#   ✔ Your runtime beats 12.97 % of java submissions
#   ✔ Your memory usage beats 28.87 % of java submissions (90.5 MB)
# Submitting: java_solutions/2129.capitalize-the-title.java
# - Downloading capitalize-the-title
#   ✔ Accepted
#   ✔ 200/200 cases passed (9 ms)
#   ✔ Your runtime beats 12.67 % of java submissions
#   ✔ Your memory usage beats 37.85 % of java submissions (44.1 MB)
# Submitting: java_solutions/2130.maximum-twin-sum-of-a-linked-list.java
# - Downloading maximum-twin-sum-of-a-linked-list
#   ✔ Accepted
#   ✔ 46/46 cases passed (10 ms)
#   ✔ Your runtime beats 17.44 % of java submissions
#   ✔ Your memory usage beats 19.43 % of java submissions (108 MB)
# Submitting: java_solutions/2131.longest-palindrome-by-concatenating-two-letter-words.java
# - Downloading longest-palindrome-by-concatenating-two-letter-words
#   ✔ Accepted
#   ✔ 120/120 cases passed (14 ms)
#   ✔ Your runtime beats 89.84 % of java submissions
#   ✔ Your memory usage beats 79.68 % of java submissions (92.4 MB)
# Submitting: java_solutions/2132.stamping-the-grid.java
# - Downloading stamping-the-grid
#   ✔ Accepted
#   ✔ 77/77 cases passed (173 ms)
#   ✔ Your runtime beats 6.02 % of java submissions
#   ✔ Your memory usage beats 6.02 % of java submissions (278.9 MB)
# Submitting: java_solutions/2133.check-if-every-row-and-column-contains-all-numbers.java
# - Downloading check-if-every-row-and-column-contains-all-numbers
#   ✔ Accepted
#   ✔ 227/227 cases passed (42 ms)
#   ✔ Your runtime beats 10.66 % of java submissions
#   ✔ Your memory usage beats 12.45 % of java submissions (48.4 MB)
# Submitting: java_solutions/2134.minimum-swaps-to-group-all-1s-together-ii.java
# - Downloading minimum-swaps-to-group-all-1s-together-ii
#   ✔ Accepted
#   ✔ 63/63 cases passed (14 ms)
#   ✔ Your runtime beats 6.74 % of java submissions
#   ✔ Your memory usage beats 63.2 % of java submissions (90.3 MB)
# Submitting: java_solutions/2135.count-words-obtained-after-adding-a-letter.java
# - Downloading count-words-obtained-after-adding-a-letter
#   ✔ Accepted
#   ✔ 93/93 cases passed (69 ms)
#   ✔ Your runtime beats 45.97 % of java submissions
#   ✔ Your memory usage beats 20.16 % of java submissions (87.1 MB)
# Submitting: java_solutions/2136.earliest-possible-day-of-full-bloom.java
# - Downloading earliest-possible-day-of-full-bloom
#   ✔ Accepted
#   ✔ 185/185 cases passed (45 ms)
#   ✔ Your runtime beats 83.61 % of java submissions
#   ✔ Your memory usage beats 97.48 % of java submissions (112.3 MB)
# Submitting: java_solutions/2138.divide-a-string-into-groups-of-size-k.java
# - Downloading divide-a-string-into-groups-of-size-k
#   ✔ Accepted
#   ✔ 157/157 cases passed (7 ms)
#   ✔ Your runtime beats 6.74 % of java submissions
#   ✔ Your memory usage beats 19.06 % of java submissions (44.1 MB)
# Submitting: java_solutions/2139.minimum-moves-to-reach-target-score.java
# - Downloading minimum-moves-to-reach-target-score
#   ✔ Accepted
#   ✔ 145/145 cases passed (4 ms)
#   ✔ Your runtime beats 5.03 % of java submissions
#   ✔ Your memory usage beats 6.98 % of java submissions (42.6 MB)
# Submitting: java_solutions/2140.solving-questions-with-brainpower.java
# - Downloading solving-questions-with-brainpower
#   ✔ Accepted
#   ✔ 54/54 cases passed (8 ms)
#   ✔ Your runtime beats 44.24 % of java submissions
#   ✔ Your memory usage beats 83.95 % of java submissions (140.5 MB)
# Submitting: java_solutions/2141.maximum-running-time-of-n-computers.java
# - Downloading maximum-running-time-of-n-computers
#   ✔ Accepted
#   ✔ 52/52 cases passed (186 ms)
#   ✔ Your runtime beats 5.48 % of java submissions
#   ✔ Your memory usage beats 7.5 % of java submissions (79.3 MB)
# Submitting: java_solutions/2144.minimum-cost-of-buying-candies-with-discount.java
# - Downloading minimum-cost-of-buying-candies-with-discount
#   ✔ Accepted
#   ✔ 192/192 cases passed (11 ms)
#   ✔ Your runtime beats 6.88 % of java submissions
#   ✔ Your memory usage beats 6.88 % of java submissions (45.1 MB)
# Submitting: java_solutions/2145.count-the-hidden-sequences.java
# - Downloading count-the-hidden-sequences
#   ✔ Accepted
#   ✔ 86/86 cases passed (7 ms)
#   ✔ Your runtime beats 6.62 % of java submissions
#   ✔ Your memory usage beats 50 % of java submissions (113.7 MB)
# Submitting: java_solutions/2146.k-highest-ranked-items-within-a-price-range.java
# - Downloading k-highest-ranked-items-within-a-price-range
#   ✔ Accepted
#   ✔ 49/49 cases passed (75 ms)
#   ✔ Your runtime beats 66.09 % of java submissions
#   ✔ Your memory usage beats 14.78 % of java submissions (187.5 MB)
# Submitting: java_solutions/2147.number-of-ways-to-divide-a-long-corridor.java
# - Downloading number-of-ways-to-divide-a-long-corridor
#   ✔ Accepted
#   ✔ 248/248 cases passed (70 ms)
#   ✔ Your runtime beats 18.95 % of java submissions
#   ✔ Your memory usage beats 42.74 % of java submissions (48.4 MB)
# Submitting: java_solutions/2148.count-elements-with-strictly-smaller-and-greater-elements.java
# - Downloading count-elements-with-strictly-smaller-and-greater-elements
#   ✔ Accepted
#   ✔ 127/127 cases passed (22 ms)
#   ✔ Your runtime beats 25.41 % of java submissions
#   ✔ Your memory usage beats 8.78 % of java submissions (46.6 MB)
# Submitting: java_solutions/2149.rearrange-array-elements-by-sign.java
# - Downloading rearrange-array-elements-by-sign
#   ✔ Accepted
#   ✔ 133/133 cases passed (53 ms)
#   ✔ Your runtime beats 7.36 % of java submissions
#   ✔ Your memory usage beats 5.32 % of java submissions (180.4 MB)
# Submitting: java_solutions/2150.find-all-lonely-numbers-in-the-array.java
# - Downloading find-all-lonely-numbers-in-the-array
#   ✔ Accepted
#   ✔ 75/75 cases passed (53 ms)
#   ✔ Your runtime beats 76.66 % of java submissions
#   ✔ Your memory usage beats 79.82 % of java submissions (132.3 MB)
# Submitting: java_solutions/2151.maximum-good-people-based-on-statements.java
# - Downloading maximum-good-people-based-on-statements
#   ✔ Accepted
#   ✔ 91/91 cases passed (672 ms)
#   ✔ Your runtime beats 6.45 % of java submissions
#   ✔ Your memory usage beats 11.29 % of java submissions (47 MB)
# Submitting: java_solutions/2154.keep-multiplying-found-values-by-two.java
# - Downloading keep-multiplying-found-values-by-two
#   ✔ Accepted
#   ✔ 82/82 cases passed (10 ms)
#   ✔ Your runtime beats 13.54 % of java submissions
#   ✔ Your memory usage beats 5.24 % of java submissions (46.8 MB)
# Submitting: java_solutions/2155.all-divisions-with-the-highest-score-of-a-binary-array.java
# - Downloading all-divisions-with-the-highest-score-of-a-binary-array
#   ✔ Accepted
#   ✔ 58/58 cases passed (28 ms)
#   ✔ Your runtime beats 15.23 % of java submissions
#   ✔ Your memory usage beats 29.14 % of java submissions (260.9 MB)
# Submitting: java_solutions/2156.find-substring-with-given-hash-value.java
# - Downloading find-substring-with-given-hash-value
#   ✔ Accepted
#   ✔ 90/90 cases passed (21 ms)
#   ✔ Your runtime beats 22.66 % of java submissions
#   ✔ Your memory usage beats 6.25 % of java submissions (52.5 MB)
# Submitting: java_solutions/2157.groups-of-strings.java
# - Downloading groups-of-strings
#   ✔ Accepted
#   ✔ 97/97 cases passed (710 ms)
#   ✔ Your runtime beats 37.5 % of java submissions
#   ✔ Your memory usage beats 5.77 % of java submissions (277 MB)
# Submitting: java_solutions/2160.minimum-sum-of-four-digit-number-after-splitting-digits.java
# - Downloading minimum-sum-of-four-digit-number-after-splitting-digits
#   ✔ Accepted
#   ✔ 99/99 cases passed (9 ms)
#   ✔ Your runtime beats 2.64 % of java submissions
#   ✔ Your memory usage beats 5.19 % of java submissions (42.9 MB)
# Submitting: java_solutions/2161.partition-array-according-to-given-pivot.java
# - Downloading partition-array-according-to-given-pivot
#   ✔ Accepted
#   ✔ 44/44 cases passed (8 ms)
#   ✔ Your runtime beats 30.25 % of java submissions
#   ✔ Your memory usage beats 19.8 % of java submissions (160.4 MB)

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-05-05 11:01:29
