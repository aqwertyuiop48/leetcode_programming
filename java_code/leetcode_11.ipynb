# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME_2')
    user_cookie = userdata.get('LEETCODE_TOKEN_2')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME_2'] = user_name
    os.environ['LEETCODE_TOKEN_2'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME_2" "$LEETCODE_TOKEN_2" | leetcode user -c

# %%
# %%bash
#
#
# # top 100 answers
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v java_solutions/*.java | sed -n '1501,1650p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 8
# done
# Out:
# Submitting: java_solutions/2353.design-a-food-rating-system.java
#   ✔ Accepted
#   ✔ 80/80 cases passed (258 ms)
#   ✔ Your runtime beats 31.21 % of java submissions
#   ✔ Your memory usage beats 10.07 % of java submissions (122 MB)
# Submitting: java_solutions/2354.number-of-excellent-pairs.java
#   ✔ Accepted
#   ✔ 56/56 cases passed (58 ms)
#   ✔ Your runtime beats 53.33 % of java submissions
#   ✔ Your memory usage beats 28.89 % of java submissions (107.7 MB)
# Submitting: java_solutions/2357.make-array-zero-by-subtracting-equal-amounts.java
#   ✔ Accepted
#   ✔ 95/95 cases passed (5 ms)
#   ✔ Your runtime beats 9.62 % of java submissions
#   ✔ Your memory usage beats 6.86 % of java submissions (43.5 MB)
# Submitting: java_solutions/2358.maximum-number-of-groups-entering-a-competition.java
#   ✔ Accepted
#   ✔ 69/69 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 32.28 % of java submissions (76.2 MB)
# Submitting: java_solutions/2359.find-closest-node-to-given-two-nodes.java
#   ✔ Accepted
#   ✔ 78/78 cases passed (14 ms)
#   ✔ Your runtime beats 60.24 % of java submissions
#   ✔ Your memory usage beats 44.88 % of java submissions (102.7 MB)
# Submitting: java_solutions/2360.longest-cycle-in-a-graph.java
#   ✔ Accepted
#   ✔ 81/81 cases passed (89 ms)
#   ✔ Your runtime beats 27.07 % of java submissions
#   ✔ Your memory usage beats 100 % of java submissions (83.2 MB)
# Submitting: java_solutions/2363.merge-similar-items.java
#   ✔ Accepted
#   ✔ 49/49 cases passed (18 ms)
#   ✔ Your runtime beats 5.66 % of java submissions
#   ✔ Your memory usage beats 12.42 % of java submissions (53.4 MB)
# Submitting: java_solutions/2364.count-number-of-bad-pairs.java
#   ✔ Accepted
#   ✔ 65/65 cases passed (41 ms)
#   ✔ Your runtime beats 47.3 % of java submissions
#   ✔ Your memory usage beats 31.36 % of java submissions (84.8 MB)
# Submitting: java_solutions/2365.task-scheduler-ii.java
#   ✔ Accepted
#   ✔ 61/61 cases passed (49 ms)
#   ✔ Your runtime beats 5.83 % of java submissions
#   ✔ Your memory usage beats 80.28 % of java submissions (92.7 MB)
# Submitting: java_solutions/2366.minimum-replacements-to-sort-the-array.java
#   ✔ Accepted
#   ✔ 48/48 cases passed (35 ms)
#   ✔ Your runtime beats 5.85 % of java submissions
#   ✔ Your memory usage beats 98.4 % of java submissions (83.3 MB)
# Submitting: java_solutions/2367.number-of-arithmetic-triplets.java
#   ✔ Accepted
#   ✔ 104/104 cases passed (22 ms)
#   ✔ Your runtime beats 15.72 % of java submissions
#   ✔ Your memory usage beats 5.12 % of java submissions (45.6 MB)
# Submitting: java_solutions/2368.reachable-nodes-with-restrictions.java
#   ✔ Accepted
#   ✔ 62/62 cases passed (12 ms)
#   ✔ Your runtime beats 97.96 % of java submissions
#   ✔ Your memory usage beats 97.55 % of java submissions (140.3 MB)
# Submitting: java_solutions/2369.check-if-there-is-a-valid-partition-for-the-array.java
#   ✔ Accepted
#   ✔ 118/118 cases passed (14 ms)
#   ✔ Your runtime beats 9.96 % of java submissions
#   ✔ Your memory usage beats 96.81 % of java submissions (92.7 MB)
# Submitting: java_solutions/2370.longest-ideal-subsequence.java
#   ✔ Accepted
#   ✔ 85/85 cases passed (41 ms)
#   ✔ Your runtime beats 44.12 % of java submissions
#   ✔ Your memory usage beats 93.53 % of java submissions (46.4 MB)
# Submitting: java_solutions/2373.largest-local-values-in-a-matrix.java
#   ✔ Accepted
#   ✔ 50/50 cases passed (7 ms)
#   ✔ Your runtime beats 6.29 % of java submissions
#   ✔ Your memory usage beats 51.43 % of java submissions (47.4 MB)
# Submitting: java_solutions/2374.node-with-highest-edge-score.java
#   ✔ Accepted
#   ✔ 118/118 cases passed (9 ms)
#   ✔ Your runtime beats 20.67 % of java submissions
#   ✔ Your memory usage beats 29.81 % of java submissions (103.6 MB)
# Submitting: java_solutions/2375.construct-smallest-number-from-di-string.java
#   ✔ Accepted
#   ✔ 104/104 cases passed (2 ms)
#   ✔ Your runtime beats 25.83 % of java submissions
#   ✔ Your memory usage beats 95 % of java submissions (42.6 MB)
# Submitting: java_solutions/2376.count-special-integers.java
#   ✔ Accepted
#   ✔ 120/120 cases passed (18 ms)
#   ✔ Your runtime beats 42.49 % of java submissions
#   ✔ Your memory usage beats 5.7 % of java submissions (49.7 MB)
# Submitting: java_solutions/2379.minimum-recolors-to-get-k-consecutive-black-blocks.java
#   ✔ Accepted
#   ✔ 122/122 cases passed (9 ms)
#   ✔ Your runtime beats 2.67 % of java submissions
#   ✔ Your memory usage beats 5.17 % of java submissions (44.7 MB)
# Submitting: java_solutions/2380.time-needed-to-rearrange-a-binary-string.java
#   ✔ Accepted
#   ✔ 103/103 cases passed (6 ms)
#   ✔ Your runtime beats 48.76 % of java submissions
#   ✔ Your memory usage beats 62.81 % of java submissions (43 MB)
# Submitting: java_solutions/2381.shifting-letters-ii.java
#   ✔ Accepted
#   ✔ 39/39 cases passed (12 ms)
#   ✔ Your runtime beats 11.48 % of java submissions
#   ✔ Your memory usage beats 36.86 % of java submissions (113.5 MB)
# Submitting: java_solutions/2382.maximum-segment-sum-after-removals.java
#   ✔ Accepted
#   ✔ 42/42 cases passed (96 ms)
#   ✔ Your runtime beats 21.78 % of java submissions
#   ✔ Your memory usage beats 97.03 % of java submissions (123.1 MB)
# Submitting: java_solutions/2383.minimum-hours-of-training-to-win-a-competition.java
#   ✔ Accepted
#   ✔ 111/111 cases passed (4 ms)
#   ✔ Your runtime beats 3.73 % of java submissions
#   ✔ Your memory usage beats 5.59 % of java submissions (44 MB)
# Submitting: java_solutions/2384.largest-palindromic-number.java
#   ✔ Accepted
#   ✔ 67/67 cases passed (15 ms)
#   ✔ Your runtime beats 45.13 % of java submissions
#   ✔ Your memory usage beats 12.27 % of java submissions (47.9 MB)
# Submitting: java_solutions/2385.amount-of-time-for-binary-tree-to-be-infected.java
#   ✔ Accepted
#   ✔ 80/80 cases passed (140 ms)
#   ✔ Your runtime beats 10.36 % of java submissions
#   ✔ Your memory usage beats 24.25 % of java submissions (149.8 MB)
# Submitting: java_solutions/2386.find-the-k-sum-of-an-array.java
#   ✔ Accepted
#   ✔ 111/111 cases passed (95 ms)
#   ✔ Your runtime beats 5.94 % of java submissions
#   ✔ Your memory usage beats 5.94 % of java submissions (90.3 MB)
# Submitting: java_solutions/2389.longest-subsequence-with-limited-sum.java
# [ERROR] session expired, please login again [code=-1]
# Submitting: java_solutions/2390.removing-stars-from-a-string.java
#   ✔ Accepted
#   ✔ 65/65 cases passed (21 ms)
#   ✔ Your runtime beats 94.14 % of java submissions
#   ✔ Your memory usage beats 57.64 % of java submissions (48 MB)
# Submitting: java_solutions/2391.minimum-amount-of-time-to-collect-garbage.java
#   ✔ Accepted
#   ✔ 75/75 cases passed (30 ms)
#   ✔ Your runtime beats 32.73 % of java submissions
#   ✔ Your memory usage beats 28.05 % of java submissions (94.8 MB)
# Submitting: java_solutions/2392.build-a-matrix-with-conditions.java
#   ✔ Accepted
#   ✔ 53/53 cases passed (38 ms)
#   ✔ Your runtime beats 5.56 % of java submissions
#   ✔ Your memory usage beats 5.93 % of java submissions (162.6 MB)
# Submitting: java_solutions/2395.find-subarrays-with-equal-sum.java
#   ✔ Accepted
#   ✔ 42/42 cases passed (5 ms)
#   ✔ Your runtime beats 5.99 % of java submissions
#   ✔ Your memory usage beats 11.04 % of java submissions (43.9 MB)
# Submitting: java_solutions/2396.strictly-palindromic-number.java
#   ✔ Accepted
#   ✔ 67/67 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 21.03 % of java submissions (42.2 MB)
# Submitting: java_solutions/2397.maximum-rows-covered-by-columns.java
# - Downloading maximum-rows-covered-by-columns
#   ✔ Accepted
#   ✔ 103/103 cases passed (8 ms)
#   ✔ Your runtime beats 16.83 % of java submissions
#   ✔ Your memory usage beats 24.75 % of java submissions (43.8 MB)
# Submitting: java_solutions/2398.maximum-number-of-robots-within-budget.java
#   ✔ Accepted
#   ✔ 82/82 cases passed (136 ms)
#   ✔ Your runtime beats 16.04 % of java submissions
#   ✔ Your memory usage beats 7.29 % of java submissions (80.4 MB)
# Submitting: java_solutions/2399.check-distances-between-same-letters.java
#   ✔ Accepted
#   ✔ 335/335 cases passed (6 ms)
#   ✔ Your runtime beats 5.14 % of java submissions
#   ✔ Your memory usage beats 42.4 % of java submissions (44.1 MB)
# Submitting: java_solutions/2400.number-of-ways-to-reach-a-position-after-exactly-k-steps.java
#   ✔ Accepted
#   ✔ 35/35 cases passed (92 ms)
#   ✔ Your runtime beats 26.23 % of java submissions
#   ✔ Your memory usage beats 50 % of java submissions (86.2 MB)
# Submitting: java_solutions/2401.longest-nice-subarray.java
#   ✔ Accepted
#   ✔ 66/66 cases passed (10 ms)
#   ✔ Your runtime beats 5.96 % of java submissions
#   ✔ Your memory usage beats 9.5 % of java submissions (81.5 MB)
# Submitting: java_solutions/2402.meeting-rooms-iii.java
#   ✔ Accepted
#   ✔ 82/82 cases passed (470 ms)
#   ✔ Your runtime beats 5.1 % of java submissions
#   ✔ Your memory usage beats 16.35 % of java submissions (155.6 MB)
# Submitting: java_solutions/2404.most-frequent-even-element.java
#   ✔ Accepted
#   ✔ 219/219 cases passed (45 ms)
#   ✔ Your runtime beats 10.4 % of java submissions
#   ✔ Your memory usage beats 11.76 % of java submissions (53.3 MB)
# Submitting: java_solutions/2405.optimal-partition-of-string.java
#   ✔ Accepted
#   ✔ 62/62 cases passed (13 ms)
#   ✔ Your runtime beats 66.67 % of java submissions
#   ✔ Your memory usage beats 68.56 % of java submissions (46.8 MB)
# Submitting: java_solutions/2406.divide-intervals-into-minimum-number-of-groups.java
#   ✔ Accepted
#   ✔ 35/35 cases passed (57 ms)
#   ✔ Your runtime beats 76.09 % of java submissions
#   ✔ Your memory usage beats 24.49 % of java submissions (114.6 MB)
# Submitting: java_solutions/2407.longest-increasing-subsequence-ii.java
#   ✔ Accepted
#   ✔ 84/84 cases passed (398 ms)
#   ✔ Your runtime beats 5.96 % of java submissions
#   ✔ Your memory usage beats 18.54 % of java submissions (79.1 MB)
# Submitting: java_solutions/2409.count-days-spent-together.java
#   ✔ Accepted
#   ✔ 51/51 cases passed (5 ms)
#   ✔ Your runtime beats 4.81 % of java submissions
#   ✔ Your memory usage beats 9.13 % of java submissions (43.4 MB)
# Submitting: java_solutions/2410.maximum-matching-of-players-with-trainers.java
#   ✔ Accepted
#   ✔ 36/36 cases passed (48 ms)
#   ✔ Your runtime beats 5.47 % of java submissions
#   ✔ Your memory usage beats 5.15 % of java submissions (91.2 MB)
# Submitting: java_solutions/2411.smallest-subarrays-with-maximum-bitwise-or.java
#   ✔ Accepted
#   ✔ 59/59 cases passed (40 ms)
#   ✔ Your runtime beats 14.84 % of java submissions
#   ✔ Your memory usage beats 49.22 % of java submissions (96.2 MB)
# Submitting: java_solutions/2412.minimum-money-required-before-transactions.java
#   ✔ Accepted
#   ✔ 56/56 cases passed (14 ms)
#   ✔ Your runtime beats 25.93 % of java submissions
#   ✔ Your memory usage beats 75.93 % of java submissions (127.1 MB)
# Submitting: java_solutions/2413.smallest-even-multiple.java
#   ✔ Accepted
#   ✔ 150/150 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 49.08 % of java submissions (42.1 MB)
# Submitting: java_solutions/2414.length-of-the-longest-alphabetical-continuous-substring.java
#   ✔ Accepted
#   ✔ 123/123 cases passed (18 ms)
#   ✔ Your runtime beats 5.12 % of java submissions
#   ✔ Your memory usage beats 62.7 % of java submissions (47.4 MB)
# Submitting: java_solutions/2415.reverse-odd-levels-of-binary-tree.java
#   ✔ Accepted
#   ✔ 57/57 cases passed (43 ms)
#   ✔ Your runtime beats 6.23 % of java submissions
#   ✔ Your memory usage beats 40.43 % of java submissions (50.2 MB)
# Submitting: java_solutions/2416.sum-of-prefix-scores-of-strings.java
#   ✔ Accepted
#   ✔ 38/38 cases passed (1103 ms)
#   ✔ Your runtime beats 5.1 % of java submissions
#   ✔ Your memory usage beats 98.09 % of java submissions (163.6 MB)
# Submitting: java_solutions/2418.sort-the-people.java
# - Downloading sort-the-people
#   ✔ Accepted
#   ✔ 68/68 cases passed (12 ms)
#   ✔ Your runtime beats 33.6 % of java submissions
#   ✔ Your memory usage beats 38.45 % of java submissions (47.4 MB)
# Submitting: java_solutions/2419.longest-subarray-with-maximum-bitwise-and.java
# - Downloading longest-subarray-with-maximum-bitwise-and
#   ✔ Accepted
#   ✔ 53/53 cases passed (9 ms)
#   ✔ Your runtime beats 5.7 % of java submissions
#   ✔ Your memory usage beats 65.19 % of java submissions (89.1 MB)
# Submitting: java_solutions/2420.find-all-good-indices.java
# - Downloading find-all-good-indices
#   ✔ Accepted
#   ✔ 68/68 cases passed (11 ms)
#   ✔ Your runtime beats 7.89 % of java submissions
#   ✔ Your memory usage beats 77.63 % of java submissions (99.1 MB)
# Submitting: java_solutions/2421.number-of-good-paths.java
# - Downloading number-of-good-paths
#   ✔ Accepted
#   ✔ 134/134 cases passed (111 ms)
#   ✔ Your runtime beats 55.06 % of java submissions
#   ✔ Your memory usage beats 79.11 % of java submissions (137.2 MB)
# Submitting: java_solutions/2423.remove-letter-to-equalize-frequency.java
# - Downloading remove-letter-to-equalize-frequency
#   ✔ Accepted
#   ✔ 51/51 cases passed (26 ms)
#   ✔ Your runtime beats 5.51 % of java submissions
#   ✔ Your memory usage beats 5.51 % of java submissions (52.4 MB)
# Submitting: java_solutions/2424.longest-uploaded-prefix.java
# - Downloading longest-uploaded-prefix
#   ✔ Accepted
#   ✔ 24/24 cases passed (41 ms)
#   ✔ Your runtime beats 42.86 % of java submissions
#   ✔ Your memory usage beats 98.5 % of java submissions (131.5 MB)
# Submitting: java_solutions/2425.bitwise-xor-of-all-pairings.java
# - Downloading bitwise-xor-of-all-pairings
#   ✔ Accepted
#   ✔ 42/42 cases passed (3 ms)
#   ✔ Your runtime beats 6.53 % of java submissions
#   ✔ Your memory usage beats 27.76 % of java submissions (78.7 MB)
# Submitting: java_solutions/2426.number-of-pairs-satisfying-inequality.java
# - Downloading number-of-pairs-satisfying-inequality
#   ✔ Accepted
#   ✔ 61/61 cases passed (274 ms)
#   ✔ Your runtime beats 5.47 % of java submissions
#   ✔ Your memory usage beats 19.67 % of java submissions (88.6 MB)
# Submitting: java_solutions/2427.number-of-common-factors.java
# - Downloading number-of-common-factors
#   ✔ Accepted
#   ✔ 76/76 cases passed (4 ms)
#   ✔ Your runtime beats 0.76 % of java submissions
#   ✔ Your memory usage beats 58.92 % of java submissions (42.1 MB)
# Submitting: java_solutions/2428.maximum-sum-of-an-hourglass.java
# - Downloading maximum-sum-of-an-hourglass
#   ✔ Accepted
#   ✔ 41/41 cases passed (14 ms)
#   ✔ Your runtime beats 11.33 % of java submissions
#   ✔ Your memory usage beats 11.33 % of java submissions (47.7 MB)
# Submitting: java_solutions/2429.minimize-xor.java
# - Downloading minimize-xor
#   ✔ Accepted
#   ✔ 280/280 cases passed (1 ms)
#   ✔ Your runtime beats 17.99 % of java submissions
#   ✔ Your memory usage beats 42.45 % of java submissions (42.3 MB)
# Submitting: java_solutions/2430.maximum-deletions-on-a-string.java
# - Downloading maximum-deletions-on-a-string
#   ✔ Accepted
#   ✔ 129/129 cases passed (704 ms)
#   ✔ Your runtime beats 15.63 % of java submissions
#   ✔ Your memory usage beats 6.25 % of java submissions (288.5 MB)
# Submitting: java_solutions/2432.the-employee-that-worked-on-the-longest-task.java
# - Downloading the-employee-that-worked-on-the-longest-task
#   ✔ Accepted
#   ✔ 514/514 cases passed (13 ms)
#   ✔ Your runtime beats 5.8 % of java submissions
#   ✔ Your memory usage beats 5.31 % of java submissions (53.4 MB)
# Submitting: java_solutions/2433.find-the-original-array-of-prefix-xor.java
# - Downloading find-the-original-array-of-prefix-xor
#   ✔ Accepted
#   ✔ 46/46 cases passed (7 ms)
#   ✔ Your runtime beats 0.74 % of java submissions
#   ✔ Your memory usage beats 5.95 % of java submissions (109.7 MB)
# Submitting: java_solutions/2434.using-a-robot-to-print-the-lexicographically-smallest-string.java
# - Downloading using-a-robot-to-print-the-lexicographically-smallest-string
#   ✔ Accepted
#   ✔ 62/62 cases passed (40 ms)
#   ✔ Your runtime beats 98.17 % of java submissions
#   ✔ Your memory usage beats 80.28 % of java submissions (48.5 MB)
# Submitting: java_solutions/2435.paths-in-matrix-whose-sum-is-divisible-by-k.java
# - Downloading paths-in-matrix-whose-sum-is-divisible-by-k
#   ✔ Accepted
#   ✔ 88/88 cases passed (201 ms)
#   ✔ Your runtime beats 5.01 % of java submissions
#   ✔ Your memory usage beats 82.38 % of java submissions (89.6 MB)
# Submitting: java_solutions/2437.number-of-valid-clock-times.java
# - Downloading number-of-valid-clock-times
#   ✔ Accepted
#   ✔ 55/55 cases passed (136 ms)
#   ✔ Your runtime beats 5.26 % of java submissions
#   ✔ Your memory usage beats 8.27 % of java submissions (47.3 MB)
# Submitting: java_solutions/2438.range-product-queries-of-powers.java
# - Downloading range-product-queries-of-powers
#   ✔ Accepted
#   ✔ 70/70 cases passed (24 ms)
#   ✔ Your runtime beats 14.29 % of java submissions
#   ✔ Your memory usage beats 6.12 % of java submissions (135.8 MB)
# Submitting: java_solutions/2439.minimize-maximum-of-array.java
# - Downloading minimize-maximum-of-array
#   ✔ Accepted
#   ✔ 68/68 cases passed (9 ms)
#   ✔ Your runtime beats 34.68 % of java submissions
#   ✔ Your memory usage beats 79.19 % of java submissions (80.2 MB)
# Submitting: java_solutions/2440.create-components-with-same-value.java
# - Downloading create-components-with-same-value
#   ✔ Accepted
#   ✔ 43/43 cases passed (704 ms)
#   ✔ Your runtime beats 6.67 % of java submissions
#   ✔ Your memory usage beats 6.67 % of java submissions (138 MB)
# Submitting: java_solutions/2441.largest-positive-integer-that-exists-with-its-negative.java
# - Downloading largest-positive-integer-that-exists-with-its-negative
#   ✔ Accepted
#   ✔ 339/339 cases passed (138 ms)
#   ✔ Your runtime beats 5.22 % of java submissions
#   ✔ Your memory usage beats 12.51 % of java submissions (47.5 MB)
# Submitting: java_solutions/2442.count-number-of-distinct-integers-after-reverse-operations.java
# - Downloading count-number-of-distinct-integers-after-reverse-operations
#   ✔ Accepted
#   ✔ 44/44 cases passed (63 ms)
#   ✔ Your runtime beats 33.7 % of java submissions
#   ✔ Your memory usage beats 10.53 % of java submissions (113.7 MB)
# Submitting: java_solutions/2443.sum-of-number-and-its-reverse.java
# - Downloading sum-of-number-and-its-reverse
#   ✔ Accepted
#   ✔ 258/258 cases passed (191 ms)
#   ✔ Your runtime beats 11.21 % of java submissions
#   ✔ Your memory usage beats 23.99 % of java submissions (42.6 MB)
# Submitting: java_solutions/2444.count-subarrays-with-fixed-bounds.java
# - Downloading count-subarrays-with-fixed-bounds
#   ✔ Accepted
#   ✔ 53/53 cases passed (17 ms)
#   ✔ Your runtime beats 6.31 % of java submissions
#   ✔ Your memory usage beats 5.18 % of java submissions (100 MB)
# Submitting: java_solutions/2446.determine-if-two-events-have-conflict.java
# - Downloading determine-if-two-events-have-conflict
#   ✔ Accepted
#   ✔ 129/129 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 46.74 % of java submissions (42.9 MB)
# Submitting: java_solutions/2447.number-of-subarrays-with-gcd-equal-to-k.java
# - Downloading number-of-subarrays-with-gcd-equal-to-k
#   ✔ Accepted
#   ✔ 87/87 cases passed (11 ms)
#   ✔ Your runtime beats 34.41 % of java submissions
#   ✔ Your memory usage beats 75.81 % of java submissions (43.7 MB)
# Submitting: java_solutions/2448.minimum-cost-to-make-array-equal.java
# - Downloading minimum-cost-to-make-array-equal
#   ✔ Accepted
#   ✔ 48/48 cases passed (76 ms)
#   ✔ Your runtime beats 5.43 % of java submissions
#   ✔ Your memory usage beats 10.08 % of java submissions (65.9 MB)
# Submitting: java_solutions/2449.minimum-number-of-operations-to-make-arrays-similar.java
# - Downloading minimum-number-of-operations-to-make-arrays-similar
#   ✔ Accepted
#   ✔ 32/32 cases passed (78 ms)
#   ✔ Your runtime beats 50 % of java submissions
#   ✔ Your memory usage beats 71.79 % of java submissions (99.3 MB)
# Submitting: java_solutions/2451.odd-string-difference.java
# - Downloading odd-string-difference
#   ✔ Accepted
#   ✔ 40/40 cases passed (11 ms)
#   ✔ Your runtime beats 7.14 % of java submissions
#   ✔ Your memory usage beats 5.95 % of java submissions (44.1 MB)
# Submitting: java_solutions/2452.words-within-two-edits-of-dictionary.java
# - Downloading words-within-two-edits-of-dictionary
#   ✔ Accepted
#   ✔ 33/33 cases passed (24 ms)
#   ✔ Your runtime beats 7.25 % of java submissions
#   ✔ Your memory usage beats 39 % of java submissions (44.5 MB)
# Submitting: java_solutions/2453.destroy-sequential-targets.java
# - Downloading destroy-sequential-targets
#   ✔ Accepted
#   ✔ 45/45 cases passed (90 ms)
#   ✔ Your runtime beats 5.08 % of java submissions
#   ✔ Your memory usage beats 23.73 % of java submissions (114.1 MB)
# Submitting: java_solutions/2454.next-greater-element-iv.java
# - Downloading next-greater-element-iv
#   ✔ Accepted
#   ✔ 51/51 cases passed (395 ms)
#   ✔ Your runtime beats 5.17 % of java submissions
#   ✔ Your memory usage beats 47.85 % of java submissions (121.5 MB)
# Submitting: java_solutions/2455.average-value-of-even-numbers-that-are-divisible-by-three.java
# - Downloading average-value-of-even-numbers-that-are-divisible-by-three
#   ✔ Accepted
#   ✔ 181/181 cases passed (6 ms)
#   ✔ Your runtime beats 1.12 % of java submissions
#   ✔ Your memory usage beats 19.27 % of java submissions (46.6 MB)
# Submitting: java_solutions/2456.most-popular-video-creator.java
# - Downloading most-popular-video-creator
#   ✔ Accepted
#   ✔ 86/86 cases passed (57 ms)
#   ✔ Your runtime beats 53.75 % of java submissions
#   ✔ Your memory usage beats 42.5 % of java submissions (108 MB)
# Submitting: java_solutions/2457.minimum-addition-to-make-integer-beautiful.java
# - Downloading minimum-addition-to-make-integer-beautiful
#   ✔ Accepted
#   ✔ 92/92 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 16.96 % of java submissions (42.4 MB)
# Submitting: java_solutions/2458.height-of-binary-tree-after-subtree-removal-queries.java
# - Downloading height-of-binary-tree-after-subtree-removal-queries
#   ✔ Accepted
#   ✔ 40/40 cases passed (36 ms)
#   ✔ Your runtime beats 52.74 % of java submissions
#   ✔ Your memory usage beats 52.06 % of java submissions (110.3 MB)
# Submitting: java_solutions/2460.apply-operations-to-an-array.java
# - Downloading apply-operations-to-an-array
#   ✔ Accepted
#   ✔ 36/36 cases passed (10 ms)
#   ✔ Your runtime beats 2.25 % of java submissions
#   ✔ Your memory usage beats 9.14 % of java submissions (45.8 MB)
# Submitting: java_solutions/2461.maximum-sum-of-distinct-subarrays-with-length-k.java
# - Downloading maximum-sum-of-distinct-subarrays-with-length-k
#   ✔ Accepted
#   ✔ 93/93 cases passed (19 ms)
#   ✔ Your runtime beats 97.27 % of java submissions
#   ✔ Your memory usage beats 99.04 % of java submissions (81.9 MB)
# Submitting: java_solutions/2462.total-cost-to-hire-k-workers.java
# - Downloading total-cost-to-hire-k-workers
#   ✔ Accepted
#   ✔ 163/163 cases passed (57 ms)
#   ✔ Your runtime beats 27.81 % of java submissions
#   ✔ Your memory usage beats 47.34 % of java submissions (72.8 MB)
# Submitting: java_solutions/2463.minimum-total-distance-traveled.java
# - Downloading minimum-total-distance-traveled
#   ✔ Accepted
#   ✔ 40/40 cases passed (258 ms)
#   ✔ Your runtime beats 5.17 % of java submissions
#   ✔ Your memory usage beats 30.71 % of java submissions (53.6 MB)
# Submitting: java_solutions/2465.number-of-distinct-averages.java
# - Downloading number-of-distinct-averages
#   ✔ Accepted
#   ✔ 36/36 cases passed (9 ms)
#   ✔ Your runtime beats 6.56 % of java submissions
#   ✔ Your memory usage beats 39.19 % of java submissions (43.1 MB)
# Submitting: java_solutions/2466.count-ways-to-build-good-strings.java
# - Downloading count-ways-to-build-good-strings
#   ✔ Accepted
#   ✔ 36/36 cases passed (15 ms)
#   ✔ Your runtime beats 17.19 % of java submissions
#   ✔ Your memory usage beats 60 % of java submissions (45.1 MB)
# Submitting: java_solutions/2467.most-profitable-path-in-a-tree.java
# - Downloading most-profitable-path-in-a-tree
#   ✔ Accepted
#   ✔ 31/31 cases passed (28 ms)
#   ✔ Your runtime beats 99.48 % of java submissions
#   ✔ Your memory usage beats 100 % of java submissions (138.5 MB)
# Submitting: java_solutions/2468.split-message-based-on-limit.java
# - Downloading split-message-based-on-limit
#   ✔ Accepted
#   ✔ 94/94 cases passed (68 ms)
#   ✔ Your runtime beats 36.43 % of java submissions
#   ✔ Your memory usage beats 5.43 % of java submissions (59.6 MB)
# Submitting: java_solutions/2469.convert-the-temperature.java
# - Downloading convert-the-temperature
#   ✔ Accepted
#   ✔ 74/74 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 59.66 % of java submissions (46 MB)
# Submitting: java_solutions/2470.number-of-subarrays-with-lcm-equal-to-k.java
# - Downloading number-of-subarrays-with-lcm-equal-to-k
#   ✔ Accepted
#   ✔ 102/102 cases passed (25 ms)
#   ✔ Your runtime beats 12.71 % of java submissions
#   ✔ Your memory usage beats 14.71 % of java submissions (44.5 MB)
# Submitting: java_solutions/2471.minimum-number-of-operations-to-sort-a-binary-tree-by-level.java
# - Downloading minimum-number-of-operations-to-sort-a-binary-tree-by-level
#   ✔ Accepted
#   ✔ 146/146 cases passed (75 ms)
#   ✔ Your runtime beats 32.45 % of java submissions
#   ✔ Your memory usage beats 32.12 % of java submissions (82 MB)
# Submitting: java_solutions/2472.maximum-number-of-non-overlapping-palindrome-substrings.java
# - Downloading maximum-number-of-non-overlapping-palindrome-substrings
#   ✔ Accepted
#   ✔ 56/56 cases passed (26 ms)
#   ✔ Your runtime beats 37.97 % of java submissions
#   ✔ Your memory usage beats 32.08 % of java submissions (52.8 MB)
# Submitting: java_solutions/2475.number-of-unequal-triplets-in-array.java
# - Downloading number-of-unequal-triplets-in-array
#   ✔ Accepted
#   ✔ 104/104 cases passed (73 ms)
#   ✔ Your runtime beats 5.82 % of java submissions
#   ✔ Your memory usage beats 5.82 % of java submissions (52.7 MB)
# Submitting: java_solutions/2476.closest-nodes-queries-in-a-binary-search-tree.java
# - Downloading closest-nodes-queries-in-a-binary-search-tree
#   ✔ Accepted
#   ✔ 35/35 cases passed (131 ms)
#   ✔ Your runtime beats 13.03 % of java submissions
#   ✔ Your memory usage beats 43 % of java submissions (160.4 MB)
# Submitting: java_solutions/2477.minimum-fuel-cost-to-report-to-the-capital.java
# - Downloading minimum-fuel-cost-to-report-to-the-capital
#   ✔ Accepted
#   ✔ 131/131 cases passed (27 ms)
#   ✔ Your runtime beats 96.65 % of java submissions
#   ✔ Your memory usage beats 97.38 % of java submissions (138 MB)
# Submitting: java_solutions/2478.number-of-beautiful-partitions.java
# - Downloading number-of-beautiful-partitions
#   ✔ Accepted
#   ✔ 74/74 cases passed (588 ms)
#   ✔ Your runtime beats 47.83 % of java submissions
#   ✔ Your memory usage beats 23.91 % of java submissions (55 MB)
# Submitting: java_solutions/2481.minimum-cuts-to-divide-a-circle.java
# - Downloading minimum-cuts-to-divide-a-circle
#   ✔ Accepted
#   ✔ 100/100 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 7.58 % of java submissions (42.3 MB)
# Submitting: java_solutions/2482.difference-between-ones-and-zeros-in-row-and-column.java
# - Downloading difference-between-ones-and-zeros-in-row-and-column
#   ✔ Accepted
#   ✔ 85/85 cases passed (14 ms)
#   ✔ Your runtime beats 12.17 % of java submissions
#   ✔ Your memory usage beats 7.91 % of java submissions (179.7 MB)
# Submitting: java_solutions/2483.minimum-penalty-for-a-shop.java
# - Downloading minimum-penalty-for-a-shop
#   ✔ Accepted
#   ✔ 42/42 cases passed (18 ms)
#   ✔ Your runtime beats 5.46 % of java submissions
#   ✔ Your memory usage beats 62.57 % of java submissions (47 MB)
# Submitting: java_solutions/2484.count-palindromic-subsequences.java
# - Downloading count-palindromic-subsequences
#   ✔ Accepted
#   ✔ 63/63 cases passed (263 ms)
#   ✔ Your runtime beats 7.89 % of java submissions
#   ✔ Your memory usage beats 17.54 % of java submissions (88.9 MB)
# Submitting: java_solutions/2485.find-the-pivot-integer.java
# - Downloading find-the-pivot-integer
#   ✔ Accepted
#   ✔ 428/428 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 53.88 % of java submissions (42.4 MB)
# Submitting: java_solutions/2486.append-characters-to-string-to-make-subsequence.java
# - Downloading append-characters-to-string-to-make-subsequence
#   ✔ Accepted
#   ✔ 86/86 cases passed (11 ms)
#   ✔ Your runtime beats 8.15 % of java submissions
#   ✔ Your memory usage beats 5.31 % of java submissions (47.8 MB)
# Submitting: java_solutions/2487.remove-nodes-from-linked-list.java
# - Downloading remove-nodes-from-linked-list
#   ✔ Accepted
#   ✔ 32/32 cases passed (14 ms)
#   ✔ Your runtime beats 50.93 % of java submissions
#   ✔ Your memory usage beats 22.18 % of java submissions (135.2 MB)
# Submitting: java_solutions/2488.count-subarrays-with-median-k.java
# - Downloading count-subarrays-with-median-k
#   ✔ Accepted
#   ✔ 45/45 cases passed (22 ms)
#   ✔ Your runtime beats 6.23 % of java submissions
#   ✔ Your memory usage beats 5.15 % of java submissions (78.3 MB)
# Submitting: java_solutions/2490.circular-sentence.java
# - Downloading circular-sentence
#   ✔ Accepted
#   ✔ 266/266 cases passed (6 ms)
#   ✔ Your runtime beats 5.82 % of java submissions
#   ✔ Your memory usage beats 12.76 % of java submissions (43.6 MB)
# Submitting: java_solutions/2491.divide-players-into-teams-of-equal-skill.java
# - Downloading divide-players-into-teams-of-equal-skill
#   ✔ Accepted
#   ✔ 89/89 cases passed (40 ms)
#   ✔ Your runtime beats 5.44 % of java submissions
#   ✔ Your memory usage beats 42.9 % of java submissions (76.9 MB)
# Submitting: java_solutions/2492.minimum-score-of-a-path-between-two-cities.java
# - Downloading minimum-score-of-a-path-between-two-cities
#   ✔ Accepted
#   ✔ 43/43 cases passed (23 ms)
#   ✔ Your runtime beats 75.37 % of java submissions
#   ✔ Your memory usage beats 86.75 % of java submissions (135.1 MB)
# Submitting: java_solutions/2493.divide-nodes-into-the-maximum-number-of-groups.java
# - Downloading divide-nodes-into-the-maximum-number-of-groups
#   ✔ Accepted
#   ✔ 57/57 cases passed (642 ms)
#   ✔ Your runtime beats 16.67 % of java submissions
#   ✔ Your memory usage beats 5.56 % of java submissions (56.3 MB)
# Submitting: java_solutions/2496.maximum-value-of-a-string-in-an-array.java
# - Downloading maximum-value-of-a-string-in-an-array
#   ✔ Accepted
#   ✔ 64/64 cases passed (8 ms)
#   ✔ Your runtime beats 9.98 % of java submissions
#   ✔ Your memory usage beats 23.43 % of java submissions (43.6 MB)
# Submitting: java_solutions/2497.maximum-star-sum-of-a-graph.java
# - Downloading maximum-star-sum-of-a-graph
#   ✔ Accepted
#   ✔ 25/25 cases passed (114 ms)
#   ✔ Your runtime beats 5.74 % of java submissions
#   ✔ Your memory usage beats 7.38 % of java submissions (160.1 MB)
# Submitting: java_solutions/2498.frog-jump-ii.java
# - Downloading frog-jump-ii
#   ✔ Accepted
#   ✔ 34/34 cases passed (11 ms)
#   ✔ Your runtime beats 7.13 % of java submissions
#   ✔ Your memory usage beats 85.34 % of java submissions (83 MB)
# Submitting: java_solutions/2499.minimum-total-cost-to-make-arrays-unequal.java
# - Downloading minimum-total-cost-to-make-arrays-unequal
#   ✔ Accepted
#   ✔ 104/104 cases passed (21 ms)
#   ✔ Your runtime beats 43.24 % of java submissions
#   ✔ Your memory usage beats 10.81 % of java submissions (112.2 MB)
# Submitting: java_solutions/2500.delete-greatest-value-in-each-row.java
# - Downloading delete-greatest-value-in-each-row
#   ✔ Accepted
#   ✔ 55/55 cases passed (68 ms)
#   ✔ Your runtime beats 6.08 % of java submissions
#   ✔ Your memory usage beats 8.6 % of java submissions (48 MB)
# Submitting: java_solutions/2501.longest-square-streak-in-an-array.java
# - Downloading longest-square-streak-in-an-array
#   ✔ Accepted
#   ✔ 92/92 cases passed (48 ms)
#   ✔ Your runtime beats 77.21 % of java submissions
#   ✔ Your memory usage beats 76.47 % of java submissions (100.8 MB)
# Submitting: java_solutions/2502.design-memory-allocator.java
# - Downloading design-memory-allocator
#   ✔ Accepted
#   ✔ 109/109 cases passed (452 ms)
#   ✔ Your runtime beats 12.41 % of java submissions
#   ✔ Your memory usage beats 5.22 % of java submissions (53.4 MB)
# Submitting: java_solutions/2503.maximum-number-of-points-from-grid-queries.java
# - Downloading maximum-number-of-points-from-grid-queries
#   ✔ Accepted
#   ✔ 22/22 cases passed (334 ms)
#   ✔ Your runtime beats 5.93 % of java submissions
#   ✔ Your memory usage beats 5.18 % of java submissions (99 MB)
# Submitting: java_solutions/2506.count-pairs-of-similar-strings.java
# - Downloading count-pairs-of-similar-strings
#   ✔ Accepted
#   ✔ 225/225 cases passed (37 ms)
#   ✔ Your runtime beats 52.2 % of java submissions
#   ✔ Your memory usage beats 7.2 % of java submissions (53.1 MB)
# Submitting: java_solutions/2507.smallest-value-after-replacing-with-sum-of-prime-factors.java
# - Downloading smallest-value-after-replacing-with-sum-of-prime-factors
#   ✔ Accepted
#   ✔ 209/209 cases passed (1 ms)
#   ✔ Your runtime beats 58.54 % of java submissions
#   ✔ Your memory usage beats 17.07 % of java submissions (42.6 MB)
# Submitting: java_solutions/2508.add-edges-to-make-degrees-of-all-nodes-even.java
# - Downloading add-edges-to-make-degrees-of-all-nodes-even
#   ✔ Accepted
#   ✔ 52/52 cases passed (71 ms)
#   ✔ Your runtime beats 52.71 % of java submissions
#   ✔ Your memory usage beats 76.74 % of java submissions (197.5 MB)
# Submitting: java_solutions/2509.cycle-length-queries-in-a-tree.java
# - Downloading cycle-length-queries-in-a-tree
#   ✔ Accepted
#   ✔ 27/27 cases passed (79 ms)
#   ✔ Your runtime beats 19.78 % of java submissions
#   ✔ Your memory usage beats 13.19 % of java submissions (104 MB)
# Submitting: java_solutions/2511.maximum-enemy-forts-that-can-be-captured.java
# - Downloading maximum-enemy-forts-that-can-be-captured
#   ✔ Accepted
#   ✔ 45/45 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 86.97 % of java submissions (42.9 MB)
# Submitting: java_solutions/2512.reward-top-k-students.java
# - Downloading reward-top-k-students
#   ✔ Accepted
#   ✔ 30/30 cases passed (81 ms)
#   ✔ Your runtime beats 40.89 % of java submissions
#   ✔ Your memory usage beats 59.79 % of java submissions (61.3 MB)
# Submitting: java_solutions/2513.minimize-the-maximum-of-two-arrays.java
# - Downloading minimize-the-maximum-of-two-arrays
#   ✔ Accepted
#   ✔ 63/63 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 14.29 % of java submissions (42.5 MB)
# Submitting: java_solutions/2514.count-anagrams.java
# - Downloading count-anagrams
#   ✔ Accepted
#   ✔ 41/41 cases passed (106 ms)
#   ✔ Your runtime beats 12.5 % of java submissions
#   ✔ Your memory usage beats 13.64 % of java submissions (56.1 MB)
# Submitting: java_solutions/2515.shortest-distance-to-target-string-in-a-circular-array.java
# - Downloading shortest-distance-to-target-string-in-a-circular-array
#   ✔ Accepted
#   ✔ 164/164 cases passed (6 ms)
#   ✔ Your runtime beats 1.28 % of java submissions
#   ✔ Your memory usage beats 13.14 % of java submissions (47.2 MB)
# Submitting: java_solutions/2516.take-k-of-each-character-from-left-and-right.java
# - Downloading take-k-of-each-character-from-left-and-right
#   ✔ Accepted
#   ✔ 142/142 cases passed (18 ms)
#   ✔ Your runtime beats 24.91 % of java submissions
#   ✔ Your memory usage beats 99.26 % of java submissions (45.9 MB)
# Submitting: java_solutions/2517.maximum-tastiness-of-candy-basket.java
# - Downloading maximum-tastiness-of-candy-basket
#   ✔ Accepted
#   ✔ 40/40 cases passed (67 ms)
#   ✔ Your runtime beats 6.37 % of java submissions
#   ✔ Your memory usage beats 6.63 % of java submissions (71.4 MB)
# Submitting: java_solutions/2518.number-of-great-partitions.java
# - Downloading number-of-great-partitions
#   ✔ Accepted
#   ✔ 46/46 cases passed (37 ms)
#   ✔ Your runtime beats 18.64 % of java submissions
#   ✔ Your memory usage beats 42.37 % of java submissions (52.3 MB)
# Submitting: java_solutions/2520.count-the-digits-that-divide-a-number.java
# - Downloading count-the-digits-that-divide-a-number
#   ✔ Accepted
#   ✔ 56/56 cases passed (3 ms)
#   ✔ Your runtime beats 0.71 % of java submissions
#   ✔ Your memory usage beats 5.33 % of java submissions (42.5 MB)
# Submitting: java_solutions/2521.distinct-prime-factors-of-product-of-array.java
# - Downloading distinct-prime-factors-of-product-of-array
#   ✔ Accepted
#   ✔ 81/81 cases passed (631 ms)
#   ✔ Your runtime beats 5.02 % of java submissions
#   ✔ Your memory usage beats 77.42 % of java submissions (47.4 MB)
# Submitting: java_solutions/2522.partition-string-into-substrings-with-values-at-most-k.java
# - Downloading partition-string-into-substrings-with-values-at-most-k
#   ✔ Accepted
#   ✔ 56/56 cases passed (18 ms)
#   ✔ Your runtime beats 35.71 % of java submissions
#   ✔ Your memory usage beats 17.86 % of java submissions (47.3 MB)
# Submitting: java_solutions/2523.closest-prime-numbers-in-range.java
# - Downloading closest-prime-numbers-in-range
#   ✔ Accepted
#   ✔ 68/68 cases passed (138 ms)
#   ✔ Your runtime beats 31.26 % of java submissions
#   ✔ Your memory usage beats 81.9 % of java submissions (45.9 MB)
# Submitting: java_solutions/2525.categorize-box-according-to-criteria.java
# - Downloading categorize-box-according-to-criteria
#   ✔ Accepted
#   ✔ 50/50 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 97.97 % of java submissions (42.1 MB)
# Submitting: java_solutions/2526.find-consecutive-integers-from-a-data-stream.java
# - Downloading find-consecutive-integers-from-a-data-stream
#   ✔ Accepted
#   ✔ 38/38 cases passed (62 ms)
#   ✔ Your runtime beats 5.36 % of java submissions
#   ✔ Your memory usage beats 44.05 % of java submissions (104.5 MB)
# Submitting: java_solutions/2527.find-xor-beauty-of-array.java
# - Downloading find-xor-beauty-of-array
#   ✔ Accepted
#   ✔ 32/32 cases passed (4 ms)
#   ✔ Your runtime beats 2.86 % of java submissions
#   ✔ Your memory usage beats 17.71 % of java submissions (70.9 MB)
# Submitting: java_solutions/2528.maximize-the-minimum-powered-city.java
# - Downloading maximize-the-minimum-powered-city
#   ✔ Accepted
#   ✔ 30/30 cases passed (215 ms)
#   ✔ Your runtime beats 5.16 % of java submissions
#   ✔ Your memory usage beats 5.81 % of java submissions (94.4 MB)
# Submitting: java_solutions/2529.maximum-count-of-positive-integer-and-negative-integer.java
# - Downloading maximum-count-of-positive-integer-and-negative-integer
#   ✔ Accepted
#   ✔ 169/169 cases passed (6 ms)
#   ✔ Your runtime beats 1 % of java submissions
#   ✔ Your memory usage beats 36.93 % of java submissions (47 MB)
# Submitting: java_solutions/2530.maximal-score-after-applying-k-operations.java
# - Downloading maximal-score-after-applying-k-operations
#   ✔ Accepted
#   ✔ 40/40 cases passed (131 ms)
#   ✔ Your runtime beats 58.77 % of java submissions
#   ✔ Your memory usage beats 23.7 % of java submissions (105.7 MB)
# Submitting: java_solutions/2531.make-number-of-distinct-characters-equal.java
# - Downloading make-number-of-distinct-characters-equal
#   ✔ Accepted
#   ✔ 99/99 cases passed (13 ms)
#   ✔ Your runtime beats 36.54 % of java submissions
#   ✔ Your memory usage beats 53.85 % of java submissions (47.8 MB)
# Submitting: java_solutions/2532.time-to-cross-a-bridge.java
# - Downloading time-to-cross-a-bridge
#   ✔ Accepted
#   ✔ 65/65 cases passed (254 ms)
#   ✔ Your runtime beats 6.25 % of java submissions
#   ✔ Your memory usage beats 6.25 % of java submissions (65.4 MB)
# Submitting: java_solutions/2535.difference-between-element-sum-and-digit-sum-of-an-array.java
# - Downloading difference-between-element-sum-and-digit-sum-of-an-array
#   ✔ Accepted
#   ✔ 142/142 cases passed (22 ms)
#   ✔ Your runtime beats 2.11 % of java submissions
#   ✔ Your memory usage beats 12.58 % of java submissions (47.3 MB)
# Submitting: java_solutions/2536.increment-submatrices-by-one.java
# - Downloading increment-submatrices-by-one
#   ✔ Accepted
#   ✔ 32/32 cases passed (34 ms)
#   ✔ Your runtime beats 23.48 % of java submissions
#   ✔ Your memory usage beats 6.5 % of java submissions (96.3 MB)
# Submitting: java_solutions/2537.count-the-number-of-good-subarrays.java
# - Downloading count-the-number-of-good-subarrays
#   ✔ Accepted
#   ✔ 41/41 cases passed (79 ms)
#   ✔ Your runtime beats 6.85 % of java submissions
#   ✔ Your memory usage beats 34.52 % of java submissions (93.3 MB)
# Submitting: java_solutions/2538.difference-between-maximum-and-minimum-price-sum.java
# - Downloading difference-between-maximum-and-minimum-price-sum
#   ✔ Accepted
#   ✔ 58/58 cases passed (193 ms)
#   ✔ Your runtime beats 5.26 % of java submissions
#   ✔ Your memory usage beats 17.1 % of java submissions (181.4 MB)

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-05-05 14:11:18
