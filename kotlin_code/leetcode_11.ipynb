# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME_3')
    user_cookie = userdata.get('LEETCODE_TOKEN_3')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME_3'] = user_name
    os.environ['LEETCODE_TOKEN_3'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME_3" "$LEETCODE_TOKEN_3" | leetcode user -c

# %%
# %%bash
#
# # top 200-300 answers (next batch)
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v kotlin_solutions_1/*.kt | sed -n '201,300p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 7
# done
# Out:
# Submitting: kotlin_solutions_1/1268.search-suggestions-system.kt
# - Downloading search-suggestions-system
#   ✔ Accepted
#   ✔ 43/43 cases passed (63 ms)
#   ✔ Your runtime beats 52.05 % of kotlin submissions
#   ✔ Your memory usage beats 50.68 % of kotlin submissions (58.6 MB)
# Submitting: kotlin_solutions_1/1269.number-of-ways-to-stay-in-the-same-place-after-some-steps.kt
# - Downloading number-of-ways-to-stay-in-the-same-place-after-some-steps
#   ✔ Accepted
#   ✔ 33/33 cases passed (11 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1275.find-winner-on-a-tic-tac-toe-game.kt
# - Downloading find-winner-on-a-tic-tac-toe-game
#   ✔ Accepted
#   ✔ 101/101 cases passed (13 ms)
#   ✔ Your runtime beats 41.67 % of kotlin submissions
#   ✔ Your memory usage beats 16.67 % of kotlin submissions (45.4 MB)
# Submitting: kotlin_solutions_1/1276.number-of-burgers-with-no-waste-of-ingredients.kt
# - Downloading number-of-burgers-with-no-waste-of-ingredients
#   ✔ Accepted
#   ✔ 1008/1008 cases passed (13 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (46.6 MB)
# Submitting: kotlin_solutions_1/1277.count-square-submatrices-with-all-ones.kt
# - Downloading count-square-submatrices-with-all-ones
#   ✔ Accepted
#   ✔ 32/32 cases passed (27 ms)
#   ✔ Your runtime beats 14.29 % of kotlin submissions
#   ✔ Your memory usage beats 28.57 % of kotlin submissions (73 MB)
# Submitting: kotlin_solutions_1/1278.palindrome-partitioning-iii.kt
# - Downloading palindrome-partitioning-iii
#   ✔ Accepted
#   ✔ 33/33 cases passed (49 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1281.subtract-the-product-and-sum-of-digits-of-an-integer.kt
# - Downloading subtract-the-product-and-sum-of-digits-of-an-integer
#   ✔ Accepted
#   ✔ 123/123 cases passed (6 ms)
#   ✔ Your runtime beats 9.09 % of kotlin submissions
#   ✔ Your memory usage beats 9.09 % of kotlin submissions (41.2 MB)
# Submitting: kotlin_solutions_1/1282.group-the-people-given-the-group-size-they-belong-to.kt
# - Downloading group-the-people-given-the-group-size-they-belong-to
#   ✔ Accepted
#   ✔ 103/103 cases passed (28 ms)
#   ✔ Your runtime beats 40 % of kotlin submissions
#   ✔ Your memory usage beats 60 % of kotlin submissions (51.9 MB)
# Submitting: kotlin_solutions_1/1283.find-the-smallest-divisor-given-a-threshold.kt
# - Downloading find-the-smallest-divisor-given-a-threshold
#   ✔ Accepted
#   ✔ 71/71 cases passed (13 ms)
#   ✔ Your runtime beats 77.78 % of kotlin submissions
#   ✔ Your memory usage beats 13.89 % of kotlin submissions (52.5 MB)
# Submitting: kotlin_solutions_1/1284.minimum-number-of-flips-to-convert-binary-matrix-to-zero-matrix.kt
# - Downloading minimum-number-of-flips-to-convert-binary-matrix-to-zero-matrix
#   ✔ Accepted
#   ✔ 26/26 cases passed (22 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (46.5 MB)
# Submitting: kotlin_solutions_1/1286.iterator-for-combination.kt
# - Downloading iterator-for-combination
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 7: Char 93: ERROR: Type mismatch: inferred type is 'kotlin.collections.List<kotlin.Int>', but 'kotlin.collections.Iterator<kotlin.String>' was expected.
#   ✘ Error: Line 7: Char 93: ERROR: Type mismatch: inferred type is 'kotlin.collections.List<kotlin.Int>', but 'kotlin.collections.Iterator<kotlin.String>' was expected.
# Line 7: Char 129: ERROR: Function invocation 'filter(...)' expected.
# Line 7: Char 138: ERROR: Syntax error: Expecting member declaration.
# Line 7: Char 145: ERROR: Syntax error: Expecting member declaration.
# Line 7: Char 146: ERROR: Syntax error: Expecting member declaration.
# Line 7: Char 154: ERROR: Syntax error: Expecting member declaration.
# Line 7: Char 155: ERROR: Syntax error: Expecting member declaration.
# Line 7: Char 157: ERROR: Syntax error: Expecting member declaration.
# Line 7: Char 159: ERROR: Syntax error: Expecting member declaration.
# Line 7: Char 162: ERROR: Syntax error: Expecting member declaration.
# Line 7: Char 181: ERROR: Syntax error: Expecting a top level declaration.
# Line 7: Char 182: ERROR: Syntax error: Expecting a top level declaration.
# Line 7: Char 186: ERROR: Syntax error: Expecting a top level declaration.
# Line 7: Char 186: ERROR: Function declaration must have a name.
# Line 7: Char 188: ERROR: Unresolved reference 'i'.
# Line 7: Char 190: ERROR: Syntax error: Unexpected tokens (use ';' to separate expressions on the same line).
# Line 7: Char 221: ERROR: An explicit type is required on a value parameter.
# Line 7: Char 226: ERROR: Operator '!=' cannot be applied to 'java.math.BigInteger' and 'kotlin.Int'.
# Line 7: Char 227: ERROR: Unresolved reference 'i'.
# Line 7: Char 241: ERROR: Unresolved reference 'characters'.
# Line 7: Char 277: ERROR: None of the following candidates is applicable:
# fun <T, R> Array<out T>.map(transform: (T) -> R): List<R>
# fun <R> ByteArray.map(transform: (Byte) -> R): List<R>
# fun <R> ShortArray.map(transform: (Short) -> R): List<R>
# fun <R> IntArray.map(transform: (Int) -> R): List<R>
# fun <R> LongArray.map(transform: (Long) -> R): List<R>
# fun <R> FloatArray.map(transform: (Float) -> R): List<R>
# fun <R> DoubleArray.map(transform: (Double) -> R): List<R>
# fun <R> BooleanArray.map(transform: (Boolean) -> R): List<R>
# fun <R> CharArray.map(transform: (Char) -> R): List<R>
# fun <T, R> Iterable<T>.map(transform: (T) -> R): List<R>
# fun <K, V, R> Map<out K, V>.map(transform: (Map.Entry<K, V>) -> R): List<R>
# fun <R> UIntArray.map(transform: (UInt) -> R): List<R>
# fun <R> ULongArray.map(transform: (ULong) -> R): List<R>
# fun <R> UByteArray.map(transform: (UByte) -> R): List<R>
# fun <R> UShortArray.map(transform: (UShort) -> R): List<R>
# fun <T, R> Sequence<T>.map(transform: (T) -> R): Sequence<R>
# fun <R> CharSequence.map(transform: (Char) -> R): List<R>
# Line 7: Char 283: ERROR: Unresolved reference 'characters'.
# Line 7: Char 294: ERROR: Unresolved reference 'it'.
# Line 7: Char 318: ERROR: Syntax error: Expecting a top level declaration.
# Line 7: Char 319: ERROR: Syntax error: Expecting a top level declaration.
# Line 7: Char 325: ERROR: Syntax error: Expecting a top level declaration.
# Line 7: Char 326: ERROR: Syntax error: Expecting a top level declaration.
# Line 7: Char 327: ERROR: Syntax error: Expecting a top level declaration.
# Line 7: Char 328: ERROR: Syntax error: Expecting a top level declaration.
# Line 7: Char 336: ERROR: Syntax error: Expecting a top level declaration.
# Line 7: Char 337: ERROR: Syntax error: Expecting a top level declaration.
# Line 54: Char 32: WARNING: 'static fun readFrom(p0: String!): JsonArray!' is deprecated. Deprecated in Java.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1287.element-appearing-more-than-25-in-sorted-array.kt
# - Downloading element-appearing-more-than-25-in-sorted-array
#   ✔ Accepted
#   ✔ 29/29 cases passed (14 ms)
#   ✔ Your runtime beats 14.29 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (48.9 MB)
# Submitting: kotlin_solutions_1/1288.remove-covered-intervals.kt
# - Downloading remove-covered-intervals
#   ✔ Accepted
#   ✔ 35/35 cases passed (22 ms)
#   ✔ Your runtime beats 28.57 % of kotlin submissions
#   ✔ Your memory usage beats 52.77 % of kotlin submissions (49.7 MB)
# Submitting: kotlin_solutions_1/1289.minimum-falling-path-sum-ii.kt
# - Downloading minimum-falling-path-sum-ii
#   ✔ Accepted
#   ✔ 20/20 cases passed (387 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1290.convert-binary-number-in-a-linked-list-to-integer.kt
# - Downloading convert-binary-number-in-a-linked-list-to-integer
#   ✔ Accepted
#   ✔ 102/102 cases passed (5 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/1291.sequential-digits.kt
# - Downloading sequential-digits
#   ✔ Accepted
#   ✔ 24/24 cases passed (17 ms)
#   ✔ Your runtime beats 14.95 % of kotlin submissions
#   ✔ Your memory usage beats 15.76 % of kotlin submissions (45.4 MB)
# Submitting: kotlin_solutions_1/1292.maximum-side-length-of-a-square-with-sum-less-than-or-equal-to-threshold.kt
# - Downloading maximum-side-length-of-a-square-with-sum-less-than-or-equal-to-threshold
#   ✔ Accepted
#   ✔ 53/53 cases passed (19 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1293.shortest-path-in-a-grid-with-obstacles-elimination.kt
# - Downloading shortest-path-in-a-grid-with-obstacles-elimination
#   ✔ Accepted
#   ✔ 56/56 cases passed (41 ms)
#   ✔ Your runtime beats 52.63 % of kotlin submissions
#   ✔ Your memory usage beats 68.42 % of kotlin submissions (47.1 MB)
# Submitting: kotlin_solutions_1/1295.find-numbers-with-even-number-of-digits.kt
# - Downloading find-numbers-with-even-number-of-digits
#   ✔ Accepted
#   ✔ 105/105 cases passed (4 ms)
#   ✔ Your runtime beats 2.38 % of kotlin submissions
#   ✔ Your memory usage beats 14.28 % of kotlin submissions (46.6 MB)
# Submitting: kotlin_solutions_1/1296.divide-array-in-sets-of-k-consecutive-numbers.kt
# - Downloading divide-array-in-sets-of-k-consecutive-numbers
#   ✔ Accepted
#   ✔ 575/575 cases passed (318 ms)
#   ✔ Your runtime beats 14.29 % of kotlin submissions
#   ✔ Your memory usage beats 85.71 % of kotlin submissions (79.7 MB)
# Submitting: kotlin_solutions_1/1297.maximum-number-of-occurrences-of-a-substring.kt
# - Downloading maximum-number-of-occurrences-of-a-substring
#   ✔ Accepted
#   ✔ 40/40 cases passed (93 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1298.maximum-candies-you-can-get-from-boxes.kt
# - Downloading maximum-candies-you-can-get-from-boxes
#   ✔ Accepted
#   ✔ 44/44 cases passed (24 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (78.1 MB)
# Submitting: kotlin_solutions_1/1299.replace-elements-with-greatest-element-on-right-side.kt
# - Downloading replace-elements-with-greatest-element-on-right-side
#   ✔ Accepted
#   ✔ 90/90 cases passed (11 ms)
#   ✔ Your runtime beats 51.85 % of kotlin submissions
#   ✔ Your memory usage beats 88.89 % of kotlin submissions (49.4 MB)
# Submitting: kotlin_solutions_1/1300.sum-of-mutated-array-closest-to-target.kt
# - Downloading sum-of-mutated-array-closest-to-target
#   ✔ Accepted
#   ✔ 22/22 cases passed (24 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1301.number-of-paths-with-max-score.kt
# - Downloading number-of-paths-with-max-score
#   ✔ Accepted
#   ✔ 36/36 cases passed (299 ms)
#   ✔ Your runtime beats 5.03 % of kotlin submissions
#   ✔ Your memory usage beats 5.03 % of kotlin submissions (55.9 MB)
# Submitting: kotlin_solutions_1/1302.deepest-leaves-sum.kt
# - Downloading deepest-leaves-sum
#   ✔ Accepted
#   ✔ 39/39 cases passed (19 ms)
#   ✔ Your runtime beats 76.47 % of kotlin submissions
#   ✔ Your memory usage beats 70.59 % of kotlin submissions (50.9 MB)
# Submitting: kotlin_solutions_1/1304.find-n-unique-integers-sum-up-to-zero.kt
# - Downloading find-n-unique-integers-sum-up-to-zero
#   ✔ Accepted
#   ✔ 43/43 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 83.33 % of kotlin submissions (41.3 MB)
# Submitting: kotlin_solutions_1/1305.all-elements-in-two-binary-search-trees.kt
# - Downloading all-elements-in-two-binary-search-trees
#   ✔ Accepted
#   ✔ 48/48 cases passed (111 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (57.4 MB)
# Submitting: kotlin_solutions_1/1306.jump-game-iii.kt
# - Downloading jump-game-iii
#   ✔ Accepted
#   ✔ 56/56 cases passed (10 ms)
#   ✔ Your runtime beats 69.77 % of kotlin submissions
#   ✔ Your memory usage beats 62.79 % of kotlin submissions (57.4 MB)
# Submitting: kotlin_solutions_1/1307.verbal-arithmetic-puzzle.kt
# - Downloading verbal-arithmetic-puzzle
#   ✔ Accepted
#   ✔ 35/35 cases passed (1339 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1309.decrypt-string-from-alphabet-to-integer-mapping.kt
# - Downloading decrypt-string-from-alphabet-to-integer-mapping
#   ✔ Accepted
#   ✔ 41/41 cases passed (41 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1310.xor-queries-of-a-subarray.kt
# - Downloading xor-queries-of-a-subarray
#   ✔ Accepted
#   ✔ 46/46 cases passed (345 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (77.5 MB)
# Submitting: kotlin_solutions_1/1311.get-watched-videos-by-your-friends.kt
# - Downloading get-watched-videos-by-your-friends
#   ✔ Accepted
#   ✔ 52/52 cases passed (85 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1312.minimum-insertion-steps-to-make-a-string-palindrome.kt
# - Downloading minimum-insertion-steps-to-make-a-string-palindrome
#   ✔ Accepted
#   ✔ 58/58 cases passed (56 ms)
#   ✔ Your runtime beats 10 % of kotlin submissions
#   ✔ Your memory usage beats 10 % of kotlin submissions (48.9 MB)
# Submitting: kotlin_solutions_1/1313.decompress-run-length-encoded-list.kt
# - Downloading decompress-run-length-encoded-list
#   ✔ Accepted
#   ✔ 53/53 cases passed (21 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
#   ✔ Your memory usage beats 62.5 % of kotlin submissions (46.9 MB)
# Submitting: kotlin_solutions_1/1314.matrix-block-sum.kt
# - Downloading matrix-block-sum
#   ✔ Accepted
#   ✔ 12/12 cases passed (12 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (47.2 MB)
# Submitting: kotlin_solutions_1/1315.sum-of-nodes-with-even-valued-grandparent.kt
# - Downloading sum-of-nodes-with-even-valued-grandparent
#   ✔ Accepted
#   ✔ 76/76 cases passed (38 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1316.distinct-echo-substrings.kt
# - Downloading distinct-echo-substrings
#   ✔ Accepted
#   ✔ 40/40 cases passed (1552 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1317.convert-integer-to-the-sum-of-two-no-zero-integers.kt
# - Downloading convert-integer-to-the-sum-of-two-no-zero-integers
#   ✔ Accepted
#   ✔ 206/206 cases passed (11 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (42.5 MB)
# Submitting: kotlin_solutions_1/1318.minimum-flips-to-make-a-or-b-equal-to-c.kt
# - Downloading minimum-flips-to-make-a-or-b-equal-to-c
#   ✔ Accepted
#   ✔ 64/64 cases passed (71 ms)
#   ✔ Your runtime beats 85.71 % of kotlin submissions
#   ✔ Your memory usage beats 61.9 % of kotlin submissions (39.3 MB)
# Submitting: kotlin_solutions_1/1319.number-of-operations-to-make-network-connected.kt
# - Downloading number-of-operations-to-make-network-connected
#   ✔ Accepted
#   ✔ 36/36 cases passed (79 ms)
#   ✔ Your runtime beats 5.88 % of kotlin submissions
#   ✔ Your memory usage beats 41.18 % of kotlin submissions (86.9 MB)
# Submitting: kotlin_solutions_1/1320.minimum-distance-to-type-a-word-using-two-fingers.kt
# - Downloading minimum-distance-to-type-a-word-using-two-fingers
#   ✔ Accepted
#   ✔ 55/55 cases passed (26 ms)
#   ✔ Your runtime beats 75 % of kotlin submissions
#   ✔ Your memory usage beats 75 % of kotlin submissions (46.1 MB)
# Submitting: kotlin_solutions_1/1323.maximum-69-number.kt
# - Downloading maximum-69-number
#   ✔ Accepted
#   ✔ 153/153 cases passed (7 ms)
#   ✔ Your runtime beats 45.45 % of kotlin submissions
#   ✔ Your memory usage beats 54.55 % of kotlin submissions (41.1 MB)
# Submitting: kotlin_solutions_1/1324.print-words-vertically.kt
# - Downloading print-words-vertically
#   ✔ Accepted
#   ✔ 32/32 cases passed (119 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1325.delete-leaves-with-a-given-value.kt
# - Downloading delete-leaves-with-a-given-value
#   ✔ Accepted
#   ✔ 51/51 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (45 MB)
# Submitting: kotlin_solutions_1/1326.minimum-number-of-taps-to-open-to-water-a-garden.kt
# - Downloading minimum-number-of-taps-to-open-to-water-a-garden
#   ✔ Accepted
#   ✔ 42/42 cases passed (16 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/1328.break-a-palindrome.kt
# - Downloading break-a-palindrome
#   ✔ Accepted
#   ✔ 33/33 cases passed (9 ms)
#   ✔ Your runtime beats 28.57 % of kotlin submissions
#   ✔ Your memory usage beats 28.57 % of kotlin submissions (42.5 MB)
# Submitting: kotlin_solutions_1/1329.sort-the-matrix-diagonally.kt
# - Downloading sort-the-matrix-diagonally
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 7: Char 263: WARNING: Parameter 'it: Pair<Int, Pair<Int, Int>>' is never used, could be renamed to '_'.
#   ✘ Error: Line 7: Char 263: WARNING: Parameter 'it: Pair<Int, Pair<Int, Int>>' is never used, could be renamed to '_'.
# Line 7: Char 266: ERROR: Unresolved reference 'v'.
# Line 7: Char 267: ERROR: Syntax error: Expecting ')'.
# Line 7: Char 267: ERROR: Syntax error: Unexpected tokens (use ';' to separate expressions on the same line).
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1330.reverse-subarray-to-maximize-array-value.kt
# - Downloading reverse-subarray-to-maximize-array-value
#   ✔ Accepted
#   ✔ 28/28 cases passed (29 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1331.rank-transform-of-an-array.kt
# - Downloading rank-transform-of-an-array
#   ✔ Accepted
#   ✔ 43/43 cases passed (101 ms)
#   ✔ Your runtime beats 27.69 % of kotlin submissions
#   ✔ Your memory usage beats 19.09 % of kotlin submissions (72.9 MB)
# Submitting: kotlin_solutions_1/1332.remove-palindromic-subsequences.kt
# - Downloading remove-palindromic-subsequences
#   ✔ Accepted
#   ✔ 48/48 cases passed (7 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
#   ✔ Your memory usage beats 10 % of kotlin submissions (41.9 MB)
# Submitting: kotlin_solutions_1/1333.filter-restaurants-by-vegan-friendly-price-and-distance.kt
# - Downloading filter-restaurants-by-vegan-friendly-price-and-distance
#   ✔ Accepted
#   ✔ 53/53 cases passed (23 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (63.3 MB)
# Submitting: kotlin_solutions_1/1334.find-the-city-with-the-smallest-number-of-neighbors-at-a-threshold-distance.kt
# - Downloading find-the-city-with-the-smallest-number-of-neighbors-at-a-threshold-distance
#   ✔ Accepted
#   ✔ 54/54 cases passed (38 ms)
#   ✔ Your runtime beats 60.87 % of kotlin submissions
#   ✔ Your memory usage beats 78.26 % of kotlin submissions (48.5 MB)
# Submitting: kotlin_solutions_1/1335.minimum-difficulty-of-a-job-schedule.kt
# - Downloading minimum-difficulty-of-a-job-schedule
#   ✔ Accepted
#   ✔ 34/34 cases passed (29 ms)
#   ✔ Your runtime beats 18.18 % of kotlin submissions
#   ✔ Your memory usage beats 9.09 % of kotlin submissions (44.7 MB)
# Submitting: kotlin_solutions_1/1337.the-k-weakest-rows-in-a-matrix.kt
# - Downloading the-k-weakest-rows-in-a-matrix
#   ✔ Accepted
#   ✔ 52/52 cases passed (24 ms)
#   ✔ Your runtime beats 21.43 % of kotlin submissions
#   ✔ Your memory usage beats 42.86 % of kotlin submissions (54.2 MB)
# Submitting: kotlin_solutions_1/1338.reduce-array-size-to-the-half.kt
# - Downloading reduce-array-size-to-the-half
#   ✔ Accepted
#   ✔ 33/33 cases passed (99 ms)
#   ✔ Your runtime beats 12.5 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (82.8 MB)
# Submitting: kotlin_solutions_1/1339.maximum-product-of-splitted-binary-tree.kt
# - Downloading maximum-product-of-splitted-binary-tree
#   ✔ Accepted
#   ✔ 56/56 cases passed (65 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1340.jump-game-v.kt
# - Downloading jump-game-v
#   ✔ Accepted
#   ✔ 129/129 cases passed (124 ms)
#   ✔ Your runtime beats 14.29 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (54.2 MB)
# Submitting: kotlin_solutions_1/1342.number-of-steps-to-reduce-a-number-to-zero.kt
# - Downloading number-of-steps-to-reduce-a-number-to-zero
#   ✔ Accepted
#   ✔ 204/204 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 54.55 % of kotlin submissions (40.2 MB)
# Submitting: kotlin_solutions_1/1343.number-of-sub-arrays-of-size-k-and-average-greater-than-or-equal-to-threshold.kt
# - Downloading number-of-sub-arrays-of-size-k-and-average-greater-than-or-equal-to-threshold
#   ✔ Accepted
#   ✔ 69/69 cases passed (24 ms)
#   ✔ Your runtime beats 26.67 % of kotlin submissions
#   ✔ Your memory usage beats 6.67 % of kotlin submissions (65.1 MB)
# Submitting: kotlin_solutions_1/1344.angle-between-hands-of-a-clock.kt
# - Downloading angle-between-hands-of-a-clock
#   ✔ Accepted
#   ✔ 105/105 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 20.4 % of kotlin submissions (40.6 MB)
# Submitting: kotlin_solutions_1/1345.jump-game-iv.kt
# - Downloading jump-game-iv
#   ✔ Accepted
#   ✔ 535/535 cases passed (279 ms)
#   ✔ Your runtime beats 5.26 % of kotlin submissions
#   ✔ Your memory usage beats 10.53 % of kotlin submissions (87 MB)
# Submitting: kotlin_solutions_1/1346.check-if-n-and-its-double-exist.kt
# - Downloading check-if-n-and-its-double-exist
#   ✔ Accepted
#   ✔ 113/113 cases passed (20 ms)
#   ✔ Your runtime beats 5.56 % of kotlin submissions
#   ✔ Your memory usage beats 22.22 % of kotlin submissions (46 MB)
# Submitting: kotlin_solutions_1/1347.minimum-number-of-steps-to-make-two-strings-anagram.kt
# - Downloading minimum-number-of-steps-to-make-two-strings-anagram
#   ✔ Accepted
#   ✔ 63/63 cases passed (30 ms)
#   ✔ Your runtime beats 28.57 % of kotlin submissions
#   ✔ Your memory usage beats 57.14 % of kotlin submissions (47.8 MB)
# Submitting: kotlin_solutions_1/1348.tweet-counts-per-frequency.kt
# - Downloading tweet-counts-per-frequency
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 212: ERROR: None of the following candidates is applicable:
#   ✘ Error: Line 2: Char 212: ERROR: None of the following candidates is applicable:
# fun Array<out Byte>.sum(): Int
# fun Array<out Short>.sum(): Int
# fun Array<out Int>.sum(): Int
# fun Array<out Long>.sum(): Long
# fun Array<out Float>.sum(): Float
# fun Array<out Double>.sum(): Double
# fun ByteArray.sum(): Int
# fun ShortArray.sum(): Int
# fun IntArray.sum(): Int
# fun LongArray.sum(): Long
# fun FloatArray.sum(): Float
# fun DoubleArray.sum(): Double
# fun Iterable<Byte>.sum(): Int
# fun Iterable<Short>.sum(): Int
# fun Iterable<Int>.sum(): Int
# fun Iterable<Long>.sum(): Long
# fun Iterable<Float>.sum(): Float
# fun Iterable<Double>.sum(): Double
# fun Iterable<UInt>.sum(): UInt
# fun Iterable<ULong>.sum(): ULong
# fun Iterable<UByte>.sum(): UInt
# fun Iterable<UShort>.sum(): UInt
# fun Array<out UInt>.sum(): UInt
# fun Array<out ULong>.sum(): ULong
# fun Array<out UByte>.sum(): UInt
# fun Array<out UShort>.sum(): UInt
# fun UIntArray.sum(): UInt
# fun ULongArray.sum(): ULong
# fun UByteArray.sum(): UInt
# fun UShortArray.sum(): UInt
# fun Sequence<Byte>.sum(): Int
# fun Sequence<Short>.sum(): Int
# fun Sequence<Int>.sum(): Int
# fun Sequence<Long>.sum(): Long
# fun Sequence<Float>.sum(): Float
# fun Sequence<Double>.sum(): Double
# fun Sequence<UInt>.sum(): UInt
# fun Sequence<ULong>.sum(): ULong
# fun Sequence<UByte>.sum(): UInt
# fun Sequence<UShort>.sum(): UInt
# Line 54: Char 32: WARNING: 'static fun readFrom(p0: String!): JsonArray!' is deprecated. Deprecated in Java.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1349.maximum-students-taking-exam.kt
# - Downloading maximum-students-taking-exam
#   ✔ Accepted
#   ✔ 57/57 cases passed (31 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1351.count-negative-numbers-in-a-sorted-matrix.kt
# - Downloading count-negative-numbers-in-a-sorted-matrix
#   ✔ Accepted
#   ✔ 44/44 cases passed (2 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
#   ✔ Your memory usage beats 75 % of kotlin submissions (48.4 MB)
# Submitting: kotlin_solutions_1/1352.product-of-the-last-k-numbers.kt
# - Downloading product-of-the-last-k-numbers
#   ✔ Accepted
#   ✔ 35/35 cases passed (57 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 11.11 % of kotlin submissions (95.5 MB)
# Submitting: kotlin_solutions_1/1353.maximum-number-of-events-that-can-be-attended.kt
# - Downloading maximum-number-of-events-that-can-be-attended
#   ✔ Accepted
#   ✔ 45/45 cases passed (103 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 62.5 % of kotlin submissions (95.9 MB)
# Submitting: kotlin_solutions_1/1354.construct-target-array-with-multiple-sums.kt
# - Downloading construct-target-array-with-multiple-sums
#   ✔ Accepted
#   ✔ 73/73 cases passed (10 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 55.56 % of kotlin submissions (53.3 MB)
# Submitting: kotlin_solutions_1/1356.sort-integers-by-the-number-of-1-bits.kt
# - Downloading sort-integers-by-the-number-of-1-bits
#   ✔ Accepted
#   ✔ 77/77 cases passed (30 ms)
#   ✔ Your runtime beats 10 % of kotlin submissions
#   ✔ Your memory usage beats 40 % of kotlin submissions (49.5 MB)
# Submitting: kotlin_solutions_1/1357.apply-discount-every-n-orders.kt
# - Downloading apply-discount-every-n-orders
#   ✔ Accepted
#   ✔ 25/25 cases passed (217 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (101.8 MB)
# Submitting: kotlin_solutions_1/1358.number-of-substrings-containing-all-three-characters.kt
# - Downloading number-of-substrings-containing-all-three-characters
#   ✔ Accepted
#   ✔ 55/55 cases passed (25 ms)
#   ✔ Your runtime beats 26.36 % of kotlin submissions
#   ✔ Your memory usage beats 47.01 % of kotlin submissions (45.8 MB)
# Submitting: kotlin_solutions_1/1359.count-all-valid-pickup-and-delivery-options.kt
# - Downloading count-all-valid-pickup-and-delivery-options
#   ✔ Accepted
#   ✔ 36/36 cases passed (3 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1360.number-of-days-between-two-dates.kt
# - Downloading number-of-days-between-two-dates
#   ✔ Accepted
#   ✔ 105/105 cases passed (9 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1361.validate-binary-tree-nodes.kt
# - Downloading validate-binary-tree-nodes
#   ✘ Wrong Answer
#   ✘ 32/51 cases passed (N/A)
#   ✘ Testcase: 4
# [1,-1,3,-1]
# [2,-1,-1,-1]
#   ✘ Answer: false
#   ✘ Expected Answer: true
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1362.closest-divisors.kt
# - Downloading closest-divisors
#   ✔ Accepted
#   ✔ 113/113 cases passed (11 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1363.largest-multiple-of-three.kt
# - Downloading largest-multiple-of-three
#   ✔ Accepted
#   ✔ 45/45 cases passed (31 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1365.how-many-numbers-are-smaller-than-the-current-number.kt
# - Downloading how-many-numbers-are-smaller-than-the-current-number
#   ✔ Accepted
#   ✔ 103/103 cases passed (26 ms)
#   ✔ Your runtime beats 14.5 % of kotlin submissions
#   ✔ Your memory usage beats 6.11 % of kotlin submissions (48.2 MB)
# Submitting: kotlin_solutions_1/1366.rank-teams-by-votes.kt
# - Downloading rank-teams-by-votes
#   ✔ Accepted
#   ✔ 37/37 cases passed (38 ms)
#   ✔ Your runtime beats 40 % of kotlin submissions
#   ✔ Your memory usage beats 40 % of kotlin submissions (48.5 MB)
# Submitting: kotlin_solutions_1/1367.linked-list-in-binary-tree.kt
# - Downloading linked-list-in-binary-tree
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 7: Char 350: ERROR: 'fun DeepRecursiveFunction<*, *>.invoke(value: Any?): Nothing' is deprecated. 'invoke' should not be called from DeepRecursiveScope. Use 'callRecursive' to do recursion in the heap instead of the call stack.
#   ✘ Error: Line 7: Char 350: ERROR: 'fun DeepRecursiveFunction<*, *>.invoke(value: Any?): Nothing' is deprecated. 'invoke' should not be called from DeepRecursiveScope. Use 'callRecursive' to do recursion in the heap instead of the call stack.
# Line 7: Char 372: WARNING: Unreachable code.
# Line 7: Char 397: WARNING: Unreachable code.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1368.minimum-cost-to-make-at-least-one-valid-path-in-a-grid.kt
# - Downloading minimum-cost-to-make-at-least-one-valid-path-in-a-grid
#   ✔ Accepted
#   ✔ 69/69 cases passed (48 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (56 MB)
# Submitting: kotlin_solutions_1/1370.increasing-decreasing-string.kt
# - Downloading increasing-decreasing-string
#   ✔ Accepted
#   ✔ 323/323 cases passed (25 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1371.find-the-longest-substring-containing-vowels-in-even-counts.kt
# - Downloading find-the-longest-substring-containing-vowels-in-even-counts
#   ✔ Accepted
#   ✔ 55/55 cases passed (33 ms)
#   ✔ Your runtime beats 66.67 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (51.3 MB)
# Submitting: kotlin_solutions_1/1372.longest-zigzag-path-in-a-binary-tree.kt
# - Downloading longest-zigzag-path-in-a-binary-tree
#   ✔ Accepted
#   ✔ 58/58 cases passed (62 ms)
#   ✔ Your runtime beats 8.33 % of kotlin submissions
#   ✔ Your memory usage beats 16.67 % of kotlin submissions (61.1 MB)
# Submitting: kotlin_solutions_1/1373.maximum-sum-bst-in-binary-tree.kt
# - Downloading maximum-sum-bst-in-binary-tree
#   ✔ Accepted
#   ✔ 60/60 cases passed (79 ms)
#   ✔ Your runtime beats 12.5 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (70.1 MB)
# Submitting: kotlin_solutions_1/1374.generate-a-string-with-characters-that-have-odd-counts.kt
# - Downloading generate-a-string-with-characters-that-have-odd-counts
#   ✔ Accepted
#   ✔ 103/103 cases passed (6 ms)
#   ✔ Your runtime beats 53.85 % of kotlin submissions
#   ✔ Your memory usage beats 23.08 % of kotlin submissions (42.3 MB)
# Submitting: kotlin_solutions_1/1375.number-of-times-binary-string-is-prefix-aligned.kt
# - Downloading number-of-times-binary-string-is-prefix-aligned
#   ✔ Accepted
#   ✔ 63/63 cases passed (34 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1376.time-needed-to-inform-all-employees.kt
# - Downloading time-needed-to-inform-all-employees
#   ✔ Accepted
#   ✔ 39/39 cases passed (153 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 27.78 % of kotlin submissions (74 MB)
# Submitting: kotlin_solutions_1/1377.frog-position-after-t-seconds.kt
# - Downloading frog-position-after-t-seconds
#   ✔ Accepted
#   ✔ 207/207 cases passed (26 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1379.find-a-corresponding-node-of-a-binary-tree-in-a-clone-of-that-tree.kt
# - Downloading find-a-corresponding-node-of-a-binary-tree-in-a-clone-of-that-tree
#   ✘ Runtime Error
#   ✘ 0/56 cases passed (N/A)
#   ✘ Error: Line 22: Exception in thread "main" java.lang.UnsupportedOperationException: Not an array: 3
#   ✘ Error: Line 22: Exception in thread "main" java.lang.UnsupportedOperationException: Not an array: 3
#   ✘ Testcase: [7,4,3,null,null,6,19]
# 3
#   ✘ Answer:
#   ✘ Expected Answer: 3
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1380.lucky-numbers-in-a-matrix.kt
# - Downloading lucky-numbers-in-a-matrix
#   ✔ Accepted
#   ✔ 106/106 cases passed (29 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1381.design-a-stack-with-increment-operation.kt
# - Downloading design-a-stack-with-increment-operation
#   ✔ Accepted
#   ✔ 34/34 cases passed (21 ms)
#   ✔ Your runtime beats 66.67 % of kotlin submissions
#   ✔ Your memory usage beats 55.56 % of kotlin submissions (48.4 MB)
# Submitting: kotlin_solutions_1/1382.balance-a-binary-search-tree.kt
# - Downloading balance-a-binary-search-tree
#   ✔ Accepted
#   ✔ 17/17 cases passed (63 ms)
#   ✔ Your runtime beats 12.5 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (52.1 MB)
# Submitting: kotlin_solutions_1/1383.maximum-performance-of-a-team.kt
# - Downloading maximum-performance-of-a-team
#   ✔ Accepted
#   ✔ 55/55 cases passed (103 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1385.find-the-distance-value-between-two-arrays.kt
# - Downloading find-the-distance-value-between-two-arrays
#   ✔ Accepted
#   ✔ 103/103 cases passed (5 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 44.44 % of kotlin submissions (46.2 MB)
# Submitting: kotlin_solutions_1/1386.cinema-seat-allocation.kt
# - Downloading cinema-seat-allocation
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 8: Char 76: ERROR: Return type mismatch: expected 'kotlin.Int', actual 'kotlin.IntArray'.
#   ✘ Error: Line 8: Char 76: ERROR: Return type mismatch: expected 'kotlin.Int', actual 'kotlin.IntArray'.
# Line 8: Char 115: ERROR: Overload resolution ambiguity between candidates:
# fun <T> Iterable<T>.sumOf(selector: (T) -> Int): Int
# fun <T> Iterable<T>.sumOf(selector: (T) -> Long): Long
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1387.sort-integers-by-the-power-value.kt
# - Downloading sort-integers-by-the-power-value
#   ✔ Accepted
#   ✔ 333/333 cases passed (648 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1388.pizza-with-3n-slices.kt
# - Downloading pizza-with-3n-slices
#   ✔ Accepted
#   ✔ 69/69 cases passed (105 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (58.7 MB)
# Submitting: kotlin_solutions_1/1390.four-divisors.kt
# - Downloading four-divisors
#   ✔ Accepted
#   ✔ 19/19 cases passed (143 ms)
#   ✔ Your runtime beats 60 % of kotlin submissions
# [WARN] Failed to get memory percentile.

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-08-17 17:26:06
