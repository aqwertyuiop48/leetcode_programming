# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME_3')
    user_cookie = userdata.get('LEETCODE_TOKEN_3')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME_3'] = user_name
    os.environ['LEETCODE_TOKEN_3'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME_3" "$LEETCODE_TOKEN_3" | leetcode user -c

# %%
# %%bash
#
# # top 600-700 answers (7th batch)
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v kotlin_solutions_1/*.kt | sed -n '601,700p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 7
# done
# Out:
# Submitting: kotlin_solutions_1/1878.get-biggest-three-rhombus-sums-in-a-grid.kt
# - Downloading problems
# - Downloading get-biggest-three-rhombus-sums-in-a-grid
#   ✔ Accepted
#   ✔ 119/119 cases passed (232 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 16.67 % of kotlin submissions (57.6 MB)
# Submitting: kotlin_solutions_1/1880.check-if-word-equals-summation-of-two-words.kt
# - Downloading check-if-word-equals-summation-of-two-words
#   ✔ Accepted
#   ✔ 100/100 cases passed (11 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1883.minimum-skips-to-arrive-at-meeting-on-time.kt
# - Downloading minimum-skips-to-arrive-at-meeting-on-time
#   ✔ Accepted
#   ✔ 61/61 cases passed (46 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1884.egg-drop-with-2-eggs-and-n-floors.kt
# - Downloading egg-drop-with-2-eggs-and-n-floors
#   ✔ Accepted
#   ✔ 139/139 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 40 % of kotlin submissions (40 MB)
# Submitting: kotlin_solutions_1/1886.determine-whether-matrix-can-be-obtained-by-rotation.kt
# - Downloading determine-whether-matrix-can-be-obtained-by-rotation
#   ✔ Accepted
#   ✔ 114/114 cases passed (13 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 9.09 % of kotlin submissions (46.4 MB)
# Submitting: kotlin_solutions_1/1887.reduction-operations-to-make-the-array-elements-equal.kt
# - Downloading reduction-operations-to-make-the-array-elements-equal
#   ✔ Accepted
#   ✔ 78/78 cases passed (216 ms)
#   ✔ Your runtime beats 12.5 % of kotlin submissions
#   ✔ Your memory usage beats 62.5 % of kotlin submissions (62 MB)
# Submitting: kotlin_solutions_1/1888.minimum-number-of-flips-to-make-the-binary-string-alternating.kt
# - Downloading minimum-number-of-flips-to-make-the-binary-string-alternating
#   ✔ Accepted
#   ✔ 66/66 cases passed (54 ms)
#   ✔ Your runtime beats 11.76 % of kotlin submissions
#   ✔ Your memory usage beats 17.65 % of kotlin submissions (47.1 MB)
# Submitting: kotlin_solutions_1/1889.minimum-space-wasted-from-packaging.kt
# - Downloading minimum-space-wasted-from-packaging
#   ✔ Accepted
#   ✔ 42/42 cases passed (391 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1893.check-if-all-the-integers-in-a-range-are-covered.kt
# - Downloading check-if-all-the-integers-in-a-range-are-covered
#   ✔ Accepted
#   ✔ 106/106 cases passed (3 ms)
#   ✔ Your runtime beats 13.33 % of kotlin submissions
#   ✔ Your memory usage beats 13.33 % of kotlin submissions (43 MB)
# Submitting: kotlin_solutions_1/1894.find-the-student-that-will-replace-the-chalk.kt
# - Downloading find-the-student-that-will-replace-the-chalk
#   ✔ Accepted
#   ✔ 74/74 cases passed (34 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1895.largest-magic-square.kt
# - Downloading largest-magic-square
#   ✔ Accepted
#   ✔ 81/81 cases passed (71 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1896.minimum-cost-to-change-the-final-value-of-expression.kt
# - Downloading minimum-cost-to-change-the-final-value-of-expression
#   ✔ Accepted
#   ✔ 70/70 cases passed (51 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (48 MB)
# Submitting: kotlin_solutions_1/1897.redistribute-characters-to-make-all-strings-equal.kt
# - Downloading redistribute-characters-to-make-all-strings-equal
#   ✔ Accepted
#   ✔ 179/179 cases passed (30 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (48.9 MB)
# Submitting: kotlin_solutions_1/1898.maximum-number-of-removable-characters.kt
# - Downloading maximum-number-of-removable-characters
#   ✔ Accepted
#   ✔ 67/67 cases passed (81 ms)
#   ✔ Your runtime beats 66.67 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (66.6 MB)
# Submitting: kotlin_solutions_1/1899.merge-triplets-to-form-target-triplet.kt
# - Downloading merge-triplets-to-form-target-triplet
# [ERROR] session expired, please login again [code=-1]
# Submitting: kotlin_solutions_1/1900.the-earliest-and-latest-rounds-where-players-compete.kt
# - Downloading the-earliest-and-latest-rounds-where-players-compete
#   ✔ Accepted
#   ✔ 139/139 cases passed (12 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (43.7 MB)
# Submitting: kotlin_solutions_1/1901.find-a-peak-element-ii.kt
# - Downloading find-a-peak-element-ii
#   ✔ Accepted
#   ✔ 51/51 cases passed (19 ms)
#   ✔ Your runtime beats 9.38 % of kotlin submissions
#   ✔ Your memory usage beats 6.25 % of kotlin submissions (102.7 MB)
# Submitting: kotlin_solutions_1/1903.largest-odd-number-in-string.kt
# - Downloading largest-odd-number-in-string
#   ✔ Accepted
#   ✔ 196/196 cases passed (2 ms)
#   ✔ Your runtime beats 60 % of kotlin submissions
#   ✔ Your memory usage beats 28 % of kotlin submissions (47.6 MB)
# Submitting: kotlin_solutions_1/1904.the-number-of-full-rounds-you-have-played.kt
# - Downloading the-number-of-full-rounds-you-have-played
#   ✔ Accepted
#   ✔ 104/104 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (41 MB)
# Submitting: kotlin_solutions_1/1905.count-sub-islands.kt
# - Downloading count-sub-islands
#   ✔ Accepted
#   ✔ 57/57 cases passed (117 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1906.minimum-absolute-difference-queries.kt
# - Downloading minimum-absolute-difference-queries
#   ✔ Accepted
#   ✔ 60/60 cases passed (135 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/1909.remove-one-element-to-make-the-array-strictly-increasing.kt
# - Downloading remove-one-element-to-make-the-array-strictly-increasing
#   ✔ Accepted
#   ✔ 109/109 cases passed (121 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1910.remove-all-occurrences-of-a-substring.kt
# - Downloading remove-all-occurrences-of-a-substring
#   ✔ Accepted
#   ✔ 82/82 cases passed (15 ms)
#   ✔ Your runtime beats 30 % of kotlin submissions
#   ✔ Your memory usage beats 10 % of kotlin submissions (46.2 MB)
# Submitting: kotlin_solutions_1/1911.maximum-alternating-subsequence-sum.kt
# - Downloading maximum-alternating-subsequence-sum
#   ✔ Accepted
#   ✔ 65/65 cases passed (451 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
#   ✔ Your memory usage beats 80 % of kotlin submissions (64.3 MB)
# Submitting: kotlin_solutions_1/1913.maximum-product-difference-between-two-pairs.kt
# - Downloading maximum-product-difference-between-two-pairs
#   ✔ Accepted
#   ✔ 96/96 cases passed (250 ms)
#   ✔ Your runtime beats 14.29 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (49.3 MB)
# Submitting: kotlin_solutions_1/1914.cyclically-rotating-a-grid.kt
# - Downloading cyclically-rotating-a-grid
#   ✔ Accepted
#   ✔ 68/68 cases passed (291 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1916.count-ways-to-build-rooms-in-an-ant-colony.kt
# - Downloading count-ways-to-build-rooms-in-an-ant-colony
#   ✔ Accepted
#   ✔ 66/66 cases passed (823 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1920.build-array-from-permutation.kt
# - Downloading build-array-from-permutation
#   ✔ Accepted
#   ✔ 140/140 cases passed (1 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (49 MB)
# Submitting: kotlin_solutions_1/1921.eliminate-maximum-number-of-monsters.kt
# - Downloading eliminate-maximum-number-of-monsters
#   ✔ Accepted
#   ✔ 131/131 cases passed (164 ms)
#   ✔ Your runtime beats 6.25 % of kotlin submissions
#   ✔ Your memory usage beats 18.75 % of kotlin submissions (67.2 MB)
# Submitting: kotlin_solutions_1/1922.count-good-numbers.kt
# - Downloading count-good-numbers
#   ✔ Accepted
#   ✔ 166/166 cases passed (11 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1923.longest-common-subpath.kt
# - Downloading longest-common-subpath
#   ✔ Accepted
#   ✔ 81/81 cases passed (275 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (92.8 MB)
# Submitting: kotlin_solutions_1/1925.count-square-sum-triples.kt
# - Downloading count-square-sum-triples
#   ✔ Accepted
#   ✔ 91/91 cases passed (25 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (41.1 MB)
# Submitting: kotlin_solutions_1/1927.sum-game.kt
# - Downloading sum-game
#   ✔ Accepted
#   ✔ 95/95 cases passed (45 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1929.concatenation-of-array.kt
# - Downloading concatenation-of-array
#   ✔ Accepted
#   ✔ 92/92 cases passed (1 ms)
#   ✔ Your runtime beats 98.76 % of kotlin submissions
#   ✔ Your memory usage beats 18.94 % of kotlin submissions (47.3 MB)
# Submitting: kotlin_solutions_1/1930.unique-length-3-palindromic-subsequences.kt
# - Downloading unique-length-3-palindromic-subsequences
#   ✔ Accepted
#   ✔ 70/70 cases passed (130 ms)
#   ✔ Your runtime beats 57.14 % of kotlin submissions
#   ✔ Your memory usage beats 57.14 % of kotlin submissions (48.4 MB)
# Submitting: kotlin_solutions_1/1931.painting-a-grid-with-three-different-colors.kt
# - Downloading painting-a-grid-with-three-different-colors
#   ✔ Accepted
#   ✔ 84/84 cases passed (47 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/1932.merge-bsts-to-create-single-bst.kt
# - Downloading merge-bsts-to-create-single-bst
#   ✔ Accepted
#   ✔ 475/475 cases passed (933 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/1935.maximum-number-of-words-you-can-type.kt
# - Downloading maximum-number-of-words-you-can-type
#   ✔ Accepted
#   ✔ 20/20 cases passed (15 ms)
#   ✔ Your runtime beats 55.56 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (43.6 MB)
# Submitting: kotlin_solutions_1/1936.add-minimum-number-of-rungs.kt
# - Downloading add-minimum-number-of-rungs
#   ✔ Accepted
#   ✔ 117/117 cases passed (17 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1941.check-if-all-characters-have-equal-number-of-occurrences.kt
# - Downloading check-if-all-characters-have-equal-number-of-occurrences
#   ✔ Accepted
#   ✔ 134/134 cases passed (25 ms)
#   ✔ Your runtime beats 7.69 % of kotlin submissions
#   ✔ Your memory usage beats 7.69 % of kotlin submissions (45.5 MB)
# Submitting: kotlin_solutions_1/1942.the-number-of-the-smallest-unoccupied-chair.kt
# - Downloading the-number-of-the-smallest-unoccupied-chair
#   ✔ Accepted
#   ✔ 65/65 cases passed (107 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (65.2 MB)
# Submitting: kotlin_solutions_1/1943.describe-the-painting.kt
# - Downloading describe-the-painting
#   ✔ Accepted
#   ✔ 68/68 cases passed (111 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 16.67 % of kotlin submissions (88.3 MB)
# Submitting: kotlin_solutions_1/1944.number-of-visible-people-in-a-queue.kt
# - Downloading number-of-visible-people-in-a-queue
#   ✔ Accepted
#   ✔ 42/42 cases passed (134 ms)
#   ✔ Your runtime beats 10.53 % of kotlin submissions
#   ✔ Your memory usage beats 5.26 % of kotlin submissions (69.2 MB)
# Submitting: kotlin_solutions_1/1945.sum-of-digits-of-string-after-convert.kt
# - Downloading sum-of-digits-of-string-after-convert
#   ✔ Accepted
#   ✔ 216/216 cases passed (20 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 11.11 % of kotlin submissions (46.4 MB)
# Submitting: kotlin_solutions_1/1946.largest-number-after-mutating-substring.kt
# - Downloading largest-number-after-mutating-substring
#   ✔ Accepted
#   ✔ 279/279 cases passed (67 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (48.6 MB)
# Submitting: kotlin_solutions_1/1947.maximum-compatibility-score-sum.kt
# - Downloading maximum-compatibility-score-sum
#   ✔ Accepted
#   ✔ 86/86 cases passed (25 ms)
#   ✔ Your runtime beats 60 % of kotlin submissions
#   ✔ Your memory usage beats 60 % of kotlin submissions (45.8 MB)
# Submitting: kotlin_solutions_1/1952.three-divisors.kt
# - Downloading three-divisors
#   ✔ Accepted
#   ✔ 229/229 cases passed (6 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1953.maximum-number-of-weeks-for-which-you-can-work.kt
# - Downloading maximum-number-of-weeks-for-which-you-can-work
#   ✔ Accepted
#   ✔ 74/74 cases passed (20 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1954.minimum-garden-perimeter-to-collect-enough-apples.kt
# - Downloading minimum-garden-perimeter-to-collect-enough-apples
#   ✔ Accepted
#   ✔ 306/306 cases passed (42 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1955.count-number-of-special-subsequences.kt
# - Downloading count-number-of-special-subsequences
#   ✔ Accepted
#   ✔ 99/99 cases passed (15 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1957.delete-characters-to-make-fancy-string.kt
# - Downloading delete-characters-to-make-fancy-string
#   ✔ Accepted
#   ✔ 306/306 cases passed (150 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/1958.check-if-move-is-legal.kt
# - Downloading check-if-move-is-legal
#   ✔ Accepted
#   ✔ 220/220 cases passed (18 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1960.maximum-product-of-the-length-of-two-palindromic-substrings.kt
# - Downloading maximum-product-of-the-length-of-two-palindromic-substrings
#   ✔ Accepted
#   ✔ 67/67 cases passed (107 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1961.check-if-string-is-a-prefix-of-array.kt
# - Downloading check-if-string-is-a-prefix-of-array
#   ✔ Accepted
#   ✔ 349/349 cases passed (33 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 7.69 % of kotlin submissions (47.8 MB)
# Submitting: kotlin_solutions_1/1962.remove-stones-to-minimize-the-total.kt
# - Downloading remove-stones-to-minimize-the-total
#   ✔ Accepted
#   ✔ 60/60 cases passed (214 ms)
#   ✔ Your runtime beats 70 % of kotlin submissions
#   ✔ Your memory usage beats 75 % of kotlin submissions (62.1 MB)
# Submitting: kotlin_solutions_1/1963.minimum-number-of-swaps-to-make-the-string-balanced.kt
# - Downloading minimum-number-of-swaps-to-make-the-string-balanced
#   ✔ Accepted
#   ✔ 59/59 cases passed (17 ms)
#   ✔ Your runtime beats 66.67 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (56.9 MB)
# Submitting: kotlin_solutions_1/1964.find-the-longest-valid-obstacle-course-at-each-position.kt
# - Downloading find-the-longest-valid-obstacle-course-at-each-position
#   ✔ Accepted
#   ✔ 78/78 cases passed (230 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
#   ✔ Your memory usage beats 40 % of kotlin submissions (69.7 MB)
# Submitting: kotlin_solutions_1/1967.number-of-strings-that-appear-as-substrings-in-word.kt
# - Downloading number-of-strings-that-appear-as-substrings-in-word
#   ✔ Accepted
#   ✔ 83/83 cases passed (8 ms)
#   ✔ Your runtime beats 66.67 % of kotlin submissions
#   ✔ Your memory usage beats 17.63 % of kotlin submissions (43.8 MB)
# Submitting: kotlin_solutions_1/1968.array-with-elements-not-equal-to-average-of-neighbors.kt
# - Downloading array-with-elements-not-equal-to-average-of-neighbors
#   ✔ Accepted
#   ✔ 293/293 cases passed (266 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1969.minimum-non-zero-product-of-the-array-elements.kt
# - Downloading minimum-non-zero-product-of-the-array-elements
#   ✔ Accepted
#   ✔ 60/60 cases passed (1 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1974.minimum-time-to-type-word-using-special-typewriter.kt
# - Downloading minimum-time-to-type-word-using-special-typewriter
#   ✔ Accepted
#   ✔ 135/135 cases passed (5 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 16.67 % of kotlin submissions (41.2 MB)
# Submitting: kotlin_solutions_1/1975.maximum-matrix-sum.kt
# - Downloading maximum-matrix-sum
#   ✔ Accepted
#   ✔ 98/98 cases passed (66 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1977.number-of-ways-to-separate-numbers.kt
# - Downloading number-of-ways-to-separate-numbers
#   ✔ Accepted
#   ✔ 257/257 cases passed (169 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (150.1 MB)
# Submitting: kotlin_solutions_1/1979.find-greatest-common-divisor-of-array.kt
# - Downloading find-greatest-common-divisor-of-array
#   ✔ Accepted
#   ✔ 215/215 cases passed (12 ms)
#   ✔ Your runtime beats 12.06 % of kotlin submissions
#   ✔ Your memory usage beats 7.35 % of kotlin submissions (46.6 MB)
# Submitting: kotlin_solutions_1/1981.minimize-the-difference-between-target-and-chosen-elements.kt
# - Downloading minimize-the-difference-between-target-and-chosen-elements
#   ✔ Accepted
#   ✔ 81/81 cases passed (593 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1984.minimum-difference-between-highest-and-lowest-of-k-scores.kt
# - Downloading minimum-difference-between-highest-and-lowest-of-k-scores
#   ✔ Accepted
#   ✔ 118/118 cases passed (32 ms)
#   ✔ Your runtime beats 11.11 % of kotlin submissions
#   ✔ Your memory usage beats 7.41 % of kotlin submissions (50.5 MB)
# Submitting: kotlin_solutions_1/1985.find-the-kth-largest-integer-in-the-array.kt
# - Downloading find-the-kth-largest-integer-in-the-array
#   ✔ Accepted
#   ✔ 219/219 cases passed (38 ms)
#   ✔ Your runtime beats 45 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (58.7 MB)
# Submitting: kotlin_solutions_1/1986.minimum-number-of-work-sessions-to-finish-the-tasks.kt
# - Downloading minimum-number-of-work-sessions-to-finish-the-tasks
#   ✔ Accepted
#   ✔ 96/96 cases passed (86 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (49.9 MB)
# Submitting: kotlin_solutions_1/1987.number-of-unique-good-subsequences.kt
# - Downloading number-of-unique-good-subsequences
#   ✔ Accepted
#   ✔ 69/69 cases passed (18 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (46.7 MB)
# Submitting: kotlin_solutions_1/1992.find-all-groups-of-farmland.kt
# - Downloading find-all-groups-of-farmland
#   ✔ Accepted
#   ✔ 220/220 cases passed (46 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1994.the-number-of-good-subsets.kt
# - Downloading the-number-of-good-subsets
#   ✔ Accepted
#   ✔ 92/92 cases passed (22 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1995.count-special-quadruplets.kt
# - Downloading count-special-quadruplets
#   ✔ Accepted
#   ✔ 211/211 cases passed (9 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 7.69 % of kotlin submissions (44.2 MB)
# Submitting: kotlin_solutions_1/1996.the-number-of-weak-characters-in-the-game.kt
# - Downloading the-number-of-weak-characters-in-the-game
#   ✔ Accepted
#   ✔ 44/44 cases passed (249 ms)
#   ✔ Your runtime beats 6.67 % of kotlin submissions
#   ✔ Your memory usage beats 60 % of kotlin submissions (118.2 MB)
# Submitting: kotlin_solutions_1/1997.first_day_where_you_have_been_in_all_the_rooms.kt
# - Downloading first-day-where-you-have-been-in-all-the-rooms
#   ✔ Accepted
#   ✔ 239/239 cases passed (11 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1998.gcd_sort_of_an_array.kt
# - Downloading gcd-sort-of-an-array
#   ✔ Accepted
#   ✔ 92/92 cases passed (340 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2000.reverse_prefix_of_word.kt
# - Downloading reverse-prefix-of-word
#   ✔ Accepted
#   ✔ 113/113 cases passed (7 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
#   ✔ Your memory usage beats 18.75 % of kotlin submissions (42.2 MB)
# Submitting: kotlin_solutions_1/2001.number_of_pairs_of_interchangeable_rectangles.kt
# - Downloading number-of-pairs-of-interchangeable-rectangles
#   ✔ Accepted
#   ✔ 46/46 cases passed (65 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/2002.maximum_product_of_the_length_of_two_palindromic_subsequences.kt
# - Downloading maximum-product-of-the-length-of-two-palindromic-subsequences
#   ✔ Accepted
#   ✔ 226/226 cases passed (156 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (52.5 MB)
# Submitting: kotlin_solutions_1/2006.count_number_of_pairs_with_absolute_difference_k.kt
# - Downloading count-number-of-pairs-with-absolute-difference-k
#   ✔ Accepted
#   ✔ 237/237 cases passed (32 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2007.find_original_array_from_doubled_array.kt
# - Downloading find-original-array-from-doubled-array
#   ✔ Accepted
#   ✔ 180/180 cases passed (98 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 11.11 % of kotlin submissions (78.8 MB)
# Submitting: kotlin_solutions_1/2008.maximum_earnings_from_taxi.kt
# - Downloading maximum-earnings-from-taxi
#   ✔ Accepted
#   ✔ 84/84 cases passed (103 ms)
#   ✔ Your runtime beats 60 % of kotlin submissions
#   ✔ Your memory usage beats 60 % of kotlin submissions (86.5 MB)
# Submitting: kotlin_solutions_1/2009.minimum_number_of_operations_to_make_array_continuous.kt
# - Downloading minimum-number-of-operations-to-make-array-continuous
#   ✔ Accepted
#   ✔ 62/62 cases passed (375 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (73.3 MB)
# Submitting: kotlin_solutions_1/2011.final-value-of-variable-after-performing-operations.kt
# - Downloading final-value-of-variable-after-performing-operations
#   ✔ Accepted
#   ✔ 259/259 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 80 % of kotlin submissions (43.5 MB)
# Submitting: kotlin_solutions_1/2012.sum-of-beauty-in-the-array.kt
# - Downloading sum-of-beauty-in-the-array
#   ✔ Accepted
#   ✔ 62/62 cases passed (17 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (63.9 MB)
# Submitting: kotlin_solutions_1/2013.detect-squares.kt
# - Downloading detect-squares
#   ✔ Accepted
#   ✔ 55/55 cases passed (137 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
#   ✔ Your memory usage beats 6.25 % of kotlin submissions (78.7 MB)
# Submitting: kotlin_solutions_1/2014.longest-subsequence-repeated-k-times.kt
# - Downloading longest-subsequence-repeated-k-times
#   ✔ Accepted
#   ✔ 314/314 cases passed (227 ms)
#   ✔ Your runtime beats 80 % of kotlin submissions
#   ✔ Your memory usage beats 80 % of kotlin submissions (51.4 MB)
# Submitting: kotlin_solutions_1/2016.maximum-difference-between-increasing-elements.kt
# - Downloading maximum-difference-between-increasing-elements
#   ✔ Accepted
#   ✔ 54/54 cases passed (24 ms)
#   ✔ Your runtime beats 8.33 % of kotlin submissions
#   ✔ Your memory usage beats 8.33 % of kotlin submissions (46 MB)
# Submitting: kotlin_solutions_1/2017.grid-game.kt
# - Downloading grid-game
#   ✔ Accepted
#   ✔ 109/109 cases passed (57 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (74.1 MB)
# Submitting: kotlin_solutions_1/2018.check-if-word-can-be-placed-in-crossword.kt
# - Downloading check-if-word-can-be-placed-in-crossword
#   ✔ Accepted
#   ✔ 154/154 cases passed (240 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2022.convert-1d-array-into-2d-array.kt
# - Downloading convert-1d-array-into-2d-array
#   ✔ Accepted
#   ✔ 107/107 cases passed (10 ms)
#   ✔ Your runtime beats 9.09 % of kotlin submissions
#   ✔ Your memory usage beats 9.09 % of kotlin submissions (63 MB)
# Submitting: kotlin_solutions_1/2023.number-of-pairs-of-strings-with-concatenation-equal-to-target.kt
# - Downloading number-of-pairs-of-strings-with-concatenation-equal-to-target
#   ✔ Accepted
#   ✔ 117/117 cases passed (49 ms)
#   ✔ Your runtime beats 8 % of kotlin submissions
#   ✔ Your memory usage beats 12 % of kotlin submissions (48.5 MB)
# Submitting: kotlin_solutions_1/2024.maximize-the-confusion-of-an-exam.kt
# - Downloading maximize-the-confusion-of-an-exam
#   ✔ Accepted
#   ✔ 93/93 cases passed (60 ms)
#   ✔ Your runtime beats 13.33 % of kotlin submissions
#   ✔ Your memory usage beats 6.67 % of kotlin submissions (50.8 MB)
# Submitting: kotlin_solutions_1/2027.minimum-moves-to-convert-string.kt
# - Downloading minimum-moves-to-convert-string
#   ✔ Accepted
#   ✔ 55/55 cases passed (16 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2028.find-missing-observations.kt
# - Downloading find-missing-observations
#   ✔ Accepted
#   ✔ 64/64 cases passed (17 ms)
#   ✔ Your runtime beats 80 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (65 MB)
# Submitting: kotlin_solutions_1/2029.stone-game-ix.kt
# - Downloading stone-game-ix
#   ✔ Accepted
#   ✔ 106/106 cases passed (5 ms)
#   ✔ Your runtime beats 26.83 % of kotlin submissions
#   ✔ Your memory usage beats 60.98 % of kotlin submissions (64.1 MB)
# Submitting: kotlin_solutions_1/2030.smallest-k-length-subsequence-with-occurrences-of-a-letter.kt
# - Downloading smallest-k-length-subsequence-with-occurrences-of-a-letter
#   ✔ Accepted
#   ✔ 152/152 cases passed (186 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2032.two-out-of-three.kt
# - Downloading two-out-of-three
#   ✔ Accepted
#   ✔ 288/288 cases passed (30 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 16.67 % of kotlin submissions (51.9 MB)
# Submitting: kotlin_solutions_1/2033.minimum-operations-to-make-a-uni-value-grid.kt
# - Downloading minimum-operations-to-make-a-uni-value-grid
#   ✔ Accepted
#   ✔ 43/43 cases passed (272 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (80.8 MB)
# Submitting: kotlin_solutions_1/2034.stock-price-fluctuation.kt
# - Downloading stock-price-fluctuation
#   ✔ Accepted
#   ✔ 18/18 cases passed (148 ms)
#   ✔ Your runtime beats 88.89 % of kotlin submissions
#   ✔ Your memory usage beats 11.11 % of kotlin submissions (128.4 MB)
# Submitting: kotlin_solutions_1/2037.minimum-number-of-moves-to-seat-everyone.kt
# - Downloading minimum-number-of-moves-to-seat-everyone
#   ✔ Accepted
#   ✔ 262/262 cases passed (28 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 85.71 % of kotlin submissions (46.4 MB)

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-08-18 13:22:49
