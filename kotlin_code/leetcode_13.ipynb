# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME')
    user_cookie = userdata.get('LEETCODE_TOKEN')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME'] = user_name
    os.environ['LEETCODE_TOKEN'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME" "$LEETCODE_TOKEN" | leetcode user -c

# %%
# %%bash
#
# # top 400-500 answers (5th batch)
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v kotlin_solutions_1/*.kt | sed -n '401,500p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 7
# done
# Out:
# Submitting: kotlin_solutions_1/1562.find-latest-group-of-size-m.kt
# - Downloading problems
# - Downloading find-latest-group-of-size-m
#   ✔ Accepted
#   ✔ 114/114 cases passed (40 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1563.stone-game-v.kt
# - Downloading stone-game-v
#   ✔ Accepted
#   ✔ 132/132 cases passed (353 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (50 MB)
# Submitting: kotlin_solutions_1/1567.maximum-length-of-subarray-with-positive-product.kt
# - Downloading maximum-length-of-subarray-with-positive-product
#   ✔ Accepted
#   ✔ 112/112 cases passed (41 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
#   ✔ Your memory usage beats 60 % of kotlin submissions (66.6 MB)
# Submitting: kotlin_solutions_1/1568.minimum-number-of-days-to-disconnect-island.kt
# - Downloading minimum-number-of-days-to-disconnect-island
#   ✔ Accepted
#   ✔ 104/104 cases passed (160 ms)
#   ✔ Your runtime beats 11.11 % of kotlin submissions
#   ✔ Your memory usage beats 11.11 % of kotlin submissions (58.6 MB)
# Submitting: kotlin_solutions_1/1569.number-of-ways-to-reorder-array-to-get-same-bst.kt
# - Downloading number-of-ways-to-reorder-array-to-get-same-bst
#   ✔ Accepted
#   ✔ 161/161 cases passed (118 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1572.matrix-diagonal-sum.kt
# - Downloading matrix-diagonal-sum
#   ✔ Accepted
#   ✔ 114/114 cases passed (13 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1573.number-of-ways-to-split-a-string.kt
# - Downloading number-of-ways-to-split-a-string
#   ✔ Accepted
#   ✔ 164/164 cases passed (39 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1574.shortest-subarray-to-be-removed-to-make-array-sorted.kt
# - Downloading shortest-subarray-to-be-removed-to-make-array-sorted
#   ✔ Accepted
#   ✔ 637/637 cases passed (31 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1575.count-all-possible-routes.kt
# - Downloading count-all-possible-routes
#   ✔ Accepted
#   ✔ 109/109 cases passed (273 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1576.replace-all-s-to-avoid-consecutive-repeating-characters.kt
# - Downloading replace-all-s-to-avoid-consecutive-repeating-characters
# [ERROR] session expired, please login again [code=-1]
# Submitting: kotlin_solutions_1/1577.number-of-ways-where-square-of-number-is-equal-to-product-of-two-numbers.kt
# - Downloading number-of-ways-where-square-of-number-is-equal-to-product-of-two-numbers
#   ✔ Accepted
#   ✔ 93/93 cases passed (46 ms)
#   ✔ Your runtime beats 66.67 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (50.7 MB)
# Submitting: kotlin_solutions_1/1578.minimum-time-to-make-rope-colorful.kt
# - Downloading minimum-time-to-make-rope-colorful
#   ✔ Accepted
#   ✔ 114/114 cases passed (55 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1579.remove-max-number-of-edges-to-keep-graph-fully-traversable.kt
# - Downloading remove-max-number-of-edges-to-keep-graph-fully-traversable
#   ✔ Accepted
#   ✔ 86/86 cases passed (103 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1582.special-positions-in-a-binary-matrix.kt
# - Downloading special-positions-in-a-binary-matrix
#   ✔ Accepted
#   ✔ 95/95 cases passed (28 ms)
#   ✔ Your runtime beats 11.11 % of kotlin submissions
#   ✔ Your memory usage beats 11.11 % of kotlin submissions (54.3 MB)
# Submitting: kotlin_solutions_1/1583.count-unhappy-friends.kt
# - Downloading count-unhappy-friends
#   ✔ Accepted
#   ✔ 99/99 cases passed (22 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 75 % of kotlin submissions (72.4 MB)
# Submitting: kotlin_solutions_1/1584.min-cost-to-connect-all-points.kt
# - Downloading min-cost-to-connect-all-points
#   ✔ Accepted
#   ✔ 72/72 cases passed (60 ms)
#   ✔ Your runtime beats 88.46 % of kotlin submissions
#   ✔ Your memory usage beats 88.46 % of kotlin submissions (49.1 MB)
# Submitting: kotlin_solutions_1/1585.check-if-string-is-transformable-with-substring-sort-operations.kt
# - Downloading check-if-string-is-transformable-with-substring-sort-operations
#   ✔ Accepted
#   ✔ 138/138 cases passed (65 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1588.sum-of-all-odd-length-subarrays.kt
# - Downloading sum-of-all-odd-length-subarrays
#   ✔ Accepted
#   ✔ 96/96 cases passed (13 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1589.maximum-sum-obtained-of-any-permutation.kt
# - Downloading maximum-sum-obtained-of-any-permutation
#   ✔ Accepted
#   ✔ 84/84 cases passed (168 ms)
#   ✔ Your runtime beats 12.5 % of kotlin submissions
#   ✔ Your memory usage beats 75 % of kotlin submissions (91.9 MB)
# Submitting: kotlin_solutions_1/1590.make-sum-divisible-by-p.kt
# - Downloading make-sum-divisible-by-p
#   ✔ Accepted
#   ✔ 145/145 cases passed (70 ms)
#   ✔ Your runtime beats 12.5 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (69.4 MB)
# Submitting: kotlin_solutions_1/1591.strange-printer-ii.kt
# - Downloading strange-printer-ii
#   ✔ Accepted
#   ✔ 153/153 cases passed (104 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1592.rearrange-spaces-between-words.kt
# - Downloading rearrange-spaces-between-words
#   ✔ Accepted
#   ✔ 90/90 cases passed (17 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
#   ✔ Your memory usage beats 8.33 % of kotlin submissions (43.7 MB)
# Submitting: kotlin_solutions_1/1593.split-a-string-into-the-max-number-of-unique-substrings.kt
# - Downloading split-a-string-into-the-max-number-of-unique-substrings
#   ✔ Accepted
#   ✔ 96/96 cases passed (194 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (57.1 MB)
# Submitting: kotlin_solutions_1/1595.minimum-cost-to-connect-two-groups-of-points.kt
# - Downloading minimum-cost-to-connect-two-groups-of-points
#   ✔ Accepted
#   ✔ 84/84 cases passed (72 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (49.8 MB)
# Submitting: kotlin_solutions_1/1598.crawler-log-folder.kt
# - Downloading crawler-log-folder
#   ✔ Accepted
#   ✔ 99/99 cases passed (1 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 22.22 % of kotlin submissions (42.6 MB)
# Submitting: kotlin_solutions_1/1599.maximum-profit-of-operating-a-centennial-wheel.kt
# - Downloading maximum-profit-of-operating-a-centennial-wheel
#   ✔ Accepted
#   ✔ 145/145 cases passed (58 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1600.throne-inheritance.kt
# - Downloading throne-inheritance
#   ✔ Accepted
#   ✔ 49/49 cases passed (355 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1601.maximum-number-of-achievable-transfer-requests.kt
# - Downloading maximum-number-of-achievable-transfer-requests
#   ✔ Accepted
#   ✔ 117/117 cases passed (176 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1603.design-parking-system.kt
# - Downloading design-parking-system
#   ✔ Accepted
#   ✔ 102/102 cases passed (25 ms)
#   ✔ Your runtime beats 39.13 % of kotlin submissions
#   ✔ Your memory usage beats 43.48 % of kotlin submissions (56.5 MB)
# Submitting: kotlin_solutions_1/1604.alert-using-same-key-card-three-or-more-times-in-a-one-hour-period.kt
# - Downloading alert-using-same-key-card-three-or-more-times-in-a-one-hour-period
#   ✔ Accepted
#   ✔ 78/78 cases passed (174 ms)
#   ✔ Your runtime beats 41.67 % of kotlin submissions
#   ✔ Your memory usage beats 8.33 % of kotlin submissions (92.9 MB)
# Submitting: kotlin_solutions_1/1605.find-valid-matrix-given-row-and-column-sums.kt
# - Downloading find-valid-matrix-given-row-and-column-sums
#   ✔ Accepted
#   ✔ 85/85 cases passed (13 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1606.find-servers-that-handled-most-number-of-requests.kt
# - Downloading find-servers-that-handled-most-number-of-requests
#   ✔ Accepted
#   ✔ 108/108 cases passed (271 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1608.special-array-with-x-elements-greater-than-or-equal-x.kt
# - Downloading special-array-with-x-elements-greater-than-or-equal-x
#   ✔ Accepted
#   ✔ 98/98 cases passed (7 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (41.5 MB)
# Submitting: kotlin_solutions_1/1609.even-odd-tree.kt
# - Downloading even-odd-tree
#   ✔ Accepted
#   ✔ 107/107 cases passed (65 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1610.maximum-number-of-visible-points.kt
# - Downloading maximum-number-of-visible-points
#   ✔ Accepted
#   ✔ 119/119 cases passed (338 ms)
#   ✔ Your runtime beats 42.86 % of kotlin submissions
#   ✔ Your memory usage beats 57.14 % of kotlin submissions (124.4 MB)
# Submitting: kotlin_solutions_1/1611.minimum-one-bit-operations-to-make-integers-zero.kt
# - Downloading minimum-one-bit-operations-to-make-integers-zero
#   ✔ Accepted
#   ✔ 308/308 cases passed (6 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (41.6 MB)
# Submitting: kotlin_solutions_1/1614.maximum-nesting-depth-of-the-parentheses.kt
# - Downloading maximum-nesting-depth-of-the-parentheses
#   ✔ Accepted
#   ✔ 168/168 cases passed (3 ms)
#   ✔ Your runtime beats 40 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (40.9 MB)
# Submitting: kotlin_solutions_1/1615.maximal-network-rank.kt
# - Downloading maximal-network-rank
#   ✔ Accepted
#   ✔ 83/83 cases passed (72 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1616.split-two-strings-to-make-palindrome.kt
# - Downloading split-two-strings-to-make-palindrome
#   ✔ Accepted
#   ✔ 112/112 cases passed (26 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1617.count-subtrees-with-max-distance-between-cities.kt
# - Downloading count-subtrees-with-max-distance-between-cities
#   ✔ Accepted
#   ✔ 31/31 cases passed (343 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1619.mean-of-array-after-removing-some-elements.kt
# - Downloading mean-of-array-after-removing-some-elements
#   ✔ Accepted
#   ✔ 50/50 cases passed (28 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1620.coordinate-with-maximum-network-quality.kt
# - Downloading coordinate-with-maximum-network-quality
#   ✔ Accepted
#   ✔ 101/101 cases passed (54 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1622.fancy-sequence.kt
# - Downloading fancy-sequence
#   ✔ Accepted
#   ✔ 106/106 cases passed (82 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 83.33 % of kotlin submissions (124.3 MB)
# Submitting: kotlin_solutions_1/1624.largest-substring-between-two-equal-characters.kt
# - Downloading largest-substring-between-two-equal-characters
#   ✔ Accepted
#   ✔ 59/59 cases passed (10 ms)
#   ✔ Your runtime beats 14.29 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (42.1 MB)
# Submitting: kotlin_solutions_1/1626.best-team-with-no-conflicts.kt
# - Downloading best-team-with-no-conflicts
#   ✔ Accepted
#   ✔ 150/150 cases passed (228 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (64.5 MB)
# Submitting: kotlin_solutions_1/1629.slowest-key.kt
# - Downloading slowest-key
#   ✔ Accepted
#   ✔ 109/109 cases passed (23 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1630.arithmetic-subarrays.kt
# - Downloading arithmetic-subarrays
#   ✔ Accepted
#   ✔ 104/104 cases passed (118 ms)
#   ✔ Your runtime beats 10 % of kotlin submissions
#   ✔ Your memory usage beats 10 % of kotlin submissions (51.4 MB)
# Submitting: kotlin_solutions_1/1636.sort-array-by-increasing-frequency.kt
# - Downloading sort-array-by-increasing-frequency
#   ✔ Accepted
#   ✔ 180/180 cases passed (33 ms)
#   ✔ Your runtime beats 18.18 % of kotlin submissions
#   ✔ Your memory usage beats 13.64 % of kotlin submissions (47.8 MB)
# Submitting: kotlin_solutions_1/1637.widest-vertical-area-between-two-points-containing-no-points.kt
# - Downloading widest-vertical-area-between-two-points-containing-no-points
#   ✔ Accepted
#   ✔ 56/56 cases passed (78 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (96.2 MB)
# Submitting: kotlin_solutions_1/1638.count-substrings-that-differ-by-one-character.kt
# - Downloading count-substrings-that-differ-by-one-character
#   ✔ Accepted
#   ✔ 63/63 cases passed (48 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1639.number-of-ways-to-form-a-target-string-given-a-dictionary.kt
# - Downloading number-of-ways-to-form-a-target-string-given-a-dictionary
#   ✔ Accepted
#   ✔ 90/90 cases passed (66 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1640.check-array-formation-through-concatenation.kt
# - Downloading check-array-formation-through-concatenation
#   ✔ Accepted
#   ✔ 85/85 cases passed (19 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1641.count-sorted-vowel-strings.kt
# - Downloading count-sorted-vowel-strings
#   ✔ Accepted
#   ✔ 41/41 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (40.5 MB)
# Submitting: kotlin_solutions_1/1642.furthest-building-you-can-reach.kt
# - Downloading furthest-building-you-can-reach
#   ✔ Accepted
#   ✔ 80/80 cases passed (36 ms)
#   ✔ Your runtime beats 12.5 % of kotlin submissions
#   ✔ Your memory usage beats 87.5 % of kotlin submissions (61 MB)
# Submitting: kotlin_solutions_1/1643.kth-smallest-instructions.kt
# - Downloading kth-smallest-instructions
#   ✔ Accepted
#   ✔ 462/462 cases passed (11 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (43.6 MB)
# Submitting: kotlin_solutions_1/1646.get-maximum-in-generated-array.kt
# - Downloading get-maximum-in-generated-array
#   ✔ Accepted
#   ✔ 101/101 cases passed (14 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1647.minimum-deletions-to-make-character-frequencies-unique.kt
# - Downloading minimum-deletions-to-make-character-frequencies-unique
#   ✔ Accepted
#   ✔ 103/103 cases passed (67 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (48.1 MB)
# Submitting: kotlin_solutions_1/1648.sell-diminishing-valued-colored-balls.kt
# - Downloading sell-diminishing-valued-colored-balls
#   ✔ Accepted
#   ✔ 95/95 cases passed (157 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1649.create-sorted-array-through-instructions.kt
# - Downloading create-sorted-array-through-instructions
#   ✔ Accepted
#   ✔ 65/65 cases passed (702 ms)
#   ✔ Your runtime beats 75 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/1652.defuse-the-bomb.kt
# - Downloading defuse-the-bomb
#   ✔ Accepted
#   ✔ 74/74 cases passed (9 ms)
#   ✔ Your runtime beats 45 % of kotlin submissions
#   ✔ Your memory usage beats 40 % of kotlin submissions (42.6 MB)
# Submitting: kotlin_solutions_1/1653.minimum-deletions-to-make-string-balanced.kt
# - Downloading minimum-deletions-to-make-string-balanced
#   ✔ Accepted
#   ✔ 158/158 cases passed (56 ms)
#   ✔ Your runtime beats 12.5 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (48.4 MB)
# Submitting: kotlin_solutions_1/1655.distribute-repeating-integers.kt
# - Downloading distribute-repeating-integers
#   ✔ Accepted
#   ✔ 109/109 cases passed (198 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1656.design-an-ordered-stream.kt
# - Downloading design-an-ordered-stream
#   ✔ Accepted
#   ✔ 101/101 cases passed (136 ms)
#   ✔ Your runtime beats 85.71 % of kotlin submissions
#   ✔ Your memory usage beats 57.14 % of kotlin submissions (68.4 MB)
# Submitting: kotlin_solutions_1/1657.determine-if-two-strings-are-close.kt
# - Downloading determine-if-two-strings-are-close
#   ✔ Accepted
#   ✔ 169/169 cases passed (157 ms)
#   ✔ Your runtime beats 6.49 % of kotlin submissions
#   ✔ Your memory usage beats 45.45 % of kotlin submissions (51.5 MB)
# Submitting: kotlin_solutions_1/1658.minimum-operations-to-reduce-x-to-zero.kt
# - Downloading minimum-operations-to-reduce-x-to-zero
#   ✔ Accepted
#   ✔ 97/97 cases passed (111 ms)
#   ✔ Your runtime beats 8.33 % of kotlin submissions
#   ✔ Your memory usage beats 8.33 % of kotlin submissions (70 MB)
# Submitting: kotlin_solutions_1/1659.maximize-grid-happiness.kt
# - Downloading maximize-grid-happiness
#   ✔ Accepted
#   ✔ 67/67 cases passed (140 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1662.check-if-two-string-arrays-are-equivalent.kt
# - Downloading check-if-two-string-arrays-are-equivalent
#   ✔ Accepted
#   ✔ 113/113 cases passed (15 ms)
#   ✔ Your runtime beats 22.22 % of kotlin submissions
#   ✔ Your memory usage beats 11.11 % of kotlin submissions (46.2 MB)
# Submitting: kotlin_solutions_1/1663.smallest-string-with-a-given-numeric-value.kt
# - Downloading smallest-string-with-a-given-numeric-value
#   ✔ Accepted
#   ✔ 94/94 cases passed (14 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (46.6 MB)
# Submitting: kotlin_solutions_1/1664.ways-to-make-a-fair-array.kt
# - Downloading ways-to-make-a-fair-array
#   ✔ Accepted
#   ✔ 105/105 cases passed (60 ms)
#   ✔ Your runtime beats 5.56 % of kotlin submissions
#   ✔ Your memory usage beats 27.78 % of kotlin submissions (61.8 MB)
# Submitting: kotlin_solutions_1/1668.maximum-repeating-substring.kt
# - Downloading maximum-repeating-substring
#   ✔ Accepted
#   ✔ 212/212 cases passed (16 ms)
#   ✔ Your runtime beats 6.67 % of kotlin submissions
#   ✔ Your memory usage beats 13.33 % of kotlin submissions (43.6 MB)
# Submitting: kotlin_solutions_1/1669.merge-in-between-linked-lists.kt
# - Downloading merge-in-between-linked-lists
#   ✔ Accepted
#   ✔ 61/61 cases passed (464 ms)
#   ✔ Your runtime beats 12.5 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/1670.design-front-middle-back-queue.kt
# - Downloading design-front-middle-back-queue
#   ✔ Accepted
#   ✔ 95/95 cases passed (24 ms)
#   ✔ Your runtime beats 88.24 % of kotlin submissions
#   ✔ Your memory usage beats 82.35 % of kotlin submissions (49 MB)
# Submitting: kotlin_solutions_1/1671.minimum-number-of-removals-to-make-mountain-array.kt
# - Downloading minimum-number-of-removals-to-make-mountain-array
#   ✔ Accepted
#   ✔ 91/91 cases passed (295 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1672.richest-customer-wealth.kt
# - Downloading richest-customer-wealth
#   ✔ Accepted
#   ✔ 34/34 cases passed (10 ms)
#   ✔ Your runtime beats 43.1 % of kotlin submissions
#   ✔ Your memory usage beats 53.45 % of kotlin submissions (46 MB)
# Submitting: kotlin_solutions_1/1673.find-the-most-competitive-subsequence.kt
# - Downloading find-the-most-competitive-subsequence
#   ✔ Accepted
#   ✔ 88/88 cases passed (86 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1674.minimum-moves-to-make-array-complementary.kt
# - Downloading minimum-moves-to-make-array-complementary
#   ✔ Accepted
#   ✔ 114/114 cases passed (40 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1678.goal-parser-interpretation.kt
# - Downloading goal-parser-interpretation
#   ✔ Accepted
#   ✔ 105/105 cases passed (106 ms)
#   ✔ Your runtime beats 8.33 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (41 MB)
# Submitting: kotlin_solutions_1/1679.max-number-of-k-sum-pairs.kt
# - Downloading max-number-of-k-sum-pairs
#   ✔ Accepted
#   ✔ 51/51 cases passed (587 ms)
#   ✔ Your runtime beats 6.5 % of kotlin submissions
#   ✔ Your memory usage beats 37.4 % of kotlin submissions (61.4 MB)
# Submitting: kotlin_solutions_1/1680.concatenation-of-consecutive-binary-numbers.kt
# - Downloading concatenation-of-consecutive-binary-numbers
#   ✔ Accepted
#   ✔ 403/403 cases passed (144 ms)
#   ✔ Your runtime beats 12.5 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (40.4 MB)
# Submitting: kotlin_solutions_1/1681.minimum-incompatibility.kt
# - Downloading minimum-incompatibility
#   ✔ Accepted
#   ✔ 59/59 cases passed (263 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/1684.count-the-number-of-consistent-strings.kt
# - Downloading count-the-number-of-consistent-strings
#   ✔ Accepted
#   ✔ 74/74 cases passed (212 ms)
#   ✔ Your runtime beats 37.93 % of kotlin submissions
#   ✔ Your memory usage beats 86.21 % of kotlin submissions (46.5 MB)
# Submitting: kotlin_solutions_1/1685.sum-of-absolute-differences-in-a-sorted-array.kt
# - Downloading sum-of-absolute-differences-in-a-sorted-array
#   ✔ Accepted
#   ✔ 59/59 cases passed (454 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (64.2 MB)
# Submitting: kotlin_solutions_1/1686.stone-game-vi.kt
# - Downloading stone-game-vi
#   ✔ Accepted
#   ✔ 95/95 cases passed (155 ms)
#   ✔ Your runtime beats 57.14 % of kotlin submissions
#   ✔ Your memory usage beats 85.71 % of kotlin submissions (74.9 MB)
# Submitting: kotlin_solutions_1/1687.delivering-boxes-from-storage-to-ports.kt
# - Downloading delivering-boxes-from-storage-to-ports
#   ✔ Accepted
#   ✔ 39/39 cases passed (26 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/1688.count-of-matches-in-tournament.kt
# - Downloading count-of-matches-in-tournament
#   ✔ Accepted
#   ✔ 200/200 cases passed (78 ms)
#   ✔ Your runtime beats 72.73 % of kotlin submissions
#   ✔ Your memory usage beats 9.09 % of kotlin submissions (39.7 MB)
# Submitting: kotlin_solutions_1/1689.partitioning-into-minimum-number-of-deci-binary-numbers.kt
# - Downloading partitioning-into-minimum-number-of-deci-binary-numbers
#   ✔ Accepted
#   ✔ 97/97 cases passed (15 ms)
#   ✔ Your runtime beats 75 % of kotlin submissions
#   ✔ Your memory usage beats 37.5 % of kotlin submissions (47.6 MB)
# Submitting: kotlin_solutions_1/1690.stone-game-vii.kt
# - Downloading stone-game-vii
#   ✔ Accepted
#   ✔ 68/68 cases passed (186 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (47.4 MB)
# Submitting: kotlin_solutions_1/1691.maximum-height-by-stacking-cuboids.kt
# - Downloading maximum-height-by-stacking-cuboids
#   ✔ Accepted
#   ✔ 83/83 cases passed (178 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1694.reformat-phone-number.kt
# - Downloading reformat-phone-number
#   ✔ Accepted
#   ✔ 108/108 cases passed (22 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1695.maximum-erasure-value.kt
# - Downloading maximum-erasure-value
#   ✔ Accepted
#   ✔ 62/62 cases passed (11 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (60.7 MB)
# Submitting: kotlin_solutions_1/1696.jump-game-vi.kt
# - Downloading jump-game-vi
#   ✔ Accepted
#   ✔ 73/73 cases passed (62 ms)
#   ✔ Your runtime beats 42.86 % of kotlin submissions
#   ✔ Your memory usage beats 28.57 % of kotlin submissions (67.4 MB)
# Submitting: kotlin_solutions_1/1700.number-of-students-unable-to-eat-lunch.kt
# - Downloading number-of-students-unable-to-eat-lunch
#   ✔ Accepted
#   ✔ 55/55 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 68.29 % of kotlin submissions (41.2 MB)
# Submitting: kotlin_solutions_1/1701.average-waiting-time.kt
# - Downloading average-waiting-time
#   ✔ Accepted
#   ✔ 38/38 cases passed (9 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1702.maximum-binary-string-after-change.kt
# - Downloading maximum-binary-string-after-change
#   ✔ Accepted
#   ✔ 76/76 cases passed (31 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1705.maximum-number-of-eaten-apples.kt
# - Downloading maximum-number-of-eaten-apples
#   ✔ Accepted
#   ✔ 73/73 cases passed (172 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (54.6 MB)
# Submitting: kotlin_solutions_1/1706.where-will-the-ball-fall.kt
# - Downloading where-will-the-ball-fall
#   ✔ Accepted
#   ✔ 64/64 cases passed (11 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
#   ✔ Your memory usage beats 20 % of kotlin submissions (55.5 MB)
# Submitting: kotlin_solutions_1/1707.maximum-xor-with-an-element-from-array.kt
# - Downloading maximum-xor-with-an-element-from-array
#   ✔ Accepted
#   ✔ 67/67 cases passed (347 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (225 MB)
# Submitting: kotlin_solutions_1/1710.maximum-units-on-a-truck.kt
# - Downloading maximum-units-on-a-truck
#   ✔ Accepted
#   ✔ 77/77 cases passed (33 ms)
#   ✔ Your runtime beats 10 % of kotlin submissions
#   ✔ Your memory usage beats 5 % of kotlin submissions (57.5 MB)
# Submitting: kotlin_solutions_1/1711.count-good-meals.kt
# - Downloading count-good-meals
#   ✔ Accepted
#   ✔ 72/72 cases passed (128 ms)
#   ✔ Your runtime beats 8.7 % of kotlin submissions
#   ✔ Your memory usage beats 26.09 % of kotlin submissions (61.3 MB)
# Submitting: kotlin_solutions_1/1712.ways-to-split-array-into-three-subarrays.kt
# - Downloading ways-to-split-array-into-three-subarrays
#   ✔ Accepted
#   ✔ 89/89 cases passed (178 ms)
#   ✔ Your runtime beats 9.09 % of kotlin submissions
#   ✔ Your memory usage beats 45.45 % of kotlin submissions (64 MB)

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-08-18 12:55:01
