# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME_2')
    user_cookie = userdata.get('LEETCODE_TOKEN_2')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME_2'] = user_name
    os.environ['LEETCODE_TOKEN_2'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME_2" "$LEETCODE_TOKEN_2" | leetcode user -c

# %%
# %%bash
#
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v kotlin_solutions_1/*.kt | sed -n '1301,$p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 7
# done
# Out:
# Submitting: kotlin_solutions_1/3142.check-if-grid-satisfies-conditions.kt
# - Downloading problems
# - Downloading check-if-grid-satisfies-conditions
#   ✔ Accepted
#   ✔ 882/882 cases passed (17 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3145.find-products-of-elements-of-big-array.kt
# - Downloading find-products-of-elements-of-big-array
#   ✔ Accepted
#   ✔ 758/758 cases passed (329 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (62.2 MB)
# Submitting: kotlin_solutions_1/3146.permutation-difference-between-two-strings.kt
# - Downloading permutation-difference-between-two-strings
#   ✔ Accepted
#   ✔ 823/823 cases passed (13 ms)
#   ✔ Your runtime beats 8.33 % of kotlin submissions
#   ✔ Your memory usage beats 16.67 % of kotlin submissions (44.6 MB)
# Submitting: kotlin_solutions_1/3147.taking-maximum-energy-from-the-mystic-dungeon.kt
# - Downloading taking-maximum-energy-from-the-mystic-dungeon
#   ✔ Accepted
#   ✔ 534/534 cases passed (558 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (70 MB)
# Submitting: kotlin_solutions_1/3148.maximum-difference-score-in-a-grid.kt
# - Downloading maximum-difference-score-in-a-grid
#   ✔ Accepted
#   ✔ 564/564 cases passed (64 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3151.special-array-i.kt
# - Downloading special-array-i
#   ✔ Accepted
#   ✔ 852/852 cases passed (7 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (45.3 MB)
# Submitting: kotlin_solutions_1/3152.special-array-ii.kt
# - Downloading special-array-ii
#   ✔ Accepted
#   ✔ 536/536 cases passed (9 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/3153.sum-of-digit-differences-of-all-pairs.kt
# - Downloading sum-of-digit-differences-of-all-pairs
#   ✔ Accepted
#   ✔ 643/643 cases passed (55 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3154.find-number-of-ways-to-reach-the-k-th-stair.kt
# - Downloading find-number-of-ways-to-reach-the-k-th-stair
#   ✔ Accepted
#   ✔ 600/600 cases passed (6 ms)
#   ✔ Your runtime beats 66.67 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (41.3 MB)
# Submitting: kotlin_solutions_1/3158.find-the-xor-of-numbers-which-appear-twice.kt
# - Downloading find-the-xor-of-numbers-which-appear-twice
#   ✔ Accepted
#   ✔ 833/833 cases passed (7 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3159.find-occurrences-of-an-element-in-an-array.kt
# - Downloading find-occurrences-of-an-element-in-an-array
#   ✔ Accepted
#   ✔ 527/527 cases passed (33 ms)
#   ✔ Your runtime beats 66.67 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (72.8 MB)
# Submitting: kotlin_solutions_1/3160.find-the-number-of-distinct-colors-among-the-balls.kt
# - Downloading find-the-number-of-distinct-colors-among-the-balls
#   ✔ Accepted
#   ✔ 551/551 cases passed (68 ms)
#   ✔ Your runtime beats 80 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/3162.find-the-number-of-good-pairs-i.kt
# - Downloading find-the-number-of-good-pairs-i
#   ✔ Accepted
#   ✔ 783/783 cases passed (2 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3163.string-compression-iii.kt
# - Downloading string-compression-iii
#   ✔ Accepted
#   ✔ 744/744 cases passed (202 ms)
#   ✔ Your runtime beats 12.5 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (59.9 MB)
# Submitting: kotlin_solutions_1/3164.find-the-number-of-good-pairs-ii.kt
# - Downloading find-the-number-of-good-pairs-ii
#   ✔ Accepted
#   ✔ 687/687 cases passed (313 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (95.1 MB)
# Submitting: kotlin_solutions_1/3168.minimum-number-of-chairs-in-a-waiting-room.kt
# - Downloading minimum-number-of-chairs-in-a-waiting-room
#   ✔ Accepted
#   ✔ 852/852 cases passed (4 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3169.count-days-without-meetings.kt
# - Downloading count-days-without-meetings
#   ✔ Accepted
#   ✔ 578/578 cases passed (136 ms)
#   ✔ Your runtime beats 60 % of kotlin submissions
#   ✔ Your memory usage beats 80 % of kotlin submissions (112.6 MB)
# Submitting: kotlin_solutions_1/3170.lexicographically-minimum-string-after-removing-stars.kt
# - Downloading lexicographically-minimum-string-after-removing-stars
#   ✔ Accepted
#   ✔ 602/602 cases passed (146 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3171.find-subarray-with-bitwise-or-closest-to-k.kt
# - Downloading find-subarray-with-bitwise-or-closest-to-k
#   ✔ Accepted
#   ✔ 814/814 cases passed (288 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3174.clear-digits.kt
# - Downloading clear-digits
#   ✔ Accepted
#   ✔ 688/688 cases passed (2 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 84.62 % of kotlin submissions (42.5 MB)
# Submitting: kotlin_solutions_1/3175.find-the-first-player-to-win-k-games-in-a-row.kt
# - Downloading find-the-first-player-to-win-k-games-in-a-row
#   ✔ Accepted
#   ✔ 684/684 cases passed (31 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3176.find-the-maximum-length-of-a-good-subsequence-i.kt
# - Downloading find-the-maximum-length-of-a-good-subsequence-i
#   ✔ Accepted
#   ✔ 543/543 cases passed (107 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (52.6 MB)
# Submitting: kotlin_solutions_1/3177.find-the-maximum-length-of-a-good-subsequence-ii.kt
# - Downloading find-the-maximum-length-of-a-good-subsequence-ii
#   ✔ Accepted
#   ✔ 551/551 cases passed (115 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (74.8 MB)
# Submitting: kotlin_solutions_1/3178.find-the-child-who-has-the-ball-after-k-seconds.kt
# - Downloading find-the-child-who-has-the-ball-after-k-seconds
#   ✔ Accepted
#   ✔ 803/803 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 28.57 % of kotlin submissions (41.1 MB)
# Submitting: kotlin_solutions_1/3179.find-the-n-th-value-after-k-seconds.kt
# - Downloading find-the-n-th-value-after-k-seconds
#   ✔ Accepted
#   ✔ 708/708 cases passed (219 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (43 MB)
# Submitting: kotlin_solutions_1/3180.maximum-total-reward-using-operations-i.kt
# - Downloading maximum-total-reward-using-operations-i
#   ✔ Accepted
#   ✔ 586/586 cases passed (234 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (49 MB)
# Submitting: kotlin_solutions_1/3181.maximum-total-reward-using-operations-ii.kt
# - Downloading maximum-total-reward-using-operations-ii
#   ✔ Accepted
#   ✔ 583/583 cases passed (1297 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (81.7 MB)
# Submitting: kotlin_solutions_1/3184.count-pairs-that-form-a-complete-day-i.kt
# - Downloading count-pairs-that-form-a-complete-day-i
#   ✔ Accepted
#   ✔ 667/667 cases passed (1 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 60 % of kotlin submissions (42.9 MB)
# Submitting: kotlin_solutions_1/3185.count-pairs-that-form-a-complete-day-ii.kt
# - Downloading count-pairs-that-form-a-complete-day-ii
#   ✔ Accepted
#   ✔ 714/714 cases passed (563 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (106.8 MB)
# Submitting: kotlin_solutions_1/3186.maximum-total-damage-with-spell-casting.kt
# - Downloading maximum-total-damage-with-spell-casting
#   ✔ Accepted
#   ✔ 555/555 cases passed (703 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (110.2 MB)
# Submitting: kotlin_solutions_1/3190.find-minimum-operations-to-make-all-elements-divisible-by-three.kt
# - Downloading find-minimum-operations-to-make-all-elements-divisible-by-three
#   ✔ Accepted
#   ✔ 660/660 cases passed (1 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (42.8 MB)
# Submitting: kotlin_solutions_1/3191.minimum-operations-to-make-binary-array-elements-equal-to-one-i.kt
# - Downloading minimum-operations-to-make-binary-array-elements-equal-to-one-i
#   ✔ Accepted
#   ✔ 689/689 cases passed (17 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (78.7 MB)
# Submitting: kotlin_solutions_1/3192.minimum-operations-to-make-binary-array-elements-equal-to-one-ii.kt
# - Downloading minimum-operations-to-make-binary-array-elements-equal-to-one-ii
#   ✔ Accepted
#   ✔ 691/691 cases passed (11 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3193.count-the-number-of-inversions.kt
# - Downloading count-the-number-of-inversions
#   ✔ Accepted
#   ✔ 719/719 cases passed (583 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (66.8 MB)
# Submitting: kotlin_solutions_1/3194.minimum-average-of-smallest-and-largest-elements.kt
# - Downloading minimum-average-of-smallest-and-largest-elements
#   ✔ Accepted
#   ✔ 720/720 cases passed (21 ms)
#   ✔ Your runtime beats 14.29 % of kotlin submissions
#   ✔ Your memory usage beats 71.43 % of kotlin submissions (48 MB)
# Submitting: kotlin_solutions_1/3195.find-the-minimum-area-to-cover-all-ones-i.kt
# - Downloading find-the-minimum-area-to-cover-all-ones-i
#   ✔ Accepted
#   ✔ 713/713 cases passed (1756 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3196.maximize-total-cost-of-alternating-subarrays.kt
# - Downloading maximize-total-cost-of-alternating-subarrays
#   ✔ Accepted
#   ✔ 692/692 cases passed (43 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (80.1 MB)
# Submitting: kotlin_solutions_1/3200.maximum-height-of-a-triangle.kt
# - Downloading maximum-height-of-a-triangle
#   ✔ Accepted
#   ✔ 857/857 cases passed (155 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3201.find-the-maximum-length-of-valid-subsequence-i.kt
# - Downloading find-the-maximum-length-of-valid-subsequence-i
#   ✔ Accepted
#   ✔ 951/951 cases passed (20 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (72.4 MB)
# Submitting: kotlin_solutions_1/3202.find-the-maximum-length-of-valid-subsequence-ii.kt
# - Downloading find-the-maximum-length-of-valid-subsequence-ii
#   ✔ Accepted
#   ✔ 734/734 cases passed (61 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3206.alternating-groups-i.kt
# - Downloading alternating-groups-i
#   ✔ Accepted
#   ✔ 795/795 cases passed (144 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 16.67 % of kotlin submissions (45.7 MB)
# Submitting: kotlin_solutions_1/3207.maximum-points-after-enemy-battles.kt
# - Downloading maximum-points-after-enemy-battles
#   ✔ Accepted
#   ✔ 579/579 cases passed (66 ms)
#   ✔ Your runtime beats 66.67 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (67.8 MB)
# Submitting: kotlin_solutions_1/3208.alternating-groups-ii.kt
# - Downloading alternating-groups-ii
#   ✔ Accepted
#   ✔ 625/625 cases passed (540 ms)
#   ✔ Your runtime beats 40 % of kotlin submissions
#   ✔ Your memory usage beats 60 % of kotlin submissions (82.8 MB)
# Submitting: kotlin_solutions_1/3209.number-of-subarrays-with-and-value-of-k.kt
# - Downloading number-of-subarrays-with-and-value-of-k
#   ✔ Accepted
#   ✔ 902/902 cases passed (743 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (64.6 MB)
# Submitting: kotlin_solutions_1/3210.find-the-encrypted-string.kt
# - Downloading find-the-encrypted-string
#   ✔ Accepted
#   ✔ 704/704 cases passed (7 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3211.generate-binary-strings-without-adjacent-zeros.kt
# - Downloading generate-binary-strings-without-adjacent-zeros
#   ✔ Accepted
#   ✔ 20/20 cases passed (209 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (48.3 MB)
# Submitting: kotlin_solutions_1/3217.delete-nodes-from-linked-list-present-in-array.kt
# - Downloading delete-nodes-from-linked-list-present-in-array
#   ✔ Accepted
#   ✔ 582/582 cases passed (80 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (91.4 MB)
# Submitting: kotlin_solutions_1/3218.minimum-cost-for-cutting-cake-i.kt
# - Downloading minimum-cost-for-cutting-cake-i
#   ✔ Accepted
#   ✔ 533/533 cases passed (22 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (46.6 MB)
# Submitting: kotlin_solutions_1/3219.minimum-cost-for-cutting-cake-ii.kt
# - Downloading minimum-cost-for-cutting-cake-ii
#   ✔ Accepted
#   ✔ 566/566 cases passed (410 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (105.1 MB)
# Submitting: kotlin_solutions_1/3222.find-the-winning-player-in-coin-game.kt
# - Downloading find-the-winning-player-in-coin-game
#   ✔ Accepted
#   ✔ 852/852 cases passed (1 ms)
#   ✔ Your runtime beats 60 % of kotlin submissions
#   ✔ Your memory usage beats 20 % of kotlin submissions (41.9 MB)
# Submitting: kotlin_solutions_1/3226.number-of-bit-changes-to-make-two-integers-equal.kt
# - Downloading number-of-bit-changes-to-make-two-integers-equal
#   ✔ Accepted
#   ✔ 682/682 cases passed (1 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (40.5 MB)
# Submitting: kotlin_solutions_1/3227.vowels-game-in-a-string.kt
# - Downloading vowels-game-in-a-string
#   ✔ Accepted
#   ✔ 697/697 cases passed (19 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (49.2 MB)
# Submitting: kotlin_solutions_1/3228.maximum-number-of-operations-to-move-ones-to-the-end.kt
# - Downloading maximum-number-of-operations-to-move-ones-to-the-end
#   ✔ Accepted
#   ✔ 694/694 cases passed (33 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3229.minimum-operations-to-make-array-equal-to-target.kt
# - Downloading minimum-operations-to-make-array-equal-to-target
#   ✔ Accepted
#   ✔ 554/554 cases passed (37 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (72.3 MB)
# Submitting: kotlin_solutions_1/3232.find-if-digit-game-can-be-won.kt
# - Downloading find-if-digit-game-can-be-won
#   ✔ Accepted
#   ✔ 897/897 cases passed (12 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3233.find-the-count-of-numbers-which-are-not-special.kt
# - Downloading find-the-count-of-numbers-which-are-not-special
#   ✔ Accepted
#   ✔ 855/855 cases passed (67 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (44.7 MB)
# Submitting: kotlin_solutions_1/3234.count-the-number-of-substrings-with-dominant-ones.kt
# - Downloading count-the-number-of-substrings-with-dominant-ones
#   ✔ Accepted
#   ✔ 882/882 cases passed (294 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/3238.find-the-number-of-winning-players.kt
# - Downloading find-the-number-of-winning-players
#   ✔ Accepted
#   ✔ 839/839 cases passed (16 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3423.maximum-difference-between-adjacent-elements-in-a-circular-array.kt
# - Downloading maximum-difference-between-adjacent-elements-in-a-circular-array
#   ✔ Accepted
#   ✔ 962/962 cases passed (15 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3424.minimum-cost-to-make-arrays-identical.kt
# - Downloading minimum-cost-to-make-arrays-identical
#   ✔ Accepted
#   ✔ 955/955 cases passed (484 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (78 MB)
# Submitting: kotlin_solutions_1/3426.manhattan-distances-of-all-arrangements-of-pieces.kt
# - Downloading manhattan-distances-of-all-arrangements-of-pieces
#   ✔ Accepted
#   ✔ 919/919 cases passed (65 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (46.3 MB)
# Submitting: kotlin_solutions_1/3427.sum-of-variable-length-subarrays.kt
# - Downloading sum-of-variable-length-subarrays
#   ✔ Accepted
#   ✔ 773/773 cases passed (19 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 16.67 % of kotlin submissions (47.3 MB)
# Submitting: kotlin_solutions_1/3429.paint-house-iv.kt
# - Downloading paint-house-iv
#   ✔ Accepted
#   ✔ 956/956 cases passed (91 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (142.3 MB)
# Submitting: kotlin_solutions_1/3432.count-partitions-with-even-sum-difference.kt
# - Downloading count-partitions-with-even-sum-difference
#   ✔ Accepted
#   ✔ 616/616 cases passed (19 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3433.count-mentions-per-user.kt
# - Downloading count-mentions-per-user
#   ✔ Accepted
#   ✔ 673/673 cases passed (65 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (52.7 MB)
# Submitting: kotlin_solutions_1/3434.maximum-frequency-after-subarray-operation.kt
# - Downloading maximum-frequency-after-subarray-operation
#   ✔ Accepted
#   ✔ 749/749 cases passed (224 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3438.find-valid-pair-of-adjacent-digits-in-string.kt
# - Downloading find-valid-pair-of-adjacent-digits-in-string
#   ✔ Accepted
#   ✔ 826/826 cases passed (24 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 16.67 % of kotlin submissions (44.8 MB)
# Submitting: kotlin_solutions_1/3439.reschedule-meetings-for-maximum-free-time-i.kt
# - Downloading reschedule-meetings-for-maximum-free-time-i
#   ✔ Accepted
#   ✔ 689/689 cases passed (25 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (84.3 MB)
# Submitting: kotlin_solutions_1/3440.reschedule-meetings-for-maximum-free-time-ii.kt
# - Downloading reschedule-meetings-for-maximum-free-time-ii
#   ✔ Accepted
#   ✔ 695/695 cases passed (101 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (87.5 MB)
# Submitting: kotlin_solutions_1/3442.maximum-difference-between-even-and-odd-frequency-i.kt
# - Downloading maximum-difference-between-even-and-odd-frequency-i
#   ✔ Accepted
#   ✔ 805/805 cases passed (22 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3468.find-the-number-of-copy-arrays.kt
# - Downloading find-the-number-of-copy-arrays
#   ✔ Accepted
#   ✔ 740/740 cases passed (10 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/3469.find-minimum-cost-to-remove-array-elements.kt
# - Downloading find-minimum-cost-to-remove-array-elements
#   ✔ Accepted
#   ✔ 807/807 cases passed (543 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3471.find-the-largest-almost-missing-integer.kt
# - Downloading find-the-largest-almost-missing-integer
#   ✔ Accepted
#   ✔ 900/900 cases passed (36 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/3474.lexicographically-smallest-generated-string.kt
# - Downloading lexicographically-smallest-generated-string
#   ✔ Accepted
#   ✔ 741/741 cases passed (131 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (53 MB)
# Submitting: kotlin_solutions_1/3477.fruits-into-baskets-ii.kt
# - Downloading fruits-into-baskets-ii
#   ✔ Accepted
#   ✔ 904/904 cases passed (30 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3479.fruits-into-baskets-iii.kt
# - Downloading fruits-into-baskets-iii
#   ✔ Accepted
#   ✔ 742/742 cases passed (66 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3487.maximum-unique-subarray-sum-after-deletion.kt
# - Downloading maximum-unique-subarray-sum-after-deletion
#   ✔ Accepted
#   ✔ 927/927 cases passed (22 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/3492.maximum-containers-on-a-ship.kt
# - Downloading maximum-containers-on-a-ship
#   ✔ Accepted
#   ✔ 686/686 cases passed (1 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3494.find-the-minimum-amount-of-time-to-brew-potions.kt
# - Downloading find-the-minimum-amount-of-time-to-brew-potions
#   ✔ Accepted
#   ✔ 744/744 cases passed (181 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (62.2 MB)
# Submitting: kotlin_solutions_1/3498.reverse-degree-of-a-string.kt
# - Downloading reverse-degree-of-a-string
#   ✔ Accepted
#   ✔ 933/933 cases passed (13 ms)
#   ✔ Your runtime beats 36.36 % of kotlin submissions
#   ✔ Your memory usage beats 45.45 % of kotlin submissions (44.4 MB)
# Submitting: kotlin_solutions_1/3500.minimum-cost-to-divide-array-into-subarrays.kt
# - Downloading minimum-cost-to-divide-array-into-subarrays
#   ✔ Accepted
#   ✔ 759/759 cases passed (48 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (50.7 MB)
# Submitting: kotlin_solutions_1/3502.minimum-cost-to-reach-every-position.kt
# - Downloading minimum-cost-to-reach-every-position
#   ✔ Accepted
#   ✔ 724/724 cases passed (9 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
#   ✔ Your memory usage beats 60 % of kotlin submissions (48 MB)
# Submitting: kotlin_solutions_1/3503.longest-palindrome-after-substring-concatenation-i.kt
# - Downloading longest-palindrome-after-substring-concatenation-i
#   ✔ Accepted
#   ✔ 584/584 cases passed (770 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (68.4 MB)
# Submitting: kotlin_solutions_1/3512.minimum-operations-to-make-array-sum-divisible-by-k.kt
# - Downloading minimum-operations-to-make-array-sum-divisible-by-k
#   ✔ Accepted
#   ✔ 855/855 cases passed (2 ms)
#   ✔ Your runtime beats 59.26 % of kotlin submissions
#   ✔ Your memory usage beats 62.96 % of kotlin submissions (49.6 MB)
# Submitting: kotlin_solutions_1/3513.number-of-unique-xor-triplets-i.kt
# - Downloading number-of-unique-xor-triplets-i
#   ✔ Accepted
#   ✔ 785/785 cases passed (1 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 43.62 % of kotlin submissions (79.3 MB)
# Submitting: kotlin_solutions_1/3516.find-closest-person.kt
# - Downloading find-closest-person
#   ✔ Accepted
#   ✔ 866/866 cases passed (1 ms)
#   ✔ Your runtime beats 70 % of kotlin submissions
#   ✔ Your memory usage beats 10 % of kotlin submissions (41.7 MB)
# Submitting: kotlin_solutions_1/3517.smallest-palindromic-rearrangement-i.kt
# - Downloading smallest-palindromic-rearrangement-i
#   ✔ Accepted
#   ✔ 930/930 cases passed (110 ms)
#   ✔ Your runtime beats 29.13 % of kotlin submissions
#   ✔ Your memory usage beats 38.94 % of kotlin submissions (52.1 MB)
# Submitting: kotlin_solutions_1/3519.count-numbers-with-non-decreasing-digits.kt
# - Downloading count-numbers-with-non-decreasing-digits
#   ✔ Accepted
#   ✔ 973/973 cases passed (92 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (55.5 MB)
# Submitting: kotlin_solutions_1/3522.calculate-score-after-performing-instructions.kt
# - Downloading calculate-score-after-performing-instructions
#   ✔ Accepted
#   ✔ 646/646 cases passed (51 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (102.2 MB)
# Submitting: kotlin_solutions_1/3523.make-array-non-decreasing.kt
# - Downloading make-array-non-decreasing
#   ✔ Accepted
#   ✔ 738/738 cases passed (26 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (92.6 MB)
# Submitting: kotlin_solutions_1/3524.find-x-value-of-array-i.kt
# - Downloading find-x-value-of-array-i
#   ✔ Accepted
#   ✔ 782/782 cases passed (59 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (70.5 MB)
# Submitting: kotlin_solutions_1/3527.find-the-most-common-response.kt
# - Downloading find-the-most-common-response
#   ✔ Accepted
#   ✔ 783/783 cases passed (154 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (240.7 MB)
# Submitting: kotlin_solutions_1/3532.path-existence-queries-in-a-graph-i.kt
# - Downloading path-existence-queries-in-a-graph-i
#   ✔ Accepted
#   ✔ 550/550 cases passed (14 ms)
#   ✔ Your runtime beats 45.05 % of kotlin submissions
#   ✔ Your memory usage beats 15.75 % of kotlin submissions (123.2 MB)
# Submitting: kotlin_solutions_1/3533.concatenated-divisibility.kt
# - Downloading concatenated-divisibility
#   ✔ Accepted
#   ✔ 622/622 cases passed (190 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (63.9 MB)
# Submitting: kotlin_solutions_1/3536.maximum-product-of-two-digits.kt
# - Downloading maximum-product-of-two-digits
#   ✔ Accepted
#   ✔ 1088/1088 cases passed (20 ms)
#   ✔ Your runtime beats 13.2 % of kotlin submissions
#   ✔ Your memory usage beats 11.73 % of kotlin submissions (45.9 MB)
# Submitting: kotlin_solutions_1/3538.merge-operations-for-minimum-travel-time.kt
# - Downloading merge-operations-for-minimum-travel-time
#   ✔ Accepted
#   ✔ 997/997 cases passed (76 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (50.7 MB)
# Submitting: kotlin_solutions_1/3541.find-most-frequent-vowel-and-consonant.kt
# - Downloading find-most-frequent-vowel-and-consonant
#   ✔ Accepted
#   ✔ 812/812 cases passed (24 ms)
#   ✔ Your runtime beats 31.58 % of kotlin submissions
#   ✔ Your memory usage beats 31.58 % of kotlin submissions (47.1 MB)
# Submitting: kotlin_solutions_1/3543.maximum-weighted-k-edge-path.kt
# - Downloading maximum-weighted-k-edge-path
#   ✔ Accepted
#   ✔ 959/959 cases passed (226 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (69.9 MB)
# Submitting: kotlin_solutions_1/3545.minimum-deletions-for-at-most-k-distinct-characters.kt
# - Downloading minimum-deletions-for-at-most-k-distinct-characters
#   ✔ Accepted
#   ✔ 936/936 cases passed (32 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (47.2 MB)
# Submitting: kotlin_solutions_1/3547.maximum-sum-of-edge-values-in-a-graph.kt
# - Downloading maximum-sum-of-edge-values-in-a-graph
#   ✔ Accepted
#   ✔ 1837/1837 cases passed (1 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (96.1 MB)
# Submitting: kotlin_solutions_1/3550.smallest-index-with-digit-sum-equal-to-index.kt
# - Downloading smallest-index-with-digit-sum-equal-to-index
#   ✔ Accepted
#   ✔ 982/982 cases passed (16 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3551.minimum-swaps-to-sort-by-digit-sum.kt
# - Downloading minimum-swaps-to-sort-by-digit-sum
#   ✔ Accepted
#   ✔ 807/807 cases passed (429 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (84 MB)
# Submitting: kotlin_solutions_1/3556.sum-of-largest-prime-substrings.kt
# - Downloading sum-of-largest-prime-substrings
#   ✔ Accepted
#   ✔ 957/957 cases passed (90 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3560.find-minimum-log-transportation-cost.kt
# - Downloading find-minimum-log-transportation-cost
#   ✔ Accepted
#   ✔ 740/740 cases passed (1 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/3566.partition-array-into-two-equal-product-subsets.kt
# - Downloading partition-array-into-two-equal-product-subsets
#   ✔ Accepted
#   ✔ 721/721 cases passed (24 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3567.minimum-absolute-difference-in-sliding-submatrix.kt
# - Downloading minimum-absolute-difference-in-sliding-submatrix
#   ✔ Accepted
#   ✔ 723/723 cases passed (71 ms)
# [WARN] Failed to get runtime percentile.

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-08-18 13:56:03
