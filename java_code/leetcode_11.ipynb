# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME_3')
    user_cookie = userdata.get('LEETCODE_TOKEN_3')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME_3'] = user_name
    os.environ['LEETCODE_TOKEN_3'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME_3" "$LEETCODE_TOKEN_3" | leetcode user -c

# %%
# %%bash
#
#
# # top 100 answers
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v java_solutions/*.java | sed -n '1001,1100p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 7
# done
# Out:
# Submitting: java_solutions/2916.subarrays-distinct-element-sum-of-squares-ii.java
#   ✔ Accepted
#   ✔ 542/542 cases passed (2090 ms)
#   ✔ Your runtime beats 12.5 % of java submissions
#   ✔ Your memory usage beats 12.5 % of java submissions (157.8 MB)
# Submitting: java_solutions/2920.maximum-points-after-collecting-coins-from-all-nodes.java
#   ✔ Accepted
#   ✔ 542/542 cases passed (1083 ms)
#   ✔ Your runtime beats 5.09 % of java submissions
#   ✔ Your memory usage beats 8.48 % of java submissions (283.6 MB)
# Submitting: java_solutions/2926.maximum-balanced-subsequence-sum.java
#   ✔ Accepted
#   ✔ 346/346 cases passed (399 ms)
#   ✔ Your runtime beats 5.33 % of java submissions
#   ✔ Your memory usage beats 36 % of java submissions (97.5 MB)
# Submitting: java_solutions/2931.maximum-spending-after-buying-items.java
#   ✔ Accepted
#   ✔ 779/779 cases passed (49 ms)
#   ✔ Your runtime beats 18.97 % of java submissions
#   ✔ Your memory usage beats 44.83 % of java submissions (78.9 MB)
# Submitting: java_solutions/2935.maximum-strong-pair-xor-ii.java
#   ✔ Accepted
#   ✔ 349/349 cases passed (706 ms)
#   ✔ Your runtime beats 5.71 % of java submissions
#   ✔ Your memory usage beats 5.71 % of java submissions (283.5 MB)
# Submitting: java_solutions/2940.find-building-where-alice-and-bob-can-meet.java
#   ✔ Accepted
#   ✔ 953/953 cases passed (1341 ms)
#   ✔ Your runtime beats 5.09 % of java submissions
#   ✔ Your memory usage beats 99.62 % of java submissions (145.2 MB)
# Submitting: java_solutions/2945.find-maximum-non-decreasing-array-length.java
#   ✔ Accepted
#   ✔ 553/553 cases passed (82 ms)
#   ✔ Your runtime beats 11.11 % of java submissions
#   ✔ Your memory usage beats 33.33 % of java submissions (121.8 MB)
# Submitting: java_solutions/2949.count-beautiful-substrings-ii.java
#   ✔ Accepted
#   ✔ 684/684 cases passed (323 ms)
#   ✔ Your runtime beats 31.91 % of java submissions
#   ✔ Your memory usage beats 12.77 % of java submissions (60.9 MB)
# Submitting: java_solutions/2953.count-complete-substrings.java
#   ✔ Accepted
#   ✔ 759/759 cases passed (396 ms)
#   ✔ Your runtime beats 21.11 % of java submissions
#   ✔ Your memory usage beats 7.78 % of java submissions (53.5 MB)
# Submitting: java_solutions/2954.count-the-number-of-infection-sequences.java
# - Downloading count-the-number-of-infection-sequences
#   ✔ Accepted
#   ✔ 1000/1000 cases passed (525 ms)
#   ✔ Your runtime beats 7.55 % of java submissions
#   ✔ Your memory usage beats 39.62 % of java submissions (63.6 MB)
# Submitting: java_solutions/2959.number-of-possible-sets-of-closing-branches.java
#   ✔ Accepted
#   ✔ 533/533 cases passed (226 ms)
#   ✔ Your runtime beats 5 % of java submissions
#   ✔ Your memory usage beats 8.75 % of java submissions (53.3 MB)
# Submitting: java_solutions/2963.count-the-number-of-good-partitions.java
#   ✔ Accepted
#   ✔ 813/813 cases passed (2285 ms)
#   ✔ Your runtime beats 5.13 % of java submissions
#   ✔ Your memory usage beats 5.13 % of java submissions (280.4 MB)
# Submitting: java_solutions/2968.apply-operations-to-maximize-frequency-score.java
#   ✔ Accepted
#   ✔ 774/774 cases passed (240 ms)
#   ✔ Your runtime beats 6.52 % of java submissions
#   ✔ Your memory usage beats 6.52 % of java submissions (105.9 MB)
# Submitting: java_solutions/2972.count-the-number-of-incremovable-subarrays-ii.java
#   ✔ Accepted
#   ✔ 840/840 cases passed (58 ms)
#   ✔ Your runtime beats 5.26 % of java submissions
#   ✔ Your memory usage beats 7.89 % of java submissions (92.2 MB)
# Submitting: java_solutions/2973.find-number-of-coins-to-place-in-tree-nodes.java
#   ✔ Accepted
#   ✔ 614/614 cases passed (460 ms)
#   ✔ Your runtime beats 17.24 % of java submissions
#   ✔ Your memory usage beats 6.9 % of java submissions (125.9 MB)
# Submitting: java_solutions/2977.minimum-cost-to-convert-string-ii.java
#   ✔ Accepted
#   ✔ 647/647 cases passed (854 ms)
#   ✔ Your runtime beats 7.45 % of java submissions
#   ✔ Your memory usage beats 5.32 % of java submissions (55.7 MB)
# Submitting: java_solutions/2983.palindrome-rearrangement-queries.java
#   ✔ Accepted
#   ✔ 1211/1211 cases passed (205 ms)
#   ✔ Your runtime beats 46.15 % of java submissions
#   ✔ Your memory usage beats 5.13 % of java submissions (186.9 MB)
# Submitting: java_solutions/2999.count-the-number-of-powerful-integers.java
#   ✔ Accepted
#   ✔ 933/933 cases passed (17 ms)
#   ✔ Your runtime beats 16.18 % of java submissions
#   ✔ Your memory usage beats 5.88 % of java submissions (51 MB)
# Submitting: java_solutions/3000.maximum-area-of-longest-diagonal-rectangle.java
#   ✔ Accepted
#   ✔ 817/817 cases passed (9 ms)
#   ✔ Your runtime beats 7.97 % of java submissions
#   ✔ Your memory usage beats 18.27 % of java submissions (46.7 MB)
# Submitting: java_solutions/3003.maximize-the-number-of-partitions-after-operations.java
# - Downloading maximize-the-number-of-partitions-after-operations
#   ✔ Accepted
#   ✔ 278/278 cases passed (1050 ms)
#   ✔ Your runtime beats 5.21 % of java submissions
#   ✔ Your memory usage beats 5.21 % of java submissions (195.4 MB)
# Submitting: java_solutions/3005.count-elements-with-maximum-frequency.java
#   ✔ Accepted
#   ✔ 623/623 cases passed (28 ms)
#   ✔ Your runtime beats 4.8 % of java submissions
#   ✔ Your memory usage beats 5.31 % of java submissions (52.2 MB)
# Submitting: java_solutions/3006.find-beautiful-indices-in-the-given-array-i.java
#   ✔ Accepted
#   ✔ 535/535 cases passed (56 ms)
#   ✔ Your runtime beats 44.1 % of java submissions
#   ✔ Your memory usage beats 6.99 % of java submissions (57.1 MB)
# Submitting: java_solutions/3008.find-beautiful-indices-in-the-given-array-ii.java
#   ✔ Accepted
#   ✔ 238/238 cases passed (1289 ms)
#   ✔ Your runtime beats 5.13 % of java submissions
#   ✔ Your memory usage beats 19.23 % of java submissions (145.2 MB)
# Submitting: java_solutions/3013.divide-an-array-into-subarrays-with-minimum-cost-ii.java
#   ✔ Accepted
#   ✔ 691/691 cases passed (559 ms)
#   ✔ Your runtime beats 5.2 % of java submissions
#   ✔ Your memory usage beats 22.22 % of java submissions (100.4 MB)
# Submitting: java_solutions/3017.count-the-number-of-houses-at-a-certain-distance-ii.java
#   ✔ Accepted
#   ✔ 549/549 cases passed (40 ms)
#   ✔ Your runtime beats 8.7 % of java submissions
#   ✔ Your memory usage beats 8.7 % of java submissions (114 MB)
# Submitting: java_solutions/3019.number-of-changing-keys.java
#   ✔ Accepted
#   ✔ 802/802 cases passed (7 ms)
#   ✔ Your runtime beats 1.96 % of java submissions
#   ✔ Your memory usage beats 6.32 % of java submissions (44 MB)
# Submitting: java_solutions/3022.minimize-or-of-remaining-elements-using-operations.java
#   ✔ Accepted
#   ✔ 822/822 cases passed (173 ms)
#   ✔ Your runtime beats 8 % of java submissions
#   ✔ Your memory usage beats 8 % of java submissions (76.4 MB)
# Submitting: java_solutions/3024.type-of-triangle.java
#   ✔ Accepted
#   ✔ 705/705 cases passed (13 ms)
#   ✔ Your runtime beats 0.1 % of java submissions
#   ✔ Your memory usage beats 11.92 % of java submissions (45 MB)
# Submitting: java_solutions/3027.find-the-number-of-ways-to-place-people-ii.java
#   ✔ Accepted
#   ✔ 551/551 cases passed (1309 ms)
#   ✔ Your runtime beats 6.12 % of java submissions
#   ✔ Your memory usage beats 6.12 % of java submissions (53 MB)
# Submitting: java_solutions/3031.minimum-time-to-revert-word-to-initial-state-ii.java
#   ✔ Accepted
#   ✔ 911/911 cases passed (1243 ms)
#   ✔ Your runtime beats 5.88 % of java submissions
#   ✔ Your memory usage beats 19.61 % of java submissions (84.7 MB)
# Submitting: java_solutions/3033.modify-the-matrix.java
#   ✔ Accepted
#   ✔ 514/514 cases passed (13 ms)
#   ✔ Your runtime beats 0.45 % of java submissions
#   ✔ Your memory usage beats 34.29 % of java submissions (47.4 MB)
# Submitting: java_solutions/3036.number-of-subarrays-that-match-a-pattern-ii.java
#   ✔ Accepted
#   ✔ 792/792 cases passed (435 ms)
#   ✔ Your runtime beats 8.7 % of java submissions
#   ✔ Your memory usage beats 7.25 % of java submissions (255.4 MB)
# Submitting: java_solutions/3041.maximize-consecutive-elements-in-an-array-after-modification.java
#   ✔ Accepted
#   ✔ 668/668 cases passed (161 ms)
#   ✔ Your runtime beats 9.26 % of java submissions
#   ✔ Your memory usage beats 9.26 % of java submissions (124.6 MB)
# Submitting: java_solutions/3045.count-prefix-and-suffix-pairs-ii.java
#   ✔ Accepted
#   ✔ 598/598 cases passed (328 ms)
#   ✔ Your runtime beats 8 % of java submissions
#   ✔ Your memory usage beats 6 % of java submissions (288.5 MB)
# Submitting: java_solutions/3049.earliest-second-to-mark-indices-ii.java
#   ✔ Accepted
#   ✔ 510/510 cases passed (69 ms)
#   ✔ Your runtime beats 5.09 % of java submissions
#   ✔ Your memory usage beats 5.08 % of java submissions (53.8 MB)
# Submitting: java_solutions/3068.find-the-maximum-sum-of-node-values.java
#   ✔ Accepted
#   ✔ 718/718 cases passed (8 ms)
#   ✔ Your runtime beats 52.94 % of java submissions
#   ✔ Your memory usage beats 33.82 % of java submissions (57.8 MB)
# Submitting: java_solutions/3072.distribute-elements-into-two-arrays-ii.java
#   ✔ Accepted
#   ✔ 785/785 cases passed (1479 ms)
#   ✔ Your runtime beats 5.6 % of java submissions
#   ✔ Your memory usage beats 47.2 % of java submissions (140.1 MB)
# Submitting: java_solutions/3077.maximum-strength-of-k-disjoint-subarrays.java
# - Downloading maximum-strength-of-k-disjoint-subarrays
#   ✔ Accepted
#   ✔ 802/802 cases passed (103 ms)
#   ✔ Your runtime beats 42.1 % of java submissions
#   ✔ Your memory usage beats 47.37 % of java submissions (106.1 MB)
# Submitting: java_solutions/3082.find-the-sum-of-the-power-of-all-subsequences.java
# - Downloading find-the-sum-of-the-power-of-all-subsequences
#   ✔ Accepted
#   ✔ 577/577 cases passed (158 ms)
#   ✔ Your runtime beats 6.67 % of java submissions
#   ✔ Your memory usage beats 30 % of java submissions (53.5 MB)
# Submitting: java_solutions/3086.minimum-moves-to-pick-k-ones.java
# - Downloading minimum-moves-to-pick-k-ones
#   ✔ Accepted
#   ✔ 825/825 cases passed (30 ms)
#   ✔ Your runtime beats 18.75 % of java submissions
#   ✔ Your memory usage beats 68.75 % of java submissions (83.5 MB)
# Submitting: java_solutions/3093.longest-common-suffix-queries.java
# - Downloading longest-common-suffix-queries
#   ✔ Accepted
#   ✔ 817/817 cases passed (453 ms)
#   ✔ Your runtime beats 8.47 % of java submissions
#   ✔ Your memory usage beats 5.08 % of java submissions (288.3 MB)
# Submitting: java_solutions/3098.find-the-sum-of-subsequence-powers.java
# - Downloading find-the-sum-of-subsequence-powers
#   ✔ Accepted
#   ✔ 549/549 cases passed (910 ms)
#   ✔ Your runtime beats 25.93 % of java submissions
#   ✔ Your memory usage beats 81.48 % of java submissions (53.7 MB)
# Submitting: java_solutions/3102.minimize-manhattan-distances.java
# - Downloading minimize-manhattan-distances
#   ✔ Accepted
#   ✔ 537/537 cases passed (116 ms)
#   ✔ Your runtime beats 15.38 % of java submissions
#   ✔ Your memory usage beats 23.08 % of java submissions (135 MB)
# Submitting: java_solutions/3108.minimum-cost-walk-in-weighted-graph.java
# - Downloading minimum-cost-walk-in-weighted-graph
#   ✔ Accepted
#   ✔ 549/549 cases passed (84 ms)
#   ✔ Your runtime beats 5.13 % of java submissions
#   ✔ Your memory usage beats 98.97 % of java submissions (207.9 MB)
# Submitting: java_solutions/3110.score-of-a-string.java
# - Downloading score-of-a-string
#   ✔ Accepted
#   ✔ 705/705 cases passed (6 ms)
#   ✔ Your runtime beats 1.15 % of java submissions
#   ✔ Your memory usage beats 9.53 % of java submissions (43.7 MB)
# Submitting: java_solutions/3113.find-the-number-of-subarrays-where-boundary-elements-are-maximum.java
# - Downloading find-the-number-of-subarrays-where-boundary-elements-are-maximum
#   ✔ Accepted
#   ✔ 890/890 cases passed (138 ms)
#   ✔ Your runtime beats 11.9 % of java submissions
#   ✔ Your memory usage beats 46.43 % of java submissions (104.5 MB)
# Submitting: java_solutions/3116.kth-smallest-amount-with-single-denomination-combination.java
# - Downloading kth-smallest-amount-with-single-denomination-combination
#   ✔ Accepted
#   ✔ 561/561 cases passed (101 ms)
#   ✔ Your runtime beats 52.08 % of java submissions
#   ✔ Your memory usage beats 6.25 % of java submissions (53.8 MB)
# Submitting: java_solutions/3117.minimum-sum-of-values-by-dividing-array.java
# - Downloading minimum-sum-of-values-by-dividing-array
#   ✔ Accepted
#   ✔ 512/512 cases passed (780 ms)
#   ✔ Your runtime beats 16.13 % of java submissions
#   ✔ Your memory usage beats 90.32 % of java submissions (54.3 MB)
# Submitting: java_solutions/3123.find-edges-in-shortest-paths.java
# - Downloading find-edges-in-shortest-paths
#   ✔ Accepted
#   ✔ 536/536 cases passed (727 ms)
#   ✔ Your runtime beats 9.65 % of java submissions
#   ✔ Your memory usage beats 18.42 % of java submissions (201.8 MB)
# Submitting: java_solutions/3130.find-all-possible-stable-binary-arrays-ii.java
# - Downloading find-all-possible-stable-binary-arrays-ii
#   ✔ Accepted
#   ✔ 582/582 cases passed (322 ms)
#   ✔ Your runtime beats 17.08 % of java submissions
#   ✔ Your memory usage beats 5.46 % of java submissions (280.3 MB)
# Submitting: java_solutions/3134.find-the-median-of-the-uniqueness-array.java
# - Downloading find-the-median-of-the-uniqueness-array
#   ✔ Accepted
#   ✔ 792/792 cases passed (1946 ms)
#   ✔ Your runtime beats 5.56 % of java submissions
#   ✔ Your memory usage beats 94.44 % of java submissions (96.9 MB)
# Submitting: java_solutions/3139.minimum-cost-to-equalize-array.java
# - Downloading minimum-cost-to-equalize-array
#   ✔ Accepted
#   ✔ 636/636 cases passed (17 ms)
#   ✔ Your runtime beats 63.64 % of java submissions
#   ✔ Your memory usage beats 13.64 % of java submissions (97.2 MB)
# Submitting: java_solutions/3145.find-products-of-elements-of-big-array.java
# - Downloading find-products-of-elements-of-big-array
#   ✔ Accepted
#   ✔ 758/758 cases passed (698 ms)
#   ✔ Your runtime beats 7.69 % of java submissions
#   ✔ Your memory usage beats 7.69 % of java submissions (53.7 MB)
# Submitting: java_solutions/3149.find-the-minimum-cost-array-permutation.java
# - Downloading find-the-minimum-cost-array-permutation
#   ✔ Accepted
#   ✔ 939/939 cases passed (1926 ms)
#   ✔ Your runtime beats 18.37 % of java submissions
#   ✔ Your memory usage beats 10.2 % of java submissions (98.6 MB)
# Submitting: java_solutions/3154.find-number-of-ways-to-reach-the-k-th-stair.java
# - Downloading find-number-of-ways-to-reach-the-k-th-stair
#   ✔ Accepted
#   ✔ 600/600 cases passed (12 ms)
#   ✔ Your runtime beats 67.5 % of java submissions
#   ✔ Your memory usage beats 75 % of java submissions (43.7 MB)
# Submitting: java_solutions/3161.block-placement-queries.java
# - Downloading block-placement-queries
#   ✔ Accepted
#   ✔ 745/745 cases passed (951 ms)
#   ✔ Your runtime beats 5.75 % of java submissions
#   ✔ Your memory usage beats 96.55 % of java submissions (261.4 MB)
# Submitting: java_solutions/3165.maximum-sum-of-subsequence-with-non-adjacent-elements.java
# - Downloading maximum-sum-of-subsequence-with-non-adjacent-elements
#   ✔ Accepted
#   ✔ 527/527 cases passed (1389 ms)
#   ✔ Your runtime beats 6.15 % of java submissions
#   ✔ Your memory usage beats 24.61 % of java submissions (220.6 MB)
# Submitting: java_solutions/3171.find-subarray-with-bitwise-or-closest-to-k.java
# - Downloading find-subarray-with-bitwise-or-closest-to-k
#   ✔ Accepted
#   ✔ 814/814 cases passed (160 ms)
#   ✔ Your runtime beats 53.57 % of java submissions
#   ✔ Your memory usage beats 10.71 % of java submissions (108.3 MB)
# Submitting: java_solutions/3177.find-the-maximum-length-of-a-good-subsequence-ii.java
# - Downloading find-the-maximum-length-of-a-good-subsequence-ii
#   ✔ Accepted
#   ✔ 551/551 cases passed (489 ms)
#   ✔ Your runtime beats 5.88 % of java submissions
#   ✔ Your memory usage beats 11.76 % of java submissions (133.3 MB)
# Submitting: java_solutions/3181.maximum-total-reward-using-operations-ii.java
# - Downloading maximum-total-reward-using-operations-ii
#   ✔ Accepted
#   ✔ 583/583 cases passed (66 ms)
#   ✔ Your runtime beats 50 % of java submissions
#   ✔ Your memory usage beats 14.29 % of java submissions (69.4 MB)
# Submitting: java_solutions/3187.peaks-in-array.java
# - Downloading peaks-in-array
#   ✔ Accepted
#   ✔ 681/681 cases passed (272 ms)
#   ✔ Your runtime beats 6.25 % of java submissions
#   ✔ Your memory usage beats 12.5 % of java submissions (232.6 MB)
# Submitting: java_solutions/3193.count-the-number-of-inversions.java
# - Downloading count-the-number-of-inversions
#   ✔ Accepted
#   ✔ 719/719 cases passed (796 ms)
#   ✔ Your runtime beats 5.11 % of java submissions
#   ✔ Your memory usage beats 51.82 % of java submissions (47.4 MB)
# Submitting: java_solutions/3197.find-the-minimum-area-to-cover-all-ones-ii.java
# - Downloading find-the-minimum-area-to-cover-all-ones-ii
#   ✔ Accepted
#   ✔ 663/663 cases passed (1225 ms)
#   ✔ Your runtime beats 5.13 % of java submissions
#   ✔ Your memory usage beats 5.13 % of java submissions (53.3 MB)
# Submitting: java_solutions/3203.find-minimum-diameter-after-merging-two-trees.java
# - Downloading find-minimum-diameter-after-merging-two-trees
#   ✔ Accepted
#   ✔ 723/723 cases passed (353 ms)
#   ✔ Your runtime beats 10.95 % of java submissions
#   ✔ Your memory usage beats 93.43 % of java submissions (212.4 MB)
# Submitting: java_solutions/3209.number-of-subarrays-with-and-value-of-k.java
# - Downloading number-of-subarrays-with-and-value-of-k
#   ✔ Accepted
#   ✔ 902/902 cases passed (321 ms)
#   ✔ Your runtime beats 18.18 % of java submissions
#   ✔ Your memory usage beats 20.45 % of java submissions (85.3 MB)
# Submitting: java_solutions/3213.construct-string-with-minimum-cost.java
# - Downloading construct-string-with-minimum-cost
#   ✔ Accepted
#   ✔ 808/808 cases passed (1709 ms)
#   ✔ Your runtime beats 18.18 % of java submissions
#   ✔ Your memory usage beats 100 % of java submissions (60.6 MB)
# Submitting: java_solutions/3217.delete-nodes-from-linked-list-present-in-array.java
# - Downloading delete-nodes-from-linked-list-present-in-array
#   ✔ Accepted
#   ✔ 582/582 cases passed (47 ms)
#   ✔ Your runtime beats 5.65 % of java submissions
#   ✔ Your memory usage beats 80.42 % of java submissions (137.2 MB)
# Submitting: java_solutions/3219.minimum-cost-for-cutting-cake-ii.java
# - Downloading minimum-cost-for-cutting-cake-ii
#   ✔ Accepted
#   ✔ 566/566 cases passed (115 ms)
#   ✔ Your runtime beats 10.96 % of java submissions
#   ✔ Your memory usage beats 10.96 % of java submissions (164.3 MB)
# Submitting: java_solutions/3225.maximum-score-from-grid-operations.java
# - Downloading maximum-score-from-grid-operations
#   ✔ Accepted
#   ✔ 794/794 cases passed (1794 ms)
#   ✔ Your runtime beats 5.56 % of java submissions
#   ✔ Your memory usage beats 11.11 % of java submissions (145.4 MB)
# Submitting: java_solutions/3229.minimum-operations-to-make-array-equal-to-target.java
# - Downloading minimum-operations-to-make-array-equal-to-target
#   ✔ Accepted
#   ✔ 554/554 cases passed (16 ms)
#   ✔ Your runtime beats 13.21 % of java submissions
#   ✔ Your memory usage beats 29.25 % of java submissions (137.8 MB)
# Submitting: java_solutions/3235.check-if-the-rectangle-corner-is-reachable.java
# - Downloading check-if-the-rectangle-corner-is-reachable
#   ✔ Accepted
#   ✔ 933/933 cases passed (254 ms)
#   ✔ Your runtime beats 7.69 % of java submissions
#   ✔ Your memory usage beats 7.69 % of java submissions (53.3 MB)
# Submitting: java_solutions/3241.time-taken-to-mark-all-nodes.java
# - Downloading time-taken-to-mark-all-nodes
#   ✔ Accepted
#   ✔ 804/804 cases passed (579 ms)
#   ✔ Your runtime beats 13.51 % of java submissions
#   ✔ Your memory usage beats 5.41 % of java submissions (385.1 MB)
# Submitting: java_solutions/3244.shortest-distance-after-road-addition-queries-ii.java
# - Downloading shortest-distance-after-road-addition-queries-ii
#   ✔ Accepted
#   ✔ 644/644 cases passed (61 ms)
#   ✔ Your runtime beats 41.86 % of java submissions
#   ✔ Your memory usage beats 44.19 % of java submissions (151.2 MB)
# Submitting: java_solutions/3245.alternating-groups-iii.java
# - Downloading alternating-groups-iii
#   ✔ Accepted
#   ✔ 731/731 cases passed (477 ms)
#   ✔ Your runtime beats 31.58 % of java submissions
#   ✔ Your memory usage beats 57.89 % of java submissions (206.2 MB)
# Submitting: java_solutions/3250.find-the-count-of-monotonic-pairs-i.java
# - Downloading find-the-count-of-monotonic-pairs-i
#   ✔ Accepted
#   ✔ 801/801 cases passed (952 ms)
#   ✔ Your runtime beats 5.77 % of java submissions
#   ✔ Your memory usage beats 40.38 % of java submissions (53.4 MB)
# Submitting: java_solutions/3251.find-the-count-of-monotonic-pairs-ii.java
# - Downloading find-the-count-of-monotonic-pairs-ii
#   ✔ Accepted
#   ✔ 801/801 cases passed (244 ms)
#   ✔ Your runtime beats 37.5 % of java submissions
#   ✔ Your memory usage beats 40.63 % of java submissions (52.7 MB)
# Submitting: java_solutions/3256.maximum-value-sum-by-placing-three-rooks-i.java
# - Downloading maximum-value-sum-by-placing-three-rooks-i
#   ✔ Accepted
#   ✔ 849/849 cases passed (58 ms)
#   ✔ Your runtime beats 78.26 % of java submissions
#   ✔ Your memory usage beats 13.04 % of java submissions (53.9 MB)
# Submitting: java_solutions/3257.maximum-value-sum-by-placing-three-rooks-ii.java
# - Downloading maximum-value-sum-by-placing-three-rooks-ii
#   ✔ Accepted
#   ✔ 857/857 cases passed (317 ms)
#   ✔ Your runtime beats 33.33 % of java submissions
#   ✔ Your memory usage beats 6.67 % of java submissions (165.8 MB)
# Submitting: java_solutions/3260.find-the-largest-palindrome-divisible-by-k.java
# - Downloading find-the-largest-palindrome-divisible-by-k
#   ✔ Accepted
#   ✔ 632/632 cases passed (24 ms)
#   ✔ Your runtime beats 64.29 % of java submissions
#   ✔ Your memory usage beats 10.71 % of java submissions (53.5 MB)
# Submitting: java_solutions/3261.count-substrings-that-satisfy-k-constraint-ii.java
# - Downloading count-substrings-that-satisfy-k-constraint-ii
#   ✔ Accepted
#   ✔ 627/627 cases passed (188 ms)
#   ✔ Your runtime beats 20 % of java submissions
#   ✔ Your memory usage beats 56 % of java submissions (157.9 MB)
# Submitting: java_solutions/3266.final-array-state-after-k-multiplication-operations-ii.java
# - Downloading final-array-state-after-k-multiplication-operations-ii
#   ✔ Accepted
#   ✔ 695/695 cases passed (153 ms)
#   ✔ Your runtime beats 5.36 % of java submissions
#   ✔ Your memory usage beats 5.36 % of java submissions (54.7 MB)
# Submitting: java_solutions/3267.count-almost-equal-pairs-ii.java
# - Downloading count-almost-equal-pairs-ii
#   ✔ Accepted
#   ✔ 631/631 cases passed (3716 ms)
#   ✔ Your runtime beats 75.56 % of java submissions
#   ✔ Your memory usage beats 6.67 % of java submissions (54.2 MB)
# Submitting: java_solutions/3272.find-the-count-of-good-integers.java
# - Downloading find-the-count-of-good-integers
#   ✔ Accepted
#   ✔ 90/90 cases passed (234 ms)
#   ✔ Your runtime beats 88 % of java submissions
#   ✔ Your memory usage beats 18 % of java submissions (54.4 MB)
# Submitting: java_solutions/3273.minimum-amount-of-damage-dealt-to-bob.java
# - Downloading minimum-amount-of-damage-dealt-to-bob
#   ✔ Accepted
#   ✔ 897/897 cases passed (131 ms)
#   ✔ Your runtime beats 34.78 % of java submissions
#   ✔ Your memory usage beats 91.3 % of java submissions (82.1 MB)
# Submitting: java_solutions/3276.select-cells-in-grid-with-maximum-score.java
# - Downloading select-cells-in-grid-with-maximum-score
#   ✔ Accepted
#   ✔ 546/546 cases passed (2472 ms)
#   ✔ Your runtime beats 5 % of java submissions
#   ✔ Your memory usage beats 25 % of java submissions (53.1 MB)
# Submitting: java_solutions/3277.maximum-xor-score-subarray-queries.java
# - Downloading maximum-xor-score-subarray-queries
#   ✔ Accepted
#   ✔ 635/635 cases passed (146 ms)
#   ✔ Your runtime beats 23.08 % of java submissions
#   ✔ Your memory usage beats 96.15 % of java submissions (228.1 MB)
# Submitting: java_solutions/3283.maximum-number-of-moves-to-kill-all-pawns.java
# - Downloading maximum-number-of-moves-to-kill-all-pawns
#   ✔ Accepted
#   ✔ 692/692 cases passed (2474 ms)
#   ✔ Your runtime beats 5.13 % of java submissions
#   ✔ Your memory usage beats 46.15 % of java submissions (57.6 MB)
# Submitting: java_solutions/3287.find-the-maximum-sequence-value-of-array.java
# - Downloading find-the-maximum-sequence-value-of-array
#   ✔ Accepted
#   ✔ 641/641 cases passed (1305 ms)
#   ✔ Your runtime beats 12.9 % of java submissions
#   ✔ Your memory usage beats 70.97 % of java submissions (53.4 MB)
# Submitting: java_solutions/3288.length-of-the-longest-increasing-path.java
# - Downloading length-of-the-longest-increasing-path
#   ✔ Accepted
#   ✔ 725/725 cases passed (86 ms)
#   ✔ Your runtime beats 11.76 % of java submissions
#   ✔ Your memory usage beats 52.94 % of java submissions (172.6 MB)
# Submitting: java_solutions/3292.minimum-number-of-valid-strings-to-form-target-ii.java
# - Downloading minimum-number-of-valid-strings-to-form-target-ii
#   ✔ Accepted
#   ✔ 807/807 cases passed (3259 ms)
#   ✔ Your runtime beats 6.06 % of java submissions
#   ✔ Your memory usage beats 75.76 % of java submissions (58.3 MB)
# Submitting: java_solutions/3298.count-substrings-that-can-be-rearranged-to-contain-a-string-ii.java
# - Downloading count-substrings-that-can-be-rearranged-to-contain-a-string-ii
#   ✔ Accepted
#   ✔ 760/760 cases passed (178 ms)
#   ✔ Your runtime beats 50.62 % of java submissions
#   ✔ Your memory usage beats 28.39 % of java submissions (66.3 MB)
# Submitting: java_solutions/3303.find-the-occurrence-of-first-almost-equal-substring.java
# - Downloading find-the-occurrence-of-first-almost-equal-substring
#   ✔ Accepted
#   ✔ 778/778 cases passed (1152 ms)
#   ✔ Your runtime beats 7.69 % of java submissions
#   ✔ Your memory usage beats 7.69 % of java submissions (93 MB)
# Submitting: java_solutions/3307.find-the-k-th-character-in-string-game-ii.java
# - Downloading find-the-k-th-character-in-string-game-ii
#   ✔ Accepted
#   ✔ 902/902 cases passed (9 ms)
#   ✔ Your runtime beats 2 % of java submissions
#   ✔ Your memory usage beats 6 % of java submissions (45.7 MB)
# Submitting: java_solutions/3311.construct-2d-grid-matching-graph-layout.java
# - Downloading construct-2d-grid-matching-graph-layout
#   ✔ Accepted
#   ✔ 785/785 cases passed (240 ms)
#   ✔ Your runtime beats 38.89 % of java submissions
#   ✔ Your memory usage beats 61.11 % of java submissions (230.2 MB)
# Submitting: java_solutions/3311.construct-2-d-grid-matching-graph-layout.java
# - Downloading construct-2d-grid-matching-graph-layout
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 4: error: missing return statement
#   ✘ Error: Line 4: error: missing return statement
#     }
#     ^
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: java_solutions/3312.sorted-gcd-pair-queries.java
# - Downloading sorted-gcd-pair-queries
#   ✔ Accepted
#   ✔ 721/721 cases passed (829 ms)
#   ✔ Your runtime beats 15.15 % of java submissions
#   ✔ Your memory usage beats 5.05 % of java submissions (114.1 MB)
# Submitting: java_solutions/3317.find-the-number-of-possible-ways-for-an-event.java
# - Downloading find-the-number-of-possible-ways-for-an-event
#   ✔ Accepted
#   ✔ 568/568 cases passed (139 ms)
#   ✔ Your runtime beats 9.09 % of java submissions
#   ✔ Your memory usage beats 77.27 % of java submissions (52.9 MB)
# Submitting: java_solutions/3320.count-the-number-of-winning-sequences.java
# - Downloading count-the-number-of-winning-sequences
#   ✔ Accepted
#   ✔ 691/691 cases passed (2431 ms)
#   ✔ Your runtime beats 6.25 % of java submissions
#   ✔ Your memory usage beats 68.75 % of java submissions (53.7 MB)
# Submitting: java_solutions/3321.find-x-sum-of-all-k-long-subarrays-ii.java
# - Downloading find-x-sum-of-all-k-long-subarrays-ii
#   ✔ Accepted
#   ✔ 784/784 cases passed (647 ms)
#   ✔ Your runtime beats 29.66 % of java submissions
#   ✔ Your memory usage beats 77.03 % of java submissions (182.3 MB)
# Submitting: java_solutions/3327.check-if-dfs-strings-are-palindromes.java
# - Downloading check-if-dfs-strings-are-palindromes
#   ✔ Accepted
#   ✔ 584/584 cases passed (627 ms)
#   ✔ Your runtime beats 5.88 % of java submissions
#   ✔ Your memory usage beats 5.88 % of java submissions (394.2 MB)

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-04-14 14:49:30
