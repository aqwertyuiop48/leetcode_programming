# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME_2')
    user_cookie = userdata.get('LEETCODE_TOKEN_2')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME_2'] = user_name
    os.environ['LEETCODE_TOKEN_2'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME_2" "$LEETCODE_TOKEN_2" | leetcode user -c

# %%
# %%bash
#
#
# # top 100 answers
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v java_solutions/*.java | sed -n '751,900p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 8
# done
# Out:
# Submitting: java_solutions/1362.closest-divisors.java
# - Downloading problems
# - Downloading closest-divisors
#   ✔ Accepted
#   ✔ 113/113 cases passed (10 ms)
#   ✔ Your runtime beats 17.86 % of java submissions
#   ✔ Your memory usage beats 58.57 % of java submissions (42.6 MB)
# Submitting: java_solutions/1363.largest-multiple-of-three.java
# - Downloading largest-multiple-of-three
#   ✔ Accepted
#   ✔ 45/45 cases passed (9 ms)
#   ✔ Your runtime beats 46.85 % of java submissions
#   ✔ Your memory usage beats 14.41 % of java submissions (47.7 MB)
# Submitting: java_solutions/1365.how-many-numbers-are-smaller-than-the-current-number.java
# - Downloading how-many-numbers-are-smaller-than-the-current-number
#   ✔ Accepted
#   ✔ 103/103 cases passed (25 ms)
#   ✔ Your runtime beats 7.27 % of java submissions
#   ✔ Your memory usage beats 11.38 % of java submissions (46.7 MB)
# Submitting: java_solutions/1366.rank-teams-by-votes.java
# - Downloading rank-teams-by-votes
#   ✔ Accepted
#   ✔ 37/37 cases passed (24 ms)
#   ✔ Your runtime beats 6.5 % of java submissions
#   ✔ Your memory usage beats 5.05 % of java submissions (52.6 MB)
# Submitting: java_solutions/1367.linked-list-in-binary-tree.java
# - Downloading linked-list-in-binary-tree
#   ✔ Accepted
#   ✔ 68/68 cases passed (5 ms)
#   ✔ Your runtime beats 7.11 % of java submissions
#   ✔ Your memory usage beats 12.85 % of java submissions (47.1 MB)
# Submitting: java_solutions/1368.minimum-cost-to-make-at-least-one-valid-path-in-a-grid.java
# - Downloading minimum-cost-to-make-at-least-one-valid-path-in-a-grid
#   ✔ Accepted
#   ✔ 69/69 cases passed (22 ms)
#   ✔ Your runtime beats 39.76 % of java submissions
#   ✔ Your memory usage beats 9.84 % of java submissions (47.6 MB)
# Submitting: java_solutions/1370.increasing-decreasing-string.java
# - Downloading increasing-decreasing-string
#   ✔ Accepted
#   ✔ 323/323 cases passed (4 ms)
#   ✔ Your runtime beats 20.37 % of java submissions
#   ✔ Your memory usage beats 93.76 % of java submissions (44.5 MB)
# Submitting: java_solutions/1371.find-the-longest-substring-containing-vowels-in-even-counts.java
# - Downloading find-the-longest-substring-containing-vowels-in-even-counts
#   ✔ Accepted
#   ✔ 55/55 cases passed (88 ms)
#   ✔ Your runtime beats 20.14 % of java submissions
#   ✔ Your memory usage beats 9.54 % of java submissions (52.3 MB)
# Submitting: java_solutions/1372.longest-zigzag-path-in-a-binary-tree.java
# - Downloading longest-zigzag-path-in-a-binary-tree
#   ✔ Accepted
#   ✔ 58/58 cases passed (38 ms)
#   ✔ Your runtime beats 5.24 % of java submissions
#   ✔ Your memory usage beats 5.05 % of java submissions (64.6 MB)
# Submitting: java_solutions/1373.maximum-sum-bst-in-binary-tree.java
# - Downloading maximum-sum-bst-in-binary-tree
#   ✔ Accepted
#   ✔ 60/60 cases passed (88 ms)
#   ✔ Your runtime beats 5.01 % of java submissions
#   ✔ Your memory usage beats 5.2 % of java submissions (72.5 MB)
# Submitting: java_solutions/1374.generate-a-string-with-characters-that-have-odd-counts.java
# - Downloading generate-a-string-with-characters-that-have-odd-counts
#   ✔ Accepted
#   ✔ 103/103 cases passed (2 ms)
#   ✔ Your runtime beats 40.08 % of java submissions
#   ✔ Your memory usage beats 65.73 % of java submissions (42.8 MB)
# Submitting: java_solutions/1375.number-of-times-binary-string-is-prefix-aligned.java
# - Downloading number-of-times-binary-string-is-prefix-aligned
#   ✔ Accepted
#   ✔ 63/63 cases passed (4 ms)
#   ✔ Your runtime beats 23.88 % of java submissions
#   ✔ Your memory usage beats 48.51 % of java submissions (52.8 MB)
# Submitting: java_solutions/1376.time-needed-to-inform-all-employees.java
# - Downloading time-needed-to-inform-all-employees
#   ✔ Accepted
#   ✔ 39/39 cases passed (126 ms)
#   ✔ Your runtime beats 11.52 % of java submissions
#   ✔ Your memory usage beats 27.41 % of java submissions (134.8 MB)
# Submitting: java_solutions/1377.frog-position-after-t-seconds.java
# - Downloading frog-position-after-t-seconds
#   ✔ Accepted
#   ✔ 207/207 cases passed (10 ms)
#   ✔ Your runtime beats 10.92 % of java submissions
#   ✔ Your memory usage beats 18.49 % of java submissions (47.9 MB)
# Submitting: java_solutions/1379.find-a-corresponding-node-of-a-binary-tree-in-a-clone-of-that-tree.java
# - Downloading find-a-corresponding-node-of-a-binary-tree-in-a-clone-of-that-tree
#   ✔ Accepted
#   ✔ 56/56 cases passed (3 ms)
#   ✔ Your runtime beats 15.14 % of java submissions
#   ✔ Your memory usage beats 69.05 % of java submissions (53.2 MB)
# Submitting: java_solutions/1380.lucky-numbers-in-a-matrix.java
# - Downloading lucky-numbers-in-a-matrix
#   ✔ Accepted
#   ✔ 106/106 cases passed (81 ms)
#   ✔ Your runtime beats 5.96 % of java submissions
#   ✔ Your memory usage beats 5.47 % of java submissions (53.1 MB)
# Submitting: java_solutions/1381.design-a-stack-with-increment-operation.java
# - Downloading design-a-stack-with-increment-operation
#   ✔ Accepted
#   ✔ 34/34 cases passed (5 ms)
#   ✔ Your runtime beats 97.96 % of java submissions
#   ✔ Your memory usage beats 28.76 % of java submissions (47.4 MB)
# Submitting: java_solutions/1382.balance-a-binary-search-tree.java
# - Downloading balance-a-binary-search-tree
#   ✔ Accepted
#   ✔ 17/17 cases passed (6 ms)
#   ✔ Your runtime beats 7.18 % of java submissions
#   ✔ Your memory usage beats 5.19 % of java submissions (49.3 MB)
# Submitting: java_solutions/1383.maximum-performance-of-a-team.java
# - Downloading maximum-performance-of-a-team
#   ✔ Accepted
#   ✔ 55/55 cases passed (43 ms)
#   ✔ Your runtime beats 25.27 % of java submissions
#   ✔ Your memory usage beats 88.67 % of java submissions (66.1 MB)
# Submitting: java_solutions/1385.find-the-distance-value-between-two-arrays.java
# - Downloading find-the-distance-value-between-two-arrays
#   ✔ Accepted
#   ✔ 103/103 cases passed (21 ms)
#   ✔ Your runtime beats 5.91 % of java submissions
#   ✔ Your memory usage beats 16.9 % of java submissions (46.7 MB)
# Submitting: java_solutions/1386.cinema-seat-allocation.java
# - Downloading cinema-seat-allocation
#   ✔ Accepted
#   ✔ 53/53 cases passed (47 ms)
#   ✔ Your runtime beats 5.1 % of java submissions
#   ✔ Your memory usage beats 29.13 % of java submissions (54 MB)
# Submitting: java_solutions/1387.sort-integers-by-the-power-value.java
# - Downloading sort-integers-by-the-power-value
#   ✔ Accepted
#   ✔ 333/333 cases passed (683 ms)
#   ✔ Your runtime beats 5.1 % of java submissions
#   ✔ Your memory usage beats 92.58 % of java submissions (45 MB)
# Submitting: java_solutions/1388.pizza-with-3n-slices.java
# - Downloading pizza-with-3n-slices
#   ✔ Accepted
#   ✔ 69/69 cases passed (17 ms)
#   ✔ Your runtime beats 8.77 % of java submissions
#   ✔ Your memory usage beats 75.44 % of java submissions (46.2 MB)
# Submitting: java_solutions/1389.create-target-array-in-the-given-order.java
# - Downloading create-target-array-in-the-given-order
#   ✔ Accepted
#   ✔ 45/45 cases passed (7 ms)
#   ✔ Your runtime beats 0.59 % of java submissions
#   ✔ Your memory usage beats 9.31 % of java submissions (50.4 MB)
# Submitting: java_solutions/1390.four-divisors.java
# - Downloading four-divisors
#   ✔ Accepted
#   ✔ 19/19 cases passed (142 ms)
#   ✔ Your runtime beats 13.95 % of java submissions
#   ✔ Your memory usage beats 5.39 % of java submissions (47.6 MB)
# Submitting: java_solutions/1392.longest-happy-prefix.java
# - Downloading longest-happy-prefix
#   ✔ Accepted
#   ✔ 83/83 cases passed (19 ms)
#   ✔ Your runtime beats 6.26 % of java submissions
#   ✔ Your memory usage beats 98.34 % of java submissions (47 MB)
# Submitting: java_solutions/1394.find-lucky-integer-in-an-array.java
# - Downloading find-lucky-integer-in-an-array
#   ✔ Accepted
#   ✔ 102/102 cases passed (18 ms)
#   ✔ Your runtime beats 5.13 % of java submissions
#   ✔ Your memory usage beats 5.21 % of java submissions (52.2 MB)
# Submitting: java_solutions/1395.count-number-of-teams.java
# - Downloading count-number-of-teams
#   ✔ Accepted
#   ✔ 72/72 cases passed (294 ms)
#   ✔ Your runtime beats 38.16 % of java submissions
#   ✔ Your memory usage beats 6.54 % of java submissions (47.2 MB)
# Submitting: java_solutions/1396.design-underground-system.java
# - Downloading design-underground-system
#   ✔ Accepted
#   ✔ 57/57 cases passed (122 ms)
#   ✔ Your runtime beats 6.8 % of java submissions
#   ✔ Your memory usage beats 26.3 % of java submissions (58.3 MB)
# Submitting: java_solutions/1397.find-all-good-strings.java
# - Downloading find-all-good-strings
#   ✔ Accepted
#   ✔ 55/55 cases passed (78 ms)
#   ✔ Your runtime beats 5.69 % of java submissions
#   ✔ Your memory usage beats 64.23 % of java submissions (45.8 MB)
# Submitting: java_solutions/1399.count-largest-group.java
# - Downloading count-largest-group
#   ✔ Accepted
#   ✔ 75/75 cases passed (91 ms)
#   ✔ Your runtime beats 5.9 % of java submissions
#   ✔ Your memory usage beats 5.73 % of java submissions (52.6 MB)
# Submitting: java_solutions/1400.construct-k-palindrome-strings.java
# - Downloading construct-k-palindrome-strings
#   ✔ Accepted
#   ✔ 112/112 cases passed (81 ms)
#   ✔ Your runtime beats 5.12 % of java submissions
#   ✔ Your memory usage beats 11.45 % of java submissions (53.4 MB)
# Submitting: java_solutions/1401.circle-and-rectangle-overlapping.java
# - Downloading circle-and-rectangle-overlapping
#   ✔ Accepted
#   ✔ 90/90 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 31.58 % of java submissions (42.3 MB)
# Submitting: java_solutions/1402.reducing-dishes.java
# - Downloading reducing-dishes
#   ✔ Accepted
#   ✔ 60/60 cases passed (9 ms)
#   ✔ Your runtime beats 40.42 % of java submissions
#   ✔ Your memory usage beats 55.41 % of java submissions (44 MB)
# Submitting: java_solutions/1403.minimum-subsequence-in-non-increasing-order.java
# - Downloading minimum-subsequence-in-non-increasing-order
#   ✔ Accepted
#   ✔ 103/103 cases passed (40 ms)
#   ✔ Your runtime beats 7.12 % of java submissions
#   ✔ Your memory usage beats 88.77 % of java submissions (46.7 MB)
# Submitting: java_solutions/1404.number-of-steps-to-reduce-a-number-in-binary-representation-to-one.java
# - Downloading number-of-steps-to-reduce-a-number-in-binary-representation-to-one
#   ✔ Accepted
#   ✔ 75/75 cases passed (5 ms)
#   ✔ Your runtime beats 10.76 % of java submissions
#   ✔ Your memory usage beats 28.2 % of java submissions (42.9 MB)
# Submitting: java_solutions/1405.longest-happy-string.java
# - Downloading longest-happy-string
#   ✔ Accepted
#   ✔ 36/36 cases passed (11 ms)
#   ✔ Your runtime beats 5.24 % of java submissions
#   ✔ Your memory usage beats 5.12 % of java submissions (43.6 MB)
# Submitting: java_solutions/1406.stone-game-iii.java
# - Downloading stone-game-iii
#   ✔ Accepted
#   ✔ 185/185 cases passed (20 ms)
#   ✔ Your runtime beats 57.02 % of java submissions
#   ✔ Your memory usage beats 93.57 % of java submissions (82.1 MB)
# Submitting: java_solutions/1408.string-matching-in-an-array.java
# - Downloading string-matching-in-an-array
#   ✔ Accepted
#   ✔ 69/69 cases passed (8 ms)
#   ✔ Your runtime beats 5.59 % of java submissions
#   ✔ Your memory usage beats 6.12 % of java submissions (44.1 MB)
# Submitting: java_solutions/1409.queries-on-a-permutation-with-key.java
# - Downloading queries-on-a-permutation-with-key
#   ✔ Accepted
#   ✔ 53/53 cases passed (76 ms)
#   ✔ Your runtime beats 6.25 % of java submissions
#   ✔ Your memory usage beats 6.25 % of java submissions (47.8 MB)
# Submitting: java_solutions/1410.html-entity-parser.java
# - Downloading html-entity-parser
#   ✔ Accepted
#   ✔ 171/171 cases passed (21 ms)
#   ✔ Your runtime beats 79.2 % of java submissions
#   ✔ Your memory usage beats 81.6 % of java submissions (47.5 MB)
# Submitting: java_solutions/1411.number-of-ways-to-paint-n-3-grid.java
# - Downloading number-of-ways-to-paint-n-3-grid
#   ✔ Accepted
#   ✔ 50/50 cases passed (9 ms)
#   ✔ Your runtime beats 19.56 % of java submissions
#   ✔ Your memory usage beats 22.67 % of java submissions (42.5 MB)
# Submitting: java_solutions/1413.minimum-value-to-get-positive-step-by-step-sum.java
# - Downloading minimum-value-to-get-positive-step-by-step-sum
#   ✔ Accepted
#   ✔ 57/57 cases passed (5 ms)
#   ✔ Your runtime beats 1.21 % of java submissions
#   ✔ Your memory usage beats 11.26 % of java submissions (43.2 MB)
# Submitting: java_solutions/1414.find-the-minimum-number-of-fibonacci-numbers-whose-sum-is-k.java
# - Downloading find-the-minimum-number-of-fibonacci-numbers-whose-sum-is-k
#   ✔ Accepted
#   ✔ 504/504 cases passed (19 ms)
#   ✔ Your runtime beats 5.13 % of java submissions
#   ✔ Your memory usage beats 6.15 % of java submissions (43.6 MB)
# Submitting: java_solutions/1415.the-k-th-lexicographical-string-of-all-happy-strings-of-length-n.java
# - Downloading the-k-th-lexicographical-string-of-all-happy-strings-of-length-n
#   ✔ Accepted
#   ✔ 345/345 cases passed (80 ms)
#   ✔ Your runtime beats 5.48 % of java submissions
#   ✔ Your memory usage beats 12.58 % of java submissions (47.1 MB)
# Submitting: java_solutions/1416.restore-the-array.java
# - Downloading restore-the-array
#   ✔ Accepted
#   ✔ 86/86 cases passed (32 ms)
#   ✔ Your runtime beats 62.12 % of java submissions
#   ✔ Your memory usage beats 83.84 % of java submissions (46.5 MB)
# Submitting: java_solutions/1417.reformat-the-string.java
# - Downloading reformat-the-string
#   ✔ Accepted
#   ✔ 302/302 cases passed (18 ms)
#   ✔ Your runtime beats 5.15 % of java submissions
#   ✔ Your memory usage beats 32.42 % of java submissions (46.6 MB)
# Submitting: java_solutions/1418.display-table-of-food-orders-in-a-restaurant.java
# - Downloading display-table-of-food-orders-in-a-restaurant
#   ✔ Accepted
#   ✔ 53/53 cases passed (357 ms)
#   ✔ Your runtime beats 6.36 % of java submissions
#   ✔ Your memory usage beats 5.78 % of java submissions (71.3 MB)
# Submitting: java_solutions/1419.minimum-number-of-frogs-croaking.java
# - Downloading minimum-number-of-frogs-croaking
#   ✔ Accepted
#   ✔ 61/61 cases passed (25 ms)
#   ✔ Your runtime beats 17.89 % of java submissions
#   ✔ Your memory usage beats 18.95 % of java submissions (46.7 MB)
# Submitting: java_solutions/1420.build-array-where-you-can-find-the-maximum-exactly-k-comparisons.java
# - Downloading build-array-where-you-can-find-the-maximum-exactly-k-comparisons
#   ✔ Accepted
#   ✔ 31/31 cases passed (126 ms)
#   ✔ Your runtime beats 49.26 % of java submissions
#   ✔ Your memory usage beats 75.86 % of java submissions (45.8 MB)
# Submitting: java_solutions/1422.maximum-score-after-splitting-a-string.java
# - Downloading maximum-score-after-splitting-a-string
#   ✔ Accepted
#   ✔ 104/104 cases passed (35 ms)
#   ✔ Your runtime beats 7.57 % of java submissions
#   ✔ Your memory usage beats 5.66 % of java submissions (47.1 MB)
# Submitting: java_solutions/1423.maximum-points-you-can-obtain-from-cards.java
# - Downloading maximum-points-you-can-obtain-from-cards
#   ✔ Accepted
#   ✔ 41/41 cases passed (13 ms)
#   ✔ Your runtime beats 3.61 % of java submissions
#   ✔ Your memory usage beats 53.24 % of java submissions (61.8 MB)
# Submitting: java_solutions/1424.diagonal-traverse-ii.java
# - Downloading diagonal-traverse-ii
#   ✔ Accepted
#   ✔ 56/56 cases passed (63 ms)
#   ✔ Your runtime beats 19.93 % of java submissions
#   ✔ Your memory usage beats 71.76 % of java submissions (112.7 MB)
# Submitting: java_solutions/1425.constrained-subsequence-sum.java
# - Downloading constrained-subsequence-sum
#   ✔ Accepted
#   ✔ 40/40 cases passed (96 ms)
#   ✔ Your runtime beats 5.2 % of java submissions
#   ✔ Your memory usage beats 6.73 % of java submissions (141.8 MB)
# Submitting: java_solutions/1431.kids-with-the-greatest-number-of-candies.java
# - Downloading kids-with-the-greatest-number-of-candies
#   ✔ Accepted
#   ✔ 103/103 cases passed (5 ms)
#   ✔ Your runtime beats 2.73 % of java submissions
#   ✔ Your memory usage beats 10.68 % of java submissions (44.5 MB)
# Submitting: java_solutions/1432.max-difference-you-can-get-from-changing-an-integer.java
# - Downloading max-difference-you-can-get-from-changing-an-integer
#   ✔ Accepted
#   ✔ 211/211 cases passed (7 ms)
#   ✔ Your runtime beats 7.19 % of java submissions
#   ✔ Your memory usage beats 11.11 % of java submissions (42.8 MB)
# Submitting: java_solutions/1433.check-if-a-string-can-break-another-string.java
# - Downloading check-if-a-string-can-break-another-string
#   ✔ Accepted
#   ✔ 103/103 cases passed (45 ms)
#   ✔ Your runtime beats 5.39 % of java submissions
#   ✔ Your memory usage beats 7.05 % of java submissions (50.1 MB)
# Submitting: java_solutions/1434.number-of-ways-to-wear-different-hats-to-each-other.java
# - Downloading number-of-ways-to-wear-different-hats-to-each-other
#   ✔ Accepted
#   ✔ 65/65 cases passed (25 ms)
#   ✔ Your runtime beats 20 % of java submissions
#   ✔ Your memory usage beats 96.32 % of java submissions (43.4 MB)
# Submitting: java_solutions/1436.destination-city.java
# - Downloading destination-city
#   ✔ Accepted
#   ✔ 104/104 cases passed (10 ms)
#   ✔ Your runtime beats 5.83 % of java submissions
#   ✔ Your memory usage beats 6.59 % of java submissions (46.2 MB)
# Submitting: java_solutions/1437.check-if-all-1s-are-at-least-length-k-places-away.java
# - Downloading check-if-all-1s-are-at-least-length-k-places-away
#   ✔ Accepted
#   ✔ 71/71 cases passed (20 ms)
#   ✔ Your runtime beats 3.37 % of java submissions
#   ✔ Your memory usage beats 5.06 % of java submissions (69.5 MB)
# Submitting: java_solutions/1438.longest-continuous-subarray-with-absolute-diff-less-than-or-equal-to-limit.java
# - Downloading longest-continuous-subarray-with-absolute-diff-less-than-or-equal-to-limit
#   ✔ Accepted
#   ✔ 63/63 cases passed (142 ms)
#   ✔ Your runtime beats 6.75 % of java submissions
#   ✔ Your memory usage beats 68.89 % of java submissions (90.8 MB)
# Submitting: java_solutions/1439.find-the-kth-smallest-sum-of-a-matrix-with-sorted-rows.java
# - Downloading find-the-kth-smallest-sum-of-a-matrix-with-sorted-rows
#   ✔ Accepted
#   ✔ 72/72 cases passed (222 ms)
#   ✔ Your runtime beats 12.08 % of java submissions
#   ✔ Your memory usage beats 43.48 % of java submissions (47 MB)
# Submitting: java_solutions/1441.build-an-array-with-stack-operations.java
# - Downloading build-an-array-with-stack-operations
#   ✔ Accepted
#   ✔ 49/49 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 68.97 % of java submissions (44.2 MB)
# Submitting: java_solutions/1442.count-triplets-that-can-form-two-arrays-of-equal-xor.java
# - Downloading count-triplets-that-can-form-two-arrays-of-equal-xor
#   ✔ Accepted
#   ✔ 47/47 cases passed (5 ms)
#   ✔ Your runtime beats 25 % of java submissions
#   ✔ Your memory usage beats 88.55 % of java submissions (42.8 MB)
# Submitting: java_solutions/1443.minimum-time-to-collect-all-apples-in-a-tree.java
# - Downloading minimum-time-to-collect-all-apples-in-a-tree
#   ✔ Accepted
#   ✔ 63/63 cases passed (70 ms)
#   ✔ Your runtime beats 8.19 % of java submissions
#   ✔ Your memory usage beats 21.98 % of java submissions (93.2 MB)
# Submitting: java_solutions/1444.number-of-ways-of-cutting-a-pizza.java
# - Downloading number-of-ways-of-cutting-a-pizza
#   ✔ Accepted
#   ✔ 54/54 cases passed (24 ms)
#   ✔ Your runtime beats 5.88 % of java submissions
#   ✔ Your memory usage beats 7.65 % of java submissions (43.6 MB)
# Submitting: java_solutions/1446.consecutive-characters.java
# - Downloading consecutive-characters
#   ✔ Accepted
#   ✔ 333/333 cases passed (23 ms)
#   ✔ Your runtime beats 2.51 % of java submissions
#   ✔ Your memory usage beats 12.07 % of java submissions (47.4 MB)
# Submitting: java_solutions/1447.simplified-fractions.java
# - Downloading simplified-fractions
#   ✔ Accepted
#   ✔ 100/100 cases passed (54 ms)
#   ✔ Your runtime beats 5.09 % of java submissions
#   ✔ Your memory usage beats 5.56 % of java submissions (53.5 MB)
# Submitting: java_solutions/1448.count-good-nodes-in-binary-tree.java
# - Downloading count-good-nodes-in-binary-tree
#   ✔ Accepted
#   ✔ 63/63 cases passed (6 ms)
#   ✔ Your runtime beats 6.97 % of java submissions
#   ✔ Your memory usage beats 13.4 % of java submissions (58.3 MB)
# Submitting: java_solutions/1449.form-largest-integer-with-digits-that-add-up-to-target.java
# - Downloading form-largest-integer-with-digits-that-add-up-to-target
#   ✔ Accepted
#   ✔ 96/96 cases passed (9 ms)
#   ✔ Your runtime beats 51 % of java submissions
#   ✔ Your memory usage beats 93 % of java submissions (43.2 MB)
# Submitting: java_solutions/1450.number-of-students-doing-homework-at-a-given-time.java
# - Downloading number-of-students-doing-homework-at-a-given-time
#   ✔ Accepted
#   ✔ 111/111 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 98.67 % of java submissions (42.9 MB)
# Submitting: java_solutions/1451.rearrange-words-in-a-sentence.java
# - Downloading rearrange-words-in-a-sentence
#   ✔ Accepted
#   ✔ 74/74 cases passed (36 ms)
#   ✔ Your runtime beats 23 % of java submissions
#   ✔ Your memory usage beats 57.33 % of java submissions (47.4 MB)
# Submitting: java_solutions/1452.people-whose-list-of-favorite-companies-is-not-a-subset-of-another-list.java
# - Downloading people-whose-list-of-favorite-companies-is-not-a-subset-of-another-list
#   ✔ Accepted
#   ✔ 55/55 cases passed (671 ms)
#   ✔ Your runtime beats 6.45 % of java submissions
#   ✔ Your memory usage beats 20.43 % of java submissions (70.3 MB)
# Submitting: java_solutions/1453.maximum-number-of-darts-inside-of-a-circular-dartboard.java
# - Downloading maximum-number-of-darts-inside-of-a-circular-dartboard
#   ✔ Accepted
#   ✔ 65/65 cases passed (40 ms)
#   ✔ Your runtime beats 28.07 % of java submissions
#   ✔ Your memory usage beats 85.96 % of java submissions (43 MB)
# Submitting: java_solutions/1455.check-if-a-word-occurs-as-a-prefix-of-any-word-in-a-sentence.java
# - Downloading check-if-a-word-occurs-as-a-prefix-of-any-word-in-a-sentence
#   ✔ Accepted
#   ✔ 45/45 cases passed (5 ms)
#   ✔ Your runtime beats 0.11 % of java submissions
#   ✔ Your memory usage beats 8.97 % of java submissions (43.1 MB)
# Submitting: java_solutions/1456.maximum-number-of-vowels-in-a-substring-of-given-length.java
# - Downloading maximum-number-of-vowels-in-a-substring-of-given-length
#   ✔ Accepted
#   ✔ 107/107 cases passed (22 ms)
#   ✔ Your runtime beats 25.84 % of java submissions
#   ✔ Your memory usage beats 64.46 % of java submissions (46.4 MB)
# Submitting: java_solutions/1457.pseudo-palindromic-paths-in-a-binary-tree.java
# - Downloading pseudo-palindromic-paths-in-a-binary-tree
#   ✔ Accepted
#   ✔ 56/56 cases passed (18 ms)
#   ✔ Your runtime beats 27.97 % of java submissions
#   ✔ Your memory usage beats 9.04 % of java submissions (113.7 MB)
# Submitting: java_solutions/1458.max-dot-product-of-two-subsequences.java
# - Downloading max-dot-product-of-two-subsequences
#   ✔ Accepted
#   ✔ 70/70 cases passed (15 ms)
#   ✔ Your runtime beats 10.9 % of java submissions
#   ✔ Your memory usage beats 59.34 % of java submissions (46.4 MB)
# Submitting: java_solutions/1460.make-two-arrays-equal-by-reversing-subarrays.java
# - Downloading make-two-arrays-equal-by-reversing-subarrays
#   ✔ Accepted
#   ✔ 109/109 cases passed (10 ms)
#   ✔ Your runtime beats 11.74 % of java submissions
#   ✔ Your memory usage beats 13.26 % of java submissions (47 MB)
# Submitting: java_solutions/1461.check-if-a-string-contains-all-binary-codes-of-size-k.java
# - Downloading check-if-a-string-contains-all-binary-codes-of-size-k
#   ✔ Accepted
#   ✔ 201/201 cases passed (191 ms)
#   ✔ Your runtime beats 20.64 % of java submissions
#   ✔ Your memory usage beats 65.91 % of java submissions (96 MB)
# Submitting: java_solutions/1462.course-schedule-iv.java
# - Downloading course-schedule-iv
#   ✔ Accepted
#   ✔ 70/70 cases passed (37 ms)
#   ✔ Your runtime beats 59.1 % of java submissions
#   ✔ Your memory usage beats 48.24 % of java submissions (50.9 MB)
# Submitting: java_solutions/1463.cherry-pickup-ii.java
# - Downloading cherry-pickup-ii
#   ✔ Accepted
#   ✔ 59/59 cases passed (48 ms)
#   ✔ Your runtime beats 5.36 % of java submissions
#   ✔ Your memory usage beats 14.54 % of java submissions (48.1 MB)
# Submitting: java_solutions/1464.maximum-product-of-two-elements-in-an-array.java
# - Downloading maximum-product-of-two-elements-in-an-array
#   ✔ Accepted
#   ✔ 104/104 cases passed (11 ms)
#   ✔ Your runtime beats 13.13 % of java submissions
#   ✔ Your memory usage beats 5.79 % of java submissions (45.4 MB)
# Submitting: java_solutions/1465.maximum-area-of-a-piece-of-cake-after-horizontal-and-vertical-cuts.java
# - Downloading maximum-area-of-a-piece-of-cake-after-horizontal-and-vertical-cuts
#   ✔ Accepted
#   ✔ 56/56 cases passed (27 ms)
#   ✔ Your runtime beats 7.84 % of java submissions
#   ✔ Your memory usage beats 11.11 % of java submissions (67.7 MB)
# Submitting: java_solutions/1466.reorder-routes-to-make-all-paths-lead-to-the-city-zero.java
# - Downloading reorder-routes-to-make-all-paths-lead-to-the-city-zero
#   ✔ Accepted
#   ✔ 77/77 cases passed (81 ms)
#   ✔ Your runtime beats 28.87 % of java submissions
#   ✔ Your memory usage beats 46.07 % of java submissions (121 MB)
# Submitting: java_solutions/1467.probability-of-a-two-boxes-having-the-same-number-of-distinct-balls.java
# - Downloading probability-of-a-two-boxes-having-the-same-number-of-distinct-balls
#   ✔ Accepted
#   ✔ 21/21 cases passed (17 ms)
#   ✔ Your runtime beats 83.75 % of java submissions
#   ✔ Your memory usage beats 20 % of java submissions (46.6 MB)
# Submitting: java_solutions/1470.shuffle-the-array.java
# - Downloading shuffle-the-array
#   ✔ Accepted
#   ✔ 53/53 cases passed (5 ms)
#   ✔ Your runtime beats 0.88 % of java submissions
#   ✔ Your memory usage beats 41.69 % of java submissions (46.6 MB)
# Submitting: java_solutions/1471.the-k-strongest-values-in-an-array.java
# - Downloading the-k-strongest-values-in-an-array
#   ✔ Accepted
#   ✔ 71/71 cases passed (103 ms)
#   ✔ Your runtime beats 8.38 % of java submissions
#   ✔ Your memory usage beats 5.23 % of java submissions (95.4 MB)
# Submitting: java_solutions/1472.design-browser-history.java
# - Downloading design-browser-history
#   ✔ Accepted
#   ✔ 73/73 cases passed (53 ms)
#   ✔ Your runtime beats 23.98 % of java submissions
#   ✔ Your memory usage beats 5.3 % of java submissions (54.7 MB)
# Submitting: java_solutions/1473.paint-house-iii.java
# - Downloading paint-house-iii
#   ✔ Accepted
#   ✔ 62/62 cases passed (33 ms)
#   ✔ Your runtime beats 18.26 % of java submissions
#   ✔ Your memory usage beats 35.24 % of java submissions (46.8 MB)
# Submitting: java_solutions/1475.final-prices-with-a-special-discount-in-a-shop.java
# - Downloading final-prices-with-a-special-discount-in-a-shop
#   ✔ Accepted
#   ✔ 103/103 cases passed (15 ms)
#   ✔ Your runtime beats 5.46 % of java submissions
#   ✔ Your memory usage beats 12.05 % of java submissions (46.9 MB)
# Submitting: java_solutions/1476.subrectangle-queries.java
# - Downloading subrectangle-queries
#   ✔ Accepted
#   ✔ 52/52 cases passed (55 ms)
#   ✔ Your runtime beats 2.3 % of java submissions
#   ✔ Your memory usage beats 9.2 % of java submissions (56 MB)
# Submitting: java_solutions/1477.find-two-non-overlapping-sub-arrays-each-with-target-sum.java
# - Downloading find-two-non-overlapping-sub-arrays-each-with-target-sum
#   ✔ Accepted
#   ✔ 61/61 cases passed (119 ms)
#   ✔ Your runtime beats 5.63 % of java submissions
#   ✔ Your memory usage beats 11.97 % of java submissions (147.5 MB)
# Submitting: java_solutions/1478.allocate-mailboxes.java
# - Downloading allocate-mailboxes
#   ✔ Accepted
#   ✔ 69/69 cases passed (29 ms)
#   ✔ Your runtime beats 8.27 % of java submissions
#   ✔ Your memory usage beats 11.28 % of java submissions (44.6 MB)
# Submitting: java_solutions/1480.running-sum-of-1d-array.java
# - Downloading running-sum-of-1d-array
#   ✔ Accepted
#   ✔ 54/54 cases passed (4 ms)
#   ✔ Your runtime beats 0.6 % of java submissions
#   ✔ Your memory usage beats 17.14 % of java submissions (44.4 MB)
# Submitting: java_solutions/1481.least-number-of-unique-integers-after-k-removals.java
# - Downloading least-number-of-unique-integers-after-k-removals
#   ✔ Accepted
#   ✔ 43/43 cases passed (83 ms)
#   ✔ Your runtime beats 14.51 % of java submissions
#   ✔ Your memory usage beats 5.32 % of java submissions (92.8 MB)
# Submitting: java_solutions/1482.minimum-number-of-days-to-make-m-bouquets.java
# - Downloading minimum-number-of-days-to-make-m-bouquets
#   ✔ Accepted
#   ✔ 93/93 cases passed (169 ms)
#   ✔ Your runtime beats 5.55 % of java submissions
#   ✔ Your memory usage beats 12.27 % of java submissions (85.6 MB)
# Submitting: java_solutions/1483.kth-ancestor-of-a-tree-node.java
# - Downloading kth-ancestor-of-a-tree-node
#   ✔ Accepted
#   ✔ 17/17 cases passed (72 ms)
#   ✔ Your runtime beats 33.33 % of java submissions
#   ✔ Your memory usage beats 53.13 % of java submissions (110.6 MB)
# Submitting: java_solutions/1486.xor-operation-in-an-array.java
# - Downloading xor-operation-in-an-array
#   ✔ Accepted
#   ✔ 54/54 cases passed (3 ms)
#   ✔ Your runtime beats 0.7 % of java submissions
#   ✔ Your memory usage beats 6.7 % of java submissions (42.5 MB)
# Submitting: java_solutions/1487.making-file-names-unique.java
# - Downloading making-file-names-unique
#   ✔ Accepted
#   ✔ 34/34 cases passed (102 ms)
#   ✔ Your runtime beats 5.49 % of java submissions
#   ✔ Your memory usage beats 5.49 % of java submissions (105.3 MB)
# Submitting: java_solutions/1488.avoid-flood-in-the-city.java
# - Downloading avoid-flood-in-the-city
#   ✔ Accepted
#   ✔ 85/85 cases passed (146 ms)
#   ✔ Your runtime beats 5.05 % of java submissions
#   ✔ Your memory usage beats 5.58 % of java submissions (174 MB)
# Submitting: java_solutions/1489.find-critical-and-pseudo-critical-edges-in-minimum-spanning-tree.java
# - Downloading find-critical-and-pseudo-critical-edges-in-minimum-spanning-tree
#   ✔ Accepted
#   ✔ 66/66 cases passed (35 ms)
#   ✔ Your runtime beats 24.7 % of java submissions
#   ✔ Your memory usage beats 5.87 % of java submissions (52.5 MB)
# Submitting: java_solutions/1491.average-salary-excluding-the-minimum-and-maximum-salary.java
# - Downloading average-salary-excluding-the-minimum-and-maximum-salary
#   ✔ Accepted
#   ✔ 43/43 cases passed (8 ms)
#   ✔ Your runtime beats 0.92 % of java submissions
#   ✔ Your memory usage beats 91.81 % of java submissions (45.4 MB)
# Submitting: java_solutions/1492.the-kth-factor-of-n.java
# - Downloading the-kth-factor-of-n
#   ✔ Accepted
#   ✔ 209/209 cases passed (6 ms)
#   ✔ Your runtime beats 1.61 % of java submissions
#   ✔ Your memory usage beats 6.12 % of java submissions (42.6 MB)
# Submitting: java_solutions/1493.longest-subarray-of-1s-after-deleting-one-element.java
# - Downloading longest-subarray-of-1s-after-deleting-one-element
#   ✔ Accepted
#   ✔ 86/86 cases passed (13 ms)
#   ✔ Your runtime beats 4.32 % of java submissions
#   ✔ Your memory usage beats 5.16 % of java submissions (71.8 MB)
# Submitting: java_solutions/1494.parallel-courses-ii.java
# - Downloading parallel-courses-ii
#   ✔ Accepted
#   ✔ 82/82 cases passed (208 ms)
#   ✔ Your runtime beats 23.31 % of java submissions
#   ✔ Your memory usage beats 80.51 % of java submissions (44.8 MB)
# Submitting: java_solutions/1496.path-crossing.java
# - Downloading path-crossing
#   ✔ Accepted
#   ✔ 85/85 cases passed (8 ms)
#   ✔ Your runtime beats 6.35 % of java submissions
#   ✔ Your memory usage beats 7.46 % of java submissions (43.8 MB)
# Submitting: java_solutions/1497.check-if-array-pairs-are-divisible-by-k.java
# - Downloading check-if-array-pairs-are-divisible-by-k
#   ✔ Accepted
#   ✔ 99/99 cases passed (19 ms)
#   ✔ Your runtime beats 48.9 % of java submissions
#   ✔ Your memory usage beats 22.79 % of java submissions (93 MB)
# Submitting: java_solutions/1498.number-of-subsequences-that-satisfy-the-given-sum-condition.java
# - Downloading number-of-subsequences-that-satisfy-the-given-sum-condition
#   ✔ Accepted
#   ✔ 63/63 cases passed (61 ms)
#   ✔ Your runtime beats 5.33 % of java submissions
#   ✔ Your memory usage beats 5.81 % of java submissions (75.5 MB)
# Submitting: java_solutions/1499.max-value-of-equation.java
# - Downloading max-value-of-equation
#   ✔ Accepted
#   ✔ 66/66 cases passed (17 ms)
#   ✔ Your runtime beats 83.02 % of java submissions
#   ✔ Your memory usage beats 92.83 % of java submissions (113.4 MB)
# Submitting: java_solutions/1502.can-make-arithmetic-progression-from-sequence.java
# - Downloading can-make-arithmetic-progression-from-sequence
#   ✔ Accepted
#   ✔ 113/113 cases passed (6 ms)
#   ✔ Your runtime beats 12.89 % of java submissions
#   ✔ Your memory usage beats 11.18 % of java submissions (45.7 MB)
# Submitting: java_solutions/1503.last-moment-before-all-ants-fall-out-of-a-plank.java
# - Downloading last-moment-before-all-ants-fall-out-of-a-plank
#   ✔ Accepted
#   ✔ 167/167 cases passed (4 ms)
#   ✔ Your runtime beats 11.49 % of java submissions
#   ✔ Your memory usage beats 96.55 % of java submissions (46.6 MB)
# Submitting: java_solutions/1504.count-submatrices-with-all-ones.java
# - Downloading count-submatrices-with-all-ones
#   ✔ Accepted
#   ✔ 73/73 cases passed (91 ms)
#   ✔ Your runtime beats 5.93 % of java submissions
#   ✔ Your memory usage beats 78.25 % of java submissions (47.2 MB)
# Submitting: java_solutions/1505.minimum-possible-integer-after-at-most-k-adjacent-swaps-on-digits.java
# - Downloading minimum-possible-integer-after-at-most-k-adjacent-swaps-on-digits
#   ✔ Accepted
#   ✔ 50/50 cases passed (25 ms)
#   ✔ Your runtime beats 50 % of java submissions
#   ✔ Your memory usage beats 23.96 % of java submissions (48.4 MB)
# Submitting: java_solutions/1507.reformat-date.java
# - Downloading reformat-date
#   ✔ Accepted
#   ✔ 110/110 cases passed (6 ms)
#   ✔ Your runtime beats 26.02 % of java submissions
#   ✔ Your memory usage beats 16.58 % of java submissions (43.7 MB)
# Submitting: java_solutions/1508.range-sum-of-sorted-subarray-sums.java
# - Downloading range-sum-of-sorted-subarray-sums
#   ✔ Accepted
#   ✔ 54/54 cases passed (126 ms)
#   ✔ Your runtime beats 43.5 % of java submissions
#   ✔ Your memory usage beats 40.4 % of java submissions (70.8 MB)
# Submitting: java_solutions/1509.minimum-difference-between-largest-and-smallest-value-in-three-moves.java
# - Downloading minimum-difference-between-largest-and-smallest-value-in-three-moves
#   ✔ Accepted
#   ✔ 73/73 cases passed (33 ms)
#   ✔ Your runtime beats 5.78 % of java submissions
#   ✔ Your memory usage beats 10.22 % of java submissions (62 MB)
# Submitting: java_solutions/1510.stone-game-iv.java
# - Downloading stone-game-iv
#   ✔ Accepted
#   ✔ 72/72 cases passed (27 ms)
#   ✔ Your runtime beats 37.5 % of java submissions
#   ✔ Your memory usage beats 60.8 % of java submissions (42.5 MB)
# Submitting: java_solutions/1512.number-of-good-pairs.java
# - Downloading number-of-good-pairs
#   ✔ Accepted
#   ✔ 49/49 cases passed (10 ms)
#   ✔ Your runtime beats 0.69 % of java submissions
#   ✔ Your memory usage beats 8.93 % of java submissions (48.7 MB)
# Submitting: java_solutions/1513.number-of-substrings-with-only-1s.java
# - Downloading number-of-substrings-with-only-1s
#   ✔ Accepted
#   ✔ 57/57 cases passed (10 ms)
#   ✔ Your runtime beats 8.34 % of java submissions
#   ✔ Your memory usage beats 64.81 % of java submissions (46.3 MB)
# Submitting: java_solutions/1514.path-with-maximum-probability.java
# - Downloading path-with-maximum-probability
#   ✔ Accepted
#   ✔ 21/21 cases passed (16 ms)
#   ✔ Your runtime beats 95.55 % of java submissions
#   ✔ Your memory usage beats 97.44 % of java submissions (62.2 MB)
# Submitting: java_solutions/1515.best-position-for-a-service-centre.java
# - Downloading best-position-for-a-service-centre
#   ✔ Accepted
#   ✔ 56/56 cases passed (12 ms)
#   ✔ Your runtime beats 23.68 % of java submissions
#   ✔ Your memory usage beats 35.53 % of java submissions (46.8 MB)
# Submitting: java_solutions/1518.water-bottles.java
# - Downloading water-bottles
#   ✔ Accepted
#   ✔ 70/70 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 5.3 % of java submissions (42.4 MB)
# Submitting: java_solutions/1519.number-of-nodes-in-the-sub-tree-with-the-same-label.java
# - Downloading number-of-nodes-in-the-sub-tree-with-the-same-label
#   ✔ Accepted
#   ✔ 60/60 cases passed (102 ms)
#   ✔ Your runtime beats 13.92 % of java submissions
#   ✔ Your memory usage beats 78.48 % of java submissions (177.7 MB)
# Submitting: java_solutions/1520.maximum-number-of-non-overlapping-substrings.java
# - Downloading maximum-number-of-non-overlapping-substrings
#   ✔ Accepted
#   ✔ 285/285 cases passed (19 ms)
#   ✔ Your runtime beats 39.13 % of java submissions
#   ✔ Your memory usage beats 18.12 % of java submissions (48.7 MB)
# Submitting: java_solutions/1521.find-a-value-of-a-mysterious-function-closest-to-target.java
# - Downloading find-a-value-of-a-mysterious-function-closest-to-target
#   ✔ Accepted
#   ✔ 43/43 cases passed (20 ms)
#   ✔ Your runtime beats 91.43 % of java submissions
#   ✔ Your memory usage beats 87.14 % of java submissions (74 MB)
# Submitting: java_solutions/1523.count-odd-numbers-in-an-interval-range.java
# - Downloading count-odd-numbers-in-an-interval-range
#   ✔ Accepted
#   ✔ 84/84 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 61.6 % of java submissions (42 MB)
# Submitting: java_solutions/1524.number-of-sub-arrays-with-odd-sum.java
# - Downloading number-of-sub-arrays-with-odd-sum
#   ✔ Accepted
#   ✔ 151/151 cases passed (12 ms)
#   ✔ Your runtime beats 9.51 % of java submissions
#   ✔ Your memory usage beats 22.91 % of java submissions (85.2 MB)
# Submitting: java_solutions/1525.number-of-good-ways-to-split-a-string.java
# - Downloading number-of-good-ways-to-split-a-string
#   ✔ Accepted
#   ✔ 61/61 cases passed (16 ms)
#   ✔ Your runtime beats 42.9 % of java submissions
#   ✔ Your memory usage beats 32.25 % of java submissions (46.8 MB)
# Submitting: java_solutions/1526.minimum-number-of-increments-on-subarrays-to-form-a-target-array.java
# - Downloading minimum-number-of-increments-on-subarrays-to-form-a-target-array
#   ✔ Accepted
#   ✔ 129/129 cases passed (6 ms)
#   ✔ Your runtime beats 4.47 % of java submissions
#   ✔ Your memory usage beats 57.45 % of java submissions (74.8 MB)
# Submitting: java_solutions/1528.shuffle-string.java
# - Downloading shuffle-string
#   ✔ Accepted
#   ✔ 399/399 cases passed (23 ms)
#   ✔ Your runtime beats 6.81 % of java submissions
#   ✔ Your memory usage beats 6.84 % of java submissions (47.6 MB)
# Submitting: java_solutions/1529.minimum-suffix-flips.java
# - Downloading minimum-suffix-flips
#   ✔ Accepted
#   ✔ 79/79 cases passed (10 ms)
#   ✔ Your runtime beats 5 % of java submissions
#   ✔ Your memory usage beats 9.74 % of java submissions (46.6 MB)
# Submitting: java_solutions/1530.number-of-good-leaf-nodes-pairs.java
# - Downloading number-of-good-leaf-nodes-pairs
#   ✔ Accepted
#   ✔ 113/113 cases passed (60 ms)
#   ✔ Your runtime beats 16.04 % of java submissions
#   ✔ Your memory usage beats 5.8 % of java submissions (47.6 MB)
# Submitting: java_solutions/1531.string-compression-ii.java
# - Downloading string-compression-ii
#   ✔ Accepted
#   ✔ 144/144 cases passed (77 ms)
#   ✔ Your runtime beats 21.99 % of java submissions
#   ✔ Your memory usage beats 66.67 % of java submissions (44.3 MB)
# Submitting: java_solutions/1534.count-good-triplets.java
# - Downloading count-good-triplets
#   ✔ Accepted
#   ✔ 92/92 cases passed (67 ms)
#   ✔ Your runtime beats 6.89 % of java submissions
#   ✔ Your memory usage beats 12.13 % of java submissions (52.9 MB)
# Submitting: java_solutions/1535.find-the-winner-of-an-array-game.java
# - Downloading find-the-winner-of-an-array-game
#   ✔ Accepted
#   ✔ 185/185 cases passed (1 ms)
#   ✔ Your runtime beats 47.84 % of java submissions
#   ✔ Your memory usage beats 52.16 % of java submissions (67 MB)
# Submitting: java_solutions/1536.minimum-swaps-to-arrange-a-binary-grid.java
# - Downloading minimum-swaps-to-arrange-a-binary-grid
#   ✔ Accepted
#   ✔ 130/130 cases passed (6 ms)
#   ✔ Your runtime beats 6.33 % of java submissions
#   ✔ Your memory usage beats 66.49 % of java submissions (49.6 MB)
# Submitting: java_solutions/1537.get-the-maximum-score.java
# - Downloading get-the-maximum-score
#   ✔ Accepted
#   ✔ 82/82 cases passed (11 ms)
#   ✔ Your runtime beats 7.42 % of java submissions
#   ✔ Your memory usage beats 94.51 % of java submissions (60.9 MB)
# Submitting: java_solutions/1539.kth-missing-positive-number.java
# - Downloading kth-missing-positive-number
#   ✔ Accepted
#   ✔ 87/87 cases passed (7 ms)
#   ✔ Your runtime beats 5.16 % of java submissions
#   ✔ Your memory usage beats 5.96 % of java submissions (45.9 MB)
# Submitting: java_solutions/1540.can-convert-string-in-k-moves.java
# - Downloading can-convert-string-in-k-moves
#   ✔ Accepted
#   ✔ 155/155 cases passed (9 ms)
#   ✔ Your runtime beats 14.07 % of java submissions
#   ✔ Your memory usage beats 99.69 % of java submissions (47.4 MB)
# Submitting: java_solutions/1541.minimum-insertions-to-balance-a-parentheses-string.java
# - Downloading minimum-insertions-to-balance-a-parentheses-string
#   ✔ Accepted
#   ✔ 102/102 cases passed (13 ms)
#   ✔ Your runtime beats 41.15 % of java submissions
#   ✔ Your memory usage beats 44.97 % of java submissions (47.6 MB)
# Submitting: java_solutions/1542.find-longest-awesome-substring.java
# - Downloading find-longest-awesome-substring
#   ✔ Accepted
#   ✔ 153/153 cases passed (22 ms)
#   ✔ Your runtime beats 52.83 % of java submissions
#   ✔ Your memory usage beats 52.83 % of java submissions (46.6 MB)
# Submitting: java_solutions/1544.make-the-string-great.java
# - Downloading make-the-string-great
#   ✔ Accepted
#   ✔ 335/335 cases passed (7 ms)
#   ✔ Your runtime beats 5.76 % of java submissions
#   ✔ Your memory usage beats 5.06 % of java submissions (44.6 MB)
# Submitting: java_solutions/1545.find-kth-bit-in-nth-binary-string.java
# - Downloading find-kth-bit-in-nth-binary-string
#   ✔ Accepted
#   ✔ 63/63 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 78.31 % of java submissions (42.5 MB)
# Submitting: java_solutions/1546.maximum-number-of-non-overlapping-subarrays-with-sum-equals-target.java
# - Downloading maximum-number-of-non-overlapping-subarrays-with-sum-equals-target
#   ✔ Accepted
#   ✔ 69/69 cases passed (43 ms)
#   ✔ Your runtime beats 5.71 % of java submissions
#   ✔ Your memory usage beats 51.43 % of java submissions (75.9 MB)
# Submitting: java_solutions/1547.minimum-cost-to-cut-a-stick.java
# - Downloading minimum-cost-to-cut-a-stick
#   ✔ Accepted
#   ✔ 101/101 cases passed (33 ms)
#   ✔ Your runtime beats 12.06 % of java submissions
#   ✔ Your memory usage beats 12.7 % of java submissions (45.2 MB)
# Submitting: java_solutions/1550.three-consecutive-odds.java
# - Downloading three-consecutive-odds
#   ✔ Accepted
#   ✔ 38/38 cases passed (3 ms)
#   ✔ Your runtime beats 0.38 % of java submissions
#   ✔ Your memory usage beats 5.91 % of java submissions (44.7 MB)
# Submitting: java_solutions/1551.minimum-operations-to-make-array-equal.java
# - Downloading minimum-operations-to-make-array-equal
#   ✔ Accepted
#   ✔ 301/301 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 79.73 % of java submissions (42.1 MB)
# Submitting: java_solutions/1552.magnetic-force-between-two-balls.java
# - Downloading magnetic-force-between-two-balls
#   ✔ Accepted
#   ✔ 98/98 cases passed (75 ms)
#   ✔ Your runtime beats 5.92 % of java submissions
#   ✔ Your memory usage beats 11.03 % of java submissions (79.8 MB)
# Submitting: java_solutions/1553.minimum-number-of-days-to-eat-n-oranges.java
# - Downloading minimum-number-of-days-to-eat-n-oranges
#   ✔ Accepted
#   ✔ 176/176 cases passed (15 ms)
#   ✔ Your runtime beats 8.51 % of java submissions
#   ✔ Your memory usage beats 16.31 % of java submissions (44.7 MB)

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-05-04 22:56:52
