# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME_3')
    user_cookie = userdata.get('LEETCODE_TOKEN_3')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME_3'] = user_name
    os.environ['LEETCODE_TOKEN_3'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME_3" "$LEETCODE_TOKEN_3" | leetcode user -c

# %%
# %%bash
#
#
# # top 100 answers
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v java_solutions/*.java | sed -n '301,450p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 8
# done
# Out:
# Submitting: java_solutions/460.lfu-cache.java
# - Downloading problems
# - Downloading lfu-cache
#   ✔ Accepted
#   ✔ 25/25 cases passed (78 ms)
#   ✔ Your runtime beats 13.97 % of java submissions
#   ✔ Your memory usage beats 27.7 % of java submissions (139.8 MB)
# Submitting: java_solutions/461.hamming-distance.java
# - Downloading hamming-distance
#   ✔ Accepted
#   ✔ 149/149 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 8.2 % of java submissions (42.5 MB)
# Submitting: java_solutions/462.minimum-moves-to-equal-array-elements-ii.java
# - Downloading minimum-moves-to-equal-array-elements-ii
#   ✔ Accepted
#   ✔ 33/33 cases passed (16 ms)
#   ✔ Your runtime beats 5.61 % of java submissions
#   ✔ Your memory usage beats 52.66 % of java submissions (47.2 MB)
# Submitting: java_solutions/463.island-perimeter.java
# - Downloading island-perimeter
#   ✔ Accepted
#   ✔ 5833/5833 cases passed (35 ms)
#   ✔ Your runtime beats 7.12 % of java submissions
#   ✔ Your memory usage beats 5.96 % of java submissions (48.2 MB)
# Submitting: java_solutions/466.count-the-repetitions.java
# - Downloading count-the-repetitions
#   ✔ Accepted
#   ✔ 49/49 cases passed (12 ms)
#   ✔ Your runtime beats 22.12 % of java submissions
#   ✔ Your memory usage beats 8.01 % of java submissions (97.5 MB)
# Submitting: java_solutions/467.unique-substrings-in-wraparound-string.java
# - Downloading unique-substrings-in-wraparound-string
#   ✔ Accepted
#   ✔ 82/82 cases passed (86 ms)
#   ✔ Your runtime beats 5.98 % of java submissions
#   ✔ Your memory usage beats 5.71 % of java submissions (47.3 MB)
# Submitting: java_solutions/468.validate-ip-address.java
# - Downloading validate-ip-address
#   ✔ Accepted
#   ✔ 79/79 cases passed (7 ms)
#   ✔ Your runtime beats 8.58 % of java submissions
#   ✔ Your memory usage beats 5.62 % of java submissions (44.1 MB)
# Submitting: java_solutions/472.concatenated-words.java
# - Downloading concatenated-words
#   ✔ Accepted
#   ✔ 43/43 cases passed (92 ms)
#   ✔ Your runtime beats 13.11 % of java submissions
#   ✔ Your memory usage beats 87.87 % of java submissions (50.4 MB)
# Submitting: java_solutions/474.ones-and-zeroes.java
# - Downloading ones-and-zeroes
#   ✔ Accepted
#   ✔ 77/77 cases passed (207 ms)
#   ✔ Your runtime beats 7.83 % of java submissions
#   ✔ Your memory usage beats 33.1 % of java submissions (52.9 MB)
# Submitting: java_solutions/475.heaters.java
# - Downloading heaters
#   ✔ Accepted
#   ✔ 30/30 cases passed (30 ms)
#   ✔ Your runtime beats 18.2 % of java submissions
#   ✔ Your memory usage beats 7.61 % of java submissions (48.8 MB)
# Submitting: java_solutions/476.number-complement.java
# - Downloading number-complement
#   ✔ Accepted
#   ✔ 154/154 cases passed (6 ms)
#   ✔ Your runtime beats 2.29 % of java submissions
#   ✔ Your memory usage beats 5.06 % of java submissions (43 MB)
# Submitting: java_solutions/477.total-hamming-distance.java
# - Downloading total-hamming-distance
#   ✔ Accepted
#   ✔ 46/46 cases passed (38 ms)
#   ✔ Your runtime beats 18.68 % of java submissions
#   ✔ Your memory usage beats 72.79 % of java submissions (48 MB)
# Submitting: java_solutions/478.generate-random-point-in-a-circle.java
# - Downloading generate-random-point-in-a-circle
#   ✔ Accepted
#   ✔ 8/8 cases passed (225 ms)
#   ✔ Your runtime beats 6.1 % of java submissions
#   ✔ Your memory usage beats 89.15 % of java submissions (56.5 MB)
# Submitting: java_solutions/479.largest-palindrome-product.java
# - Downloading largest-palindrome-product
#   ✔ Accepted
#   ✔ 8/8 cases passed (128 ms)
#   ✔ Your runtime beats 12.15 % of java submissions
#   ✔ Your memory usage beats 32.2 % of java submissions (45.4 MB)
# Submitting: java_solutions/480.sliding-window-median.java
# - Downloading sliding-window-median
#   ✔ Accepted
#   ✔ 45/45 cases passed (107 ms)
#   ✔ Your runtime beats 32.89 % of java submissions
#   ✔ Your memory usage beats 88.7 % of java submissions (62.3 MB)
# Submitting: java_solutions/482.license-key-formatting.java
# - Downloading license-key-formatting
#   ✔ Accepted
#   ✔ 40/40 cases passed (39 ms)
#   ✔ Your runtime beats 15.91 % of java submissions
#   ✔ Your memory usage beats 5.23 % of java submissions (48 MB)
# Submitting: java_solutions/483.smallest-good-base.java
# - Downloading smallest-good-base
#   ✔ Accepted
#   ✔ 109/109 cases passed (7 ms)
#   ✔ Your runtime beats 16.44 % of java submissions
#   ✔ Your memory usage beats 22.15 % of java submissions (43.1 MB)
# Submitting: java_solutions/485.max-consecutive-ones.java
# - Downloading max-consecutive-ones
#   ✔ Accepted
#   ✔ 45/45 cases passed (8 ms)
#   ✔ Your runtime beats 1.24 % of java submissions
#   ✔ Your memory usage beats 10.25 % of java submissions (52.7 MB)
# Submitting: java_solutions/488.zuma-game.java
# - Downloading zuma-game
#   ✔ Accepted
#   ✔ 57/57 cases passed (317 ms)
#   ✔ Your runtime beats 52.1 % of java submissions
#   ✔ Your memory usage beats 5.88 % of java submissions (290.3 MB)
# Submitting: java_solutions/491.non-decreasing-subsequences.java
# - Downloading non-decreasing-subsequences
#   ✔ Accepted
#   ✔ 58/58 cases passed (52 ms)
#   ✔ Your runtime beats 5.23 % of java submissions
#   ✔ Your memory usage beats 5.03 % of java submissions (61.1 MB)
# Submitting: java_solutions/493.reverse-pairs.java
# - Downloading reverse-pairs
#   ✔ Accepted
#   ✔ 140/140 cases passed (69 ms)
#   ✔ Your runtime beats 30.86 % of java submissions
#   ✔ Your memory usage beats 56.41 % of java submissions (61.4 MB)
# Submitting: java_solutions/495.teemo-attacking.java
# - Downloading teemo-attacking
#   ✔ Accepted
#   ✔ 40/40 cases passed (7 ms)
#   ✔ Your runtime beats 2.05 % of java submissions
#   ✔ Your memory usage beats 77.29 % of java submissions (48.1 MB)
# Submitting: java_solutions/496.next-greater-element-i.java
# - Downloading next-greater-element-i
#   ✔ Accepted
#   ✔ 17/17 cases passed (98 ms)
#   ✔ Your runtime beats 5.17 % of java submissions
#   ✔ Your memory usage beats 10.69 % of java submissions (47.4 MB)
# Submitting: java_solutions/498.diagonal-traverse.java
# - Downloading diagonal-traverse
#   ✔ Accepted
#   ✔ 33/33 cases passed (36 ms)
#   ✔ Your runtime beats 5.29 % of java submissions
#   ✔ Your memory usage beats 5.01 % of java submissions (59.3 MB)
# Submitting: java_solutions/500.keyboard-row.java
# - Downloading keyboard-row
#   ✔ Accepted
#   ✔ 25/25 cases passed (3 ms)
#   ✔ Your runtime beats 4.46 % of java submissions
#   ✔ Your memory usage beats 6.4 % of java submissions (43.4 MB)
# Submitting: java_solutions/501.find-mode-in-binary-search-tree.java
# - Downloading find-mode-in-binary-search-tree
#   ✔ Accepted
#   ✔ 24/24 cases passed (32 ms)
#   ✔ Your runtime beats 5.76 % of java submissions
#   ✔ Your memory usage beats 5.88 % of java submissions (54.5 MB)
# Submitting: java_solutions/502.ipo.java
# - Downloading ipo
#   ✔ Accepted
#   ✔ 40/40 cases passed (34 ms)
#   ✔ Your runtime beats 99.96 % of java submissions
#   ✔ Your memory usage beats 98.62 % of java submissions (116.8 MB)
# Submitting: java_solutions/504.base-7.java
# - Downloading base-7
#   ✔ Accepted
#   ✔ 241/241 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 45.46 % of java submissions (42.8 MB)
# Submitting: java_solutions/506.relative-ranks.java
# - Downloading relative-ranks
#   ✔ Accepted
#   ✔ 18/18 cases passed (150 ms)
#   ✔ Your runtime beats 5.08 % of java submissions
#   ✔ Your memory usage beats 39.44 % of java submissions (47.6 MB)
# Submitting: java_solutions/507.perfect-number.java
# - Downloading perfect-number
#   ✔ Accepted
#   ✔ 98/98 cases passed (6 ms)
#   ✔ Your runtime beats 61.16 % of java submissions
#   ✔ Your memory usage beats 26.22 % of java submissions (42.3 MB)
# Submitting: java_solutions/509.fibonacci-number.java
# - Downloading fibonacci-number
#   ✔ Accepted
#   ✔ 31/31 cases passed (13 ms)
#   ✔ Your runtime beats 9.55 % of java submissions
#   ✔ Your memory usage beats 16.18 % of java submissions (42.2 MB)
# Submitting: java_solutions/513.find-bottom-left-tree-value.java
# - Downloading find-bottom-left-tree-value
#   ✔ Accepted
#   ✔ 79/79 cases passed (19 ms)
#   ✔ Your runtime beats 11.32 % of java submissions
#   ✔ Your memory usage beats 5.73 % of java submissions (47.8 MB)
# Submitting: java_solutions/514.freedom-trail.java
# - Downloading freedom-trail
#   ✔ Accepted
#   ✔ 303/303 cases passed (292 ms)
#   ✔ Your runtime beats 5.33 % of java submissions
#   ✔ Your memory usage beats 14.04 % of java submissions (47.2 MB)
# Submitting: java_solutions/515.find-largest-value-in-each-tree-row.java
# - Downloading find-largest-value-in-each-tree-row
#   ✔ Accepted
#   ✔ 78/78 cases passed (15 ms)
#   ✔ Your runtime beats 4.27 % of java submissions
#   ✔ Your memory usage beats 13.97 % of java submissions (47.6 MB)
# Submitting: java_solutions/517.super-washing-machines.java
# - Downloading super-washing-machines
#   ✔ Accepted
#   ✔ 120/120 cases passed (4 ms)
#   ✔ Your runtime beats 1.04 % of java submissions
#   ✔ Your memory usage beats 11.46 % of java submissions (47.1 MB)
# Submitting: java_solutions/520.detect-capital.java
# - Downloading detect-capital
#   ✔ Accepted
#   ✔ 553/553 cases passed (7 ms)
#   ✔ Your runtime beats 3.3 % of java submissions
#   ✔ Your memory usage beats 6.1 % of java submissions (45.1 MB)
# Submitting: java_solutions/521.longest-uncommon-subsequence-i.java
# - Downloading longest-uncommon-subsequence-i
#   ✔ Accepted
#   ✔ 41/41 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 40.4 % of java submissions (42.7 MB)
# Submitting: java_solutions/524.longest-word-in-dictionary-through-deleting.java
# - Downloading longest-word-in-dictionary-through-deleting
#   ✔ Accepted
#   ✔ 31/31 cases passed (31 ms)
#   ✔ Your runtime beats 5.35 % of java submissions
#   ✔ Your memory usage beats 6.02 % of java submissions (53 MB)
# Submitting: java_solutions/530.minimum-absolute-difference-in-bst.java
# - Downloading minimum-absolute-difference-in-bst
#   ✔ Accepted
#   ✔ 190/190 cases passed (27 ms)
#   ✔ Your runtime beats 5.71 % of java submissions
#   ✔ Your memory usage beats 5.16 % of java submissions (47.9 MB)
# Submitting: java_solutions/535.encode-and-decode-tinyurl.java
# - Downloading encode-and-decode-tinyurl
#   ✔ Accepted
#   ✔ 739/739 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 96.36 % of java submissions (43.9 MB)
# Submitting: java_solutions/537.complex-number-multiplication.java
# - Downloading complex-number-multiplication
#   ✔ Accepted
#   ✔ 56/56 cases passed (7 ms)
#   ✔ Your runtime beats 9.2 % of java submissions
#   ✔ Your memory usage beats 14.21 % of java submissions (43.5 MB)
# Submitting: java_solutions/541.reverse-string-ii.java
# - Downloading reverse-string-ii
#   ✔ Accepted
#   ✔ 60/60 cases passed (6 ms)
#   ✔ Your runtime beats 5.48 % of java submissions
#   ✔ Your memory usage beats 5.01 % of java submissions (46.3 MB)
# Submitting: java_solutions/543.diameter-of-binary-tree.java
# - Downloading diameter-of-binary-tree
#   ✔ Accepted
#   ✔ 106/106 cases passed (33 ms)
#   ✔ Your runtime beats 10.76 % of java submissions
#   ✔ Your memory usage beats 5.07 % of java submissions (53.5 MB)
# Submitting: java_solutions/546.remove-boxes.java
# - Downloading remove-boxes
#   ✔ Accepted
#   ✔ 63/63 cases passed (192 ms)
#   ✔ Your runtime beats 5.25 % of java submissions
#   ✔ Your memory usage beats 5.25 % of java submissions (172.4 MB)
# Submitting: java_solutions/551.student-attendance-record-i.java
# - Downloading student-attendance-record-i
#   ✔ Accepted
#   ✔ 115/115 cases passed (10 ms)
#   ✔ Your runtime beats 4.07 % of java submissions
#   ✔ Your memory usage beats 5.53 % of java submissions (45 MB)
# Submitting: java_solutions/552.student-attendance-record-ii.java
# - Downloading student-attendance-record-ii
#   ✔ Accepted
#   ✔ 59/59 cases passed (169 ms)
#   ✔ Your runtime beats 86.83 % of java submissions
#   ✔ Your memory usage beats 97.6 % of java submissions (42.2 MB)
# Submitting: java_solutions/557.reverse-words-in-a-string-iii.java
# - Downloading reverse-words-in-a-string-iii
#   ✔ Accepted
#   ✔ 29/29 cases passed (6 ms)
#   ✔ Your runtime beats 50.2 % of java submissions
#   ✔ Your memory usage beats 64.67 % of java submissions (46.8 MB)
# Submitting: java_solutions/559.maximum-depth-of-n-ary-tree.java
# - Downloading maximum-depth-of-n-ary-tree
#   ✔ Accepted
#   ✔ 38/38 cases passed (6 ms)
#   ✔ Your runtime beats 1.33 % of java submissions
#   ✔ Your memory usage beats 5.92 % of java submissions (46.4 MB)
# Submitting: java_solutions/561.array-partition.java
# - Downloading array-partition
#   ✔ Accepted
#   ✔ 85/85 cases passed (30 ms)
#   ✔ Your runtime beats 11.45 % of java submissions
#   ✔ Your memory usage beats 98.52 % of java submissions (48.2 MB)
# Submitting: java_solutions/564.find-the-closest-palindrome.java
# - Downloading find-the-closest-palindrome
#   ✔ Accepted
#   ✔ 232/232 cases passed (2 ms)
#   ✔ Your runtime beats 95.72 % of java submissions
#   ✔ Your memory usage beats 59.08 % of java submissions (43.3 MB)
# Submitting: java_solutions/566.reshape-the-matrix.java
# - Downloading reshape-the-matrix
#   ✔ Accepted
#   ✔ 57/57 cases passed (7 ms)
#   ✔ Your runtime beats 1.32 % of java submissions
#   ✔ Your memory usage beats 6.05 % of java submissions (47.6 MB)
# Submitting: java_solutions/575.distribute-candies.java
# - Downloading distribute-candies
#   ✔ Accepted
#   ✔ 206/206 cases passed (37 ms)
#   ✔ Your runtime beats 16.09 % of java submissions
#   ✔ Your memory usage beats 49.93 % of java submissions (48.5 MB)
# Submitting: java_solutions/587.erect-the-fence.java
# - Downloading erect-the-fence
#   ✔ Accepted
#   ✔ 88/88 cases passed (26 ms)
#   ✔ Your runtime beats 21.67 % of java submissions
#   ✔ Your memory usage beats 5.42 % of java submissions (48.5 MB)
# Submitting: java_solutions/591.tag-validator.java
# - Downloading tag-validator
#   ✔ Accepted
#   ✔ 261/261 cases passed (2 ms)
#   ✔ Your runtime beats 83.83 % of java submissions
#   ✔ Your memory usage beats 5.96 % of java submissions (44.3 MB)
# Submitting: java_solutions/594.longest-harmonious-subsequence.java
# - Downloading longest-harmonious-subsequence
#   ✔ Accepted
#   ✔ 208/208 cases passed (49 ms)
#   ✔ Your runtime beats 5.03 % of java submissions
#   ✔ Your memory usage beats 7.8 % of java submissions (53.8 MB)
# Submitting: java_solutions/599.minimum-index-sum-of-two-lists.java
# - Downloading minimum-index-sum-of-two-lists
#   ✔ Accepted
#   ✔ 137/137 cases passed (23 ms)
#   ✔ Your runtime beats 24.65 % of java submissions
#   ✔ Your memory usage beats 5.09 % of java submissions (53.3 MB)
# Submitting: java_solutions/600.non-negative-integers-without-consecutive-ones.java
# - Downloading non-negative-integers-without-consecutive-ones
#   ✔ Accepted
#   ✔ 527/527 cases passed (1 ms)
#   ✔ Your runtime beats 99.15 % of java submissions
#   ✔ Your memory usage beats 52.54 % of java submissions (42.6 MB)
# Submitting: java_solutions/605.can-place-flowers.java
# - Downloading can-place-flowers
#   ✔ Accepted
#   ✔ 130/130 cases passed (6 ms)
#   ✔ Your runtime beats 2.27 % of java submissions
#   ✔ Your memory usage beats 36.74 % of java submissions (47.8 MB)
# Submitting: java_solutions/617.merge-two-binary-trees.java
# - Downloading merge-two-binary-trees
#   ✔ Accepted
#   ✔ 182/182 cases passed (3 ms)
#   ✔ Your runtime beats 0.41 % of java submissions
#   ✔ Your memory usage beats 56.86 % of java submissions (46.9 MB)
# Submitting: java_solutions/628.maximum-product-of-three-numbers.java
# - Downloading maximum-product-of-three-numbers
#   ✔ Accepted
#   ✔ 93/93 cases passed (25 ms)
#   ✔ Your runtime beats 8.52 % of java submissions
#   ✔ Your memory usage beats 64.26 % of java submissions (47.9 MB)
# Submitting: java_solutions/629.k-inverse-pairs-array.java
# - Downloading k-inverse-pairs-array
#   ✔ Accepted
#   ✔ 81/81 cases passed (27 ms)
#   ✔ Your runtime beats 28.73 % of java submissions
#   ✔ Your memory usage beats 74.63 % of java submissions (46.7 MB)
# Submitting: java_solutions/630.course-schedule-iii.java
# - Downloading course-schedule-iii
#   ✔ Accepted
#   ✔ 97/97 cases passed (53 ms)
#   ✔ Your runtime beats 6.76 % of java submissions
#   ✔ Your memory usage beats 6.88 % of java submissions (58.7 MB)
# Submitting: java_solutions/632.smallest-range-covering-elements-from-k-lists.java
# - Downloading smallest-range-covering-elements-from-k-lists
#   ✔ Accepted
#   ✔ 94/94 cases passed (100 ms)
#   ✔ Your runtime beats 46 % of java submissions
#   ✔ Your memory usage beats 8.25 % of java submissions (96.9 MB)
# Submitting: java_solutions/639.decode-ways-ii.java
# - Downloading decode-ways-ii
#   ✔ Accepted
#   ✔ 218/218 cases passed (17 ms)
#   ✔ Your runtime beats 52.08 % of java submissions
#   ✔ Your memory usage beats 45.71 % of java submissions (47.7 MB)
# Submitting: java_solutions/643.maximum-average-subarray-i.java
# - Downloading maximum-average-subarray-i
#   ✔ Accepted
#   ✔ 128/128 cases passed (17 ms)
#   ✔ Your runtime beats 5.12 % of java submissions
#   ✔ Your memory usage beats 97.31 % of java submissions (68.8 MB)
# Submitting: java_solutions/645.set-mismatch.java
# - Downloading set-mismatch
#   ✔ Accepted
#   ✔ 49/49 cases passed (16 ms)
#   ✔ Your runtime beats 18.45 % of java submissions
#   ✔ Your memory usage beats 11.02 % of java submissions (48.2 MB)
# Submitting: java_solutions/647.palindromic-substrings.java
# - Downloading palindromic-substrings
#   ✔ Accepted
#   ✔ 132/132 cases passed (29 ms)
#   ✔ Your runtime beats 21.16 % of java submissions
#   ✔ Your memory usage beats 10.63 % of java submissions (47.1 MB)
# Submitting: java_solutions/653.two-sum-iv-input-is-a-bst.java
# - Downloading two-sum-iv-input-is-a-bst
#   ✔ Accepted
#   ✔ 423/423 cases passed (32 ms)
#   ✔ Your runtime beats 6.09 % of java submissions
#   ✔ Your memory usage beats 10.43 % of java submissions (48 MB)
# Submitting: java_solutions/657.robot-return-to-origin.java
# - Downloading robot-return-to-origin
#   ✔ Accepted
#   ✔ 78/78 cases passed (13 ms)
#   ✔ Your runtime beats 5.26 % of java submissions
#   ✔ Your memory usage beats 22.03 % of java submissions (46.3 MB)
# Submitting: java_solutions/664.strange-printer.java
# - Downloading strange-printer
#   ✔ Accepted
#   ✔ 200/200 cases passed (35 ms)
#   ✔ Your runtime beats 13.09 % of java submissions
#   ✔ Your memory usage beats 6.45 % of java submissions (45.2 MB)
# Submitting: java_solutions/668.kth-smallest-number-in-multiplication-table.java
# - Downloading kth-smallest-number-in-multiplication-table
#   ✔ Accepted
#   ✔ 71/71 cases passed (15 ms)
#   ✔ Your runtime beats 6.62 % of java submissions
#   ✔ Your memory usage beats 77.59 % of java submissions (42 MB)
# Submitting: java_solutions/671.second-minimum-node-in-a-binary-tree.java
# - Downloading second-minimum-node-in-a-binary-tree
#   ✔ Accepted
#   ✔ 39/39 cases passed (12 ms)
#   ✔ Your runtime beats 0.87 % of java submissions
#   ✔ Your memory usage beats 11.08 % of java submissions (43.6 MB)
# Submitting: java_solutions/674.longest-continuous-increasing-subsequence.java
# - Downloading longest-continuous-increasing-subsequence
#   ✔ Accepted
#   ✔ 35/35 cases passed (5 ms)
#   ✔ Your runtime beats 1.68 % of java submissions
#   ✔ Your memory usage beats 93.17 % of java submissions (46.5 MB)
# Submitting: java_solutions/675.cut-off-trees-for-golf-event.java
# - Downloading cut-off-trees-for-golf-event
#   ✔ Accepted
#   ✔ 55/55 cases passed (524 ms)
#   ✔ Your runtime beats 31.28 % of java submissions
#   ✔ Your memory usage beats 5.08 % of java submissions (48.7 MB)
# Submitting: java_solutions/679.24-game.java
# - Downloading 24-game
#   ✔ Accepted
#   ✔ 71/71 cases passed (58 ms)
#   ✔ Your runtime beats 5.36 % of java submissions
#   ✔ Your memory usage beats 12.98 % of java submissions (48.4 MB)
# Submitting: java_solutions/680.valid-palindrome-ii.java
# - Downloading valid-palindrome-ii
#   ✔ Accepted
#   ✔ 477/477 cases passed (22 ms)
#   ✔ Your runtime beats 5.09 % of java submissions
#   ✔ Your memory usage beats 12.84 % of java submissions (48.1 MB)
# Submitting: java_solutions/682.baseball-game.java
# - Downloading baseball-game
#   ✔ Accepted
#   ✔ 39/39 cases passed (7 ms)
#   ✔ Your runtime beats 3.74 % of java submissions
#   ✔ Your memory usage beats 5.54 % of java submissions (44.2 MB)
# Submitting: java_solutions/685.redundant-connection-ii.java
# - Downloading redundant-connection-ii
#   ✔ Accepted
#   ✔ 58/58 cases passed (3 ms)
#   ✔ Your runtime beats 20.4 % of java submissions
#   ✔ Your memory usage beats 63.96 % of java submissions (45.2 MB)
# Submitting: java_solutions/689.maximum-sum-of-3-non-overlapping-subarrays.java
# - Downloading maximum-sum-of-3-non-overlapping-subarrays
#   ✔ Accepted
#   ✔ 43/43 cases passed (12 ms)
#   ✔ Your runtime beats 8.08 % of java submissions
#   ✔ Your memory usage beats 41.23 % of java submissions (49.2 MB)
# Submitting: java_solutions/691.stickers-to-spell-word.java
# - Downloading stickers-to-spell-word
#   ✔ Accepted
#   ✔ 102/102 cases passed (15 ms)
#   ✔ Your runtime beats 87.31 % of java submissions
#   ✔ Your memory usage beats 92.23 % of java submissions (45.3 MB)
# Submitting: java_solutions/693.binary-number-with-alternating-bits.java
# - Downloading binary-number-with-alternating-bits
#   ✔ Accepted
#   ✔ 204/204 cases passed (7 ms)
#   ✔ Your runtime beats 0.44 % of java submissions
#   ✔ Your memory usage beats 5.41 % of java submissions (43.4 MB)
# Submitting: java_solutions/697.degree-of-an-array.java
# - Downloading degree-of-an-array
#   ✔ Accepted
#   ✔ 89/89 cases passed (30 ms)
#   ✔ Your runtime beats 34.8 % of java submissions
#   ✔ Your memory usage beats 9.19 % of java submissions (51.8 MB)
# Submitting: java_solutions/699.falling-squares.java
# - Downloading falling-squares
#   ✔ Accepted
#   ✔ 48/48 cases passed (19 ms)
#   ✔ Your runtime beats 64.74 % of java submissions
#   ✔ Your memory usage beats 55.32 % of java submissions (46.8 MB)
# Submitting: java_solutions/700.search-in-a-binary-search-tree.java
# - Downloading search-in-a-binary-search-tree
#   ✔ Accepted
#   ✔ 36/36 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 15.23 % of java submissions (47.3 MB)
# Submitting: java_solutions/704.binary-search.java
# - Downloading binary-search
#   ✔ Accepted
#   ✔ 47/47 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 50 % of java submissions (48.4 MB)
# Submitting: java_solutions/705.design-hashset.java
# - Downloading design-hashset
#   ✔ Accepted
#   ✔ 34/34 cases passed (12 ms)
#   ✔ Your runtime beats 99.38 % of java submissions
#   ✔ Your memory usage beats 5 % of java submissions (82.4 MB)
# Submitting: java_solutions/706.design-hashmap.java
# - Downloading design-hashmap
#   ✔ Accepted
#   ✔ 37/37 cases passed (549 ms)
#   ✔ Your runtime beats 5.02 % of java submissions
#   ✔ Your memory usage beats 5.01 % of java submissions (277.9 MB)
# Submitting: java_solutions/709.to-lower-case.java
# - Downloading to-lower-case
#   ✔ Accepted
#   ✔ 114/114 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 82.03 % of java submissions (42.8 MB)
# Submitting: java_solutions/710.random-pick-with-blacklist.java
# - Downloading random-pick-with-blacklist
#   ✔ Accepted
#   ✔ 68/68 cases passed (52 ms)
#   ✔ Your runtime beats 16.77 % of java submissions
#   ✔ Your memory usage beats 82.62 % of java submissions (66.6 MB)
# Submitting: java_solutions/715.range-module.java
# - Downloading range-module
#   ✔ Accepted
#   ✔ 56/56 cases passed (59 ms)
#   ✔ Your runtime beats 18.37 % of java submissions
#   ✔ Your memory usage beats 57.46 % of java submissions (57.8 MB)
# Submitting: java_solutions/717.1-bit-and-2-bit-characters.java
# - Downloading 1-bit-and-2-bit-characters
#   ✔ Accepted
#   ✔ 95/95 cases passed (3 ms)
#   ✔ Your runtime beats 1.02 % of java submissions
#   ✔ Your memory usage beats 11.34 % of java submissions (45 MB)
# Submitting: java_solutions/719.find-k-th-smallest-pair-distance.java
# - Downloading find-k-th-smallest-pair-distance
#   ✔ Accepted
#   ✔ 21/21 cases passed (20 ms)
#   ✔ Your runtime beats 10.61 % of java submissions
#   ✔ Your memory usage beats 61.1 % of java submissions (46.9 MB)
# Submitting: java_solutions/724.find-pivot-index.java
# - Downloading find-pivot-index
#   ✔ Accepted
#   ✔ 747/747 cases passed (10 ms)
#   ✔ Your runtime beats 9.31 % of java submissions
#   ✔ Your memory usage beats 22.45 % of java submissions (47.5 MB)
# Submitting: java_solutions/726.number-of-atoms.java
# - Downloading number-of-atoms
#   ✔ Accepted
#   ✔ 39/39 cases passed (11 ms)
#   ✔ Your runtime beats 6.35 % of java submissions
#   ✔ Your memory usage beats 5.33 % of java submissions (44.3 MB)
# Submitting: java_solutions/728.self-dividing-numbers.java
# - Downloading self-dividing-numbers
#   ✔ Accepted
#   ✔ 31/31 cases passed (20 ms)
#   ✔ Your runtime beats 5.1 % of java submissions
#   ✔ Your memory usage beats 5.09 % of java submissions (46.9 MB)
# Submitting: java_solutions/730.count-different-palindromic-subsequences.java
# - Downloading count-different-palindromic-subsequences
#   ✔ Accepted
#   ✔ 367/367 cases passed (113 ms)
#   ✔ Your runtime beats 15.31 % of java submissions
#   ✔ Your memory usage beats 44.9 % of java submissions (57.6 MB)
# Submitting: java_solutions/732.my-calendar-iii.java
# - Downloading my-calendar-iii
#   ✔ Accepted
#   ✔ 98/98 cases passed (2036 ms)
#   ✔ Your runtime beats 5.29 % of java submissions
#   ✔ Your memory usage beats 5.83 % of java submissions (48.4 MB)
# Submitting: java_solutions/736.parse-lisp-expression.java
# - Downloading parse-lisp-expression
#   ✔ Accepted
#   ✔ 66/66 cases passed (10 ms)
#   ✔ Your runtime beats 6.67 % of java submissions
#   ✔ Your memory usage beats 5.45 % of java submissions (46.6 MB)
# Submitting: java_solutions/741.cherry-pickup.java
# - Downloading cherry-pickup
#   ✔ Accepted
#   ✔ 60/60 cases passed (107 ms)
#   ✔ Your runtime beats 15.94 % of java submissions
#   ✔ Your memory usage beats 45 % of java submissions (47.3 MB)
# Submitting: java_solutions/744.find-smallest-letter-greater-than-target.java
# - Downloading find-smallest-letter-greater-than-target
#   ✔ Accepted
#   ✔ 167/167 cases passed (6 ms)
#   ✔ Your runtime beats 0.49 % of java submissions
#   ✔ Your memory usage beats 14 % of java submissions (46.5 MB)
# Submitting: java_solutions/745.prefix-and-suffix-search.java
# - Downloading prefix-and-suffix-search
#   ✔ Accepted
#   ✔ 17/17 cases passed (487 ms)
#   ✔ Your runtime beats 43.69 % of java submissions
#   ✔ Your memory usage beats 63.51 % of java submissions (169.9 MB)
# Submitting: java_solutions/747.largest-number-at-least-twice-of-others.java
# - Downloading largest-number-at-least-twice-of-others
#   ✔ Accepted
#   ✔ 231/231 cases passed (8 ms)
#   ✔ Your runtime beats 4.85 % of java submissions
#   ✔ Your memory usage beats 35.5 % of java submissions (43.4 MB)
# Submitting: java_solutions/749.contain-virus.java
# - Downloading contain-virus
#   ✔ Accepted
#   ✔ 32/32 cases passed (30 ms)
#   ✔ Your runtime beats 6.06 % of java submissions
#   ✔ Your memory usage beats 7.27 % of java submissions (49.3 MB)
# Submitting: java_solutions/753.cracking-the-safe.java
# - Downloading cracking-the-safe
#   ✔ Accepted
#   ✔ 38/38 cases passed (9 ms)
#   ✔ Your runtime beats 78.98 % of java submissions
#   ✔ Your memory usage beats 7.96 % of java submissions (48.3 MB)
# Submitting: java_solutions/757.set-intersection-size-at-least-two.java
# - Downloading set-intersection-size-at-least-two
#   ✔ Accepted
#   ✔ 118/118 cases passed (363 ms)
#   ✔ Your runtime beats 10.03 % of java submissions
#   ✔ Your memory usage beats 5.63 % of java submissions (48 MB)
# Submitting: java_solutions/761.special-binary-string.java
# - Downloading special-binary-string
#   ✔ Accepted
#   ✔ 87/87 cases passed (3 ms)
#   ✔ Your runtime beats 62.54 % of java submissions
#   ✔ Your memory usage beats 17.55 % of java submissions (43.5 MB)
# Submitting: java_solutions/765.couples-holding-hands.java
# - Downloading couples-holding-hands
#   ✔ Accepted
#   ✔ 56/56 cases passed (1 ms)
#   ✔ Your runtime beats 34.57 % of java submissions
#   ✔ Your memory usage beats 43.85 % of java submissions (43 MB)
# Submitting: java_solutions/766.toeplitz-matrix.java
# - Downloading toeplitz-matrix
#   ✔ Accepted
#   ✔ 483/483 cases passed (11 ms)
#   ✔ Your runtime beats 0.66 % of java submissions
#   ✔ Your memory usage beats 9.68 % of java submissions (46.7 MB)
# Submitting: java_solutions/768.max-chunks-to-make-sorted-ii.java
# - Downloading max-chunks-to-make-sorted-ii
#   ✔ Accepted
#   ✔ 139/139 cases passed (1 ms)
#   ✔ Your runtime beats 46.58 % of java submissions
#   ✔ Your memory usage beats 75.78 % of java submissions (46.2 MB)
# Submitting: java_solutions/769.max-chunks-to-make-sorted.java
# - Downloading max-chunks-to-make-sorted
#   ✔ Accepted
#   ✔ 53/53 cases passed (3 ms)
#   ✔ Your runtime beats 1.46 % of java submissions
#   ✔ Your memory usage beats 13.78 % of java submissions (43.1 MB)
# Submitting: java_solutions/770.basic-calculator-iv.java
# - Downloading basic-calculator-iv
#   ✔ Accepted
#   ✔ 158/158 cases passed (11 ms)
#   ✔ Your runtime beats 67.19 % of java submissions
#   ✔ Your memory usage beats 15.62 % of java submissions (50.1 MB)
# Submitting: java_solutions/771.jewels-and-stones.java
# - Downloading jewels-and-stones
#   ✔ Accepted
#   ✔ 255/255 cases passed (4 ms)
#   ✔ Your runtime beats 2.55 % of java submissions
#   ✔ Your memory usage beats 35.88 % of java submissions (43.3 MB)
# Submitting: java_solutions/773.sliding-puzzle.java
# - Downloading sliding-puzzle
#   ✔ Accepted
#   ✔ 32/32 cases passed (17 ms)
#   ✔ Your runtime beats 17.65 % of java submissions
#   ✔ Your memory usage beats 36.93 % of java submissions (45.6 MB)
# Submitting: java_solutions/778.swim-in-rising-water.java
# - Downloading swim-in-rising-water
#   ✔ Accepted
#   ✔ 43/43 cases passed (19 ms)
#   ✔ Your runtime beats 14.51 % of java submissions
#   ✔ Your memory usage beats 12 % of java submissions (46.7 MB)
# Submitting: java_solutions/780.reaching-points.java
# - Downloading reaching-points
#   ✔ Accepted
#   ✔ 197/197 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 66.95 % of java submissions (42.2 MB)
# Submitting: java_solutions/782.transform-to-chessboard.java
# - Downloading transform-to-chessboard
#   ✔ Accepted
#   ✔ 127/127 cases passed (3 ms)
#   ✔ Your runtime beats 1.63 % of java submissions
#   ✔ Your memory usage beats 39.84 % of java submissions (46.4 MB)
# Submitting: java_solutions/783.minimum-distance-between-bst-nodes.java
# - Downloading minimum-distance-between-bst-nodes
#   ✔ Accepted
#   ✔ 49/49 cases passed (16 ms)
#   ✔ Your runtime beats 1.96 % of java submissions
#   ✔ Your memory usage beats 12.78 % of java submissions (44.7 MB)
# Submitting: java_solutions/784.letter-case-permutation.java
# - Downloading letter-case-permutation
#   ✔ Accepted
#   ✔ 63/63 cases passed (15 ms)
#   ✔ Your runtime beats 5.37 % of java submissions
#   ✔ Your memory usage beats 20.85 % of java submissions (53 MB)
# Submitting: java_solutions/787.cheapest-flights-within-k-stops.java
# - Downloading cheapest-flights-within-k-stops
#   ✔ Accepted
#   ✔ 59/59 cases passed (175 ms)
#   ✔ Your runtime beats 5.07 % of java submissions
#   ✔ Your memory usage beats 5.27 % of java submissions (54.1 MB)
# Submitting: java_solutions/793.preimage-size-of-factorial-zeroes-function.java
# - Downloading preimage-size-of-factorial-zeroes-function
#   ✔ Accepted
#   ✔ 44/44 cases passed (1 ms)
#   ✔ Your runtime beats 5.7 % of java submissions
#   ✔ Your memory usage beats 52.53 % of java submissions (42 MB)
# Submitting: java_solutions/796.rotate-string.java
# - Downloading rotate-string
#   ✔ Accepted
#   ✔ 62/62 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 28.67 % of java submissions (43 MB)
# Submitting: java_solutions/798.smallest-rotation-with-highest-score.java
# - Downloading smallest-rotation-with-highest-score
#   ✔ Accepted
#   ✔ 44/44 cases passed (7 ms)
#   ✔ Your runtime beats 58.91 % of java submissions
#   ✔ Your memory usage beats 28.22 % of java submissions (77.3 MB)
# Submitting: java_solutions/801.minimum-swaps-to-make-sequences-increasing.java
# - Downloading minimum-swaps-to-make-sequences-increasing
#   ✔ Accepted
#   ✔ 117/117 cases passed (7 ms)
#   ✔ Your runtime beats 42.07 % of java submissions
#   ✔ Your memory usage beats 60.52 % of java submissions (93.7 MB)
# Submitting: java_solutions/803.bricks-falling-when-hit.java
# - Downloading bricks-falling-when-hit
#   ✔ Accepted
#   ✔ 40/40 cases passed (28 ms)
#   ✔ Your runtime beats 7.98 % of java submissions
#   ✔ Your memory usage beats 7.45 % of java submissions (91 MB)
# Submitting: java_solutions/804.unique-morse-code-words.java
# - Downloading unique-morse-code-words
#   ✔ Accepted
#   ✔ 82/82 cases passed (11 ms)
#   ✔ Your runtime beats 1.99 % of java submissions
#   ✔ Your memory usage beats 9.47 % of java submissions (45.9 MB)
# Submitting: java_solutions/805.split-array-with-same-average.java
# - Downloading split-array-with-same-average
#   ✔ Accepted
#   ✔ 111/111 cases passed (915 ms)
#   ✔ Your runtime beats 27.84 % of java submissions
#   ✔ Your memory usage beats 34.9 % of java submissions (273.8 MB)
# Submitting: java_solutions/806.number-of-lines-to-write-string.java
# - Downloading number-of-lines-to-write-string
#   ✔ Accepted
#   ✔ 27/27 cases passed (3 ms)
#   ✔ Your runtime beats 1.76 % of java submissions
#   ✔ Your memory usage beats 10.02 % of java submissions (43.7 MB)
# Submitting: java_solutions/807.max-increase-to-keep-city-skyline.java
# - Downloading max-increase-to-keep-city-skyline
#   ✔ Accepted
#   ✔ 133/133 cases passed (15 ms)
#   ✔ Your runtime beats 1.87 % of java submissions
#   ✔ Your memory usage beats 5.21 % of java submissions (47 MB)
# Submitting: java_solutions/810.chalkboard-xor-game.java
# - Downloading chalkboard-xor-game
#   ✔ Accepted
#   ✔ 168/168 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 33.01 % of java submissions (46.5 MB)
# Submitting: java_solutions/811.subdomain-visit-count.java
# - Downloading subdomain-visit-count
#   ✔ Accepted
#   ✔ 52/52 cases passed (45 ms)
#   ✔ Your runtime beats 5.25 % of java submissions
#   ✔ Your memory usage beats 6.38 % of java submissions (53.3 MB)
# Submitting: java_solutions/812.largest-triangle-area.java
# - Downloading largest-triangle-area
#   ✔ Accepted
#   ✔ 57/57 cases passed (20 ms)
#   ✔ Your runtime beats 5.54 % of java submissions
#   ✔ Your memory usage beats 9.59 % of java submissions (47.8 MB)
# Submitting: java_solutions/815.bus-routes.java
# - Downloading bus-routes
#   ✔ Accepted
#   ✔ 54/54 cases passed (413 ms)
#   ✔ Your runtime beats 36.35 % of java submissions
#   ✔ Your memory usage beats 5.02 % of java submissions (270.8 MB)
# Submitting: java_solutions/818.race-car.java
# - Downloading race-car
#   ✔ Accepted
#   ✔ 55/55 cases passed (9 ms)
#   ✔ Your runtime beats 67.64 % of java submissions
#   ✔ Your memory usage beats 75.27 % of java submissions (42.5 MB)
# Submitting: java_solutions/819.most-common-word.java
# - Downloading most-common-word
#   ✔ Accepted
#   ✔ 50/50 cases passed (28 ms)
#   ✔ Your runtime beats 5.31 % of java submissions
#   ✔ Your memory usage beats 5.06 % of java submissions (52.5 MB)
# Submitting: java_solutions/821.shortest-distance-to-a-character.java
# - Downloading shortest-distance-to-a-character
#   ✔ Accepted
#   ✔ 76/76 cases passed (176 ms)
#   ✔ Your runtime beats 7.35 % of java submissions
#   ✔ Your memory usage beats 5.66 % of java submissions (47.6 MB)
# Submitting: java_solutions/824.goat-latin.java
# - Downloading goat-latin
#   ✔ Accepted
#   ✔ 99/99 cases passed (16 ms)
#   ✔ Your runtime beats 8.19 % of java submissions
#   ✔ Your memory usage beats 5.52 % of java submissions (51.2 MB)
# Submitting: java_solutions/827.making-a-large-island.java
# - Downloading making-a-large-island
#   ✔ Accepted
#   ✔ 75/75 cases passed (91 ms)
#   ✔ Your runtime beats 64.79 % of java submissions
#   ✔ Your memory usage beats 13.24 % of java submissions (169.2 MB)
# Submitting: java_solutions/828.count-unique-characters-of-all-substrings-of-a-given-string.java
# - Downloading count-unique-characters-of-all-substrings-of-a-given-string
#   ✔ Accepted
#   ✔ 76/76 cases passed (19 ms)
#   ✔ Your runtime beats 40.16 % of java submissions
#   ✔ Your memory usage beats 43.37 % of java submissions (47.3 MB)
# Submitting: java_solutions/829.consecutive-numbers-sum.java
# - Downloading consecutive-numbers-sum
#   ✔ Accepted
#   ✔ 170/170 cases passed (5 ms)
#   ✔ Your runtime beats 20 % of java submissions
#   ✔ Your memory usage beats 58.95 % of java submissions (42.2 MB)
# Submitting: java_solutions/830.positions-of-large-groups.java
# - Downloading positions-of-large-groups
#   ✔ Accepted
#   ✔ 202/202 cases passed (11 ms)
#   ✔ Your runtime beats 2.89 % of java submissions
#   ✔ Your memory usage beats 5.42 % of java submissions (47.1 MB)
# Submitting: java_solutions/832.flipping-an-image.java
# - Downloading flipping-an-image
#   ✔ Accepted
#   ✔ 82/82 cases passed (6 ms)
#   ✔ Your runtime beats 0.52 % of java submissions
#   ✔ Your memory usage beats 5.2 % of java submissions (46.8 MB)
# Submitting: java_solutions/833.find-and-replace-in-string.java
# - Downloading find-and-replace-in-string
#   ✔ Accepted
#   ✔ 59/59 cases passed (7 ms)
#   ✔ Your runtime beats 6.72 % of java submissions
#   ✔ Your memory usage beats 16.54 % of java submissions (44.2 MB)
# Submitting: java_solutions/834.sum-of-distances-in-tree.java
# - Downloading sum-of-distances-in-tree
#   ✔ Accepted
#   ✔ 74/74 cases passed (23 ms)
#   ✔ Your runtime beats 98.59 % of java submissions
#   ✔ Your memory usage beats 98.97 % of java submissions (88.3 MB)
# Submitting: java_solutions/836.rectangle-overlap.java
# - Downloading rectangle-overlap
#   ✔ Accepted
#   ✔ 41/41 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 12.97 % of java submissions (42.9 MB)
# Submitting: java_solutions/839.similar-string-groups.java
# - Downloading similar-string-groups
#   ✔ Accepted
#   ✔ 77/77 cases passed (20 ms)
#   ✔ Your runtime beats 48.97 % of java submissions
#   ✔ Your memory usage beats 19.35 % of java submissions (45.2 MB)
# Submitting: java_solutions/843.guess-the-word.java
# - Downloading guess-the-word
#   ✔ Accepted
#   ✔ 13/13 cases passed (12 ms)
#   ✔ Your runtime beats 26.49 % of java submissions
#   ✔ Your memory usage beats 18.11 % of java submissions (43.4 MB)
# Submitting: java_solutions/844.backspace-string-compare.java
# - Downloading backspace-string-compare
#   ✔ Accepted
#   ✔ 115/115 cases passed (9 ms)
#   ✔ Your runtime beats 4.08 % of java submissions
#   ✔ Your memory usage beats 10.49 % of java submissions (43.5 MB)
# Submitting: java_solutions/847.shortest-path-visiting-all-nodes.java
# - Downloading shortest-path-visiting-all-nodes
#   ✔ Accepted
#   ✔ 55/55 cases passed (82 ms)
#   ✔ Your runtime beats 7.98 % of java submissions
#   ✔ Your memory usage beats 7.44 % of java submissions (53.8 MB)
# Submitting: java_solutions/850.rectangle-area-ii.java
# - Downloading rectangle-area-ii
#   ✔ Accepted
#   ✔ 78/78 cases passed (50 ms)
#   ✔ Your runtime beats 10.45 % of java submissions
#   ✔ Your memory usage beats 35.82 % of java submissions (45.7 MB)
# Submitting: java_solutions/853.car-fleet.java
# - Downloading car-fleet
#   ✔ Accepted
#   ✔ 49/49 cases passed (176 ms)
#   ✔ Your runtime beats 5.15 % of java submissions
#   ✔ Your memory usage beats 9.15 % of java submissions (114.2 MB)

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-05-04 17:37:27
