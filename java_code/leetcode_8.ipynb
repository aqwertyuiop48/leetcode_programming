# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME_2')
    user_cookie = userdata.get('LEETCODE_TOKEN_2')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME_2'] = user_name
    os.environ['LEETCODE_TOKEN_2'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME_2" "$LEETCODE_TOKEN_2" | leetcode user -c

# %%
# %%bash
#
#
# # top 100 answers
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v java_solutions/*.java | sed -n '701,800p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 7
# done
# Out:
# Submitting: java_solutions/1957.delete-characters-to-make-fancy-string.java
# - Downloading delete-characters-to-make-fancy-string
#   ✔ Accepted
#   ✔ 306/306 cases passed (119 ms)
#   ✔ Your runtime beats 12.17 % of java submissions
#   ✔ Your memory usage beats 8.35 % of java submissions (48.5 MB)
# Submitting: java_solutions/1960.maximum-product-of-the-length-of-two-palindromic-substrings.java
# - Downloading maximum-product-of-the-length-of-two-palindromic-substrings
#   ✔ Accepted
#   ✔ 67/67 cases passed (463 ms)
#   ✔ Your runtime beats 6.15 % of java submissions
#   ✔ Your memory usage beats 6.15 % of java submissions (64 MB)
# Submitting: java_solutions/1961.check-if-string-is-a-prefix-of-array.java
# - Downloading check-if-string-is-a-prefix-of-array
#   ✔ Accepted
#   ✔ 349/349 cases passed (9 ms)
#   ✔ Your runtime beats 1.82 % of java submissions
#   ✔ Your memory usage beats 9.37 % of java submissions (45.4 MB)
# Submitting: java_solutions/1964.find-the-longest-valid-obstacle-course-at-each-position.java
# - Downloading find-the-longest-valid-obstacle-course-at-each-position
#   ✔ Accepted
#   ✔ 78/78 cases passed (691 ms)
#   ✔ Your runtime beats 5.29 % of java submissions
#   ✔ Your memory usage beats 99.52 % of java submissions (117 MB)
# Submitting: java_solutions/1967.number-of-strings-that-appear-as-substrings-in-word.java
# - Downloading number-of-strings-that-appear-as-substrings-in-word
#   ✔ Accepted
#   ✔ 82/82 cases passed (2 ms)
#   ✔ Your runtime beats 7.42 % of java submissions
#   ✔ Your memory usage beats 63.73 % of java submissions (43.3 MB)
# Submitting: java_solutions/1970.last-day-where-you-can-still-cross.java
# - Downloading last-day-where-you-can-still-cross
#   ✔ Accepted
#   ✔ 118/118 cases passed (123 ms)
#   ✔ Your runtime beats 10.56 % of java submissions
#   ✔ Your memory usage beats 5.28 % of java submissions (94.6 MB)
# Submitting: java_solutions/1974.minimum-time-to-type-word-using-special-typewriter.java
# - Downloading minimum-time-to-type-word-using-special-typewriter
#   ✔ Accepted
#   ✔ 135/135 cases passed (5 ms)
#   ✔ Your runtime beats 2.25 % of java submissions
#   ✔ Your memory usage beats 31.01 % of java submissions (43 MB)
# Submitting: java_solutions/1977.number-of-ways-to-separate-numbers.java
# - Downloading number-of-ways-to-separate-numbers
# [ERROR] Error: read ECONNRESET
# Submitting: java_solutions/1979.find-greatest-common-divisor-of-array.java
# - Downloading find-greatest-common-divisor-of-array
#   ✔ Accepted
#   ✔ 215/215 cases passed (6 ms)
#   ✔ Your runtime beats 21.48 % of java submissions
#   ✔ Your memory usage beats 9.68 % of java submissions (45.7 MB)
# Submitting: java_solutions/1982.find-array-given-subset-sums.java
# - Downloading find-array-given-subset-sums
#   ✔ Accepted
#   ✔ 131/131 cases passed (303 ms)
#   ✔ Your runtime beats 10.75 % of java submissions
#   ✔ Your memory usage beats 37.63 % of java submissions (68.6 MB)
# Submitting: java_solutions/1984.minimum-difference-between-highest-and-lowest-of-k-scores.java
# - Downloading minimum-difference-between-highest-and-lowest-of-k-scores
#   ✔ Accepted
#   ✔ 118/118 cases passed (1288 ms)
#   ✔ Your runtime beats 5.02 % of java submissions
#   ✔ Your memory usage beats 8.22 % of java submissions (47.6 MB)
# Submitting: java_solutions/1987.number-of-unique-good-subsequences.java
# - Downloading number-of-unique-good-subsequences
#   ✔ Accepted
#   ✔ 69/69 cases passed (12 ms)
#   ✔ Your runtime beats 17.24 % of java submissions
#   ✔ Your memory usage beats 33.33 % of java submissions (47.9 MB)
# Submitting: java_solutions/1991.find-the-middle-index-in-array.java
# - Downloading find-the-middle-index-in-array
#   ✔ Accepted
#   ✔ 294/294 cases passed (15 ms)
#   ✔ Your runtime beats 0.83 % of java submissions
#   ✔ Your memory usage beats 11.76 % of java submissions (46.4 MB)
# Submitting: java_solutions/1994.the-number-of-good-subsets.java
# - Downloading the-number-of-good-subsets
#   ✔ Accepted
#   ✔ 92/92 cases passed (84 ms)
#   ✔ Your runtime beats 7.14 % of java submissions
#   ✔ Your memory usage beats 5.55 % of java submissions (166.1 MB)
# Submitting: java_solutions/1998.gcd-sort-of-an-array.java
# - Downloading gcd-sort-of-an-array
#   ✔ Accepted
#   ✔ 92/92 cases passed (681 ms)
#   ✔ Your runtime beats 5.28 % of java submissions
#   ✔ Your memory usage beats 18.32 % of java submissions (69.8 MB)
# Submitting: java_solutions/2000.reverse-prefix-of-word.java
# - Downloading reverse-prefix-of-word
#   ✔ Accepted
#   ✔ 113/113 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 97.09 % of java submissions (42.6 MB)
# Submitting: java_solutions/2003.smallest-missing-genetic-value-in-each-subtree.java
# - Downloading smallest-missing-genetic-value-in-each-subtree
#   ✔ Accepted
#   ✔ 68/68 cases passed (199 ms)
#   ✔ Your runtime beats 6.67 % of java submissions
#   ✔ Your memory usage beats 100 % of java submissions (114.8 MB)
# Submitting: java_solutions/2006.count-number-of-pairs-with-absolute-difference-k.java
# - Downloading count-number-of-pairs-with-absolute-difference-k
#   ✔ Accepted
#   ✔ 237/237 cases passed (36 ms)
#   ✔ Your runtime beats 6.4 % of java submissions
#   ✔ Your memory usage beats 8.63 % of java submissions (47 MB)
# Submitting: java_solutions/2009.minimum-number-of-operations-to-make-array-continuous.java
# - Downloading minimum-number-of-operations-to-make-array-continuous
#   ✔ Accepted
#   ✔ 62/62 cases passed (94 ms)
#   ✔ Your runtime beats 25 % of java submissions
#   ✔ Your memory usage beats 64.04 % of java submissions (90.7 MB)
# Submitting: java_solutions/2011.final-value-of-variable-after-performing-operations.java
# - Downloading final-value-of-variable-after-performing-operations
#   ✔ Accepted
#   ✔ 259/259 cases passed (4 ms)
#   ✔ Your runtime beats 1.5 % of java submissions
#   ✔ Your memory usage beats 36.29 % of java submissions (44.5 MB)
# Submitting: java_solutions/2014.longest-subsequence-repeated-k-times.java
# - Downloading longest-subsequence-repeated-k-times
#   ✔ Accepted
#   ✔ 314/314 cases passed (1605 ms)
#   ✔ Your runtime beats 5.22 % of java submissions
#   ✔ Your memory usage beats 6.09 % of java submissions (53.5 MB)
# Submitting: java_solutions/2016.maximum-difference-between-increasing-elements.java
# - Downloading maximum-difference-between-increasing-elements
#   ✔ Accepted
#   ✔ 54/54 cases passed (46 ms)
#   ✔ Your runtime beats 23.13 % of java submissions
#   ✔ Your memory usage beats 12.01 % of java submissions (46.4 MB)
# Submitting: java_solutions/2019.the-score-of-students-solving-math-expression.java
# - Downloading the-score-of-students-solving-math-expression
#   ✔ Accepted
#   ✔ 274/274 cases passed (964 ms)
#   ✔ Your runtime beats 5.95 % of java submissions
#   ✔ Your memory usage beats 5.95 % of java submissions (66 MB)
# Submitting: java_solutions/2022.convert-1d-array-into-2d-array.java
# - Downloading convert-1d-array-into-2d-array
#   ✔ Accepted
#   ✔ 107/107 cases passed (7 ms)
#   ✔ Your runtime beats 1.07 % of java submissions
#   ✔ Your memory usage beats 48.31 % of java submissions (67 MB)
# Submitting: java_solutions/2025.maximum-number-of-ways-to-partition-an-array.java
# - Downloading maximum-number-of-ways-to-partition-an-array
#   ✔ Accepted
#   ✔ 179/179 cases passed (325 ms)
#   ✔ Your runtime beats 5.33 % of java submissions
#   ✔ Your memory usage beats 5.33 % of java submissions (198.1 MB)
# Submitting: java_solutions/2027.minimum-moves-to-convert-string.java
# - Downloading minimum-moves-to-convert-string
#   ✔ Accepted
#   ✔ 55/55 cases passed (6 ms)
#   ✔ Your runtime beats 0.92 % of java submissions
#   ✔ Your memory usage beats 15.24 % of java submissions (43.1 MB)
# Submitting: java_solutions/2030.smallest-k-length-subsequence-with-occurrences-of-a-letter.java
# - Downloading smallest-k-length-subsequence-with-occurrences-of-a-letter
#   ✔ Accepted
#   ✔ 152/152 cases passed (546 ms)
#   ✔ Your runtime beats 13.21 % of java submissions
#   ✔ Your memory usage beats 5.66 % of java submissions (53.5 MB)
# Submitting: java_solutions/2032.two-out-of-three.java
# - Downloading two-out-of-three
#   ✔ Accepted
#   ✔ 288/288 cases passed (28 ms)
#   ✔ Your runtime beats 5.6 % of java submissions
#   ✔ Your memory usage beats 7.82 % of java submissions (53.2 MB)
# Submitting: java_solutions/2035.partition-array-into-two-arrays-to-minimize-sum-difference.java
# - Downloading partition-array-into-two-arrays-to-minimize-sum-difference
#   ✔ Accepted
#   ✔ 201/201 cases passed (2511 ms)
#   ✔ Your runtime beats 5.06 % of java submissions
#   ✔ Your memory usage beats 5.06 % of java submissions (224.9 MB)
# Submitting: java_solutions/2040.kth-smallest-product-of-two-sorted-arrays.java
# - Downloading kth-smallest-product-of-two-sorted-arrays
#   ✔ Accepted
#   ✔ 112/112 cases passed (1264 ms)
#   ✔ Your runtime beats 5.17 % of java submissions
#   ✔ Your memory usage beats 32.76 % of java submissions (62.9 MB)
# Submitting: java_solutions/2042.check-if-numbers-are-ascending-in-a-sentence.java
# - Downloading check-if-numbers-are-ascending-in-a-sentence
#   ✔ Accepted
#   ✔ 98/98 cases passed (11 ms)
#   ✔ Your runtime beats 5.93 % of java submissions
#   ✔ Your memory usage beats 16.49 % of java submissions (44 MB)
# Submitting: java_solutions/2045.second-minimum-time-to-reach-destination.java
# - Downloading second-minimum-time-to-reach-destination
#   ✔ Accepted
#   ✔ 77/77 cases passed (436 ms)
#   ✔ Your runtime beats 5 % of java submissions
#   ✔ Your memory usage beats 5 % of java submissions (155.2 MB)
# Submitting: java_solutions/2047.number-of-valid-words-in-a-sentence.java
# - Downloading number-of-valid-words-in-a-sentence
#   ✔ Accepted
#   ✔ 244/244 cases passed (44 ms)
#   ✔ Your runtime beats 7.11 % of java submissions
#   ✔ Your memory usage beats 12.55 % of java submissions (47.5 MB)
# Submitting: java_solutions/2050.parallel-courses-iii.java
# - Downloading parallel-courses-iii
#   ✔ Accepted
#   ✔ 42/42 cases passed (82 ms)
#   ✔ Your runtime beats 5.01 % of java submissions
#   ✔ Your memory usage beats 99.74 % of java submissions (106 MB)
# Submitting: java_solutions/2053.kth-distinct-string-in-an-array.java
# - Downloading kth-distinct-string-in-an-array
#   ✔ Accepted
#   ✔ 66/66 cases passed (21 ms)
#   ✔ Your runtime beats 11.34 % of java submissions
#   ✔ Your memory usage beats 6.72 % of java submissions (52.6 MB)
# Submitting: java_solutions/2056.number-of-valid-move-combinations-on-chessboard.java
# - Downloading number-of-valid-move-combinations-on-chessboard
#   ✔ Accepted
#   ✔ 273/273 cases passed (1650 ms)
#   ✔ Your runtime beats 5.13 % of java submissions
#   ✔ Your memory usage beats 10.26 % of java submissions (53.7 MB)
# Submitting: java_solutions/2057.smallest-index-with-equal-value.java
# - Downloading smallest-index-with-equal-value
#   ✔ Accepted
#   ✔ 663/663 cases passed (6 ms)
#   ✔ Your runtime beats 0.12 % of java submissions
#   ✔ Your memory usage beats 13.08 % of java submissions (46.8 MB)
# Submitting: java_solutions/2060.check-if-an-original-string-exists-given-two-encoded-strings.java
# - Downloading check-if-an-original-string-exists-given-two-encoded-strings
#   ✔ Accepted
#   ✔ 215/215 cases passed (856 ms)
#   ✔ Your runtime beats 5.94 % of java submissions
#   ✔ Your memory usage beats 19.8 % of java submissions (280.5 MB)
# Submitting: java_solutions/2065.maximum-path-quality-of-a-graph.java
# - Downloading maximum-path-quality-of-a-graph
#   ✔ Accepted
#   ✔ 62/62 cases passed (583 ms)
#   ✔ Your runtime beats 5.33 % of java submissions
#   ✔ Your memory usage beats 5.07 % of java submissions (53.6 MB)
# Submitting: java_solutions/2068.check-whether-two-strings-are-almost-equivalent.java
# - Downloading check-whether-two-strings-are-almost-equivalent
#   ✔ Accepted
#   ✔ 196/196 cases passed (9 ms)
#   ✔ Your runtime beats 2.19 % of java submissions
#   ✔ Your memory usage beats 5.54 % of java submissions (44.6 MB)
# Submitting: java_solutions/2071.maximum-number-of-tasks-you-can-assign.java
# - Downloading maximum-number-of-tasks-you-can-assign
#   ✔ Accepted
#   ✔ 49/49 cases passed (559 ms)
#   ✔ Your runtime beats 34.78 % of java submissions
#   ✔ Your memory usage beats 36.41 % of java submissions (70.6 MB)
# Submitting: java_solutions/2076.process-restricted-friend-requests.java
# - Downloading process-restricted-friend-requests
#   ✔ Accepted
#   ✔ 49/49 cases passed (1042 ms)
#   ✔ Your runtime beats 5.28 % of java submissions
#   ✔ Your memory usage beats 6.52 % of java submissions (53.5 MB)
# Submitting: java_solutions/2078.two-furthest-houses-with-different-colors.java
# - Downloading two-furthest-houses-with-different-colors
#   ✔ Accepted
#   ✔ 126/126 cases passed (12 ms)
#   ✔ Your runtime beats 1.47 % of java submissions
#   ✔ Your memory usage beats 12.07 % of java submissions (45.4 MB)
# Submitting: java_solutions/2081.sum-of-k-mirror-numbers.java
# - Downloading sum-of-k-mirror-numbers
#   ✔ Accepted
#   ✔ 97/97 cases passed (914 ms)
#   ✔ Your runtime beats 6.25 % of java submissions
#   ✔ Your memory usage beats 5.47 % of java submissions (53.1 MB)
# Submitting: java_solutions/2085.count-common-words-with-one-occurrence.java
# - Downloading count-common-words-with-one-occurrence
#   ✔ Accepted
#   ✔ 61/61 cases passed (457 ms)
#   ✔ Your runtime beats 5 % of java submissions
#   ✔ Your memory usage beats 5.53 % of java submissions (53.3 MB)
# Submitting: java_solutions/2088.count-fertile-pyramids-in-a-land.java
# - Downloading count-fertile-pyramids-in-a-land
#   ✔ Accepted
#   ✔ 49/49 cases passed (30 ms)
#   ✔ Your runtime beats 7.69 % of java submissions
#   ✔ Your memory usage beats 8.46 % of java submissions (74.6 MB)
# Submitting: java_solutions/2089.find-target-indices-after-sorting-array.java
# - Downloading find-target-indices-after-sorting-array
#   ✔ Accepted
#   ✔ 216/216 cases passed (8 ms)
#   ✔ Your runtime beats 27.68 % of java submissions
#   ✔ Your memory usage beats 55.56 % of java submissions (45.5 MB)
# Submitting: java_solutions/2092.find-all-people-with-secret.java
# - Downloading find-all-people-with-secret
#   ✔ Accepted
#   ✔ 63/63 cases passed (235 ms)
#   ✔ Your runtime beats 15.28 % of java submissions
#   ✔ Your memory usage beats 72.66 % of java submissions (268.2 MB)
# Submitting: java_solutions/2097.valid-arrangement-of-pairs.java
# - Downloading valid-arrangement-of-pairs
#   ✔ Accepted
#   ✔ 41/41 cases passed (155 ms)
#   ✔ Your runtime beats 81.25 % of java submissions
#   ✔ Your memory usage beats 51.63 % of java submissions (278.3 MB)
# Submitting: java_solutions/2099.find-subsequence-of-length-k-with-the-largest-sum.java
# - Downloading find-subsequence-of-length-k-with-the-largest-sum
#   ✔ Accepted
#   ✔ 49/49 cases passed (16 ms)
#   ✔ Your runtime beats 5.67 % of java submissions
#   ✔ Your memory usage beats 80.47 % of java submissions (45.9 MB)
# Submitting: java_solutions/2102.sequentially-ordinal-rank-tracker.java
# - Downloading sequentially-ordinal-rank-tracker
#   ✔ Accepted
#   ✔ 81/81 cases passed (228 ms)
#   ✔ Your runtime beats 12.33 % of java submissions
#   ✔ Your memory usage beats 100 % of java submissions (96.4 MB)
# Submitting: java_solutions/2106.maximum-fruits-harvested-after-at-most-k-steps.java
# - Downloading maximum-fruits-harvested-after-at-most-k-steps
#   ✔ Accepted
#   ✔ 202/202 cases passed (80 ms)
#   ✔ Your runtime beats 19.82 % of java submissions
#   ✔ Your memory usage beats 5.41 % of java submissions (142.5 MB)
# Submitting: java_solutions/2108.find-first-palindromic-string-in-the-array.java
# - Downloading find-first-palindromic-string-in-the-array
#   ✔ Accepted
#   ✔ 266/266 cases passed (14 ms)
#   ✔ Your runtime beats 8.17 % of java submissions
#   ✔ Your memory usage beats 5.43 % of java submissions (48.1 MB)
# Submitting: java_solutions/2111.minimum-operations-to-make-the-array-k-increasing.java
# - Downloading minimum-operations-to-make-the-array-k-increasing
#   ✔ Accepted
#   ✔ 90/90 cases passed (1537 ms)
#   ✔ Your runtime beats 5.46 % of java submissions
#   ✔ Your memory usage beats 8.74 % of java submissions (107.7 MB)
# Submitting: java_solutions/2114.maximum-number-of-words-found-in-sentences.java
# - Downloading maximum-number-of-words-found-in-sentences
#   ✔ Accepted
#   ✔ 90/90 cases passed (7 ms)
#   ✔ Your runtime beats 6.89 % of java submissions
#   ✔ Your memory usage beats 8.92 % of java submissions (46.6 MB)
# Submitting: java_solutions/2117.abbreviating-the-product-of-a-range.java
# - Downloading abbreviating-the-product-of-a-range
#   ✔ Accepted
#   ✔ 292/292 cases passed (475 ms)
#   ✔ Your runtime beats 5.26 % of java submissions
#   ✔ Your memory usage beats 5.26 % of java submissions (53.4 MB)
# Submitting: java_solutions/2119.a-number-after-a-double-reversal.java
# - Downloading a-number-after-a-double-reversal
#   ✔ Accepted
#   ✔ 129/129 cases passed (1 ms)
#   ✔ Your runtime beats 3.49 % of java submissions
#   ✔ Your memory usage beats 54.09 % of java submissions (42.2 MB)
# Submitting: java_solutions/2122.recover-the-original-array.java
# - Downloading recover-the-original-array
#   ✔ Accepted
#   ✔ 110/110 cases passed (150 ms)
#   ✔ Your runtime beats 41.62 % of java submissions
#   ✔ Your memory usage beats 7.45 % of java submissions (53.6 MB)
# Submitting: java_solutions/2124.check-if-all-as-appears-before-all-bs.java
# - Downloading check-if-all-as-appears-before-all-bs
#   ✔ Accepted
#   ✔ 216/216 cases passed (1 ms)
#   ✔ Your runtime beats 17.04 % of java submissions
#   ✔ Your memory usage beats 49.85 % of java submissions (43 MB)
# Submitting: java_solutions/2127.maximum-employees-to-be-invited-to-a-meeting.java
# - Downloading maximum-employees-to-be-invited-to-a-meeting
#   ✔ Accepted
#   ✔ 99/99 cases passed (87 ms)
#   ✔ Your runtime beats 10.04 % of java submissions
#   ✔ Your memory usage beats 28.11 % of java submissions (90.7 MB)
# Submitting: java_solutions/2129.capitalize-the-title.java
# - Downloading capitalize-the-title
#   ✔ Accepted
#   ✔ 200/200 cases passed (8 ms)
#   ✔ Your runtime beats 14.66 % of java submissions
#   ✔ Your memory usage beats 59.32 % of java submissions (43.9 MB)
# Submitting: java_solutions/2132.stamping-the-grid.java
# - Downloading stamping-the-grid
#   ✔ Accepted
#   ✔ 77/77 cases passed (201 ms)
#   ✔ Your runtime beats 5.26 % of java submissions
#   ✔ Your memory usage beats 31.58 % of java submissions (226.9 MB)
# Submitting: java_solutions/2133.check-if-every-row-and-column-contains-all-numbers.java
# - Downloading check-if-every-row-and-column-contains-all-numbers
#   ✔ Accepted
#   ✔ 227/227 cases passed (43 ms)
#   ✔ Your runtime beats 8.79 % of java submissions
#   ✔ Your memory usage beats 21.36 % of java submissions (48.3 MB)
# Submitting: java_solutions/2136.earliest-possible-day-of-full-bloom.java
# - Downloading earliest-possible-day-of-full-bloom
#   ✔ Accepted
#   ✔ 185/185 cases passed (45 ms)
#   ✔ Your runtime beats 85.39 % of java submissions
#   ✔ Your memory usage beats 98.63 % of java submissions (111.9 MB)
# Submitting: java_solutions/2138.divide-a-string-into-groups-of-size-k.java
# - Downloading divide-a-string-into-groups-of-size-k
#   ✔ Accepted
#   ✔ 157/157 cases passed (5 ms)
#   ✔ Your runtime beats 7.26 % of java submissions
#   ✔ Your memory usage beats 17.88 % of java submissions (44.1 MB)
# Submitting: java_solutions/2141.maximum-running-time-of-n-computers.java
# - Downloading maximum-running-time-of-n-computers
#   ✔ Accepted
#   ✔ 52/52 cases passed (187 ms)
#   ✔ Your runtime beats 5.05 % of java submissions
#   ✔ Your memory usage beats 5.29 % of java submissions (79.3 MB)
# Submitting: java_solutions/2147.number-of-ways-to-divide-a-long-corridor.java
# - Downloading number-of-ways-to-divide-a-long-corridor
#   ✔ Accepted
#   ✔ 248/248 cases passed (74 ms)
#   ✔ Your runtime beats 16.83 % of java submissions
#   ✔ Your memory usage beats 46.63 % of java submissions (48.1 MB)
# Submitting: java_solutions/2148.count-elements-with-strictly-smaller-and-greater-elements.java
# - Downloading count-elements-with-strictly-smaller-and-greater-elements
#   ✔ Accepted
#   ✔ 127/127 cases passed (21 ms)
#   ✔ Your runtime beats 23.86 % of java submissions
#   ✔ Your memory usage beats 5.34 % of java submissions (46.7 MB)
# Submitting: java_solutions/2149.rearrange-array-elements-by-sign.java
# - Downloading rearrange-array-elements-by-sign
#   ✔ Accepted
#   ✔ 133/133 cases passed (51 ms)
#   ✔ Your runtime beats 7.47 % of java submissions
#   ✔ Your memory usage beats 5.08 % of java submissions (182.8 MB)
# Submitting: java_solutions/2151.maximum-good-people-based-on-statements.java
# - Downloading maximum-good-people-based-on-statements
#   ✔ Accepted
#   ✔ 91/91 cases passed (646 ms)
#   ✔ Your runtime beats 5.55 % of java submissions
#   ✔ Your memory usage beats 5.56 % of java submissions (47.3 MB)
# Submitting: java_solutions/2154.keep-multiplying-found-values-by-two.java
# - Downloading keep-multiplying-found-values-by-two
#   ✔ Accepted
#   ✔ 82/82 cases passed (9 ms)
#   ✔ Your runtime beats 5.89 % of java submissions
#   ✔ Your memory usage beats 31.52 % of java submissions (46.5 MB)
# Submitting: java_solutions/2156.find-substring-with-given-hash-value.java
# - Downloading find-substring-with-given-hash-value
#   ✔ Accepted
#   ✔ 90/90 cases passed (23 ms)
#   ✔ Your runtime beats 25 % of java submissions
#   ✔ Your memory usage beats 5.56 % of java submissions (52.6 MB)
# Submitting: java_solutions/2157.groups-of-strings.java
# - Downloading groups-of-strings
#   ✔ Accepted
#   ✔ 97/97 cases passed (691 ms)
#   ✔ Your runtime beats 48 % of java submissions
#   ✔ Your memory usage beats 5 % of java submissions (278.4 MB)
# Submitting: java_solutions/2160.minimum-sum-of-four-digit-number-after-splitting-digits.java
# - Downloading minimum-sum-of-four-digit-number-after-splitting-digits
#   ✔ Accepted
#   ✔ 99/99 cases passed (8 ms)
#   ✔ Your runtime beats 2.27 % of java submissions
#   ✔ Your memory usage beats 7.66 % of java submissions (42.6 MB)
# Submitting: java_solutions/2163.minimum-difference-in-sums-after-removal-of-elements.java
# - Downloading minimum-difference-in-sums-after-removal-of-elements
#   ✔ Accepted
#   ✔ 110/110 cases passed (559 ms)
#   ✔ Your runtime beats 5.29 % of java submissions
#   ✔ Your memory usage beats 59.26 % of java submissions (166.4 MB)
# Submitting: java_solutions/2164.sort-even-and-odd-indices-independently.java
# - Downloading sort-even-and-odd-indices-independently
#   ✔ Accepted
#   ✔ 218/218 cases passed (21 ms)
#   ✔ Your runtime beats 18.2 % of java submissions
#   ✔ Your memory usage beats 5.73 % of java submissions (52.8 MB)
# Submitting: java_solutions/2167.minimum-time-to-remove-all-cars-containing-illegal-goods.java
# - Downloading minimum-time-to-remove-all-cars-containing-illegal-goods
#   ✔ Accepted
#   ✔ 89/89 cases passed (34 ms)
#   ✔ Your runtime beats 62.71 % of java submissions
#   ✔ Your memory usage beats 76.27 % of java submissions (48.5 MB)
# Submitting: java_solutions/2169.count-operations-to-obtain-zero.java
# - Downloading count-operations-to-obtain-zero
#   ✔ Accepted
#   ✔ 161/161 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 53.07 % of java submissions (42.3 MB)
# Submitting: java_solutions/2172.maximum-and-sum-of-array.java
# - Downloading maximum-and-sum-of-array
#   ✔ Accepted
#   ✔ 84/84 cases passed (178 ms)
#   ✔ Your runtime beats 31.33 % of java submissions
#   ✔ Your memory usage beats 32.53 % of java submissions (53.1 MB)
# Submitting: java_solutions/2176.count-equal-and-divisible-pairs-in-an-array.java
# - Downloading count-equal-and-divisible-pairs-in-an-array
#   ✔ Accepted
#   ✔ 238/238 cases passed (20 ms)
#   ✔ Your runtime beats 2.45 % of java submissions
#   ✔ Your memory usage beats 5.14 % of java submissions (46.7 MB)
# Submitting: java_solutions/2179.count-good-triplets-in-an-array.java
# - Downloading count-good-triplets-in-an-array
#   ✔ Accepted
#   ✔ 148/148 cases passed (235 ms)
#   ✔ Your runtime beats 6.77 % of java submissions
#   ✔ Your memory usage beats 45.82 % of java submissions (94.3 MB)
# Submitting: java_solutions/2180.count-integers-with-even-digit-sum.java
# - Downloading count-integers-with-even-digit-sum
#   ✔ Accepted
#   ✔ 71/71 cases passed (12 ms)
#   ✔ Your runtime beats 1.91 % of java submissions
#   ✔ Your memory usage beats 11.55 % of java submissions (46.3 MB)
# Submitting: java_solutions/2183.count-array-pairs-divisible-by-k.java
# - Downloading count-array-pairs-divisible-by-k
#   ✔ Accepted
#   ✔ 115/115 cases passed (52 ms)
#   ✔ Your runtime beats 93.49 % of java submissions
#   ✔ Your memory usage beats 88.7 % of java submissions (77 MB)
# Submitting: java_solutions/2185.counting-words-with-a-given-prefix.java
# - Downloading counting-words-with-a-given-prefix
#   ✔ Accepted
#   ✔ 95/95 cases passed (2 ms)
#   ✔ Your runtime beats 17.07 % of java submissions
#   ✔ Your memory usage beats 82.46 % of java submissions (44.2 MB)
# Submitting: java_solutions/2188.minimum-time-to-finish-the-race.java
# - Downloading minimum-time-to-finish-the-race
#   ✔ Accepted
#   ✔ 58/58 cases passed (179 ms)
#   ✔ Your runtime beats 10 % of java submissions
#   ✔ Your memory usage beats 92.22 % of java submissions (173.4 MB)
# Submitting: java_solutions/2193.minimum-number-of-moves-to-make-palindrome.java
# - Downloading minimum-number-of-moves-to-make-palindrome
#   ✔ Accepted
#   ✔ 129/129 cases passed (242 ms)
#   ✔ Your runtime beats 5.16 % of java submissions
#   ✔ Your memory usage beats 5.16 % of java submissions (52.9 MB)
# Submitting: java_solutions/2194.cells-in-a-range-on-an-excel-sheet.java
# - Downloading cells-in-a-range-on-an-excel-sheet
# [ERROR] session expired, please login again [code=-1]
# Submitting: java_solutions/2197.replace-non-coprime-numbers-in-array.java
# - Downloading replace-non-coprime-numbers-in-array
#   ✔ Accepted
#   ✔ 73/73 cases passed (253 ms)
#   ✔ Your runtime beats 5.28 % of java submissions
#   ✔ Your memory usage beats 100 % of java submissions (114.8 MB)
# Submitting: java_solutions/2203.minimum-weighted-subgraph-with-the-required-paths.java
# - Downloading minimum-weighted-subgraph-with-the-required-paths
#   ✔ Accepted
#   ✔ 88/88 cases passed (465 ms)
#   ✔ Your runtime beats 5.28 % of java submissions
#   ✔ Your memory usage beats 74.53 % of java submissions (216.6 MB)
# Submitting: java_solutions/2206.divide-array-into-equal-pairs.java
# - Downloading divide-array-into-equal-pairs
#   ✔ Accepted
#   ✔ 137/137 cases passed (23 ms)
#   ✔ Your runtime beats 5.78 % of java submissions
#   ✔ Your memory usage beats 6.94 % of java submissions (53.1 MB)
# Submitting: java_solutions/2209.minimum-white-tiles-after-covering-with-carpets.java
# - Downloading minimum-white-tiles-after-covering-with-carpets
#   ✔ Accepted
#   ✔ 2706/2706 cases passed (475 ms)
#   ✔ Your runtime beats 5.55 % of java submissions
#   ✔ Your memory usage beats 7.41 % of java submissions (58.8 MB)
# Submitting: java_solutions/2210.count-hills-and-valleys-in-an-array.java
# - Downloading count-hills-and-valleys-in-an-array
#   ✔ Accepted
#   ✔ 121/121 cases passed (8 ms)
#   ✔ Your runtime beats 1.43 % of java submissions
#   ✔ Your memory usage beats 9.43 % of java submissions (44.1 MB)
# Submitting: java_solutions/2213.longest-substring-of-one-repeating-character.java
# - Downloading longest-substring-of-one-repeating-character
#   ✔ Accepted
#   ✔ 57/57 cases passed (993 ms)
#   ✔ Your runtime beats 5.26 % of java submissions
#   ✔ Your memory usage beats 75.44 % of java submissions (133.8 MB)
# Submitting: java_solutions/2215.find-the-difference-of-two-arrays.java
# - Downloading find-the-difference-of-two-arrays
#   ✔ Accepted
#   ✔ 202/202 cases passed (19 ms)
#   ✔ Your runtime beats 11.73 % of java submissions
#   ✔ Your memory usage beats 62.43 % of java submissions (47.5 MB)
# Submitting: java_solutions/2218.maximum-value-of-k-coins-from-piles.java
# - Downloading maximum-value-of-k-coins-from-piles
#   ✔ Accepted
#   ✔ 123/123 cases passed (952 ms)
#   ✔ Your runtime beats 5.24 % of java submissions
#   ✔ Your memory usage beats 78.67 % of java submissions (53.6 MB)
# Submitting: java_solutions/2220.minimum-bit-flips-to-convert-number.java
# - Downloading minimum-bit-flips-to-convert-number
#   ✔ Accepted
#   ✔ 250/250 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 9.32 % of java submissions (42.6 MB)
# Submitting: java_solutions/2223.sum-of-scores-of-built-strings.java
# - Downloading sum-of-scores-of-built-strings
#   ✔ Accepted
#   ✔ 150/150 cases passed (271 ms)
#   ✔ Your runtime beats 5.04 % of java submissions
#   ✔ Your memory usage beats 5.29 % of java submissions (60.6 MB)
# Submitting: java_solutions/2224.minimum-number-of-operations-to-convert-time.java
# - Downloading minimum-number-of-operations-to-convert-time
#   ✔ Accepted
#   ✔ 256/256 cases passed (1 ms)
#   ✔ Your runtime beats 83.46 % of java submissions
#   ✔ Your memory usage beats 7.52 % of java submissions (43.5 MB)
# Submitting: java_solutions/2227.encrypt-and-decrypt-strings.java
# - Downloading encrypt-and-decrypt-strings
#   ✔ Accepted
#   ✔ 211/211 cases passed (266 ms)
#   ✔ Your runtime beats 19.61 % of java submissions
#   ✔ Your memory usage beats 99.35 % of java submissions (53.1 MB)
# Submitting: java_solutions/2231.largest-number-after-digit-swaps-by-parity.java
# - Downloading largest-number-after-digit-swaps-by-parity
#   ✔ Accepted
#   ✔ 238/238 cases passed (18 ms)
#   ✔ Your runtime beats 5.06 % of java submissions
#   ✔ Your memory usage beats 5.06 % of java submissions (43.7 MB)

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-04-14 12:33:10
