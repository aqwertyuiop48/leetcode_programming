# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME_3')
    user_cookie = userdata.get('LEETCODE_TOKEN_3')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME_3'] = user_name
    os.environ['LEETCODE_TOKEN_3'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME_3" "$LEETCODE_TOKEN_3" | leetcode user -c

# %%
# %%bash
#
# # top 200-300 answers (next batch)
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v kotlin_solutions_1/*.kt | sed -n '801,900p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 7
# done
# Out:
# Submitting: kotlin_solutions_1/2068.check-whether-two-strings-are-almost-equivalent.kt
# - Downloading check-whether-two-strings-are-almost-equivalent
#   ✔ Accepted
#   ✔ 196/196 cases passed (8 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 16.67 % of kotlin submissions (41.4 MB)
# Submitting: kotlin_solutions_1/2069.walking-robot-simulation-ii.kt
# - Downloading walking-robot-simulation-ii
#   ✘ Wrong Answer
#   ✘ 53/142 cases passed (N/A)
#   ✘ Testcase: ["Robot","step","step","getPos","getDir","step","getPos","getDir","getPos","getDir"]
# ' +
#   '[[20,13],[12],[21],[],[],[17],[],[],[],[]]
#   ✘ Answer: [null,null,null,[17,12],"West",null,[0,12],"South",[0,12],"South"]
#   ✘ Expected Answer: [null,null,null,[17,12],"West",null,[0,12],"West",[0,12],"West"]
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2070.most-beautiful-item-for-each-query.kt
# - Downloading most-beautiful-item-for-each-query
#   ✔ Accepted
#   ✔ 35/35 cases passed (135 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2071.maximum-number-of-tasks-you-can-assign.kt
# - Downloading maximum-number-of-tasks-you-can-assign
#   ✔ Accepted
#   ✔ 49/49 cases passed (192 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/2073.time-needed-to-buy-tickets.kt
# - Downloading time-needed-to-buy-tickets
#   ✔ Accepted
#   ✔ 65/65 cases passed (15 ms)
#   ✔ Your runtime beats 26.92 % of kotlin submissions
#   ✔ Your memory usage beats 26.92 % of kotlin submissions (44.2 MB)
# Submitting: kotlin_solutions_1/2074.reverse-nodes-in-even-length-groups.kt
# - Downloading reverse-nodes-in-even-length-groups
#   ✔ Accepted
#   ✔ 165/165 cases passed (132 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
#   ✔ Your memory usage beats 80 % of kotlin submissions (82.6 MB)
# Submitting: kotlin_solutions_1/2075.decode-the-slanted-ciphertext.kt
# - Downloading decode-the-slanted-ciphertext
#   ✔ Accepted
#   ✔ 40/40 cases passed (327 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2076.process-restricted-friend-requests.kt
# - Downloading process-restricted-friend-requests
#   ✔ Accepted
#   ✔ 49/49 cases passed (462 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2078.two-furthest-houses-with-different-colors.kt
# - Downloading two-furthest-houses-with-different-colors
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 138: ERROR: Unresolved reference 'size'.
#   ✘ Error: Line 2: Char 138: ERROR: Unresolved reference 'size'.
# Line 2: Char 194: ERROR: Unresolved reference 'size'.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2079.watering-plants.kt
# - Downloading watering-plants
#   ✔ Accepted
#   ✔ 40/40 cases passed (17 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2080.range-frequency-queries.kt
# - Downloading range-frequency-queries
#   ✔ Accepted
#   ✔ 20/20 cases passed (229 ms)
#   ✔ Your runtime beats 40 % of kotlin submissions
#   ✔ Your memory usage beats 40 % of kotlin submissions (178 MB)
# Submitting: kotlin_solutions_1/2081.sum-of-k-mirror-numbers.kt
# - Downloading sum-of-k-mirror-numbers
#   ✔ Accepted
#   ✔ 97/97 cases passed (461 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2085.count-common-words-with-one-occurrence.kt
# - Downloading count-common-words-with-one-occurrence
#   ✔ Accepted
#   ✔ 61/61 cases passed (21 ms)
#   ✔ Your runtime beats 10 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (46.4 MB)
# Submitting: kotlin_solutions_1/2086.minimum-number-of-food-buckets-to-feed-the-hamsters.kt
# - Downloading minimum-number-of-food-buckets-to-feed-the-hamsters
# [ERROR] session expired, please login again [code=-1]
# Submitting: kotlin_solutions_1/2087.minimum-cost-homecoming-of-a-robot-in-a-grid.kt
# - Downloading minimum-cost-homecoming-of-a-robot-in-a-grid
#   ✔ Accepted
#   ✔ 69/69 cases passed (10 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2088.count_fertile_pyramids_in_a_land.kt
# - Downloading count-fertile-pyramids-in-a-land
#   ✔ Accepted
#   ✔ 49/49 cases passed (48 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (77.1 MB)
# Submitting: kotlin_solutions_1/2089.find_target_indices_after_sorting_array.kt
# - Downloading find-target-indices-after-sorting-array
#   ✔ Accepted
#   ✔ 216/216 cases passed (1 ms)
#   ✔ Your runtime beats 95 % of kotlin submissions
#   ✔ Your memory usage beats 85 % of kotlin submissions (45.5 MB)
# Submitting: kotlin_solutions_1/2090.k_radius_subarray_averages.kt
# - Downloading k-radius-subarray-averages
#   ✔ Accepted
#   ✔ 41/41 cases passed (22 ms)
#   ✔ Your runtime beats 5.88 % of kotlin submissions
#   ✔ Your memory usage beats 52.94 % of kotlin submissions (66.8 MB)
# Submitting: kotlin_solutions_1/2091.removing_minimum_and_maximum_from_array.kt
# - Downloading removing-minimum-and-maximum-from-array
#   ✔ Accepted
#   ✔ 62/62 cases passed (21 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/2092.find_all_people_with_secret.kt
# - Downloading find-all-people-with-secret
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 8: Char 478: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
#   ✘ Error: Line 8: Char 478: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 8: Char 527: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 8: Char 652: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 47: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2094.finding_3_digit_even_numbers.kt
# - Downloading finding-3-digit-even-numbers
#   ✔ Accepted
#   ✔ 79/79 cases passed (27 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 90 % of kotlin submissions (48.5 MB)
# Submitting: kotlin_solutions_1/2095.delete-the-middle-node-of-a-linked-list.kt
# - Downloading delete-the-middle-node-of-a-linked-list
#   ✔ Accepted
#   ✔ 70/70 cases passed (65 ms)
#   ✔ Your runtime beats 6.25 % of kotlin submissions
#   ✔ Your memory usage beats 8.75 % of kotlin submissions (71.4 MB)
# Submitting: kotlin_solutions_1/2095.delete_the_middle_node_of_a_linked_list.kt
#   ✔ Accepted
#   ✔ 70/70 cases passed (22 ms)
#   ✔ Your runtime beats 6.25 % of kotlin submissions
#   ✔ Your memory usage beats 97.5 % of kotlin submissions (66.4 MB)
# Submitting: kotlin_solutions_1/2096.step_by_step_directions_from_a_binary_tree_node_to_another.kt
# - Downloading step-by-step-directions-from-a-binary-tree-node-to-another
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 8: Char 293: WARNING: Variable is unused.
#   ✘ Error: Line 8: Char 293: WARNING: Variable is unused.
# Line 8: Char 311: ERROR: The expression cannot be a selector (cannot occur after a dot).
# Line 8: Char 314: ERROR: Syntax error: Expecting property name or receiver type.
# Line 8: Char 331: ERROR: Syntax error: Expecting an element.
# Line 8: Char 352: ERROR: Syntax error: Expecting ']'.
# Line 8: Char 363: WARNING: Parameter 'it: MutableList<TreeNode?>' is never used, could be renamed to '_'.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2097.valid_arrangement_of_pairs.kt
# - Downloading valid-arrangement-of-pairs
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 8: Char 145: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
#   ✘ Error: Line 8: Char 145: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 8: Char 145: ERROR: Not enough information to infer type argument for 'R'.
# Line 8: Char 232: WARNING: Parameter 'it: Boolean' is never used, could be renamed to '_'.
# Line 8: Char 268: WARNING: Parameter 'it: Boolean' is never used, could be renamed to '_'.
# Line 8: Char 305: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 8: Char 364: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 8: Char 364: ERROR: Not enough information to infer type argument for 'R'.
# Line 8: Char 603: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 8: Char 603: ERROR: Not enough information to infer type argument for 'R'.
# Line 8: Char 607: WARNING: Parameter 'it: MutableList<Int>' is never used, could be renamed to '_'.
# Line 8: Char 609: ERROR: Unresolved reference 'path'.
# Line 8: Char 625: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 8: Char 625: ERROR: Not enough information to infer type argument for 'R'.
# Line 8: Char 625: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun <T, R> T.let(block: (T) -> R): R
#     [R|Contract description]
#      <
#         CallsInPlace(block, EXACTLY_ONCE)
#     >
# Line 8: Char 631: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 8: Char 672: ERROR: Argument type mismatch: actual type is 'V?', but 'kotlin.Int' was expected.
# Line 8: Char 672: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 8: Char 678: ERROR: Argument type mismatch: actual type is 'V?', but 'kotlin.Int' was expected.
# Line 8: Char 678: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2099.find_subsequence_of_length_k_with_the_largest_sum.kt
# - Downloading find-subsequence-of-length-k-with-the-largest-sum
#   ✔ Accepted
#   ✔ 49/49 cases passed (32 ms)
#   ✔ Your runtime beats 28.57 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (48.8 MB)
# Submitting: kotlin_solutions_1/2100.find-good-days-to-rob-the-bank.kt
# - Downloading find-good-days-to-rob-the-bank
#   ✔ Accepted
#   ✔ 144/144 cases passed (33 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (66.6 MB)
# Submitting: kotlin_solutions_1/2101.detonate-the-maximum-bombs.kt
# - Downloading detonate-the-maximum-bombs
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 396: ERROR: Argument type mismatch: actual type is 'kotlin.Int', but 'kotlin.collections.Collection<kotlin.Int>' was expected.
#   ✘ Error: Line 2: Char 396: ERROR: Argument type mismatch: actual type is 'kotlin.Int', but 'kotlin.collections.Collection<kotlin.Int>' was expected.
# Line 36: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2102.sequentially-ordinal-rank-tracker.kt
# - Downloading sequentially-ordinal-rank-tracker
#   ✔ Accepted
#   ✔ 81/81 cases passed (296 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
#   ✔ Your memory usage beats 60 % of kotlin submissions (102.2 MB)
# Submitting: kotlin_solutions_1/2103.rings-and-rods.kt
# - Downloading rings-and-rods
#   ✔ Accepted
#   ✔ 66/66 cases passed (16 ms)
#   ✔ Your runtime beats 7.14 % of kotlin submissions
#   ✔ Your memory usage beats 7.14 % of kotlin submissions (43.4 MB)
# Submitting: kotlin_solutions_1/2104.sum-of-subarray-ranges.kt
# - Downloading sum-of-subarray-ranges
#   ✔ Accepted
#   ✔ 71/71 cases passed (305 ms)
#   ✔ Your runtime beats 9.09 % of kotlin submissions
#   ✔ Your memory usage beats 9.09 % of kotlin submissions (51.4 MB)
# Submitting: kotlin_solutions_1/2105.watering-plants-ii.kt
# - Downloading watering-plants-ii
#   ✔ Accepted
#   ✔ 57/57 cases passed (34 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (62 MB)
# Submitting: kotlin_solutions_1/2106.maximum-fruits-harvested-after-at-most-k-steps.kt
# - Downloading maximum-fruits-harvested-after-at-most-k-steps
#   ✔ Accepted
#   ✔ 202/202 cases passed (144 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2108.find-first-palindromic-string-in-the-array.kt
# - Downloading find-first-palindromic-string-in-the-array
#   ✔ Accepted
#   ✔ 266/266 cases passed (14 ms)
#   ✔ Your runtime beats 7.69 % of kotlin submissions
#   ✔ Your memory usage beats 7.69 % of kotlin submissions (50.3 MB)
# Submitting: kotlin_solutions_1/2109.adding-spaces-to-a-string.kt
# - Downloading adding-spaces-to-a-string
#   ✔ Accepted
#   ✔ 66/66 cases passed (81 ms)
#   ✔ Your runtime beats 14.29 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (89.7 MB)
# Submitting: kotlin_solutions_1/2110.number-of-smooth-descent-periods-of-a-stock.kt
# - Downloading number-of-smooth-descent-periods-of-a-stock
#   ✔ Accepted
#   ✔ 168/168 cases passed (42 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (66.7 MB)
# Submitting: kotlin_solutions_1/2111.minimum-operations-to-make-the-array-k-increasing.kt
# - Downloading minimum-operations-to-make-the-array-k-increasing
#   ✔ Accepted
#   ✔ 90/90 cases passed (87 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2114.maximum-number-of-words-found-in-sentences.kt
# - Downloading maximum-number-of-words-found-in-sentences
#   ✔ Accepted
#   ✔ 90/90 cases passed (27 ms)
#   ✔ Your runtime beats 8.33 % of kotlin submissions
#   ✔ Your memory usage beats 8.33 % of kotlin submissions (48.7 MB)
# Submitting: kotlin_solutions_1/2115.find-all-possible-recipes-from-given-supplies.kt
# - Downloading find-all-possible-recipes-from-given-supplies
#   ✘ Wrong Answer
#   ✘ 2/114 cases passed (N/A)
#   ✘ Testcase: ["bread"]
# [["yeast","flour"]]
# ["yeast","flour","corn"]
#   ✘ Answer: []
#   ✘ Expected Answer: ["bread"]
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2116.check-if-a-parentheses-string-can-be-valid.kt
# - Downloading check-if-a-parentheses-string-can-be-valid
#   ✔ Accepted
#   ✔ 260/260 cases passed (36 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2117.abbreviating-the-product-of-a-range.kt
# - Downloading abbreviating-the-product-of-a-range
#   ✔ Accepted
#   ✔ 292/292 cases passed (49 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/2119.a-number-after-a-double-reversal.kt
# - Downloading a-number-after-a-double-reversal
#   ✔ Accepted
#   ✔ 129/129 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (40 MB)
# Submitting: kotlin_solutions_1/2120.execution-of-all-suffix-instructions-staying-in-a-grid.kt
# - Downloading execution-of-all-suffix-instructions-staying-in-a-grid
#   ✔ Accepted
#   ✔ 113/113 cases passed (215 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2121.intervals-between-identical-elements.kt
# - Downloading intervals-between-identical-elements
#   ✔ Accepted
#   ✔ 61/61 cases passed (27 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (69.7 MB)
# Submitting: kotlin_solutions_1/2122.recover-the-original-array.kt
# - Downloading recover-the-original-array
#   ✔ Accepted
#   ✔ 110/110 cases passed (94 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (52.7 MB)
# Submitting: kotlin_solutions_1/2124.check-if-all-as-appears-before-all-bs.kt
# - Downloading check-if-all-as-appears-before-all-bs
#   ✔ Accepted
#   ✔ 216/216 cases passed (6 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (42.3 MB)
# Submitting: kotlin_solutions_1/2125.number_of_laser_beams_in_a_bank.kt
# - Downloading number-of-laser-beams-in-a-bank
#   ✔ Accepted
#   ✔ 147/147 cases passed (33 ms)
#   ✔ Your runtime beats 37.5 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (50.2 MB)
# Submitting: kotlin_solutions_1/2126.destroying_asteroids.kt
# - Downloading destroying-asteroids
#   ✔ Accepted
#   ✔ 75/75 cases passed (192 ms)
#   ✔ Your runtime beats 6.25 % of kotlin submissions
#   ✔ Your memory usage beats 62.5 % of kotlin submissions (66.7 MB)
# Submitting: kotlin_solutions_1/2127.maximum_employees_to_be_invited_to_a_meeting.kt
# - Downloading maximum-employees-to-be-invited-to-a-meeting
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 36: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Error: Line 36: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2129.capitalize_the_title.kt
# - Downloading capitalize-the-title
#   ✔ Accepted
#   ✔ 200/200 cases passed (17 ms)
#   ✔ Your runtime beats 44.44 % of kotlin submissions
#   ✔ Your memory usage beats 11.11 % of kotlin submissions (46 MB)
# Submitting: kotlin_solutions_1/2130.maximum_twin_sum_of_a_linked_list.kt
# - Downloading maximum-twin-sum-of-a-linked-list
#   ✔ Accepted
#   ✔ 46/46 cases passed (47 ms)
#   ✔ Your runtime beats 5.08 % of kotlin submissions
#   ✔ Your memory usage beats 16.95 % of kotlin submissions (69.7 MB)
# Submitting: kotlin_solutions_1/2131.longest_palindrome_by_concatenating_two_letter_words.kt
# - Downloading longest-palindrome-by-concatenating-two-letter-words
#   ✔ Accepted
#   ✔ 120/120 cases passed (45 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 55.56 % of kotlin submissions (67.4 MB)
# Submitting: kotlin_solutions_1/2132.stamping_the_grid.kt
# - Downloading stamping-the-grid
#   ✔ Accepted
#   ✔ 77/77 cases passed (71 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2133.check_if_every_row_and_column_contains_all_numbers.kt
# - Downloading check-if-every-row-and-column-contains-all-numbers
#   ✔ Accepted
#   ✔ 227/227 cases passed (56 ms)
#   ✔ Your runtime beats 13.33 % of kotlin submissions
#   ✔ Your memory usage beats 6.67 % of kotlin submissions (67.3 MB)
# Submitting: kotlin_solutions_1/2134.minimum_swaps_to_group_all_1s_together_ii.kt
# - Downloading minimum-swaps-to-group-all-1s-together-ii
#   ✔ Accepted
#   ✔ 63/63 cases passed (27 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 55.56 % of kotlin submissions (62.8 MB)
# Submitting: kotlin_solutions_1/2135.count_words_obtained_after_adding_a_letter.kt
# - Downloading count-words-obtained-after-adding-a-letter
# [ERROR] session expired, please login again [code=-1]
# Submitting: kotlin_solutions_1/2136.earliest-possible-day-of-full-bloom.kt
# - Downloading earliest-possible-day-of-full-bloom
#   ✔ Accepted
#   ✔ 185/185 cases passed (126 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (91.1 MB)
# Submitting: kotlin_solutions_1/2138.divide-a-string-into-groups-of-size-k.kt
# - Downloading divide-a-string-into-groups-of-size-k
#   ✔ Accepted
#   ✔ 157/157 cases passed (10 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/2139.minimum-moves-to-reach-target-score.kt
# - Downloading minimum-moves-to-reach-target-score
#   ✔ Accepted
#   ✔ 145/145 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 37.5 % of kotlin submissions (40.4 MB)
# Submitting: kotlin_solutions_1/2140.solving-questions-with-brainpower.kt
# - Downloading solving-questions-with-brainpower
#   ✔ Accepted
#   ✔ 54/54 cases passed (13 ms)
#   ✔ Your runtime beats 52.38 % of kotlin submissions
#   ✔ Your memory usage beats 95.24 % of kotlin submissions (113.5 MB)
# Submitting: kotlin_solutions_1/2141.maximum-running-time-of-n-computers.kt
# - Downloading maximum-running-time-of-n-computers
#   ✔ Accepted
#   ✔ 52/52 cases passed (21 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (61.3 MB)
# Submitting: kotlin_solutions_1/2144.minimum-cost-of-buying-candies-with-discount.kt
# - Downloading minimum-cost-of-buying-candies-with-discount
#   ✔ Accepted
#   ✔ 192/192 cases passed (22 ms)
#   ✔ Your runtime beats 15 % of kotlin submissions
#   ✔ Your memory usage beats 30 % of kotlin submissions (46.8 MB)
# Submitting: kotlin_solutions_1/2145.count-the-hidden-sequences.kt
# - Downloading count-the-hidden-sequences
#   ✔ Accepted
#   ✔ 86/86 cases passed (37 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 16.67 % of kotlin submissions (68.7 MB)
# Submitting: kotlin_solutions_1/2146.k-highest-ranked-items-within-a-price-range.kt
# - Downloading k-highest-ranked-items-within-a-price-range
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 128: ERROR: Return type mismatch: expected 'kotlin.collections.List<kotlin.collections.List<kotlin.Int>>', actual 'kotlin.collections.MutableList<kotlin.IntArray>'.
#   ✘ Error: Line 2: Char 128: ERROR: Return type mismatch: expected 'kotlin.collections.List<kotlin.collections.List<kotlin.Int>>', actual 'kotlin.collections.MutableList<kotlin.IntArray>'.
# Line 2: Char 295: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 544: WARNING: Parameter 'it: Any' is never used, could be renamed to '_'.
# Line 2: Char 743: WARNING: Parameter 'it: Boolean' is never used, could be renamed to '_'.
# Line 2: Char 790: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 800: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 811: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 822: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 833: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 859: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 866: ERROR: Unresolved reference 'it'.
# Line 2: Char 866: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 866: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 873: ERROR: Unresolved reference 'it'.
# Line 2: Char 873: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 42: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2147.number-of-ways-to-divide-a-long-corridor.kt
# - Downloading number-of-ways-to-divide-a-long-corridor
#   ✔ Accepted
#   ✔ 248/248 cases passed (101 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2148.count-elements-with-strictly-smaller-and-greater-elements.kt
# - Downloading count-elements-with-strictly-smaller-and-greater-elements
#   ✔ Accepted
#   ✔ 127/127 cases passed (15 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2149.rearrange-array-elements-by-sign.kt
# - Downloading rearrange-array-elements-by-sign
#   ✔ Accepted
#   ✔ 133/133 cases passed (16 ms)
#   ✔ Your runtime beats 14.29 % of kotlin submissions
#   ✔ Your memory usage beats 46.43 % of kotlin submissions (88.9 MB)
# Submitting: kotlin_solutions_1/2150.find-all-lonely-numbers-in-the-array.kt
# - Downloading find-all-lonely-numbers-in-the-array
#   ✔ Accepted
#   ✔ 75/75 cases passed (162 ms)
#   ✔ Your runtime beats 14.29 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (77 MB)
# Submitting: kotlin_solutions_1/2151.maximum-good-people-based-on-statements.kt
# - Downloading maximum-good-people-based-on-statements
#   ✔ Accepted
#   ✔ 91/91 cases passed (93 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2154.keep-multiplying-found-values-by-two.kt
# - Downloading keep-multiplying-found-values-by-two
#   ✔ Accepted
#   ✔ 82/82 cases passed (22 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 16.67 % of kotlin submissions (47.5 MB)
# Submitting: kotlin_solutions_1/2155.all-divisions-with-the-highest-score-of-a-binary-array.kt
# - Downloading all-divisions-with-the-highest-score-of-a-binary-array
#   ✔ Accepted
#   ✔ 58/58 cases passed (108 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (71.2 MB)
# Submitting: kotlin_solutions_1/2156.find-substring-with-given-hash-value.kt
# - Downloading find-substring-with-given-hash-value
#   ✔ Accepted
#   ✔ 90/90 cases passed (34 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2157.groups-of-strings.kt
# - Downloading groups-of-strings
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 38: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Error: Line 38: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2160.minimum-sum-of-four-digit-number-after-splitting-digits.kt
# - Downloading minimum-sum-of-four-digit-number-after-splitting-digits
#   ✔ Accepted
#   ✔ 99/99 cases passed (13 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 22.22 % of kotlin submissions (45.1 MB)
# Submitting: kotlin_solutions_1/2161.partition-array-according-to-given-pivot.kt
# - Downloading partition-array-according-to-given-pivot
#   ✔ Accepted
#   ✔ 44/44 cases passed (29 ms)
#   ✔ Your runtime beats 38.46 % of kotlin submissions
#   ✔ Your memory usage beats 69.23 % of kotlin submissions (66.7 MB)
# Submitting: kotlin_solutions_1/2162.minimum-cost-to-set-cooking-time.kt
# - Downloading minimum-cost-to-set-cooking-time
#   ✔ Accepted
#   ✔ 239/239 cases passed (26 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2163.minimum-difference-in-sums-after-removal-of-elements.kt
# - Downloading minimum-difference-in-sums-after-removal-of-elements
#   ✔ Accepted
#   ✔ 110/110 cases passed (159 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/2164.sort-even-and-odd-indices-independently.kt
# - Downloading sort-even-and-odd-indices-independently
#   ✔ Accepted
#   ✔ 218/218 cases passed (25 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
#   ✔ Your memory usage beats 30 % of kotlin submissions (46.9 MB)
# Submitting: kotlin_solutions_1/2165.smallest-value-of-the-rearranged-number.kt
# - Downloading smallest-value-of-the-rearranged-number
#   ✔ Accepted
#   ✔ 413/413 cases passed (29 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2166.design-bitset.kt
# - Downloading design-bitset
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 6: Char 54: ERROR: Syntax error: Property getter or setter expected.
#   ✘ Error: Line 6: Char 54: ERROR: Syntax error: Property getter or setter expected.
# Line 6: Char 109: ERROR: Unresolved reference 'f'.
# Line 6: Char 147: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 6: Char 149: ERROR: Unresolved reference 'c'.
# Line 6: Char 150: ERROR: Unresolved reference 'c'.
# Line 6: Char 202: ERROR: Unresolved reference 'f'.
# Line 6: Char 240: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 6: Char 242: ERROR: Unresolved reference 'c'.
# Line 6: Char 243: ERROR: Unresolved reference 'c'.
# Line 6: Char 277: ERROR: Unresolved reference 'f'.
# Line 6: Char 281: ERROR: Unresolved reference 'f'.
# Line 6: Char 296: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 6: Char 298: ERROR: Unresolved reference 'c'.
# Line 6: Char 309: ERROR: Unresolved reference 'c'.
# Line 6: Char 325: ERROR: Unresolved reference 'c'.
# Line 6: Char 347: ERROR: Unresolved reference 'c'.
# Line 6: Char 367: ERROR: Unresolved reference 'c'.
# Line 6: Char 382: ERROR: Anonymous functions with names are prohibited.
# Line 6: Char 424: ERROR: Unresolved reference 'f'.
# Line 72: Char 32: WARNING: 'static fun readFrom(p0: String!): JsonArray!' is deprecated. Deprecated in Java.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2167.minimum-time-to-remove-all-cars-containing-illegal-goods.kt
# - Downloading minimum-time-to-remove-all-cars-containing-illegal-goods
#   ✔ Accepted
#   ✔ 89/89 cases passed (72 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (56 MB)
# Submitting: kotlin_solutions_1/2169.count-operations-to-obtain-zero.kt
# - Downloading count-operations-to-obtain-zero
#   ✔ Accepted
#   ✔ 161/161 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 11.11 % of kotlin submissions (40.4 MB)
# Submitting: kotlin_solutions_1/2170.minimum-operations-to-make-the-array-alternating.kt
# - Downloading minimum-operations-to-make-the-array-alternating
#   ✔ Accepted
#   ✔ 153/153 cases passed (168 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2171.removing-minimum-number-of-magic-beans.kt
# - Downloading removing-minimum-number-of-magic-beans
#   ✔ Accepted
#   ✔ 64/64 cases passed (74 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2172.maximum-and-sum-of-array.kt
# - Downloading maximum-and-sum-of-array
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 42: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Error: Line 42: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2176.count-equal-and-divisible-pairs-in-an-array.kt
# - Downloading count-equal-and-divisible-pairs-in-an-array
#   ✔ Accepted
#   ✔ 238/238 cases passed (28 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2177.find-three-consecutive-integers-that-sum-to-a-given-number.kt
# - Downloading find-three-consecutive-integers-that-sum-to-a-given-number
#   ✔ Accepted
#   ✔ 379/379 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/2178.maximum-split-of-positive-even-integers.kt
# - Downloading maximum-split-of-positive-even-integers
#   ✔ Accepted
#   ✔ 56/56 cases passed (20 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2179.count-good-triplets-in-an-array.kt
# - Downloading count-good-triplets-in-an-array
#   ✔ Accepted
#   ✔ 148/148 cases passed (521 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2180.count-integers-with-even-digit-sum.kt
# - Downloading count-integers-with-even-digit-sum
#   ✔ Accepted
#   ✔ 71/71 cases passed (9 ms)
#   ✔ Your runtime beats 10 % of kotlin submissions
#   ✔ Your memory usage beats 10 % of kotlin submissions (42.6 MB)
# Submitting: kotlin_solutions_1/2181.merge-nodes-in-between-zeros.kt
# - Downloading merge-nodes-in-between-zeros
#   ✔ Accepted
#   ✔ 39/39 cases passed (134 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (101.2 MB)
# Submitting: kotlin_solutions_1/2182.construct-string-with-repeat-limit.kt
# - Downloading construct-string-with-repeat-limit
#   ✔ Accepted
#   ✔ 150/150 cases passed (78 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (49.4 MB)
# Submitting: kotlin_solutions_1/2183.count-array-pairs-divisible-by-k.kt
# - Downloading count-array-pairs-divisible-by-k
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 42: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Error: Line 42: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2185.counting-words-with-a-given-prefix.kt
# - Downloading counting-words-with-a-given-prefix
#   ✔ Accepted
#   ✔ 95/95 cases passed (7 ms)
#   ✔ Your runtime beats 40 % of kotlin submissions
#   ✔ Your memory usage beats 40 % of kotlin submissions (45 MB)
# Submitting: kotlin_solutions_1/2186.minimum-number-of-steps-to-make-two-strings-anagram-ii.kt
# - Downloading minimum-number-of-steps-to-make-two-strings-anagram-ii
# [ERROR] session expired, please login again [code=-1]
# Submitting: kotlin_solutions_1/2187.minimum-time-to-complete-trips.kt
# - Downloading minimum-time-to-complete-trips
#   ✔ Accepted
#   ✔ 124/124 cases passed (61 ms)
#   ✔ Your runtime beats 53.85 % of kotlin submissions
#   ✔ Your memory usage beats 53.85 % of kotlin submissions (63.4 MB)
# Submitting: kotlin_solutions_1/2188.minimum-time-to-finish-the-race.kt
# - Downloading minimum-time-to-finish-the-race
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 6: Char 116: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 6: Char 116: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 6: Char 248: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 6: Char 339: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 6: Char 386: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 44: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2190.most-frequent-number-following-key-in-an-array.kt
# - Downloading most-frequent-number-following-key-in-an-array
#   ✔ Accepted
#   ✔ 101/101 cases passed (29 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (49.9 MB)
# Submitting: kotlin_solutions_1/2191.sort-the-jumbled-numbers.kt
# - Downloading sort-the-jumbled-numbers
#   ✔ Accepted
#   ✔ 68/68 cases passed (3648 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (65.8 MB)
# Submitting: kotlin_solutions_1/2192.all-ancestors-of-a-node-in-a-directed-acyclic-graph.kt
# - Downloading all-ancestors-of-a-node-in-a-directed-acyclic-graph
#   ✔ Accepted
#   ✔ 80/80 cases passed (417 ms)
# [WARN] Failed to get runtime percentile.

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-08-17 18:46:25
