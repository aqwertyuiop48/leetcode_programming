# %%
# %%capture
import os
import getpass

# 1. Install and Clone
# !npm install -g leetcode-tools/leetcode-cli
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Interactive input (Safe and hidden)
print("Please enter your LeetCode credentials:")
user_name = getpass.getpass('LeetCode Username: ')
user_cookie = getpass.getpass('LeetCode Session Token: ')

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME'] = user_name
    os.environ['LEETCODE_TOKEN'] = user_cookie

    # 4. Run the login silently
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME" "$LEETCODE_TOKEN" | leetcode user -c

# %%
# %%bash
#
#
# # top 100 answers
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v kotlin_solutions/*.kt | head -n 100); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 7
# done
# Out:
# Submitting: kotlin_solutions/1.two-sum.kt
# - Downloading problems
# - Downloading two-sum
#   ✔ Accepted
#   ✔ 63/63 cases passed (38 ms)
#   ✔ Your runtime beats 13.17 % of kotlin submissions
#   ✔ Your memory usage beats 6.96 % of kotlin submissions (49.3 MB)
# Submitting: kotlin_solutions/2.add-two-numbers.kt
# - Downloading add-two-numbers
#   ✔ Accepted
#   ✔ 1569/1569 cases passed (79 ms)
#   ✔ Your runtime beats 5.07 % of kotlin submissions
#   ✔ Your memory usage beats 5.07 % of kotlin submissions (54.2 MB)
# Submitting: kotlin_solutions/3.longest-substring-without-repeating-characters.kt
# - Downloading longest-substring-without-repeating-characters
#   ✔ Accepted
#   ✔ 988/988 cases passed (16 ms)
#   ✔ Your runtime beats 26.73 % of kotlin submissions
#   ✔ Your memory usage beats 56.17 % of kotlin submissions (46.2 MB)
# Submitting: kotlin_solutions/4.median-of-two-sorted-arrays.kt
# - Downloading median-of-two-sorted-arrays
#   ✔ Accepted
#   ✔ 2098/2098 cases passed (26 ms)
#   ✔ Your runtime beats 10.63 % of kotlin submissions
#   ✔ Your memory usage beats 87.99 % of kotlin submissions (49.7 MB)
# Submitting: kotlin_solutions/5.longest-palindromic-substring.kt
# - Downloading longest-palindromic-substring
#   ✔ Accepted
#   ✔ 143/143 cases passed (213 ms)
#   ✔ Your runtime beats 22.35 % of kotlin submissions
#   ✔ Your memory usage beats 14.71 % of kotlin submissions (49.1 MB)
# Submitting: kotlin_solutions/6.zigzag-conversion.kt
# - Downloading zigzag-conversion
#   ✔ Accepted
#   ✔ 1157/1157 cases passed (63 ms)
#   ✔ Your runtime beats 11.38 % of kotlin submissions
#   ✔ Your memory usage beats 8.23 % of kotlin submissions (52.7 MB)
# Submitting: kotlin_solutions/7.reverse-integer.kt
# - Downloading reverse-integer
#   ✔ Accepted
#   ✔ 1045/1045 cases passed (123 ms)
#   ✔ Your runtime beats 9.98 % of kotlin submissions
#   ✔ Your memory usage beats 15.16 % of kotlin submissions (41.9 MB)
# Submitting: kotlin_solutions/8.string-to-integer-atoi.kt
# - Downloading string-to-integer-atoi
#   ✔ Accepted
#   ✔ 1096/1096 cases passed (43 ms)
#   ✔ Your runtime beats 5.9 % of kotlin submissions
#   ✔ Your memory usage beats 13.97 % of kotlin submissions (47.3 MB)
# Submitting: kotlin_solutions/9.palindrome-number.kt
# - Downloading palindrome-number
#   ✔ Accepted
#   ✔ 11511/11511 cases passed (19 ms)
#   ✔ Your runtime beats 14.61 % of kotlin submissions
#   ✔ Your memory usage beats 18.28 % of kotlin submissions (46.4 MB)
# Submitting: kotlin_solutions/10.regular-expression-matching.kt
# - Downloading regular-expression-matching
#   ✔ Accepted
#   ✔ 354/354 cases passed (220 ms)
#   ✔ Your runtime beats 30.72 % of kotlin submissions
#   ✔ Your memory usage beats 56.86 % of kotlin submissions (43.2 MB)
# Submitting: kotlin_solutions/11.container-with-most-water.kt
# - Downloading container-with-most-water
#   ✔ Accepted
#   ✔ 65/65 cases passed (42 ms)
#   ✔ Your runtime beats 5.69 % of kotlin submissions
#   ✔ Your memory usage beats 13.07 % of kotlin submissions (62 MB)
# Submitting: kotlin_solutions/12.integer-to-roman.kt
# - Downloading integer-to-roman
#   ✔ Accepted
#   ✔ 3999/3999 cases passed (26 ms)
#   ✔ Your runtime beats 13.92 % of kotlin submissions
#   ✔ Your memory usage beats 6.47 % of kotlin submissions (50.4 MB)
# Submitting: kotlin_solutions/13.roman-to-integer.kt
# - Downloading roman-to-integer
#   ✔ Accepted
#   ✔ 3999/3999 cases passed (12 ms)
#   ✔ Your runtime beats 64.69 % of kotlin submissions
#   ✔ Your memory usage beats 59.94 % of kotlin submissions (46.2 MB)
# Submitting: kotlin_solutions/14.longest-common-prefix.kt
# - Downloading longest-common-prefix
#   ✔ Accepted
#   ✔ 126/126 cases passed (27 ms)
#   ✔ Your runtime beats 5.25 % of kotlin submissions
#   ✔ Your memory usage beats 9.54 % of kotlin submissions (46.4 MB)
# Submitting: kotlin_solutions/15.3-sum.kt
# - Downloading 3sum
#   ✔ Accepted
#   ✔ 316/316 cases passed (511 ms)
#   ✔ Your runtime beats 14.75 % of kotlin submissions
#   ✔ Your memory usage beats 49.77 % of kotlin submissions (67.6 MB)
# Submitting: kotlin_solutions/16.3-sum-closest.kt
# - Downloading 3sum-closest
#   ✔ Accepted
#   ✔ 107/107 cases passed (172 ms)
#   ✔ Your runtime beats 15.02 % of kotlin submissions
#   ✔ Your memory usage beats 5.15 % of kotlin submissions (62.5 MB)
# Submitting: kotlin_solutions/17.letter-combinations-of-a-phone-number.kt
# - Downloading letter-combinations-of-a-phone-number
#   ✔ Accepted
#   ✔ 24/24 cases passed (11 ms)
#   ✔ Your runtime beats 43.94 % of kotlin submissions
#   ✔ Your memory usage beats 52.63 % of kotlin submissions (43 MB)
# Submitting: kotlin_solutions/18.4-sum.kt
# - Downloading 4sum
#   ✔ Accepted
#   ✔ 294/294 cases passed (192 ms)
#   ✔ Your runtime beats 13.42 % of kotlin submissions
#   ✔ Your memory usage beats 23.61 % of kotlin submissions (54.9 MB)
# Submitting: kotlin_solutions/19.remove-nth-node-from-end-of-list.kt
# - Downloading remove-nth-node-from-end-of-list
#   ✔ Accepted
#   ✔ 208/208 cases passed (9 ms)
#   ✔ Your runtime beats 6.45 % of kotlin submissions
#   ✔ Your memory usage beats 5.47 % of kotlin submissions (43.2 MB)
# Submitting: kotlin_solutions/20.valid-parentheses.kt
# - Downloading valid-parentheses
#   ✔ Accepted
#   ✔ 102/102 cases passed (20 ms)
#   ✔ Your runtime beats 40.11 % of kotlin submissions
#   ✔ Your memory usage beats 48.01 % of kotlin submissions (45.9 MB)
# Submitting: kotlin_solutions/21.merge-two-sorted-lists.kt
# - Downloading merge-two-sorted-lists
#   ✔ Accepted
#   ✔ 208/208 cases passed (8 ms)
#   ✔ Your runtime beats 3.8 % of kotlin submissions
#   ✔ Your memory usage beats 5.48 % of kotlin submissions (45.2 MB)
# Submitting: kotlin_solutions/22.generate-parentheses.kt
# - Downloading generate-parentheses
#   ✔ Accepted
#   ✔ 8/8 cases passed (32 ms)
#   ✔ Your runtime beats 5.08 % of kotlin submissions
#   ✔ Your memory usage beats 12.47 % of kotlin submissions (47 MB)
# Submitting: kotlin_solutions/23.merge-k-sorted-lists.kt
# - Downloading merge-k-sorted-lists
#   ✔ Accepted
#   ✔ 134/134 cases passed (29 ms)
#   ✔ Your runtime beats 23.61 % of kotlin submissions
#   ✔ Your memory usage beats 33.93 % of kotlin submissions (48.1 MB)
# Submitting: kotlin_solutions/24.swap-nodes-in-pairs.kt
# - Downloading swap-nodes-in-pairs
#   ✔ Accepted
#   ✔ 55/55 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 70.56 % of kotlin submissions (40.8 MB)
# Submitting: kotlin_solutions/25.reverse-nodes-in-k-group.kt
# - Downloading reverse-nodes-in-k-group
#   ✔ Accepted
#   ✔ 62/62 cases passed (26 ms)
#   ✔ Your runtime beats 5.56 % of kotlin submissions
#   ✔ Your memory usage beats 11.11 % of kotlin submissions (46.2 MB)
# Submitting: kotlin_solutions/26.remove-duplicates-from-sorted-array.kt
# - Downloading remove-duplicates-from-sorted-array
#   ✔ Accepted
#   ✔ 362/362 cases passed (6 ms)
#   ✔ Your runtime beats 14.19 % of kotlin submissions
#   ✔ Your memory usage beats 76.26 % of kotlin submissions (47.2 MB)
# Submitting: kotlin_solutions/27.remove-element.kt
# - Downloading remove-element
#   ✔ Accepted
#   ✔ 116/116 cases passed (13 ms)
#   ✔ Your runtime beats 5.09 % of kotlin submissions
#   ✔ Your memory usage beats 6.04 % of kotlin submissions (45.6 MB)
# Submitting: kotlin_solutions/28.find-the-index-of-the-first-occurrence-in-a-string.kt
# - Downloading find-the-index-of-the-first-occurrence-in-a-string
#   ✔ Accepted
#   ✔ 85/85 cases passed (4 ms)
#   ✔ Your runtime beats 50.73 % of kotlin submissions
#   ✔ Your memory usage beats 47.8 % of kotlin submissions (41.7 MB)
# Submitting: kotlin_solutions/29.divide-two-integers.kt
# - Downloading divide-two-integers
#   ✔ Accepted
#   ✔ 994/994 cases passed (1 ms)
#   ✔ Your runtime beats 89.72 % of kotlin submissions
#   ✔ Your memory usage beats 81.31 % of kotlin submissions (40.9 MB)
# Submitting: kotlin_solutions/30.substring-with-concatenation-of-all-words.kt
# - Downloading substring-with-concatenation-of-all-words
#   ✔ Accepted
#   ✔ 182/182 cases passed (2701 ms)
#   ✔ Your runtime beats 10.91 % of kotlin submissions
#   ✔ Your memory usage beats 15.45 % of kotlin submissions (63.3 MB)
# Submitting: kotlin_solutions/31.next-permutation.kt
# - Downloading next-permutation
#   ✔ Accepted
#   ✔ 266/266 cases passed (18 ms)
#   ✔ Your runtime beats 10.95 % of kotlin submissions
#   ✔ Your memory usage beats 22.89 % of kotlin submissions (46.5 MB)
# Submitting: kotlin_solutions/32.longest-valid-parentheses.kt
# - Downloading longest-valid-parentheses
#   ✔ Accepted
#   ✔ 235/235 cases passed (17 ms)
#   ✔ Your runtime beats 59.29 % of kotlin submissions
#   ✔ Your memory usage beats 39.82 % of kotlin submissions (47.3 MB)
# Submitting: kotlin_solutions/33.search-in-rotated-sorted-array.kt
# - Downloading search-in-rotated-sorted-array
#   ✔ Accepted
#   ✔ 196/196 cases passed (10 ms)
#   ✔ Your runtime beats 30.09 % of kotlin submissions
#   ✔ Your memory usage beats 7.93 % of kotlin submissions (51.1 MB)
# Submitting: kotlin_solutions/34.find-first-and-last-position-of-element-in-sorted-array.kt
# - Downloading find-first-and-last-position-of-element-in-sorted-array
#   ✔ Accepted
#   ✔ 88/88 cases passed (23 ms)
#   ✔ Your runtime beats 5.29 % of kotlin submissions
#   ✔ Your memory usage beats 5.59 % of kotlin submissions (51.7 MB)
# Submitting: kotlin_solutions/35.search-insert-position.kt
# - Downloading search-insert-position
#   ✔ Accepted
#   ✔ 66/66 cases passed (7 ms)
#   ✔ Your runtime beats 24.78 % of kotlin submissions
#   ✔ Your memory usage beats 14.66 % of kotlin submissions (46 MB)
# Submitting: kotlin_solutions/36.valid-sudoku.kt
# - Downloading valid-sudoku
#   ✔ Accepted
#   ✔ 507/507 cases passed (31 ms)
#   ✔ Your runtime beats 6.85 % of kotlin submissions
#   ✔ Your memory usage beats 5.38 % of kotlin submissions (54.6 MB)
# Submitting: kotlin_solutions/37.sudoku-solver.kt
# - Downloading sudoku-solver
#   ✔ Accepted
#   ✔ 8/8 cases passed (815 ms)
#   ✔ Your runtime beats 6.67 % of kotlin submissions
#   ✔ Your memory usage beats 29.33 % of kotlin submissions (54.1 MB)
# Submitting: kotlin_solutions/38.count-and-say.kt
# - Downloading count-and-say
#   ✔ Accepted
#   ✔ 30/30 cases passed (58 ms)
#   ✔ Your runtime beats 10.94 % of kotlin submissions
#   ✔ Your memory usage beats 10.94 % of kotlin submissions (47.9 MB)
# Submitting: kotlin_solutions/39.combination-sum.kt
# - Downloading combination-sum
#   ✔ Accepted
#   ✔ 160/160 cases passed (26 ms)
#   ✔ Your runtime beats 12.15 % of kotlin submissions
#   ✔ Your memory usage beats 10.98 % of kotlin submissions (52.1 MB)
# Submitting: kotlin_solutions/40.combination-sum-ii.kt
# - Downloading combination-sum-ii
#   ✔ Accepted
#   ✔ 176/176 cases passed (162 ms)
#   ✔ Your runtime beats 6.08 % of kotlin submissions
#   ✔ Your memory usage beats 5.52 % of kotlin submissions (66.6 MB)
# Submitting: kotlin_solutions/41.first-missing-positive.kt
# - Downloading first-missing-positive
#   ✔ Accepted
#   ✔ 179/179 cases passed (3296 ms)
#   ✔ Your runtime beats 5.38 % of kotlin submissions
#   ✔ Your memory usage beats 7.53 % of kotlin submissions (72.7 MB)
# Submitting: kotlin_solutions/42.trapping-rain-water.kt
# - Downloading trapping-rain-water
#   ✔ Accepted
#   ✔ 324/324 cases passed (31 ms)
#   ✔ Your runtime beats 12.4 % of kotlin submissions
#   ✔ Your memory usage beats 8.33 % of kotlin submissions (57.2 MB)
# Submitting: kotlin_solutions/43.multiply-strings.kt
# - Downloading multiply-strings
#   ✔ Accepted
#   ✔ 311/311 cases passed (14 ms)
#   ✔ Your runtime beats 43.88 % of kotlin submissions
#   ✔ Your memory usage beats 94.9 % of kotlin submissions (42.4 MB)
# Submitting: kotlin_solutions/44.wildcard-matching.kt
# - Downloading wildcard-matching
#   ✔ Accepted
#   ✔ 1812/1812 cases passed (83 ms)
#   ✔ Your runtime beats 14.12 % of kotlin submissions
#   ✔ Your memory usage beats 32.94 % of kotlin submissions (50.4 MB)
# Submitting: kotlin_solutions/45.jump-game-ii.kt
# - Downloading jump-game-ii
#   ✔ Accepted
#   ✔ 110/110 cases passed (32 ms)
#   ✔ Your runtime beats 30.51 % of kotlin submissions
#   ✔ Your memory usage beats 39.32 % of kotlin submissions (49.1 MB)
# Submitting: kotlin_solutions/46.permutations.kt
# - Downloading permutations
#   ✔ Accepted
#   ✔ 26/26 cases passed (26 ms)
#   ✔ Your runtime beats 5.93 % of kotlin submissions
#   ✔ Your memory usage beats 10.05 % of kotlin submissions (49 MB)
# Submitting: kotlin_solutions/47.permutations-ii.kt
# - Downloading permutations-ii
#   ✔ Accepted
#   ✔ 33/33 cases passed (122 ms)
#   ✔ Your runtime beats 12.35 % of kotlin submissions
#   ✔ Your memory usage beats 5.88 % of kotlin submissions (56 MB)
# Submitting: kotlin_solutions/48.rotate-image.kt
# - Downloading rotate-image
#   ✔ Accepted
#   ✔ 21/21 cases passed (21 ms)
#   ✔ Your runtime beats 7.02 % of kotlin submissions
#   ✔ Your memory usage beats 7.37 % of kotlin submissions (46.2 MB)
# Submitting: kotlin_solutions/49.group-anagrams.kt
# - Downloading group-anagrams
#   ✔ Accepted
#   ✔ 128/128 cases passed (57 ms)
#   ✔ Your runtime beats 27.81 % of kotlin submissions
#   ✔ Your memory usage beats 18.57 % of kotlin submissions (55.7 MB)
# Submitting: kotlin_solutions/50.pow-x-n.kt
# - Downloading powx-n
#   ✔ Accepted
#   ✔ 307/307 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 81.36 % of kotlin submissions (41.7 MB)
# Submitting: kotlin_solutions/51.n-queens.kt
# - Downloading n-queens
#   ✔ Accepted
#   ✔ 9/9 cases passed (41 ms)
#   ✔ Your runtime beats 22.48 % of kotlin submissions
#   ✔ Your memory usage beats 11.63 % of kotlin submissions (53.3 MB)
# Submitting: kotlin_solutions/52.n-queens-ii.kt
# - Downloading n-queens-ii
#   ✔ Accepted
#   ✔ 9/9 cases passed (16 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 38.1 % of kotlin submissions (45.3 MB)
# Submitting: kotlin_solutions/53.maximum-subarray.kt
# - Downloading maximum-subarray
# [ERROR] Error: read ECONNRESET
# Submitting: kotlin_solutions/54.spiral-matrix.kt
# - Downloading spiral-matrix
#   ✔ Accepted
#   ✔ 26/26 cases passed (4 ms)
#   ✔ Your runtime beats 32.52 % of kotlin submissions
#   ✔ Your memory usage beats 67.48 % of kotlin submissions (40.8 MB)
# Submitting: kotlin_solutions/55.jump-game.kt
# - Downloading jump-game
#   ✔ Accepted
#   ✔ 178/178 cases passed (55 ms)
#   ✔ Your runtime beats 22.17 % of kotlin submissions
#   ✔ Your memory usage beats 5.06 % of kotlin submissions (54.2 MB)
# Submitting: kotlin_solutions/56.merge-intervals.kt
# - Downloading merge-intervals
#   ✔ Accepted
#   ✔ 172/172 cases passed (33 ms)
#   ✔ Your runtime beats 12.45 % of kotlin submissions
#   ✔ Your memory usage beats 21.26 % of kotlin submissions (61.3 MB)
# Submitting: kotlin_solutions/57.insert-interval.kt
# - Downloading insert-interval
#   ✔ Accepted
#   ✔ 158/158 cases passed (22 ms)
#   ✔ Your runtime beats 11.4 % of kotlin submissions
#   ✔ Your memory usage beats 14.01 % of kotlin submissions (50.4 MB)
# Submitting: kotlin_solutions/58.length-of-last-word.kt
# - Downloading length-of-last-word
#   ✔ Accepted
#   ✔ 60/60 cases passed (13 ms)
#   ✔ Your runtime beats 25.27 % of kotlin submissions
#   ✔ Your memory usage beats 9.09 % of kotlin submissions (43.9 MB)
# Submitting: kotlin_solutions/59.spiral-matrix-ii.kt
# - Downloading spiral-matrix-ii
#   ✔ Accepted
#   ✔ 20/20 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 51.67 % of kotlin submissions (41 MB)
# Submitting: kotlin_solutions/60.permutation-sequence.kt
# - Downloading permutation-sequence
#   ✔ Accepted
#   ✔ 200/200 cases passed (15 ms)
#   ✔ Your runtime beats 64.71 % of kotlin submissions
#   ✔ Your memory usage beats 52.94 % of kotlin submissions (42.9 MB)
# Submitting: kotlin_solutions/61.rotate-list.kt
# - Downloading rotate-list
#   ✔ Accepted
#   ✔ 232/232 cases passed (13 ms)
#   ✔ Your runtime beats 5.26 % of kotlin submissions
#   ✔ Your memory usage beats 10.53 % of kotlin submissions (45 MB)
# Submitting: kotlin_solutions/62.unique-paths.kt
# - Downloading unique-paths
#   ✔ Accepted
#   ✔ 64/64 cases passed (5 ms)
#   ✔ Your runtime beats 11.35 % of kotlin submissions
#   ✔ Your memory usage beats 10.74 % of kotlin submissions (41 MB)
# Submitting: kotlin_solutions/63.unique-paths-ii.kt
# - Downloading unique-paths-ii
#   ✔ Accepted
#   ✔ 42/42 cases passed (6 ms)
#   ✔ Your runtime beats 17.02 % of kotlin submissions
#   ✔ Your memory usage beats 48.23 % of kotlin submissions (42.1 MB)
# Submitting: kotlin_solutions/64.minimum-path-sum.kt
# - Downloading minimum-path-sum
#   ✔ Accepted
#   ✔ 66/66 cases passed (10 ms)
#   ✔ Your runtime beats 26.23 % of kotlin submissions
#   ✔ Your memory usage beats 43.72 % of kotlin submissions (52.4 MB)
# Submitting: kotlin_solutions/65.valid-number.kt
# - Downloading valid-number
#   ✔ Accepted
#   ✔ 1499/1499 cases passed (33 ms)
#   ✔ Your runtime beats 18.64 % of kotlin submissions
#   ✔ Your memory usage beats 35.59 % of kotlin submissions (46.8 MB)
# Submitting: kotlin_solutions/66.plus-one.kt
# - Downloading plus-one
#   ✔ Accepted
#   ✔ 114/114 cases passed (14 ms)
#   ✔ Your runtime beats 12.92 % of kotlin submissions
#   ✔ Your memory usage beats 11.62 % of kotlin submissions (45.9 MB)
# Submitting: kotlin_solutions/67.add-binary.kt
# - Downloading add-binary
#   ✔ Accepted
#   ✔ 296/296 cases passed (8 ms)
#   ✔ Your runtime beats 50.46 % of kotlin submissions
#   ✔ Your memory usage beats 57.49 % of kotlin submissions (42.8 MB)
# Submitting: kotlin_solutions/68.text-justification.kt
# - Downloading text-justification
#   ✔ Accepted
#   ✔ 29/29 cases passed (16 ms)
#   ✔ Your runtime beats 26.23 % of kotlin submissions
#   ✔ Your memory usage beats 26.23 % of kotlin submissions (44.1 MB)
# Submitting: kotlin_solutions/69.sqrt-x.kt
# - Downloading sqrtx
#   ✔ Accepted
#   ✔ 1019/1019 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 10.83 % of kotlin submissions (41.6 MB)
# Submitting: kotlin_solutions/70.climbing-stairs.kt
# - Downloading climbing-stairs
#   ✔ Accepted
#   ✔ 45/45 cases passed (3 ms)
#   ✔ Your runtime beats 9.42 % of kotlin submissions
#   ✔ Your memory usage beats 18.55 % of kotlin submissions (40.5 MB)
# Submitting: kotlin_solutions/71.simplify-path.kt
# - Downloading simplify-path
#   ✔ Accepted
#   ✔ 264/264 cases passed (19 ms)
#   ✔ Your runtime beats 71.01 % of kotlin submissions
#   ✔ Your memory usage beats 69.08 % of kotlin submissions (46.3 MB)
# Submitting: kotlin_solutions/72.edit-distance.kt
# - Downloading edit-distance
#   ✔ Accepted
#   ✔ 1149/1149 cases passed (5 ms)
#   ✔ Your runtime beats 90.45 % of kotlin submissions
#   ✔ Your memory usage beats 21.66 % of kotlin submissions (48.6 MB)
# Submitting: kotlin_solutions/73.set-matrix-zeroes.kt
# - Downloading set-matrix-zeroes
#   ✔ Accepted
#   ✔ 203/203 cases passed (99 ms)
#   ✔ Your runtime beats 6.67 % of kotlin submissions
#   ✔ Your memory usage beats 5.24 % of kotlin submissions (66.1 MB)
# Submitting: kotlin_solutions/74.search-a-2-d-matrix.kt
# - Downloading search-a-2d-matrix
#   ✔ Accepted
#   ✔ 133/133 cases passed (10 ms)
#   ✔ Your runtime beats 17.18 % of kotlin submissions
#   ✔ Your memory usage beats 21.99 % of kotlin submissions (45.3 MB)
# Submitting: kotlin_solutions/75.sort-colors.kt
# - Downloading sort-colors
#   ✔ Accepted
#   ✔ 89/89 cases passed (6 ms)
#   ✔ Your runtime beats 19.23 % of kotlin submissions
#   ✔ Your memory usage beats 38.46 % of kotlin submissions (41.6 MB)
# Submitting: kotlin_solutions/76.minimum-window-substring.kt
# - Downloading minimum-window-substring
#   ✔ Accepted
#   ✔ 268/268 cases passed (230 ms)
#   ✔ Your runtime beats 7.14 % of kotlin submissions
#   ✔ Your memory usage beats 23.71 % of kotlin submissions (53.1 MB)
# Submitting: kotlin_solutions/77.combinations.kt
# - Downloading combinations
#   ✔ Accepted
#   ✔ 27/27 cases passed (135 ms)
#   ✔ Your runtime beats 6.18 % of kotlin submissions
#   ✔ Your memory usage beats 8.43 % of kotlin submissions (139.9 MB)
# Submitting: kotlin_solutions/78.subsets.kt
# - Downloading subsets
#   ✔ Accepted
#   ✔ 10/10 cases passed (7 ms)
#   ✔ Your runtime beats 69.69 % of kotlin submissions
#   ✔ Your memory usage beats 27.2 % of kotlin submissions (44.6 MB)
# Submitting: kotlin_solutions/79.word-search.kt
# - Downloading word-search
#   ✔ Accepted
#   ✔ 88/88 cases passed (923 ms)
#   ✔ Your runtime beats 11.07 % of kotlin submissions
#   ✔ Your memory usage beats 30.54 % of kotlin submissions (50.1 MB)
# Submitting: kotlin_solutions/80.remove-duplicates-from-sorted-array-ii.kt
# - Downloading remove-duplicates-from-sorted-array-ii
#   ✔ Accepted
#   ✔ 170/170 cases passed (174 ms)
#   ✔ Your runtime beats 56.75 % of kotlin submissions
#   ✔ Your memory usage beats 18.75 % of kotlin submissions (50 MB)
# Submitting: kotlin_solutions/81.search-in-rotated-sorted-array-ii.kt
# - Downloading search-in-rotated-sorted-array-ii
#   ✔ Accepted
#   ✔ 283/283 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 70.34 % of kotlin submissions (43.8 MB)
# Submitting: kotlin_solutions/82.remove-duplicates-from-sorted-list-ii.kt
# - Downloading remove-duplicates-from-sorted-list-ii
#   ✔ Accepted
#   ✔ 166/166 cases passed (9 ms)
#   ✔ Your runtime beats 9.17 % of kotlin submissions
#   ✔ Your memory usage beats 6.67 % of kotlin submissions (46.4 MB)
# Submitting: kotlin_solutions/83.remove-duplicates-from-sorted-list.kt
# - Downloading remove-duplicates-from-sorted-list
#   ✔ Accepted
#   ✔ 168/168 cases passed (9 ms)
#   ✔ Your runtime beats 6.12 % of kotlin submissions
#   ✔ Your memory usage beats 5.78 % of kotlin submissions (46.2 MB)
# Submitting: kotlin_solutions/84.largest-rectangle-in-histogram.kt
# - Downloading largest-rectangle-in-histogram
#   ✔ Accepted
#   ✔ 99/99 cases passed (74 ms)
#   ✔ Your runtime beats 21.79 % of kotlin submissions
#   ✔ Your memory usage beats 63.04 % of kotlin submissions (63.1 MB)
# Submitting: kotlin_solutions/85.maximal-rectangle.kt
# - Downloading maximal-rectangle
#   ✔ Accepted
#   ✔ 76/76 cases passed (78 ms)
#   ✔ Your runtime beats 9.52 % of kotlin submissions
#   ✔ Your memory usage beats 57.14 % of kotlin submissions (53.5 MB)
# Submitting: kotlin_solutions/86.partition-list.kt
# - Downloading partition-list
#   ✔ Accepted
#   ✔ 168/168 cases passed (8 ms)
#   ✔ Your runtime beats 11.11 % of kotlin submissions
#   ✔ Your memory usage beats 9.52 % of kotlin submissions (43.1 MB)
# Submitting: kotlin_solutions/87.scramble-string.kt
# - Downloading scramble-string
#   ✔ Accepted
#   ✔ 290/290 cases passed (54 ms)
#   ✔ Your runtime beats 13.33 % of kotlin submissions
#   ✔ Your memory usage beats 60 % of kotlin submissions (51 MB)
# Submitting: kotlin_solutions/88.merge-sorted-array.kt
# - Downloading merge-sorted-array
#   ✔ Accepted
#   ✔ 59/59 cases passed (9 ms)
#   ✔ Your runtime beats 10.44 % of kotlin submissions
#   ✔ Your memory usage beats 16.75 % of kotlin submissions (43.1 MB)
# Submitting: kotlin_solutions/89.gray-code.kt
# - Downloading gray-code
#   ✔ Accepted
#   ✔ 16/16 cases passed (16 ms)
#   ✔ Your runtime beats 43.24 % of kotlin submissions
#   ✔ Your memory usage beats 77.03 % of kotlin submissions (52.7 MB)
# Submitting: kotlin_solutions/90.subsets-ii.kt
# - Downloading subsets-ii
#   ✔ Accepted
#   ✔ 20/20 cases passed (20 ms)
#   ✔ Your runtime beats 12.9 % of kotlin submissions
#   ✔ Your memory usage beats 27.1 % of kotlin submissions (47.9 MB)
# Submitting: kotlin_solutions/91.decode-ways.kt
# - Downloading decode-ways
#   ✔ Accepted
#   ✔ 269/269 cases passed (11 ms)
#   ✔ Your runtime beats 21.48 % of kotlin submissions
#   ✔ Your memory usage beats 16.11 % of kotlin submissions (43.4 MB)
# Submitting: kotlin_solutions/92.reverse-linked-list-ii.kt
# - Downloading reverse-linked-list-ii
#   ✔ Accepted
#   ✔ 44/44 cases passed (4 ms)
#   ✔ Your runtime beats 8.93 % of kotlin submissions
#   ✔ Your memory usage beats 5.36 % of kotlin submissions (41.8 MB)
# Submitting: kotlin_solutions/93.restore-ip-addresses.kt
# - Downloading restore-ip-addresses
#   ✔ Accepted
#   ✔ 146/146 cases passed (27 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 15.48 % of kotlin submissions (47.9 MB)
# Submitting: kotlin_solutions/94.binary-tree-inorder-traversal.kt
# - Downloading binary-tree-inorder-traversal
#   ✔ Accepted
#   ✔ 71/71 cases passed (10 ms)
#   ✔ Your runtime beats 6.63 % of kotlin submissions
#   ✔ Your memory usage beats 39.8 % of kotlin submissions (41.8 MB)
# Submitting: kotlin_solutions/95.unique-binary-search-trees-ii.kt
# - Downloading unique-binary-search-trees-ii
#   ✔ Accepted
#   ✔ 8/8 cases passed (13 ms)
#   ✔ Your runtime beats 16.22 % of kotlin submissions
#   ✔ Your memory usage beats 70.27 % of kotlin submissions (45.8 MB)
# Submitting: kotlin_solutions/96.unique-binary-search-trees.kt
# - Downloading unique-binary-search-trees
#   ✔ Accepted
#   ✔ 19/19 cases passed (3106 ms)
#   ✔ Your runtime beats 8.82 % of kotlin submissions
#   ✔ Your memory usage beats 7.35 % of kotlin submissions (44.7 MB)
# Submitting: kotlin_solutions/97.interleaving-string.kt
# - Downloading interleaving-string
#   ✔ Accepted
#   ✔ 107/107 cases passed (1635 ms)
#   ✔ Your runtime beats 5.49 % of kotlin submissions
#   ✔ Your memory usage beats 21.98 % of kotlin submissions (43.6 MB)
# Submitting: kotlin_solutions/98.validate-binary-search-tree.kt
# - Downloading validate-binary-search-tree
#   ✔ Accepted
#   ✔ 86/86 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 35.47 % of kotlin submissions (45.7 MB)
# Submitting: kotlin_solutions/99.recover-binary-search-tree.kt
# - Downloading recover-binary-search-tree
#   ✔ Accepted
#   ✔ 1919/1919 cases passed (5 ms)
#   ✔ Your runtime beats 40 % of kotlin submissions
#   ✔ Your memory usage beats 16.67 % of kotlin submissions (49.3 MB)
# Submitting: kotlin_solutions/100.same-tree.kt
# - Downloading same-tree
#   ✔ Accepted
#   ✔ 67/67 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 83.15 % of kotlin submissions (40.5 MB)

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-03-17 14:23:58
