# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME_3')
    user_cookie = userdata.get('LEETCODE_TOKEN_3')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME_2'] = user_name
    os.environ['LEETCODE_TOKEN_2'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME_2" "$LEETCODE_TOKEN_2" | leetcode user -c

# %%
# %%bash
#
# # top 200-300 answers (next batch)
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v kotlin_solutions/*.kt | sed -n '201,300p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 7
# done
# Out:
# Submitting: kotlin_solutions/225.implement-stack-using-queues.kt
# - Downloading problems
# - Downloading implement-stack-using-queues
#   ✔ Accepted
#   ✔ 20/20 cases passed (25 ms)
#   ✔ Your runtime beats 29.9 % of kotlin submissions
#   ✔ Your memory usage beats 48.45 % of kotlin submissions (46 MB)
# Submitting: kotlin_solutions/226.invert-binary-tree.kt
# - Downloading invert-binary-tree
#   ✔ Accepted
#   ✔ 77/77 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 88.51 % of kotlin submissions (40.4 MB)
# Submitting: kotlin_solutions/227.basic-calculator-ii.kt
# - Downloading basic-calculator-ii
#   ✔ Accepted
#   ✔ 111/111 cases passed (64 ms)
#   ✔ Your runtime beats 17.31 % of kotlin submissions
#   ✔ Your memory usage beats 23.08 % of kotlin submissions (53 MB)
# Submitting: kotlin_solutions/228.summary-ranges.kt
# - Downloading summary-ranges
#   ✔ Accepted
#   ✔ 34/34 cases passed (16 ms)
#   ✔ Your runtime beats 6.02 % of kotlin submissions
#   ✔ Your memory usage beats 26.39 % of kotlin submissions (42.2 MB)
# Submitting: kotlin_solutions/229.majority-element-ii.kt
# - Downloading majority-element-ii
#   ✔ Accepted
#   ✔ 95/95 cases passed (20 ms)
#   ✔ Your runtime beats 45.45 % of kotlin submissions
#   ✔ Your memory usage beats 5.45 % of kotlin submissions (56.5 MB)
# Submitting: kotlin_solutions/230.kth-smallest-element-in-a-bst.kt
# - Downloading kth-smallest-element-in-a-bst
#   ✔ Accepted
#   ✔ 93/93 cases passed (26 ms)
#   ✔ Your runtime beats 7.09 % of kotlin submissions
#   ✔ Your memory usage beats 5.67 % of kotlin submissions (50.8 MB)
# Submitting: kotlin_solutions/231.power-of-two.kt
# - Downloading power-of-two
#   ✔ Accepted
#   ✔ 1110/1110 cases passed (1 ms)
#   ✔ Your runtime beats 56.52 % of kotlin submissions
#   ✔ Your memory usage beats 46.96 % of kotlin submissions (41 MB)
# Submitting: kotlin_solutions/232.implement-queue-using-stacks.kt
# - Downloading implement-queue-using-stacks
#   ✔ Accepted
#   ✔ 22/22 cases passed (17 ms)
#   ✔ Your runtime beats 49.74 % of kotlin submissions
#   ✔ Your memory usage beats 64.25 % of kotlin submissions (42.8 MB)
# Submitting: kotlin_solutions/233.number-of-digit-one.kt
# - Downloading number-of-digit-one
#   ✔ Accepted
#   ✔ 38/38 cases passed (8 ms)
#   ✔ Your runtime beats 12.5 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (40.4 MB)
# Submitting: kotlin_solutions/234.palindrome-linked-list.kt
# - Downloading palindrome-linked-list
#   ✔ Accepted
#   ✔ 93/93 cases passed (47 ms)
#   ✔ Your runtime beats 6.45 % of kotlin submissions
#   ✔ Your memory usage beats 23.39 % of kotlin submissions (62.8 MB)
# Submitting: kotlin_solutions/235.lowest-common-ancestor-of-a-binary-search-tree.kt
# - Downloading lowest-common-ancestor-of-a-binary-search-tree
#   ✔ Accepted
#   ✔ 30/30 cases passed (177 ms)
#   ✔ Your runtime beats 91.93 % of kotlin submissions
#   ✔ Your memory usage beats 44.56 % of kotlin submissions (48.1 MB)
# Submitting: kotlin_solutions/236.lowest-common-ancestor-of-a-binary-tree.kt
# - Downloading lowest-common-ancestor-of-a-binary-tree
#   ✔ Accepted
#   ✔ 32/32 cases passed (178 ms)
#   ✔ Your runtime beats 19.26 % of kotlin submissions
#   ✔ Your memory usage beats 16.62 % of kotlin submissions (48.1 MB)
# Submitting: kotlin_solutions/237.delete-node-in-a-linked-list.kt
# - Downloading delete-node-in-a-linked-list
#   ✔ Accepted
#   ✔ 41/41 cases passed (153 ms)
#   ✔ Your runtime beats 5.05 % of kotlin submissions
#   ✔ Your memory usage beats 6.06 % of kotlin submissions (44.4 MB)
# Submitting: kotlin_solutions/238.product-of-array-except-self.kt
# - Downloading product-of-array-except-self
#   ✔ Accepted
#   ✔ 24/24 cases passed (48 ms)
#   ✔ Your runtime beats 5.44 % of kotlin submissions
#   ✔ Your memory usage beats 5.06 % of kotlin submissions (65.2 MB)
# Submitting: kotlin_solutions/239.sliding-window-maximum.kt
# - Downloading sliding-window-maximum
#   ✔ Accepted
#   ✔ 52/52 cases passed (101 ms)
#   ✔ Your runtime beats 22.11 % of kotlin submissions
#   ✔ Your memory usage beats 5.03 % of kotlin submissions (70.8 MB)
# Submitting: kotlin_solutions/240.search-a-2-d-matrix-ii.kt
# - Downloading search-a-2d-matrix-ii
#   ✔ Accepted
#   ✔ 130/130 cases passed (184 ms)
#   ✔ Your runtime beats 96.47 % of kotlin submissions
#   ✔ Your memory usage beats 96.47 % of kotlin submissions (48.9 MB)
# Submitting: kotlin_solutions/241.different-ways-to-add-parentheses.kt
# - Downloading different-ways-to-add-parentheses
#   ✔ Accepted
#   ✔ 25/25 cases passed (19 ms)
#   ✔ Your runtime beats 30.77 % of kotlin submissions
#   ✔ Your memory usage beats 46.15 % of kotlin submissions (44.4 MB)
# Submitting: kotlin_solutions/242.valid-anagram.kt
# - Downloading valid-anagram
#   ✔ Accepted
#   ✔ 54/54 cases passed (17 ms)
#   ✔ Your runtime beats 62.2 % of kotlin submissions
#   ✔ Your memory usage beats 22.95 % of kotlin submissions (46.5 MB)
# Submitting: kotlin_solutions/257.binary-tree-paths.kt
# - Downloading binary-tree-paths
#   ✔ Accepted
#   ✔ 208/208 cases passed (33 ms)
#   ✔ Your runtime beats 7.63 % of kotlin submissions
#   ✔ Your memory usage beats 5.08 % of kotlin submissions (47 MB)
# Submitting: kotlin_solutions/258.add-digits.kt
# - Downloading add-digits
#   ✔ Accepted
#   ✔ 1101/1101 cases passed (1 ms)
#   ✔ Your runtime beats 54.76 % of kotlin submissions
#   ✔ Your memory usage beats 47.62 % of kotlin submissions (41.2 MB)
# Submitting: kotlin_solutions/260.single-number-iii.kt
# - Downloading single-number-iii
#   ✔ Accepted
#   ✔ 35/35 cases passed (16 ms)
#   ✔ Your runtime beats 14.29 % of kotlin submissions
#   ✔ Your memory usage beats 28.57 % of kotlin submissions (47.1 MB)
# Submitting: kotlin_solutions/263.ugly-number.kt
# - Downloading ugly-number
#   ✔ Accepted
#   ✔ 1013/1013 cases passed (10 ms)
#   ✔ Your runtime beats 30.95 % of kotlin submissions
#   ✔ Your memory usage beats 26.19 % of kotlin submissions (42.5 MB)
# Submitting: kotlin_solutions/264.ugly-number-ii.kt
# - Downloading ugly-number-ii
#   ✔ Accepted
#   ✔ 596/596 cases passed (46 ms)
#   ✔ Your runtime beats 37.5 % of kotlin submissions
#   ✔ Your memory usage beats 6.25 % of kotlin submissions (51.7 MB)
# Submitting: kotlin_solutions/268.missing-number.kt
# - Downloading missing-number
#   ✔ Accepted
#   ✔ 122/122 cases passed (10 ms)
#   ✔ Your runtime beats 52.08 % of kotlin submissions
#   ✔ Your memory usage beats 76.59 % of kotlin submissions (47.6 MB)
# Submitting: kotlin_solutions/273.integer-to-english-words.kt
# - Downloading integer-to-english-words
#   ✔ Accepted
#   ✔ 601/601 cases passed (34 ms)
#   ✔ Your runtime beats 8.33 % of kotlin submissions
#   ✔ Your memory usage beats 20.83 % of kotlin submissions (47.2 MB)
# Submitting: kotlin_solutions/274.h-index.kt
# - Downloading h-index
#   ✔ Accepted
#   ✔ 83/83 cases passed (23 ms)
#   ✔ Your runtime beats 10 % of kotlin submissions
#   ✔ Your memory usage beats 7.69 % of kotlin submissions (46.4 MB)
# Submitting: kotlin_solutions/275.h-index-ii.kt
# - Downloading h-index-ii
#   ✔ Accepted
#   ✔ 83/83 cases passed (20 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 30.77 % of kotlin submissions (53.1 MB)
# Submitting: kotlin_solutions/278.first-bad-version.kt
# - Downloading first-bad-version
#   ✔ Accepted
#   ✔ 24/24 cases passed (213 ms)
#   ✔ Your runtime beats 26.2 % of kotlin submissions
#   ✔ Your memory usage beats 12.23 % of kotlin submissions (39.6 MB)
# Submitting: kotlin_solutions/279.perfect-squares.kt
# - Downloading perfect-squares
#   ✔ Accepted
#   ✔ 589/589 cases passed (44 ms)
#   ✔ Your runtime beats 43.24 % of kotlin submissions
#   ✔ Your memory usage beats 59.46 % of kotlin submissions (45.5 MB)
# Submitting: kotlin_solutions/282.expression-add-operators.kt
# - Downloading expression-add-operators
#   ✔ Accepted
#   ✔ 25/25 cases passed (94 ms)
#   ✔ Your runtime beats 92.31 % of kotlin submissions
#   ✔ Your memory usage beats 92.31 % of kotlin submissions (55.9 MB)
# Submitting: kotlin_solutions/283.move-zeroes.kt
# - Downloading move-zeroes
#   ✔ Accepted
#   ✔ 75/75 cases passed (20 ms)
#   ✔ Your runtime beats 13.2 % of kotlin submissions
#   ✔ Your memory usage beats 5.71 % of kotlin submissions (52.7 MB)
# Submitting: kotlin_solutions/284.peeking-iterator.kt
# - Downloading peeking-iterator
#   ✔ Accepted
#   ✔ 15/15 cases passed (128 ms)
#   ✔ Your runtime beats 21.43 % of kotlin submissions
#   ✔ Your memory usage beats 7.14 % of kotlin submissions (43.8 MB)
# Submitting: kotlin_solutions/287.find-the-duplicate-number.kt
# - Downloading find-the-duplicate-number
#   ✔ Accepted
#   ✔ 59/59 cases passed (49 ms)
#   ✔ Your runtime beats 11.35 % of kotlin submissions
#   ✔ Your memory usage beats 85.95 % of kotlin submissions (62.2 MB)
# Submitting: kotlin_solutions/289.game-of-life.kt
# - Downloading game-of-life
#   ✔ Accepted
#   ✔ 23/23 cases passed (21 ms)
#   ✔ Your runtime beats 6.15 % of kotlin submissions
#   ✔ Your memory usage beats 7.69 % of kotlin submissions (46.2 MB)
# Submitting: kotlin_solutions/290.word-pattern.kt
# - Downloading word-pattern
#   ✔ Accepted
#   ✔ 44/44 cases passed (15 ms)
#   ✔ Your runtime beats 10.14 % of kotlin submissions
#   ✔ Your memory usage beats 5.4 % of kotlin submissions (43.4 MB)
# Submitting: kotlin_solutions/292.nim-game.kt
# - Downloading nim-game
#   ✔ Accepted
#   ✔ 60/60 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 24.14 % of kotlin submissions (40.2 MB)
# Submitting: kotlin_solutions/295.find-median-from-data-stream.kt
# - Downloading find-median-from-data-stream
#   ✔ Accepted
#   ✔ 22/22 cases passed (548 ms)
#   ✔ Your runtime beats 7.93 % of kotlin submissions
#   ✔ Your memory usage beats 46.7 % of kotlin submissions (110.3 MB)
# Submitting: kotlin_solutions/297.serialize-and-deserialize-binary-tree.kt
# - Downloading serialize-and-deserialize-binary-tree
#   ✔ Accepted
#   ✔ 53/53 cases passed (291 ms)
#   ✔ Your runtime beats 6.54 % of kotlin submissions
#   ✔ Your memory usage beats 41.83 % of kotlin submissions (50.1 MB)
# Submitting: kotlin_solutions/299.bulls-and-cows.kt
# - Downloading bulls-and-cows
#   ✔ Accepted
#   ✔ 152/152 cases passed (25 ms)
#   ✔ Your runtime beats 12 % of kotlin submissions
#   ✔ Your memory usage beats 8 % of kotlin submissions (47.1 MB)
# Submitting: kotlin_solutions/300.longest-increasing-subsequence.kt
# - Downloading longest-increasing-subsequence
#   ✔ Accepted
#   ✔ 56/56 cases passed (15 ms)
#   ✔ Your runtime beats 85.28 % of kotlin submissions
#   ✔ Your memory usage beats 69.7 % of kotlin submissions (47.6 MB)
# Submitting: kotlin_solutions/301.remove-invalid-parentheses.kt
# - Downloading remove-invalid-parentheses
#   ✔ Accepted
#   ✔ 129/129 cases passed (1377 ms)
#   ✔ Your runtime beats 5.56 % of kotlin submissions
#   ✔ Your memory usage beats 5.56 % of kotlin submissions (65.6 MB)
# Submitting: kotlin_solutions/303.range-sum-query-immutable.kt
# - Downloading range-sum-query-immutable
#   ✔ Accepted
#   ✔ 15/15 cases passed (25 ms)
#   ✔ Your runtime beats 57.87 % of kotlin submissions
#   ✔ Your memory usage beats 72.68 % of kotlin submissions (51.5 MB)
# Submitting: kotlin_solutions/304.range-sum-query-2-d-immutable.kt
# - Downloading range-sum-query-2d-immutable
#   ✔ Accepted
#   ✔ 22/22 cases passed (164 ms)
#   ✔ Your runtime beats 28.3 % of kotlin submissions
#   ✔ Your memory usage beats 52.83 % of kotlin submissions (95.5 MB)
# Submitting: kotlin_solutions/306.additive-number.kt
# - Downloading additive-number
#   ✔ Accepted
#   ✔ 47/47 cases passed (15 ms)
#   ✔ Your runtime beats 11.11 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (42.5 MB)
# Submitting: kotlin_solutions/307.range-sum-query-mutable.kt
# - Downloading range-sum-query-mutable
#   ✔ Accepted
#   ✔ 16/16 cases passed (170 ms)
#   ✔ Your runtime beats 37.93 % of kotlin submissions
#   ✔ Your memory usage beats 53.45 % of kotlin submissions (95 MB)
# Submitting: kotlin_solutions/309.best-time-to-buy-and-sell-stock-with-cooldown.kt
# - Downloading best-time-to-buy-and-sell-stock-with-cooldown
#   ✔ Accepted
#   ✔ 210/210 cases passed (19 ms)
#   ✔ Your runtime beats 6.67 % of kotlin submissions
#   ✔ Your memory usage beats 6.67 % of kotlin submissions (47.1 MB)
# Submitting: kotlin_solutions/310.minimum-height-trees.kt
# - Downloading minimum-height-trees
#   ✔ Accepted
#   ✔ 71/71 cases passed (60 ms)
#   ✔ Your runtime beats 27.45 % of kotlin submissions
#   ✔ Your memory usage beats 9.8 % of kotlin submissions (78.9 MB)
# Submitting: kotlin_solutions/312.burst-balloons.kt
# - Downloading burst-balloons
#   ✔ Accepted
#   ✔ 73/73 cases passed (172 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
#   ✔ Your memory usage beats 17.14 % of kotlin submissions (51.9 MB)
# Submitting: kotlin_solutions/313.super-ugly-number.kt
# - Downloading super-ugly-number
#   ✔ Accepted
#   ✔ 87/87 cases passed (106 ms)
#   ✔ Your runtime beats 30.77 % of kotlin submissions
#   ✔ Your memory usage beats 53.85 % of kotlin submissions (49.4 MB)
# Submitting: kotlin_solutions/315.count-of-smaller-numbers-after-self.kt
# - Downloading count-of-smaller-numbers-after-self
#   ✔ Accepted
#   ✔ 66/66 cases passed (307 ms)
#   ✔ Your runtime beats 22.73 % of kotlin submissions
#   ✔ Your memory usage beats 27.27 % of kotlin submissions (71.3 MB)
# Submitting: kotlin_solutions/316.remove-duplicate-letters.kt
# - Downloading remove-duplicate-letters
#   ✔ Accepted
#   ✔ 290/290 cases passed (43 ms)
#   ✔ Your runtime beats 6.25 % of kotlin submissions
#   ✔ Your memory usage beats 16.67 % of kotlin submissions (47.5 MB)
# Submitting: kotlin_solutions/318.maximum-product-of-word-lengths.kt
# - Downloading maximum-product-of-word-lengths
#   ✔ Accepted
#   ✔ 168/168 cases passed (2007 ms)
#   ✔ Your runtime beats 10 % of kotlin submissions
#   ✔ Your memory usage beats 10 % of kotlin submissions (140.8 MB)
# Submitting: kotlin_solutions/319.bulb-switcher.kt
# - Downloading bulb-switcher
#   ✔ Accepted
#   ✔ 35/35 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 75 % of kotlin submissions (39.6 MB)
# Submitting: kotlin_solutions/321.create-maximum-number.kt
# - Downloading create-maximum-number
#   ✔ Accepted
#   ✔ 102/102 cases passed (95 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (55.1 MB)
# Submitting: kotlin_solutions/322.coin-change.kt
# - Downloading coin-change
#   ✔ Accepted
#   ✔ 189/189 cases passed (21 ms)
#   ✔ Your runtime beats 51.88 % of kotlin submissions
#   ✔ Your memory usage beats 43.01 % of kotlin submissions (45.8 MB)
# Submitting: kotlin_solutions/324.wiggle-sort-ii.kt
# - Downloading wiggle-sort-ii
#   ✔ Accepted
#   ✔ 52/52 cases passed (32 ms)
#   ✔ Your runtime beats 36 % of kotlin submissions
#   ✔ Your memory usage beats 96 % of kotlin submissions (50.8 MB)
# Submitting: kotlin_solutions/326.power-of-three.kt
# - Downloading power-of-three
#   ✔ Accepted
#   ✔ 21040/21040 cases passed (7 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 73.61 % of kotlin submissions (46.2 MB)
# Submitting: kotlin_solutions/327.count-of-range-sum.kt
# - Downloading count-of-range-sum
#   ✔ Accepted
#   ✔ 67/67 cases passed (115 ms)
#   ✔ Your runtime beats 73.33 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (62.3 MB)
# Submitting: kotlin_solutions/328.odd-even-linked-list.kt
# - Downloading odd-even-linked-list
#   ✔ Accepted
#   ✔ 70/70 cases passed (8 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 27.33 % of kotlin submissions (45.4 MB)
# Submitting: kotlin_solutions/329.longest-increasing-path-in-a-matrix.kt
# - Downloading longest-increasing-path-in-a-matrix
#   ✔ Accepted
#   ✔ 139/139 cases passed (89 ms)
#   ✔ Your runtime beats 8.79 % of kotlin submissions
#   ✔ Your memory usage beats 23.08 % of kotlin submissions (54.6 MB)
# Submitting: kotlin_solutions/330.patching-array.kt
# - Downloading patching-array
#   ✔ Accepted
#   ✔ 150/150 cases passed (10 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/331.verify-preorder-serialization-of-a-binary-tree.kt
# - Downloading verify-preorder-serialization-of-a-binary-tree
#   ✔ Accepted
#   ✔ 152/152 cases passed (22 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (45.3 MB)
# Submitting: kotlin_solutions/332.reconstruct-itinerary.kt
# - Downloading reconstruct-itinerary
#   ✔ Accepted
#   ✔ 82/82 cases passed (57 ms)
#   ✔ Your runtime beats 5.88 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (51.2 MB)
# Submitting: kotlin_solutions/334.increasing-triplet-subsequence.kt
# - Downloading increasing-triplet-subsequence
#   ✔ Accepted
#   ✔ 86/86 cases passed (31 ms)
#   ✔ Your runtime beats 7.41 % of kotlin submissions
#   ✔ Your memory usage beats 91.67 % of kotlin submissions (128.5 MB)
# Submitting: kotlin_solutions/335.self-crossing.kt
# - Downloading self-crossing
#   ✔ Accepted
#   ✔ 31/31 cases passed (43 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/336.palindrome-pairs.kt
# - Downloading palindrome-pairs
#   ✔ Accepted
#   ✔ 136/136 cases passed (1107 ms)
#   ✔ Your runtime beats 11.11 % of kotlin submissions
#   ✔ Your memory usage beats 77.78 % of kotlin submissions (89.2 MB)
# Submitting: kotlin_solutions/337.house-robber-iii.kt
# - Downloading house-robber-iii
#   ✔ Accepted
#   ✔ 124/124 cases passed (19 ms)
#   ✔ Your runtime beats 7.14 % of kotlin submissions
#   ✔ Your memory usage beats 61.9 % of kotlin submissions (45.9 MB)
# Submitting: kotlin_solutions/338.counting-bits.kt
# - Downloading counting-bits
#   ✔ Accepted
#   ✔ 15/15 cases passed (2 ms)
#   ✔ Your runtime beats 87.57 % of kotlin submissions
#   ✔ Your memory usage beats 7.69 % of kotlin submissions (52.2 MB)
# Submitting: kotlin_solutions/341.flatten-nested-list-iterator.kt
# - Downloading flatten-nested-list-iterator
#   ✔ Accepted
#   ✔ 43/43 cases passed (174 ms)
#   ✔ Your runtime beats 14.29 % of kotlin submissions
#   ✔ Your memory usage beats 28.57 % of kotlin submissions (48.2 MB)
# Submitting: kotlin_solutions/342.power-of-four.kt
# - Downloading power-of-four
#   ✔ Accepted
#   ✔ 1063/1063 cases passed (1 ms)
#   ✔ Your runtime beats 53.33 % of kotlin submissions
#   ✔ Your memory usage beats 80 % of kotlin submissions (40.7 MB)
# Submitting: kotlin_solutions/343.integer-break.kt
# - Downloading integer-break
#   ✔ Accepted
#   ✔ 50/50 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 65.22 % of kotlin submissions (39.9 MB)
# Submitting: kotlin_solutions/344.reverse-string.kt
# - Downloading reverse-string
#   ✔ Accepted
#   ✔ 477/477 cases passed (6 ms)
#   ✔ Your runtime beats 23.95 % of kotlin submissions
#   ✔ Your memory usage beats 66.08 % of kotlin submissions (54.4 MB)
# Submitting: kotlin_solutions/345.reverse-vowels-of-a-string.kt
# - Downloading reverse-vowels-of-a-string
#   ✔ Accepted
#   ✔ 480/480 cases passed (34 ms)
#   ✔ Your runtime beats 15.38 % of kotlin submissions
#   ✔ Your memory usage beats 10.58 % of kotlin submissions (50.5 MB)
# Submitting: kotlin_solutions/347.top-k-frequent-elements.kt
# - Downloading top-k-frequent-elements
#   ✔ Accepted
#   ✔ 23/23 cases passed (24 ms)
#   ✔ Your runtime beats 51.4 % of kotlin submissions
#   ✔ Your memory usage beats 76.59 % of kotlin submissions (50.7 MB)
# Submitting: kotlin_solutions/349.intersection-of-two-arrays.kt
# - Downloading intersection-of-two-arrays
#   ✔ Accepted
#   ✔ 57/57 cases passed (25 ms)
#   ✔ Your runtime beats 5.45 % of kotlin submissions
#   ✔ Your memory usage beats 13.18 % of kotlin submissions (47.2 MB)
# Submitting: kotlin_solutions/350.intersection-of-two-arrays-ii.kt
# - Downloading intersection-of-two-arrays-ii
#   ✔ Accepted
#   ✔ 61/61 cases passed (17 ms)
#   ✔ Your runtime beats 28.18 % of kotlin submissions
#   ✔ Your memory usage beats 38.67 % of kotlin submissions (46 MB)
# Submitting: kotlin_solutions/352.data-stream-as-disjoint-intervals.kt
# - Downloading data-stream-as-disjoint-intervals
#   ✔ Accepted
#   ✔ 8/8 cases passed (61 ms)
#   ✔ Your runtime beats 7.41 % of kotlin submissions
#   ✔ Your memory usage beats 7.41 % of kotlin submissions (48 MB)
# Submitting: kotlin_solutions/354.russian-doll-envelopes.kt
# - Downloading russian-doll-envelopes
#   ✔ Accepted
#   ✔ 87/87 cases passed (111 ms)
#   ✔ Your runtime beats 7.69 % of kotlin submissions
#   ✔ Your memory usage beats 46.15 % of kotlin submissions (118.1 MB)
# Submitting: kotlin_solutions/355.design-twitter.kt
# - Downloading design-twitter
#   ✔ Accepted
#   ✔ 18/18 cases passed (99 ms)
#   ✔ Your runtime beats 24.45 % of kotlin submissions
#   ✔ Your memory usage beats 30 % of kotlin submissions (68.4 MB)
# Submitting: kotlin_solutions/357.count-numbers-with-unique-digits.kt
# - Downloading count-numbers-with-unique-digits
#   ✔ Accepted
#   ✔ 9/9 cases passed (3 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (40.2 MB)
# Submitting: kotlin_solutions/363.max-sum-of-rectangle-no-larger-than-k.kt
# - Downloading max-sum-of-rectangle-no-larger-than-k
#   ✔ Accepted
#   ✔ 36/36 cases passed (434 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/365.water-and-jug-problem.kt
# - Downloading water-and-jug-problem
#   ✔ Accepted
#   ✔ 32/32 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 80 % of kotlin submissions (40.1 MB)
# Submitting: kotlin_solutions/367.valid-perfect-square.kt
# - Downloading valid-perfect-square
#   ✔ Accepted
#   ✔ 72/72 cases passed (12 ms)
#   ✔ Your runtime beats 10.45 % of kotlin submissions
#   ✔ Your memory usage beats 5.97 % of kotlin submissions (44.9 MB)
# Submitting: kotlin_solutions/368.largest-divisible-subset.kt
# - Downloading largest-divisible-subset
#   ✔ Accepted
#   ✔ 49/49 cases passed (91 ms)
#   ✔ Your runtime beats 9.09 % of kotlin submissions
#   ✔ Your memory usage beats 9.09 % of kotlin submissions (52.9 MB)
# Submitting: kotlin_solutions/371.sum-of-two-integers.kt
# - Downloading sum-of-two-integers
#   ✔ Accepted
#   ✔ 31/31 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 17.39 % of kotlin submissions (40.5 MB)
# Submitting: kotlin_solutions/372.super-pow.kt
# - Downloading super-pow
#   ✔ Accepted
#   ✔ 57/57 cases passed (46 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/373.find-k-pairs-with-smallest-sums.kt
# - Downloading find-k-pairs-with-smallest-sums
#   ✔ Accepted
#   ✔ 31/31 cases passed (74 ms)
#   ✔ Your runtime beats 45.52 % of kotlin submissions
#   ✔ Your memory usage beats 17.16 % of kotlin submissions (77.3 MB)
# Submitting: kotlin_solutions/374.guess-number-higher-or-lower.kt
# - Downloading guess-number-higher-or-lower
#   ✔ Accepted
#   ✔ 25/25 cases passed (64 ms)
#   ✔ Your runtime beats 85.63 % of kotlin submissions
#   ✔ Your memory usage beats 37.5 % of kotlin submissions (39.3 MB)
# Submitting: kotlin_solutions/375.guess-number-higher-or-lower-ii.kt
# - Downloading guess-number-higher-or-lower-ii
#   ✔ Accepted
#   ✔ 27/27 cases passed (51 ms)
#   ✔ Your runtime beats 40 % of kotlin submissions
#   ✔ Your memory usage beats 10 % of kotlin submissions (47.9 MB)
# Submitting: kotlin_solutions/376.wiggle-subsequence.kt
# - Downloading wiggle-subsequence
#   ✔ Accepted
#   ✔ 32/32 cases passed (20 ms)
#   ✔ Your runtime beats 25.81 % of kotlin submissions
#   ✔ Your memory usage beats 19.35 % of kotlin submissions (46 MB)
# Submitting: kotlin_solutions/377.combination-sum-iv.kt
# - Downloading combination-sum-iv
#   ✔ Accepted
#   ✔ 17/17 cases passed (90 ms)
#   ✔ Your runtime beats 36.59 % of kotlin submissions
#   ✔ Your memory usage beats 97.56 % of kotlin submissions (39.4 MB)
# Submitting: kotlin_solutions/378.kth-smallest-element-in-a-sorted-matrix.kt
# - Downloading kth-smallest-element-in-a-sorted-matrix
#   ✔ Accepted
#   ✔ 87/87 cases passed (39 ms)
#   ✔ Your runtime beats 12.25 % of kotlin submissions
#   ✔ Your memory usage beats 8.16 % of kotlin submissions (56.3 MB)
# Submitting: kotlin_solutions/380.insert-delete-get-random-o-1.kt
# - Downloading insert-delete-getrandom-o1
#   ✔ Accepted
#   ✔ 21/21 cases passed (148 ms)
#   ✔ Your runtime beats 15.3 % of kotlin submissions
#   ✔ Your memory usage beats 12.57 % of kotlin submissions (120.3 MB)
# Submitting: kotlin_solutions/381.insert-delete-get-random-o-1-duplicates-allowed.kt
# - Downloading insert-delete-getrandom-o1-duplicates-allowed
#   ✔ Accepted
#   ✔ 32/32 cases passed (189 ms)
#   ✔ Your runtime beats 9.09 % of kotlin submissions
#   ✔ Your memory usage beats 18.18 % of kotlin submissions (117.3 MB)
# Submitting: kotlin_solutions/382.linked-list-random-node.kt
# - Downloading linked-list-random-node
#   ✔ Accepted
#   ✔ 8/8 cases passed (48 ms)
#   ✔ Your runtime beats 9.09 % of kotlin submissions
#   ✔ Your memory usage beats 90.91 % of kotlin submissions (49.3 MB)
# Submitting: kotlin_solutions/383.ransom-note.kt
# - Downloading ransom-note
#   ✔ Accepted
#   ✔ 130/130 cases passed (37 ms)
#   ✔ Your runtime beats 6.6 % of kotlin submissions
#   ✔ Your memory usage beats 50.66 % of kotlin submissions (46.7 MB)
# Submitting: kotlin_solutions/384.shuffle-an-array.kt
# - Downloading shuffle-an-array
#   ✔ Accepted
#   ✔ 8/8 cases passed (124 ms)
#   ✔ Your runtime beats 26.67 % of kotlin submissions
#   ✔ Your memory usage beats 16.67 % of kotlin submissions (61.6 MB)
# Submitting: kotlin_solutions/385.mini-parser.kt
# - Downloading mini-parser
#   ✔ Accepted
#   ✔ 58/58 cases passed (26 ms)
#   ✔ Your runtime beats 60 % of kotlin submissions
#   ✔ Your memory usage beats 40 % of kotlin submissions (49.1 MB)
# Submitting: kotlin_solutions/386.lexicographical-numbers.kt
# - Downloading lexicographical-numbers
#   ✔ Accepted
#   ✔ 27/27 cases passed (37 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 41.67 % of kotlin submissions (51.5 MB)
# Submitting: kotlin_solutions/387.first-unique-character-in-a-string.kt
# - Downloading first-unique-character-in-a-string
#   ✔ Accepted
#   ✔ 107/107 cases passed (62 ms)
#   ✔ Your runtime beats 9.83 % of kotlin submissions
#   ✔ Your memory usage beats 12.2 % of kotlin submissions (48.7 MB)

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-02-13 19:50:27
