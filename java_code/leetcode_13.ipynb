# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME_3')
    user_cookie = userdata.get('LEETCODE_TOKEN_3')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME_3'] = user_name
    os.environ['LEETCODE_TOKEN_3'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME_3" "$LEETCODE_TOKEN_3" | leetcode user -c

# %%
# %%bash
#
#
# # top 100 answers
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v java_solutions/*.java | sed -n '1201,$p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 7
# done
# Out:
# Submitting: java_solutions/3621.number-of-integers-with-popcount-depth-equal-to-k-i.java
# - Downloading number-of-integers-with-popcount-depth-equal-to-k-i
#   ✔ Accepted
#   ✔ 855/855 cases passed (76 ms)
#   ✔ Your runtime beats 7.14 % of java submissions
#   ✔ Your memory usage beats 14.29 % of java submissions (53.2 MB)
# Submitting: java_solutions/3622.check-divisibility-by-digit-sum-and-product.java
# - Downloading check-divisibility-by-digit-sum-and-product
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 4: error: missing return statement
#   ✘ Error: Line 4: error: missing return statement
#     }
#     ^
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: java_solutions/3624.number-of-integers-with-popcount-depth-equal-to-k-ii.java
# - Downloading number-of-integers-with-popcount-depth-equal-to-k-ii
#   ✔ Accepted
#   ✔ 600/600 cases passed (251 ms)
#   ✔ Your runtime beats 7.69 % of java submissions
#   ✔ Your memory usage beats 42.31 % of java submissions (207.7 MB)
# Submitting: java_solutions/3625.count-number-of-trapezoids-ii.java
# - Downloading count-number-of-trapezoids-ii
#   ✔ Accepted
#   ✔ 551/551 cases passed (1219 ms)
#   ✔ Your runtime beats 5.51 % of java submissions
#   ✔ Your memory usage beats 5.5 % of java submissions (288.9 MB)
# Submitting: java_solutions/3630.partition-array-for-maximum-xor-and-and.java
# - Downloading partition-array-for-maximum-xor-and-and
#   ✔ Accepted
#   ✔ 551/551 cases passed (1065 ms)
#   ✔ Your runtime beats 21.43 % of java submissions
#   ✔ Your memory usage beats 7.14 % of java submissions (80.7 MB)
# Submitting: java_solutions/3636.threshold-majority-queries.java
# - Downloading threshold-majority-queries
#   ✔ Accepted
#   ✔ 559/559 cases passed (2520 ms)
#   ✔ Your runtime beats 7.69 % of java submissions
#   ✔ Your memory usage beats 7.69 % of java submissions (170.9 MB)
# Submitting: java_solutions/3640.trionic-array-ii.java
# - Downloading trionic-array-ii
#   ✔ Accepted
#   ✔ 861/861 cases passed (216 ms)
#   ✔ Your runtime beats 5.12 % of java submissions
#   ✔ Your memory usage beats 15.15 % of java submissions (107.3 MB)
# Submitting: java_solutions/3646.next-special-palindrome-number.java
# - Downloading next-special-palindrome-number
#   ✔ Accepted
#   ✔ 618/618 cases passed (51 ms)
#   ✔ Your runtime beats 73.08 % of java submissions
#   ✔ Your memory usage beats 7.69 % of java submissions (52.7 MB)
# Submitting: java_solutions/3651.minimum-cost-path-with-teleportations.java
# - Downloading minimum-cost-path-with-teleportations
#   ✔ Accepted
#   ✔ 880/880 cases passed (475 ms)
#   ✔ Your runtime beats 21.03 % of java submissions
#   ✔ Your memory usage beats 19.05 % of java submissions (53.5 MB)
# Submitting: java_solutions/3655.xor-after-range-multiplication-queries-ii.java
# - Downloading xor-after-range-multiplication-queries-ii
# [ERROR] Error: read ECONNRESET
# Submitting: java_solutions/3661.maximum-walls-destroyed-by-robots.java
# - Downloading maximum-walls-destroyed-by-robots
#   ✔ Accepted
#   ✔ 602/602 cases passed (272 ms)
#   ✔ Your runtime beats 22.36 % of java submissions
#   ✔ Your memory usage beats 11.04 % of java submissions (181.6 MB)
# Submitting: java_solutions/3666.minimum-operations-to-equalize-binary-string.java
# - Downloading minimum-operations-to-equalize-binary-string
#   ✔ Accepted
#   ✔ 999/999 cases passed (966 ms)
#   ✔ Your runtime beats 5.13 % of java submissions
#   ✔ Your memory usage beats 5.49 % of java submissions (141.9 MB)
# Submitting: java_solutions/3671.sum-of-beautiful-subsequences.java
# - Downloading sum-of-beautiful-subsequences
#   ✔ Accepted
#   ✔ 594/594 cases passed (2493 ms)
#   ✔ Your runtime beats 6.25 % of java submissions
#   ✔ Your memory usage beats 100 % of java submissions (48.5 MB)
# Submitting: java_solutions/3673.find-zombie-sessions.java
# - Downloading find-zombie-sessions
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: java_solutions/3677.count-binary-palindromic-numbers.java
# - Downloading count-binary-palindromic-numbers
#   ✔ Accepted
#   ✔ 847/847 cases passed (31 ms)
#   ✔ Your runtime beats 9.52 % of java submissions
#   ✔ Your memory usage beats 9.52 % of java submissions (52.7 MB)
# Submitting: java_solutions/3681.maximum-xor-of-subsequences.java
# - Downloading maximum-xor-of-subsequences
#   ✔ Accepted
#   ✔ 670/670 cases passed (1053 ms)
#   ✔ Your runtime beats 6.06 % of java submissions
#   ✔ Your memory usage beats 9.09 % of java submissions (128.9 MB)
# Submitting: java_solutions/3686.number-of-stable-subsequences.java
# - Downloading number-of-stable-subsequences
#   ✔ Accepted
#   ✔ 1098/1098 cases passed (34 ms)
#   ✔ Your runtime beats 49.31 % of java submissions
#   ✔ Your memory usage beats 95.89 % of java submissions (117 MB)
# Submitting: java_solutions/3691.maximum-total-subarray-value-ii.java
# - Downloading maximum-total-subarray-value-ii
#   ✔ Accepted
#   ✔ 930/930 cases passed (972 ms)
#   ✔ Your runtime beats 10.81 % of java submissions
#   ✔ Your memory usage beats 5.41 % of java submissions (242.4 MB)
# Submitting: java_solutions/3695.maximize-alternating-sum-using-swaps.java
# - Downloading maximize-alternating-sum-using-swaps
#   ✔ Accepted
#   ✔ 583/583 cases passed (563 ms)
#   ✔ Your runtime beats 6.82 % of java submissions
#   ✔ Your memory usage beats 70.45 % of java submissions (259 MB)
# Submitting: java_solutions/3699.number-of-zigzag-arrays-i.java
# - Downloading number-of-zigzag-arrays-i
#   ✔ Accepted
#   ✔ 921/921 cases passed (1484 ms)
#   ✔ Your runtime beats 42.67 % of java submissions
#   ✔ Your memory usage beats 13.33 % of java submissions (47.3 MB)
# Submitting: java_solutions/3699.number-of-zig-zag-arrays-i.java
# - Downloading number-of-zigzag-arrays-i
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 4: error: missing return statement
#   ✘ Error: Line 4: error: missing return statement
#     }
#     ^
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: java_solutions/3700.number-of-zigzag-arrays-ii.java
# - Downloading number-of-zigzag-arrays-ii
#   ✔ Accepted
#   ✔ 574/574 cases passed (2534 ms)
#   ✔ Your runtime beats 9.52 % of java submissions
#   ✔ Your memory usage beats 14.29 % of java submissions (59.6 MB)
# Submitting: java_solutions/3700.number-of-zig-zag-arrays-ii.java
# - Downloading number-of-zigzag-arrays-ii
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 4: error: missing return statement
#   ✘ Error: Line 4: error: missing return statement
#     }
#     ^
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: java_solutions/3704.count-no-zero-pairs-that-sum-to-n.java
# - Downloading count-no-zero-pairs-that-sum-to-n
#   ✔ Accepted
#   ✔ 1001/1001 cases passed (855 ms)
#   ✔ Your runtime beats 7.32 % of java submissions
#   ✔ Your memory usage beats 9.76 % of java submissions (53.1 MB)
# Submitting: java_solutions/3710.maximum-partition-factor.java
# - Downloading maximum-partition-factor
#   ✔ Accepted
#   ✔ 741/741 cases passed (1334 ms)
#   ✔ Your runtime beats 8.11 % of java submissions
#   ✔ Your memory usage beats 62.16 % of java submissions (58.5 MB)
# Submitting: java_solutions/3715.sum-of-perfect-square-ancestors.java
# - Downloading sum-of-perfect-square-ancestors
#   ✔ Accepted
#   ✔ 695/695 cases passed (1408 ms)
#   ✔ Your runtime beats 5.13 % of java submissions
#   ✔ Your memory usage beats 66.67 % of java submissions (291.7 MB)
# Submitting: java_solutions/3721.longest-balanced-subarray-ii.java
# - Downloading longest-balanced-subarray-ii
#   ✔ Accepted
#   ✔ 999/999 cases passed (2177 ms)
#   ✔ Your runtime beats 5.09 % of java submissions
#   ✔ Your memory usage beats 39.57 % of java submissions (146.7 MB)
# Submitting: java_solutions/3725.count-ways-to-choose-coprime-integers-from-rows.java
# - Downloading count-ways-to-choose-coprime-integers-from-rows
#   ✔ Accepted
#   ✔ 982/982 cases passed (1488 ms)
#   ✔ Your runtime beats 5.81 % of java submissions
#   ✔ Your memory usage beats 5.81 % of java submissions (56 MB)
# Submitting: java_solutions/3729.count-distinct-subarrays-divisible-by-k-in-sorted-array.java
# - Downloading count-distinct-subarrays-divisible-by-k-in-sorted-array
#   ✔ Accepted
#   ✔ 1024/1024 cases passed (601 ms)
#   ✔ Your runtime beats 5.26 % of java submissions
#   ✔ Your memory usage beats 98.25 % of java submissions (118.6 MB)
# Submitting: java_solutions/3734.lexicographically-smallest-palindromic-permutation-greater-than-target.java
# - Downloading lexicographically-smallest-palindromic-permutation-greater-than-target
#   ✔ Accepted
#   ✔ 1035/1035 cases passed (68 ms)
#   ✔ Your runtime beats 8 % of java submissions
#   ✔ Your memory usage beats 8 % of java submissions (53.6 MB)
# Submitting: java_solutions/3739.count-subarrays-with-majority-element-ii.java
# - Downloading count-subarrays-with-majority-element-ii
#   ✔ Accepted
#   ✔ 516/516 cases passed (62 ms)
#   ✔ Your runtime beats 14.85 % of java submissions
#   ✔ Your memory usage beats 20.79 % of java submissions (114 MB)
# Submitting: java_solutions/3743.maximize-cyclic-partition-score.java
# - Downloading maximize-cyclic-partition-score
#   ✔ Accepted
#   ✔ 1274/1274 cases passed (1537 ms)
#   ✔ Your runtime beats 6.67 % of java submissions
#   ✔ Your memory usage beats 10 % of java submissions (53.7 MB)
# Submitting: java_solutions/3748.count-stable-subarrays.java
# - Downloading count-stable-subarrays
#   ✔ Accepted
#   ✔ 1041/1041 cases passed (188 ms)
#   ✔ Your runtime beats 5.43 % of java submissions
#   ✔ Your memory usage beats 100 % of java submissions (167.2 MB)
# Submitting: java_solutions/3753.total-waviness-of-numbers-in-range-ii.java
# - Downloading total-waviness-of-numbers-in-range-ii
#   ✔ Accepted
#   ✔ 1013/1013 cases passed (2689 ms)
#   ✔ Your runtime beats 5.36 % of java submissions
#   ✔ Your memory usage beats 5.36 % of java submissions (277.9 MB)
# Submitting: java_solutions/3757.number-of-effective-subsequences.java
# - Downloading number-of-effective-subsequences
#   ✔ Accepted
#   ✔ 1041/1041 cases passed (1465 ms)
#   ✔ Your runtime beats 5.8 % of java submissions
#   ✔ Your memory usage beats 13.04 % of java submissions (113.8 MB)
# Submitting: java_solutions/3762.minimum-operations-to-equalize-subarrays.java
# - Downloading minimum-operations-to-equalize-subarrays
#   ✔ Accepted
#   ✔ 1118/1118 cases passed (2424 ms)
#   ✔ Your runtime beats 5 % of java submissions
#   ✔ Your memory usage beats 15 % of java submissions (283.4 MB)
# Submitting: java_solutions/3764.most-common-course-pairs.java
# - Downloading most-common-course-pairs
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: java_solutions/3768.minimum-inversion-count-in-subarrays-of-fixed-length.java
# - Downloading minimum-inversion-count-in-subarrays-of-fixed-length
#   ✔ Accepted
#   ✔ 926/926 cases passed (1450 ms)
#   ✔ Your runtime beats 6.15 % of java submissions
#   ✔ Your memory usage beats 80 % of java submissions (138.3 MB)
# Submitting: java_solutions/3772.maximum-subgraph-score-in-a-tree.java
# - Downloading maximum-subgraph-score-in-a-tree
#   ✔ Accepted
#   ✔ 876/876 cases passed (1237 ms)
#   ✔ Your runtime beats 6.12 % of java submissions
#   ✔ Your memory usage beats 7.14 % of java submissions (290.6 MB)
# Submitting: java_solutions/3777.minimum-deletions-to-make-alternating-substring.java
# - Downloading minimum-deletions-to-make-alternating-substring
#   ✔ Accepted
#   ✔ 1008/1008 cases passed (1446 ms)
#   ✔ Your runtime beats 5.88 % of java submissions
#   ✔ Your memory usage beats 5.88 % of java submissions (284.2 MB)
# Submitting: java_solutions/3782.last-remaining-integer-after-alternating-deletion-operations.java
# - Downloading last-remaining-integer-after-alternating-deletion-operations
#   ✔ Accepted
#   ✔ 1310/1310 cases passed (1 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 37.8 % of java submissions (42.8 MB)
# Submitting: java_solutions/3785.minimum-swaps-to-avoid-forbidden-values.java
# - Downloading minimum-swaps-to-avoid-forbidden-values
#   ✔ Accepted
#   ✔ 1111/1111 cases passed (124 ms)
#   ✔ Your runtime beats 12.16 % of java submissions
#   ✔ Your memory usage beats 51.35 % of java submissions (173.7 MB)
# Submitting: java_solutions/3786.total-sum-of-interaction-cost-in-tree-groups.java
# - Downloading total-sum-of-interaction-cost-in-tree-groups
#   ✔ Accepted
#   ✔ 1147/1147 cases passed (1179 ms)
#   ✔ Your runtime beats 6.45 % of java submissions
#   ✔ Your memory usage beats 53.23 % of java submissions (291.6 MB)
# Submitting: java_solutions/3791.number-of-balanced-integers-in-a-range.java
# - Downloading number-of-balanced-integers-in-a-range
#   ✔ Accepted
#   ✔ 1042/1042 cases passed (1666 ms)
#   ✔ Your runtime beats 8.33 % of java submissions
#   ✔ Your memory usage beats 34.37 % of java submissions (47.8 MB)
# Submitting: java_solutions/3797.count-routes-to-climb-a-rectangular-grid.java
# - Downloading count-routes-to-climb-a-rectangular-grid
#   ✔ Accepted
#   ✔ 2254/2254 cases passed (427 ms)
#   ✔ Your runtime beats 6.52 % of java submissions
#   ✔ Your memory usage beats 45.65 % of java submissions (60.9 MB)
# Submitting: java_solutions/3801.minimum-cost-to-merge-sorted-lists.java
# - Downloading minimum-cost-to-merge-sorted-lists
#   ✔ Accepted
#   ✔ 881/881 cases passed (2676 ms)
#   ✔ Your runtime beats 25.81 % of java submissions
#   ✔ Your memory usage beats 32.26 % of java submissions (55.8 MB)
# Submitting: java_solutions/3806.maximum-bitwise-and-after-increment-operations.java
# - Downloading maximum-bitwise-and-after-increment-operations
#   ✔ Accepted
#   ✔ 1032/1032 cases passed (1551 ms)
#   ✔ Your runtime beats 6.67 % of java submissions
#   ✔ Your memory usage beats 6.67 % of java submissions (71.1 MB)
# Submitting: java_solutions/3812.minimum-edge-toggles-on-a-tree.java
# - Downloading minimum-edge-toggles-on-a-tree
#   ✔ Accepted
#   ✔ 537/537 cases passed (575 ms)
#   ✔ Your runtime beats 5.94 % of java submissions
#   ✔ Your memory usage beats 5.94 % of java submissions (415.2 MB)
# Submitting: java_solutions/3816.lexicographically-smallest-string-after-deleting-duplicate-characters.java
# - Downloading lexicographically-smallest-string-after-deleting-duplicate-characters
#   ✔ Accepted
#   ✔ 1017/1017 cases passed (1997 ms)
#   ✔ Your runtime beats 5.94 % of java submissions
#   ✔ Your memory usage beats 11.88 % of java submissions (56.8 MB)
# Submitting: java_solutions/3821.find-nth-smallest-integer-with-k-one-bits.java
# - Downloading find-nth-smallest-integer-with-k-one-bits
#   ✔ Accepted
#   ✔ 1007/1007 cases passed (12 ms)
#   ✔ Your runtime beats 21.74 % of java submissions
#   ✔ Your memory usage beats 10.87 % of java submissions (53.5 MB)
# Submitting: java_solutions/3826.minimum-partition-score.java
# - Downloading minimum-partition-score
#   ✔ Accepted
#   ✔ 822/822 cases passed (12 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 53.61 % of java submissions (54.5 MB)
# Submitting: java_solutions/3830.longest-alternating-subarray-after-removing-at-most-one-element.java
# - Downloading longest-alternating-subarray-after-removing-at-most-one-element
#   ✔ Accepted
#   ✔ 1018/1018 cases passed (11 ms)
#   ✔ Your runtime beats 98.33 % of java submissions
#   ✔ Your memory usage beats 95.83 % of java submissions (176.6 MB)
# Submitting: java_solutions/3832.find-users-with-persistent-behavior-patterns.java
# - Downloading find-users-with-persistent-behavior-patterns
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: java_solutions/3836.maximum-score-using-exactly-k-pairs.java
# - Downloading maximum-score-using-exactly-k-pairs
#   ✔ Accepted
#   ✔ 884/884 cases passed (16 ms)
#   ✔ Your runtime beats 98.59 % of java submissions
#   ✔ Your memory usage beats 5.41 % of java submissions (291.7 MB)
# Submitting: java_solutions/3841.palindromic-path-queries-in-a-tree.java
# - Downloading palindromic-path-queries-in-a-tree
#   ✔ Accepted
#   ✔ 1040/1040 cases passed (16 ms)
#   ✔ Your runtime beats 99.61 % of java submissions
#   ✔ Your memory usage beats 44.1 % of java submissions (235.1 MB)
# Submitting: java_solutions/3845.maximum-subarray-xor-with-bounded-range.java
# - Downloading maximum-subarray-xor-with-bounded-range
#   ✔ Accepted
#   ✔ 1015/1015 cases passed (16 ms)
#   ✔ Your runtime beats 99.83 % of java submissions
#   ✔ Your memory usage beats 5.06 % of java submissions (291.9 MB)
# Submitting: java_solutions/3850.count-sequences-to-k.java
# - Downloading count-sequences-to-k
#   ✔ Accepted
#   ✔ 999/999 cases passed (15 ms)
#   ✔ Your runtime beats 98.79 % of java submissions
#   ✔ Your memory usage beats 37.21 % of java submissions (54.2 MB)
# Submitting: java_solutions/3855.sum-of-k-digit-numbers-in-a-range.java
# - Downloading sum-of-k-digit-numbers-in-a-range
#   ✔ Accepted
#   ✔ 1500/1500 cases passed (14 ms)
#   ✔ Your runtime beats 2.66 % of java submissions
#   ✔ Your memory usage beats 10.65 % of java submissions (53.3 MB)
# Submitting: java_solutions/3859.count-subarrays-with-k-distinct-integers.java
# - Downloading count-subarrays-with-k-distinct-integers
#   ✔ Accepted
#   ✔ 1078/1078 cases passed (19 ms)
#   ✔ Your runtime beats 93.47 % of java submissions
#   ✔ Your memory usage beats 15.92 % of java submissions (91.2 MB)
# Submitting: java_solutions/3864.minimum-cost-to-partition-a-binary-string.java
# - Downloading minimum-cost-to-partition-a-binary-string
#   ✔ Accepted
#   ✔ 1009/1009 cases passed (13 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 20.89 % of java submissions (72.3 MB)
# Submitting: java_solutions/3869.count-fancy-numbers-in-a-range.java
# - Downloading count-fancy-numbers-in-a-range
#   ✔ Accepted
#   ✔ 747/747 cases passed (14 ms)
#   ✔ Your runtime beats 98.58 % of java submissions
#   ✔ Your memory usage beats 23.19 % of java submissions (279.9 MB)
# Submitting: java_solutions/3873.maximum-points-activated-with-one-addition.java
# - Downloading maximum-points-activated-with-one-addition
#   ✔ Accepted
#   ✔ 1007/1007 cases passed (139 ms)
#   ✔ Your runtime beats 29.27 % of java submissions
#   ✔ Your memory usage beats 15.29 % of java submissions (283.7 MB)
# Submitting: java_solutions/3878.count-good-subarrays.java
# - Downloading count-good-subarrays
#   ✔ Accepted
#   ✔ 787/787 cases passed (1747 ms)
#   ✔ Your runtime beats 8.82 % of java submissions
#   ✔ Your memory usage beats 21.31 % of java submissions (153 MB)
# Submitting: java_solutions/3883.count-non-decreasing-arrays-with-given-digit-sums.java
# - Downloading count-non-decreasing-arrays-with-given-digit-sums
#   ✔ Accepted
#   ✔ 663/663 cases passed (1901 ms)
#   ✔ Your runtime beats 8.53 % of java submissions
#   ✔ Your memory usage beats 23.13 % of java submissions (53.2 MB)
# Submitting: java_solutions/3886.sum-of-sortable-integers.java
# - Downloading sum-of-sortable-integers
#   ✔ Accepted
#   ✔ 1053/1053 cases passed (651 ms)
#   ✔ Your runtime beats 9.19 % of java submissions
#   ✔ Your memory usage beats 11.89 % of java submissions (83.4 MB)
# Submitting: java_solutions/3887.incremental-even-weighted-cycle-queries.java
# - Downloading incremental-even-weighted-cycle-queries
#   ✔ Accepted
#   ✔ 1008/1008 cases passed (203 ms)
#   ✔ Your runtime beats 5.23 % of java submissions
#   ✔ Your memory usage beats 99.94 % of java submissions (167.6 MB)
# Submitting: java_solutions/3892.minimum-operations-to-achieve-at-least-k-peaks.java
# - Downloading minimum-operations-to-achieve-at-least-k-peaks
#   ✔ Accepted
#   ✔ 1142/1142 cases passed (2580 ms)
#   ✔ Your runtime beats 5.04 % of java submissions
#   ✔ Your memory usage beats 56.63 % of java submissions (204.7 MB)
# Submitting: java_solutions/3897.maximum-value-of-concatenated-binary-segments.java
# - Downloading maximum-value-of-concatenated-binary-segments
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 4: error: missing return statement
#   ✘ Error: Line 4: error: missing return statement
#     }
#     ^
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-04-14 15:31:14
