# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME_2')
    user_cookie = userdata.get('LEETCODE_TOKEN_2')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME_2'] = user_name
    os.environ['LEETCODE_TOKEN_2'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME_2" "$LEETCODE_TOKEN_2" | leetcode user -c

# %%
# %%bash
#
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v kotlin_solutions_1/*.kt | sed -n '1301,1400p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 7
# done
# Out:
# Submitting: kotlin_solutions_1/2830.maximize-the-profit-as-the-salesman.kt
# - Downloading maximize-the-profit-as-the-salesman
#   ✔ Accepted
#   ✔ 435/435 cases passed (73 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2831.find-the-longest-equal-subarray.kt
# - Downloading find-the-longest-equal-subarray
#   ✘ Wrong Answer
#   ✘ 1194/1422 cases passed (N/A)
#   ✘ Testcase: [2,6,10,8,3,9,6,6,9,9]
# 1
#   ✘ Answer: 3
#   ✘ Expected Answer: 2
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2833.furthest-point-from-origin.kt
# - Downloading furthest-point-from-origin
#   ✔ Accepted
#   ✔ 1254/1254 cases passed (3 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2834.find-the-minimum-possible-sum-of-a-beautiful-array.kt
# - Downloading find-the-minimum-possible-sum-of-a-beautiful-array
#   ✔ Accepted
#   ✔ 577/577 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (40.6 MB)
# Submitting: kotlin_solutions_1/2835.minimum-operations-to-form-subsequence-with-target-sum.kt
# - Downloading minimum-operations-to-form-subsequence-with-target-sum
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 499: WARNING: Parameter 'it: Long' is never used, could be renamed to '_'.
#   ✘ Error: Line 2: Char 499: WARNING: Parameter 'it: Long' is never used, could be renamed to '_'.
# Line 2: Char 571: WARNING: Parameter 'it: Long' is never used, could be renamed to '_'.
# Line 2: Char 621: WARNING: Parameter 'it: Any' is never used, could be renamed to '_'.
# Line 38: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2836.maximize-value-of-function-in-a-ball-passing-game.kt
# - Downloading maximize-value-of-function-in-a-ball-passing-game
#   ✔ Accepted
#   ✔ 948/948 cases passed (125 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (132.9 MB)
# Submitting: kotlin_solutions_1/2839.check-if-strings-can-be-made-equal-with-operations-i.kt
# - Downloading check-if-strings-can-be-made-equal-with-operations-i
# [ERROR] session expired, please login again [code=-1]
# Submitting: kotlin_solutions_1/2840.check-if-strings-can-be-made-equal-with-operations-ii.kt
# - Downloading check-if-strings-can-be-made-equal-with-operations-ii
#   ✔ Accepted
#   ✔ 756/756 cases passed (369 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2841.maximum-sum-of-almost-unique-subarray.kt
# - Downloading maximum-sum-of-almost-unique-subarray
#   ✔ Accepted
#   ✔ 767/767 cases passed (69 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (59 MB)
# Submitting: kotlin_solutions_1/2842.count-k-subsequences-of-a-string-with-maximum-beauty.kt
# - Downloading count-k-subsequences-of-a-string-with-maximum-beauty
#   ✔ Accepted
#   ✔ 611/611 cases passed (74 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (52.1 MB)
# Submitting: kotlin_solutions_1/2843.count-symmetric-integers.kt
# - Downloading count-symmetric-integers
#   ✔ Accepted
#   ✔ 1967/1967 cases passed (60 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (47.4 MB)
# Submitting: kotlin_solutions_1/2844.minimum-operations-to-make-a-special-number.kt
# - Downloading minimum-operations-to-make-a-special-number
#   ✔ Accepted
#   ✔ 814/814 cases passed (27 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (47.4 MB)
# Submitting: kotlin_solutions_1/2845.count-of-interesting-subarrays.kt
# - Downloading count-of-interesting-subarrays
#   ✔ Accepted
#   ✔ 617/617 cases passed (133 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (82.2 MB)
# Submitting: kotlin_solutions_1/2846.minimum-edge-weight-equilibrium-queries-in-a-tree.kt
# - Downloading minimum-edge-weight-equilibrium-queries-in-a-tree
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 122: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 2: Char 122: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 306: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 343: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 596: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 618: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 651: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 709: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 731: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 756: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 2: Char 853: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 40: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2848.points-that-intersect-with-cars.kt
# - Downloading points-that-intersect-with-cars
#   ✔ Accepted
#   ✔ 807/807 cases passed (25 ms)
#   ✔ Your runtime beats 5.56 % of kotlin submissions
#   ✔ Your memory usage beats 88.89 % of kotlin submissions (47.5 MB)
# Submitting: kotlin_solutions_1/2849.determine-if-a-cell-is-reachable-at-a-given-time.kt
# - Downloading determine-if-a-cell-is-reachable-at-a-given-time
#   ✔ Accepted
#   ✔ 806/806 cases passed (81 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (39.5 MB)
# Submitting: kotlin_solutions_1/2850.minimum_moves_to_spread_stones_over_grid.kt
# - Downloading minimum-moves-to-spread-stones-over-grid
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 606: ERROR: Unresolved reference 'call'.
#   ✘ Error: Line 2: Char 606: ERROR: Unresolved reference 'call'.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2851.string_transformation.kt
# - Downloading string-transformation
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 297: WARNING: Condition is always 'false'.
#   ✘ Error: Line 2: Char 297: WARNING: Condition is always 'false'.
# Line 2: Char 415: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 415: ERROR: Not enough information to infer type argument for 'R'.
# Line 2: Char 603: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 603: ERROR: Not enough information to infer type argument for 'R'.
# Line 2: Char 620: ERROR: Unresolved reference 'call'.
# Line 2: Char 637: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 637: ERROR: Not enough information to infer type argument for 'R'.
# Line 2: Char 643: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 653: ERROR: Unresolved reference 'call'.
# Line 2: Char 676: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 682: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 733: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 733: ERROR: Not enough information to infer type argument for 'R'.
# Line 2: Char 775: ERROR: Unresolved reference 'rem' for operator '%'.
# Line 2: Char 809: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 809: ERROR: Not enough information to infer type argument for 'R'.
# Line 2: Char 809: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun <T, R> T.let(block: (T) -> R): R
#     [R|Contract description]
#      <
#         CallsInPlace(block, EXACTLY_ONCE)
#     >
# Line 2: Char 815: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 908: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 908: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun <T, R> T.let(block: (T) -> R): R
#     [R|Contract description]
#      <
#         CallsInPlace(block, EXACTLY_ONCE)
#     >
# Line 2: Char 914: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2855.minimum_right_shifts_to_sort_the_array.kt
# - Downloading minimum-right-shifts-to-sort-the-array
#   ✔ Accepted
#   ✔ 814/814 cases passed (10 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2856.minimum_array_length_after_pair_removals.kt
# - Downloading minimum-array-length-after-pair-removals
#   ✔ Accepted
#   ✔ 636/636 cases passed (89 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (83.5 MB)
# Submitting: kotlin_solutions_1/2857.count_pairs_of_points_with_distance_k.kt
# - Downloading count-pairs-of-points-with-distance-k
#   ✔ Accepted
#   ✔ 1007/1007 cases passed (707 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (98.4 MB)
# Submitting: kotlin_solutions_1/2858.minimum_edge_reversals_so_every_node_is_reachable.kt
# - Downloading minimum-edge-reversals-so-every-node-is-reachable
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 92: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 2: Char 92: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 413: ERROR: Unresolved reference 'call'.
# Line 2: Char 660: ERROR: Unresolved reference 'call'.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2859.sum_of_values_at_indices_with_k_set_bits.kt
# - Downloading sum-of-values-at-indices-with-k-set-bits
#   ✔ Accepted
#   ✔ 639/639 cases passed (13 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2860.happy_students.kt
# - Downloading happy-students
#   ✔ Accepted
#   ✔ 727/727 cases passed (92 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (64.3 MB)
# Submitting: kotlin_solutions_1/2861.maximum_number_of_alloys.kt
# - Downloading maximum-number-of-alloys
#   ✔ Accepted
#   ✔ 731/731 cases passed (36 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (55.7 MB)
# Submitting: kotlin_solutions_1/2862.maximum_element_sum_of_a_complete_subset_of_indices.kt
# - Downloading maximum-element-sum-of-a-complete-subset-of-indices
#   ✔ Accepted
#   ✔ 663/663 cases passed (201 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (74.6 MB)
# Submitting: kotlin_solutions_1/2864.maximum-odd-binary-number.kt
# - Downloading maximum-odd-binary-number
# [ERROR] session expired, please login again [code=-1]
# Submitting: kotlin_solutions_1/2865.beautiful-towers-i.kt
# - Downloading beautiful-towers-i
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 235: WARNING: Condition is always 'true'.
#   ✘ Error: Line 2: Char 235: WARNING: Condition is always 'true'.
# Line 2: Char 291: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 602: WARNING: Condition is always 'true'.
# Line 2: Char 658: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 804: WARNING: Parameter 'it: Long' is never used, could be renamed to '_'.
# Line 22: Char 13: ERROR: Argument type mismatch: actual type is 'kotlin.IntArray!', but 'kotlin.collections.List<kotlin.Int>' was expected.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2866.beautiful-towers-ii.kt
# - Downloading beautiful-towers-ii
#   ✔ Accepted
#   ✔ 785/785 cases passed (241 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (83.4 MB)
# Submitting: kotlin_solutions_1/2867.count-valid-paths-in-a-tree.kt
# - Downloading count-valid-paths-in-a-tree
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 260: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 2: Char 260: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 340: WARNING: Parameter 'it: Boolean' is never used, could be renamed to '_'.
# Line 2: Char 369: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 369: ERROR: Not enough information to infer type argument for 'R'.
# Line 2: Char 398: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 398: ERROR: Not enough information to infer type argument for 'R'.
# Line 2: Char 819: ERROR: Unresolved reference 'callRecursive'.
# Line 2: Char 842: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 842: ERROR: Not enough information to infer type argument for 'R'.
# Line 2: Char 846: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2869.minimum-operations-to-collect-elements.kt
# - Downloading minimum-operations-to-collect-elements
#   ✔ Accepted
#   ✔ 619/619 cases passed (25 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2870.minimum-number-of-operations-to-make-array-empty.kt
# - Downloading minimum-number-of-operations-to-make-array-empty
#   ✔ Accepted
#   ✔ 748/748 cases passed (63 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (87.3 MB)
# Submitting: kotlin_solutions_1/2871.split-array-into-maximum-number-of-subarrays.kt
# - Downloading split-array-into-maximum-number-of-subarrays
#   ✔ Accepted
#   ✔ 887/887 cases passed (36 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (79.5 MB)
# Submitting: kotlin_solutions_1/2872.maximum-number-of-k-divisible-components.kt
# - Downloading maximum-number-of-k-divisible-components
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 120: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 2: Char 120: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 256: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 256: ERROR: Not enough information to infer type argument for 'R'.
# Line 2: Char 481: ERROR: Unresolved reference 'callRecursive'.
# Line 2: Char 504: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 504: ERROR: Not enough information to infer type argument for 'R'.
# Line 2: Char 508: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2873.maximum-value-of-an-ordered-triplet-i.kt
# - Downloading maximum-value-of-an-ordered-triplet-i
#   ✔ Accepted
#   ✔ 564/564 cases passed (4 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/2874.maximum-value-of-an-ordered-triplet-ii.kt
# - Downloading maximum-value-of-an-ordered-triplet-ii
#   ✔ Accepted
#   ✔ 599/599 cases passed (27 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2875.minimum-size-subarray-in-infinite-array.kt
# - Downloading minimum-size-subarray-in-infinite-array
#   ✔ Accepted
#   ✔ 535/535 cases passed (87 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (84.3 MB)
# Submitting: kotlin_solutions_1/2876.count-visited-nodes-in-a-directed-graph.kt
# - Downloading count-visited-nodes-in-a-directed-graph
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 170: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 2: Char 170: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 390: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 561: WARNING: Parameter 'it: Array<Function2<Int, Int, Int>?>' is never used, could be renamed to '_'.
# Line 36: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2894.divisible-and-non-divisible-sums-difference.kt
# - Downloading divisible-and-non-divisible-sums-difference
#   ✔ Accepted
#   ✔ 737/737 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (40.7 MB)
# Submitting: kotlin_solutions_1/2895.minimum-processing-time.kt
# - Downloading minimum-processing-time
#   ✔ Accepted
#   ✔ 716/716 cases passed (119 ms)
#   ✔ Your runtime beats 64.29 % of kotlin submissions
#   ✔ Your memory usage beats 7.14 % of kotlin submissions (87.5 MB)
# Submitting: kotlin_solutions_1/2896.apply-operations-to-make-two-strings-equal.kt
# - Downloading apply-operations-to-make-two-strings-equal
#   ✔ Accepted
#   ✔ 729/729 cases passed (19 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2897.apply-operations-on-array-to-maximize-sum-of-squares.kt
# - Downloading apply-operations-on-array-to-maximize-sum-of-squares
#   ✔ Accepted
#   ✔ 918/918 cases passed (79 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2899.last-visited-integers.kt
# - Downloading last-visited-integers
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 29: Char 13: ERROR: Argument type mismatch: actual type is 'kotlin.IntArray!', but 'kotlin.collections.List<kotlin.Int>' was expected.
#   ✘ Error: Line 29: Char 13: ERROR: Argument type mismatch: actual type is 'kotlin.IntArray!', but 'kotlin.collections.List<kotlin.Int>' was expected.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2900.longest-unequal-adjacent-groups-subsequence-i.kt
# - Downloading longest-unequal-adjacent-groups-subsequence-i
#   ✔ Accepted
#   ✔ 382/382 cases passed (22 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (52.9 MB)
# Submitting: kotlin_solutions_1/2901.longest-unequal-adjacent-groups-subsequence-ii.kt
# - Downloading longest-unequal-adjacent-groups-subsequence-ii
#   ✔ Accepted
#   ✔ 443/443 cases passed (322 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (71.5 MB)
# Submitting: kotlin_solutions_1/2902.count-of-sub-multisets-with-bounded-sum.kt
# - Downloading count-of-sub-multisets-with-bounded-sum
#   ✔ Accepted
#   ✔ 643/643 cases passed (386 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (51.5 MB)
# Submitting: kotlin_solutions_1/2903.find-indices-with-index-and-value-difference-i.kt
# - Downloading find-indices-with-index-and-value-difference-i
#   ✔ Accepted
#   ✔ 525/525 cases passed (17 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 16.67 % of kotlin submissions (53.4 MB)
# Submitting: kotlin_solutions_1/2904.shortest-and-lexicographically-smallest-beautiful-string.kt
# - Downloading shortest-and-lexicographically-smallest-beautiful-string
#   ✔ Accepted
#   ✔ 674/674 cases passed (61 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2905.find-indices-with-index-and-value-difference-ii.kt
# - Downloading find-indices-with-index-and-value-difference-ii
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 8: Char 248: ERROR: Argument type mismatch: actual type is 'it(R & Any & java.io.Serializable)', but 'kotlin.Triple<kotlin.IntArray, kotlin.Int, kotlin.Int>' was expected.
#   ✘ Error: Line 8: Char 248: ERROR: Argument type mismatch: actual type is 'it(R & Any & java.io.Serializable)', but 'kotlin.Triple<kotlin.IntArray, kotlin.Int, kotlin.Int>' was expected.
# Line 8: Char 452: ERROR: Unresolved reference 'nums'.
# Line 8: Char 456: ERROR: Unsupported [Collection literals outside of annotations].
# Line 8: Char 465: ERROR: None of the following candidates is applicable:
# fun <T> Iterable<T>.minus(element: T): List<T>
# fun <T> Iterable<T>.minus(elements: Array<out T>): List<T>
# fun <T> Iterable<T>.minus(elements: Iterable<T>): List<T>
# fun <T> Iterable<T>.minus(elements: Sequence<T>): List<T>
# fun <K, V> Map<out K, V>.minus(key: K): Map<K, V>
# fun <K, V> Map<out K, V>.minus(keys: Iterable<K>): Map<K, V>
# fun <K, V> Map<out K, V>.minus(keys: Array<out K>): Map<K, V>
# fun <K, V> Map<out K, V>.minus(keys: Sequence<K>): Map<K, V>
# fun <T> Set<T>.minus(element: T): Set<T>
# fun <T> Set<T>.minus(elements: Array<out T>): Set<T>
# fun <T> Set<T>.minus(elements: Iterable<T>): Set<T>
# fun <T> Set<T>.minus(elements: Sequence<T>): Set<T>
# fun <T> Sequence<T>.minus(element: T): Sequence<T>
# fun <T> Sequence<T>.minus(elements: Array<out T>): Sequence<T>
# fun <T> Sequence<T>.minus(elements: Iterable<T>): Sequence<T>
# fun <T> Sequence<T>.minus(elements: Sequence<T>): Sequence<T>
# Line 8: Char 488: ERROR: Syntax error: Expecting an expression, is-condition or in-condition.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2906.construct-product-matrix.kt
# - Downloading construct-product-matrix
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 7: Char 104: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 7: Char 104: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 7: Char 157: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 7: Char 226: ERROR: Only expressions are allowed in this context.
# Line 7: Char 279: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 7: Char 443: ERROR: Only expressions are allowed in this context.
# Line 7: Char 548: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2908.minimum-sum-of-mountain-triplets-i.kt
# - Downloading minimum-sum-of-mountain-triplets-i
#   ✔ Accepted
#   ✔ 724/724 cases passed (143 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2909.minimum-sum-of-mountain-triplets-ii.kt
# - Downloading minimum-sum-of-mountain-triplets-ii
#   ✔ Accepted
#   ✔ 788/788 cases passed (34 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/2910.minimum-number-of-groups-to-create-a-valid-assignment.kt
# - Downloading minimum-number-of-groups-to-create-a-valid-assignment
#   ✔ Accepted
#   ✔ 631/631 cases passed (64 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/2911.minimum-changes-to-make-k-semi-palindromes.kt
# - Downloading minimum-changes-to-make-k-semi-palindromes
#   ✔ Accepted
#   ✔ 558/558 cases passed (392 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2913.subarrays-distinct-element-sum-of-squares-i.kt
# - Downloading subarrays-distinct-element-sum-of-squares-i
#   ✔ Accepted
#   ✔ 707/707 cases passed (90 ms)
#   ✔ Your runtime beats 30 % of kotlin submissions
#   ✔ Your memory usage beats 30 % of kotlin submissions (49.6 MB)
# Submitting: kotlin_solutions_1/2914.minimum-number-of-changes-to-make-binary-string-beautiful.kt
# - Downloading minimum-number-of-changes-to-make-binary-string-beautiful
#   ✔ Accepted
#   ✔ 577/577 cases passed (13 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (47 MB)
# Submitting: kotlin_solutions_1/2915.length-of-the-longest-subsequence-that-sums-to-target.kt
# - Downloading length-of-the-longest-subsequence-that-sums-to-target
#   ✔ Accepted
#   ✔ 941/941 cases passed (65 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (51 MB)
# Submitting: kotlin_solutions_1/2916.subarrays-distinct-element-sum-of-squares-ii.kt
# - Downloading subarrays-distinct-element-sum-of-squares-ii
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 231: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 2: Char 231: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 425: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 2: Char 478: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 2: Char 826: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 2: Char 880: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 2: Char 929: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 2: Char 1025: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 2: Char 1079: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 2: Char 1128: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 2: Char 1260: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 2: Char 1330: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 2: Char 1401: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 2: Char 1655: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 2: Char 1681: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 36: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2917.find-the-k-or-of-an-array.kt
# - Downloading find-the-k-or-of-an-array
#   ✔ Accepted
#   ✔ 951/951 cases passed (12 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (46.2 MB)
# Submitting: kotlin_solutions_1/2918.minimum-equal-sum-of-two-arrays-after-replacing-zeros.kt
# - Downloading minimum-equal-sum-of-two-arrays-after-replacing-zeros
#   ✔ Accepted
#   ✔ 638/638 cases passed (557 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 75 % of kotlin submissions (74.2 MB)
# Submitting: kotlin_solutions_1/2919.minimum-increment-operations-to-make-array-beautiful.kt
# - Downloading minimum-increment-operations-to-make-array-beautiful
#   ✔ Accepted
#   ✔ 570/570 cases passed (8 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/2920.maximum-points-after-collecting-coins-from-all-nodes.kt
# - Downloading maximum-points-after-collecting-coins-from-all-nodes
#   ✔ Accepted
#   ✔ 542/542 cases passed (357 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (135.9 MB)
# Submitting: kotlin_solutions_1/2923.find-champion-i.kt
# - Downloading find-champion-i
#   ✔ Accepted
#   ✔ 587/587 cases passed (11 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (67.1 MB)
# Submitting: kotlin_solutions_1/2924.find-champion-ii.kt
# - Downloading find-champion-ii
#   ✔ Accepted
#   ✔ 758/758 cases passed (7 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2925.maximum-score-after-applying-operations-on-a-tree.kt
# - Downloading maximum-score-after-applying-operations-on-a-tree
#   ✔ Accepted
#   ✔ 821/821 cases passed (113 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (82.3 MB)
# Submitting: kotlin_solutions_1/2926.maximum-balanced-subsequence-sum.kt
# - Downloading maximum-balanced-subsequence-sum
#   ✔ Accepted
#   ✔ 346/346 cases passed (635 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (74.8 MB)
# Submitting: kotlin_solutions_1/2928.distribute-candies-among-children-i.kt
# - Downloading distribute-candies-among-children-i
#   ✔ Accepted
#   ✔ 827/827 cases passed (3 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (41.1 MB)
# Submitting: kotlin_solutions_1/2929.distribute-candies-among-children-ii.kt
# - Downloading distribute-candies-among-children-ii
#   ✔ Accepted
#   ✔ 958/958 cases passed (96 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2930.number-of-strings-which-can-be-rearranged-to-contain-substring.kt
# - Downloading number-of-strings-which-can-be-rearranged-to-contain-substring
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 8: Char 64: ERROR: Unresolved reference 'longValue'.
#   ✘ Error: Line 8: Char 64: ERROR: Unresolved reference 'longValue'.
# Line 8: Char 193: ERROR: Unresolved reference 'longValue'.
# Line 8: Char 207: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 8: Char 207: ERROR: Not enough information to infer type argument for 'R'.
# Line 8: Char 240: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 8: Char 240: ERROR: Not enough information to infer type argument for 'R'.
# Line 8: Char 246: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 8: Char 273: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 8: Char 279: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 8: Char 312: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 8: Char 318: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 8: Char 347: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 8: Char 353: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 8: Char 386: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 8: Char 392: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 8: Char 421: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 8: Char 427: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 8: Char 460: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 8: Char 466: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 8: Char 514: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 8: Char 514: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun <T, R> T.let(block: (T) -> R): R
#     [R|Contract description]
#      <
#         CallsInPlace(block, EXACTLY_ONCE)
#     >
# Line 8: Char 520: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 8: Char 572: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 8: Char 572: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun <T, R> T.let(block: (T) -> R): R
#     [R|Contract description]
#      <
#         CallsInPlace(block, EXACTLY_ONCE)
#     >
# Line 8: Char 578: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 8: Char 622: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 8: Char 622: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun <T, R> T.let(block: (T) -> R): R
#     [R|Contract description]
#      <
#         CallsInPlace(block, EXACTLY_ONCE)
#     >
# Line 8: Char 628: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 8: Char 681: ERROR: Unresolved reference 'rem' for operator '%'.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2931.maximum-spending-after-buying-items.kt
# - Downloading maximum-spending-after-buying-items
#   ✔ Accepted
#   ✔ 779/779 cases passed (94 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (67.5 MB)
# Submitting: kotlin_solutions_1/2932.maximum-strong-pair-xor-i.kt
# - Downloading maximum-strong-pair-xor-i
#   ✔ Accepted
#   ✔ 861/861 cases passed (33 ms)
#   ✔ Your runtime beats 14.29 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (49.2 MB)
# Submitting: kotlin_solutions_1/2933.high-access-employees.kt
# - Downloading high-access-employees
#   ✔ Accepted
#   ✔ 1143/1143 cases passed (321 ms)
#   ✔ Your runtime beats 12.5 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (55.3 MB)
# Submitting: kotlin_solutions_1/2934.minimum-operations-to-maximize-last-elements-in-arrays.kt
# - Downloading minimum-operations-to-maximize-last-elements-in-arrays
#   ✔ Accepted
#   ✔ 702/702 cases passed (27 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (56.8 MB)
# Submitting: kotlin_solutions_1/2935.maximum-strong-pair-xor-ii.kt
# - Downloading maximum-strong-pair-xor-ii
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 7: Char 99: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 7: Char 99: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 7: Char 181: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 7: Char 712: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 7: Char 833: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 41: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2937.make-three-strings-equal.kt
# - Downloading make-three-strings-equal
#   ✔ Accepted
#   ✔ 1935/1935 cases passed (8 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (46.2 MB)
# Submitting: kotlin_solutions_1/2938.separate-black-and-white-balls.kt
# - Downloading separate-black-and-white-balls
#   ✔ Accepted
#   ✔ 581/581 cases passed (21 ms)
#   ✔ Your runtime beats 22.22 % of kotlin submissions
#   ✔ Your memory usage beats 77.78 % of kotlin submissions (47.2 MB)
# Submitting: kotlin_solutions_1/2939.maximum-xor-product.kt
# - Downloading maximum-xor-product
#   ✔ Accepted
#   ✔ 863/863 cases passed (8 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (42.8 MB)
# Submitting: kotlin_solutions_1/2940.find-building-where-alice-and-bob-can-meet.kt
# - Downloading find-building-where-alice-and-bob-can-meet
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 7: Char 175: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 7: Char 175: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 7: Char 179: WARNING: Parameter '<unused var>: Int' is never used, could be renamed to '_'.
# Line 7: Char 182: WARNING: Parameter '<unused var>: Int' is never used, could be renamed to '_'.
# Line 7: Char 185: WARNING: Parameter '<unused var>: Int' is never used, could be renamed to '_'.
# Line 7: Char 418: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 7: Char 468: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 7: Char 472: WARNING: Parameter '<unused var>: Int' is never used, could be renamed to '_'.
# Line 7: Char 475: WARNING: Parameter '<unused var>: Int' is never used, could be renamed to '_'.
# Line 7: Char 478: WARNING: Parameter '<unused var>: Int' is never used, could be renamed to '_'.
# Line 7: Char 481: WARNING: Parameter '<unused var>: Int' is never used, could be renamed to '_'.
# Line 7: Char 484: WARNING: Parameter '<unused var>: Int' is never used, could be renamed to '_'.
# Line 7: Char 487: WARNING: Parameter '<unused var>: Int' is never used, could be renamed to '_'.
# Line 43: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2942.find-words-containing-character.kt
# - Downloading find-words-containing-character
#   ✔ Accepted
#   ✔ 912/912 cases passed (23 ms)
#   ✔ Your runtime beats 7.69 % of kotlin submissions
#   ✔ Your memory usage beats 7.69 % of kotlin submissions (49.7 MB)
# Submitting: kotlin_solutions_1/2943.maximize-area-of-square-hole-in-grid.kt
# - Downloading maximize-area-of-square-hole-in-grid
#   ✔ Accepted
#   ✔ 524/524 cases passed (28 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (46.9 MB)
# Submitting: kotlin_solutions_1/2944.minimum-number-of-coins-for-fruits.kt
# - Downloading minimum-number-of-coins-for-fruits
#   ✔ Accepted
#   ✔ 578/578 cases passed (33 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2945.find-maximum-non-decreasing-array-length.kt
# - Downloading find-maximum-non-decreasing-array-length
#   ✔ Accepted
#   ✔ 553/553 cases passed (65 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (75.2 MB)
# Submitting: kotlin_solutions_1/2946.matrix-similarity-after-cyclic-shifts.kt
# - Downloading matrix-similarity-after-cyclic-shifts
#   ✔ Accepted
#   ✔ 920/920 cases passed (17 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2947.count-beautiful-substrings-i.kt
# - Downloading count-beautiful-substrings-i
#   ✔ Accepted
#   ✔ 619/619 cases passed (313 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (49 MB)
# Submitting: kotlin_solutions_1/2948.make-lexicographically-smallest-array-by-swapping-elements.kt
# - Downloading make-lexicographically-smallest-array-by-swapping-elements
#   ✔ Accepted
#   ✔ 523/523 cases passed (377 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2949.count-beautiful-substrings-ii.kt
# - Downloading count-beautiful-substrings-ii
#   ✔ Accepted
#   ✔ 684/684 cases passed (448 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (58.9 MB)
# Submitting: kotlin_solutions_1/2951.find-the-peaks.kt
# - Downloading find-the-peaks
#   ✔ Accepted
#   ✔ 648/648 cases passed (6 ms)
#   ✔ Your runtime beats 12.5 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (48 MB)
# Submitting: kotlin_solutions_1/2952.minimum-number-of-coins-to-be-added.kt
# - Downloading minimum-number-of-coins-to-be-added
#   ✔ Accepted
#   ✔ 628/628 cases passed (150 ms)
#   ✔ Your runtime beats 60 % of kotlin submissions
#   ✔ Your memory usage beats 80 % of kotlin submissions (66.8 MB)
# Submitting: kotlin_solutions_1/2953.count-complete-substrings.kt
# - Downloading count-complete-substrings
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 8: Char 517: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 8: Char 517: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 8: Char 539: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 8: Char 681: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 8: Char 706: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 45: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/2954.count-the-number-of-infection-sequences.kt
# - Downloading count-the-number-of-infection-sequences
#   ✔ Accepted
#   ✔ 1000/1000 cases passed (307 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (73.7 MB)
# Submitting: kotlin_solutions_1/2956.find-common-elements-between-two-arrays.kt
# - Downloading find-common-elements-between-two-arrays
#   ✔ Accepted
#   ✔ 1208/1208 cases passed (14 ms)
#   ✔ Your runtime beats 14.29 % of kotlin submissions
#   ✔ Your memory usage beats 85.71 % of kotlin submissions (51.1 MB)
# Submitting: kotlin_solutions_1/2957.remove-adjacent-almost-equal-characters.kt
# - Downloading remove-adjacent-almost-equal-characters
#   ✔ Accepted
#   ✔ 779/779 cases passed (8 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2958.length-of-longest-subarray-with-at-most-k-frequency.kt
# - Downloading length-of-longest-subarray-with-at-most-k-frequency
#   ✔ Accepted
#   ✔ 994/994 cases passed (184 ms)
#   ✔ Your runtime beats 5.12 % of kotlin submissions
#   ✔ Your memory usage beats 31.4 % of kotlin submissions (78.4 MB)
# Submitting: kotlin_solutions_1/2959.number-of-possible-sets-of-closing-branches.kt
# - Downloading number-of-possible-sets-of-closing-branches
#   ✔ Accepted
#   ✔ 533/533 cases passed (80 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (50 MB)
# Submitting: kotlin_solutions_1/2960.count-tested-devices-after-test-operations.kt
# - Downloading count-tested-devices-after-test-operations
#   ✔ Accepted
#   ✔ 520/520 cases passed (1 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (45.6 MB)
# Submitting: kotlin_solutions_1/2961.double-modular-exponentiation.kt
# - Downloading double-modular-exponentiation
#   ✔ Accepted
#   ✔ 524/524 cases passed (46 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (57.4 MB)
# Submitting: kotlin_solutions_1/2962.count-subarrays-where-max-element-appears-at-least-k-times.kt
# - Downloading count-subarrays-where-max-element-appears-at-least-k-times
#   ✔ Accepted
#   ✔ 634/634 cases passed (42 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2963.count-the-number-of-good-partitions.kt
# - Downloading count-the-number-of-good-partitions
#   ✔ Accepted
#   ✔ 813/813 cases passed (72 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/2965.find-missing-and-repeated-values.kt
# - Downloading find-missing-and-repeated-values
#   ✔ Accepted
#   ✔ 584/584 cases passed (51 ms)
#   ✔ Your runtime beats 7.14 % of kotlin submissions
#   ✔ Your memory usage beats 7.14 % of kotlin submissions (58.1 MB)
# Submitting: kotlin_solutions_1/2966.divide-array-into-arrays-with-max-difference.kt
# - Downloading divide-array-into-arrays-with-max-difference
#   ✔ Accepted
#   ✔ 1117/1117 cases passed (112 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 16.67 % of kotlin submissions (83.4 MB)

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-08-17 19:29:43
