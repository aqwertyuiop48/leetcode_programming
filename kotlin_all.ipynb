# %%
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git
# !pip install nbmerge
# !nbmerge leetcode_programming/kotlin_code/*.ipynb > all_kotlin_solutions.ipynb

# %run leetcode_programming/kotlin_code/leetcode_8.ipynb
# %run leetcode_programming/kotlin_code/leetcode_7.ipynb
# %run leetcode_programming/kotlin_code/leetcode_6.ipynb
# %run leetcode_programming/kotlin_code/leetcode_5.ipynb
# %run leetcode_programming/kotlin_code/leetcode_4.ipynb
# %run leetcode_programming/kotlin_code/leetcode_3.ipynb
# %run leetcode_programming/kotlin_code/leetcode_2.ipynb
# %run leetcode_programming/kotlin_code/leetcode_1.ipynb

# %run leetcode_programming/kotlin_code/retry_1_to_8.ipynb
# Out:
# Cloning into 'leetcode_programming'...
# remote: Enumerating objects: 1837, done.
# remote: Counting objects: 100% (194/194), done.
# remote: Compressing objects: 100% (175/175), done.
# remote: Total 1837 (delta 50), reused 137 (delta 18), pack-reused 1643 (from 1)
# Receiving objects: 100% (1837/1837), 1.16 MiB | 8.12 MiB/s, done.
# Resolving deltas: 100% (315/315), done.
# Submitting: kotlin_solutions/899.orderly-queue.kt
# - Downloading problems
# - Downloading orderly-queue
#   ✔ Accepted
#   ✔ 112/112 cases passed (32 ms)
#   ✔ Your runtime beats 66.67 % of kotlin submissions
#   ✔ Your memory usage beats 22.22 % of kotlin submissions (47.6 MB)
# Submitting: kotlin_solutions/900.rle-iterator.kt
# - Downloading rle-iterator
#   ✔ Accepted
#   ✔ 11/11 cases passed (24 ms)
#   ✔ Your runtime beats 38.71 % of kotlin submissions
#   ✔ Your memory usage beats 32.26 % of kotlin submissions (46.2 MB)
# Submitting: kotlin_solutions/902.numbers-at-most-n-given-digit-set.kt
# - Downloading numbers-at-most-n-given-digit-set
#   ✔ Accepted
#   ✔ 84/84 cases passed (11 ms)
#   ✔ Your runtime beats 84.62 % of kotlin submissions
#   ✔ Your memory usage beats 46.15 % of kotlin submissions (42.5 MB)
# Submitting: kotlin_solutions/903.valid-permutations-for-di-sequence.kt
# - Downloading valid-permutations-for-di-sequence
#   ✔ Accepted
#   ✔ 83/83 cases passed (40 ms)
#   ✔ Your runtime beats 55.56 % of kotlin submissions
#   ✔ Your memory usage beats 22.22 % of kotlin submissions (47 MB)
# Submitting: kotlin_solutions/1389.create-target-array-in-the-given-order.kt
# - Downloading create-target-array-in-the-given-order
#   ✔ Accepted
#   ✔ 45/45 cases passed (19 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 11.11 % of kotlin submissions (46.3 MB)
# Submitting: kotlin_solutions/1991.find-the-middle-index-in-array.kt
# - Downloading find-the-middle-index-in-array
#   ✔ Accepted
#   ✔ 294/294 cases passed (21 ms)
#   ✔ Your runtime beats 24.32 % of kotlin submissions
#   ✔ Your memory usage beats 5.41 % of kotlin submissions (46.6 MB)
# Submitting: kotlin_solutions/2303.calculate-amount-paid-in-taxes.kt
# - Downloading calculate-amount-paid-in-taxes
#   ✔ Accepted
#   ✔ 227/227 cases passed (2 ms)
#   ✔ Your runtime beats 47.06 % of kotlin submissions
#   ✔ Your memory usage beats 70.59 % of kotlin submissions (48.8 MB)
# Submitting: kotlin_solutions/2437.number-of-valid-clock-times.kt
# - Downloading number-of-valid-clock-times
#   ✔ Accepted
#   ✔ 55/55 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 72.73 % of kotlin submissions (40.1 MB)
# Submitting: kotlin_solutions/2441.largest-positive-integer-that-exists-with-its-negative.kt
# - Downloading largest-positive-integer-that-exists-with-its-negative
#   ✔ Accepted
#   ✔ 339/339 cases passed (20 ms)
#   ✔ Your runtime beats 19.05 % of kotlin submissions
#   ✔ Your memory usage beats 95.24 % of kotlin submissions (48 MB)
# Submitting: kotlin_solutions/2446.determine-if-two-events-have-conflict.kt
# - Downloading determine-if-two-events-have-conflict
#   ✔ Accepted
#   ✔ 129/129 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (41.2 MB)
# Submitting: kotlin_solutions/2451.odd-string-difference.kt
# - Downloading odd-string-difference
#   ✔ Accepted
#   ✔ 40/40 cases passed (20 ms)
#   ✔ Your runtime beats 78.57 % of kotlin submissions
#   ✔ Your memory usage beats 85.71 % of kotlin submissions (45.2 MB)
# Submitting: kotlin_solutions/2455.average-value-of-even-numbers-that-are-divisible-by-three.kt
# - Downloading average-value-of-even-numbers-that-are-divisible-by-three
#   ✔ Accepted
#   ✔ 181/181 cases passed (18 ms)
#   ✔ Your runtime beats 66.67 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (49.2 MB)
# Submitting: kotlin_solutions/2460.apply-operations-to-an-array.kt
# - Downloading apply-operations-to-an-array
#   ✔ Accepted
#   ✔ 36/36 cases passed (22 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 71.43 % of kotlin submissions (45.7 MB)
# Submitting: kotlin_solutions/2465.number-of-distinct-averages.kt
# - Downloading number-of-distinct-averages
#   ✔ Accepted
#   ✔ 36/36 cases passed (21 ms)
#   ✔ Your runtime beats 53.33 % of kotlin submissions
#   ✔ Your memory usage beats 13.33 % of kotlin submissions (46 MB)
# Submitting: kotlin_solutions/2469.convert-the-temperature.kt
# - Downloading convert-the-temperature
#   ✔ Accepted
#   ✔ 74/74 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 64 % of kotlin submissions (41.2 MB)
# Submitting: kotlin_solutions/2475.number-of-unequal-triplets-in-array.kt
# - Downloading number-of-unequal-triplets-in-array
#   ✔ Accepted
#   ✔ 104/104 cases passed (28 ms)
#   ✔ Your runtime beats 69.23 % of kotlin submissions
#   ✔ Your memory usage beats 38.46 % of kotlin submissions (47.4 MB)
# Submitting: kotlin_solutions/2481.minimum-cuts-to-divide-a-circle.kt
# - Downloading minimum-cuts-to-divide-a-circle
#   ✔ Accepted
#   ✔ 100/100 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 8.33 % of kotlin submissions (40.6 MB)
# Submitting: kotlin_solutions/2490.circular-sentence.kt
# - Downloading circular-sentence
#   ✔ Accepted
#   ✔ 266/266 cases passed (16 ms)
#   ✔ Your runtime beats 13.64 % of kotlin submissions
#   ✔ Your memory usage beats 22.73 % of kotlin submissions (44.4 MB)
# Submitting: kotlin_solutions/2496.maximum-value-of-a-string-in-an-array.kt
# - Downloading maximum-value-of-a-string-in-an-array
#   ✔ Accepted
#   ✔ 64/64 cases passed (18 ms)
#   ✔ Your runtime beats 23.53 % of kotlin submissions
#   ✔ Your memory usage beats 5.88 % of kotlin submissions (46.2 MB)
# Submitting: kotlin_solutions/2500.delete-greatest-value-in-each-row.kt
# - Downloading delete-greatest-value-in-each-row
#   ✔ Accepted
#   ✔ 55/55 cases passed (20 ms)
#   ✔ Your runtime beats 53.85 % of kotlin submissions
#   ✔ Your memory usage beats 46.15 % of kotlin submissions (50.2 MB)
# Submitting: kotlin_solutions/2506.count-pairs-of-similar-strings.kt
# - Downloading count-pairs-of-similar-strings
#   ✔ Accepted
#   ✔ 225/225 cases passed (67 ms)
#   ✔ Your runtime beats 13.04 % of kotlin submissions
#   ✔ Your memory usage beats 8.7 % of kotlin submissions (51.5 MB)
# Submitting: kotlin_solutions/2513.minimize-the-maximum-of-two-arrays.kt
# - Downloading minimize-the-maximum-of-two-arrays
#   ✔ Accepted
#   ✔ 63/63 cases passed (114 ms)
#   ✔ Your runtime beats 44.44 % of kotlin submissions
#   ✔ Your memory usage beats 77.78 % of kotlin submissions (45.8 MB)
# Submitting: kotlin_solutions/2520.count-the-digits-that-divide-a-number.kt
# - Downloading count-the-digits-that-divide-a-number
#   ✔ Accepted
#   ✔ 56/56 cases passed (1 ms)
#   ✔ Your runtime beats 61.54 % of kotlin submissions
#   ✔ Your memory usage beats 46.15 % of kotlin submissions (40.3 MB)
# Submitting: kotlin_solutions/2521.distinct-prime-factors-of-product-of-array.kt
# - Downloading distinct-prime-factors-of-product-of-array
#   ✔ Accepted
#   ✔ 81/81 cases passed (220 ms)
#   ✔ Your runtime beats 46.15 % of kotlin submissions
#   ✔ Your memory usage beats 69.23 % of kotlin submissions (49.6 MB)
# Submitting: kotlin_solutions/2525.categorize-box-according-to-criteria.kt
# - Downloading categorize-box-according-to-criteria
#   ✔ Accepted
#   ✔ 50/50 cases passed (1 ms)
#   ✔ Your runtime beats 10 % of kotlin submissions
#   ✔ Your memory usage beats 20 % of kotlin submissions (40.8 MB)
# Submitting: kotlin_solutions/2527.find-xor-beauty-of-array.kt
# - Downloading find-xor-beauty-of-array
#   ✔ Accepted
#   ✔ 32/32 cases passed (11 ms)
#   ✔ Your runtime beats 76.92 % of kotlin submissions
#   ✔ Your memory usage beats 69.23 % of kotlin submissions (62.4 MB)
# Submitting: kotlin_solutions/2529.maximum-count-of-positive-integer-and-negative-integer.kt
# - Downloading maximum-count-of-positive-integer-and-negative-integer
#   ✔ Accepted
#   ✔ 169/169 cases passed (9 ms)
#   ✔ Your runtime beats 22.5 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (49.6 MB)
# Submitting: kotlin_solutions/2535.difference-between-element-sum-and-digit-sum-of-an-array.kt
# - Downloading difference-between-element-sum-and-digit-sum-of-an-array
#   ✔ Accepted
#   ✔ 142/142 cases passed (7 ms)
#   ✔ Your runtime beats 45.45 % of kotlin submissions
#   ✔ Your memory usage beats 9.09 % of kotlin submissions (49.7 MB)
# Submitting: kotlin_solutions/2536.increment-submatrices-by-one.kt
# - Downloading increment-submatrices-by-one
#   ✔ Accepted
#   ✔ 32/32 cases passed (54 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 26.67 % of kotlin submissions (75.3 MB)
# Submitting: kotlin_solutions/2540.minimum-common-value.kt
# - Downloading minimum-common-value
#   ✔ Accepted
#   ✔ 41/41 cases passed (77 ms)
#   ✔ Your runtime beats 9.38 % of kotlin submissions
#   ✔ Your memory usage beats 10.94 % of kotlin submissions (91.4 MB)
# Submitting: kotlin_solutions/2544.alternating-digit-sum.kt
# - Downloading alternating-digit-sum
#   ✔ Accepted
#   ✔ 118/118 cases passed (7 ms)
#   ✔ Your runtime beats 42.31 % of kotlin submissions
#   ✔ Your memory usage beats 11.54 % of kotlin submissions (41.6 MB)
# Submitting: kotlin_solutions/2545.sort-the-students-by-their-kth-score.kt
# - Downloading sort-the-students-by-their-kth-score
#   ✔ Accepted
#   ✔ 33/33 cases passed (14 ms)
#   ✔ Your runtime beats 68.42 % of kotlin submissions
#   ✔ Your memory usage beats 68.42 % of kotlin submissions (60.3 MB)
# Submitting: kotlin_solutions/2553.separate-the-digits-in-an-array.kt
# - Downloading separate-the-digits-in-an-array
#   ✔ Accepted
#   ✔ 52/52 cases passed (19 ms)
#   ✔ Your runtime beats 38.46 % of kotlin submissions
#   ✔ Your memory usage beats 7.69 % of kotlin submissions (49.8 MB)
# Submitting: kotlin_solutions/2559.count-vowel-strings-in-ranges.kt
# - Downloading count-vowel-strings-in-ranges
#   ✔ Accepted
#   ✔ 94/94 cases passed (50 ms)
#   ✔ Your runtime beats 38.46 % of kotlin submissions
#   ✔ Your memory usage beats 34.61 % of kotlin submissions (114.5 MB)
# Submitting: kotlin_solutions/2562.find-the-array-concatenation-value.kt
# - Downloading find-the-array-concatenation-value
#   ✔ Accepted
#   ✔ 53/53 cases passed (14 ms)
#   ✔ Your runtime beats 40 % of kotlin submissions
#   ✔ Your memory usage beats 6.67 % of kotlin submissions (47.9 MB)
# Submitting: kotlin_solutions/2563.count-the-number-of-fair-pairs.kt
# - Downloading count-the-number-of-fair-pairs
#   ✔ Accepted
#   ✔ 55/55 cases passed (272 ms)
#   ✔ Your runtime beats 43.75 % of kotlin submissions
#   ✔ Your memory usage beats 6.25 % of kotlin submissions (92.7 MB)
# Submitting: kotlin_solutions/2566.maximum-difference-by-remapping-a-digit.kt
# - Downloading maximum-difference-by-remapping-a-digit
#   ✔ Accepted
#   ✔ 214/214 cases passed (11 ms)
#   ✔ Your runtime beats 30 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (41.6 MB)
# Submitting: kotlin_solutions/2570.merge-two-2-d-arrays-by-summing-values.kt
# - Downloading merge-two-2d-arrays-by-summing-values
#   ✔ Accepted
#   ✔ 39/39 cases passed (17 ms)
#   ✔ Your runtime beats 45.45 % of kotlin submissions
#   ✔ Your memory usage beats 13.64 % of kotlin submissions (53 MB)
# Submitting: kotlin_solutions/2574.left-and-right-sum-differences.kt
# - Downloading left-and-right-sum-differences
#   ✔ Accepted
#   ✔ 53/53 cases passed (108 ms)
#   ✔ Your runtime beats 7.41 % of kotlin submissions
#   ✔ Your memory usage beats 29.63 % of kotlin submissions (50.2 MB)
# Submitting: kotlin_solutions/2575.find-the-divisibility-array-of-a-string.kt
# - Downloading find-the-divisibility-array-of-a-string
#   ✔ Accepted
#   ✔ 51/51 cases passed (61 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 22.22 % of kotlin submissions (60.6 MB)
# Submitting: kotlin_solutions/2578.split-with-minimum-sum.kt
# - Downloading split-with-minimum-sum
#   ✔ Accepted
#   ✔ 140/140 cases passed (24 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
#   ✔ Your memory usage beats 10 % of kotlin submissions (46.3 MB)
# Submitting: kotlin_solutions/2582.pass-the-pillow.kt
# - Downloading pass-the-pillow
#   ✔ Accepted
#   ✔ 68/68 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 92.31 % of kotlin submissions (39.8 MB)
# Submitting: kotlin_solutions/2583.kth-largest-sum-in-a-binary-tree.kt
# - Downloading kth-largest-sum-in-a-binary-tree
#   ✔ Accepted
#   ✔ 51/51 cases passed (173 ms)
#   ✔ Your runtime beats 40 % of kotlin submissions
#   ✔ Your memory usage beats 70 % of kotlin submissions (76.3 MB)
# Submitting: kotlin_solutions/2586.count-the-number-of-vowel-strings-in-range.kt
# - Downloading count-the-number-of-vowel-strings-in-range
#   ✔ Accepted
#   ✔ 1053/1053 cases passed (27 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
#   ✔ Your memory usage beats 6.25 % of kotlin submissions (49.5 MB)
# Submitting: kotlin_solutions/2587.rearrange-array-to-maximize-prefix-score.kt
# - Downloading rearrange-array-to-maximize-prefix-score
#   ✔ Accepted
#   ✔ 1071/1071 cases passed (97 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (62.4 MB)
# Submitting: kotlin_solutions/2595.number-of-even-and-odd-bits.kt
# - Downloading number-of-even-and-odd-bits
#   ✔ Accepted
#   ✔ 1003/1003 cases passed (1 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (42.7 MB)
# Submitting: kotlin_solutions/2600.k-items-with-the-maximum-sum.kt
# - Downloading k-items-with-the-maximum-sum
#   ✔ Accepted
#   ✔ 1310/1310 cases passed (1 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 22.22 % of kotlin submissions (41.6 MB)
# Submitting: kotlin_solutions/2605.form-smallest-number-from-two-digit-arrays.kt
# - Downloading form-smallest-number-from-two-digit-arrays
#   ✔ Accepted
#   ✔ 388/388 cases passed (24 ms)
#   ✔ Your runtime beats 45.45 % of kotlin submissions
#   ✔ Your memory usage beats 45.45 % of kotlin submissions (46.6 MB)
# Submitting: kotlin_solutions/2609.find-the-longest-balanced-substring-of-a-binary-string.kt
# - Downloading find-the-longest-balanced-substring-of-a-binary-string
#   ✔ Accepted
#   ✔ 1848/1848 cases passed (49 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
#   ✔ Your memory usage beats 8.33 % of kotlin submissions (49.8 MB)
# Submitting: kotlin_solutions/2615.sum-of-distances.kt
# - Downloading sum-of-distances
#   ✔ Accepted
#   ✔ 1068/1068 cases passed (109 ms)
#   ✔ Your runtime beats 30 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (91.2 MB)
# Submitting: kotlin_solutions/2640.find-the-score-of-all-prefixes-of-an-array.kt
# - Downloading find-the-score-of-all-prefixes-of-an-array
#   ✔ Accepted
#   ✔ 43/43 cases passed (42 ms)
#   ✔ Your runtime beats 22.22 % of kotlin submissions
#   ✔ Your memory usage beats 88.89 % of kotlin submissions (66.7 MB)
# Submitting: kotlin_solutions/2643.row-with-maximum-ones.kt
# - Downloading row-with-maximum-ones
#   ✔ Accepted
#   ✔ 1049/1049 cases passed (15 ms)
#   ✔ Your runtime beats 28.57 % of kotlin submissions
#   ✔ Your memory usage beats 23.81 % of kotlin submissions (69.9 MB)
# Submitting: kotlin_solutions/2644.find-the-maximum-divisibility-score.kt
# - Downloading find-the-maximum-divisibility-score
#   ✔ Accepted
#   ✔ 160/160 cases passed (277 ms)
#   ✔ Your runtime beats 9.52 % of kotlin submissions
#   ✔ Your memory usage beats 9.52 % of kotlin submissions (66 MB)
# Submitting: kotlin_solutions/2651.calculate-delayed-arrival-time.kt
# - Downloading calculate-delayed-arrival-time
#   ✔ Accepted
#   ✔ 556/556 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 15.38 % of kotlin submissions (41.1 MB)
# Submitting: kotlin_solutions/2652.sum-multiples.kt
# - Downloading sum-multiples
#   ✔ Accepted
#   ✔ 1000/1000 cases passed (23 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 43.75 % of kotlin submissions (47 MB)
# Submitting: kotlin_solutions/2656.maximum-sum-with-exactly-k-elements.kt
# - Downloading maximum-sum-with-exactly-k-elements
#   ✔ Accepted
#   ✔ 3004/3004 cases passed (13 ms)
#   ✔ Your runtime beats 37.5 % of kotlin submissions
#   ✔ Your memory usage beats 37.5 % of kotlin submissions (50.3 MB)
# Submitting: kotlin_solutions/2657.find-the-prefix-common-array-of-two-arrays.kt
# - Downloading find-the-prefix-common-array-of-two-arrays
#   ✔ Accepted
#   ✔ 1773/1773 cases passed (120 ms)
#   ✔ Your runtime beats 8.33 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (69.4 MB)
# Submitting: kotlin_solutions/3000.maximum-area-of-longest-diagonal-rectangle.kt
# - Downloading maximum-area-of-longest-diagonal-rectangle
#   ✔ Accepted
#   ✔ 817/817 cases passed (7 ms)
#   ✔ Your runtime beats 26.32 % of kotlin submissions
#   ✔ Your memory usage beats 21.05 % of kotlin submissions (51.7 MB)
# Submitting: kotlin_solutions/3005.count-elements-with-maximum-frequency.kt
# - Downloading count-elements-with-maximum-frequency
#   ✔ Accepted
#   ✔ 623/623 cases passed (20 ms)
#   ✔ Your runtime beats 21.15 % of kotlin submissions
#   ✔ Your memory usage beats 5.77 % of kotlin submissions (47.2 MB)
# Submitting: kotlin_solutions/3006.find-beautiful-indices-in-the-given-array-i.kt
# - Downloading find-beautiful-indices-in-the-given-array-i
#   ✔ Accepted
#   ✔ 535/535 cases passed (202 ms)
#   ✔ Your runtime beats 42.86 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (55.9 MB)
# Submitting: kotlin_solutions/3019.number-of-changing-keys.kt
# - Downloading number-of-changing-keys
#   ✔ Accepted
#   ✔ 802/802 cases passed (15 ms)
#   ✔ Your runtime beats 35 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (45.9 MB)
# Submitting: kotlin_solutions/3024.type-of-triangle.kt
# - Downloading type-of-triangle
#   ✔ Accepted
#   ✔ 705/705 cases passed (19 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (46.7 MB)
# Submitting: kotlin_solutions/3033.modify-the-matrix.kt
# - Downloading modify-the-matrix
#   ✔ Accepted
#   ✔ 514/514 cases passed (19 ms)
#   ✔ Your runtime beats 17.65 % of kotlin submissions
#   ✔ Your memory usage beats 82.35 % of kotlin submissions (51.3 MB)
# Submitting: kotlin_solutions/3563.lexicographically-smallest-string-after-adjacent-removals.kt
# - Downloading lexicographically-smallest-string-after-adjacent-removals
#   ✔ Accepted
#   ✔ 930/930 cases passed (404 ms)
#   ✔ Your runtime beats 36.36 % of kotlin submissions
#   ✔ Your memory usage beats 27.27 % of kotlin submissions (60 MB)
# Submitting: kotlin_solutions/3721.longest-balanced-subarray-ii.kt
# - Downloading longest-balanced-subarray-ii
#   ✔ Accepted
#   ✔ 999/999 cases passed (264 ms)
#   ✔ Your runtime beats 27.22 % of kotlin submissions
#   ✔ Your memory usage beats 39.24 % of kotlin submissions (84.6 MB)
# Current Time in IST: 2026-02-26 10:01:59
# Submitting: kotlin_solutions/789.escape-the-ghosts.kt
# - Downloading escape-the-ghosts
#   ✔ Accepted
#   ✔ 77/77 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 41.18 % of kotlin submissions (42.8 MB)
# Submitting: kotlin_solutions/790.domino-and-tromino-tiling.kt
# - Downloading domino-and-tromino-tiling
#   ✔ Accepted
#   ✔ 39/39 cases passed (6 ms)
#   ✔ Your runtime beats 40 % of kotlin submissions
#   ✔ Your memory usage beats 23.33 % of kotlin submissions (41.3 MB)
# Submitting: kotlin_solutions/791.custom-sort-string.kt
# - Downloading custom-sort-string
#   ✔ Accepted
#   ✔ 41/41 cases passed (36 ms)
#   ✔ Your runtime beats 10.81 % of kotlin submissions
#   ✔ Your memory usage beats 5.41 % of kotlin submissions (47.9 MB)
# Submitting: kotlin_solutions/792.number-of-matching-subsequences.kt
# - Downloading number-of-matching-subsequences
#   ✔ Accepted
#   ✔ 53/53 cases passed (81 ms)
#   ✔ Your runtime beats 53.33 % of kotlin submissions
#   ✔ Your memory usage beats 48.89 % of kotlin submissions (50.8 MB)
# Submitting: kotlin_solutions/793.preimage-size-of-factorial-zeroes-function.kt
# - Downloading preimage-size-of-factorial-zeroes-function
#   ✔ Accepted
#   ✔ 44/44 cases passed (20 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 87.5 % of kotlin submissions (43.3 MB)
# Submitting: kotlin_solutions/794.valid-tic-tac-toe-state.kt
# - Downloading valid-tic-tac-toe-state
#   ✔ Accepted
#   ✔ 111/111 cases passed (30 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (46.7 MB)
# Submitting: kotlin_solutions/795.number-of-subarrays-with-bounded-maximum.kt
# - Downloading number-of-subarrays-with-bounded-maximum
#   ✔ Accepted
#   ✔ 46/46 cases passed (46 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 44.44 % of kotlin submissions (61.8 MB)
# Submitting: kotlin_solutions/796.rotate-string.kt
# - Downloading rotate-string
#   ✔ Accepted
#   ✔ 58/58 cases passed (6 ms)
#   ✔ Your runtime beats 69.81 % of kotlin submissions
#   ✔ Your memory usage beats 20.75 % of kotlin submissions (42.2 MB)
# Submitting: kotlin_solutions/797.all-paths-from-source-to-target.kt
# - Downloading all-paths-from-source-to-target
#   ✔ Accepted
#   ✔ 30/30 cases passed (31 ms)
#   ✔ Your runtime beats 10.96 % of kotlin submissions
#   ✔ Your memory usage beats 5.48 % of kotlin submissions (57.2 MB)
# Submitting: kotlin_solutions/798.smallest-rotation-with-highest-score.kt
# - Downloading smallest-rotation-with-highest-score
#   ✔ Accepted
#   ✔ 44/44 cases passed (31 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (62.2 MB)
# Submitting: kotlin_solutions/799.champagne-tower.kt
# - Downloading champagne-tower
#   ✔ Accepted
#   ✔ 312/312 cases passed (154 ms)
#   ✔ Your runtime beats 12.32 % of kotlin submissions
#   ✔ Your memory usage beats 27.11 % of kotlin submissions (45.7 MB)
# Submitting: kotlin_solutions/801.minimum-swaps-to-make-sequences-increasing.kt
# - Downloading minimum-swaps-to-make-sequences-increasing
#   ✔ Accepted
#   ✔ 117/117 cases passed (307 ms)
#   ✔ Your runtime beats 12.5 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (122.4 MB)
# Submitting: kotlin_solutions/802.find-eventual-safe-states.kt
# - Downloading find-eventual-safe-states
#   ✔ Accepted
#   ✔ 113/113 cases passed (61 ms)
#   ✔ Your runtime beats 32.73 % of kotlin submissions
#   ✔ Your memory usage beats 14.54 % of kotlin submissions (80.1 MB)
# Submitting: kotlin_solutions/803.bricks-falling-when-hit.kt
# - Downloading bricks-falling-when-hit
#   ✔ Accepted
#   ✔ 40/40 cases passed (109 ms)
#   ✔ Your runtime beats 26.67 % of kotlin submissions
#   ✔ Your memory usage beats 93.33 % of kotlin submissions (74.3 MB)
# Submitting: kotlin_solutions/804.unique-morse-code-words.kt
# - Downloading unique-morse-code-words
#   ✔ Accepted
#   ✔ 82/82 cases passed (20 ms)
#   ✔ Your runtime beats 36.84 % of kotlin submissions
#   ✔ Your memory usage beats 60.53 % of kotlin submissions (45.2 MB)
# Submitting: kotlin_solutions/805.split-array-with-same-average.kt
# - Downloading split-array-with-same-average
#   ✔ Accepted
#   ✔ 111/111 cases passed (2023 ms)
#   ✔ Your runtime beats 66.67 % of kotlin submissions
#   ✔ Your memory usage beats 16.67 % of kotlin submissions (146.9 MB)
# Submitting: kotlin_solutions/806.number-of-lines-to-write-string.kt
# - Downloading number-of-lines-to-write-string
#   ✔ Accepted
#   ✔ 27/27 cases passed (96 ms)
#   ✔ Your runtime beats 31.58 % of kotlin submissions
#   ✔ Your memory usage beats 5.26 % of kotlin submissions (41 MB)
# Submitting: kotlin_solutions/807.max-increase-to-keep-city-skyline.kt
# - Downloading max-increase-to-keep-city-skyline
#   ✔ Accepted
#   ✔ 133/133 cases passed (23 ms)
#   ✔ Your runtime beats 11.54 % of kotlin submissions
#   ✔ Your memory usage beats 7.69 % of kotlin submissions (49 MB)
# Submitting: kotlin_solutions/808.soup-servings.kt
# - Downloading soup-servings
#   ✔ Accepted
#   ✔ 43/43 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 85.71 % of kotlin submissions (40.3 MB)
# Submitting: kotlin_solutions/809.expressive-words.kt
# - Downloading expressive-words
#   ✔ Accepted
#   ✔ 36/36 cases passed (30 ms)
#   ✔ Your runtime beats 15.79 % of kotlin submissions
#   ✔ Your memory usage beats 26.32 % of kotlin submissions (48.1 MB)
# Submitting: kotlin_solutions/810.chalkboard-xor-game.kt
# - Downloading chalkboard-xor-game
#   ✔ Accepted
#   ✔ 168/168 cases passed (10 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 83.33 % of kotlin submissions (46.2 MB)
# Submitting: kotlin_solutions/811.subdomain-visit-count.kt
# - Downloading subdomain-visit-count
#   ✔ Accepted
#   ✔ 52/52 cases passed (49 ms)
#   ✔ Your runtime beats 12.5 % of kotlin submissions
#   ✔ Your memory usage beats 18.75 % of kotlin submissions (48.4 MB)
# Submitting: kotlin_solutions/812.largest-triangle-area.kt
# - Downloading largest-triangle-area
#   ✔ Accepted
#   ✔ 57/57 cases passed (48 ms)
#   ✔ Your runtime beats 11.11 % of kotlin submissions
#   ✔ Your memory usage beats 22.22 % of kotlin submissions (48 MB)
# Submitting: kotlin_solutions/813.largest-sum-of-averages.kt
# - Downloading largest-sum-of-averages
#   ✔ Accepted
#   ✔ 51/51 cases passed (50 ms)
#   ✔ Your runtime beats 5.26 % of kotlin submissions
#   ✔ Your memory usage beats 31.58 % of kotlin submissions (47.2 MB)
# Submitting: kotlin_solutions/814.binary-tree-pruning.kt
# - Downloading binary-tree-pruning
#   ✔ Accepted
#   ✔ 31/31 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 18.18 % of kotlin submissions (41.5 MB)
# Submitting: kotlin_solutions/815.bus-routes.kt
# - Downloading bus-routes
#   ✔ Accepted
#   ✔ 54/54 cases passed (367 ms)
#   ✔ Your runtime beats 25.58 % of kotlin submissions
#   ✔ Your memory usage beats 6.98 % of kotlin submissions (133.2 MB)
# Submitting: kotlin_solutions/816.ambiguous-coordinates.kt
# - Downloading ambiguous-coordinates
#   ✔ Accepted
#   ✔ 346/346 cases passed (28 ms)
#   ✔ Your runtime beats 14.29 % of kotlin submissions
#   ✔ Your memory usage beats 42.86 % of kotlin submissions (47.8 MB)
# Submitting: kotlin_solutions/817.linked-list-components.kt
# - Downloading linked-list-components
#   ✔ Accepted
#   ✔ 57/57 cases passed (65 ms)
#   ✔ Your runtime beats 7.69 % of kotlin submissions
#   ✔ Your memory usage beats 30.77 % of kotlin submissions (52.4 MB)
# Submitting: kotlin_solutions/818.race-car.kt
# - Downloading race-car
#   ✔ Accepted
#   ✔ 55/55 cases passed (16 ms)
#   ✔ Your runtime beats 87.5 % of kotlin submissions
#   ✔ Your memory usage beats 75 % of kotlin submissions (44.6 MB)
# Submitting: kotlin_solutions/819.most-common-word.kt
# - Downloading most-common-word
#   ✔ Accepted
#   ✔ 50/50 cases passed (39 ms)
#   ✔ Your runtime beats 47.69 % of kotlin submissions
#   ✔ Your memory usage beats 30.77 % of kotlin submissions (47.6 MB)
# Submitting: kotlin_solutions/820.short-encoding-of-words.kt
# - Downloading short-encoding-of-words
#   ✔ Accepted
#   ✔ 39/39 cases passed (242 ms)
#   ✔ Your runtime beats 14.29 % of kotlin submissions
#   ✔ Your memory usage beats 28.57 % of kotlin submissions (52.3 MB)
# Submitting: kotlin_solutions/821.shortest-distance-to-a-character.kt
# - Downloading shortest-distance-to-a-character
#   ✔ Accepted
#   ✔ 76/76 cases passed (88 ms)
#   ✔ Your runtime beats 10.81 % of kotlin submissions
#   ✔ Your memory usage beats 5.41 % of kotlin submissions (50.9 MB)
# Submitting: kotlin_solutions/822.card-flipping-game.kt
# - Downloading card-flipping-game
#   ✔ Accepted
#   ✔ 169/169 cases passed (39 ms)
#   ✔ Your runtime beats 40 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions/823.binary-trees-with-factors.kt
# - Downloading binary-trees-with-factors
#   ✔ Accepted
#   ✔ 48/48 cases passed (71 ms)
#   ✔ Your runtime beats 42.86 % of kotlin submissions
#   ✔ Your memory usage beats 28.57 % of kotlin submissions (51.4 MB)
# Submitting: kotlin_solutions/824.goat-latin.kt
# - Downloading goat-latin
#   ✔ Accepted
#   ✔ 99/99 cases passed (17 ms)
#   ✔ Your runtime beats 61.7 % of kotlin submissions
#   ✔ Your memory usage beats 76.6 % of kotlin submissions (43.4 MB)
# Submitting: kotlin_solutions/825.friends-of-appropriate-ages.kt
# - Downloading friends-of-appropriate-ages
#   ✔ Accepted
#   ✔ 89/89 cases passed (18 ms)
#   ✔ Your runtime beats 38.89 % of kotlin submissions
#   ✔ Your memory usage beats 11.11 % of kotlin submissions (52.5 MB)
# Submitting: kotlin_solutions/826.most-profit-assigning-work.kt
# - Downloading most-profit-assigning-work
#   ✔ Accepted
#   ✔ 60/60 cases passed (427 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 30 % of kotlin submissions (56.8 MB)
# Submitting: kotlin_solutions/827.making-a-large-island.kt
# - Downloading making-a-large-island
#   ✔ Accepted
#   ✔ 75/75 cases passed (781 ms)
#   ✔ Your runtime beats 19.51 % of kotlin submissions
#   ✔ Your memory usage beats 9.76 % of kotlin submissions (116.4 MB)
# Submitting: kotlin_solutions/828.count-unique-characters-of-all-substrings-of-a-given-string.kt
# - Downloading count-unique-characters-of-all-substrings-of-a-given-string
#   ✔ Accepted
#   ✔ 76/76 cases passed (54 ms)
#   ✔ Your runtime beats 60 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions/829.consecutive-numbers-sum.kt
# - Downloading consecutive-numbers-sum
#   ✔ Accepted
#   ✔ 170/170 cases passed (17 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (48 MB)
# Submitting: kotlin_solutions/830.positions-of-large-groups.kt
# - Downloading positions-of-large-groups
#   ✔ Accepted
#   ✔ 202/202 cases passed (18 ms)
#   ✔ Your runtime beats 34.48 % of kotlin submissions
#   ✔ Your memory usage beats 17.24 % of kotlin submissions (47.9 MB)
# Submitting: kotlin_solutions/831.masking-personal-information.kt
# - Downloading masking-personal-information
#   ✔ Accepted
#   ✔ 66/66 cases passed (9 ms)
#   ✔ Your runtime beats 45.65 % of kotlin submissions
#   ✔ Your memory usage beats 45.65 % of kotlin submissions (42.2 MB)
# Submitting: kotlin_solutions/832.flipping-an-image.kt
# - Downloading flipping-an-image
#   ✔ Accepted
#   ✔ 82/82 cases passed (15 ms)
#   ✔ Your runtime beats 23.53 % of kotlin submissions
#   ✔ Your memory usage beats 41.18 % of kotlin submissions (48.2 MB)
# Submitting: kotlin_solutions/833.find-and-replace-in-string.kt
# - Downloading find-and-replace-in-string
#   ✔ Accepted
#   ✔ 59/59 cases passed (39 ms)
#   ✔ Your runtime beats 7.69 % of kotlin submissions
#   ✔ Your memory usage beats 7.69 % of kotlin submissions (47.7 MB)
# Submitting: kotlin_solutions/834.sum-of-distances-in-tree.kt
# - Downloading sum-of-distances-in-tree
#   ✔ Accepted
#   ✔ 74/74 cases passed (150 ms)
#   ✔ Your runtime beats 14.29 % of kotlin submissions
#   ✔ Your memory usage beats 42.86 % of kotlin submissions (82.2 MB)
# Submitting: kotlin_solutions/835.image-overlap.kt
# - Downloading image-overlap
#   ✔ Accepted
#   ✔ 60/60 cases passed (64 ms)
#   ✔ Your runtime beats 55.56 % of kotlin submissions
#   ✔ Your memory usage beats 77.78 % of kotlin submissions (52.6 MB)
# Submitting: kotlin_solutions/836.rectangle-overlap.kt
# - Downloading rectangle-overlap
#   ✔ Accepted
#   ✔ 41/41 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 9.09 % of kotlin submissions (41.1 MB)
# Submitting: kotlin_solutions/837.new-21-game.kt
# - Downloading new-21-game
#   ✔ Accepted
#   ✔ 152/152 cases passed (26 ms)
#   ✔ Your runtime beats 22.22 % of kotlin submissions
#   ✔ Your memory usage beats 55.56 % of kotlin submissions (45.6 MB)
# Submitting: kotlin_solutions/838.push-dominoes.kt
# - Downloading push-dominoes
#   ✔ Accepted
#   ✔ 45/45 cases passed (34 ms)
#   ✔ Your runtime beats 38.46 % of kotlin submissions
#   ✔ Your memory usage beats 53.85 % of kotlin submissions (47.5 MB)
# Submitting: kotlin_solutions/839.similar-string-groups.kt
# - Downloading similar-string-groups
#   ✔ Accepted
#   ✔ 77/77 cases passed (189 ms)
#   ✔ Your runtime beats 62.5 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (53.4 MB)
# Submitting: kotlin_solutions/840.magic-squares-in-grid.kt
# - Downloading magic-squares-in-grid
#   ✔ Accepted
#   ✔ 102/102 cases passed (24 ms)
#   ✔ Your runtime beats 7.69 % of kotlin submissions
#   ✔ Your memory usage beats 11.34 % of kotlin submissions (46.2 MB)
# Submitting: kotlin_solutions/841.keys-and-rooms.kt
# - Downloading keys-and-rooms
#   ✔ Accepted
#   ✔ 70/70 cases passed (17 ms)
#   ✔ Your runtime beats 40.88 % of kotlin submissions
#   ✔ Your memory usage beats 66.04 % of kotlin submissions (46.2 MB)
# Submitting: kotlin_solutions/842.split-array-into-fibonacci-sequence.kt
# - Downloading split-array-into-fibonacci-sequence
#   ✔ Accepted
#   ✔ 74/74 cases passed (40 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 16.67 % of kotlin submissions (48.3 MB)
# Submitting: kotlin_solutions/843.guess-the-word.kt
# - Downloading guess-the-word
#   ✔ Accepted
#   ✔ 13/13 cases passed (93 ms)
#   ✔ Your runtime beats 67.39 % of kotlin submissions
#   ✔ Your memory usage beats 8.7 % of kotlin submissions (46.4 MB)
# Submitting: kotlin_solutions/844.backspace-string-compare.kt
# - Downloading backspace-string-compare
#   ✔ Accepted
#   ✔ 115/115 cases passed (8 ms)
#   ✔ Your runtime beats 23.28 % of kotlin submissions
#   ✔ Your memory usage beats 32.76 % of kotlin submissions (42.1 MB)
# Submitting: kotlin_solutions/845.longest-mountain-in-array.kt
# - Downloading longest-mountain-in-array
#   ✔ Accepted
#   ✔ 75/75 cases passed (515 ms)
#   ✔ Your runtime beats 8.57 % of kotlin submissions
#   ✔ Your memory usage beats 5.71 % of kotlin submissions (51.7 MB)
# Submitting: kotlin_solutions/846.hand-of-straights.kt
# - Downloading hand-of-straights
#   ✔ Accepted
#   ✔ 92/92 cases passed (51 ms)
#   ✔ Your runtime beats 61.7 % of kotlin submissions
#   ✔ Your memory usage beats 31.91 % of kotlin submissions (50.4 MB)
# Submitting: kotlin_solutions/847.shortest-path-visiting-all-nodes.kt
# - Downloading shortest-path-visiting-all-nodes
#   ✔ Accepted
#   ✔ 55/55 cases passed (57 ms)
#   ✔ Your runtime beats 66.67 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (50.2 MB)
# Submitting: kotlin_solutions/848.shifting-letters.kt
# - Downloading shifting-letters
#   ✔ Accepted
#   ✔ 54/54 cases passed (26 ms)
#   ✔ Your runtime beats 36.36 % of kotlin submissions
#   ✔ Your memory usage beats 27.27 % of kotlin submissions (73.3 MB)
# Submitting: kotlin_solutions/849.maximize-distance-to-closest-person.kt
# - Downloading maximize-distance-to-closest-person
#   ✔ Accepted
#   ✔ 82/82 cases passed (35 ms)
#   ✔ Your runtime beats 5.8 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (50.1 MB)
# Submitting: kotlin_solutions/850.rectangle-area-ii.kt
# - Downloading rectangle-area-ii
#   ✔ Accepted
#   ✔ 78/78 cases passed (40 ms)
#   ✔ Your runtime beats 35.71 % of kotlin submissions
#   ✔ Your memory usage beats 35.71 % of kotlin submissions (49.3 MB)
# Submitting: kotlin_solutions/854.k-similar-strings.kt
# - Downloading k-similar-strings
#   ✔ Accepted
#   ✔ 66/66 cases passed (204 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (63.5 MB)
# Submitting: kotlin_solutions/857.minimum-cost-to-hire-k-workers.kt
# - Downloading minimum-cost-to-hire-k-workers
#   ✔ Accepted
#   ✔ 49/49 cases passed (233 ms)
#   ✔ Your runtime beats 9.09 % of kotlin submissions
#   ✔ Your memory usage beats 18.18 % of kotlin submissions (56.7 MB)
# Submitting: kotlin_solutions/862.shortest-subarray-with-sum-at-least-k.kt
# - Downloading shortest-subarray-with-sum-at-least-k
#   ✔ Accepted
#   ✔ 99/99 cases passed (209 ms)
#   ✔ Your runtime beats 14.29 % of kotlin submissions
#   ✔ Your memory usage beats 57.14 % of kotlin submissions (65.9 MB)
# Submitting: kotlin_solutions/863.all-nodes-distance-k-in-binary-tree.kt
# - Downloading all-nodes-distance-k-in-binary-tree
#   ✔ Accepted
#   ✔ 57/57 cases passed (188 ms)
#   ✔ Your runtime beats 6.56 % of kotlin submissions
#   ✔ Your memory usage beats 6.56 % of kotlin submissions (46.5 MB)
# Submitting: kotlin_solutions/864.shortest-path-to-get-all-keys.kt
# - Downloading shortest-path-to-get-all-keys
#   ✔ Accepted
#   ✔ 36/36 cases passed (135 ms)
#   ✔ Your runtime beats 75 % of kotlin submissions
#   ✔ Your memory usage beats 75 % of kotlin submissions (64.3 MB)
# Submitting: kotlin_solutions/865.smallest-subtree-with-all-the-deepest-nodes.kt
# - Downloading smallest-subtree-with-all-the-deepest-nodes
#   ✔ Accepted
#   ✔ 60/60 cases passed (13 ms)
#   ✔ Your runtime beats 6.55 % of kotlin submissions
#   ✔ Your memory usage beats 15.1 % of kotlin submissions (43 MB)
# Submitting: kotlin_solutions/866.prime-palindrome.kt
# - Downloading prime-palindrome
#   ✔ Accepted
#   ✔ 61/61 cases passed (3364 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (49.6 MB)
# Submitting: kotlin_solutions/867.transpose-matrix.kt
# - Downloading transpose-matrix
#   ✔ Accepted
#   ✔ 36/36 cases passed (24 ms)
#   ✔ Your runtime beats 6.25 % of kotlin submissions
#   ✔ Your memory usage beats 6.25 % of kotlin submissions (51.3 MB)
# Submitting: kotlin_solutions/868.binary-gap.kt
# - Downloading binary-gap
#   ✔ Accepted
#   ✔ 261/261 cases passed (9 ms)
#   ✔ Your runtime beats 7.6 % of kotlin submissions
#   ✔ Your memory usage beats 6.38 % of kotlin submissions (41.8 MB)
# Submitting: kotlin_solutions/869.reordered-power-of-2.kt
# - Downloading reordered-power-of-2
#   ✔ Accepted
#   ✔ 138/138 cases passed (46 ms)
#   ✔ Your runtime beats 6.45 % of kotlin submissions
#   ✔ Your memory usage beats 22.58 % of kotlin submissions (46.3 MB)
# Submitting: kotlin_solutions/870.advantage-shuffle.kt
# - Downloading advantage-shuffle
#   ✔ Accepted
#   ✔ 67/67 cases passed (177 ms)
#   ✔ Your runtime beats 36.36 % of kotlin submissions
#   ✔ Your memory usage beats 90.91 % of kotlin submissions (63.8 MB)
# Submitting: kotlin_solutions/871.minimum-number-of-refueling-stops.kt
# - Downloading minimum-number-of-refueling-stops
#   ✔ Accepted
#   ✔ 198/198 cases passed (50 ms)
#   ✔ Your runtime beats 7.14 % of kotlin submissions
#   ✔ Your memory usage beats 28.57 % of kotlin submissions (52.3 MB)
# Submitting: kotlin_solutions/872.leaf-similar-trees.kt
# - Downloading leaf-similar-trees
#   ✔ Accepted
#   ✔ 48/48 cases passed (20 ms)
#   ✔ Your runtime beats 7.45 % of kotlin submissions
#   ✔ Your memory usage beats 10.64 % of kotlin submissions (44.8 MB)
# Submitting: kotlin_solutions/873.length-of-longest-fibonacci-subsequence.kt
# - Downloading length-of-longest-fibonacci-subsequence
#   ✔ Accepted
#   ✔ 57/57 cases passed (213 ms)
#   ✔ Your runtime beats 40 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions/874.walking-robot-simulation.kt
# - Downloading walking-robot-simulation
#   ✔ Accepted
#   ✔ 51/51 cases passed (105 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (78.8 MB)
# Submitting: kotlin_solutions/875.koko-eating-bananas.kt
# - Downloading koko-eating-bananas
#   ✔ Accepted
#   ✔ 127/127 cases passed (28 ms)
#   ✔ Your runtime beats 14.71 % of kotlin submissions
#   ✔ Your memory usage beats 5.23 % of kotlin submissions (51.3 MB)
# Submitting: kotlin_solutions/876.middle-of-the-linked-list.kt
# - Downloading middle-of-the-linked-list
#   ✔ Accepted
#   ✔ 36/36 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 8.27 % of kotlin submissions (41.4 MB)
# Submitting: kotlin_solutions/877.stone-game.kt
# - Downloading stone-game
#   ✔ Accepted
#   ✔ 46/46 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 72.22 % of kotlin submissions (41.2 MB)
# Submitting: kotlin_solutions/878.nth-magical-number.kt
# - Downloading nth-magical-number
#   ✔ Accepted
#   ✔ 70/70 cases passed (10 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (40.7 MB)
# Submitting: kotlin_solutions/879.profitable-schemes.kt
# - Downloading profitable-schemes
#   ✔ Accepted
#   ✔ 45/45 cases passed (363 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (58.5 MB)
# Submitting: kotlin_solutions/880.decoded-string-at-index.kt
# - Downloading decoded-string-at-index
#   ✔ Accepted
#   ✔ 46/46 cases passed (9 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (41.8 MB)
# Submitting: kotlin_solutions/881.boats-to-save-people.kt
# - Downloading boats-to-save-people
#   ✔ Accepted
#   ✔ 78/78 cases passed (160 ms)
#   ✔ Your runtime beats 9.76 % of kotlin submissions
#   ✔ Your memory usage beats 48.78 % of kotlin submissions (61.5 MB)
# Submitting: kotlin_solutions/882.reachable-nodes-in-subdivided-graph.kt
# - Downloading reachable-nodes-in-subdivided-graph
#   ✔ Accepted
#   ✔ 50/50 cases passed (55 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (62.2 MB)
# Submitting: kotlin_solutions/883.projection-area-of-3-d-shapes.kt
# - Downloading projection-area-of-3d-shapes
#   ✔ Accepted
#   ✔ 90/90 cases passed (16 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 16.67 % of kotlin submissions (48.4 MB)
# Submitting: kotlin_solutions/884.uncommon-words-from-two-sentences.kt
# - Downloading uncommon-words-from-two-sentences
#   ✔ Accepted
#   ✔ 55/55 cases passed (17 ms)
#   ✔ Your runtime beats 10.53 % of kotlin submissions
#   ✔ Your memory usage beats 36.84 % of kotlin submissions (44 MB)
# Submitting: kotlin_solutions/885.spiral-matrix-iii.kt
# - Downloading spiral-matrix-iii
#   ✔ Accepted
#   ✔ 73/73 cases passed (41 ms)
#   ✔ Your runtime beats 6.25 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (52 MB)
# Submitting: kotlin_solutions/886.possible-bipartition.kt
# - Downloading possible-bipartition
#   ✔ Accepted
#   ✔ 74/74 cases passed (42 ms)
#   ✔ Your runtime beats 8.33 % of kotlin submissions
#   ✔ Your memory usage beats 58.33 % of kotlin submissions (72 MB)
# Submitting: kotlin_solutions/887.super-egg-drop.kt
# - Downloading super-egg-drop
#   ✔ Accepted
#   ✔ 121/121 cases passed (8 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (41.1 MB)
# Submitting: kotlin_solutions/888.fair-candy-swap.kt
# - Downloading fair-candy-swap
#   ✔ Accepted
#   ✔ 76/76 cases passed (30 ms)
#   ✔ Your runtime beats 42.86 % of kotlin submissions
#   ✔ Your memory usage beats 67.86 % of kotlin submissions (51.7 MB)
# Submitting: kotlin_solutions/889.construct-binary-tree-from-preorder-and-postorder-traversal.kt
# - Downloading construct-binary-tree-from-preorder-and-postorder-traversal
#   ✔ Accepted
#   ✔ 306/306 cases passed (27 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 16.67 % of kotlin submissions (46.8 MB)
# Submitting: kotlin_solutions/890.find-and-replace-pattern.kt
# - Downloading find-and-replace-pattern
#   ✔ Accepted
#   ✔ 50/50 cases passed (14 ms)
#   ✔ Your runtime beats 27.27 % of kotlin submissions
#   ✔ Your memory usage beats 9.09 % of kotlin submissions (46 MB)
# Submitting: kotlin_solutions/891.sum-of-subsequence-widths.kt
# - Downloading sum-of-subsequence-widths
#   ✔ Accepted
#   ✔ 68/68 cases passed (254 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (61.8 MB)
# Submitting: kotlin_solutions/892.surface-area-of-3-d-shapes.kt
# - Downloading surface-area-of-3d-shapes
#   ✔ Accepted
#   ✔ 91/91 cases passed (19 ms)
#   ✔ Your runtime beats 71.43 % of kotlin submissions
#   ✔ Your memory usage beats 71.43 % of kotlin submissions (48.7 MB)
# Submitting: kotlin_solutions/893.groups-of-special-equivalent-strings.kt
# - Downloading groups-of-special-equivalent-strings
#   ✔ Accepted
#   ✔ 36/36 cases passed (47 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions/894.all-possible-full-binary-trees.kt
# - Downloading all-possible-full-binary-trees
#   ✔ Accepted
#   ✔ 20/20 cases passed (28 ms)
#   ✔ Your runtime beats 6.25 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (53 MB)
# Submitting: kotlin_solutions/895.maximum-frequency-stack.kt
# - Downloading maximum-frequency-stack
#   ✔ Accepted
#   ✔ 38/38 cases passed (114 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 44.44 % of kotlin submissions (79.4 MB)
# Submitting: kotlin_solutions/896.monotonic-array.kt
# - Downloading monotonic-array
#   ✔ Accepted
#   ✔ 371/371 cases passed (43 ms)
#   ✔ Your runtime beats 8.06 % of kotlin submissions
#   ✔ Your memory usage beats 8.06 % of kotlin submissions (77.1 MB)
# Submitting: kotlin_solutions/897.increasing-order-search-tree.kt
# - Downloading increasing-order-search-tree
#   ✔ Accepted
#   ✔ 38/38 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 21.43 % of kotlin submissions (41.6 MB)
# Submitting: kotlin_solutions/898.bitwise-o-rs-of-subarrays.kt
# - Downloading bitwise-ors-of-subarrays
#   ✔ Accepted
#   ✔ 87/87 cases passed (367 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (89.6 MB)
# Current Time in IST: 2026-02-26 10:21:55
# Submitting: kotlin_solutions/668.kth-smallest-number-in-multiplication-table.kt
# - Downloading kth-smallest-number-in-multiplication-table
#   ✔ Accepted
#   ✔ 71/71 cases passed (30 ms)
#   ✔ Your runtime beats 6.25 % of kotlin submissions
#   ✔ Your memory usage beats 62.5 % of kotlin submissions (41.5 MB)
# Submitting: kotlin_solutions/669.trim-a-binary-search-tree.kt
# - Downloading trim-a-binary-search-tree
#   ✔ Accepted
#   ✔ 78/78 cases passed (12 ms)
#   ✔ Your runtime beats 23.53 % of kotlin submissions
#   ✔ Your memory usage beats 5.88 % of kotlin submissions (47.9 MB)
# Submitting: kotlin_solutions/670.maximum-swap.kt
# - Downloading maximum-swap
#   ✔ Accepted
#   ✔ 112/112 cases passed (22 ms)
#   ✔ Your runtime beats 18.92 % of kotlin submissions
#   ✔ Your memory usage beats 35.14 % of kotlin submissions (45 MB)
# Submitting: kotlin_solutions/671.second-minimum-node-in-a-binary-tree.kt
# - Downloading second-minimum-node-in-a-binary-tree
#   ✔ Accepted
#   ✔ 39/39 cases passed (33 ms)
#   ✔ Your runtime beats 5.56 % of kotlin submissions
#   ✔ Your memory usage beats 38.89 % of kotlin submissions (46.5 MB)
# Submitting: kotlin_solutions/672.bulb-switcher-ii.kt
# - Downloading bulb-switcher-ii
#   ✔ Accepted
#   ✔ 80/80 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (39.7 MB)
# Submitting: kotlin_solutions/673.number-of-longest-increasing-subsequence.kt
# - Downloading number-of-longest-increasing-subsequence
#   ✔ Accepted
#   ✔ 223/223 cases passed (121 ms)
#   ✔ Your runtime beats 28.57 % of kotlin submissions
#   ✔ Your memory usage beats 10.71 % of kotlin submissions (52.5 MB)
# Submitting: kotlin_solutions/674.longest-continuous-increasing-subsequence.kt
# - Downloading longest-continuous-increasing-subsequence
#   ✔ Accepted
#   ✔ 35/35 cases passed (37 ms)
#   ✔ Your runtime beats 5.77 % of kotlin submissions
#   ✔ Your memory usage beats 5.77 % of kotlin submissions (51.1 MB)
# Submitting: kotlin_solutions/675.cut-off-trees-for-golf-event.kt
# - Downloading cut-off-trees-for-golf-event
#   ✔ Accepted
#   ✔ 55/55 cases passed (1578 ms)
#   ✔ Your runtime beats 36.36 % of kotlin submissions
#   ✔ Your memory usage beats 27.27 % of kotlin submissions (63 MB)
# Submitting: kotlin_solutions/676.implement-magic-dictionary.kt
# - Downloading implement-magic-dictionary
#   ✔ Accepted
#   ✔ 83/83 cases passed (108 ms)
#   ✔ Your runtime beats 31.58 % of kotlin submissions
#   ✔ Your memory usage beats 63.16 % of kotlin submissions (52 MB)
# Submitting: kotlin_solutions/677.map-sum-pairs.kt
# - Downloading map-sum-pairs
#   ✔ Accepted
#   ✔ 35/35 cases passed (27 ms)
#   ✔ Your runtime beats 13.64 % of kotlin submissions
#   ✔ Your memory usage beats 54.55 % of kotlin submissions (45.7 MB)
# Submitting: kotlin_solutions/678.valid-parenthesis-string.kt
# - Downloading valid-parenthesis-string
#   ✔ Accepted
#   ✔ 84/84 cases passed (2 ms)
#   ✔ Your runtime beats 40.85 % of kotlin submissions
# ...
# Submitting: kotlin_solutions/37.sudoku-solver.kt
# - Downloading sudoku-solver
#   ✔ Accepted
#   ✔ 8/8 cases passed (774 ms)
#   ✔ Your runtime beats 15.71 % of kotlin submissions
#   ✔ Your memory usage beats 10 % of kotlin submissions (54.7 MB)
# Submitting: kotlin_solutions/38.count-and-say.kt
# - Downloading count-and-say
#   ✔ Accepted
#   ✔ 30/30 cases passed (59 ms)
#   ✔ Your runtime beats 7.38 % of kotlin submissions
#   ✔ Your memory usage beats 6.56 % of kotlin submissions (48.6 MB)
# Submitting: kotlin_solutions/39.combination-sum.kt
# - Downloading combination-sum
#   ✔ Accepted
#   ✔ 160/160 cases passed (25 ms)
#   ✔ Your runtime beats 14.78 % of kotlin submissions
#   ✔ Your memory usage beats 8.48 % of kotlin submissions (53.5 MB)
# Submitting: kotlin_solutions/40.combination-sum-ii.kt
# - Downloading combination-sum-ii
#   ✔ Accepted
#   ✔ 176/176 cases passed (109 ms)
#   ✔ Your runtime beats 8.99 % of kotlin submissions
#   ✔ Your memory usage beats 6.35 % of kotlin submissions (58.9 MB)
# Submitting: kotlin_solutions/41.first-missing-positive.kt
# - Downloading first-missing-positive
#   ✔ Accepted
#   ✔ 179/179 cases passed (2923 ms)
#   ✔ Your runtime beats 6.49 % of kotlin submissions
#   ✔ Your memory usage beats 11.35 % of kotlin submissions (71.2 MB)
# Submitting: kotlin_solutions/42.trapping-rain-water.kt
# - Downloading trapping-rain-water
#   ✔ Accepted
#   ✔ 324/324 cases passed (36 ms)
#   ✔ Your runtime beats 8.79 % of kotlin submissions
#   ✔ Your memory usage beats 9.42 % of kotlin submissions (56.4 MB)
# Submitting: kotlin_solutions/43.multiply-strings.kt
# - Downloading multiply-strings
#   ✔ Accepted
#   ✔ 311/311 cases passed (11 ms)
#   ✔ Your runtime beats 66.67 % of kotlin submissions
#   ✔ Your memory usage beats 82.35 % of kotlin submissions (43 MB)
# Submitting: kotlin_solutions/44.wildcard-matching.kt
# - Downloading wildcard-matching
#   ✔ Accepted
#   ✔ 1812/1812 cases passed (66 ms)
#   ✔ Your runtime beats 29.69 % of kotlin submissions
#   ✔ Your memory usage beats 28.13 % of kotlin submissions (50.8 MB)
# Submitting: kotlin_solutions/45.jump-game-ii.kt
# - Downloading jump-game-ii
#   ✔ Accepted
#   ✔ 110/110 cases passed (31 ms)
#   ✔ Your runtime beats 33.22 % of kotlin submissions
#   ✔ Your memory usage beats 34.61 % of kotlin submissions (49.8 MB)
# Submitting: kotlin_solutions/46.permutations.kt
# - Downloading permutations
#   ✔ Accepted
#   ✔ 26/26 cases passed (25 ms)
#   ✔ Your runtime beats 7.98 % of kotlin submissions
#   ✔ Your memory usage beats 54.69 % of kotlin submissions (47.6 MB)
# Submitting: kotlin_solutions/47.permutations-ii.kt
# - Downloading permutations-ii
#   ✔ Accepted
#   ✔ 33/33 cases passed (131 ms)
#   ✔ Your runtime beats 9.36 % of kotlin submissions
#   ✔ Your memory usage beats 16.96 % of kotlin submissions (53.7 MB)
# Submitting: kotlin_solutions/48.rotate-image.kt
# - Downloading rotate-image
#   ✔ Accepted
#   ✔ 21/21 cases passed (22 ms)
#   ✔ Your runtime beats 6.84 % of kotlin submissions
#   ✔ Your memory usage beats 6.84 % of kotlin submissions (46.3 MB)
# Submitting: kotlin_solutions/49.group-anagrams.kt
# - Downloading group-anagrams
#   ✔ Accepted
#   ✔ 128/128 cases passed (52 ms)
#   ✔ Your runtime beats 40.21 % of kotlin submissions
#   ✔ Your memory usage beats 35.95 % of kotlin submissions (54.8 MB)
# Submitting: kotlin_solutions/50.pow-x-n.kt
# - Downloading powx-n
#   ✔ Accepted
#   ✔ 307/307 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 17.31 % of kotlin submissions (42.6 MB)
# Submitting: kotlin_solutions/51.n-queens.kt
# - Downloading n-queens
#   ✔ Accepted
#   ✔ 9/9 cases passed (66 ms)
#   ✔ Your runtime beats 5.71 % of kotlin submissions
#   ✔ Your memory usage beats 5.71 % of kotlin submissions (53.6 MB)
# Submitting: kotlin_solutions/52.n-queens-ii.kt
# - Downloading n-queens-ii
#   ✔ Accepted
#   ✔ 9/9 cases passed (15 ms)
#   ✔ Your runtime beats 35.71 % of kotlin submissions
#   ✔ Your memory usage beats 20 % of kotlin submissions (46.2 MB)
# Submitting: kotlin_solutions/53.maximum-subarray.kt
# - Downloading maximum-subarray
#   ✔ Accepted
#   ✔ 210/210 cases passed (57 ms)
#   ✔ Your runtime beats 5 % of kotlin submissions
#   ✔ Your memory usage beats 5.16 % of kotlin submissions (75 MB)
# Submitting: kotlin_solutions/54.spiral-matrix.kt
# - Downloading spiral-matrix
#   ✔ Accepted
#   ✔ 26/26 cases passed (5 ms)
#   ✔ Your runtime beats 28.08 % of kotlin submissions
#   ✔ Your memory usage beats 23.97 % of kotlin submissions (41.8 MB)
# Submitting: kotlin_solutions/55.jump-game.kt
# - Downloading jump-game
#   ✔ Accepted
#   ✔ 178/178 cases passed (57 ms)
#   ✔ Your runtime beats 20.72 % of kotlin submissions
#   ✔ Your memory usage beats 15.42 % of kotlin submissions (52.6 MB)
# Submitting: kotlin_solutions/56.merge-intervals.kt
# - Downloading merge-intervals
#   ✔ Accepted
#   ✔ 172/172 cases passed (31 ms)
#   ✔ Your runtime beats 19.51 % of kotlin submissions
#   ✔ Your memory usage beats 62.96 % of kotlin submissions (54.5 MB)
# Submitting: kotlin_solutions/57.insert-interval.kt
# - Downloading insert-interval
#   ✔ Accepted
#   ✔ 158/158 cases passed (24 ms)
#   ✔ Your runtime beats 8.43 % of kotlin submissions
#   ✔ Your memory usage beats 15.96 % of kotlin submissions (50.3 MB)
# Submitting: kotlin_solutions/58.length-of-last-word.kt
# - Downloading length-of-last-word
#   ✔ Accepted
#   ✔ 60/60 cases passed (12 ms)
#   ✔ Your runtime beats 30.69 % of kotlin submissions
#   ✔ Your memory usage beats 6.95 % of kotlin submissions (44 MB)
# Submitting: kotlin_solutions/59.spiral-matrix-ii.kt
# - Downloading spiral-matrix-ii
#   ✔ Accepted
#   ✔ 20/20 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 11.11 % of kotlin submissions (41.5 MB)
# Submitting: kotlin_solutions/60.permutation-sequence.kt
# - Downloading permutation-sequence
#   ✔ Accepted
#   ✔ 200/200 cases passed (15 ms)
#   ✔ Your runtime beats 61.11 % of kotlin submissions
#   ✔ Your memory usage beats 61.11 % of kotlin submissions (42.6 MB)
# Submitting: kotlin_solutions/61.rotate-list.kt
# - Downloading rotate-list
#   ✔ Accepted
#   ✔ 232/232 cases passed (13 ms)
#   ✔ Your runtime beats 8.61 % of kotlin submissions
#   ✔ Your memory usage beats 5.3 % of kotlin submissions (46.6 MB)
# Submitting: kotlin_solutions/62.unique-paths.kt
# - Downloading unique-paths
#   ✔ Accepted
#   ✔ 64/64 cases passed (6 ms)
#   ✔ Your runtime beats 9.63 % of kotlin submissions
#   ✔ Your memory usage beats 18.32 % of kotlin submissions (40.7 MB)
# Submitting: kotlin_solutions/63.unique-paths-ii.kt
# - Downloading unique-paths-ii
#   ✔ Accepted
#   ✔ 42/42 cases passed (6 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
#   ✔ Your memory usage beats 33.79 % of kotlin submissions (42.6 MB)
# Submitting: kotlin_solutions/64.minimum-path-sum.kt
# - Downloading minimum-path-sum
#   ✔ Accepted
#   ✔ 66/66 cases passed (9 ms)
#   ✔ Your runtime beats 27.06 % of kotlin submissions
#   ✔ Your memory usage beats 45.88 % of kotlin submissions (51.6 MB)
# Submitting: kotlin_solutions/65.valid-number.kt
# - Downloading valid-number
#   ✔ Accepted
#   ✔ 1499/1499 cases passed (32 ms)
#   ✔ Your runtime beats 19.3 % of kotlin submissions
#   ✔ Your memory usage beats 12.28 % of kotlin submissions (49.3 MB)
# Submitting: kotlin_solutions/66.plus-one.kt
# - Downloading plus-one
#   ✔ Accepted
#   ✔ 114/114 cases passed (14 ms)
#   ✔ Your runtime beats 13.85 % of kotlin submissions
#   ✔ Your memory usage beats 5.02 % of kotlin submissions (46.3 MB)
# Submitting: kotlin_solutions/67.add-binary.kt
# - Downloading add-binary
#   ✔ Accepted
#   ✔ 296/296 cases passed (8 ms)
#   ✔ Your runtime beats 52.14 % of kotlin submissions
#   ✔ Your memory usage beats 57.86 % of kotlin submissions (42.9 MB)
# Submitting: kotlin_solutions/68.text-justification.kt
# - Downloading text-justification
#   ✔ Accepted
#   ✔ 29/29 cases passed (15 ms)
#   ✔ Your runtime beats 27.78 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (44 MB)
# Submitting: kotlin_solutions/69.sqrt-x.kt
# - Downloading sqrtx
#   ✔ Accepted
#   ✔ 1019/1019 cases passed (1 ms)
#   ✔ Your runtime beats 93.87 % of kotlin submissions
#   ✔ Your memory usage beats 32.59 % of kotlin submissions (41.2 MB)
# Submitting: kotlin_solutions/70.climbing-stairs.kt
# - Downloading climbing-stairs
#   ✔ Accepted
#   ✔ 45/45 cases passed (4 ms)
#   ✔ Your runtime beats 8.74 % of kotlin submissions
#   ✔ Your memory usage beats 8.6 % of kotlin submissions (40.8 MB)
# Submitting: kotlin_solutions/71.simplify-path.kt
# - Downloading simplify-path
#   ✔ Accepted
#   ✔ 264/264 cases passed (21 ms)
#   ✔ Your runtime beats 66.5 % of kotlin submissions
#   ✔ Your memory usage beats 64.04 % of kotlin submissions (46.5 MB)
# Submitting: kotlin_solutions/72.edit-distance.kt
# - Downloading edit-distance
#   ✔ Accepted
#   ✔ 1149/1149 cases passed (5 ms)
#   ✔ Your runtime beats 87.88 % of kotlin submissions
#   ✔ Your memory usage beats 29.09 % of kotlin submissions (47.5 MB)
# Submitting: kotlin_solutions/73.set-matrix-zeroes.kt
# - Downloading set-matrix-zeroes
#   ✔ Accepted
#   ✔ 202/202 cases passed (16 ms)
#   ✔ Your runtime beats 7.04 % of kotlin submissions
#   ✔ Your memory usage beats 58.22 % of kotlin submissions (51.6 MB)
# Submitting: kotlin_solutions/74.search-a-2-d-matrix.kt
# - Downloading search-a-2d-matrix
#   ✔ Accepted
#   ✔ 133/133 cases passed (10 ms)
#   ✔ Your runtime beats 19.06 % of kotlin submissions
#   ✔ Your memory usage beats 18.4 % of kotlin submissions (45.7 MB)
# Submitting: kotlin_solutions/75.sort-colors.kt
# - Downloading sort-colors
#   ✔ Accepted
#   ✔ 89/89 cases passed (6 ms)
#   ✔ Your runtime beats 18.21 % of kotlin submissions
#   ✔ Your memory usage beats 16.89 % of kotlin submissions (42.7 MB)
# Submitting: kotlin_solutions/76.minimum-window-substring.kt
# - Downloading minimum-window-substring
#   ✔ Accepted
#   ✔ 268/268 cases passed (233 ms)
#   ✔ Your runtime beats 6.55 % of kotlin submissions
#   ✔ Your memory usage beats 19.66 % of kotlin submissions (53.7 MB)
# Submitting: kotlin_solutions/77.combinations.kt
# - Downloading combinations
#   ✔ Accepted
#   ✔ 27/27 cases passed (137 ms)
#   ✔ Your runtime beats 5.85 % of kotlin submissions
#   ✔ Your memory usage beats 5.37 % of kotlin submissions (141.2 MB)
# Submitting: kotlin_solutions/78.subsets.kt
# - Downloading subsets
#   ✔ Accepted
#   ✔ 10/10 cases passed (8 ms)
#   ✔ Your runtime beats 45.43 % of kotlin submissions
#   ✔ Your memory usage beats 35.73 % of kotlin submissions (44.1 MB)
# Submitting: kotlin_solutions/79.word-search.kt
# - Downloading word-search
#   ✔ Accepted
#   ✔ 88/88 cases passed (1038 ms)
#   ✔ Your runtime beats 7.2 % of kotlin submissions
#   ✔ Your memory usage beats 26.13 % of kotlin submissions (50.7 MB)
# Submitting: kotlin_solutions/80.remove-duplicates-from-sorted-array-ii.kt
# - Downloading remove-duplicates-from-sorted-array-ii
#   ✔ Accepted
#   ✔ 170/170 cases passed (185 ms)
#   ✔ Your runtime beats 34.91 % of kotlin submissions
#   ✔ Your memory usage beats 22.31 % of kotlin submissions (49.7 MB)
# Submitting: kotlin_solutions/81.search-in-rotated-sorted-array-ii.kt
# - Downloading search-in-rotated-sorted-array-ii
#   ✔ Accepted
#   ✔ 282/282 cases passed (1 ms)
#   ✔ Your runtime beats 33.63 % of kotlin submissions
#   ✔ Your memory usage beats 42.48 % of kotlin submissions (44.5 MB)
# Submitting: kotlin_solutions/82.remove-duplicates-from-sorted-list-ii.kt
# - Downloading remove-duplicates-from-sorted-list-ii
#   ✔ Accepted
#   ✔ 166/166 cases passed (9 ms)
#   ✔ Your runtime beats 8.53 % of kotlin submissions
#   ✔ Your memory usage beats 5.43 % of kotlin submissions (47.4 MB)
# Submitting: kotlin_solutions/83.remove-duplicates-from-sorted-list.kt
# - Downloading remove-duplicates-from-sorted-list
#   ✔ Accepted
#   ✔ 168/168 cases passed (8 ms)
#   ✔ Your runtime beats 5.28 % of kotlin submissions
#   ✔ Your memory usage beats 10.56 % of kotlin submissions (45.6 MB)
# Submitting: kotlin_solutions/84.largest-rectangle-in-histogram.kt
# - Downloading largest-rectangle-in-histogram
#   ✔ Accepted
#   ✔ 99/99 cases passed (67 ms)
#   ✔ Your runtime beats 34.52 % of kotlin submissions
#   ✔ Your memory usage beats 56.58 % of kotlin submissions (63.7 MB)
# Submitting: kotlin_solutions/85.maximal-rectangle.kt
# - Downloading maximal-rectangle
#   ✔ Accepted
#   ✔ 76/76 cases passed (84 ms)
#   ✔ Your runtime beats 5.47 % of kotlin submissions
#   ✔ Your memory usage beats 5.11 % of kotlin submissions (62.1 MB)
# Submitting: kotlin_solutions/86.partition-list.kt
# - Downloading partition-list
#   ✔ Accepted
#   ✔ 168/168 cases passed (7 ms)
#   ✔ Your runtime beats 15.52 % of kotlin submissions
#   ✔ Your memory usage beats 5.17 % of kotlin submissions (43.8 MB)
# Submitting: kotlin_solutions/87.scramble-string.kt
# - Downloading scramble-string
#   ✔ Accepted
#   ✔ 290/290 cases passed (50 ms)
#   ✔ Your runtime beats 40.74 % of kotlin submissions
#   ✔ Your memory usage beats 44.44 % of kotlin submissions (52.2 MB)
# Submitting: kotlin_solutions/88.merge-sorted-array.kt
# - Downloading merge-sorted-array
#   ✔ Accepted
#   ✔ 59/59 cases passed (9 ms)
#   ✔ Your runtime beats 10.48 % of kotlin submissions
#   ✔ Your memory usage beats 17.28 % of kotlin submissions (42.9 MB)
# Submitting: kotlin_solutions/89.gray-code.kt
# - Downloading gray-code
#   ✔ Accepted
#   ✔ 16/16 cases passed (15 ms)
#   ✔ Your runtime beats 46.38 % of kotlin submissions
#   ✔ Your memory usage beats 76.81 % of kotlin submissions (52.8 MB)
# Submitting: kotlin_solutions/90.subsets-ii.kt
# - Downloading subsets-ii
#   ✔ Accepted
#   ✔ 20/20 cases passed (20 ms)
#   ✔ Your runtime beats 13.82 % of kotlin submissions
#   ✔ Your memory usage beats 37.5 % of kotlin submissions (47.6 MB)
# Submitting: kotlin_solutions/91.decode-ways.kt
# - Downloading decode-ways
#   ✔ Accepted
#   ✔ 269/269 cases passed (12 ms)
#   ✔ Your runtime beats 16.8 % of kotlin submissions
#   ✔ Your memory usage beats 18.4 % of kotlin submissions (43.3 MB)
# Submitting: kotlin_solutions/92.reverse-linked-list-ii.kt
# - Downloading reverse-linked-list-ii
#   ✔ Accepted
#   ✔ 44/44 cases passed (4 ms)
#   ✔ Your runtime beats 9.57 % of kotlin submissions
#   ✔ Your memory usage beats 6.38 % of kotlin submissions (41.6 MB)
# Submitting: kotlin_solutions/93.restore-ip-addresses.kt
# - Downloading restore-ip-addresses
#   ✔ Accepted
#   ✔ 146/146 cases passed (28 ms)
#   ✔ Your runtime beats 13.92 % of kotlin submissions
#   ✔ Your memory usage beats 18.99 % of kotlin submissions (47.8 MB)
# Submitting: kotlin_solutions/94.binary-tree-inorder-traversal.kt
# - Downloading binary-tree-inorder-traversal
#   ✔ Accepted
#   ✔ 71/71 cases passed (11 ms)
#   ✔ Your runtime beats 5.24 % of kotlin submissions
#   ✔ Your memory usage beats 28.27 % of kotlin submissions (42.1 MB)
# Submitting: kotlin_solutions/95.unique-binary-search-trees-ii.kt
# - Downloading unique-binary-search-trees-ii
#   ✔ Accepted
#   ✔ 8/8 cases passed (13 ms)
#   ✔ Your runtime beats 15.63 % of kotlin submissions
#   ✔ Your memory usage beats 34.38 % of kotlin submissions (46.9 MB)
# Submitting: kotlin_solutions/96.unique-binary-search-trees.kt
# - Downloading unique-binary-search-trees
#   ✔ Accepted
#   ✔ 19/19 cases passed (3124 ms)
#   ✔ Your runtime beats 6.15 % of kotlin submissions
#   ✔ Your memory usage beats 7.69 % of kotlin submissions (44.9 MB)
# Submitting: kotlin_solutions/97.interleaving-string.kt
# - Downloading interleaving-string
#   ✔ Accepted
#   ✔ 107/107 cases passed (1615 ms)
#   ✔ Your runtime beats 5.62 % of kotlin submissions
#   ✔ Your memory usage beats 15.73 % of kotlin submissions (43.9 MB)
# Submitting: kotlin_solutions/98.validate-binary-search-tree.kt
# - Downloading validate-binary-search-tree
#   ✔ Accepted
#   ✔ 86/86 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 17.1 % of kotlin submissions (46.3 MB)
# Submitting: kotlin_solutions/99.recover-binary-search-tree.kt
# - Downloading recover-binary-search-tree
#   ✔ Accepted
#   ✔ 1919/1919 cases passed (5 ms)
#   ✔ Your runtime beats 26.67 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (47.1 MB)
# Submitting: kotlin_solutions/100.same-tree.kt
# - Downloading same-tree
#   ✔ Accepted
#   ✔ 67/67 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 22.32 % of kotlin submissions (41.2 MB)
# Current Time in IST: 2026-02-26 12:19:44

# %%
# !rm -rf -r leetcode_programming/
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git
# !leetcode user

# %%
# %%bash

# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1

# # 2. Enter the directory
# cd leetcode_programming

# # 3. Define the specific files you want to run here
# # You can add more files by separating them with a space or a newline
# files=(
#     "kotlin_solutions/701.insert-into-a-binary-search-tree.kt"
#     "kotlin_solutions/818.race-car.kt"
# )

# # 4. Run the loop over your specific list
# for f in "${files[@]}"; do
#     echo "Submitting: $f"

#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"

#     sleep 7
# done

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-02-26 12:30:31
