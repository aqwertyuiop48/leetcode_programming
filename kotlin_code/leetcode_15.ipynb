# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME')
    user_cookie = userdata.get('LEETCODE_TOKEN')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME'] = user_name
    os.environ['LEETCODE_TOKEN'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME" "$LEETCODE_TOKEN" | leetcode user -c

# %%
# %%bash
#
# # top 600-700 answers (7th batch)
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v kotlin_solutions_1/*.kt | sed -n '601,700p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 7
# done
# Out:
# Submitting: kotlin_solutions_1/1792.maximum-average-pass-ratio.kt
# - Downloading maximum-average-pass-ratio
#   ✔ Accepted
#   ✔ 88/88 cases passed (181 ms)
#   ✔ Your runtime beats 83.33 % of kotlin submissions
#   ✔ Your memory usage beats 83.33 % of kotlin submissions (99.3 MB)
# Submitting: kotlin_solutions_1/1793.maximum-score-of-a-good-subarray.kt
# - Downloading maximum-score-of-a-good-subarray
#   ✔ Accepted
#   ✔ 73/73 cases passed (19 ms)
#   ✔ Your runtime beats 60 % of kotlin submissions
#   ✔ Your memory usage beats 80 % of kotlin submissions (61.9 MB)
# Submitting: kotlin_solutions_1/1796.second-largest-digit-in-a-string.kt
# - Downloading second-largest-digit-in-a-string
#   ✔ Accepted
#   ✔ 301/301 cases passed (26 ms)
#   ✔ Your runtime beats 5.88 % of kotlin submissions
#   ✔ Your memory usage beats 5.88 % of kotlin submissions (47.1 MB)
# Submitting: kotlin_solutions_1/1797.design-authentication-manager.kt
# - Downloading design-authentication-manager
#   ✔ Accepted
#   ✔ 91/91 cases passed (92 ms)
#   ✔ Your runtime beats 27.27 % of kotlin submissions
#   ✔ Your memory usage beats 9.09 % of kotlin submissions (67.8 MB)
# Submitting: kotlin_solutions_1/1798.maximum-number-of-consecutive-values-you-can-make.kt
# - Downloading maximum-number-of-consecutive-values-you-can-make
#   ✔ Accepted
#   ✔ 72/72 cases passed (177 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1799.maximize-score-after-n-operations.kt
# - Downloading maximize-score-after-n-operations
#   ✔ Accepted
#   ✔ 77/77 cases passed (187 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1800.maximum-ascending-subarray-sum.kt
# - Downloading maximum-ascending-subarray-sum
#   ✔ Accepted
#   ✔ 104/104 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 23.08 % of kotlin submissions (41.4 MB)
# Submitting: kotlin_solutions_1/1801.number-of-orders-in-the-backlog.kt
# - Downloading number-of-orders-in-the-backlog
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 257: ERROR: Argument type mismatch: actual type is 'T', but 'K' was expected.
#   ✘ Error: Line 2: Char 257: ERROR: Argument type mismatch: actual type is 'T', but 'K' was expected.
# Line 2: Char 267: ERROR: Unresolved reference 'generateSequence'.
# Line 2: Char 381: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 398: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 404: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 404: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun <T, R> T.let(block: (T) -> R): R
#     [R|Contract description]
#      <
#         CallsInPlace(block, EXACTLY_ONCE)
#     >
# Line 2: Char 410: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 444: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 446: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 446: ERROR: Not enough information to infer type argument for 'V'.
# Line 2: Char 463: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 469: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 469: ERROR: Not enough information to infer type argument for 'V'.
# Line 2: Char 474: ERROR: 'operator' modifier is required on 'FirNamedFunctionSymbol kotlin/compareTo' in 'compareTo'.
# Line 2: Char 499: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 499: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun <T> T.also(block: (T) -> Unit): T
#     [R|Contract description]
#      <
#         CallsInPlace(block, EXACTLY_ONCE)
#     >
# Line 2: Char 504: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 504: WARNING: Parameter 'it: <ERROR TYPE REF: Cannot infer argument for type parameter T>' is never used, could be renamed to '_'.
# Line 2: Char 561: ERROR: Argument type mismatch: actual type is 'T', but 'K' was expected.
# Line 2: Char 571: ERROR: Unresolved reference 'generateSequence'.
# Line 2: Char 682: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 699: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 705: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 705: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun <T, R> T.let(block: (T) -> R): R
#     [R|Contract description]
#      <
#         CallsInPlace(block, EXACTLY_ONCE)
#     >
# Line 2: Char 711: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 745: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 747: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 747: ERROR: Not enough information to infer type argument for 'V'.
# Line 2: Char 764: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 770: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 770: ERROR: Not enough information to infer type argument for 'V'.
# Line 2: Char 775: ERROR: 'operator' modifier is required on 'FirNamedFunctionSymbol kotlin/compareTo' in 'compareTo'.
# Line 2: Char 799: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 799: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun <T> T.also(block: (T) -> Unit): T
#     [R|Contract description]
#      <
#         CallsInPlace(block, EXACTLY_ONCE)
#     >
# Line 2: Char 804: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 804: WARNING: Parameter 'it: <ERROR TYPE REF: Cannot infer argument for type parameter T>' is never used, could be renamed to '_'.
# Line 2: Char 863: WARNING: Parameter 'it: IntArray' is never used, could be renamed to '_'.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1803.count-pairs-with-xor-in-a-range.kt
# - Downloading count-pairs-with-xor-in-a-range
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 154: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 2: Char 154: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 528: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 31: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1805.number-of-different-integers-in-a-string.kt
# - Downloading number-of-different-integers-in-a-string
#   ✔ Accepted
#   ✔ 86/86 cases passed (25 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/1806.minimum-number-of-operations-to-reinitialize-a-permutation.kt
# - Downloading minimum-number-of-operations-to-reinitialize-a-permutation
#   ✔ Accepted
#   ✔ 66/66 cases passed (8 ms)
#   ✔ Your runtime beats 75 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (40.3 MB)
# Submitting: kotlin_solutions_1/1807.evaluate-the-bracket-pairs-of-a-string.kt
# - Downloading evaluate-the-bracket-pairs-of-a-string
#   ✔ Accepted
#   ✔ 105/105 cases passed (125 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (112.6 MB)
# Submitting: kotlin_solutions_1/1808.maximize-number-of-nice-divisors.kt
# - Downloading maximize-number-of-nice-divisors
#   ✔ Accepted
#   ✔ 213/213 cases passed (110 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1812.determine-color-of-a-chessboard-square.kt
# - Downloading determine-color-of-a-chessboard-square
#   ✔ Accepted
#   ✔ 64/64 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 45.45 % of kotlin submissions (40.4 MB)
# Submitting: kotlin_solutions_1/1813.sentence-similarity-iii.kt
# - Downloading sentence-similarity-iii
#   ✔ Accepted
#   ✔ 144/144 cases passed (18 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (43.6 MB)
# Submitting: kotlin_solutions_1/1814.count-nice-pairs-in-an-array.kt
# - Downloading count-nice-pairs-in-an-array
#   ✔ Accepted
#   ✔ 84/84 cases passed (97 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 83.33 % of kotlin submissions (66.3 MB)
# Submitting: kotlin_solutions_1/1815.maximum-number-of-groups-getting-fresh-donuts.kt
# - Downloading maximum-number-of-groups-getting-fresh-donuts
#   ✔ Accepted
#   ✔ 74/74 cases passed (490 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1816.truncate-sentence.kt
# - Downloading truncate-sentence
#   ✔ Accepted
#   ✔ 72/72 cases passed (14 ms)
#   ✔ Your runtime beats 23.08 % of kotlin submissions
#   ✔ Your memory usage beats 53.85 % of kotlin submissions (43.2 MB)
# Submitting: kotlin_solutions_1/1817.finding-the-users-active-minutes.kt
# - Downloading finding-the-users-active-minutes
#   ✔ Accepted
#   ✔ 38/38 cases passed (53 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/1818.minimum-absolute-sum-difference.kt
# - Downloading minimum-absolute-sum-difference
#   ✔ Accepted
#   ✔ 52/52 cases passed (268 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1819.number-of-different-subsequences-gcds.kt
# - Downloading number-of-different-subsequences-gcds
#   ✔ Accepted
#   ✔ 39/39 cases passed (458 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1822.sign-of-the-product-of-an-array.kt
# - Downloading sign-of-the-product-of-an-array
#   ✔ Accepted
#   ✔ 76/76 cases passed (1 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (46.5 MB)
# Submitting: kotlin_solutions_1/1823.find-the-winner-of-the-circular-game.kt
# - Downloading find-the-winner-of-the-circular-game
#   ✔ Accepted
#   ✔ 95/95 cases passed (4 ms)
#   ✔ Your runtime beats 60 % of kotlin submissions
#   ✔ Your memory usage beats 70 % of kotlin submissions (40.4 MB)
# Submitting: kotlin_solutions_1/1824.minimum-sideway-jumps.kt
# - Downloading minimum-sideway-jumps
#   ✔ Accepted
#   ✔ 48/48 cases passed (59 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (131.5 MB)
# Submitting: kotlin_solutions_1/1825.finding-mk-average.kt
# - Downloading finding-mk-average
#   ✔ Accepted
#   ✔ 18/18 cases passed (254 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1827.minimum-operations-to-make-the-array-increasing.kt
# - Downloading minimum-operations-to-make-the-array-increasing
#   ✔ Accepted
#   ✔ 94/94 cases passed (204 ms)
#   ✔ Your runtime beats 7.14 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (48.1 MB)
# Submitting: kotlin_solutions_1/1828.queries-on-number-of-points-inside-a-circle.kt
# - Downloading queries-on-number-of-points-inside-a-circle
# [ERROR] session expired, please login again [code=-1]
# Submitting: kotlin_solutions_1/1829.maximum-xor-for-each-query.kt
# - Downloading maximum-xor-for-each-query
#   ✔ Accepted
#   ✔ 86/86 cases passed (49 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1830.minimum-number-of-operations-to-make-string-sorted.kt
# - Downloading minimum-number-of-operations-to-make-string-sorted
#   ✔ Accepted
#   ✔ 73/73 cases passed (43 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/1832.check-if-the-sentence-is-pangram.kt
# - Downloading check-if-the-sentence-is-pangram
#   ✔ Accepted
#   ✔ 79/79 cases passed (20 ms)
#   ✔ Your runtime beats 5.88 % of kotlin submissions
#   ✔ Your memory usage beats 5.88 % of kotlin submissions (44.2 MB)
# Submitting: kotlin_solutions_1/1833.maximum-ice-cream-bars.kt
# - Downloading maximum-ice-cream-bars
#   ✔ Accepted
#   ✔ 65/65 cases passed (369 ms)
#   ✔ Your runtime beats 5.23 % of kotlin submissions
#   ✔ Your memory usage beats 37.79 % of kotlin submissions (63.5 MB)
# Submitting: kotlin_solutions_1/1835.find-xor-sum-of-all-pairs-bitwise-and.kt
# - Downloading find-xor-sum-of-all-pairs-bitwise-and
#   ✔ Accepted
#   ✔ 84/84 cases passed (3 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1837.sum-of-digits-in-base-k.kt
# - Downloading sum-of-digits-in-base-k
#   ✔ Accepted
#   ✔ 65/65 cases passed (1 ms)
#   ✔ Your runtime beats 12.5 % of kotlin submissions
#   ✔ Your memory usage beats 37.5 % of kotlin submissions (40.1 MB)
# Submitting: kotlin_solutions_1/1838.frequency-of-the-most-frequent-element.kt
# - Downloading frequency-of-the-most-frequent-element
#   ✔ Accepted
#   ✔ 73/73 cases passed (327 ms)
#   ✔ Your runtime beats 5.56 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (63.4 MB)
# Submitting: kotlin_solutions_1/1839.longest-substring-of-all-vowels-in-order.kt
# - Downloading longest-substring-of-all-vowels-in-order
#   ✔ Accepted
#   ✔ 121/121 cases passed (112 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1840.maximum-building-height.kt
# - Downloading maximum-building-height
#   ✔ Accepted
#   ✔ 51/51 cases passed (225 ms)
#   ✔ Your runtime beats 5.55 % of kotlin submissions
#   ✔ Your memory usage beats 5.55 % of kotlin submissions (127.4 MB)
# Submitting: kotlin_solutions_1/1844.replace-all-digits-with-characters.kt
# - Downloading replace-all-digits-with-characters
#   ✔ Accepted
#   ✔ 99/99 cases passed (17 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/1845.seat-reservation-manager.kt
# - Downloading seat-reservation-manager
#   ✔ Accepted
#   ✔ 69/69 cases passed (101 ms)
#   ✔ Your runtime beats 36.36 % of kotlin submissions
#   ✔ Your memory usage beats 45.45 % of kotlin submissions (115.2 MB)
# Submitting: kotlin_solutions_1/1846.maximum-element-after-decreasing-and-rearranging.kt
# - Downloading maximum-element-after-decreasing-and-rearranging
#   ✔ Accepted
#   ✔ 58/58 cases passed (36 ms)
#   ✔ Your runtime beats 9.06 % of kotlin submissions
#   ✔ Your memory usage beats 7.09 % of kotlin submissions (63.4 MB)
# Submitting: kotlin_solutions_1/1847.closest-room.kt
# - Downloading closest-room
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 42: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Error: Line 42: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1848.minimum-distance-to-the-target-element.kt
# - Downloading minimum-distance-to-the-target-element
#   ✔ Accepted
#   ✔ 72/72 cases passed (22 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1849.splitting-a-string-into-descending-consecutive-values.kt
# - Downloading splitting-a-string-into-descending-consecutive-values
#   ✔ Accepted
#   ✔ 203/203 cases passed (21 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1851.minimum-interval-to-include-each-query.kt
# - Downloading minimum-interval-to-include-each-query
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 6: Char 614: WARNING: Parameter 'it: IntArray' is never used, could be renamed to '_'.
#   ✘ Error: Line 6: Char 614: WARNING: Parameter 'it: IntArray' is never used, could be renamed to '_'.
# Line 42: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1854.maximum-population-year.kt
# - Downloading maximum-population-year
#   ✔ Accepted
#   ✔ 53/53 cases passed (7 ms)
#   ✔ Your runtime beats 35 % of kotlin submissions
#   ✔ Your memory usage beats 40 % of kotlin submissions (41.8 MB)
# Submitting: kotlin_solutions_1/1855.maximum-distance-between-a-pair-of-values.kt
# - Downloading maximum-distance-between-a-pair-of-values
#   ✔ Accepted
#   ✔ 531/531 cases passed (32 ms)
#   ✔ Your runtime beats 44.44 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (67.2 MB)
# Submitting: kotlin_solutions_1/1857.largest-color-value-in-a-directed-graph.kt
# - Downloading largest-color-value-in-a-directed-graph
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 6: Char 106: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 6: Char 106: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 13: Char 1: ERROR: Argument type mismatch: actual type is 'kotlin.Unit', but 'kotlin.Int' was expected.
# Line 33: Char 2: ERROR: Syntax error: Expecting '}'.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1859.sorting-the-sentence.kt
# - Downloading sorting-the-sentence
#   ✔ Accepted
#   ✔ 45/45 cases passed (123 ms)
#   ✔ Your runtime beats 6.67 % of kotlin submissions
#   ✔ Your memory usage beats 46.67 % of kotlin submissions (45.2 MB)
# Submitting: kotlin_solutions_1/1860.incremental-memory-leak.kt
# - Downloading incremental-memory-leak
#   ✔ Accepted
#   ✔ 82/82 cases passed (25 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (46.2 MB)
# Submitting: kotlin_solutions_1/1861.rotating-the-box.kt
# - Downloading rotating-the-box
#   ✔ Accepted
#   ✔ 87/87 cases passed (32 ms)
#   ✔ Your runtime beats 12.5 % of kotlin submissions
#   ✔ Your memory usage beats 62.5 % of kotlin submissions (99.8 MB)
# Submitting: kotlin_solutions_1/1862.sum-of-floored-pairs.kt
# - Downloading sum-of-floored-pairs
#   ✔ Accepted
#   ✔ 51/51 cases passed (84 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1863.sum-of-all-subset-xor-totals.kt
# - Downloading sum-of-all-subset-xor-totals
#   ✔ Accepted
#   ✔ 48/48 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 76.19 % of kotlin submissions (40.4 MB)
# Submitting: kotlin_solutions_1/1864.minimum-number-of-swaps-to-make-the-binary-string-alternating.kt
# - Downloading minimum-number-of-swaps-to-make-the-binary-string-alternating
#   ✔ Accepted
#   ✔ 124/124 cases passed (13 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1865.finding-pairs-with-a-certain-sum.kt
# - Downloading finding-pairs-with-a-certain-sum
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 1: Char 199: ERROR: Syntax error: Property getter or setter expected.
#   ✘ Error: Line 1: Char 199: ERROR: Syntax error: Property getter or setter expected.
# Line 52: Char 32: WARNING: 'static fun readFrom(p0: String!): JsonArray!' is deprecated. Deprecated in Java.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1866.number-of-ways-to-rearrange-sticks-with-k-sticks-visible.kt
# - Downloading number-of-ways-to-rearrange-sticks-with-k-sticks-visible
#   ✔ Accepted
#   ✔ 50/50 cases passed (33 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1869.longer-contiguous-segments-of-ones-than-zeros.kt
# - Downloading longer-contiguous-segments-of-ones-than-zeros
#   ✔ Accepted
#   ✔ 141/141 cases passed (13 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/1870.minimum-speed-to-arrive-on-time.kt
# - Downloading minimum-speed-to-arrive-on-time
#   ✔ Accepted
#   ✔ 67/67 cases passed (100 ms)
#   ✔ Your runtime beats 14.29 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (67.7 MB)
# Submitting: kotlin_solutions_1/1871.jump-game-vii.kt
# - Downloading jump-game-vii
#   ✔ Accepted
#   ✔ 128/128 cases passed (40 ms)
#   ✔ Your runtime beats 36.36 % of kotlin submissions
#   ✔ Your memory usage beats 54.55 % of kotlin submissions (49.3 MB)
# Submitting: kotlin_solutions_1/1872.stone-game-viii.kt
# - Downloading stone-game-viii
#   ✔ Accepted
#   ✔ 80/80 cases passed (438 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (64.7 MB)
# Submitting: kotlin_solutions_1/1876.substrings-of-size-three-with-distinct-characters.kt
# - Downloading substrings-of-size-three-with-distinct-characters
#   ✔ Accepted
#   ✔ 160/160 cases passed (4 ms)
#   ✔ Your runtime beats 48.48 % of kotlin submissions
#   ✔ Your memory usage beats 84.85 % of kotlin submissions (41 MB)
# Submitting: kotlin_solutions_1/1877.minimize-maximum-pair-sum-in-array.kt
# - Downloading minimize-maximum-pair-sum-in-array
#   ✔ Accepted
#   ✔ 37/37 cases passed (1315 ms)
#   ✔ Your runtime beats 8.33 % of kotlin submissions
#   ✔ Your memory usage beats 8.33 % of kotlin submissions (64.8 MB)
# Submitting: kotlin_solutions_1/1878.get-biggest-three-rhombus-sums-in-a-grid.kt
# - Downloading get-biggest-three-rhombus-sums-in-a-grid
#   ✔ Accepted
#   ✔ 119/119 cases passed (227 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 16.67 % of kotlin submissions (57.4 MB)
# Submitting: kotlin_solutions_1/1879.minimum-xor-sum-of-two-arrays.kt
# - Downloading minimum-xor-sum-of-two-arrays
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 387: ERROR: Syntax error: Expecting ')'.
#   ✘ Error: Line 2: Char 387: ERROR: Syntax error: Expecting ')'.
# Line 2: Char 388: ERROR: Syntax error: Expecting ')'.
# Line 2: Char 390: ERROR: Unresolved reference 'nums2'.
# Line 2: Char 395: ERROR: Unsupported [Collection literals outside of annotations].
# Line 2: Char 398: ERROR: Syntax error: Unexpected tokens (use ';' to separate expressions on the same line).
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1880.check-if-word-equals-summation-of-two-words.kt
# - Downloading check-if-word-equals-summation-of-two-words
#   ✔ Accepted
#   ✔ 100/100 cases passed (12 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1883.minimum-skips-to-arrive-at-meeting-on-time.kt
# - Downloading minimum-skips-to-arrive-at-meeting-on-time
#   ✔ Accepted
#   ✔ 61/61 cases passed (50 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1884.egg-drop-with-2-eggs-and-n-floors.kt
# - Downloading egg-drop-with-2-eggs-and-n-floors
#   ✔ Accepted
#   ✔ 139/139 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 40 % of kotlin submissions (40 MB)
# Submitting: kotlin_solutions_1/1886.determine-whether-matrix-can-be-obtained-by-rotation.kt
# - Downloading determine-whether-matrix-can-be-obtained-by-rotation
#   ✔ Accepted
#   ✔ 114/114 cases passed (13 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 9.09 % of kotlin submissions (45.8 MB)
# Submitting: kotlin_solutions_1/1887.reduction-operations-to-make-the-array-elements-equal.kt
# - Downloading reduction-operations-to-make-the-array-elements-equal
#   ✔ Accepted
#   ✔ 78/78 cases passed (218 ms)
#   ✔ Your runtime beats 12.5 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (63.3 MB)
# Submitting: kotlin_solutions_1/1888.minimum-number-of-flips-to-make-the-binary-string-alternating.kt
# - Downloading minimum-number-of-flips-to-make-the-binary-string-alternating
#   ✔ Accepted
#   ✔ 66/66 cases passed (50 ms)
#   ✔ Your runtime beats 6.67 % of kotlin submissions
#   ✔ Your memory usage beats 26.67 % of kotlin submissions (46.9 MB)
# Submitting: kotlin_solutions_1/1889.minimum-space-wasted-from-packaging.kt
# - Downloading minimum-space-wasted-from-packaging
#   ✔ Accepted
#   ✔ 42/42 cases passed (403 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1893.check-if-all-the-integers-in-a-range-are-covered.kt
# - Downloading check-if-all-the-integers-in-a-range-are-covered
#   ✔ Accepted
#   ✔ 106/106 cases passed (3 ms)
#   ✔ Your runtime beats 13.33 % of kotlin submissions
#   ✔ Your memory usage beats 20 % of kotlin submissions (42 MB)
# Submitting: kotlin_solutions_1/1894.find-the-student-that-will-replace-the-chalk.kt
# - Downloading find-the-student-that-will-replace-the-chalk
#   ✔ Accepted
#   ✔ 74/74 cases passed (34 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1895.largest-magic-square.kt
# - Downloading largest-magic-square
#   ✔ Accepted
#   ✔ 81/81 cases passed (90 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1896.minimum-cost-to-change-the-final-value-of-expression.kt
# - Downloading minimum-cost-to-change-the-final-value-of-expression
#   ✔ Accepted
#   ✔ 70/70 cases passed (51 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (48.7 MB)
# Submitting: kotlin_solutions_1/1897.redistribute-characters-to-make-all-strings-equal.kt
# - Downloading redistribute-characters-to-make-all-strings-equal
#   ✔ Accepted
#   ✔ 179/179 cases passed (31 ms)
#   ✔ Your runtime beats 25 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/1898.maximum-number-of-removable-characters.kt
# - Downloading maximum-number-of-removable-characters
#   ✔ Accepted
#   ✔ 67/67 cases passed (80 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (66.6 MB)
# Submitting: kotlin_solutions_1/1899.merge-triplets-to-form-target-triplet.kt
# - Downloading merge-triplets-to-form-target-triplet
#   ✔ Accepted
#   ✔ 63/63 cases passed (12 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
#   ✔ Your memory usage beats 90 % of kotlin submissions (120.6 MB)
# Submitting: kotlin_solutions_1/1900.the-earliest-and-latest-rounds-where-players-compete.kt
# - Downloading the-earliest-and-latest-rounds-where-players-compete
#   ✔ Accepted
#   ✔ 139/139 cases passed (12 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (43.4 MB)
# Submitting: kotlin_solutions_1/1901.find-a-peak-element-ii.kt
# - Downloading find-a-peak-element-ii
#   ✔ Accepted
#   ✔ 51/51 cases passed (19 ms)
#   ✔ Your runtime beats 9.68 % of kotlin submissions
#   ✔ Your memory usage beats 6.45 % of kotlin submissions (102.1 MB)
# Submitting: kotlin_solutions_1/1903.largest-odd-number-in-string.kt
# - Downloading largest-odd-number-in-string
#   ✔ Accepted
#   ✔ 196/196 cases passed (1 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 95.45 % of kotlin submissions (46.1 MB)
# Submitting: kotlin_solutions_1/1904.the-number-of-full-rounds-you-have-played.kt
# - Downloading the-number-of-full-rounds-you-have-played
#   ✔ Accepted
#   ✔ 104/104 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (40.9 MB)
# Submitting: kotlin_solutions_1/1905.count-sub-islands.kt
# - Downloading count-sub-islands
#   ✔ Accepted
#   ✔ 57/57 cases passed (110 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1906.minimum-absolute-difference-queries.kt
# - Downloading minimum-absolute-difference-queries
#   ✔ Accepted
#   ✔ 60/60 cases passed (154 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1909.remove-one-element-to-make-the-array-strictly-increasing.kt
# - Downloading remove-one-element-to-make-the-array-strictly-increasing
#   ✔ Accepted
#   ✔ 109/109 cases passed (128 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1910.remove-all-occurrences-of-a-substring.kt
# - Downloading remove-all-occurrences-of-a-substring
#   ✔ Accepted
#   ✔ 82/82 cases passed (16 ms)
#   ✔ Your runtime beats 10 % of kotlin submissions
#   ✔ Your memory usage beats 40 % of kotlin submissions (45.6 MB)
# Submitting: kotlin_solutions_1/1911.maximum-alternating-subsequence-sum.kt
# - Downloading maximum-alternating-subsequence-sum
#   ✔ Accepted
#   ✔ 65/65 cases passed (433 ms)
#   ✔ Your runtime beats 40 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (61 MB)
# Submitting: kotlin_solutions_1/1912.design-movie-rental-system.kt
# - Downloading design-movie-rental-system
#   ✘ Time Limit Exceeded
#   ✘ 37/42 cases passed (N/A)
#   ✘ Testcase: ["MovieRentingSystem","rent","search","drop","rent","rent","rent","drop","drop","rent","drop","rent","drop","rent","rent","drop","drop","rent","search","rent","drop","drop","drop","rent","rent","search","drop","drop","rent","drop","report","rent","rent","rent","drop","rent","rent","rent","rent","rent","rent","rent","rent","drop","drop","drop","drop","report","drop","rent","drop","search","rent","drop","drop","rent","drop","rent","rent","search","drop","rent","search","rent","rent","drop","drop","rent","rent","drop","rent","rent","drop","rent","drop","rent","rent","rent","drop","drop","search","report","rent","drop","search","drop","drop","drop","rent","drop","drop","report","drop","drop","drop","drop","drop","search","rent","rent","rent","rent","drop","rent","rent","drop","rent","rent","rent","drop","drop","report","drop","drop","report","rent","rent","drop","rent","rent","drop","rent","search","rent","drop","rent","drop","drop","drop","rent","rent","rent","rent","report","drop","search","rent","drop","rent","drop","drop","drop","drop","rent","rent","rent","drop","rent","rent","rent","rent","report","report","drop","rent","rent","drop","rent","drop","rent","rent","search","rent","rent","drop","rent","drop","drop","drop","rent","rent","report","rent","report","drop","rent","drop","report","report","report","search","rent","drop","drop","report","rent","search","rent","rent","drop","rent","drop","drop","rent","rent","rent","rent","rent","rent","rent","rent","rent","report","rent","drop","drop","drop","rent","report","drop","rent","drop","drop","drop","search","drop","drop","rent","drop","drop","drop","drop","drop","rent","rent","rent","rent","search","drop","rent","rent","rent","drop","search","drop","report","drop","drop","drop","rent","drop","rent","drop","drop","report","drop","rent","rent","rent","drop","rent","search","drop","drop","report","rent","rent","report","rent","rent","drop","rent","rent","rent","rent","drop","rent","drop","drop","search","drop","rent","rent","drop","drop","rent","drop","rent","rent","rent","drop","drop","drop","drop","rent","drop","rent","drop","rent","rent","drop","rent","search","drop","rent","rent","drop","rent","drop","drop","rent","rent","drop","drop","report","drop","drop","drop","search","rent","rent","rent","rent","drop","drop","rent","rent","drop","rent","drop","rent","drop","drop","drop","rent","drop","rent","rent","drop","drop","rent","rent","rent","report","rent","drop","rent","rent","drop","rent","rent","rent","rent","rent","rent","rent","rent","report","rent","rent","rent","drop","drop","rent","rent","search","drop","rent","drop","drop","report","drop","report","rent","rent","drop","drop","report","drop","rent","drop","search","drop","drop","drop","rent","drop","report","drop","drop","drop","rent","rent","rent","drop","rent","drop","drop","rent","drop","rent","drop","rent","drop","drop","drop","rent","drop","drop","rent","drop","drop","report","rent","rent","drop","drop","report","drop","rent","drop","drop","rent","drop","rent","drop","drop","drop","drop","drop","rent","drop","drop","search","drop","search","report","drop","search","rent","report","rent","rent","rent","drop","rent","search","rent","rent","drop","rent","report","rent","drop","drop","drop","rent","rent","drop","rent","drop","drop","drop","report","rent","drop","rent","rent","rent","drop","rent","drop","rent","rent","rent","rent","drop","drop","rent","rent","rent","rent","rent","report","drop","drop","drop","rent","drop","rent","rent","report","rent","drop","drop","rent","rent","drop","drop","drop","drop","drop","drop","drop","drop","drop","drop","rent","drop","rent","rent","report","rent","drop","rent","drop","drop","drop","rent","drop","drop","drop","drop","drop","rent","drop","rent","rent","drop","rent","search","search","drop","drop","rent","drop","rent","drop","rent","rent","drop","drop","report","rent","drop","drop","drop","drop","drop","drop","report","rent","rent","rent","rent","rent","rent","drop" ...
#   ✘ Answer:
#   ✘ Expected Answer: [null,null,[],null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,[],null,null,null,null,null,null,[],null,null,null,null,[],null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,[[136544,7],[13274,7],[271126,7],[150804,7],[298274,7]],null,null,null,[],null,null,null,null,null,null,null,[],null,null,[],null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,[],[[127098,7],[30074,7],[13274,7],[142714,7],[37678,7]],null,null,[],null,null,null,null,null,null,[[127098,7],[142714,7],[71038,7],[197171,7],[237001,7]],null,null,null,null,null,[],null,null,null,null,null,null,null,null,null,null,null,null,null,[[44796,7],[216954,7],[274743,7],[3148,7],[229022,7]],null,null,[[44796,7],[216954,7],[229022,7]],null,null,null,null,null,null,null,[],null,null,null,null,null,null,null,null,null,null,[[44796,7],[218341,7],[243628,7],[129692,7],[207265,7]],null,[],null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,[[99424,7],[299354,7],[44796,7],[105480,7],[218341,7]],[[99424,7],[299354,7],[44796,7],[105480,7],[218341,7]],null,null,null,null,null,null,null,null,[],null,null,null,null,null,null,null,null,null,[[99424,7],[44796,7],[259919,7],[268702,7],[118202,7]],null,[[99424,7],[44796,7],[259919,7],[268702,7],[118202,7]],null,null,null,[[99424,7],[44796,7],[259919,7],[268702,7],[118202,7]],[[99424,7],[44796,7],[259919,7],[268702,7],[118202,7]],[[99424,7],[44796,7],[259919,7],[268702,7],[118202,7]],[],null,null,null,[[102713,7],[44796,7],[259919,7],[268702,7],[118202,7]],null,[],null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,[[102713,7],[44796,7],[259919,7],[268702,7],[118202,7]],null,null,null,null,null,[[102713,7],[15696,7],[44796,7],[259919,7],[268702,7]],null,null,null,null,null,[],null,null,null,null,null,null,null,null,null,null,null,null,[],null,null,null,null,null,[],null,[[102713,7],[15696,7],[74282,7],[116157,7],[56648,7]],null,null,null,null,null,null,null,null,[[102713,7],[15696,7],[74282,7],[116157,7],[56648,7]],null,null,null,null,null,null,[],null,null,[[102713,7],[74282,7],[116157,7],[142625,7],[103883,7]],null,null,[[102713,7],[74282,7],[116157,7],[142625,7],[103883,7]],null,null,null,null,null,null,null,null,null,null,null,[],null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,[],null,null,null,null,null,null,null,null,null,null,null,[[102713,7],[53476,7],[116157,7],[150157,7],[14656,7]],null,null,null,[],null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,[[102713,7],[53476,7],[116157,7],[138570,7],[14656,7]],null,null,null,null,null,null,null,null,null,null,null,null,null,[[102713,7],[252150,7],[53476,7],[132882,7],[79103,7]],null,null,null,null,null,null,null,[],null,null,null,null,[[102713,7],[252150,7],[53476,7],[132882,7],[79103,7]],null,[[102713,7],[252150,7],[53476,7],[132882,7],[269731,7]],null,null,null,null,[[102713,7],[252150,7],[53476,7],[132882,7],[269731,7]],null,null,null,[],null,null,null,null,null,[[102713,7],[252150,7],[132882,7],[182776,7],[287678,7]],null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,[[102713,7],[252150,7],[14387,7],[230522,7],[11529,7]],null,null,null,null,[[102713,7],[252150,7],[14387,7],[230522,7],[11529,7]],null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,[],null,[],[[102713,7],[230522,7],[11529,7],[7391,7],[225107,7]],null,[],null,[[102713,7],[110745,7],[230522,7],[7391,7],[225107,7]],null,null,null,null,null,[],null,null,null,null,[[102713,7],[110745,7],[277112,7],[123544,7],[7350,7]],null,null,null,null,null,null,null,null,null,null,null,[[102713,7],[58013,7],[277112,7],[241054,7],[123544,7]],null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,[[85435,7],[58013,7],[24686,7],[2 ...
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1913.maximum-product-difference-between-two-pairs.kt
# - Downloading maximum-product-difference-between-two-pairs
#   ✔ Accepted
#   ✔ 96/96 cases passed (266 ms)
#   ✔ Your runtime beats 14.29 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (49.8 MB)
# Submitting: kotlin_solutions_1/1914.cyclically-rotating-a-grid.kt
# - Downloading cyclically-rotating-a-grid
#   ✔ Accepted
#   ✔ 68/68 cases passed (283 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1915.number-of-wonderful-substrings.kt
# - Downloading number-of-wonderful-substrings
#   ✘ Wrong Answer
#   ✘ 0/88 cases passed (N/A)
#   ✘ Testcase: "aba"
#   ✘ Answer: 7
#   ✘ Expected Answer: 4
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1916.count-ways-to-build-rooms-in-an-ant-colony.kt
# - Downloading count-ways-to-build-rooms-in-an-ant-colony
#   ✔ Accepted
#   ✔ 66/66 cases passed (764 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1920.build-array-from-permutation.kt
# - Downloading build-array-from-permutation
#   ✔ Accepted
#   ✔ 140/140 cases passed (1 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 60 % of kotlin submissions (48.5 MB)
# Submitting: kotlin_solutions_1/1921.eliminate-maximum-number-of-monsters.kt
# - Downloading eliminate-maximum-number-of-monsters
#   ✔ Accepted
#   ✔ 131/131 cases passed (137 ms)
#   ✔ Your runtime beats 5.88 % of kotlin submissions
#   ✔ Your memory usage beats 11.76 % of kotlin submissions (67.8 MB)
# Submitting: kotlin_solutions_1/1922.count-good-numbers.kt
# - Downloading count-good-numbers
#   ✔ Accepted
#   ✔ 166/166 cases passed (10 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1923.longest-common-subpath.kt
# - Downloading longest-common-subpath
#   ✔ Accepted
#   ✔ 81/81 cases passed (262 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (84.5 MB)
# Submitting: kotlin_solutions_1/1925.count-square-sum-triples.kt
# - Downloading count-square-sum-triples
#   ✔ Accepted
#   ✔ 91/91 cases passed (29 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (41.1 MB)
# Submitting: kotlin_solutions_1/1927.sum-game.kt
# - Downloading sum-game
#   ✔ Accepted
#   ✔ 95/95 cases passed (47 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/1928.minimum-cost-to-reach-destination-in-time.kt
# - Downloading minimum-cost-to-reach-destination-in-time
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 125: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 2: Char 125: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 40: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/1929.concatenation-of-array.kt
# - Downloading concatenation-of-array
#   ✔ Accepted
#   ✔ 92/92 cases passed (1 ms)
#   ✔ Your runtime beats 98.74 % of kotlin submissions
#   ✔ Your memory usage beats 72.56 % of kotlin submissions (46.1 MB)
# Submitting: kotlin_solutions_1/1930.unique-length-3-palindromic-subsequences.kt
# - Downloading unique-length-3-palindromic-subsequences
#   ✔ Accepted
#   ✔ 70/70 cases passed (122 ms)
#   ✔ Your runtime beats 71.43 % of kotlin submissions
#   ✔ Your memory usage beats 85.71 % of kotlin submissions (47.9 MB)
# Submitting: kotlin_solutions_1/1931.painting-a-grid-with-three-different-colors.kt
# - Downloading painting-a-grid-with-three-different-colors
#   ✔ Accepted
#   ✔ 84/84 cases passed (50 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (47.8 MB)

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-08-17 17:30:37
