# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME_2')
    user_cookie = userdata.get('LEETCODE_TOKEN_2')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME_2'] = user_name
    os.environ['LEETCODE_TOKEN_2'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME_2" "$LEETCODE_TOKEN_2" | leetcode user -c

# %%
# %%bash
#
# # top 500-600 answers (6th batch)
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v kotlin_solutions_1/*.kt | sed -n '1301,$p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 7
# done
# Out:
# Submitting: kotlin_solutions_1/3423.maximum-difference-between-adjacent-elements-in-a-circular-array.kt
# - Downloading maximum-difference-between-adjacent-elements-in-a-circular-array
#   ✔ Accepted
#   ✔ 962/962 cases passed (15 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3424.minimum-cost-to-make-arrays-identical.kt
# - Downloading minimum-cost-to-make-arrays-identical
#   ✔ Accepted
#   ✔ 955/955 cases passed (431 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (84.7 MB)
# Submitting: kotlin_solutions_1/3425.longest-special-path.kt
# - Downloading longest-special-path
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 8: Char 87: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 8: Char 87: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 8: Char 189: ERROR: Argument type mismatch: actual type is 'kotlin.text.MatchGroup?', but 'kotlin.Int' was expected.
# Line 8: Char 189: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun MatchGroupCollection.get(name: String): MatchGroup?
# Line 8: Char 211: ERROR: Argument type mismatch: actual type is 'kotlin.text.MatchGroup?', but 'kotlin.Int' was expected.
# Line 8: Char 211: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun MatchGroupCollection.get(name: String): MatchGroup?
# Line 8: Char 218: ERROR: Argument type mismatch: actual type is 'kotlin.text.MatchGroup?', but 'kotlin.Int' was expected.
# Line 8: Char 218: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun MatchGroupCollection.get(name: String): MatchGroup?
# Line 8: Char 238: WARNING: Parameter 'g: Array<MutableList<IntArray>>' is never used, could be renamed to '_'.
# Line 8: Char 278: WARNING: Unchecked cast of 'kotlin.Any' to 'kotlin.Function2<kotlin.Any, kotlin.Array<kotlin.Any>, kotlin.IntArray>'.
# Line 8: Char 395: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 9: Char 61: WARNING: Unchecked cast of 'kotlin.Any' to 'kotlin.Function2<kotlin.Any, kotlin.Array<kotlin.Any>, kotlin.IntArray>'.
# Line 10: Char 100: ERROR: Argument type mismatch: actual type is 'kotlin.text.MatchGroup?', but 'kotlin.Int' was expected.
# Line 10: Char 100: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun MatchGroupCollection.get(name: String): MatchGroup?
# Line 15: Char 87: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 15: Char 189: ERROR: Argument type mismatch: actual type is 'kotlin.text.MatchGroup?', but 'kotlin.Int' was expected.
# Line 15: Char 189: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun MatchGroupCollection.get(name: String): MatchGroup?
# Line 15: Char 211: ERROR: Argument type mismatch: actual type is 'kotlin.text.MatchGroup?', but 'kotlin.Int' was expected.
# Line 15: Char 211: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun MatchGroupCollection.get(name: String): MatchGroup?
# Line 15: Char 218: ERROR: Argument type mismatch: actual type is 'kotlin.text.MatchGroup?', but 'kotlin.Int' was expected.
# Line 15: Char 218: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun MatchGroupCollection.get(name: String): MatchGroup?
# Line 15: Char 405: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 15: Char 684: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 15: Char 706: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 15: Char 741: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 15: Char 832: WARNING: Parameter 'it: Boolean' is never used, could be renamed to '_'.
# Line 15: Char 834: ERROR: Unresolved reference 'f'.
# Line 15: Char 892: WARNING: Parameter 'it: Boolean' is never used, could be renamed to '_'.
# Line 15: Char 934: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/3426.manhattan-distances-of-all-arrangements-of-pieces.kt
# - Downloading manhattan-distances-of-all-arrangements-of-pieces
#   ✔ Accepted
#   ✔ 919/919 cases passed (62 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (45.3 MB)
# Submitting: kotlin_solutions_1/3427.sum-of-variable-length-subarrays.kt
# - Downloading sum-of-variable-length-subarrays
#   ✔ Accepted
#   ✔ 773/773 cases passed (22 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 16.67 % of kotlin submissions (46.2 MB)
# Submitting: kotlin_solutions_1/3429.paint-house-iv.kt
# - Downloading paint-house-iv
#   ✔ Accepted
#   ✔ 956/956 cases passed (65 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (138 MB)
# Submitting: kotlin_solutions_1/3430.maximum-and-minimum-sums-of-at-most-size-k-subarrays.kt
# - Downloading maximum-and-minimum-sums-of-at-most-size-k-subarrays
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 45: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Error: Line 45: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/3432.count-partitions-with-even-sum-difference.kt
# - Downloading count-partitions-with-even-sum-difference
#   ✔ Accepted
#   ✔ 616/616 cases passed (18 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3433.count-mentions-per-user.kt
# - Downloading count-mentions-per-user
#   ✔ Accepted
#   ✔ 673/673 cases passed (64 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (54.7 MB)
# Submitting: kotlin_solutions_1/3434.maximum-frequency-after-subarray-operation.kt
# - Downloading maximum-frequency-after-subarray-operation
#   ✔ Accepted
#   ✔ 749/749 cases passed (237 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3435.frequencies-of-shortest-supersequences.kt
# - Downloading frequencies-of-shortest-supersequences
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 8: Char 87: WARNING: Type argument for reified type parameter 'T' was inferred to the intersection of ['kotlin.Cloneable' & 'java.io.Serializable']. Reification of an intersection type results in the common supertype being used. This may lead to subtle issues and an explicit type argument is encouraged. This will become an error in a future release.
#   ✘ Error: Line 8: Char 87: WARNING: Type argument for reified type parameter 'T' was inferred to the intersection of ['kotlin.Cloneable' & 'java.io.Serializable']. Reification of an intersection type results in the common supertype being used. This may lead to subtle issues and an explicit type argument is encouraged. This will become an error in a future release.
# Line 8: Char 108: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 8: Char 279: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 8: Char 442: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 8: Char 641: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 8: Char 717: WARNING: Unchecked cast of 'it(kotlin.Cloneable & java.io.Serializable)' to 'kotlin.Array<kotlin.Any?>'.
# Line 8: Char 747: WARNING: Parameter 'it: IntArray' is never used, could be renamed to '_'.
# Line 8: Char 930: WARNING: Unchecked cast of 'it(kotlin.Cloneable & java.io.Serializable)' to 'kotlin.Array<kotlin.Any?>'.
# Line 8: Char 1082: WARNING: Unchecked cast of 'it(kotlin.Cloneable & java.io.Serializable)' to 'kotlin.Array<kotlin.Any?>'.
# Line 8: Char 1111: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 8: Char 1140: WARNING: Unchecked cast of 'it(kotlin.Cloneable & java.io.Serializable)' to 'kotlin.Array<kotlin.Any?>'.
# Line 8: Char 1177: ERROR: Argument type mismatch: actual type is 'kotlin.Array<kotlin.Any>', but 'kotlin.Int' was expected.
# Line 8: Char 1249: WARNING: Unchecked cast of 'it(kotlin.Cloneable & java.io.Serializable)' to 'kotlin.Array<kotlin.Any?>'.
# Line 8: Char 1294: WARNING: Unchecked cast of 'it(kotlin.Cloneable & java.io.Serializable)' to 'kotlin.Array<kotlin.Any?>'.
# Line 8: Char 1313: WARNING: Unchecked cast of 'kotlin.Any?' to 'kotlin.Function3<kotlin.Int, kotlin.Int, kotlin.Function2<kotlin.Int, kotlin.Int, kotlin.Int>, kotlin.Int>'.
# Line 8: Char 1378: WARNING: Unchecked cast of 'it(kotlin.Cloneable & java.io.Serializable)' to 'kotlin.Array<kotlin.Any?>'.
# Line 8: Char 1397: WARNING: Unchecked cast of 'kotlin.Any?' to 'kotlin.Function3<kotlin.Int, kotlin.Int, kotlin.Function2<kotlin.Int, kotlin.Int, kotlin.Int>, kotlin.Int>'.
# Line 8: Char 1468: WARNING: Parameter 'it: Unit' is never used, could be renamed to '_'.
# Line 8: Char 1477: WARNING: Unchecked cast of 'kotlin.Array<it(kotlin.Cloneable & java.io.Serializable)>!' to 'kotlin.Array<kotlin.Any>'.
# Line 8: Char 1506: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun MatchGroupCollection.get(name: String): MatchGroup?
# Line 8: Char 1530: ERROR: Argument type mismatch: actual type is 'java.io.Serializable', but 'kotlin.Int' was expected.
# Line 8: Char 1547: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun MatchGroupCollection.get(name: String): MatchGroup?
# Line 8: Char 1582: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun MatchGroupCollection.get(name: String): MatchGroup?
# Line 8: Char 1677: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 8: Char 1729: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun MatchGroupCollection.get(name: String): MatchGroup?
# Line 8: Char 1764: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun MatchGroupCollection.get(name: String): MatchGroup?
# Line 8: Char 1839: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun MatchGroupCollection.get(name: String): MatchGroup?
# Line 8: Char 1903: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun MatchGroupCollection.get(name: String): MatchGroup?
# Line 8: Char 1957: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun MatchGroupCollection.get(name: String): MatchGroup?
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/3438.find-valid-pair-of-adjacent-digits-in-string.kt
# - Downloading find-valid-pair-of-adjacent-digits-in-string
#   ✔ Accepted
#   ✔ 826/826 cases passed (24 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 16.67 % of kotlin submissions (44.7 MB)
# Submitting: kotlin_solutions_1/3439.reschedule-meetings-for-maximum-free-time-i.kt
# - Downloading reschedule-meetings-for-maximum-free-time-i
#   ✔ Accepted
#   ✔ 689/689 cases passed (22 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (74.7 MB)
# Submitting: kotlin_solutions_1/3440.reschedule-meetings-for-maximum-free-time-ii.kt
# - Downloading reschedule-meetings-for-maximum-free-time-ii
#   ✔ Accepted
#   ✔ 695/695 cases passed (99 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (86.9 MB)
# Submitting: kotlin_solutions_1/3442.maximum-difference-between-even-and-odd-frequency-i.kt
# - Downloading maximum-difference-between-even-and-odd-frequency-i
#   ✔ Accepted
#   ✔ 805/805 cases passed (24 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3443.maximum-manhattan-distance-after-k-changes.kt
# - Downloading maximum-manhattan-distance-after-k-changes
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 6: error: <identifier> expected
#   ✘ Error: Line 6: error: <identifier> expected
# class Solution { fun maxDistance(s: String, k: Int): Int = IntArray(10).let { v -> s.indices.forEach { i -> (if (s[i] == 'N') v[1]++ else if (s[i] == 'S') v[2]++ else if (s[i] == 'E') v[3]++ else v[4]++).run { (Math.min(v[1], v[2]) + Math.min(v[3], v[4])).let { m -> (v[1] + v[2] + v[3] + v[4] - 2 * Math.max(0, m - k)).let { dist -> if (dist > v[6]) v[6] = dist } } } }.run { v[6] } } }
#                                   ^
# Line 6: error: not a statement
# class Solution { fun maxDistance(s: String, k: Int): Int = IntArray(10).let { v -> s.indices.forEach { i -> (if (s[i] == 'N') v[1]++ else if (s[i] == 'S') v[2]++ else if (s[i] == 'E') v[3]++ else v[4]++).run { (Math.min(v[1], v[2]) + Math.min(v[3], v[4])).let { m -> (v[1] + v[2] + v[3] + v[4] - 2 * Math.max(0, m - k)).let { dist -> if (dist > v[6]) v[6] = dist } } } }.run { v[6] } } }
#                                                                               ^
# Line 6: error: ';' expected
# class Solution { fun maxDistance(s: String, k: Int): Int = IntArray(10).let { v -> s.indices.forEach { i -> (if (s[i] == 'N') v[1]++ else if (s[i] == 'S') v[2]++ else if (s[i] == 'E') v[3]++ else v[4]++).run { (Math.min(v[1], v[2]) + Math.min(v[3], v[4])).let { m -> (v[1] + v[2] + v[3] + v[4] - 2 * Math.max(0, m - k)).let { dist -> if (dist > v[6]) v[6] = dist } } } }.run { v[6] } } }
#                                                                                                     ^
# Line 6: error: illegal start of expression
# class Solution { fun maxDistance(s: String, k: Int): Int = IntArray(10).let { v -> s.indices.forEach { i -> (if (s[i] == 'N') v[1]++ else if (s[i] == 'S') v[2]++ else if (s[i] == 'E') v[3]++ else v[4]++).run { (Math.min(v[1], v[2]) + Math.min(v[3], v[4])).let { m -> (v[1] + v[2] + v[3] + v[4] - 2 * Math.max(0, m - k)).let { dist -> if (dist > v[6]) v[6] = dist } } } }.run { v[6] } } }
#                                                                                                              ^
# Line 6: error: not a statement
# class Solution { fun maxDistance(s: String, k: Int): Int = IntArray(10).let { v -> s.indices.forEach { i -> (if (s[i] == 'N') v[1]++ else if (s[i] == 'S') v[2]++ else if (s[i] == 'E') v[3]++ else v[4]++).run { (Math.min(v[1], v[2]) + Math.min(v[3], v[4])).let { m -> (v[1] + v[2] + v[3] + v[4] - 2 * Math.max(0, m - k)).let { dist -> if (dist > v[6]) v[6] = dist } } } }.run { v[6] } } }
#                                                                                                        ^
# Line 6: error: ';' expected
# class Solution { fun maxDistance(s: String, k: Int): Int = IntArray(10).let { v -> s.indices.forEach { i -> (if (s[i] == 'N') v[1]++ else if (s[i] == 'S') v[2]++ else if (s[i] == 'E') v[3]++ else v[4]++).run { (Math.min(v[1], v[2]) + Math.min(v[3], v[4])).let { m -> (v[1] + v[2] + v[3] + v[4] - 2 * Math.max(0, m - k)).let { dist -> if (dist > v[6]) v[6] = dist } } } }.run { v[6] } } }
#                                                                                                                                     ^
# Line 6: error: ';' expected
# class Solution { fun maxDistance(s: String, k: Int): Int = IntArray(10).let { v -> s.indices.forEach { i -> (if (s[i] == 'N') v[1]++ else if (s[i] == 'S') v[2]++ else if (s[i] == 'E') v[3]++ else v[4]++).run { (Math.min(v[1], v[2]) + Math.min(v[3], v[4])).let { m -> (v[1] + v[2] + v[3] + v[4] - 2 * Math.max(0, m - k)).let { dist -> if (dist > v[6]) v[6] = dist } } } }.run { v[6] } } }
#                                                                                                                                                                  ^
# Line 6: error: ';' expected
# class Solution { fun maxDistance(s: String, k: Int): Int = IntArray(10).let { v -> s.indices.forEach { i -> (if (s[i] == 'N') v[1]++ else if (s[i] == 'S') v[2]++ else if (s[i] == 'E') v[3]++ else v[4]++).run { (Math.min(v[1], v[2]) + Math.min(v[3], v[4])).let { m -> (v[1] + v[2] + v[3] + v[4] - 2 * Math.max(0, m - k)).let { dist -> if (dist > v[6]) v[6] = dist } } } }.run { v[6] } } }
#                                                                                                                                                                                               ^
# Line 6: error: ';' expected
# class Solution { fun maxDistance(s: String, k: Int): Int = IntArray(10).let { v -> s.indices.forEach { i -> (if (s[i] == 'N') v[1]++ else if (s[i] == 'S') v[2]++ else if (s[i] == 'E') v[3]++ else v[4]++).run { (Math.min(v[1], v[2]) + Math.min(v[3], v[4])).let { m -> (v[1] + v[2] + v[3] + v[4] - 2 * Math.max(0, m - k)).let { dist -> if (dist > v[6]) v[6] = dist } } } }.run { v[6] } } }
#                                                                                                                                                                                                           ^
# Line 6: error: not a statement
# class Solution { fun maxDistance(s: String, k: Int): Int = IntArray(10).let { v -> s.indices.forEach { i -> (if (s[i] == 'N') v[1]++ else if (s[i] == 'S') v[2]++ else if (s[i] == 'E') v[3]++ else v[4]++).run { (Math.min(v[1], v[2]) + Math.min(v[3], v[4])).let { m -> (v[1] + v[2] + v[3] + v[4] - 2 * Math.max(0, m - k)).let { dist -> if (dist > v[6]) v[6] = dist } } } }.run { v[6] } } }
#                                                                                                                                                                                                             ^
# Line 6: error: ';' expected
# class Solution { fun maxDistance(s: String, k: Int): Int = IntArray(10).let { v -> s.indices.forEach { i -> (if (s[i] == 'N') v[1]++ else if (s[i] == 'S') v[2]++ else if (s[i] == 'E') v[3]++ else v[4]++).run { (Math.min(v[1], v[2]) + Math.min(v[3], v[4])).let { m -> (v[1] + v[2] + v[3] + v[4] - 2 * Math.max(0, m - k)).let { dist -> if (dist > v[6]) v[6] = dist } } } }.run { v[6] } } }
#                                                                                                                                                                                                                ^
# Line 6: error: not a statement
# class Solution { fun maxDistance(s: String, k: Int): Int = IntArray(10).let { v -> s.indices.forEach { i -> (if (s[i] == 'N') v[1]++ else if (s[i] == 'S') v[2]++ else if (s[i] == 'E') v[3]++ else v[4]++).run { (Math.min(v[1], v[2]) + Math.min(v[3], v[4])).let { m -> (v[1] + v[2] + v[3] + v[4] - 2 * Math.max(0, m - k)).let { dist -> if (dist > v[6]) v[6] = dist } } } }.run { v[6] } } }
#                                                                                                                                                                                                                                                                ^
# Line 6: error: ';' expected
# class Solution { fun maxDistance(s: String, k: Int): Int = IntArray(10).let { v -> s.indices.forEach { i -> (if (s[i] == 'N') v[1]++ else if (s[i] == 'S') v[2]++ else if (s[i] == 'E') v[3]++ else v[4]++).run { (Math.min(v[1], v[2]) + Math.min(v[3], v[4])).let { m -> (v[1] + v[2] + v[3] + v[4] - 2 * Math.max(0, m - k)).let { dist -> if (dist > v[6]) v[6] = dist } } } }.run { v[6] } } }
#                                                                                                                                                                                                                                                                    ^
# Line 6: error: not a statement
# class Solution { fun maxDistance(s: String, k: Int): Int = IntArray(10).let { v -> s.indices.forEach { i -> (if (s[i] == 'N') v[1]++ else if (s[i] == 'S') v[2]++ else if (s[i] == 'E') v[3]++ else v[4]++).run { (Math.min(v[1], v[2]) + Math.min(v[3], v[4])).let { m -> (v[1] + v[2] + v[3] + v[4] - 2 * Math.max(0, m - k)).let { dist -> if (dist > v[6]) v[6] = dist } } } }.run { v[6] } } }
#                                                                                                                                                                                                                                                                       ^
# Line 6: error: ';' expected
# class Solution { fun maxDistance(s: String, k: Int): Int = IntArray(10).let { v -> s.indices.forEach { i -> (if (s[i] == 'N') v[1]++ else if (s[i] == 'S') v[2]++ else if (s[i] == 'E') v[3]++ else v[4]++).run { (Math.min(v[1], v[2]) + Math.min(v[3], v[4])).let { m -> (v[1] + v[2] + v[3] + v[4] - 2 * Math.max(0, m - k)).let { dist -> if (dist > v[6]) v[6] = dist } } } }.run { v[6] } } }
#                                                                                                                                                                                                                                                                                                                                    ^
# Line 6: error: illegal start of expression
# class Solution { fun maxDistance(s: String, k: Int): Int = IntArray(10).let { v -> s.indices.forEach { i -> (if (s[i] == 'N') v[1]++ else if (s[i] == 'S') v[2]++ else if (s[i] == 'E') v[3]++ else v[4]++).run { (Math.min(v[1], v[2]) + Math.min(v[3], v[4])).let { m -> (v[1] + v[2] + v[3] + v[4] - 2 * Math.max(0, m - k)).let { dist -> if (dist > v[6]) v[6] = dist } } } }.run { v[6] } } }
#                                                                                                                                                                                                                                                                                                                                               ^
# Line 6: error: not a statement
# class Solution { fun maxDistance(s: String, k: Int): Int = IntArray(10).let { v -> s.indices.forEach { i -> (if (s[i] == 'N') v[1]++ else if (s[i] == 'S') v[2]++ else if (s[i] == 'E') v[3]++ else v[4]++).run { (Math.min(v[1], v[2]) + Math.min(v[3], v[4])).let { m -> (v[1] + v[2] + v[3] + v[4] - 2 * Math.max(0, m - k)).let { dist -> if (dist > v[6]) v[6] = dist } } } }.run { v[6] } } }
#                                                                                                                                                                                                                                                                                                                                       ^
# Line 6: error: ';' expected
# class Solution { fun maxDistance(s: String, k: Int): Int = IntArray(10).let { v -> s.indices.forEach { i -> (if (s[i] == 'N') v[1]++ else if (s[i] == 'S') v[2]++ else if (s[i] == 'E') v[3]++ else v[4]++).run { (Math.min(v[1], v[2]) + Math.min(v[3], v[4])).let { m -> (v[1] + v[2] + v[3] + v[4] - 2 * Math.max(0, m - k)).let { dist -> if (dist > v[6]) v[6] = dist } } } }.run { v[6] } } }
#                                                                                                                                                                                                                                                                                                                                                                           ^
# Line 6: error: illegal start of expression
# class Solution { fun maxDistance(s: String, k: Int): Int = IntArray(10).let { v -> s.indices.forEach { i -> (if (s[i] == 'N') v[1]++ else if (s[i] == 'S') v[2]++ else if (s[i] == 'E') v[3]++ else v[4]++).run { (Math.min(v[1], v[2]) + Math.min(v[3], v[4])).let { m -> (v[1] + v[2] + v[3] + v[4] - 2 * Math.max(0, m - k)).let { dist -> if (dist > v[6]) v[6] = dist } } } }.run { v[6] } } }
#                                                                                                                                                                                                                                                                                                                                                                                   ^
# Line 6: error: not a statement
# class Solution { fun maxDistance(s: String, k: Int): Int = IntArray(10).let { v -> s.indices.forEach { i -> (if (s[i] == 'N') v[1]++ else if (s[i] == 'S') v[2]++ else if (s[i] == 'E') v[3]++ else v[4]++).run { (Math.min(v[1], v[2]) + Math.min(v[3], v[4])).let { m -> (v[1] + v[2] + v[3] + v[4] - 2 * Math.max(0, m - k)).let { dist -> if (dist > v[6]) v[6] = dist } } } }.run { v[6] } } }
#                                                                                                                                                                                                                                                                                                                                                                                    ^
# Line 6: error: ';' expected
# class Solution { fun maxDistance(s: String, k: Int): Int = IntArray(10).let { v -> s.indices.forEach { i -> (if (s[i] == 'N') v[1]++ else if (s[i] == 'S') v[2]++ else if (s[i] == 'E') v[3]++ else v[4]++).run { (Math.min(v[1], v[2]) + Math.min(v[3], v[4])).let { m -> (v[1] + v[2] + v[3] + v[4] - 2 * Math.max(0, m - k)).let { dist -> if (dist > v[6]) v[6] = dist } } } }.run { v[6] } } }
#                                                                                                                                                                                                                                                                                                                                                                                       ^
# Line 6: error: not a statement
# class Solution { fun maxDistance(s: String, k: Int): Int = IntArray(10).let { v -> s.indices.forEach { i -> (if (s[i] == 'N') v[1]++ else if (s[i] == 'S') v[2]++ else if (s[i] == 'E') v[3]++ else v[4]++).run { (Math.min(v[1], v[2]) + Math.min(v[3], v[4])).let { m -> (v[1] + v[2] + v[3] + v[4] - 2 * Math.max(0, m - k)).let { dist -> if (dist > v[6]) v[6] = dist } } } }.run { v[6] } } }
#                                                                                                                                                                                                                                                                                                                                                                                           ^
# Line 6: error: ';' expected
# class Solution { fun maxDistance(s: String, k: Int): Int = IntArray(10).let { v -> s.indices.forEach { i -> (if (s[i] == 'N') v[1]++ else if (s[i] == 'S') v[2]++ else if (s[i] == 'E') v[3]++ else v[4]++).run { (Math.min(v[1], v[2]) + Math.min(v[3], v[4])).let { m -> (v[1] + v[2] + v[3] + v[4] - 2 * Math.max(0, m - k)).let { dist -> if (dist > v[6]) v[6] = dist } } } }.run { v[6] } } }
#                                                                                                                                                                                                                                                                                                                                                                                              ^
# 23 errors
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/3444.minimum-increments-for-target-multiples-in-an-array.kt
# - Downloading minimum-increments-for-target-multiples-in-an-array
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 6: error: <identifier> expected
#   ✘ Error: Line 6: error: <identifier> expected
# class Solution { fun minimumIncrements(nums: IntArray, target: IntArray): Int = (1 until (1 shl target.size)).map { mask -> target.indices.filter { (mask shr it) and 1 == 1 }.map { target[it].toLong() }.reduce { a, b -> (a * b) / java.math.BigInteger.valueOf(a).gcd(java.math.BigInteger.valueOf(b)).toLong() } }.let { lcms -> nums.fold(LongArray(1 shl target.size) { 1e15.toLong() }.also { it[0] = 0 }) { dp, x -> LongArray(1 shl target.size) { dp[it] }.also { next -> lcms.forEachIndexed { i, lcm -> (i + 1).let { mask -> (lcm - (x % lcm)).let { if (it == lcm) 0L else it }.let { cost -> (0 until (1 shl target.size)).forEach { prev -> next[prev or mask] = Math.min(next[prev or mask], dp[prev] + cost) } } } } } } }.last().toInt() } }
#                                            ^
# Line 6: error: not a statement
# class Solution { fun minimumIncrements(nums: IntArray, target: IntArray): Int = (1 until (1 shl target.size)).map { mask -> target.indices.filter { (mask shr it) and 1 == 1 }.map { target[it].toLong() }.reduce { a, b -> (a * b) / java.math.BigInteger.valueOf(a).gcd(java.math.BigInteger.valueOf(b)).toLong() } }.let { lcms -> nums.fold(LongArray(1 shl target.size) { 1e15.toLong() }.also { it[0] = 0 }) { dp, x -> LongArray(1 shl target.size) { dp[it] }.also { next -> lcms.forEachIndexed { i, lcm -> (i + 1).let { mask -> (lcm - (x % lcm)).let { if (it == lcm) 0L else it }.let { cost -> (0 until (1 shl target.size)).forEach { prev -> next[prev or mask] = Math.min(next[prev or mask], dp[prev] + cost) } } } } } } }.last().toInt() } }
#                                                                                                                     ^
# Line 6: error: ';' expected
# class Solution { fun minimumIncrements(nums: IntArray, target: IntArray): Int = (1 until (1 shl target.size)).map { mask -> target.indices.filter { (mask shr it) and 1 == 1 }.map { target[it].toLong() }.reduce { a, b -> (a * b) / java.math.BigInteger.valueOf(a).gcd(java.math.BigInteger.valueOf(b)).toLong() } }.let { lcms -> nums.fold(LongArray(1 shl target.size) { 1e15.toLong() }.also { it[0] = 0 }) { dp, x -> LongArray(1 shl target.size) { dp[it] }.also { next -> lcms.forEachIndexed { i, lcm -> (i + 1).let { mask -> (lcm - (x % lcm)).let { if (it == lcm) 0L else it }.let { cost -> (0 until (1 shl target.size)).forEach { prev -> next[prev or mask] = Math.min(next[prev or mask], dp[prev] + cost) } } } } } } }.last().toInt() } }
#                                                                                                                                                  ^
# Line 6: error: ',', ')', or '[' expected
# class Solution { fun minimumIncrements(nums: IntArray, target: IntArray): Int = (1 until (1 shl target.size)).map { mask -> target.indices.filter { (mask shr it) and 1 == 1 }.map { target[it].toLong() }.reduce { a, b -> (a * b) / java.math.BigInteger.valueOf(a).gcd(java.math.BigInteger.valueOf(b)).toLong() } }.let { lcms -> nums.fold(LongArray(1 shl target.size) { 1e15.toLong() }.also { it[0] = 0 }) { dp, x -> LongArray(1 shl target.size) { dp[it] }.also { next -> lcms.forEachIndexed { i, lcm -> (i + 1).let { mask -> (lcm - (x % lcm)).let { if (it == lcm) 0L else it }.let { cost -> (0 until (1 shl target.size)).forEach { prev -> next[prev or mask] = Math.min(next[prev or mask], dp[prev] + cost) } } } } } } }.last().toInt() } }
#                                                                                                                                                              ^
# Line 6: error: not a statement
# class Solution { fun minimumIncrements(nums: IntArray, target: IntArray): Int = (1 until (1 shl target.size)).map { mask -> target.indices.filter { (mask shr it) and 1 == 1 }.map { target[it].toLong() }.reduce { a, b -> (a * b) / java.math.BigInteger.valueOf(a).gcd(java.math.BigInteger.valueOf(b)).toLong() } }.let { lcms -> nums.fold(LongArray(1 shl target.size) { 1e15.toLong() }.also { it[0] = 0 }) { dp, x -> LongArray(1 shl target.size) { dp[it] }.also { next -> lcms.forEachIndexed { i, lcm -> (i + 1).let { mask -> (lcm - (x % lcm)).let { if (it == lcm) 0L else it }.let { cost -> (0 until (1 shl target.size)).forEach { prev -> next[prev or mask] = Math.min(next[prev or mask], dp[prev] + cost) } } } } } } }.last().toInt() } }
#                                                                                                                                                     ^
# Line 6: error: ';' expected
# class Solution { fun minimumIncrements(nums: IntArray, target: IntArray): Int = (1 until (1 shl target.size)).map { mask -> target.indices.filter { (mask shr it) and 1 == 1 }.map { target[it].toLong() }.reduce { a, b -> (a * b) / java.math.BigInteger.valueOf(a).gcd(java.math.BigInteger.valueOf(b)).toLong() } }.let { lcms -> nums.fold(LongArray(1 shl target.size) { 1e15.toLong() }.also { it[0] = 0 }) { dp, x -> LongArray(1 shl target.size) { dp[it] }.also { next -> lcms.forEachIndexed { i, lcm -> (i + 1).let { mask -> (lcm - (x % lcm)).let { if (it == lcm) 0L else it }.let { cost -> (0 until (1 shl target.size)).forEach { prev -> next[prev or mask] = Math.min(next[prev or mask], dp[prev] + cost) } } } } } } }.last().toInt() } }
#                                                                                                                                                                 ^
# Line 6: error: not a statement
# class Solution { fun minimumIncrements(nums: IntArray, target: IntArray): Int = (1 until (1 shl target.size)).map { mask -> target.indices.filter { (mask shr it) and 1 == 1 }.map { target[it].toLong() }.reduce { a, b -> (a * b) / java.math.BigInteger.valueOf(a).gcd(java.math.BigInteger.valueOf(b)).toLong() } }.let { lcms -> nums.fold(LongArray(1 shl target.size) { 1e15.toLong() }.also { it[0] = 0 }) { dp, x -> LongArray(1 shl target.size) { dp[it] }.also { next -> lcms.forEachIndexed { i, lcm -> (i + 1).let { mask -> (lcm - (x % lcm)).let { if (it == lcm) 0L else it }.let { cost -> (0 until (1 shl target.size)).forEach { prev -> next[prev or mask] = Math.min(next[prev or mask], dp[prev] + cost) } } } } } } }.last().toInt() } }
#                                                                                                                                                                   ^
# Line 6: error: ';' expected
# class Solution { fun minimumIncrements(nums: IntArray, target: IntArray): Int = (1 until (1 shl target.size)).map { mask -> target.indices.filter { (mask shr it) and 1 == 1 }.map { target[it].toLong() }.reduce { a, b -> (a * b) / java.math.BigInteger.valueOf(a).gcd(java.math.BigInteger.valueOf(b)).toLong() } }.let { lcms -> nums.fold(LongArray(1 shl target.size) { 1e15.toLong() }.also { it[0] = 0 }) { dp, x -> LongArray(1 shl target.size) { dp[it] }.also { next -> lcms.forEachIndexed { i, lcm -> (i + 1).let { mask -> (lcm - (x % lcm)).let { if (it == lcm) 0L else it }.let { cost -> (0 until (1 shl target.size)).forEach { prev -> next[prev or mask] = Math.min(next[prev or mask], dp[prev] + cost) } } } } } } }.last().toInt() } }
#                                                                                                                                                                      ^
# Line 6: error: illegal start of expression
# class Solution { fun minimumIncrements(nums: IntArray, target: IntArray): Int = (1 until (1 shl target.size)).map { mask -> target.indices.filter { (mask shr it) and 1 == 1 }.map { target[it].toLong() }.reduce { a, b -> (a * b) / java.math.BigInteger.valueOf(a).gcd(java.math.BigInteger.valueOf(b)).toLong() } }.let { lcms -> nums.fold(LongArray(1 shl target.size) { 1e15.toLong() }.also { it[0] = 0 }) { dp, x -> LongArray(1 shl target.size) { dp[it] }.also { next -> lcms.forEachIndexed { i, lcm -> (i + 1).let { mask -> (lcm - (x % lcm)).let { if (it == lcm) 0L else it }.let { cost -> (0 until (1 shl target.size)).forEach { prev -> next[prev or mask] = Math.min(next[prev or mask], dp[prev] + cost) } } } } } } }.last().toInt() } }
#                                                                                                                                                                               ^
# Line 6: error: not a statement
# class Solution { fun minimumIncrements(nums: IntArray, target: IntArray): Int = (1 until (1 shl target.size)).map { mask -> target.indices.filter { (mask shr it) and 1 == 1 }.map { target[it].toLong() }.reduce { a, b -> (a * b) / java.math.BigInteger.valueOf(a).gcd(java.math.BigInteger.valueOf(b)).toLong() } }.let { lcms -> nums.fold(LongArray(1 shl target.size) { 1e15.toLong() }.also { it[0] = 0 }) { dp, x -> LongArray(1 shl target.size) { dp[it] }.also { next -> lcms.forEachIndexed { i, lcm -> (i + 1).let { mask -> (lcm - (x % lcm)).let { if (it == lcm) 0L else it }.let { cost -> (0 until (1 shl target.size)).forEach { prev -> next[prev or mask] = Math.min(next[prev or mask], dp[prev] + cost) } } } } } } }.last().toInt() } }
#                                                                                                                                                                                ^
# Line 6: error: ';' expected
# class Solution { fun minimumIncrements(nums: IntArray, target: IntArray): Int = (1 until (1 shl target.size)).map { mask -> target.indices.filter { (mask shr it) and 1 == 1 }.map { target[it].toLong() }.reduce { a, b -> (a * b) / java.math.BigInteger.valueOf(a).gcd(java.math.BigInteger.valueOf(b)).toLong() } }.let { lcms -> nums.fold(LongArray(1 shl target.size) { 1e15.toLong() }.also { it[0] = 0 }) { dp, x -> LongArray(1 shl target.size) { dp[it] }.also { next -> lcms.forEachIndexed { i, lcm -> (i + 1).let { mask -> (lcm - (x % lcm)).let { if (it == lcm) 0L else it }.let { cost -> (0 until (1 shl target.size)).forEach { prev -> next[prev or mask] = Math.min(next[prev or mask], dp[prev] + cost) } } } } } } }.last().toInt() } }
#                                                                                                                                                                                   ^
# Line 6: error: ';' expected
# class Solution { fun minimumIncrements(nums: IntArray, target: IntArray): Int = (1 until (1 shl target.size)).map { mask -> target.indices.filter { (mask shr it) and 1 == 1 }.map { target[it].toLong() }.reduce { a, b -> (a * b) / java.math.BigInteger.valueOf(a).gcd(java.math.BigInteger.valueOf(b)).toLong() } }.let { lcms -> nums.fold(LongArray(1 shl target.size) { 1e15.toLong() }.also { it[0] = 0 }) { dp, x -> LongArray(1 shl target.size) { dp[it] }.also { next -> lcms.forEachIndexed { i, lcm -> (i + 1).let { mask -> (lcm - (x % lcm)).let { if (it == lcm) 0L else it }.let { cost -> (0 until (1 shl target.size)).forEach { prev -> next[prev or mask] = Math.min(next[prev or mask], dp[prev] + cost) } } } } } } }.last().toInt() } }
#                                                                                                                                                                                                         ^
# Line 6: error: illegal start of expression
# class Solution { fun minimumIncrements(nums: IntArray, target: IntArray): Int = (1 until (1 shl target.size)).map { mask -> target.indices.filter { (mask shr it) and 1 == 1 }.map { target[it].toLong() }.reduce { a, b -> (a * b) / java.math.BigInteger.valueOf(a).gcd(java.math.BigInteger.valueOf(b)).toLong() } }.let { lcms -> nums.fold(LongArray(1 shl target.size) { 1e15.toLong() }.also { it[0] = 0 }) { dp, x -> LongArray(1 shl target.size) { dp[it] }.also { next -> lcms.forEachIndexed { i, lcm -> (i + 1).let { mask -> (lcm - (x % lcm)).let { if (it == lcm) 0L else it }.let { cost -> (0 until (1 shl target.size)).forEach { prev -> next[prev or mask] = Math.min(next[prev or mask], dp[prev] + cost) } } } } } } }.last().toInt() } }
#                                                                                                                                                                                                           ^
# Line 6: error: not a statement
# class Solution { fun minimumIncrements(nums: IntArray, target: IntArray): Int = (1 until (1 shl target.size)).map { mask -> target.indices.filter { (mask shr it) and 1 == 1 }.map { target[it].toLong() }.reduce { a, b -> (a * b) / java.math.BigInteger.valueOf(a).gcd(java.math.BigInteger.valueOf(b)).toLong() } }.let { lcms -> nums.fold(LongArray(1 shl target.size) { 1e15.toLong() }.also { it[0] = 0 }) { dp, x -> LongArray(1 shl target.size) { dp[it] }.also { next -> lcms.forEachIndexed { i, lcm -> (i + 1).let { mask -> (lcm - (x % lcm)).let { if (it == lcm) 0L else it }.let { cost -> (0 until (1 shl target.size)).forEach { prev -> next[prev or mask] = Math.min(next[prev or mask], dp[prev] + cost) } } } } } } }.last().toInt() } }
#                                                                                                                                                                                                            ^
# Line 6: error: ';' expected
# class Solution { fun minimumIncrements(nums: IntArray, target: IntArray): Int = (1 until (1 shl target.size)).map { mask -> target.indices.filter { (mask shr it) and 1 == 1 }.map { target[it].toLong() }.reduce { a, b -> (a * b) / java.math.BigInteger.valueOf(a).gcd(java.math.BigInteger.valueOf(b)).toLong() } }.let { lcms -> nums.fold(LongArray(1 shl target.size) { 1e15.toLong() }.also { it[0] = 0 }) { dp, x -> LongArray(1 shl target.size) { dp[it] }.also { next -> lcms.forEachIndexed { i, lcm -> (i + 1).let { mask -> (lcm - (x % lcm)).let { if (it == lcm) 0L else it }.let { cost -> (0 until (1 shl target.size)).forEach { prev -> next[prev or mask] = Math.min(next[prev or mask], dp[prev] + cost) } } } } } } }.last().toInt() } }
#                                                                                                                                                                                                                  ^
# Line 6: error: not a statement
# class Solution { fun minimumIncrements(nums: IntArray, target: IntArray): Int = (1 until (1 shl target.size)).map { mask -> target.indices.filter { (mask shr it) and 1 == 1 }.map { target[it].toLong() }.reduce { a, b -> (a * b) / java.math.BigInteger.valueOf(a).gcd(java.math.BigInteger.valueOf(b)).toLong() } }.let { lcms -> nums.fold(LongArray(1 shl target.size) { 1e15.toLong() }.also { it[0] = 0 }) { dp, x -> LongArray(1 shl target.size) { dp[it] }.also { next -> lcms.forEachIndexed { i, lcm -> (i + 1).let { mask -> (lcm - (x % lcm)).let { if (it == lcm) 0L else it }.let { cost -> (0 until (1 shl target.size)).forEach { prev -> next[prev or mask] = Math.min(next[prev or mask], dp[prev] + cost) } } } } } } }.last().toInt() } }
#                                                                                                                                                                                                                     ^
# Line 6: error: ';' expected
# class Solution { fun minimumIncrements(nums: IntArray, target: IntArray): Int = (1 until (1 shl target.size)).map { mask -> target.indices.filter { (mask shr it) and 1 == 1 }.map { target[it].toLong() }.reduce { a, b -> (a * b) / java.math.BigInteger.valueOf(a).gcd(java.math.BigInteger.valueOf(b)).toLong() } }.let { lcms -> nums.fold(LongArray(1 shl target.size) { 1e15.toLong() }.also { it[0] = 0 }) { dp, x -> LongArray(1 shl target.size) { dp[it] }.also { next -> lcms.forEachIndexed { i, lcm -> (i + 1).let { mask -> (lcm - (x % lcm)).let { if (it == lcm) 0L else it }.let { cost -> (0 until (1 shl target.size)).forEach { prev -> next[prev or mask] = Math.min(next[prev or mask], dp[prev] + cost) } } } } } } }.last().toInt() } }
#                                                                                                                                                                                                                      ^
# Line 6: error: not a statement
# class Solution { fun minimumIncrements(nums: IntArray, target: IntArray): Int = (1 until (1 shl target.size)).map { mask -> target.indices.filter { (mask shr it) and 1 == 1 }.map { target[it].toLong() }.reduce { a, b -> (a * b) / java.math.BigInteger.valueOf(a).gcd(java.math.BigInteger.valueOf(b)).toLong() } }.let { lcms -> nums.fold(LongArray(1 shl target.size) { 1e15.toLong() }.also { it[0] = 0 }) { dp, x -> LongArray(1 shl target.size) { dp[it] }.also { next -> lcms.forEachIndexed { i, lcm -> (i + 1).let { mask -> (lcm - (x % lcm)).let { if (it == lcm) 0L else it }.let { cost -> (0 until (1 shl target.size)).forEach { prev -> next[prev or mask] = Math.min(next[prev or mask], dp[prev] + cost) } } } } } } }.last().toInt() } }
#                                                                                                                                                                                                                        ^
# Line 6: error: ';' expected
# class Solution { fun minimumIncrements(nums: IntArray, target: IntArray): Int = (1 until (1 shl target.size)).map { mask -> target.indices.filter { (mask shr it) and 1 == 1 }.map { target[it].toLong() }.reduce { a, b -> (a * b) / java.math.BigInteger.valueOf(a).gcd(java.math.BigInteger.valueOf(b)).toLong() } }.let { lcms -> nums.fold(LongArray(1 shl target.size) { 1e15.toLong() }.also { it[0] = 0 }) { dp, x -> LongArray(1 shl target.size) { dp[it] }.also { next -> lcms.forEachIndexed { i, lcm -> (i + 1).let { mask -> (lcm - (x % lcm)).let { if (it == lcm) 0L else it }.let { cost -> (0 until (1 shl target.size)).forEach { prev -> next[prev or mask] = Math.min(next[prev or mask], dp[prev] + cost) } } } } } } }.last().toInt() } }
#                                                                                                                                                                                                                                                                                                                    ^
# Line 6: error: illegal start of type
# class Solution { fun minimumIncrements(nums: IntArray, target: IntArray): Int = (1 until (1 shl target.size)).map { mask -> target.indices.filter { (mask shr it) and 1 == 1 }.map { target[it].toLong() }.reduce { a, b -> (a * b) / java.math.BigInteger.valueOf(a).gcd(java.math.BigInteger.valueOf(b)).toLong() } }.let { lcms -> nums.fold(LongArray(1 shl target.size) { 1e15.toLong() }.also { it[0] = 0 }) { dp, x -> LongArray(1 shl target.size) { dp[it] }.also { next -> lcms.forEachIndexed { i, lcm -> (i + 1).let { mask -> (lcm - (x % lcm)).let { if (it == lcm) 0L else it }.let { cost -> (0 until (1 shl target.size)).forEach { prev -> next[prev or mask] = Math.min(next[prev or mask], dp[prev] + cost) } } } } } } }.last().toInt() } }
#                                                                                                                                                                                                                                                                                                                        ^
# Line 6: error: <identifier> expected
# class Solution { fun minimumIncrements(nums: IntArray, target: IntArray): Int = (1 until (1 shl target.size)).map { mask -> target.indices.filter { (mask shr it) and 1 == 1 }.map { target[it].toLong() }.reduce { a, b -> (a * b) / java.math.BigInteger.valueOf(a).gcd(java.math.BigInteger.valueOf(b)).toLong() } }.let { lcms -> nums.fold(LongArray(1 shl target.size) { 1e15.toLong() }.also { it[0] = 0 }) { dp, x -> LongArray(1 shl target.size) { dp[it] }.also { next -> lcms.forEachIndexed { i, lcm -> (i + 1).let { mask -> (lcm - (x % lcm)).let { if (it == lcm) 0L else it }.let { cost -> (0 until (1 shl target.size)).forEach { prev -> next[prev or mask] = Math.min(next[prev or mask], dp[prev] + cost) } } } } } } }.last().toInt() } }
# ...
#   ✔ 900/900 cases passed (32 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/3472.longest-palindromic-subsequence-after-at-most-k-operations.kt
# - Downloading longest-palindromic-subsequence-after-at-most-k-operations
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 7: Char 94: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 7: Char 94: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 7: Char 112: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 7: Char 130: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 7: Char 155: ERROR: Argument type mismatch: actual type is 'kotlin.DeepRecursiveFunction<kotlin.Int, kotlin.Int>', but 'kotlin.Int' was expected.
# Line 7: Char 205: ERROR: 'fun DeepRecursiveFunction<*, *>.invoke(value: Any?): Nothing' is deprecated. 'invoke' should not be called from DeepRecursiveScope. Use 'callRecursive' to do recursion in the heap instead of the call stack.
# Line 7: Char 205: ERROR: Unresolved reference. None of the following candidates is applicable because of a receiver type mismatch:
# fun DeepRecursiveFunction<*, *>.invoke(value: Any?): Nothing
# Line 43: Char 2: ERROR: Syntax error: Missing '}.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/3473.sum-of-k-subarrays-with-length-at-least-m.kt
# - Downloading sum-of-k-subarrays-with-length-at-least-m
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 7: Char 199: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 7: Char 199: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 7: Char 210: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 7: Char 228: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 7: Char 902: ERROR: Syntax error: Unexpected tokens (use ';' to separate expressions on the same line).
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/3474.lexicographically-smallest-generated-string.kt
# - Downloading lexicographically-smallest-generated-string
#   ✔ Accepted
#   ✔ 741/741 cases passed (145 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (53.6 MB)
# Submitting: kotlin_solutions_1/3477.fruits-into-baskets-ii.kt
# - Downloading fruits-into-baskets-ii
#   ✔ Accepted
#   ✔ 904/904 cases passed (33 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3479.fruits-into-baskets-iii.kt
# - Downloading fruits-into-baskets-iii
#   ✔ Accepted
#   ✔ 742/742 cases passed (104 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3487.maximum-unique-subarray-sum-after-deletion.kt
# - Downloading maximum-unique-subarray-sum-after-deletion
#   ✔ Accepted
#   ✔ 927/927 cases passed (23 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (46.4 MB)
# Submitting: kotlin_solutions_1/3492.maximum-containers-on-a-ship.kt
# - Downloading maximum-containers-on-a-ship
#   ✔ Accepted
#   ✔ 686/686 cases passed (1 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3493.properties-graph.kt
# - Downloading properties-graph
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 745: ERROR: Unresolved reference 'p'.
#   ✘ Error: Line 2: Char 745: ERROR: Unresolved reference 'p'.
# Line 2: Char 745: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/3494.find-the-minimum-amount-of-time-to-brew-potions.kt
# - Downloading find-the-minimum-amount-of-time-to-brew-potions
#   ✔ Accepted
#   ✔ 744/744 cases passed (307 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (72.2 MB)
# Submitting: kotlin_solutions_1/3495.minimum-operations-to-make-array-elements-zero.kt
# - Downloading minimum-operations-to-make-array-elements-zero
#   ✘ Wrong Answer
#   ✘ 501/646 cases passed (N/A)
#   ✘ Testcase: [[1,8]]
#   ✘ Answer: 6
#   ✘ Expected Answer: 7
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/3498.reverse-degree-of-a-string.kt
# - Downloading reverse-degree-of-a-string
#   ✔ Accepted
#   ✔ 933/933 cases passed (14 ms)
#   ✔ Your runtime beats 36.36 % of kotlin submissions
#   ✔ Your memory usage beats 45.45 % of kotlin submissions (44.5 MB)
# Submitting: kotlin_solutions_1/3499.maximize-active-section-with-trade-i.kt
# - Downloading maximize-active-section-with-trade-i
#   ✘ Time Limit Exceeded
#   ✘ 901/996 cases passed (N/A)
#   ✘ Testcase: "...'... 35319 more character
#   ✘ Answer:
#   ✘ Expected Answer: 22818
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/3500.minimum-cost-to-divide-array-into-subarrays.kt
# - Downloading minimum-cost-to-divide-array-into-subarrays
#   ✔ Accepted
#   ✔ 759/759 cases passed (136 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (68.3 MB)
# Submitting: kotlin_solutions_1/3502.minimum-cost-to-reach-every-position.kt
# - Downloading minimum-cost-to-reach-every-position
#   ✔ Accepted
#   ✔ 724/724 cases passed (10 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/3503.longest-palindrome-after-substring-concatenation-i.kt
# - Downloading longest-palindrome-after-substring-concatenation-i
#   ✔ Accepted
#   ✔ 584/584 cases passed (747 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (68.2 MB)
# Submitting: kotlin_solutions_1/3512.minimum-operations-to-make-array-sum-divisible-by-k.kt
# - Downloading minimum-operations-to-make-array-sum-divisible-by-k
#   ✔ Accepted
#   ✔ 855/855 cases passed (2 ms)
#   ✔ Your runtime beats 59.26 % of kotlin submissions
#   ✔ Your memory usage beats 62.96 % of kotlin submissions (49.5 MB)
# Submitting: kotlin_solutions_1/3513.number-of-unique-xor-triplets-i.kt
# - Downloading number-of-unique-xor-triplets-i
#   ✔ Accepted
#   ✔ 785/785 cases passed (1 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 18.62 % of kotlin submissions (83.5 MB)
# Submitting: kotlin_solutions_1/3516.find-closest-person.kt
# - Downloading find-closest-person
#   ✔ Accepted
#   ✔ 866/866 cases passed (1 ms)
#   ✔ Your runtime beats 70 % of kotlin submissions
#   ✔ Your memory usage beats 60 % of kotlin submissions (40.9 MB)
# Submitting: kotlin_solutions_1/3517.smallest-palindromic-rearrangement-i.kt
# - Downloading smallest-palindromic-rearrangement-i
#   ✔ Accepted
#   ✔ 930/930 cases passed (145 ms)
#   ✔ Your runtime beats 24.65 % of kotlin submissions
#   ✔ Your memory usage beats 72.27 % of kotlin submissions (50.9 MB)
# Submitting: kotlin_solutions_1/3518.smallest-palindromic-rearrangement-ii.kt
# - Downloading smallest-palindromic-rearrangement-ii
#   ✘ Wrong Answer
#   ✘ 531/812 cases passed (N/A)
#   ✘ Testcase: "xfjnuhqxssnnssxqhunjfx"
# 736899
#   ✘ Answer: ""
#   ✘ Expected Answer: "hssqxnjunfxxfnujnxqssh"
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/3519.count-numbers-with-non-decreasing-digits.kt
# - Downloading count-numbers-with-non-decreasing-digits
#   ✔ Accepted
#   ✔ 973/973 cases passed (89 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (55.1 MB)
# Submitting: kotlin_solutions_1/3522.calculate-score-after-performing-instructions.kt
# - Downloading calculate-score-after-performing-instructions
#   ✔ Accepted
#   ✔ 646/646 cases passed (54 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (95.5 MB)
# Submitting: kotlin_solutions_1/3523.make-array-non-decreasing.kt
# - Downloading make-array-non-decreasing
#   ✔ Accepted
#   ✔ 738/738 cases passed (43 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (91.2 MB)
# Submitting: kotlin_solutions_1/3524.find-x-value-of-array-i.kt
# - Downloading find-x-value-of-array-i
#   ✔ Accepted
#   ✔ 782/782 cases passed (44 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (78 MB)
# Submitting: kotlin_solutions_1/3527.find-the-most-common-response.kt
# - Downloading find-the-most-common-response
#   ✔ Accepted
#   ✔ 783/783 cases passed (159 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (229.5 MB)
# Submitting: kotlin_solutions_1/3529.count-cells-in-overlapping-horizontal-and-vertical-substrings.kt
# - Downloading count-cells-in-overlapping-horizontal-and-vertical-substrings
#   ✘ Wrong Answer
#   ✘ 534/573 cases passed (N/A)
#   ✘ Testcase: [["a","a","c","c"],["b","b","b","c"],["a","a","b","a"],["c","a","a","c"],["a","a","b","a"]]
# ' +
#   '"abaca"
#   ✘ Answer: 0
#   ✘ Expected Answer: 1
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/3532.path-existence-queries-in-a-graph-i.kt
# - Downloading path-existence-queries-in-a-graph-i
#   ✔ Accepted
#   ✔ 550/550 cases passed (13 ms)
#   ✔ Your runtime beats 46.89 % of kotlin submissions
#   ✔ Your memory usage beats 42.49 % of kotlin submissions (110.9 MB)
# Submitting: kotlin_solutions_1/3533.concatenated-divisibility.kt
# - Downloading concatenated-divisibility
#   ✔ Accepted
#   ✔ 622/622 cases passed (220 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (64.8 MB)
# Submitting: kotlin_solutions_1/3536.maximum-product-of-two-digits.kt
# - Downloading maximum-product-of-two-digits
#   ✔ Accepted
#   ✔ 1088/1088 cases passed (21 ms)
#   ✔ Your runtime beats 9.68 % of kotlin submissions
#   ✔ Your memory usage beats 6.74 % of kotlin submissions (46.2 MB)
# Submitting: kotlin_solutions_1/3537.fill-a-special-grid.kt
# - Downloading fill-a-special-grid
# [ERROR] session expired, please login again [code=-1]
# Submitting: kotlin_solutions_1/3538.merge-operations-for-minimum-travel-time.kt
# - Downloading merge-operations-for-minimum-travel-time
#   ✔ Accepted
#   ✔ 997/997 cases passed (77 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (49.6 MB)
# Submitting: kotlin_solutions_1/3541.find-most-frequent-vowel-and-consonant.kt
# - Downloading find-most-frequent-vowel-and-consonant
#   ✔ Accepted
#   ✔ 812/812 cases passed (22 ms)
#   ✔ Your runtime beats 36.84 % of kotlin submissions
#   ✔ Your memory usage beats 31.58 % of kotlin submissions (47.1 MB)
# Submitting: kotlin_solutions_1/3542.minimum-operations-to-convert-all-elements-to-zero.kt
# - Downloading minimum-operations-to-convert-all-elements-to-zero
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 197: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
#   ✘ Error: Line 2: Char 197: WARNING: Parameter 'it: Int' is never used, could be renamed to '_'.
# Line 2: Char 222: ERROR: Argument type mismatch: actual type is 'kotlin.Int', but 'kotlin.Pair<java.util.ArrayDeque<kotlin.Int!>, kotlin.Int>' was expected.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/3543.maximum-weighted-k-edge-path.kt
# - Downloading maximum-weighted-k-edge-path
#   ✔ Accepted
#   ✔ 959/959 cases passed (258 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3545.minimum-deletions-for-at-most-k-distinct-characters.kt
# - Downloading minimum-deletions-for-at-most-k-distinct-characters
#   ✔ Accepted
#   ✔ 936/936 cases passed (34 ms)
#   ✔ Your runtime beats 12.5 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (47.7 MB)
# Submitting: kotlin_solutions_1/3546.equal-sum-grid-partition-i.kt
# - Downloading equal-sum-grid-partition-i
#   ✘ Compile Error
#   ✘ 0/0 cases passed (N/A)
#   ✘ Error: Line 2: Char 170: ERROR: None of the following candidates is applicable:
#   ✘ Error: Line 2: Char 170: ERROR: None of the following candidates is applicable:
# fun <T> Array<out T>.dropLast(n: Int): List<T>
# fun ByteArray.dropLast(n: Int): List<Byte>
# fun ShortArray.dropLast(n: Int): List<Short>
# fun IntArray.dropLast(n: Int): List<Int>
# fun LongArray.dropLast(n: Int): List<Long>
# fun FloatArray.dropLast(n: Int): List<Float>
# fun DoubleArray.dropLast(n: Int): List<Double>
# fun BooleanArray.dropLast(n: Int): List<Boolean>
# fun CharArray.dropLast(n: Int): List<Char>
# fun <T> List<T>.dropLast(n: Int): List<T>
# fun UIntArray.dropLast(n: Int): List<UInt>
# fun ULongArray.dropLast(n: Int): List<ULong>
# fun UByteArray.dropLast(n: Int): List<UByte>
# fun UShortArray.dropLast(n: Int): List<UShort>
# fun CharSequence.dropLast(n: Int): CharSequence
# fun String.dropLast(n: Int): String
# Line 2: Char 200: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 205: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 262: ERROR: Unresolved reference 'it'.
# Line 2: Char 299: ERROR: None of the following candidates is applicable:
# fun <T> Array<out T>.dropLast(n: Int): List<T>
# fun ByteArray.dropLast(n: Int): List<Byte>
# fun ShortArray.dropLast(n: Int): List<Short>
# fun IntArray.dropLast(n: Int): List<Int>
# fun LongArray.dropLast(n: Int): List<Long>
# fun FloatArray.dropLast(n: Int): List<Float>
# fun DoubleArray.dropLast(n: Int): List<Double>
# fun BooleanArray.dropLast(n: Int): List<Boolean>
# fun CharArray.dropLast(n: Int): List<Char>
# fun <T> List<T>.dropLast(n: Int): List<T>
# fun UIntArray.dropLast(n: Int): List<UInt>
# fun ULongArray.dropLast(n: Int): List<ULong>
# fun UByteArray.dropLast(n: Int): List<UByte>
# fun UShortArray.dropLast(n: Int): List<UShort>
# fun CharSequence.dropLast(n: Int): CharSequence
# fun String.dropLast(n: Int): String
# Line 2: Char 329: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 334: ERROR: Cannot infer type for this parameter. Please specify it explicitly.
# Line 2: Char 399: ERROR: Unresolved reference 'it'.
#   ✘ Testcase:
#   ✘ Answer:
#   ✘ Expected Answer:
#   ✘ Stdout:
# Submitting: kotlin_solutions_1/3547.maximum-sum-of-edge-values-in-a-graph.kt
# - Downloading maximum-sum-of-edge-values-in-a-graph
#   ✔ Accepted
#   ✔ 1837/1837 cases passed (2 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (97.2 MB)
# Submitting: kotlin_solutions_1/3550.smallest-index-with-digit-sum-equal-to-index.kt
# - Downloading smallest-index-with-digit-sum-equal-to-index
#   ✔ Accepted
#   ✔ 982/982 cases passed (16 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3551.minimum-swaps-to-sort-by-digit-sum.kt
# - Downloading minimum-swaps-to-sort-by-digit-sum
#   ✔ Accepted
#   ✔ 807/807 cases passed (457 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (83.8 MB)
# Submitting: kotlin_solutions_1/3556.sum-of-largest-prime-substrings.kt
# - Downloading sum-of-largest-prime-substrings
#   ✔ Accepted
#   ✔ 957/957 cases passed (90 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3560.find-minimum-log-transportation-cost.kt
# - Downloading find-minimum-log-transportation-cost
#   ✔ Accepted
#   ✔ 740/740 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions_1/3561.resulting-string-after-adjacent-removals.kt
# - Downloading resulting-string-after-adjacent-removals
# [ERROR] session expired, please login again [code=-1]
# Submitting: kotlin_solutions_1/3566.partition-array-into-two-equal-product-subsets.kt
# - Downloading partition-array-into-two-equal-product-subsets
#   ✔ Accepted
#   ✔ 721/721 cases passed (26 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions_1/3567.minimum-absolute-difference-in-sliding-submatrix.kt
# - Downloading minimum-absolute-difference-in-sliding-submatrix
#   ✔ Accepted
#   ✔ 723/723 cases passed (87 ms)
# [WARN] Failed to get runtime percentile.

# %%
# %%bash
#
# # top 500-600 answers (6th batch)
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v kotlin_solutions/*.kt | sed -n '501,505p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 7
# done
# Out:
# Submitting: kotlin_solutions/668.kth-smallest-number-in-multiplication-table.kt
#   ✔ Accepted
#   ✔ 71/71 cases passed (29 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/669.trim-a-binary-search-tree.kt
#   ✔ Accepted
#   ✔ 78/78 cases passed (11 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/670.maximum-swap.kt
#   ✔ Accepted
#   ✔ 112/112 cases passed (20 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (45.6 MB)
# Submitting: kotlin_solutions/671.second-minimum-node-in-a-binary-tree.kt
#   ✔ Accepted
#   ✔ 39/39 cases passed (29 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/672.bulb-switcher-ii.kt
#   ✔ Accepted
#   ✔ 80/80 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (40.7 MB)

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-08-17 19:28:46
