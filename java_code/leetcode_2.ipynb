# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME_2')
    user_cookie = userdata.get('LEETCODE_TOKEN_2')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME_2'] = user_name
    os.environ['LEETCODE_TOKEN_2'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME_2" "$LEETCODE_TOKEN_2" | leetcode user -c

# %%
# %%bash
#
#
# # top 100 answers
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v java_solutions/*.java | sed -n '151,300p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 8
# done
# Out:
# Submitting: java_solutions/171.excel-sheet-column-number.java
# - Downloading problems
# - Downloading excel-sheet-column-number
#   ✔ Accepted
#   ✔ 1002/1002 cases passed (4 ms)
#   ✔ Your runtime beats 1.43 % of java submissions
#   ✔ Your memory usage beats 5.95 % of java submissions (44 MB)
# Submitting: java_solutions/172.factorial-trailing-zeroes.java
# - Downloading factorial-trailing-zeroes
#   ✔ Accepted
#   ✔ 500/500 cases passed (6 ms)
#   ✔ Your runtime beats 2.36 % of java submissions
#   ✔ Your memory usage beats 16.39 % of java submissions (42.6 MB)
# Submitting: java_solutions/174.dungeon-game.java
# - Downloading dungeon-game
#   ✔ Accepted
#   ✔ 45/45 cases passed (5 ms)
#   ✔ Your runtime beats 4.27 % of java submissions
#   ✔ Your memory usage beats 36.53 % of java submissions (45.3 MB)
# Submitting: java_solutions/179.largest-number.java
# - Downloading largest-number
#   ✔ Accepted
#   ✔ 236/236 cases passed (13 ms)
#   ✔ Your runtime beats 6.18 % of java submissions
#   ✔ Your memory usage beats 8.73 % of java submissions (45.9 MB)
# Submitting: java_solutions/187.repeated-dna-sequences.java
# - Downloading repeated-dna-sequences
#   ✔ Accepted
#   ✔ 32/32 cases passed (42 ms)
#   ✔ Your runtime beats 5.47 % of java submissions
#   ✔ Your memory usage beats 5.11 % of java submissions (63.6 MB)
# Submitting: java_solutions/188.best-time-to-buy-and-sell-stock-iv.java
# - Downloading best-time-to-buy-and-sell-stock-iv
#   ✔ Accepted
#   ✔ 211/211 cases passed (5 ms)
#   ✔ Your runtime beats 41.84 % of java submissions
#   ✔ Your memory usage beats 93.86 % of java submissions (43.1 MB)
# Submitting: java_solutions/189.rotate-array.java
# - Downloading rotate-array
#   ✔ Accepted
#   ✔ 40/40 cases passed (7 ms)
#   ✔ Your runtime beats 3.76 % of java submissions
#   ✔ Your memory usage beats 7.93 % of java submissions (63.3 MB)
# Submitting: java_solutions/190.reverse-bits.java
# - Downloading reverse-bits
#   ✔ Accepted
#   ✔ 600/600 cases passed (4 ms)
#   ✔ Your runtime beats 6.66 % of java submissions
#   ✔ Your memory usage beats 8.86 % of java submissions (42.7 MB)
# Submitting: java_solutions/191.number-of-1-bits.java
# - Downloading number-of-1-bits
#   ✔ Accepted
#   ✔ 598/598 cases passed (11 ms)
#   ✔ Your runtime beats 1.73 % of java submissions
#   ✔ Your memory usage beats 12.25 % of java submissions (44.3 MB)
# Submitting: java_solutions/198.house-robber.java
# - Downloading house-robber
#   ✔ Accepted
#   ✔ 70/70 cases passed (3 ms)
#   ✔ Your runtime beats 0.64 % of java submissions
#   ✔ Your memory usage beats 5.78 % of java submissions (43.1 MB)
# Submitting: java_solutions/199.binary-tree-right-side-view.java
# - Downloading binary-tree-right-side-view
#   ✔ Accepted
#   ✔ 217/217 cases passed (10 ms)
#   ✔ Your runtime beats 0.56 % of java submissions
#   ✔ Your memory usage beats 13.97 % of java submissions (44.5 MB)
# Submitting: java_solutions/200.number-of-islands.java
# - Downloading number-of-islands
#   ✔ Accepted
#   ✔ 49/49 cases passed (66 ms)
#   ✔ Your runtime beats 5.05 % of java submissions
#   ✔ Your memory usage beats 11.47 % of java submissions (53 MB)
# Submitting: java_solutions/201.bitwise-and-of-numbers-range.java
# - Downloading bitwise-and-of-numbers-range
#   ✔ Accepted
#   ✔ 8272/8272 cases passed (3 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 57.89 % of java submissions (45.9 MB)
# Submitting: java_solutions/202.happy-number.java
# - Downloading happy-number
#   ✔ Accepted
#   ✔ 420/420 cases passed (12 ms)
#   ✔ Your runtime beats 2.38 % of java submissions
#   ✔ Your memory usage beats 5.84 % of java submissions (44.6 MB)
# Submitting: java_solutions/203.remove-linked-list-elements.java
# - Downloading remove-linked-list-elements
#   ✔ Accepted
#   ✔ 66/66 cases passed (1 ms)
#   ✔ Your runtime beats 95.52 % of java submissions
#   ✔ Your memory usage beats 7.83 % of java submissions (48.5 MB)
# Submitting: java_solutions/204.count-primes.java
# - Downloading count-primes
#   ✔ Accepted
#   ✔ 66/66 cases passed (596 ms)
#   ✔ Your runtime beats 5.06 % of java submissions
#   ✔ Your memory usage beats 98.97 % of java submissions (46.2 MB)
# Submitting: java_solutions/205.isomorphic-strings.java
# - Downloading isomorphic-strings
#   ✔ Accepted
#   ✔ 47/47 cases passed (10 ms)
#   ✔ Your runtime beats 68.48 % of java submissions
#   ✔ Your memory usage beats 16.02 % of java submissions (44.2 MB)
# Submitting: java_solutions/206.reverse-linked-list.java
# - Downloading reverse-linked-list
#   ✔ Accepted
#   ✔ 28/28 cases passed (6 ms)
#   ✔ Your runtime beats 0.53 % of java submissions
#   ✔ Your memory usage beats 13.99 % of java submissions (45.2 MB)
# Submitting: java_solutions/209.minimum-size-subarray-sum.java
# - Downloading minimum-size-subarray-sum
#   ✔ Accepted
#   ✔ 21/21 cases passed (17 ms)
#   ✔ Your runtime beats 3.26 % of java submissions
#   ✔ Your memory usage beats 15.01 % of java submissions (63.1 MB)
# Submitting: java_solutions/212.word-search-ii.java
# - Downloading word-search-ii
#   ✔ Accepted
#   ✔ 65/65 cases passed (1396 ms)
#   ✔ Your runtime beats 5.02 % of java submissions
#   ✔ Your memory usage beats 8.36 % of java submissions (50.6 MB)
# Submitting: java_solutions/213.house-robber-ii.java
# - Downloading house-robber-ii
#   ✔ Accepted
#   ✔ 75/75 cases passed (4 ms)
#   ✔ Your runtime beats 1.07 % of java submissions
#   ✔ Your memory usage beats 8.88 % of java submissions (43.5 MB)
# Submitting: java_solutions/214.shortest-palindrome.java
# - Downloading shortest-palindrome
#   ✔ Accepted
#   ✔ 126/126 cases passed (11 ms)
#   ✔ Your runtime beats 12.68 % of java submissions
#   ✔ Your memory usage beats 7.95 % of java submissions (47.4 MB)
# Submitting: java_solutions/215.kth-largest-element-in-an-array.java
# - Downloading kth-largest-element-in-an-array
#   ✔ Accepted
#   ✔ 45/45 cases passed (127 ms)
#   ✔ Your runtime beats 5.01 % of java submissions
#   ✔ Your memory usage beats 6.75 % of java submissions (70.6 MB)
# Submitting: java_solutions/216.combination-sum-iii.java
# - Downloading combination-sum-iii
#   ✔ Accepted
#   ✔ 19/19 cases passed (14 ms)
#   ✔ Your runtime beats 1.85 % of java submissions
#   ✔ Your memory usage beats 5.36 % of java submissions (48.4 MB)
# Submitting: java_solutions/217.contains-duplicate.java
# - Downloading contains-duplicate
#   ✔ Accepted
#   ✔ 77/77 cases passed (27 ms)
#   ✔ Your runtime beats 5.36 % of java submissions
#   ✔ Your memory usage beats 76.98 % of java submissions (80.7 MB)
# Submitting: java_solutions/218.the-skyline-problem.java
# - Downloading the-skyline-problem
#   ✔ Accepted
#   ✔ 44/44 cases passed (42 ms)
#   ✔ Your runtime beats 57.32 % of java submissions
#   ✔ Your memory usage beats 57.85 % of java submissions (54 MB)
# Submitting: java_solutions/219.contains-duplicate-ii.java
# - Downloading contains-duplicate-ii
#   ✔ Accepted
#   ✔ 65/65 cases passed (42 ms)
#   ✔ Your runtime beats 11.1 % of java submissions
#   ✔ Your memory usage beats 9.31 % of java submissions (93.8 MB)
# Submitting: java_solutions/220.contains-duplicate-iii.java
# - Downloading contains-duplicate-iii
#   ✔ Accepted
#   ✔ 56/56 cases passed (142 ms)
#   ✔ Your runtime beats 39.91 % of java submissions
#   ✔ Your memory usage beats 6.63 % of java submissions (127.9 MB)
# Submitting: java_solutions/222.count-complete-tree-nodes.java
# - Downloading count-complete-tree-nodes
#   ✔ Accepted
#   ✔ 18/18 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 66.82 % of java submissions (49.4 MB)
# Submitting: java_solutions/224.basic-calculator.java
# - Downloading basic-calculator
#   ✔ Accepted
#   ✔ 49/49 cases passed (19 ms)
#   ✔ Your runtime beats 8.1 % of java submissions
#   ✔ Your memory usage beats 6.48 % of java submissions (48.2 MB)
# Submitting: java_solutions/226.invert-binary-tree.java
# - Downloading invert-binary-tree
#   ✔ Accepted
#   ✔ 77/77 cases passed (7 ms)
#   ✔ Your runtime beats 0.08 % of java submissions
#   ✔ Your memory usage beats 11.01 % of java submissions (43.8 MB)
# Submitting: java_solutions/228.summary-ranges.java
# - Downloading summary-ranges
#   ✔ Accepted
#   ✔ 34/34 cases passed (8 ms)
#   ✔ Your runtime beats 1.22 % of java submissions
#   ✔ Your memory usage beats 5.24 % of java submissions (48.8 MB)
# Submitting: java_solutions/229.majority-element-ii.java
# - Downloading majority-element-ii
#   ✔ Accepted
#   ✔ 95/95 cases passed (16 ms)
#   ✔ Your runtime beats 21.63 % of java submissions
#   ✔ Your memory usage beats 78.44 % of java submissions (52.2 MB)
# Submitting: java_solutions/230.kth-smallest-element-in-a-bst.java
# - Downloading kth-smallest-element-in-a-bst
#   ✔ Accepted
#   ✔ 93/93 cases passed (11 ms)
#   ✔ Your runtime beats 3.04 % of java submissions
#   ✔ Your memory usage beats 17.25 % of java submissions (47 MB)
# Submitting: java_solutions/231.power-of-two.java
# - Downloading power-of-two
#   ✔ Accepted
#   ✔ 1110/1110 cases passed (1 ms)
#   ✔ Your runtime beats 96.66 % of java submissions
#   ✔ Your memory usage beats 93.48 % of java submissions (42.3 MB)
# Submitting: java_solutions/232.implement-queue-using-stacks.java
# - Downloading implement-queue-using-stacks
#   ✔ Accepted
#   ✔ 22/22 cases passed (3 ms)
#   ✔ Your runtime beats 0.05 % of java submissions
#   ✔ Your memory usage beats 38.98 % of java submissions (42.7 MB)
# Submitting: java_solutions/233.number-of-digit-one.java
# - Downloading number-of-digit-one
#   ✔ Accepted
#   ✔ 38/38 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 53.54 % of java submissions (42.1 MB)
# Submitting: java_solutions/234.palindrome-linked-list.java
# - Downloading palindrome-linked-list
#   ✔ Accepted
#   ✔ 93/93 cases passed (30 ms)
#   ✔ Your runtime beats 5.8 % of java submissions
#   ✔ Your memory usage beats 15.57 % of java submissions (100 MB)
# Submitting: java_solutions/235.lowest-common-ancestor-of-a-binary-search-tree.java
# - Downloading lowest-common-ancestor-of-a-binary-search-tree
#   ✔ Accepted
#   ✔ 30/30 cases passed (6 ms)
#   ✔ Your runtime beats 97.3 % of java submissions
#   ✔ Your memory usage beats 54.76 % of java submissions (47.7 MB)
# Submitting: java_solutions/237.delete-node-in-a-linked-list.java
# - Downloading delete-node-in-a-linked-list
#   ✔ Accepted
#   ✔ 41/41 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 61.28 % of java submissions (45.2 MB)
# Submitting: java_solutions/238.product-of-array-except-self.java
# - Downloading product-of-array-except-self
#   ✔ Accepted
#   ✔ 24/24 cases passed (17 ms)
#   ✔ Your runtime beats 3.5 % of java submissions
#   ✔ Your memory usage beats 64.81 % of java submissions (71.2 MB)
# Submitting: java_solutions/239.sliding-window-maximum.java
# - Downloading sliding-window-maximum
#   ✔ Accepted
#   ✔ 52/52 cases passed (39 ms)
#   ✔ Your runtime beats 18.34 % of java submissions
#   ✔ Your memory usage beats 42.88 % of java submissions (147.6 MB)
# Submitting: java_solutions/240.search-a-2d-matrix-ii.java
# - Downloading search-a-2d-matrix-ii
#   ✔ Accepted
#   ✔ 130/130 cases passed (194 ms)
#   ✔ Your runtime beats 7.14 % of java submissions
#   ✔ Your memory usage beats 10.2 % of java submissions (59.3 MB)
# Submitting: java_solutions/241.different-ways-to-add-parentheses.java
# - Downloading different-ways-to-add-parentheses
#   ✔ Accepted
#   ✔ 25/25 cases passed (23 ms)
#   ✔ Your runtime beats 3.38 % of java submissions
#   ✔ Your memory usage beats 5.29 % of java submissions (52.8 MB)
# Submitting: java_solutions/242.valid-anagram.java
# - Downloading valid-anagram
#   ✔ Accepted
#   ✔ 54/54 cases passed (21 ms)
#   ✔ Your runtime beats 8.12 % of java submissions
#   ✔ Your memory usage beats 23.85 % of java submissions (46.6 MB)
# Submitting: java_solutions/257.binary-tree-paths.java
# - Downloading binary-tree-paths
#   ✔ Accepted
#   ✔ 208/208 cases passed (12 ms)
#   ✔ Your runtime beats 10.23 % of java submissions
#   ✔ Your memory usage beats 9.3 % of java submissions (50.8 MB)
# Submitting: java_solutions/258.add-digits.java
# - Downloading add-digits
#   ✔ Accepted
#   ✔ 1101/1101 cases passed (5 ms)
#   ✔ Your runtime beats 0.82 % of java submissions
#   ✔ Your memory usage beats 9.88 % of java submissions (43.6 MB)
# Submitting: java_solutions/260.single-number-iii.java
# - Downloading single-number-iii
#   ✔ Accepted
#   ✔ 35/35 cases passed (5 ms)
#   ✔ Your runtime beats 34.76 % of java submissions
#   ✔ Your memory usage beats 40.67 % of java submissions (48.1 MB)
# Submitting: java_solutions/263.ugly-number.java
# - Downloading ugly-number
#   ✔ Accepted
#   ✔ 1013/1013 cases passed (1 ms)
#   ✔ Your runtime beats 99.49 % of java submissions
#   ✔ Your memory usage beats 33.49 % of java submissions (42.7 MB)
# Submitting: java_solutions/268.missing-number.java
# - Downloading missing-number
#   ✔ Accepted
#   ✔ 122/122 cases passed (2 ms)
#   ✔ Your runtime beats 22.08 % of java submissions
#   ✔ Your memory usage beats 19.9 % of java submissions (47.6 MB)
# Submitting: java_solutions/273.integer-to-english-words.java
# - Downloading integer-to-english-words
#   ✔ Accepted
#   ✔ 601/601 cases passed (16 ms)
#   ✔ Your runtime beats 5.7 % of java submissions
#   ✔ Your memory usage beats 7.85 % of java submissions (50.4 MB)
# Submitting: java_solutions/274.h-index.java
# - Downloading h-index
#   ✔ Accepted
#   ✔ 83/83 cases passed (14 ms)
#   ✔ Your runtime beats 5.64 % of java submissions
#   ✔ Your memory usage beats 6.15 % of java submissions (43.9 MB)
# Submitting: java_solutions/275.h-index-ii.java
# - Downloading h-index-ii
#   ✔ Accepted
#   ✔ 83/83 cases passed (20 ms)
#   ✔ Your runtime beats 5.06 % of java submissions
#   ✔ Your memory usage beats 11.98 % of java submissions (50.9 MB)
# Submitting: java_solutions/278.first-bad-version.java
# - Downloading first-bad-version
#   ✔ Accepted
#   ✔ 24/24 cases passed (15 ms)
#   ✔ Your runtime beats 13.02 % of java submissions
#   ✔ Your memory usage beats 71.4 % of java submissions (42 MB)
# Submitting: java_solutions/279.perfect-squares.java
# - Downloading perfect-squares
#   ✔ Accepted
#   ✔ 589/589 cases passed (10 ms)
#   ✔ Your runtime beats 92.62 % of java submissions
#   ✔ Your memory usage beats 93.79 % of java submissions (42.8 MB)
# Submitting: java_solutions/282.expression-add-operators.java
# - Downloading expression-add-operators
#   ✔ Accepted
#   ✔ 25/25 cases passed (241 ms)
#   ✔ Your runtime beats 5.15 % of java submissions
#   ✔ Your memory usage beats 8.59 % of java submissions (53.4 MB)
# Submitting: java_solutions/283.move-zeroes.java
# - Downloading move-zeroes
#   ✔ Accepted
#   ✔ 75/75 cases passed (10 ms)
#   ✔ Your runtime beats 7.5 % of java submissions
#   ✔ Your memory usage beats 6.84 % of java submissions (48.6 MB)
# Submitting: java_solutions/284.peeking-iterator.java
# - Downloading peeking-iterator
#   ✔ Accepted
#   ✔ 15/15 cases passed (5 ms)
#   ✔ Your runtime beats 3.56 % of java submissions
#   ✔ Your memory usage beats 46.44 % of java submissions (43.6 MB)
# Submitting: java_solutions/287.find-the-duplicate-number.java
# - Downloading find-the-duplicate-number
#   ✔ Accepted
#   ✔ 59/59 cases passed (7 ms)
#   ✔ Your runtime beats 41.55 % of java submissions
#   ✔ Your memory usage beats 57.38 % of java submissions (82.9 MB)
# Submitting: java_solutions/290.word-pattern.java
# - Downloading word-pattern
#   ✔ Accepted
#   ✔ 44/44 cases passed (9 ms)
#   ✔ Your runtime beats 1.57 % of java submissions
#   ✔ Your memory usage beats 5.92 % of java submissions (43.6 MB)
# Submitting: java_solutions/292.nim-game.java
# - Downloading nim-game
#   ✔ Accepted
#   ✔ 60/60 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 35.3 % of java submissions (42.1 MB)
# Submitting: java_solutions/295.find-median-from-data-stream.java
# - Downloading find-median-from-data-stream
#   ✔ Accepted
#   ✔ 22/22 cases passed (176 ms)
#   ✔ Your runtime beats 37.33 % of java submissions
#   ✔ Your memory usage beats 5.14 % of java submissions (116 MB)
# Submitting: java_solutions/297.serialize-and-deserialize-binary-tree.java
# - Downloading serialize-and-deserialize-binary-tree
#   ✔ Accepted
#   ✔ 53/53 cases passed (24 ms)
#   ✔ Your runtime beats 9.9 % of java submissions
#   ✔ Your memory usage beats 64.95 % of java submissions (47.8 MB)
# Submitting: java_solutions/300.longest-increasing-subsequence.java
# - Downloading longest-increasing-subsequence
#   ✔ Accepted
#   ✔ 56/56 cases passed (11 ms)
#   ✔ Your runtime beats 74.58 % of java submissions
#   ✔ Your memory usage beats 22.19 % of java submissions (46.7 MB)
# Submitting: java_solutions/301.remove-invalid-parentheses.java
# - Downloading remove-invalid-parentheses
#   ✔ Accepted
#   ✔ 129/129 cases passed (63 ms)
#   ✔ Your runtime beats 29.5 % of java submissions
#   ✔ Your memory usage beats 9.62 % of java submissions (48.6 MB)
# Submitting: java_solutions/303.range-sum-query-immutable.java
# - Downloading range-sum-query-immutable
#   ✔ Accepted
#   ✔ 15/15 cases passed (154 ms)
#   ✔ Your runtime beats 5.07 % of java submissions
#   ✔ Your memory usage beats 5 % of java submissions (51.2 MB)
# Submitting: java_solutions/312.burst-balloons.java
# - Downloading burst-balloons
#   ✔ Accepted
#   ✔ 73/73 cases passed (116 ms)
#   ✔ Your runtime beats 23.59 % of java submissions
#   ✔ Your memory usage beats 11.32 % of java submissions (44.8 MB)
# Submitting: java_solutions/315.count-of-smaller-numbers-after-self.java
# - Downloading count-of-smaller-numbers-after-self
#   ✔ Accepted
#   ✔ 66/66 cases passed (103 ms)
#   ✔ Your runtime beats 45.28 % of java submissions
#   ✔ Your memory usage beats 43.58 % of java submissions (104.7 MB)
# Submitting: java_solutions/318.maximum-product-of-word-lengths.java
# - Downloading maximum-product-of-word-lengths
#   ✔ Accepted
#   ✔ 168/168 cases passed (63 ms)
#   ✔ Your runtime beats 26.45 % of java submissions
#   ✔ Your memory usage beats 74.04 % of java submissions (49.1 MB)
# Submitting: java_solutions/319.bulb-switcher.java
# - Downloading bulb-switcher
#   ✔ Accepted
#   ✔ 35/35 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 68.81 % of java submissions (42 MB)
# Submitting: java_solutions/321.create-maximum-number.java
# - Downloading create-maximum-number
#   ✔ Accepted
#   ✔ 102/102 cases passed (20 ms)
#   ✔ Your runtime beats 10.65 % of java submissions
#   ✔ Your memory usage beats 97.69 % of java submissions (46 MB)
# Submitting: java_solutions/326.power-of-three.java
# - Downloading power-of-three
#   ✔ Accepted
#   ✔ 21040/21040 cases passed (9 ms)
#   ✔ Your runtime beats 7.3 % of java submissions
#   ✔ Your memory usage beats 92.11 % of java submissions (45.7 MB)
# Submitting: java_solutions/327.count-of-range-sum.java
# - Downloading count-of-range-sum
#   ✔ Accepted
#   ✔ 67/67 cases passed (236 ms)
#   ✔ Your runtime beats 17.97 % of java submissions
#   ✔ Your memory usage beats 15.86 % of java submissions (106.5 MB)
# Submitting: java_solutions/328.odd-even-linked-list.java
# - Downloading odd-even-linked-list
#   ✔ Accepted
#   ✔ 70/70 cases passed (17 ms)
#   ✔ Your runtime beats 0.97 % of java submissions
#   ✔ Your memory usage beats 16.67 % of java submissions (52.9 MB)
# Submitting: java_solutions/329.longest-increasing-path-in-a-matrix.java
# - Downloading longest-increasing-path-in-a-matrix
#   ✔ Accepted
#   ✔ 139/139 cases passed (50 ms)
#   ✔ Your runtime beats 7.61 % of java submissions
#   ✔ Your memory usage beats 17.36 % of java submissions (47.4 MB)
# Submitting: java_solutions/330.patching-array.java
# - Downloading patching-array
#   ✔ Accepted
#   ✔ 150/150 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 12.9 % of java submissions (45.7 MB)
# Submitting: java_solutions/331.verify-preorder-serialization-of-a-binary-tree.java
# - Downloading verify-preorder-serialization-of-a-binary-tree
#   ✔ Accepted
#   ✔ 152/152 cases passed (6 ms)
#   ✔ Your runtime beats 21.72 % of java submissions
#   ✔ Your memory usage beats 27.34 % of java submissions (45.1 MB)
# Submitting: java_solutions/332.reconstruct-itinerary.java
# - Downloading reconstruct-itinerary
#   ✔ Accepted
#   ✔ 82/82 cases passed (11 ms)
#   ✔ Your runtime beats 8.76 % of java submissions
#   ✔ Your memory usage beats 13.53 % of java submissions (47.5 MB)
# Submitting: java_solutions/334.increasing-triplet-subsequence.java
# - Downloading increasing-triplet-subsequence
#   ✔ Accepted
#   ✔ 86/86 cases passed (18 ms)
#   ✔ Your runtime beats 5 % of java submissions
#   ✔ Your memory usage beats 5.71 % of java submissions (128.2 MB)
# Submitting: java_solutions/335.self-crossing.java
# - Downloading self-crossing
#   ✔ Accepted
#   ✔ 31/31 cases passed (10 ms)
#   ✔ Your runtime beats 23.42 % of java submissions
#   ✔ Your memory usage beats 65.99 % of java submissions (59.3 MB)
# Submitting: java_solutions/336.palindrome-pairs.java
# - Downloading palindrome-pairs
#   ✔ Accepted
#   ✔ 136/136 cases passed (2604 ms)
#   ✔ Your runtime beats 5.37 % of java submissions
#   ✔ Your memory usage beats 16.98 % of java submissions (65.5 MB)
# Submitting: java_solutions/338.counting-bits.java
# - Downloading counting-bits
#   ✔ Accepted
#   ✔ 15/15 cases passed (29 ms)
#   ✔ Your runtime beats 8.73 % of java submissions
#   ✔ Your memory usage beats 30.74 % of java submissions (48.7 MB)
# Submitting: java_solutions/341.flatten-nested-list-iterator.java
# - Downloading flatten-nested-list-iterator
#   ✔ Accepted
#   ✔ 43/43 cases passed (10 ms)
#   ✔ Your runtime beats 4.66 % of java submissions
#   ✔ Your memory usage beats 88.07 % of java submissions (48 MB)
# Submitting: java_solutions/342.power-of-four.java
# - Downloading power-of-four
#   ✔ Accepted
#   ✔ 1063/1063 cases passed (1 ms)
#   ✔ Your runtime beats 91.54 % of java submissions
#   ✔ Your memory usage beats 32.61 % of java submissions (42.7 MB)
# Submitting: java_solutions/343.integer-break.java
# - Downloading integer-break
#   ✔ Accepted
#   ✔ 50/50 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 56.83 % of java submissions (42.1 MB)
# Submitting: java_solutions/344.reverse-string.java
# - Downloading reverse-string
#   ✔ Accepted
#   ✔ 477/477 cases passed (3 ms)
#   ✔ Your runtime beats 5.71 % of java submissions
#   ✔ Your memory usage beats 55.03 % of java submissions (48.3 MB)
# Submitting: java_solutions/345.reverse-vowels-of-a-string.java
# - Downloading reverse-vowels-of-a-string
#   ✔ Accepted
#   ✔ 480/480 cases passed (23 ms)
#   ✔ Your runtime beats 6.74 % of java submissions
#   ✔ Your memory usage beats 11.03 % of java submissions (47.4 MB)
# Submitting: java_solutions/347.top-k-frequent-elements.java
# - Downloading top-k-frequent-elements
#   ✔ Accepted
#   ✔ 23/23 cases passed (23 ms)
#   ✔ Your runtime beats 5.74 % of java submissions
#   ✔ Your memory usage beats 5.03 % of java submissions (56.6 MB)
# Submitting: java_solutions/349.intersection-of-two-arrays.java
# - Downloading intersection-of-two-arrays
#   ✔ Accepted
#   ✔ 57/57 cases passed (91 ms)
#   ✔ Your runtime beats 9.12 % of java submissions
#   ✔ Your memory usage beats 6.36 % of java submissions (47.2 MB)
# Submitting: java_solutions/350.intersection-of-two-arrays-ii.java
# - Downloading intersection-of-two-arrays-ii
#   ✔ Accepted
#   ✔ 61/61 cases passed (60 ms)
#   ✔ Your runtime beats 5.45 % of java submissions
#   ✔ Your memory usage beats 11.19 % of java submissions (47 MB)
# Submitting: java_solutions/352.data-stream-as-disjoint-intervals.java
# - Downloading data-stream-as-disjoint-intervals
#   ✔ Accepted
#   ✔ 8/8 cases passed (25 ms)
#   ✔ Your runtime beats 14.58 % of java submissions
#   ✔ Your memory usage beats 20.74 % of java submissions (45.5 MB)
# Submitting: java_solutions/354.russian-doll-envelopes.java
# - Downloading russian-doll-envelopes
#   ✔ Accepted
#   ✔ 87/87 cases passed (53 ms)
#   ✔ Your runtime beats 21.23 % of java submissions
#   ✔ Your memory usage beats 16.72 % of java submissions (104.2 MB)
# Submitting: java_solutions/355.design-twitter.java
# - Downloading design-twitter
#   ✔ Accepted
#   ✔ 20/20 cases passed (60 ms)
#   ✔ Your runtime beats 5.17 % of java submissions
#   ✔ Your memory usage beats 13 % of java submissions (57 MB)
# Submitting: java_solutions/357.count-numbers-with-unique-digits.java
# - Downloading count-numbers-with-unique-digits
#   ✔ Accepted
#   ✔ 9/9 cases passed (2 ms)
#   ✔ Your runtime beats 17.96 % of java submissions
#   ✔ Your memory usage beats 11.08 % of java submissions (42.5 MB)
# Submitting: java_solutions/363.max-sum-of-rectangle-no-larger-than-k.java
# - Downloading max-sum-of-rectangle-no-larger-than-k
#   ✔ Accepted
#   ✔ 36/36 cases passed (375 ms)
#   ✔ Your runtime beats 12.23 % of java submissions
#   ✔ Your memory usage beats 12.9 % of java submissions (47.4 MB)
# Submitting: java_solutions/365.water-and-jug-problem.java
# - Downloading water-and-jug-problem
#   ✔ Accepted
#   ✔ 32/32 cases passed (2 ms)
#   ✔ Your runtime beats 20.38 % of java submissions
#   ✔ Your memory usage beats 48.6 % of java submissions (42.2 MB)
# Submitting: java_solutions/367.valid-perfect-square.java
# - Downloading valid-perfect-square
#   ✔ Accepted
#   ✔ 72/72 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 5.57 % of java submissions (42.4 MB)
# Submitting: java_solutions/371.sum-of-two-integers.java
# - Downloading sum-of-two-integers
#   ✔ Accepted
#   ✔ 31/31 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 32.6 % of java submissions (42.1 MB)
# Submitting: java_solutions/372.super-pow.java
# - Downloading super-pow
#   ✔ Accepted
#   ✔ 57/57 cases passed (46 ms)
#   ✔ Your runtime beats 5.26 % of java submissions
#   ✔ Your memory usage beats 5.6 % of java submissions (47.5 MB)
# Submitting: java_solutions/374.guess-number-higher-or-lower.java
# - Downloading guess-number-higher-or-lower
#   ✔ Accepted
#   ✔ 25/25 cases passed (4 ms)
#   ✔ Your runtime beats 0.81 % of java submissions
#   ✔ Your memory usage beats 16.43 % of java submissions (42.7 MB)
# Submitting: java_solutions/381.insert-delete-getrandom-o1-duplicates-allowed.java
# - Downloading insert-delete-getrandom-o1-duplicates-allowed
#   ✔ Accepted
#   ✔ 32/32 cases passed (47 ms)
#   ✔ Your runtime beats 5.18 % of java submissions
#   ✔ Your memory usage beats 6.66 % of java submissions (100.8 MB)
# Submitting: java_solutions/383.ransom-note.java
# - Downloading ransom-note
#   ✔ Accepted
#   ✔ 130/130 cases passed (13 ms)
#   ✔ Your runtime beats 39.74 % of java submissions
#   ✔ Your memory usage beats 44.25 % of java submissions (46.7 MB)
# Submitting: java_solutions/386.lexicographical-numbers.java
# - Downloading lexicographical-numbers
#   ✔ Accepted
#   ✔ 27/27 cases passed (38 ms)
#   ✔ Your runtime beats 5.13 % of java submissions
#   ✔ Your memory usage beats 5.05 % of java submissions (55 MB)
# Submitting: java_solutions/387.first-unique-character-in-a-string.java
# - Downloading first-unique-character-in-a-string
#   ✔ Accepted
#   ✔ 107/107 cases passed (83 ms)
#   ✔ Your runtime beats 5.01 % of java submissions
#   ✔ Your memory usage beats 6.47 % of java submissions (52.9 MB)
# Submitting: java_solutions/389.find-the-difference.java
# - Downloading find-the-difference
#   ✔ Accepted
#   ✔ 54/54 cases passed (4 ms)
#   ✔ Your runtime beats 18.31 % of java submissions
#   ✔ Your memory usage beats 37.34 % of java submissions (43.3 MB)
# Submitting: java_solutions/390.elimination-game.java
# - Downloading elimination-game
#   ✔ Accepted
#   ✔ 3377/3377 cases passed (2 ms)
#   ✔ Your runtime beats 91.88 % of java submissions
#   ✔ Your memory usage beats 43.14 % of java submissions (43.4 MB)
# Submitting: java_solutions/391.perfect-rectangle.java
# - Downloading perfect-rectangle
#   ✔ Accepted
#   ✔ 49/49 cases passed (54 ms)
#   ✔ Your runtime beats 7.42 % of java submissions
#   ✔ Your memory usage beats 23.5 % of java submissions (56.6 MB)
# Submitting: java_solutions/392.is-subsequence.java
# - Downloading is-subsequence
#   ✔ Accepted
#   ✔ 22/22 cases passed (4 ms)
#   ✔ Your runtime beats 3.85 % of java submissions
#   ✔ Your memory usage beats 12.6 % of java submissions (43.1 MB)
# Submitting: java_solutions/393.utf-8-validation.java
# - Downloading utf-8-validation
#   ✔ Accepted
#   ✔ 54/54 cases passed (5 ms)
#   ✔ Your runtime beats 5.41 % of java submissions
#   ✔ Your memory usage beats 43.59 % of java submissions (46.6 MB)
# Submitting: java_solutions/394.decode-string.java
# - Downloading decode-string
#   ✔ Accepted
#   ✔ 34/34 cases passed (7 ms)
#   ✔ Your runtime beats 2.63 % of java submissions
#   ✔ Your memory usage beats 8.55 % of java submissions (43.2 MB)
# Submitting: java_solutions/396.rotate-function.java
# - Downloading rotate-function
#   ✔ Accepted
#   ✔ 58/58 cases passed (46 ms)
#   ✔ Your runtime beats 10.07 % of java submissions
#   ✔ Your memory usage beats 6.64 % of java submissions (93.6 MB)
# Submitting: java_solutions/397.integer-replacement.java
# - Downloading integer-replacement
#   ✔ Accepted
#   ✔ 47/47 cases passed (2 ms)
#   ✔ Your runtime beats 14.65 % of java submissions
#   ✔ Your memory usage beats 10.93 % of java submissions (42.3 MB)
# Submitting: java_solutions/400.nth-digit.java
# - Downloading nth-digit
#   ✔ Accepted
#   ✔ 72/72 cases passed (3 ms)
#   ✔ Your runtime beats 1.56 % of java submissions
#   ✔ Your memory usage beats 6.79 % of java submissions (42.7 MB)
# Submitting: java_solutions/401.binary-watch.java
# - Downloading binary-watch
#   ✔ Accepted
#   ✔ 11/11 cases passed (11 ms)
#   ✔ Your runtime beats 9.24 % of java submissions
#   ✔ Your memory usage beats 71.52 % of java submissions (44.3 MB)
# Submitting: java_solutions/403.frog-jump.java
# - Downloading frog-jump
#   ✔ Accepted
#   ✔ 56/56 cases passed (25 ms)
#   ✔ Your runtime beats 86.66 % of java submissions
#   ✔ Your memory usage beats 37.9 % of java submissions (52.7 MB)
# Submitting: java_solutions/404.sum-of-left-leaves.java
# - Downloading sum-of-left-leaves
#   ✔ Accepted
#   ✔ 100/100 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 92.58 % of java submissions (43 MB)
# Submitting: java_solutions/405.convert-a-number-to-hexadecimal.java
# - Downloading convert-a-number-to-hexadecimal
#   ✔ Accepted
#   ✔ 100/100 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 80.1 % of java submissions (42.5 MB)
# Submitting: java_solutions/406.queue-reconstruction-by-height.java
# - Downloading queue-reconstruction-by-height
#   ✔ Accepted
#   ✔ 36/36 cases passed (13 ms)
#   ✔ Your runtime beats 8.84 % of java submissions
#   ✔ Your memory usage beats 12.77 % of java submissions (47.6 MB)
# Submitting: java_solutions/407.trapping-rain-water-ii.java
# - Downloading trapping-rain-water-ii
#   ✔ Accepted
#   ✔ 42/42 cases passed (38 ms)
#   ✔ Your runtime beats 5.19 % of java submissions
#   ✔ Your memory usage beats 6.49 % of java submissions (50.1 MB)
# Submitting: java_solutions/409.longest-palindrome.java
# - Downloading longest-palindrome
#   ✔ Accepted
#   ✔ 98/98 cases passed (19 ms)
#   ✔ Your runtime beats 7.86 % of java submissions
#   ✔ Your memory usage beats 7.28 % of java submissions (50.8 MB)
# Submitting: java_solutions/410.split-array-largest-sum.java
# - Downloading split-array-largest-sum
#   ✔ Accepted
#   ✔ 35/35 cases passed (8 ms)
#   ✔ Your runtime beats 5.1 % of java submissions
#   ✔ Your memory usage beats 70.02 % of java submissions (42.9 MB)
# Submitting: java_solutions/412.fizz-buzz.java
# - Downloading fizz-buzz
#   ✔ Accepted
#   ✔ 8/8 cases passed (2 ms)
#   ✔ Your runtime beats 20.74 % of java submissions
#   ✔ Your memory usage beats 5.2 % of java submissions (47.2 MB)
# Submitting: java_solutions/413.arithmetic-slices.java
# - Downloading arithmetic-slices
#   ✔ Accepted
#   ✔ 16/16 cases passed (3 ms)
#   ✔ Your runtime beats 3.22 % of java submissions
#   ✔ Your memory usage beats 10.11 % of java submissions (43.6 MB)
# Submitting: java_solutions/414.third-maximum-number.java
# - Downloading third-maximum-number
#   ✔ Accepted
#   ✔ 34/34 cases passed (17 ms)
#   ✔ Your runtime beats 5.18 % of java submissions
#   ✔ Your memory usage beats 6.26 % of java submissions (47.1 MB)
# Submitting: java_solutions/415.add-strings.java
# - Downloading add-strings
#   ✔ Accepted
#   ✔ 317/317 cases passed (19 ms)
#   ✔ Your runtime beats 9.02 % of java submissions
#   ✔ Your memory usage beats 11.7 % of java submissions (46 MB)
# Submitting: java_solutions/416.partition-equal-subset-sum.java
# - Downloading partition-equal-subset-sum
#   ✔ Accepted
#   ✔ 147/147 cases passed (12 ms)
#   ✔ Your runtime beats 97.8 % of java submissions
#   ✔ Your memory usage beats 67 % of java submissions (46.8 MB)
# Submitting: java_solutions/419.battleships-in-a-board.java
# - Downloading battleships-in-a-board
#   ✔ Accepted
#   ✔ 27/27 cases passed (7 ms)
#   ✔ Your runtime beats 2.8 % of java submissions
#   ✔ Your memory usage beats 8.86 % of java submissions (48.1 MB)
# Submitting: java_solutions/420.strong-password-checker.java
# - Downloading strong-password-checker
#   ✔ Accepted
#   ✔ 54/54 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 61.98 % of java submissions (42.7 MB)
# Submitting: java_solutions/421.maximum-xor-of-two-numbers-in-an-array.java
# - Downloading maximum-xor-of-two-numbers-in-an-array
#   ✔ Accepted
#   ✔ 46/46 cases passed (860 ms)
#   ✔ Your runtime beats 40.08 % of java submissions
#   ✔ Your memory usage beats 5.22 % of java submissions (246.8 MB)
# Submitting: java_solutions/423.reconstruct-original-digits-from-english.java
# - Downloading reconstruct-original-digits-from-english
#   ✔ Accepted
#   ✔ 24/24 cases passed (103 ms)
#   ✔ Your runtime beats 5.59 % of java submissions
#   ✔ Your memory usage beats 5.15 % of java submissions (53.4 MB)
# Submitting: java_solutions/424.longest-repeating-character-replacement.java
# - Downloading longest-repeating-character-replacement
#   ✔ Accepted
#   ✔ 50/50 cases passed (239 ms)
#   ✔ Your runtime beats 5.03 % of java submissions
#   ✔ Your memory usage beats 7.55 % of java submissions (53.2 MB)
# Submitting: java_solutions/429.n-ary-tree-level-order-traversal.java
# - Downloading n-ary-tree-level-order-traversal
#   ✔ Accepted
#   ✔ 38/38 cases passed (8 ms)
#   ✔ Your runtime beats 4.37 % of java submissions
#   ✔ Your memory usage beats 6.03 % of java submissions (47.6 MB)
# Submitting: java_solutions/432.all-oone-data-structure.java
# - Downloading all-oone-data-structure
#   ✔ Accepted
#   ✔ 25/25 cases passed (89 ms)
#   ✔ Your runtime beats 20.31 % of java submissions
#   ✔ Your memory usage beats 12.62 % of java submissions (80.5 MB)
# Submitting: java_solutions/434.number-of-segments-in-a-string.java
# - Downloading number-of-segments-in-a-string
#   ✔ Accepted
#   ✔ 28/28 cases passed (1 ms)
#   ✔ Your runtime beats 26.3 % of java submissions
#   ✔ Your memory usage beats 67.75 % of java submissions (42.6 MB)
# Submitting: java_solutions/435.non-overlapping-intervals.java
# - Downloading non-overlapping-intervals
#   ✔ Accepted
#   ✔ 60/60 cases passed (68 ms)
#   ✔ Your runtime beats 5.33 % of java submissions
#   ✔ Your memory usage beats 9.07 % of java submissions (117.7 MB)
# Submitting: java_solutions/438.find-all-anagrams-in-a-string.java
# - Downloading find-all-anagrams-in-a-string
#   ✔ Accepted
#   ✔ 65/65 cases passed (42 ms)
#   ✔ Your runtime beats 26.06 % of java submissions
#   ✔ Your memory usage beats 6.15 % of java submissions (53.7 MB)
# Submitting: java_solutions/440.k-th-smallest-in-lexicographical-order.java
# - Downloading k-th-smallest-in-lexicographical-order
#   ✔ Accepted
#   ✔ 70/70 cases passed (1 ms)
#   ✔ Your runtime beats 6.2 % of java submissions
#   ✔ Your memory usage beats 24.32 % of java submissions (42.3 MB)
# Submitting: java_solutions/441.arranging-coins.java
# - Downloading arranging-coins
#   ✔ Accepted
#   ✔ 1336/1336 cases passed (1 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 24.84 % of java submissions (42.9 MB)
# Submitting: java_solutions/442.find-all-duplicates-in-an-array.java
# - Downloading find-all-duplicates-in-an-array
#   ✔ Accepted
#   ✔ 29/29 cases passed (12 ms)
#   ✔ Your runtime beats 44.22 % of java submissions
#   ✔ Your memory usage beats 49.37 % of java submissions (60 MB)
# Submitting: java_solutions/443.string-compression.java
# - Downloading string-compression
#   ✔ Accepted
#   ✔ 77/77 cases passed (19 ms)
#   ✔ Your runtime beats 6.31 % of java submissions
#   ✔ Your memory usage beats 5.04 % of java submissions (52.5 MB)
# Submitting: java_solutions/445.add-two-numbers-ii.java
# - Downloading add-two-numbers-ii
#   ✔ Accepted
#   ✔ 1563/1563 cases passed (26 ms)
#   ✔ Your runtime beats 2.52 % of java submissions
#   ✔ Your memory usage beats 7.29 % of java submissions (47.7 MB)
# Submitting: java_solutions/446.arithmetic-slices-ii-subsequence.java
# - Downloading arithmetic-slices-ii-subsequence
#   ✔ Accepted
#   ✔ 101/101 cases passed (189 ms)
#   ✔ Your runtime beats 26.83 % of java submissions
#   ✔ Your memory usage beats 7.8 % of java submissions (112.4 MB)
# Submitting: java_solutions/448.find-all-numbers-disappeared-in-an-array.java
# - Downloading find-all-numbers-disappeared-in-an-array
#   ✔ Accepted
#   ✔ 35/35 cases passed (19 ms)
#   ✔ Your runtime beats 33.35 % of java submissions
#   ✔ Your memory usage beats 99.72 % of java submissions (65.4 MB)
# Submitting: java_solutions/451.sort-characters-by-frequency.java
# - Downloading sort-characters-by-frequency
#   ✔ Accepted
#   ✔ 33/33 cases passed (29 ms)
#   ✔ Your runtime beats 11.09 % of java submissions
#   ✔ Your memory usage beats 5.1 % of java submissions (53.6 MB)
# Submitting: java_solutions/452.minimum-number-of-arrows-to-burst-balloons.java
# - Downloading minimum-number-of-arrows-to-burst-balloons
#   ✔ Accepted
#   ✔ 50/50 cases passed (77 ms)
#   ✔ Your runtime beats 5.03 % of java submissions
#   ✔ Your memory usage beats 5.01 % of java submissions (97.8 MB)
# Submitting: java_solutions/453.minimum-moves-to-equal-array-elements.java
# - Downloading minimum-moves-to-equal-array-elements
#   ✔ Accepted
#   ✔ 84/84 cases passed (7 ms)
#   ✔ Your runtime beats 14.47 % of java submissions
#   ✔ Your memory usage beats 15.14 % of java submissions (47.8 MB)
# Submitting: java_solutions/454.4sum-ii.java
# - Downloading 4sum-ii
#   ✔ Accepted
#   ✔ 133/133 cases passed (313 ms)
#   ✔ Your runtime beats 5.19 % of java submissions
#   ✔ Your memory usage beats 7.1 % of java submissions (53.4 MB)
# Submitting: java_solutions/455.assign-cookies.java
# - Downloading assign-cookies
#   ✔ Accepted
#   ✔ 25/25 cases passed (24 ms)
#   ✔ Your runtime beats 12.11 % of java submissions
#   ✔ Your memory usage beats 91.95 % of java submissions (51.2 MB)
# Submitting: java_solutions/458.poor-pigs.java
# - Downloading poor-pigs
#   ✔ Accepted
#   ✔ 26/26 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 15.45 % of java submissions (42.3 MB)
# Submitting: java_solutions/459.repeated-substring-pattern.java
# - Downloading repeated-substring-pattern
#   ✔ Accepted
#   ✔ 130/130 cases passed (525 ms)
#   ✔ Your runtime beats 5.02 % of java submissions
#   ✔ Your memory usage beats 70.31 % of java submissions (46.8 MB)

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-05-04 17:37:55
