# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME_3')
    user_cookie = userdata.get('LEETCODE_TOKEN_3')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME_3'] = user_name
    os.environ['LEETCODE_TOKEN_3'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME_3" "$LEETCODE_TOKEN_3" | leetcode user -c

# %%
# %%bash
#
# # top 500-650 answers (6th batch)
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v kotlin_solutions/*.kt | sed -n '501,650p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 7
# done
# Out:
# Submitting: kotlin_solutions/668.kth-smallest-number-in-multiplication-table.kt
#   ✔ Accepted
#   ✔ 71/71 cases passed (28 ms)
#   ✔ Your runtime beats 14.29 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (42.4 MB)
# Submitting: kotlin_solutions/669.trim-a-binary-search-tree.kt
#   ✔ Accepted
#   ✔ 78/78 cases passed (11 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/670.maximum-swap.kt
#   ✔ Accepted
#   ✔ 112/112 cases passed (22 ms)
#   ✔ Your runtime beats 5.88 % of kotlin submissions
#   ✔ Your memory usage beats 5.88 % of kotlin submissions (45.5 MB)
# Submitting: kotlin_solutions/671.second-minimum-node-in-a-binary-tree.kt
#   ✔ Accepted
#   ✔ 39/39 cases passed (27 ms)
#   ✔ Your runtime beats 7.69 % of kotlin submissions
#   ✔ Your memory usage beats 7.69 % of kotlin submissions (46.2 MB)
# Submitting: kotlin_solutions/672.bulb-switcher-ii.kt
#   ✔ Accepted
#   ✔ 80/80 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (40.4 MB)
# Submitting: kotlin_solutions/673.number-of-longest-increasing-subsequence.kt
#   ✔ Accepted
#   ✔ 223/223 cases passed (106 ms)
#   ✔ Your runtime beats 8 % of kotlin submissions
#   ✔ Your memory usage beats 8 % of kotlin submissions (51.9 MB)
# Submitting: kotlin_solutions/674.longest-continuous-increasing-subsequence.kt
#   ✔ Accepted
#   ✔ 35/35 cases passed (32 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 5.13 % of kotlin submissions (50.4 MB)
# Submitting: kotlin_solutions/675.cut-off-trees-for-golf-event.kt
#   ✔ Accepted
#   ✔ 55/55 cases passed (1479 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (72 MB)
# Submitting: kotlin_solutions/676.implement-magic-dictionary.kt
#   ✔ Accepted
#   ✔ 83/83 cases passed (102 ms)
#   ✔ Your runtime beats 27.27 % of kotlin submissions
#   ✔ Your memory usage beats 81.82 % of kotlin submissions (51.7 MB)
# Submitting: kotlin_solutions/677.map-sum-pairs.kt
#   ✔ Accepted
#   ✔ 35/35 cases passed (25 ms)
#   ✔ Your runtime beats 18.75 % of kotlin submissions
#   ✔ Your memory usage beats 18.75 % of kotlin submissions (46 MB)
# Submitting: kotlin_solutions/678.valid-parenthesis-string.kt
#   ✔ Accepted
#   ✔ 83/83 cases passed (2 ms)
#   ✔ Your runtime beats 32.08 % of kotlin submissions
#   ✔ Your memory usage beats 35.85 % of kotlin submissions (40.8 MB)
# Submitting: kotlin_solutions/679.24-game.kt
#   ✔ Accepted
#   ✔ 71/71 cases passed (121 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/680.valid-palindrome-ii.kt
#   ✔ Accepted
#   ✔ 477/477 cases passed (70 ms)
#   ✔ Your runtime beats 5.67 % of kotlin submissions
#   ✔ Your memory usage beats 5.67 % of kotlin submissions (58.5 MB)
# Submitting: kotlin_solutions/682.baseball-game.kt
#   ✔ Accepted
#   ✔ 39/39 cases passed (11 ms)
#   ✔ Your runtime beats 52.87 % of kotlin submissions
#   ✔ Your memory usage beats 49.42 % of kotlin submissions (43.3 MB)
# Submitting: kotlin_solutions/684.redundant-connection.kt
#   ✔ Accepted
#   ✔ 39/39 cases passed (14 ms)
#   ✔ Your runtime beats 9.33 % of kotlin submissions
#   ✔ Your memory usage beats 30.67 % of kotlin submissions (45.2 MB)
# Submitting: kotlin_solutions/685.redundant-connection-ii.kt
#   ✔ Accepted
#   ✔ 58/58 cases passed (40 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/686.repeated-string-match.kt
#   ✔ Accepted
#   ✔ 61/61 cases passed (209 ms)
#   ✔ Your runtime beats 28.57 % of kotlin submissions
#   ✔ Your memory usage beats 7.14 % of kotlin submissions (48.4 MB)
# Submitting: kotlin_solutions/687.longest-univalue-path.kt
#   ✔ Accepted
#   ✔ 71/71 cases passed (67 ms)
#   ✔ Your runtime beats 9.09 % of kotlin submissions
#   ✔ Your memory usage beats 13.64 % of kotlin submissions (53.4 MB)
# Submitting: kotlin_solutions/688.knight-probability-in-chessboard.kt
#   ✔ Accepted
#   ✔ 22/22 cases passed (80 ms)
#   ✔ Your runtime beats 12.5 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (52.4 MB)
# Submitting: kotlin_solutions/689.maximum-sum-of-3-non-overlapping-subarrays.kt
#   ✔ Accepted
#   ✔ 43/43 cases passed (165 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/690.employee-importance.kt
#   ✔ Accepted
#   ✔ 102/102 cases passed (248 ms)
#   ✔ Your runtime beats 22.22 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (56.8 MB)
# Submitting: kotlin_solutions/691.stickers-to-spell-word.kt
#   ✔ Accepted
#   ✔ 102/102 cases passed (380 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/692.top-k-frequent-words.kt
#   ✔ Accepted
#   ✔ 111/111 cases passed (26 ms)
#   ✔ Your runtime beats 20.33 % of kotlin submissions
#   ✔ Your memory usage beats 22.76 % of kotlin submissions (48 MB)
# Submitting: kotlin_solutions/693.binary-number-with-alternating-bits.kt
#   ✔ Accepted
#   ✔ 204/204 cases passed (9 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/695.max-area-of-island.kt
#   ✔ Accepted
#   ✔ 728/728 cases passed (48 ms)
#   ✔ Your runtime beats 6.14 % of kotlin submissions
#   ✔ Your memory usage beats 44.69 % of kotlin submissions (49.8 MB)
# Submitting: kotlin_solutions/696.count-binary-substrings.kt
#   ✔ Accepted
#   ✔ 91/91 cases passed (51 ms)
#   ✔ Your runtime beats 12.2 % of kotlin submissions
#   ✔ Your memory usage beats 17.07 % of kotlin submissions (47.6 MB)
# Submitting: kotlin_solutions/697.degree-of-an-array.kt
#   ✔ Accepted
#   ✔ 89/89 cases passed (42 ms)
#   ✔ Your runtime beats 20.69 % of kotlin submissions
#   ✔ Your memory usage beats 6.9 % of kotlin submissions (55.2 MB)
# Submitting: kotlin_solutions/698.partition-to-k-equal-sum-subsets.kt
#   ✔ Accepted
#   ✔ 164/164 cases passed (66 ms)
#   ✔ Your runtime beats 58.82 % of kotlin submissions
#   ✔ Your memory usage beats 11.76 % of kotlin submissions (53.4 MB)
# Submitting: kotlin_solutions/699.falling-squares.kt
#   ✔ Accepted
#   ✔ 48/48 cases passed (116 ms)
#   ✔ Your runtime beats 14.29 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (52.4 MB)
# Submitting: kotlin_solutions/700.search-in-a-binary-search-tree.kt
#   ✔ Accepted
#   ✔ 36/36 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 37.16 % of kotlin submissions (49 MB)
# Submitting: kotlin_solutions/701.insert-into-a-binary-search-tree.kt
#   ✔ Accepted
#   ✔ 36/36 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 74.23 % of kotlin submissions (48.7 MB)
# Submitting: kotlin_solutions/703.kth-largest-element-in-a-stream.kt
# - Downloading kth-largest-element-in-a-stream
#   ✔ Accepted
#   ✔ 12/12 cases passed (46 ms)
#   ✔ Your runtime beats 83.02 % of kotlin submissions
#   ✔ Your memory usage beats 75 % of kotlin submissions (62 MB)
# Submitting: kotlin_solutions/704.binary-search.kt
#   ✔ Accepted
#   ✔ 47/47 cases passed (20 ms)
#   ✔ Your runtime beats 6.33 % of kotlin submissions
#   ✔ Your memory usage beats 6.33 % of kotlin submissions (51.2 MB)
# Submitting: kotlin_solutions/705.design-hash-set.kt
#   ✔ Accepted
#   ✔ 34/34 cases passed (34 ms)
#   ✔ Your runtime beats 80.77 % of kotlin submissions
#   ✔ Your memory usage beats 73.08 % of kotlin submissions (58.4 MB)
# Submitting: kotlin_solutions/706.design-hash-map.kt
#   ✔ Accepted
#   ✔ 37/37 cases passed (47 ms)
#   ✔ Your runtime beats 41.41 % of kotlin submissions
#   ✔ Your memory usage beats 61.62 % of kotlin submissions (70 MB)
# Submitting: kotlin_solutions/707.design-linked-list.kt
#   ✔ Accepted
#   ✔ 66/66 cases passed (55 ms)
#   ✔ Your runtime beats 5.88 % of kotlin submissions
#   ✔ Your memory usage beats 10.59 % of kotlin submissions (52.1 MB)
# Submitting: kotlin_solutions/709.to-lower-case.kt
#   ✔ Accepted
#   ✔ 114/114 cases passed (13 ms)
#   ✔ Your runtime beats 6.38 % of kotlin submissions
#   ✔ Your memory usage beats 6.38 % of kotlin submissions (43.4 MB)
# Submitting: kotlin_solutions/710.random-pick-with-blacklist.kt
#   ✔ Accepted
#   ✔ 68/68 cases passed (130 ms)
#   ✔ Your runtime beats 10 % of kotlin submissions
#   ✔ Your memory usage beats 10 % of kotlin submissions (83.4 MB)
# Submitting: kotlin_solutions/712.minimum-ascii-delete-sum-for-two-strings.kt
#   ✔ Accepted
#   ✔ 93/93 cases passed (421 ms)
#   ✔ Your runtime beats 5.09 % of kotlin submissions
#   ✔ Your memory usage beats 5.09 % of kotlin submissions (86.4 MB)
# Submitting: kotlin_solutions/713.subarray-product-less-than-k.kt
#   ✔ Accepted
#   ✔ 98/98 cases passed (132 ms)
#   ✔ Your runtime beats 9.46 % of kotlin submissions
#   ✔ Your memory usage beats 6.76 % of kotlin submissions (53.1 MB)
# Submitting: kotlin_solutions/714.best-time-to-buy-and-sell-stock-with-transaction-fee.kt
#   ✔ Accepted
#   ✔ 45/45 cases passed (28 ms)
#   ✔ Your runtime beats 17.46 % of kotlin submissions
#   ✔ Your memory usage beats 44.44 % of kotlin submissions (60.2 MB)
# Submitting: kotlin_solutions/715.range-module.kt
#   ✔ Accepted
#   ✔ 56/56 cases passed (509 ms)
#   ✔ Your runtime beats 11.11 % of kotlin submissions
#   ✔ Your memory usage beats 11.11 % of kotlin submissions (79 MB)
# Submitting: kotlin_solutions/717.1-bit-and-2-bit-characters.kt
#   ✔ Accepted
#   ✔ 95/95 cases passed (18 ms)
#   ✔ Your runtime beats 4 % of kotlin submissions
#   ✔ Your memory usage beats 12 % of kotlin submissions (47.1 MB)
# Submitting: kotlin_solutions/718.maximum-length-of-repeated-subarray.kt
#   ✔ Accepted
#   ✔ 55/55 cases passed (65 ms)
#   ✔ Your runtime beats 6.67 % of kotlin submissions
#   ✔ Your memory usage beats 6.67 % of kotlin submissions (60 MB)
# Submitting: kotlin_solutions/719.find-k-th-smallest-pair-distance.kt
#   ✔ Accepted
#   ✔ 21/21 cases passed (3164 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 16.67 % of kotlin submissions (51.3 MB)
# Submitting: kotlin_solutions/720.longest-word-in-dictionary.kt
#   ✔ Accepted
#   ✔ 59/59 cases passed (77 ms)
#   ✔ Your runtime beats 9.09 % of kotlin submissions
#   ✔ Your memory usage beats 27.27 % of kotlin submissions (50.6 MB)
# Submitting: kotlin_solutions/721.accounts-merge.kt
#   ✔ Accepted
#   ✔ 50/50 cases passed (51 ms)
#   ✔ Your runtime beats 61.7 % of kotlin submissions
#   ✔ Your memory usage beats 74.47 % of kotlin submissions (54.2 MB)
# Submitting: kotlin_solutions/722.remove-comments.kt
#   ✔ Accepted
#   ✔ 55/55 cases passed (18 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/724.find-pivot-index.kt
#   ✔ Accepted
#   ✔ 747/747 cases passed (15 ms)
#   ✔ Your runtime beats 11.31 % of kotlin submissions
#   ✔ Your memory usage beats 62.41 % of kotlin submissions (49.2 MB)
# Submitting: kotlin_solutions/725.split-linked-list-in-parts.kt
#   ✔ Accepted
#   ✔ 43/43 cases passed (11 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/726.number-of-atoms.kt
#   ✔ Accepted
#   ✔ 39/39 cases passed (44 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/728.self-dividing-numbers.kt
#   ✔ Accepted
#   ✔ 31/31 cases passed (15 ms)
#   ✔ Your runtime beats 12.73 % of kotlin submissions
#   ✔ Your memory usage beats 14.55 % of kotlin submissions (44.9 MB)
# Submitting: kotlin_solutions/729.my-calendar-i.kt
#   ✔ Accepted
#   ✔ 107/107 cases passed (45 ms)
#   ✔ Your runtime beats 69.81 % of kotlin submissions
#   ✔ Your memory usage beats 83.02 % of kotlin submissions (50.1 MB)
# Submitting: kotlin_solutions/730.count-different-palindromic-subsequences.kt
#   ✔ Accepted
#   ✔ 367/367 cases passed (52 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions/731.my-calendar-ii.kt
#   ✔ Accepted
#   ✔ 97/97 cases passed (158 ms)
#   ✔ Your runtime beats 37.5 % of kotlin submissions
#   ✔ Your memory usage beats 53.13 % of kotlin submissions (52.6 MB)
# Submitting: kotlin_solutions/732.my-calendar-iii.kt
#   ✔ Accepted
#   ✔ 98/98 cases passed (268 ms)
#   ✔ Your runtime beats 7.14 % of kotlin submissions
#   ✔ Your memory usage beats 7.14 % of kotlin submissions (68.9 MB)
# Submitting: kotlin_solutions/733.flood-fill.kt
# - Downloading flood-fill
#   ✔ Accepted
#   ✔ 278/278 cases passed (13 ms)
#   ✔ Your runtime beats 47.73 % of kotlin submissions
#   ✔ Your memory usage beats 81.25 % of kotlin submissions (46.5 MB)
# Submitting: kotlin_solutions/735.asteroid-collision.kt
#   ✔ Accepted
#   ✔ 276/276 cases passed (28 ms)
#   ✔ Your runtime beats 6.19 % of kotlin submissions
#   ✔ Your memory usage beats 58.41 % of kotlin submissions (48.5 MB)
# Submitting: kotlin_solutions/736.parse-lisp-expression.kt
#   ✔ Accepted
#   ✔ 66/66 cases passed (58 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/738.monotone-increasing-digits.kt
#   ✔ Accepted
#   ✔ 308/308 cases passed (19 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/739.daily-temperatures.kt
#   ✔ Accepted
#   ✔ 48/48 cases passed (133 ms)
#   ✔ Your runtime beats 14.57 % of kotlin submissions
#   ✔ Your memory usage beats 75.31 % of kotlin submissions (62.6 MB)
# Submitting: kotlin_solutions/740.delete-and-earn.kt
#   ✔ Accepted
#   ✔ 52/52 cases passed (36 ms)
#   ✔ Your runtime beats 23.81 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (50.4 MB)
# Submitting: kotlin_solutions/741.cherry-pickup.kt
#   ✔ Accepted
#   ✔ 60/60 cases passed (208 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 16.67 % of kotlin submissions (76.9 MB)
# Submitting: kotlin_solutions/743.network-delay-time.kt
#   ✔ Accepted
#   ✔ 56/56 cases passed (290 ms)
#   ✔ Your runtime beats 62.69 % of kotlin submissions
#   ✔ Your memory usage beats 20.9 % of kotlin submissions (68.6 MB)
# Submitting: kotlin_solutions/744.find-smallest-letter-greater-than-target.kt
#   ✔ Accepted
#   ✔ 167/167 cases passed (10 ms)
#   ✔ Your runtime beats 26.64 % of kotlin submissions
#   ✔ Your memory usage beats 13.11 % of kotlin submissions (48 MB)
# Submitting: kotlin_solutions/745.prefix-and-suffix-search.kt
#   ✔ Accepted
#   ✔ 17/17 cases passed (633 ms)
#   ✔ Your runtime beats 16.67 % of kotlin submissions
#   ✔ Your memory usage beats 83.33 % of kotlin submissions (120.7 MB)
# Submitting: kotlin_solutions/746.min-cost-climbing-stairs.kt
#   ✔ Accepted
#   ✔ 285/285 cases passed (23 ms)
#   ✔ Your runtime beats 7.29 % of kotlin submissions
#   ✔ Your memory usage beats 5.21 % of kotlin submissions (47.3 MB)
# Submitting: kotlin_solutions/747.largest-number-at-least-twice-of-others.kt
#   ✔ Accepted
#   ✔ 231/231 cases passed (14 ms)
#   ✔ Your runtime beats 3.7 % of kotlin submissions
#   ✔ Your memory usage beats 11.11 % of kotlin submissions (45.7 MB)
# Submitting: kotlin_solutions/748.shortest-completing-word.kt
#   ✔ Accepted
#   ✔ 102/102 cases passed (35 ms)
#   ✔ Your runtime beats 17.24 % of kotlin submissions
#   ✔ Your memory usage beats 6.9 % of kotlin submissions (49 MB)
# Submitting: kotlin_solutions/749.contain-virus.kt
#   ✔ Accepted
#   ✔ 32/32 cases passed (113 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/752.open-the-lock.kt
#   ✔ Accepted
#   ✔ 48/48 cases passed (267 ms)
#   ✔ Your runtime beats 9.43 % of kotlin submissions
#   ✔ Your memory usage beats 7.55 % of kotlin submissions (75 MB)
# Submitting: kotlin_solutions/753.cracking-the-safe.kt
#   ✔ Accepted
#   ✔ 38/38 cases passed (254 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/754.reach-a-number.kt
#   ✔ Accepted
#   ✔ 73/73 cases passed (31 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/756.pyramid-transition-matrix.kt
#   ✔ Accepted
#   ✔ 67/67 cases passed (1925 ms)
#   ✔ Your runtime beats 5.05 % of kotlin submissions
#   ✔ Your memory usage beats 32.32 % of kotlin submissions (56.5 MB)
# Submitting: kotlin_solutions/757.set-intersection-size-at-least-two.kt
#   ✔ Accepted
#   ✔ 118/118 cases passed (37 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (49.7 MB)
# Submitting: kotlin_solutions/761.special-binary-string.kt
#   ✔ Accepted
#   ✔ 87/87 cases passed (31 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (47.1 MB)
# Submitting: kotlin_solutions/762.prime-number-of-set-bits-in-binary-representation.kt
#   ✔ Accepted
#   ✔ 202/202 cases passed (113 ms)
#   ✔ Your runtime beats 9.09 % of kotlin submissions
#   ✔ Your memory usage beats 18.18 % of kotlin submissions (48.4 MB)
# Submitting: kotlin_solutions/763.partition-labels.kt
#   ✔ Accepted
#   ✔ 118/118 cases passed (14 ms)
#   ✔ Your runtime beats 35.9 % of kotlin submissions
#   ✔ Your memory usage beats 19.23 % of kotlin submissions (45.3 MB)
# Submitting: kotlin_solutions/764.largest-plus-sign.kt
#   ✔ Accepted
#   ✔ 56/56 cases passed (306 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/765.couples-holding-hands.kt
#   ✔ Accepted
#   ✔ 56/56 cases passed (21 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (45.7 MB)
# Submitting: kotlin_solutions/766.toeplitz-matrix.kt
#   ✔ Accepted
#   ✔ 483/483 cases passed (15 ms)
#   ✔ Your runtime beats 6.25 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (51 MB)
# Submitting: kotlin_solutions/767.reorganize-string.kt
#   ✔ Accepted
#   ✔ 71/71 cases passed (24 ms)
#   ✔ Your runtime beats 13.64 % of kotlin submissions
#   ✔ Your memory usage beats 18.18 % of kotlin submissions (44.7 MB)
# Submitting: kotlin_solutions/768.max-chunks-to-make-sorted-ii.kt
# [ERROR] session expired, please login again [code=-1]
# Submitting: kotlin_solutions/769.max-chunks-to-make-sorted.kt
#   ✔ Accepted
#   ✔ 53/53 cases passed (13 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/770.basic-calculator-iv.kt
#   ✔ Accepted
#   ✔ 158/158 cases passed (66 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (56.2 MB)
# Submitting: kotlin_solutions/771.jewels-and-stones.kt
#   ✔ Accepted
#   ✔ 255/255 cases passed (13 ms)
#   ✔ Your runtime beats 20.86 % of kotlin submissions
#   ✔ Your memory usage beats 10.07 % of kotlin submissions (43.7 MB)
# Submitting: kotlin_solutions/773.sliding-puzzle.kt
#   ✔ Accepted
#   ✔ 32/32 cases passed (236 ms)
#   ✔ Your runtime beats 14.29 % of kotlin submissions
#   ✔ Your memory usage beats 14.29 % of kotlin submissions (56.1 MB)
# Submitting: kotlin_solutions/775.global-and-local-inversions.kt
#   ✔ Accepted
#   ✔ 226/226 cases passed (27 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/777.swap-adjacent-in-lr-string.kt
#   ✔ Accepted
#   ✔ 99/99 cases passed (43 ms)
#   ✔ Your runtime beats 9.09 % of kotlin submissions
#   ✔ Your memory usage beats 9.09 % of kotlin submissions (47.6 MB)
# Submitting: kotlin_solutions/778.swim-in-rising-water.kt
#   ✔ Accepted
#   ✔ 43/43 cases passed (912 ms)
#   ✔ Your runtime beats 6 % of kotlin submissions
#   ✔ Your memory usage beats 6 % of kotlin submissions (62 MB)
# Submitting: kotlin_solutions/779.k-th-symbol-in-grammar.kt
#   ✔ Accepted
#   ✔ 55/55 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 37.5 % of kotlin submissions (40.2 MB)
# Submitting: kotlin_solutions/780.reaching-points.kt
#   ✔ Accepted
#   ✔ 197/197 cases passed (13 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/781.rabbits-in-forest.kt
#   ✔ Accepted
#   ✔ 56/56 cases passed (19 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/782.transform-to-chessboard.kt
#   ✔ Accepted
#   ✔ 127/127 cases passed (36 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (52.3 MB)
# Submitting: kotlin_solutions/783.minimum-distance-between-bst-nodes.kt
#   ✔ Accepted
#   ✔ 49/49 cases passed (19 ms)
#   ✔ Your runtime beats 6.25 % of kotlin submissions
#   ✔ Your memory usage beats 6.25 % of kotlin submissions (43.3 MB)
# Submitting: kotlin_solutions/784.letter-case-permutation.kt
#   ✔ Accepted
#   ✔ 63/63 cases passed (40 ms)
#   ✔ Your runtime beats 7.14 % of kotlin submissions
#   ✔ Your memory usage beats 7.14 % of kotlin submissions (52.3 MB)
# Submitting: kotlin_solutions/785.is-graph-bipartite.kt
#   ✔ Accepted
#   ✔ 86/86 cases passed (30 ms)
#   ✔ Your runtime beats 6.49 % of kotlin submissions
#   ✔ Your memory usage beats 5.19 % of kotlin submissions (57.3 MB)
# Submitting: kotlin_solutions/786.k-th-smallest-prime-fraction.kt
#   ✔ Accepted
#   ✔ 59/59 cases passed (523 ms)
#   ✔ Your runtime beats 37.5 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (104.3 MB)
# Submitting: kotlin_solutions/787.cheapest-flights-within-k-stops.kt
#   ✔ Accepted
#   ✔ 59/59 cases passed (11 ms)
#   ✔ Your runtime beats 87.25 % of kotlin submissions
#   ✔ Your memory usage beats 95.1 % of kotlin submissions (45.5 MB)
# Submitting: kotlin_solutions/788.rotated-digits.kt
#   ✔ Accepted
#   ✔ 50/50 cases passed (28 ms)
#   ✔ Your runtime beats 60 % of kotlin submissions
#   ✔ Your memory usage beats 60 % of kotlin submissions (45.6 MB)
# Submitting: kotlin_solutions/789.escape-the-ghosts.kt
#   ✔ Accepted
#   ✔ 77/77 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 77.78 % of kotlin submissions (42.5 MB)
# Submitting: kotlin_solutions/790.domino-and-tromino-tiling.kt
#   ✔ Accepted
#   ✔ 39/39 cases passed (6 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
#   ✔ Your memory usage beats 24 % of kotlin submissions (41.3 MB)
# Submitting: kotlin_solutions/791.custom-sort-string.kt
# - Downloading custom-sort-string
#   ✔ Accepted
#   ✔ 41/41 cases passed (35 ms)
#   ✔ Your runtime beats 5.71 % of kotlin submissions
#   ✔ Your memory usage beats 5.71 % of kotlin submissions (48.4 MB)
# Submitting: kotlin_solutions/792.number-of-matching-subsequences.kt
#   ✔ Accepted
#   ✔ 53/53 cases passed (84 ms)
#   ✔ Your runtime beats 57.14 % of kotlin submissions
#   ✔ Your memory usage beats 61.9 % of kotlin submissions (50.4 MB)
# Submitting: kotlin_solutions/793.preimage-size-of-factorial-zeroes-function.kt
#   ✔ Accepted
#   ✔ 44/44 cases passed (20 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions/794.valid-tic-tac-toe-state.kt
# [ERROR] session expired, please login again [code=-1]
# Submitting: kotlin_solutions/795.number-of-subarrays-with-bounded-maximum.kt
#   ✔ Accepted
#   ✔ 46/46 cases passed (45 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (61.6 MB)
# Submitting: kotlin_solutions/796.rotate-string.kt
#   ✔ Accepted
#   ✔ 58/58 cases passed (6 ms)
#   ✔ Your runtime beats 65.43 % of kotlin submissions
#   ✔ Your memory usage beats 33.33 % of kotlin submissions (42.1 MB)
# Submitting: kotlin_solutions/797.all-paths-from-source-to-target.kt
#   ✔ Accepted
#   ✔ 30/30 cases passed (31 ms)
#   ✔ Your runtime beats 9.23 % of kotlin submissions
#   ✔ Your memory usage beats 6.15 % of kotlin submissions (56.7 MB)
# Submitting: kotlin_solutions/798.smallest-rotation-with-highest-score.kt
#   ✔ Accepted
#   ✔ 44/44 cases passed (26 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/799.champagne-tower.kt
#   ✔ Accepted
#   ✔ 312/312 cases passed (138 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
#   ✔ Your memory usage beats 50 % of kotlin submissions (45.8 MB)
# Submitting: kotlin_solutions/801.minimum-swaps-to-make-sequences-increasing.kt
#   ✔ Accepted
#   ✔ 117/117 cases passed (269 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/802.find-eventual-safe-states.kt
#   ✔ Accepted
#   ✔ 113/113 cases passed (66 ms)
#   ✔ Your runtime beats 30 % of kotlin submissions
#   ✔ Your memory usage beats 24 % of kotlin submissions (78.6 MB)
# Submitting: kotlin_solutions/803.bricks-falling-when-hit.kt
#   ✔ Accepted
#   ✔ 40/40 cases passed (108 ms)
#   ✔ Your runtime beats 22.22 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (77.5 MB)
# Submitting: kotlin_solutions/804.unique-morse-code-words.kt
#   ✔ Accepted
#   ✔ 82/82 cases passed (18 ms)
#   ✔ Your runtime beats 34.29 % of kotlin submissions
#   ✔ Your memory usage beats 34.29 % of kotlin submissions (46 MB)
# Submitting: kotlin_solutions/805.split-array-with-same-average.kt
#   ✔ Accepted
#   ✔ 111/111 cases passed (2554 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (113 MB)
# Submitting: kotlin_solutions/806.number-of-lines-to-write-string.kt
#   ✔ Accepted
#   ✔ 27/27 cases passed (88 ms)
#   ✔ Your runtime beats 68.75 % of kotlin submissions
#   ✔ Your memory usage beats 18.75 % of kotlin submissions (40.6 MB)
# Submitting: kotlin_solutions/807.max-increase-to-keep-city-skyline.kt
#   ✔ Accepted
#   ✔ 133/133 cases passed (21 ms)
#   ✔ Your runtime beats 21.05 % of kotlin submissions
#   ✔ Your memory usage beats 26.32 % of kotlin submissions (47.2 MB)
# Submitting: kotlin_solutions/808.soup-servings.kt
#   ✔ Accepted
#   ✔ 43/43 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (40.4 MB)
# Submitting: kotlin_solutions/809.expressive-words.kt
#   ✔ Accepted
#   ✔ 36/36 cases passed (30 ms)
#   ✔ Your runtime beats 6.67 % of kotlin submissions
#   ✔ Your memory usage beats 6.67 % of kotlin submissions (48 MB)
# Submitting: kotlin_solutions/810.chalkboard-xor-game.kt
#   ✔ Accepted
#   ✔ 168/168 cases passed (11 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (49 MB)
# Submitting: kotlin_solutions/811.subdomain-visit-count.kt
#   ✔ Accepted
#   ✔ 52/52 cases passed (47 ms)
#   ✔ Your runtime beats 8.33 % of kotlin submissions
#   ✔ Your memory usage beats 8.33 % of kotlin submissions (48.4 MB)
# Submitting: kotlin_solutions/812.largest-triangle-area.kt
#   ✔ Accepted
#   ✔ 57/57 cases passed (49 ms)
#   ✔ Your runtime beats 7.69 % of kotlin submissions
#   ✔ Your memory usage beats 7.69 % of kotlin submissions (48.6 MB)
# Submitting: kotlin_solutions/813.largest-sum-of-averages.kt
#   ✔ Accepted
#   ✔ 51/51 cases passed (49 ms)
#   ✔ Your runtime beats 7.14 % of kotlin submissions
#   ✔ Your memory usage beats 7.14 % of kotlin submissions (47.3 MB)
# Submitting: kotlin_solutions/814.binary-tree-pruning.kt
#   ✔ Accepted
#   ✔ 31/31 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 12.5 % of kotlin submissions (41.7 MB)
# Submitting: kotlin_solutions/815.bus-routes.kt
#   ✔ Accepted
#   ✔ 54/54 cases passed (405 ms)
#   ✔ Your runtime beats 17.14 % of kotlin submissions
#   ✔ Your memory usage beats 8.57 % of kotlin submissions (115.7 MB)
# Submitting: kotlin_solutions/816.ambiguous-coordinates.kt
#   ✔ Accepted
#   ✔ 346/346 cases passed (23 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/817.linked-list-components.kt
#   ✔ Accepted
#   ✔ 57/57 cases passed (66 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/818.race-car.kt
#   ✘ Time Limit Exceeded
#   ✘ 54/55 cases passed (N/A)
#   ✘ Testcase: 6102
#   ✘ Answer:
#   ✘ Expected Answer: 39
#   ✘ Stdout:
# Submitting: kotlin_solutions/819.most-common-word.kt
#   ✔ Accepted
#   ✔ 50/50 cases passed (48 ms)
#   ✔ Your runtime beats 16.33 % of kotlin submissions
#   ✔ Your memory usage beats 20.41 % of kotlin submissions (48.1 MB)
# Submitting: kotlin_solutions/820.short-encoding-of-words.kt
#   ✔ Accepted
#   ✔ 39/39 cases passed (231 ms)
#   ✔ Your runtime beats 11.11 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (50.9 MB)
# Submitting: kotlin_solutions/821.shortest-distance-to-a-character.kt
#   ✔ Accepted
#   ✔ 76/76 cases passed (95 ms)
#   ✔ Your runtime beats 6.67 % of kotlin submissions
#   ✔ Your memory usage beats 6.67 % of kotlin submissions (50.5 MB)
# Submitting: kotlin_solutions/822.card-flipping-game.kt
#   ✔ Accepted
#   ✔ 169/169 cases passed (39 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (50.2 MB)
# Submitting: kotlin_solutions/823.binary-trees-with-factors.kt
#   ✔ Accepted
#   ✔ 48/48 cases passed (73 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/824.goat-latin.kt
# [ERROR] session expired, please login again [code=-1]
# Submitting: kotlin_solutions/825.friends-of-appropriate-ages.kt
#   ✔ Accepted
#   ✔ 89/89 cases passed (15 ms)
#   ✔ Your runtime beats 36.36 % of kotlin submissions
#   ✔ Your memory usage beats 72.73 % of kotlin submissions (51 MB)
# Submitting: kotlin_solutions/826.most-profit-assigning-work.kt
#   ✔ Accepted
#   ✔ 60/60 cases passed (423 ms)
#   ✔ Your runtime beats 50 % of kotlin submissions
# [WARN] Failed to get memory percentile.
# Submitting: kotlin_solutions/827.making-a-large-island.kt
#   ✔ Accepted
#   ✔ 75/75 cases passed (858 ms)
#   ✔ Your runtime beats 8.62 % of kotlin submissions
#   ✔ Your memory usage beats 5.17 % of kotlin submissions (113.7 MB)
# Submitting: kotlin_solutions/828.count-unique-characters-of-all-substrings-of-a-given-string.kt
#   ✔ Accepted
#   ✔ 76/76 cases passed (55 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (47 MB)
# Submitting: kotlin_solutions/829.consecutive-numbers-sum.kt
#   ✔ Accepted
#   ✔ 170/170 cases passed (28 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (47 MB)
# Submitting: kotlin_solutions/830.positions-of-large-groups.kt
#   ✔ Accepted
#   ✔ 202/202 cases passed (19 ms)
#   ✔ Your runtime beats 26.09 % of kotlin submissions
#   ✔ Your memory usage beats 8.7 % of kotlin submissions (51.5 MB)
# Submitting: kotlin_solutions/831.masking-personal-information.kt
#   ✔ Accepted
#   ✔ 66/66 cases passed (9 ms)
#   ✔ Your runtime beats 41.67 % of kotlin submissions
#   ✔ Your memory usage beats 8.33 % of kotlin submissions (42.8 MB)
# Submitting: kotlin_solutions/832.flipping-an-image.kt
#   ✔ Accepted
#   ✔ 82/82 cases passed (15 ms)
#   ✔ Your runtime beats 6.9 % of kotlin submissions
#   ✔ Your memory usage beats 51.72 % of kotlin submissions (47.4 MB)
# Submitting: kotlin_solutions/833.find-and-replace-in-string.kt
#   ✔ Accepted
#   ✔ 59/59 cases passed (35 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/834.sum-of-distances-in-tree.kt
#   ✔ Accepted
#   ✔ 74/74 cases passed (137 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/835.image-overlap.kt
#   ✔ Accepted
#   ✔ 60/60 cases passed (55 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 100 % of kotlin submissions (54.4 MB)
# Submitting: kotlin_solutions/836.rectangle-overlap.kt
#   ✔ Accepted
#   ✔ 41/41 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 25 % of kotlin submissions (40.9 MB)
# Submitting: kotlin_solutions/837.new-21-game.kt
#   ✔ Accepted
#   ✔ 152/152 cases passed (26 ms)
# [WARN] Failed to get runtime percentile.
# Submitting: kotlin_solutions/838.push-dominoes.kt
#   ✔ Accepted
#   ✔ 45/45 cases passed (32 ms)
#   ✔ Your runtime beats 33.33 % of kotlin submissions
#   ✔ Your memory usage beats 44.44 % of kotlin submissions (47.4 MB)
# Submitting: kotlin_solutions/839.similar-string-groups.kt
#   ✔ Accepted
#   ✔ 77/77 cases passed (256 ms)
#   ✔ Your runtime beats 0 % of kotlin submissions
#   ✔ Your memory usage beats 0 % of kotlin submissions (51 MB)

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-02-14 22:18:50
