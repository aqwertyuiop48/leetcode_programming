# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME')
    user_cookie = userdata.get('LEETCODE_TOKEN')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME'] = user_name
    os.environ['LEETCODE_TOKEN'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME" "$LEETCODE_TOKEN" | leetcode user -c

# %%
# %%bash
#
#
# # top 100 answers
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v kotlin_solutions/*.kt | head -n 100); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 7
# done
# Out:
# Submitting: kotlin_solutions/1.two-sum.kt
#   ✔ Accepted
#   ✔ 63/63 cases passed (38 ms)
#   ✔ Your runtime beats 15.17 % of kotlin submissions
#   ✔ Your memory usage beats 11.34 % of kotlin submissions (49 MB)
# Submitting: kotlin_solutions/2.add-two-numbers.kt
#   ✔ Accepted
#   ✔ 1569/1569 cases passed (71 ms)
#   ✔ Your runtime beats 5.09 % of kotlin submissions
#   ✔ Your memory usage beats 5.2 % of kotlin submissions (54.8 MB)
# Submitting: kotlin_solutions/3.longest-substring-without-repeating-characters.kt
# - Downloading longest-substring-without-repeating-characters
#   ✔ Accepted
#   ✔ 988/988 cases passed (14 ms)
#   ✔ Your runtime beats 30.39 % of kotlin submissions
#   ✔ Your memory usage beats 35.01 % of kotlin submissions (46.4 MB)
# Submitting: kotlin_solutions/4.median-of-two-sorted-arrays.kt
# - Downloading median-of-two-sorted-arrays
#   ✔ Accepted
#   ✔ 2098/2098 cases passed (26 ms)
#   ✔ Your runtime beats 8.31 % of kotlin submissions
#   ✔ Your memory usage beats 64.24 % of kotlin submissions (51.2 MB)
# Submitting: kotlin_solutions/5.longest-palindromic-substring.kt
# - Downloading longest-palindromic-substring
#   ✔ Accepted
#   ✔ 143/143 cases passed (217 ms)
#   ✔ Your runtime beats 19.3 % of kotlin submissions
#   ✔ Your memory usage beats 9.41 % of kotlin submissions (50 MB)
# Submitting: kotlin_solutions/6.zigzag-conversion.kt
# - Downloading zigzag-conversion
#   ✔ Accepted
#   ✔ 1157/1157 cases passed (63 ms)
#   ✔ Your runtime beats 13.35 % of kotlin submissions
#   ✔ Your memory usage beats 7.9 % of kotlin submissions (52.7 MB)
# Submitting: kotlin_solutions/7.reverse-integer.kt
# - Downloading reverse-integer
#   ✔ Accepted
#   ✔ 1045/1045 cases passed (114 ms)
#   ✔ Your runtime beats 20.56 % of kotlin submissions
#   ✔ Your memory usage beats 10.84 % of kotlin submissions (42 MB)
# Submitting: kotlin_solutions/8.string-to-integer-atoi.kt
# - Downloading string-to-integer-atoi
#   ✔ Accepted
#   ✔ 1096/1096 cases passed (38 ms)
#   ✔ Your runtime beats 6.23 % of kotlin submissions
#   ✔ Your memory usage beats 5.92 % of kotlin submissions (47.9 MB)
# Submitting: kotlin_solutions/9.palindrome-number.kt
# - Downloading palindrome-number
#   ✔ Accepted
#   ✔ 11511/11511 cases passed (18 ms)
#   ✔ Your runtime beats 20.96 % of kotlin submissions
#   ✔ Your memory usage beats 12.51 % of kotlin submissions (46.7 MB)
# Submitting: kotlin_solutions/10.regular-expression-matching.kt
# - Downloading regular-expression-matching
#   ✔ Accepted
#   ✔ 354/354 cases passed (213 ms)
#   ✔ Your runtime beats 27.73 % of kotlin submissions
#   ✔ Your memory usage beats 68.07 % of kotlin submissions (43.2 MB)
# Submitting: kotlin_solutions/11.container-with-most-water.kt
# - Downloading container-with-most-water
#   ✔ Accepted
#   ✔ 65/65 cases passed (30 ms)
#   ✔ Your runtime beats 7.7 % of kotlin submissions
#   ✔ Your memory usage beats 10.02 % of kotlin submissions (62.7 MB)
# Submitting: kotlin_solutions/12.integer-to-roman.kt
# - Downloading integer-to-roman
#   ✔ Accepted
#   ✔ 3999/3999 cases passed (26 ms)
#   ✔ Your runtime beats 10.92 % of kotlin submissions
#   ✔ Your memory usage beats 8.8 % of kotlin submissions (49.6 MB)
# Submitting: kotlin_solutions/13.roman-to-integer.kt
# - Downloading roman-to-integer
#   ✔ Accepted
#   ✔ 3999/3999 cases passed (12 ms)
#   ✔ Your runtime beats 65.71 % of kotlin submissions
#   ✔ Your memory usage beats 88.82 % of kotlin submissions (45.5 MB)
# Submitting: kotlin_solutions/14.longest-common-prefix.kt
# - Downloading longest-common-prefix
#   ✔ Accepted
#   ✔ 126/126 cases passed (28 ms)
#   ✔ Your runtime beats 5.31 % of kotlin submissions
#   ✔ Your memory usage beats 5.31 % of kotlin submissions (47.1 MB)
# Submitting: kotlin_solutions/15.3-sum.kt
# - Downloading 3sum
#   ✔ Accepted
#   ✔ 316/316 cases passed (523 ms)
#   ✔ Your runtime beats 15.68 % of kotlin submissions
#   ✔ Your memory usage beats 35.69 % of kotlin submissions (68.1 MB)
# Submitting: kotlin_solutions/16.3-sum-closest.kt
# - Downloading 3sum-closest
#   ✔ Accepted
#   ✔ 107/107 cases passed (206 ms)
#   ✔ Your runtime beats 5.88 % of kotlin submissions
#   ✔ Your memory usage beats 5.88 % of kotlin submissions (62.5 MB)
# Submitting: kotlin_solutions/17.letter-combinations-of-a-phone-number.kt
# - Downloading letter-combinations-of-a-phone-number
#   ✔ Accepted
#   ✔ 24/24 cases passed (10 ms)
#   ✔ Your runtime beats 48.97 % of kotlin submissions
#   ✔ Your memory usage beats 44.36 % of kotlin submissions (43.6 MB)
# Submitting: kotlin_solutions/18.4-sum.kt
# - Downloading 4sum
#   ✔ Accepted
#   ✔ 294/294 cases passed (197 ms)
#   ✔ Your runtime beats 14.1 % of kotlin submissions
#   ✔ Your memory usage beats 22.15 % of kotlin submissions (54.8 MB)
# Submitting: kotlin_solutions/19.remove-nth-node-from-end-of-list.kt
# - Downloading remove-nth-node-from-end-of-list
#   ✔ Accepted
#   ✔ 208/208 cases passed (9 ms)
#   ✔ Your runtime beats 6.14 % of kotlin submissions
#   ✔ Your memory usage beats 5.68 % of kotlin submissions (42.9 MB)
# Submitting: kotlin_solutions/20.valid-parentheses.kt
# - Downloading valid-parentheses
#   ✔ Accepted
#   ✔ 102/102 cases passed (18 ms)
#   ✔ Your runtime beats 58.45 % of kotlin submissions
#   ✔ Your memory usage beats 40.53 % of kotlin submissions (46.1 MB)
# Submitting: kotlin_solutions/21.merge-two-sorted-lists.kt
# - Downloading merge-two-sorted-lists
#   ✔ Accepted
#   ✔ 208/208 cases passed (9 ms)
#   ✔ Your runtime beats 1.36 % of kotlin submissions
#   ✔ Your memory usage beats 6.2 % of kotlin submissions (46.3 MB)
# Submitting: kotlin_solutions/22.generate-parentheses.kt
# - Downloading generate-parentheses
#   ✔ Accepted
#   ✔ 8/8 cases passed (33 ms)
#   ✔ Your runtime beats 5.36 % of kotlin submissions
#   ✔ Your memory usage beats 8.04 % of kotlin submissions (47.5 MB)
# Submitting: kotlin_solutions/23.merge-k-sorted-lists.kt
# - Downloading merge-k-sorted-lists
#   ✔ Accepted
#   ✔ 134/134 cases passed (32 ms)
#   ✔ Your runtime beats 18.25 % of kotlin submissions
#   ✔ Your memory usage beats 29.15 % of kotlin submissions (48.3 MB)
# Submitting: kotlin_solutions/24.swap-nodes-in-pairs.kt
# - Downloading swap-nodes-in-pairs
#   ✔ Accepted
#   ✔ 55/55 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 63.01 % of kotlin submissions (40.9 MB)
# Submitting: kotlin_solutions/25.reverse-nodes-in-k-group.kt
# - Downloading reverse-nodes-in-k-group
#   ✔ Accepted
#   ✔ 62/62 cases passed (28 ms)
#   ✔ Your runtime beats 5.93 % of kotlin submissions
#   ✔ Your memory usage beats 5.08 % of kotlin submissions (46.5 MB)
# Submitting: kotlin_solutions/26.remove-duplicates-from-sorted-array.kt
# - Downloading remove-duplicates-from-sorted-array
#   ✔ Accepted
#   ✔ 362/362 cases passed (6 ms)
#   ✔ Your runtime beats 16.28 % of kotlin submissions
#   ✔ Your memory usage beats 60.6 % of kotlin submissions (47.6 MB)
# Submitting: kotlin_solutions/27.remove-element.kt
# - Downloading remove-element
#   ✔ Accepted
#   ✔ 116/116 cases passed (13 ms)
#   ✔ Your runtime beats 5.13 % of kotlin submissions
#   ✔ Your memory usage beats 5.25 % of kotlin submissions (45.9 MB)
# Submitting: kotlin_solutions/28.find-the-index-of-the-first-occurrence-in-a-string.kt
# - Downloading find-the-index-of-the-first-occurrence-in-a-string
#   ✔ Accepted
#   ✔ 85/85 cases passed (4 ms)
#   ✔ Your runtime beats 44.12 % of kotlin submissions
#   ✔ Your memory usage beats 39.01 % of kotlin submissions (41.9 MB)
# Submitting: kotlin_solutions/29.divide-two-integers.kt
# - Downloading divide-two-integers
#   ✔ Accepted
#   ✔ 994/994 cases passed (1 ms)
#   ✔ Your runtime beats 94.74 % of kotlin submissions
#   ✔ Your memory usage beats 42.11 % of kotlin submissions (41.3 MB)
# Submitting: kotlin_solutions/30.substring-with-concatenation-of-all-words.kt
# - Downloading substring-with-concatenation-of-all-words
#   ✔ Accepted
#   ✔ 182/182 cases passed (2733 ms)
#   ✔ Your runtime beats 5.81 % of kotlin submissions
#   ✔ Your memory usage beats 9.3 % of kotlin submissions (63.1 MB)
# Submitting: kotlin_solutions/31.next-permutation.kt
# - Downloading next-permutation
#   ✔ Accepted
#   ✔ 266/266 cases passed (16 ms)
#   ✔ Your runtime beats 7.18 % of kotlin submissions
#   ✔ Your memory usage beats 16.41 % of kotlin submissions (46.6 MB)
# Submitting: kotlin_solutions/32.longest-valid-parentheses.kt
# - Downloading longest-valid-parentheses
#   ✔ Accepted
#   ✔ 235/235 cases passed (18 ms)
#   ✔ Your runtime beats 52.04 % of kotlin submissions
#   ✔ Your memory usage beats 43.88 % of kotlin submissions (47.2 MB)
# Submitting: kotlin_solutions/33.search-in-rotated-sorted-array.kt
# - Downloading search-in-rotated-sorted-array
#   ✔ Accepted
#   ✔ 196/196 cases passed (10 ms)
#   ✔ Your runtime beats 32.58 % of kotlin submissions
#   ✔ Your memory usage beats 5.37 % of kotlin submissions (48.1 MB)
# Submitting: kotlin_solutions/34.find-first-and-last-position-of-element-in-sorted-array.kt
# - Downloading find-first-and-last-position-of-element-in-sorted-array
#   ✔ Accepted
#   ✔ 88/88 cases passed (22 ms)
#   ✔ Your runtime beats 5.47 % of kotlin submissions
#   ✔ Your memory usage beats 6.69 % of kotlin submissions (51.3 MB)
# Submitting: kotlin_solutions/35.search-insert-position.kt
# - Downloading search-insert-position
#   ✔ Accepted
#   ✔ 66/66 cases passed (7 ms)
#   ✔ Your runtime beats 19.66 % of kotlin submissions
#   ✔ Your memory usage beats 5.64 % of kotlin submissions (48.3 MB)
# Submitting: kotlin_solutions/36.valid-sudoku.kt
# - Downloading valid-sudoku
#   ✔ Accepted
#   ✔ 507/507 cases passed (39 ms)
#   ✔ Your runtime beats 5.15 % of kotlin submissions
#   ✔ Your memory usage beats 5.67 % of kotlin submissions (56.1 MB)
# Submitting: kotlin_solutions/37.sudoku-solver.kt
# - Downloading sudoku-solver
#   ✔ Accepted
#   ✔ 8/8 cases passed (783 ms)
#   ✔ Your runtime beats 6.67 % of kotlin submissions
#   ✔ Your memory usage beats 17.78 % of kotlin submissions (54.1 MB)
# Submitting: kotlin_solutions/38.count-and-say.kt
# - Downloading count-and-say
#   ✔ Accepted
#   ✔ 30/30 cases passed (68 ms)
#   ✔ Your runtime beats 5.56 % of kotlin submissions
#   ✔ Your memory usage beats 5.56 % of kotlin submissions (47.9 MB)
# Submitting: kotlin_solutions/39.combination-sum.kt
# - Downloading combination-sum
#   ✔ Accepted
#   ✔ 160/160 cases passed (27 ms)
#   ✔ Your runtime beats 15.38 % of kotlin submissions
#   ✔ Your memory usage beats 5.46 % of kotlin submissions (56.9 MB)
# Submitting: kotlin_solutions/40.combination-sum-ii.kt
# - Downloading combination-sum-ii
#   ✔ Accepted
#   ✔ 176/176 cases passed (166 ms)
#   ✔ Your runtime beats 5.56 % of kotlin submissions
#   ✔ Your memory usage beats 5.55 % of kotlin submissions (64.4 MB)
# Submitting: kotlin_solutions/41.first-missing-positive.kt
# - Downloading first-missing-positive
#   ✔ Accepted
#   ✔ 179/179 cases passed (2869 ms)
#   ✔ Your runtime beats 5.26 % of kotlin submissions
#   ✔ Your memory usage beats 11.18 % of kotlin submissions (70.8 MB)
# Submitting: kotlin_solutions/42.trapping-rain-water.kt
# - Downloading trapping-rain-water
#   ✔ Accepted
#   ✔ 324/324 cases passed (35 ms)
#   ✔ Your runtime beats 9.28 % of kotlin submissions
#   ✔ Your memory usage beats 42.76 % of kotlin submissions (50.4 MB)
# Submitting: kotlin_solutions/43.multiply-strings.kt
# - Downloading multiply-strings
#   ✔ Accepted
#   ✔ 311/311 cases passed (14 ms)
#   ✔ Your runtime beats 60 % of kotlin submissions
#   ✔ Your memory usage beats 83.33 % of kotlin submissions (43.1 MB)
# Submitting: kotlin_solutions/44.wildcard-matching.kt
# - Downloading wildcard-matching
#   ✔ Accepted
#   ✔ 1812/1812 cases passed (65 ms)
#   ✔ Your runtime beats 16.07 % of kotlin submissions
#   ✔ Your memory usage beats 32.14 % of kotlin submissions (50.7 MB)
# Submitting: kotlin_solutions/45.jump-game-ii.kt
# - Downloading jump-game-ii
#   ✔ Accepted
#   ✔ 110/110 cases passed (33 ms)
#   ✔ Your runtime beats 30.63 % of kotlin submissions
#   ✔ Your memory usage beats 43.91 % of kotlin submissions (49.2 MB)
# Submitting: kotlin_solutions/46.permutations.kt
# - Downloading permutations
#   ✔ Accepted
#   ✔ 26/26 cases passed (31 ms)
#   ✔ Your runtime beats 5.82 % of kotlin submissions
#   ✔ Your memory usage beats 6.58 % of kotlin submissions (49.4 MB)
# Submitting: kotlin_solutions/47.permutations-ii.kt
# - Downloading permutations-ii
#   ✔ Accepted
#   ✔ 33/33 cases passed (128 ms)
#   ✔ Your runtime beats 10.71 % of kotlin submissions
#   ✔ Your memory usage beats 18.57 % of kotlin submissions (53.5 MB)
# Submitting: kotlin_solutions/48.rotate-image.kt
# - Downloading rotate-image
#   ✔ Accepted
#   ✔ 21/21 cases passed (20 ms)
#   ✔ Your runtime beats 5.02 % of kotlin submissions
#   ✔ Your memory usage beats 5.48 % of kotlin submissions (46.3 MB)
# Submitting: kotlin_solutions/49.group-anagrams.kt
# - Downloading group-anagrams
#   ✔ Accepted
#   ✔ 128/128 cases passed (61 ms)
#   ✔ Your runtime beats 20.4 % of kotlin submissions
#   ✔ Your memory usage beats 14.27 % of kotlin submissions (56.2 MB)
# Submitting: kotlin_solutions/50.pow-x-n.kt
# - Downloading powx-n
#   ✔ Accepted
#   ✔ 307/307 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 39.2 % of kotlin submissions (42.4 MB)
# Submitting: kotlin_solutions/51.n-queens.kt
# - Downloading n-queens
#   ✔ Accepted
#   ✔ 9/9 cases passed (43 ms)
#   ✔ Your runtime beats 8.7 % of kotlin submissions
#   ✔ Your memory usage beats 5.22 % of kotlin submissions (53.2 MB)
# Submitting: kotlin_solutions/52.n-queens-ii.kt
# - Downloading n-queens-ii
#   ✔ Accepted
#   ✔ 9/9 cases passed (16 ms)
#   ✔ Your runtime beats 25.86 % of kotlin submissions
#   ✔ Your memory usage beats 13.79 % of kotlin submissions (46.5 MB)
# Submitting: kotlin_solutions/53.maximum-subarray.kt
# - Downloading maximum-subarray
#   ✔ Accepted
#   ✔ 210/210 cases passed (55 ms)
#   ✔ Your runtime beats 5 % of kotlin submissions
#   ✔ Your memory usage beats 17.5 % of kotlin submissions (67.5 MB)
# Submitting: kotlin_solutions/54.spiral-matrix.kt
# - Downloading spiral-matrix
#   ✔ Accepted
#   ✔ 26/26 cases passed (4 ms)
#   ✔ Your runtime beats 31.4 % of kotlin submissions
#   ✔ Your memory usage beats 28.68 % of kotlin submissions (41.5 MB)
# Submitting: kotlin_solutions/55.jump-game.kt
# - Downloading jump-game
#   ✔ Accepted
#   ✔ 178/178 cases passed (63 ms)
#   ✔ Your runtime beats 23.5 % of kotlin submissions
#   ✔ Your memory usage beats 32.9 % of kotlin submissions (51.8 MB)
# Submitting: kotlin_solutions/56.merge-intervals.kt
# - Downloading merge-intervals
#   ✔ Accepted
#   ✔ 172/172 cases passed (32 ms)
#   ✔ Your runtime beats 16.07 % of kotlin submissions
#   ✔ Your memory usage beats 61.26 % of kotlin submissions (54.7 MB)
# Submitting: kotlin_solutions/57.insert-interval.kt
# - Downloading insert-interval
#   ✔ Accepted
#   ✔ 158/158 cases passed (22 ms)
#   ✔ Your runtime beats 14.39 % of kotlin submissions
#   ✔ Your memory usage beats 31.06 % of kotlin submissions (49 MB)
# Submitting: kotlin_solutions/58.length-of-last-word.kt
# - Downloading length-of-last-word
#   ✔ Accepted
#   ✔ 60/60 cases passed (15 ms)
#   ✔ Your runtime beats 7.38 % of kotlin submissions
#   ✔ Your memory usage beats 24.36 % of kotlin submissions (43.4 MB)
# Submitting: kotlin_solutions/59.spiral-matrix-ii.kt
# - Downloading spiral-matrix-ii
#   ✔ Accepted
#   ✔ 20/20 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 16.28 % of kotlin submissions (41.6 MB)
# Submitting: kotlin_solutions/60.permutation-sequence.kt
# - Downloading permutation-sequence
#   ✔ Accepted
#   ✔ 200/200 cases passed (15 ms)
#   ✔ Your runtime beats 40 % of kotlin submissions
#   ✔ Your memory usage beats 43.33 % of kotlin submissions (43.2 MB)
# Submitting: kotlin_solutions/61.rotate-list.kt
# - Downloading rotate-list
#   ✔ Accepted
#   ✔ 232/232 cases passed (14 ms)
#   ✔ Your runtime beats 5.3 % of kotlin submissions
#   ✔ Your memory usage beats 5.3 % of kotlin submissions (45.2 MB)
# Submitting: kotlin_solutions/62.unique-paths.kt
# - Downloading unique-paths
#   ✔ Accepted
#   ✔ 64/64 cases passed (5 ms)
#   ✔ Your runtime beats 10.07 % of kotlin submissions
#   ✔ Your memory usage beats 17.71 % of kotlin submissions (40.6 MB)
# Submitting: kotlin_solutions/63.unique-paths-ii.kt
# - Downloading unique-paths-ii
#   ✔ Accepted
#   ✔ 42/42 cases passed (5 ms)
#   ✔ Your runtime beats 22.22 % of kotlin submissions
#   ✔ Your memory usage beats 9.52 % of kotlin submissions (46.2 MB)
# Submitting: kotlin_solutions/64.minimum-path-sum.kt
# - Downloading minimum-path-sum
#   ✔ Accepted
#   ✔ 66/66 cases passed (9 ms)
#   ✔ Your runtime beats 24.54 % of kotlin submissions
#   ✔ Your memory usage beats 20.24 % of kotlin submissions (55.9 MB)
# Submitting: kotlin_solutions/65.valid-number.kt
# - Downloading valid-number
#   ✔ Accepted
#   ✔ 1499/1499 cases passed (30 ms)
#   ✔ Your runtime beats 15.79 % of kotlin submissions
#   ✔ Your memory usage beats 13.16 % of kotlin submissions (48.9 MB)
# Submitting: kotlin_solutions/66.plus-one.kt
# - Downloading plus-one
#   ✔ Accepted
#   ✔ 114/114 cases passed (13 ms)
#   ✔ Your runtime beats 14.73 % of kotlin submissions
#   ✔ Your memory usage beats 20.59 % of kotlin submissions (45.6 MB)
# Submitting: kotlin_solutions/67.add-binary.kt
# - Downloading add-binary
#   ✔ Accepted
#   ✔ 296/296 cases passed (8 ms)
#   ✔ Your runtime beats 52.42 % of kotlin submissions
#   ✔ Your memory usage beats 53.23 % of kotlin submissions (43.4 MB)
# Submitting: kotlin_solutions/68.text-justification.kt
# - Downloading text-justification
#   ✔ Accepted
#   ✔ 29/29 cases passed (16 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
#   ✔ Your memory usage beats 27.37 % of kotlin submissions (43.8 MB)
# Submitting: kotlin_solutions/69.sqrt-x.kt
# - Downloading sqrtx
#   ✔ Accepted
#   ✔ 1019/1019 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 74.78 % of kotlin submissions (40.8 MB)
# Submitting: kotlin_solutions/70.climbing-stairs.kt
# - Downloading climbing-stairs
#   ✔ Accepted
#   ✔ 45/45 cases passed (4 ms)
#   ✔ Your runtime beats 9.54 % of kotlin submissions
#   ✔ Your memory usage beats 26.53 % of kotlin submissions (40.4 MB)
# Submitting: kotlin_solutions/71.simplify-path.kt
# - Downloading simplify-path
#   ✔ Accepted
#   ✔ 264/264 cases passed (21 ms)
#   ✔ Your runtime beats 66.15 % of kotlin submissions
#   ✔ Your memory usage beats 69.23 % of kotlin submissions (46.2 MB)
# Submitting: kotlin_solutions/72.edit-distance.kt
# - Downloading edit-distance
#   ✔ Accepted
#   ✔ 1149/1149 cases passed (5 ms)
#   ✔ Your runtime beats 86.75 % of kotlin submissions
#   ✔ Your memory usage beats 19.2 % of kotlin submissions (48.4 MB)
# Submitting: kotlin_solutions/73.set-matrix-zeroes.kt
# - Downloading set-matrix-zeroes
#   ✔ Accepted
#   ✔ 202/202 cases passed (17 ms)
#   ✔ Your runtime beats 6.97 % of kotlin submissions
#   ✔ Your memory usage beats 6.97 % of kotlin submissions (57.2 MB)
# Submitting: kotlin_solutions/74.search-a-2-d-matrix.kt
# - Downloading search-a-2d-matrix
#   ✔ Accepted
#   ✔ 133/133 cases passed (10 ms)
#   ✔ Your runtime beats 18.44 % of kotlin submissions
#   ✔ Your memory usage beats 12.77 % of kotlin submissions (46 MB)
# Submitting: kotlin_solutions/75.sort-colors.kt
# - Downloading sort-colors
#   ✔ Accepted
#   ✔ 89/89 cases passed (6 ms)
#   ✔ Your runtime beats 18.91 % of kotlin submissions
#   ✔ Your memory usage beats 18.91 % of kotlin submissions (42.3 MB)
# Submitting: kotlin_solutions/76.minimum-window-substring.kt
# - Downloading minimum-window-substring
#   ✔ Accepted
#   ✔ 268/268 cases passed (225 ms)
#   ✔ Your runtime beats 8 % of kotlin submissions
#   ✔ Your memory usage beats 18.77 % of kotlin submissions (53.6 MB)
# Submitting: kotlin_solutions/77.combinations.kt
# - Downloading combinations
#   ✔ Accepted
#   ✔ 27/27 cases passed (148 ms)
#   ✔ Your runtime beats 5.03 % of kotlin submissions
#   ✔ Your memory usage beats 5.53 % of kotlin submissions (141.1 MB)
# Submitting: kotlin_solutions/78.subsets.kt
# - Downloading subsets
#   ✔ Accepted
#   ✔ 10/10 cases passed (7 ms)
#   ✔ Your runtime beats 70.44 % of kotlin submissions
#   ✔ Your memory usage beats 24.21 % of kotlin submissions (44.6 MB)
# Submitting: kotlin_solutions/79.word-search.kt
# - Downloading word-search
#   ✔ Accepted
#   ✔ 88/88 cases passed (1228 ms)
#   ✔ Your runtime beats 6.37 % of kotlin submissions
#   ✔ Your memory usage beats 25.22 % of kotlin submissions (50.8 MB)
# Submitting: kotlin_solutions/80.remove-duplicates-from-sorted-array-ii.kt
# - Downloading remove-duplicates-from-sorted-array-ii
#   ✔ Accepted
#   ✔ 170/170 cases passed (170 ms)
#   ✔ Your runtime beats 65.09 % of kotlin submissions
#   ✔ Your memory usage beats 6.8 % of kotlin submissions (51.8 MB)
# Submitting: kotlin_solutions/81.search-in-rotated-sorted-array-ii.kt
# - Downloading search-in-rotated-sorted-array-ii
#   ✔ Accepted
#   ✔ 282/282 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 79.59 % of kotlin submissions (43.6 MB)
# Submitting: kotlin_solutions/82.remove-duplicates-from-sorted-list-ii.kt
# - Downloading remove-duplicates-from-sorted-list-ii
#   ✔ Accepted
#   ✔ 166/166 cases passed (10 ms)
#   ✔ Your runtime beats 5.56 % of kotlin submissions
#   ✔ Your memory usage beats 5.56 % of kotlin submissions (46.5 MB)
# Submitting: kotlin_solutions/83.remove-duplicates-from-sorted-list.kt
# - Downloading remove-duplicates-from-sorted-list
#   ✔ Accepted
#   ✔ 168/168 cases passed (9 ms)
#   ✔ Your runtime beats 1.72 % of kotlin submissions
#   ✔ Your memory usage beats 5.17 % of kotlin submissions (46.4 MB)
# Submitting: kotlin_solutions/84.largest-rectangle-in-histogram.kt
# - Downloading largest-rectangle-in-histogram
#   ✔ Accepted
#   ✔ 99/99 cases passed (80 ms)
#   ✔ Your runtime beats 19.47 % of kotlin submissions
#   ✔ Your memory usage beats 62.6 % of kotlin submissions (63 MB)
# Submitting: kotlin_solutions/85.maximal-rectangle.kt
# - Downloading maximal-rectangle
#   ✔ Accepted
#   ✔ 76/76 cases passed (72 ms)
#   ✔ Your runtime beats 5.91 % of kotlin submissions
#   ✔ Your memory usage beats 42.13 % of kotlin submissions (52.4 MB)
# Submitting: kotlin_solutions/86.partition-list.kt
# - Downloading partition-list
#   ✔ Accepted
#   ✔ 168/168 cases passed (8 ms)
#   ✔ Your runtime beats 4.35 % of kotlin submissions
#   ✔ Your memory usage beats 6.52 % of kotlin submissions (43 MB)
# Submitting: kotlin_solutions/87.scramble-string.kt
# - Downloading scramble-string
#   ✔ Accepted
#   ✔ 290/290 cases passed (50 ms)
#   ✔ Your runtime beats 56.52 % of kotlin submissions
#   ✔ Your memory usage beats 47.83 % of kotlin submissions (51.3 MB)
# Submitting: kotlin_solutions/88.merge-sorted-array.kt
# - Downloading merge-sorted-array
#   ✔ Accepted
#   ✔ 59/59 cases passed (8 ms)
#   ✔ Your runtime beats 16.29 % of kotlin submissions
#   ✔ Your memory usage beats 17.48 % of kotlin submissions (43.2 MB)
# Submitting: kotlin_solutions/89.gray-code.kt
# - Downloading gray-code
#   ✔ Accepted
#   ✔ 16/16 cases passed (16 ms)
#   ✔ Your runtime beats 40 % of kotlin submissions
#   ✔ Your memory usage beats 90 % of kotlin submissions (52.7 MB)
# Submitting: kotlin_solutions/90.subsets-ii.kt
# - Downloading subsets-ii
#   ✔ Accepted
#   ✔ 20/20 cases passed (19 ms)
#   ✔ Your runtime beats 17.42 % of kotlin submissions
#   ✔ Your memory usage beats 39.39 % of kotlin submissions (47.4 MB)
# Submitting: kotlin_solutions/91.decode-ways.kt
# - Downloading decode-ways
#   ✔ Accepted
#   ✔ 269/269 cases passed (12 ms)
#   ✔ Your runtime beats 20.74 % of kotlin submissions
#   ✔ Your memory usage beats 26.67 % of kotlin submissions (43.4 MB)
# Submitting: kotlin_solutions/92.reverse-linked-list-ii.kt
# - Downloading reverse-linked-list-ii
#   ✔ Accepted
#   ✔ 44/44 cases passed (4 ms)
#   ✔ Your runtime beats 6.49 % of kotlin submissions
#   ✔ Your memory usage beats 12.34 % of kotlin submissions (41.4 MB)
# Submitting: kotlin_solutions/93.restore-ip-addresses.kt
# - Downloading restore-ip-addresses
#   ✔ Accepted
#   ✔ 146/146 cases passed (27 ms)
#   ✔ Your runtime beats 21.67 % of kotlin submissions
#   ✔ Your memory usage beats 23.33 % of kotlin submissions (47.8 MB)
# Submitting: kotlin_solutions/94.binary-tree-inorder-traversal.kt
# - Downloading binary-tree-inorder-traversal
#   ✔ Accepted
#   ✔ 71/71 cases passed (10 ms)
#   ✔ Your runtime beats 5.72 % of kotlin submissions
#   ✔ Your memory usage beats 16.62 % of kotlin submissions (42.3 MB)
# Submitting: kotlin_solutions/95.unique-binary-search-trees-ii.kt
# - Downloading unique-binary-search-trees-ii
#   ✔ Accepted
#   ✔ 8/8 cases passed (14 ms)
#   ✔ Your runtime beats 14.29 % of kotlin submissions
#   ✔ Your memory usage beats 76.19 % of kotlin submissions (45.5 MB)
# Submitting: kotlin_solutions/96.unique-binary-search-trees.kt
# - Downloading unique-binary-search-trees
#   ✔ Accepted
#   ✔ 19/19 cases passed (3125 ms)
#   ✔ Your runtime beats 5.88 % of kotlin submissions
#   ✔ Your memory usage beats 5.88 % of kotlin submissions (41 MB)
# Submitting: kotlin_solutions/97.interleaving-string.kt
# - Downloading interleaving-string
#   ✔ Accepted
#   ✔ 107/107 cases passed (1670 ms)
#   ✔ Your runtime beats 7.94 % of kotlin submissions
#   ✔ Your memory usage beats 7.94 % of kotlin submissions (44.1 MB)
# Submitting: kotlin_solutions/98.validate-binary-search-tree.kt
# - Downloading validate-binary-search-tree
#   ✔ Accepted
#   ✔ 86/86 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 65.81 % of kotlin submissions (45 MB)
# Submitting: kotlin_solutions/99.recover-binary-search-tree.kt
# - Downloading recover-binary-search-tree
#   ✔ Accepted
#   ✔ 1919/1919 cases passed (6 ms)
#   ✔ Your runtime beats 20 % of kotlin submissions
#   ✔ Your memory usage beats 66.67 % of kotlin submissions (45.9 MB)
# Submitting: kotlin_solutions/100.same-tree.kt
# - Downloading same-tree
#   ✔ Accepted
#   ✔ 67/67 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of kotlin submissions
#   ✔ Your memory usage beats 39.91 % of kotlin submissions (41 MB)

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-02-12 21:04:33
