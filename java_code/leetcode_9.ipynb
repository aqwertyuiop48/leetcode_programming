# %%
# %%capture
from google.colab import userdata
import os

# 1. Install and Clone (Moved inside to keep the notebook clean)
# !npm install -g leetcode-tools/leetcode-cli
# Use 'or true' to prevent error if folder already exists
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git || true

# 2. Pull from Colab's Secret storage
try:
    user_name = userdata.get('LEETCODE_USERNAME_2')
    user_cookie = userdata.get('LEETCODE_TOKEN_2')
except userdata.SecretNotFoundError:
    # This won't show because of %%capture, but it helps for debugging
    raise Exception("Secrets not found. Check the Key icon on the left!")

if user_name and user_cookie:
    # 3. Assign to OS environment
    os.environ['LEETCODE_USERNAME_2'] = user_name
    os.environ['LEETCODE_TOKEN_2'] = user_cookie

    # 4. Run the login silently
    # We use 'unbuffer' or direct pipe to ensure it processes correctly
    # !export PATH=$PATH:$(npm config get prefix)/bin && \
     printf "%s\n%s\n" "$LEETCODE_USERNAME_2" "$LEETCODE_TOKEN_2" | leetcode user -c

# %%
# %%bash
#
#
# # top 100 answers
# # 1. Silence the node warnings
# export NODE_NO_WARNINGS=1
#
# # 2. Run the loop
# cd leetcode_programming && for f in $(ls -v java_solutions/*.java | sed -n '801,900p'); do
#     echo "Submitting: $f"
#
#     leetcode submit "$f" 2>&1 \
#     | tr '\r' '\n' \
#     | grep -vE "Sending code to judge|Waiting for judge result" \
#     | grep -v "^$"
#
#     sleep 7
# done
# Out:
# Submitting: java_solutions/2234.maximum-total-beauty-of-the-gardens.java
# - Downloading maximum-total-beauty-of-the-gardens
#   ✔ Accepted
#   ✔ 77/77 cases passed (229 ms)
#   ✔ Your runtime beats 33.33 % of java submissions
#   ✔ Your memory usage beats 6.25 % of java submissions (106.3 MB)
# Submitting: java_solutions/2235.add-two-integers.java
# - Downloading add-two-integers
#   ✔ Accepted
#   ✔ 262/262 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 63.07 % of java submissions (42.3 MB)
# Submitting: java_solutions/2236.root-equals-sum-of-children.java
# - Downloading root-equals-sum-of-children
#   ✔ Accepted
#   ✔ 309/309 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 82.68 % of java submissions (42.8 MB)
# Submitting: java_solutions/2239.find-closest-number-to-zero.java
# - Downloading find-closest-number-to-zero
#   ✔ Accepted
#   ✔ 227/227 cases passed (4 ms)
#   ✔ Your runtime beats 8.61 % of java submissions
#   ✔ Your memory usage beats 45.28 % of java submissions (46.9 MB)
# Submitting: java_solutions/2242.maximum-score-of-a-node-sequence.java
# - Downloading maximum-score-of-a-node-sequence
#   ✔ Accepted
#   ✔ 75/75 cases passed (212 ms)
#   ✔ Your runtime beats 5.26 % of java submissions
#   ✔ Your memory usage beats 85.26 % of java submissions (127.8 MB)
# Submitting: java_solutions/2243.calculate-digit-sum-of-a-string.java
# - Downloading calculate-digit-sum-of-a-string
#   ✔ Accepted
#   ✔ 121/121 cases passed (14 ms)
#   ✔ Your runtime beats 5.29 % of java submissions
#   ✔ Your memory usage beats 7.45 % of java submissions (44.7 MB)
# Submitting: java_solutions/2246.longest-path-with-different-adjacent-characters.java
# - Downloading longest-path-with-different-adjacent-characters
#   ✔ Accepted
#   ✔ 142/142 cases passed (80 ms)
#   ✔ Your runtime beats 83.4 % of java submissions
#   ✔ Your memory usage beats 99.23 % of java submissions (103.3 MB)
# Submitting: java_solutions/2248.intersection-of-multiple-arrays.java
# - Downloading intersection-of-multiple-arrays
#   ✔ Accepted
#   ✔ 151/151 cases passed (26 ms)
#   ✔ Your runtime beats 5.2 % of java submissions
#   ✔ Your memory usage beats 7.56 % of java submissions (53.5 MB)
# Submitting: java_solutions/2251.number-of-flowers-in-full-bloom.java
# - Downloading number-of-flowers-in-full-bloom
#   ✔ Accepted
#   ✔ 53/53 cases passed (462 ms)
#   ✔ Your runtime beats 5.14 % of java submissions
#   ✔ Your memory usage beats 82.01 % of java submissions (108.2 MB)
# Submitting: java_solutions/2255.count-prefixes-of-a-given-string.java
# - Downloading count-prefixes-of-a-given-string
#   ✔ Accepted
#   ✔ 123/123 cases passed (3 ms)
#   ✔ Your runtime beats 3.93 % of java submissions
#   ✔ Your memory usage beats 62.39 % of java submissions (44.8 MB)
# Submitting: java_solutions/2258.escape-the-spreading-fire.java
# - Downloading escape-the-spreading-fire
#   ✔ Accepted
#   ✔ 57/57 cases passed (235 ms)
#   ✔ Your runtime beats 5.32 % of java submissions
#   ✔ Your memory usage beats 5.32 % of java submissions (57.1 MB)
# Submitting: java_solutions/2259.remove-digit-from-number-to-maximize-result.java
# - Downloading remove-digit-from-number-to-maximize-result
#   ✔ Accepted
#   ✔ 112/112 cases passed (9 ms)
#   ✔ Your runtime beats 5.03 % of java submissions
#   ✔ Your memory usage beats 5.95 % of java submissions (44.2 MB)
# Submitting: java_solutions/2262.total-appeal-of-a-string.java
# - Downloading total-appeal-of-a-string
#   ✔ Accepted
#   ✔ 77/77 cases passed (13 ms)
#   ✔ Your runtime beats 27.15 % of java submissions
#   ✔ Your memory usage beats 17.88 % of java submissions (47.2 MB)
# Submitting: java_solutions/2264.largest-3-same-digit-number-in-string.java
# - Downloading largest-3-same-digit-number-in-string
#   ✔ Accepted
#   ✔ 141/141 cases passed (9 ms)
#   ✔ Your runtime beats 9.38 % of java submissions
#   ✔ Your memory usage beats 38.61 % of java submissions (44.4 MB)
# Submitting: java_solutions/2267.check-if-there-is-a-valid-parentheses-string-path.java
# - Downloading check-if-there-is-a-valid-parentheses-string-path
#   ✔ Accepted
#   ✔ 81/81 cases passed (241 ms)
#   ✔ Your runtime beats 5.71 % of java submissions
#   ✔ Your memory usage beats 80 % of java submissions (59.6 MB)
# Submitting: java_solutions/2269.find-the-k-beauty-of-a-number.java
# - Downloading find-the-k-beauty-of-a-number
#   ✔ Accepted
#   ✔ 183/183 cases passed (7 ms)
#   ✔ Your runtime beats 4.93 % of java submissions
#   ✔ Your memory usage beats 11.73 % of java submissions (42.9 MB)
# Submitting: java_solutions/2272.substring-with-largest-variance.java
# - Downloading substring-with-largest-variance
#   ✔ Accepted
#   ✔ 139/139 cases passed (689 ms)
#   ✔ Your runtime beats 6.17 % of java submissions
#   ✔ Your memory usage beats 12.35 % of java submissions (53.3 MB)
# Submitting: java_solutions/2273.find-resultant-array-after-removing-anagrams.java
# - Downloading find-resultant-array-after-removing-anagrams
#   ✔ Accepted
#   ✔ 202/202 cases passed (40 ms)
#   ✔ Your runtime beats 7.03 % of java submissions
#   ✔ Your memory usage beats 5.39 % of java submissions (53.7 MB)
# Submitting: java_solutions/2276.count-integers-in-intervals.java
# - Downloading count-integers-in-intervals
#   ✔ Accepted
#   ✔ 73/73 cases passed (140 ms)
#   ✔ Your runtime beats 10.08 % of java submissions
#   ✔ Your memory usage beats 50 % of java submissions (127 MB)
# Submitting: java_solutions/2278.percentage-of-letter-in-string.java
# - Downloading percentage-of-letter-in-string
#   ✔ Accepted
#   ✔ 86/86 cases passed (2 ms)
#   ✔ Your runtime beats 7.38 % of java submissions
#   ✔ Your memory usage beats 42.4 % of java submissions (42.9 MB)
# Submitting: java_solutions/2281.sum-of-total-strength-of-wizards.java
# - Downloading sum-of-total-strength-of-wizards
#   ✔ Accepted
#   ✔ 82/82 cases passed (350 ms)
#   ✔ Your runtime beats 5.63 % of java submissions
#   ✔ Your memory usage beats 29.58 % of java submissions (108.6 MB)
# Submitting: java_solutions/2283.check-if-number-has-equal-digit-count-and-digit-value.java
# - Downloading check-if-number-has-equal-digit-count-and-digit-value
#   ✔ Accepted
#   ✔ 433/433 cases passed (8 ms)
#   ✔ Your runtime beats 4.33 % of java submissions
#   ✔ Your memory usage beats 6.56 % of java submissions (43.8 MB)
# Submitting: java_solutions/2286.booking-concert-tickets-in-groups.java
# - Downloading booking-concert-tickets-in-groups
#   ✔ Accepted
#   ✔ 97/97 cases passed (385 ms)
#   ✔ Your runtime beats 25 % of java submissions
#   ✔ Your memory usage beats 13.89 % of java submissions (137.1 MB)
# Submitting: java_solutions/2287.rearrange-characters-to-make-target-string.java
# - Downloading rearrange-characters-to-make-target-string
#   ✔ Accepted
#   ✔ 116/116 cases passed (9 ms)
#   ✔ Your runtime beats 2.25 % of java submissions
#   ✔ Your memory usage beats 5.5 % of java submissions (43.9 MB)
# Submitting: java_solutions/2290.minimum-obstacle-removal-to-reach-corner.java
# - Downloading minimum-obstacle-removal-to-reach-corner
#   ✔ Accepted
#   ✔ 54/54 cases passed (744 ms)
#   ✔ Your runtime beats 5.21 % of java submissions
#   ✔ Your memory usage beats 5.66 % of java submissions (144.1 MB)
# Submitting: java_solutions/2296.design-a-text-editor.java
# - Downloading design-a-text-editor
#   ✔ Accepted
#   ✔ 45/45 cases passed (220 ms)
#   ✔ Your runtime beats 7.62 % of java submissions
#   ✔ Your memory usage beats 86.73 % of java submissions (92.5 MB)
# Submitting: java_solutions/2301.match-substring-after-replacement.java
# - Downloading match-substring-after-replacement
#   ✔ Accepted
#   ✔ 117/117 cases passed (693 ms)
#   ✔ Your runtime beats 5.66 % of java submissions
#   ✔ Your memory usage beats 7.55 % of java submissions (53.3 MB)
# Submitting: java_solutions/2302.count-subarrays-with-score-less-than-k.java
# - Downloading count-subarrays-with-score-less-than-k
#   ✔ Accepted
#   ✔ 167/167 cases passed (178 ms)
#   ✔ Your runtime beats 2.1 % of java submissions
#   ✔ Your memory usage beats 10.37 % of java submissions (90.9 MB)
# Submitting: java_solutions/2303.calculate-amount-paid-in-taxes.java
# - Downloading calculate-amount-paid-in-taxes
#   ✔ Accepted
#   ✔ 227/227 cases passed (8 ms)
#   ✔ Your runtime beats 3.93 % of java submissions
#   ✔ Your memory usage beats 28.65 % of java submissions (47.5 MB)
# Submitting: java_solutions/2306.naming-a-company.java
# - Downloading naming-a-company
#   ✔ Accepted
#   ✔ 89/89 cases passed (179 ms)
#   ✔ Your runtime beats 47.69 % of java submissions
#   ✔ Your memory usage beats 32.31 % of java submissions (79 MB)
# Submitting: java_solutions/2309.greatest-english-letter-in-upper-and-lower-case.java
# - Downloading greatest-english-letter-in-upper-and-lower-case
#   ✔ Accepted
#   ✔ 113/113 cases passed (11 ms)
#   ✔ Your runtime beats 13.97 % of java submissions
#   ✔ Your memory usage beats 43.65 % of java submissions (43.6 MB)
# Submitting: java_solutions/2312.selling-pieces-of-wood.java
# - Downloading selling-pieces-of-wood
#   ✔ Accepted
#   ✔ 60/60 cases passed (199 ms)
#   ✔ Your runtime beats 5.66 % of java submissions
#   ✔ Your memory usage beats 5.66 % of java submissions (64.9 MB)
# Submitting: java_solutions/2315.count-asterisks.java
# - Downloading count-asterisks
#   ✔ Accepted
#   ✔ 69/69 cases passed (21 ms)
#   ✔ Your runtime beats 2.36 % of java submissions
#   ✔ Your memory usage beats 7.9 % of java submissions (47.1 MB)
# Submitting: java_solutions/2318.number-of-distinct-roll-sequences.java
# - Downloading number-of-distinct-roll-sequences
#   ✔ Accepted
#   ✔ 64/64 cases passed (1427 ms)
#   ✔ Your runtime beats 6.82 % of java submissions
#   ✔ Your memory usage beats 70.45 % of java submissions (53 MB)
# Submitting: java_solutions/2319.check-if-matrix-is-x-matrix.java
# - Downloading check-if-matrix-is-x-matrix
#   ✔ Accepted
#   ✔ 84/84 cases passed (7 ms)
#   ✔ Your runtime beats 0.86 % of java submissions
#   ✔ Your memory usage beats 9.16 % of java submissions (47.9 MB)
# Submitting: java_solutions/2321.maximum-score-of-spliced-array.java
# - Downloading maximum-score-of-spliced-array
#   ✔ Accepted
#   ✔ 34/34 cases passed (9 ms)
#   ✔ Your runtime beats 24.77 % of java submissions
#   ✔ Your memory usage beats 8.26 % of java submissions (93.8 MB)
# Submitting: java_solutions/2322.minimum-score-after-removals-on-a-tree.java
# - Downloading minimum-score-after-removals-on-a-tree
#   ✔ Accepted
#   ✔ 65/65 cases passed (751 ms)
#   ✔ Your runtime beats 10.53 % of java submissions
#   ✔ Your memory usage beats 14.47 % of java submissions (54.7 MB)
# Submitting: java_solutions/2325.decode-the-message.java
# - Downloading decode-the-message
#   ✔ Accepted
#   ✔ 69/69 cases passed (14 ms)
#   ✔ Your runtime beats 24.09 % of java submissions
#   ✔ Your memory usage beats 5.48 % of java submissions (51.5 MB)
# Submitting: java_solutions/2328.number-of-increasing-paths-in-a-grid.java
# - Downloading number-of-increasing-paths-in-a-grid
#   ✔ Accepted
#   ✔ 36/36 cases passed (331 ms)
#   ✔ Your runtime beats 5.16 % of java submissions
#   ✔ Your memory usage beats 25.82 % of java submissions (100 MB)
# Submitting: java_solutions/2334.subarray-with-elements-greater-than-varying-threshold.java
# - Downloading subarray-with-elements-greater-than-varying-threshold
#   ✔ Accepted
#   ✔ 68/68 cases passed (287 ms)
#   ✔ Your runtime beats 7.06 % of java submissions
#   ✔ Your memory usage beats 23.53 % of java submissions (99.3 MB)
# Submitting: java_solutions/2338.count-the-number-of-ideal-arrays.java
# - Downloading count-the-number-of-ideal-arrays
#   ✔ Accepted
#   ✔ 47/47 cases passed (309 ms)
#   ✔ Your runtime beats 20.58 % of java submissions
#   ✔ Your memory usage beats 23.47 % of java submissions (60.3 MB)
# Submitting: java_solutions/2341.maximum-number-of-pairs-in-array.java
# - Downloading maximum-number-of-pairs-in-array
#   ✔ Accepted
#   ✔ 128/128 cases passed (13 ms)
#   ✔ Your runtime beats 6.21 % of java submissions
#   ✔ Your memory usage beats 8.54 % of java submissions (50.5 MB)
# Submitting: java_solutions/2344.minimum-deletions-to-make-array-divisible.java
# - Downloading minimum-deletions-to-make-array-divisible
#   ✔ Accepted
#   ✔ 49/49 cases passed (49 ms)
#   ✔ Your runtime beats 5.37 % of java submissions
#   ✔ Your memory usage beats 5.1 % of java submissions (110.9 MB)
# Submitting: java_solutions/2350.shortest-impossible-sequence-of-rolls.java
# - Downloading shortest-impossible-sequence-of-rolls
#   ✔ Accepted
#   ✔ 65/65 cases passed (15 ms)
#   ✔ Your runtime beats 72.46 % of java submissions
#   ✔ Your memory usage beats 79.71 % of java submissions (81.5 MB)
# Submitting: java_solutions/2351.first-letter-to-appear-twice.java
# - Downloading first-letter-to-appear-twice
#   ✔ Accepted
#   ✔ 92/92 cases passed (4 ms)
#   ✔ Your runtime beats 0.98 % of java submissions
#   ✔ Your memory usage beats 8.45 % of java submissions (43.5 MB)
# Submitting: java_solutions/2354.number-of-excellent-pairs.java
# - Downloading number-of-excellent-pairs
#   ✔ Accepted
#   ✔ 56/56 cases passed (56 ms)
#   ✔ Your runtime beats 43.33 % of java submissions
#   ✔ Your memory usage beats 48.33 % of java submissions (108 MB)
# Submitting: java_solutions/2357.make-array-zero-by-subtracting-equal-amounts.java
# - Downloading make-array-zero-by-subtracting-equal-amounts
#   ✔ Accepted
#   ✔ 95/95 cases passed (5 ms)
#   ✔ Your runtime beats 11.4 % of java submissions
#   ✔ Your memory usage beats 7.79 % of java submissions (43.7 MB)
# Submitting: java_solutions/2360.longest-cycle-in-a-graph.java
# - Downloading longest-cycle-in-a-graph
#   ✔ Accepted
#   ✔ 81/81 cases passed (90 ms)
#   ✔ Your runtime beats 30.46 % of java submissions
#   ✔ Your memory usage beats 99.87 % of java submissions (84.3 MB)
# Submitting: java_solutions/2363.merge-similar-items.java
# - Downloading merge-similar-items
#   ✔ Accepted
#   ✔ 49/49 cases passed (17 ms)
#   ✔ Your runtime beats 6.59 % of java submissions
#   ✔ Your memory usage beats 6.59 % of java submissions (53.5 MB)
# Submitting: java_solutions/2366.minimum-replacements-to-sort-the-array.java
# - Downloading minimum-replacements-to-sort-the-array
#   ✔ Accepted
#   ✔ 48/48 cases passed (38 ms)
#   ✔ Your runtime beats 6.12 % of java submissions
#   ✔ Your memory usage beats 98.47 % of java submissions (83.3 MB)
# Submitting: java_solutions/2367.number-of-arithmetic-triplets.java
# - Downloading number-of-arithmetic-triplets
#   ✔ Accepted
#   ✔ 104/104 cases passed (24 ms)
#   ✔ Your runtime beats 8.5 % of java submissions
#   ✔ Your memory usage beats 7.17 % of java submissions (45.5 MB)
# Submitting: java_solutions/2376.count-special-integers.java
# - Downloading count-special-integers
#   ✔ Accepted
#   ✔ 120/120 cases passed (19 ms)
#   ✔ Your runtime beats 45.22 % of java submissions
#   ✔ Your memory usage beats 5.73 % of java submissions (49.4 MB)
# Submitting: java_solutions/2379.minimum-recolors-to-get-k-consecutive-black-blocks.java
# - Downloading minimum-recolors-to-get-k-consecutive-black-blocks
#   ✔ Accepted
#   ✔ 122/122 cases passed (9 ms)
#   ✔ Your runtime beats 2.2 % of java submissions
#   ✔ Your memory usage beats 7.72 % of java submissions (44.8 MB)
# Submitting: java_solutions/2382.maximum-segment-sum-after-removals.java
# - Downloading maximum-segment-sum-after-removals
#   ✔ Accepted
#   ✔ 42/42 cases passed (94 ms)
#   ✔ Your runtime beats 22.73 % of java submissions
#   ✔ Your memory usage beats 100 % of java submissions (121.4 MB)
# Submitting: java_solutions/2386.find-the-k-sum-of-an-array.java
# - Downloading find-the-k-sum-of-an-array
#   ✔ Accepted
#   ✔ 111/111 cases passed (92 ms)
#   ✔ Your runtime beats 7.23 % of java submissions
#   ✔ Your memory usage beats 6.02 % of java submissions (90 MB)
# Submitting: java_solutions/2392.build-a-matrix-with-conditions.java
# - Downloading build-a-matrix-with-conditions
#   ✔ Accepted
#   ✔ 53/53 cases passed (35 ms)
#   ✔ Your runtime beats 5.52 % of java submissions
#   ✔ Your memory usage beats 5.15 % of java submissions (162.6 MB)
# Submitting: java_solutions/2395.find-subarrays-with-equal-sum.java
# - Downloading find-subarrays-with-equal-sum
#   ✔ Accepted
#   ✔ 42/42 cases passed (5 ms)
#   ✔ Your runtime beats 6.98 % of java submissions
#   ✔ Your memory usage beats 14.24 % of java submissions (43.7 MB)
# Submitting: java_solutions/2398.maximum-number-of-robots-within-budget.java
# - Downloading maximum-number-of-robots-within-budget
#   ✔ Accepted
#   ✔ 82/82 cases passed (133 ms)
#   ✔ Your runtime beats 20.83 % of java submissions
#   ✔ Your memory usage beats 7.05 % of java submissions (80.7 MB)
# Submitting: java_solutions/2399.check-distances-between-same-letters.java
# - Downloading check-distances-between-same-letters
#   ✔ Accepted
#   ✔ 335/335 cases passed (6 ms)
#   ✔ Your runtime beats 4.84 % of java submissions
#   ✔ Your memory usage beats 8.12 % of java submissions (44.6 MB)
# Submitting: java_solutions/2402.meeting-rooms-iii.java
# - Downloading meeting-rooms-iii
#   ✔ Accepted
#   ✔ 82/82 cases passed (475 ms)
#   ✔ Your runtime beats 5.04 % of java submissions
#   ✔ Your memory usage beats 5.04 % of java submissions (186.4 MB)
# Submitting: java_solutions/2404.most-frequent-even-element.java
# - Downloading most-frequent-even-element
#   ✔ Accepted
#   ✔ 219/219 cases passed (45 ms)
#   ✔ Your runtime beats 9.23 % of java submissions
#   ✔ Your memory usage beats 5.65 % of java submissions (53.4 MB)
# Submitting: java_solutions/2407.longest-increasing-subsequence-ii.java
# - Downloading longest-increasing-subsequence-ii
#   ✔ Accepted
#   ✔ 84/84 cases passed (395 ms)
#   ✔ Your runtime beats 5.49 % of java submissions
#   ✔ Your memory usage beats 18.29 % of java submissions (78.2 MB)
# Submitting: java_solutions/2409.count-days-spent-together.java
# - Downloading count-days-spent-together
#   ✔ Accepted
#   ✔ 51/51 cases passed (6 ms)
#   ✔ Your runtime beats 4.56 % of java submissions
#   ✔ Your memory usage beats 10.37 % of java submissions (43.4 MB)
# Submitting: java_solutions/2412.minimum-money-required-before-transactions.java
# - Downloading minimum-money-required-before-transactions
#   ✔ Accepted
#   ✔ 56/56 cases passed (14 ms)
#   ✔ Your runtime beats 25 % of java submissions
#   ✔ Your memory usage beats 79.55 % of java submissions (127.1 MB)
# Submitting: java_solutions/2413.smallest-even-multiple.java
# - Downloading smallest-even-multiple
#   ✔ Accepted
#   ✔ 150/150 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 74.08 % of java submissions (42.1 MB)
# Submitting: java_solutions/2416.sum-of-prefix-scores-of-strings.java
# - Downloading sum-of-prefix-scores-of-strings
#   ✔ Accepted
#   ✔ 38/38 cases passed (1139 ms)
#   ✔ Your runtime beats 5.26 % of java submissions
#   ✔ Your memory usage beats 98.83 % of java submissions (163.6 MB)
# Submitting: java_solutions/2418.sort-the-people.java
# - Downloading sort-the-people
#   ✔ Accepted
#   ✔ 68/68 cases passed (13 ms)
#   ✔ Your runtime beats 27.43 % of java submissions
#   ✔ Your memory usage beats 42.25 % of java submissions (47.3 MB)
# Submitting: java_solutions/2421.number-of-good-paths.java
# - Downloading number-of-good-paths
#   ✔ Accepted
#   ✔ 134/134 cases passed (87 ms)
#   ✔ Your runtime beats 67.07 % of java submissions
#   ✔ Your memory usage beats 75.61 % of java submissions (137.3 MB)
# Submitting: java_solutions/2423.remove-letter-to-equalize-frequency.java
# - Downloading remove-letter-to-equalize-frequency
#   ✔ Accepted
#   ✔ 51/51 cases passed (26 ms)
#   ✔ Your runtime beats 5.44 % of java submissions
#   ✔ Your memory usage beats 6.38 % of java submissions (52.6 MB)
# Submitting: java_solutions/2426.number-of-pairs-satisfying-inequality.java
# - Downloading number-of-pairs-satisfying-inequality
#   ✔ Accepted
#   ✔ 61/61 cases passed (288 ms)
#   ✔ Your runtime beats 5.23 % of java submissions
#   ✔ Your memory usage beats 19.77 % of java submissions (88.5 MB)
# Submitting: java_solutions/2427.number-of-common-factors.java
# - Downloading number-of-common-factors
#   ✔ Accepted
#   ✔ 76/76 cases passed (4 ms)
#   ✔ Your runtime beats 0.55 % of java submissions
#   ✔ Your memory usage beats 46.49 % of java submissions (42.2 MB)
# Submitting: java_solutions/2430.maximum-deletions-on-a-string.java
# - Downloading maximum-deletions-on-a-string
#   ✔ Accepted
#   ✔ 129/129 cases passed (700 ms)
#   ✔ Your runtime beats 11.54 % of java submissions
#   ✔ Your memory usage beats 5.77 % of java submissions (288.7 MB)
# Submitting: java_solutions/2432.the-employee-that-worked-on-the-longest-task.java
# - Downloading the-employee-that-worked-on-the-longest-task
#   ✔ Accepted
#   ✔ 514/514 cases passed (13 ms)
#   ✔ Your runtime beats 4.02 % of java submissions
#   ✔ Your memory usage beats 5.03 % of java submissions (53 MB)
# Submitting: java_solutions/2435.paths-in-matrix-whose-sum-is-divisible-by-k.java
# - Downloading paths-in-matrix-whose-sum-is-divisible-by-k
#   ✔ Accepted
#   ✔ 88/88 cases passed (197 ms)
#   ✔ Your runtime beats 6.01 % of java submissions
#   ✔ Your memory usage beats 87.72 % of java submissions (89.8 MB)
# Submitting: java_solutions/2437.number-of-valid-clock-times.java
# - Downloading number-of-valid-clock-times
#   ✔ Accepted
#   ✔ 55/55 cases passed (135 ms)
#   ✔ Your runtime beats 5.3 % of java submissions
#   ✔ Your memory usage beats 5.3 % of java submissions (47.1 MB)
# Submitting: java_solutions/2440.create-components-with-same-value.java
# - Downloading create-components-with-same-value
#   ✔ Accepted
#   ✔ 43/43 cases passed (688 ms)
#   ✔ Your runtime beats 8.82 % of java submissions
#   ✔ Your memory usage beats 5.88 % of java submissions (138 MB)
# Submitting: java_solutions/2441.largest-positive-integer-that-exists-with-its-negative.java
# - Downloading largest-positive-integer-that-exists-with-its-negative
#   ✔ Accepted
#   ✔ 339/339 cases passed (134 ms)
#   ✔ Your runtime beats 5.02 % of java submissions
#   ✔ Your memory usage beats 20.14 % of java submissions (47.4 MB)
# Submitting: java_solutions/2444.count-subarrays-with-fixed-bounds.java
# - Downloading count-subarrays-with-fixed-bounds
#   ✔ Accepted
#   ✔ 53/53 cases passed (18 ms)
#   ✔ Your runtime beats 5.42 % of java submissions
#   ✔ Your memory usage beats 5.21 % of java submissions (100.2 MB)
# Submitting: java_solutions/2446.determine-if-two-events-have-conflict.java
# - Downloading determine-if-two-events-have-conflict
#   ✔ Accepted
#   ✔ 129/129 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 38.91 % of java submissions (43 MB)
# Submitting: java_solutions/2448.minimum-cost-to-make-array-equal.java
# - Downloading minimum-cost-to-make-array-equal
#   ✔ Accepted
#   ✔ 48/48 cases passed (74 ms)
#   ✔ Your runtime beats 5.39 % of java submissions
#   ✔ Your memory usage beats 16.67 % of java submissions (65.5 MB)
# Submitting: java_solutions/2449.minimum-number-of-operations-to-make-arrays-similar.java
# - Downloading minimum-number-of-operations-to-make-arrays-similar
#   ✔ Accepted
#   ✔ 32/32 cases passed (76 ms)
#   ✔ Your runtime beats 53.23 % of java submissions
#   ✔ Your memory usage beats 72.58 % of java submissions (99.1 MB)
# Submitting: java_solutions/2451.odd-string-difference.java
# - Downloading odd-string-difference
#   ✔ Accepted
#   ✔ 40/40 cases passed (13 ms)
#   ✔ Your runtime beats 5.48 % of java submissions
#   ✔ Your memory usage beats 6.05 % of java submissions (44.1 MB)
# Submitting: java_solutions/2454.next-greater-element-iv.java
# - Downloading next-greater-element-iv
#   ✔ Accepted
#   ✔ 51/51 cases passed (389 ms)
#   ✔ Your runtime beats 5.14 % of java submissions
#   ✔ Your memory usage beats 49.8 % of java submissions (121.9 MB)
# Submitting: java_solutions/2455.average-value-of-even-numbers-that-are-divisible-by-three.java
# - Downloading average-value-of-even-numbers-that-are-divisible-by-three
#   ✔ Accepted
#   ✔ 181/181 cases passed (6 ms)
#   ✔ Your runtime beats 1.16 % of java submissions
#   ✔ Your memory usage beats 7.38 % of java submissions (46.7 MB)
# Submitting: java_solutions/2458.height-of-binary-tree-after-subtree-removal-queries.java
# - Downloading height-of-binary-tree-after-subtree-removal-queries
#   ✔ Accepted
#   ✔ 40/40 cases passed (38 ms)
#   ✔ Your runtime beats 54.01 % of java submissions
#   ✔ Your memory usage beats 55.61 % of java submissions (110.2 MB)
# Submitting: java_solutions/2460.apply-operations-to-an-array.java
# - Downloading apply-operations-to-an-array
#   ✔ Accepted
#   ✔ 36/36 cases passed (10 ms)
#   ✔ Your runtime beats 2.78 % of java submissions
#   ✔ Your memory usage beats 12.45 % of java submissions (45.8 MB)
# Submitting: java_solutions/2463.minimum-total-distance-traveled.java
# - Downloading minimum-total-distance-traveled
#   ✔ Accepted
#   ✔ 40/40 cases passed (248 ms)
#   ✔ Your runtime beats 6.45 % of java submissions
#   ✔ Your memory usage beats 38.71 % of java submissions (53.6 MB)
# Submitting: java_solutions/2465.number-of-distinct-averages.java
# - Downloading number-of-distinct-averages
#   ✔ Accepted
#   ✔ 36/36 cases passed (9 ms)
#   ✔ Your runtime beats 4.61 % of java submissions
#   ✔ Your memory usage beats 13.82 % of java submissions (43.5 MB)
# Submitting: java_solutions/2468.split-message-based-on-limit.java
# - Downloading split-message-based-on-limit
#   ✔ Accepted
#   ✔ 94/94 cases passed (72 ms)
#   ✔ Your runtime beats 27.92 % of java submissions
#   ✔ Your memory usage beats 5.19 % of java submissions (59.5 MB)
# Submitting: java_solutions/2469.convert-the-temperature.java
# - Downloading convert-the-temperature
#   ✔ Accepted
#   ✔ 74/74 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 29.83 % of java submissions (46.3 MB)
# Submitting: java_solutions/2472.maximum-number-of-non-overlapping-palindrome-substrings.java
# - Downloading maximum-number-of-non-overlapping-palindrome-substrings
#   ✔ Accepted
#   ✔ 56/56 cases passed (24 ms)
#   ✔ Your runtime beats 37.66 % of java submissions
#   ✔ Your memory usage beats 30.13 % of java submissions (52.5 MB)
# Submitting: java_solutions/2475.number-of-unequal-triplets-in-array.java
# - Downloading number-of-unequal-triplets-in-array
#   ✔ Accepted
#   ✔ 104/104 cases passed (70 ms)
#   ✔ Your runtime beats 5.04 % of java submissions
#   ✔ Your memory usage beats 8.11 % of java submissions (53.3 MB)
# Submitting: java_solutions/2478.number-of-beautiful-partitions.java
# - Downloading number-of-beautiful-partitions
#   ✔ Accepted
#   ✔ 74/74 cases passed (604 ms)
#   ✔ Your runtime beats 46.43 % of java submissions
#   ✔ Your memory usage beats 25 % of java submissions (54.8 MB)
# Submitting: java_solutions/2481.minimum-cuts-to-divide-a-circle.java
# - Downloading minimum-cuts-to-divide-a-circle
#   ✔ Accepted
#   ✔ 100/100 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 12.98 % of java submissions (42.4 MB)
# Submitting: java_solutions/2484.count-palindromic-subsequences.java
# - Downloading count-palindromic-subsequences
#   ✔ Accepted
#   ✔ 63/63 cases passed (235 ms)
#   ✔ Your runtime beats 9.17 % of java submissions
#   ✔ Your memory usage beats 18.35 % of java submissions (85.9 MB)
# Submitting: java_solutions/2485.find-the-pivot-integer.java
# - Downloading find-the-pivot-integer
#   ✔ Accepted
#   ✔ 428/428 cases passed (0 ms)
#   ✔ Your runtime beats 100 % of java submissions
#   ✔ Your memory usage beats 59.91 % of java submissions (42.3 MB)
# Submitting: java_solutions/2487.remove-nodes-from-linked-list.java
# - Downloading remove-nodes-from-linked-list
#   ✔ Accepted
#   ✔ 32/32 cases passed (13 ms)
#   ✔ Your runtime beats 55.36 % of java submissions
#   ✔ Your memory usage beats 20.57 % of java submissions (135.6 MB)
# Submitting: java_solutions/2488.count-subarrays-with-median-k.java
# - Downloading count-subarrays-with-median-k
#   ✔ Accepted
#   ✔ 45/45 cases passed (24 ms)
#   ✔ Your runtime beats 6.46 % of java submissions
#   ✔ Your memory usage beats 5.06 % of java submissions (78.3 MB)
# Submitting: java_solutions/2490.circular-sentence.java
# - Downloading circular-sentence
#   ✔ Accepted
#   ✔ 266/266 cases passed (6 ms)
#   ✔ Your runtime beats 4.58 % of java submissions
#   ✔ Your memory usage beats 44.32 % of java submissions (43.4 MB)
# Submitting: java_solutions/2493.divide-nodes-into-the-maximum-number-of-groups.java
# - Downloading divide-nodes-into-the-maximum-number-of-groups
#   ✔ Accepted
#   ✔ 57/57 cases passed (650 ms)
#   ✔ Your runtime beats 11.29 % of java submissions
#   ✔ Your memory usage beats 5.64 % of java submissions (56.8 MB)

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2026-04-14 12:56:03
