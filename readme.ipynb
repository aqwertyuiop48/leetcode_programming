# %% [markdown]
# ## TO BE EXECUTED IN GOOGLE COLAB

# %%
'''
Add the Secret to Colab
- Open your Colab notebook.
- Click the Key icon on the left-hand toolbar.
- Click "Add new secret".Set the Name (e.g., LEETCODE_USERNAME) and paste your token into the Value field.
- Important: Toggle the "Notebook access" switch to ON for that specific secret.

For leetcode cli (reference: https://fantasy.tistory.com/entry/leetcode-cli-cookie-login)
'''
from google.colab import userdata
my_username = userdata.get('LEETCODE_USERNAME')
my_token = userdata.get('LEETCODE_TOKEN')

# !npm install -g leetcode-tools/leetcode-cli
# !git clone https://github.com/aqwertyuiop48/leetcode_programming.git
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧npm warn deprecated inflight@1.0.6: This module is not supported, and leaks memory. Do not use it. Check out lru-cache if you want a good and tested way to coalesce async requests by a key value, which is much more comprehensive and powerful.
# ⠧⠇npm warn deprecated rimraf@2.7.1: Rimraf versions prior to v4 are no longer supported
# ⠇npm warn deprecated har-validator@5.1.5: this library is no longer supported
# ⠇npm warn deprecated abab@1.0.4: Use your platform's native atob() and btoa() methods instead
# ⠇npm warn deprecated glob@7.2.3: Old versions of glob are not supported, and contain widely publicized security vulnerabilities, which have been fixed in the current version. Please update. Support for old versions may be purchased (at exorbitant rates) by contacting i@izs.me
# ⠏⠋⠙npm warn deprecated uuid@3.4.0: Please upgrade  to version 7 or higher.  Older versions may use Math.random() in certain circumstances, which is known to be problematic.  See https://v8.dev/blog/math-random for details.
# ⠙npm warn deprecated request@2.88.0: request has been deprecated, see https://github.com/request/request/issues/3142
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼
# changed 195 packages in 14s
# ⠼
# ⠼9 packages are looking for funding
# ⠼  run `npm fund` for details
# ⠼fatal: destination path 'leetcode_programming' already exists and is not an empty directory.

# %%
# %%bash -s "{my_username}" "{my_token}"
# (printf "%s\n%s" "$1" "$2" | leetcode user -c) > /dev/null 2>&1

# %%
# !leetcode user
# !cd leetcode_programming && ls && for f in $(ls -v kotlin_solutions/*.kt); do echo "Submitting: $f"; leetcode submit "$f"; sleep 7; done
# Out:
#  Premium   User                 Host
# ------------------------------------------------------------
#     ✘      9zBRyP9hkZ           https://leetcode.com
# (node:16423) Warning: Accessing non-existent property 'padLevels' of module exports inside circular dependency
# (Use `node --trace-warnings ...` to show where the warning was created)
# felis_leo_internship  java_solutions  kotlin_solutions	README.md  script.sh
# Submitting: kotlin_solutions/1.two-sum.kt
# ⠋ Sending code to judge(node:16437) Warning: Accessing non-existent property 'padLevels' of module exports inside circular dependency
# (Use `node --trace-warnings ...` to show where the warning was created)
# ⠙ Sending code to judge⠹ Sending code to judge⠸ Sending code to judge⠼ Sending code to judge⠴ Sending code to judge⠦ Sending code to judge⠋ Waiting for judge result⠙ Waiting for judge result⠹ Waiting for judge result⠋ Waiting for judge result⠙ Waiting for judge result⠹ Waiting for judge result⠸ Waiting for judge result⠼ Waiting for judge result⠋ Waiting for judge result⠙ Waiting for judge result⠹ Waiting for judge result⠸ Waiting for judge result⠼ Waiting for judge result⠋ Waiting for judge result⠙ Waiting for judge result⠹ Waiting for judge result⠋ Waiting for judge result⠙ Waiting for judge result⠹ Waiting for judge result⠋ Waiting for judge result⠙ Waiting for judge result⠹ Waiting for judge result⠋ Waiting for judge result⠙ Waiting for judge result⠹ Waiting for judge result⠋ Waiting for judge result⠙ Waiting for judge result⠹ Waiting for judge result⠋ Waiting for judge result⠙ Waiting for judge result⠹ Waiting for judge result⠋ Waiting for judge result⠙ Waiting for judge result⠹ Waiting for judge result⠸ Waiting for judge result⠋ Waiting for judge result⠙ Waiting for judge result⠹ Waiting for judge result⠋ Waiting for judge result⠙ Waiting for judge result⠹ Waiting for judge result⠋ Waiting for judge result⠙ Waiting for judge result⠹ Waiting for judge result⠸ Waiting for judge result⠼ Waiting for judge result⠴ Waiting for judge result  ✔ Accepted
#   ✔ 63/63 cases passed (37 ms)
#   ✔ Your runtime beats 16.09 % of kotlin submissions
#   ✔ Your memory usage beats 7.12 % of kotlin submissions (49.3 MB)
# Submitting: kotlin_solutions/2.add-two-numbers.kt
# ⠋ Sending code to judge(node:16493) Warning: Accessing non-existent property 'padLevels' of module exports inside circular dependency
# (Use `node --trace-warnings ...` to show where the warning was created)
# ⠙ Sending code to judge⠹ Sending code to judge⠸ Sending code to judge⠼ Sending code to judge⠋ Waiting for judge result⠙ Waiting for judge result⠹ Waiting for judge result⠋ Waiting for judge result⠙ Waiting for judge result⠹ Waiting for judge result⠋ Waiting for judge result⠙ Waiting for judge result⠹ Waiting for judge result⠋ Waiting for judge result⠙ Waiting for judge result⠹ Waiting for judge result⠸ Waiting for judge result⠋ Waiting for judge result⠙ Waiting for judge result⠹ Waiting for judge result⠋ Waiting for judge result⠙ Waiting for judge result⠹ Waiting for judge result⠋ Waiting for judge result⠙ Waiting for judge result⠹ Waiting for judge result⠸ Waiting for judge result⠼ Waiting for judge result⠴ Waiting for judge result⠦ Waiting for judge result⠧ Waiting for judge result⠇ Waiting for judge result⠏ Waiting for judge result⠋ Waiting for judge result⠙ Waiting for judge result⠹ Waiting for judge result⠋ Waiting for judge result⠙ Waiting for judge result⠹ Waiting for judge result⠸ Waiting for judge result⠼ Waiting for judge result⠴ Waiting for judge result⠦ Waiting for judge result⠧ Waiting for judge result⠇ Waiting for judge result⠏ Waiting for judge result⠋ Waiting for judge result⠙ Waiting for judge result⠹ Waiting for judge result⠸ Waiting for judge result⠋ Waiting for judge result⠙ Waiting for judge result⠹ Waiting for judge result⠸ Waiting for judge result⠼ Waiting for judge result⠴ Waiting for judge result⠦ Waiting for judge result⠧ Waiting for judge result  ✔ Accepted
#   ✔ 1569/1569 cases passed (78 ms)
#   ✔ Your runtime beats 5.02 % of kotlin submissions
#   ✔ Your memory usage beats 5.02 % of kotlin submissions (59.5 MB)
# Submitting: kotlin_solutions/3.longest-substring-without-repeating-characters.kt
# ⠋ Downloading longest-substring-without-repeating-characters(node:16553) Warning: Accessing non-existent property 'padLevels' of module exports inside circular dependency
# (Use `node --trace-warnings ...` to show where the warning was created)
# ⠙ Downloading longest-substring-without-repeating-characters⠹ Downloading longest-substring-without-repeating-characters⠸ Downloading longest-substring-without-repeating-characters⠼ Downloading longest-substring-without-repeating-characters⠴ Downloading longest-substring-without-repeating-characters⠋ Sending code to judge⠙ Sending code to judge⠹ Sending code to judge⠸ Sending code to judge⠋ Waiting for judge result⠙ Waiting for judge result⠹ Waiting for judge result⠸ Waiting for judge result⠋ Waiting for judge result⠙ Waiting for judge result⠹ Waiting for judge result⠸ Waiting for judge result⠼ Waiting for judge result⠴ Waiting for judge result⠦ Waiting for judge result⠧ Waiting for judge result⠇ Waiting for judge result⠋ Waiting for judge result⠙ Waiting for judge result⠹ Waiting for judge result⠋ Waiting for judge result⠙ Waiting for judge result⠹ Waiting for judge result⠋ Waiting for judge result⠙ Waiting for judge result⠹ Waiting for judge result⠋ Waiting for judge result⠙ Waiting for judge result⠹ Waiting for judge result⠋ Waiting for judge result⠙ Waiting for judge result⠹ Waiting for judge result⠋ Waiting for judge result⠙ Waiting for judge result⠹ Waiting for judge result⠸ Waiting for judge result⠼ Waiting for judge result⠴ Waiting for judge result⠋ Waiting for judge result⠙ Waiting for judge result⠹ Waiting for judge result⠸ Waiting for judge result⠼ Waiting for judge result⠴ Waiting for judge result⠦ Waiting for judge result⠧ Waiting for judge result⠇ Waiting for judge result⠏ Waiting for judge result⠋ Waiting for judge result  ✔ Accepted
#   ✔ 988/988 cases passed (14 ms)
#   ✔ Your runtime beats 30.28 % of kotlin submissions
#   ✔ Your memory usage beats 89.8 % of kotlin submissions (45.2 MB)
# Submitting: kotlin_solutions/4.median-of-two-sorted-arrays.kt
# ⠋ Downloading median-of-two-sorted-arrays(node:16609) Warning: Accessing non-existent property 'padLevels' of module exports inside circular dependency
# (Use `node --trace-warnings ...` to show where the warning was created)
# ⠙ Downloading median-of-two-sorted-arrays⠹ Downloading median-of-two-sorted-arrays⠸ Downloading median-of-two-sorted-arrays⠋ Sending code to judge⠙ Sending code to judge⠹ Sending code to judge⠸ Sending code to judge⠋ Waiting for judge result⠙ Waiting for judge result⠹ Waiting for judge result⠸ Waiting for judge result⠼ Waiting for judge result⠴ Waiting for judge result⠦ Waiting for judge result⠧ Waiting for judge result⠇ Waiting for judge result⠋ Waiting for judge result⠙ Waiting for judge result⠹ Waiting for judge result⠋ Waiting for judge result⠙ Waiting for judge result⠹ Waiting for judge result⠸ Waiting for judge result⠼ Waiting for judge result⠴ Waiting for judge result⠋ Waiting for judge result⠙ Waiting for judge result⠹ Waiting for judge result⠸ Waiting for judge result⠼ Waiting for judge result⠴ Waiting for judge result⠦ Waiting for judge result⠧ Waiting for judge result⠋ Waiting for judge result⠙ Waiting for judge result⠹ Waiting for judge result⠸ Waiting for judge result⠼ Waiting for judge result⠴ Waiting for judge result⠋ Waiting for judge result⠙ Waiting for judge result⠹ Waiting for judge result⠋ Waiting for judge result⠙ Waiting for judge result⠹ Waiting for judge result⠋ Waiting for judge result⠙ Waiting for judge result⠹ Waiting for judge result⠋ Waiting for judge result⠙ Waiting for judge result⠹ Waiting for judge result⠋ Waiting for judge result⠙ Waiting for judge result⠹ Waiting for judge result⠋ Waiting for judge result⠙ Waiting for judge result⠹ Waiting for judge result⠸ Waiting for judge result⠋ Waiting for judge result⠙ Waiting for judge result⠹ Waiting for judge result⠸ Waiting for judge result⠼ Waiting for judge result⠴ Waiting for judge result⠦ Waiting for judge result⠧ Waiting for judge result⠇ Waiting for judge result⠏ Waiting for judge result⠋ Waiting for judge result  ✔ Accepted
#   ✔ 2098/2098 cases passed (26 ms)
#   ✔ Your runtime beats 8.01 % of kotlin submissions
#   ✔ Your memory usage beats 23.68 % of kotlin submissions (53.3 MB)
# ^C
